# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756816
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Genuine Qiskit VQE on shifted Pauli Hamiltonian
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SPSA

from qiskit.primitives import StatevectorEstimator


# ============================================================
# Variational circuit
# ============================================================

def variational_circuit(nq, layers):

    qc = QuantumCircuit(nq)

    nparams = 2 * nq * layers

    params = ParameterVector("θ", nparams)

    p = 0

    for l in range(layers):

        # ----------------------------------------------------
        # Single-qubit rotations
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(params[p], q)
            qc.rz(params[p + 1], q)

            p += 2

        # ----------------------------------------------------
        # Entanglement layer
        # ----------------------------------------------------

        if l != layers - 1:

            # even bonds
            if l % 2 == 0:

                for q in range(0, nq - 1, 2):
                    qc.cz(q, q + 1)

            # odd bonds
            else:

                for q in range(1, nq - 1, 2):
                    qc.cz(q, q + 1)

    return qc


# ============================================================
# Ansatz
# ============================================================

nqubits = 8

# start modestly
layers = 8

ansatz = variational_circuit(
    nqubits,
    layers
)

# ============================================================
# Estimator
# ============================================================

estimator = StatevectorEstimator()

# ============================================================
# Optimizer
# ============================================================

optimizer = SPSA(
    maxiter=5000
)

# ============================================================
# VQE
# ============================================================
initial_point = 0.01 * np.random.randn(
    ansatz.num_parameters
)
vqe = VQE(
    estimator=estimator,
    ansatz=ansatz,
    optimizer=optimizer,
    initial_point=initial_point
)

# ============================================================
# Run VQE
# ============================================================

print("\nRunning VQE...\n")

result = vqe.compute_minimum_eigenvalue(
    H_pauli_shifted
)

# ============================================================
# Shifted energy
# ============================================================

E_shifted = result.eigenvalue.real

# ============================================================
# Physical energy
# ============================================================

E_vqe = E_shifted + identity_shift

# ============================================================
# Optimal parameters
# ============================================================

optimal_params = result.optimal_parameters

# ============================================================
# Optimized circuit
# ============================================================

optimal_circuit = ansatz.assign_parameters(
    optimal_params
)

# ============================================================
# VQE state
# ============================================================

psi_vqe = Statevector.from_instruction(
    optimal_circuit
).data

# ============================================================
# Fidelity
# ============================================================

Fidelity = np.abs(
    np.vdot(psi_loc, psi_vqe)
)**2

# ============================================================
# Results
# ============================================================

print("\n================================")
print("Exact energy :", E0_loc)
print("VQE energy   :", E_vqe)
print("Energy error :", abs(E_vqe - E0_loc))
print("Fidelity     :", Fidelity)
print("Layers        :", layers)
print("Pauli terms   :", len(H_pauli_shifted))
print("================================")
# Out:
# Running VQE...
#
#
# ================================
# Exact energy : 1.0554722545756816
# VQE energy   : 1.062713557498367
# Energy error : 0.007241302922685433
# Fidelity     : 0.9978873060290868
# Layers        : 8
# Pauli terms   : 111
# ================================

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Multi-parameter scan with robust eigenstate tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0
layers = 8

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance for low-energy manifold selection
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },

    {
        "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-5
    },

    {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#"*80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#"*80)

    case_results = []

    # --------------------------------------------------------
    # Eigenstate tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "="*60)
        print(f"Running λ = {lam:.3f}")
        print("="*60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(Hloc_sparse)

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(H_op)

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ----------------------------------------------------
        # Ansatz
        # ----------------------------------------------------

        ansatz = variational_circuit(
            nq=nqubits,
            layers=layers
        )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)

        # ====================================================
        # Multiple VQE restarts
        # ====================================================

        trial_results = []

        for trial in range(n_restarts):

            print(f"\nRestart {trial}")

            # ------------------------------------------------
            # Initial point
            # ------------------------------------------------

            if trial == 0 and previous_optimal_point is not None:

                # warm-start continuation
                initial_point = previous_optimal_point

            else:

                # random restart
                initial_point = 0.01 * np.random.randn(
                    ansatz.num_parameters
                )

            # ------------------------------------------------
            # VQE
            # ------------------------------------------------

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = vqe.compute_minimum_eigenvalue(
                H_pauli_shifted
            )

            # ------------------------------------------------
            # Physical energy
            # ------------------------------------------------

            E_trial = (
                np.real(result.eigenvalue)
                + identity_shift
            )

            # ------------------------------------------------
            # Build trial state
            # ------------------------------------------------

            qc_trial = ansatz.assign_parameters(
                result.optimal_parameters
            )

            psi_trial = Statevector.from_instruction(
                qc_trial
            ).data

            # ------------------------------------------------
            # Overlap tracking
            # ------------------------------------------------

            if previous_state is None:

                overlap = 1.0

            else:

                overlap = abs(np.vdot(
                    previous_state,
                    psi_trial
                ))**2

            print(f"Energy  : {E_trial:.12f}")
            print(f"Overlap : {overlap:.12f}")

            # ------------------------------------------------
            # Store candidate
            # ------------------------------------------------

            trial_results.append({

                'energy': E_trial,
                'overlap': overlap,
                'state': psi_trial,
                'result': result

            })

        # ====================================================
        # Hybrid energy + overlap selection
        # ====================================================

        energies = np.array([
            t['energy']
            for t in trial_results
        ])

        E_min = np.min(energies)

        # ----------------------------------------------------
        # Keep only low-energy candidates
        # ----------------------------------------------------

        filtered_candidates = [

            t for t in trial_results

            if (t['energy'] - E_min) < energy_tol
        ]

        # ----------------------------------------------------
        # Among low-energy states,
        # maximize overlap continuity
        # ----------------------------------------------------

        best_candidate = max(
            filtered_candidates,
            key=lambda x: x['overlap']
        )

        best_state = best_candidate['state']

        best_result = best_candidate['result']

        best_energy = best_candidate['energy']

        best_overlap = best_candidate['overlap']

        # ====================================================
        # Final selected state
        # ====================================================

        psi_vqe = best_state

        E_vqe = best_energy

        previous_state = psi_vqe

        previous_optimal_point = (
            best_result.optimal_point
        )

        # ----------------------------------------------------
        # Fidelity
        # ----------------------------------------------------

        F = fidelity(psi_exact, psi_vqe)

        # ----------------------------------------------------
        # Store
        # ----------------------------------------------------

        data = {
            'case': label,
            'lambda': lam,
            'mI2': mI2,
            'f': f,
            'E_exact': E_exact,
            'E_vqe': E_vqe,
            'error': abs(E_exact - E_vqe),
            'fidelity': F,
            'tracking_overlap': best_overlap
        }

        case_results.append(data)
        all_results.append(data)

        # ----------------------------------------------------
        # Print
        # ----------------------------------------------------

        print("\nFINAL SELECTED STATE")

        print(f"Exact energy     : {E_exact:.12f}")
        print(f"VQE energy       : {E_vqe:.12f}")
        print(f"Energy error     : {abs(E_exact - E_vqe):.6e}")
        print(f"Fidelity         : {F:.12f}")
        print(f"Tracking overlap : {best_overlap:.12f}")

    # ========================================================
    # Case summary
    # ========================================================

    print("\n")
    print("="*110)
    print(f"SUMMARY : {label}")
    print("="*110)

    print(
        f"{'lambda':<12} "
        f"{'Exact E':<18} "
        f"{'VQE E':<18} "
        f"{'Error':<15} "
        f"{'Fidelity':<15} "
        f"{'TrackOverlap':<15}"
    )

    print("="*110)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f} "
            f"{r['E_exact']:<18.10f} "
            f"{r['E_vqe']:<18.10f} "
            f"{r['error']:<15.4e} "
            f"{r['fidelity']:<15.10f} "
            f"{r['tracking_overlap']:<15.10f}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Restart 0
# Energy  : 1.006161738855
# Overlap : 1.000000000000
#
# Restart 1
# Energy  : 1.006161747653
# Overlap : 1.000000000000
#
# Restart 2
# Energy  : 1.006161756739
# Overlap : 1.000000000000
#
# Restart 3
# Energy  : 1.006161751969
# Overlap : 1.000000000000
#
# Restart 4
# Energy  : 1.006161715790
# Overlap : 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161738855
# Energy error     : 1.069624e-08
# Fidelity         : 0.999999991889
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Restart 0
# Energy  : 1.018641813153
# Overlap : 0.999849269004
#
# Restart 1
# Energy  : 1.018641483752
# Overlap : 0.999848971301
#
# Restart 2
# Energy  : 1.018641467296
# Overlap : 0.999849003847
#
# Restart 3
# Energy  : 1.018641469093
# Overlap : 0.999848951801
#
# Restart 4
# Energy  : 1.018641485114
# Overlap : 0.999848917301
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641813153
# Energy error     : 3.858056e-07
# Fidelity         : 0.999999905526
# Tracking overlap : 0.999849269004
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Restart 0
# Energy  : 1.030499403085
# Overlap : 0.999875662826
#
# Restart 1
# Energy  : 1.030499392017
# Overlap : 0.999875611794
#
# Restart 2
# Energy  : 1.030499369014
# Overlap : 0.999875585426
#
# Restart 3
# Energy  : 1.030499350391
# Overlap : 0.999875672383
#
# Restart 4
# Energy  : 1.030499365683
# Overlap : 0.999875666646
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030499350391
# Energy error     : 4.059648e-08
# Fidelity         : 0.999999988542
# Tracking overlap : 0.999875672383
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Restart 0
# Energy  : 1.041824411357
# Overlap : 0.999895876884
#
# Restart 1
# Energy  : 1.041824511186
# Overlap : 0.999895807349
#
# Restart 2
# Energy  : 1.041824653964
# Overlap : 0.999895636729
#
# Restart 3
# Energy  : 1.041824417305
# Overlap : 0.999895761005
#
# Restart 4
# Energy  : 1.041824436197
# Overlap : 0.999895906818
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041824436197
# Energy error     : 1.139362e-07
# Fidelity         : 0.999999978732
# Tracking overlap : 0.999895906818
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Restart 0
# Energy  : 1.052684701841
# Overlap : 0.999910514488
#
# Restart 1
# Energy  : 1.052684771756
# Overlap : 0.999910617569
#
# Restart 2
# Energy  : 1.052684750034
# Overlap : 0.999910714483
#
# Restart 3
# Energy  : 1.052684696235
# Overlap : 0.999910729096
#
# Restart 4
# Energy  : 1.052684736738
# Overlap : 0.999910671599
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052684696235
# Energy error     : 1.524732e-07
# Fidelity         : 0.999999982202
# Tracking overlap : 0.999910729096
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Restart 0
# Energy  : 1.063134029019
# Overlap : 0.999922514775
#
# Restart 1
# Energy  : 1.063134040926
# Overlap : 0.999922609110
#
# Restart 2
# Energy  : 1.063134075425
# Overlap : 0.999922401847
#
# Restart 3
# Energy  : 1.063134122593
# Overlap : 0.999922409984
#
# Restart 4
# Energy  : 1.063134023132
# Overlap : 0.999922521048
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063134040926
# Energy error     : 2.521562e-07
# Fidelity         : 0.999999971352
# Tracking overlap : 0.999922609110
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Restart 0
# Energy  : 1.073216000984
# Overlap : 0.999931795781
#
# Restart 1
# Energy  : 1.073215988310
# Overlap : 0.999931773023
#
# Restart 2
# Energy  : 1.073216064447
# Overlap : 0.999931784825
#
# Restart 3
# Energy  : 1.073215985705
# Overlap : 0.999931725388
#
# Restart 4
# Energy  : 1.073216723019
# Overlap : 0.999931895170
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073216723019
# Energy error     : 1.069248e-06
# Fidelity         : 0.999999799360
# Tracking overlap : 0.999931895170
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Restart 0
# Energy  : 1.082966615107
# Overlap : 0.999939149760
#
# Restart 1
# Energy  : 1.082966605273
# Overlap : 0.999939135257
#
# Restart 2
# Energy  : 1.082966644131
# Overlap : 0.999938968291
#
# Restart 3
# Energy  : 1.082966654712
# Overlap : 0.999939081299
#
# Restart 4
# Energy  : 1.082966640917
# Overlap : 0.999939202644
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082966640917
# Energy error     : 4.891025e-07
# Fidelity         : 0.999999951517
# Tracking overlap : 0.999939202644
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Restart 0
# Energy  : 1.092416068603
# Overlap : 0.999945807121
#
# Restart 1
# Energy  : 1.092415985261
# Overlap : 0.999945752483
#
# Restart 2
# Energy  : 1.092416088860
# Overlap : 0.999945706222
#
# Restart 3
# Energy  : 1.092416073507
# Overlap : 0.999945920157
#
# Restart 4
# Energy  : 1.092416061941
# Overlap : 0.999945777590
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092416073507
# Energy error     : 5.653991e-07
# Fidelity         : 0.999999944497
# Tracking overlap : 0.999945920157
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Restart 0
# Energy  : 1.101590001085
# Overlap : 0.999951079015
#
# Restart 1
# Energy  : 1.101589892025
# Overlap : 0.999951036168
#
# Restart 2
# Energy  : 1.101589993129
# Overlap : 0.999951077667
#
# Restart 3
# Energy  : 1.101589997369
# Overlap : 0.999950999904
#
# Restart 4
# Energy  : 1.101589988996
# Overlap : 0.999951051569
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101590001085
# Energy error     : 5.723421e-07
# Fidelity         : 0.999999941190
# Tracking overlap : 0.999951079015
#
#
# ==============================================================================================================
# SUMMARY : Symmetric
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       1.0061617282       1.0061617389       1.0696e-08      0.9999999919    1.0000000000
# 0.3111       1.0186414273       1.0186418132       3.8581e-07      0.9999999055    0.9998492690
# 0.5222       1.0304993098       1.0304993504       4.0596e-08      0.9999999885    0.9998756724
# 0.7333       1.0418243223       1.0418244362       1.1394e-07      0.9999999787    0.9998959068
# 0.9444       1.0526845438       1.0526846962       1.5247e-07      0.9999999822    0.9999107291
# 1.1556       1.0631337888       1.0631340409       2.5216e-07      0.9999999714    0.9999226091
# 1.3667       1.0732156538       1.0732167230       1.0692e-06      0.9999997994    0.9999318952
# 1.5778       1.0829661518       1.0829666409       4.8910e-07      0.9999999515    0.9999392026
# 1.7889       1.0924155081       1.0924160735       5.6540e-07      0.9999999445    0.9999459202
# 2.0000       1.1015894287       1.1015900011       5.7234e-07      0.9999999412    0.9999510790
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 1e-05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Restart 0
# Energy  : -16.943780436905
# Overlap : 1.000000000000
#
# Restart 1
# Energy  : -16.943794331607
# Overlap : 1.000000000000
#
# Restart 2
# Energy  : -16.943778999171
# Overlap : 1.000000000000
#
# Restart 3
# Energy  : -16.943873578500
# Overlap : 1.000000000000
#
# Restart 4
# Energy  : -16.943854940010
# Overlap : 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902169977
# VQE energy       : -16.943780436905
# Energy error     : 1.217331e-04
# Fidelity         : 0.999985862286
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Restart 0
# Energy  : -8.892067836806
# Overlap : 0.875265433452
#
# Restart 1
# Energy  : -8.891888721397
# Overlap : 0.874792338392
#
# Restart 2
# Energy  : -8.887618785234
# Overlap : 0.874034232343
#
# Restart 3
# Energy  : -8.891960527098
# Overlap : 0.875610956482
#
# Restart 4
# Energy  : -8.891762981248
# Overlap : 0.875645045695
#
# FINAL SELECTED STATE
# Exact energy     : -8.892068720847
# VQE energy       : -8.891762981248
# Energy error     : 3.057396e-04
# Fidelity         : 0.999865865548
# Tracking overlap : 0.875645045695
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Restart 0
# Energy  : -4.379107345998
# Overlap : 0.049084159574
#
# Restart 1
# Energy  : -4.377435426129
# Overlap : 0.000000000091
#
# Restart 2
# Energy  : -4.377435408478
# Overlap : 0.000000000099
#
# Restart 3
# Energy  : -4.377435398957
# Overlap : 0.000000000090
#
# Restart 4
# Energy  : -4.377435377220
# Overlap : 0.000000000073
#
# FINAL SELECTED STATE
# Exact energy     : -4.379113856397
# VQE energy       : -4.379107345998
# Energy error     : 6.510399e-06
# Fidelity         : 0.996629741912
# Tracking overlap : 0.049084159574
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Restart 0
# Energy  : -2.741473795942
# Overlap : 0.660523728914
#
# Restart 1
# Energy  : -2.749793008724
# Overlap : 0.000000000012
#
# Restart 2
# Energy  : -2.749793064463
# Overlap : 0.000000000004
#
# Restart 3
# Energy  : -2.749792995394
# Overlap : 0.000000000005
#
# Restart 4
# Energy  : -2.749793053245
# Overlap : 0.000000000009
#
# FINAL SELECTED STATE
# Exact energy     : -2.749793396636
# VQE energy       : -2.749793008724
# Energy error     : 3.879122e-07
# Fidelity         : 0.999939175895
# Tracking overlap : 0.000000000012
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Restart 0
# Energy  : -1.874700597267
# Overlap : 0.821464753274
#
# Restart 1
# Energy  : -1.874700587927
# Overlap : 0.821463083527
#
# Restart 2
# Energy  : -1.874700531993
# Overlap : 0.821472761257
#
# Restart 3
# Energy  : -1.874700527275
# Overlap : 0.821472118971
#
# Restart 4
# Energy  : -1.874700573612
# Overlap : 0.821460353883
#
# FINAL SELECTED STATE
# Exact energy     : -1.874700666195
# VQE energy       : -1.874700531993
# Energy error     : 1.342026e-07
# Fidelity         : 0.999998814613
# Tracking overlap : 0.821472761257
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Restart 0
# Energy  : -1.348815316276
# Overlap : 0.894836339563
#
# Restart 1
# Energy  : -1.348821223073
# Overlap : 0.894868747311
#
# Restart 2
# Energy  : -1.348821384986
# Overlap : 0.894881633089
#
# Restart 3
# Energy  : -1.348821300965
# Overlap : 0.894895663569
#
# Restart 4
# Energy  : -1.348821399524
# Overlap : 0.894878281222
#
# FINAL SELECTED STATE
# Exact energy     : -1.348821613293
# VQE energy       : -1.348821300965
# Energy error     : 3.123278e-07
# Fidelity         : 0.999999852782
# Tracking overlap : 0.894895663569
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Restart 0
# Energy  : -1.010439425307
# Overlap : 0.936941711431
#
# Restart 1
# Energy  : -1.010438928014
# Overlap : 0.936910753942
#
# Restart 2
# Energy  : -1.010439181987
# Overlap : 0.936967890020
#
# Restart 3
# Energy  : -1.010438808198
# Overlap : 0.936938633179
#
# Restart 4
# Energy  : -1.010438219359
# Overlap : 0.936933953244
#
# FINAL SELECTED STATE
# Exact energy     : -1.010439481239
# VQE energy       : -1.010439181987
# Energy error     : 2.992525e-07
# Fidelity         : 0.999999833982
# Tracking overlap : 0.936967890020
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Restart 0
# Energy  : -0.779139711113
# Overlap : 0.962776242691
#
# Restart 1
# Energy  : -0.779120244528
# Overlap : 0.962763418555
#
# Restart 2
# Energy  : -0.779057872723
# Overlap : 0.962608958122
#
# Restart 3
# Energy  : -0.779106294591
# Overlap : 0.962818150252
#
# Restart 4
# Energy  : -0.779109886652
# Overlap : 0.962774568596
#
# FINAL SELECTED STATE
# Exact energy     : -0.779139779365
# VQE energy       : -0.779106294591
# Energy error     : 3.348477e-05
# Fidelity         : 0.999987500512
# Tracking overlap : 0.962818150252
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Restart 0
# Energy  : -0.611722146547
# Overlap : 0.977811584958
#
# Restart 1
# Energy  : -0.610293017696
# Overlap : 0.976298671941
#
# Restart 2
# Energy  : -0.611611809350
# Overlap : 0.977521931782
#
# Restart 3
# Energy  : -0.611178157475
# Overlap : 0.977571125658
#
# Restart 4
# Energy  : -0.609728072048
# Overlap : 0.976284369492
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723370121
# VQE energy       : -0.611722146547
# Energy error     : 1.223574e-06
# Fidelity         : 0.999999759844
# Tracking overlap : 0.977811584958
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Restart 0
# Energy  : -0.484294869698
# Overlap : 0.986377884885
#
# Restart 1
# Energy  : -0.483113215366
# Overlap : 0.985396355529
#
# Restart 2
# Energy  : -0.483137413583
# Overlap : 0.985432499659
#
# Restart 3
# Energy  : -0.483119811768
# Overlap : 0.985402804960
#
# Restart 4
# Energy  : -0.483115472103
# Overlap : 0.985436390929
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295385847
# VQE energy       : -0.484294869698
# Energy error     : 5.161487e-07
# Fidelity         : 0.999999918069
# Tracking overlap : 0.986377884885
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -16.9439021700     -16.9437804369     1.2173e-04      0.9999858623    1.0000000000
# 0.3111       -8.8920687208      -8.8917629812      3.0574e-04      0.9998658655    0.8756450457
# 0.5222       -4.3791138564      -4.3791073460      6.5104e-06      0.9966297419    0.0490841596
# 0.7333       -2.7497933966      -2.7497930087      3.8791e-07      0.9999391759    0.0000000000
# 0.9444       -1.8747006662      -1.8747005320      1.3420e-07      0.9999988146    0.8214727613
# 1.1556       -1.3488216133      -1.3488213010      3.1233e-07      0.9999998528    0.8948956636
# 1.3667       -1.0104394812      -1.0104391820      2.9925e-07      0.9999998340    0.9369678900
# 1.5778       -0.7791397794      -0.7791062946      3.3485e-05      0.9999875005    0.9628181503
# 1.7889       -0.6117233701      -0.6117221465      1.2236e-06      0.9999997598    0.9778115850
# 2.0000       -0.4842953858      -0.4842948697      5.1615e-07      0.9999999181    0.9863778849
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Restart 0
# Energy  : -20.776911046825
# Overlap : 1.000000000000
#
# Restart 1
# Energy  : -20.777210600856
# Overlap : 1.000000000000
#
# Restart 2
# Energy  : -20.776957259554
# Overlap : 1.000000000000
#
# Restart 3
# Energy  : -20.777104165608
# Overlap : 1.000000000000
#
# Restart 4
# Energy  : -20.777131539355
# Overlap : 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.776911046825
# Energy error     : 4.173984e-04
# Fidelity         : 0.999961917110
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Restart 0
# Energy  : -12.836331185609
# Overlap : 0.848510989192
#
# Restart 1
# Energy  : -12.835337462032
# Overlap : 0.849932859472
#
# Restart 2
# Energy  : -12.835223807355
# Overlap : 0.851042176512
#
# Restart 3
# Energy  : -12.834995597366
# Overlap : 0.848652863425
#
# Restart 4
# Energy  : -12.835863342363
# Overlap : 0.849095093788
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.835337462032
# Energy error     : 1.103681e-03
# Fidelity         : 0.999836647698
# Tracking overlap : 0.849932859472
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Restart 0
# Energy  : -7.730414613837
# Overlap : 0.164654546722
#
# Restart 1
# Energy  : -7.729984858332
# Overlap : 0.165252902320
#
# Restart 2
# Energy  : -7.729953450456
# Overlap : 0.165648052241
#
# Restart 3
# Energy  : -7.730023428405
# Overlap : 0.164837778412
#
# Restart 4
# Energy  : -7.730033087780
# Overlap : 0.164951353708
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.729953450456
# Energy error     : 7.629144e-04
# Fidelity         : 0.999888075786
# Tracking overlap : 0.165648052241
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Restart 0
# Energy  : -5.537987097773
# Overlap : 0.636391015303
#
# Restart 1
# Energy  : -5.536079793326
# Overlap : 0.634727933928
#
# Restart 2
# Energy  : -5.537849540318
# Overlap : 0.635566546315
#
# Restart 3
# Energy  : -5.537019192146
# Overlap : 0.639496217824
#
# Restart 4
# Energy  : -5.532189874225
# Overlap : 0.637376344878
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.537019192146
# Energy error     : 1.129639e-03
# Fidelity         : 0.999797817631
# Tracking overlap : 0.639496217824
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Restart 0
# Energy  : -4.275985715416
# Overlap : 0.820189335313
#
# Restart 1
# Energy  : -4.270227150577
# Overlap : 0.814739732127
#
# Restart 2
# Energy  : -4.270980913198
# Overlap : 0.815009427912
#
# Restart 3
# Energy  : -4.270877232775
# Overlap : 0.815180111614
#
# Restart 4
# Energy  : -4.270088348127
# Overlap : 0.814957185335
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.275985715416
# Energy error     : 2.807751e-05
# Fidelity         : 0.999997339059
# Tracking overlap : 0.820189335313
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Restart 0
# Energy  : -3.448563743369
# Overlap : 0.904087276628
#
# Restart 1
# Energy  : -3.445994912018
# Overlap : 0.902137772280
#
# Restart 2
# Energy  : -3.446025394827
# Overlap : 0.902170239190
#
# Restart 3
# Energy  : -3.445919920735
# Overlap : 0.901663882817
#
# Restart 4
# Energy  : -3.445959761798
# Overlap : 0.902279629514
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.448563743369
# Energy error     : 1.166421e-04
# Fidelity         : 0.999987513457
# Tracking overlap : 0.904087276628
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Restart 0
# Energy  : -2.860765081262
# Overlap : 0.941812685701
#
# Restart 1
# Energy  : -2.858193378178
# Overlap : 0.941997825382
#
# Restart 2
# Energy  : -2.858399031639
# Overlap : 0.942008511920
#
# Restart 3
# Energy  : -2.858111550281
# Overlap : 0.941794973583
#
# Restart 4
# Energy  : -2.858067888923
# Overlap : 0.941743009331
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.860765081262
# Energy error     : 6.718392e-05
# Fidelity         : 0.999992971025
# Tracking overlap : 0.941812685701
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Restart 0
# Energy  : -2.420048287619
# Overlap : 0.962268805130
#
# Restart 1
# Energy  : -2.415196187207
# Overlap : 0.960975359843
#
# Restart 2
# Energy  : -2.415628351900
# Overlap : 0.961961974336
#
# Restart 3
# Energy  : -2.415007925481
# Overlap : 0.960848326308
#
# Restart 4
# Energy  : -2.416531030975
# Overlap : 0.961217056210
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.420048287619
# Energy error     : 4.224166e-05
# Fidelity         : 0.999996623296
# Tracking overlap : 0.962268805130
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Restart 0
# Energy  : -2.076285190495
# Overlap : 0.973918083892
#
# Restart 1
# Energy  : -2.070777834131
# Overlap : 0.971935228710
#
# Restart 2
# Energy  : -2.070634462726
# Overlap : 0.971606549114
#
# Restart 3
# Energy  : -2.071121157815
# Overlap : 0.972097029464
#
# Restart 4
# Energy  : -2.070984640660
# Overlap : 0.971867584195
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.076285190495
# Energy error     : 2.737712e-05
# Fidelity         : 0.999997977963
# Tracking overlap : 0.973918083892
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Restart 0
# Energy  : -1.800040266773
# Overlap : 0.981147882928
#
# Restart 1
# Energy  : -1.795618942456
# Overlap : 0.976688335535
#
# Restart 2
# Energy  : -1.794157353645
# Overlap : 0.977962931972
#
# Restart 3
# Energy  : -1.794492235018
# Overlap : 0.978027547777
#
# Restart 4
# Energy  : -1.795985140146
# Overlap : 0.979291204901
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.800040266773
# Energy error     : 3.299944e-05
# Fidelity         : 0.999997602964
# Tracking overlap : 0.981147882928
#
#
# ==============================================================================================================
# SUMMARY : Strong SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -20.7773284453     -20.7769110468     4.1740e-04      0.9999619171    1.0000000000
# 0.3111       -12.8364411428     -12.8353374620     1.1037e-03      0.9998366477    0.8499328595
# 0.5222       -7.7307163648      -7.7299534505      7.6291e-04      0.9998880758    0.1656480522
# 0.7333       -5.5381488307      -5.5370191921      1.1296e-03      0.9997978176    0.6394962178
# 0.9444       -4.2760137929      -4.2759857154      2.8078e-05      0.9999973391    0.8201893353
# 1.1556       -3.4486803854      -3.4485637434      1.1664e-04      0.9999875135    0.9040872766
# 1.3667       -2.8608322652      -2.8607650813      6.7184e-05      0.9999929710    0.9418126857
# 1.5778       -2.4200905293      -2.4200482876      4.2242e-05      0.9999966233    0.9622688051
# 1.7889       -2.0763125676      -2.0762851905      2.7377e-05      0.9999979780    0.9739180839
# 2.0000       -1.8000732662      -1.8000402668      3.2999e-05      0.9999976030    0.9811478829

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.show()
