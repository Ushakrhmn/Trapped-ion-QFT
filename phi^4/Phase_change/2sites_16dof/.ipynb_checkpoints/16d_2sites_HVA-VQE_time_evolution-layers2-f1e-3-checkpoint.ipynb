# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756834
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_asymm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):
            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_symm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
'
# ============================================================
# Multi-parameter scan
# HVA + warm-start continuation + overlap tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0

# Default depth
layers = 4

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },

    {
        "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-5
    },
    {
        "label": "Weak SSB optimized",
        "mI2": -1.0,
        "f": 1e-4
    },
    {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#" * 80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#" * 80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "=" * 60)
        print(f"Running λ = {lam:.3f}")
        print("=" * 60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(
            Hloc_sparse
        )

        # ----------------------------------------------------
        # Dense Hamiltonian
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(
            H_op
        )

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ====================================================
        # Adaptive depth near critical region
        # ====================================================

        

        # ====================================================
        # Ansatz
        # ====================================================

        if mI2 < 0:

            ansatz = grouped_hva_asymm(
                nq=nqubits,
                layers=layers
            )

        else:

            ansatz = grouped_hva_symm(
                nq=nqubits,
                layers=layers
            )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)



        
        # ====================================================
        # Weak SSB:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )
        # ====================================================
        # Weak SSB optimized:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )

        # ====================================================
        # Symmetric + Strong SSB
        # ====================================================

        else:

            print(
                "\nRunning ordinary HVA-VQE...\n"
            )

            initial_point = (
                0.01 * np.random.randn(
                    ansatz.num_parameters
                )
            )

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = (
                vqe.compute_minimum_eigenvalue(
                    H_pauli_shifted
                )
            )

            best_energy = (
                result.eigenvalue.real
                + identity_shift
            )

            optimal_circuit = (
                ansatz.assign_parameters(
                    result.optimal_parameters
                )
            )

            best_state = (
                Statevector.from_instruction(
                    optimal_circuit
                ).data
            )

            best_fidelity = np.abs(
                np.vdot(
                    psi_exact,
                    best_state
                )
            )**2

            best_overlap = 1.0

        # ====================================================
        # Final VQE data
        # ====================================================

        E_vqe = best_energy
        F = best_fidelity

        # ====================================================
        # Store results
        # ====================================================

        data = {

            "case": label,

            "lambda": lam,

            "mI2": mI2,

            "f": f,
            'psi_vqe': best_state,

            "E_exact": E_exact,

            "E_vqe": E_vqe,

            "error": abs(
                E_exact - E_vqe
            ),

            "fidelity": F,

            "tracking_overlap": best_overlap,

            "layers": layers
        }

        case_results.append(data)
        all_results.append(data)

        # ====================================================
        # Print
        # ====================================================

        print("\nFINAL SELECTED STATE")

        print(
            f"Exact energy     : "
            f"{E_exact:.12f}"
        )

        print(
            f"VQE energy       : "
            f"{E_vqe:.12f}"
        )

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(
            f"Fidelity         : "
            f"{F:.12f}"
        )

        print(
            f"Tracking overlap : "
            f"{best_overlap:.12f}"
        )

        print(
            f"Layers            : "
            f"{layers}"
        )

        print(
            f"Pauli terms       : "
            f"{len(H_pauli_shifted.paulis)}"
        )

    # ========================================================
    # Summary
    # ========================================================

    print("\n")
    print("=" * 140)
    print(f"SUMMARY : {label}")
    print("=" * 140)

    print(
        f"{'lambda':<12}"
        f"{'Exact E':<20}"
        f"{'VQE E':<20}"
        f"{'Error':<18}"
        f"{'Fidelity':<18}"
        f"{'TrackOverlap':<18}"
        f"{'Layers':<10}"
    )

    print("=" * 140)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
            f"{r['E_vqe']:<20.10f}"
            f"{r['error']:<18.4e}"
            f"{r['fidelity']:<18.10f}"
            f"{r['tracking_overlap']:<18.10f}"
            f"{r['layers']:<10}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006162093746
# Energy error     : 3.655865e-07
# Fidelity         : 0.999999913868
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 106
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018642321684
# Energy error     : 8.943364e-07
# Fidelity         : 0.999999864698
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030508035195
# Energy error     : 8.725401e-06
# Fidelity         : 0.999998714557
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041833152799
# Energy error     : 8.830538e-06
# Fidelity         : 0.999998828559
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052691166008
# Energy error     : 6.622246e-06
# Fidelity         : 0.999999056993
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063152209532
# Energy error     : 1.842076e-05
# Fidelity         : 0.999997556893
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073221697810
# Energy error     : 6.044039e-06
# Fidelity         : 0.999999108934
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.083030594566
# Energy error     : 6.444275e-05
# Fidelity         : 0.999991921801
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092425485347
# Energy error     : 9.977239e-06
# Fidelity         : 0.999997194691
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101592191164
# Energy error     : 2.762421e-06
# Fidelity         : 0.999999790550
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
#
# ============================================================================================================================================
# SUMMARY : Symmetric
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      1.0061617282        1.0061620937        3.6559e-07        0.9999999139      1.0000000000      4
# 0.3111      1.0186414273        1.0186423217        8.9434e-07        0.9999998647      1.0000000000      4
# 0.5222      1.0304993098        1.0305080352        8.7254e-06        0.9999987146      1.0000000000      4
# 0.7333      1.0418243223        1.0418331528        8.8305e-06        0.9999988286      1.0000000000      4
# 0.9444      1.0526845438        1.0526911660        6.6222e-06        0.9999990570      1.0000000000      4
# 1.1556      1.0631337888        1.0631522095        1.8421e-05        0.9999975569      1.0000000000      4
# 1.3667      1.0732156538        1.0732216978        6.0440e-06        0.9999991089      1.0000000000      4
# 1.5778      1.0829661518        1.0830305946        6.4443e-05        0.9999919218      1.0000000000      4
# 1.7889      1.0924155081        1.0924254853        9.9772e-06        0.9999971947      1.0000000000      4
# 2.0000      1.1015894287        1.1015921912        2.7624e-06        0.9999997905      1.0000000000      4
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 1e-05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.866899419859
# Fidelity = 0.989188363319
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.873738851385
# Fidelity = 0.992015693347
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.942487147692
# Fidelity = 0.999815014617
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.881054606609
# Fidelity = 0.992016221835
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.903203867102
# Fidelity = 0.993562933054
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.943854735428
# Fidelity = 0.999991900951
# Overlap  = 0.999833919645
#
# Restart 1
# Energy   = -16.943502489599
# Fidelity = 0.999951841068
# Overlap  = 0.999760618562
#
# Restart 2
# Energy   = -16.936928421655
# Fidelity = 0.998698612038
# Overlap  = 0.998404503017
#
# Restart 3
# Energy   = -16.895136891772
# Fidelity = 0.993829480559
# Overlap  = 0.993913953184
#
# Restart 4
# Energy   = -16.808955764894
# Fidelity = 0.984971752791
# Overlap  = 0.984838767184
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902169977
# VQE energy       : -16.943854735428
# Energy error     : 4.743455e-05
# Fidelity         : 0.999991900951
# Tracking overlap : 0.999833919645
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.892026650564
# Fidelity = 0.999976641145
# Overlap  = 0.875543974760
#
# Restart 1
# Energy   = -8.891849339754
# Fidelity = 0.999907979489
# Overlap  = 0.877121415471
#
# Restart 2
# Energy   = -8.549189653793
# Fidelity = 0.000773972529
# Overlap  = 0.000662606863
#
# Restart 3
# Energy   = -8.549281594538
# Fidelity = 0.000001076596
# Overlap  = 0.000003994546
#
# Restart 4
# Energy   = -8.892021981101
# Fidelity = 0.999976007003
# Overlap  = 0.875550473643
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.892033038060
# Fidelity = 0.999970373841
# Overlap  = 0.999915284791
#
# Restart 1
# Energy   = -8.543644174802
# Fidelity = 0.000002197438
# Overlap  = 0.000039961627
#
# Restart 2
# Energy   = -8.549205363210
# Fidelity = 0.000026390803
# Overlap  = 0.000054437391
#
# Restart 3
# Energy   = -8.881328857748
# Fidelity = 0.996598121656
# Overlap  = 0.996892073842
#
# Restart 4
# Energy   = -8.549200506188
# Fidelity = 0.000014997381
# Overlap  = 0.000073263624
#
# FINAL SELECTED STATE
# Exact energy     : -8.892068720847
# VQE energy       : -8.892033038060
# Energy error     : 3.568279e-05
# Fidelity         : 0.999970373841
# Tracking overlap : 0.999915284791
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379074843303
# Fidelity = 0.997068042404
# Overlap  = 0.049152073912
#
# Restart 1
# Energy   = -4.377429120283
# Fidelity = 0.000002090910
# Overlap  = 0.000000000026
#
# Restart 2
# Energy   = -4.377418454661
# Fidelity = 0.000002227519
# Overlap  = 0.000000000006
#
# Restart 3
# Energy   = -4.377416524330
# Fidelity = 0.000002046148
# Overlap  = 0.000000000183
#
# Restart 4
# Energy   = -4.377429759623
# Fidelity = 0.000001861348
# Overlap  = 0.000000000153
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379099425950
# Fidelity = 0.996550835010
# Overlap  = 0.999951252562
#
# Restart 1
# Energy   = -4.377412970924
# Fidelity = 0.000001347637
# Overlap  = 0.000000002013
#
# Restart 2
# Energy   = -4.377421057532
# Fidelity = 0.000001363632
# Overlap  = 0.000000000602
#
# Restart 3
# Energy   = -4.377422174518
# Fidelity = 0.000001574914
# Overlap  = 0.000000000332
#
# Restart 4
# Energy   = -4.377391594657
# Fidelity = 0.000002577262
# Overlap  = 0.000000001076
#
# FINAL SELECTED STATE
# Exact energy     : -4.379113856397
# VQE energy       : -4.379099425950
# Energy error     : 1.443045e-05
# Fidelity         : 0.996550835010
# Tracking overlap : 0.999951252562
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.741471187013
# Fidelity = 0.000000000028
# Overlap  = 0.660691634353
#
# Restart 1
# Energy   = -2.749769010719
# Fidelity = 0.999702564738
# Overlap  = 0.000000007998
#
# Restart 2
# Energy   = -2.749766535313
# Fidelity = 0.999778801906
# Overlap  = 0.000000002329
#
# Restart 3
# Energy   = -2.749745935117
# Fidelity = 0.999888636482
# Overlap  = 0.000000000208
#
# Restart 4
# Energy   = -2.749766702866
# Fidelity = 0.999779643833
# Overlap  = 0.000000002964
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.749776980609
# Fidelity = 0.999779134981
# Overlap  = 0.999957921334
#
# Restart 1
# Energy   = -2.749767105553
# Fidelity = 0.999768771990
# Overlap  = 0.999852347578
#
# Restart 2
# Energy   = -2.749770879072
# Fidelity = 0.999776483470
# Overlap  = 0.999914619804
#
# Restart 3
# Energy   = -2.749774351847
# Fidelity = 0.999788684013
# Overlap  = 0.999894179265
#
# Restart 4
# Energy   = -2.749766631556
# Fidelity = 0.999894798622
# Overlap  = 0.999889591627
#
# FINAL SELECTED STATE
# Exact energy     : -2.749793396636
# VQE energy       : -2.749776980609
# Energy error     : 1.641603e-05
# Fidelity         : 0.999779134981
# Tracking overlap : 0.999957921334
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874689598249
# Fidelity = 0.999945693540
# Overlap  = 0.821439639226
#
# Restart 1
# Energy   = -1.874649599973
# Fidelity = 0.999985037612
# Overlap  = 0.821127774098
#
# Restart 2
# Energy   = -1.874166564007
# Fidelity = 0.999825561960
# Overlap  = 0.817719299513
#
# Restart 3
# Energy   = -1.867946278628
# Fidelity = 0.998206537796
# Overlap  = 0.801523104377
#
# Restart 4
# Energy   = -1.874142120071
# Fidelity = 0.999817501799
# Overlap  = 0.819264862892
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874695712989
# Fidelity = 0.999953014159
# Overlap  = 0.999997727606
#
# Restart 1
# Energy   = -1.871936307964
# Fidelity = 0.999324315939
# Overlap  = 0.999361279977
#
# Restart 2
# Energy   = -1.874646765797
# Fidelity = 0.999939591974
# Overlap  = 0.999958964912
#
# Restart 3
# Energy   = -1.872899008696
# Fidelity = 0.999379602652
# Overlap  = 0.999343567746
#
# Restart 4
# Energy   = -1.871705808749
# Fidelity = 0.999314804895
# Overlap  = 0.999280915451
#
# FINAL SELECTED STATE
# Exact energy     : -1.874700666195
# VQE energy       : -1.874695712989
# Energy error     : 4.953206e-06
# Fidelity         : 0.999953014159
# Tracking overlap : 0.999997727606
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348765268946
# Fidelity = 0.999944216228
# Overlap  = 0.895023871579
#
# Restart 1
# Energy   = -1.348339002233
# Fidelity = 0.999893914992
# Overlap  = 0.896476742355
#
# Restart 2
# Energy   = -1.348052091638
# Fidelity = 0.999844330991
# Overlap  = 0.896104251844
#
# Restart 3
# Energy   = -1.348218848214
# Fidelity = 0.999879292668
# Overlap  = 0.896267665854
#
# Restart 4
# Energy   = -1.348448690809
# Fidelity = 0.999923838727
# Overlap  = 0.895767703983
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348770496649
# Fidelity = 0.999982727972
# Overlap  = 0.999883874391
#
# Restart 1
# Energy   = -1.348215190430
# Fidelity = 0.999866106869
# Overlap  = 0.999963705352
#
# Restart 2
# Energy   = -1.348137048223
# Fidelity = 0.999835601839
# Overlap  = 0.999921820584
#
# Restart 3
# Energy   = -1.348231241371
# Fidelity = 0.999883148999
# Overlap  = 0.999978555034
#
# Restart 4
# Energy   = -1.348169375385
# Fidelity = 0.999862336520
# Overlap  = 0.999946840896
#
# FINAL SELECTED STATE
# Exact energy     : -1.348821613293
# VQE energy       : -1.348231241371
# Energy error     : 5.903719e-04
# Fidelity         : 0.999883148999
# Tracking overlap : 0.999978555034
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.007430126608
# Fidelity = 0.999425562807
# Overlap  = 0.935478996933
#
# Restart 1
# Energy   = -1.007123994847
# Fidelity = 0.999464342384
# Overlap  = 0.935553288807
#
# Restart 2
# Energy   = -1.007151863425
# Fidelity = 0.999461469814
# Overlap  = 0.935547802603
#
# Restart 3
# Energy   = -1.007152017227
# Fidelity = 0.999463018655
# Overlap  = 0.935616625284
#
# Restart 4
# Energy   = -1.007113582180
# Fidelity = 0.999427315001
# Overlap  = 0.935560773651
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.008776575727
# Fidelity = 0.999722495890
# Overlap  = 0.999720131605
#
# Restart 1
# Energy   = -1.007166659389
# Fidelity = 0.999469575468
# Overlap  = 0.999990108832
#
# Restart 2
# Energy   = -1.007158358520
# Fidelity = 0.999463672746
# Overlap  = 0.999977742868
#
# Restart 3
# Energy   = -1.007137965854
# Fidelity = 0.999461453876
# Overlap  = 0.999988824780
#
# Restart 4
# Energy   = -1.007151343655
# Fidelity = 0.999465204142
# Overlap  = 0.999992890513
#
# FINAL SELECTED STATE
# Exact energy     : -1.010439481239
# VQE energy       : -1.008776575727
# Energy error     : 1.662906e-03
# Fidelity         : 0.999722495890
# Tracking overlap : 0.999720131605
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.777489430264
# Fidelity = 0.999750295356
# Overlap  = 0.962517253124
#
# Restart 1
# Energy   = -0.775812361903
# Fidelity = 0.999501025727
# Overlap  = 0.961243087896
#
# Restart 2
# Energy   = -0.775705710903
# Fidelity = 0.999476848315
# Overlap  = 0.961309731318
#
# Restart 3
# Energy   = -0.775795810214
# Fidelity = 0.999502543835
# Overlap  = 0.961250716894
#
# Restart 4
# Energy   = -0.775782992701
# Fidelity = 0.999426403977
# Overlap  = 0.961264807188
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.777623652764
# Fidelity = 0.999779802508
# Overlap  = 0.999985007509
#
# Restart 1
# Energy   = -0.775811447469
# Fidelity = 0.999501528849
# Overlap  = 0.999739282687
#
# Restart 2
# Energy   = -0.775789018243
# Fidelity = 0.999470102596
# Overlap  = 0.999726756759
#
# Restart 3
# Energy   = -0.775835779168
# Fidelity = 0.999502466197
# Overlap  = 0.999736869734
#
# Restart 4
# Energy   = -0.775819937661
# Fidelity = 0.999501256220
# Overlap  = 0.999746858113
#
# FINAL SELECTED STATE
# Exact energy     : -0.779139779365
# VQE energy       : -0.777623652764
# Energy error     : 1.516127e-03
# Fidelity         : 0.999779802508
# Tracking overlap : 0.999985007509
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.610670558800
# Fidelity = 0.999850400757
# Overlap  = 0.977935995369
#
# Restart 1
# Energy   = -0.609509709721
# Fidelity = 0.999676098062
# Overlap  = 0.976903498166
#
# Restart 2
# Energy   = -0.609497822942
# Fidelity = 0.999694166833
# Overlap  = 0.977175415008
#
# Restart 3
# Energy   = -0.609505674511
# Fidelity = 0.999689161890
# Overlap  = 0.977006320491
#
# Restart 4
# Energy   = -0.609504672902
# Fidelity = 0.999684874336
# Overlap  = 0.977015367855
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.610760350207
# Fidelity = 0.999864132393
# Overlap  = 0.999988128929
#
# Restart 1
# Energy   = -0.609518209821
# Fidelity = 0.999686940365
# Overlap  = 0.999817699723
#
# Restart 2
# Energy   = -0.609506585924
# Fidelity = 0.999690358144
# Overlap  = 0.999831700284
#
# Restart 3
# Energy   = -0.609509280318
# Fidelity = 0.999682933046
# Overlap  = 0.999827272672
#
# Restart 4
# Energy   = -0.609503783683
# Fidelity = 0.999694058220
# Overlap  = 0.999835214802
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723370121
# VQE energy       : -0.610760350207
# Energy error     : 9.630199e-04
# Fidelity         : 0.999864132393
# Tracking overlap : 0.999988128929
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.483799523996
# Fidelity = 0.999929409319
# Overlap  = 0.986636274988
#
# Restart 1
# Energy   = -0.483112965129
# Fidelity = 0.999845263048
# Overlap  = 0.986226745199
#
# Restart 2
# Energy   = -0.483112478431
# Fidelity = 0.999844225562
# Overlap  = 0.986225534204
#
# Restart 3
# Energy   = -0.483112827549
# Fidelity = 0.999841938208
# Overlap  = 0.986215391035
#
# Restart 4
# Energy   = -0.483114200426
# Fidelity = 0.999846825533
# Overlap  = 0.986229737472
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484244871643
# Fidelity = 0.999988255823
# Overlap  = 0.999894319078
#
# Restart 1
# Energy   = -0.483113415234
# Fidelity = 0.999846463121
# Overlap  = 0.999921054219
#
# Restart 2
# Energy   = -0.483106269710
# Fidelity = 0.999845980783
# Overlap  = 0.999926183001
#
# Restart 3
# Energy   = -0.483107084053
# Fidelity = 0.999844592112
# Overlap  = 0.999916505436
#
# Restart 4
# Energy   = -0.483110894505
# Fidelity = 0.999838851129
# Overlap  = 0.999925857534
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295385847
# VQE energy       : -0.484244871643
# Energy error     : 5.051420e-05
# Fidelity         : 0.999988255823
# Tracking overlap : 0.999894319078
# Layers            : 4
# Pauli terms       : 110
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9439021700      -16.9438547354      4.7435e-05        0.9999919010      0.9998339196      4
# 0.3111      -8.8920687208       -8.8920330381       3.5683e-05        0.9999703738      0.9999152848      4
# 0.5222      -4.3791138564       -4.3790994260       1.4430e-05        0.9965508350      0.9999512526      4
# 0.7333      -2.7497933966       -2.7497769806       1.6416e-05        0.9997791350      0.9999579213      4
# 0.9444      -1.8747006662       -1.8746957130       4.9532e-06        0.9999530142      0.9999977276      4
# 1.1556      -1.3488216133       -1.3482312414       5.9037e-04        0.9998831490      0.9999785550      4
# 1.3667      -1.0104394812       -1.0087765757       1.6629e-03        0.9997224959      0.9997201316      4
# 1.5778      -0.7791397794       -0.7776236528       1.5161e-03        0.9997798025      0.9999850075      4
# 1.7889      -0.6117233701       -0.6107603502       9.6302e-04        0.9998641324      0.9999881289      4
# 2.0000      -0.4842953858       -0.4842448716       5.0514e-05        0.9999882558      0.9998943191      4
#
#
# ################################################################################
# CASE: Weak SSB optimized
# mI² = -1.0,  f = 0.0001
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.943325315633
# Fidelity = 0.999918701886
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.942190182333
# Fidelity = 0.999548278449
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.943436194665
# Fidelity = 0.999913776504
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.935551088204
# Fidelity = 0.998145068704
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.877412249233
# Fidelity = 0.992442755284
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.943844393311
# Fidelity = 0.999991343403
# Overlap  = 0.999926420532
#
# Restart 1
# Energy   = -16.943608656331
# Fidelity = 0.999955269899
# Overlap  = 0.999865780387
#
# Restart 2
# Energy   = -16.917182511706
# Fidelity = 0.997479184246
# Overlap  = 0.997362515475
#
# Restart 3
# Energy   = -15.399177152298
# Fidelity = 0.000000001283
# Overlap  = 0.000000001584
#
# Restart 4
# Energy   = -16.943593391137
# Fidelity = 0.999937215428
# Overlap  = 0.999845087341
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902685020
# VQE energy       : -16.943844393311
# Energy error     : 5.829171e-05
# Fidelity         : 0.999991343403
# Tracking overlap : 0.999926420532
# Layers            : 4
# Pauli terms       : 158
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.891933040313
# Fidelity = 0.999975816152
# Overlap  = 0.875595800231
#
# Restart 1
# Energy   = -8.886651120383
# Fidelity = 0.997149464290
# Overlap  = 0.877605998590
#
# Restart 2
# Energy   = -8.549149163728
# Fidelity = 0.000003335939
# Overlap  = 0.000005914152
#
# Restart 3
# Energy   = -8.549148772299
# Fidelity = 0.000002928487
# Overlap  = 0.000008541566
#
# Restart 4
# Energy   = -8.892020144210
# Fidelity = 0.999977953719
# Overlap  = 0.876069714752
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.892068499912
# Fidelity = 0.999998879263
# Overlap  = 0.999980326995
#
# Restart 1
# Energy   = -8.549271873323
# Fidelity = 0.000048266307
# Overlap  = 0.000024716904
#
# Restart 2
# Energy   = -8.892013421185
# Fidelity = 0.999986631498
# Overlap  = 0.999966122093
#
# Restart 3
# Energy   = -8.549251056470
# Fidelity = 0.000003354975
# Overlap  = 0.000001378679
#
# Restart 4
# Energy   = -8.892032397967
# Fidelity = 0.999973273967
# Overlap  = 0.999969051001
#
# FINAL SELECTED STATE
# Exact energy     : -8.892069658534
# VQE energy       : -8.892068499912
# Energy error     : 1.158622e-06
# Fidelity         : 0.999998879263
# Tracking overlap : 0.999980326995
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379109720932
# Fidelity = 0.806687515777
# Overlap  = 0.049185732915
#
# Restart 1
# Energy   = -4.377412324340
# Fidelity = 0.010098402847
# Overlap  = 0.000000000049
#
# Restart 2
# Energy   = -4.377431491750
# Fidelity = 0.010694555990
# Overlap  = 0.000000000000
#
# Restart 3
# Energy   = -4.377368328354
# Fidelity = 0.010634468309
# Overlap  = 0.000000000222
#
# Restart 4
# Energy   = -4.377418503547
# Fidelity = 0.010490665421
# Overlap  = 0.000000000007
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379111778350
# Fidelity = 0.805944044162
# Overlap  = 0.999997768982
#
# Restart 1
# Energy   = -4.377389732252
# Fidelity = 0.010615007616
# Overlap  = 0.000000000004
#
# Restart 2
# Energy   = -4.377432332165
# Fidelity = 0.010652369332
# Overlap  = 0.000000000018
#
# Restart 3
# Energy   = -4.378247197517
# Fidelity = 0.091755948257
# Overlap  = 0.000004179152
#
# Restart 4
# Energy   = -4.377402722746
# Fidelity = 0.010227332090
# Overlap  = 0.000000000042
#
# FINAL SELECTED STATE
# Exact energy     : -4.379329565434
# VQE energy       : -4.379111778350
# Energy error     : 2.177871e-04
# Fidelity         : 0.805944044162
# Tracking overlap : 0.999997768982
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.741472665779
# Fidelity = 0.000019293862
# Overlap  = 0.660727572073
#
# Restart 1
# Energy   = -2.709088725823
# Fidelity = 0.980934658299
# Overlap  = 0.000000000015
#
# Restart 2
# Energy   = -2.749757011785
# Fidelity = 0.991204519141
# Overlap  = 0.000000000015
#
# Restart 3
# Energy   = -2.749777891134
# Fidelity = 0.992485264246
# Overlap  = 0.000000000229
#
# Restart 4
# Energy   = -2.749762622097
# Fidelity = 0.991579543533
# Overlap  = 0.000000000006
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.749789775522
# Fidelity = 0.992347790643
# Overlap  = 0.999983339577
#
# Restart 1
# Energy   = -2.749734853197
# Fidelity = 0.991291859082
# Overlap  = 0.999907262972
#
# Restart 2
# Energy   = -2.749753716870
# Fidelity = 0.991458379149
# Overlap  = 0.999908251889
#
# Restart 3
# Energy   = -2.749765964675
# Fidelity = 0.991314008429
# Overlap  = 0.999923280683
#
# Restart 4
# Energy   = -2.749768195625
# Fidelity = 0.990925954896
# Overlap  = 0.999890720484
#
# FINAL SELECTED STATE
# Exact energy     : -2.749826501443
# VQE energy       : -2.749789775522
# Energy error     : 3.672592e-05
# Fidelity         : 0.992347790643
# Tracking overlap : 0.999983339577
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874696795714
# Fidelity = 0.999742158363
# Overlap  = 0.821473236791
#
# Restart 1
# Energy   = -1.874690679318
# Fidelity = 0.999772970034
# Overlap  = 0.821348795066
#
# Restart 2
# Energy   = -1.874076644505
# Fidelity = 0.999456235125
# Overlap  = 0.819130562870
#
# Restart 3
# Energy   = -1.874583477582
# Fidelity = 0.999578840669
# Overlap  = 0.821343471714
#
# Restart 4
# Energy   = -1.874651787006
# Fidelity = 0.999813078850
# Overlap  = 0.820726232955
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874699807593
# Fidelity = 0.999733602947
# Overlap  = 0.999997375619
#
# Restart 1
# Energy   = -1.874509422018
# Fidelity = 0.999647287225
# Overlap  = 0.999840986855
#
# Restart 2
# Energy   = -1.874664579443
# Fidelity = 0.999598329956
# Overlap  = 0.999968936439
#
# Restart 3
# Energy   = -1.870569221587
# Fidelity = 0.998818120568
# Overlap  = 0.999134512457
#
# Restart 4
# Energy   = -1.874661145459
# Fidelity = 0.999662863242
# Overlap  = 0.999936945406
#
# FINAL SELECTED STATE
# Exact energy     : -1.874705890824
# VQE energy       : -1.874699807593
# Energy error     : 6.083231e-06
# Fidelity         : 0.999733602947
# Tracking overlap : 0.999997375619
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348816493616
# Fidelity = 0.999972102600
# Overlap  = 0.894885662434
#
# Restart 1
# Energy   = -1.348245226294
# Fidelity = 0.999857626821
# Overlap  = 0.896465300698
#
# Restart 2
# Energy   = -1.348252118174
# Fidelity = 0.999785456029
# Overlap  = 0.896348088791
#
# Restart 3
# Energy   = -1.348221112032
# Fidelity = 0.999808723502
# Overlap  = 0.896382992977
#
# Restart 4
# Energy   = -1.348224003767
# Fidelity = 0.999825673979
# Overlap  = 0.896434602422
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348565872561
# Fidelity = 0.999943670011
# Overlap  = 0.999941250579
#
# Restart 1
# Energy   = -1.348111863746
# Fidelity = 0.999846650961
# Overlap  = 0.999974436460
#
# Restart 2
# Energy   = -1.348292905575
# Fidelity = 0.999846216993
# Overlap  = 0.999980943038
#
# Restart 3
# Energy   = -1.348167872919
# Fidelity = 0.999771822563
# Overlap  = 0.999962161171
#
# Restart 4
# Energy   = -1.348195440852
# Fidelity = 0.999829870569
# Overlap  = 0.999985792724
#
# FINAL SELECTED STATE
# Exact energy     : -1.348823187245
# VQE energy       : -1.348195440852
# Energy error     : 6.277464e-04
# Fidelity         : 0.999829870569
# Tracking overlap : 0.999985792724
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.007146190420
# Fidelity = 0.999460168989
# Overlap  = 0.935455914789
#
# Restart 1
# Energy   = -1.007132823837
# Fidelity = 0.999430800665
# Overlap  = 0.935463573192
#
# Restart 2
# Energy   = -1.007181138271
# Fidelity = 0.999472237026
# Overlap  = 0.935492425411
#
# Restart 3
# Energy   = -1.007143636485
# Fidelity = 0.999413137603
# Overlap  = 0.935401707479
#
# Restart 4
# Energy   = -1.006979638805
# Fidelity = 0.999362729955
# Overlap  = 0.935002546841
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.008268228118
# Fidelity = 0.999589160234
# Overlap  = 0.999818675121
#
# Restart 1
# Energy   = -1.007052710975
# Fidelity = 0.999445715717
# Overlap  = 0.999958825967
#
# Restart 2
# Energy   = -1.008250899061
# Fidelity = 0.999487665026
# Overlap  = 0.999655033827
#
# Restart 3
# Energy   = -1.007120724815
# Fidelity = 0.999440008560
# Overlap  = 0.999949979189
#
# Restart 4
# Energy   = -1.007126948615
# Fidelity = 0.999437091121
# Overlap  = 0.999923868759
#
# FINAL SELECTED STATE
# Exact energy     : -1.010440164101
# VQE energy       : -1.008268228118
# Energy error     : 2.171936e-03
# Fidelity         : 0.999589160234
# Tracking overlap : 0.999818675121
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.777936653834
# Fidelity = 0.999799719423
# Overlap  = 0.963391131731
#
# Restart 1
# Energy   = -0.775774906148
# Fidelity = 0.999433971900
# Overlap  = 0.961662252779
#
# Restart 2
# Energy   = -0.775818401430
# Fidelity = 0.999490564352
# Overlap  = 0.961700445650
#
# Restart 3
# Energy   = -0.775784928157
# Fidelity = 0.999495049261
# Overlap  = 0.961723159773
#
# Restart 4
# Energy   = -0.776128936119
# Fidelity = 0.999432828902
# Overlap  = 0.961545258461
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.779114840631
# Fidelity = 0.999971339936
# Overlap  = 0.999739872295
#
# Restart 1
# Energy   = -0.775791052184
# Fidelity = 0.999471730918
# Overlap  = 0.999628581748
#
# Restart 2
# Energy   = -0.776201227758
# Fidelity = 0.999449889168
# Overlap  = 0.999513807252
#
# Restart 3
# Energy   = -0.775814944858
# Fidelity = 0.999498822620
# Overlap  = 0.999700562868
#
# Restart 4
# Energy   = -0.775786785267
# Fidelity = 0.999493828065
# Overlap  = 0.999673516519
#
# FINAL SELECTED STATE
# Exact energy     : -0.779140149474
# VQE energy       : -0.779114840631
# Energy error     : 2.530884e-05
# Fidelity         : 0.999971339936
# Tracking overlap : 0.999739872295
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611723315315
# Fidelity = 0.999999489406
# Overlap  = 0.977805097942
#
# Restart 1
# Energy   = -0.609511217636
# Fidelity = 0.999691497089
# Overlap  = 0.975960725553
#
# Restart 2
# Energy   = -0.609484474587
# Fidelity = 0.999681058270
# Overlap  = 0.975967949342
#
# Restart 3
# Energy   = -0.609505007237
# Fidelity = 0.999680938061
# Overlap  = 0.975977189054
#
# Restart 4
# Energy   = -0.609512610523
# Fidelity = 0.999694364462
# Overlap  = 0.976031489837
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611723474933
# Fidelity = 0.999999479808
# Overlap  = 0.999999966898
#
# Restart 1
# Energy   = -0.609496556976
# Fidelity = 0.999692163653
# Overlap  = 0.999693132354
#
# Restart 2
# Energy   = -0.609519450804
# Fidelity = 0.999679002774
# Overlap  = 0.999683270506
#
# Restart 3
# Energy   = -0.609500453597
# Fidelity = 0.999695580722
# Overlap  = 0.999696022245
#
# Restart 4
# Energy   = -0.609507190090
# Fidelity = 0.999685029267
# Overlap  = 0.999690151178
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723602270
# VQE energy       : -0.611723474933
# Energy error     : 1.273369e-07
# Fidelity         : 0.999999479808
# Tracking overlap : 0.999999966898
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484294474690
# Fidelity = 0.999999043458
# Overlap  = 0.986366595510
#
# Restart 1
# Energy   = -0.483115060627
# Fidelity = 0.999848002893
# Overlap  = 0.985410188080
#
# Restart 2
# Energy   = -0.483113036918
# Fidelity = 0.999844485151
# Overlap  = 0.985398237313
#
# Restart 3
# Energy   = -0.483115309631
# Fidelity = 0.999844945893
# Overlap  = 0.985398406966
#
# Restart 4
# Energy   = -0.483110417830
# Fidelity = 0.999846874860
# Overlap  = 0.985387427601
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484295426961
# Fidelity = 0.999999674226
# Overlap  = 0.999999645522
#
# Restart 1
# Energy   = -0.483109151778
# Fidelity = 0.999846278100
# Overlap  = 0.999842099323
#
# Restart 2
# Energy   = -0.483113550820
# Fidelity = 0.999846804513
# Overlap  = 0.999842735151
#
# Restart 3
# Energy   = -0.483110339849
# Fidelity = 0.999841128375
# Overlap  = 0.999839476962
#
# Restart 4
# Energy   = -0.483108041538
# Fidelity = 0.999836188905
# Overlap  = 0.999834847018
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295546782
# VQE energy       : -0.484295426961
# Energy error     : 1.198210e-07
# Fidelity         : 0.999999674226
# Tracking overlap : 0.999999645522
# Layers            : 4
# Pauli terms       : 160
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB optimized
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9439026850      -16.9438443933      5.8292e-05        0.9999913434      0.9999264205      4
# 0.3111      -8.8920696585       -8.8920684999       1.1586e-06        0.9999988793      0.9999803270      4
# 0.5222      -4.3793295654       -4.3791117784       2.1779e-04        0.8059440442      0.9999977690      4
# 0.7333      -2.7498265014       -2.7497897755       3.6726e-05        0.9923477906      0.9999833396      4
# 0.9444      -1.8747058908       -1.8746998076       6.0832e-06        0.9997336029      0.9999973756      4
# 1.1556      -1.3488231872       -1.3481954409       6.2775e-04        0.9998298706      0.9999857927      4
# 1.3667      -1.0104401641       -1.0082682281       2.1719e-03        0.9995891602      0.9998186751      4
# 1.5778      -0.7791401495       -0.7791148406       2.5309e-05        0.9999713399      0.9997398723      4
# 1.7889      -0.6117236023       -0.6117234749       1.2734e-07        0.9999994798      0.9999999669      4
# 2.0000      -0.4842955468       -0.4842954270       1.1982e-07        0.9999996742      0.9999996455      4
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.761533649930
# Fidelity = 0.998285634420
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -20.744771707235
# Fidelity = 0.995945525607
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -20.736758938060
# Fidelity = 0.994909528500
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -20.748917441788
# Fidelity = 0.996713071816
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -20.755523591784
# Fidelity = 0.997700834954
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.767463802769
# Fidelity = 0.999014669565
# Overlap  = 0.999576020958
#
# Restart 1
# Energy   = -20.754255365468
# Fidelity = 0.997901680448
# Overlap  = 0.998743033932
#
# Restart 2
# Energy   = -20.755140923359
# Fidelity = 0.997293452816
# Overlap  = 0.999210525743
#
# Restart 3
# Energy   = -20.746315216617
# Fidelity = 0.996125318000
# Overlap  = 0.998649987671
#
# Restart 4
# Energy   = -20.711467807675
# Fidelity = 0.992352448354
# Overlap  = 0.994619478732
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.767463802769
# Energy error     : 9.864642e-03
# Fidelity         : 0.999014669565
# Tracking overlap : 0.999576020958
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.818007237811
# Fidelity = 0.997085296881
# Overlap  = 0.856351135255
#
# Restart 1
# Energy   = -12.813171332646
# Fidelity = 0.995516475051
# Overlap  = 0.856754718742
#
# Restart 2
# Energy   = -12.814827618429
# Fidelity = 0.996121521608
# Overlap  = 0.858921247392
#
# Restart 3
# Energy   = -12.815274082686
# Fidelity = 0.996017853954
# Overlap  = 0.861065821037
#
# Restart 4
# Energy   = -12.813129662538
# Fidelity = 0.995722275091
# Overlap  = 0.855959980178
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.823660592802
# Fidelity = 0.997722607395
# Overlap  = 0.999270418575
#
# Restart 1
# Energy   = -12.810827971443
# Fidelity = 0.995205957382
# Overlap  = 0.998460876834
#
# Restart 2
# Energy   = -12.778023589567
# Fidelity = 0.991207406982
# Overlap  = 0.994897087562
#
# Restart 3
# Energy   = -12.806913684399
# Fidelity = 0.994517134065
# Overlap  = 0.996864848417
#
# Restart 4
# Energy   = -12.807263598270
# Fidelity = 0.994496508493
# Overlap  = 0.997744733157
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.823660592802
# Energy error     : 1.278055e-02
# Fidelity         : 0.997722607395
# Tracking overlap : 0.999270418575
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.666892480643
# Fidelity = 0.986862245326
# Overlap  = 0.170506082287
#
# Restart 1
# Energy   = -7.621262802710
# Fidelity = 0.975337834272
# Overlap  = 0.171517617678
#
# Restart 2
# Energy   = -7.610001958068
# Fidelity = 0.971905459780
# Overlap  = 0.176744849323
#
# Restart 3
# Energy   = -7.609573747855
# Fidelity = 0.972043843452
# Overlap  = 0.176671394537
#
# Restart 4
# Energy   = -7.624059879341
# Fidelity = 0.976343648635
# Overlap  = 0.172451302071
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.685000830565
# Fidelity = 0.991267256710
# Overlap  = 0.997666729096
#
# Restart 1
# Energy   = -7.670706805321
# Fidelity = 0.988339928807
# Overlap  = 0.997584520465
#
# Restart 2
# Energy   = -7.613239215563
# Fidelity = 0.973472672006
# Overlap  = 0.985277908139
#
# Restart 3
# Energy   = -7.677557092234
# Fidelity = 0.989813254934
# Overlap  = 0.997792128378
#
# Restart 4
# Energy   = -7.608660387444
# Fidelity = 0.971678200683
# Overlap  = 0.987234346565
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.685000830565
# Energy error     : 4.571553e-02
# Fidelity         : 0.991267256710
# Tracking overlap : 0.997666729096
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.511245719798
# Fidelity = 0.995496044897
# Overlap  = 0.626395227187
#
# Restart 1
# Energy   = -5.430910829825
# Fidelity = 0.968513296611
# Overlap  = 0.557950405222
#
# Restart 2
# Energy   = -5.483389332553
# Fidelity = 0.989598135431
# Overlap  = 0.609376439685
#
# Restart 3
# Energy   = -5.443958561541
# Fidelity = 0.978317157944
# Overlap  = 0.606686523641
#
# Restart 4
# Energy   = -5.478746252334
# Fidelity = 0.986867773591
# Overlap  = 0.610367679184
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.521241137623
# Fidelity = 0.997706509017
# Overlap  = 0.998206769597
#
# Restart 1
# Energy   = -5.495246954339
# Fidelity = 0.991531978673
# Overlap  = 0.996818295371
#
# Restart 2
# Energy   = -5.489833893531
# Fidelity = 0.990717007002
# Overlap  = 0.994236853528
#
# Restart 3
# Energy   = -5.494422388826
# Fidelity = 0.992523995216
# Overlap  = 0.994138976127
#
# Restart 4
# Energy   = -5.480601291716
# Fidelity = 0.989096226851
# Overlap  = 0.993868703661
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.521241137623
# Energy error     : 1.690769e-02
# Fidelity         : 0.997706509017
# Tracking overlap : 0.998206769597
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.271955310294
# Fidelity = 0.999552997413
# Overlap  = 0.827995958458
#
# Restart 1
# Energy   = -4.244323924121
# Fidelity = 0.993015024335
# Overlap  = 0.786685874350
#
# Restart 2
# Energy   = -4.251643647110
# Fidelity = 0.995174994389
# Overlap  = 0.800246378936
#
# Restart 3
# Energy   = -4.254773997279
# Fidelity = 0.995746971513
# Overlap  = 0.802723986138
#
# Restart 4
# Energy   = -4.255870897210
# Fidelity = 0.996487644385
# Overlap  = 0.806696266281
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.272513363308
# Fidelity = 0.999620914414
# Overlap  = 0.999903666046
#
# Restart 1
# Energy   = -4.250451394030
# Fidelity = 0.995223022207
# Overlap  = 0.996291130843
#
# Restart 2
# Energy   = -4.257469140987
# Fidelity = 0.996918033790
# Overlap  = 0.997741549737
#
# Restart 3
# Energy   = -4.252167456178
# Fidelity = 0.995398433420
# Overlap  = 0.996469691948
#
# Restart 4
# Energy   = -4.253915808466
# Fidelity = 0.996161606802
# Overlap  = 0.997135934870
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.272513363308
# Energy error     : 3.500430e-03
# Fidelity         : 0.999620914414
# Tracking overlap : 0.999903666046
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.446695886146
# Fidelity = 0.999746589061
# Overlap  = 0.906667102582
#
# Restart 1
# Energy   = -3.444225609844
# Fidelity = 0.999425017761
# Overlap  = 0.903848919243
#
# Restart 2
# Energy   = -3.444797303183
# Fidelity = 0.999507373378
# Overlap  = 0.904298116651
#
# Restart 3
# Energy   = -3.444843454496
# Fidelity = 0.999524442189
# Overlap  = 0.903859214167
#
# Restart 4
# Energy   = -3.444926069203
# Fidelity = 0.999519993123
# Overlap  = 0.904767541581
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.447283983208
# Fidelity = 0.999837844296
# Overlap  = 0.999907671430
#
# Restart 1
# Energy   = -3.444369478789
# Fidelity = 0.999469618130
# Overlap  = 0.999571541472
#
# Restart 2
# Energy   = -3.444859895132
# Fidelity = 0.999493215182
# Overlap  = 0.999678280732
#
# Restart 3
# Energy   = -3.443329482119
# Fidelity = 0.999316842300
# Overlap  = 0.999432159903
#
# Restart 4
# Energy   = -3.444027499240
# Fidelity = 0.999384398116
# Overlap  = 0.999533159789
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.447283983208
# Energy error     : 1.396402e-03
# Fidelity         : 0.999837844296
# Tracking overlap : 0.999907671430
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.859264444722
# Fidelity = 0.999829069613
# Overlap  = 0.942335662122
#
# Restart 1
# Energy   = -2.856028482026
# Fidelity = 0.999305301003
# Overlap  = 0.942757864426
#
# Restart 2
# Energy   = -2.853071690665
# Fidelity = 0.998806546098
# Overlap  = 0.941379543543
#
# Restart 3
# Energy   = -2.855446417097
# Fidelity = 0.999190028451
# Overlap  = 0.942795552773
#
# Restart 4
# Energy   = -2.852571443375
# Fidelity = 0.998765331920
# Overlap  = 0.941916717945
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.860157072311
# Fidelity = 0.999930155279
# Overlap  = 0.999892643072
#
# Restart 1
# Energy   = -2.856718861207
# Fidelity = 0.999362644972
# Overlap  = 0.999576248536
#
# Restart 2
# Energy   = -2.853911945774
# Fidelity = 0.998862073105
# Overlap  = 0.999111062155
#
# Restart 3
# Energy   = -2.855847507870
# Fidelity = 0.999349629344
# Overlap  = 0.999478198240
#
# Restart 4
# Energy   = -2.853218454786
# Fidelity = 0.998839988672
# Overlap  = 0.999094572854
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.860157072311
# Energy error     : 6.751929e-04
# Fidelity         : 0.999930155279
# Tracking overlap : 0.999892643072
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.419355837183
# Fidelity = 0.999925864968
# Overlap  = 0.962417163767
#
# Restart 1
# Energy   = -2.409643856763
# Fidelity = 0.998417545473
# Overlap  = 0.959894744885
#
# Restart 2
# Energy   = -2.413074213487
# Fidelity = 0.999001220656
# Overlap  = 0.960170174751
#
# Restart 3
# Energy   = -2.409515350771
# Fidelity = 0.998359635308
# Overlap  = 0.959357915401
#
# Restart 4
# Energy   = -2.409756840348
# Fidelity = 0.998331948537
# Overlap  = 0.959046947088
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.419667282954
# Fidelity = 0.999956903536
# Overlap  = 0.999969921685
#
# Restart 1
# Energy   = -2.409683570147
# Fidelity = 0.998384839995
# Overlap  = 0.998505767160
#
# Restart 2
# Energy   = -2.411671710054
# Fidelity = 0.998500057186
# Overlap  = 0.998639568294
#
# Restart 3
# Energy   = -2.409146139118
# Fidelity = 0.998415199501
# Overlap  = 0.998535753226
#
# Restart 4
# Energy   = -2.407402891929
# Fidelity = 0.997600892927
# Overlap  = 0.997751767384
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.419667282954
# Energy error     : 4.232463e-04
# Fidelity         : 0.999956903536
# Tracking overlap : 0.999969921685
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.075811413109
# Fidelity = 0.999955739479
# Overlap  = 0.973945523377
#
# Restart 1
# Energy   = -2.066427634863
# Fidelity = 0.998588536396
# Overlap  = 0.969794336020
#
# Restart 2
# Energy   = -2.066556148684
# Fidelity = 0.998563778578
# Overlap  = 0.969784347302
#
# Restart 3
# Energy   = -2.066171374810
# Fidelity = 0.998555336000
# Overlap  = 0.969341447982
#
# Restart 4
# Energy   = -2.065995035330
# Fidelity = 0.998482782618
# Overlap  = 0.969074719246
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.076104929557
# Fidelity = 0.999982569741
# Overlap  = 0.999977334149
#
# Restart 1
# Energy   = -2.066549854326
# Fidelity = 0.998583487159
# Overlap  = 0.998665671664
#
# Restart 2
# Energy   = -2.066531580605
# Fidelity = 0.998603209893
# Overlap  = 0.998685677053
#
# Restart 3
# Energy   = -2.067546716776
# Fidelity = 0.998671331944
# Overlap  = 0.998751436279
#
# Restart 4
# Energy   = -2.066568598787
# Fidelity = 0.998576316045
# Overlap  = 0.998654907189
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.076104929557
# Energy error     : 2.076381e-04
# Fidelity         : 0.999982569741
# Tracking overlap : 0.999977334149
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.799927230207
# Fidelity = 0.999988202626
# Overlap  = 0.981286268826
#
# Restart 1
# Energy   = -1.792993452720
# Fidelity = 0.999020063966
# Overlap  = 0.977667119945
#
# Restart 2
# Energy   = -1.792935661857
# Fidelity = 0.999019740291
# Overlap  = 0.977628988989
#
# Restart 3
# Energy   = -1.792800546758
# Fidelity = 0.999005115143
# Overlap  = 0.977677825883
#
# Restart 4
# Energy   = -1.792801069275
# Fidelity = 0.998990926111
# Overlap  = 0.977442262413
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.799984730728
# Fidelity = 0.999993630221
# Overlap  = 0.999995070965
#
# Restart 1
# Energy   = -1.792819058628
# Fidelity = 0.999013142227
# Overlap  = 0.999039912622
#
# Restart 2
# Energy   = -1.792978021364
# Fidelity = 0.999020576683
# Overlap  = 0.999049038121
#
# Restart 3
# Energy   = -1.793244185280
# Fidelity = 0.999070043765
# Overlap  = 0.999098582699
#
# Restart 4
# Energy   = -1.793004526508
# Fidelity = 0.999028375104
# Overlap  = 0.999054814933
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1