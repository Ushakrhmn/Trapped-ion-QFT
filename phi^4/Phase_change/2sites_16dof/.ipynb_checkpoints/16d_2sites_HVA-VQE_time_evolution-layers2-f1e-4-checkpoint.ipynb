# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.055472254575694
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_asymm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):
            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_symm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Multi-parameter scan
# HVA + warm-start continuation + overlap tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0

# Default depth
layers = 4

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },

    {
        "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-5
    },

    {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#" * 80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#" * 80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "=" * 60)
        print(f"Running λ = {lam:.3f}")
        print("=" * 60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(
            Hloc_sparse
        )

        # ----------------------------------------------------
        # Dense Hamiltonian
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(
            H_op
        )

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ====================================================
        # Adaptive depth near critical region
        # ====================================================

        

        # ====================================================
        # Ansatz
        # ====================================================

        if mI2 < 0:

            ansatz = grouped_hva_asymm(
                nq=nqubits,
                layers=layers
            )

        else:

            ansatz = grouped_hva_symm(
                nq=nqubits,
                layers=layers
            )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)

        # ====================================================
        # Weak SSB:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )

        # ====================================================
        # Symmetric + Strong SSB
        # ====================================================

        else:

            print(
                "\nRunning ordinary HVA-VQE...\n"
            )

            initial_point = (
                0.01 * np.random.randn(
                    ansatz.num_parameters
                )
            )

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = (
                vqe.compute_minimum_eigenvalue(
                    H_pauli_shifted
                )
            )

            best_energy = (
                result.eigenvalue.real
                + identity_shift
            )

            optimal_circuit = (
                ansatz.assign_parameters(
                    result.optimal_parameters
                )
            )

            best_state = (
                Statevector.from_instruction(
                    optimal_circuit
                ).data
            )

            best_fidelity = np.abs(
                np.vdot(
                    psi_exact,
                    best_state
                )
            )**2

            best_overlap = 1.0

        # ====================================================
        # Final VQE data
        # ====================================================

        E_vqe = best_energy
        F = best_fidelity

        # ====================================================
        # Store results
        # ====================================================

        data = {

            "case": label,

            "lambda": lam,

            "mI2": mI2,

            "f": f,
            'psi_vqe': best_state,

            "E_exact": E_exact,

            "E_vqe": E_vqe,

            "error": abs(
                E_exact - E_vqe
            ),

            "fidelity": F,

            "tracking_overlap": best_overlap,

            "layers": layers
        }

        case_results.append(data)
        all_results.append(data)

        # ====================================================
        # Print
        # ====================================================

        print("\nFINAL SELECTED STATE")

        print(
            f"Exact energy     : "
            f"{E_exact:.12f}"
        )

        print(
            f"VQE energy       : "
            f"{E_vqe:.12f}"
        )

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(
            f"Fidelity         : "
            f"{F:.12f}"
        )

        print(
            f"Tracking overlap : "
            f"{best_overlap:.12f}"
        )

        print(
            f"Layers            : "
            f"{layers}"
        )

        print(
            f"Pauli terms       : "
            f"{len(H_pauli_shifted.paulis)}"
        )

    # ========================================================
    # Summary
    # ========================================================

    print("\n")
    print("=" * 140)
    print(f"SUMMARY : {label}")
    print("=" * 140)

    print(
        f"{'lambda':<12}"
        f"{'Exact E':<20}"
        f"{'VQE E':<20}"
        f"{'Error':<18}"
        f"{'Fidelity':<18}"
        f"{'TrackOverlap':<18}"
        f"{'Layers':<10}"
    )

    print("=" * 140)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
            f"{r['E_vqe']:<20.10f}"
            f"{r['error']:<18.4e}"
            f"{r['fidelity']:<18.10f}"
            f"{r['tracking_overlap']:<18.10f}"
            f"{r['layers']:<10}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006162186942
# Energy error     : 4.587824e-07
# Fidelity         : 0.999999886978
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 106
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018642706104
# Energy error     : 1.278757e-06
# Fidelity         : 0.999999763569
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030507974534
# Energy error     : 8.664740e-06
# Fidelity         : 0.999998727265
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041837892983
# Energy error     : 1.357072e-05
# Fidelity         : 0.999997838858
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052707646823
# Energy error     : 2.310306e-05
# Fidelity         : 0.999996807968
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063140240611
# Energy error     : 6.451841e-06
# Fidelity         : 0.999999247218
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073219731987
# Energy error     : 4.078216e-06
# Fidelity         : 0.999999474506
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.083007069073
# Energy error     : 4.091726e-05
# Fidelity         : 0.999994761762
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092417516048
# Energy error     : 2.007940e-06
# Fidelity         : 0.999999703909
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101601769775
# Energy error     : 1.234103e-05
# Fidelity         : 0.999998698535
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
#
# ============================================================================================================================================
# SUMMARY : Symmetric
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      1.0061617282        1.0061621869        4.5878e-07        0.9999998870      1.0000000000      4
# 0.3111      1.0186414273        1.0186427061        1.2788e-06        0.9999997636      1.0000000000      4
# 0.5222      1.0304993098        1.0305079745        8.6647e-06        0.9999987273      1.0000000000      4
# 0.7333      1.0418243223        1.0418378930        1.3571e-05        0.9999978389      1.0000000000      4
# 0.9444      1.0526845438        1.0527076468        2.3103e-05        0.9999968080      1.0000000000      4
# 1.1556      1.0631337888        1.0631402406        6.4518e-06        0.9999992472      1.0000000000      4
# 1.3667      1.0732156538        1.0732197320        4.0782e-06        0.9999994745      1.0000000000      4
# 1.5778      1.0829661518        1.0830070691        4.0917e-05        0.9999947618      1.0000000000      4
# 1.7889      1.0924155081        1.0924175160        2.0079e-06        0.9999997039      1.0000000000      4
# 2.0000      1.1015894287        1.1016017698        1.2341e-05        0.9999986985      1.0000000000      4
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 1e-05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.809545836707
# Fidelity = 0.985160004617
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.942657530428
# Fidelity = 0.999844631859
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.937528954874
# Fidelity = 0.998610921946
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.875927700059
# Fidelity = 0.991908248375
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.942867083188
# Fidelity = 0.999875981103
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902169977
# VQE energy       : -16.942657530428
# Energy error     : 1.244640e-03
# Fidelity         : 0.999844631859
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.891994111152
# Fidelity = 0.999975677399
# Overlap  = 0.877100702752
#
# Restart 1
# Energy   = -8.549114169659
# Fidelity = 0.000026375554
# Overlap  = 0.000008600126
#
# Restart 2
# Energy   = -8.549010608205
# Fidelity = 0.000002169269
# Overlap  = 0.000007299679
#
# Restart 3
# Energy   = -8.892027112354
# Fidelity = 0.999988578158
# Overlap  = 0.876519655607
#
# Restart 4
# Energy   = -8.549106022474
# Fidelity = 0.000001925104
# Overlap  = 0.000007678482
#
# FINAL SELECTED STATE
# Exact energy     : -8.892068720847
# VQE energy       : -8.891994111152
# Energy error     : 7.460969e-05
# Fidelity         : 0.999975677399
# Tracking overlap : 0.877100702752
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379109289676
# Fidelity = 0.997057769181
# Overlap  = 0.049062042441
#
# Restart 1
# Energy   = -4.377380688218
# Fidelity = 0.000002113157
# Overlap  = 0.000000000207
#
# Restart 2
# Energy   = -4.377423351133
# Fidelity = 0.000001488920
# Overlap  = 0.000000000011
#
# Restart 3
# Energy   = -4.377425364365
# Fidelity = 0.000002079580
# Overlap  = 0.000000000003
#
# Restart 4
# Energy   = -4.377433190410
# Fidelity = 0.000002170014
# Overlap  = 0.000000000024
#
# FINAL SELECTED STATE
# Exact energy     : -4.379113856397
# VQE energy       : -4.379109289676
# Energy error     : 4.566721e-06
# Fidelity         : 0.997057769181
# Tracking overlap : 0.049062042441
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.741458320848
# Fidelity = 0.000000002806
# Overlap  = 0.660679885433
#
# Restart 1
# Energy   = -2.749718248641
# Fidelity = 0.999782596099
# Overlap  = 0.000000000248
#
# Restart 2
# Energy   = -2.749731458635
# Fidelity = 0.999920112238
# Overlap  = 0.000000000002
#
# Restart 3
# Energy   = -2.749764908640
# Fidelity = 0.999815245930
# Overlap  = 0.000000000107
#
# Restart 4
# Energy   = -2.749749344978
# Fidelity = 0.999839601168
# Overlap  = 0.000000000354
#
# FINAL SELECTED STATE
# Exact energy     : -2.749793396636
# VQE energy       : -2.749749344978
# Energy error     : 4.405166e-05
# Fidelity         : 0.999839601168
# Tracking overlap : 0.000000000354
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874687507932
# Fidelity = 0.999971181640
# Overlap  = 0.821386579691
#
# Restart 1
# Energy   = -1.868730673239
# Fidelity = 0.998431223638
# Overlap  = 0.802172293707
#
# Restart 2
# Energy   = -1.873376108776
# Fidelity = 0.999610172926
# Overlap  = 0.818104558432
#
# Restart 3
# Energy   = -1.872679083095
# Fidelity = 0.999394874322
# Overlap  = 0.815959149544
#
# Restart 4
# Energy   = -1.871590142640
# Fidelity = 0.999286593928
# Overlap  = 0.811920543288
#
# FINAL SELECTED STATE
# Exact energy     : -1.874700666195
# VQE energy       : -1.874687507932
# Energy error     : 1.315826e-05
# Fidelity         : 0.999971181640
# Tracking overlap : 0.821386579691
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348136952885
# Fidelity = 0.999898750085
# Overlap  = 0.895855389379
#
# Restart 1
# Energy   = -1.348227983133
# Fidelity = 0.999870607584
# Overlap  = 0.896342920929
#
# Restart 2
# Energy   = -1.348223239850
# Fidelity = 0.999881349368
# Overlap  = 0.896230503929
#
# Restart 3
# Energy   = -1.348629631265
# Fidelity = 0.999947027864
# Overlap  = 0.895733829259
#
# Restart 4
# Energy   = -1.348192662164
# Fidelity = 0.999876605599
# Overlap  = 0.896338921792
#
# FINAL SELECTED STATE
# Exact energy     : -1.348821613293
# VQE energy       : -1.348227983133
# Energy error     : 5.936302e-04
# Fidelity         : 0.999870607584
# Tracking overlap : 0.896342920929
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.007222638223
# Fidelity = 0.999466522310
# Overlap  = 0.935512592576
#
# Restart 1
# Energy   = -1.007185707973
# Fidelity = 0.999381060947
# Overlap  = 0.934973173814
#
# Restart 2
# Energy   = -1.006998368671
# Fidelity = 0.999404496918
# Overlap  = 0.935603657101
#
# Restart 3
# Energy   = -1.007155334109
# Fidelity = 0.999459684975
# Overlap  = 0.935574980404
#
# Restart 4
# Energy   = -1.007208206975
# Fidelity = 0.999486710911
# Overlap  = 0.935446829252
#
# FINAL SELECTED STATE
# Exact energy     : -1.010439481239
# VQE energy       : -1.006998368671
# Energy error     : 3.441113e-03
# Fidelity         : 0.999404496918
# Tracking overlap : 0.935603657101
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.775807370020
# Fidelity = 0.999494138200
# Overlap  = 0.962185513226
#
# Restart 1
# Energy   = -0.775816587255
# Fidelity = 0.999494554630
# Overlap  = 0.962055571387
#
# Restart 2
# Energy   = -0.775785936519
# Fidelity = 0.999494809215
# Overlap  = 0.962091351548
#
# Restart 3
# Energy   = -0.775765229717
# Fidelity = 0.999502896690
# Overlap  = 0.961983864711
#
# Restart 4
# Energy   = -0.775809490737
# Fidelity = 0.999501132137
# Overlap  = 0.962103542521
#
# FINAL SELECTED STATE
# Exact energy     : -0.779139779365
# VQE energy       : -0.775807370020
# Energy error     : 3.332409e-03
# Fidelity         : 0.999494138200
# Tracking overlap : 0.962185513226
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.609489073037
# Fidelity = 0.999690796513
# Overlap  = 0.978166062501
#
# Restart 1
# Energy   = -0.609493598715
# Fidelity = 0.999683022564
# Overlap  = 0.978141791209
#
# Restart 2
# Energy   = -0.609506440345
# Fidelity = 0.999690760102
# Overlap  = 0.978174922373
#
# Restart 3
# Energy   = -0.609511586084
# Fidelity = 0.999689202294
# Overlap  = 0.978174777078
#
# Restart 4
# Energy   = -0.609480838442
# Fidelity = 0.999683138113
# Overlap  = 0.978169946770
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723370121
# VQE energy       : -0.609506440345
# Energy error     : 2.216930e-03
# Fidelity         : 0.999690760102
# Tracking overlap : 0.978174922373
# Layers            : 4
# Pauli terms       : 110
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.483114955525
# Fidelity = 0.999847116243
# Overlap  = 0.986813348375
#
# Restart 1
# Energy   = -0.483106367062
# Fidelity = 0.999846398904
# Overlap  = 0.986804303025
#
# Restart 2
# Energy   = -0.483115628674
# Fidelity = 0.999845848713
# Overlap  = 0.986788396739
#
# Restart 3
# Energy   = -0.483114147399
# Fidelity = 0.999847375017
# Overlap  = 0.986799474302
#
# Restart 4
# Energy   = -0.483114774750
# Fidelity = 0.999845123315
# Overlap  = 0.986813955721
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295385847
# VQE energy       : -0.483114774750
# Energy error     : 1.180611e-03
# Fidelity         : 0.999845123315
# Tracking overlap : 0.986813955721
# Layers            : 4
# Pauli terms       : 110
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9439021700      -16.9426575304      1.2446e-03        0.9998446319      1.0000000000      4
# 0.3111      -8.8920687208       -8.8919941112       7.4610e-05        0.9999756774      0.8771007028      4
# 0.5222      -4.3791138564       -4.3791092897       4.5667e-06        0.9970577692      0.0490620424      4
# 0.7333      -2.7497933966       -2.7497493450       4.4052e-05        0.9998396012      0.0000000004      4
# 0.9444      -1.8747006662       -1.8746875079       1.3158e-05        0.9999711816      0.8213865797      4
# 1.1556      -1.3488216133       -1.3482279831       5.9363e-04        0.9998706076      0.8963429209      4
# 1.3667      -1.0104394812       -1.0069983687       3.4411e-03        0.9994044969      0.9356036571      4
# 1.5778      -0.7791397794       -0.7758073700       3.3324e-03        0.9994941382      0.9621855132      4
# 1.7889      -0.6117233701       -0.6095064403       2.2169e-03        0.9996907601      0.9781749224      4
# 2.0000      -0.4842953858       -0.4831147747       1.1806e-03        0.9998451233      0.9868139557      4
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.686425349549
# Fidelity = 0.990463018137
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -20.737086677045
# Fidelity = 0.994898321655
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -20.754407831441
# Fidelity = 0.997351204550
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -20.699885526121
# Fidelity = 0.991782794701
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -20.745244090459
# Fidelity = 0.996195585927
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.754407831441
# Energy error     : 2.292061e-02
# Fidelity         : 0.997351204550
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.814699649282
# Fidelity = 0.995607890371
# Overlap  = 0.860142037057
#
# Restart 1
# Energy   = -12.700217128821
# Fidelity = 0.971756049777
# Overlap  = 0.886638127054
#
# Restart 2
# Energy   = -12.812836248242
# Fidelity = 0.995332408493
# Overlap  = 0.864447759382
#
# Restart 3
# Energy   = -12.806078879126
# Fidelity = 0.994940884299
# Overlap  = 0.850483102630
#
# Restart 4
# Energy   = -12.812576604435
# Fidelity = 0.995118562556
# Overlap  = 0.863431505903
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.814699649282
# Energy error     : 2.174149e-02
# Fidelity         : 0.995607890371
# Tracking overlap : 0.860142037057
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.632593671286
# Fidelity = 0.977491126722
# Overlap  = 0.174950315599
#
# Restart 1
# Energy   = -7.641153782896
# Fidelity = 0.980096870136
# Overlap  = 0.166788223461
#
# Restart 2
# Energy   = -7.659103281815
# Fidelity = 0.984449528970
# Overlap  = 0.169678427077
#
# Restart 3
# Energy   = -7.662960972935
# Fidelity = 0.985952459129
# Overlap  = 0.168403658303
#
# Restart 4
# Energy   = -7.636837726176
# Fidelity = 0.980475426350
# Overlap  = 0.171881903595
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.662960972935
# Energy error     : 6.775539e-02
# Fidelity         : 0.985952459129
# Tracking overlap : 0.168403658303
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.515387884980
# Fidelity = 0.996027235732
# Overlap  = 0.614334099115
#
# Restart 1
# Energy   = -5.477944823368
# Fidelity = 0.988034334776
# Overlap  = 0.600994945600
#
# Restart 2
# Energy   = -5.504110572722
# Fidelity = 0.994564484217
# Overlap  = 0.611347533745
#
# Restart 3
# Energy   = -5.479126239097
# Fidelity = 0.988738894458
# Overlap  = 0.597245143502
#
# Restart 4
# Energy   = -5.501482837967
# Fidelity = 0.993921899394
# Overlap  = 0.607133907789
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.515387884980
# Energy error     : 2.276095e-02
# Fidelity         : 0.996027235732
# Tracking overlap : 0.614334099115
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.271191790122
# Fidelity = 0.999444681610
# Overlap  = 0.830940091366
#
# Restart 1
# Energy   = -4.256738895604
# Fidelity = 0.996386018537
# Overlap  = 0.810875130486
#
# Restart 2
# Energy   = -4.259191032574
# Fidelity = 0.997296201946
# Overlap  = 0.818257301877
#
# Restart 3
# Energy   = -4.251203915327
# Fidelity = 0.994540696289
# Overlap  = 0.798960424615
#
# Restart 4
# Energy   = -4.255716286022
# Fidelity = 0.996292608226
# Overlap  = 0.805579492732
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.271191790122
# Energy error     : 4.822003e-03
# Fidelity         : 0.999444681610
# Tracking overlap : 0.830940091366
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.445733924244
# Fidelity = 0.999652411733
# Overlap  = 0.907106863495
#
# Restart 1
# Energy   = -3.444157439729
# Fidelity = 0.999431872150
# Overlap  = 0.904571722714
#
# Restart 2
# Energy   = -3.444351037396
# Fidelity = 0.999440514093
# Overlap  = 0.903423787157
#
# Restart 3
# Energy   = -3.445222917577
# Fidelity = 0.999595915902
# Overlap  = 0.905552704319
#
# Restart 4
# Energy   = -3.444851240167
# Fidelity = 0.999536593740
# Overlap  = 0.905504569081
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.445733924244
# Energy error     : 2.946461e-03
# Fidelity         : 0.999652411733
# Tracking overlap : 0.907106863495
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.855483726212
# Fidelity = 0.999198342092
# Overlap  = 0.941435516603
#
# Restart 1
# Energy   = -2.855194268191
# Fidelity = 0.999123775093
# Overlap  = 0.943491110550
#
# Restart 2
# Energy   = -2.855695646981
# Fidelity = 0.999235688178
# Overlap  = 0.942931177732
#
# Restart 3
# Energy   = -2.855407741773
# Fidelity = 0.999200644296
# Overlap  = 0.943430327362
#
# Restart 4
# Energy   = -2.858986509877
# Fidelity = 0.999789457355
# Overlap  = 0.942183856082
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.858986509877
# Energy error     : 1.845755e-03
# Fidelity         : 0.999789457355
# Tracking overlap : 0.942183856082
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.417716680755
# Fidelity = 0.999737228244
# Overlap  = 0.962300104353
#
# Restart 1
# Energy   = -2.409316576005
# Fidelity = 0.998394223098
# Overlap  = 0.959087131488
#
# Restart 2
# Energy   = -2.409653795324
# Fidelity = 0.998378752058
# Overlap  = 0.959886151738
#
# Restart 3
# Energy   = -2.409555294366
# Fidelity = 0.998362374429
# Overlap  = 0.959283203106
#
# Restart 4
# Energy   = -2.410750199609
# Fidelity = 0.998547638539
# Overlap  = 0.959199576519
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.417716680755
# Energy error     : 2.373849e-03
# Fidelity         : 0.999737228244
# Tracking overlap : 0.962300104353
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.073328037402
# Fidelity = 0.999689123352
# Overlap  = 0.973768315703
#
# Restart 1
# Energy   = -2.066299439722
# Fidelity = 0.998556181916
# Overlap  = 0.970367000469
#
# Restart 2
# Energy   = -2.033153210170
# Fidelity = 0.988689125764
# Overlap  = 0.953726226021
#
# Restart 3
# Energy   = -2.066643763892
# Fidelity = 0.998572287334
# Overlap  = 0.970586914195
#
# Restart 4
# Energy   = -2.067740270812
# Fidelity = 0.998785518788
# Overlap  = 0.970569555004
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.073328037402
# Energy error     : 2.984530e-03
# Fidelity         : 0.999689123352
# Tracking overlap : 0.973768315703
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.797254043703
# Fidelity = 0.999707665668
# Overlap  = 0.981078701646
#
# Restart 1
# Energy   = -1.793029194308
# Fidelity = 0.999030742652
# Overlap  = 0.978636848985
#
# Restart 2
# Energy   = -1.792889430396
# Fidelity = 0.998988186656
# Overlap  = 0.978432083513
#
# Restart 3
# Energy   = -1.792906600003
# Fidelity = 0.999013068654
# Overlap  = 0.978761019745
#
# Restart 4
# Energy   = -1.792908491161
# Fidelity = 0.999018263760
# Overlap  = 0.978825539520
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.797254043703
# Energy error     : 2.819223e-03
# Fidelity         : 0.999707665668
# Tracking overlap : 0.981078701646
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Strong SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -20.7773284453      -20.
-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063463
# T = 10    Fidelity = 0.00012346
# T = 20    Fidelity = 0.00391382
# T = 30    Fidelity = 0.05548186
# T = 40    Fidelity = 0.12290767
# T = 50    Fidelity = 0.21156451
# T = 75    Fidelity = 0.58163681
# T = 100   Fidelity = 0.76645610
# T = 125   Fidelity = 0.73522614
# T = 150   Fidelity = 0.86905309
# T = 175   Fidelity = 0.91433334
# T = 200   Fidelity = 0.87549122
# T = 225   Fidelity = 0.95204758
# T = 250   Fidelity = 0.98631872
#
# Minimum T for Fidelity >= 0.97 : 250
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.22564919e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00018340
# T = 10    Fidelity = 0.04100949
# T = 20    Fidelity = 0.42085070
# T = 30    Fidelity = 0.49077442
# T = 40    Fidelity = 0.64151681
# T = 50    Fidelity = 0.64439219
# T = 75    Fidelity = 0.88083068
# T = 100   Fidelity = 0.90212150
# T = 125   Fidelity = 0.87210670
# T = 150   Fidelity = 0.88632945
# T = 175   Fidelity = 0.92112478
# T = 200   Fidelity = 0.94270430
# T = 225   Fidelity = 0.95693998
# T = 250   Fidelity = 0.95095170
# T = 275   Fidelity = 0.96224138
# T = 300   Fidelity = 0.94435938
# T = 400   Fidelity = 0.98176304
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.14483174e-04
# T = 1     Fidelity = 0.00001182
# T = 2     Fidelity = 0.00016896
# T = 5     Fidelity = 0.01433491
# T = 10    Fidelity = 0.17121654
# T = 20    Fidelity = 0.44272552
# T = 30    Fidelity = 0.34005890
# T = 40    Fidelity = 0.54717422
# T = 50    Fidelity = 0.43879187
# T = 75    Fidelity = 0.49360002
# T = 100   Fidelity = 0.50316471
# T = 125   Fidelity = 0.50308171
# T = 150   Fidelity = 0.50221547
# T = 175   Fidelity = 0.50142503
# T = 200   Fidelity = 0.49698141
# T = 225   Fidelity = 0.50876115
# T = 250   Fidelity = 0.50136872
# T = 275   Fidelity = 0.48749573
# T = 300   Fidelity = 0.48757740
# T = 400   Fidelity = 0.49866739
# T = 500   Fidelity = 0.30951966
# T = 600   Fidelity = 0.51096142
# T = 700   Fidelity = 0.39123729
# T = 800   Fidelity = 0.53871605
# T = 900   Fidelity = 0.53604472
# T = 1000  Fidelity = 0.70832226
# T = 1010  Fidelity = 0.40404759
# T = 1020  Fidelity = 0.40786760
# T = 1030  Fidelity = 0.47794720
# T = 1040  Fidelity = 0.50605346
# T = 1050  Fidelity = 0.47577527
# T = 1060  Fidelity = 0.37539223
# T = 1070  Fidelity = 0.57018271
# T = 1080  Fidelity = 0.27357908
# T = 1090  Fidelity = 0.28163277
# T = 1100  Fidelity = 0.62085118
# T = 1200  Fidelity = 0.29944254
# T = 1300  Fidelity = 0.56647525
# T = 1400  Fidelity = 0.55231818
# T = 1500  Fidelity = 0.37840084
# T = 2000  Fidelity = 0.31510731
# T = 2100  Fidelity = 0.22276369
# T = 2110  Fidelity = 0.58886735
# T = 2120  Fidelity = 0.50691907
# T = 2130  Fidelity = 0.53892351
# T = 2140  Fidelity = 0.35492783
# T = 2150  Fidelity = 0.48216184
# T = 2160  Fidelity = 0.42018127
# T = 2170  Fidelity = 0.42322166
# T = 2180  Fidelity = 0.57071503
# T = 2190  Fidelity = 0.21667102
# T = 2200  Fidelity = 0.51738176
# T = 2300  Fidelity = 0.57563017
# T = 2400  Fidelity = 0.53676245
# T = 2500  Fidelity = 0.50396756
# T = 2600  Fidelity = 0.51043145
# T = 2700  Fidelity = 0.63549005
# T = 2800  Fidelity = 0.66477064
# T = 2900  Fidelity = 0.52315621
# T = 3000  Fidelity = 0.49546622
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.49546622
# P1     = 0.00066293
# P0+P1  = 0.49612915
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.21982966e-04
# T = 1     Fidelity = 0.00306925
# T = 2     Fidelity = 0.01238374
# T = 5     Fidelity = 0.08436355
# T = 10    Fidelity = 0.22344717
# T = 20    Fidelity = 0.31779439
# T = 30    Fidelity = 0.38304077
# T = 40    Fidelity = 0.54974665
# T = 50    Fidelity = 0.58075213
# T = 75    Fidelity = 0.50037381
# T = 100   Fidelity = 0.52177113
# T = 125   Fidelity = 0.52336566
# T = 150   Fidelity = 0.52319563
# T = 175   Fidelity = 0.52000323
# T = 200   Fidelity = 0.53033898
# T = 225   Fidelity = 0.52292644
# T = 250   Fidelity = 0.51830655
# T = 275   Fidelity = 0.52662209
# T = 300   Fidelity = 0.49518537
# T = 400   Fidelity = 0.51003641
# T = 500   Fidelity = 0.55446334
# T = 600   Fidelity = 0.50907292
# T = 700   Fidelity = 0.44381751
# T = 800   Fidelity = 0.45443167
# T = 900   Fidelity = 0.53558024
# T = 1000  Fidelity = 0.78110239
# T = 1010  Fidelity = 0.44828207
# T = 1020  Fidelity = 0.12725674
# T = 1030  Fidelity = 0.56290262
# T = 1040  Fidelity = 0.79511991
# T = 1050  Fidelity = 0.59784534
# T = 1060  Fidelity = 0.48944966
# T = 1070  Fidelity = 0.50200608
# T = 1080  Fidelity = 0.42480972
# T = 1090  Fidelity = 0.25693128
# T = 1100  Fidelity = 0.74485108
# T = 1200  Fidelity = 0.58968487
# T = 1300  Fidelity = 0.45971108
# T = 1400  Fidelity = 0.52937585
# T = 1500  Fidelity = 0.54442391
# T = 2000  Fidelity = 0.46785692
# T = 2100  Fidelity = 0.53038932
# T = 2110  Fidelity = 0.56808380
# T = 2120  Fidelity = 0.48125934
# T = 2130  Fidelity = 0.40457719
# T = 2140  Fidelity = 0.57394506
# T = 2150  Fidelity = 0.78521984
# T = 2160  Fidelity = 0.45192918
# T = 2170  Fidelity = 0.25309952
# T = 2180  Fidelity = 0.50750874
# T = 2190  Fidelity = 0.70346656
# T = 2200  Fidelity = 0.63132253
# T = 2300  Fidelity = 0.83233484
# T = 2400  Fidelity = 0.55109402
# T = 2500  Fidelity = 0.52133960
# T = 2600  Fidelity = 0.57277151
# T = 2700  Fidelity = 0.46747891
# T = 2800  Fidelity = 0.55981710
# T = 2900  Fidelity = 0.32448876
# T = 3000  Fidelity = 0.46076070
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.46076070
# P1     = 0.00024328
# P0+P1  = 0.46100398
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.33063144e-03
# T = 1     Fidelity = 0.02405694
# T = 2     Fidelity = 0.06516475
# T = 5     Fidelity = 0.21905075
# T = 10    Fidelity = 0.40681572
# T = 20    Fidelity = 0.52932063
# T = 30    Fidelity = 0.49785249
# T = 40    Fidelity = 0.50386519
# T = 50    Fidelity = 0.54927534
# T = 75    Fidelity = 0.60865001
# T = 100   Fidelity = 0.60706522
# T = 125   Fidelity = 0.61207580
# T = 150   Fidelity = 0.61605469
# T = 175   Fidelity = 0.61941158
# T = 200   Fidelity = 0.62645542
# T = 225   Fidelity = 0.62929591
# T = 250   Fidelity = 0.63307087
# T = 275   Fidelity = 0.62996131
# T = 300   Fidelity = 0.64620158
# T = 400   Fidelity = 0.59412175
# T = 500   Fidelity = 0.65373908
# T = 600   Fidelity = 0.67757528
# T = 700   Fidelity = 0.59511435
# T = 800   Fidelity = 0.71409985
# T = 900   Fidelity = 0.60951504
# T = 1000  Fidelity = 0.48796169
# T = 1010  Fidelity = 0.76100535
# T = 1020  Fidelity = 0.85264754
# T = 1030  Fidelity = 0.75199652
# T = 1040  Fidelity = 0.53079987
# T = 1050  Fidelity = 0.47569467
# T = 1060  Fidelity = 0.65095740
# T = 1070  Fidelity = 0.77846953
# T = 1080  Fidelity = 0.82288263
# T = 1090  Fidelity = 0.55786874
# T = 1100  Fidelity = 0.40190808
# T = 1200  Fidelity = 0.46097816
# T = 1300  Fidelity = 0.54242477
# T = 1400  Fidelity = 0.77143905
# T = 1500  Fidelity = 0.68256560
# T = 2000  Fidelity = 0.77616577
# T = 2100  Fidelity = 0.82185852
# T = 2110  Fidelity = 0.81249985
# T = 2120  Fidelity = 0.55443254
# T = 2130  Fidelity = 0.65790486
# T = 2140  Fidelity = 0.71475831
# T = 2150  Fidelity = 0.83409575
# T = 2160  Fidelity = 0.84960888
# T = 2170  Fidelity = 0.78542526
# T = 2180  Fidelity = 0.53546949
# T = 2190  Fidelity = 0.57229749
# T = 2200  Fidelity = 0.70206861
# T = 2300  Fidelity = 0.77089316
# T = 2400  Fidelity = 0.75743735
# T = 2500  Fidelity = 0.83044910
# T = 2600  Fidelity = 0.73444348
# T = 2700  Fidelity = 0.78127876
# T = 2800  Fidelity = 0.76627121
# T = 2900  Fidelity = 0.70208923
# T = 3000  Fidelity = 0.75460624
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.75460624
# P1     = 0.00009359
# P0+P1  = 0.75469982
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50115281e-02
# T = 1     Fidelity = 0.08301532
# T = 2     Fidelity = 0.17507868
# T = 5     Fidelity = 0.39217469
# T = 10    Fidelity = 0.58557708
# T = 20    Fidelity = 0.71367506
# T = 30    Fidelity = 0.72015321
# T = 40    Fidelity = 0.71294779
# T = 50    Fidelity = 0.71869192
# T = 75    Fidelity = 0.74406100
# T = 100   Fidelity = 0.76238569
# T = 125   Fidelity = 0.77519751
# T = 150   Fidelity = 0.78575331
# T = 175   Fidelity = 0.79495801
# T = 200   Fidelity = 0.80412315
# T = 225   Fidelity = 0.81033227
# T = 250   Fidelity = 0.81604616
# T = 275   Fidelity = 0.82577119
# T = 300   Fidelity = 0.81736889
# T = 400   Fidelity = 0.87432672
# T = 500   Fidelity = 0.87060230
# T = 600   Fidelity = 0.79407293
# T = 700   Fidelity = 0.82798589
# T = 800   Fidelity = 0.84450635
# T = 900   Fidelity = 0.85205032
# T = 1000  Fidelity = 0.87668311
# T = 1010  Fidelity = 0.79381082
# T = 1020  Fidelity = 0.77900750
# T = 1030  Fidelity = 0.86800646
# T = 1040  Fidelity = 0.95141869
# T = 1050  Fidelity = 0.97306353
#
# Minimum T for Fidelity >= 0.97 : 1050
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77198754e-02
# T = 1     Fidelity = 0.17832240
# T = 2     Fidelity = 0.31910604
# T = 5     Fidelity = 0.55735958
# T = 10    Fidelity = 0.72531150
# T = 20    Fidelity = 0.82871467
# T = 30    Fidelity = 0.85227220
# T = 40    Fidelity = 0.85820152
# T = 50    Fidelity = 0.86397053
# T = 75    Fidelity = 0.88141636
# T = 100   Fidelity = 0.89771344
# T = 125   Fidelity = 0.90908250
# T = 150   Fidelity = 0.91737237
# T = 175   Fidelity = 0.92501066
# T = 200   Fidelity = 0.93432322
# T = 225   Fidelity = 0.93505950
# T = 250   Fidelity = 0.93491954
# T = 275   Fidelity = 0.94423086
# T = 300   Fidelity = 0.93519830
# T = 400   Fidelity = 0.94775513
# T = 500   Fidelity = 0.95222529
# T = 600   Fidelity = 0.96092991
# T = 700   Fidelity = 0.91700545
# T = 800   Fidelity = 0.92742875
# T = 900   Fidelity = 0.94651597
# T = 1000  Fidelity = 0.94009030
# T = 1010  Fidelity = 0.95046345
# T = 1020  Fidelity = 0.95525783
# T = 1030  Fidelity = 0.97889412
#
# Minimum T for Fidelity >= 0.97 : 1030
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20186803e-01
# T = 1     Fidelity = 0.28451423
# T = 2     Fidelity = 0.45721576
# T = 5     Fidelity = 0.68456254
# T = 10    Fidelity = 0.82015811
# T = 20    Fidelity = 0.89616676
# T = 30    Fidelity = 0.91744584
# T = 40    Fidelity = 0.92876454
# T = 50    Fidelity = 0.93738744
# T = 75    Fidelity = 0.95108334
# T = 100   Fidelity = 0.96129369
# T = 125   Fidelity = 0.96768965
# T = 150   Fidelity = 0.97354787
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405410e-01
# T = 1     Fidelity = 0.38234498
# T = 2     Fidelity = 0.57010035
# T = 5     Fidelity = 0.77248771
# T = 10    Fidelity = 0.87990963
# T = 20    Fidelity = 0.93517994
# T = 30    Fidelity = 0.95253895
# T = 40    Fidelity = 0.96368720
# T = 50    Fidelity = 0.96933323
# T = 75    Fidelity = 0.97917675
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843285e-01
# T = 1     Fidelity = 0.46606699
# T = 2     Fidelity = 0.65753712
# T = 5     Fidelity = 0.83219553
# T = 10    Fidelity = 0.91743200
# T = 20    Fidelity = 0.95847362
# T = 30    Fidelity = 0.97270257
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000016
# T = 5     Fidelity = 0.00082549
# T = 10    Fidelity = 0.06504508
# T = 20    Fidelity = 0.45480473
# T = 30    Fidelity = 0.87963387
# T = 40    Fidelity = 0.96477670
# T = 50    Fidelity = 0.98935922
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000130
# T = 5     Fidelity = 0.02560454
# T = 10    Fidelity = 0.89149347
# T = 20    Fidelity = 0.96573256
# T = 30    Fidelity = 0.99251831
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00006875
# T = 2     Fidelity = 0.00052405
# T = 5     Fidelity = 0.18820615
# T = 10    Fidelity = 0.97289728
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00146651
# T = 2     Fidelity = 0.00858912
# T = 5     Fidelity = 0.33655040
# T = 10    Fidelity = 0.98253739
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00721766
# T = 2     Fidelity = 0.02951129
# T = 5     Fidelity = 0.46869697
# T = 10    Fidelity = 0.98064822
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02090094
# T = 2     Fidelity = 0.06415946
# T = 5     Fidelity = 0.56474974
# T = 10    Fidelity = 0.97615891
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04433532
# T = 2     Fidelity = 0.11095635
# T = 5     Fidelity = 0.63687481
# T = 10    Fidelity = 0.97171154
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07618606
# T = 2     Fidelity = 0.16448808
# T = 5     Fidelity = 0.69486807
# T = 10    Fidelity = 0.96873811
# T = 20    Fidelity = 0.99302016
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11494201
# T = 2     Fidelity = 0.22197794
# T = 5     Fidelity = 0.74167196
# T = 10    Fidelity = 0.96694157
# T = 20    Fidelity = 0.99338048
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15818217
# T = 2     Fidelity = 0.28009149
# T = 5     Fidelity = 0.78006777
# T = 10    Fidelity = 0.96636638
# T = 20    Fidelity = 0.99363293
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     1         0.9811974658      1.00972087e+00    None        None        None
# Symmetric      0.311     1         0.9826785054      1.02934439e+00    None        None        None
# Symmetric      0.522     1         0.9839408606      1.04790824e+00    None        None        None
# Symmetric      0.733     1         0.9850295405      1.06556366e+00    None        None        None
# Symmetric      0.944     1         0.9860133088      1.08242773e+00    None        None        None
# Symmetric      1.156     1         0.9868304741      1.09859358e+00    None        None        None
# Symmetric      1.367     1         0.9876172276      1.11413694e+00    None        None        None
# Symmetric      1.578     1         0.9883028251      1.12912045e+00    None        None        None
# Symmetric      1.789     1         0.9889322390      1.14359670e+00    None        None        None
# Symmetric      2.000     1         0.9895015696      1.15761039e+00    None        None        None
# Weak SSB       0.100     250       0.9863187168      3.13498607e-04    None        None        None
# Weak SSB       0.311     400       0.9817630412      1.22564919e-04    None        None        None
# Weak SSB       0.522     None      0.7083222626      1.14483174e-04    0.495466    0.000663    0.496129
# Weak SSB       0.733     None      0.8323348362      2.21982966e-04    0.460761    0.000243    0.461004
# Weak SSB       0.944     None      0.8526475353      4.33063144e-03    0.754606    9.4e-05     0.7547
# Weak SSB       1.156     1050      0.9730635342      2.50115281e-02    None        None        None
# Weak SSB       1.367     1030      0.9788941234      6.77198754e-02    None        None        None
# Weak SSB       1.578     150       0.9735478658      1.20186803e-01    None        None        None
# Weak SSB       1.789     75        0.9791767537      1.71405410e-01    None        None        None
# Weak SSB       2.000     30        0.9727025717      2.18843285e-01    None        None        None
# Strong SSB     0.100     50        0.9893592184      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9925183143      7.22062439e-01    None        None        None
# Strong SSB     0.522     10        0.9728972803      7.78318602e-01    None        None        None
# Strong SSB     0.733     10        0.9825373862      8.15979742e-01    None        None        None
# Strong SSB     0.944     10        0.9806482206      8.44059983e-01    None        None        None
# Strong SSB     1.156     10        0.9761589096      8.66317759e-01    None        None        None
# Strong SSB     1.367     10        0.9717115444      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9930201591      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9933804751      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9936329336      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()
