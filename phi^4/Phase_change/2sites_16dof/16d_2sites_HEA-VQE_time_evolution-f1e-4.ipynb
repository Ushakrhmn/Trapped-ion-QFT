# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756816
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Genuine Qiskit VQE on shifted Pauli Hamiltonian
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SPSA

from qiskit.primitives import StatevectorEstimator


# ============================================================
# Variational circuit
# ============================================================

def variational_circuit(nq, layers):

    qc = QuantumCircuit(nq)

    nparams = 2 * nq * layers

    params = ParameterVector("θ", nparams)

    p = 0

    for l in range(layers):

        # ----------------------------------------------------
        # Single-qubit rotations
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(params[p], q)
            qc.rz(params[p + 1], q)

            p += 2

        # ----------------------------------------------------
        # Entanglement layer
        # ----------------------------------------------------

        if l != layers - 1:

            # even bonds
            if l % 2 == 0:

                for q in range(0, nq - 1, 2):
                    qc.cz(q, q + 1)

            # odd bonds
            else:

                for q in range(1, nq - 1, 2):
                    qc.cz(q, q + 1)

    return qc


# ============================================================
# Ansatz
# ============================================================

nqubits = 8

# start modestly
layers = 8

ansatz = variational_circuit(
    nqubits,
    layers
)

# ============================================================
# Estimator
# ============================================================

estimator = StatevectorEstimator()

# ============================================================
# Optimizer
# ============================================================

optimizer = SPSA(
    maxiter=5000
)

# ============================================================
# VQE
# ============================================================
initial_point = 0.01 * np.random.randn(
    ansatz.num_parameters
)
vqe = VQE(
    estimator=estimator,
    ansatz=ansatz,
    optimizer=optimizer,
    initial_point=initial_point
)

# ============================================================
# Run VQE
# ============================================================

print("\nRunning VQE...\n")

result = vqe.compute_minimum_eigenvalue(
    H_pauli_shifted
)

# ============================================================
# Shifted energy
# ============================================================

E_shifted = result.eigenvalue.real

# ============================================================
# Physical energy
# ============================================================

E_vqe = E_shifted + identity_shift

# ============================================================
# Optimal parameters
# ============================================================

optimal_params = result.optimal_parameters

# ============================================================
# Optimized circuit
# ============================================================

optimal_circuit = ansatz.assign_parameters(
    optimal_params
)

# ============================================================
# VQE state
# ============================================================

psi_vqe = Statevector.from_instruction(
    optimal_circuit
).data

# ============================================================
# Fidelity
# ============================================================

Fidelity = np.abs(
    np.vdot(psi_loc, psi_vqe)
)**2

# ============================================================
# Results
# ============================================================

print("\n================================")
print("Exact energy :", E0_loc)
print("VQE energy   :", E_vqe)
print("Energy error :", abs(E_vqe - E0_loc))
print("Fidelity     :", Fidelity)
print("Layers        :", layers)
print("Pauli terms   :", len(H_pauli_shifted))
print("================================")
# Out:
# Running VQE...
#
#
# ================================
# Exact energy : 1.0554722545756816
# VQE energy   : 1.0668143582335112
# Energy error : 0.011342103657829616
# Fidelity     : 0.9975590174861528
# Layers        : 8
# Pauli terms   : 111
# ================================

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Robust VQE with eigenstate tracking
# ============================================================
import numpy as np

from scipy.sparse import identity, kron

from qiskit.quantum_info import (
    Statevector,
    Operator,
    SparsePauliOp
)

from qiskit.primitives import StatevectorEstimator

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B
def run_robust_vqe(

    H_sparse,

    nq,

    layers,

    n_restarts,

    energy_tol,

    previous_state=None,

    previous_optimal_point=None
):

    nqubits = nq

    # --------------------------------------------------------
    # Exact ground state
    # --------------------------------------------------------

    E_exact, psi_exact = exact_ground_state(H_sparse)

    # --------------------------------------------------------
    # Convert Hamiltonian
    # --------------------------------------------------------

    H_dense = H_sparse.toarray()

    H_op = Operator(H_dense)

    H_pauli = SparsePauliOp.from_operator(H_op)

    coeffs = H_pauli.coeffs

    paulis = H_pauli.paulis

    new_coeffs = []

    new_paulis = []

    identity_shift = 0.0

    for p, c in zip(paulis, coeffs):

        if str(p) == 'I' * nqubits:

            identity_shift += np.real(c)

        else:

            new_paulis.append(p)

            new_coeffs.append(c)

    H_pauli_shifted = SparsePauliOp(

        new_paulis,

        coeffs=new_coeffs
    )

    # --------------------------------------------------------
    # Ansatz
    # --------------------------------------------------------

    ansatz = variational_circuit(

        nq=nqubits,

        layers=layers
    )

    estimator = StatevectorEstimator()

    optimizer = L_BFGS_B(maxiter=1000)

    # ========================================================
    # Multiple restarts
    # ========================================================

    trial_results = []

    for trial in range(n_restarts):

        # ----------------------------------------------------
        # Initial point
        # ----------------------------------------------------

        if trial == 0 and previous_optimal_point is not None:

            initial_point = previous_optimal_point

        else:

            initial_point = 0.01 * np.random.randn(

                ansatz.num_parameters
            )

        # ----------------------------------------------------
        # VQE
        # ----------------------------------------------------

        vqe = VQE(

            estimator=estimator,

            ansatz=ansatz,

            optimizer=optimizer,

            initial_point=initial_point
        )

        result = vqe.compute_minimum_eigenvalue(

            H_pauli_shifted
        )

        E_trial = (

            np.real(result.eigenvalue)

            + identity_shift
        )

        # ----------------------------------------------------
        # Trial state
        # ----------------------------------------------------

        qc_trial = ansatz.assign_parameters(

            result.optimal_parameters
        )

        psi_trial = Statevector.from_instruction(

            qc_trial

        ).data

        # ----------------------------------------------------
        # Overlap tracking
        # ----------------------------------------------------

        if previous_state is None:

            overlap = 1.0

        else:

            overlap = abs(np.vdot(

                previous_state,

                psi_trial

            ))**2

        trial_results.append({

            'energy': E_trial,

            'overlap': overlap,

            'state': psi_trial,

            'result': result
        })

    # ========================================================
    # Hybrid selection
    # ========================================================

    energies = np.array([

        t['energy']

        for t in trial_results
    ])

    E_min = np.min(energies)

    filtered_candidates = [

        t for t in trial_results

        if (t['energy'] - E_min) < energy_tol
    ]

    best_candidate = max(

        filtered_candidates,

        key=lambda x: x['overlap']
    )

    # ========================================================
    # Outputs
    # ========================================================

    # ========================================================
    # Final outputs
    # ========================================================

    psi_vqe = best_candidate['state']

    E_vqe = best_candidate['energy']

    optimal_point = (

        best_candidate['result'].optimal_point
    )

    tracking_overlap = best_candidate['overlap']

    F = fidelity(

    psi_exact,

    psi_vqe
    )

    return {

        "E_exact": E_exact,

        "E_vqe": E_vqe,

        "psi_vqe": psi_vqe,

        "fidelity": F,

        "tracking_overlap": tracking_overlap,

        "optimal_point": optimal_point,

        "state_for_tracking": psi_vqe
    }

# %%
nq_site = 4

nqubits = 2 * nq_site

mu = 1.0

layers = 8

# ============================================================
# VQE settings
# ============================================================

n_restarts = 5

energy_tol = 1e-3

# ============================================================
# Parameter sets
# ============================================================

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },

    {
        "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-5
    },
    
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
    
    {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ============================================================
# Lambda scan
# ============================================================

lambda_list = np.linspace(0.1, 2.0, 10)

# ============================================================
# Storage
# ============================================================

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]

    mI2 = params["mI2"]

    f = params["f"]

    print("\n")
    print("#"*80)

    print(f"CASE: {label}")

    print(f"mI² = {mI2},  f = {f}")

    print("#"*80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None

    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "="*60)

        print(f"Running λ = {lam:.3f}")

        print("="*60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(

            nq=nq_site,

            mu=mu,

            mI2=mI2,

            lam=lam,

            f=f
        )

        # ====================================================
        # Run robust VQE
        # ====================================================

        vqe_data = run_robust_vqe(

            H_sparse=Hloc_sparse,

            nq=nqubits,

            layers=layers,

            n_restarts=n_restarts,

            energy_tol=energy_tol,

            previous_state=previous_state,

            previous_optimal_point=previous_optimal_point
        )

        # ====================================================
        # Extract outputs
        # ====================================================

        E_exact = vqe_data["E_exact"]

        E_vqe = vqe_data["E_vqe"]

        psi_vqe = vqe_data["psi_vqe"]

        F = vqe_data["fidelity"]

        tracking_overlap = vqe_data["tracking_overlap"]

        # ----------------------------------------------------
        # Update tracking
        # ----------------------------------------------------

        previous_state = vqe_data["state_for_tracking"]

        previous_optimal_point = (

            vqe_data["optimal_point"]
        )

        # ----------------------------------------------------
        # Store
        # ----------------------------------------------------

        data = {

            'case': label,

            'lambda': lam,

            'mI2': mI2,

            'f': f,

            'E_exact': E_exact,

            'E_vqe': E_vqe,

            'error': abs(E_exact - E_vqe),

            'fidelity': F,

            'tracking_overlap': tracking_overlap,

            'psi_vqe': psi_vqe
        }

        case_results.append(data)

        all_results.append(data)

        # ----------------------------------------------------
        # Print
        # ----------------------------------------------------

        print("\nFINAL SELECTED STATE")

        print(f"Exact energy     : {E_exact:.12f}")

        print(f"VQE energy       : {E_vqe:.12f}")

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(f"Fidelity         : {F:.12f}")

        print(
            f"Tracking overlap : "
            f"{tracking_overlap:.12f}"
        )

    # ========================================================
    # Case summary
    # ========================================================

    print("\n")

    print("="*110)

    print(f"SUMMARY : {label}")

    print("="*110)

    print(

        f"{'lambda':<12} "
        f"{'Exact E':<18} "
        f"{'VQE E':<18} "
        f"{'Error':<15} "
        f"{'Fidelity':<15} "
        f"{'TrackOverlap':<15}"
    )

    print("="*110)

    for r in case_results:

        print(

            f"{r['lambda']:<12.4f} "
            f"{r['E_exact']:<18.10f} "
            f"{r['E_vqe']:<18.10f} "
            f"{r['error']:<15.4e} "
            f"{r['fidelity']:<15.10f} "
            f"{r['tracking_overlap']:<15.10f}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161775866
# Energy error     : 4.770717e-08
# Fidelity         : 0.999999953066
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641800660
# Energy error     : 3.733128e-07
# Fidelity         : 0.999999931590
# Tracking overlap : 0.999848985667
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030499336064
# Energy error     : 2.627013e-08
# Fidelity         : 0.999999996677
# Tracking overlap : 0.999875897862
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041824400377
# Energy error     : 7.811640e-08
# Fidelity         : 0.999999987179
# Tracking overlap : 0.999895824393
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052684734186
# Energy error     : 1.904246e-07
# Fidelity         : 0.999999969679
# Tracking overlap : 0.999910858268
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063134068110
# Energy error     : 2.793400e-07
# Fidelity         : 0.999999967362
# Tracking overlap : 0.999922465634
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073216049745
# Energy error     : 3.959740e-07
# Fidelity         : 0.999999954152
# Tracking overlap : 0.999931947315
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082966612961
# Energy error     : 4.611462e-07
# Fidelity         : 0.999999935175
# Tracking overlap : 0.999939456954
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092416022736
# Energy error     : 5.146287e-07
# Fidelity         : 0.999999931558
# Tracking overlap : 0.999945816059
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101590063180
# Energy error     : 6.344367e-07
# Fidelity         : 0.999999902039
# Tracking overlap : 0.999951205011
#
#
# ==============================================================================================================
# SUMMARY : Symmetric
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       1.0061617282       1.0061617759       4.7707e-08      0.9999999531    1.0000000000
# 0.3111       1.0186414273       1.0186418007       3.7331e-07      0.9999999316    0.9998489857
# 0.5222       1.0304993098       1.0304993361       2.6270e-08      0.9999999967    0.9998758979
# 0.7333       1.0418243223       1.0418244004       7.8116e-08      0.9999999872    0.9998958244
# 0.9444       1.0526845438       1.0526847342       1.9042e-07      0.9999999697    0.9999108583
# 1.1556       1.0631337888       1.0631340681       2.7934e-07      0.9999999674    0.9999224656
# 1.3667       1.0732156538       1.0732160497       3.9597e-07      0.9999999542    0.9999319473
# 1.5778       1.0829661518       1.0829666130       4.6115e-07      0.9999999352    0.9999394570
# 1.7889       1.0924155081       1.0924160227       5.1463e-07      0.9999999316    0.9999458161
# 2.0000       1.1015894287       1.1015900632       6.3444e-07      0.9999999020    0.9999512050
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 1e-05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902169977
# VQE energy       : -16.943707665340
# Energy error     : 1.945046e-04
# Fidelity         : 0.999982974075
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -8.892068720847
# VQE energy       : -8.891980150732
# Energy error     : 8.857011e-05
# Fidelity         : 0.999982743297
# Tracking overlap : 0.876075335988
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.379113856397
# VQE energy       : -4.379109869939
# Energy error     : 3.986458e-06
# Fidelity         : 0.997200889247
# Tracking overlap : 0.048984148303
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.749793396636
# VQE energy       : -2.749793075145
# Energy error     : 3.214914e-07
# Fidelity         : 0.999945413107
# Tracking overlap : 0.000000000013
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.874700666195
# VQE energy       : -1.874700531515
# Energy error     : 1.346798e-07
# Fidelity         : 0.999998425589
# Tracking overlap : 0.821472731947
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.348821613293
# VQE energy       : -1.348821400907
# Energy error     : 2.123858e-07
# Fidelity         : 0.999999749293
# Tracking overlap : 0.894885735119
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.010439481239
# VQE energy       : -1.010439132155
# Energy error     : 3.490845e-07
# Fidelity         : 0.999999932309
# Tracking overlap : 0.936954157961
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.779139779365
# VQE energy       : -0.779121824825
# Energy error     : 1.795454e-05
# Fidelity         : 0.999988599897
# Tracking overlap : 0.962931108726
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723370121
# VQE energy       : -0.611722826341
# Energy error     : 5.437804e-07
# Fidelity         : 0.999999755442
# Tracking overlap : 0.977732022689
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295385847
# VQE energy       : -0.484295167932
# Energy error     : 2.179145e-07
# Fidelity         : 0.999999970333
# Tracking overlap : 0.986378264560
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -16.9439021700     -16.9437076653     1.9450e-04      0.9999829741    1.0000000000
# 0.3111       -8.8920687208      -8.8919801507      8.8570e-05      0.9999827433    0.8760753360
# 0.5222       -4.3791138564      -4.3791098699      3.9865e-06      0.9972008892    0.0489841483
# 0.7333       -2.7497933966      -2.7497930751      3.2149e-07      0.9999454131    0.0000000000
# 0.9444       -1.8747006662      -1.8747005315      1.3468e-07      0.9999984256    0.8214727319
# 1.1556       -1.3488216133      -1.3488214009      2.1239e-07      0.9999997493    0.8948857351
# 1.3667       -1.0104394812      -1.0104391322      3.4908e-07      0.9999999323    0.9369541580
# 1.5778       -0.7791397794      -0.7791218248      1.7955e-05      0.9999885999    0.9629311087
# 1.7889       -0.6117233701      -0.6117228263      5.4378e-07      0.9999997554    0.9777320227
# 2.0000       -0.4842953858      -0.4842951679      2.1791e-07      0.9999999703    0.9863782646
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.064362901005
# Energy error     : 3.304509e-04
# Fidelity         : 0.999937786597
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.078078864049
# Energy error     : 2.371048e-03
# Fidelity         : 0.999490971076
# Tracking overlap : 0.804385874064
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.699812964571
# Energy error     : 1.382008e-03
# Fidelity         : 0.999734275812
# Tracking overlap : 0.069956485879
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.011507851371
# Energy error     : 2.350025e-05
# Fidelity         : 0.999996422267
# Tracking overlap : 0.654702493954
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.083454065503
# Energy error     : 1.116580e-04
# Fidelity         : 0.999973866380
# Tracking overlap : 0.831656023507
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503594499321
# Energy error     : 8.933734e-04
# Fidelity         : 0.999854931442
# Tracking overlap : 0.896435867971
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118629139890
# Energy error     : 4.705905e-04
# Fidelity         : 0.999870367878
# Tracking overlap : 0.917208611585
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.853257198501
# Energy error     : 7.485550e-05
# Fidelity         : 0.999979786934
# Tracking overlap : 0.937550836435
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663533603708
# Energy error     : 2.653783e-05
# Fidelity         : 0.999996785395
# Tracking overlap : 0.959218746417
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.522120469675
# Energy error     : 1.929462e-05
# Fidelity         : 0.999997188403
# Tracking overlap : 0.975634696225
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB optimised
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -17.0646933519     -17.0643629010     3.3045e-04      0.9999377866    1.0000000000
# 0.3111       -9.0804499123      -9.0780788640      2.3710e-03      0.9994909711    0.8043858741
# 0.5222       -4.7011949726      -4.6998129646      1.3820e-03      0.9997342758    0.0699564859
# 0.7333       -3.0115313516      -3.0115078514      2.3500e-05      0.9999964223    0.6547024940
# 0.9444       -2.0835657235      -2.0834540655      1.1166e-04      0.9999738664    0.8316560235
# 1.1556       -1.5044878727      -1.5035944993      8.9337e-04      0.9998549314    0.8964358680
# 1.3667       -1.1190997304      -1.1186291399      4.7059e-04      0.9998703679    0.9172086116
# 1.5778       -0.8533320540      -0.8532571985      7.4856e-05      0.9999797869    0.9375508364
# 1.7889       -0.6635601415      -0.6635336037      2.6538e-05      0.9999967854    0.9592187464
# 2.0000       -0.5221397643      -0.5221204697      1.9295e-05      0.9999971884    0.9756346962
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.776671233542
# Energy error     : 6.572117e-04
# Fidelity         : 0.999938767594
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.835758781433
# Energy error     : 6.823614e-04
# Fidelity         : 0.999902390313
# Tracking overlap : 0.849341906012
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.729727970504
# Energy error     : 9.883943e-04
# Fidelity         : 0.999877550690
# Tracking overlap : 0.166455427215
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.538013433425
# Energy error     : 1.353973e-04
# Fidelity         : 0.999987307754
# Tracking overlap : 0.634806412425
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.276011154486
# Energy error     : 2.638443e-06
# Fidelity         : 0.999999706449
# Tracking overlap : 0.822686596704
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.447913061329
# Energy error     : 7.673241e-04
# Fidelity         : 0.999908504956
# Tracking overlap : 0.904923841233
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.860546552898
# Energy error     : 2.857123e-04
# Fidelity         : 0.999968769705
# Tracking overlap : 0.941793007743
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.419790987461
# Energy error     : 2.995418e-04
# Fidelity         : 0.999967302822
# Tracking overlap : 0.962076506948
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.076275598939
# Energy error     : 3.696868e-05
# Fidelity         : 0.999997416329
# Tracking overlap : 0.973943113051
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.800043387107
# Energy error     : 2.987911e-05
# Fidelity         : 0.999998017806
# Tracking overlap : 0.981162634473
#
#
# ==============================================================================================================
# SUMMARY : Strong SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -20.7773284453     -20.7766712335     6.5721e-04      0.9999387676    1.0000000000
# 0.3111       -12.8364411428     -12.8357587814     6.8236e-04      0.9999023903    0.8493419060
# 0.5222       -7.7307163648      -7.7297279705      9.8839e-04      0.9998775507    0.1664554272
# 0.7333       -5.5381488307      -5.5380134334      1.3540e-04      0.9999873078    0.6348064124
# 0.9444       -4.2760137929      -4.2760111545      2.6384e-06      0.9999997064    0.8226865967
# 1.1556       -3.4486803854      -3.4479130613      7.6732e-04      0.9999085050    0.9049238412
# 1.3667       -2.8608322652      -2.8605465529      2.8571e-04      0.9999687697    0.9417930077
# 1.5778       -2.4200905293      -2.4197909875      2.9954e-04      0.9999673028    0.9620765069
# 1.7889       -2.0763125676      -2.0762755989      3.6969e-05      0.9999974163    0.9739431131
# 2.0000       -1.8000732662      -1.8000433871      2.9879e-05      0.9999980178    0.9811626345

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HEA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119699
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98269265
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394376
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98503136
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98601005
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98686450
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762600
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98831292
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893568
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98951294
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.13498607e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063644
# T = 10    Fidelity = 0.00011499
# T = 20    Fidelity = 0.00399991
# T = 30    Fidelity = 0.05561190
# T = 40    Fidelity = 0.12251588
# T = 50    Fidelity = 0.21143107
# T = 75    Fidelity = 0.58081778
# T = 100   Fidelity = 0.76544635
# T = 125   Fidelity = 0.73557630
# T = 150   Fidelity = 0.86960881
# T = 175   Fidelity = 0.91396907
# T = 200   Fidelity = 0.87535428
# T = 225   Fidelity = 0.95253920
# T = 250   Fidelity = 0.98642764
#
# Minimum T for Fidelity >= 0.97 : 250
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.22564919e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00018032
# T = 10    Fidelity = 0.04093631
# T = 20    Fidelity = 0.42075979
# T = 30    Fidelity = 0.49050430
# T = 40    Fidelity = 0.64114165
# T = 50    Fidelity = 0.64442134
# T = 75    Fidelity = 0.88102080
# T = 100   Fidelity = 0.90190502
# T = 125   Fidelity = 0.87192246
# T = 150   Fidelity = 0.88638319
# T = 175   Fidelity = 0.92118978
# T = 200   Fidelity = 0.94267766
# T = 225   Fidelity = 0.95689065
# T = 250   Fidelity = 0.95100207
# T = 275   Fidelity = 0.96233370
# T = 300   Fidelity = 0.94450380
# T = 400   Fidelity = 0.98187907
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.14483174e-04
# T = 1     Fidelity = 0.00001183
# T = 2     Fidelity = 0.00016906
# T = 5     Fidelity = 0.01433719
# T = 10    Fidelity = 0.17120072
# T = 20    Fidelity = 0.44272382
# T = 30    Fidelity = 0.34004617
# T = 40    Fidelity = 0.54716826
# T = 50    Fidelity = 0.43879645
# T = 75    Fidelity = 0.49359582
# T = 100   Fidelity = 0.50315999
# T = 125   Fidelity = 0.50307877
# T = 150   Fidelity = 0.50221367
# T = 175   Fidelity = 0.50142293
# T = 200   Fidelity = 0.49698460
# T = 225   Fidelity = 0.50875957
# T = 250   Fidelity = 0.50137157
# T = 275   Fidelity = 0.48749056
# T = 300   Fidelity = 0.48757828
# T = 400   Fidelity = 0.49867246
# T = 500   Fidelity = 0.30952317
# T = 600   Fidelity = 0.51099490
# T = 700   Fidelity = 0.39123756
# T = 800   Fidelity = 0.53871775
# T = 900   Fidelity = 0.53605990
# T = 1000  Fidelity = 0.70836436
# T = 1010  Fidelity = 0.40403773
# T = 1020  Fidelity = 0.40789489
# T = 1030  Fidelity = 0.47797413
# T = 1040  Fidelity = 0.50607655
# T = 1050  Fidelity = 0.47580483
# T = 1060  Fidelity = 0.37539413
# T = 1070  Fidelity = 0.57018984
# T = 1080  Fidelity = 0.27358706
# T = 1090  Fidelity = 0.28162094
# T = 1100  Fidelity = 0.62086769
# T = 1200  Fidelity = 0.29949031
# T = 1300  Fidelity = 0.56642707
# T = 1400  Fidelity = 0.55233053
# T = 1500  Fidelity = 0.37841207
# T = 2000  Fidelity = 0.31512340
# T = 2100  Fidelity = 0.22277987
# T = 2110  Fidelity = 0.58886404
# T = 2120  Fidelity = 0.50691675
# T = 2130  Fidelity = 0.53891326
# T = 2140  Fidelity = 0.35492465
# T = 2150  Fidelity = 0.48216872
# T = 2160  Fidelity = 0.42018661
# T = 2170  Fidelity = 0.42326240
# T = 2180  Fidelity = 0.57070488
# T = 2190  Fidelity = 0.21668841
# T = 2200  Fidelity = 0.51740718
# T = 2300  Fidelity = 0.57567184
# T = 2400  Fidelity = 0.53676141
# T = 2500  Fidelity = 0.50396909
# T = 2600  Fidelity = 0.51047758
# T = 2700  Fidelity = 0.63552416
# T = 2800  Fidelity = 0.66479480
# T = 2900  Fidelity = 0.52317497
# T = 3000  Fidelity = 0.49548961
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.49548961
# P1     = 0.00064982
# P0+P1  = 0.49613943
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.21982966e-04
# T = 1     Fidelity = 0.00307240
# T = 2     Fidelity = 0.01239275
# T = 5     Fidelity = 0.08439858
# T = 10    Fidelity = 0.22347762
# T = 20    Fidelity = 0.31776630
# T = 30    Fidelity = 0.38306950
# T = 40    Fidelity = 0.54977337
# T = 50    Fidelity = 0.58075834
# T = 75    Fidelity = 0.50038525
# T = 100   Fidelity = 0.52178319
# T = 125   Fidelity = 0.52337609
# T = 150   Fidelity = 0.52320503
# T = 175   Fidelity = 0.52001012
# T = 200   Fidelity = 0.53035000
# T = 225   Fidelity = 0.52293680
# T = 250   Fidelity = 0.51831844
# T = 275   Fidelity = 0.52661987
# T = 300   Fidelity = 0.49518227
# T = 400   Fidelity = 0.51004191
# T = 500   Fidelity = 0.55445416
# T = 600   Fidelity = 0.50914134
# T = 700   Fidelity = 0.44381253
# T = 800   Fidelity = 0.45443916
# T = 900   Fidelity = 0.53558298
# T = 1000  Fidelity = 0.78107647
# T = 1010  Fidelity = 0.44826856
# T = 1020  Fidelity = 0.12727059
# T = 1030  Fidelity = 0.56288436
# T = 1040  Fidelity = 0.79509469
# T = 1050  Fidelity = 0.59786471
# T = 1060  Fidelity = 0.48945643
# T = 1070  Fidelity = 0.50197157
# T = 1080  Fidelity = 0.42478233
# T = 1090  Fidelity = 0.25695042
# T = 1100  Fidelity = 0.74487248
# T = 1200  Fidelity = 0.58973327
# T = 1300  Fidelity = 0.45970310
# T = 1400  Fidelity = 0.52938360
# T = 1500  Fidelity = 0.54443677
# T = 2000  Fidelity = 0.46786742
# T = 2100  Fidelity = 0.53038460
# T = 2110  Fidelity = 0.56807530
# T = 2120  Fidelity = 0.48124616
# T = 2130  Fidelity = 0.40456967
# T = 2140  Fidelity = 0.57398048
# T = 2150  Fidelity = 0.78517430
# T = 2160  Fidelity = 0.45190148
# T = 2170  Fidelity = 0.25308725
# T = 2180  Fidelity = 0.50752554
# T = 2190  Fidelity = 0.70346887
# T = 2200  Fidelity = 0.63130763
# T = 2300  Fidelity = 0.83237372
# T = 2400  Fidelity = 0.55105211
# T = 2500  Fidelity = 0.52131945
# T = 2600  Fidelity = 0.57275802
# T = 2700  Fidelity = 0.46746817
# T = 2800  Fidelity = 0.55979741
# T = 2900  Fidelity = 0.32446482
# T = 3000  Fidelity = 0.46074793
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.46074793
# P1     = 0.00024069
# P0+P1  = 0.46098861
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.33063144e-03
# T = 1     Fidelity = 0.02405157
# T = 2     Fidelity = 0.06515407
# T = 5     Fidelity = 0.21904833
# T = 10    Fidelity = 0.40684762
# T = 20    Fidelity = 0.52936417
# T = 30    Fidelity = 0.49787494
# T = 40    Fidelity = 0.50388048
# T = 50    Fidelity = 0.54929218
# T = 75    Fidelity = 0.60866699
# T = 100   Fidelity = 0.60708055
# T = 125   Fidelity = 0.61208998
# T = 150   Fidelity = 0.61606814
# T = 175   Fidelity = 0.61942603
# T = 200   Fidelity = 0.62646425
# T = 225   Fidelity = 0.62931111
# T = 250   Fidelity = 0.63307971
# T = 275   Fidelity = 0.62996576
# T = 300   Fidelity = 0.64620923
# T = 400   Fidelity = 0.59412808
# T = 500   Fidelity = 0.65373664
# T = 600   Fidelity = 0.67758146
# T = 700   Fidelity = 0.59513114
# T = 800   Fidelity = 0.71411203
# T = 900   Fidelity = 0.60950960
# T = 1000  Fidelity = 0.48797172
# T = 1010  Fidelity = 0.76100736
# T = 1020  Fidelity = 0.85265234
# T = 1030  Fidelity = 0.75202378
# T = 1040  Fidelity = 0.53080485
# T = 1050  Fidelity = 0.47569183
# T = 1060  Fidelity = 0.65096770
# T = 1070  Fidelity = 0.77849464
# T = 1080  Fidelity = 0.82289310
# T = 1090  Fidelity = 0.55785875
# T = 1100  Fidelity = 0.40191342
# T = 1200  Fidelity = 0.46098279
# T = 1300  Fidelity = 0.54240431
# T = 1400  Fidelity = 0.77144620
# T = 1500  Fidelity = 0.68257794
# T = 2000  Fidelity = 0.77617708
# T = 2100  Fidelity = 0.82188802
# T = 2110  Fidelity = 0.81252008
# T = 2120  Fidelity = 0.55445528
# T = 2130  Fidelity = 0.65792319
# T = 2140  Fidelity = 0.71477148
# T = 2150  Fidelity = 0.83412398
# T = 2160  Fidelity = 0.84963191
# T = 2170  Fidelity = 0.78544720
# T = 2180  Fidelity = 0.53547562
# T = 2190  Fidelity = 0.57231388
# T = 2200  Fidelity = 0.70209496
# T = 2300  Fidelity = 0.77091256
# T = 2400  Fidelity = 0.75746402
# T = 2500  Fidelity = 0.83047602
# T = 2600  Fidelity = 0.73447955
# T = 2700  Fidelity = 0.78131892
# T = 2800  Fidelity = 0.76629685
# T = 2900  Fidelity = 0.70211507
# T = 3000  Fidelity = 0.75464150
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.75464150
# P1     = 0.00005595
# P0+P1  = 0.75469745
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50115281e-02
# T = 1     Fidelity = 0.08269028
# T = 2     Fidelity = 0.17487854
# T = 5     Fidelity = 0.39234147
# T = 10    Fidelity = 0.58593982
# T = 20    Fidelity = 0.71389374
# T = 30    Fidelity = 0.72027330
# T = 40    Fidelity = 0.71303139
# T = 50    Fidelity = 0.71876354
# T = 75    Fidelity = 0.74412855
# T = 100   Fidelity = 0.76245845
# T = 125   Fidelity = 0.77527571
# T = 150   Fidelity = 0.78587252
# T = 175   Fidelity = 0.79500699
# T = 200   Fidelity = 0.80419182
# T = 225   Fidelity = 0.81045973
# T = 250   Fidelity = 0.81599257
# T = 275   Fidelity = 0.82617782
# T = 300   Fidelity = 0.81747436
# T = 400   Fidelity = 0.87422219
# T = 500   Fidelity = 0.87059962
# T = 600   Fidelity = 0.79407332
# T = 700   Fidelity = 0.82785710
# T = 800   Fidelity = 0.84472079
# T = 900   Fidelity = 0.85229243
# T = 1000  Fidelity = 0.87687330
# T = 1010  Fidelity = 0.79393701
# T = 1020  Fidelity = 0.77899434
# T = 1030  Fidelity = 0.86814567
# T = 1040  Fidelity = 0.95158947
# T = 1050  Fidelity = 0.97309100
#
# Minimum T for Fidelity >= 0.97 : 1050
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77198754e-02
# T = 1     Fidelity = 0.17553278
# T = 2     Fidelity = 0.31613475
# T = 5     Fidelity = 0.55526977
# T = 10    Fidelity = 0.72492567
# T = 20    Fidelity = 0.82948718
# T = 30    Fidelity = 0.85312743
# T = 40    Fidelity = 0.85899113
# T = 50    Fidelity = 0.86468089
# T = 75    Fidelity = 0.88210097
# T = 100   Fidelity = 0.89840050
# T = 125   Fidelity = 0.90980400
# T = 150   Fidelity = 0.91811538
# T = 175   Fidelity = 0.92575336
# T = 200   Fidelity = 0.93483035
# T = 225   Fidelity = 0.93591099
# T = 250   Fidelity = 0.93618982
# T = 275   Fidelity = 0.94546186
# T = 300   Fidelity = 0.93550000
# T = 400   Fidelity = 0.94951984
# T = 500   Fidelity = 0.95253330
# T = 600   Fidelity = 0.96024561
# T = 700   Fidelity = 0.91552495
# T = 800   Fidelity = 0.92796652
# T = 900   Fidelity = 0.94694788
# T = 1000  Fidelity = 0.93970840
# T = 1010  Fidelity = 0.95195498
# T = 1020  Fidelity = 0.95694755
# T = 1030  Fidelity = 0.97884441
#
# Minimum T for Fidelity >= 0.97 : 1030
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20186803e-01
# T = 1     Fidelity = 0.28020489
# T = 2     Fidelity = 0.45281422
# T = 5     Fidelity = 0.68158963
# T = 10    Fidelity = 0.81938909
# T = 20    Fidelity = 0.89675843
# T = 30    Fidelity = 0.91815234
# T = 40    Fidelity = 0.92947120
# T = 50    Fidelity = 0.93812046
# T = 75    Fidelity = 0.95178783
# T = 100   Fidelity = 0.96204418
# T = 125   Fidelity = 0.96844272
# T = 150   Fidelity = 0.97430293
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405410e-01
# T = 1     Fidelity = 0.37879267
# T = 2     Fidelity = 0.56657162
# T = 5     Fidelity = 0.77017291
# T = 10    Fidelity = 0.87914268
# T = 20    Fidelity = 0.93532672
# T = 30    Fidelity = 0.95282130
# T = 40    Fidelity = 0.96403220
# T = 50    Fidelity = 0.96971226
# T = 75    Fidelity = 0.97962236
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843285e-01
# T = 1     Fidelity = 0.46388424
# T = 2     Fidelity = 0.65547997
# T = 5     Fidelity = 0.83095105
# T = 10    Fidelity = 0.91704700
# T = 20    Fidelity = 0.95852069
# T = 30    Fidelity = 0.97284958
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00037933
# T = 10    Fidelity = 0.00053361
# T = 20    Fidelity = 0.01176859
# T = 30    Fidelity = 0.08093410
# T = 40    Fidelity = 0.18873661
# T = 50    Fidelity = 0.42945062
# T = 75    Fidelity = 0.56692059
# T = 100   Fidelity = 0.72822735
# T = 125   Fidelity = 0.80787426
# T = 150   Fidelity = 0.83732032
# T = 175   Fidelity = 0.90593331
# T = 200   Fidelity = 0.91946043
# T = 225   Fidelity = 0.96691678
# T = 250   Fidelity = 0.89119461
# T = 275   Fidelity = 0.96874632
# T = 300   Fidelity = 0.85615569
# T = 400   Fidelity = 0.98079828
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000013
# T = 5     Fidelity = 0.00045369
# T = 10    Fidelity = 0.06816482
# T = 20    Fidelity = 0.22524826
# T = 30    Fidelity = 0.62308890
# T = 40    Fidelity = 0.37166005
# T = 50    Fidelity = 0.78916705
# T = 75    Fidelity = 0.74776293
# T = 100   Fidelity = 0.79708222
# T = 125   Fidelity = 0.87705366
# T = 150   Fidelity = 0.88263467
# T = 175   Fidelity = 0.90177708
# T = 200   Fidelity = 0.92579672
# T = 225   Fidelity = 0.93748626
# T = 250   Fidelity = 0.94614957
# T = 275   Fidelity = 0.95140440
# T = 300   Fidelity = 0.94751437
# T = 400   Fidelity = 0.97149832
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00003610
# T = 2     Fidelity = 0.00032161
# T = 5     Fidelity = 0.02068693
# T = 10    Fidelity = 0.22176342
# T = 20    Fidelity = 0.59037753
# T = 30    Fidelity = 0.66005721
# T = 40    Fidelity = 0.79031683
# T = 50    Fidelity = 0.82240920
# T = 75    Fidelity = 0.92683422
# T = 100   Fidelity = 0.96721755
# T = 125   Fidelity = 0.98411987
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00115299
# T = 2     Fidelity = 0.00476057
# T = 5     Fidelity = 0.06199335
# T = 10    Fidelity = 0.28426039
# T = 20    Fidelity = 0.68073768
# T = 30    Fidelity = 0.73432214
# T = 40    Fidelity = 0.82192993
# T = 50    Fidelity = 0.88767228
# T = 75    Fidelity = 0.95505871
# T = 100   Fidelity = 0.98256641
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00851740
# T = 2     Fidelity = 0.02344541
# T = 5     Fidelity = 0.12519001
# T = 10    Fidelity = 0.34194946
# T = 20    Fidelity = 0.67099628
# T = 30    Fidelity = 0.79868736
# T = 40    Fidelity = 0.85961564
# T = 50    Fidelity = 0.90967775
# T = 75    Fidelity = 0.97045893
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03408087
# T = 2     Fidelity = 0.07301430
# T = 5     Fidelity = 0.22147585
# T = 10    Fidelity = 0.42643175
# T = 20    Fidelity = 0.67746491
# T = 30    Fidelity = 0.80059986
# T = 40    Fidelity = 0.87043344
# T = 50    Fidelity = 0.91782676
# T = 75    Fidelity = 0.97855596
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09523685
# T = 2     Fidelity = 0.17399067
# T = 5     Fidelity = 0.36587142
# T = 10    Fidelity = 0.55647863
# T = 20    Fidelity = 0.74310500
# T = 30    Fidelity = 0.83254608
# T = 40    Fidelity = 0.88438847
# T = 50    Fidelity = 0.91839060
# T = 75    Fidelity = 0.96571483
# T = 100   Fidelity = 0.98445886
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19082507
# T = 2     Fidelity = 0.31258418
# T = 5     Fidelity = 0.52542734
# T = 10    Fidelity = 0.69250027
# T = 20    Fidelity = 0.82862209
# T = 30    Fidelity = 0.88818410
# T = 40    Fidelity = 0.92234718
# T = 50    Fidelity = 0.94374762
# T = 75    Fidelity = 0.96985733
# T = 100   Fidelity = 0.98229509
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30070002
# T = 2     Fidelity = 0.45436665
# T = 5     Fidelity = 0.66189348
# T = 10    Fidelity = 0.79878731
# T = 20    Fidelity = 0.89490631
# T = 30    Fidelity = 0.93368288
# T = 40    Fidelity = 0.95531319
# T = 50    Fidelity = 0.96735499
# T = 75    Fidelity = 0.98310999
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40223375
# T = 2     Fidelity = 0.57279133
# T = 5     Fidelity = 0.76043035
# T = 10    Fidelity = 0.86916472
# T = 20    Fidelity = 0.93657710
# T = 30    Fidelity = 0.96228455
# T = 40    Fidelity = 0.97437272
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00083703
# T = 10    Fidelity = 0.06382867
# T = 20    Fidelity = 0.45550009
# T = 30    Fidelity = 0.88093075
# T = 40    Fidelity = 0.96743451
# T = 50    Fidelity = 0.99171046
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000226
# T = 5     Fidelity = 0.02498589
# T = 10    Fidelity = 0.90029338
# T = 20    Fidelity = 0.96750177
# T = 30    Fidelity = 0.99638207
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00005270
# T = 2     Fidelity = 0.00078158
# T = 5     Fidelity = 0.18861696
# T = 10    Fidelity = 0.98836900
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00123942
# T = 2     Fidelity = 0.00813229
# T = 5     Fidelity = 0.34549265
# T = 10    Fidelity = 0.98662445
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00700119
# T = 2     Fidelity = 0.02898228
# T = 5     Fidelity = 0.47056764
# T = 10    Fidelity = 0.98168801
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02075058
# T = 2     Fidelity = 0.06373810
# T = 5     Fidelity = 0.56295410
# T = 10    Fidelity = 0.97577187
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04382958
# T = 2     Fidelity = 0.11045904
# T = 5     Fidelity = 0.63887277
# T = 10    Fidelity = 0.97250370
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07526809
# T = 2     Fidelity = 0.16326471
# T = 5     Fidelity = 0.69531709
# T = 10    Fidelity = 0.96908182
# T = 20    Fidelity = 0.99301230
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11361369
# T = 2     Fidelity = 0.22072664
# T = 5     Fidelity = 0.74281715
# T = 10    Fidelity = 0.96777321
# T = 20    Fidelity = 0.99356317
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15671216
# T = 2     Fidelity = 0.27885167
# T = 5     Fidelity = 0.78129170
# T = 10    Fidelity = 0.96731620
# T = 20    Fidelity = 0.99389976
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     1         0.9811969912      1.00972087e+00    None        None        None
# Symmetric      0.311     1         0.9826926492      1.02934439e+00    None        None        None
# Symmetric      0.522     1         0.9839437625      1.04790824e+00    None        None        None
# Symmetric      0.733     1         0.9850313640      1.06556366e+00    None        None        None
# Symmetric      0.944     1         0.9860100468      1.08242773e+00    None        None        None
# Symmetric      1.156     1         0.9868645004      1.09859358e+00    None        None        None
# Symmetric      1.367     1         0.9876260022      1.11413694e+00    None        None        None
# Symmetric      1.578     1         0.9883129199      1.12912045e+00    None        None        None
# Symmetric      1.789     1         0.9889356752      1.14359670e+00    None        None        None
# Symmetric      2.000     1         0.9895129386      1.15761039e+00    None        None        None
# Weak SSB       0.100     250       0.9864276399      3.13498607e-04    None        None        None
# Weak SSB       0.311     400       0.9818790710      1.22564919e-04    None        None        None
# Weak SSB       0.522     None      0.7083643648      1.14483174e-04    0.49549     0.00065     0.496139
# Weak SSB       0.733     None      0.8323737210      2.21982966e-04    0.460748    0.000241    0.460989
# Weak SSB       0.944     None      0.8526523353      4.33063144e-03    0.754641    5.6e-05     0.754697
# Weak SSB       1.156     1050      0.9730910026      2.50115281e-02    None        None        None
# Weak SSB       1.367     1030      0.9788444083      6.77198754e-02    None        None        None
# Weak SSB       1.578     150       0.9743029276      1.20186803e-01    None        None        None
# Weak SSB       1.789     75        0.9796223572      1.71405410e-01    None        None        None
# Weak SSB       2.000     30        0.9728495820      2.18843285e-01    None        None        None
# Weak SSB optimised0.100     400       0.9807982754      2.42819099e-01    None        None        None
# Weak SSB optimised0.311     400       0.9714983181      2.61171322e-01    None        None        None
# Weak SSB optimised0.522     125       0.9841198710      2.64873214e-01    None        None        None
# Weak SSB optimised0.733     100       0.9825664066      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     75        0.9704589289      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     75        0.9785559635      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     100       0.9844588649      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     100       0.9822950877      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     75        0.9831099907      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     40        0.9743727193      2.55131735e-01    None        None        None
# Strong SSB     0.100     50        0.9917104631      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9963820675      7.22062439e-01    None        None        None
# Strong SSB     0.522     10        0.9883689952      7.78318602e-01    None        None        None
# Strong SSB     0.733     10        0.9866244530      8.15979742e-01    None        None        None
# Strong SSB     0.944     10        0.9816880119      8.44059983e-01    None        None        None
# Strong SSB     1.156     10        0.9757718694      8.66317759e-01    None        None        None
# Strong SSB     1.367     10        0.9725037044      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9930123029      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9935631672      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9938997560      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimized')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []

for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)

    elif case == "Strong SSB":

        M_strong.append(M)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 46
#      36 match = next(
#      37     x for x in all_results
#      38     if (
#    (...)     41     )
#      42 )
#      44 psi_vqe = match['psi_vqe']
# ---> 46 psi_final = adiabatic_circuit_evolution(
#      47
#      48     initial_state=psi_vqe,
#      49
#      50     nq=nq_site,
#      51
#      52     T=Tmin,
#      53
#      54     mu=mu,
#      55
#      56     mI2=mI2,
#      57
#      58     m0_sq=1.0,
#      59
#      60     lam=lam,
#      61
#      62     f=f,
#      63
#      64     nsteps=100
#      65 )
#      67 M = np.real(
#      68
#      69     np.vdot(
#    (...)     74     )
#      75 )
#      77 if case == "Symmetric":
#
# Cell In[19], line 28, in adiabatic_circuit_evolution(initial_state, nq, T, mu, mI2, m0_sq, lam, f, nsteps)
#       5 def adiabatic_circuit_evolution(
#       6
#       7     initial_state,
#    (...)     23     nsteps=100
#      24 ):
#      26     nqubits = 2 * nq
# ---> 28     dt = T / nsteps
#      30     psi = Statevector(initial_state)
#      32     # --------------------------------------------------------
#      33     # Time evolution
#      34     # --------------------------------------------------------
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %%
# ============================================================
# λc from order parameter
# ============================================================

dM_sym = np.gradient(

    M_sym,

    lambda_list
)

dM_weak = np.gradient(

    M_weak_opt,

    lambda_list
)

dM_strong = np.gradient(

    M_strong,

    lambda_list
)

lamc_M_sym = lambda_list[

    np.argmax(np.abs(dM_sym))
]

lamc_M_weak = lambda_list[

    np.argmax(np.abs(dM_weak))
]

lamc_M_strong = lambda_list[

    np.argmax(np.abs(dM_strong))
]

print("\nOrder parameter estimator")
print("-"*50)

print(
    f"Symmetric        λc = {lamc_M_sym:.4f}"
)

print(
    f"Weak SSB opt     λc = {lamc_M_weak:.4f}"
)

print(
    f"Strong SSB       λc = {lamc_M_strong:.4f}"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 12
#       1 # ============================================================
#       2 # λc from order parameter
#       3 # ============================================================
#       5 dM_sym = np.gradient(
#       6
#       7     M_sym,
#       8
#       9     lambda_list
#      10 )
# ---> 12 dM_weak = np.gradient(
#      13
#      14     M_weak_opt,
#      15
#      16     lambda_list
#      17 )
#      19 dM_strong = np.gradient(
#      20
#      21     M_strong,
#      22
#      23     lambda_list
#      24 )
#      26 lamc_M_sym = lambda_list[
#      27
#      28     np.argmax(np.abs(dM_sym))
#      29 ]
#
# File ~/Documents/CERN/Quantum_computer/venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:1221, in gradient(f, axis, edge_order, *varargs)
#    1219     raise ValueError("distances must be either scalars or 1d")
#    1220 if len(distances) != f.shape[axes[i]]:
# -> 1221     raise ValueError("when 1d, distances must match "
#    1222                      "the length of the corresponding dimension")
#    1223 if np.issubdtype(distances.dtype, np.integer):
#    1224     # Convert numpy integer types to float64 to avoid modular
#    1225     # arithmetic in np.diff(distances).
#    1226     distances = distances.astype(np.float64)
#
# ValueError: when 1d, distances must match the length of the corresponding dimension

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_list,

    M_sym,

    'o-',

    label='Symmetric'
)

plt.plot(

    lambda_list,

    M_weak_opt,

    's-',

    label='Weak SSB optimized'
)

plt.plot(

    lambda_list,

    M_strong,

    '^-',

    label='Strong SSB'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_list,
    dM_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_list,
    dM_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_list,
    dM_strong,
    '^-',
    label='Strong SSB'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Starting of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96521517
# T = 2     Fidelity = 0.99334536
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.03626623e+00
# T = 1     Fidelity = 0.96808099
# T = 2     Fidelity = 0.99423144
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05846299e+00
# T = 1     Fidelity = 0.97048678
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07916278e+00
# T = 1     Fidelity = 0.97257903
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.09862393e+00
# T = 1     Fidelity = 0.97446032
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.11703633e+00
# T = 1     Fidelity = 0.97610164
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.13454489e+00
# T = 1     Fidelity = 0.97756234
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.15126343e+00
# T = 1     Fidelity = 0.97887837
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.16728342e+00
# T = 1     Fidelity = 0.98006924
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98117161
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 4.00578748e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000116
# T = 10    Fidelity = 0.00114123
# T = 20    Fidelity = 0.00650888
# T = 30    Fidelity = 0.02771857
# T = 40    Fidelity = 0.11876476
# T = 50    Fidelity = 0.09123241
# T = 75    Fidelity = 0.30343571
# T = 100   Fidelity = 0.53488632
# T = 125   Fidelity = 0.55349925
# T = 150   Fidelity = 0.69280391
# T = 175   Fidelity = 0.80346018
# T = 200   Fidelity = 0.78794358
# T = 225   Fidelity = 0.85592747
# T = 250   Fidelity = 0.93717567
# T = 275   Fidelity = 0.73991183
# T = 300   Fidelity = 0.74407787
# T = 400   Fidelity = 0.95735083
# T = 500   Fidelity = 0.95451187
# T = 600   Fidelity = 0.97112117
#
# Minimum T for Fidelity >= 0.97 : 600
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.22897118e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00000706
# T = 10    Fidelity = 0.00112373
# T = 20    Fidelity = 0.19620689
# T = 30    Fidelity = 0.53127430
# T = 40    Fidelity = 0.08254383
# T = 50    Fidelity = 0.71324595
# T = 75    Fidelity = 0.50863342
# T = 100   Fidelity = 0.68279369
# T = 125   Fidelity = 0.91751494
# T = 150   Fidelity = 0.91763945
# T = 175   Fidelity = 0.86927427
# T = 200   Fidelity = 0.91418878
# T = 225   Fidelity = 0.95405695
# T = 250   Fidelity = 0.95380572
# T = 275   Fidelity = 0.94302881
# T = 300   Fidelity = 0.97005250
#
# Minimum T for Fidelity >= 0.97 : 300
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.15176142e-04
# T = 1     Fidelity = 0.00000155
# T = 2     Fidelity = 0.00007284
# T = 5     Fidelity = 0.00176103
# T = 10    Fidelity = 0.03349584
# T = 20    Fidelity = 0.35785661
# T = 30    Fidelity = 0.61458630
# T = 40    Fidelity = 0.36338971
# T = 50    Fidelity = 0.26411453
# T = 75    Fidelity = 0.57948493
# T = 100   Fidelity = 0.44177317
# T = 125   Fidelity = 0.52893993
# T = 150   Fidelity = 0.48171254
# T = 175   Fidelity = 0.50045262
# T = 200   Fidelity = 0.47683474
# T = 225   Fidelity = 0.51557248
# T = 250   Fidelity = 0.48978393
# T = 275   Fidelity = 0.48735005
# T = 300   Fidelity = 0.51264562
# T = 400   Fidelity = 0.50878422
# T = 500   Fidelity = 0.43376362
# T = 600   Fidelity = 0.40036348
# T = 700   Fidelity = 0.27943182
# T = 800   Fidelity = 0.29718759
# T = 900   Fidelity = 0.51003849
# T = 1000  Fidelity = 0.43712142
# T = 1010  Fidelity = 0.28576658
# T = 1020  Fidelity = 0.60561537
# T = 1030  Fidelity = 0.79144360
# T = 1040  Fidelity = 0.62437399
# T = 1050  Fidelity = 0.06896900
# T = 1060  Fidelity = 0.22418993
# T = 1070  Fidelity = 0.62217432
# T = 1080  Fidelity = 0.79983920
# T = 1090  Fidelity = 0.48760304
# T = 1100  Fidelity = 0.20011013
# T = 1200  Fidelity = 0.81605354
# T = 1300  Fidelity = 0.45255651
# T = 1400  Fidelity = 0.22984066
# T = 1500  Fidelity = 0.29289074
# T = 2000  Fidelity = 0.44739488
# T = 2100  Fidelity = 0.18178606
# T = 2110  Fidelity = 0.25634957
# T = 2120  Fidelity = 0.49546378
# T = 2130  Fidelity = 0.55663533
# T = 2140  Fidelity = 0.47136235
# T = 2150  Fidelity = 0.18467459
# T = 2160  Fidelity = 0.38759633
# T = 2170  Fidelity = 0.75617091
# T = 2180  Fidelity = 0.71497611
# T = 2190  Fidelity = 0.43432301
# T = 2200  Fidelity = 0.21230356
# T = 2300  Fidelity = 0.55725620
# T = 2400  Fidelity = 0.72411652
# T = 2500  Fidelity = 0.74685847
# T = 2600  Fidelity = 0.63232809
# T = 2700  Fidelity = 0.59389879
# T = 2800  Fidelity = 0.61848569
# T = 2900  Fidelity = 0.24915509
# T = 3000  Fidelity = 0.44705447
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44121779e+00
# P0     = 0.44705447
# P1     = 0.00031018
# P0+P1  = 0.44736465
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.97449186e-04
# T = 1     Fidelity = 0.00181025
# T = 2     Fidelity = 0.00875841
# T = 5     Fidelity = 0.04031901
# T = 10    Fidelity = 0.14627566
# T = 20    Fidelity = 0.35535857
# T = 30    Fidelity = 0.38160566
# T = 40    Fidelity = 0.32522930
# T = 50    Fidelity = 0.32607082
# T = 75    Fidelity = 0.55886562
# T = 100   Fidelity = 0.56004605
# T = 125   Fidelity = 0.50583381
# T = 150   Fidelity = 0.52362777
# T = 175   Fidelity = 0.52818649
# T = 200   Fidelity = 0.52078445
# T = 225   Fidelity = 0.49581921
# T = 250   Fidelity = 0.49591508
# T = 275   Fidelity = 0.49768657
# T = 300   Fidelity = 0.48323622
# T = 400   Fidelity = 0.51271697
# T = 500   Fidelity = 0.50216381
# T = 600   Fidelity = 0.56042355
# T = 700   Fidelity = 0.53777406
# T = 800   Fidelity = 0.58941345
# T = 900   Fidelity = 0.65962534
# T = 1000  Fidelity = 0.63817154
# T = 1010  Fidelity = 0.55701394
# T = 1020  Fidelity = 0.51471269
# T = 1030  Fidelity = 0.29784369
# T = 1040  Fidelity = 0.13403819
# T = 1050  Fidelity = 0.32341071
# T = 1060  Fidelity = 0.53530523
# T = 1070  Fidelity = 0.81668882
# T = 1080  Fidelity = 0.83973199
# T = 1090  Fidelity = 0.63609348
# T = 1100  Fidelity = 0.58580835
# T = 1200  Fidelity = 0.83346041
# T = 1300  Fidelity = 0.72307953
# T = 1400  Fidelity = 0.48869284
# T = 1500  Fidelity = 0.65458128
# T = 2000  Fidelity = 0.46956266
# T = 2100  Fidelity = 0.48259507
# T = 2110  Fidelity = 0.17030267
# T = 2120  Fidelity = 0.20060152
# T = 2130  Fidelity = 0.35906891
# T = 2140  Fidelity = 0.49730242
# T = 2150  Fidelity = 0.43205088
# T = 2160  Fidelity = 0.57694410
# T = 2170  Fidelity = 0.52303837
# T = 2180  Fidelity = 0.64957884
# T = 2190  Fidelity = 0.61664967
# T = 2200  Fidelity = 0.67238822
# T = 2300  Fidelity = 0.58712930
# T = 2400  Fidelity = 0.35438318
# T = 2500  Fidelity = 0.72786935
# T = 2600  Fidelity = 0.69666342
# T = 2700  Fidelity = 0.69285433
# T = 2800  Fidelity = 0.61869732
# T = 2900  Fidelity = 0.40623606
# T = 3000  Fidelity = 0.41956477
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.45168821e+00
# P0     = 0.41956477
# P1     = 0.00011593
# P0+P1  = 0.41968070
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 5.82831771e-03
# T = 1     Fidelity = 0.01683383
# T = 2     Fidelity = 0.05152345
# T = 5     Fidelity = 0.13906836
# T = 10    Fidelity = 0.31438848
# T = 20    Fidelity = 0.55040096
# T = 30    Fidelity = 0.62705160
# T = 40    Fidelity = 0.61105796
# T = 50    Fidelity = 0.57957563
# T = 75    Fidelity = 0.55888809
# T = 100   Fidelity = 0.60023201
# T = 125   Fidelity = 0.62829884
# T = 150   Fidelity = 0.63563773
# T = 175   Fidelity = 0.64419987
# T = 200   Fidelity = 0.64401916
# T = 225   Fidelity = 0.67554367
# T = 250   Fidelity = 0.68044938
# T = 275   Fidelity = 0.67208804
# T = 300   Fidelity = 0.68412109
# T = 400   Fidelity = 0.70747632
# T = 500   Fidelity = 0.60555669
# T = 600   Fidelity = 0.55953307
# T = 700   Fidelity = 0.72649326
# T = 800   Fidelity = 0.76658068
# T = 900   Fidelity = 0.58858635
# T = 1000  Fidelity = 0.64522313
# T = 1010  Fidelity = 0.71553133
# T = 1020  Fidelity = 0.81916596
# T = 1030  Fidelity = 0.82774590
# T = 1040  Fidelity = 0.75677476
# T = 1050  Fidelity = 0.67596104
# T = 1060  Fidelity = 0.62817535
# T = 1070  Fidelity = 0.53897666
# T = 1080  Fidelity = 0.48086230
# T = 1090  Fidelity = 0.56582117
# T = 1100  Fidelity = 0.67684038
# T = 1200  Fidelity = 0.52331744
# T = 1300  Fidelity = 0.67936867
# T = 1400  Fidelity = 0.73933595
# T = 1500  Fidelity = 0.85199079
# T = 2000  Fidelity = 0.80652433
# T = 2100  Fidelity = 0.68860646
# T = 2110  Fidelity = 0.69421788
# T = 2120  Fidelity = 0.61760999
# T = 2130  Fidelity = 0.63539279
# T = 2140  Fidelity = 0.68613718
# T = 2150  Fidelity = 0.87176435
# T = 2160  Fidelity = 0.87508099
# T = 2170  Fidelity = 0.85717289
# T = 2180  Fidelity = 0.77022730
# T = 2190  Fidelity = 0.63713065
# T = 2200  Fidelity = 0.64002490
# T = 2300  Fidelity = 0.66672903
# T = 2400  Fidelity = 0.71886448
# T = 2500  Fidelity = 0.78833553
# T = 2600  Fidelity = 0.40555642
# T = 2700  Fidelity = 0.82469278
# T = 2800  Fidelity = 0.60772113
# T = 2900  Fidelity = 0.72546984
# T = 3000  Fidelity = 0.81925695
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.46192674e+00
# P0     = 0.81925695
# P1     = 0.00002713
# P0+P1  = 0.81928408
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 3.15665395e-02
# T = 1     Fidelity = 0.06375608
# T = 2     Fidelity = 0.14776976
# T = 5     Fidelity = 0.29256659
# T = 10    Fidelity = 0.49856169
# T = 20    Fidelity = 0.70650478
# T = 30    Fidelity = 0.78192423
# T = 40    Fidelity = 0.79737854
# T = 50    Fidelity = 0.79506522
# T = 75    Fidelity = 0.78966640
# T = 100   Fidelity = 0.79656715
# T = 125   Fidelity = 0.80624760
# T = 150   Fidelity = 0.81388756
# T = 175   Fidelity = 0.82334797
# T = 200   Fidelity = 0.82919491
# T = 225   Fidelity = 0.83520136
# T = 250   Fidelity = 0.84622260
# T = 275   Fidelity = 0.83513810
# T = 300   Fidelity = 0.85863495
# T = 400   Fidelity = 0.85780251
# T = 500   Fidelity = 0.82486875
# T = 600   Fidelity = 0.83339424
# T = 700   Fidelity = 0.69585103
# T = 800   Fidelity = 0.93254408
# T = 900   Fidelity = 0.87079290
# T = 1000  Fidelity = 0.87094167
# T = 1010  Fidelity = 0.88465328
# T = 1020  Fidelity = 0.84368058
# T = 1030  Fidelity = 0.78488639
# T = 1040  Fidelity = 0.81694354
# T = 1050  Fidelity = 0.88071940
# T = 1060  Fidelity = 0.89099858
# T = 1070  Fidelity = 0.92622937
# T = 1080  Fidelity = 0.96643355
# T = 1090  Fidelity = 0.97753504
#
# Minimum T for Fidelity >= 0.97 : 1090
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.80721241e-02
# T = 1     Fidelity = 0.14357008
# T = 2     Fidelity = 0.27844359
# T = 5     Fidelity = 0.45577989
# T = 10    Fidelity = 0.65320464
# T = 20    Fidelity = 0.81523485
# T = 30    Fidelity = 0.87209513
# T = 40    Fidelity = 0.89379156
# T = 50    Fidelity = 0.90255053
# T = 75    Fidelity = 0.91317657
# T = 100   Fidelity = 0.92131309
# T = 125   Fidelity = 0.92936570
# T = 150   Fidelity = 0.93575251
# T = 175   Fidelity = 0.94383156
# T = 200   Fidelity = 0.95003883
# T = 225   Fidelity = 0.93681988
# T = 250   Fidelity = 0.94518754
# T = 275   Fidelity = 0.94892359
# T = 300   Fidelity = 0.96257280
# T = 400   Fidelity = 0.95834171
# T = 500   Fidelity = 0.93470885
# T = 600   Fidelity = 0.94624426
# T = 700   Fidelity = 0.89649947
# T = 800   Fidelity = 0.94202739
# T = 900   Fidelity = 0.93777794
# T = 1000  Fidelity = 0.92648763
# T = 1010  Fidelity = 0.97162235
#
# Minimum T for Fidelity >= 0.97 : 1010
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.28699324e-01
# T = 1     Fidelity = 0.23817036
# T = 2     Fidelity = 0.40980905
# T = 5     Fidelity = 0.59363069
# T = 10    Fidelity = 0.76348177
# T = 20    Fidelity = 0.88416692
# T = 30    Fidelity = 0.92453615
# T = 40    Fidelity = 0.94174155
# T = 50    Fidelity = 0.95060187
# T = 75    Fidelity = 0.96148332
# T = 100   Fidelity = 0.96928346
# T = 125   Fidelity = 0.97460132
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.76942005e-01
# T = 1     Fidelity = 0.33067942
# T = 2     Fidelity = 0.52256968
# T = 5     Fidelity = 0.69678729
# T = 10    Fidelity = 0.83579547
# T = 20    Fidelity = 0.92561930
# T = 30    Fidelity = 0.95439170
# T = 40    Fidelity = 0.96614338
# T = 50    Fidelity = 0.97237562
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.20505465e-01
# T = 1     Fidelity = 0.41290567
# T = 2     Fidelity = 0.61283511
# T = 5     Fidelity = 0.77098711
# T = 10    Fidelity = 0.88314210
# T = 20    Fidelity = 0.95119919
# T = 30    Fidelity = 0.97144827
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000152
# T = 10    Fidelity = 0.00047188
# T = 20    Fidelity = 0.00572758
# T = 30    Fidelity = 0.01825825
# T = 40    Fidelity = 0.06165545
# T = 50    Fidelity = 0.16103248
# T = 75    Fidelity = 0.32289737
# T = 100   Fidelity = 0.48093101
# T = 125   Fidelity = 0.62888678
# T = 150   Fidelity = 0.72476559
# T = 175   Fidelity = 0.79397072
# T = 200   Fidelity = 0.83518799
# T = 225   Fidelity = 0.84733226
# T = 250   Fidelity = 0.85542922
# T = 275   Fidelity = 0.71814059
# T = 300   Fidelity = 0.79229040
# T = 400   Fidelity = 0.93119736
# T = 500   Fidelity = 0.91079471
# T = 600   Fidelity = 0.89312122
# T = 700   Fidelity = 0.81663180
# T = 800   Fidelity = 0.64662923
# T = 900   Fidelity = 0.74813473
# T = 1000  Fidelity = 0.62960951
# T = 1010  Fidelity = 0.62178316
# T = 1020  Fidelity = 0.70122104
# T = 1030  Fidelity = 0.67229104
# T = 1040  Fidelity = 0.25497809
# T = 1050  Fidelity = 0.41832156
# T = 1060  Fidelity = 0.49994178
# T = 1070  Fidelity = 0.47203005
# T = 1080  Fidelity = 0.56605772
# T = 1090  Fidelity = 0.54942270
# T = 1100  Fidelity = 0.75454278
# T = 1200  Fidelity = 0.22365188
# T = 1300  Fidelity = 0.25214725
# T = 1400  Fidelity = 0.65151474
# T = 1500  Fidelity = 0.48293485
# T = 2000  Fidelity = 0.33813633
# T = 2100  Fidelity = 0.88865065
# T = 2110  Fidelity = 0.81594441
# T = 2120  Fidelity = 0.77005600
# T = 2130  Fidelity = 0.74823766
# T = 2140  Fidelity = 0.54452160
# T = 2150  Fidelity = 0.75810885
# T = 2160  Fidelity = 0.56091292
# T = 2170  Fidelity = 0.63589453
# T = 2180  Fidelity = 0.70265645
# T = 2190  Fidelity = 0.53248793
# T = 2200  Fidelity = 0.52997862
# T = 2300  Fidelity = 0.33869991
# T = 2400  Fidelity = 0.51712120
# T = 2500  Fidelity = 0.52695074
# T = 2600  Fidelity = 0.30661320
# T = 2700  Fidelity = 0.24651291
# T = 2800  Fidelity = 0.53840901
# T = 2900  Fidelity = 0.50492837
# T = 3000  Fidelity = 0.91758417
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91758417
# P1     = 0.00923018
# P0+P1  = 0.92681436
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61673084e-01
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000002
# T = 5     Fidelity = 0.00001550
# T = 10    Fidelity = 0.00289530
# T = 20    Fidelity = 0.22026551
# T = 30    Fidelity = 0.29529911
# T = 40    Fidelity = 0.34741052
# T = 50    Fidelity = 0.70891872
# T = 75    Fidelity = 0.77691798
# T = 100   Fidelity = 0.66425826
# T = 125   Fidelity = 0.86212859
# T = 150   Fidelity = 0.77510266
# T = 175   Fidelity = 0.90212973
# T = 200   Fidelity = 0.96466272
# T = 225   Fidelity = 0.88671102
# T = 250   Fidelity = 0.96265843
# T = 275   Fidelity = 0.94737894
# T = 300   Fidelity = 0.93273064
# T = 400   Fidelity = 0.96754876
# T = 500   Fidelity = 0.96258697
# T = 600   Fidelity = 0.87440404
# T = 700   Fidelity = 0.62774786
# T = 800   Fidelity = 0.79961426
# T = 900   Fidelity = 0.73873719
# T = 1000  Fidelity = 0.83711300
# T = 1010  Fidelity = 0.79937550
# T = 1020  Fidelity = 0.84484158
# T = 1030  Fidelity = 0.74562991
# T = 1040  Fidelity = 0.70895291
# T = 1050  Fidelity = 0.68574996
# T = 1060  Fidelity = 0.55272844
# T = 1070  Fidelity = 0.52619765
# T = 1080  Fidelity = 0.64455415
# T = 1090  Fidelity = 0.51689016
# T = 1100  Fidelity = 0.49258847
# T = 1200  Fidelity = 0.88745108
# T = 1300  Fidelity = 0.66924866
# T = 1400  Fidelity = 0.81390451
# T = 1500  Fidelity = 0.91683343
# T = 2000  Fidelity = 0.62425661
# T = 2100  Fidelity = 0.48828225
# T = 2110  Fidelity = 0.76178026
# T = 2120  Fidelity = 0.72475196
# T = 2130  Fidelity = 0.56705486
# T = 2140  Fidelity = 0.48350812
# T = 2150  Fidelity = 0.62098464
# T = 2160  Fidelity = 0.54486307
# T = 2170  Fidelity = 0.42833454
# T = 2180  Fidelity = 0.49394352
# T = 2190  Fidelity = 0.81371047
# T = 2200  Fidelity = 0.62038408
# T = 2300  Fidelity = 0.66038228
# T = 2400  Fidelity = 0.58886168
# T = 2500  Fidelity = 0.82895267
# T = 2600  Fidelity = 0.61310778
# T = 2700  Fidelity = 0.88430667
# T = 2800  Fidelity = 0.64435782
# T = 2900  Fidelity = 0.69519707
# T = 3000  Fidelity = 0.86651065
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43053089e+00
# P0     = 0.86651065
# P1     = 0.03889189
# P0+P1  = 0.90540254
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64768458e-01
# T = 1     Fidelity = 0.00000966
# T = 2     Fidelity = 0.00014601
# T = 5     Fidelity = 0.00349084
# T = 10    Fidelity = 0.05154523
# T = 20    Fidelity = 0.40844383
# T = 30    Fidelity = 0.59472464
# T = 40    Fidelity = 0.58296864
# T = 50    Fidelity = 0.72320252
# T = 75    Fidelity = 0.81367512
# T = 100   Fidelity = 0.89301771
# T = 125   Fidelity = 0.94377030
# T = 150   Fidelity = 0.96714384
# T = 175   Fidelity = 0.97739097
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00050102
# T = 2     Fidelity = 0.00289435
# T = 5     Fidelity = 0.02081612
# T = 10    Fidelity = 0.11081882
# T = 20    Fidelity = 0.42501293
# T = 30    Fidelity = 0.66188785
# T = 40    Fidelity = 0.73185965
# T = 50    Fidelity = 0.76189757
# T = 75    Fidelity = 0.88541677
# T = 100   Fidelity = 0.93289731
# T = 125   Fidelity = 0.96621518
# T = 150   Fidelity = 0.98143837
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00483456
# T = 2     Fidelity = 0.01672413
# T = 5     Fidelity = 0.06250569
# T = 10    Fidelity = 0.18623857
# T = 20    Fidelity = 0.44930153
# T = 30    Fidelity = 0.64634917
# T = 40    Fidelity = 0.75543385
# T = 50    Fidelity = 0.81764061
# T = 75    Fidelity = 0.91075419
# T = 100   Fidelity = 0.95920304
# T = 125   Fidelity = 0.97967098
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.02298704
# T = 2     Fidelity = 0.05767501
# T = 5     Fidelity = 0.14262974
# T = 10    Fidelity = 0.29276258
# T = 20    Fidelity = 0.51755750
# T = 30    Fidelity = 0.66414820
# T = 40    Fidelity = 0.75735373
# T = 50    Fidelity = 0.82096106
# T = 75    Fidelity = 0.91744979
# T = 100   Fidelity = 0.96571961
# T = 125   Fidelity = 0.98706899
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.07197989
# T = 2     Fidelity = 0.14691719
# T = 5     Fidelity = 0.27721388
# T = 10    Fidelity = 0.44514951
# T = 20    Fidelity = 0.63847618
# T = 30    Fidelity = 0.74424381
# T = 40    Fidelity = 0.81056739
# T = 50    Fidelity = 0.85718341
# T = 75    Fidelity = 0.92570615
# T = 100   Fidelity = 0.96084889
# T = 125   Fidelity = 0.97939300
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.15458632
# T = 2     Fidelity = 0.27529428
# T = 5     Fidelity = 0.43765627
# T = 10    Fidelity = 0.60374218
# T = 20    Fidelity = 0.76197351
# T = 30    Fidelity = 0.83657137
# T = 40    Fidelity = 0.88093018
# T = 50    Fidelity = 0.91043799
# T = 75    Fidelity = 0.95196833
# T = 100   Fidelity = 0.97288355
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.25467579
# T = 2     Fidelity = 0.41159293
# T = 5     Fidelity = 0.58364356
# T = 10    Fidelity = 0.73087417
# T = 20    Fidelity = 0.85290033
# T = 30    Fidelity = 0.90379930
# T = 40    Fidelity = 0.93210977
# T = 50    Fidelity = 0.94967310
# T = 75    Fidelity = 0.97425895
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.35081374
# T = 2     Fidelity = 0.52884480
# T = 5     Fidelity = 0.69439427
# T = 10    Fidelity = 0.81776964
# T = 20    Fidelity = 0.91000834
# T = 30    Fidelity = 0.94410113
# T = 40    Fidelity = 0.96189240
# T = 50    Fidelity = 0.97273073
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.06623659e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00011779
# T = 10    Fidelity = 0.00638060
# T = 20    Fidelity = 0.15720433
# T = 30    Fidelity = 0.48648237
# T = 40    Fidelity = 0.76077270
# T = 50    Fidelity = 0.90710633
# T = 75    Fidelity = 0.99423016
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.20609288e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000014
# T = 5     Fidelity = 0.00111760
# T = 10    Fidelity = 0.18568698
# T = 20    Fidelity = 0.88890683
# T = 30    Fidelity = 0.96887058
# T = 40    Fidelity = 0.99612174
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.76105909e-01
# T = 1     Fidelity = 0.00000399
# T = 2     Fidelity = 0.00014325
# T = 5     Fidelity = 0.03236225
# T = 10    Fidelity = 0.56544458
# T = 20    Fidelity = 0.90495023
# T = 30    Fidelity = 0.99221625
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.12909217e-01
# T = 1     Fidelity = 0.00019359
# T = 2     Fidelity = 0.00242211
# T = 5     Fidelity = 0.10907438
# T = 10    Fidelity = 0.69700222
# T = 20    Fidelity = 0.94967510
# T = 30    Fidelity = 0.99068168
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.40169449e-01
# T = 1     Fidelity = 0.00166652
# T = 2     Fidelity = 0.01139948
# T = 5     Fidelity = 0.20675852
# T = 10    Fidelity = 0.76567053
# T = 20    Fidelity = 0.97046886
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.61748289e-01
# T = 1     Fidelity = 0.00653018
# T = 2     Fidelity = 0.03017089
# T = 5     Fidelity = 0.30248540
# T = 10    Fidelity = 0.80500217
# T = 20    Fidelity = 0.97914537
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.79340685e-01
# T = 1     Fidelity = 0.01679281
# T = 2     Fidelity = 0.05951112
# T = 5     Fidelity = 0.39425155
# T = 10    Fidelity = 0.83530824
# T = 20    Fidelity = 0.98430396
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.94021606e-01
# T = 1     Fidelity = 0.03342027
# T = 2     Fidelity = 0.09698620
# T = 5     Fidelity = 0.47221839
# T = 10    Fidelity = 0.85582948
# T = 20    Fidelity = 0.98561032
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.06402712e-01
# T = 1     Fidelity = 0.05658564
# T = 2     Fidelity = 0.14150683
# T = 5     Fidelity = 0.54224091
# T = 10    Fidelity = 0.87422443
# T = 20    Fidelity = 0.98627648
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.17036009e-01
# T = 1     Fidelity = 0.08551803
# T = 2     Fidelity = 0.18993027
# T = 5     Fidelity = 0.60224146
# T = 10    Fidelity = 0.88961082
# T = 20    Fidelity = 0.98629289
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9933453581      1.01220263e+00    None        None        None
# Symmetric      0.311     2         0.9942314364      1.03626623e+00    None        None        None
# Symmetric      0.522     1         0.9704867849      1.05846299e+00    None        None        None
# Symmetric      0.733     1         0.9725790313      1.07916278e+00    None        None        None
# Symmetric      0.944     1         0.9744603177      1.09862393e+00    None        None        None
# Symmetric      1.156     1         0.9761016417      1.11703633e+00    None        None        None
# Symmetric      1.367     1         0.9775623410      1.13454489e+00    None        None        None
# Symmetric      1.578     1         0.9788783717      1.15126343e+00    None        None        None
# Symmetric      1.789     1         0.9800692403      1.16728342e+00    None        None        None
# Symmetric      2.000     1         0.9811716124      1.18267976e+00    None        None        None
# Weak SSB       0.100     600       0.9711211669      4.00578748e-04    None        None        None
# Weak SSB       0.311     300       0.9700525043      1.22897118e-04    None        None        None
# Weak SSB       0.522     None      0.8160535356      1.15176142e-04    0.447054    0.00031     0.447365
# Weak SSB       0.733     None      0.8397319933      2.97449186e-04    0.419565    0.000116    0.419681
# Weak SSB       0.944     None      0.8750809928      5.82831771e-03    0.819257    2.7e-05     0.819284
# Weak SSB       1.156     1090      0.9775350448      3.15665395e-02    None        None        None
# Weak SSB       1.367     1010      0.9716223490      7.80721241e-02    None        None        None
# Weak SSB       1.578     125       0.9746013239      1.28699324e-01    None        None        None
# Weak SSB       1.789     50        0.9723756170      1.76942005e-01    None        None        None
# Weak SSB       2.000     30        0.9714482673      2.20505465e-01    None        None        None
# Weak SSB optimised0.100     None      0.9311973554      2.43127858e-01    0.917584    0.00923     0.926814
# Weak SSB optimised0.311     None      0.9675487615      2.61673084e-01    0.866511    0.038892    0.905403
# Weak SSB optimised0.522     175       0.9773909660      2.64768458e-01    None        None        None
# Weak SSB optimised0.733     150       0.9814383681      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     125       0.9796709764      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     125       0.9870689913      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9793930030      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     100       0.9728835455      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     75        0.9742589546      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     50        0.9727307256      2.55131735e-01    None        None        None
# Strong SSB     0.100     75        0.9942301624      6.06623659e-01    None        None        None
# Strong SSB     0.311     40        0.9961217364      7.20609288e-01    None        None        None
# Strong SSB     0.522     30        0.9922162547      7.76105909e-01    None        None        None
# Strong SSB     0.733     30        0.9906816773      8.12909217e-01    None        None        None
# Strong SSB     0.944     20        0.9704688587      8.40169449e-01    None        None        None
# Strong SSB     1.156     20        0.9791453734      8.61748289e-01    None        None        None
# Strong SSB     1.367     20        0.9843039591      8.79340685e-01    None        None        None
# Strong SSB     1.578     20        0.9856103161      8.94021606e-01    None        None        None
# Strong SSB     1.789     20        0.9862764848      9.06402712e-01    None        None        None
# Strong SSB     2.000     20        0.9862928919      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimized')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from order parameter
# ============================================================

dM_sym = np.gradient(
    M_sym,
    lambda_sym
)

dM_weak = np.gradient(
    M_weak_opt,
    lambda_weak_opt
)

dM_strong = np.gradient(
    M_strong,
    lambda_strong
)

lamc_M_sym = lambda_sym[
    np.argmax(np.abs(dM_sym))
]

lamc_M_weak = lambda_weak_opt[
    np.argmax(np.abs(dM_weak))
]

lamc_M_strong = lambda_strong[
    np.argmax(np.abs(dM_strong))
]

print("\nOrder parameter estimator")
print("-"*50)

print(f"Symmetric        λc = {lamc_M_sym:.4f}")
print(f"Weak SSB opt     λc = {lamc_M_weak:.4f}")
print(f"Strong SSB       λc = {lamc_M_strong:.4f}")
# Out:
# Order parameter estimator
# --------------------------------------------------
# Symmetric        λc = 0.1000
# Weak SSB opt     λc = 2.0000
# Strong SSB       λc = 0.1000

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimized'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009559
# T = 10    Fidelity = 0.00119284
# T = 20    Fidelity = 0.02687458
# T = 30    Fidelity = 0.09667369
# T = 40    Fidelity = 0.19609950
# T = 50    Fidelity = 0.31173362
# T = 75    Fidelity = 0.56619506
# T = 100   Fidelity = 0.72002056
# T = 125   Fidelity = 0.80739082
# T = 150   Fidelity = 0.86470423
# T = 175   Fidelity = 0.90864735
# T = 200   Fidelity = 0.94629997
# T = 225   Fidelity = 0.96686790
# T = 250   Fidelity = 0.95352266
# T = 275   Fidelity = 0.98204224
#
# Minimum T for Fidelity >= 0.97 : 275
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624068e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144472
# T = 10    Fidelity = 0.10203750
# T = 20    Fidelity = 0.52985626
# T = 30    Fidelity = 0.63890323
# T = 40    Fidelity = 0.76792449
# T = 50    Fidelity = 0.88387462
# T = 75    Fidelity = 0.94224339
# T = 100   Fidelity = 0.97307181
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043113e-07
# T = 1     Fidelity = 0.00005024
# T = 2     Fidelity = 0.00043637
# T = 5     Fidelity = 0.02724405
# T = 10    Fidelity = 0.28403900
# T = 20    Fidelity = 0.77881492
# T = 30    Fidelity = 0.80542793
# T = 40    Fidelity = 0.95120201
# T = 50    Fidelity = 0.93700905
# T = 75    Fidelity = 0.99144550
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155147
# T = 2     Fidelity = 0.00639606
# T = 5     Fidelity = 0.08479215
# T = 10    Fidelity = 0.38779304
# T = 20    Fidelity = 0.90884644
# T = 30    Fidelity = 0.89422517
# T = 40    Fidelity = 0.97220461
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01057894
# T = 2     Fidelity = 0.02892369
# T = 5     Fidelity = 0.16450010
# T = 10    Fidelity = 0.46789329
# T = 20    Fidelity = 0.92255317
# T = 30    Fidelity = 0.97977213
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03667508
# T = 2     Fidelity = 0.07739853
# T = 5     Fidelity = 0.25992052
# T = 10    Fidelity = 0.54100507
# T = 20    Fidelity = 0.90448916
# T = 30    Fidelity = 0.99651422
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08776447
# T = 2     Fidelity = 0.15530782
# T = 5     Fidelity = 0.36741610
# T = 10    Fidelity = 0.61610558
# T = 20    Fidelity = 0.89396600
# T = 30    Fidelity = 0.98167363
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16578813
# T = 2     Fidelity = 0.25894489
# T = 5     Fidelity = 0.48156266
# T = 10    Fidelity = 0.69439323
# T = 20    Fidelity = 0.90353081
# T = 30    Fidelity = 0.97294318
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26390321
# T = 2     Fidelity = 0.37662065
# T = 5     Fidelity = 0.59256359
# T = 10    Fidelity = 0.76991308
# T = 20    Fidelity = 0.92535871
# T = 30    Fidelity = 0.97251212
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36877926
# T = 2     Fidelity = 0.49272401
# T = 5     Fidelity = 0.68998016
# T = 10    Fidelity = 0.83493967
# T = 20    Fidelity = 0.94708344
# T = 30    Fidelity = 0.97595768
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.33865795e-02
# T = 1     Fidelity = 0.59501530
# T = 2     Fidelity = 0.64030738
# T = 5     Fidelity = 0.72186655
# T = 10    Fidelity = 0.79947998
# T = 20    Fidelity = 0.88131353
# T = 30    Fidelity = 0.92385456
# T = 40    Fidelity = 0.94863444
# T = 50    Fidelity = 0.96365416
# T = 75    Fidelity = 0.98160077
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.33760034e-03
# T = 1     Fidelity = 0.48941163
# T = 2     Fidelity = 0.50389278
# T = 5     Fidelity = 0.54888748
# T = 10    Fidelity = 0.60563091
# T = 20    Fidelity = 0.67846633
# T = 30    Fidelity = 0.72871745
# T = 40    Fidelity = 0.76701105
# T = 50    Fidelity = 0.79747423
# T = 75    Fidelity = 0.85227737
# T = 100   Fidelity = 0.88721594
# T = 125   Fidelity = 0.91227553
# T = 150   Fidelity = 0.92879721
# T = 175   Fidelity = 0.93736149
# T = 200   Fidelity = 0.95456654
# T = 225   Fidelity = 0.95731115
# T = 250   Fidelity = 0.96023002
# T = 275   Fidelity = 0.94858769
# T = 300   Fidelity = 0.95979756
# T = 400   Fidelity = 0.97360781
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.28632798e-04
# T = 1     Fidelity = 0.24949465
# T = 2     Fidelity = 0.25134707
# T = 5     Fidelity = 0.25180269
# T = 10    Fidelity = 0.25198369
# T = 20    Fidelity = 0.25203315
# T = 30    Fidelity = 0.25206416
# T = 40    Fidelity = 0.25214550
# T = 50    Fidelity = 0.25219369
# T = 75    Fidelity = 0.25238207
# T = 100   Fidelity = 0.25251479
# T = 125   Fidelity = 0.25250779
# T = 150   Fidelity = 0.25250877
# T = 175   Fidelity = 0.25093284
# T = 200   Fidelity = 0.25331562
# T = 225   Fidelity = 0.25114543
# T = 250   Fidelity = 0.25294636
# T = 275   Fidelity = 0.25273940
# T = 300   Fidelity = 0.25314305
# T = 400   Fidelity = 0.25132735
# T = 500   Fidelity = 0.25279446
# T = 600   Fidelity = 0.25303826
# T = 700   Fidelity = 0.25611976
# T = 800   Fidelity = 0.25454483
# T = 900   Fidelity = 0.24988653
# T = 1000  Fidelity = 0.25466594
# T = 1010  Fidelity = 0.25486230
# T = 1020  Fidelity = 0.25172894
# T = 1030  Fidelity = 0.25390296
# T = 1040  Fidelity = 0.25574453
# T = 1050  Fidelity = 0.25526293
# T = 1060  Fidelity = 0.25166150
# T = 1070  Fidelity = 0.25277033
# T = 1080  Fidelity = 0.25279229
# T = 1090  Fidelity = 0.25131236
# T = 1100  Fidelity = 0.25136577
# T = 1200  Fidelity = 0.25429524
# T = 1300  Fidelity = 0.25499137
# T = 1400  Fidelity = 0.25332299
# T = 1500  Fidelity = 0.25309408
# T = 2000  Fidelity = 0.25484594
# T = 2100  Fidelity = 0.25370080
# T = 2110  Fidelity = 0.25261948
# T = 2120  Fidelity = 0.25340219
# T = 2130  Fidelity = 0.25413597
# T = 2140  Fidelity = 0.25417637
# T = 2150  Fidelity = 0.25481577
# T = 2160  Fidelity = 0.25413635
# T = 2170  Fidelity = 0.25351679
# T = 2180  Fidelity = 0.25298683
# T = 2190  Fidelity = 0.25527179
# T = 2200  Fidelity = 0.25409201
# T = 2300  Fidelity = 0.25317978
# T = 2400  Fidelity = 0.25331433
# T = 2500  Fidelity = 0.25410664
# T = 2600  Fidelity = 0.25713997
# T = 2700  Fidelity = 0.25419660
# T = 2800  Fidelity = 0.25227952
# T = 2900  Fidelity = 0.25105526
# T = 3000  Fidelity = 0.25038522
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.29930841e-04
# P0     = 0.25038522
# P1     = 0.24766851
# P0+P1  = 0.49805373
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07617225e-04
# T = 1     Fidelity = 0.26831257
# T = 2     Fidelity = 0.27178478
# T = 5     Fidelity = 0.27387819
# T = 10    Fidelity = 0.27442225
# T = 20    Fidelity = 0.27580932
# T = 30    Fidelity = 0.27631584
# T = 40    Fidelity = 0.27682399
# T = 50    Fidelity = 0.27747396
# T = 75    Fidelity = 0.27848335
# T = 100   Fidelity = 0.27921317
# T = 125   Fidelity = 0.27985235
# T = 150   Fidelity = 0.28049960
# T = 175   Fidelity = 0.28035568
# T = 200   Fidelity = 0.28117934
# T = 225   Fidelity = 0.28196337
# T = 250   Fidelity = 0.28226739
# T = 275   Fidelity = 0.28219187
# T = 300   Fidelity = 0.28432846
# T = 400   Fidelity = 0.28451741
# T = 500   Fidelity = 0.28737358
# T = 600   Fidelity = 0.28887965
# T = 700   Fidelity = 0.28687785
# T = 800   Fidelity = 0.28999730
# T = 900   Fidelity = 0.28654277
# T = 1000  Fidelity = 0.28993711
# T = 1010  Fidelity = 0.28827491
# T = 1020  Fidelity = 0.28520323
# T = 1030  Fidelity = 0.29636498
# T = 1040  Fidelity = 0.28485296
# T = 1050  Fidelity = 0.29735514
# T = 1060  Fidelity = 0.29580364
# T = 1070  Fidelity = 0.29248664
# T = 1080  Fidelity = 0.28972723
# T = 1090  Fidelity = 0.28995882
# T = 1100  Fidelity = 0.29133375
# T = 1200  Fidelity = 0.29157469
# T = 1300  Fidelity = 0.29133776
# T = 1400  Fidelity = 0.28927235
# T = 1500  Fidelity = 0.29039976
# T = 2000  Fidelity = 0.30224005
# T = 2100  Fidelity = 0.30058347
# T = 2110  Fidelity = 0.29709985
# T = 2120  Fidelity = 0.30100644
# T = 2130  Fidelity = 0.30429176
# T = 2140  Fidelity = 0.30514191
# T = 2150  Fidelity = 0.30433501
# T = 2160  Fidelity = 0.30223666
# T = 2170  Fidelity = 0.30023397
# T = 2180  Fidelity = 0.29986173
# T = 2190  Fidelity = 0.29854006
# T = 2200  Fidelity = 0.29939393
# T = 2300  Fidelity = 0.29816422
# T = 2400  Fidelity = 0.29979003
# T = 2500  Fidelity = 0.29960619
# T = 2600  Fidelity = 0.30271561
# T = 2700  Fidelity = 0.30063615
# T = 2800  Fidelity = 0.29635311
# T = 2900  Fidelity = 0.29453342
# T = 3000  Fidelity = 0.29423525
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.07826512e-04
# P0     = 0.29423525
# P1     = 0.24463144
# P0+P1  = 0.53886669
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.61167872e-04
# T = 1     Fidelity = 0.47264221
# T = 2     Fidelity = 0.48469610
# T = 5     Fidelity = 0.49945637
# T = 10    Fidelity = 0.50545540
# T = 20    Fidelity = 0.51350733
# T = 30    Fidelity = 0.52081129
# T = 40    Fidelity = 0.52624609
# T = 50    Fidelity = 0.52992898
# T = 75    Fidelity = 0.53956716
# T = 100   Fidelity = 0.54683512
# T = 125   Fidelity = 0.55279506
# T = 150   Fidelity = 0.55840617
# T = 175   Fidelity = 0.56375751
# T = 200   Fidelity = 0.56813426
# T = 225   Fidelity = 0.57215803
# T = 250   Fidelity = 0.57645187
# T = 275   Fidelity = 0.58028493
# T = 300   Fidelity = 0.58406728
# T = 400   Fidelity = 0.59757709
# T = 500   Fidelity = 0.60842785
# T = 600   Fidelity = 0.63026755
# T = 700   Fidelity = 0.63432841
# T = 800   Fidelity = 0.64226317
# T = 900   Fidelity = 0.63183644
# T = 1000  Fidelity = 0.65440679
# T = 1010  Fidelity = 0.65788029
# T = 1020  Fidelity = 0.65920280
# T = 1030  Fidelity = 0.66245634
# T = 1040  Fidelity = 0.66533750
# T = 1050  Fidelity = 0.66462834
# T = 1060  Fidelity = 0.66438669
# T = 1070  Fidelity = 0.66892256
# T = 1080  Fidelity = 0.67785783
# T = 1090  Fidelity = 0.67865800
# T = 1100  Fidelity = 0.66548698
# T = 1200  Fidelity = 0.64856898
# T = 1300  Fidelity = 0.64761928
# T = 1400  Fidelity = 0.67509650
# T = 1500  Fidelity = 0.68945307
# T = 2000  Fidelity = 0.67795120
# T = 2100  Fidelity = 0.67475378
# T = 2110  Fidelity = 0.67160313
# T = 2120  Fidelity = 0.67078984
# T = 2130  Fidelity = 0.66310278
# T = 2140  Fidelity = 0.67368704
# T = 2150  Fidelity = 0.66389261
# T = 2160  Fidelity = 0.66279469
# T = 2170  Fidelity = 0.66930925
# T = 2180  Fidelity = 0.67601442
# T = 2190  Fidelity = 0.68830992
# T = 2200  Fidelity = 0.69689632
# T = 2300  Fidelity = 0.70667470
# T = 2400  Fidelity = 0.72938093
# T = 2500  Fidelity = 0.73189676
# T = 2600  Fidelity = 0.73611891
# T = 2700  Fidelity = 0.77461488
# T = 2800  Fidelity = 0.76569551
# T = 2900  Fidelity = 0.77674473
# T = 3000  Fidelity = 0.76469056
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 2.60193315e-04
# P0     = 0.76469056
# P1     = 0.02155283
# P0+P1  = 0.78624339
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.86673133e-03
# T = 1     Fidelity = 0.49164786
# T = 2     Fidelity = 0.51375384
# T = 5     Fidelity = 0.54725203
# T = 10    Fidelity = 0.56404788
# T = 20    Fidelity = 0.59185182
# T = 30    Fidelity = 0.60857272
# T = 40    Fidelity = 0.62446055
# T = 50    Fidelity = 0.63527982
# T = 75    Fidelity = 0.66020925
# T = 100   Fidelity = 0.68039144
# T = 125   Fidelity = 0.69652082
# T = 150   Fidelity = 0.71068791
# T = 175   Fidelity = 0.72380958
# T = 200   Fidelity = 0.73515513
# T = 225   Fidelity = 0.74541444
# T = 250   Fidelity = 0.75523849
# T = 275   Fidelity = 0.76407205
# T = 300   Fidelity = 0.77252104
# T = 400   Fidelity = 0.80046847
# T = 500   Fidelity = 0.82258981
# T = 600   Fidelity = 0.82671484
# T = 700   Fidelity = 0.84971161
# T = 800   Fidelity = 0.87713044
# T = 900   Fidelity = 0.89450644
# T = 1000  Fidelity = 0.89009609
# T = 1010  Fidelity = 0.89720828
# T = 1020  Fidelity = 0.90322978
# T = 1030  Fidelity = 0.90953534
# T = 1040  Fidelity = 0.91321153
# T = 1050  Fidelity = 0.91433782
# T = 1060  Fidelity = 0.91277149
# T = 1070  Fidelity = 0.90999354
# T = 1080  Fidelity = 0.90722886
# T = 1090  Fidelity = 0.90397738
# T = 1100  Fidelity = 0.89967623
# T = 1200  Fidelity = 0.88925084
# T = 1300  Fidelity = 0.94032330
# T = 1400  Fidelity = 0.91505680
# T = 1500  Fidelity = 0.88530375
# T = 2000  Fidelity = 0.92434080
# T = 2100  Fidelity = 0.89586420
# T = 2110  Fidelity = 0.89435580
# T = 2120  Fidelity = 0.88621424
# T = 2130  Fidelity = 0.88239561
# T = 2140  Fidelity = 0.88995220
# T = 2150  Fidelity = 0.90166864
# T = 2160  Fidelity = 0.90727131
# T = 2170  Fidelity = 0.90605903
# T = 2180  Fidelity = 0.90286844
# T = 2190  Fidelity = 0.90420005
# T = 2200  Fidelity = 0.91123622
# T = 2300  Fidelity = 0.91223968
# T = 2400  Fidelity = 0.93287813
# T = 2500  Fidelity = 0.96773318
# T = 2600  Fidelity = 0.96755422
# T = 2700  Fidelity = 0.98657939
#
# Minimum T for Fidelity >= 0.97 : 2700
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.31352271e-03
# T = 1     Fidelity = 0.51144018
# T = 2     Fidelity = 0.54461295
# T = 5     Fidelity = 0.59840375
# T = 10    Fidelity = 0.63163364
# T = 20    Fidelity = 0.68363909
# T = 30    Fidelity = 0.71663316
# T = 40    Fidelity = 0.73885177
# T = 50    Fidelity = 0.75853600
# T = 75    Fidelity = 0.79760503
# T = 100   Fidelity = 0.82581333
# T = 125   Fidelity = 0.84741240
# T = 150   Fidelity = 0.86509614
# T = 175   Fidelity = 0.88008517
# T = 200   Fidelity = 0.89248674
# T = 225   Fidelity = 0.90318179
# T = 250   Fidelity = 0.91193560
# T = 275   Fidelity = 0.92015977
# T = 300   Fidelity = 0.92738297
# T = 400   Fidelity = 0.94824532
# T = 500   Fidelity = 0.96150513
# T = 600   Fidelity = 0.97037766
#
# Minimum T for Fidelity >= 0.97 : 600
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.92005942e-02
# T = 1     Fidelity = 0.54956748
# T = 2     Fidelity = 0.59342170
# T = 5     Fidelity = 0.66458648
# T = 10    Fidelity = 0.72009532
# T = 20    Fidelity = 0.78272912
# T = 30    Fidelity = 0.82314139
# T = 40    Fidelity = 0.85202096
# T = 50    Fidelity = 0.87341755
# T = 75    Fidelity = 0.90869119
# T = 100   Fidelity = 0.93109149
# T = 125   Fidelity = 0.94639117
# T = 150   Fidelity = 0.95734808
# T = 175   Fidelity = 0.96528374
# T = 200   Fidelity = 0.97135701
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 3.87723930e-02
# T = 1     Fidelity = 0.60021606
# T = 2     Fidelity = 0.65323965
# T = 5     Fidelity = 0.73589176
# T = 10    Fidelity = 0.80610614
# T = 20    Fidelity = 0.86833085
# T = 30    Fidelity = 0.90341745
# T = 40    Fidelity = 0.92626263
# T = 50    Fidelity = 0.94224225
# T = 75    Fidelity = 0.96465899
# T = 100   Fidelity = 0.97694782
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 6.53468672e-02
# T = 1     Fidelity = 0.65428400
# T = 2     Fidelity = 0.71392818
# T = 5     Fidelity = 0.80123370
# T = 10    Fidelity = 0.87224386
# T = 20    Fidelity = 0.92460648
# T = 30    Fidelity = 0.95035016
# T = 40    Fidelity = 0.96543959
# T = 50    Fidelity = 0.97500845
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.62195049
# T = 2     Fidelity = 0.65070207
# T = 5     Fidelity = 0.70716299
# T = 10    Fidelity = 0.76180251
# T = 20    Fidelity = 0.82831612
# T = 30    Fidelity = 0.86907018
# T = 40    Fidelity = 0.89751584
# T = 50    Fidelity = 0.91779778
# T = 75    Fidelity = 0.94913972
# T = 100   Fidelity = 0.96608941
# T = 125   Fidelity = 0.97461869
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.74543611
# T = 2     Fidelity = 0.75532585
# T = 5     Fidelity = 0.78438776
# T = 10    Fidelity = 0.81534713
# T = 20    Fidelity = 0.85094428
# T = 30    Fidelity = 0.87314655
# T = 40    Fidelity = 0.88893017
# T = 50    Fidelity = 0.90118011
# T = 75    Fidelity = 0.92284761
# T = 100   Fidelity = 0.93743978
# T = 125   Fidelity = 0.94768380
# T = 150   Fidelity = 0.95427271
# T = 175   Fidelity = 0.96175401
# T = 200   Fidelity = 0.96381031
# T = 225   Fidelity = 0.96714563
# T = 250   Fidelity = 0.96669402
# T = 275   Fidelity = 0.97008340
#
# Minimum T for Fidelity >= 0.97 : 275
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.99072350
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98782392
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97951650
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.95051208
# T = 2     Fidelity = 0.96663126
# T = 5     Fidelity = 0.97816442
#
# Minimum T for Fidelity >= 0.97 : 5
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.87878456
# T = 2     Fidelity = 0.90167443
# T = 5     Fidelity = 0.92585101
# T = 10    Fidelity = 0.93599402
# T = 20    Fidelity = 0.95038424
# T = 30    Fidelity = 0.95700797
# T = 40    Fidelity = 0.96273321
# T = 50    Fidelity = 0.96622489
# T = 75    Fidelity = 0.97314590
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78744014
# T = 2     Fidelity = 0.81755533
# T = 5     Fidelity = 0.85609771
# T = 10    Fidelity = 0.87781862
# T = 20    Fidelity = 0.90923545
# T = 30    Fidelity = 0.92352410
# T = 40    Fidelity = 0.93420930
# T = 50    Fidelity = 0.94267837
# T = 75    Fidelity = 0.95653315
# T = 100   Fidelity = 0.96554040
# T = 125   Fidelity = 0.97177389
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.71982133
# T = 2     Fidelity = 0.75640201
# T = 5     Fidelity = 0.80678469
# T = 10    Fidelity = 0.84301340
# T = 20    Fidelity = 0.89148456
# T = 30    Fidelity = 0.91296215
# T = 40    Fidelity = 0.92992556
# T = 50    Fidelity = 0.93961760
# T = 75    Fidelity = 0.95844703
# T = 100   Fidelity = 0.96973334
# T = 125   Fidelity = 0.97699351
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.69205658
# T = 2     Fidelity = 0.73424310
# T = 5     Fidelity = 0.79274952
# T = 10    Fidelity = 0.84041872
# T = 20    Fidelity = 0.90322326
# T = 30    Fidelity = 0.92687679
# T = 40    Fidelity = 0.94559089
# T = 50    Fidelity = 0.95647201
# T = 75    Fidelity = 0.97325220
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99432455
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.99416723
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.42665601e+00
# T = 1     Fidelity = 0.99374767
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41121208e+00
# T = 1     Fidelity = 0.99395949
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.99330401
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.99230280
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99120904
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98987592
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98831262
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98653183
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     275       0.9820422371      2.15534848e-04    None        None        None
# Symmetric      0.311     100       0.9730718105      1.15624068e-06    None        None        None
# Symmetric      0.522     75        0.9914455041      3.42043113e-07    None        None        None
# Symmetric      0.733     40        0.9722046096      1.41278093e-05    None        None        None
# Symmetric      0.944     30        0.9797721265      3.35131121e-04    None        None        None
# Symmetric      1.156     30        0.9965142153      2.39158790e-03    None        None        None
# Symmetric      1.367     30        0.9816736336      8.93695212e-03    None        None        None
# Symmetric      1.578     30        0.9729431768      2.26116126e-02    None        None        None
# Symmetric      1.789     30        0.9725121222      4.43232760e-02    None        None        None
# Symmetric      2.000     30        0.9759576770      7.29248761e-02    None        None        None
# Weak SSB       0.100     75        0.9816007707      1.33865795e-02    None        None        None
# Weak SSB       0.311     400       0.9736078113      2.33760034e-03    None        None        None
# Weak SSB       0.522     None      0.2571399715      1.28632798e-04    0.250385    0.247669    0.498054
# Weak SSB       0.733     None      0.3051419130      1.07617225e-04    0.294235    0.244631    0.538867
# Weak SSB       0.944     None      0.7767447258      2.61167872e-04    0.764691    0.021553    0.786243
# Weak SSB       1.156     2700      0.9865793856      1.86673133e-03    None        None        None
# Weak SSB       1.367     600       0.9703776573      7.31352271e-03    None        None        None
# Weak SSB       1.578     200       0.9713570072      1.92005942e-02    None        None        None
# Weak SSB       1.789     100       0.9769478177      3.87723930e-02    None        None        None
# Weak SSB       2.000     50        0.9750084501      6.53468672e-02    None        None        None
# Weak SSB optimised0.100     125       0.9746186897      8.65519637e-01    None        None        None
# Weak SSB optimised0.311     275       0.9700834044      5.19764834e-01    None        None        None
# Weak SSB optimised0.522     1         0.9907234978      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     1         0.9878239237      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     1         0.9795165008      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     5         0.9781644179      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     75        0.9731459025      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     125       0.9717738851      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9769935063      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     75        0.9732522027      2.54594564e-01    None        None        None
# Strong SSB     0.100     1         0.9943245526      3.59472102e+00    None        None        None
# Strong SSB     0.311     1         0.9941672253      1.58498916e+00    None        None        None
# Strong SSB     0.522     1         0.9937476677      1.42665601e+00    None        None        None
# Strong SSB     0.733     1         0.9939594947      1.41121208e+00    None        None        None
# Strong SSB     0.944     1         0.9933040147      1.38481786e+00    None        None        None
# Strong SSB     1.156     1         0.9923028049      1.34302163e+00    None        None        None
# Strong SSB     1.367     1         0.9912090426      1.29217279e+00    None        None        None
# Strong SSB     1.578     1         0.9898759248      1.23335459e+00    None        None        None
# Strong SSB     1.789     1         0.9883126164      1.17426012e+00    None        None        None
# Strong SSB     2.000     1         0.9865318321      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimized')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, m_{0}^{2}=-1.0')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from order parameter
# ============================================================

dM_sym = np.gradient(
    M_sym,
    lambda_sym
)

dM_weak = np.gradient(
    M_weak_opt,
    lambda_weak_opt
)

dM_strong = np.gradient(
    M_strong,
    lambda_strong
)

lamc_M_sym = lambda_sym[
    np.argmax(np.abs(dM_sym))
]

lamc_M_weak = lambda_weak_opt[
    np.argmax(np.abs(dM_weak))
]

lamc_M_strong = lambda_strong[
    np.argmax(np.abs(dM_strong))
]

print("\nOrder parameter estimator")
print("-"*50)

print(f"Symmetric        λc = {lamc_M_sym:.4f}")
print(f"Weak SSB opt     λc = {lamc_M_weak:.4f}")
print(f"Strong SSB       λc = {lamc_M_strong:.4f}")
# Out:
# Order parameter estimator
# --------------------------------------------------
# Symmetric        λc = 0.1000
# Weak SSB opt     λc = 0.5222
# Strong SSB       λc = 0.5222

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimized'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Start of m0^2=-2.0

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000295
# T = 10    Fidelity = 0.00027918
# T = 20    Fidelity = 0.00630272
# T = 30    Fidelity = 0.02604179
# T = 40    Fidelity = 0.06582173
# T = 50    Fidelity = 0.12447450
# T = 75    Fidelity = 0.30902584
# T = 100   Fidelity = 0.46391315
# T = 125   Fidelity = 0.64204481
# T = 150   Fidelity = 0.69157749
# T = 175   Fidelity = 0.77469265
# T = 200   Fidelity = 0.83395398
# T = 225   Fidelity = 0.81460988
# T = 250   Fidelity = 0.90536125
# T = 275   Fidelity = 0.91626410
# T = 300   Fidelity = 0.86715686
# T = 400   Fidelity = 0.97880084
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.17908351e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00030535
# T = 10    Fidelity = 0.01972688
# T = 20    Fidelity = 0.35206857
# T = 30    Fidelity = 0.52583734
# T = 40    Fidelity = 0.54429339
# T = 50    Fidelity = 0.70356313
# T = 75    Fidelity = 0.85011321
# T = 100   Fidelity = 0.92372282
# T = 125   Fidelity = 0.95512488
# T = 150   Fidelity = 0.97619438
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.94880932e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.01013613
# T = 10    Fidelity = 0.29395622
# T = 20    Fidelity = 0.47649453
# T = 30    Fidelity = 0.65919177
# T = 40    Fidelity = 0.84256926
# T = 50    Fidelity = 0.88343520
# T = 75    Fidelity = 0.96311927
# T = 100   Fidelity = 0.98782681
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.58119054e-07
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000816
# T = 5     Fidelity = 0.06261804
# T = 10    Fidelity = 0.29637156
# T = 20    Fidelity = 0.55812841
# T = 30    Fidelity = 0.72700567
# T = 40    Fidelity = 0.83531451
# T = 50    Fidelity = 0.91096468
# T = 75    Fidelity = 0.98047911
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.89654565e-08
# T = 1     Fidelity = 0.00000138
# T = 2     Fidelity = 0.00013171
# T = 5     Fidelity = 0.11160710
# T = 10    Fidelity = 0.49001937
# T = 20    Fidelity = 0.76516571
# T = 30    Fidelity = 0.88757484
# T = 40    Fidelity = 0.94381316
# T = 50    Fidelity = 0.97009276
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.17592606e-07
# T = 1     Fidelity = 0.00002206
# T = 2     Fidelity = 0.00081312
# T = 5     Fidelity = 0.15754757
# T = 10    Fidelity = 0.62742004
# T = 20    Fidelity = 0.87768851
# T = 30    Fidelity = 0.95887216
# T = 40    Fidelity = 0.98612562
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 2.47961138e-07
# T = 1     Fidelity = 0.00014367
# T = 2     Fidelity = 0.00277461
# T = 5     Fidelity = 0.19659440
# T = 10    Fidelity = 0.73839907
# T = 20    Fidelity = 0.93001381
# T = 30    Fidelity = 0.97197617
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 3.56990587e-07
# T = 1     Fidelity = 0.00057625
# T = 2     Fidelity = 0.00690671
# T = 5     Fidelity = 0.23187797
# T = 10    Fidelity = 0.80830540
# T = 20    Fidelity = 0.93689922
# T = 30    Fidelity = 0.96371778
# T = 40    Fidelity = 0.98388568
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.45005900e-06
# T = 1     Fidelity = 0.00169041
# T = 2     Fidelity = 0.01404762
# T = 5     Fidelity = 0.26488013
# T = 10    Fidelity = 0.84405400
# T = 20    Fidelity = 0.92519966
# T = 30    Fidelity = 0.96896423
# T = 40    Fidelity = 0.99383759
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396296
# T = 2     Fidelity = 0.02466737
# T = 5     Fidelity = 0.29524401
# T = 10    Fidelity = 0.85801715
# T = 20    Fidelity = 0.92051849
# T = 30    Fidelity = 0.98400154
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.80997252e-02
# T = 1     Fidelity = 0.60419289
# T = 2     Fidelity = 0.64828399
# T = 5     Fidelity = 0.72641335
# T = 10    Fidelity = 0.80234753
# T = 20    Fidelity = 0.88316538
# T = 30    Fidelity = 0.92519693
# T = 40    Fidelity = 0.94944764
# T = 50    Fidelity = 0.96410884
# T = 75    Fidelity = 0.98214692
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.50638569e-02
# T = 1     Fidelity = 0.54387879
# T = 2     Fidelity = 0.58671348
# T = 5     Fidelity = 0.63056136
# T = 10    Fidelity = 0.66777346
# T = 20    Fidelity = 0.72542174
# T = 30    Fidelity = 0.76728396
# T = 40    Fidelity = 0.79967934
# T = 50    Fidelity = 0.82355264
# T = 75    Fidelity = 0.87073680
# T = 100   Fidelity = 0.90092237
# T = 125   Fidelity = 0.92001138
# T = 150   Fidelity = 0.93410881
# T = 175   Fidelity = 0.94160290
# T = 200   Fidelity = 0.94242997
# T = 225   Fidelity = 0.94999864
# T = 250   Fidelity = 0.94171712
# T = 275   Fidelity = 0.93141765
# T = 300   Fidelity = 0.94553048
# T = 400   Fidelity = 0.96719330
# T = 500   Fidelity = 0.94948119
# T = 600   Fidelity = 0.95719011
# T = 700   Fidelity = 0.83442582
# T = 800   Fidelity = 0.87209085
# T = 900   Fidelity = 0.88482410
# T = 1000  Fidelity = 0.88116248
# T = 1010  Fidelity = 0.93286832
# T = 1020  Fidelity = 0.90781773
# T = 1030  Fidelity = 0.94429433
# T = 1040  Fidelity = 0.94741060
# T = 1050  Fidelity = 0.96156299
# T = 1060  Fidelity = 0.97104628
#
# Minimum T for Fidelity >= 0.97 : 1060
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.29389510e-04
# T = 1     Fidelity = 0.02293070
# T = 2     Fidelity = 0.09351901
# T = 5     Fidelity = 0.43023060
# T = 10    Fidelity = 0.48234074
# T = 20    Fidelity = 0.49758750
# T = 30    Fidelity = 0.49898788
# T = 40    Fidelity = 0.49975137
# T = 50    Fidelity = 0.50176104
# T = 75    Fidelity = 0.50014528
# T = 100   Fidelity = 0.50189292
# T = 125   Fidelity = 0.50027771
# T = 150   Fidelity = 0.50332696
# T = 175   Fidelity = 0.50078365
# T = 200   Fidelity = 0.50069509
# T = 225   Fidelity = 0.50127124
# T = 250   Fidelity = 0.50188643
# T = 275   Fidelity = 0.49898459
# T = 300   Fidelity = 0.49807707
# T = 400   Fidelity = 0.48541008
# T = 500   Fidelity = 0.47912996
# T = 600   Fidelity = 0.49918239
# T = 700   Fidelity = 0.49327877
# T = 800   Fidelity = 0.49011589
# T = 900   Fidelity = 0.50853671
# T = 1000  Fidelity = 0.48619460
# T = 1010  Fidelity = 0.49749653
# T = 1020  Fidelity = 0.49853790
# T = 1030  Fidelity = 0.49447015
# T = 1040  Fidelity = 0.50369984
# T = 1050  Fidelity = 0.49236100
# T = 1060  Fidelity = 0.49769857
# T = 1070  Fidelity = 0.49955164
# T = 1080  Fidelity = 0.50461377
# T = 1090  Fidelity = 0.49632011
# T = 1100  Fidelity = 0.49479864
# T = 1200  Fidelity = 0.50680594
# T = 1300  Fidelity = 0.49718299
# T = 1400  Fidelity = 0.43840457
# T = 1500  Fidelity = 0.49690070
# T = 2000  Fidelity = 0.49287479
# T = 2100  Fidelity = 0.50525996
# T = 2110  Fidelity = 0.49936405
# T = 2120  Fidelity = 0.49540259
# T = 2130  Fidelity = 0.48554511
# T = 2140  Fidelity = 0.49906269
# T = 2150  Fidelity = 0.50178303
# T = 2160  Fidelity = 0.49374763
# T = 2170  Fidelity = 0.48302091
# T = 2180  Fidelity = 0.49808179
# T = 2190  Fidelity = 0.49692912
# T = 2200  Fidelity = 0.49079573
# T = 2300  Fidelity = 0.48567689
# T = 2400  Fidelity = 0.42232645
# T = 2500  Fidelity = 0.49602710
# T = 2600  Fidelity = 0.50222425
# T = 2700  Fidelity = 0.48982969
# T = 2800  Fidelity = 0.48922064
# T = 2900  Fidelity = 0.48870707
# T = 3000  Fidelity = 0.47453776
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.15023181e-03
# P0     = 0.47453776
# P1     = 0.00901678
# P0+P1  = 0.48355453
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.10289833e-04
# T = 1     Fidelity = 0.03592598
# T = 2     Fidelity = 0.10685748
# T = 5     Fidelity = 0.28304455
# T = 10    Fidelity = 0.30484752
# T = 20    Fidelity = 0.33510696
# T = 30    Fidelity = 0.33437837
# T = 40    Fidelity = 0.33504007
# T = 50    Fidelity = 0.33887127
# T = 75    Fidelity = 0.33960002
# T = 100   Fidelity = 0.34066621
# T = 125   Fidelity = 0.34054793
# T = 150   Fidelity = 0.34095386
# T = 175   Fidelity = 0.34083678
# T = 200   Fidelity = 0.34818295
# T = 225   Fidelity = 0.34602913
# T = 250   Fidelity = 0.33804678
# T = 275   Fidelity = 0.34347069
# T = 300   Fidelity = 0.34611170
# T = 400   Fidelity = 0.36778082
# T = 500   Fidelity = 0.32786667
# T = 600   Fidelity = 0.34313393
# T = 700   Fidelity = 0.34057558
# T = 800   Fidelity = 0.31063767
# T = 900   Fidelity = 0.30726389
# T = 1000  Fidelity = 0.33497904
# T = 1010  Fidelity = 0.33863674
# T = 1020  Fidelity = 0.33751898
# T = 1030  Fidelity = 0.36737417
# T = 1040  Fidelity = 0.34705219
# T = 1050  Fidelity = 0.36796932
# T = 1060  Fidelity = 0.42751347
# T = 1070  Fidelity = 0.28117243
# T = 1080  Fidelity = 0.32800538
# T = 1090  Fidelity = 0.32473441
# T = 1100  Fidelity = 0.39392859
# T = 1200  Fidelity = 0.41048383
# T = 1300  Fidelity = 0.38564963
# T = 1400  Fidelity = 0.38895851
# T = 1500  Fidelity = 0.27389029
# T = 2000  Fidelity = 0.34973350
# T = 2100  Fidelity = 0.25384207
# T = 2110  Fidelity = 0.38571901
# T = 2120  Fidelity = 0.37566678
# T = 2130  Fidelity = 0.30110281
# T = 2140  Fidelity = 0.45155542
# T = 2150  Fidelity = 0.28015871
# T = 2160  Fidelity = 0.37647348
# T = 2170  Fidelity = 0.30762279
# T = 2180  Fidelity = 0.38583452
# T = 2190  Fidelity = 0.37771923
# T = 2200  Fidelity = 0.36379029
# T = 2300  Fidelity = 0.38537846
# T = 2400  Fidelity = 0.31470305
# T = 2500  Fidelity = 0.37803085
# T = 2600  Fidelity = 0.37901874
# T = 2700  Fidelity = 0.32808564
# T = 2800  Fidelity = 0.32238227
# T = 2900  Fidelity = 0.33505865
# T = 3000  Fidelity = 0.31402004
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.69459506e-04
# P0     = 0.31402004
# P1     = 0.16542455
# P0+P1  = 0.47944459
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.04207670e-04
# T = 1     Fidelity = 0.04065923
# T = 2     Fidelity = 0.09809418
# T = 5     Fidelity = 0.24033239
# T = 10    Fidelity = 0.25302935
# T = 20    Fidelity = 0.27496161
# T = 30    Fidelity = 0.28236354
# T = 40    Fidelity = 0.28031224
# T = 50    Fidelity = 0.28682988
# T = 75    Fidelity = 0.28983869
# T = 100   Fidelity = 0.29388235
# T = 125   Fidelity = 0.29936974
# T = 150   Fidelity = 0.30458363
# T = 175   Fidelity = 0.31313530
# T = 200   Fidelity = 0.31156584
# T = 225   Fidelity = 0.31632119
# T = 250   Fidelity = 0.31478885
# T = 275   Fidelity = 0.31272909
# T = 300   Fidelity = 0.32233829
# T = 400   Fidelity = 0.37129012
# T = 500   Fidelity = 0.29871288
# T = 600   Fidelity = 0.34327593
# T = 700   Fidelity = 0.25165446
# T = 800   Fidelity = 0.39753415
# T = 900   Fidelity = 0.39317085
# T = 1000  Fidelity = 0.36853858
# T = 1010  Fidelity = 0.39445814
# T = 1020  Fidelity = 0.41713199
# T = 1030  Fidelity = 0.37427568
# T = 1040  Fidelity = 0.30008529
# T = 1050  Fidelity = 0.28465334
# T = 1060  Fidelity = 0.31428456
# T = 1070  Fidelity = 0.34918956
# T = 1080  Fidelity = 0.41173844
# T = 1090  Fidelity = 0.43170273
# T = 1100  Fidelity = 0.29646956
# T = 1200  Fidelity = 0.28804592
# T = 1300  Fidelity = 0.43291807
# T = 1400  Fidelity = 0.31206433
# T = 1500  Fidelity = 0.43294977
# T = 2000  Fidelity = 0.43172401
# T = 2100  Fidelity = 0.36780432
# T = 2110  Fidelity = 0.43736495
# T = 2120  Fidelity = 0.40511542
# T = 2130  Fidelity = 0.40735905
# T = 2140  Fidelity = 0.46880030
# T = 2150  Fidelity = 0.37982688
# T = 2160  Fidelity = 0.37051424
# T = 2170  Fidelity = 0.32735189
# T = 2180  Fidelity = 0.33788405
# T = 2190  Fidelity = 0.45807980
# T = 2200  Fidelity = 0.32132177
# T = 2300  Fidelity = 0.44858170
# T = 2400  Fidelity = 0.38514356
# T = 2500  Fidelity = 0.44189917
# T = 2600  Fidelity = 0.43298569
# T = 2700  Fidelity = 0.37033318
# T = 2800  Fidelity = 0.40086670
# T = 2900  Fidelity = 0.43993976
# T = 3000  Fidelity = 0.44652022
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.39396699e-04
# P0     = 0.44652022
# P1     = 0.38083450
# P0+P1  = 0.82735473
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.00641152e-04
# T = 1     Fidelity = 0.04497337
# T = 2     Fidelity = 0.09415365
# T = 5     Fidelity = 0.22431683
# T = 10    Fidelity = 0.23892322
# T = 20    Fidelity = 0.26109955
# T = 30    Fidelity = 0.28444300
# T = 40    Fidelity = 0.29266517
# T = 50    Fidelity = 0.29153372
# T = 75    Fidelity = 0.31372974
# T = 100   Fidelity = 0.31924524
# T = 125   Fidelity = 0.32869166
# T = 150   Fidelity = 0.34057174
# T = 175   Fidelity = 0.34268068
# T = 200   Fidelity = 0.35215026
# T = 225   Fidelity = 0.35828911
# T = 250   Fidelity = 0.35922589
# T = 275   Fidelity = 0.37166767
# T = 300   Fidelity = 0.37016816
# T = 400   Fidelity = 0.33706004
# T = 500   Fidelity = 0.37742792
# T = 600   Fidelity = 0.41852366
# T = 700   Fidelity = 0.42056962
# T = 800   Fidelity = 0.43765464
# T = 900   Fidelity = 0.44586316
# T = 1000  Fidelity = 0.47132519
# T = 1010  Fidelity = 0.41593815
# T = 1020  Fidelity = 0.39652889
# T = 1030  Fidelity = 0.44892701
# T = 1040  Fidelity = 0.48133173
# T = 1050  Fidelity = 0.46866239
# T = 1060  Fidelity = 0.41025022
# T = 1070  Fidelity = 0.36010415
# T = 1080  Fidelity = 0.44190072
# T = 1090  Fidelity = 0.47371903
# T = 1100  Fidelity = 0.38895160
# T = 1200  Fidelity = 0.46386310
# T = 1300  Fidelity = 0.48838681
# T = 1400  Fidelity = 0.45960262
# T = 1500  Fidelity = 0.46001322
# T = 2000  Fidelity = 0.45757226
# T = 2100  Fidelity = 0.47275350
# T = 2110  Fidelity = 0.46052426
# T = 2120  Fidelity = 0.44507994
# T = 2130  Fidelity = 0.45813735
# T = 2140  Fidelity = 0.43759095
# T = 2150  Fidelity = 0.43865225
# T = 2160  Fidelity = 0.44178374
# T = 2170  Fidelity = 0.42392518
# T = 2180  Fidelity = 0.41450851
# T = 2190  Fidelity = 0.43937490
# T = 2200  Fidelity = 0.43301596
# T = 2300  Fidelity = 0.48288891
# T = 2400  Fidelity = 0.49620395
# T = 2500  Fidelity = 0.46309880
# T = 2600  Fidelity = 0.48018552
# T = 2700  Fidelity = 0.49881085
# T = 2800  Fidelity = 0.47425159
# T = 2900  Fidelity = 0.50457806
# T = 3000  Fidelity = 0.50516037
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.24417142e-04
# P0     = 0.50516037
# P1     = 0.48609178
# P0+P1  = 0.99125215
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 9.79040346e-05
# T = 1     Fidelity = 0.04774472
# T = 2     Fidelity = 0.09164464
# T = 5     Fidelity = 0.23553417
# T = 10    Fidelity = 0.25961832
# T = 20    Fidelity = 0.28507785
# T = 30    Fidelity = 0.30794687
# T = 40    Fidelity = 0.33055677
# T = 50    Fidelity = 0.34845255
# T = 75    Fidelity = 0.36874674
# T = 100   Fidelity = 0.38467463
# T = 125   Fidelity = 0.40365568
# T = 150   Fidelity = 0.41215588
# T = 175   Fidelity = 0.42201616
# T = 200   Fidelity = 0.43304640
# T = 225   Fidelity = 0.43679679
# T = 250   Fidelity = 0.44454824
# T = 275   Fidelity = 0.45247676
# T = 300   Fidelity = 0.45041688
# T = 400   Fidelity = 0.46917052
# T = 500   Fidelity = 0.44832338
# T = 600   Fidelity = 0.48340454
# T = 700   Fidelity = 0.47965825
# T = 800   Fidelity = 0.49656969
# T = 900   Fidelity = 0.49951567
# T = 1000  Fidelity = 0.46720238
# T = 1010  Fidelity = 0.49363405
# T = 1020  Fidelity = 0.47546554
# T = 1030  Fidelity = 0.46603130
# T = 1040  Fidelity = 0.49016900
# T = 1050  Fidelity = 0.49164260
# T = 1060  Fidelity = 0.46717286
# T = 1070  Fidelity = 0.49770686
# T = 1080  Fidelity = 0.49087398
# T = 1090  Fidelity = 0.50090730
# T = 1100  Fidelity = 0.48713003
# T = 1200  Fidelity = 0.47985779
# T = 1300  Fidelity = 0.49562233
# T = 1400  Fidelity = 0.46406297
# T = 1500  Fidelity = 0.48536121
# T = 2000  Fidelity = 0.49473981
# T = 2100  Fidelity = 0.50614539
# T = 2110  Fidelity = 0.50316671
# T = 2120  Fidelity = 0.49344269
# T = 2130  Fidelity = 0.49025959
# T = 2140  Fidelity = 0.49787058
# T = 2150  Fidelity = 0.50181924
# T = 2160  Fidelity = 0.50644826
# T = 2170  Fidelity = 0.50325762
# T = 2180  Fidelity = 0.48929741
# T = 2190  Fidelity = 0.49537043
# T = 2200  Fidelity = 0.49009575
# T = 2300  Fidelity = 0.47417554
# T = 2400  Fidelity = 0.50986644
# T = 2500  Fidelity = 0.49294393
# T = 2600  Fidelity = 0.43020262
# T = 2700  Fidelity = 0.45353508
# T = 2800  Fidelity = 0.45056485
# T = 2900  Fidelity = 0.46261184
# T = 3000  Fidelity = 0.40158312
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.13589115e-04
# P0     = 0.40158312
# P1     = 0.38164257
# P0+P1  = 0.78322569
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 9.56243266e-05
# T = 1     Fidelity = 0.04996850
# T = 2     Fidelity = 0.09009797
# T = 5     Fidelity = 0.25416821
# T = 10    Fidelity = 0.29222067
# T = 20    Fidelity = 0.33337692
# T = 30    Fidelity = 0.36102633
# T = 40    Fidelity = 0.38162174
# T = 50    Fidelity = 0.39796156
# T = 75    Fidelity = 0.42713065
# T = 100   Fidelity = 0.44646967
# T = 125   Fidelity = 0.46015981
# T = 150   Fidelity = 0.47023614
# T = 175   Fidelity = 0.47783759
# T = 200   Fidelity = 0.48348176
# T = 225   Fidelity = 0.48794278
# T = 250   Fidelity = 0.49122761
# T = 275   Fidelity = 0.49352285
# T = 300   Fidelity = 0.49486433
# T = 400   Fidelity = 0.49251304
# T = 500   Fidelity = 0.50050569
# T = 600   Fidelity = 0.49359825
# T = 700   Fidelity = 0.49921978
# T = 800   Fidelity = 0.48688932
# T = 900   Fidelity = 0.50417035
# T = 1000  Fidelity = 0.48910730
# T = 1010  Fidelity = 0.50343424
# T = 1020  Fidelity = 0.49329901
# T = 1030  Fidelity = 0.49312839
# T = 1040  Fidelity = 0.50352483
# T = 1050  Fidelity = 0.49765067
# T = 1060  Fidelity = 0.47857155
# T = 1070  Fidelity = 0.49832293
# T = 1080  Fidelity = 0.48672443
# T = 1090  Fidelity = 0.50330288
# T = 1100  Fidelity = 0.49345292
# T = 1200  Fidelity = 0.49255134
# T = 1300  Fidelity = 0.50522615
# T = 1400  Fidelity = 0.45809613
# T = 1500  Fidelity = 0.48923652
# T = 2000  Fidelity = 0.42672364
# T = 2100  Fidelity = 0.42923816
# T = 2110  Fidelity = 0.47366232
# T = 2120  Fidelity = 0.44381922
# T = 2130  Fidelity = 0.44445033
# T = 2140  Fidelity = 0.45687408
# T = 2150  Fidelity = 0.42874334
# T = 2160  Fidelity = 0.42196121
# T = 2170  Fidelity = 0.44123998
# T = 2180  Fidelity = 0.43988933
# T = 2190  Fidelity = 0.42428835
# T = 2200  Fidelity = 0.38876437
# T = 2300  Fidelity = 0.47302406
# T = 2400  Fidelity = 0.47014004
# T = 2500  Fidelity = 0.43185241
# T = 2600  Fidelity = 0.48806985
# T = 2700  Fidelity = 0.49280152
# T = 2800  Fidelity = 0.46398403
# T = 2900  Fidelity = 0.50605489
# T = 3000  Fidelity = 0.50850204
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.05026659e-04
# P0     = 0.50850204
# P1     = 0.47786318
# P0+P1  = 0.98636522
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.37092431e-05
# T = 1     Fidelity = 0.05469333
# T = 2     Fidelity = 0.09379942
# T = 5     Fidelity = 0.28192117
# T = 10    Fidelity = 0.33455745
# T = 20    Fidelity = 0.39239010
# T = 30    Fidelity = 0.42410944
# T = 40    Fidelity = 0.44443628
# T = 50    Fidelity = 0.45834631
# T = 75    Fidelity = 0.47928971
# T = 100   Fidelity = 0.49080231
# T = 125   Fidelity = 0.49780052
# T = 150   Fidelity = 0.50211148
# T = 175   Fidelity = 0.50462966
# T = 200   Fidelity = 0.50584888
# T = 225   Fidelity = 0.50656382
# T = 250   Fidelity = 0.50683762
# T = 275   Fidelity = 0.50701504
# T = 300   Fidelity = 0.50685164
# T = 400   Fidelity = 0.49450042
# T = 500   Fidelity = 0.50042098
# T = 600   Fidelity = 0.50845335
# T = 700   Fidelity = 0.50101782
# T = 800   Fidelity = 0.49722907
# T = 900   Fidelity = 0.49399899
# T = 1000  Fidelity = 0.48937733
# T = 1010  Fidelity = 0.51143273
# T = 1020  Fidelity = 0.50365652
# T = 1030  Fidelity = 0.50478170
# T = 1040  Fidelity = 0.51005540
# T = 1050  Fidelity = 0.49069320
# T = 1060  Fidelity = 0.50944225
# T = 1070  Fidelity = 0.51036274
# T = 1080  Fidelity = 0.47966059
# T = 1090  Fidelity = 0.49475685
# T = 1100  Fidelity = 0.50423627
# T = 1200  Fidelity = 0.50056318
# T = 1300  Fidelity = 0.47906576
# T = 1400  Fidelity = 0.48003832
# T = 1500  Fidelity = 0.47986462
# T = 2000  Fidelity = 0.48798104
# T = 2100  Fidelity = 0.49782861
# T = 2110  Fidelity = 0.51617665
# T = 2120  Fidelity = 0.50843827
# T = 2130  Fidelity = 0.51403549
# T = 2140  Fidelity = 0.51868662
# T = 2150  Fidelity = 0.51268546
# T = 2160  Fidelity = 0.50593696
# T = 2170  Fidelity = 0.50330262
# T = 2180  Fidelity = 0.51056829
# T = 2190  Fidelity = 0.51474066
# T = 2200  Fidelity = 0.50857536
# T = 2300  Fidelity = 0.51246845
# T = 2400  Fidelity = 0.51625095
# T = 2500  Fidelity = 0.51636051
# T = 2600  Fidelity = 0.48140599
# T = 2700  Fidelity = 0.51284547
# T = 2800  Fidelity = 0.49443462
# T = 2900  Fidelity = 0.51990768
# T = 3000  Fidelity = 0.50673635
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.78352675e-05
# P0     = 0.50673635
# P1     = 0.46011140
# P0+P1  = 0.96684775
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.20598135e-05
# T = 1     Fidelity = 0.06522795
# T = 2     Fidelity = 0.10733177
# T = 5     Fidelity = 0.33518584
# T = 10    Fidelity = 0.40365989
# T = 20    Fidelity = 0.46641471
# T = 30    Fidelity = 0.49762473
# T = 40    Fidelity = 0.51817421
# T = 50    Fidelity = 0.53229283
# T = 75    Fidelity = 0.54742660
# T = 100   Fidelity = 0.55047464
# T = 125   Fidelity = 0.55323023
# T = 150   Fidelity = 0.55459301
# T = 175   Fidelity = 0.55468766
# T = 200   Fidelity = 0.55564246
# T = 225   Fidelity = 0.55597266
# T = 250   Fidelity = 0.55586429
# T = 275   Fidelity = 0.55633153
# T = 300   Fidelity = 0.55540742
# T = 400   Fidelity = 0.54620205
# T = 500   Fidelity = 0.54954997
# T = 600   Fidelity = 0.55278390
# T = 700   Fidelity = 0.55303881
# T = 800   Fidelity = 0.54820557
# T = 900   Fidelity = 0.55331205
# T = 1000  Fidelity = 0.53159530
# T = 1010  Fidelity = 0.55576162
# T = 1020  Fidelity = 0.53831702
# T = 1030  Fidelity = 0.56003150
# T = 1040  Fidelity = 0.53875376
# T = 1050  Fidelity = 0.55353369
# T = 1060  Fidelity = 0.54392164
# T = 1070  Fidelity = 0.53642090
# T = 1080  Fidelity = 0.53475757
# T = 1090  Fidelity = 0.54729114
# T = 1100  Fidelity = 0.55273468
# T = 1200  Fidelity = 0.53692569
# T = 1300  Fidelity = 0.52093323
# T = 1400  Fidelity = 0.51722964
# T = 1500  Fidelity = 0.52359102
# T = 2000  Fidelity = 0.55332494
# T = 2100  Fidelity = 0.55560851
# T = 2110  Fidelity = 0.55421472
# T = 2120  Fidelity = 0.56513003
# T = 2130  Fidelity = 0.56072331
# T = 2140  Fidelity = 0.56650508
# T = 2150  Fidelity = 0.53441436
# T = 2160  Fidelity = 0.54900884
# T = 2170  Fidelity = 0.56321154
# T = 2180  Fidelity = 0.54929461
# T = 2190  Fidelity = 0.56238450
# T = 2200  Fidelity = 0.55751140
# T = 2300  Fidelity = 0.56038126
# T = 2400  Fidelity = 0.55696711
# T = 2500  Fidelity = 0.55759513
# T = 2600  Fidelity = 0.55741271
# T = 2700  Fidelity = 0.51914628
# T = 2800  Fidelity = 0.53676978
# T = 2900  Fidelity = 0.54542508
# T = 3000  Fidelity = 0.56267828
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.23373761e-05
# P0     = 0.56267828
# P1     = 0.42015365
# P0+P1  = 0.98283193
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.62821580
# T = 2     Fidelity = 0.65676839
# T = 5     Fidelity = 0.71243235
# T = 10    Fidelity = 0.76587206
# T = 20    Fidelity = 0.83150634
# T = 30    Fidelity = 0.87121807
# T = 40    Fidelity = 0.89960925
# T = 50    Fidelity = 0.91944972
# T = 75    Fidelity = 0.95028481
# T = 100   Fidelity = 0.96456583
# T = 125   Fidelity = 0.97360978
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.70121258
# T = 2     Fidelity = 0.77020910
# T = 5     Fidelity = 0.81768465
# T = 10    Fidelity = 0.84683707
# T = 20    Fidelity = 0.87490764
# T = 30    Fidelity = 0.89254634
# T = 40    Fidelity = 0.90599523
# T = 50    Fidelity = 0.91586411
# T = 75    Fidelity = 0.93359424
# T = 100   Fidelity = 0.94483082
# T = 125   Fidelity = 0.95112549
# T = 150   Fidelity = 0.95615425
# T = 175   Fidelity = 0.96367292
# T = 200   Fidelity = 0.97097812
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.05166726
# T = 2     Fidelity = 0.19649815
# T = 5     Fidelity = 0.84810392
# T = 10    Fidelity = 0.96978881
# T = 20    Fidelity = 0.99303125
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.11303586
# T = 2     Fidelity = 0.33352861
# T = 5     Fidelity = 0.84570746
# T = 10    Fidelity = 0.91483060
# T = 20    Fidelity = 0.99919465
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.16801870
# T = 2     Fidelity = 0.40021184
# T = 5     Fidelity = 0.89875463
# T = 10    Fidelity = 0.94647466
# T = 20    Fidelity = 0.99410511
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.20994332
# T = 2     Fidelity = 0.42976513
# T = 5     Fidelity = 0.87844022
# T = 10    Fidelity = 0.92205781
# T = 20    Fidelity = 0.97181725
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.21726940
# T = 2     Fidelity = 0.40374569
# T = 5     Fidelity = 0.82534932
# T = 10    Fidelity = 0.86427331
# T = 20    Fidelity = 0.90675782
# T = 30    Fidelity = 0.93345054
# T = 40    Fidelity = 0.94557145
# T = 50    Fidelity = 0.94744925
# T = 75    Fidelity = 0.96089933
# T = 100   Fidelity = 0.96431054
# T = 125   Fidelity = 0.97299229
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.20105039
# T = 2     Fidelity = 0.34926672
# T = 5     Fidelity = 0.74394917
# T = 10    Fidelity = 0.79149907
# T = 20    Fidelity = 0.83407044
# T = 30    Fidelity = 0.86158375
# T = 40    Fidelity = 0.88524539
# T = 50    Fidelity = 0.90476623
# T = 75    Fidelity = 0.92920964
# T = 100   Fidelity = 0.94051530
# T = 125   Fidelity = 0.95393164
# T = 150   Fidelity = 0.96157285
# T = 175   Fidelity = 0.96615732
# T = 200   Fidelity = 0.97204427
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.18027897
# T = 2     Fidelity = 0.29819645
# T = 5     Fidelity = 0.67058531
# T = 10    Fidelity = 0.73240289
# T = 20    Fidelity = 0.79335462
# T = 30    Fidelity = 0.82943687
# T = 40    Fidelity = 0.85596844
# T = 50    Fidelity = 0.87719832
# T = 75    Fidelity = 0.91467710
# T = 100   Fidelity = 0.93861646
# T = 125   Fidelity = 0.95457250
# T = 150   Fidelity = 0.96529799
# T = 175   Fidelity = 0.97243417
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.48783584e-01
# T = 1     Fidelity = 0.16414002
# T = 2     Fidelity = 0.26135819
# T = 5     Fidelity = 0.61988062
# T = 10    Fidelity = 0.69434854
# T = 20    Fidelity = 0.77223573
# T = 30    Fidelity = 0.82140893
# T = 40    Fidelity = 0.85797067
# T = 50    Fidelity = 0.88608117
# T = 75    Fidelity = 0.93165020
# T = 100   Fidelity = 0.95678409
# T = 125   Fidelity = 0.97132095
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99358442
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.89738676
# T = 2     Fidelity = 0.95289476
# T = 5     Fidelity = 0.98557393
#
# Minimum T for Fidelity >= 0.97 : 5
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.31621635e+00
# T = 1     Fidelity = 0.10132694
# T = 2     Fidelity = 0.29862163
# T = 5     Fidelity = 0.80821615
# T = 10    Fidelity = 0.99315097
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.40805723e+00
# T = 1     Fidelity = 0.13217021
# T = 2     Fidelity = 0.38013600
# T = 5     Fidelity = 0.80801567
# T = 10    Fidelity = 0.92213480
# T = 20    Fidelity = 0.99604645
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.23645336
# T = 2     Fidelity = 0.53326867
# T = 5     Fidelity = 0.91878361
# T = 10    Fidelity = 0.98336820
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.30609594
# T = 2     Fidelity = 0.59468592
# T = 5     Fidelity = 0.91661130
# T = 10    Fidelity = 0.98303642
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.36122394
# T = 2     Fidelity = 0.63520928
# T = 5     Fidelity = 0.93273461
# T = 10    Fidelity = 0.98434508
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.40257809
# T = 2     Fidelity = 0.66036194
# T = 5     Fidelity = 0.93992990
# T = 10    Fidelity = 0.98329411
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.43990538
# T = 2     Fidelity = 0.68184047
# T = 5     Fidelity = 0.94426585
# T = 10    Fidelity = 0.98205696
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.47113151
# T = 2     Fidelity = 0.69831896
# T = 5     Fidelity = 0.94922538
# T = 10    Fidelity = 0.98134398
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     400       0.9788008392      3.07240439e-04    None        None        None
# Symmetric      0.311     150       0.9761943812      1.17908351e-06    None        None        None
# Symmetric      0.522     100       0.9878268063      2.94880932e-07    None        None        None
# Symmetric      0.733     75        0.9804791082      1.58119054e-07    None        None        None
# Symmetric      0.944     50        0.9700927577      6.89654565e-08    None        None        None
# Symmetric      1.156     40        0.9861256211      1.17592606e-07    None        None        None
# Symmetric      1.367     30        0.9719761748      2.47961138e-07    None        None        None
# Symmetric      1.578     40        0.9838856780      3.56990587e-07    None        None        None
# Symmetric      1.789     40        0.9938375885      2.45005900e-06    None        None        None
# Symmetric      2.000     30        0.9840015381      1.44257094e-05    None        None        None
# Weak SSB       0.100     75        0.9821469228      1.80997252e-02    None        None        None
# Weak SSB       0.311     1060      0.9710462805      1.50638569e-02    None        None        None
# Weak SSB       0.522     None      0.5085367092      1.29389510e-04    0.474538    0.009017    0.483555
# Weak SSB       0.733     None      0.4515554179      1.10289833e-04    0.31402     0.165425    0.479445
# Weak SSB       0.944     None      0.4688002960      1.04207670e-04    0.44652     0.380835    0.827355
# Weak SSB       1.156     None      0.5051603735      1.00641152e-04    0.50516     0.486092    0.991252
# Weak SSB       1.367     None      0.5098664389      9.79040346e-05    0.401583    0.381643    0.783226
# Weak SSB       1.578     None      0.5085020374      9.56243266e-05    0.508502    0.477863    0.986365
# Weak SSB       1.789     None      0.5199076778      9.37092431e-05    0.506736    0.460111    0.966848
# Weak SSB       2.000     None      0.5665050808      9.20598135e-05    0.562678    0.420154    0.982832
# Weak SSB optimised0.100     125       0.9736097796      8.67181393e-01    None        None        None
# Weak SSB optimised0.311     200       0.9709781172      5.19764834e-01    None        None        None
# Weak SSB optimised0.522     20        0.9930312466      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     20        0.9991946526      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     20        0.9941051148      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     20        0.9718172461      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9729922912      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     200       0.9720442694      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     175       0.9724341693      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     125       0.9713209539      2.48783584e-01    None        None        None
# Strong SSB     0.100     1         0.9935844169      3.59472102e+00    None        None        None
# Strong SSB     0.311     5         0.9855739320      1.58498916e+00    None        None        None
# Strong SSB     0.522     10        0.9931509743      1.31621635e+00    None        None        None
# Strong SSB     0.733     20        0.9960464481      1.40805723e+00    None        None        None
# Strong SSB     0.944     10        0.9833682011      1.38481786e+00    None        None        None
# Strong SSB     1.156     10        0.9830364243      1.34302163e+00    None        None        None
# Strong SSB     1.367     10        0.9843450765      1.29217279e+00    None        None        None
# Strong SSB     1.578     10        0.9832941128      1.23335459e+00    None        None        None
# Strong SSB     1.789     10        0.9820569644      1.17426012e+00    None        None        None
# Strong SSB     2.000     10        0.9813439805      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.1556
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7333

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimized')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, m_{0}^{2}=-2.0')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from order parameter
# ============================================================

dM_sym = np.gradient(
    M_sym,
    lambda_sym
)

dM_weak = np.gradient(
    M_weak_opt,
    lambda_weak_opt
)

dM_strong = np.gradient(
    M_strong,
    lambda_strong
)

lamc_M_sym = lambda_sym[
    np.argmax(np.abs(dM_sym))
]

lamc_M_weak = lambda_weak_opt[
    np.argmax(np.abs(dM_weak))
]

lamc_M_strong = lambda_strong[
    np.argmax(np.abs(dM_strong))
]

print("\nOrder parameter estimator")
print("-"*50)

print(f"Symmetric        λc = {lamc_M_sym:.4f}")
print(f"Weak SSB opt     λc = {lamc_M_weak:.4f}")
print(f"Strong SSB       λc = {lamc_M_strong:.4f}")
# Out:
# Order parameter estimator
# --------------------------------------------------
# Symmetric        λc = 0.1000
# Weak SSB opt     λc = 0.7333
# Strong SSB       λc = 0.7333

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimized'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
