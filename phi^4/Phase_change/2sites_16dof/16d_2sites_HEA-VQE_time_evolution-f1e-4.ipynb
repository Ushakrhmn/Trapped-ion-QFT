# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.055472254575683
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Genuine Qiskit VQE on shifted Pauli Hamiltonian
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SPSA

from qiskit.primitives import StatevectorEstimator


# ============================================================
# Variational circuit
# ============================================================

def variational_circuit(nq, layers):

    qc = QuantumCircuit(nq)

    nparams = 2 * nq * layers

    params = ParameterVector("θ", nparams)

    p = 0

    for l in range(layers):

        # ----------------------------------------------------
        # Single-qubit rotations
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(params[p], q)
            qc.rz(params[p + 1], q)

            p += 2

        # ----------------------------------------------------
        # Entanglement layer
        # ----------------------------------------------------

        if l != layers - 1:

            # even bonds
            if l % 2 == 0:

                for q in range(0, nq - 1, 2):
                    qc.cz(q, q + 1)

            # odd bonds
            else:

                for q in range(1, nq - 1, 2):
                    qc.cz(q, q + 1)

    return qc


# ============================================================
# Ansatz
# ============================================================

nqubits = 8

# start modestly
layers = 8

ansatz = variational_circuit(
    nqubits,
    layers
)

# ============================================================
# Estimator
# ============================================================

estimator = StatevectorEstimator()

# ============================================================
# Optimizer
# ============================================================

optimizer = SPSA(
    maxiter=5000
)

# ============================================================
# VQE
# ============================================================
initial_point = 0.01 * np.random.randn(
    ansatz.num_parameters
)
vqe = VQE(
    estimator=estimator,
    ansatz=ansatz,
    optimizer=optimizer,
    initial_point=initial_point
)

# ============================================================
# Run VQE
# ============================================================

print("\nRunning VQE...\n")

result = vqe.compute_minimum_eigenvalue(
    H_pauli_shifted
)

# ============================================================
# Shifted energy
# ============================================================

E_shifted = result.eigenvalue.real

# ============================================================
# Physical energy
# ============================================================

E_vqe = E_shifted + identity_shift

# ============================================================
# Optimal parameters
# ============================================================

optimal_params = result.optimal_parameters

# ============================================================
# Optimized circuit
# ============================================================

optimal_circuit = ansatz.assign_parameters(
    optimal_params
)

# ============================================================
# VQE state
# ============================================================

psi_vqe = Statevector.from_instruction(
    optimal_circuit
).data

# ============================================================
# Fidelity
# ============================================================

Fidelity = np.abs(
    np.vdot(psi_loc, psi_vqe)
)**2

# ============================================================
# Results
# ============================================================

print("\n================================")
print("Exact energy :", E0_loc)
print("VQE energy   :", E_vqe)
print("Energy error :", abs(E_vqe - E0_loc))
print("Fidelity     :", Fidelity)
print("Layers        :", layers)
print("Pauli terms   :", len(H_pauli_shifted))
print("================================")
# Out:
# Running VQE...
#
#
# ================================
# Exact energy : 1.055472254575683
# VQE energy   : 1.069909612481406
# Energy error : 0.014437357905723092
# Fidelity     : 0.9964794753887781
# Layers        : 8
# Pauli terms   : 111
# ================================

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Robust VQE with eigenstate tracking
# ============================================================
import numpy as np

from scipy.sparse import identity, kron

from qiskit.quantum_info import (
    Statevector,
    Operator,
    SparsePauliOp
)

from qiskit.primitives import StatevectorEstimator

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B
def run_robust_vqe(

    H_sparse,

    nq,

    layers,

    n_restarts,

    energy_tol,

    previous_state=None,

    previous_optimal_point=None
):

    nqubits = nq

    # --------------------------------------------------------
    # Exact ground state
    # --------------------------------------------------------

    E_exact, psi_exact = exact_ground_state(H_sparse)

    # --------------------------------------------------------
    # Convert Hamiltonian
    # --------------------------------------------------------

    H_dense = H_sparse.toarray()

    H_op = Operator(H_dense)

    H_pauli = SparsePauliOp.from_operator(H_op)

    coeffs = H_pauli.coeffs

    paulis = H_pauli.paulis

    new_coeffs = []

    new_paulis = []

    identity_shift = 0.0

    for p, c in zip(paulis, coeffs):

        if str(p) == 'I' * nqubits:

            identity_shift += np.real(c)

        else:

            new_paulis.append(p)

            new_coeffs.append(c)

    H_pauli_shifted = SparsePauliOp(

        new_paulis,

        coeffs=new_coeffs
    )

    # --------------------------------------------------------
    # Ansatz
    # --------------------------------------------------------

    ansatz = variational_circuit(

        nq=nqubits,

        layers=layers
    )

    estimator = StatevectorEstimator()

    optimizer = L_BFGS_B(maxiter=1000)

    # ========================================================
    # Multiple restarts
    # ========================================================

    trial_results = []

    for trial in range(n_restarts):

        # ----------------------------------------------------
        # Initial point
        # ----------------------------------------------------

        if trial == 0 and previous_optimal_point is not None:

            initial_point = previous_optimal_point

        else:

            initial_point = 0.01 * np.random.randn(

                ansatz.num_parameters
            )

        # ----------------------------------------------------
        # VQE
        # ----------------------------------------------------

        vqe = VQE(

            estimator=estimator,

            ansatz=ansatz,

            optimizer=optimizer,

            initial_point=initial_point
        )

        result = vqe.compute_minimum_eigenvalue(

            H_pauli_shifted
        )

        E_trial = (

            np.real(result.eigenvalue)

            + identity_shift
        )

        # ----------------------------------------------------
        # Trial state
        # ----------------------------------------------------

        qc_trial = ansatz.assign_parameters(

            result.optimal_parameters
        )

        psi_trial = Statevector.from_instruction(

            qc_trial

        ).data

        # ----------------------------------------------------
        # Overlap tracking
        # ----------------------------------------------------

        if previous_state is None:

            overlap = 1.0

        else:

            overlap = abs(np.vdot(

                previous_state,

                psi_trial

            ))**2

        trial_results.append({

            'energy': E_trial,

            'overlap': overlap,

            'state': psi_trial,

            'result': result
        })

    # ========================================================
    # Hybrid selection
    # ========================================================

    energies = np.array([

        t['energy']

        for t in trial_results
    ])

    E_min = np.min(energies)

    filtered_candidates = [

        t for t in trial_results

        if (t['energy'] - E_min) < energy_tol
    ]

    best_candidate = max(

        filtered_candidates,

        key=lambda x: x['overlap']
    )

    # ========================================================
    # Outputs
    # ========================================================

    # ========================================================
    # Final outputs
    # ========================================================

    psi_vqe = best_candidate['state']

    E_vqe = best_candidate['energy']

    optimal_point = (

        best_candidate['result'].optimal_point
    )

    tracking_overlap = best_candidate['overlap']

    F = fidelity(

    psi_exact,

    psi_vqe
    )

    return {

        "E_exact": E_exact,

        "E_vqe": E_vqe,

        "psi_vqe": psi_vqe,

        "fidelity": F,

        "tracking_overlap": tracking_overlap,

        "optimal_point": optimal_point,

        "state_for_tracking": psi_vqe
    }

# %%
nq_site = 4

nqubits = 2 * nq_site

mu = 1.0

layers = 8

# ============================================================
# VQE settings
# ============================================================

n_restarts = 5

energy_tol = 1e-3

# ============================================================
# Parameter sets
# ============================================================

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },

    {
        "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-5
    },
    
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 0.5*1e-3
    },
    
    {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ============================================================
# Lambda scan
# ============================================================

lambda_list = np.linspace(0.1, 2.0, 10)

# ============================================================
# Storage
# ============================================================

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]

    mI2 = params["mI2"]

    f = params["f"]

    print("\n")
    print("#"*80)

    print(f"CASE: {label}")

    print(f"mI² = {mI2},  f = {f}")

    print("#"*80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None

    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "="*60)

        print(f"Running λ = {lam:.3f}")

        print("="*60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(

            nq=nq_site,

            mu=mu,

            mI2=mI2,

            lam=lam,

            f=f
        )

        # ====================================================
        # Run robust VQE
        # ====================================================

        vqe_data = run_robust_vqe(

            H_sparse=Hloc_sparse,

            nq=nqubits,

            layers=layers,

            n_restarts=n_restarts,

            energy_tol=energy_tol,

            previous_state=previous_state,

            previous_optimal_point=previous_optimal_point
        )

        # ====================================================
        # Extract outputs
        # ====================================================

        E_exact = vqe_data["E_exact"]

        E_vqe = vqe_data["E_vqe"]

        psi_vqe = vqe_data["psi_vqe"]

        F = vqe_data["fidelity"]

        tracking_overlap = vqe_data["tracking_overlap"]

        # ----------------------------------------------------
        # Update tracking
        # ----------------------------------------------------

        previous_state = vqe_data["state_for_tracking"]

        previous_optimal_point = (

            vqe_data["optimal_point"]
        )

        # ----------------------------------------------------
        # Store
        # ----------------------------------------------------

        data = {

            'case': label,

            'lambda': lam,

            'mI2': mI2,

            'f': f,

            'E_exact': E_exact,

            'E_vqe': E_vqe,

            'error': abs(E_exact - E_vqe),

            'fidelity': F,

            'tracking_overlap': tracking_overlap,

            'psi_vqe': psi_vqe
        }

        case_results.append(data)

        all_results.append(data)

        # ----------------------------------------------------
        # Print
        # ----------------------------------------------------

        print("\nFINAL SELECTED STATE")

        print(f"Exact energy     : {E_exact:.12f}")

        print(f"VQE energy       : {E_vqe:.12f}")

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(f"Fidelity         : {F:.12f}")

        print(
            f"Tracking overlap : "
            f"{tracking_overlap:.12f}"
        )

    # ========================================================
    # Case summary
    # ========================================================

    print("\n")

    print("="*110)

    print(f"SUMMARY : {label}")

    print("="*110)

    print(

        f"{'lambda':<12} "
        f"{'Exact E':<18} "
        f"{'VQE E':<18} "
        f"{'Error':<15} "
        f"{'Fidelity':<15} "
        f"{'TrackOverlap':<15}"
    )

    print("="*110)

    for r in case_results:

        print(

            f"{r['lambda']:<12.4f} "
            f"{r['E_exact']:<18.10f} "
            f"{r['E_vqe']:<18.10f} "
            f"{r['error']:<15.4e} "
            f"{r['fidelity']:<15.10f} "
            f"{r['tracking_overlap']:<15.10f}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161774181
# Energy error     : 4.602158e-08
# Fidelity         : 0.999999959402
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641637954
# Energy error     : 2.106073e-07
# Fidelity         : 0.999999935704
# Tracking overlap : 0.999849055056
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030499414258
# Energy error     : 1.044635e-07
# Fidelity         : 0.999999968931
# Tracking overlap : 0.999876005447
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041824429023
# Energy error     : 1.067618e-07
# Fidelity         : 0.999999974728
# Tracking overlap : 0.999896016286
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052684706800
# Energy error     : 1.630388e-07
# Fidelity         : 0.999999972577
# Tracking overlap : 0.999910655581
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063134042490
# Energy error     : 2.537197e-07
# Fidelity         : 0.999999967109
# Tracking overlap : 0.999922458863
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073215980770
# Energy error     : 3.269991e-07
# Fidelity         : 0.999999968030
# Tracking overlap : 0.999931850674
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082966761166
# Energy error     : 6.093506e-07
# Fidelity         : 0.999999941355
# Tracking overlap : 0.999939595555
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092416072465
# Energy error     : 5.643573e-07
# Fidelity         : 0.999999946746
# Tracking overlap : 0.999945822333
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101590040410
# Energy error     : 6.116675e-07
# Fidelity         : 0.999999946058
# Tracking overlap : 0.999951148351
#
#
# ==============================================================================================================
# SUMMARY : Symmetric
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       1.0061617282       1.0061617742       4.6022e-08      0.9999999594    1.0000000000
# 0.3111       1.0186414273       1.0186416380       2.1061e-07      0.9999999357    0.9998490551
# 0.5222       1.0304993098       1.0304994143       1.0446e-07      0.9999999689    0.9998760054
# 0.7333       1.0418243223       1.0418244290       1.0676e-07      0.9999999747    0.9998960163
# 0.9444       1.0526845438       1.0526847068       1.6304e-07      0.9999999726    0.9999106556
# 1.1556       1.0631337888       1.0631340425       2.5372e-07      0.9999999671    0.9999224589
# 1.3667       1.0732156538       1.0732159808       3.2700e-07      0.9999999680    0.9999318507
# 1.5778       1.0829661518       1.0829667612       6.0935e-07      0.9999999414    0.9999395956
# 1.7889       1.0924155081       1.0924160725       5.6436e-07      0.9999999467    0.9999458223
# 2.0000       1.1015894287       1.1015900404       6.1167e-07      0.9999999461    0.9999511484
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 1e-05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902169977
# VQE energy       : -16.943789064677
# Energy error     : 1.131053e-04
# Fidelity         : 0.999977196286
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -8.892068720847
# VQE energy       : -8.892067037207
# Energy error     : 1.683640e-06
# Fidelity         : 0.999999666942
# Tracking overlap : 0.875069537675
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.379113856397
# VQE energy       : -4.379110086734
# Energy error     : 3.769663e-06
# Fidelity         : 0.997533396427
# Tracking overlap : 0.049166062178
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.749793396636
# VQE energy       : -2.749793083352
# Energy error     : 3.132846e-07
# Fidelity         : 0.999933801207
# Tracking overlap : 0.000000000145
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.874700666195
# VQE energy       : -1.874700624394
# Energy error     : 4.180115e-08
# Fidelity         : 0.999998995957
# Tracking overlap : 0.821468022619
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.348821613293
# VQE energy       : -1.348821055353
# Energy error     : 5.579397e-07
# Fidelity         : 0.999999891699
# Tracking overlap : 0.894904487932
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.010439481239
# VQE energy       : -1.010438934566
# Energy error     : 5.466733e-07
# Fidelity         : 0.999999708109
# Tracking overlap : 0.936973980608
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.779139779365
# VQE energy       : -0.779065549733
# Energy error     : 7.422963e-05
# Fidelity         : 0.999977477793
# Tracking overlap : 0.962838389125
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723370121
# VQE energy       : -0.611718116665
# Energy error     : 5.253456e-06
# Fidelity         : 0.999999030580
# Tracking overlap : 0.977787018820
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295385847
# VQE energy       : -0.484294045228
# Energy error     : 1.340618e-06
# Fidelity         : 0.999999770966
# Tracking overlap : 0.986350839141
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -16.9439021700     -16.9437890647     1.1311e-04      0.9999771963    1.0000000000
# 0.3111       -8.8920687208      -8.8920670372      1.6836e-06      0.9999996669    0.8750695377
# 0.5222       -4.3791138564      -4.3791100867      3.7697e-06      0.9975333964    0.0491660622
# 0.7333       -2.7497933966      -2.7497930834      3.1328e-07      0.9999338012    0.0000000001
# 0.9444       -1.8747006662      -1.8747006244      4.1801e-08      0.9999989960    0.8214680226
# 1.1556       -1.3488216133      -1.3488210554      5.5794e-07      0.9999998917    0.8949044879
# 1.3667       -1.0104394812      -1.0104389346      5.4667e-07      0.9999997081    0.9369739806
# 1.5778       -0.7791397794      -0.7790655497      7.4230e-05      0.9999774778    0.9628383891
# 1.7889       -0.6117233701      -0.6117181167      5.2535e-06      0.9999990306    0.9777870188
# 2.0000       -0.4842953858      -0.4842940452      1.3406e-06      0.9999997710    0.9863508391
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.0005
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -16.943915170806
# VQE energy       : -16.943598633846
# Energy error     : 3.165370e-04
# Fidelity         : 0.999930794160
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -8.892092389605
# VQE energy       : -8.891818359604
# Energy error     : 2.740300e-04
# Fidelity         : 0.999930642916
# Tracking overlap : 0.875929339820
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.381595164259
# VQE energy       : -4.379213614703
# Energy error     : 2.381550e-03
# Fidelity         : 0.436451303584
# Tracking overlap : 0.048960116461
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.750561457486
# VQE energy       : -2.750006716308
# Energy error     : 5.547412e-04
# Fidelity         : 0.917012912790
# Tracking overlap : 0.000067865916
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.874832119175
# VQE energy       : -1.874782310142
# Energy error     : 4.980903e-05
# Fidelity         : 0.998257206625
# Tracking overlap : 0.815542630820
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.348861328254
# VQE energy       : -1.348854260424
# Energy error     : 7.067829e-06
# Fidelity         : 0.999944151907
# Tracking overlap : 0.893708317430
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.010456716759
# VQE energy       : -1.010451292414
# Energy error     : 5.424345e-06
# Fidelity         : 0.999989496295
# Tracking overlap : 0.936847748155
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.779149121511
# VQE energy       : -0.779114294946
# Energy error     : 3.482656e-05
# Fidelity         : 0.999990492656
# Tracking overlap : 0.962848038358
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.611729230034
# VQE energy       : -0.611724727257
# Energy error     : 4.502777e-06
# Fidelity         : 0.999998459939
# Tracking overlap : 0.977752238311
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.484299448212
# VQE energy       : -0.484297720909
# Energy error     : 1.727304e-06
# Fidelity         : 0.999999497133
# Tracking overlap : 0.986401271482
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB optimised
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -16.9439151708     -16.9435986338     3.1654e-04      0.9999307942    1.0000000000
# 0.3111       -8.8920923896      -8.8918183596      2.7403e-04      0.9999306429    0.8759293398
# 0.5222       -4.3815951643      -4.3792136147      2.3815e-03      0.4364513036    0.0489601165
# 0.7333       -2.7505614575      -2.7500067163      5.5474e-04      0.9170129128    0.0000678659
# 0.9444       -1.8748321192      -1.8747823101      4.9809e-05      0.9982572066    0.8155426308
# 1.1556       -1.3488613283      -1.3488542604      7.0678e-06      0.9999441519    0.8937083174
# 1.3667       -1.0104567168      -1.0104512924      5.4243e-06      0.9999894963    0.9368477482
# 1.5778       -0.7791491215      -0.7791142949      3.4827e-05      0.9999904927    0.9628480384
# 1.7889       -0.6117292300      -0.6117247273      4.5028e-06      0.9999984599    0.9777522383
# 2.0000       -0.4842994482      -0.4842977209      1.7273e-06      0.9999994971    0.9864012715
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.776923461041
# Energy error     : 4.049842e-04
# Fidelity         : 0.999962332998
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.836382165004
# Energy error     : 5.897784e-05
# Fidelity         : 0.999991421736
# Tracking overlap : 0.848788606968
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.729853211558
# Energy error     : 8.631533e-04
# Fidelity         : 0.999892334256
# Tracking overlap : 0.167078895646
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.538019692715
# Energy error     : 1.291380e-04
# Fidelity         : 0.999988427109
# Tracking overlap : 0.634562550175
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.276010010474
# Energy error     : 3.782455e-06
# Fidelity         : 0.999999517110
# Tracking overlap : 0.822430347747
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.447814489261
# Energy error     : 8.658962e-04
# Fidelity         : 0.999880158010
# Tracking overlap : 0.905374708780
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.860396019446
# Energy error     : 4.362457e-04
# Fidelity         : 0.999939879749
# Tracking overlap : 0.941761950517
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529279
# VQE energy       : -2.420025426597
# Energy error     : 6.510268e-05
# Fidelity         : 0.999995085245
# Tracking overlap : 0.961700392224
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.076277883979
# Energy error     : 3.468364e-05
# Fidelity         : 0.999997572010
# Tracking overlap : 0.973887974805
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.800054784502
# Energy error     : 1.848171e-05
# Fidelity         : 0.999998536945
# Tracking overlap : 0.981206780804
#
#
# ==============================================================================================================
# SUMMARY : Strong SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -20.7773284453     -20.7769234610     4.0498e-04      0.9999623330    1.0000000000
# 0.3111       -12.8364411428     -12.8363821650     5.8978e-05      0.9999914217    0.8487886070
# 0.5222       -7.7307163648      -7.7298532116      8.6315e-04      0.9998923343    0.1670788956
# 0.7333       -5.5381488307      -5.5380196927      1.2914e-04      0.9999884271    0.6345625502
# 0.9444       -4.2760137929      -4.2760100105      3.7825e-06      0.9999995171    0.8224303477
# 1.1556       -3.4486803854      -3.4478144893      8.6590e-04      0.9998801580    0.9053747088
# 1.3667       -2.8608322652      -2.8603960194      4.3625e-04      0.9999398797    0.9417619505
# 1.5778       -2.4200905293      -2.4200254266      6.5103e-05      0.9999950852    0.9617003922
# 1.7889       -2.0763125676      -2.0762778840      3.4684e-05      0.9999975720    0.9738879748
# 2.0000       -1.8000732662      -1.8000547845      1.8482e-05      0.9999985369    0.9812067808

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HEA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98117821
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98266342
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394153
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98503916
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98600262
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98685816
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762220
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98831250
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893478
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98950488
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.13498607e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063399
# T = 10    Fidelity = 0.00011472
# T = 20    Fidelity = 0.00404086
# T = 30    Fidelity = 0.05560321
# T = 40    Fidelity = 0.12217196
# T = 50    Fidelity = 0.21126756
# T = 75    Fidelity = 0.58073989
# T = 100   Fidelity = 0.76483238
# T = 125   Fidelity = 0.73558591
# T = 150   Fidelity = 0.86996143
# T = 175   Fidelity = 0.91384273
# T = 200   Fidelity = 0.87506776
# T = 225   Fidelity = 0.95271046
# T = 250   Fidelity = 0.98657160
#
# Minimum T for Fidelity >= 0.97 : 250
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.22564919e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000006
# T = 5     Fidelity = 0.00018121
# T = 10    Fidelity = 0.04088399
# T = 20    Fidelity = 0.42106245
# T = 30    Fidelity = 0.49014614
# T = 40    Fidelity = 0.64150821
# T = 50    Fidelity = 0.64405028
# T = 75    Fidelity = 0.88100586
# T = 100   Fidelity = 0.90196403
# T = 125   Fidelity = 0.87188183
# T = 150   Fidelity = 0.88628777
# T = 175   Fidelity = 0.92112065
# T = 200   Fidelity = 0.94263892
# T = 225   Fidelity = 0.95691614
# T = 250   Fidelity = 0.95092842
# T = 275   Fidelity = 0.96232692
# T = 300   Fidelity = 0.94453158
# T = 400   Fidelity = 0.98187039
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.14483174e-04
# T = 1     Fidelity = 0.00001182
# T = 2     Fidelity = 0.00016889
# T = 5     Fidelity = 0.01433356
# T = 10    Fidelity = 0.17121809
# T = 20    Fidelity = 0.44273245
# T = 30    Fidelity = 0.34005180
# T = 40    Fidelity = 0.54718222
# T = 50    Fidelity = 0.43878274
# T = 75    Fidelity = 0.49359794
# T = 100   Fidelity = 0.50316618
# T = 125   Fidelity = 0.50308417
# T = 150   Fidelity = 0.50221845
# T = 175   Fidelity = 0.50142858
# T = 200   Fidelity = 0.49698532
# T = 225   Fidelity = 0.50876196
# T = 250   Fidelity = 0.50137118
# T = 275   Fidelity = 0.48750263
# T = 300   Fidelity = 0.48758357
# T = 400   Fidelity = 0.49867308
# T = 500   Fidelity = 0.30952804
# T = 600   Fidelity = 0.51095233
# T = 700   Fidelity = 0.39126896
# T = 800   Fidelity = 0.53873734
# T = 900   Fidelity = 0.53605987
# T = 1000  Fidelity = 0.70833251
# T = 1010  Fidelity = 0.40404055
# T = 1020  Fidelity = 0.40789717
# T = 1030  Fidelity = 0.47794416
# T = 1040  Fidelity = 0.50606102
# T = 1050  Fidelity = 0.47575855
# T = 1060  Fidelity = 0.37540597
# T = 1070  Fidelity = 0.57019053
# T = 1080  Fidelity = 0.27356397
# T = 1090  Fidelity = 0.28167888
# T = 1100  Fidelity = 0.62084730
# T = 1200  Fidelity = 0.29941045
# T = 1300  Fidelity = 0.56649436
# T = 1400  Fidelity = 0.55232855
# T = 1500  Fidelity = 0.37842271
# T = 2000  Fidelity = 0.31509518
# T = 2100  Fidelity = 0.22279241
# T = 2110  Fidelity = 0.58892433
# T = 2120  Fidelity = 0.50697218
# T = 2130  Fidelity = 0.53894848
# T = 2140  Fidelity = 0.35495972
# T = 2150  Fidelity = 0.48219081
# T = 2160  Fidelity = 0.42021960
# T = 2170  Fidelity = 0.42325166
# T = 2180  Fidelity = 0.57071090
# T = 2190  Fidelity = 0.21669238
# T = 2200  Fidelity = 0.51744315
# T = 2300  Fidelity = 0.57559966
# T = 2400  Fidelity = 0.53680052
# T = 2500  Fidelity = 0.50403070
# T = 2600  Fidelity = 0.51048504
# T = 2700  Fidelity = 0.63550623
# T = 2800  Fidelity = 0.66484880
# T = 2900  Fidelity = 0.52318505
# T = 3000  Fidelity = 0.49550490
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.49550490
# P1     = 0.00064665
# P0+P1  = 0.49615155
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.21982966e-04
# T = 1     Fidelity = 0.00307206
# T = 2     Fidelity = 0.01239181
# T = 5     Fidelity = 0.08439706
# T = 10    Fidelity = 0.22347880
# T = 20    Fidelity = 0.31776791
# T = 30    Fidelity = 0.38306924
# T = 40    Fidelity = 0.54977363
# T = 50    Fidelity = 0.58075934
# T = 75    Fidelity = 0.50038567
# T = 100   Fidelity = 0.52178364
# T = 125   Fidelity = 0.52337651
# T = 150   Fidelity = 0.52320539
# T = 175   Fidelity = 0.52001054
# T = 200   Fidelity = 0.53035013
# T = 225   Fidelity = 0.52293699
# T = 250   Fidelity = 0.51831847
# T = 275   Fidelity = 0.52662062
# T = 300   Fidelity = 0.49518186
# T = 400   Fidelity = 0.51004171
# T = 500   Fidelity = 0.55445509
# T = 600   Fidelity = 0.50913849
# T = 700   Fidelity = 0.44381170
# T = 800   Fidelity = 0.45443783
# T = 900   Fidelity = 0.53557857
# T = 1000  Fidelity = 0.78107766
# T = 1010  Fidelity = 0.44827016
# T = 1020  Fidelity = 0.12726900
# T = 1030  Fidelity = 0.56288010
# T = 1040  Fidelity = 0.79509456
# T = 1050  Fidelity = 0.59786487
# T = 1060  Fidelity = 0.48945445
# T = 1070  Fidelity = 0.50197106
# T = 1080  Fidelity = 0.42478179
# T = 1090  Fidelity = 0.25694680
# T = 1100  Fidelity = 0.74486705
# T = 1200  Fidelity = 0.58973010
# T = 1300  Fidelity = 0.45970096
# T = 1400  Fidelity = 0.52937995
# T = 1500  Fidelity = 0.54443054
# T = 2000  Fidelity = 0.46786100
# T = 2100  Fidelity = 0.53038121
# T = 2110  Fidelity = 0.56806987
# T = 2120  Fidelity = 0.48124038
# T = 2130  Fidelity = 0.40456366
# T = 2140  Fidelity = 0.57397067
# T = 2150  Fidelity = 0.78517007
# T = 2160  Fidelity = 0.45190421
# T = 2170  Fidelity = 0.25308288
# T = 2180  Fidelity = 0.50751618
# T = 2190  Fidelity = 0.70346006
# T = 2200  Fidelity = 0.63130393
# T = 2300  Fidelity = 0.83236581
# T = 2400  Fidelity = 0.55105011
# T = 2500  Fidelity = 0.52131579
# T = 2600  Fidelity = 0.57275112
# T = 2700  Fidelity = 0.46746313
# T = 2800  Fidelity = 0.55979064
# T = 2900  Fidelity = 0.32446305
# T = 3000  Fidelity = 0.46073957
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.46073957
# P1     = 0.00024838
# P0+P1  = 0.46098795
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.33063144e-03
# T = 1     Fidelity = 0.02405100
# T = 2     Fidelity = 0.06515060
# T = 5     Fidelity = 0.21903483
# T = 10    Fidelity = 0.40682389
# T = 20    Fidelity = 0.52935095
# T = 30    Fidelity = 0.49787329
# T = 40    Fidelity = 0.50387916
# T = 50    Fidelity = 0.54928928
# T = 75    Fidelity = 0.60866492
# T = 100   Fidelity = 0.60707898
# T = 125   Fidelity = 0.61208877
# T = 150   Fidelity = 0.61606714
# T = 175   Fidelity = 0.61942458
# T = 200   Fidelity = 0.62646524
# T = 225   Fidelity = 0.62930939
# T = 250   Fidelity = 0.63308078
# T = 275   Fidelity = 0.62996736
# T = 300   Fidelity = 0.64621128
# T = 400   Fidelity = 0.59413335
# T = 500   Fidelity = 0.65374385
# T = 600   Fidelity = 0.67757586
# T = 700   Fidelity = 0.59512538
# T = 800   Fidelity = 0.71410835
# T = 900   Fidelity = 0.60951427
# T = 1000  Fidelity = 0.48797241
# T = 1010  Fidelity = 0.76101382
# T = 1020  Fidelity = 0.85265429
# T = 1030  Fidelity = 0.75201611
# T = 1040  Fidelity = 0.53080869
# T = 1050  Fidelity = 0.47569843
# T = 1060  Fidelity = 0.65096563
# T = 1070  Fidelity = 0.77848854
# T = 1080  Fidelity = 0.82290082
# T = 1090  Fidelity = 0.55787086
# T = 1100  Fidelity = 0.40190866
# T = 1200  Fidelity = 0.46098573
# T = 1300  Fidelity = 0.54242425
# T = 1400  Fidelity = 0.77144968
# T = 1500  Fidelity = 0.68257619
# T = 2000  Fidelity = 0.77617469
# T = 2100  Fidelity = 0.82189338
# T = 2110  Fidelity = 0.81252114
# T = 2120  Fidelity = 0.55444976
# T = 2130  Fidelity = 0.65793032
# T = 2140  Fidelity = 0.71477646
# T = 2150  Fidelity = 0.83412349
# T = 2160  Fidelity = 0.84963370
# T = 2170  Fidelity = 0.78544525
# T = 2180  Fidelity = 0.53548184
# T = 2190  Fidelity = 0.57231686
# T = 2200  Fidelity = 0.70209754
# T = 2300  Fidelity = 0.77092030
# T = 2400  Fidelity = 0.75746782
# T = 2500  Fidelity = 0.83047814
# T = 2600  Fidelity = 0.73448574
# T = 2700  Fidelity = 0.78131803
# T = 2800  Fidelity = 0.76630345
# T = 2900  Fidelity = 0.70212261
# T = 3000  Fidelity = 0.75464884
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.75464884
# P1     = 0.00005143
# P0+P1  = 0.75470027
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50115281e-02
# T = 1     Fidelity = 0.08268107
# T = 2     Fidelity = 0.17485025
# T = 5     Fidelity = 0.39229086
# T = 10    Fidelity = 0.58588598
# T = 20    Fidelity = 0.71386521
# T = 30    Fidelity = 0.72026130
# T = 40    Fidelity = 0.71302416
# T = 50    Fidelity = 0.71875768
# T = 75    Fidelity = 0.74412394
# T = 100   Fidelity = 0.76245469
# T = 125   Fidelity = 0.77527233
# T = 150   Fidelity = 0.78586850
# T = 175   Fidelity = 0.79500343
# T = 200   Fidelity = 0.80419482
# T = 225   Fidelity = 0.81045443
# T = 250   Fidelity = 0.81598886
# T = 275   Fidelity = 0.82617510
# T = 300   Fidelity = 0.81746768
# T = 400   Fidelity = 0.87422646
# T = 500   Fidelity = 0.87061501
# T = 600   Fidelity = 0.79408449
# T = 700   Fidelity = 0.82785028
# T = 800   Fidelity = 0.84472172
# T = 900   Fidelity = 0.85228909
# T = 1000  Fidelity = 0.87685961
# T = 1010  Fidelity = 0.79392245
# T = 1020  Fidelity = 0.77900515
# T = 1030  Fidelity = 0.86814670
# T = 1040  Fidelity = 0.95157982
# T = 1050  Fidelity = 0.97309743
#
# Minimum T for Fidelity >= 0.97 : 1050
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77198754e-02
# T = 1     Fidelity = 0.17552841
# T = 2     Fidelity = 0.31612330
# T = 5     Fidelity = 0.55526542
# T = 10    Fidelity = 0.72493521
# T = 20    Fidelity = 0.82950063
# T = 30    Fidelity = 0.85313725
# T = 40    Fidelity = 0.85899842
# T = 50    Fidelity = 0.86468665
# T = 75    Fidelity = 0.88210512
# T = 100   Fidelity = 0.89840374
# T = 125   Fidelity = 0.90980674
# T = 150   Fidelity = 0.91811847
# T = 175   Fidelity = 0.92575591
# T = 200   Fidelity = 0.93483154
# T = 225   Fidelity = 0.93591264
# T = 250   Fidelity = 0.93618731
# T = 275   Fidelity = 0.94546547
# T = 300   Fidelity = 0.93550140
# T = 400   Fidelity = 0.94951840
# T = 500   Fidelity = 0.95253403
# T = 600   Fidelity = 0.96024689
# T = 700   Fidelity = 0.91551119
# T = 800   Fidelity = 0.92796984
# T = 900   Fidelity = 0.94694996
# T = 1000  Fidelity = 0.93970676
# T = 1010  Fidelity = 0.95196665
# T = 1020  Fidelity = 0.95695511
# T = 1030  Fidelity = 0.97883708
#
# Minimum T for Fidelity >= 0.97 : 1030
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20186803e-01
# T = 1     Fidelity = 0.28049994
# T = 2     Fidelity = 0.45345321
# T = 5     Fidelity = 0.68244006
# T = 10    Fidelity = 0.82018688
# T = 20    Fidelity = 0.89724526
# T = 30    Fidelity = 0.91846124
# T = 40    Fidelity = 0.92969391
# T = 50    Fidelity = 0.93829931
# T = 75    Fidelity = 0.95190513
# T = 100   Fidelity = 0.96213142
# T = 125   Fidelity = 0.96849878
# T = 150   Fidelity = 0.97434884
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405410e-01
# T = 1     Fidelity = 0.37877647
# T = 2     Fidelity = 0.56658817
# T = 5     Fidelity = 0.77020120
# T = 10    Fidelity = 0.87917782
# T = 20    Fidelity = 0.93535236
# T = 30    Fidelity = 0.95283972
# T = 40    Fidelity = 0.96404669
# T = 50    Fidelity = 0.96972399
# T = 75    Fidelity = 0.97963148
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843285e-01
# T = 1     Fidelity = 0.46391022
# T = 2     Fidelity = 0.65548534
# T = 5     Fidelity = 0.83094304
# T = 10    Fidelity = 0.91703024
# T = 20    Fidelity = 0.95850726
# T = 30    Fidelity = 0.97283860
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.12114884e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00064044
# T = 10    Fidelity = 0.00011660
# T = 20    Fidelity = 0.00396689
# T = 30    Fidelity = 0.05546933
# T = 40    Fidelity = 0.12186638
# T = 50    Fidelity = 0.20984127
# T = 75    Fidelity = 0.57338387
# T = 100   Fidelity = 0.75174656
# T = 125   Fidelity = 0.71710605
# T = 150   Fidelity = 0.84328016
# T = 175   Fidelity = 0.88210982
# T = 200   Fidelity = 0.83726682
# T = 225   Fidelity = 0.90445922
# T = 250   Fidelity = 0.93180310
# T = 275   Fidelity = 0.92519798
# T = 300   Fidelity = 0.80149822
# T = 400   Fidelity = 0.82462281
# T = 500   Fidelity = 0.81022222
# T = 600   Fidelity = 0.77414722
# T = 700   Fidelity = 0.75189002
# T = 800   Fidelity = 0.64753956
# T = 900   Fidelity = 0.59869104
# T = 1000  Fidelity = 0.49884610
# T = 1010  Fidelity = 0.40680346
# T = 1020  Fidelity = 0.42256754
# T = 1030  Fidelity = 0.54145923
# T = 1040  Fidelity = 0.65537772
# T = 1050  Fidelity = 0.61609601
# T = 1060  Fidelity = 0.59268290
# T = 1070  Fidelity = 0.49008301
# T = 1080  Fidelity = 0.34946389
# T = 1090  Fidelity = 0.33020482
# T = 1100  Fidelity = 0.35594677
# T = 1200  Fidelity = 0.41704371
# T = 1300  Fidelity = 0.39622833
# T = 1400  Fidelity = 0.39469102
# T = 1500  Fidelity = 0.15356480
# T = 2000  Fidelity = 0.02154305
# T = 2100  Fidelity = 0.46806446
# T = 2110  Fidelity = 0.40540493
# T = 2120  Fidelity = 0.46943970
# T = 2130  Fidelity = 0.48349307
# T = 2140  Fidelity = 0.47537598
# T = 2150  Fidelity = 0.50072775
# T = 2160  Fidelity = 0.47792068
# T = 2170  Fidelity = 0.42677367
# T = 2180  Fidelity = 0.35366676
# T = 2190  Fidelity = 0.12571924
# T = 2200  Fidelity = 0.09630987
# T = 2300  Fidelity = 0.24516569
# T = 2400  Fidelity = 0.40691304
# T = 2500  Fidelity = 0.40621033
# T = 2600  Fidelity = 0.39441569
# T = 2700  Fidelity = 0.32155310
# T = 2800  Fidelity = 0.20642450
# T = 2900  Fidelity = 0.41791638
# T = 3000  Fidelity = 0.30707898
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00970922e+00
# P0     = 0.30707898
# P1     = 0.44411717
# P0+P1  = 0.75119615
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.23925085e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00018202
# T = 10    Fidelity = 0.04088226
# T = 20    Fidelity = 0.42035834
# T = 30    Fidelity = 0.49001370
# T = 40    Fidelity = 0.64001498
# T = 50    Fidelity = 0.64216069
# T = 75    Fidelity = 0.87443659
# T = 100   Fidelity = 0.88996957
# T = 125   Fidelity = 0.85346688
# T = 150   Fidelity = 0.85941518
# T = 175   Fidelity = 0.88374069
# T = 200   Fidelity = 0.89345282
# T = 225   Fidelity = 0.89467173
# T = 250   Fidelity = 0.87575808
# T = 275   Fidelity = 0.87207688
# T = 300   Fidelity = 0.84058171
# T = 400   Fidelity = 0.80487813
# T = 500   Fidelity = 0.71611551
# T = 600   Fidelity = 0.62417788
# T = 700   Fidelity = 0.32013916
# T = 800   Fidelity = 0.31863905
# T = 900   Fidelity = 0.30864540
# T = 1000  Fidelity = 0.32707815
# T = 1010  Fidelity = 0.16332015
# T = 1020  Fidelity = 0.28195256
# T = 1030  Fidelity = 0.26308048
# T = 1040  Fidelity = 0.20714467
# T = 1050  Fidelity = 0.26869375
# T = 1060  Fidelity = 0.13929751
# T = 1070  Fidelity = 0.25143221
# T = 1080  Fidelity = 0.14819352
# T = 1090  Fidelity = 0.25173571
# T = 1100  Fidelity = 0.17049808
# T = 1200  Fidelity = 0.12556372
# T = 1300  Fidelity = 0.09747384
# T = 1400  Fidelity = 0.09456540
# T = 1500  Fidelity = 0.06973896
# T = 2000  Fidelity = 0.20247649
# T = 2100  Fidelity = 0.16361318
# T = 2110  Fidelity = 0.21278979
# T = 2120  Fidelity = 0.21269165
# T = 2130  Fidelity = 0.18040948
# T = 2140  Fidelity = 0.20991918
# T = 2150  Fidelity = 0.21832524
# T = 2160  Fidelity = 0.17763785
# T = 2170  Fidelity = 0.22379486
# T = 2180  Fidelity = 0.17316059
# T = 2190  Fidelity = 0.22461533
# T = 2200  Fidelity = 0.12249962
# T = 2300  Fidelity = 0.25292857
# T = 2400  Fidelity = 0.27619243
# T = 2500  Fidelity = 0.34078677
# T = 2600  Fidelity = 0.14472534
# T = 2700  Fidelity = 0.48849709
# T = 2800  Fidelity = 0.36965574
# T = 2900  Fidelity = 0.46211376
# T = 3000  Fidelity = 0.67055963
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02931059e+00
# P0     = 0.67055963
# P1     = 0.23315142
# P0+P1  = 0.90371104
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.32159854e-03
# T = 1     Fidelity = 0.00001192
# T = 2     Fidelity = 0.00016847
# T = 5     Fidelity = 0.01430943
# T = 10    Fidelity = 0.17094456
# T = 20    Fidelity = 0.44220075
# T = 30    Fidelity = 0.33990445
# T = 40    Fidelity = 0.54614647
# T = 50    Fidelity = 0.43790832
# T = 75    Fidelity = 0.49159493
# T = 100   Fidelity = 0.49981327
# T = 125   Fidelity = 0.49805450
# T = 150   Fidelity = 0.49518390
# T = 175   Fidelity = 0.49204728
# T = 200   Fidelity = 0.48507710
# T = 225   Fidelity = 0.49354849
# T = 250   Fidelity = 0.48290306
# T = 275   Fidelity = 0.46603778
# T = 300   Fidelity = 0.46232457
# T = 400   Fidelity = 0.45500905
# T = 500   Fidelity = 0.26071020
# T = 600   Fidelity = 0.42365058
# T = 700   Fidelity = 0.29768637
# T = 800   Fidelity = 0.38608669
# T = 900   Fidelity = 0.35725763
# T = 1000  Fidelity = 0.49097676
# T = 1010  Fidelity = 0.21456106
# T = 1020  Fidelity = 0.25194202
# T = 1030  Fidelity = 0.26687185
# T = 1040  Fidelity = 0.29059245
# T = 1050  Fidelity = 0.25299119
# T = 1060  Fidelity = 0.21823412
# T = 1070  Fidelity = 0.32608415
# T = 1080  Fidelity = 0.12604136
# T = 1090  Fidelity = 0.15700285
# T = 1100  Fidelity = 0.36003462
# T = 1200  Fidelity = 0.13209773
# T = 1300  Fidelity = 0.24894963
# T = 1400  Fidelity = 0.20391638
# T = 1500  Fidelity = 0.08848475
# T = 2000  Fidelity = 0.00879968
# T = 2100  Fidelity = 0.05851476
# T = 2110  Fidelity = 0.07616664
# T = 2120  Fidelity = 0.06255062
# T = 2130  Fidelity = 0.03175435
# T = 2140  Fidelity = 0.02235209
# T = 2150  Fidelity = 0.03180910
# T = 2160  Fidelity = 0.02668466
# T = 2170  Fidelity = 0.06239448
# T = 2180  Fidelity = 0.03072051
# T = 2190  Fidelity = 0.03578212
# T = 2200  Fidelity = 0.11726004
# T = 2300  Fidelity = 0.03195482
# T = 2400  Fidelity = 0.01306895
# T = 2500  Fidelity = 0.05296098
# T = 2600  Fidelity = 0.08044495
# T = 2700  Fidelity = 0.02333305
# T = 2800  Fidelity = 0.09398866
# T = 2900  Fidelity = 0.07560457
# T = 3000  Fidelity = 0.09745930
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785500e+00
# P0     = 0.09745930
# P1     = 0.30387754
# P0+P1  = 0.40133683
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 4.75754041e-03
# T = 1     Fidelity = 0.00301281
# T = 2     Fidelity = 0.01214011
# T = 5     Fidelity = 0.08288190
# T = 10    Fidelity = 0.21998690
# T = 20    Fidelity = 0.31432003
# T = 30    Fidelity = 0.37917666
# T = 40    Fidelity = 0.54260082
# T = 50    Fidelity = 0.57263278
# T = 75    Fidelity = 0.49418572
# T = 100   Fidelity = 0.51469842
# T = 125   Fidelity = 0.51600959
# T = 150   Fidelity = 0.51533461
# T = 175   Fidelity = 0.51158582
# T = 200   Fidelity = 0.52093166
# T = 225   Fidelity = 0.51276175
# T = 250   Fidelity = 0.50719891
# T = 275   Fidelity = 0.51434892
# T = 300   Fidelity = 0.48258183
# T = 400   Fidelity = 0.48969776
# T = 500   Fidelity = 0.52505627
# T = 600   Fidelity = 0.48126559
# T = 700   Fidelity = 0.40219735
# T = 800   Fidelity = 0.39958776
# T = 900   Fidelity = 0.50717833
# T = 1000  Fidelity = 0.66811260
# T = 1010  Fidelity = 0.34953544
# T = 1020  Fidelity = 0.09981768
# T = 1030  Fidelity = 0.52732607
# T = 1040  Fidelity = 0.69747388
# T = 1050  Fidelity = 0.48344672
# T = 1060  Fidelity = 0.40549162
# T = 1070  Fidelity = 0.40800972
# T = 1080  Fidelity = 0.33301293
# T = 1090  Fidelity = 0.22908724
# T = 1100  Fidelity = 0.67266500
# T = 1200  Fidelity = 0.46507969
# T = 1300  Fidelity = 0.34878381
# T = 1400  Fidelity = 0.39541347
# T = 1500  Fidelity = 0.40884887
# T = 2000  Fidelity = 0.31383947
# T = 2100  Fidelity = 0.27255727
# T = 2110  Fidelity = 0.31737829
# T = 2120  Fidelity = 0.25623647
# T = 2130  Fidelity = 0.23017582
# T = 2140  Fidelity = 0.39811654
# T = 2150  Fidelity = 0.45708979
# T = 2160  Fidelity = 0.18232208
# T = 2170  Fidelity = 0.12009723
# T = 2180  Fidelity = 0.35281056
# T = 2190  Fidelity = 0.45309434
# T = 2200  Fidelity = 0.31391221
# T = 2300  Fidelity = 0.56022465
# T = 2400  Fidelity = 0.22270569
# T = 2500  Fidelity = 0.19984126
# T = 2600  Fidelity = 0.26172548
# T = 2700  Fidelity = 0.15738265
# T = 2800  Fidelity = 0.21280374
# T = 2900  Fidelity = 0.06401653
# T = 3000  Fidelity = 0.18844648
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549315e+00
# P0     = 0.18844648
# P1     = 0.32250242
# P0+P1  = 0.51094889
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.08544988e-03
# T = 1     Fidelity = 0.02395146
# T = 2     Fidelity = 0.06488896
# T = 5     Fidelity = 0.21830609
# T = 10    Fidelity = 0.40566975
# T = 20    Fidelity = 0.52821179
# T = 30    Fidelity = 0.49708572
# T = 40    Fidelity = 0.50319031
# T = 50    Fidelity = 0.54851073
# T = 75    Fidelity = 0.60763159
# T = 100   Fidelity = 0.60595978
# T = 125   Fidelity = 0.61082394
# T = 150   Fidelity = 0.61459028
# T = 175   Fidelity = 0.61767625
# T = 200   Fidelity = 0.62440227
# T = 225   Fidelity = 0.62689145
# T = 250   Fidelity = 0.63031249
# T = 275   Fidelity = 0.62683016
# T = 300   Fidelity = 0.64225272
# T = 400   Fidelity = 0.58883180
# T = 500   Fidelity = 0.64636939
# T = 600   Fidelity = 0.66693872
# T = 700   Fidelity = 0.58410045
# T = 800   Fidelity = 0.69971082
# T = 900   Fidelity = 0.58705600
# T = 1000  Fidelity = 0.47050229
# T = 1010  Fidelity = 0.74172436
# T = 1020  Fidelity = 0.82475830
# T = 1030  Fidelity = 0.71718585
# T = 1040  Fidelity = 0.50395294
# T = 1050  Fidelity = 0.45467366
# T = 1060  Fidelity = 0.63400008
# T = 1070  Fidelity = 0.75076860
# T = 1080  Fidelity = 0.78873382
# T = 1090  Fidelity = 0.52419980
# T = 1100  Fidelity = 0.37752821
# T = 1200  Fidelity = 0.44219718
# T = 1300  Fidelity = 0.51404192
# T = 1400  Fidelity = 0.72550884
# T = 1500  Fidelity = 0.63724377
# T = 2000  Fidelity = 0.70949373
# T = 2100  Fidelity = 0.75836493
# T = 2110  Fidelity = 0.72905055
# T = 2120  Fidelity = 0.48614431
# T = 2130  Fidelity = 0.60306828
# T = 2140  Fidelity = 0.66099063
# T = 2150  Fidelity = 0.77099490
# T = 2160  Fidelity = 0.77502505
# T = 2170  Fidelity = 0.69235703
# T = 2180  Fidelity = 0.46731962
# T = 2190  Fidelity = 0.52204878
# T = 2200  Fidelity = 0.65114440
# T = 2300  Fidelity = 0.67179487
# T = 2400  Fidelity = 0.67515616
# T = 2500  Fidelity = 0.73702418
# T = 2600  Fidelity = 0.64222494
# T = 2700  Fidelity = 0.70088186
# T = 2800  Fidelity = 0.65683871
# T = 2900  Fidelity = 0.60527508
# T = 3000  Fidelity = 0.66693362
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234171e+00
# P0     = 0.66693362
# P1     = 0.09927727
# P0+P1  = 0.76621089
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.52576626e-02
# T = 1     Fidelity = 0.08266665
# T = 2     Fidelity = 0.17482162
# T = 5     Fidelity = 0.39223038
# T = 10    Fidelity = 0.58579464
# T = 20    Fidelity = 0.71373567
# T = 30    Fidelity = 0.72013934
# T = 40    Fidelity = 0.71292242
# T = 50    Fidelity = 0.71866469
# T = 75    Fidelity = 0.74401517
# T = 100   Fidelity = 0.76230180
# T = 125   Fidelity = 0.77505950
# T = 150   Fidelity = 0.78558286
# T = 175   Fidelity = 0.79463538
# T = 200   Fidelity = 0.80372492
# T = 225   Fidelity = 0.80989817
# T = 250   Fidelity = 0.81532744
# T = 275   Fidelity = 0.82539396
# T = 300   Fidelity = 0.81669460
# T = 400   Fidelity = 0.87294777
# T = 500   Fidelity = 0.86892975
# T = 600   Fidelity = 0.79231811
# T = 700   Fidelity = 0.82568821
# T = 800   Fidelity = 0.84285194
# T = 900   Fidelity = 0.85016220
# T = 1000  Fidelity = 0.87329335
# T = 1010  Fidelity = 0.79035570
# T = 1020  Fidelity = 0.77713013
# T = 1030  Fidelity = 0.86616378
# T = 1040  Fidelity = 0.94935029
# T = 1050  Fidelity = 0.96934132
# T = 1060  Fidelity = 0.93062038
# T = 1070  Fidelity = 0.82523971
# T = 1080  Fidelity = 0.83828557
# T = 1090  Fidelity = 0.76606601
# T = 1100  Fidelity = 0.82540588
# T = 1200  Fidelity = 0.79420389
# T = 1300  Fidelity = 0.95252264
# T = 1400  Fidelity = 0.85152539
# T = 1500  Fidelity = 0.92580856
# T = 2000  Fidelity = 0.85755893
# T = 2100  Fidelity = 0.86572568
# T = 2110  Fidelity = 0.86477527
# T = 2120  Fidelity = 0.91907035
# T = 2130  Fidelity = 0.86043641
# T = 2140  Fidelity = 0.87792134
# T = 2150  Fidelity = 0.80604957
# T = 2160  Fidelity = 0.83642935
# T = 2170  Fidelity = 0.95319440
# T = 2180  Fidelity = 0.93536728
# T = 2190  Fidelity = 0.93456996
# T = 2200  Fidelity = 0.93810507
# T = 2300  Fidelity = 0.94775464
# T = 2400  Fidelity = 0.97126298
#
# Minimum T for Fidelity >= 0.97 : 2400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77771528e-02
# T = 1     Fidelity = 0.17550247
# T = 2     Fidelity = 0.31608018
# T = 5     Fidelity = 0.55521215
# T = 10    Fidelity = 0.72487919
# T = 20    Fidelity = 0.82944792
# T = 30    Fidelity = 0.85309127
# T = 40    Fidelity = 0.85895767
# T = 50    Fidelity = 0.86464792
# T = 75    Fidelity = 0.88206238
# T = 100   Fidelity = 0.89834873
# T = 125   Fidelity = 0.90973688
# T = 150   Fidelity = 0.91803430
# T = 175   Fidelity = 0.92565613
# T = 200   Fidelity = 0.93471622
# T = 225   Fidelity = 0.93578497
# T = 250   Fidelity = 0.93604375
# T = 275   Fidelity = 0.94532798
# T = 300   Fidelity = 0.93535914
# T = 400   Fidelity = 0.94936238
# T = 500   Fidelity = 0.95238579
# T = 600   Fidelity = 0.96005036
# T = 700   Fidelity = 0.91528931
# T = 800   Fidelity = 0.92789135
# T = 900   Fidelity = 0.94672840
# T = 1000  Fidelity = 0.93961467
# T = 1010  Fidelity = 0.95198147
# T = 1020  Fidelity = 0.95688375
# T = 1030  Fidelity = 0.97881992
#
# Minimum T for Fidelity >= 0.97 : 1030
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20207484e-01
# T = 1     Fidelity = 0.28006643
# T = 2     Fidelity = 0.45230853
# T = 5     Fidelity = 0.68072342
# T = 10    Fidelity = 0.81844732
# T = 20    Fidelity = 0.89612321
# T = 30    Fidelity = 0.91773600
# T = 40    Fidelity = 0.92916665
# T = 50    Fidelity = 0.93787295
# T = 75    Fidelity = 0.95162420
# T = 100   Fidelity = 0.96191711
# T = 125   Fidelity = 0.96836946
# T = 150   Fidelity = 0.97422763
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71414710e-01
# T = 1     Fidelity = 0.37884228
# T = 2     Fidelity = 0.56660277
# T = 5     Fidelity = 0.77019877
# T = 10    Fidelity = 0.87915488
# T = 20    Fidelity = 0.93532891
# T = 30    Fidelity = 0.95282172
# T = 40    Fidelity = 0.96403121
# T = 50    Fidelity = 0.96971013
# T = 75    Fidelity = 0.97961783
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18848087e-01
# T = 1     Fidelity = 0.46386205
# T = 2     Fidelity = 0.65548009
# T = 5     Fidelity = 0.83096424
# T = 10    Fidelity = 0.91706722
# T = 20    Fidelity = 0.95853567
# T = 30    Fidelity = 0.97286149
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00083408
# T = 10    Fidelity = 0.06388640
# T = 20    Fidelity = 0.45556817
# T = 30    Fidelity = 0.88091457
# T = 40    Fidelity = 0.96753742
# T = 50    Fidelity = 0.99169445
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000204
# T = 5     Fidelity = 0.02491942
# T = 10    Fidelity = 0.89981433
# T = 20    Fidelity = 0.96752533
# T = 30    Fidelity = 0.99642433
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00005176
# T = 2     Fidelity = 0.00078481
# T = 5     Fidelity = 0.18943766
# T = 10    Fidelity = 0.98855935
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00123988
# T = 2     Fidelity = 0.00813752
# T = 5     Fidelity = 0.34564548
# T = 10    Fidelity = 0.98668068
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00700085
# T = 2     Fidelity = 0.02898258
# T = 5     Fidelity = 0.47054481
# T = 10    Fidelity = 0.98166188
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02078060
# T = 2     Fidelity = 0.06460167
# T = 5     Fidelity = 0.56733147
# T = 10    Fidelity = 0.97717175
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04357111
# T = 2     Fidelity = 0.10974731
# T = 5     Fidelity = 0.63776676
# T = 10    Fidelity = 0.97218857
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07534336
# T = 2     Fidelity = 0.16382484
# T = 5     Fidelity = 0.69629643
# T = 10    Fidelity = 0.96945988
# T = 20    Fidelity = 0.99320014
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11369394
# T = 2     Fidelity = 0.22084952
# T = 5     Fidelity = 0.74291801
# T = 10    Fidelity = 0.96780710
# T = 20    Fidelity = 0.99359699
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15668647
# T = 2     Fidelity = 0.27883671
# T = 5     Fidelity = 0.78135269
# T = 10    Fidelity = 0.96734774
# T = 20    Fidelity = 0.99390659
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     1         0.9811782124      1.00972087e+00    None        None        None
# Symmetric      0.311     1         0.9826634206      1.02934439e+00    None        None        None
# Symmetric      0.522     1         0.9839415287      1.04790824e+00    None        None        None
# Symmetric      0.733     1         0.9850391553      1.06556366e+00    None        None        None
# Symmetric      0.944     1         0.9860026216      1.08242773e+00    None        None        None
# Symmetric      1.156     1         0.9868581564      1.09859358e+00    None        None        None
# Symmetric      1.367     1         0.9876221992      1.11413694e+00    None        None        None
# Symmetric      1.578     1         0.9883124963      1.12912045e+00    None        None        None
# Symmetric      1.789     1         0.9889347796      1.14359670e+00    None        None        None
# Symmetric      2.000     1         0.9895048775      1.15761039e+00    None        None        None
# Weak SSB       0.100     250       0.9865716033      3.13498607e-04    None        None        None
# Weak SSB       0.311     400       0.9818703890      1.22564919e-04    None        None        None
# Weak SSB       0.522     None      0.7083325134      1.14483174e-04    0.495505    0.000647    0.496152
# Weak SSB       0.733     None      0.8323658100      2.21982966e-04    0.46074     0.000248    0.460988
# Weak SSB       0.944     None      0.8526542934      4.33063144e-03    0.754649    5.1e-05     0.7547
# Weak SSB       1.156     1050      0.9730974273      2.50115281e-02    None        None        None
# Weak SSB       1.367     1030      0.9788370773      6.77198754e-02    None        None        None
# Weak SSB       1.578     150       0.9743488357      1.20186803e-01    None        None        None
# Weak SSB       1.789     75        0.9796314802      1.71405410e-01    None        None        None
# Weak SSB       2.000     30        0.9728385975      2.18843285e-01    None        None        None
# Weak SSB optimised0.100     None      0.9318031022      6.12114884e-03    0.307079    0.444117    0.751196
# Weak SSB optimised0.311     None      0.8946717255      5.23925085e-03    0.67056     0.233151    0.903711
# Weak SSB optimised0.522     None      0.5461464749      3.32159854e-03    0.097459    0.303878    0.401337
# Weak SSB optimised0.733     None      0.6974738785      4.75754041e-03    0.188446    0.322502    0.510949
# Weak SSB optimised0.944     None      0.8247582983      6.08544988e-03    0.666934    0.099277    0.766211
# Weak SSB optimised1.156     2400      0.9712629760      2.52576626e-02    None        None        None
# Weak SSB optimised1.367     1030      0.9788199208      6.77771528e-02    None        None        None
# Weak SSB optimised1.578     150       0.9742276324      1.20207484e-01    None        None        None
# Weak SSB optimised1.789     75        0.9796178285      1.71414710e-01    None        None        None
# Weak SSB optimised2.000     30        0.9728614901      2.18848087e-01    None        None        None
# Strong SSB     0.100     50        0.9916944527      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9964243261      7.22062439e-01    None        None        None
# Strong SSB     0.522     10        0.9885593500      7.78318602e-01    None        None        None
# Strong SSB     0.733     10        0.9866806817      8.15979742e-01    None        None        None
# Strong SSB     0.944     10        0.9816618800      8.44059983e-01    None        None        None
# Strong SSB     1.156     10        0.9771717529      8.66317759e-01    None        None        None
# Strong SSB     1.367     10        0.9721885699      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9932001377      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9935969881      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9939065905      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()
