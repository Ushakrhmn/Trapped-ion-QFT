# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-4

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722464521298
# State dimension     = (256,)
# Norm                = 0.9999999999999999

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_asymm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------
    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):
            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_symm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Multi-parameter scan
# HVA + warm-start continuation + overlap tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0

# Default depth
layers = 4

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

   # {
    #    "label": "Symmetric",
    #    "mI2": 1.0,
    #    "f": 0.0
#    },

 #   {
 #       "label": "Weak SSB",
  #      "mI2": -1.0,
   #     "f": 1e-5
  #  },
      
    {
        "label": "Weak SSB optimised f=0.01",
        "mI2": -1.0,
        "f": 1e-2
    },
    {
        "label": "Weak SSB optimised f=0.05",
        "mI2": -1.0,
        "f": 5*1e-2
    },
    {
        "label": "Weak SSB optimised f=0.001",
        "mI2": -1.0,
        "f": 1e-3
    }
  #  {
  #      "label": "Strong SSB",
   #     "mI2": -1.0,
   #     "f": 0.5
   # }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#" * 80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#" * 80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "=" * 60)
        print(f"Running λ = {lam:.3f}")
        print("=" * 60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(
            Hloc_sparse
        )

        # ----------------------------------------------------
        # Dense Hamiltonian
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(
            H_op
        )

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ====================================================
        # Adaptive depth near critical region
        # ====================================================

        

        # ====================================================
        # Ansatz
        # ====================================================

        if mI2 < 0:

            ansatz = grouped_hva_asymm(
                nq=nqubits,
                layers=layers
            )

        else:

            ansatz = grouped_hva_symm(
                nq=nqubits,
                layers=layers
            )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)



        
        # ====================================================
        # Weak SSB:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )
        # ====================================================
        # Weak SSB optimized:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )

        # ====================================================
        # Symmetric + Strong SSB
        # ====================================================

        else:

            print(
                "\nRunning ordinary HVA-VQE...\n"
            )

            initial_point = (
                0.01 * np.random.randn(
                    ansatz.num_parameters
                )
            )

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = (
                vqe.compute_minimum_eigenvalue(
                    H_pauli_shifted
                )
            )

            best_energy = (
                result.eigenvalue.real
                + identity_shift
            )

            optimal_circuit = (
                ansatz.assign_parameters(
                    result.optimal_parameters
                )
            )

            best_state = (
                Statevector.from_instruction(
                    optimal_circuit
                ).data
            )

            best_fidelity = np.abs(
                np.vdot(
                    psi_exact,
                    best_state
                )
            )**2

            best_overlap = 1.0

        # ====================================================
        # Final VQE data
        # ====================================================

        E_vqe = best_energy
        F = best_fidelity

        # ====================================================
        # Store results
        # ====================================================

        data = {

            "case": label,

            "lambda": lam,

            "mI2": mI2,

            "f": f,
            'psi_vqe': best_state,

            "E_exact": E_exact,

            "E_vqe": E_vqe,

            "error": abs(
                E_exact - E_vqe
            ),

            "fidelity": F,

            "tracking_overlap": best_overlap,

            "layers": layers
        }

        case_results.append(data)
        all_results.append(data)

        # ====================================================
        # Print
        # ====================================================

        print("\nFINAL SELECTED STATE")

        print(
            f"Exact energy     : "
            f"{E_exact:.12f}"
        )

        print(
            f"VQE energy       : "
            f"{E_vqe:.12f}"
        )

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(
            f"Fidelity         : "
            f"{F:.12f}"
        )

        print(
            f"Tracking overlap : "
            f"{best_overlap:.12f}"
        )

        print(
            f"Layers            : "
            f"{layers}"
        )

        print(
            f"Pauli terms       : "
            f"{len(H_pauli_shifted.paulis)}"
        )

    # ========================================================
    # Summary
    # ========================================================

    print("\n")
    print("=" * 140)
    print(f"SUMMARY : {label}")
    print("=" * 140)

    print(
        f"{'lambda':<12}"
        f"{'Exact E':<20}"
        f"{'VQE E':<20}"
        f"{'Error':<18}"
        f"{'Fidelity':<18}"
        f"{'TrackOverlap':<18}"
        f"{'Layers':<10}"
    )

    print("=" * 140)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
            f"{r['E_vqe']:<20.10f}"
            f"{r['error']:<18.4e}"
            f"{r['fidelity']:<18.10f}"
            f"{r['tracking_overlap']:<18.10f}"
            f"{r['layers']:<10}"
        )
# Out:
# ################################################################################
# CASE: Weak SSB optimised f=0.01
# mI² = -1.0,  f = 0.01
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.947372049660
# Fidelity = 0.999726888439
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.948882581518
# Fidelity = 0.999980317526
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.946255147518
# Fidelity = 0.998159687258
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.814554116801
# Fidelity = 0.985095141086
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.864188551843
# Fidelity = 0.983867125120
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.949000723146
# Fidelity = 0.999991626172
# Overlap  = 0.999990560040
#
# Restart 1
# Energy   = -16.947877299246
# Fidelity = 0.999284684345
# Overlap  = 0.999302624768
#
# Restart 2
# Energy   = -16.948110944357
# Fidelity = 0.999608556932
# Overlap  = 0.999624724096
#
# Restart 3
# Energy   = -16.928234230653
# Fidelity = 0.996878136257
# Overlap  = 0.996891693850
#
# Restart 4
# Energy   = -16.945051164465
# Fidelity = 0.997884189146
# Overlap  = 0.997935905485
#
# FINAL SELECTED STATE
# Exact energy     : -16.949087521387
# VQE energy       : -16.949000723146
# Energy error     : 8.679824e-05
# Fidelity         : 0.999991626172
# Tracking overlap : 0.999990560040
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.898867701608
# Fidelity = 0.997013496751
# Overlap  = 0.873224266019
#
# Restart 1
# Energy   = -8.898389523688
# Fidelity = 0.996310799076
# Overlap  = 0.873486257162
#
# Restart 2
# Energy   = -8.896315939145
# Fidelity = 0.991346739405
# Overlap  = 0.877279072075
#
# Restart 3
# Energy   = -8.898254113468
# Fidelity = 0.996373093239
# Overlap  = 0.872945860257
#
# Restart 4
# Energy   = -8.898053032501
# Fidelity = 0.995982665073
# Overlap  = 0.874224432793
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.898916299033
# Fidelity = 0.996917436593
# Overlap  = 0.999668074430
#
# Restart 1
# Energy   = -8.897943982961
# Fidelity = 0.995340694618
# Overlap  = 0.999341932072
#
# Restart 2
# Energy   = -8.897968544994
# Fidelity = 0.996174963208
# Overlap  = 0.999076679275
#
# Restart 3
# Energy   = -8.895439014908
# Fidelity = 0.989091444481
# Overlap  = 0.997492589396
#
# Restart 4
# Energy   = -8.553722980443
# Fidelity = 0.015741587283
# Overlap  = 0.006212659080
#
# FINAL SELECTED STATE
# Exact energy     : -8.901420005232
# VQE energy       : -8.898916299033
# Energy error     : 2.503706e-03
# Fidelity         : 0.996917436593
# Tracking overlap : 0.999668074430
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.403255095744
# Fidelity = 0.753653026518
# Overlap  = 0.039816208170
#
# Restart 1
# Energy   = -4.406263906441
# Fidelity = 0.852002760442
# Overlap  = 0.010773483171
#
# Restart 2
# Energy   = -4.405358241650
# Fidelity = 0.851618744298
# Overlap  = 0.010607054334
#
# Restart 3
# Energy   = -4.408166501893
# Fidelity = 0.494991619377
# Overlap  = 0.000265397426
#
# Restart 4
# Energy   = -4.405136183748
# Fidelity = 0.802045825821
# Overlap  = 0.008577605951
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.410100812291
# Fidelity = 0.496863407898
# Overlap  = 0.996711851206
#
# Restart 1
# Energy   = -4.414741937965
# Fidelity = 0.876562350329
# Overlap  = 0.794244712190
#
# Restart 2
# Energy   = -4.408258697148
# Fidelity = 0.864672032275
# Overlap  = 0.797096259811
#
# Restart 3
# Energy   = -4.403971066752
# Fidelity = 0.803845035165
# Overlap  = 0.738001986043
#
# Restart 4
# Energy   = -4.404134762120
# Fidelity = 0.777909505474
# Overlap  = 0.736431304615
#
# FINAL SELECTED STATE
# Exact energy     : -4.442622757234
# VQE energy       : -4.414741937965
# Energy error     : 2.788082e-02
# Fidelity         : 0.876562350329
# Tracking overlap : 0.794244712190
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.781109596925
# Fidelity = 0.815809032916
# Overlap  = 0.655993740993
#
# Restart 1
# Energy   = -2.769060520447
# Fidelity = 0.765164139607
# Overlap  = 0.590182836854
#
# Restart 2
# Energy   = -2.768174548748
# Fidelity = 0.722378828799
# Overlap  = 0.578137196886
#
# Restart 3
# Energy   = -2.771972096763
# Fidelity = 0.795315485282
# Overlap  = 0.607621294475
#
# Restart 4
# Energy   = -2.778820983528
# Fidelity = 0.812615923669
# Overlap  = 0.653166801930
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.791469408676
# Fidelity = 0.994287428093
# Overlap  = 0.847470668942
#
# Restart 1
# Energy   = -2.768796918512
# Fidelity = 0.755472897886
# Overlap  = 0.881222902498
#
# Restart 2
# Energy   = -2.770225183876
# Fidelity = 0.812458187366
# Overlap  = 0.825213998084
#
# Restart 3
# Energy   = -2.765460786696
# Fidelity = 0.653132497238
# Overlap  = 0.834494259447
#
# Restart 4
# Energy   = -2.773575811210
# Fidelity = 0.765235218560
# Overlap  = 0.965146698627
#
# FINAL SELECTED STATE
# Exact energy     : -2.798699278535
# VQE energy       : -2.791469408676
# Energy error     : 7.229870e-03
# Fidelity         : 0.994287428093
# Tracking overlap : 0.847470668942
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.903446327443
# Fidelity = 0.999728419348
# Overlap  = 0.792175361885
#
# Restart 1
# Energy   = -1.896318994866
# Fidelity = 0.976767761126
# Overlap  = 0.731134767475
#
# Restart 2
# Energy   = -1.894944759507
# Fidelity = 0.957749962227
# Overlap  = 0.698421063360
#
# Restart 3
# Energy   = -1.889688783156
# Fidelity = 0.932031295225
# Overlap  = 0.666538828264
#
# Restart 4
# Energy   = -1.895926605045
# Fidelity = 0.983875671457
# Overlap  = 0.787995070089
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.903606915373
# Fidelity = 0.999694193707
# Overlap  = 0.999947246140
#
# Restart 1
# Energy   = -1.898248894938
# Fidelity = 0.997311165717
# Overlap  = 0.997065462629
#
# Restart 2
# Energy   = -1.894987106789
# Fidelity = 0.949570663815
# Overlap  = 0.953809876373
#
# Restart 3
# Energy   = -1.881166050964
# Fidelity = 0.862302372731
# Overlap  = 0.868056909113
#
# Restart 4
# Energy   = -1.897805382441
# Fidelity = 0.997358621013
# Overlap  = 0.997637928247
#
# FINAL SELECTED STATE
# Exact energy     : -1.904522768472
# VQE energy       : -1.903606915373
# Energy error     : 9.158531e-04
# Fidelity         : 0.999694193707
# Tracking overlap : 0.999947246140
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.362368230102
# Fidelity = 0.999839614551
# Overlap  = 0.800906491087
#
# Restart 1
# Energy   = -1.361648347597
# Fidelity = 0.999413694596
# Overlap  = 0.797189503543
#
# Restart 2
# Energy   = -1.358445125163
# Fidelity = 0.979422798716
# Overlap  = 0.725211081786
#
# Restart 3
# Energy   = -1.356290754233
# Fidelity = 0.957161758270
# Overlap  = 0.673393821431
#
# Restart 4
# Energy   = -1.355710805979
# Fidelity = 0.951670221148
# Overlap  = 0.663224483910
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.362586000292
# Fidelity = 0.999941272552
# Overlap  = 0.999906375031
#
# Restart 1
# Energy   = -1.360170696683
# Fidelity = 0.995231661158
# Overlap  = 0.995620146634
#
# Restart 2
# Energy   = -1.355874919706
# Fidelity = 0.957266639474
# Overlap  = 0.960638837429
#
# Restart 3
# Energy   = -1.355946602735
# Fidelity = 0.957286245548
# Overlap  = 0.960803803676
#
# Restart 4
# Energy   = -1.358216766184
# Fidelity = 0.975818368769
# Overlap  = 0.976823341243
#
# FINAL SELECTED STATE
# Exact energy     : -1.362751204880
# VQE energy       : -1.362586000292
# Energy error     : 1.652046e-04
# Fidelity         : 0.999941272552
# Tracking overlap : 0.999906375031
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.017004693122
# Fidelity = 0.999985123110
# Overlap  = 0.896704186219
#
# Restart 1
# Energy   = -1.011465921505
# Fidelity = 0.989300148200
# Overlap  = 0.851246980415
#
# Restart 2
# Energy   = -1.013380021909
# Fidelity = 0.998491889556
# Overlap  = 0.888880588013
#
# Restart 3
# Energy   = -1.010126236777
# Fidelity = 0.971952879173
# Overlap  = 0.815537989724
#
# Restart 4
# Energy   = -1.012197094948
# Fidelity = 0.993774554105
# Overlap  = 0.866943383806
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.017030467596
# Fidelity = 0.999970077959
# Overlap  = 0.999980810205
#
# Restart 1
# Energy   = -1.011750510487
# Fidelity = 0.992175954032
# Overlap  = 0.992528356228
#
# Restart 2
# Energy   = -1.011490230884
# Fidelity = 0.989351584566
# Overlap  = 0.989796213410
#
# Restart 3
# Energy   = -1.012421083937
# Fidelity = 0.997895906129
# Overlap  = 0.998049170834
#
# Restart 4
# Energy   = -1.010933114171
# Fidelity = 0.987583890372
# Overlap  = 0.988070627267
#
# FINAL SELECTED STATE
# Exact energy     : -1.017093855943
# VQE energy       : -1.017030467596
# Energy error     : 6.338835e-05
# Fidelity         : 0.999970077959
# Tracking overlap : 0.999980810205
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.782802007370
# Fidelity = 0.999992341959
# Overlap  = 0.953113781112
#
# Restart 1
# Energy   = -0.778658345127
# Fidelity = 0.997705795193
# Overlap  = 0.941693698585
#
# Restart 2
# Energy   = -0.778172914186
# Fidelity = 0.995507277457
# Overlap  = 0.935651394282
#
# Restart 3
# Energy   = -0.778812982413
# Fidelity = 0.998382410602
# Overlap  = 0.944314322008
#
# Restart 4
# Energy   = -0.778897351261
# Fidelity = 0.998431467125
# Overlap  = 0.944345724076
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.782807021501
# Fidelity = 0.999995801023
# Overlap  = 0.999998163312
#
# Restart 1
# Energy   = -0.778702493589
# Fidelity = 0.998001334997
# Overlap  = 0.998134105711
#
# Restart 2
# Energy   = -0.778759040106
# Fidelity = 0.998142825977
# Overlap  = 0.998269099045
#
# Restart 3
# Energy   = -0.778780923558
# Fidelity = 0.998267793139
# Overlap  = 0.998385973614
#
# Restart 4
# Energy   = -0.778606100644
# Fidelity = 0.997600309545
# Overlap  = 0.997756479478
#
# FINAL SELECTED STATE
# Exact energy     : -0.782829901157
# VQE energy       : -0.782807021501
# Energy error     : 2.287966e-05
# Fidelity         : 0.999995801023
# Tracking overlap : 0.999998163312
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.614036706422
# Fidelity = 0.999995795995
# Overlap  = 0.975201956516
#
# Restart 1
# Energy   = -0.611490542276
# Fidelity = 0.999320959099
# Overlap  = 0.971465931641
#
# Restart 2
# Energy   = -0.611298444305
# Fidelity = 0.998909318324
# Overlap  = 0.969796929327
#
# Restart 3
# Energy   = -0.611497226863
# Fidelity = 0.999360674566
# Overlap  = 0.971646183965
#
# Restart 4
# Energy   = -0.611479931744
# Fidelity = 0.998867652640
# Overlap  = 0.971318283784
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.614042415114
# Fidelity = 0.999998228612
# Overlap  = 0.999998117353
#
# Restart 1
# Energy   = -0.611382894198
# Fidelity = 0.998985137600
# Overlap  = 0.999040839554
#
# Restart 2
# Energy   = -0.611510356471
# Fidelity = 0.999243321610
# Overlap  = 0.999299280872
#
# Restart 3
# Energy   = -0.611446585264
# Fidelity = 0.999221952974
# Overlap  = 0.999281660557
#
# Restart 4
# Energy   = -0.611475295791
# Fidelity = 0.999277720427
# Overlap  = 0.999331832061
#
# FINAL SELECTED STATE
# Exact energy     : -0.614054426369
# VQE energy       : -0.614042415114
# Energy error     : 1.201126e-05
# Fidelity         : 0.999998228612
# Tracking overlap : 0.999998117353
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.485899840450
# Fidelity = 0.999995964064
# Overlap  = 0.985498249224
#
# Restart 1
# Energy   = -0.484547479634
# Fidelity = 0.999695503844
# Overlap  = 0.983810831894
#
# Restart 2
# Energy   = -0.484544396461
# Fidelity = 0.999698089017
# Overlap  = 0.983869208717
#
# Restart 3
# Energy   = -0.484578958454
# Fidelity = 0.999720029963
# Overlap  = 0.983852766632
#
# Restart 4
# Energy   = -0.484562882300
# Fidelity = 0.999736136373
# Overlap  = 0.983946474602
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.485905207145
# Fidelity = 0.999998082655
# Overlap  = 0.999998742730
#
# Restart 1
# Energy   = -0.484514432458
# Fidelity = 0.999665302733
# Overlap  = 0.999684092585
#
# Restart 2
# Energy   = -0.484530797379
# Fidelity = 0.999650493912
# Overlap  = 0.999667210914
#
# Restart 3
# Energy   = -0.484224976576
# Fidelity = 0.998702044469
# Overlap  = 0.998714573495
#
# Restart 4
# Energy   = -0.484309945375
# Fidelity = 0.999318864804
# Overlap  = 0.999345394853
#
# FINAL SELECTED STATE
# Exact energy     : -0.485915822602
# VQE energy       : -0.485905207145
# Energy error     : 1.061546e-05
# Fidelity         : 0.999998082655
# Tracking overlap : 0.999998742730
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB optimised f=0.01
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9490875214      -16.9490007231      8.6798e-05        0.9999916262      0.9999905600      4
# 0.3111      -8.9014200052       -8.8989162990       2.5037e-03        0.9969174366      0.9996680744      4
# 0.5222      -4.4426227572       -4.4147419380       2.7881e-02        0.8765623503      0.7942447122      4
# 0.7333      -2.7986992785       -2.7914694087       7.2299e-03        0.9942874281      0.8474706689      4
# 0.9444      -1.9045227685       -1.9036069154       9.1585e-04        0.9996941937      0.9999472461      4
# 1.1556      -1.3627512049       -1.3625860003       1.6520e-04        0.9999412726      0.9999063750      4
# 1.3667      -1.0170938559       -1.0170304676       6.3388e-05        0.9999700780      0.9999808102      4
# 1.5778      -0.7828299012       -0.7828070215       2.2880e-05        0.9999958010      0.9999981633      4
# 1.7889      -0.6140544264       -0.6140424151       1.2011e-05        0.9999982286      0.9999981174      4
# 2.0000      -0.4859158226       -0.4859052071       1.0615e-05        0.9999980827      0.9999987427      4
#
#
# ################################################################################
# CASE: Weak SSB optimised f=0.05
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.059667499125
# Fidelity = 0.998737318708
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -17.064049733327
# Fidelity = 0.999890077349
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -17.059990031790
# Fidelity = 0.999439924825
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -17.026812161939
# Fidelity = 0.995832682925
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.999094570947
# Fidelity = 0.992401185373
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.064177374401
# Fidelity = 0.999903983810
# Overlap  = 0.999983555182
#
# Restart 1
# Energy   = -17.063871222637
# Fidelity = 0.999872192827
# Overlap  = 0.999943184947
#
# Restart 2
# Energy   = -17.063930438217
# Fidelity = 0.999877591732
# Overlap  = 0.999966250510
#
# Restart 3
# Energy   = -17.039773604617
# Fidelity = 0.996726014725
# Overlap  = 0.996871962528
#
# Restart 4
# Energy   = -17.060658927008
# Fidelity = 0.998903302398
# Overlap  = 0.999053601179
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.064177374401
# Energy error     : 5.159775e-04
# Fidelity         : 0.999903983810
# Tracking overlap : 0.999983555182
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.058831019057
# Fidelity = 0.990409805993
# Overlap  = 0.818924936410
#
# Restart 1
# Energy   = -9.052495753633
# Fidelity = 0.985365910127
# Overlap  = 0.832134624716
#
# Restart 2
# Energy   = -9.045556032571
# Fidelity = 0.983378383718
# Overlap  = 0.839744466731
#
# Restart 3
# Energy   = -8.979613891748
# Fidelity = 0.967318966360
# Overlap  = 0.847222622535
#
# Restart 4
# Energy   = -9.056822864979
# Fidelity = 0.987332739043
# Overlap  = 0.830480811170
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.071075911623
# Fidelity = 0.996647771635
# Overlap  = 0.995473835433
#
# Restart 1
# Energy   = -9.051506718251
# Fidelity = 0.984269911376
# Overlap  = 0.995325076367
#
# Restart 2
# Energy   = -9.031248855633
# Fidelity = 0.972007408172
# Overlap  = 0.986769684458
#
# Restart 3
# Energy   = -9.056272809555
# Fidelity = 0.987569842639
# Overlap  = 0.997630263180
#
# Restart 4
# Energy   = -9.052198999634
# Fidelity = 0.984290919694
# Overlap  = 0.996634142932
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.071075911623
# Energy error     : 9.374001e-03
# Fidelity         : 0.996647771635
# Tracking overlap : 0.995473835433
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.664369798094
# Fidelity = 0.977995266156
# Overlap  = 0.072428397919
#
# Restart 1
# Energy   = -4.664390803765
# Fidelity = 0.978353679259
# Overlap  = 0.071776748441
#
# Restart 2
# Energy   = -4.658715152918
# Fidelity = 0.973494941755
# Overlap  = 0.076527681082
#
# Restart 3
# Energy   = -4.681496526158
# Fidelity = 0.991347128910
# Overlap  = 0.065178165676
#
# Restart 4
# Energy   = -4.663219384332
# Fidelity = 0.977919502213
# Overlap  = 0.074517135223
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.690717293999
# Fidelity = 0.995695468614
# Overlap  = 0.996001235484
#
# Restart 1
# Energy   = -4.672624725639
# Fidelity = 0.984825017132
# Overlap  = 0.990229349547
#
# Restart 2
# Energy   = -4.655239131763
# Fidelity = 0.970699548652
# Overlap  = 0.987045553257
#
# Restart 3
# Energy   = -4.667121919286
# Fidelity = 0.979856635402
# Overlap  = 0.990233787173
#
# Restart 4
# Energy   = -4.672349141549
# Fidelity = 0.985842923670
# Overlap  = 0.995225005972
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.690717293999
# Energy error     : 1.047768e-02
# Fidelity         : 0.995695468614
# Tracking overlap : 0.996001235484
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.005171480702
# Fidelity = 0.998268430264
# Overlap  = 0.643688714495
#
# Restart 1
# Energy   = -2.995298143598
# Fidelity = 0.994398869654
# Overlap  = 0.630545115091
#
# Restart 2
# Energy   = -2.991225067898
# Fidelity = 0.991707959674
# Overlap  = 0.622297544126
#
# Restart 3
# Energy   = -2.991285498448
# Fidelity = 0.992611383373
# Overlap  = 0.627412512008
#
# Restart 4
# Energy   = -2.992810297766
# Fidelity = 0.992723154602
# Overlap  = 0.627507421690
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.007786535959
# Fidelity = 0.999192564673
# Overlap  = 0.999283413246
#
# Restart 1
# Energy   = -2.999946069553
# Fidelity = 0.995859677133
# Overlap  = 0.996293863254
#
# Restart 2
# Energy   = -2.995454426173
# Fidelity = 0.994115589542
# Overlap  = 0.995897781839
#
# Restart 3
# Energy   = -2.984853976079
# Fidelity = 0.990265329855
# Overlap  = 0.991884619134
#
# Restart 4
# Energy   = -2.991752765684
# Fidelity = 0.992339221090
# Overlap  = 0.994983899922
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.007786535959
# Energy error     : 3.744816e-03
# Fidelity         : 0.999192564673
# Tracking overlap : 0.999283413246
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.082732172457
# Fidelity = 0.999866695265
# Overlap  = 0.835109927501
#
# Restart 1
# Energy   = -2.077606733828
# Fidelity = 0.998457510708
# Overlap  = 0.824931161395
#
# Restart 2
# Energy   = -2.079245298178
# Fidelity = 0.998927036003
# Overlap  = 0.826867501275
#
# Restart 3
# Energy   = -2.079409335946
# Fidelity = 0.999017877896
# Overlap  = 0.826519261004
#
# Restart 4
# Energy   = -2.077867525221
# Fidelity = 0.998459236968
# Overlap  = 0.823370290906
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.082928952435
# Fidelity = 0.999901483635
# Overlap  = 0.999974544853
#
# Restart 1
# Energy   = -2.077745258151
# Fidelity = 0.998412291077
# Overlap  = 0.998584466292
#
# Restart 2
# Energy   = -2.077654234208
# Fidelity = 0.998510117351
# Overlap  = 0.998681366384
#
# Restart 3
# Energy   = -2.076923337002
# Fidelity = 0.998282609700
# Overlap  = 0.998466293721
#
# Restart 4
# Energy   = -2.077138540107
# Fidelity = 0.998413497899
# Overlap  = 0.998617584799
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.082928952435
# Energy error     : 6.367710e-04
# Fidelity         : 0.999901483635
# Tracking overlap : 0.999974544853
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.503364010720
# Fidelity = 0.999804742565
# Overlap  = 0.896114960554
#
# Restart 1
# Energy   = -1.502460588149
# Fidelity = 0.999602674645
# Overlap  = 0.895708216617
#
# Restart 2
# Energy   = -1.501574095861
# Fidelity = 0.999358169922
# Overlap  = 0.894836994350
#
# Restart 3
# Energy   = -1.490575717474
# Fidelity = 0.988471746592
# Overlap  = 0.876671976673
#
# Restart 4
# Energy   = -1.501669084049
# Fidelity = 0.999368205250
# Overlap  = 0.893806147450
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.503689333005
# Fidelity = 0.999867880876
# Overlap  = 0.999950157069
#
# Restart 1
# Energy   = -1.502542869241
# Fidelity = 0.999669095386
# Overlap  = 0.999848444811
#
# Restart 2
# Energy   = -1.503067316059
# Fidelity = 0.999765165403
# Overlap  = 0.999870544754
#
# Restart 3
# Energy   = -1.502714513915
# Fidelity = 0.999709487026
# Overlap  = 0.999846094718
#
# Restart 4
# Energy   = -1.502209272287
# Fidelity = 0.999553228200
# Overlap  = 0.999680800194
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503689333005
# Energy error     : 7.985397e-04
# Fidelity         : 0.999867880876
# Tracking overlap : 0.999950157069
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118302324013
# Fidelity = 0.999857295297
# Overlap  = 0.918822514334
#
# Restart 1
# Energy   = -1.113927438127
# Fidelity = 0.998199877230
# Overlap  = 0.914446238711
#
# Restart 2
# Energy   = -1.104775040938
# Fidelity = 0.986074099800
# Overlap  = 0.877035420484
#
# Restart 3
# Energy   = -1.108035274103
# Fidelity = 0.995469080602
# Overlap  = 0.904850421641
#
# Restart 4
# Energy   = -1.107605349364
# Fidelity = 0.993058077727
# Overlap  = 0.899846564921
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118950601666
# Fidelity = 0.999981738176
# Overlap  = 0.999879642731
#
# Restart 1
# Energy   = -1.107419358946
# Fidelity = 0.993504653965
# Overlap  = 0.994047759285
#
# Restart 2
# Energy   = -1.110294672882
# Fidelity = 0.994726109053
# Overlap  = 0.994817149038
#
# Restart 3
# Energy   = -1.114481521003
# Fidelity = 0.999205324931
# Overlap  = 0.999285253857
#
# Restart 4
# Energy   = -1.115180045546
# Fidelity = 0.999347937628
# Overlap  = 0.999445381623
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118950601666
# Energy error     : 1.491288e-04
# Fidelity         : 0.999981738176
# Tracking overlap : 0.999879642731
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.853228302966
# Fidelity = 0.999989389745
# Overlap  = 0.936659452038
#
# Restart 1
# Energy   = -0.849035654855
# Fidelity = 0.999344061802
# Overlap  = 0.932836383956
#
# Restart 2
# Energy   = -0.849762257975
# Fidelity = 0.999351865398
# Overlap  = 0.932270658763
#
# Restart 3
# Energy   = -0.849242622637
# Fidelity = 0.999253320283
# Overlap  = 0.934819190107
#
# Restart 4
# Energy   = -0.849279870164
# Fidelity = 0.999300023164
# Overlap  = 0.933111429519
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.853260410774
# Fidelity = 0.999992927045
# Overlap  = 0.999997194420
#
# Restart 1
# Energy   = -0.842909406790
# Fidelity = 0.993319881811
# Overlap  = 0.993424214921
#
# Restart 2
# Energy   = -0.840306025405
# Fidelity = 0.990353049394
# Overlap  = 0.990495224699
#
# Restart 3
# Energy   = -0.840716089471
# Fidelity = 0.990745525942
# Overlap  = 0.990874763641
#
# Restart 4
# Energy   = -0.847805681282
# Fidelity = 0.998667748225
# Overlap  = 0.998684489341
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.853260410774
# Energy error     : 7.164323e-05
# Fidelity         : 0.999992927045
# Tracking overlap : 0.999997194420
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663495989079
# Fidelity = 0.999993495871
# Overlap  = 0.958898686650
#
# Restart 1
# Energy   = -0.660752377914
# Fidelity = 0.999401039751
# Overlap  = 0.954626952596
#
# Restart 2
# Energy   = -0.656286032801
# Fidelity = 0.995927723609
# Overlap  = 0.940291352555
#
# Restart 3
# Energy   = -0.659447004670
# Fidelity = 0.998491734513
# Overlap  = 0.951051179905
#
# Restart 4
# Energy   = -0.655123505292
# Fidelity = 0.994518594309
# Overlap  = 0.935883205380
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663506204772
# Fidelity = 0.999994030573
# Overlap  = 0.999998356914
#
# Restart 1
# Energy   = -0.657155664389
# Fidelity = 0.996307817014
# Overlap  = 0.996373626579
#
# Restart 2
# Energy   = -0.659627297087
# Fidelity = 0.998477194115
# Overlap  = 0.998511938930
#
# Restart 3
# Energy   = -0.657861231385
# Fidelity = 0.997245121262
# Overlap  = 0.997309624154
#
# Restart 4
# Energy   = -0.658810808983
# Fidelity = 0.998142053771
# Overlap  = 0.998185251961
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663506204772
# Energy error     : 5.393677e-05
# Fidelity         : 0.999994030573
# Tracking overlap : 0.999998356914
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.522090160001
# Fidelity = 0.999994459995
# Overlap  = 0.975708298520
#
# Restart 1
# Energy   = -0.518417627489
# Fidelity = 0.998219581528
# Overlap  = 0.966890391339
#
# Restart 2
# Energy   = -0.517867199219
# Fidelity = 0.997891634759
# Overlap  = 0.965875845306
#
# Restart 3
# Energy   = -0.517792305756
# Fidelity = 0.997727824647
# Overlap  = 0.965462178600
#
# Restart 4
# Energy   = -0.517642296331
# Fidelity = 0.997580301049
# Overlap  = 0.965166981510
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.522095650556
# Fidelity = 0.999995553789
# Overlap  = 0.999999199196
#
# Restart 1
# Energy   = -0.517242589842
# Fidelity = 0.997204159901
# Overlap  = 0.997289946896
#
# Restart 2
# Energy   = -0.517941393413
# Fidelity = 0.998014685112
# Overlap  = 0.998079020183
#
# Restart 3
# Energy   = -0.517721662163
# Fidelity = 0.997674901792
# Overlap  = 0.997747929505
#
# Restart 4
# Energy   = -0.518079329072
# Fidelity = 0.998177487046
# Overlap  = 0.998235175129
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.522095650556
# Energy error     : 4.411374e-05
# Fidelity         : 0.999995553789
# Tracking overlap : 0.999999199196
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB optimised f=0.05
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -17.0646933519      -17.0641773744      5.1598e-04        0.9999039838      0.9999835552      4
# 0.3111      -9.0804499123       -9.0710759116       9.3740e-03        0.9966477716      0.9954738354      4
# 0.5222      -4.7011949726       -4.6907172940       1.0478e-02        0.9956954686      0.9960012355      4
# 0.7333      -3.0115313516       -3.0077865360       3.7448e-03        0.9991925647      0.9992834132      4
# 0.9444      -2.0835657235       -2.0829289524       6.3677e-04        0.9999014836      0.9999745449      4
# 1.1556      -1.5044878727       -1.5036893330       7.9854e-04        0.9998678809      0.9999501571      4
# 1.3667      -1.1190997304       -1.1189506017       1.4913e-04        0.9999817382      0.9998796427      4
# 1.5778      -0.8533320540       -0.8532604108       7.1643e-05        0.9999929270      0.9999971944      4
# 1.7889      -0.6635601415       -0.6635062048       5.3937e-05        0.9999940306      0.9999983569      4
# 2.0000      -0.5221397643       -0.5220956506       4.4114e-05        0.9999955538      0.9999991992      4
#
#
# ################################################################################
# CASE: Weak SSB optimised f=0.001
# mI² = -1.0,  f = 0.001
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.943686163141
# Fidelity = 0.999887882220
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.900687279616
# Fidelity = 0.993905007810
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.863044786639
# Fidelity = 0.989104394454
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.941371657196
# Fidelity = 0.999644426260
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.881971521810
# Fidelity = 0.993396032185
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.943821098888
# Fidelity = 0.999936773125
# Overlap  = 0.999980954670
#
# Restart 1
# Energy   = -16.897282868503
# Fidelity = 0.995649067519
# Overlap  = 0.995473773076
#
# Restart 2
# Energy   = -16.938938520003
# Fidelity = 0.999365039025
# Overlap  = 0.999463127407
#
# Restart 3
# Energy   = -16.942651936902
# Fidelity = 0.999854805455
# Overlap  = 0.999748539762
#
# Restart 4
# Energy   = -15.399261523150
# Fidelity = 0.000000004663
# Overlap  = 0.000000002612
#
# FINAL SELECTED STATE
# Exact energy     : -16.943954187610
# VQE energy       : -16.943821098888
# Energy error     : 1.330887e-04
# Fidelity         : 0.999936773125
# Tracking overlap : 0.999980954670
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.892053584594
# Fidelity = 0.999856193476
# Overlap  = 0.875598757692
#
# Restart 1
# Energy   = -8.891056695872
# Fidelity = 0.999636801137
# Overlap  = 0.874457176225
#
# Restart 2
# Energy   = -8.891869358350
# Fidelity = 0.999488712944
# Overlap  = 0.875430661653
#
# Restart 3
# Energy   = -8.891965911642
# Fidelity = 0.999768947552
# Overlap  = 0.875973334649
#
# Restart 4
# Energy   = -8.206514200927
# Fidelity = 0.000000040725
# Overlap  = 0.000000000479
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.892027687746
# Fidelity = 0.999807161928
# Overlap  = 0.999983484320
#
# Restart 1
# Energy   = -8.891995037396
# Fidelity = 0.999729172141
# Overlap  = 0.999941408742
#
# Restart 2
# Energy   = -8.891842874247
# Fidelity = 0.999757457379
# Overlap  = 0.999834604098
#
# Restart 3
# Energy   = -8.892044502787
# Fidelity = 0.999824332465
# Overlap  = 0.999968506100
#
# Restart 4
# Energy   = -8.549288748035
# Fidelity = 0.000398078368
# Overlap  = 0.000128148169
#
# FINAL SELECTED STATE
# Exact energy     : -8.892163415035
# VQE energy       : -8.892027687746
# Energy error     : 1.357273e-04
# Fidelity         : 0.999807161928
# Tracking overlap : 0.999983484320
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379187893967
# Fidelity = 0.336258704898
# Overlap  = 0.049177014002
#
# Restart 1
# Energy   = -4.377477409992
# Fidelity = 0.205184242136
# Overlap  = 0.000000000929
#
# Restart 2
# Energy   = -4.377604300573
# Fidelity = 0.216939768281
# Overlap  = 0.000000004981
#
# Restart 3
# Energy   = -4.377482971935
# Fidelity = 0.198534973193
# Overlap  = 0.000000008243
#
# Restart 4
# Energy   = -4.377454087664
# Fidelity = 0.192931219921
# Overlap  = 0.000000000027
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379272053185
# Fidelity = 0.348200829224
# Overlap  = 0.999682869059
#
# Restart 1
# Energy   = -4.377506969450
# Fidelity = 0.199830633426
# Overlap  = 0.000000412804
#
# Restart 2
# Energy   = -4.377446932412
# Fidelity = 0.191395710091
# Overlap  = 0.000000034715
#
# Restart 3
# Energy   = -4.377358500129
# Fidelity = 0.191473815034
# Overlap  = 0.000000049722
#
# Restart 4
# Energy   = -4.377439631977
# Fidelity = 0.190938081698
# Overlap  = 0.000000065057
#
# FINAL SELECTED STATE
# Exact energy     : -4.384756724769
# VQE energy       : -4.379272053185
# Energy error     : 5.484672e-03
# Fidelity         : 0.348200829224
# Tracking overlap : 0.999682869059
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.741580449731
# Fidelity = 0.042747133040
# Overlap  = 0.660491103537
#
# Restart 1
# Energy   = -2.749778103193
# Fidelity = 0.655809795024
# Overlap  = 0.000000254240
#
# Restart 2
# Energy   = -2.749868770412
# Fidelity = 0.671991492901
# Overlap  = 0.000001386424
#
# Restart 3
# Energy   = -2.749747428765
# Fidelity = 0.656155328121
# Overlap  = 0.000000380090
#
# Restart 4
# Energy   = -2.749825966115
# Fidelity = 0.664098296800
# Overlap  = 0.000000640687
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.749957154023
# Fidelity = 0.695765606787
# Overlap  = 0.998961942798
#
# Restart 1
# Energy   = -2.749653646088
# Fidelity = 0.654728938798
# Overlap  = 0.999448305760
#
# Restart 2
# Energy   = -2.749843295354
# Fidelity = 0.665890818947
# Overlap  = 0.999656830293
#
# Restart 3
# Energy   = -2.749793261234
# Fidelity = 0.660445973449
# Overlap  = 0.999643308236
#
# Restart 4
# Energy   = -2.749769530910
# Fidelity = 0.654976428242
# Overlap  = 0.999454958861
#
# FINAL SELECTED STATE
# Exact energy     : -2.752359086998
# VQE energy       : -2.749843295354
# Energy error     : 2.515792e-03
# Fidelity         : 0.665890818947
# Tracking overlap : 0.999656830293
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874737838986
# Fidelity = 0.977948341787
# Overlap  = 0.821513844384
#
# Restart 1
# Energy   = -1.874641966546
# Fidelity = 0.977006628308
# Overlap  = 0.821086862735
#
# Restart 2
# Energy   = -1.874679521014
# Fidelity = 0.977737563674
# Overlap  = 0.822017647556
#
# Restart 3
# Energy   = -1.873086940743
# Fidelity = 0.976137504791
# Overlap  = 0.816053736525
#
# Restart 4
# Energy   = -1.874674736885
# Fidelity = 0.973858300233
# Overlap  = 0.821524201434
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874809687573
# Fidelity = 0.983230887341
# Overlap  = 0.998816790213
#
# Restart 1
# Energy   = -1.871993138259
# Fidelity = 0.972809567504
# Overlap  = 0.998860910726
#
# Restart 2
# Energy   = -1.868286994470
# Fidelity = 0.972325137256
# Overlap  = 0.998072178929
#
# Restart 3
# Energy   = -1.867431419739
# Fidelity = 0.976305882453
# Overlap  = 0.997897553069
#
# Restart 4
# Energy   = -1.871168719345
# Fidelity = 0.973435930301
# Overlap  = 0.998815841510
#
# FINAL SELECTED STATE
# Exact energy     : -1.875221408114
# VQE energy       : -1.874809687573
# Energy error     : 4.117205e-04
# Fidelity         : 0.983230887341
# Tracking overlap : 0.998816790213
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348236615028
# Fidelity = 0.999056017856
# Overlap  = 0.894969882979
#
# Restart 1
# Energy   = -1.348208664532
# Fidelity = 0.997417300215
# Overlap  = 0.894576378566
#
# Restart 2
# Energy   = -1.348276278871
# Fidelity = 0.997344656192
# Overlap  = 0.894853077002
#
# Restart 3
# Energy   = -1.348274083775
# Fidelity = 0.998222030890
# Overlap  = 0.895611489291
#
# Restart 4
# Energy   = -1.348534633290
# Fidelity = 0.997577861968
# Overlap  = 0.894693673005
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348396237024
# Fidelity = 0.999126712296
# Overlap  = 0.999773638670
#
# Restart 1
# Energy   = -1.348119561027
# Fidelity = 0.997365205502
# Overlap  = 0.999765052702
#
# Restart 2
# Energy   = -1.348416352345
# Fidelity = 0.997840452415
# Overlap  = 0.999895643444
#
# Restart 3
# Energy   = -1.348324198186
# Fidelity = 0.999039648890
# Overlap  = 0.999842447305
#
# Restart 4
# Energy   = -1.348500107601
# Fidelity = 0.997254888877
# Overlap  = 0.999701128865
#
# FINAL SELECTED STATE
# Exact energy     : -1.348980328883
# VQE energy       : -1.348416352345
# Energy error     : 5.639765e-04
# Fidelity         : 0.997840452415
# Tracking overlap : 0.999895643444
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.009785335075
# Fidelity = 0.999515139134
# Overlap  = 0.936432950401
#
# Restart 1
# Energy   = -1.007152706788
# Fidelity = 0.999103092132
# Overlap  = 0.935333552295
#
# Restart 2
# Energy   = -1.007194696569
# Fidelity = 0.999324047118
# Overlap  = 0.935422527613
#
# Restart 3
# Energy   = -1.007177920074
# Fidelity = 0.999052950608
# Overlap  = 0.935649949149
#
# Restart 4
# Energy   = -1.006986183521
# Fidelity = 0.998891132628
# Overlap  = 0.935000450066
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.010468438967
# Fidelity = 0.999676947375
# Overlap  = 0.999841918772
#
# Restart 1
# Energy   = -1.007207724244
# Fidelity = 0.999285105387
# Overlap  = 0.999575804674
#
# Restart 2
# Energy   = -1.007175793438
# Fidelity = 0.999178273397
# Overlap  = 0.999434732092
#
# Restart 3
# Energy   = -1.007169394337
# Fidelity = 0.998896214693
# Overlap  = 0.999414723007
#
# Restart 4
# Energy   = -1.007182425669
# Fidelity = 0.999301883898
# Overlap  = 0.999557829400
#
# FINAL SELECTED STATE
# Exact energy     : -1.010508424407
# VQE energy       : -1.010468438967
# Energy error     : 3.998544e-05
# Fidelity         : 0.999676947375
# Tracking overlap : 0.999841918772
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.779155412337
# Fidelity = 0.999902603642
# Overlap  = 0.962748230960
#
# Restart 1
# Energy   = -0.775774247329
# Fidelity = 0.999324285897
# Overlap  = 0.959966276436
#
# Restart 2
# Energy   = -0.775803074142
# Fidelity = 0.999232336712
# Overlap  = 0.960037064035
#
# Restart 3
# Energy   = -0.775762761118
# Fidelity = 0.999327557074
# Overlap  = 0.960064440624
#
# Restart 4
# Energy   = -0.775818966121
# Fidelity = 0.999367064010
# Overlap  = 0.959986085646
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.779170035059
# Fidelity = 0.999988132839
# Overlap  = 0.999954893456
#
# Restart 1
# Energy   = -0.775802665034
# Fidelity = 0.999393930428
# Overlap  = 0.999373758268
#
# Restart 2
# Energy   = -0.775769503547
# Fidelity = 0.999351827143
# Overlap  = 0.999451518708
#
# Restart 3
# Energy   = -0.776109669883
# Fidelity = 0.999379607359
# Overlap  = 0.999465432003
#
# Restart 4
# Energy   = -0.775825393623
# Fidelity = 0.999440656719
# Overlap  = 0.999489225035
#
# FINAL SELECTED STATE
# Exact energy     : -0.779177155440
# VQE energy       : -0.779170035059
# Energy error     : 7.120381e-06
# Fidelity         : 0.999988132839
# Tracking overlap : 0.999954893456
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611742830911
# Fidelity = 0.999994971086
# Overlap  = 0.977819452371
#
# Restart 1
# Energy   = -0.609520348377
# Fidelity = 0.999660221202
# Overlap  = 0.976022667962
#
# Restart 2
# Energy   = -0.609513764097
# Fidelity = 0.999587314874
# Overlap  = 0.975842418225
#
# Restart 3
# Energy   = -0.609508117716
# Fidelity = 0.999624857279
# Overlap  = 0.975950820241
#
# Restart 4
# Energy   = -0.609487887535
# Fidelity = 0.999553753006
# Overlap  = 0.975854640601
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611744064708
# Fidelity = 0.999997264475
# Overlap  = 0.999999203784
#
# Restart 1
# Energy   = -0.609521584443
# Fidelity = 0.999680331019
# Overlap  = 0.999686816156
#
# Restart 2
# Energy   = -0.609518038104
# Fidelity = 0.999625491944
# Overlap  = 0.999645160473
#
# Restart 3
# Energy   = -0.609528116141
# Fidelity = 0.999673157393
# Overlap  = 0.999679913266
#
# Restart 4
# Energy   = -0.609500191864
# Fidelity = 0.999564071667
# Overlap  = 0.999599420015
#
# FINAL SELECTED STATE
# Exact energy     : -0.611746815753
# VQE energy       : -0.611744064708
# Energy error     : 2.751046e-06
# Fidelity         : 0.999997264475
# Tracking overlap : 0.999999203784
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484309047475
# Fidelity = 0.999998811961
# Overlap  = 0.986378667081
#
# Restart 1
# Energy   = -0.483119275536
# Fidelity = 0.999785775543
# Overlap  = 0.985301992348
#
# Restart 2
# Energy   = -0.483127882318
# Fidelity = 0.999840435624
# Overlap  = 0.985326520697
#
# Restart 3
# Energy   = -0.483116311545
# Fidelity = 0.999804803641
# Overlap  = 0.985374788296
#
# Restart 4
# Energy   = -0.483122880435
# Fidelity = 0.999834507687
# Overlap  = 0.985361205807
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484309867574
# Fidelity = 0.999998688877
# Overlap  = 0.999999849213
#
# Restart 1
# Energy   = -0.483122179783
# Fidelity = 0.999825109990
# Overlap  = 0.999829562190
#
# Restart 2
# Energy   = -0.483110027010
# Fidelity = 0.999802729856
# Overlap  = 0.999810562401
#
# Restart 3
# Energy   = -0.483112578039
# Fidelity = 0.999797764718
# Overlap  = 0.999806697620
#
# Restart 4
# Energy   = -0.483108465774
# Fidelity = 0.999767105386
# Overlap  = 0.999778217595
#
# FINAL SELECTED STATE
# Exact energy     : -0.484311639796
# VQE energy       : -0.484309867574
# Energy error     : 1.772222e-06
# Fidelity         : 0.999998688877
# Tracking overlap : 0.999999849213
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB optimised f=0.001
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9439541876      -16.9438210989      1.3309e-04        0.9999367731      0.9999809547      4
# 0.3111      -8.8921634150       -8.8920276877       1.3573e-04        0.9998071619      0.9999834843      4
# 0.5222      -4.3847567248       -4.3792720532       5.4847e-03        0.3482008292      0.9996828691      4
# 0.7333      -2.7523590870       -2.7498432954       2.5158e-03        0.6658908189      0.9996568303      4
# 0.9444      -1.8752214081       -1.8748096876       4.1172e-04        0.9832308873      0.9988167902      4
# 1.1556      -1.3489803289       -1.3484163523       5.6398e-04        0.9978404524      0.9998956434      4
# 1.3667      -1.0105084244       -1.0104684390       3.9985e-05        0.9996769474      0.9998419188      4
# 1.5778      -0.7791771554       -0.7791700351       7.1204e-06        0.9999881328      0.9999548935      4
# 1.7889      -0.6117468158       -0.6117440647       2.7510e-06        0.9999972645      0.9999992038      4
# 2.0000      -0.4843116398       -0.4843098676       1.7722e-06        0.9999986889      0.9999998492      4

# %%
print(all_results[0])
# Out:
# {'case': 'Weak SSB optimised f=0.01', 'lambda': np.float64(0.1), 'mI2': -1.0, 'f': 0.01, 'psi_vqe': array([-1.39928342e-06-8.43864064e-07j,  2.51803703e-05+1.56279991e-05j,
#        -1.54109969e-06-1.47886817e-06j,  2.72576090e-05+2.57268362e-05j,
#        -1.27896482e-06-1.95842027e-06j,  2.19619091e-05+3.39444422e-05j,
#        -1.42189178e-06-2.16648931e-06j,  2.44868376e-05+3.83247803e-05j,
#        -1.84396167e-06+4.66051262e-07j,  3.28337240e-05-8.24817474e-06j,
#        -2.49678389e-06+5.74651176e-07j,  4.37638138e-05-1.02538453e-05j,
#        -2.02701708e-06+3.23247023e-08j,  3.49903297e-05+6.97120679e-08j,
#        -1.23707760e-06-4.89981617e-07j,  2.18684991e-05+8.84925683e-06j,
#        -5.38702848e-08-1.73194465e-07j,  1.78134528e-06-3.19191031e-06j,
#        -3.28557430e-07+1.83794516e-06j,  4.73863536e-06-3.15305342e-05j,
#        -1.06728439e-06+7.45283133e-06j,  1.28746056e-05-1.31344459e-04j,
#        -1.71648493e-06+2.10772876e-05j,  3.26077652e-05-3.65466415e-04j,
#        -4.02817676e-06+4.13838330e-05j,  6.48332019e-05-7.47674811e-04j,
#        -6.13345555e-06+6.54820958e-05j,  9.89052671e-05-1.14708974e-03j,
#        -5.73147719e-06+7.56053207e-05j,  1.11741719e-04-1.30458224e-03j,
#        -3.97265151e-06+5.34441215e-05j,  8.04823011e-05-9.41666953e-04j,
#        -7.04353372e-07+8.13938705e-07j,  1.23187228e-05-1.19016568e-05j,
#        -7.02289950e-07-2.35469808e-08j,  1.26934570e-05+4.29132516e-08j,
#        -2.29146747e-07-2.58104407e-06j,  6.14621317e-06+4.57982398e-05j,
#         5.77202181e-08-8.07448335e-06j, -1.85782366e-06+1.40150818e-04j,
#         1.81153297e-06-1.52560182e-05j, -2.95619086e-05+2.76174279e-04j,
#         2.84432459e-06-2.44892068e-05j, -4.64921356e-05+4.29034190e-04j,
#         2.69159984e-06-2.91546759e-05j, -5.11913479e-05+5.03044410e-04j,
#         1.42862887e-06-2.10044839e-05j, -2.93191219e-05+3.69981217e-04j,
#         2.13571259e-07-8.17922349e-07j,  1.03234916e-06-2.98579983e-05j,
#        -1.36244454e-06+1.36200594e-05j,  1.67000911e-05-2.33698536e-04j,
#        -5.91175600e-06+5.33366923e-05j,  6.27828775e-05-9.38970191e-04j,
#        -8.68379493e-06+1.49179897e-04j,  1.70610585e-04-2.58738170e-03j,
#        -2.21428815e-05+2.91002929e-04j,  3.44467682e-04-5.25652434e-03j,
#        -3.35205668e-05+4.60489927e-04j,  5.27222220e-04-8.06549438e-03j,
#        -2.95804687e-05+5.31743355e-04j,  6.00632711e-04-9.17725518e-03j,
#        -2.04648835e-05+3.76061786e-04j,  4.34188232e-04-6.62753544e-03j,
#        -1.24365537e-06-1.43639500e-06j,  1.98828149e-05+3.62649591e-05j,
#        -1.55063906e-07-5.48719721e-06j,  4.85995759e-06+9.51902887e-05j,
#         2.61351988e-06-1.46919839e-05j, -3.71747853e-05+2.58696209e-04j,
#         5.41581072e-06-3.60944298e-05j, -9.90308820e-05+6.26327562e-04j,
#         7.32359723e-06-6.56114721e-05j, -1.20349316e-04+1.18626457e-03j,
#         1.18874941e-05-1.03953662e-04j, -1.94511129e-04+1.82153051e-03j,
#         1.30481458e-05-1.20857582e-04j, -2.45806936e-04+2.08510365e-03j,
#         9.35465672e-06-8.62044361e-05j, -1.81620968e-04+1.51828575e-03j,
#         9.28037626e-07-3.67853042e-06j,  2.19266223e-06-1.15914321e-04j,
#        -5.13711307e-06+5.52308462e-05j,  6.08812126e-05-9.47358270e-04j,
#        -2.28112364e-05+2.17523143e-04j,  2.33027543e-04-3.82863324e-03j,
#        -3.19847195e-05+6.08881295e-04j,  6.36272309e-04-1.05608735e-02j,
#        -8.42503775e-05+1.18812635e-03j,  1.29519858e-03-2.14605997e-02j,
#        -1.27088507e-04+1.88016540e-03j,  1.98149212e-03-3.29298628e-02j,
#        -1.09375024e-04+2.17106676e-03j,  2.25542117e-03-3.74719345e-02j,
#        -7.53593538e-05+1.53547319e-03j,  1.62823472e-03-2.70620180e-02j,
#        -2.36152783e-06+7.36028197e-06j,  3.81870199e-05-1.01410439e-04j,
#        -5.40192089e-07-1.37656581e-06j,  1.38082306e-05+2.08116693e-05j,
#         4.71642802e-06-2.93928335e-05j, -5.55743991e-05+5.20268206e-04j,
#         6.69344035e-06-9.33548395e-05j, -1.27837148e-04+1.61860525e-03j,
#         1.69041064e-05-1.84677206e-04j, -2.67888069e-04+3.33965603e-03j,
#         2.59319210e-05-2.94622194e-04j, -4.15003321e-04+5.16058498e-03j,
#         2.27787090e-05-3.46135464e-04j, -4.50145691e-04+5.97313091e-03j,
#         1.16189067e-05-2.47409005e-04j, -2.53753213e-04+4.35952128e-03j,
#         2.69816111e-06-9.40146659e-06j,  3.69218790e-06-3.33424766e-04j,
#        -1.40713777e-05+1.53411008e-04j,  1.66037810e-04-2.63177765e-03j,
#        -6.29477832e-05+6.01289767e-04j,  6.43086860e-04-1.05830878e-02j,
#        -8.85158410e-05+1.68137996e-03j,  1.76043090e-03-2.91632082e-02j,
#        -2.32299488e-04+3.27977429e-03j,  3.57071469e-03-5.92409792e-02j,
#        -3.50506052e-04+5.18999850e-03j,  5.46432771e-03-9.08994363e-02j,
#        -3.01902249e-04+5.99276735e-03j,  6.22565957e-03-1.03433367e-01j,
#        -2.08324508e-04+4.23830938e-03j,  4.49980240e-03-7.46982826e-02j,
#        -8.16036459e-06-9.45732612e-06j,  1.34310764e-04+2.30816505e-04j,
#        -1.12800027e-06-3.34895372e-05j,  3.21989403e-05+5.81264996e-04j,
#         1.45674199e-05-8.69305860e-05j, -2.06215934e-04+1.52669225e-03j,
#         2.36866598e-05-2.08371168e-04j, -4.41038543e-04+3.61772898e-03j,
#         2.18687718e-05-3.65821349e-04j, -3.29425403e-04+6.61212817e-03j,
#         3.75193425e-05-5.80020552e-04j, -5.80638839e-04+1.01600952e-02j,
#         4.20092927e-05-6.75957809e-04j, -8.39990777e-04+1.16675469e-02j,
#         2.97186369e-05-4.83608479e-04j, -6.17570577e-04+8.52191229e-03j,
#         5.16818695e-06-2.06915116e-05j,  1.31967647e-05-6.48405963e-04j,
#        -2.88317447e-05+3.09461663e-04j,  3.41884056e-04-5.30808189e-03j,
#        -1.28077206e-04+1.21913223e-03j,  1.30987473e-03-2.14584081e-02j,
#        -1.80309457e-04+3.41300938e-03j,  3.58424328e-03-5.91974792e-02j,
#        -4.74638482e-04+6.66064933e-03j,  7.30292684e-03-1.20308705e-01j,
#        -7.16079762e-04+1.05402035e-02j,  1.11716646e-02-1.84605193e-01j,
#        -6.17212907e-04+1.21709318e-02j,  1.27139307e-02-2.10065788e-01j,
#        -4.25397061e-04+8.60774378e-03j,  9.17956354e-03-1.51707010e-01j,
#        -1.08030686e-05+2.43738246e-05j,  1.82195036e-04-3.41748798e-04j,
#        -6.20872888e-06-3.65297832e-06j,  1.22311895e-04+5.30883348e-05j,
#         9.66547796e-06-9.19315946e-05j, -8.72783719e-05+1.62680845e-03j,
#         1.42174811e-05-2.88827046e-04j, -2.81841085e-04+5.00948297e-03j,
#         5.03230026e-05-5.62912999e-04j, -7.93969762e-04+1.01813065e-02j,
#         7.74894083e-05-8.99520529e-04j, -1.23698143e-03+1.57556418e-02j,
#         6.73335179e-05-1.06044364e-03j, -1.33610452e-03+1.83004700e-02j,
#         3.23745811e-05-7.59188693e-04j, -7.20831286e-04+1.33777207e-02j,
#         8.20181547e-06-2.91731110e-05j,  1.58179831e-05-1.04129346e-03j,
#        -4.43034143e-05+4.78162978e-04j,  5.25284148e-04-8.20307092e-03j,
#        -1.97117618e-04+1.87382692e-03j,  2.02061549e-03-3.29810404e-02j,
#        -2.77992601e-04+5.23995094e-03j,  5.52345702e-03-9.08855984e-02j,
#        -7.27425877e-04+1.02216757e-02j,  1.11906667e-02-1.84629740e-01j,
#        -1.09781774e-03+1.61749746e-02j,  1.71252457e-02-2.83294833e-01j,
#        -9.47200458e-04+1.86767570e-02j,  1.95115261e-02-3.22354133e-01j,
#        -6.53795114e-04+1.32088432e-02j,  1.41039329e-02-2.32799011e-01j,
#        -1.07549522e-06-1.04347291e-05j, -2.49452100e-06+2.95144152e-04j,
#         1.42966260e-05-4.85547625e-05j, -2.30133866e-04+8.42631963e-04j,
#         4.05790788e-05-1.41880683e-04j, -6.16489036e-04+2.49291935e-03j,
#         5.30276794e-05-3.61754655e-04j, -9.74588325e-04+6.27491484e-03j,
#         4.10401413e-05-6.68355770e-04j, -6.18726137e-04+1.20764229e-02j,
#         6.71241335e-05-1.05806094e-03j, -1.03725976e-03+1.85327568e-02j,
#         6.90268340e-05-1.22729014e-03j, -1.39991373e-03+2.11825332e-02j,
#         4.66126362e-05-8.74088092e-04j, -9.92507793e-04+1.54043974e-02j,
#         9.93244442e-06-3.57473713e-05j,  6.88132773e-06-1.13924451e-03j,
#        -4.92512489e-05+5.41069933e-04j,  5.77684944e-04-9.28091611e-03j,
#        -2.22765332e-04+2.12969342e-03j,  2.27223960e-03-3.74856074e-02j,
#        -3.14568097e-04+5.96061224e-03j,  6.25374096e-03-1.03385096e-01j,
#        -8.29621136e-04+1.16302804e-02j,  1.27672018e-02-2.10073602e-01j,
#        -1.25186845e-03+1.84045488e-02j,  1.95333746e-02-3.22344616e-01j,
#        -1.07980378e-03+2.12523714e-02j,  2.22359827e-02-3.66807901e-01j,
#        -7.44421401e-04+1.50307041e-02j,  1.60573162e-02-2.64908023e-01j,
#        -7.76775965e-07+1.86082992e-05j,  4.69657196e-06-2.54782092e-04j,
#         5.67554297e-06-3.69446604e-06j, -8.84893926e-05+5.69145579e-05j,
#         1.80528219e-05-7.57984458e-05j, -2.44828341e-04+1.33850219e-03j,
#         1.72205302e-05-2.39253067e-04j, -3.30404738e-04+4.14776942e-03j,
#         3.25108743e-05-4.74575162e-04j, -4.90552808e-04+8.57899494e-03j,
#         4.88384940e-05-7.56606860e-04j, -7.55184953e-04+1.32502974e-02j,
#         3.70121351e-05-8.87281600e-04j, -7.85066860e-04+1.53142179e-02j,
#         1.36151687e-05-6.32648981e-04j, -3.65650659e-04+1.11512024e-02j,
#         7.25415652e-06-2.40797646e-05j,  3.86341245e-06-8.53731281e-04j,
#        -3.57372238e-05+3.92855244e-04j,  4.19914912e-04-6.73949207e-03j,
#        -1.61414114e-04+1.53976333e-03j,  1.65074155e-03-2.71014762e-02j,
#        -2.28314220e-04+4.30581663e-03j,  4.53653699e-03-7.46833580e-02j,
#        -5.98738862e-04+8.39896412e-03j,  9.21369414e-03-1.51707227e-01j,
#        -9.03726876e-04+1.32907802e-02j,  1.41006817e-02-2.32780141e-01j,
#        -7.80277504e-04+1.53467386e-02j,  1.60664760e-02-2.64878957e-01j,
#        -5.38622083e-04+1.08538938e-02j,  1.16138588e-02-1.91293941e-01j]), 'E_exact': np.float64(-16.94908752138655), 'E_vqe': np.float64(-16.949000723146114), 'error': np.float64(8.67982404351153e-05), 'fidelity': np.float64(0.9999916261720952), 'tracking_overlap': np.float64(0.9999905600403943), 'layers': 4}

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HVA_Floc vs lambda different f.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    
    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,
        'psi_vqe': psi_vqe,
        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.89252645e-02
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00062205
# T = 10    Fidelity = 0.00012483
# T = 20    Fidelity = 0.00175099
# T = 30    Fidelity = 0.01676541
# T = 40    Fidelity = 0.02472290
# T = 50    Fidelity = 0.05116967
# T = 75    Fidelity = 0.37165421
# T = 100   Fidelity = 0.53313291
# T = 125   Fidelity = 0.42295351
# T = 150   Fidelity = 0.51763420
# T = 175   Fidelity = 0.59357774
# T = 200   Fidelity = 0.62116277
# T = 225   Fidelity = 0.62870010
# T = 250   Fidelity = 0.58652807
# T = 275   Fidelity = 0.66850123
# T = 300   Fidelity = 0.69074958
# T = 400   Fidelity = 0.65094738
# T = 500   Fidelity = 0.78165401
# T = 600   Fidelity = 0.79895555
# T = 700   Fidelity = 0.74459477
# T = 800   Fidelity = 0.79573474
# T = 900   Fidelity = 0.87353839
# T = 1000  Fidelity = 0.83893874
# T = 1010  Fidelity = 0.74086047
# T = 1020  Fidelity = 0.70676258
# T = 1030  Fidelity = 0.86224084
# T = 1040  Fidelity = 0.77371524
# T = 1050  Fidelity = 0.67224086
# T = 1060  Fidelity = 0.58412945
# T = 1070  Fidelity = 0.34870877
# T = 1080  Fidelity = 0.38278098
# T = 1090  Fidelity = 0.50812478
# T = 1100  Fidelity = 0.56876483
# T = 1200  Fidelity = 0.70387566
# T = 1300  Fidelity = 0.74459389
# T = 1400  Fidelity = 0.57381824
# T = 1500  Fidelity = 0.66607461
# T = 2000  Fidelity = 0.94308068
# T = 2100  Fidelity = 0.67477202
# T = 2110  Fidelity = 0.52893302
# T = 2120  Fidelity = 0.45347918
# T = 2130  Fidelity = 0.41361253
# T = 2140  Fidelity = 0.36162617
# T = 2150  Fidelity = 0.37065214
# T = 2160  Fidelity = 0.68372144
# T = 2170  Fidelity = 0.81236740
# T = 2180  Fidelity = 0.68930138
# T = 2190  Fidelity = 0.78790534
# T = 2200  Fidelity = 0.74522076
# T = 2300  Fidelity = 0.66934904
# T = 2400  Fidelity = 0.46134116
# T = 2500  Fidelity = 0.58955655
# T = 2600  Fidelity = 0.79929140
# T = 2700  Fidelity = 0.66659361
# T = 2800  Fidelity = 0.69990124
# T = 2900  Fidelity = 0.70434749
# T = 3000  Fidelity = 0.79321441
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00971153e+00
# P0     = 0.79321441
# P1     = 0.08768489
# P0+P1  = 0.88089929
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 0.311
# ================================================================================
# Minimum path gap = 8.15078413e-02
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00018546
# T = 10    Fidelity = 0.04130515
# T = 20    Fidelity = 0.33828913
# T = 30    Fidelity = 0.32764547
# T = 40    Fidelity = 0.24296538
# T = 50    Fidelity = 0.15542778
# T = 75    Fidelity = 0.07749027
# T = 100   Fidelity = 0.44304539
# T = 125   Fidelity = 0.83019042
# T = 150   Fidelity = 0.80002317
# T = 175   Fidelity = 0.44382410
# T = 200   Fidelity = 0.22319795
# T = 225   Fidelity = 0.41935384
# T = 250   Fidelity = 0.80644567
# T = 275   Fidelity = 0.96407264
# T = 300   Fidelity = 0.76350093
# T = 400   Fidelity = 0.94273350
# T = 500   Fidelity = 0.79451513
# T = 600   Fidelity = 0.85339871
# T = 700   Fidelity = 0.89607798
# T = 800   Fidelity = 0.67087067
# T = 900   Fidelity = 0.63286192
# T = 1000  Fidelity = 0.88006377
# T = 1010  Fidelity = 0.92087226
# T = 1020  Fidelity = 0.68777871
# T = 1030  Fidelity = 0.91124225
# T = 1040  Fidelity = 0.67640839
# T = 1050  Fidelity = 0.93875336
# T = 1060  Fidelity = 0.67489072
# T = 1070  Fidelity = 0.97312146
#
# Minimum T for Fidelity >= 0.97 : 1070
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 0.522
# ================================================================================
# Minimum path gap = 6.42884586e-02
# T = 1     Fidelity = 0.00004912
# T = 2     Fidelity = 0.00034320
# T = 5     Fidelity = 0.01357460
# T = 10    Fidelity = 0.11407591
# T = 20    Fidelity = 0.40473730
# T = 30    Fidelity = 0.39172236
# T = 40    Fidelity = 0.47252948
# T = 50    Fidelity = 0.48922580
# T = 75    Fidelity = 0.53804006
# T = 100   Fidelity = 0.58177090
# T = 125   Fidelity = 0.62018588
# T = 150   Fidelity = 0.65244049
# T = 175   Fidelity = 0.67810015
# T = 200   Fidelity = 0.69868126
# T = 225   Fidelity = 0.72255772
# T = 250   Fidelity = 0.73195500
# T = 275   Fidelity = 0.74791043
# T = 300   Fidelity = 0.76867472
# T = 400   Fidelity = 0.83639520
# T = 500   Fidelity = 0.82350855
# T = 600   Fidelity = 0.81746941
# T = 700   Fidelity = 0.78834201
# T = 800   Fidelity = 0.75786169
# T = 900   Fidelity = 0.70686467
# T = 1000  Fidelity = 0.82543802
# T = 1010  Fidelity = 0.86787059
# T = 1020  Fidelity = 0.85081948
# T = 1030  Fidelity = 0.67746693
# T = 1040  Fidelity = 0.75192457
# T = 1050  Fidelity = 0.71529357
# T = 1060  Fidelity = 0.61673391
# T = 1070  Fidelity = 0.77473484
# T = 1080  Fidelity = 0.74416442
# T = 1090  Fidelity = 0.73318564
# T = 1100  Fidelity = 0.81255310
# T = 1200  Fidelity = 0.62994031
# T = 1300  Fidelity = 0.67641438
# T = 1400  Fidelity = 0.88208121
# T = 1500  Fidelity = 0.80894212
# T = 2000  Fidelity = 0.84066988
# T = 2100  Fidelity = 0.77511316
# T = 2110  Fidelity = 0.73862913
# T = 2120  Fidelity = 0.61216990
# T = 2130  Fidelity = 0.85779405
# T = 2140  Fidelity = 0.72204887
# T = 2150  Fidelity = 0.83851664
# T = 2160  Fidelity = 0.84642139
# T = 2170  Fidelity = 0.74513860
# T = 2180  Fidelity = 0.79258668
# T = 2190  Fidelity = 0.83549471
# T = 2200  Fidelity = 0.72294014
# T = 2300  Fidelity = 0.83706129
# T = 2400  Fidelity = 0.77194706
# T = 2500  Fidelity = 0.67267728
# T = 2600  Fidelity = 0.79185163
# T = 2700  Fidelity = 0.87161065
# T = 2800  Fidelity = 0.72288151
# T = 2900  Fidelity = 0.84914964
# T = 3000  Fidelity = 0.76383315
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04786421e+00
# P0     = 0.76383315
# P1     = 0.00120917
# P0+P1  = 0.76504232
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 0.733
# ================================================================================
# Minimum path gap = 5.29940229e-02
# T = 1     Fidelity = 0.00140430
# T = 2     Fidelity = 0.00514256
# T = 5     Fidelity = 0.05168973
# T = 10    Fidelity = 0.19197999
# T = 20    Fidelity = 0.46003966
# T = 30    Fidelity = 0.53145741
# T = 40    Fidelity = 0.55908889
# T = 50    Fidelity = 0.59119700
# T = 75    Fidelity = 0.64135784
# T = 100   Fidelity = 0.68642992
# T = 125   Fidelity = 0.72980272
# T = 150   Fidelity = 0.76801499
# T = 175   Fidelity = 0.80253313
# T = 200   Fidelity = 0.82934334
# T = 225   Fidelity = 0.85596689
# T = 250   Fidelity = 0.87625362
# T = 275   Fidelity = 0.89542804
# T = 300   Fidelity = 0.90891293
# T = 400   Fidelity = 0.94523167
# T = 500   Fidelity = 0.96534036
# T = 600   Fidelity = 0.87782981
# T = 700   Fidelity = 0.92164417
# T = 800   Fidelity = 0.89880280
# T = 900   Fidelity = 0.96954055
# T = 1000  Fidelity = 0.78005331
# T = 1010  Fidelity = 0.86142877
# T = 1020  Fidelity = 0.90554517
# T = 1030  Fidelity = 0.96155606
# T = 1040  Fidelity = 0.97248836
#
# Minimum T for Fidelity >= 0.97 : 1040
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.89992186e-02
# T = 1     Fidelity = 0.01352655
# T = 2     Fidelity = 0.03594366
# T = 5     Fidelity = 0.14323679
# T = 10    Fidelity = 0.30544875
# T = 20    Fidelity = 0.48732160
# T = 30    Fidelity = 0.53725683
# T = 40    Fidelity = 0.57022543
# T = 50    Fidelity = 0.60914894
# T = 75    Fidelity = 0.66505279
# T = 100   Fidelity = 0.69651380
# T = 125   Fidelity = 0.72830109
# T = 150   Fidelity = 0.75586640
# T = 175   Fidelity = 0.78039241
# T = 200   Fidelity = 0.80460904
# T = 225   Fidelity = 0.82643135
# T = 250   Fidelity = 0.84946688
# T = 275   Fidelity = 0.86883608
# T = 300   Fidelity = 0.87176423
# T = 400   Fidelity = 0.93695064
# T = 500   Fidelity = 0.94953486
# T = 600   Fidelity = 0.91513390
# T = 700   Fidelity = 0.93006866
# T = 800   Fidelity = 0.88579225
# T = 900   Fidelity = 0.95149680
# T = 1000  Fidelity = 0.80123101
# T = 1010  Fidelity = 0.89131297
# T = 1020  Fidelity = 0.94722953
# T = 1030  Fidelity = 0.96477567
# T = 1040  Fidelity = 0.92454602
# T = 1050  Fidelity = 0.88636084
# T = 1060  Fidelity = 0.90361624
# T = 1070  Fidelity = 0.93563173
# T = 1080  Fidelity = 0.86237721
# T = 1090  Fidelity = 0.66906065
# T = 1100  Fidelity = 0.62195426
# T = 1200  Fidelity = 0.91918521
# T = 1300  Fidelity = 0.79609752
# T = 1400  Fidelity = 0.93566668
# T = 1500  Fidelity = 0.96337278
# T = 2000  Fidelity = 0.98175973
#
# Minimum T for Fidelity >= 0.97 : 2000
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 1.156
# ================================================================================
# Minimum path gap = 6.23933661e-02
# T = 1     Fidelity = 0.06734840
# T = 2     Fidelity = 0.14187764
# T = 5     Fidelity = 0.33268775
# T = 10    Fidelity = 0.51522146
# T = 20    Fidelity = 0.65631358
# T = 30    Fidelity = 0.68445337
# T = 40    Fidelity = 0.69304528
# T = 50    Fidelity = 0.70755244
# T = 75    Fidelity = 0.74233604
# T = 100   Fidelity = 0.76353222
# T = 125   Fidelity = 0.77642260
# T = 150   Fidelity = 0.78527747
# T = 175   Fidelity = 0.79144428
# T = 200   Fidelity = 0.79835780
# T = 225   Fidelity = 0.80070193
# T = 250   Fidelity = 0.80424228
# T = 275   Fidelity = 0.81227128
# T = 300   Fidelity = 0.82673917
# T = 400   Fidelity = 0.85675579
# T = 500   Fidelity = 0.86691156
# T = 600   Fidelity = 0.88912809
# T = 700   Fidelity = 0.84418867
# T = 800   Fidelity = 0.94686608
# T = 900   Fidelity = 0.93323639
# T = 1000  Fidelity = 0.91479307
# T = 1010  Fidelity = 0.92162916
# T = 1020  Fidelity = 0.93871808
# T = 1030  Fidelity = 0.91353931
# T = 1040  Fidelity = 0.80492579
# T = 1050  Fidelity = 0.85598969
# T = 1060  Fidelity = 0.82869258
# T = 1070  Fidelity = 0.88936152
# T = 1080  Fidelity = 0.92771408
# T = 1090  Fidelity = 0.91946290
# T = 1100  Fidelity = 0.93437618
# T = 1200  Fidelity = 0.90897097
# T = 1300  Fidelity = 0.81404439
# T = 1400  Fidelity = 0.90238566
# T = 1500  Fidelity = 0.91528988
# T = 2000  Fidelity = 0.86340274
# T = 2100  Fidelity = 0.94178998
# T = 2110  Fidelity = 0.93048502
# T = 2120  Fidelity = 0.93881120
# T = 2130  Fidelity = 0.93994555
# T = 2140  Fidelity = 0.93146766
# T = 2150  Fidelity = 0.86884328
# T = 2160  Fidelity = 0.89116234
# T = 2170  Fidelity = 0.93154194
# T = 2180  Fidelity = 0.93498334
# T = 2190  Fidelity = 0.96137244
# T = 2200  Fidelity = 0.95024471
# T = 2300  Fidelity = 0.96143843
# T = 2400  Fidelity = 0.95295637
# T = 2500  Fidelity = 0.89344268
# T = 2600  Fidelity = 0.93562875
# T = 2700  Fidelity = 0.88522154
# T = 2800  Fidelity = 0.89274431
# T = 2900  Fidelity = 0.96706949
# T = 3000  Fidelity = 0.88117008
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.09850825e+00
# P0     = 0.88117008
# P1     = 0.03747841
# P0+P1  = 0.91864849
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.76187631e-02
# T = 1     Fidelity = 0.16447860
# T = 2     Fidelity = 0.29627785
# T = 5     Fidelity = 0.52755700
# T = 10    Fidelity = 0.69680884
# T = 20    Fidelity = 0.80746668
# T = 30    Fidelity = 0.83698177
# T = 40    Fidelity = 0.84729985
# T = 50    Fidelity = 0.85579105
# T = 75    Fidelity = 0.87633454
# T = 100   Fidelity = 0.89231184
# T = 125   Fidelity = 0.90212916
# T = 150   Fidelity = 0.90866107
# T = 175   Fidelity = 0.91417892
# T = 200   Fidelity = 0.92096559
# T = 225   Fidelity = 0.92012354
# T = 250   Fidelity = 0.92045284
# T = 275   Fidelity = 0.93032136
# T = 300   Fidelity = 0.92121932
# T = 400   Fidelity = 0.93823215
# T = 500   Fidelity = 0.94630639
# T = 600   Fidelity = 0.92353057
# T = 700   Fidelity = 0.88035072
# T = 800   Fidelity = 0.94338937
# T = 900   Fidelity = 0.91890649
# T = 1000  Fidelity = 0.94064544
# T = 1010  Fidelity = 0.97188352
#
# Minimum T for Fidelity >= 0.97 : 1010
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.27763034e-01
# T = 1     Fidelity = 0.27308534
# T = 2     Fidelity = 0.44139634
# T = 5     Fidelity = 0.66831904
# T = 10    Fidelity = 0.80753586
# T = 20    Fidelity = 0.88856281
# T = 30    Fidelity = 0.91254176
# T = 40    Fidelity = 0.92551228
# T = 50    Fidelity = 0.93512683
# T = 75    Fidelity = 0.94973152
# T = 100   Fidelity = 0.96015129
# T = 125   Fidelity = 0.96632842
# T = 150   Fidelity = 0.97188176
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.75077570e-01
# T = 1     Fidelity = 0.37415314
# T = 2     Fidelity = 0.55986527
# T = 5     Fidelity = 0.76354349
# T = 10    Fidelity = 0.87392523
# T = 20    Fidelity = 0.93222183
# T = 30    Fidelity = 0.95090331
# T = 40    Fidelity = 0.96273108
# T = 50    Fidelity = 0.96880814
# T = 75    Fidelity = 0.97913895
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.01
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.20753697e-01
# T = 1     Fidelity = 0.46072940
# T = 2     Fidelity = 0.65126267
# T = 5     Fidelity = 0.82730397
# T = 10    Fidelity = 0.91447986
# T = 20    Fidelity = 0.95720977
# T = 30    Fidelity = 0.97211211
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00037992
# T = 10    Fidelity = 0.00052752
# T = 20    Fidelity = 0.01188855
# T = 30    Fidelity = 0.08146006
# T = 40    Fidelity = 0.18814453
# T = 50    Fidelity = 0.42906461
# T = 75    Fidelity = 0.56627396
# T = 100   Fidelity = 0.72824145
# T = 125   Fidelity = 0.80795576
# T = 150   Fidelity = 0.83668131
# T = 175   Fidelity = 0.90616724
# T = 200   Fidelity = 0.91940816
# T = 225   Fidelity = 0.96682213
# T = 250   Fidelity = 0.89096942
# T = 275   Fidelity = 0.96866572
# T = 300   Fidelity = 0.85562590
# T = 400   Fidelity = 0.98046685
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000023
# T = 2     Fidelity = 0.00000010
# T = 5     Fidelity = 0.00047258
# T = 10    Fidelity = 0.06617582
# T = 20    Fidelity = 0.21738407
# T = 30    Fidelity = 0.62595477
# T = 40    Fidelity = 0.35231725
# T = 50    Fidelity = 0.78814706
# T = 75    Fidelity = 0.74250576
# T = 100   Fidelity = 0.79406480
# T = 125   Fidelity = 0.87543373
# T = 150   Fidelity = 0.87837517
# T = 175   Fidelity = 0.89843912
# T = 200   Fidelity = 0.92391852
# T = 225   Fidelity = 0.93314852
# T = 250   Fidelity = 0.94355547
# T = 275   Fidelity = 0.94880447
# T = 300   Fidelity = 0.94606377
# T = 400   Fidelity = 0.97177372
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00004805
# T = 2     Fidelity = 0.00025315
# T = 5     Fidelity = 0.01863246
# T = 10    Fidelity = 0.22561258
# T = 20    Fidelity = 0.57987032
# T = 30    Fidelity = 0.66275751
# T = 40    Fidelity = 0.78557917
# T = 50    Fidelity = 0.82136200
# T = 75    Fidelity = 0.92375259
# T = 100   Fidelity = 0.96315984
# T = 125   Fidelity = 0.98039374
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00122269
# T = 2     Fidelity = 0.00499218
# T = 5     Fidelity = 0.06228661
# T = 10    Fidelity = 0.28112555
# T = 20    Fidelity = 0.67919111
# T = 30    Fidelity = 0.73600539
# T = 40    Fidelity = 0.81976842
# T = 50    Fidelity = 0.88702707
# T = 75    Fidelity = 0.95417039
# T = 100   Fidelity = 0.98166303
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00855365
# T = 2     Fidelity = 0.02356128
# T = 5     Fidelity = 0.12528905
# T = 10    Fidelity = 0.34155783
# T = 20    Fidelity = 0.67056155
# T = 30    Fidelity = 0.79869191
# T = 40    Fidelity = 0.85957145
# T = 50    Fidelity = 0.90950465
# T = 75    Fidelity = 0.97036109
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03427898
# T = 2     Fidelity = 0.07350277
# T = 5     Fidelity = 0.22272137
# T = 10    Fidelity = 0.42822474
# T = 20    Fidelity = 0.67849317
# T = 30    Fidelity = 0.80048243
# T = 40    Fidelity = 0.86966301
# T = 50    Fidelity = 0.91686826
# T = 75    Fidelity = 0.97801709
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09410196
# T = 2     Fidelity = 0.17210264
# T = 5     Fidelity = 0.36339798
# T = 10    Fidelity = 0.55412933
# T = 20    Fidelity = 0.74136102
# T = 30    Fidelity = 0.83148552
# T = 40    Fidelity = 0.88406258
# T = 50    Fidelity = 0.91868119
# T = 75    Fidelity = 0.96672536
# T = 100   Fidelity = 0.98543895
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19089360
# T = 2     Fidelity = 0.31235971
# T = 5     Fidelity = 0.52477833
# T = 10    Fidelity = 0.69146582
# T = 20    Fidelity = 0.82751199
# T = 30    Fidelity = 0.88737871
# T = 40    Fidelity = 0.92188816
# T = 50    Fidelity = 0.94357960
# T = 75    Fidelity = 0.97016145
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30083909
# T = 2     Fidelity = 0.45453320
# T = 5     Fidelity = 0.66203697
# T = 10    Fidelity = 0.79886248
# T = 20    Fidelity = 0.89486825
# T = 30    Fidelity = 0.93358027
# T = 40    Fidelity = 0.95517687
# T = 50    Fidelity = 0.96720429
# T = 75    Fidelity = 0.98297217
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.05
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40227233
# T = 2     Fidelity = 0.57283469
# T = 5     Fidelity = 0.76045135
# T = 10    Fidelity = 0.86916384
# T = 20    Fidelity = 0.93654885
# T = 30    Fidelity = 0.96224941
# T = 40    Fidelity = 0.97433766
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.19189911e-02
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063665
# T = 10    Fidelity = 0.00011375
# T = 20    Fidelity = 0.00396196
# T = 30    Fidelity = 0.05490089
# T = 40    Fidelity = 0.12003052
# T = 50    Fidelity = 0.20524971
# T = 75    Fidelity = 0.55221532
# T = 100   Fidelity = 0.71372751
# T = 125   Fidelity = 0.66790406
# T = 150   Fidelity = 0.77038310
# T = 175   Fidelity = 0.79076797
# T = 200   Fidelity = 0.73234712
# T = 225   Fidelity = 0.77948139
# T = 250   Fidelity = 0.79442313
# T = 275   Fidelity = 0.76894207
# T = 300   Fidelity = 0.64432175
# T = 400   Fidelity = 0.61762357
# T = 500   Fidelity = 0.56123441
# T = 600   Fidelity = 0.48675879
# T = 700   Fidelity = 0.46612774
# T = 800   Fidelity = 0.38214010
# T = 900   Fidelity = 0.37012561
# T = 1000  Fidelity = 0.29325517
# T = 1010  Fidelity = 0.30733328
# T = 1020  Fidelity = 0.29264463
# T = 1030  Fidelity = 0.33023561
# T = 1040  Fidelity = 0.40442368
# T = 1050  Fidelity = 0.35819790
# T = 1060  Fidelity = 0.33117385
# T = 1070  Fidelity = 0.26799952
# T = 1080  Fidelity = 0.14949248
# T = 1090  Fidelity = 0.14996793
# T = 1100  Fidelity = 0.15556158
# T = 1200  Fidelity = 0.17508012
# T = 1300  Fidelity = 0.31486481
# T = 1400  Fidelity = 0.26680521
# T = 1500  Fidelity = 0.16655155
# T = 2000  Fidelity = 0.01881506
# T = 2100  Fidelity = 0.45787254
# T = 2110  Fidelity = 0.43536733
# T = 2120  Fidelity = 0.54681992
# T = 2130  Fidelity = 0.54676380
# T = 2140  Fidelity = 0.55420279
# T = 2150  Fidelity = 0.51541972
# T = 2160  Fidelity = 0.50926952
# T = 2170  Fidelity = 0.40428567
# T = 2180  Fidelity = 0.23791935
# T = 2190  Fidelity = 0.10550798
# T = 2200  Fidelity = 0.20102411
# T = 2300  Fidelity = 0.23505754
# T = 2400  Fidelity = 0.56452306
# T = 2500  Fidelity = 0.44952103
# T = 2600  Fidelity = 0.52650952
# T = 2700  Fidelity = 0.38388598
# T = 2800  Fidelity = 0.58814739
# T = 2900  Fidelity = 0.55982384
# T = 3000  Fidelity = 0.48593394
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00970923e+00
# P0     = 0.48593394
# P1     = 0.24995263
# P0+P1  = 0.73588658
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.00749492e-02
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00018107
# T = 10    Fidelity = 0.04086790
# T = 20    Fidelity = 0.42008510
# T = 30    Fidelity = 0.48784475
# T = 40    Fidelity = 0.63572555
# T = 50    Fidelity = 0.63512809
# T = 75    Fidelity = 0.85381154
# T = 100   Fidelity = 0.85252502
# T = 125   Fidelity = 0.79722262
# T = 150   Fidelity = 0.77921828
# T = 175   Fidelity = 0.77470886
# T = 200   Fidelity = 0.75316099
# T = 225   Fidelity = 0.72160730
# T = 250   Fidelity = 0.67145710
# T = 275   Fidelity = 0.63407529
# T = 300   Fidelity = 0.57479459
# T = 400   Fidelity = 0.41009493
# T = 500   Fidelity = 0.24414130
# T = 600   Fidelity = 0.13487742
# T = 700   Fidelity = 0.05220153
# T = 800   Fidelity = 0.05621100
# T = 900   Fidelity = 0.15745386
# T = 1000  Fidelity = 0.18752169
# T = 1010  Fidelity = 0.21905458
# T = 1020  Fidelity = 0.24675733
# T = 1030  Fidelity = 0.22431493
# T = 1040  Fidelity = 0.28369336
# T = 1050  Fidelity = 0.26296319
# T = 1060  Fidelity = 0.24329466
# T = 1070  Fidelity = 0.31140102
# T = 1080  Fidelity = 0.26587433
# T = 1090  Fidelity = 0.35407968
# T = 1100  Fidelity = 0.29604368
# T = 1200  Fidelity = 0.39381271
# T = 1300  Fidelity = 0.57539183
# T = 1400  Fidelity = 0.54625604
# T = 1500  Fidelity = 0.50122324
# T = 2000  Fidelity = 0.64536058
# T = 2100  Fidelity = 0.55032260
# T = 2110  Fidelity = 0.64447858
# T = 2120  Fidelity = 0.69198429
# T = 2130  Fidelity = 0.51987124
# T = 2140  Fidelity = 0.55546968
# T = 2150  Fidelity = 0.67899993
# T = 2160  Fidelity = 0.45313481
# T = 2170  Fidelity = 0.61628726
# T = 2180  Fidelity = 0.53381184
# T = 2190  Fidelity = 0.62227283
# T = 2200  Fidelity = 0.31335600
# T = 2300  Fidelity = 0.50928533
# T = 2400  Fidelity = 0.40278884
# T = 2500  Fidelity = 0.47365677
# T = 2600  Fidelity = 0.07644876
# T = 2700  Fidelity = 0.35709402
# T = 2800  Fidelity = 0.26236737
# T = 2900  Fidelity = 0.45234016
# T = 3000  Fidelity = 0.63419190
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02931064e+00
# P0     = 0.63419190
# P1     = 0.23834961
# P0+P1  = 0.87254151
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 0.522
# ================================================================================
# Minimum path gap = 6.48270242e-03
# T = 1     Fidelity = 0.00001190
# T = 2     Fidelity = 0.00016881
# T = 5     Fidelity = 0.01432917
# T = 10    Fidelity = 0.17107586
# T = 20    Fidelity = 0.44156809
# T = 30    Fidelity = 0.33929504
# T = 40    Fidelity = 0.54405230
# T = 50    Fidelity = 0.43520803
# T = 75    Fidelity = 0.48532505
# T = 100   Fidelity = 0.48894963
# T = 125   Fidelity = 0.48168012
# T = 150   Fidelity = 0.47242354
# T = 175   Fidelity = 0.46205279
# T = 200   Fidelity = 0.44733753
# T = 225   Fidelity = 0.44643475
# T = 250   Fidelity = 0.42673216
# T = 275   Fidelity = 0.40125332
# T = 300   Fidelity = 0.38737699
# T = 400   Fidelity = 0.33436054
# T = 500   Fidelity = 0.14014273
# T = 600   Fidelity = 0.21647014
# T = 700   Fidelity = 0.10587357
# T = 800   Fidelity = 0.10653451
# T = 900   Fidelity = 0.07806678
# T = 1000  Fidelity = 0.14735910
# T = 1010  Fidelity = 0.00250903
# T = 1020  Fidelity = 0.08166823
# T = 1030  Fidelity = 0.02355366
# T = 1040  Fidelity = 0.03958653
# T = 1050  Fidelity = 0.00333614
# T = 1060  Fidelity = 0.06456208
# T = 1070  Fidelity = 0.02601816
# T = 1080  Fidelity = 0.00288543
# T = 1090  Fidelity = 0.07530839
# T = 1100  Fidelity = 0.03031933
# T = 1200  Fidelity = 0.00175648
# T = 1300  Fidelity = 0.00421941
# T = 1400  Fidelity = 0.08884608
# T = 1500  Fidelity = 0.19779862
# T = 2000  Fidelity = 0.34534357
# T = 2100  Fidelity = 0.53358155
# T = 2110  Fidelity = 0.37522763
# T = 2120  Fidelity = 0.40188914
# T = 2130  Fidelity = 0.35055692
# T = 2140  Fidelity = 0.50302817
# T = 2150  Fidelity = 0.40966095
# T = 2160  Fidelity = 0.42628639
# T = 2170  Fidelity = 0.46711770
# T = 2180  Fidelity = 0.23695768
# T = 2190  Fidelity = 0.52181150
# T = 2200  Fidelity = 0.31417936
# T = 2300  Fidelity = 0.19641479
# T = 2400  Fidelity = 0.40583467
# T = 2500  Fidelity = 0.30261005
# T = 2600  Fidelity = 0.39185736
# T = 2700  Fidelity = 0.28550712
# T = 2800  Fidelity = 0.17783904
# T = 2900  Fidelity = 0.20829544
# T = 3000  Fidelity = 0.13981504
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785507e+00
# P0     = 0.13981504
# P1     = 0.24195861
# P0+P1  = 0.38177365
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 0.733
# ================================================================================
# Minimum path gap = 6.72272568e-03
# T = 1     Fidelity = 0.00307359
# T = 2     Fidelity = 0.01239366
# T = 5     Fidelity = 0.08438618
# T = 10    Fidelity = 0.22338584
# T = 20    Fidelity = 0.31744149
# T = 30    Fidelity = 0.38251885
# T = 40    Fidelity = 0.54850124
# T = 50    Fidelity = 0.57853955
# T = 75    Fidelity = 0.49625357
# T = 100   Fidelity = 0.51455384
# T = 125   Fidelity = 0.51265886
# T = 150   Fidelity = 0.50839475
# T = 175   Fidelity = 0.50064360
# T = 200   Fidelity = 0.50565485
# T = 225   Fidelity = 0.49280819
# T = 250   Fidelity = 0.48229035
# T = 275   Fidelity = 0.48402860
# T = 300   Fidelity = 0.44751952
# T = 400   Fidelity = 0.43034196
# T = 500   Fidelity = 0.43576376
# T = 600   Fidelity = 0.37489232
# T = 700   Fidelity = 0.26988537
# T = 800   Fidelity = 0.23501773
# T = 900   Fidelity = 0.34366287
# T = 1000  Fidelity = 0.38550667
# T = 1010  Fidelity = 0.14980738
# T = 1020  Fidelity = 0.02817240
# T = 1030  Fidelity = 0.34878408
# T = 1040  Fidelity = 0.41571072
# T = 1050  Fidelity = 0.23111111
# T = 1060  Fidelity = 0.18184308
# T = 1070  Fidelity = 0.17531550
# T = 1080  Fidelity = 0.12141385
# T = 1090  Fidelity = 0.11645417
# T = 1100  Fidelity = 0.41677746
# T = 1200  Fidelity = 0.18805550
# T = 1300  Fidelity = 0.10252323
# T = 1400  Fidelity = 0.11167488
# T = 1500  Fidelity = 0.12818440
# T = 2000  Fidelity = 0.14576041
# T = 2100  Fidelity = 0.05422706
# T = 2110  Fidelity = 0.08169918
# T = 2120  Fidelity = 0.09873723
# T = 2130  Fidelity = 0.15552409
# T = 2140  Fidelity = 0.21489111
# T = 2150  Fidelity = 0.05590240
# T = 2160  Fidelity = 0.02081673
# T = 2170  Fidelity = 0.16504564
# T = 2180  Fidelity = 0.23096920
# T = 2190  Fidelity = 0.16417980
# T = 2200  Fidelity = 0.03378107
# T = 2300  Fidelity = 0.16228989
# T = 2400  Fidelity = 0.05606827
# T = 2500  Fidelity = 0.10617131
# T = 2600  Fidelity = 0.16933454
# T = 2700  Fidelity = 0.16420842
# T = 2800  Fidelity = 0.21369615
# T = 2900  Fidelity = 0.27172569
# T = 3000  Fidelity = 0.32852282
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549323e+00
# P0     = 0.32852282
# P1     = 0.25713117
# P0+P1  = 0.58565400
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.58401304e-03
# T = 1     Fidelity = 0.02404706
# T = 2     Fidelity = 0.06508395
# T = 5     Fidelity = 0.21863365
# T = 10    Fidelity = 0.40588468
# T = 20    Fidelity = 0.52803881
# T = 30    Fidelity = 0.49671405
# T = 40    Fidelity = 0.50271940
# T = 50    Fidelity = 0.54790347
# T = 75    Fidelity = 0.60640151
# T = 100   Fidelity = 0.60383684
# T = 125   Fidelity = 0.60761268
# T = 150   Fidelity = 0.61009368
# T = 175   Fidelity = 0.61171329
# T = 200   Fidelity = 0.61684943
# T = 225   Fidelity = 0.61753433
# T = 250   Fidelity = 0.61913591
# T = 275   Fidelity = 0.61383512
# T = 300   Fidelity = 0.62655706
# T = 400   Fidelity = 0.56551498
# T = 500   Fidelity = 0.61344248
# T = 600   Fidelity = 0.62241304
# T = 700   Fidelity = 0.53482942
# T = 800   Fidelity = 0.63723006
# T = 900   Fidelity = 0.50583427
# T = 1000  Fidelity = 0.40143822
# T = 1010  Fidelity = 0.66097952
# T = 1020  Fidelity = 0.72215282
# T = 1030  Fidelity = 0.60338484
# T = 1040  Fidelity = 0.41238405
# T = 1050  Fidelity = 0.37769006
# T = 1060  Fidelity = 0.56033298
# T = 1070  Fidelity = 0.64823957
# T = 1080  Fidelity = 0.67077931
# T = 1090  Fidelity = 0.41716232
# T = 1100  Fidelity = 0.29599822
# T = 1200  Fidelity = 0.36943651
# T = 1300  Fidelity = 0.41601170
# T = 1400  Fidelity = 0.57624412
# T = 1500  Fidelity = 0.49397649
# T = 2000  Fidelity = 0.51914917
# T = 2100  Fidelity = 0.58047587
# T = 2110  Fidelity = 0.50607198
# T = 2120  Fidelity = 0.31798468
# T = 2130  Fidelity = 0.45916870
# T = 2140  Fidelity = 0.51650493
# T = 2150  Fidelity = 0.59542700
# T = 2160  Fidelity = 0.57226373
# T = 2170  Fidelity = 0.45038149
# T = 2180  Fidelity = 0.30386875
# T = 2190  Fidelity = 0.39714140
# T = 2200  Fidelity = 0.51442800
# T = 2300  Fidelity = 0.41930462
# T = 2400  Fidelity = 0.47393287
# T = 2500  Fidelity = 0.51342098
# T = 2600  Fidelity = 0.43715595
# T = 2700  Fidelity = 0.52499785
# T = 2800  Fidelity = 0.42637943
# T = 2900  Fidelity = 0.42389460
# T = 3000  Fidelity = 0.50422823
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234181e+00
# P0     = 0.50422823
# P1     = 0.28793080
# P0+P1  = 0.79215903
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.59823446e-02
# T = 1     Fidelity = 0.08296053
# T = 2     Fidelity = 0.17497965
# T = 5     Fidelity = 0.39208508
# T = 10    Fidelity = 0.58548687
# T = 20    Fidelity = 0.71351077
# T = 30    Fidelity = 0.71990754
# T = 40    Fidelity = 0.71259815
# T = 50    Fidelity = 0.71820638
# T = 75    Fidelity = 0.74310973
# T = 100   Fidelity = 0.76084725
# T = 125   Fidelity = 0.77299251
# T = 150   Fidelity = 0.78282947
# T = 175   Fidelity = 0.79126016
# T = 200   Fidelity = 0.79965900
# T = 225   Fidelity = 0.80505116
# T = 250   Fidelity = 0.80993486
# T = 275   Fidelity = 0.81887061
# T = 300   Fidelity = 0.80999496
# T = 400   Fidelity = 0.86366033
# T = 500   Fidelity = 0.85745924
# T = 600   Fidelity = 0.77996981
# T = 700   Fidelity = 0.81174575
# T = 800   Fidelity = 0.82893416
# T = 900   Fidelity = 0.83530507
# T = 1000  Fidelity = 0.85388416
# T = 1010  Fidelity = 0.77137139
# T = 1020  Fidelity = 0.76368120
# T = 1030  Fidelity = 0.85190023
# T = 1040  Fidelity = 0.93449313
# T = 1050  Fidelity = 0.94966221
# T = 1060  Fidelity = 0.91013155
# T = 1070  Fidelity = 0.80517046
# T = 1080  Fidelity = 0.81964510
# T = 1090  Fidelity = 0.74990095
# T = 1100  Fidelity = 0.81166041
# T = 1200  Fidelity = 0.77577967
# T = 1300  Fidelity = 0.93545181
# T = 1400  Fidelity = 0.83657121
# T = 1500  Fidelity = 0.91181529
# T = 2000  Fidelity = 0.84692576
# T = 2100  Fidelity = 0.85767651
# T = 2110  Fidelity = 0.85299936
# T = 2120  Fidelity = 0.90756777
# T = 2130  Fidelity = 0.84569726
# T = 2140  Fidelity = 0.86624894
# T = 2150  Fidelity = 0.79340206
# T = 2160  Fidelity = 0.83191254
# T = 2170  Fidelity = 0.94747307
# T = 2180  Fidelity = 0.92495714
# T = 2190  Fidelity = 0.92314613
# T = 2200  Fidelity = 0.92641940
# T = 2300  Fidelity = 0.93709056
# T = 2400  Fidelity = 0.96544259
# T = 2500  Fidelity = 0.95430809
# T = 2600  Fidelity = 0.97329992
#
# Minimum T for Fidelity >= 0.97 : 2600
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.79487559e-02
# T = 1     Fidelity = 0.17544915
# T = 2     Fidelity = 0.31599214
# T = 5     Fidelity = 0.55506831
# T = 10    Fidelity = 0.72470734
# T = 20    Fidelity = 0.82923773
# T = 30    Fidelity = 0.85283230
# T = 40    Fidelity = 0.85864237
# T = 50    Fidelity = 0.86427165
# T = 75    Fidelity = 0.88153339
# T = 100   Fidelity = 0.89766807
# T = 125   Fidelity = 0.90891503
# T = 150   Fidelity = 0.91709006
# T = 175   Fidelity = 0.92460594
# T = 200   Fidelity = 0.93357849
# T = 225   Fidelity = 0.93456710
# T = 250   Fidelity = 0.93479666
# T = 275   Fidelity = 0.94405425
# T = 300   Fidelity = 0.93403318
# T = 400   Fidelity = 0.94812536
# T = 500   Fidelity = 0.95120465
# T = 600   Fidelity = 0.95877644
# T = 700   Fidelity = 0.91401495
# T = 800   Fidelity = 0.92718424
# T = 900   Fidelity = 0.94563799
# T = 1000  Fidelity = 0.93897057
# T = 1010  Fidelity = 0.95180442
# T = 1020  Fidelity = 0.95648488
# T = 1030  Fidelity = 0.97859546
#
# Minimum T for Fidelity >= 0.97 : 1030
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20269526e-01
# T = 1     Fidelity = 0.28016268
# T = 2     Fidelity = 0.45258875
# T = 5     Fidelity = 0.68119338
# T = 10    Fidelity = 0.81892616
# T = 20    Fidelity = 0.89641459
# T = 30    Fidelity = 0.91791125
# T = 40    Fidelity = 0.92928237
# T = 50    Fidelity = 0.93795448
# T = 75    Fidelity = 0.95164834
# T = 100   Fidelity = 0.96190939
# T = 125   Fidelity = 0.96831781
# T = 150   Fidelity = 0.97417313
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71442616e-01
# T = 1     Fidelity = 0.37872989
# T = 2     Fidelity = 0.56647687
# T = 5     Fidelity = 0.77007933
# T = 10    Fidelity = 0.87906812
# T = 20    Fidelity = 0.93527912
# T = 30    Fidelity = 0.95278629
# T = 40    Fidelity = 0.96400312
# T = 50    Fidelity = 0.96968684
# T = 75    Fidelity = 0.97960068
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised f=0.001
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18862496e-01
# T = 1     Fidelity = 0.46384408
# T = 2     Fidelity = 0.65543672
# T = 5     Fidelity = 0.83091731
# T = 10    Fidelity = 0.91702632
# T = 20    Fidelity = 0.95850942
# T = 30    Fidelity = 0.97284190
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Weak SSB optimised f=0.010.100     None      0.9430806842      8.89252645e-02    0.793214    0.087685    0.880899
# Weak SSB optimised f=0.010.311     1070      0.9731214622      8.15078413e-02    None        None        None
# Weak SSB optimised f=0.010.522     None      0.8820812076      6.42884586e-02    0.763833    0.001209    0.765042
# Weak SSB optimised f=0.010.733     1040      0.9724883592      5.29940229e-02    None        None        None
# Weak SSB optimised f=0.010.944     2000      0.9817597323      4.89992186e-02    None        None        None
# Weak SSB optimised f=0.011.156     None      0.9670694891      6.23933661e-02    0.88117     0.037478    0.918648
# Weak SSB optimised f=0.011.367     1010      0.9718835233      8.76187631e-02    None        None        None
# Weak SSB optimised f=0.011.578     150       0.9718817619      1.27763034e-01    None        None        None
# Weak SSB optimised f=0.011.789     75        0.9791389528      1.75077570e-01    None        None        None
# Weak SSB optimised f=0.012.000     30        0.9721121099      2.20753697e-01    None        None        None
# Weak SSB optimised f=0.050.100     400       0.9804668501      2.42819099e-01    None        None        None
# Weak SSB optimised f=0.050.311     400       0.9717737176      2.61171322e-01    None        None        None
# Weak SSB optimised f=0.050.522     125       0.9803937440      2.64873214e-01    None        None        None
# Weak SSB optimised f=0.050.733     100       0.9816630271      2.64154074e-01    None        None        None
# Weak SSB optimised f=0.050.944     75        0.9703610889      2.26024680e-01    None        None        None
# Weak SSB optimised f=0.051.156     75        0.9780170875      2.01656789e-01    None        None        None
# Weak SSB optimised f=0.051.367     100       0.9854389467      1.93673930e-01    None        None        None
# Weak SSB optimised f=0.051.578     75        0.9701614513      2.03071995e-01    None        None        None
# Weak SSB optimised f=0.051.789     75        0.9829721709      2.25515049e-01    None        None        None
# Weak SSB optimised f=0.052.000     40        0.9743376606      2.55131735e-01    None        None        None
# Weak SSB optimised f=0.0010.100     None      0.7944231310      1.19189911e-02    0.485934    0.249953    0.735887
# Weak SSB optimised f=0.0010.311     None      0.8538115357      1.00749492e-02    0.634192    0.23835     0.872542
# Weak SSB optimised f=0.0010.522     None      0.5440523000      6.48270242e-03    0.139815    0.241959    0.381774
# Weak SSB optimised f=0.0010.733     None      0.5785395520      6.72272568e-03    0.328523    0.257131    0.585654
# Weak SSB optimised f=0.0010.944     None      0.7221528155      9.58401304e-03    0.504228    0.287931    0.792159
# Weak SSB optimised f=0.0011.156     2600      0.9732999161      2.59823446e-02    None        None        None
# Weak SSB optimised f=0.0011.367     1030      0.9785954618      6.79487559e-02    None        None        None
# Weak SSB optimised f=0.0011.578     150       0.9741731320      1.20269526e-01    None        None        None
# Weak SSB optimised f=0.0011.789     75        0.9796006847      1.71442616e-01    None        None        None
# Weak SSB optimised f=0.0012.000     30        0.9728418973      2.18862496e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.savefig(
    "HVA_adiabatic time vs lambda different f.pdf",
    bbox_inches='tight'
)

plt.show()
