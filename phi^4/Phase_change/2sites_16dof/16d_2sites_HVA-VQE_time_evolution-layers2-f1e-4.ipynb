# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756847
# State dimension     = (256,)
# Norm                = 1.0000000000000002

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_asymm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):
            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_symm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Multi-parameter scan
# HVA + warm-start continuation + overlap tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0

# Default depth
layers = 4

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },

    {
        "label": "Weak SSB",
        "mI2": -1.0,
        "f":5*1e-2
    },
    {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#" * 80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#" * 80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "=" * 60)
        print(f"Running λ = {lam:.3f}")
        print("=" * 60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(
            Hloc_sparse
        )

        # ----------------------------------------------------
        # Dense Hamiltonian
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(
            H_op
        )

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ====================================================
        # Adaptive depth near critical region
        # ====================================================

        

        # ====================================================
        # Ansatz
        # ====================================================

        if mI2 < 0:

            ansatz = grouped_hva_asymm(
                nq=nqubits,
                layers=layers
            )

        else:

            ansatz = grouped_hva_symm(
                nq=nqubits,
                layers=layers
            )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)



        
        # ====================================================
        # Weak SSB:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )
        # ====================================================
        # Weak SSB optimized:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )

        # ====================================================
        # Symmetric + Strong SSB
        # ====================================================

        else:

            print(
                "\nRunning ordinary HVA-VQE...\n"
            )

            initial_point = (
                0.01 * np.random.randn(
                    ansatz.num_parameters
                )
            )

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = (
                vqe.compute_minimum_eigenvalue(
                    H_pauli_shifted
                )
            )

            best_energy = (
                result.eigenvalue.real
                + identity_shift
            )

            optimal_circuit = (
                ansatz.assign_parameters(
                    result.optimal_parameters
                )
            )

            best_state = (
                Statevector.from_instruction(
                    optimal_circuit
                ).data
            )

            best_fidelity = np.abs(
                np.vdot(
                    psi_exact,
                    best_state
                )
            )**2

            best_overlap = 1.0

        # ====================================================
        # Final VQE data
        # ====================================================

        E_vqe = best_energy
        F = best_fidelity

        # ====================================================
        # Store results
        # ====================================================

        data = {

            "case": label,

            "lambda": lam,

            "mI2": mI2,

            "f": f,
            'psi_vqe': best_state,

            "E_exact": E_exact,

            "E_vqe": E_vqe,

            "error": abs(
                E_exact - E_vqe
            ),

            "fidelity": F,

            "tracking_overlap": best_overlap,

            "layers": layers
        }

        case_results.append(data)
        all_results.append(data)

        # ====================================================
        # Print
        # ====================================================

        print("\nFINAL SELECTED STATE")

        print(
            f"Exact energy     : "
            f"{E_exact:.12f}"
        )

        print(
            f"VQE energy       : "
            f"{E_vqe:.12f}"
        )

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(
            f"Fidelity         : "
            f"{F:.12f}"
        )

        print(
            f"Tracking overlap : "
            f"{best_overlap:.12f}"
        )

        print(
            f"Layers            : "
            f"{layers}"
        )

        print(
            f"Pauli terms       : "
            f"{len(H_pauli_shifted.paulis)}"
        )

    # ========================================================
    # Summary
    # ========================================================

    print("\n")
    print("=" * 140)
    print(f"SUMMARY : {label}")
    print("=" * 140)

    print(
        f"{'lambda':<12}"
        f"{'Exact E':<20}"
        f"{'VQE E':<20}"
        f"{'Error':<18}"
        f"{'Fidelity':<18}"
        f"{'TrackOverlap':<18}"
        f"{'Layers':<10}"
    )

    print("=" * 140)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
            f"{r['E_vqe']:<20.10f}"
            f"{r['error']:<18.4e}"
            f"{r['fidelity']:<18.10f}"
            f"{r['tracking_overlap']:<18.10f}"
            f"{r['layers']:<10}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161917548
# Energy error     : 1.893894e-07
# Fidelity         : 0.999999954751
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 106
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018642643692
# Energy error     : 1.216345e-06
# Fidelity         : 0.999999813936
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030502771287
# Energy error     : 3.461493e-06
# Fidelity         : 0.999999531806
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041827305293
# Energy error     : 2.983032e-06
# Fidelity         : 0.999999470832
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052708778806
# Energy error     : 2.423504e-05
# Fidelity         : 0.999996041781
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063138463575
# Energy error     : 4.674804e-06
# Fidelity         : 0.999999500127
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073275074620
# Energy error     : 5.942085e-05
# Fidelity         : 0.999992646177
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082977839327
# Energy error     : 1.168751e-05
# Fidelity         : 0.999997505613
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092417107264
# Energy error     : 1.599157e-06
# Fidelity         : 0.999999898372
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101597426321
# Energy error     : 7.997579e-06
# Fidelity         : 0.999999077219
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
#
# ============================================================================================================================================
# SUMMARY : Symmetric
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      1.0061617282        1.0061619175        1.8939e-07        0.9999999548      1.0000000000      4
# 0.3111      1.0186414273        1.0186426437        1.2163e-06        0.9999998139      1.0000000000      4
# 0.5222      1.0304993098        1.0305027713        3.4615e-06        0.9999995318      1.0000000000      4
# 0.7333      1.0418243223        1.0418273053        2.9830e-06        0.9999994708      1.0000000000      4
# 0.9444      1.0526845438        1.0527087788        2.4235e-05        0.9999960418      1.0000000000      4
# 1.1556      1.0631337888        1.0631384636        4.6748e-06        0.9999995001      1.0000000000      4
# 1.3667      1.0732156538        1.0732750746        5.9421e-05        0.9999926462      1.0000000000      4
# 1.5778      1.0829661518        1.0829778393        1.1688e-05        0.9999975056      1.0000000000      4
# 1.7889      1.0924155081        1.0924171073        1.5992e-06        0.9999998984      1.0000000000      4
# 2.0000      1.1015894287        1.1015974263        7.9976e-06        0.9999990772      1.0000000000      4
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.057036062141
# Fidelity = 0.998310882168
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -17.063315082018
# Fidelity = 0.999811135061
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -17.038707568773
# Fidelity = 0.997263190687
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.987163436513
# Fidelity = 0.989305784622
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -17.052659105878
# Fidelity = 0.998001344705
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.064070748194
# Fidelity = 0.999893067589
# Overlap  = 0.999904974630
#
# Restart 1
# Energy   = -17.000856709539
# Fidelity = 0.993103213847
# Overlap  = 0.993168644136
#
# Restart 2
# Energy   = -16.930758200880
# Fidelity = 0.985093903286
# Overlap  = 0.985446909824
#
# Restart 3
# Energy   = -17.063970987159
# Fidelity = 0.999887778652
# Overlap  = 0.999853032033
#
# Restart 4
# Energy   = -17.063718530137
# Fidelity = 0.999838106947
# Overlap  = 0.999848601159
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.064070748194
# Energy error     : 6.226037e-04
# Fidelity         : 0.999893067589
# Tracking overlap : 0.999904974630
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.060404623300
# Fidelity = 0.989838377606
# Overlap  = 0.823431524508
#
# Restart 1
# Energy   = -9.054960767215
# Fidelity = 0.987998765294
# Overlap  = 0.841027115184
#
# Restart 2
# Energy   = -9.046608771987
# Fidelity = 0.977729726399
# Overlap  = 0.846003351039
#
# Restart 3
# Energy   = -9.049036514938
# Fidelity = 0.984291970872
# Overlap  = 0.828459643522
#
# Restart 4
# Energy   = -9.058155904956
# Fidelity = 0.987957635592
# Overlap  = 0.824397899082
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.064746518899
# Fidelity = 0.992890705776
# Overlap  = 0.998658302010
#
# Restart 1
# Energy   = -9.053543559161
# Fidelity = 0.985225398652
# Overlap  = 0.996505636107
#
# Restart 2
# Energy   = -9.057263359930
# Fidelity = 0.989073320068
# Overlap  = 0.998188189464
#
# Restart 3
# Energy   = -9.025570273396
# Fidelity = 0.980566338389
# Overlap  = 0.989128691026
#
# Restart 4
# Energy   = -8.971990453891
# Fidelity = 0.967409021731
# Overlap  = 0.976064796851
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.064746518899
# Energy error     : 1.570339e-02
# Fidelity         : 0.992890705776
# Tracking overlap : 0.998658302010
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.672852444971
# Fidelity = 0.985400878017
# Overlap  = 0.067647302349
#
# Restart 1
# Energy   = -4.668885382806
# Fidelity = 0.982975895135
# Overlap  = 0.069214713947
#
# Restart 2
# Energy   = -4.675904365121
# Fidelity = 0.985662118516
# Overlap  = 0.068195928587
#
# Restart 3
# Energy   = -4.674188645105
# Fidelity = 0.986523488613
# Overlap  = 0.065032996354
#
# Restart 4
# Energy   = -4.666582834971
# Fidelity = 0.979722306512
# Overlap  = 0.071787888174
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.683309497760
# Fidelity = 0.990748207403
# Overlap  = 0.996965028770
#
# Restart 1
# Energy   = -4.666304815797
# Fidelity = 0.978511789036
# Overlap  = 0.995002341240
#
# Restart 2
# Energy   = -4.674991133465
# Fidelity = 0.988755215810
# Overlap  = 0.994528698639
#
# Restart 3
# Energy   = -4.670925891344
# Fidelity = 0.985389729302
# Overlap  = 0.994351572034
#
# Restart 4
# Energy   = -4.672591831159
# Fidelity = 0.986180788136
# Overlap  = 0.992477539325
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.683309497760
# Energy error     : 1.788547e-02
# Fidelity         : 0.990748207403
# Tracking overlap : 0.996965028770
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.002474388056
# Fidelity = 0.997003792685
# Overlap  = 0.653210582851
#
# Restart 1
# Energy   = -2.978499319053
# Fidelity = 0.986545503396
# Overlap  = 0.619742713450
#
# Restart 2
# Energy   = -3.001317929954
# Fidelity = 0.996421484053
# Overlap  = 0.652244009647
#
# Restart 3
# Energy   = -2.994231414877
# Fidelity = 0.993493200117
# Overlap  = 0.642555410635
#
# Restart 4
# Energy   = -2.993115826790
# Fidelity = 0.992858319582
# Overlap  = 0.643418914087
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.004246496200
# Fidelity = 0.997811700836
# Overlap  = 0.999336937873
#
# Restart 1
# Energy   = -2.997779389306
# Fidelity = 0.995407078459
# Overlap  = 0.997497328597
#
# Restart 2
# Energy   = -2.964543065936
# Fidelity = 0.977675960109
# Overlap  = 0.980528561202
#
# Restart 3
# Energy   = -2.985091081959
# Fidelity = 0.990614079419
# Overlap  = 0.992455765098
#
# Restart 4
# Energy   = -2.994441384700
# Fidelity = 0.993717768689
# Overlap  = 0.997010045148
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.004246496200
# Energy error     : 7.284855e-03
# Fidelity         : 0.997811700836
# Tracking overlap : 0.999336937873
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.081787132578
# Fidelity = 0.999627643121
# Overlap  = 0.835227552874
#
# Restart 1
# Energy   = -2.078540397975
# Fidelity = 0.998819376623
# Overlap  = 0.827408004436
#
# Restart 2
# Energy   = -2.077712061276
# Fidelity = 0.998609023599
# Overlap  = 0.824916602458
#
# Restart 3
# Energy   = -2.077593156031
# Fidelity = 0.998384513680
# Overlap  = 0.825864098234
#
# Restart 4
# Energy   = -2.053251594910
# Fidelity = 0.982326149993
# Overlap  = 0.803145579494
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.082127386493
# Fidelity = 0.999693775113
# Overlap  = 0.999946193377
#
# Restart 1
# Energy   = -2.078734874186
# Fidelity = 0.998801633417
# Overlap  = 0.999149523747
#
# Restart 2
# Energy   = -2.077665469996
# Fidelity = 0.998557539338
# Overlap  = 0.998883359237
#
# Restart 3
# Energy   = -2.078245786568
# Fidelity = 0.998647464438
# Overlap  = 0.998989369889
#
# Restart 4
# Energy   = -2.078001958748
# Fidelity = 0.998514862348
# Overlap  = 0.998828667835
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.082127386493
# Energy error     : 1.438337e-03
# Fidelity         : 0.999693775113
# Tracking overlap : 0.999946193377
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.503520198030
# Fidelity = 0.999866690764
# Overlap  = 0.897061158150
#
# Restart 1
# Energy   = -1.502188443513
# Fidelity = 0.999597592654
# Overlap  = 0.896888154090
#
# Restart 2
# Energy   = -1.502241385980
# Fidelity = 0.999659699869
# Overlap  = 0.896943323138
#
# Restart 3
# Energy   = -1.502040344905
# Fidelity = 0.999569898018
# Overlap  = 0.896344617977
#
# Restart 4
# Energy   = -1.502438083244
# Fidelity = 0.999613066180
# Overlap  = 0.896353122572
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.503926618101
# Fidelity = 0.999929029691
# Overlap  = 0.999935939064
#
# Restart 1
# Energy   = -1.502718765629
# Fidelity = 0.999713777784
# Overlap  = 0.999724486554
#
# Restart 2
# Energy   = -1.501822867078
# Fidelity = 0.999556703360
# Overlap  = 0.999646200024
#
# Restart 3
# Energy   = -1.502301178081
# Fidelity = 0.999595786185
# Overlap  = 0.999653491164
#
# Restart 4
# Energy   = -1.503004266985
# Fidelity = 0.999732475501
# Overlap  = 0.999697487918
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503926618101
# Energy error     : 5.612546e-04
# Fidelity         : 0.999929029691
# Tracking overlap : 0.999935939064
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118580297924
# Fidelity = 0.999928281013
# Overlap  = 0.918821007142
#
# Restart 1
# Energy   = -1.114555068669
# Fidelity = 0.999223785432
# Overlap  = 0.917931511674
#
# Restart 2
# Energy   = -1.102074575227
# Fidelity = 0.988557657856
# Overlap  = 0.884244704891
#
# Restart 3
# Energy   = -1.107066141527
# Fidelity = 0.989761990275
# Overlap  = 0.891411647767
#
# Restart 4
# Energy   = -1.114861193945
# Fidelity = 0.999236863385
# Overlap  = 0.915104580009
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118769760925
# Fidelity = 0.999954207704
# Overlap  = 0.999974748845
#
# Restart 1
# Energy   = -1.115083550349
# Fidelity = 0.999329138806
# Overlap  = 0.999435652784
#
# Restart 2
# Energy   = -1.114589903371
# Fidelity = 0.999204440957
# Overlap  = 0.999297648807
#
# Restart 3
# Energy   = -1.107590872599
# Fidelity = 0.993322965496
# Overlap  = 0.993679284670
#
# Restart 4
# Energy   = -1.115411752583
# Fidelity = 0.999028554373
# Overlap  = 0.999040077218
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118769760925
# Energy error     : 3.299695e-04
# Fidelity         : 0.999954207704
# Tracking overlap : 0.999974748845
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.853027764910
# Fidelity = 0.999956068651
# Overlap  = 0.936857462930
#
# Restart 1
# Energy   = -0.840714250160
# Fidelity = 0.990824350284
# Overlap  = 0.902620609825
#
# Restart 2
# Energy   = -0.840750771893
# Fidelity = 0.990907332643
# Overlap  = 0.902949882494
#
# Restart 3
# Energy   = -0.844741806916
# Fidelity = 0.994967094549
# Overlap  = 0.917926897309
#
# Restart 4
# Energy   = -0.844463614533
# Fidelity = 0.994638463467
# Overlap  = 0.916557579165
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.853116665163
# Fidelity = 0.999970060595
# Overlap  = 0.999987910970
#
# Restart 1
# Energy   = -0.839062877720
# Fidelity = 0.988597719028
# Overlap  = 0.989160797941
#
# Restart 2
# Energy   = -0.849171608121
# Fidelity = 0.999377797396
# Overlap  = 0.999439302535
#
# Restart 3
# Energy   = -0.848956616841
# Fidelity = 0.999122111497
# Overlap  = 0.999191234783
#
# Restart 4
# Energy   = -0.848855805602
# Fidelity = 0.999202440588
# Overlap  = 0.999291720550
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.853116665163
# Energy error     : 2.153888e-04
# Fidelity         : 0.999970060595
# Tracking overlap : 0.999987910970
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663418296017
# Fidelity = 0.999981824356
# Overlap  = 0.958997376607
#
# Restart 1
# Energy   = -0.657794027247
# Fidelity = 0.997024316123
# Overlap  = 0.944570909351
#
# Restart 2
# Energy   = -0.656080230943
# Fidelity = 0.995550911115
# Overlap  = 0.939303581887
#
# Restart 3
# Energy   = -0.655849623938
# Fidelity = 0.996375144822
# Overlap  = 0.944469877064
#
# Restart 4
# Energy   = -0.659085167573
# Fidelity = 0.998153225209
# Overlap  = 0.949379255966
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663433365923
# Fidelity = 0.999984994021
# Overlap  = 0.999997306084
#
# Restart 1
# Energy   = -0.656720734701
# Fidelity = 0.996431174116
# Overlap  = 0.996609109094
#
# Restart 2
# Energy   = -0.656236831178
# Fidelity = 0.995796857504
# Overlap  = 0.995987722035
#
# Restart 3
# Energy   = -0.655834405031
# Fidelity = 0.995274012837
# Overlap  = 0.995479740962
#
# Restart 4
# Energy   = -0.656004440630
# Fidelity = 0.995714263121
# Overlap  = 0.995911464126
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663433365923
# Energy error     : 1.267756e-04
# Fidelity         : 0.999984994021
# Tracking overlap : 0.999997306084
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.522062119980
# Fidelity = 0.999990759199
# Overlap  = 0.975791923502
#
# Restart 1
# Energy   = -0.518016725314
# Fidelity = 0.998145243735
# Overlap  = 0.966907741829
#
# Restart 2
# Energy   = -0.519029225400
# Fidelity = 0.998632337720
# Overlap  = 0.968960504686
#
# Restart 3
# Energy   = -0.518249253996
# Fidelity = 0.998412759743
# Overlap  = 0.967988945677
#
# Restart 4
# Energy   = -0.517580522126
# Fidelity = 0.997529232332
# Overlap  = 0.965155479771
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.522068455212
# Fidelity = 0.999991558716
# Overlap  = 0.999999129465
#
# Restart 1
# Energy   = -0.519194385597
# Fidelity = 0.998807602149
# Overlap  = 0.998859328729
#
# Restart 2
# Energy   = -0.517031439530
# Fidelity = 0.997134871632
# Overlap  = 0.997255692246
#
# Restart 3
# Energy   = -0.518960742988
# Fidelity = 0.998343962621
# Overlap  = 0.998369416700
#
# Restart 4
# Energy   = -0.518006047758
# Fidelity = 0.998064738484
# Overlap  = 0.998154492174
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.522068455212
# Energy error     : 7.130909e-05
# Fidelity         : 0.999991558716
# Tracking overlap : 0.999999129465
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -17.0646933519      -17.0640707482      6.2260e-04        0.9998930676      0.9999049746      4
# 0.3111      -9.0804499123       -9.0647465189       1.5703e-02        0.9928907058      0.9986583020      4
# 0.5222      -4.7011949726       -4.6833094978       1.7885e-02        0.9907482074      0.9969650288      4
# 0.7333      -3.0115313516       -3.0042464962       7.2849e-03        0.9978117008      0.9993369379      4
# 0.9444      -2.0835657235       -2.0821273865       1.4383e-03        0.9996937751      0.9999461934      4
# 1.1556      -1.5044878727       -1.5039266181       5.6125e-04        0.9999290297      0.9999359391      4
# 1.3667      -1.1190997304       -1.1187697609       3.2997e-04        0.9999542077      0.9999747488      4
# 1.5778      -0.8533320540       -0.8531166652       2.1539e-04        0.9999700606      0.9999879110      4
# 1.7889      -0.6635601415       -0.6634333659       1.2678e-04        0.9999849940      0.9999973061      4
# 2.0000      -0.5221397643       -0.5220684552       7.1309e-05        0.9999915587      0.9999991295      4
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.751684337894
# Fidelity = 0.996956324055
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -20.685259827689
# Fidelity = 0.990053470377
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -20.595298420683
# Fidelity = 0.980500937397
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -20.670166821313
# Fidelity = 0.988115964597
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -20.751437997959
# Fidelity = 0.996802316347
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.758239478863
# Fidelity = 0.997824515685
# Overlap  = 0.999547631139
#
# Restart 1
# Energy   = -20.753243478319
# Fidelity = 0.996994711046
# Overlap  = 0.998075451902
#
# Restart 2
# Energy   = -20.751877496049
# Fidelity = 0.997115045077
# Overlap  = 0.997685345243
#
# Restart 3
# Energy   = -20.681988887777
# Fidelity = 0.989119394104
# Overlap  = 0.990204833386
#
# Restart 4
# Energy   = -20.753911700192
# Fidelity = 0.997186645864
# Overlap  = 0.998216702692
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.758239478863
# Energy error     : 1.908897e-02
# Fidelity         : 0.997824515685
# Tracking overlap : 0.999547631139
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.812907231512
# Fidelity = 0.995496664468
# Overlap  = 0.857175784166
#
# Restart 1
# Energy   = -12.810497770395
# Fidelity = 0.995157954087
# Overlap  = 0.855222326665
#
# Restart 2
# Energy   = -12.808029453692
# Fidelity = 0.994274474059
# Overlap  = 0.864090800673
#
# Restart 3
# Energy   = -12.808371034399
# Fidelity = 0.994458123679
# Overlap  = 0.863665078248
#
# Restart 4
# Energy   = -12.811793066884
# Fidelity = 0.995296878433
# Overlap  = 0.858371437081
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.815046642197
# Fidelity = 0.995682754679
# Overlap  = 0.999665148672
#
# Restart 1
# Energy   = -12.810605605475
# Fidelity = 0.995138601553
# Overlap  = 0.999153381363
#
# Restart 2
# Energy   = -12.809580724367
# Fidelity = 0.994615483451
# Overlap  = 0.998498988941
#
# Restart 3
# Energy   = -12.812217432086
# Fidelity = 0.995361895847
# Overlap  = 0.999575304924
#
# Restart 4
# Energy   = -12.814673780427
# Fidelity = 0.996066745241
# Overlap  = 0.999168969506
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.815046642197
# Energy error     : 2.139450e-02
# Fidelity         : 0.995682754679
# Tracking overlap : 0.999665148672
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.650959044153
# Fidelity = 0.983529001449
# Overlap  = 0.165453470849
#
# Restart 1
# Energy   = -7.645971251015
# Fidelity = 0.982106222486
# Overlap  = 0.169080311045
#
# Restart 2
# Energy   = -7.668137919172
# Fidelity = 0.987993726131
# Overlap  = 0.163615985397
#
# Restart 3
# Energy   = -7.652975858659
# Fidelity = 0.982829338837
# Overlap  = 0.167343341604
#
# Restart 4
# Energy   = -7.649509664100
# Fidelity = 0.982584385594
# Overlap  = 0.169331122809
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.685018672810
# Fidelity = 0.991771835806
# Overlap  = 0.997516674776
#
# Restart 1
# Energy   = -7.609174405817
# Fidelity = 0.972083326584
# Overlap  = 0.987392150215
#
# Restart 2
# Energy   = -7.647265021655
# Fidelity = 0.982240339609
# Overlap  = 0.992796887620
#
# Restart 3
# Energy   = -7.651330722336
# Fidelity = 0.982231226480
# Overlap  = 0.993310970507
#
# Restart 4
# Energy   = -7.610419138521
# Fidelity = 0.972145456329
# Overlap  = 0.987008436604
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.685018672810
# Energy error     : 4.569769e-02
# Fidelity         : 0.991771835806
# Tracking overlap : 0.997516674776
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.501512607395
# Fidelity = 0.992660043665
# Overlap  = 0.614143678406
#
# Restart 1
# Energy   = -5.500671174690
# Fidelity = 0.993283925929
# Overlap  = 0.612492511280
#
# Restart 2
# Energy   = -5.487021555119
# Fidelity = 0.990630200783
# Overlap  = 0.609586530768
#
# Restart 3
# Energy   = -5.483567321081
# Fidelity = 0.989595492264
# Overlap  = 0.604852960128
#
# Restart 4
# Energy   = -5.477330952466
# Fidelity = 0.988374139538
# Overlap  = 0.603457226403
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.520805115997
# Fidelity = 0.997407604541
# Overlap  = 0.995923733062
#
# Restart 1
# Energy   = -5.510214164841
# Fidelity = 0.995228415749
# Overlap  = 0.992120974563
#
# Restart 2
# Energy   = -5.472118973524
# Fidelity = 0.986530474141
# Overlap  = 0.991421387583
#
# Restart 3
# Energy   = -5.468362374271
# Fidelity = 0.985502770876
# Overlap  = 0.991159775577
#
# Restart 4
# Energy   = -5.498190673917
# Fidelity = 0.993051622825
# Overlap  = 0.996488191851
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.520805115997
# Energy error     : 1.734371e-02
# Fidelity         : 0.997407604541
# Tracking overlap : 0.995923733062
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.273331748034
# Fidelity = 0.999710968983
# Overlap  = 0.825503787611
#
# Restart 1
# Energy   = -4.257564852026
# Fidelity = 0.996855598997
# Overlap  = 0.807072726937
#
# Restart 2
# Energy   = -4.259018874417
# Fidelity = 0.997257674989
# Overlap  = 0.809645362177
#
# Restart 3
# Energy   = -4.251523166732
# Fidelity = 0.994684645766
# Overlap  = 0.790475454493
#
# Restart 4
# Energy   = -4.258096146088
# Fidelity = 0.996359363476
# Overlap  = 0.801444395788
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.273910115909
# Fidelity = 0.999777139853
# Overlap  = 0.999883793312
#
# Restart 1
# Energy   = -4.252847850070
# Fidelity = 0.995084143189
# Overlap  = 0.995701100186
#
# Restart 2
# Energy   = -4.256655341960
# Fidelity = 0.995576045771
# Overlap  = 0.996071551809
#
# Restart 3
# Energy   = -4.258036693813
# Fidelity = 0.996997923412
# Overlap  = 0.997510219512
#
# Restart 4
# Energy   = -4.253066547375
# Fidelity = 0.994934451067
# Overlap  = 0.995486716249
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.273910115909
# Energy error     : 2.103677e-03
# Fidelity         : 0.999777139853
# Tracking overlap : 0.999883793312
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.445609053392
# Fidelity = 0.999592569417
# Overlap  = 0.903955230656
#
# Restart 1
# Energy   = -3.444722878782
# Fidelity = 0.999507591114
# Overlap  = 0.903938942495
#
# Restart 2
# Energy   = -3.443816132029
# Fidelity = 0.999318309066
# Overlap  = 0.902412385615
#
# Restart 3
# Energy   = -3.445220678024
# Fidelity = 0.999586156111
# Overlap  = 0.903141143899
#
# Restart 4
# Energy   = -3.443772792742
# Fidelity = 0.999324988649
# Overlap  = 0.903391125495
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.446641650405
# Fidelity = 0.999773153767
# Overlap  = 0.999863598176
#
# Restart 1
# Energy   = -3.444877884784
# Fidelity = 0.999537933096
# Overlap  = 0.999731225299
#
# Restart 2
# Energy   = -3.445611001858
# Fidelity = 0.999631461325
# Overlap  = 0.999748031819
#
# Restart 3
# Energy   = -3.444116997998
# Fidelity = 0.999399620565
# Overlap  = 0.999620285425
#
# Restart 4
# Energy   = -3.443945122322
# Fidelity = 0.999353263256
# Overlap  = 0.999668103688
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.446641650405
# Energy error     : 2.038735e-03
# Fidelity         : 0.999773153767
# Tracking overlap : 0.999863598176
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.859015417367
# Fidelity = 0.999783773174
# Overlap  = 0.943032878457
#
# Restart 1
# Energy   = -2.856009915349
# Fidelity = 0.999249896157
# Overlap  = 0.942993291663
#
# Restart 2
# Energy   = -2.855222594794
# Fidelity = 0.999183527961
# Overlap  = 0.943598431751
#
# Restart 3
# Energy   = -2.857858366477
# Fidelity = 0.999596719780
# Overlap  = 0.943008067059
#
# Restart 4
# Energy   = -2.853787617011
# Fidelity = 0.998928661354
# Overlap  = 0.943535587302
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.860150614006
# Fidelity = 0.999927697088
# Overlap  = 0.999891840390
#
# Restart 1
# Energy   = -2.856895554443
# Fidelity = 0.999391262646
# Overlap  = 0.999589056724
#
# Restart 2
# Energy   = -2.853527094324
# Fidelity = 0.998794378340
# Overlap  = 0.999063184026
#
# Restart 3
# Energy   = -2.854124667883
# Fidelity = 0.998963536034
# Overlap  = 0.999190431898
#
# Restart 4
# Energy   = -2.857512844438
# Fidelity = 0.999502460410
# Overlap  = 0.999690234113
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.860150614006
# Energy error     : 6.816512e-04
# Fidelity         : 0.999927697088
# Tracking overlap : 0.999891840390
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.419024715355
# Fidelity = 0.999896435673
# Overlap  = 0.962604652743
#
# Restart 1
# Energy   = -2.409389484993
# Fidelity = 0.998419993238
# Overlap  = 0.959229618490
#
# Restart 2
# Energy   = -2.408752632199
# Fidelity = 0.998301088160
# Overlap  = 0.958759971552
#
# Restart 3
# Energy   = -2.409587008171
# Fidelity = 0.998393857601
# Overlap  = 0.959279178260
#
# Restart 4
# Energy   = -2.414591833742
# Fidelity = 0.999189687858
# Overlap  = 0.960405987786
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.419411160681
# Fidelity = 0.999936677113
# Overlap  = 0.999945897734
#
# Restart 1
# Energy   = -2.407777880646
# Fidelity = 0.998160103798
# Overlap  = 0.998414921110
#
# Restart 2
# Energy   = -2.410929451119
# Fidelity = 0.998641379887
# Overlap  = 0.998852640411
#
# Restart 3
# Energy   = -2.409150278853
# Fidelity = 0.998418338344
# Overlap  = 0.998633974079
#
# Restart 4
# Energy   = -2.409438956002
# Fidelity = 0.998352569899
# Overlap  = 0.998592804177
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.419411160681
# Energy error     : 6.793686e-04
# Fidelity         : 0.999936677113
# Tracking overlap : 0.999945897734
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.075052091668
# Fidelity = 0.999890555673
# Overlap  = 0.973876562805
#
# Restart 1
# Energy   = -1.989584618683
# Fidelity = 0.974020842092
# Overlap  = 0.929936964270
#
# Restart 2
# Energy   = -2.065995965385
# Fidelity = 0.998471719056
# Overlap  = 0.968740894642
#
# Restart 3
# Energy   = -2.066210724571
# Fidelity = 0.998472309585
# Overlap  = 0.968780724902
#
# Restart 4
# Energy   = -2.067558494562
# Fidelity = 0.998755195143
# Overlap  = 0.970543391753
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.075406589048
# Fidelity = 0.999918375457
# Overlap  = 0.999966120724
#
# Restart 1
# Energy   = -2.066444192706
# Fidelity = 0.998555741634
# Overlap  = 0.998813693186
#
# Restart 2
# Energy   = -2.068998565166
# Fidelity = 0.998966303873
# Overlap  = 0.999214971027
#
# Restart 3
# Energy   = -2.066375039690
# Fidelity = 0.998531012075
# Overlap  = 0.998786463486
#
# Restart 4
# Energy   = -2.066721689266
# Fidelity = 0.998612188226
# Overlap  = 0.998873729194
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.075406589048
# Energy error     : 9.059786e-04
# Fidelity         : 0.999918375457
# Tracking overlap : 0.999966120724
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.798884979300
# Fidelity = 0.999897735360
# Overlap  = 0.981196939327
#
# Restart 1
# Energy   = -1.792995937247
# Fidelity = 0.999016888365
# Overlap  = 0.977761843432
#
# Restart 2
# Energy   = -1.792951564613
# Fidelity = 0.999000368437
# Overlap  = 0.977493997499
#
# Restart 3
# Energy   = -1.792758746581
# Fidelity = 0.998973762872
# Overlap  = 0.977192624087
#
# Restart 4
# Energy   = -1.792981042068
# Fidelity = 0.999014964616
# Overlap  = 0.977657312153
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.799394123855
# Fidelity = 0.999928997221
# Overlap  = 0.999956186360
#
# Restart 1
# Energy   = -1.792921764311
# Fidelity = 0.999008467806
# Overlap  = 0.999204051506
#
# Restart 2
# Energy   = -1.792774433073
# Fidelity = 0.998988126599
# Overlap  = 0.999179498066
#
# Restart 3
# Energy   = -1.793056149884
# Fidelity = 0.999024356963
# Overlap  = 0.999219035441
#
# Restart 4
# Energy   = -1.792984102042
# Fidelity = 0.999026107226
# Overlap  = 0.999214330993
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.799394123855
# Energy error     : 6.791424e-04
# Fidelity         : 0.999928997221
# Tracking overlap : 0.999956186360
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Strong SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -20.7773284453      -20.7582394789      1.9089e-02        0.9978245157      0.9995476311      4
# 0.3111      -12.8364411428      -12.8150466422      2.1395e-02        0.9956827547      0.9996651487      4
# 0.5222      -7.7307163648       -7.6850186728       4.5698e-02        0.9917718358      0.9975166748      4
# 0.7333      -5.5381488307       -5.5208051160       1.7344e-02        0.9974076045      0.9959237331      4
# 0.9444      -4.2760137929       -4.2739101159       2.1037e-03        0.9997771399      0.9998837933      4
# 1.1556      -3.4486803854       -3.4466416504       2.0387e-03        0.9997731538      0.9998635982      4
# 1.3667      -2.8608322652       -2.8601506140       6.8165e-04        0.9999276971      0.9998918404      4
# 1.5778      -2.4200905293       -2.4194111607       6.7937e-04        0.9999366771      0.9999458977      4
#         5.57973433e-15-1.15631826e-14j,  5.46586797e-17-1.23817129e-16j,
#        -4.22534869e-11-1.21077069e-09j, -2.13143752e-15-1.98075178e-14j,
#         1.80090456e-13+5.21109158e-12j,  1.85292777e-13+4.16210887e-15j,
#         5.43671310e-13-6.70983560e-12j, -9.38737902e-18-1.21974550e-16j,
#         8.18257867e-14-2.35941587e-15j,  2.13235616e-15-1.31449967e-17j,
#         2.28258174e-07+2.63278535e-07j,  4.05644088e-12+4.04683816e-12j,
#        -9.82140015e-10-1.13335579e-09j, -4.22137207e-11+3.25552213e-11j,
#        -2.70973686e-10-3.13435888e-10j, -1.23944396e-15-3.70562163e-15j,
#        -1.49051739e-11+1.86921836e-11j, -1.57700132e-13+2.06047721e-13j,
#         1.46643570e-12+7.38575822e-13j,  2.48719628e-17+1.03893063e-17j,
#        -6.19086608e-15-3.82319195e-15j, -1.24447057e-16+2.08822339e-16j,
#         9.13506369e-12+2.09124988e-12j,  1.70093199e-16+2.52707486e-17j,
#        -8.10759741e-14+9.29024946e-14j, -9.10747553e-16+2.13205173e-15j,
#         4.48251516e-09-3.78908998e-10j,  7.30673817e-14-1.15399229e-14j,
#        -1.92927300e-11+1.62631144e-12j,  1.85727529e-14+6.87969337e-13j,
#        -5.33116517e-12+4.43660955e-13j, -4.80926803e-17-1.52405671e-17j,
#         8.16375492e-14+2.97642210e-13j,  9.50038998e-16+3.21204095e-15j,
#         2.75407195e-11-5.86668167e-12j,  4.44723416e-16-1.28937762e-16j,
#        -1.18545520e-13+2.52110892e-14j,  6.54497568e-16+4.25778653e-15j,
#         1.31855840e-13-8.40725693e-14j,  2.46449954e-18-1.88736695e-18j,
#         5.36524085e-16+3.46742970e-15j,  2.14119560e-17+5.73114783e-17j]), 'E_exact': np.float64(1.0061617281590702), 'E_vqe': np.float64(1.0061619175484289), 'error': np.float64(1.893893586402129e-07), 'fidelity': np.float64(0.9999999547511448), 'tracking_overlap': 1.0, 'layers': 4}

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HVA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    
    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,
        'psi_vqe': psi_vqe,
        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119685
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98267689
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394204
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98504103
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98601639
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98685983
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98759109
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98835774
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893923
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98953081
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00037721
# T = 10    Fidelity = 0.00053429
# T = 20    Fidelity = 0.01186070
# T = 30    Fidelity = 0.08177321
# T = 40    Fidelity = 0.18842753
# T = 50    Fidelity = 0.42853243
# T = 75    Fidelity = 0.56698854
# T = 100   Fidelity = 0.72920215
# T = 125   Fidelity = 0.80777397
# T = 150   Fidelity = 0.83693980
# T = 175   Fidelity = 0.90639379
# T = 200   Fidelity = 0.91956778
# T = 225   Fidelity = 0.96689476
# T = 250   Fidelity = 0.89085934
# T = 275   Fidelity = 0.96876779
# T = 300   Fidelity = 0.85615285
# T = 400   Fidelity = 0.98025036
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000010
# T = 5     Fidelity = 0.00047705
# T = 10    Fidelity = 0.06565463
# T = 20    Fidelity = 0.21654155
# T = 30    Fidelity = 0.62103473
# T = 40    Fidelity = 0.34086209
# T = 50    Fidelity = 0.77988505
# T = 75    Fidelity = 0.73970174
# T = 100   Fidelity = 0.79154618
# T = 125   Fidelity = 0.87459166
# T = 150   Fidelity = 0.87484179
# T = 175   Fidelity = 0.89595543
# T = 200   Fidelity = 0.92190868
# T = 225   Fidelity = 0.93006071
# T = 250   Fidelity = 0.94077219
# T = 275   Fidelity = 0.94689146
# T = 300   Fidelity = 0.94540044
# T = 400   Fidelity = 0.97128217
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00004039
# T = 2     Fidelity = 0.00033277
# T = 5     Fidelity = 0.01908074
# T = 10    Fidelity = 0.21675278
# T = 20    Fidelity = 0.58578882
# T = 30    Fidelity = 0.65267822
# T = 40    Fidelity = 0.78591995
# T = 50    Fidelity = 0.81320103
# T = 75    Fidelity = 0.91793504
# T = 100   Fidelity = 0.95825081
# T = 125   Fidelity = 0.97534863
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00122706
# T = 2     Fidelity = 0.00501436
# T = 5     Fidelity = 0.06211632
# T = 10    Fidelity = 0.27908859
# T = 20    Fidelity = 0.67893965
# T = 30    Fidelity = 0.73520244
# T = 40    Fidelity = 0.81744737
# T = 50    Fidelity = 0.88614803
# T = 75    Fidelity = 0.95268583
# T = 100   Fidelity = 0.98015797
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00857737
# T = 2     Fidelity = 0.02353233
# T = 5     Fidelity = 0.12520704
# T = 10    Fidelity = 0.34103362
# T = 20    Fidelity = 0.66983976
# T = 30    Fidelity = 0.79898502
# T = 40    Fidelity = 0.85991112
# T = 50    Fidelity = 0.90944224
# T = 75    Fidelity = 0.97011770
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03422637
# T = 2     Fidelity = 0.07351516
# T = 5     Fidelity = 0.22287660
# T = 10    Fidelity = 0.42859478
# T = 20    Fidelity = 0.67914166
# T = 30    Fidelity = 0.80106645
# T = 40    Fidelity = 0.87001481
# T = 50    Fidelity = 0.91700254
# T = 75    Fidelity = 0.97792665
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09471086
# T = 2     Fidelity = 0.17307889
# T = 5     Fidelity = 0.36472011
# T = 10    Fidelity = 0.55540501
# T = 20    Fidelity = 0.74219562
# T = 30    Fidelity = 0.83188237
# T = 40    Fidelity = 0.88408145
# T = 50    Fidelity = 0.91842185
# T = 75    Fidelity = 0.96619236
# T = 100   Fidelity = 0.98497282
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19128845
# T = 2     Fidelity = 0.31298159
# T = 5     Fidelity = 0.52557926
# T = 10    Fidelity = 0.69229025
# T = 20    Fidelity = 0.82822073
# T = 30    Fidelity = 0.88789140
# T = 40    Fidelity = 0.92219385
# T = 50    Fidelity = 0.94370442
# T = 75    Fidelity = 0.96999022
# T = 100   Fidelity = 0.98245587
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30108277
# T = 2     Fidelity = 0.45480993
# T = 5     Fidelity = 0.66224788
# T = 10    Fidelity = 0.79896373
# T = 20    Fidelity = 0.89483478
# T = 30    Fidelity = 0.93348775
# T = 40    Fidelity = 0.95505573
# T = 50    Fidelity = 0.96707249
# T = 75    Fidelity = 0.98285384
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40243404
# T = 2     Fidelity = 0.57300123
# T = 5     Fidelity = 0.76055023
# T = 10    Fidelity = 0.86918423
# T = 20    Fidelity = 0.93648887
# T = 30    Fidelity = 0.96216292
# T = 40    Fidelity = 0.97424468
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000016
# T = 5     Fidelity = 0.00068398
# T = 10    Fidelity = 0.06504177
# T = 20    Fidelity = 0.45504130
# T = 30    Fidelity = 0.87754282
# T = 40    Fidelity = 0.96659093
# T = 50    Fidelity = 0.98899681
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000108
# T = 5     Fidelity = 0.02618337
# T = 10    Fidelity = 0.89261623
# T = 20    Fidelity = 0.96690249
# T = 30    Fidelity = 0.99242345
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00006457
# T = 2     Fidelity = 0.00058116
# T = 5     Fidelity = 0.18899261
# T = 10    Fidelity = 0.97940340
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00132987
# T = 2     Fidelity = 0.00820612
# T = 5     Fidelity = 0.34485916
# T = 10    Fidelity = 0.98505288
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00707462
# T = 2     Fidelity = 0.02921321
# T = 5     Fidelity = 0.47039822
# T = 10    Fidelity = 0.98151814
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02097570
# T = 2     Fidelity = 0.06456113
# T = 5     Fidelity = 0.56457304
# T = 10    Fidelity = 0.97598654
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04395205
# T = 2     Fidelity = 0.11047186
# T = 5     Fidelity = 0.63801617
# T = 10    Fidelity = 0.97215866
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07534984
# T = 2     Fidelity = 0.16338305
# T = 5     Fidelity = 0.69545817
# T = 10    Fidelity = 0.96920012
# T = 20    Fidelity = 0.99306800
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11402715
# T = 2     Fidelity = 0.22106758
# T = 5     Fidelity = 0.74255837
# T = 10    Fidelity = 0.96761784
# T = 20    Fidelity = 0.99357116
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15699182
# T = 2     Fidelity = 0.27925153
# T = 5     Fidelity = 0.78119321
# T = 10    Fidelity = 0.96718791
# T = 20    Fidelity = 0.99384731
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     1         0.9811968491      1.00972087e+00    None        None        None
# Symmetric      0.311     1         0.9826768861      1.02934439e+00    None        None        None
# Symmetric      0.522     1         0.9839420394      1.04790824e+00    None        None        None
# Symmetric      0.733     1         0.9850410295      1.06556366e+00    None        None        None
# Symmetric      0.944     1         0.9860163936      1.08242773e+00    None        None        None
# Symmetric      1.156     1         0.9868598260      1.09859358e+00    None        None        None
# Symmetric      1.367     1         0.9875910904      1.11413694e+00    None        None        None
# Symmetric      1.578     1         0.9883577396      1.12912045e+00    None        None        None
# Symmetric      1.789     1         0.9889392346      1.14359670e+00    None        None        None
# Symmetric      2.000     1         0.9895308088      1.15761039e+00    None        None        None
# Weak SSB       0.100     400       0.9802503609      2.42819099e-01    None        None        None
# Weak SSB       0.311     400       0.9712821699      2.61171322e-01    None        None        None
# Weak SSB       0.522     125       0.9753486280      2.64873214e-01    None        None        None
# Weak SSB       0.733     100       0.9801579729      2.64154074e-01    None        None        None
# Weak SSB       0.944     75        0.9701176996      2.26024680e-01    None        None        None
# Weak SSB       1.156     75        0.9779266488      2.01656789e-01    None        None        None
# Weak SSB       1.367     100       0.9849728155      1.93673930e-01    None        None        None
# Weak SSB       1.578     100       0.9824558653      2.03071995e-01    None        None        None
# Weak SSB       1.789     75        0.9828538387      2.25515049e-01    None        None        None
# Weak SSB       2.000     40        0.9742446821      2.55131735e-01    None        None        None
# Strong SSB     0.100     50        0.9889968129      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9924234461      7.22062439e-01    None        None        None
# Strong SSB     0.522     10        0.9794033964      7.78318602e-01    None        None        None
# Strong SSB     0.733     10        0.9850528763      8.15979742e-01    None        None        None
# Strong SSB     0.944     10        0.9815181442      8.44059983e-01    None        None        None
# Strong SSB     1.156     10        0.9759865404      8.66317759e-01    None        None        None
# Strong SSB     1.367     10        0.9721586619      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9930680013      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9935711612      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9938473089      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HVA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()
