# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # -------------------------------------------------------- kjacvbnm,./qwertyuiopp//÷//

 
    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756947
# State dimension     = (256,)
# Norm                = 0.9999999999999999

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Genuine Qiskit VQE on shifted Pauli Hamiltonian
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SPSA

from qiskit.primitives import StatevectorEstimator


# ============================================================
# Variational circuit
# ============================================================

def variational_circuit(nq, layers):

    qc = QuantumCircuit(nq)

    nparams = 2 * nq * layers

    params = ParameterVector("θ", nparams)

    p = 0

    for l in range(layers):

        # ----------------------------------------------------
        # Single-qubit rotations
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(params[p], q)
            qc.rz(params[p + 1], q)

            p += 2

        # ----------------------------------------------------
        # Entanglement layer
        # ----------------------------------------------------

        if l != layers - 1:

            # even bonds
            if l % 2 == 0:

                for q in range(0, nq - 1, 2):
                    qc.cz(q, q + 1)

            # odd bonds
            else:

                for q in range(1, nq - 1, 2):
                    qc.cz(q, q + 1)

    return qc


# ============================================================
# Ansatz
# ============================================================

nqubits = 8

# start modestly
layers = 8

ansatz = variational_circuit(
    nqubits,
    layers
)

# ============================================================
# Estimator
# ============================================================

estimator = StatevectorEstimator()

# ============================================================
# Optimizer
# ============================================================

optimizer = SPSA(
    maxiter=5000
)

# ============================================================
# VQE
# ============================================================
initial_point = 0.01 * np.random.randn(
    ansatz.num_parameters
)
vqe = VQE(
    estimator=estimator,
    ansatz=ansatz,
    optimizer=optimizer,
    initial_point=initial_point
)

# ============================================================
# Run VQE
# ============================================================

print("\nRunning VQE...\n")

result = vqe.compute_minimum_eigenvalue(
    H_pauli_shifted
)

# ============================================================
# Shifted energy
# ============================================================

E_shifted = result.eigenvalue.real

# ============================================================
# Physical energy
# ============================================================

E_vqe = E_shifted + identity_shift

# ============================================================
# Optimal parameters
# ============================================================

optimal_params = result.optimal_parameters

# ============================================================
# Optimized circuit
# ============================================================

optimal_circuit = ansatz.assign_parameters(
    optimal_params
)

# ============================================================
# VQE state
# ============================================================

psi_vqe = Statevector.from_instruction(
    optimal_circuit
).data

# ============================================================
# Fidelity
# ============================================================

Fidelity = np.abs(
    np.vdot(psi_loc, psi_vqe)
)**2

# ============================================================
# Results
# ============================================================

print("\n================================")
print("Exact energy :", E0_loc)
print("VQE energy   :", E_vqe)
print("Energy error :", abs(E_vqe - E0_loc))
print("Fidelity     :", Fidelity)
print("Layers        :", layers)
print("Pauli terms   :", len(H_pauli_shifted))
print("================================")
# Out:
# Running VQE...
#
#
# ================================
# Exact energy : 1.0554722545756947
# VQE energy   : 1.0616588703611871
# Energy error : 0.0061866157854924
# Fidelity     : 0.9984059052089401
# Layers        : 8
# Pauli terms   : 111
# ================================

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Robust VQE with eigenstate tracking
# ============================================================
import numpy as np

from scipy.sparse import identity, kron

from qiskit.quantum_info import (
    Statevector,
    Operator,
    SparsePauliOp
)

from qiskit.primitives import StatevectorEstimator

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B
def run_robust_vqe(

    H_sparse,

    nq,

    layers,

    n_restarts,

    energy_tol,

    previous_state=None,

    previous_optimal_point=None
):

    nqubits = nq

    # --------------------------------------------------------
    # Exact ground state
    # --------------------------------------------------------

    E_exact, psi_exact = exact_ground_state(H_sparse)

    # --------------------------------------------------------
    # Convert Hamiltonian
    # --------------------------------------------------------

    H_dense = H_sparse.toarray()

    H_op = Operator(H_dense)

    H_pauli = SparsePauliOp.from_operator(H_op)

    coeffs = H_pauli.coeffs

    paulis = H_pauli.paulis

    new_coeffs = []

    new_paulis = []

    identity_shift = 0.0

    for p, c in zip(paulis, coeffs):

        if str(p) == 'I' * nqubits:

            identity_shift += np.real(c)

        else:

            new_paulis.append(p)

            new_coeffs.append(c)

    H_pauli_shifted = SparsePauliOp(

        new_paulis,

        coeffs=new_coeffs
    )

    # --------------------------------------------------------
    # Ansatz
    # --------------------------------------------------------

    ansatz = variational_circuit(

        nq=nqubits,

        layers=layers
    )

    estimator = StatevectorEstimator()

    optimizer = L_BFGS_B(maxiter=1000)

    # ========================================================
    # Multiple restarts
    # ========================================================

    trial_results = []

    for trial in range(n_restarts):

        # ----------------------------------------------------
        # Initial point
        # ----------------------------------------------------

        if trial == 0 and previous_optimal_point is not None:

            initial_point = previous_optimal_point

        else:

            initial_point = 0.01 * np.random.randn(

                ansatz.num_parameters
            )

        # ----------------------------------------------------
        # VQE
        # ----------------------------------------------------

        vqe = VQE(

            estimator=estimator,

            ansatz=ansatz,

            optimizer=optimizer,

            initial_point=initial_point
        )

        result = vqe.compute_minimum_eigenvalue(

            H_pauli_shifted
        )

        E_trial = (

            np.real(result.eigenvalue)

            + identity_shift
        )

        # ----------------------------------------------------
        # Trial state
        # ----------------------------------------------------

        qc_trial = ansatz.assign_parameters(

            result.optimal_parameters
        )

        psi_trial = Statevector.from_instruction(

            qc_trial

        ).data

        # ----------------------------------------------------
        # Overlap tracking
        # ----------------------------------------------------

        if previous_state is None:

            overlap = 1.0

        else:

            overlap = abs(np.vdot(

                previous_state,

                psi_trial

            ))**2

        trial_results.append({

            'energy': E_trial,

            'overlap': overlap,

            'state': psi_trial,

            'result': result
        })

    # ========================================================
    # Hybrid selection
    # ========================================================

    energies = np.array([

        t['energy']

        for t in trial_results
    ])

    E_min = np.min(energies)

    filtered_candidates = [

        t for t in trial_results

        if (t['energy'] - E_min) < energy_tol
    ]

    best_candidate = max(

        filtered_candidates,

        key=lambda x: x['overlap']
    )

    # ========================================================
    # Outputs
    # ========================================================

    # ========================================================
    # Final outputs
    # ========================================================

    psi_vqe = best_candidate['state']

    E_vqe = best_candidate['energy']

    optimal_point = (

        best_candidate['result'].optimal_point
    )

    tracking_overlap = best_candidate['overlap']

    F = fidelity(

    psi_exact,

    psi_vqe
    )

    return {

        "E_exact": E_exact,

        "E_vqe": E_vqe,

        "psi_vqe": psi_vqe,

        "fidelity": F,

        "tracking_overlap": tracking_overlap,

        "optimal_point": optimal_point,

        "state_for_tracking": psi_vqe
    }

# %%
nq_site = 4

nqubits = 2 * nq_site

mu = 1.0

layers = 8

# ============================================================
# VQE settings
# ============================================================

n_restarts = 5

energy_tol = 1e-3

# ============================================================
# Parameter sets
# ============================================================

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
    {
       "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-4
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ============================================================
# Lambda scan
# ============================================================

lambda_list = np.linspace(0.1, 2.0, 10)

# ============================================================
# Storage
# ============================================================

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]

    mI2 = params["mI2"]

    f = params["f"]

    print("\n")
    print("#"*80)

    print(f"CASE: {label}")

    print(f"mI² = {mI2},  f = {f}")

    print("#"*80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None

    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "="*60)

        print(f"Running λ = {lam:.3f}")

        print("="*60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(

            nq=nq_site,

            mu=mu,

            mI2=mI2,

            lam=lam,

            f=f
        )

        # ====================================================
        # Run robust VQE
        # ====================================================

        vqe_data = run_robust_vqe(

            H_sparse=Hloc_sparse,

            nq=nqubits,

            layers=layers,

            n_restarts=n_restarts,

            energy_tol=energy_tol,

            previous_state=previous_state,

            previous_optimal_point=previous_optimal_point
        )

        # ====================================================
        # Extract outputs
        # ====================================================

        E_exact = vqe_data["E_exact"]

        E_vqe = vqe_data["E_vqe"]

        psi_vqe = vqe_data["psi_vqe"]

        F = vqe_data["fidelity"]

        tracking_overlap = vqe_data["tracking_overlap"]

        # ----------------------------------------------------
        # Update tracking
        # ----------------------------------------------------

        previous_state = vqe_data["state_for_tracking"]

        previous_optimal_point = (

            vqe_data["optimal_point"]
        )

        # ----------------------------------------------------
        # Store
        # ----------------------------------------------------

        data = {

            'case': label,

            'lambda': lam,

            'mI2': mI2,

            'f': f,

            'E_exact': E_exact,

            'E_vqe': E_vqe,

            'error': abs(E_exact - E_vqe),

            'fidelity': F,

            'tracking_overlap': tracking_overlap,

            'psi_vqe': psi_vqe
        }

        case_results.append(data)

        all_results.append(data)

        # ----------------------------------------------------
        # Print
        # ----------------------------------------------------

        print("\nFINAL SELECTED STATE")

        print(f"Exact energy     : {E_exact:.12f}")

        print(f"VQE energy       : {E_vqe:.12f}")

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(f"Fidelity         : {F:.12f}")

        print(
            f"Tracking overlap : "
            f"{tracking_overlap:.12f}"
        )

    # ========================================================
    # Case summary
    # ========================================================

    print("\n")

    print("="*110)

    print(f"SUMMARY : {label}")

    print("="*110)

    print(

        f"{'lambda':<12} "
        f"{'Exact E':<18} "
        f"{'VQE E':<18} "
        f"{'Error':<15} "
        f"{'Fidelity':<15} "
        f"{'TrackOverlap':<15}"
    )

    print("="*110)

    for r in case_results:

        print(

            f"{r['lambda']:<12.4f} "
            f"{r['E_exact']:<18.10f} "
            f"{r['E_vqe']:<18.10f} "
            f"{r['error']:<15.4e} "
            f"{r['fidelity']:<15.10f} "
            f"{r['tracking_overlap']:<15.10f}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
# /home/semin/jupyter/qiskit_env/lib/python3.12/site-packages/qiskit_algorithms/optimizers/scipy_optimizer.py:162: OptimizeWarning: Unknown solver options: iprint
#   raw_result = minimize(
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161895438
# Energy error     : 1.672790e-07
# Fidelity         : 0.999999925427
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641513435
# Energy error     : 8.608764e-08
# Fidelity         : 0.999999964266
# Tracking overlap : 0.999848898377
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030499336041
# Energy error     : 2.624665e-08
# Fidelity         : 0.999999993386
# Tracking overlap : 0.999876105164
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041824387848
# Energy error     : 6.558733e-08
# Fidelity         : 0.999999992458
# Tracking overlap : 0.999895840913
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052684784894
# Energy error     : 2.411327e-07
# Fidelity         : 0.999999947213
# Tracking overlap : 0.999911110306
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063134090215
# Energy error     : 3.014450e-07
# Fidelity         : 0.999999918694
# Tracking overlap : 0.999922289379
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073216053726
# Energy error     : 3.999554e-07
# Fidelity         : 0.999999912627
# Tracking overlap : 0.999931724406
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082966632903
# Energy error     : 4.810881e-07
# Fidelity         : 0.999999934788
# Tracking overlap : 0.999939629960
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092416108337
# Energy error     : 6.002290e-07
# Fidelity         : 0.999999922156
# Tracking overlap : 0.999945862540
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101590070433
# Energy error     : 6.416903e-07
# Fidelity         : 0.999999918469
# Tracking overlap : 0.999951065971
#
#
# ==============================================================================================================
# SUMMARY : Symmetric
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       1.0061617282       1.0061618954       1.6728e-07      0.9999999254    1.0000000000
# 0.3111       1.0186414273       1.0186415134       8.6088e-08      0.9999999643    0.9998488984
# 0.5222       1.0304993098       1.0304993360       2.6247e-08      0.9999999934    0.9998761052
# 0.7333       1.0418243223       1.0418243878       6.5587e-08      0.9999999925    0.9998958409
# 0.9444       1.0526845438       1.0526847849       2.4113e-07      0.9999999472    0.9999111103
# 1.1556       1.0631337888       1.0631340902       3.0144e-07      0.9999999187    0.9999222894
# 1.3667       1.0732156538       1.0732160537       3.9996e-07      0.9999999126    0.9999317244
# 1.5778       1.0829661518       1.0829666329       4.8109e-07      0.9999999348    0.9999396300
# 1.7889       1.0924155081       1.0924161083       6.0023e-07      0.9999999222    0.9999458625
# 2.0000       1.1015894287       1.1015900704       6.4169e-07      0.9999999185    0.9999510660
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.064295311365
# Energy error     : 3.980405e-04
# Fidelity         : 0.999931504407
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.077463742470
# Energy error     : 2.986170e-03
# Fidelity         : 0.999023700034
# Tracking overlap : 0.805213621316
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.701060917695
# Energy error     : 1.340549e-04
# Fidelity         : 0.999956173339
# Tracking overlap : 0.069271664883
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.011512010062
# Energy error     : 1.934156e-05
# Fidelity         : 0.999994896979
# Tracking overlap : 0.654894788382
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.083368813397
# Energy error     : 1.969101e-04
# Fidelity         : 0.999966956066
# Tracking overlap : 0.831695848301
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503520101351
# Energy error     : 9.677714e-04
# Fidelity         : 0.999850662965
# Tracking overlap : 0.896057935288
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118358780509
# Energy error     : 7.409499e-04
# Fidelity         : 0.999748115896
# Tracking overlap : 0.918957366284
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.853249009915
# Energy error     : 8.304409e-05
# Fidelity         : 0.999983692295
# Tracking overlap : 0.935722628560
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663535780255
# Energy error     : 2.436129e-05
# Fidelity         : 0.999997417328
# Tracking overlap : 0.959262183227
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.522120047133
# Energy error     : 1.971717e-05
# Fidelity         : 0.999997468253
# Tracking overlap : 0.975755237007
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB optimised
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -17.0646933519     -17.0642953114     3.9804e-04      0.9999315044    1.0000000000
# 0.3111       -9.0804499123      -9.0774637425      2.9862e-03      0.9990237000    0.8052136213
# 0.5222       -4.7011949726      -4.7010609177      1.3405e-04      0.9999561733    0.0692716649
# 0.7333       -3.0115313516      -3.0115120101      1.9342e-05      0.9999948970    0.6548947884
# 0.9444       -2.0835657235      -2.0833688134      1.9691e-04      0.9999669561    0.8316958483
# 1.1556       -1.5044878727      -1.5035201014      9.6777e-04      0.9998506630    0.8960579353
# 1.3667       -1.1190997304      -1.1183587805      7.4095e-04      0.9997481159    0.9189573663
# 1.5778       -0.8533320540      -0.8532490099      8.3044e-05      0.9999836923    0.9357226286
# 1.7889       -0.6635601415      -0.6635357803      2.4361e-05      0.9999974173    0.9592621832
# 2.0000       -0.5221397643      -0.5221200471      1.9717e-05      0.9999974683    0.9757552370
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 0.0001
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902685020
# VQE energy       : -16.943721196822
# Energy error     : 1.814882e-04
# Fidelity         : 0.999970084450
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -8.892069658534
# VQE energy       : -8.891427409839
# Energy error     : 6.422487e-04
# Fidelity         : 0.999762333366
# Tracking overlap : 0.875968199724
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.379329565434
# VQE energy       : -4.379113451836
# Energy error     : 2.161136e-04
# Fidelity         : 0.811156763096
# Tracking overlap : 0.049012390542
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.749826501443
# VQE energy       : -2.749797541799
# Energy error     : 2.895964e-05
# Fidelity         : 0.994073111128
# Tracking overlap : 0.000000031384
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.874705890824
# VQE energy       : -1.874703469707
# Energy error     : 2.421118e-06
# Fidelity         : 0.999927966301
# Tracking overlap : 0.821475340516
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.348823187245
# VQE energy       : -1.348822052915
# Energy error     : 1.134330e-06
# Fidelity         : 0.999999004385
# Tracking overlap : 0.894889575320
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.010440164101
# VQE energy       : -1.010439588929
# Energy error     : 5.751719e-07
# Fidelity         : 0.999999783506
# Tracking overlap : 0.936973636235
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.779140149474
# VQE energy       : -0.779110418961
# Energy error     : 2.973051e-05
# Fidelity         : 0.999987932584
# Tracking overlap : 0.962958579878
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723602270
# VQE energy       : -0.611722167866
# Energy error     : 1.434404e-06
# Fidelity         : 0.999999652178
# Tracking overlap : 0.977655599151
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295546782
# VQE energy       : -0.484295206011
# Energy error     : 3.407709e-07
# Fidelity         : 0.999999924811
# Tracking overlap : 0.986387663457
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -16.9439026850     -16.9437211968     1.8149e-04      0.9999700845    1.0000000000
# 0.3111       -8.8920696585      -8.8914274098      6.4225e-04      0.9997623334    0.8759681997
# 0.5222       -4.3793295654      -4.3791134518      2.1611e-04      0.8111567631    0.0490123905
# 0.7333       -2.7498265014      -2.7497975418      2.8960e-05      0.9940731111    0.0000000314
# 0.9444       -1.8747058908      -1.8747034697      2.4211e-06      0.9999279663    0.8214753405
# 1.1556       -1.3488231872      -1.3488220529      1.1343e-06      0.9999990044    0.8948895753
# 1.3667       -1.0104401641      -1.0104395889      5.7517e-07      0.9999997835    0.9369736362
# 1.5778       -0.7791401495      -0.7791104190      2.9731e-05      0.9999879326    0.9629585799
# 1.7889       -0.6117236023      -0.6117221679      1.4344e-06      0.9999996522    0.9776555992
# 2.0000       -0.4842955468      -0.4842952060      3.4077e-07      0.9999999248    0.9863876635
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.777143110415
# Energy error     : 1.853349e-04
# Fidelity         : 0.999983096594
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.835466114626
# Energy error     : 9.750282e-04
# Fidelity         : 0.999858383955
# Tracking overlap : 0.849682895754
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.729975937265
# Energy error     : 7.404276e-04
# Fidelity         : 0.999884924685
# Tracking overlap : 0.166228013927
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.537606117397
# Energy error     : 5.427133e-04
# Fidelity         : 0.999901629131
# Tracking overlap : 0.636909541724
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.276012757727
# Energy error     : 1.035201e-06
# Fidelity         : 0.999999881531
# Tracking overlap : 0.821649366076
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.448523294305
# Energy error     : 1.570911e-04
# Fidelity         : 0.999981958488
# Tracking overlap : 0.904235912470
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.860706035943
# Energy error     : 1.262292e-04
# Fidelity         : 0.999987996714
# Tracking overlap : 0.941753934025
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.420010554468
# Energy error     : 7.997481e-05
# Fidelity         : 0.999994055767
# Tracking overlap : 0.962240181026
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.076254687842
# Energy error     : 5.787978e-05
# Fidelity         : 0.999995793592
# Tracking overlap : 0.973922376838
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.800041721553
# Energy error     : 3.154466e-05
# Fidelity         : 0.999996216992
# Tracking overlap : 0.981415964116
#
#
# ==============================================================================================================
# SUMMARY : Strong SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -20.7773284453     -20.7771431104     1.8533e-04      0.9999830966    1.0000000000
# 0.3111       -12.8364411428     -12.8354661146     9.7503e-04      0.9998583840    0.8496828958
# 0.5222       -7.7307163648      -7.7299759373      7.4043e-04      0.9998849247    0.1662280139
# 0.7333       -5.5381488307      -5.5376061174      5.4271e-04      0.9999016291    0.6369095417
# 0.9444       -4.2760137929      -4.2760127577      1.0352e-06      0.9999998815    0.8216493661
# 1.1556       -3.4486803854      -3.4485232943      1.5709e-04      0.9999819585    0.9042359125
# 1.3667       -2.8608322652      -2.8607060359      1.2623e-04      0.9999879967    0.9417539340
# 1.5778       -2.4200905293      -2.4200105545      7.9975e-05      0.9999940558    0.9622401810
# 1.7889       -2.0763125676      -2.0762546878      5.7880e-05      0.9999957936    0.9739223768
# 2.0000       -1.8000732662      -1.8000417216      3.1545e-05      0.9999962170    0.9814159641

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------


plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HEA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HEA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119046
# T = 2     Fidelity = 0.99733049
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98268506
# T = 2     Fidelity = 0.99772346
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394332
# T = 2     Fidelity = 0.99802466
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98504334
# T = 2     Fidelity = 0.99826884
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98600084
# T = 2     Fidelity = 0.99846434
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98685686
# T = 2     Fidelity = 0.99862714
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762115
# T = 2     Fidelity = 0.99876192
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98831528
# T = 2     Fidelity = 0.99887660
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893684
# T = 2     Fidelity = 0.99897102
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98950854
# T = 2     Fidelity = 0.99905277
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00037927
# T = 10    Fidelity = 0.00053853
# T = 20    Fidelity = 0.01172705
# T = 30    Fidelity = 0.08075728
# T = 40    Fidelity = 0.18881122
# T = 50    Fidelity = 0.42952587
# T = 75    Fidelity = 0.56718541
# T = 100   Fidelity = 0.72790369
# T = 125   Fidelity = 0.80783829
# T = 150   Fidelity = 0.83706762
# T = 175   Fidelity = 0.90602725
# T = 200   Fidelity = 0.91921351
# T = 225   Fidelity = 0.96691803
# T = 250   Fidelity = 0.89103537
# T = 275   Fidelity = 0.96874213
# T = 300   Fidelity = 0.85615988
# T = 400   Fidelity = 0.98079422
# T = 500   Fidelity = 0.96090057
# T = 600   Fidelity = 0.95885028
# T = 700   Fidelity = 0.62980649
# T = 800   Fidelity = 0.83512097
# T = 900   Fidelity = 0.82333458
# T = 1000  Fidelity = 0.66410808
# T = 1010  Fidelity = 0.57929333
# T = 1020  Fidelity = 0.61942760
# T = 1030  Fidelity = 0.69812874
# T = 1040  Fidelity = 0.72127585
# T = 1050  Fidelity = 0.78670462
# T = 1060  Fidelity = 0.91687745
# T = 1070  Fidelity = 0.77705851
# T = 1080  Fidelity = 0.78773492
# T = 1090  Fidelity = 0.71198548
# T = 1100  Fidelity = 0.38091668
# T = 1200  Fidelity = 0.59282733
# T = 1300  Fidelity = 0.48275130
# T = 1400  Fidelity = 0.71933528
# T = 1500  Fidelity = 0.46443263
# T = 2000  Fidelity = 0.93500084
# T = 2100  Fidelity = 0.70777874
# T = 2110  Fidelity = 0.56820891
# T = 2120  Fidelity = 0.47348645
# T = 2130  Fidelity = 0.39791763
# T = 2140  Fidelity = 0.49559881
# T = 2150  Fidelity = 0.41695227
# T = 2160  Fidelity = 0.62902203
# T = 2170  Fidelity = 0.52090111
# T = 2180  Fidelity = 0.49511667
# T = 2190  Fidelity = 0.50063603
# T = 2200  Fidelity = 0.35926395
# T = 2300  Fidelity = 0.77409437
# T = 2400  Fidelity = 0.21867472
# T = 2500  Fidelity = 0.75761473
# T = 2600  Fidelity = 0.43496241
# T = 2700  Fidelity = 0.55693017
# T = 2800  Fidelity = 0.85184440
# T = 2900  Fidelity = 0.64713976
# T = 3000  Fidelity = 0.82574794
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00976726e+00
# P0     = 0.82574794
# P1     = 0.05928465
# P0+P1  = 0.88503258
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000003
# T = 5     Fidelity = 0.00048717
# T = 10    Fidelity = 0.06795763
# T = 20    Fidelity = 0.22417768
# T = 30    Fidelity = 0.62653372
# T = 40    Fidelity = 0.37377833
# T = 50    Fidelity = 0.78969159
# T = 75    Fidelity = 0.74916019
# T = 100   Fidelity = 0.79947323
# T = 125   Fidelity = 0.87760336
# T = 150   Fidelity = 0.88432453
# T = 175   Fidelity = 0.90332808
# T = 200   Fidelity = 0.92739321
# T = 225   Fidelity = 0.93808939
# T = 250   Fidelity = 0.94666964
# T = 275   Fidelity = 0.95157900
# T = 300   Fidelity = 0.94579525
# T = 400   Fidelity = 0.97150819
# T = 500   Fidelity = 0.97110572
# T = 600   Fidelity = 0.82121170
# T = 700   Fidelity = 0.79841706
# T = 800   Fidelity = 0.84651252
# T = 900   Fidelity = 0.72360132
# T = 1000  Fidelity = 0.77854150
# T = 1010  Fidelity = 0.89510946
# T = 1020  Fidelity = 0.86694011
# T = 1030  Fidelity = 0.92933823
# T = 1040  Fidelity = 0.85953495
# T = 1050  Fidelity = 0.87249722
# T = 1060  Fidelity = 0.75776137
# T = 1070  Fidelity = 0.79306639
# T = 1080  Fidelity = 0.54021168
# T = 1090  Fidelity = 0.69187148
# T = 1100  Fidelity = 0.56855822
# T = 1200  Fidelity = 0.79641278
# T = 1300  Fidelity = 0.83489419
# T = 1400  Fidelity = 0.93467088
# T = 1500  Fidelity = 0.85221091
# T = 2000  Fidelity = 0.58934345
# T = 2100  Fidelity = 0.60373381
# T = 2110  Fidelity = 0.67977200
# T = 2120  Fidelity = 0.82556758
# T = 2130  Fidelity = 0.96006087
# T = 2140  Fidelity = 0.76860549
# T = 2150  Fidelity = 0.84458111
# T = 2160  Fidelity = 0.87968008
# T = 2170  Fidelity = 0.61307755
# T = 2180  Fidelity = 0.89647207
# T = 2190  Fidelity = 0.58069072
# T = 2200  Fidelity = 0.49554536
# T = 2300  Fidelity = 0.51639012
# T = 2400  Fidelity = 0.68663935
# T = 2500  Fidelity = 0.34025278
# T = 2600  Fidelity = 0.92859049
# T = 2700  Fidelity = 0.86334899
# T = 2800  Fidelity = 0.85848846
# T = 2900  Fidelity = 0.82278540
# T = 3000  Fidelity = 0.86971324
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02946706e+00
# P0     = 0.86971324
# P1     = 0.01294137
# P0+P1  = 0.88265461
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00003688
# T = 2     Fidelity = 0.00032390
# T = 5     Fidelity = 0.02053911
# T = 10    Fidelity = 0.22192151
# T = 20    Fidelity = 0.58956240
# T = 30    Fidelity = 0.66107441
# T = 40    Fidelity = 0.79029472
# T = 50    Fidelity = 0.82272588
# T = 75    Fidelity = 0.92691944
# T = 100   Fidelity = 0.96746964
# T = 125   Fidelity = 0.98441438
# T = 150   Fidelity = 0.99245178
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00115144
# T = 2     Fidelity = 0.00475606
# T = 5     Fidelity = 0.06199665
# T = 10    Fidelity = 0.28433953
# T = 20    Fidelity = 0.68061551
# T = 30    Fidelity = 0.73438988
# T = 40    Fidelity = 0.82199079
# T = 50    Fidelity = 0.88762084
# T = 75    Fidelity = 0.95504076
# T = 100   Fidelity = 0.98258074
# T = 125   Fidelity = 0.99310993
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00848115
# T = 2     Fidelity = 0.02334992
# T = 5     Fidelity = 0.12489553
# T = 10    Fidelity = 0.34161768
# T = 20    Fidelity = 0.67127994
# T = 30    Fidelity = 0.79903334
# T = 40    Fidelity = 0.85967277
# T = 50    Fidelity = 0.90961503
# T = 75    Fidelity = 0.97041744
# T = 100   Fidelity = 0.98953961
# T = 125   Fidelity = 0.99606494
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03426656
# T = 2     Fidelity = 0.07345007
# T = 5     Fidelity = 0.22251232
# T = 10    Fidelity = 0.42790007
# T = 20    Fidelity = 0.67815498
# T = 30    Fidelity = 0.80017282
# T = 40    Fidelity = 0.86942741
# T = 50    Fidelity = 0.91673068
# T = 75    Fidelity = 0.97803236
# T = 100   Fidelity = 0.99448417
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09387961
# T = 2     Fidelity = 0.17171195
# T = 5     Fidelity = 0.36271780
# T = 10    Fidelity = 0.55343012
# T = 20    Fidelity = 0.74131876
# T = 30    Fidelity = 0.83186574
# T = 40    Fidelity = 0.88451760
# T = 50    Fidelity = 0.91904051
# T = 75    Fidelity = 0.96674411
# T = 100   Fidelity = 0.98523280
# T = 125   Fidelity = 0.99221031
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19128099
# T = 2     Fidelity = 0.31295479
# T = 5     Fidelity = 0.52539389
# T = 10    Fidelity = 0.69188348
# T = 20    Fidelity = 0.82742466
# T = 30    Fidelity = 0.88698305
# T = 40    Fidelity = 0.92135315
# T = 50    Fidelity = 0.94300272
# T = 75    Fidelity = 0.96967529
# T = 100   Fidelity = 0.98240535
# T = 125   Fidelity = 0.98821072
# T = 150   Fidelity = 0.99123880
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30079396
# T = 2     Fidelity = 0.45444379
# T = 5     Fidelity = 0.66192427
# T = 10    Fidelity = 0.79874485
# T = 20    Fidelity = 0.89477043
# T = 30    Fidelity = 0.93351813
# T = 40    Fidelity = 0.95514675
# T = 50    Fidelity = 0.96720160
# T = 75    Fidelity = 0.98300973
# T = 100   Fidelity = 0.98934208
# T = 125   Fidelity = 0.99272854
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40222291
# T = 2     Fidelity = 0.57277497
# T = 5     Fidelity = 0.76040619
# T = 10    Fidelity = 0.86913947
# T = 20    Fidelity = 0.93656360
# T = 30    Fidelity = 0.96228640
# T = 40    Fidelity = 0.97438631
# T = 50    Fidelity = 0.98214581
# T = 75    Fidelity = 0.99122667
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.36752113e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063851
# T = 10    Fidelity = 0.00011150
# T = 20    Fidelity = 0.00397162
# T = 30    Fidelity = 0.05541340
# T = 40    Fidelity = 0.12231932
# T = 50    Fidelity = 0.21157737
# T = 75    Fidelity = 0.58023270
# T = 100   Fidelity = 0.76482110
# T = 125   Fidelity = 0.73486715
# T = 150   Fidelity = 0.86846595
# T = 175   Fidelity = 0.91257575
# T = 200   Fidelity = 0.87387342
# T = 225   Fidelity = 0.95061176
# T = 250   Fidelity = 0.98408511
# T = 275   Fidelity = 0.98505853
# T = 300   Fidelity = 0.86180809
# T = 400   Fidelity = 0.91385877
# T = 500   Fidelity = 0.92722432
# T = 600   Fidelity = 0.91969200
# T = 700   Fidelity = 0.91433259
# T = 800   Fidelity = 0.82102005
# T = 900   Fidelity = 0.78182330
# T = 1000  Fidelity = 0.67244157
# T = 1010  Fidelity = 0.52178817
# T = 1020  Fidelity = 0.57359715
# T = 1030  Fidelity = 0.75266637
# T = 1040  Fidelity = 0.89783975
# T = 1050  Fidelity = 0.85717406
# T = 1060  Fidelity = 0.83329802
# T = 1070  Fidelity = 0.70185540
# T = 1080  Fidelity = 0.54477603
# T = 1090  Fidelity = 0.51432849
# T = 1100  Fidelity = 0.55254476
# T = 1200  Fidelity = 0.67085937
# T = 1300  Fidelity = 0.58650848
# T = 1400  Fidelity = 0.67208574
# T = 1500  Fidelity = 0.29169196
# T = 2000  Fidelity = 0.11282495
# T = 2100  Fidelity = 0.68378824
# T = 2110  Fidelity = 0.68255354
# T = 2120  Fidelity = 0.73046603
# T = 2130  Fidelity = 0.81319978
# T = 2140  Fidelity = 0.85559500
# T = 2150  Fidelity = 0.92230811
# T = 2160  Fidelity = 0.90556662
# T = 2170  Fidelity = 0.86589555
# T = 2180  Fidelity = 0.77660926
# T = 2190  Fidelity = 0.40700422
# T = 2200  Fidelity = 0.26067585
# T = 2300  Fidelity = 0.55592535
# T = 2400  Fidelity = 0.82731323
# T = 2500  Fidelity = 0.90618841
# T = 2600  Fidelity = 0.80689128
# T = 2700  Fidelity = 0.81029011
# T = 2800  Fidelity = 0.35076070
# T = 2900  Fidelity = 0.89001820
# T = 3000  Fidelity = 0.74292085
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00970921e+00
# P0     = 0.74292085
# P1     = 0.04148923
# P0+P1  = 0.78441008
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.12924856e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000006
# T = 5     Fidelity = 0.00018282
# T = 10    Fidelity = 0.04148609
# T = 20    Fidelity = 0.42113227
# T = 30    Fidelity = 0.49131403
# T = 40    Fidelity = 0.64133853
# T = 50    Fidelity = 0.64480968
# T = 75    Fidelity = 0.88002046
# T = 100   Fidelity = 0.90137143
# T = 125   Fidelity = 0.87121934
# T = 150   Fidelity = 0.88469968
# T = 175   Fidelity = 0.91871432
# T = 200   Fidelity = 0.93982243
# T = 225   Fidelity = 0.95350798
# T = 250   Fidelity = 0.94665822
# T = 275   Fidelity = 0.95719805
# T = 300   Fidelity = 0.93872837
# T = 400   Fidelity = 0.97377917
# T = 500   Fidelity = 0.95643785
# T = 600   Fidelity = 0.92958040
# T = 700   Fidelity = 0.56383523
# T = 800   Fidelity = 0.62073181
# T = 900   Fidelity = 0.67794112
# T = 1000  Fidelity = 0.89003593
# T = 1010  Fidelity = 0.56790154
# T = 1020  Fidelity = 0.84382207
# T = 1030  Fidelity = 0.83970966
# T = 1040  Fidelity = 0.70920973
# T = 1050  Fidelity = 0.85539395
# T = 1060  Fidelity = 0.56575185
# T = 1070  Fidelity = 0.80812665
# T = 1080  Fidelity = 0.62341759
# T = 1090  Fidelity = 0.81736442
# T = 1100  Fidelity = 0.70670406
# T = 1200  Fidelity = 0.61588650
# T = 1300  Fidelity = 0.60225737
# T = 1400  Fidelity = 0.55150610
# T = 1500  Fidelity = 0.71207324
# T = 2000  Fidelity = 0.50060358
# T = 2100  Fidelity = 0.70523116
# T = 2110  Fidelity = 0.68591317
# T = 2120  Fidelity = 0.82775841
# T = 2130  Fidelity = 0.67086675
# T = 2140  Fidelity = 0.59349305
# T = 2150  Fidelity = 0.80723856
# T = 2160  Fidelity = 0.53638663
# T = 2170  Fidelity = 0.69877454
# T = 2180  Fidelity = 0.66123460
# T = 2190  Fidelity = 0.77353189
# T = 2200  Fidelity = 0.50925802
# T = 2300  Fidelity = 0.68230336
# T = 2400  Fidelity = 0.67509702
# T = 2500  Fidelity = 0.66477059
# T = 2600  Fidelity = 0.71522105
# T = 2700  Fidelity = 0.75545664
# T = 2800  Fidelity = 0.79124703
# T = 2900  Fidelity = 0.52640627
# T = 3000  Fidelity = 0.56244688
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02931057e+00
# P0     = 0.56244688
# P1     = 0.20487814
# P0+P1  = 0.76732502
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00001183
# T = 2     Fidelity = 0.00016903
# T = 5     Fidelity = 0.01433755
# T = 10    Fidelity = 0.17121164
# T = 20    Fidelity = 0.44269803
# T = 30    Fidelity = 0.34006880
# T = 40    Fidelity = 0.54713148
# T = 50    Fidelity = 0.43877965
# T = 75    Fidelity = 0.49353370
# T = 100   Fidelity = 0.50304072
# T = 125   Fidelity = 0.50289030
# T = 150   Fidelity = 0.50194392
# T = 175   Fidelity = 0.50105815
# T = 200   Fidelity = 0.49651474
# T = 225   Fidelity = 0.50816004
# T = 250   Fidelity = 0.50063847
# T = 275   Fidelity = 0.48663406
# T = 300   Fidelity = 0.48656128
# T = 400   Fidelity = 0.49688336
# T = 500   Fidelity = 0.30746108
# T = 600   Fidelity = 0.50727655
# T = 700   Fidelity = 0.38709952
# T = 800   Fidelity = 0.53188857
# T = 900   Fidelity = 0.52779164
# T = 1000  Fidelity = 0.69823646
# T = 1010  Fidelity = 0.39503802
# T = 1020  Fidelity = 0.40017217
# T = 1030  Fidelity = 0.46780696
# T = 1040  Fidelity = 0.49565846
# T = 1050  Fidelity = 0.46512982
# T = 1060  Fidelity = 0.36756255
# T = 1070  Fidelity = 0.55854030
# T = 1080  Fidelity = 0.26627082
# T = 1090  Fidelity = 0.27513119
# T = 1100  Fidelity = 0.60844760
# T = 1200  Fidelity = 0.29102621
# T = 1300  Fidelity = 0.55030621
# T = 1400  Fidelity = 0.53316801
# T = 1500  Fidelity = 0.36062110
# T = 2000  Fidelity = 0.28908275
# T = 2100  Fidelity = 0.20239833
# T = 2110  Fidelity = 0.54844117
# T = 2120  Fidelity = 0.46952207
# T = 2130  Fidelity = 0.49817849
# T = 2140  Fidelity = 0.32258060
# T = 2150  Fidelity = 0.44340995
# T = 2160  Fidelity = 0.38436151
# T = 2170  Fidelity = 0.38903253
# T = 2180  Fidelity = 0.52910501
# T = 2190  Fidelity = 0.19288574
# T = 2200  Fidelity = 0.48350237
# T = 2300  Fidelity = 0.53174620
# T = 2400  Fidelity = 0.48596743
# T = 2500  Fidelity = 0.45758309
# T = 2600  Fidelity = 0.45794713
# T = 2700  Fidelity = 0.56730429
# T = 2800  Fidelity = 0.59707301
# T = 2900  Fidelity = 0.45420419
# T = 3000  Fidelity = 0.42695550
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.42695550
# P1     = 0.06092808
# P0+P1  = 0.48788358
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.03672155e-03
# T = 1     Fidelity = 0.00307236
# T = 2     Fidelity = 0.01239095
# T = 5     Fidelity = 0.08437388
# T = 10    Fidelity = 0.22340458
# T = 20    Fidelity = 0.31774530
# T = 30    Fidelity = 0.38305697
# T = 40    Fidelity = 0.54970207
# T = 50    Fidelity = 0.58068318
# T = 75    Fidelity = 0.50032172
# T = 100   Fidelity = 0.52169214
# T = 125   Fidelity = 0.52326242
# T = 150   Fidelity = 0.52305998
# T = 175   Fidelity = 0.51983008
# T = 200   Fidelity = 0.53011908
# T = 225   Fidelity = 0.52266568
# T = 250   Fidelity = 0.51799068
# T = 275   Fidelity = 0.52623883
# T = 300   Fidelity = 0.49476262
# T = 400   Fidelity = 0.50927669
# T = 500   Fidelity = 0.55329569
# T = 600   Fidelity = 0.50784769
# T = 700   Fidelity = 0.44194131
# T = 800   Fidelity = 0.45193613
# T = 900   Fidelity = 0.53373124
# T = 1000  Fidelity = 0.77620227
# T = 1010  Fidelity = 0.44412219
# T = 1020  Fidelity = 0.12564029
# T = 1030  Fidelity = 0.56061631
# T = 1040  Fidelity = 0.79062951
# T = 1050  Fidelity = 0.59297472
# T = 1060  Fidelity = 0.48541980
# T = 1070  Fidelity = 0.49762120
# T = 1080  Fidelity = 0.42056927
# T = 1090  Fidelity = 0.25495531
# T = 1100  Fidelity = 0.74108826
# T = 1200  Fidelity = 0.58410748
# T = 1300  Fidelity = 0.45415954
# T = 1400  Fidelity = 0.52257910
# T = 1500  Fidelity = 0.53717531
# T = 2000  Fidelity = 0.45819461
# T = 2100  Fidelity = 0.51589492
# T = 2110  Fidelity = 0.55365533
# T = 2120  Fidelity = 0.46781062
# T = 2130  Fidelity = 0.39319565
# T = 2140  Fidelity = 0.56251771
# T = 2150  Fidelity = 0.76797127
# T = 2160  Fidelity = 0.43734758
# T = 2170  Fidelity = 0.24373120
# T = 2180  Fidelity = 0.49675925
# T = 2190  Fidelity = 0.68859352
# T = 2200  Fidelity = 0.61397433
# T = 2300  Fidelity = 0.81737422
# T = 2400  Fidelity = 0.53209095
# T = 2500  Fidelity = 0.50163692
# T = 2600  Fidelity = 0.55254015
# T = 2700  Fidelity = 0.44691200
# T = 2800  Fidelity = 0.53622584
# T = 2900  Fidelity = 0.30501852
# T = 3000  Fidelity = 0.43890842
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.43890842
# P1     = 0.02390881
# P0+P1  = 0.46281723
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.41475042e-03
# T = 1     Fidelity = 0.02404917
# T = 2     Fidelity = 0.06514443
# T = 5     Fidelity = 0.21900787
# T = 10    Fidelity = 0.40677280
# T = 20    Fidelity = 0.52930978
# T = 30    Fidelity = 0.49785373
# T = 40    Fidelity = 0.50386296
# T = 50    Fidelity = 0.54926931
# T = 75    Fidelity = 0.60863672
# T = 100   Fidelity = 0.60704637
# T = 125   Fidelity = 0.61204933
# T = 150   Fidelity = 0.61601784
# T = 175   Fidelity = 0.61936255
# T = 200   Fidelity = 0.62639112
# T = 225   Fidelity = 0.62921702
# T = 250   Fidelity = 0.63297814
# T = 275   Fidelity = 0.62984761
# T = 300   Fidelity = 0.64605811
# T = 400   Fidelity = 0.59391591
# T = 500   Fidelity = 0.65343685
# T = 600   Fidelity = 0.67712521
# T = 700   Fidelity = 0.59464015
# T = 800   Fidelity = 0.71348235
# T = 900   Fidelity = 0.60856547
# T = 1000  Fidelity = 0.48719845
# T = 1010  Fidelity = 0.76016574
# T = 1020  Fidelity = 0.85146055
# T = 1030  Fidelity = 0.75055080
# T = 1040  Fidelity = 0.52966515
# T = 1050  Fidelity = 0.47477864
# T = 1060  Fidelity = 0.65019794
# T = 1070  Fidelity = 0.77729163
# T = 1080  Fidelity = 0.82145966
# T = 1090  Fidelity = 0.55645949
# T = 1100  Fidelity = 0.40084786
# T = 1200  Fidelity = 0.46013732
# T = 1300  Fidelity = 0.54118222
# T = 1400  Fidelity = 0.76945465
# T = 1500  Fidelity = 0.68057646
# T = 2000  Fidelity = 0.77319927
# T = 2100  Fidelity = 0.81898093
# T = 2110  Fidelity = 0.80879504
# T = 2120  Fidelity = 0.55133367
# T = 2130  Fidelity = 0.65536226
# T = 2140  Fidelity = 0.71224918
# T = 2150  Fidelity = 0.83121774
# T = 2160  Fidelity = 0.84625206
# T = 2170  Fidelity = 0.78133566
# T = 2180  Fidelity = 0.53235915
# T = 2190  Fidelity = 0.56991373
# T = 2200  Fidelity = 0.69967242
# T = 2300  Fidelity = 0.76659655
# T = 2400  Fidelity = 0.75366855
# T = 2500  Fidelity = 0.82617051
# T = 2600  Fidelity = 0.73018483
# T = 2700  Fidelity = 0.77745129
# T = 2800  Fidelity = 0.76119776
# T = 2900  Fidelity = 0.69743982
# T = 3000  Fidelity = 0.75031502
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.75031502
# P1     = 0.00485158
# P0+P1  = 0.75516660
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50213251e-02
# T = 1     Fidelity = 0.08267340
# T = 2     Fidelity = 0.17483957
# T = 5     Fidelity = 0.39228632
# T = 10    Fidelity = 0.58589640
# T = 20    Fidelity = 0.71387813
# T = 30    Fidelity = 0.72026778
# T = 40    Fidelity = 0.71302750
# T = 50    Fidelity = 0.71875984
# T = 75    Fidelity = 0.74412497
# T = 100   Fidelity = 0.76245393
# T = 125   Fidelity = 0.77526926
# T = 150   Fidelity = 0.78586252
# T = 175   Fidelity = 0.79499528
# T = 200   Fidelity = 0.80418188
# T = 225   Fidelity = 0.81044094
# T = 250   Fidelity = 0.81597486
# T = 275   Fidelity = 0.82614950
# T = 300   Fidelity = 0.81744666
# T = 400   Fidelity = 0.87418279
# T = 500   Fidelity = 0.87055658
# T = 600   Fidelity = 0.79401212
# T = 700   Fidelity = 0.82775879
# T = 800   Fidelity = 0.84465963
# T = 900   Fidelity = 0.85221129
# T = 1000  Fidelity = 0.87672729
# T = 1010  Fidelity = 0.79380164
# T = 1020  Fidelity = 0.77893421
# T = 1030  Fidelity = 0.86807205
# T = 1040  Fidelity = 0.95150924
# T = 1050  Fidelity = 0.97295767
# T = 1060  Fidelity = 0.93455021
# T = 1070  Fidelity = 0.82901571
# T = 1080  Fidelity = 0.84154569
# T = 1090  Fidelity = 0.76878834
# T = 1100  Fidelity = 0.82736657
# T = 1200  Fidelity = 0.79764256
# T = 1300  Fidelity = 0.95553398
# T = 1400  Fidelity = 0.85405265
# T = 1500  Fidelity = 0.92816745
# T = 2000  Fidelity = 0.85955675
# T = 2100  Fidelity = 0.86732549
# T = 2110  Fidelity = 0.86736988
# T = 2120  Fidelity = 0.92148171
# T = 2130  Fidelity = 0.86403670
# T = 2140  Fidelity = 0.88049561
# T = 2150  Fidelity = 0.80894616
# T = 2160  Fidelity = 0.83691998
# T = 2170  Fidelity = 0.95398568
# T = 2180  Fidelity = 0.93774393
# T = 2190  Fidelity = 0.93724661
# T = 2200  Fidelity = 0.94080750
# T = 2300  Fidelity = 0.95022438
# T = 2400  Fidelity = 0.97264468
# T = 2500  Fidelity = 0.96418819
# T = 2600  Fidelity = 0.98741966
# T = 2700  Fidelity = 0.96909273
# T = 2800  Fidelity = 0.95236420
# T = 2900  Fidelity = 0.85486489
# T = 3000  Fidelity = 0.97240002
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.09849352e+00
# P0     = 0.97240002
# P1     = 0.00008271
# P0+P1  = 0.97248273
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77221454e-02
# T = 1     Fidelity = 0.17551352
# T = 2     Fidelity = 0.31612412
# T = 5     Fidelity = 0.55527572
# T = 10    Fidelity = 0.72495588
# T = 20    Fidelity = 0.82951919
# T = 30    Fidelity = 0.85314920
# T = 40    Fidelity = 0.85900685
# T = 50    Fidelity = 0.86469318
# T = 75    Fidelity = 0.88210997
# T = 100   Fidelity = 0.89840764
# T = 125   Fidelity = 0.90980964
# T = 150   Fidelity = 0.91812025
# T = 175   Fidelity = 0.92575979
# T = 200   Fidelity = 0.93482827
# T = 225   Fidelity = 0.93591839
# T = 250   Fidelity = 0.93620041
# T = 275   Fidelity = 0.94546898
# T = 300   Fidelity = 0.93549800
# T = 400   Fidelity = 0.94952476
# T = 500   Fidelity = 0.95253851
# T = 600   Fidelity = 0.96023537
# T = 700   Fidelity = 0.91548563
# T = 800   Fidelity = 0.92797590
# T = 900   Fidelity = 0.94694710
# T = 1000  Fidelity = 0.93970317
# T = 1010  Fidelity = 0.95198310
# T = 1020  Fidelity = 0.95696148
# T = 1030  Fidelity = 0.97883161
# T = 1040  Fidelity = 0.99490555
#
# Minimum T for Fidelity >= 0.99 : 1040
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20187623e-01
# T = 1     Fidelity = 0.27983619
# T = 2     Fidelity = 0.45238454
# T = 5     Fidelity = 0.68125914
# T = 10    Fidelity = 0.81919685
# T = 20    Fidelity = 0.89668228
# T = 30    Fidelity = 0.91811042
# T = 40    Fidelity = 0.92944244
# T = 50    Fidelity = 0.93809827
# T = 75    Fidelity = 0.95177156
# T = 100   Fidelity = 0.96203259
# T = 125   Fidelity = 0.96842602
# T = 150   Fidelity = 0.97428948
# T = 175   Fidelity = 0.97599602
# T = 200   Fidelity = 0.98170332
# T = 225   Fidelity = 0.97814096
# T = 250   Fidelity = 0.98140447
# T = 275   Fidelity = 0.97905498
# T = 300   Fidelity = 0.98004642
# T = 400   Fidelity = 0.97513305
# T = 500   Fidelity = 0.95337656
# T = 600   Fidelity = 0.93814177
# T = 700   Fidelity = 0.97979278
# T = 800   Fidelity = 0.98440403
# T = 900   Fidelity = 0.98927417
# T = 1000  Fidelity = 0.97948471
# T = 1010  Fidelity = 0.97136915
# T = 1020  Fidelity = 0.99570250
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405779e-01
# T = 1     Fidelity = 0.37885123
# T = 2     Fidelity = 0.56667452
# T = 5     Fidelity = 0.77028792
# T = 10    Fidelity = 0.87923841
# T = 20    Fidelity = 0.93538185
# T = 30    Fidelity = 0.95285899
# T = 40    Fidelity = 0.96406048
# T = 50    Fidelity = 0.96973413
# T = 75    Fidelity = 0.97963667
# T = 100   Fidelity = 0.98517503
# T = 125   Fidelity = 0.98840906
# T = 150   Fidelity = 0.99074439
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843475e-01
# T = 1     Fidelity = 0.46389333
# T = 2     Fidelity = 0.65548277
# T = 5     Fidelity = 0.83094903
# T = 10    Fidelity = 0.91704337
# T = 20    Fidelity = 0.95851806
# T = 30    Fidelity = 0.97284755
# T = 40    Fidelity = 0.97909242
# T = 50    Fidelity = 0.98365767
# T = 75    Fidelity = 0.99020913
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000008
# T = 5     Fidelity = 0.00082466
# T = 10    Fidelity = 0.06388907
# T = 20    Fidelity = 0.45557453
# T = 30    Fidelity = 0.88104114
# T = 40    Fidelity = 0.96746376
# T = 50    Fidelity = 0.99174867
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000225
# T = 5     Fidelity = 0.02513016
# T = 10    Fidelity = 0.90055444
# T = 20    Fidelity = 0.96721418
# T = 30    Fidelity = 0.99647854
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00005271
# T = 2     Fidelity = 0.00078633
# T = 5     Fidelity = 0.18890817
# T = 10    Fidelity = 0.98869690
# T = 20    Fidelity = 0.99533066
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00123912
# T = 2     Fidelity = 0.00817737
# T = 5     Fidelity = 0.34554614
# T = 10    Fidelity = 0.98683091
# T = 20    Fidelity = 0.99359856
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00700326
# T = 2     Fidelity = 0.02897809
# T = 5     Fidelity = 0.47049184
# T = 10    Fidelity = 0.98167696
# T = 20    Fidelity = 0.99294449
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02073336
# T = 2     Fidelity = 0.06401129
# T = 5     Fidelity = 0.56537362
# T = 10    Fidelity = 0.97650025
# T = 20    Fidelity = 0.99258234
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04378742
# T = 2     Fidelity = 0.11042866
# T = 5     Fidelity = 0.63867567
# T = 10    Fidelity = 0.97238870
# T = 20    Fidelity = 0.99280615
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07543643
# T = 2     Fidelity = 0.16389417
# T = 5     Fidelity = 0.69626950
# T = 10    Fidelity = 0.96945561
# T = 20    Fidelity = 0.99322386
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11373794
# T = 2     Fidelity = 0.22088871
# T = 5     Fidelity = 0.74281186
# T = 10    Fidelity = 0.96775875
# T = 20    Fidelity = 0.99358826
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15636465
# T = 2     Fidelity = 0.27855609
# T = 5     Fidelity = 0.78147584
# T = 10    Fidelity = 0.96744596
# T = 20    Fidelity = 0.99388932
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9973304947      1.00972087e+00    None        None        None
# Symmetric      0.311     2         0.9977234591      1.02934439e+00    None        None        None
# Symmetric      0.522     2         0.9980246614      1.04790824e+00    None        None        None
# Symmetric      0.733     2         0.9982688428      1.06556366e+00    None        None        None
# Symmetric      0.944     2         0.9984643380      1.08242773e+00    None        None        None
# Symmetric      1.156     2         0.9986271397      1.09859358e+00    None        None        None
# Symmetric      1.367     2         0.9987619193      1.11413694e+00    None        None        None
# Symmetric      1.578     2         0.9988766009      1.12912045e+00    None        None        None
# Symmetric      1.789     2         0.9989710230      1.14359670e+00    None        None        None
# Symmetric      2.000     2         0.9990527722      1.15761039e+00    None        None        None
# Weak SSB optimised0.100     None      0.9807942216      2.42819099e-01    0.825748    0.059285    0.885033
# Weak SSB optimised0.311     None      0.9715081929      2.61171322e-01    0.869713    0.012941    0.882655
# Weak SSB optimised0.522     150       0.9924517793      2.64873214e-01    None        None        None
# Weak SSB optimised0.733     125       0.9931099307      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     125       0.9960649391      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     100       0.9944841733      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9922103148      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     150       0.9912388001      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9927285410      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     75        0.9912266709      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9850585253      1.36752113e-03    0.742921    0.041489    0.78441
# Weak SSB       0.311     None      0.9737791725      1.12924856e-03    0.562447    0.204878    0.767325
# Weak SSB       0.522     None      0.6982364615      1.05614584e-03    0.426956    0.060928    0.487884
# Weak SSB       0.733     None      0.8173742159      1.03672155e-03    0.438908    0.023909    0.462817
# Weak SSB       0.944     None      0.8514605516      4.41475042e-03    0.750315    0.004852    0.755167
# Weak SSB       1.156     None      0.9874196638      2.50213251e-02    0.9724      8.3e-05     0.972483
# Weak SSB       1.367     1040      0.9949055464      6.77221454e-02    None        None        None
# Weak SSB       1.578     1020      0.9957024989      1.20187623e-01    None        None        None
# Weak SSB       1.789     150       0.9907443885      1.71405779e-01    None        None        None
# Weak SSB       2.000     75        0.9902091288      2.18843475e-01    None        None        None
# Strong SSB     0.100     50        0.9917486744      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9964785439      7.22062439e-01    None        None        None
# Strong SSB     0.522     20        0.9953306614      7.78318602e-01    None        None        None
# Strong SSB     0.733     20        0.9935985587      8.15979742e-01    None        None        None
# Strong SSB     0.944     20        0.9929444911      8.44059983e-01    None        None        None
# Strong SSB     1.156     20        0.9925823433      8.66317759e-01    None        None        None
# Strong SSB     1.367     20        0.9928061489      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9932238568      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9935882649      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9938893228      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        color=case_colors[case],
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=1$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color="blue")

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color="green")

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB', color="red")

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='blue'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='green'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='red'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)



plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_0^2=1$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Starting of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96520223
# T = 2     Fidelity = 0.99333995
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.03626623e+00
# T = 1     Fidelity = 0.96806759
# T = 2     Fidelity = 0.99422525
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05846299e+00
# T = 1     Fidelity = 0.97048613
# T = 2     Fidelity = 0.99491015
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07916278e+00
# T = 1     Fidelity = 0.97260126
# T = 2     Fidelity = 0.99546740
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.09862393e+00
# T = 1     Fidelity = 0.97444236
# T = 2     Fidelity = 0.99591605
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.11703633e+00
# T = 1     Fidelity = 0.97608656
# T = 2     Fidelity = 0.99629073
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.13454489e+00
# T = 1     Fidelity = 0.97755303
# T = 2     Fidelity = 0.99660226
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.15126343e+00
# T = 1     Fidelity = 0.97888264
# T = 2     Fidelity = 0.99686821
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.16728342e+00
# T = 1     Fidelity = 0.98007154
# T = 2     Fidelity = 0.99708871
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98116258
# T = 2     Fidelity = 0.99728036
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000151
# T = 10    Fidelity = 0.00047291
# T = 20    Fidelity = 0.00572749
# T = 30    Fidelity = 0.01822470
# T = 40    Fidelity = 0.06165583
# T = 50    Fidelity = 0.16108730
# T = 75    Fidelity = 0.32290257
# T = 100   Fidelity = 0.48090177
# T = 125   Fidelity = 0.62887384
# T = 150   Fidelity = 0.72467530
# T = 175   Fidelity = 0.79356542
# T = 200   Fidelity = 0.83494672
# T = 225   Fidelity = 0.84712640
# T = 250   Fidelity = 0.85518053
# T = 275   Fidelity = 0.71797904
# T = 300   Fidelity = 0.79204004
# T = 400   Fidelity = 0.93106191
# T = 500   Fidelity = 0.91074266
# T = 600   Fidelity = 0.89313093
# T = 700   Fidelity = 0.81699319
# T = 800   Fidelity = 0.64670563
# T = 900   Fidelity = 0.74811308
# T = 1000  Fidelity = 0.62957613
# T = 1010  Fidelity = 0.62201560
# T = 1020  Fidelity = 0.70090506
# T = 1030  Fidelity = 0.67206638
# T = 1040  Fidelity = 0.25474709
# T = 1050  Fidelity = 0.41849008
# T = 1060  Fidelity = 0.50011751
# T = 1070  Fidelity = 0.47216326
# T = 1080  Fidelity = 0.56602994
# T = 1090  Fidelity = 0.54906170
# T = 1100  Fidelity = 0.75463087
# T = 1200  Fidelity = 0.22356555
# T = 1300  Fidelity = 0.25223521
# T = 1400  Fidelity = 0.65177933
# T = 1500  Fidelity = 0.48287024
# T = 2000  Fidelity = 0.33812462
# T = 2100  Fidelity = 0.88846753
# T = 2110  Fidelity = 0.81598836
# T = 2120  Fidelity = 0.77008767
# T = 2130  Fidelity = 0.74845098
# T = 2140  Fidelity = 0.54506607
# T = 2150  Fidelity = 0.75842257
# T = 2160  Fidelity = 0.56108714
# T = 2170  Fidelity = 0.63603707
# T = 2180  Fidelity = 0.70292059
# T = 2190  Fidelity = 0.53238509
# T = 2200  Fidelity = 0.52993614
# T = 2300  Fidelity = 0.33882149
# T = 2400  Fidelity = 0.51734889
# T = 2500  Fidelity = 0.52688439
# T = 2600  Fidelity = 0.30655544
# T = 2700  Fidelity = 0.24636088
# T = 2800  Fidelity = 0.53839016
# T = 2900  Fidelity = 0.50540316
# T = 3000  Fidelity = 0.91738561
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91738561
# P1     = 0.00917290
# P0+P1  = 0.92655851
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61673084e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00001564
# T = 10    Fidelity = 0.00297660
# T = 20    Fidelity = 0.22245736
# T = 30    Fidelity = 0.29338122
# T = 40    Fidelity = 0.34862245
# T = 50    Fidelity = 0.71053103
# T = 75    Fidelity = 0.77594883
# T = 100   Fidelity = 0.66888441
# T = 125   Fidelity = 0.86442867
# T = 150   Fidelity = 0.77786042
# T = 175   Fidelity = 0.90507589
# T = 200   Fidelity = 0.96527427
# T = 225   Fidelity = 0.88765606
# T = 250   Fidelity = 0.96257998
# T = 275   Fidelity = 0.94670933
# T = 300   Fidelity = 0.93274913
# T = 400   Fidelity = 0.96635332
# T = 500   Fidelity = 0.96281673
# T = 600   Fidelity = 0.87112115
# T = 700   Fidelity = 0.62797345
# T = 800   Fidelity = 0.79333165
# T = 900   Fidelity = 0.73898964
# T = 1000  Fidelity = 0.83602731
# T = 1010  Fidelity = 0.79654220
# T = 1020  Fidelity = 0.84451053
# T = 1030  Fidelity = 0.74598643
# T = 1040  Fidelity = 0.70392594
# T = 1050  Fidelity = 0.69049691
# T = 1060  Fidelity = 0.55314332
# T = 1070  Fidelity = 0.52340658
# T = 1080  Fidelity = 0.64971128
# T = 1090  Fidelity = 0.51492907
# T = 1100  Fidelity = 0.49235354
# T = 1200  Fidelity = 0.88973074
# T = 1300  Fidelity = 0.66657271
# T = 1400  Fidelity = 0.81505722
# T = 1500  Fidelity = 0.91687451
# T = 2000  Fidelity = 0.62355353
# T = 2100  Fidelity = 0.48437492
# T = 2110  Fidelity = 0.76200839
# T = 2120  Fidelity = 0.72542129
# T = 2130  Fidelity = 0.56457886
# T = 2140  Fidelity = 0.48347693
# T = 2150  Fidelity = 0.62491973
# T = 2160  Fidelity = 0.54226902
# T = 2170  Fidelity = 0.42454704
# T = 2180  Fidelity = 0.49967009
# T = 2190  Fidelity = 0.81384594
# T = 2200  Fidelity = 0.61721946
# T = 2300  Fidelity = 0.66002991
# T = 2400  Fidelity = 0.59234010
# T = 2500  Fidelity = 0.82328589
# T = 2600  Fidelity = 0.61843538
# T = 2700  Fidelity = 0.88595979
# T = 2800  Fidelity = 0.64973118
# T = 2900  Fidelity = 0.69435602
# T = 3000  Fidelity = 0.86600526
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43053089e+00
# P0     = 0.86600526
# P1     = 0.03855039
# P0+P1  = 0.90455565
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64768458e-01
# T = 1     Fidelity = 0.00000994
# T = 2     Fidelity = 0.00014800
# T = 5     Fidelity = 0.00346947
# T = 10    Fidelity = 0.05108293
# T = 20    Fidelity = 0.41013525
# T = 30    Fidelity = 0.59489528
# T = 40    Fidelity = 0.58263718
# T = 50    Fidelity = 0.72390601
# T = 75    Fidelity = 0.81395731
# T = 100   Fidelity = 0.89326569
# T = 125   Fidelity = 0.94404756
# T = 150   Fidelity = 0.96739033
# T = 175   Fidelity = 0.97760265
# T = 200   Fidelity = 0.98534140
# T = 225   Fidelity = 0.98716210
# T = 250   Fidelity = 0.99142900
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00050027
# T = 2     Fidelity = 0.00289102
# T = 5     Fidelity = 0.02081003
# T = 10    Fidelity = 0.11085490
# T = 20    Fidelity = 0.42505008
# T = 30    Fidelity = 0.66170354
# T = 40    Fidelity = 0.73173857
# T = 50    Fidelity = 0.76201627
# T = 75    Fidelity = 0.88538865
# T = 100   Fidelity = 0.93293181
# T = 125   Fidelity = 0.96621548
# T = 150   Fidelity = 0.98145385
# T = 175   Fidelity = 0.98898063
# T = 200   Fidelity = 0.99278454
#
# Minimum T for Fidelity >= 0.99 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00480950
# T = 2     Fidelity = 0.01664973
# T = 5     Fidelity = 0.06230203
# T = 10    Fidelity = 0.18584316
# T = 20    Fidelity = 0.44902282
# T = 30    Fidelity = 0.64650900
# T = 40    Fidelity = 0.75584809
# T = 50    Fidelity = 0.81802725
# T = 75    Fidelity = 0.91076067
# T = 100   Fidelity = 0.95910134
# T = 125   Fidelity = 0.97961923
# T = 150   Fidelity = 0.98954730
# T = 175   Fidelity = 0.99320559
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.02312821
# T = 2     Fidelity = 0.05803247
# T = 5     Fidelity = 0.14341181
# T = 10    Fidelity = 0.29416218
# T = 20    Fidelity = 0.51928604
# T = 30    Fidelity = 0.66537555
# T = 40    Fidelity = 0.75781444
# T = 50    Fidelity = 0.82074137
# T = 75    Fidelity = 0.91644337
# T = 100   Fidelity = 0.96485504
# T = 125   Fidelity = 0.98665612
# T = 150   Fidelity = 0.99461056
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.07082179
# T = 2     Fidelity = 0.14486433
# T = 5     Fidelity = 0.27428303
# T = 10    Fidelity = 0.44178320
# T = 20    Fidelity = 0.63553605
# T = 30    Fidelity = 0.74201066
# T = 40    Fidelity = 0.80900581
# T = 50    Fidelity = 0.85620806
# T = 75    Fidelity = 0.92577034
# T = 100   Fidelity = 0.96144313
# T = 125   Fidelity = 0.98008003
# T = 150   Fidelity = 0.98831267
# T = 175   Fidelity = 0.99201254
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.15499798
# T = 2     Fidelity = 0.27568730
# T = 5     Fidelity = 0.43784850
# T = 10    Fidelity = 0.60350165
# T = 20    Fidelity = 0.76108124
# T = 30    Fidelity = 0.83538992
# T = 40    Fidelity = 0.87967926
# T = 50    Fidelity = 0.90924715
# T = 75    Fidelity = 0.95110442
# T = 100   Fidelity = 0.97236882
# T = 125   Fidelity = 0.98319566
# T = 150   Fidelity = 0.98846770
# T = 175   Fidelity = 0.99226057
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.25476157
# T = 2     Fidelity = 0.41167621
# T = 5     Fidelity = 0.58370289
# T = 10    Fidelity = 0.73089044
# T = 20    Fidelity = 0.85283740
# T = 30    Fidelity = 0.90368939
# T = 40    Fidelity = 0.93197475
# T = 50    Fidelity = 0.94952911
# T = 75    Fidelity = 0.97412321
# T = 100   Fidelity = 0.98519319
# T = 125   Fidelity = 0.99068369
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.35080231
# T = 2     Fidelity = 0.52882579
# T = 5     Fidelity = 0.69437333
# T = 10    Fidelity = 0.81774129
# T = 20    Fidelity = 0.90997937
# T = 30    Fidelity = 0.94407859
# T = 40    Fidelity = 0.96187976
# T = 50    Fidelity = 0.97272518
# T = 75    Fidelity = 0.98638907
# T = 100   Fidelity = 0.99214645
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.40037050e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000118
# T = 10    Fidelity = 0.00113325
# T = 20    Fidelity = 0.00650905
# T = 30    Fidelity = 0.02771446
# T = 40    Fidelity = 0.11890549
# T = 50    Fidelity = 0.09124505
# T = 75    Fidelity = 0.30336405
# T = 100   Fidelity = 0.53433539
# T = 125   Fidelity = 0.55295454
# T = 150   Fidelity = 0.69245014
# T = 175   Fidelity = 0.80310141
# T = 200   Fidelity = 0.78736517
# T = 225   Fidelity = 0.85501093
# T = 250   Fidelity = 0.93640507
# T = 275   Fidelity = 0.73915153
# T = 300   Fidelity = 0.74314531
# T = 400   Fidelity = 0.95577315
# T = 500   Fidelity = 0.95200807
# T = 600   Fidelity = 0.96828178
# T = 700   Fidelity = 0.85568969
# T = 800   Fidelity = 0.83721757
# T = 900   Fidelity = 0.56675106
# T = 1000  Fidelity = 0.69841822
# T = 1010  Fidelity = 0.63528113
# T = 1020  Fidelity = 0.61057102
# T = 1030  Fidelity = 0.63138168
# T = 1040  Fidelity = 0.75870334
# T = 1050  Fidelity = 0.62041115
# T = 1060  Fidelity = 0.68089217
# T = 1070  Fidelity = 0.48121369
# T = 1080  Fidelity = 0.80532412
# T = 1090  Fidelity = 0.65952073
# T = 1100  Fidelity = 0.25702196
# T = 1200  Fidelity = 0.74488591
# T = 1300  Fidelity = 0.51599339
# T = 1400  Fidelity = 0.35206243
# T = 1500  Fidelity = 0.77892544
# T = 2000  Fidelity = 0.50035207
# T = 2100  Fidelity = 0.78888218
# T = 2110  Fidelity = 0.60458198
# T = 2120  Fidelity = 0.75460680
# T = 2130  Fidelity = 0.76879728
# T = 2140  Fidelity = 0.63039623
# T = 2150  Fidelity = 0.32770612
# T = 2160  Fidelity = 0.49929434
# T = 2170  Fidelity = 0.19998285
# T = 2180  Fidelity = 0.19549662
# T = 2190  Fidelity = 0.12322816
# T = 2200  Fidelity = 0.21529055
# T = 2300  Fidelity = 0.51644082
# T = 2400  Fidelity = 0.82105936
# T = 2500  Fidelity = 0.86438778
# T = 2600  Fidelity = 0.95851591
# T = 2700  Fidelity = 0.57994809
# T = 2800  Fidelity = 0.44978891
# T = 2900  Fidelity = 0.84371111
# T = 3000  Fidelity = 0.91267154
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41951501e+00
# P0     = 0.91267154
# P1     = 0.01920630
# P0+P1  = 0.93187784
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.13564004e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00000687
# T = 10    Fidelity = 0.00116649
# T = 20    Fidelity = 0.19597739
# T = 30    Fidelity = 0.53219275
# T = 40    Fidelity = 0.08320028
# T = 50    Fidelity = 0.71263196
# T = 75    Fidelity = 0.50907520
# T = 100   Fidelity = 0.68363512
# T = 125   Fidelity = 0.91752706
# T = 150   Fidelity = 0.91661841
# T = 175   Fidelity = 0.86774936
# T = 200   Fidelity = 0.91253898
# T = 225   Fidelity = 0.95252759
# T = 250   Fidelity = 0.95174156
# T = 275   Fidelity = 0.94053622
# T = 300   Fidelity = 0.96735160
# T = 400   Fidelity = 0.91723875
# T = 500   Fidelity = 0.94790023
# T = 600   Fidelity = 0.88332773
# T = 700   Fidelity = 0.93830167
# T = 800   Fidelity = 0.55650380
# T = 900   Fidelity = 0.78677412
# T = 1000  Fidelity = 0.38768901
# T = 1010  Fidelity = 0.86899342
# T = 1020  Fidelity = 0.73985605
# T = 1030  Fidelity = 0.59638075
# T = 1040  Fidelity = 0.76774391
# T = 1050  Fidelity = 0.85393958
# T = 1060  Fidelity = 0.82314922
# T = 1070  Fidelity = 0.78512584
# T = 1080  Fidelity = 0.53125945
# T = 1090  Fidelity = 0.84241066
# T = 1100  Fidelity = 0.74264271
# T = 1200  Fidelity = 0.87554020
# T = 1300  Fidelity = 0.16473723
# T = 1400  Fidelity = 0.76033794
# T = 1500  Fidelity = 0.47024345
# T = 2000  Fidelity = 0.82730683
# T = 2100  Fidelity = 0.50293274
# T = 2110  Fidelity = 0.42647729
# T = 2120  Fidelity = 0.56959283
# T = 2130  Fidelity = 0.73452185
# T = 2140  Fidelity = 0.66756677
# T = 2150  Fidelity = 0.67669656
# T = 2160  Fidelity = 0.81790780
# T = 2170  Fidelity = 0.72925292
# T = 2180  Fidelity = 0.51160787
# T = 2190  Fidelity = 0.53819162
# T = 2200  Fidelity = 0.78158857
# T = 2300  Fidelity = 0.76783132
# T = 2400  Fidelity = 0.66299957
# T = 2500  Fidelity = 0.82657547
# T = 2600  Fidelity = 0.26752370
# T = 2700  Fidelity = 0.11412695
# T = 2800  Fidelity = 0.50893237
# T = 2900  Fidelity = 0.54279233
# T = 3000  Fidelity = 0.74721800
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43049943e+00
# P0     = 0.74721800
# P1     = 0.08855653
# P0+P1  = 0.83577453
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00000155
# T = 2     Fidelity = 0.00007283
# T = 5     Fidelity = 0.00176098
# T = 10    Fidelity = 0.03349756
# T = 20    Fidelity = 0.35786565
# T = 30    Fidelity = 0.61455199
# T = 40    Fidelity = 0.36337143
# T = 50    Fidelity = 0.26413203
# T = 75    Fidelity = 0.57944790
# T = 100   Fidelity = 0.44172759
# T = 125   Fidelity = 0.52885123
# T = 150   Fidelity = 0.48160131
# T = 175   Fidelity = 0.50029232
# T = 200   Fidelity = 0.47663490
# T = 225   Fidelity = 0.51530122
# T = 250   Fidelity = 0.48944716
# T = 275   Fidelity = 0.48697363
# T = 300   Fidelity = 0.51219566
# T = 400   Fidelity = 0.50797649
# T = 500   Fidelity = 0.43261648
# T = 600   Fidelity = 0.39889411
# T = 700   Fidelity = 0.27773883
# T = 800   Fidelity = 0.29508616
# T = 900   Fidelity = 0.50637650
# T = 1000  Fidelity = 0.43274673
# T = 1010  Fidelity = 0.28272548
# T = 1020  Fidelity = 0.60132778
# T = 1030  Fidelity = 0.78571901
# T = 1040  Fidelity = 0.61901408
# T = 1050  Fidelity = 0.06733724
# T = 1060  Fidelity = 0.22249296
# T = 1070  Fidelity = 0.61797431
# T = 1080  Fidelity = 0.79398747
# T = 1090  Fidelity = 0.48262292
# T = 1100  Fidelity = 0.19693552
# T = 1200  Fidelity = 0.80863936
# T = 1300  Fidelity = 0.44736349
# T = 1400  Fidelity = 0.22432505
# T = 1500  Fidelity = 0.28584194
# T = 2000  Fidelity = 0.43397647
# T = 2100  Fidelity = 0.17148477
# T = 2110  Fidelity = 0.24609881
# T = 2120  Fidelity = 0.47946543
# T = 2130  Fidelity = 0.53881150
# T = 2140  Fidelity = 0.45378818
# T = 2150  Fidelity = 0.17473148
# T = 2160  Fidelity = 0.37549914
# T = 2170  Fidelity = 0.73616449
# T = 2180  Fidelity = 0.69238992
# T = 2190  Fidelity = 0.41680998
# T = 2200  Fidelity = 0.20055452
# T = 2300  Fidelity = 0.53605195
# T = 2400  Fidelity = 0.69696976
# T = 2500  Fidelity = 0.72220785
# T = 2600  Fidelity = 0.61303374
# T = 2700  Fidelity = 0.56657663
# T = 2800  Fidelity = 0.58541254
# T = 2900  Fidelity = 0.22751623
# T = 3000  Fidelity = 0.41438986
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44121779e+00
# P0     = 0.41438986
# P1     = 0.02985014
# P0+P1  = 0.44424000
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05663390e-03
# T = 1     Fidelity = 0.00181028
# T = 2     Fidelity = 0.00875749
# T = 5     Fidelity = 0.04030926
# T = 10    Fidelity = 0.14622581
# T = 20    Fidelity = 0.35525242
# T = 30    Fidelity = 0.38154935
# T = 40    Fidelity = 0.32521941
# T = 50    Fidelity = 0.32605903
# T = 75    Fidelity = 0.55880616
# T = 100   Fidelity = 0.55996824
# T = 125   Fidelity = 0.50576101
# T = 150   Fidelity = 0.52354470
# T = 175   Fidelity = 0.52808226
# T = 200   Fidelity = 0.52066233
# T = 225   Fidelity = 0.49569239
# T = 250   Fidelity = 0.49576408
# T = 275   Fidelity = 0.49750032
# T = 300   Fidelity = 0.48304398
# T = 400   Fidelity = 0.51239797
# T = 500   Fidelity = 0.50168350
# T = 600   Fidelity = 0.55968344
# T = 700   Fidelity = 0.53694117
# T = 800   Fidelity = 0.58800591
# T = 900   Fidelity = 0.65790546
# T = 1000  Fidelity = 0.63632681
# T = 1010  Fidelity = 0.55496984
# T = 1020  Fidelity = 0.51266435
# T = 1030  Fidelity = 0.29624008
# T = 1040  Fidelity = 0.13343184
# T = 1050  Fidelity = 0.32278363
# T = 1060  Fidelity = 0.53415505
# T = 1070  Fidelity = 0.81490455
# T = 1080  Fidelity = 0.83723388
# T = 1090  Fidelity = 0.63366627
# T = 1100  Fidelity = 0.58352564
# T = 1200  Fidelity = 0.83209187
# T = 1300  Fidelity = 0.72019066
# T = 1400  Fidelity = 0.48569368
# T = 1500  Fidelity = 0.65070267
# T = 2000  Fidelity = 0.46525754
# T = 2100  Fidelity = 0.47562937
# T = 2110  Fidelity = 0.16638143
# T = 2120  Fidelity = 0.19780484
# T = 2130  Fidelity = 0.35507552
# T = 2140  Fidelity = 0.49194881
# T = 2150  Fidelity = 0.42720645
# T = 2160  Fidelity = 0.57090433
# T = 2170  Fidelity = 0.51670906
# T = 2180  Fidelity = 0.64296769
# T = 2190  Fidelity = 0.60979171
# T = 2200  Fidelity = 0.66575233
# T = 2300  Fidelity = 0.57968200
# T = 2400  Fidelity = 0.35171745
# T = 2500  Fidelity = 0.72021954
# T = 2600  Fidelity = 0.68644501
# T = 2700  Fidelity = 0.68099563
# T = 2800  Fidelity = 0.60815600
# T = 2900  Fidelity = 0.39785154
# T = 3000  Fidelity = 0.40901145
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.45168821e+00
# P0     = 0.40901145
# P1     = 0.01166502
# P0+P1  = 0.42067646
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 5.88899605e-03
# T = 1     Fidelity = 0.01683214
# T = 2     Fidelity = 0.05151662
# T = 5     Fidelity = 0.13904399
# T = 10    Fidelity = 0.31432650
# T = 20    Fidelity = 0.55030887
# T = 30    Fidelity = 0.62697802
# T = 40    Fidelity = 0.61100919
# T = 50    Fidelity = 0.57954125
# T = 75    Fidelity = 0.55886150
# T = 100   Fidelity = 0.60020367
# T = 125   Fidelity = 0.62826729
# T = 150   Fidelity = 0.63560239
# T = 175   Fidelity = 0.64415893
# T = 200   Fidelity = 0.64397539
# T = 225   Fidelity = 0.67549009
# T = 250   Fidelity = 0.68040105
# T = 275   Fidelity = 0.67202778
# T = 300   Fidelity = 0.68405427
# T = 400   Fidelity = 0.70735371
# T = 500   Fidelity = 0.60543736
# T = 600   Fidelity = 0.55943129
# T = 700   Fidelity = 0.72618918
# T = 800   Fidelity = 0.76631025
# T = 900   Fidelity = 0.58819143
# T = 1000  Fidelity = 0.64490492
# T = 1010  Fidelity = 0.71510687
# T = 1020  Fidelity = 0.81872039
# T = 1030  Fidelity = 0.82719813
# T = 1040  Fidelity = 0.75612646
# T = 1050  Fidelity = 0.67538091
# T = 1060  Fidelity = 0.62758010
# T = 1070  Fidelity = 0.53843831
# T = 1080  Fidelity = 0.48052226
# T = 1090  Fidelity = 0.56545293
# T = 1100  Fidelity = 0.67645770
# T = 1200  Fidelity = 0.52287847
# T = 1300  Fidelity = 0.67851696
# T = 1400  Fidelity = 0.73877275
# T = 1500  Fidelity = 0.85093493
# T = 2000  Fidelity = 0.80499132
# T = 2100  Fidelity = 0.68728091
# T = 2110  Fidelity = 0.69278926
# T = 2120  Fidelity = 0.61628894
# T = 2130  Fidelity = 0.63416328
# T = 2140  Fidelity = 0.68526817
# T = 2150  Fidelity = 0.87049654
# T = 2160  Fidelity = 0.87345953
# T = 2170  Fidelity = 0.85534211
# T = 2180  Fidelity = 0.76842307
# T = 2190  Fidelity = 0.63549823
# T = 2200  Fidelity = 0.63859939
# T = 2300  Fidelity = 0.66502128
# T = 2400  Fidelity = 0.71670078
# T = 2500  Fidelity = 0.78680468
# T = 2600  Fidelity = 0.40425821
# T = 2700  Fidelity = 0.82302142
# T = 2800  Fidelity = 0.60575384
# T = 2900  Fidelity = 0.72381931
# T = 3000  Fidelity = 0.81730215
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.46192674e+00
# P0     = 0.81730215
# P1     = 0.00223327
# P0+P1  = 0.81953543
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 3.15736806e-02
# T = 1     Fidelity = 0.06374287
# T = 2     Fidelity = 0.14773696
# T = 5     Fidelity = 0.29251473
# T = 10    Fidelity = 0.49850697
# T = 20    Fidelity = 0.70647031
# T = 30    Fidelity = 0.78190528
# T = 40    Fidelity = 0.79736741
# T = 50    Fidelity = 0.79505738
# T = 75    Fidelity = 0.78966092
# T = 100   Fidelity = 0.79656258
# T = 125   Fidelity = 0.80624352
# T = 150   Fidelity = 0.81388122
# T = 175   Fidelity = 0.82334205
# T = 200   Fidelity = 0.82918671
# T = 225   Fidelity = 0.83519787
# T = 250   Fidelity = 0.84622467
# T = 275   Fidelity = 0.83511674
# T = 300   Fidelity = 0.85862506
# T = 400   Fidelity = 0.85780553
# T = 500   Fidelity = 0.82484371
# T = 600   Fidelity = 0.83337365
# T = 700   Fidelity = 0.69581397
# T = 800   Fidelity = 0.93250718
# T = 900   Fidelity = 0.87074644
# T = 1000  Fidelity = 0.87089259
# T = 1010  Fidelity = 0.88460773
# T = 1020  Fidelity = 0.84361075
# T = 1030  Fidelity = 0.78484665
# T = 1040  Fidelity = 0.81693106
# T = 1050  Fidelity = 0.88068621
# T = 1060  Fidelity = 0.89096935
# T = 1070  Fidelity = 0.92619754
# T = 1080  Fidelity = 0.96639328
# T = 1090  Fidelity = 0.97747921
# T = 1100  Fidelity = 0.97798977
# T = 1200  Fidelity = 0.83677547
# T = 1300  Fidelity = 0.92385069
# T = 1400  Fidelity = 0.72155599
# T = 1500  Fidelity = 0.89049245
# T = 2000  Fidelity = 0.88140954
# T = 2100  Fidelity = 0.78950205
# T = 2110  Fidelity = 0.79076482
# T = 2120  Fidelity = 0.73348279
# T = 2130  Fidelity = 0.70600504
# T = 2140  Fidelity = 0.83702195
# T = 2150  Fidelity = 0.95917035
# T = 2160  Fidelity = 0.89191502
# T = 2170  Fidelity = 0.88455859
# T = 2180  Fidelity = 0.94209802
# T = 2190  Fidelity = 0.87896999
# T = 2200  Fidelity = 0.93901177
# T = 2300  Fidelity = 0.90400490
# T = 2400  Fidelity = 0.96128314
# T = 2500  Fidelity = 0.94059708
# T = 2600  Fidelity = 0.86810729
# T = 2700  Fidelity = 0.92448684
# T = 2800  Fidelity = 0.95687247
# T = 2900  Fidelity = 0.76177726
# T = 3000  Fidelity = 0.94976504
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.47194767e+00
# P0     = 0.94976504
# P1     = 0.00005326
# P0+P1  = 0.94981830
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.80738351e-02
# T = 1     Fidelity = 0.14355293
# T = 2     Fidelity = 0.27842801
# T = 5     Fidelity = 0.45577717
# T = 10    Fidelity = 0.65322349
# T = 20    Fidelity = 0.81527041
# T = 30    Fidelity = 0.87212813
# T = 40    Fidelity = 0.89381825
# T = 50    Fidelity = 0.90257177
# T = 75    Fidelity = 0.91319070
# T = 100   Fidelity = 0.92132491
# T = 125   Fidelity = 0.92937539
# T = 150   Fidelity = 0.93576104
# T = 175   Fidelity = 0.94383275
# T = 200   Fidelity = 0.95003823
# T = 225   Fidelity = 0.93683391
# T = 250   Fidelity = 0.94519773
# T = 275   Fidelity = 0.94892778
# T = 300   Fidelity = 0.96258183
# T = 400   Fidelity = 0.95835362
# T = 500   Fidelity = 0.93472736
# T = 600   Fidelity = 0.94627096
# T = 700   Fidelity = 0.89647804
# T = 800   Fidelity = 0.94202788
# T = 900   Fidelity = 0.93779853
# T = 1000  Fidelity = 0.92646081
# T = 1010  Fidelity = 0.97162510
# T = 1020  Fidelity = 0.97411895
# T = 1030  Fidelity = 0.94042758
# T = 1040  Fidelity = 0.96698674
# T = 1050  Fidelity = 0.98322316
# T = 1060  Fidelity = 0.98492981
# T = 1070  Fidelity = 0.98096820
# T = 1080  Fidelity = 0.98524940
# T = 1090  Fidelity = 0.92959914
# T = 1100  Fidelity = 0.96987645
# T = 1200  Fidelity = 0.93189622
# T = 1300  Fidelity = 0.95526910
# T = 1400  Fidelity = 0.91272859
# T = 1500  Fidelity = 0.96772828
# T = 2000  Fidelity = 0.91244291
# T = 2100  Fidelity = 0.92687964
# T = 2110  Fidelity = 0.92478321
# T = 2120  Fidelity = 0.88627869
# T = 2130  Fidelity = 0.94593540
# T = 2140  Fidelity = 0.90973735
# T = 2150  Fidelity = 0.93509335
# T = 2160  Fidelity = 0.91107267
# T = 2170  Fidelity = 0.94469920
# T = 2180  Fidelity = 0.89565954
# T = 2190  Fidelity = 0.94293933
# T = 2200  Fidelity = 0.89535861
# T = 2300  Fidelity = 0.96993645
# T = 2400  Fidelity = 0.89487846
# T = 2500  Fidelity = 0.95300620
# T = 2600  Fidelity = 0.94548544
# T = 2700  Fidelity = 0.93125917
# T = 2800  Fidelity = 0.93848218
# T = 2900  Fidelity = 0.95166623
# T = 3000  Fidelity = 0.90478041
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.48176382e+00
# P0     = 0.90478041
# P1     = 0.00000103
# P0+P1  = 0.90478144
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.28699899e-01
# T = 1     Fidelity = 0.23782287
# T = 2     Fidelity = 0.40937834
# T = 5     Fidelity = 0.59324668
# T = 10    Fidelity = 0.76321639
# T = 20    Fidelity = 0.88403769
# T = 30    Fidelity = 0.92446612
# T = 40    Fidelity = 0.94169774
# T = 50    Fidelity = 0.95057003
# T = 75    Fidelity = 0.96146575
# T = 100   Fidelity = 0.96927004
# T = 125   Fidelity = 0.97458785
# T = 150   Fidelity = 0.97839421
# T = 175   Fidelity = 0.98224543
# T = 200   Fidelity = 0.98467177
# T = 225   Fidelity = 0.97026566
# T = 250   Fidelity = 0.97602336
# T = 275   Fidelity = 0.97933387
# T = 300   Fidelity = 0.98576861
# T = 400   Fidelity = 0.98154369
# T = 500   Fidelity = 0.97342956
# T = 600   Fidelity = 0.91538500
# T = 700   Fidelity = 0.93525891
# T = 800   Fidelity = 0.98630633
# T = 900   Fidelity = 0.99310557
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.76942225e-01
# T = 1     Fidelity = 0.33073097
# T = 2     Fidelity = 0.52265916
# T = 5     Fidelity = 0.69690375
# T = 10    Fidelity = 0.83590648
# T = 20    Fidelity = 0.92569652
# T = 30    Fidelity = 0.95444497
# T = 40    Fidelity = 0.96618334
# T = 50    Fidelity = 0.97240755
# T = 75    Fidelity = 0.98218867
# T = 100   Fidelity = 0.98644211
# T = 125   Fidelity = 0.98964715
# T = 150   Fidelity = 0.99204019
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.20505613e-01
# T = 1     Fidelity = 0.41291576
# T = 2     Fidelity = 0.61284011
# T = 5     Fidelity = 0.77098641
# T = 10    Fidelity = 0.88313875
# T = 20    Fidelity = 0.95119576
# T = 30    Fidelity = 0.97144560
# T = 40    Fidelity = 0.97942083
# T = 50    Fidelity = 0.98444226
# T = 75    Fidelity = 0.99020225
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.06623659e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00011882
# T = 10    Fidelity = 0.00638375
# T = 20    Fidelity = 0.15739876
# T = 30    Fidelity = 0.48667700
# T = 40    Fidelity = 0.76082016
# T = 50    Fidelity = 0.90715212
# T = 75    Fidelity = 0.99422763
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.20609288e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000015
# T = 5     Fidelity = 0.00112642
# T = 10    Fidelity = 0.18607452
# T = 20    Fidelity = 0.88953069
# T = 30    Fidelity = 0.96864364
# T = 40    Fidelity = 0.99622402
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.76105909e-01
# T = 1     Fidelity = 0.00000399
# T = 2     Fidelity = 0.00014452
# T = 5     Fidelity = 0.03253127
# T = 10    Fidelity = 0.56518236
# T = 20    Fidelity = 0.90568962
# T = 30    Fidelity = 0.99240923
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.12909217e-01
# T = 1     Fidelity = 0.00019322
# T = 2     Fidelity = 0.00245302
# T = 5     Fidelity = 0.10895453
# T = 10    Fidelity = 0.69772661
# T = 20    Fidelity = 0.94987891
# T = 30    Fidelity = 0.99085504
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.40169449e-01
# T = 1     Fidelity = 0.00166760
# T = 2     Fidelity = 0.01139957
# T = 5     Fidelity = 0.20669993
# T = 10    Fidelity = 0.76562583
# T = 20    Fidelity = 0.97045230
# T = 30    Fidelity = 0.99048153
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.61748289e-01
# T = 1     Fidelity = 0.00651332
# T = 2     Fidelity = 0.03023911
# T = 5     Fidelity = 0.30425859
# T = 10    Fidelity = 0.80681454
# T = 20    Fidelity = 0.97982119
# T = 30    Fidelity = 0.99049217
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.79340685e-01
# T = 1     Fidelity = 0.01676875
# T = 2     Fidelity = 0.05948522
# T = 5     Fidelity = 0.39415048
# T = 10    Fidelity = 0.83508814
# T = 20    Fidelity = 0.98422422
# T = 30    Fidelity = 0.99101685
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.94021606e-01
# T = 1     Fidelity = 0.03352219
# T = 2     Fidelity = 0.09740835
# T = 5     Fidelity = 0.47334413
# T = 10    Fidelity = 0.85653694
# T = 20    Fidelity = 0.98591170
# T = 30    Fidelity = 0.99165320
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.06402712e-01
# T = 1     Fidelity = 0.05666930
# T = 2     Fidelity = 0.14163938
# T = 5     Fidelity = 0.54234600
# T = 10    Fidelity = 0.87420585
# T = 20    Fidelity = 0.98628890
# T = 30    Fidelity = 0.99221636
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.17036009e-01
# T = 1     Fidelity = 0.08528397
# T = 2     Fidelity = 0.18964523
# T = 5     Fidelity = 0.60215362
# T = 10    Fidelity = 0.88980276
# T = 20    Fidelity = 0.98634754
# T = 30    Fidelity = 0.99278575
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9933399463      1.01220263e+00    None        None        None
# Symmetric      0.311     2         0.9942252537      1.03626623e+00    None        None        None
# Symmetric      0.522     2         0.9949101495      1.05846299e+00    None        None        None
# Symmetric      0.733     2         0.9954673990      1.07916278e+00    None        None        None
# Symmetric      0.944     2         0.9959160525      1.09862393e+00    None        None        None
# Symmetric      1.156     2         0.9962907336      1.11703633e+00    None        None        None
# Symmetric      1.367     2         0.9966022596      1.13454489e+00    None        None        None
# Symmetric      1.578     2         0.9968682070      1.15126343e+00    None        None        None
# Symmetric      1.789     2         0.9970887076      1.16728342e+00    None        None        None
# Symmetric      2.000     2         0.9972803555      1.18267976e+00    None        None        None
# Weak SSB optimised0.100     None      0.9310619068      2.43127858e-01    0.917386    0.009173    0.926559
# Weak SSB optimised0.311     None      0.9663533194      2.61673084e-01    0.866005    0.03855     0.904556
# Weak SSB optimised0.522     250       0.9914290036      2.64768458e-01    None        None        None
# Weak SSB optimised0.733     200       0.9927845450      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     175       0.9932055924      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     150       0.9946105623      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     175       0.9920125423      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     175       0.9922605725      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9906836871      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     100       0.9921464504      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9682817847      1.40037050e-03    0.912672    0.019206    0.931878
# Weak SSB       0.311     None      0.9673516036      1.13564004e-03    0.747218    0.088557    0.835775
# Weak SSB       0.522     None      0.8086393560      1.05614584e-03    0.41439     0.02985     0.44424
# Weak SSB       0.733     None      0.8372338818      1.05663390e-03    0.409011    0.011665    0.420676
# Weak SSB       0.944     None      0.8734595314      5.88899605e-03    0.817302    0.002233    0.819535
# Weak SSB       1.156     None      0.9779897727      3.15736806e-02    0.949765    5.3e-05     0.949818
# Weak SSB       1.367     None      0.9852494019      7.80738351e-02    0.90478     1e-06       0.904781
# Weak SSB       1.578     900       0.9931055727      1.28699899e-01    None        None        None
# Weak SSB       1.789     150       0.9920401886      1.76942225e-01    None        None        None
# Weak SSB       2.000     75        0.9902022520      2.20505613e-01    None        None        None
# Strong SSB     0.100     75        0.9942276332      6.06623659e-01    None        None        None
# Strong SSB     0.311     40        0.9962240174      7.20609288e-01    None        None        None
# Strong SSB     0.522     30        0.9924092331      7.76105909e-01    None        None        None
# Strong SSB     0.733     30        0.9908550436      8.12909217e-01    None        None        None
# Strong SSB     0.944     30        0.9904815327      8.40169449e-01    None        None        None
# Strong SSB     1.156     30        0.9904921715      8.61748289e-01    None        None        None
# Strong SSB     1.367     30        0.9910168545      8.79340685e-01    None        None        None
# Strong SSB     1.578     30        0.9916531987      8.94021606e-01    None        None        None
# Strong SSB     1.789     30        0.9922163563      9.06402712e-01    None        None        None
# Strong SSB     2.000     30        0.9927857488      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap,  $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009553
# T = 10    Fidelity = 0.00119345
# T = 20    Fidelity = 0.02687192
# T = 30    Fidelity = 0.09666453
# T = 40    Fidelity = 0.19608552
# T = 50    Fidelity = 0.31173796
# T = 75    Fidelity = 0.56618939
# T = 100   Fidelity = 0.72000486
# T = 125   Fidelity = 0.80737170
# T = 150   Fidelity = 0.86468645
# T = 175   Fidelity = 0.90863496
# T = 200   Fidelity = 0.94629197
# T = 225   Fidelity = 0.96686679
# T = 250   Fidelity = 0.95352045
# T = 275   Fidelity = 0.98204755
# T = 300   Fidelity = 0.96282839
# T = 400   Fidelity = 0.95497919
# T = 500   Fidelity = 0.93802612
# T = 600   Fidelity = 0.90704253
# T = 700   Fidelity = 0.99336461
#
# Minimum T for Fidelity >= 0.99 : 700
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624068e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144479
# T = 10    Fidelity = 0.10202820
# T = 20    Fidelity = 0.52982362
# T = 30    Fidelity = 0.63893337
# T = 40    Fidelity = 0.76792985
# T = 50    Fidelity = 0.88385686
# T = 75    Fidelity = 0.94225600
# T = 100   Fidelity = 0.97306715
# T = 125   Fidelity = 0.99693356
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043164e-07
# T = 1     Fidelity = 0.00005024
# T = 2     Fidelity = 0.00043636
# T = 5     Fidelity = 0.02724367
# T = 10    Fidelity = 0.28403658
# T = 20    Fidelity = 0.77881581
# T = 30    Fidelity = 0.80542672
# T = 40    Fidelity = 0.95120246
# T = 50    Fidelity = 0.93700834
# T = 75    Fidelity = 0.99144564
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155072
# T = 2     Fidelity = 0.00639414
# T = 5     Fidelity = 0.08479882
# T = 10    Fidelity = 0.38783900
# T = 20    Fidelity = 0.90882990
# T = 30    Fidelity = 0.89422593
# T = 40    Fidelity = 0.97222081
# T = 50    Fidelity = 0.99232019
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01058034
# T = 2     Fidelity = 0.02892975
# T = 5     Fidelity = 0.16450056
# T = 10    Fidelity = 0.46787952
# T = 20    Fidelity = 0.92253611
# T = 30    Fidelity = 0.97977780
# T = 40    Fidelity = 0.97237055
# T = 50    Fidelity = 0.99387933
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03667783
# T = 2     Fidelity = 0.07740966
# T = 5     Fidelity = 0.25992209
# T = 10    Fidelity = 0.54101302
# T = 20    Fidelity = 0.90449004
# T = 30    Fidelity = 0.99651385
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08776933
# T = 2     Fidelity = 0.15532093
# T = 5     Fidelity = 0.36741800
# T = 10    Fidelity = 0.61611720
# T = 20    Fidelity = 0.89397900
# T = 30    Fidelity = 0.98167871
# T = 40    Fidelity = 0.99755506
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16578103
# T = 2     Fidelity = 0.25893994
# T = 5     Fidelity = 0.48155716
# T = 10    Fidelity = 0.69438260
# T = 20    Fidelity = 0.90352682
# T = 30    Fidelity = 0.97294635
# T = 40    Fidelity = 0.99115234
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26389804
# T = 2     Fidelity = 0.37661107
# T = 5     Fidelity = 0.59256199
# T = 10    Fidelity = 0.76990530
# T = 20    Fidelity = 0.92535874
# T = 30    Fidelity = 0.97251418
# T = 40    Fidelity = 0.98679488
# T = 50    Fidelity = 0.99323281
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36878587
# T = 2     Fidelity = 0.49273968
# T = 5     Fidelity = 0.68999680
# T = 10    Fidelity = 0.83495331
# T = 20    Fidelity = 0.94707468
# T = 30    Fidelity = 0.97596334
# T = 40    Fidelity = 0.98838130
# T = 50    Fidelity = 0.99291131
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.62240695
# T = 2     Fidelity = 0.65115812
# T = 5     Fidelity = 0.70757700
# T = 10    Fidelity = 0.76214465
# T = 20    Fidelity = 0.82853920
# T = 30    Fidelity = 0.86920120
# T = 40    Fidelity = 0.89758425
# T = 50    Fidelity = 0.91781336
# T = 75    Fidelity = 0.94906027
# T = 100   Fidelity = 0.96596709
# T = 125   Fidelity = 0.97449658
# T = 150   Fidelity = 0.98073803
# T = 175   Fidelity = 0.98165477
# T = 200   Fidelity = 0.98707743
# T = 225   Fidelity = 0.97828997
# T = 250   Fidelity = 0.98530604
# T = 275   Fidelity = 0.95562537
# T = 300   Fidelity = 0.93872368
# T = 400   Fidelity = 0.97093970
# T = 500   Fidelity = 0.97611917
# T = 600   Fidelity = 0.94404612
# T = 700   Fidelity = 0.81248369
# T = 800   Fidelity = 0.94203668
# T = 900   Fidelity = 0.98426339
# T = 1000  Fidelity = 0.97569349
# T = 1010  Fidelity = 0.95564517
# T = 1020  Fidelity = 0.94284058
# T = 1030  Fidelity = 0.95692784
# T = 1040  Fidelity = 0.96834825
# T = 1050  Fidelity = 0.96509334
# T = 1060  Fidelity = 0.96750515
# T = 1070  Fidelity = 0.97131122
# T = 1080  Fidelity = 0.98803554
# T = 1090  Fidelity = 0.99145109
#
# Minimum T for Fidelity >= 0.99 : 1090
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.74572082
# T = 2     Fidelity = 0.75583800
# T = 5     Fidelity = 0.78537749
# T = 10    Fidelity = 0.81677069
# T = 20    Fidelity = 0.85280137
# T = 30    Fidelity = 0.87518519
# T = 40    Fidelity = 0.89101552
# T = 50    Fidelity = 0.90324994
# T = 75    Fidelity = 0.92475599
# T = 100   Fidelity = 0.93903877
# T = 125   Fidelity = 0.94891501
# T = 150   Fidelity = 0.95529559
# T = 175   Fidelity = 0.96305399
# T = 200   Fidelity = 0.96434033
# T = 225   Fidelity = 0.96714059
# T = 250   Fidelity = 0.96804258
# T = 275   Fidelity = 0.96906885
# T = 300   Fidelity = 0.97144921
# T = 400   Fidelity = 0.97748224
# T = 500   Fidelity = 0.96262166
# T = 600   Fidelity = 0.95975611
# T = 700   Fidelity = 0.97841980
# T = 800   Fidelity = 0.92515877
# T = 900   Fidelity = 0.91541883
# T = 1000  Fidelity = 0.93083207
# T = 1010  Fidelity = 0.93146384
# T = 1020  Fidelity = 0.93048236
# T = 1030  Fidelity = 0.92930995
# T = 1040  Fidelity = 0.92618267
# T = 1050  Fidelity = 0.92508201
# T = 1060  Fidelity = 0.92415161
# T = 1070  Fidelity = 0.92527863
# T = 1080  Fidelity = 0.92379314
# T = 1090  Fidelity = 0.92601050
# T = 1100  Fidelity = 0.92490951
# T = 1200  Fidelity = 0.94663006
# T = 1300  Fidelity = 0.96958026
# T = 1400  Fidelity = 0.97481128
# T = 1500  Fidelity = 0.96762370
# T = 2000  Fidelity = 0.94116406
# T = 2100  Fidelity = 0.95465828
# T = 2110  Fidelity = 0.95594105
# T = 2120  Fidelity = 0.95667209
# T = 2130  Fidelity = 0.95858366
# T = 2140  Fidelity = 0.95674394
# T = 2150  Fidelity = 0.95691399
# T = 2160  Fidelity = 0.95299432
# T = 2170  Fidelity = 0.95089226
# T = 2180  Fidelity = 0.94545298
# T = 2190  Fidelity = 0.94458912
# T = 2200  Fidelity = 0.94402530
# T = 2300  Fidelity = 0.92879933
# T = 2400  Fidelity = 0.97999875
# T = 2500  Fidelity = 0.98061356
# T = 2600  Fidelity = 0.95940165
# T = 2700  Fidelity = 0.94574604
# T = 2800  Fidelity = 0.92751255
# T = 2900  Fidelity = 0.92797616
# T = 3000  Fidelity = 0.94441451
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.71621181e-01
# P0     = 0.94441451
# P1     = 0.03485065
# P0+P1  = 0.97926516
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.99082406
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98785172
# T = 2     Fidelity = 0.99684124
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97967064
# T = 2     Fidelity = 0.99117047
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.94941870
# T = 2     Fidelity = 0.96551596
# T = 5     Fidelity = 0.97716878
# T = 10    Fidelity = 0.98104331
# T = 20    Fidelity = 0.98476563
# T = 30    Fidelity = 0.98732453
# T = 40    Fidelity = 0.98863899
# T = 50    Fidelity = 0.98966746
# T = 75    Fidelity = 0.99165730
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.88145530
# T = 2     Fidelity = 0.90418200
# T = 5     Fidelity = 0.92803431
# T = 10    Fidelity = 0.93793644
# T = 20    Fidelity = 0.95203573
# T = 30    Fidelity = 0.95853321
# T = 40    Fidelity = 0.96414770
# T = 50    Fidelity = 0.96756543
# T = 75    Fidelity = 0.97432401
# T = 100   Fidelity = 0.97891539
# T = 125   Fidelity = 0.98204986
# T = 150   Fidelity = 0.98434970
# T = 175   Fidelity = 0.98621876
# T = 200   Fidelity = 0.98755578
# T = 225   Fidelity = 0.98874032
# T = 250   Fidelity = 0.98984806
# T = 275   Fidelity = 0.99064322
#
# Minimum T for Fidelity >= 0.99 : 275
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78753101
# T = 2     Fidelity = 0.81779354
# T = 5     Fidelity = 0.85657330
# T = 10    Fidelity = 0.87840182
# T = 20    Fidelity = 0.90991970
# T = 30    Fidelity = 0.92425748
# T = 40    Fidelity = 0.93497146
# T = 50    Fidelity = 0.94345784
# T = 75    Fidelity = 0.95731255
# T = 100   Fidelity = 0.96630427
# T = 125   Fidelity = 0.97251011
# T = 150   Fidelity = 0.97697457
# T = 175   Fidelity = 0.98059226
# T = 200   Fidelity = 0.98299551
# T = 225   Fidelity = 0.98495024
# T = 250   Fidelity = 0.98695871
# T = 275   Fidelity = 0.98840037
# T = 300   Fidelity = 0.98968273
# T = 400   Fidelity = 0.99275786
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.71963142
# T = 2     Fidelity = 0.75623558
# T = 5     Fidelity = 0.80667910
# T = 10    Fidelity = 0.84294653
# T = 20    Fidelity = 0.89146734
# T = 30    Fidelity = 0.91297483
# T = 40    Fidelity = 0.92995775
# T = 50    Fidelity = 0.93966372
# T = 75    Fidelity = 0.95851630
# T = 100   Fidelity = 0.96981180
# T = 125   Fidelity = 0.97707688
# T = 150   Fidelity = 0.98198044
# T = 175   Fidelity = 0.98544049
# T = 200   Fidelity = 0.98776874
# T = 225   Fidelity = 0.98956841
# T = 250   Fidelity = 0.99103364
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.69219657
# T = 2     Fidelity = 0.73438625
# T = 5     Fidelity = 0.79289310
# T = 10    Fidelity = 0.84055201
# T = 20    Fidelity = 0.90332894
# T = 30    Fidelity = 0.92696913
# T = 40    Fidelity = 0.94566666
# T = 50    Fidelity = 0.95653839
# T = 75    Fidelity = 0.97329898
# T = 100   Fidelity = 0.98219087
# T = 125   Fidelity = 0.98740095
# T = 150   Fidelity = 0.99063569
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.35126357e-02
# T = 1     Fidelity = 0.59222025
# T = 2     Fidelity = 0.63732610
# T = 5     Fidelity = 0.71853936
# T = 10    Fidelity = 0.79583888
# T = 20    Fidelity = 0.87745196
# T = 30    Fidelity = 0.92005304
# T = 40    Fidelity = 0.94504705
# T = 50    Fidelity = 0.96036904
# T = 75    Fidelity = 0.97919664
# T = 100   Fidelity = 0.98526060
# T = 125   Fidelity = 0.98656015
# T = 150   Fidelity = 0.98954395
# T = 175   Fidelity = 0.98843862
# T = 200   Fidelity = 0.97827193
# T = 225   Fidelity = 0.99181192
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.91075005e-03
# T = 1     Fidelity = 0.43772426
# T = 2     Fidelity = 0.45074670
# T = 5     Fidelity = 0.49146129
# T = 10    Fidelity = 0.54251682
# T = 20    Fidelity = 0.60816249
# T = 30    Fidelity = 0.65363320
# T = 40    Fidelity = 0.68851500
# T = 50    Fidelity = 0.71653970
# T = 75    Fidelity = 0.76807316
# T = 100   Fidelity = 0.80270216
# T = 125   Fidelity = 0.82897454
# T = 150   Fidelity = 0.84819650
# T = 175   Fidelity = 0.86026185
# T = 200   Fidelity = 0.87979234
# T = 225   Fidelity = 0.88602835
# T = 250   Fidelity = 0.89175647
# T = 275   Fidelity = 0.88431209
# T = 300   Fidelity = 0.89647322
# T = 400   Fidelity = 0.91755551
# T = 500   Fidelity = 0.94057398
# T = 600   Fidelity = 0.95102751
# T = 700   Fidelity = 0.79740507
# T = 800   Fidelity = 0.77389213
# T = 900   Fidelity = 0.83625982
# T = 1000  Fidelity = 0.91624310
# T = 1010  Fidelity = 0.90126331
# T = 1020  Fidelity = 0.89206714
# T = 1030  Fidelity = 0.90765957
# T = 1040  Fidelity = 0.93359771
# T = 1050  Fidelity = 0.94479586
# T = 1060  Fidelity = 0.93738611
# T = 1070  Fidelity = 0.91969096
# T = 1080  Fidelity = 0.90586339
# T = 1090  Fidelity = 0.89632442
# T = 1100  Fidelity = 0.91020168
# T = 1200  Fidelity = 0.92794656
# T = 1300  Fidelity = 0.94866015
# T = 1400  Fidelity = 0.97411245
# T = 1500  Fidelity = 0.87185907
# T = 2000  Fidelity = 0.85790753
# T = 2100  Fidelity = 0.93697067
# T = 2110  Fidelity = 0.93714957
# T = 2120  Fidelity = 0.94883766
# T = 2130  Fidelity = 0.96264128
# T = 2140  Fidelity = 0.97560496
# T = 2150  Fidelity = 0.98690517
# T = 2160  Fidelity = 0.99156445
#
# Minimum T for Fidelity >= 0.99 : 2160
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.25437007
# T = 2     Fidelity = 0.25627392
# T = 5     Fidelity = 0.25674432
# T = 10    Fidelity = 0.25693034
# T = 20    Fidelity = 0.25698060
# T = 30    Fidelity = 0.25701262
# T = 40    Fidelity = 0.25709463
# T = 50    Fidelity = 0.25714210
# T = 75    Fidelity = 0.25733298
# T = 100   Fidelity = 0.25746677
# T = 125   Fidelity = 0.25745982
# T = 150   Fidelity = 0.25745773
# T = 175   Fidelity = 0.25582500
# T = 200   Fidelity = 0.25830655
# T = 225   Fidelity = 0.25609696
# T = 250   Fidelity = 0.25790627
# T = 275   Fidelity = 0.25767961
# T = 300   Fidelity = 0.25809192
# T = 400   Fidelity = 0.25628573
# T = 500   Fidelity = 0.25787545
# T = 600   Fidelity = 0.25793543
# T = 700   Fidelity = 0.26168533
# T = 800   Fidelity = 0.25939665
# T = 900   Fidelity = 0.25452995
# T = 1000  Fidelity = 0.25904783
# T = 1010  Fidelity = 0.26047435
# T = 1020  Fidelity = 0.25631201
# T = 1030  Fidelity = 0.25999892
# T = 1040  Fidelity = 0.26131997
# T = 1050  Fidelity = 0.26097206
# T = 1060  Fidelity = 0.25782926
# T = 1070  Fidelity = 0.25689221
# T = 1080  Fidelity = 0.25811537
# T = 1090  Fidelity = 0.25641386
# T = 1100  Fidelity = 0.25604320
# T = 1200  Fidelity = 0.25829302
# T = 1300  Fidelity = 0.25993155
# T = 1400  Fidelity = 0.25926171
# T = 1500  Fidelity = 0.25891188
# T = 2000  Fidelity = 0.25915887
# T = 2100  Fidelity = 0.25956675
# T = 2110  Fidelity = 0.25750461
# T = 2120  Fidelity = 0.25775342
# T = 2130  Fidelity = 0.25972006
# T = 2140  Fidelity = 0.25848898
# T = 2150  Fidelity = 0.26048771
# T = 2160  Fidelity = 0.25839578
# T = 2170  Fidelity = 0.25949565
# T = 2180  Fidelity = 0.25820934
# T = 2190  Fidelity = 0.25893951
# T = 2200  Fidelity = 0.25999659
# T = 2300  Fidelity = 0.25900380
# T = 2400  Fidelity = 0.25719542
# T = 2500  Fidelity = 0.26008681
# T = 2600  Fidelity = 0.26076491
# T = 2700  Fidelity = 0.25828799
# T = 2800  Fidelity = 0.25781068
# T = 2900  Fidelity = 0.25497803
# T = 3000  Fidelity = 0.25429791
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.29930120e-03
# P0     = 0.25429791
# P1     = 0.24521169
# P0+P1  = 0.49950960
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05944621e-03
# T = 1     Fidelity = 0.25703841
# T = 2     Fidelity = 0.26035052
# T = 5     Fidelity = 0.26232778
# T = 10    Fidelity = 0.26284564
# T = 20    Fidelity = 0.26415495
# T = 30    Fidelity = 0.26463194
# T = 40    Fidelity = 0.26511307
# T = 50    Fidelity = 0.26572560
# T = 75    Fidelity = 0.26667905
# T = 100   Fidelity = 0.26736987
# T = 125   Fidelity = 0.26797475
# T = 150   Fidelity = 0.26858727
# T = 175   Fidelity = 0.26845129
# T = 200   Fidelity = 0.26923005
# T = 225   Fidelity = 0.26997356
# T = 250   Fidelity = 0.27026951
# T = 275   Fidelity = 0.27023331
# T = 300   Fidelity = 0.27228266
# T = 400   Fidelity = 0.27245140
# T = 500   Fidelity = 0.27514720
# T = 600   Fidelity = 0.27650651
# T = 700   Fidelity = 0.27491409
# T = 800   Fidelity = 0.27783624
# T = 900   Fidelity = 0.27459515
# T = 1000  Fidelity = 0.27822280
# T = 1010  Fidelity = 0.27503211
# T = 1020  Fidelity = 0.27291564
# T = 1030  Fidelity = 0.28380958
# T = 1040  Fidelity = 0.27347112
# T = 1050  Fidelity = 0.28524313
# T = 1060  Fidelity = 0.28308375
# T = 1070  Fidelity = 0.28016792
# T = 1080  Fidelity = 0.27763376
# T = 1090  Fidelity = 0.27794920
# T = 1100  Fidelity = 0.27954564
# T = 1200  Fidelity = 0.27948742
# T = 1300  Fidelity = 0.27939598
# T = 1400  Fidelity = 0.27774409
# T = 1500  Fidelity = 0.27792626
# T = 2000  Fidelity = 0.29162253
# T = 2100  Fidelity = 0.28826399
# T = 2110  Fidelity = 0.28569918
# T = 2120  Fidelity = 0.28998708
# T = 2130  Fidelity = 0.29310734
# T = 2140  Fidelity = 0.29344124
# T = 2150  Fidelity = 0.29243186
# T = 2160  Fidelity = 0.29015688
# T = 2170  Fidelity = 0.28867596
# T = 2180  Fidelity = 0.28832491
# T = 2190  Fidelity = 0.28724628
# T = 2200  Fidelity = 0.28834665
# T = 2300  Fidelity = 0.28705967
# T = 2400  Fidelity = 0.28848811
# T = 2500  Fidelity = 0.28795648
# T = 2600  Fidelity = 0.29081114
# T = 2700  Fidelity = 0.28920874
# T = 2800  Fidelity = 0.28557069
# T = 2900  Fidelity = 0.28387338
# T = 3000  Fidelity = 0.28397224
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.07434343e-03
# P0     = 0.28397224
# P1     = 0.25363516
# P0+P1  = 0.53760740
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.57867035e-04
# T = 1     Fidelity = 0.31243835
# T = 2     Fidelity = 0.32036617
# T = 5     Fidelity = 0.33003634
# T = 10    Fidelity = 0.33396404
# T = 20    Fidelity = 0.33923478
# T = 30    Fidelity = 0.34401611
# T = 40    Fidelity = 0.34757809
# T = 50    Fidelity = 0.34999183
# T = 75    Fidelity = 0.35632370
# T = 100   Fidelity = 0.36110825
# T = 125   Fidelity = 0.36504979
# T = 150   Fidelity = 0.36878785
# T = 175   Fidelity = 0.37236392
# T = 200   Fidelity = 0.37529617
# T = 225   Fidelity = 0.37802543
# T = 250   Fidelity = 0.38095832
# T = 275   Fidelity = 0.38359425
# T = 300   Fidelity = 0.38619712
# T = 400   Fidelity = 0.39568913
# T = 500   Fidelity = 0.40373726
# T = 600   Fidelity = 0.41933496
# T = 700   Fidelity = 0.42297237
# T = 800   Fidelity = 0.43002437
# T = 900   Fidelity = 0.42458289
# T = 1000  Fidelity = 0.44174735
# T = 1010  Fidelity = 0.44437777
# T = 1020  Fidelity = 0.44551550
# T = 1030  Fidelity = 0.44752237
# T = 1040  Fidelity = 0.44981846
# T = 1050  Fidelity = 0.44991884
# T = 1060  Fidelity = 0.44851386
# T = 1070  Fidelity = 0.45472931
# T = 1080  Fidelity = 0.45779287
# T = 1090  Fidelity = 0.45952382
# T = 1100  Fidelity = 0.45256249
# T = 1200  Fidelity = 0.44156502
# T = 1300  Fidelity = 0.44430275
# T = 1400  Fidelity = 0.46562064
# T = 1500  Fidelity = 0.47771133
# T = 2000  Fidelity = 0.48543467
# T = 2100  Fidelity = 0.48693904
# T = 2110  Fidelity = 0.48434110
# T = 2120  Fidelity = 0.48457566
# T = 2130  Fidelity = 0.48050012
# T = 2140  Fidelity = 0.48617065
# T = 2150  Fidelity = 0.47983183
# T = 2160  Fidelity = 0.48121526
# T = 2170  Fidelity = 0.48664172
# T = 2180  Fidelity = 0.49079602
# T = 2190  Fidelity = 0.49844393
# T = 2200  Fidelity = 0.50631224
# T = 2300  Fidelity = 0.51746318
# T = 2400  Fidelity = 0.53714151
# T = 2500  Fidelity = 0.54227739
# T = 2600  Fidelity = 0.55015040
# T = 2700  Fidelity = 0.57945573
# T = 2800  Fidelity = 0.57839800
# T = 2900  Fidelity = 0.59110203
# T = 3000  Fidelity = 0.58445704
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.57706167e-04
# P0     = 0.58445704
# P1     = 0.20168642
# P0+P1  = 0.78614346
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.03605669e-03
# T = 1     Fidelity = 0.47244046
# T = 2     Fidelity = 0.49365731
# T = 5     Fidelity = 0.52579803
# T = 10    Fidelity = 0.54191099
# T = 20    Fidelity = 0.56858611
# T = 30    Fidelity = 0.58463491
# T = 40    Fidelity = 0.59988765
# T = 50    Fidelity = 0.61028730
# T = 75    Fidelity = 0.63426865
# T = 100   Fidelity = 0.65373948
# T = 125   Fidelity = 0.66936232
# T = 150   Fidelity = 0.68313456
# T = 175   Fidelity = 0.69595011
# T = 200   Fidelity = 0.70710317
# T = 225   Fidelity = 0.71725235
# T = 250   Fidelity = 0.72701937
# T = 275   Fidelity = 0.73588324
# T = 300   Fidelity = 0.74442165
# T = 400   Fidelity = 0.77331476
# T = 500   Fidelity = 0.79714360
# T = 600   Fidelity = 0.80401347
# T = 700   Fidelity = 0.82952968
# T = 800   Fidelity = 0.85927715
# T = 900   Fidelity = 0.87958058
# T = 1000  Fidelity = 0.87845812
# T = 1010  Fidelity = 0.88570376
# T = 1020  Fidelity = 0.89193623
# T = 1030  Fidelity = 0.89840493
# T = 1040  Fidelity = 0.90234257
# T = 1050  Fidelity = 0.90368648
# T = 1060  Fidelity = 0.90245220
# T = 1070  Fidelity = 0.89999558
# T = 1080  Fidelity = 0.89755568
# T = 1090  Fidelity = 0.89456245
# T = 1100  Fidelity = 0.89062911
# T = 1200  Fidelity = 0.88258220
# T = 1300  Fidelity = 0.93538781
# T = 1400  Fidelity = 0.91213965
# T = 1500  Fidelity = 0.88374449
# T = 2000  Fidelity = 0.92413602
# T = 2100  Fidelity = 0.89553496
# T = 2110  Fidelity = 0.89392302
# T = 2120  Fidelity = 0.88580205
# T = 2130  Fidelity = 0.88207524
# T = 2140  Fidelity = 0.88965783
# T = 2150  Fidelity = 0.90128985
# T = 2160  Fidelity = 0.90681854
# T = 2170  Fidelity = 0.90553729
# T = 2180  Fidelity = 0.90243153
# T = 2190  Fidelity = 0.90373468
# T = 2200  Fidelity = 0.91080151
# T = 2300  Fidelity = 0.91152291
# T = 2400  Fidelity = 0.93175473
# T = 2500  Fidelity = 0.96660984
# T = 2600  Fidelity = 0.96659670
# T = 2700  Fidelity = 0.98569919
# T = 2800  Fidelity = 0.99773767
#
# Minimum T for Fidelity >= 0.99 : 2800
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.34955504e-03
# T = 1     Fidelity = 0.51037226
# T = 2     Fidelity = 0.54346677
# T = 5     Fidelity = 0.59712939
# T = 10    Fidelity = 0.63028349
# T = 20    Fidelity = 0.68217394
# T = 30    Fidelity = 0.71510001
# T = 40    Fidelity = 0.73727979
# T = 50    Fidelity = 0.75693780
# T = 75    Fidelity = 0.79598251
# T = 100   Fidelity = 0.82422009
# T = 125   Fidelity = 0.84589082
# T = 150   Fidelity = 0.86367887
# T = 175   Fidelity = 0.87879572
# T = 200   Fidelity = 0.89134158
# T = 225   Fidelity = 0.90218978
# T = 250   Fidelity = 0.91110042
# T = 275   Fidelity = 0.91947692
# T = 300   Fidelity = 0.92684366
# T = 400   Fidelity = 0.94811747
# T = 500   Fidelity = 0.96150475
# T = 600   Fidelity = 0.97034087
# T = 700   Fidelity = 0.96749947
# T = 800   Fidelity = 0.98537293
# T = 900   Fidelity = 0.98845782
# T = 1000  Fidelity = 0.99400765
#
# Minimum T for Fidelity >= 0.99 : 1000
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.92117516e-02
# T = 1     Fidelity = 0.54949416
# T = 2     Fidelity = 0.59330214
# T = 5     Fidelity = 0.66441234
# T = 10    Fidelity = 0.71988344
# T = 20    Fidelity = 0.78249307
# T = 30    Fidelity = 0.82290121
# T = 40    Fidelity = 0.85178781
# T = 50    Fidelity = 0.87319944
# T = 75    Fidelity = 0.90852706
# T = 100   Fidelity = 0.93098967
# T = 125   Fidelity = 0.94633948
# T = 150   Fidelity = 0.95733177
# T = 175   Fidelity = 0.96527138
# T = 200   Fidelity = 0.97134974
# T = 225   Fidelity = 0.97584031
# T = 250   Fidelity = 0.97966407
# T = 275   Fidelity = 0.98257525
# T = 300   Fidelity = 0.98508173
# T = 400   Fidelity = 0.99068183
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 3.87769083e-02
# T = 1     Fidelity = 0.60019325
# T = 2     Fidelity = 0.65320191
# T = 5     Fidelity = 0.73585365
# T = 10    Fidelity = 0.80607168
# T = 20    Fidelity = 0.86829949
# T = 30    Fidelity = 0.90339052
# T = 40    Fidelity = 0.92624183
# T = 50    Fidelity = 0.94222806
# T = 75    Fidelity = 0.96465800
# T = 100   Fidelity = 0.97695116
# T = 125   Fidelity = 0.98406334
# T = 150   Fidelity = 0.98826228
# T = 175   Fidelity = 0.99063705
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 6.53490673e-02
# T = 1     Fidelity = 0.65427432
# T = 2     Fidelity = 0.71391951
# T = 5     Fidelity = 0.80122458
# T = 10    Fidelity = 0.87223359
# T = 20    Fidelity = 0.92459744
# T = 30    Fidelity = 0.95034382
# T = 40    Fidelity = 0.96543606
# T = 50    Fidelity = 0.97500692
# T = 75    Fidelity = 0.98639324
# T = 100   Fidelity = 0.99178605
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99425380
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.99412532
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.42665601e+00
# T = 1     Fidelity = 0.99364199
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41121208e+00
# T = 1     Fidelity = 0.99378976
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.99330646
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.99240633
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99124745
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98982354
# T = 2     Fidelity = 0.99683591
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98824871
# T = 2     Fidelity = 0.99600315
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98664137
# T = 2     Fidelity = 0.99510653
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     700       0.9933646140      2.15534848e-04    None        None        None
# Symmetric      0.311     125       0.9969335628      1.15624068e-06    None        None        None
# Symmetric      0.522     75        0.9914456368      3.42043164e-07    None        None        None
# Symmetric      0.733     50        0.9923201869      1.41278093e-05    None        None        None
# Symmetric      0.944     50        0.9938793282      3.35131121e-04    None        None        None
# Symmetric      1.156     30        0.9965138529      2.39158790e-03    None        None        None
# Symmetric      1.367     40        0.9975550613      8.93695212e-03    None        None        None
# Symmetric      1.578     40        0.9911523418      2.26116126e-02    None        None        None
# Symmetric      1.789     50        0.9932328057      4.43232760e-02    None        None        None
# Symmetric      2.000     50        0.9929113142      7.29248761e-02    None        None        None
# Weak SSB optimised0.100     1090      0.9914510948      8.65519637e-01    None        None        None
# Weak SSB optimised0.311     None      0.9806135633      5.19764834e-01    0.944415    0.034851    0.979265
# Weak SSB optimised0.522     1         0.9908240637      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     2         0.9968412400      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     2         0.9911704669      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     75        0.9916573001      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     275       0.9906432162      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     400       0.9927578641      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     250       0.9910336403      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     150       0.9906356913      2.54594564e-01    None        None        None
# Weak SSB       0.100     225       0.9918119178      1.35126357e-02    None        None        None
# Weak SSB       0.311     2160      0.9915644529      2.91075005e-03    None        None        None
# Weak SSB       0.522     None      0.2616853314      1.05614584e-03    0.254298    0.245212    0.49951
# Weak SSB       0.733     None      0.2934412360      1.05944621e-03    0.283972    0.253635    0.537607
# Weak SSB       0.944     None      0.5911020278      9.57867035e-04    0.584457    0.201686    0.786143
# Weak SSB       1.156     2800      0.9977376726      2.03605669e-03    None        None        None
# Weak SSB       1.367     1000      0.9940076491      7.34955504e-03    None        None        None
# Weak SSB       1.578     400       0.9906818264      1.92117516e-02    None        None        None
# Weak SSB       1.789     175       0.9906370533      3.87769083e-02    None        None        None
# Weak SSB       2.000     100       0.9917860505      6.53490673e-02    None        None        None
# Strong SSB     0.100     1         0.9942538021      3.59472102e+00    None        None        None
# Strong SSB     0.311     1         0.9941253218      1.58498916e+00    None        None        None
# Strong SSB     0.522     1         0.9936419888      1.42665601e+00    None        None        None
# Strong SSB     0.733     1         0.9937897560      1.41121208e+00    None        None        None
# Strong SSB     0.944     1         0.9933064567      1.38481786e+00    None        None        None
# Strong SSB     1.156     1         0.9924063274      1.34302163e+00    None        None        None
# Strong SSB     1.367     1         0.9912474474      1.29217279e+00    None        None        None
# Strong SSB     1.578     2         0.9968359069      1.23335459e+00    None        None        None
# Strong SSB     1.789     2         0.9960031533      1.17426012e+00    None        None        None
# Strong SSB     2.000     2         0.9951065325      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================



case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
# Define colors for each case
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

    
for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()


plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-2.0

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000295
# T = 10    Fidelity = 0.00027918
# T = 20    Fidelity = 0.00630151
# T = 30    Fidelity = 0.02603823
# T = 40    Fidelity = 0.06583358
# T = 50    Fidelity = 0.12448230
# T = 75    Fidelity = 0.30903911
# T = 100   Fidelity = 0.46392380
# T = 125   Fidelity = 0.64204866
# T = 150   Fidelity = 0.69157665
# T = 175   Fidelity = 0.77468406
# T = 200   Fidelity = 0.83394305
# T = 225   Fidelity = 0.81459941
# T = 250   Fidelity = 0.90535128
# T = 275   Fidelity = 0.91625418
# T = 300   Fidelity = 0.86714376
# T = 400   Fidelity = 0.97880091
# T = 500   Fidelity = 0.86744463
# T = 600   Fidelity = 0.89637181
# T = 700   Fidelity = 0.86507350
# T = 800   Fidelity = 0.84094882
# T = 900   Fidelity = 0.91561453
# T = 1000  Fidelity = 0.78789623
# T = 1010  Fidelity = 0.86617532
# T = 1020  Fidelity = 0.76217518
# T = 1030  Fidelity = 0.71445672
# T = 1040  Fidelity = 0.60475250
# T = 1050  Fidelity = 0.44975996
# T = 1060  Fidelity = 0.49370360
# T = 1070  Fidelity = 0.46202246
# T = 1080  Fidelity = 0.54277296
# T = 1090  Fidelity = 0.59939749
# T = 1100  Fidelity = 0.58203888
# T = 1200  Fidelity = 0.69557908
# T = 1300  Fidelity = 0.53378409
# T = 1400  Fidelity = 0.88369891
# T = 1500  Fidelity = 0.75104993
# T = 2000  Fidelity = 0.48181450
# T = 2100  Fidelity = 0.34342803
# T = 2110  Fidelity = 0.54052572
# T = 2120  Fidelity = 0.62152643
# T = 2130  Fidelity = 0.58569556
# T = 2140  Fidelity = 0.55835416
# T = 2150  Fidelity = 0.44171936
# T = 2160  Fidelity = 0.59535014
# T = 2170  Fidelity = 0.54224474
# T = 2180  Fidelity = 0.58480646
# T = 2190  Fidelity = 0.64417151
# T = 2200  Fidelity = 0.57757245
# T = 2300  Fidelity = 0.89032147
# T = 2400  Fidelity = 0.61187373
# T = 2500  Fidelity = 0.43003150
# T = 2600  Fidelity = 0.69223703
# T = 2700  Fidelity = 0.84404743
# T = 2800  Fidelity = 0.79490602
# T = 2900  Fidelity = 0.77014082
# T = 3000  Fidelity = 0.70248532
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.79379555e-02
# P0     = 0.70248532
# P1     = 0.00000000
# P0+P1  = 0.70248532
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.17908350e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00030548
# T = 10    Fidelity = 0.01972951
# T = 20    Fidelity = 0.35206773
# T = 30    Fidelity = 0.52580789
# T = 40    Fidelity = 0.54425990
# T = 50    Fidelity = 0.70353722
# T = 75    Fidelity = 0.85010024
# T = 100   Fidelity = 0.92373693
# T = 125   Fidelity = 0.95513113
# T = 150   Fidelity = 0.97618507
# T = 175   Fidelity = 0.99755228
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.94880930e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.01013579
# T = 10    Fidelity = 0.29395816
# T = 20    Fidelity = 0.47649636
# T = 30    Fidelity = 0.65919337
# T = 40    Fidelity = 0.84257061
# T = 50    Fidelity = 0.88343643
# T = 75    Fidelity = 0.96311856
# T = 100   Fidelity = 0.98782725
# T = 125   Fidelity = 0.99595710
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.58119033e-07
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000816
# T = 5     Fidelity = 0.06263499
# T = 10    Fidelity = 0.29632976
# T = 20    Fidelity = 0.55808031
# T = 30    Fidelity = 0.72698695
# T = 40    Fidelity = 0.83532645
# T = 50    Fidelity = 0.91098887
# T = 75    Fidelity = 0.98046922
# T = 100   Fidelity = 0.99984502
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.89654582e-08
# T = 1     Fidelity = 0.00000138
# T = 2     Fidelity = 0.00013184
# T = 5     Fidelity = 0.11159609
# T = 10    Fidelity = 0.49005075
# T = 20    Fidelity = 0.76516191
# T = 30    Fidelity = 0.88755450
# T = 40    Fidelity = 0.94380613
# T = 50    Fidelity = 0.97010052
# T = 75    Fidelity = 0.99783138
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.17592584e-07
# T = 1     Fidelity = 0.00002204
# T = 2     Fidelity = 0.00081382
# T = 5     Fidelity = 0.15753701
# T = 10    Fidelity = 0.62743505
# T = 20    Fidelity = 0.87767080
# T = 30    Fidelity = 0.95887106
# T = 40    Fidelity = 0.98613186
# T = 50    Fidelity = 0.99608435
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 2.47961127e-07
# T = 1     Fidelity = 0.00014361
# T = 2     Fidelity = 0.00277571
# T = 5     Fidelity = 0.19658229
# T = 10    Fidelity = 0.73840444
# T = 20    Fidelity = 0.93000389
# T = 30    Fidelity = 0.97198329
# T = 40    Fidelity = 0.98584785
# T = 50    Fidelity = 0.99133462
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 3.56990589e-07
# T = 1     Fidelity = 0.00057618
# T = 2     Fidelity = 0.00690644
# T = 5     Fidelity = 0.23188066
# T = 10    Fidelity = 0.80830911
# T = 20    Fidelity = 0.93689698
# T = 30    Fidelity = 0.96371847
# T = 40    Fidelity = 0.98388591
# T = 50    Fidelity = 0.99475549
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.45005899e-06
# T = 1     Fidelity = 0.00169007
# T = 2     Fidelity = 0.01404613
# T = 5     Fidelity = 0.26488661
# T = 10    Fidelity = 0.84405768
# T = 20    Fidelity = 0.92519532
# T = 30    Fidelity = 0.96896668
# T = 40    Fidelity = 0.99383651
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396163
# T = 2     Fidelity = 0.02467218
# T = 5     Fidelity = 0.29523401
# T = 10    Fidelity = 0.85800478
# T = 20    Fidelity = 0.92052589
# T = 30    Fidelity = 0.98399985
# T = 40    Fidelity = 0.99992204
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.62865996
# T = 2     Fidelity = 0.65720729
# T = 5     Fidelity = 0.71283639
# T = 10    Fidelity = 0.76620733
# T = 20    Fidelity = 0.83172712
# T = 30    Fidelity = 0.87134849
# T = 40    Fidelity = 0.89966954
# T = 50    Fidelity = 0.91945780
# T = 75    Fidelity = 0.95021131
# T = 100   Fidelity = 0.96446424
# T = 125   Fidelity = 0.97348669
# T = 150   Fidelity = 0.98142529
# T = 175   Fidelity = 0.97956927
# T = 200   Fidelity = 0.98379070
# T = 225   Fidelity = 0.97859351
# T = 250   Fidelity = 0.98489977
# T = 275   Fidelity = 0.95104808
# T = 300   Fidelity = 0.94014940
# T = 400   Fidelity = 0.97914876
# T = 500   Fidelity = 0.97590839
# T = 600   Fidelity = 0.93030982
# T = 700   Fidelity = 0.81785673
# T = 800   Fidelity = 0.95126519
# T = 900   Fidelity = 0.98238341
# T = 1000  Fidelity = 0.95640075
# T = 1010  Fidelity = 0.95764281
# T = 1020  Fidelity = 0.95799623
# T = 1030  Fidelity = 0.95722173
# T = 1040  Fidelity = 0.96135300
# T = 1050  Fidelity = 0.95751344
# T = 1060  Fidelity = 0.97379764
# T = 1070  Fidelity = 0.98726464
# T = 1080  Fidelity = 0.98960854
# T = 1090  Fidelity = 0.98094018
# T = 1100  Fidelity = 0.97313865
# T = 1200  Fidelity = 0.98528933
# T = 1300  Fidelity = 0.96715750
# T = 1400  Fidelity = 0.84364214
# T = 1500  Fidelity = 0.91483945
# T = 2000  Fidelity = 0.95480563
# T = 2100  Fidelity = 0.87174207
# T = 2110  Fidelity = 0.84870546
# T = 2120  Fidelity = 0.84991643
# T = 2130  Fidelity = 0.85152731
# T = 2140  Fidelity = 0.85411563
# T = 2150  Fidelity = 0.84946371
# T = 2160  Fidelity = 0.86386816
# T = 2170  Fidelity = 0.87677436
# T = 2180  Fidelity = 0.88452952
# T = 2190  Fidelity = 0.89515180
# T = 2200  Fidelity = 0.91130862
# T = 2300  Fidelity = 0.97223076
# T = 2400  Fidelity = 0.97218318
# T = 2500  Fidelity = 0.94349107
# T = 2600  Fidelity = 0.97706207
# T = 2700  Fidelity = 0.97325573
# T = 2800  Fidelity = 0.88820323
# T = 2900  Fidelity = 0.89988915
# T = 3000  Fidelity = 0.94612861
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.33549253e-01
# P0     = 0.94612861
# P1     = 0.02853965
# P0+P1  = 0.97466825
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.70134415
# T = 2     Fidelity = 0.77063726
# T = 5     Fidelity = 0.81850828
# T = 10    Fidelity = 0.84810528
# T = 20    Fidelity = 0.87659192
# T = 30    Fidelity = 0.89441895
# T = 40    Fidelity = 0.90794498
# T = 50    Fidelity = 0.91779882
# T = 75    Fidelity = 0.93530026
# T = 100   Fidelity = 0.94652406
# T = 125   Fidelity = 0.95236805
# T = 150   Fidelity = 0.95702065
# T = 175   Fidelity = 0.96521871
# T = 200   Fidelity = 0.97118346
# T = 225   Fidelity = 0.96492363
# T = 250   Fidelity = 0.96669759
# T = 275   Fidelity = 0.97055210
# T = 300   Fidelity = 0.96266505
# T = 400   Fidelity = 0.96904054
# T = 500   Fidelity = 0.96196889
# T = 600   Fidelity = 0.96344808
# T = 700   Fidelity = 0.96601744
# T = 800   Fidelity = 0.93910504
# T = 900   Fidelity = 0.92330721
# T = 1000  Fidelity = 0.93430535
# T = 1010  Fidelity = 0.93404255
# T = 1020  Fidelity = 0.93752941
# T = 1030  Fidelity = 0.94585074
# T = 1040  Fidelity = 0.93793862
# T = 1050  Fidelity = 0.95046774
# T = 1060  Fidelity = 0.95545157
# T = 1070  Fidelity = 0.92997977
# T = 1080  Fidelity = 0.94620986
# T = 1090  Fidelity = 0.92439095
# T = 1100  Fidelity = 0.92769882
# T = 1200  Fidelity = 0.95403353
# T = 1300  Fidelity = 0.95861250
# T = 1400  Fidelity = 0.97632315
# T = 1500  Fidelity = 0.98631294
# T = 2000  Fidelity = 0.94445854
# T = 2100  Fidelity = 0.95213570
# T = 2110  Fidelity = 0.95166025
# T = 2120  Fidelity = 0.95511219
# T = 2130  Fidelity = 0.94376369
# T = 2140  Fidelity = 0.96000713
# T = 2150  Fidelity = 0.95557773
# T = 2160  Fidelity = 0.95274119
# T = 2170  Fidelity = 0.95880928
# T = 2180  Fidelity = 0.92815621
# T = 2190  Fidelity = 0.94242775
# T = 2200  Fidelity = 0.94031147
# T = 2300  Fidelity = 0.94511914
# T = 2400  Fidelity = 0.97436056
# T = 2500  Fidelity = 0.96740288
# T = 2600  Fidelity = 0.95899867
# T = 2700  Fidelity = 0.94551875
# T = 2800  Fidelity = 0.93752010
# T = 2900  Fidelity = 0.91144242
# T = 3000  Fidelity = 0.96766995
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.30329715e-01
# P0     = 0.96766995
# P1     = 0.01688430
# P0+P1  = 0.98455424
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.05158065
# T = 2     Fidelity = 0.19625752
# T = 5     Fidelity = 0.84824027
# T = 10    Fidelity = 0.96981790
# T = 20    Fidelity = 0.99315941
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.11301321
# T = 2     Fidelity = 0.33364759
# T = 5     Fidelity = 0.84573160
# T = 10    Fidelity = 0.91481578
# T = 20    Fidelity = 0.99917350
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.16812506
# T = 2     Fidelity = 0.40048080
# T = 5     Fidelity = 0.89902265
# T = 10    Fidelity = 0.94670421
# T = 20    Fidelity = 0.99422643
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.20942129
# T = 2     Fidelity = 0.42817269
# T = 5     Fidelity = 0.87703788
# T = 10    Fidelity = 0.92057530
# T = 20    Fidelity = 0.97064843
# T = 30    Fidelity = 0.97912062
# T = 40    Fidelity = 0.97883565
# T = 50    Fidelity = 0.98334676
# T = 75    Fidelity = 0.98581565
# T = 100   Fidelity = 0.98861504
# T = 125   Fidelity = 0.99124106
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.21775438
# T = 2     Fidelity = 0.40611705
# T = 5     Fidelity = 0.82818426
# T = 10    Fidelity = 0.86728246
# T = 20    Fidelity = 0.90916220
# T = 30    Fidelity = 0.93549186
# T = 40    Fidelity = 0.94744796
# T = 50    Fidelity = 0.94919804
# T = 75    Fidelity = 0.96238538
# T = 100   Fidelity = 0.96570549
# T = 125   Fidelity = 0.97417002
# T = 150   Fidelity = 0.97564210
# T = 175   Fidelity = 0.97948547
# T = 200   Fidelity = 0.98206539
# T = 225   Fidelity = 0.98245226
# T = 250   Fidelity = 0.98606752
# T = 275   Fidelity = 0.98502321
# T = 300   Fidelity = 0.98788136
# T = 400   Fidelity = 0.95377464
# T = 500   Fidelity = 0.96691279
# T = 600   Fidelity = 0.98211864
# T = 700   Fidelity = 0.96946689
# T = 800   Fidelity = 0.96729847
# T = 900   Fidelity = 0.98259832
# T = 1000  Fidelity = 0.97089252
# T = 1010  Fidelity = 0.98705547
# T = 1020  Fidelity = 0.99154667
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.20075049
# T = 2     Fidelity = 0.34917505
# T = 5     Fidelity = 0.74414118
# T = 10    Fidelity = 0.79187141
# T = 20    Fidelity = 0.83478561
# T = 30    Fidelity = 0.86251766
# T = 40    Fidelity = 0.88625010
# T = 50    Fidelity = 0.90578383
# T = 75    Fidelity = 0.93019218
# T = 100   Fidelity = 0.94152298
# T = 125   Fidelity = 0.95490054
# T = 150   Fidelity = 0.96248533
# T = 175   Fidelity = 0.96705433
# T = 200   Fidelity = 0.97288642
# T = 225   Fidelity = 0.97597259
# T = 250   Fidelity = 0.97854749
# T = 275   Fidelity = 0.98225080
# T = 300   Fidelity = 0.98253898
# T = 400   Fidelity = 0.95705805
# T = 500   Fidelity = 0.97152389
# T = 600   Fidelity = 0.98380614
# T = 700   Fidelity = 0.96732535
# T = 800   Fidelity = 0.97390030
# T = 900   Fidelity = 0.99396352
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.18010305
# T = 2     Fidelity = 0.29812012
# T = 5     Fidelity = 0.67044367
# T = 10    Fidelity = 0.73231410
# T = 20    Fidelity = 0.79332723
# T = 30    Fidelity = 0.82945294
# T = 40    Fidelity = 0.85601994
# T = 50    Fidelity = 0.87727539
# T = 75    Fidelity = 0.91479134
# T = 100   Fidelity = 0.93874599
# T = 125   Fidelity = 0.95470570
# T = 150   Fidelity = 0.96543199
# T = 175   Fidelity = 0.97256399
# T = 200   Fidelity = 0.97743804
# T = 225   Fidelity = 0.98058912
# T = 250   Fidelity = 0.98394080
# T = 275   Fidelity = 0.98650869
# T = 300   Fidelity = 0.98823382
# T = 400   Fidelity = 0.97349889
# T = 500   Fidelity = 0.97301437
# T = 600   Fidelity = 0.98569955
# T = 700   Fidelity = 0.98640486
# T = 800   Fidelity = 0.98680058
# T = 900   Fidelity = 0.98959234
# T = 1000  Fidelity = 0.98265396
# T = 1010  Fidelity = 0.97173786
# T = 1020  Fidelity = 0.99465309
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.48783584e-01
# T = 1     Fidelity = 0.16418678
# T = 2     Fidelity = 0.26141641
# T = 5     Fidelity = 0.62002874
# T = 10    Fidelity = 0.69450289
# T = 20    Fidelity = 0.77238392
# T = 30    Fidelity = 0.82154013
# T = 40    Fidelity = 0.85808291
# T = 50    Fidelity = 0.88617575
# T = 75    Fidelity = 0.93171124
# T = 100   Fidelity = 0.95682338
# T = 125   Fidelity = 0.97134648
# T = 150   Fidelity = 0.98008120
# T = 175   Fidelity = 0.98553050
# T = 200   Fidelity = 0.98856926
# T = 225   Fidelity = 0.99106101
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.81947687e-02
# T = 1     Fidelity = 0.60256303
# T = 2     Fidelity = 0.64656823
# T = 5     Fidelity = 0.72454287
# T = 10    Fidelity = 0.80032666
# T = 20    Fidelity = 0.88106718
# T = 30    Fidelity = 0.92319054
# T = 40    Fidelity = 0.94762485
# T = 50    Fidelity = 0.96252981
# T = 75    Fidelity = 0.98115571
# T = 100   Fidelity = 0.98439189
# T = 125   Fidelity = 0.98494479
# T = 150   Fidelity = 0.99043687
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.51771385e-02
# T = 1     Fidelity = 0.54018846
# T = 2     Fidelity = 0.58318657
# T = 5     Fidelity = 0.62712559
# T = 10    Fidelity = 0.66452989
# T = 20    Fidelity = 0.72223062
# T = 30    Fidelity = 0.76413942
# T = 40    Fidelity = 0.79663449
# T = 50    Fidelity = 0.82074744
# T = 75    Fidelity = 0.86857794
# T = 100   Fidelity = 0.89956026
# T = 125   Fidelity = 0.91945469
# T = 150   Fidelity = 0.93352120
# T = 175   Fidelity = 0.94112542
# T = 200   Fidelity = 0.94233115
# T = 225   Fidelity = 0.94934119
# T = 250   Fidelity = 0.94157720
# T = 275   Fidelity = 0.93116006
# T = 300   Fidelity = 0.94469446
# T = 400   Fidelity = 0.96621172
# T = 500   Fidelity = 0.94955511
# T = 600   Fidelity = 0.95690359
# T = 700   Fidelity = 0.83460103
# T = 800   Fidelity = 0.87176506
# T = 900   Fidelity = 0.88454669
# T = 1000  Fidelity = 0.88117856
# T = 1010  Fidelity = 0.93284374
# T = 1020  Fidelity = 0.90753471
# T = 1030  Fidelity = 0.94385050
# T = 1040  Fidelity = 0.94721936
# T = 1050  Fidelity = 0.96186700
# T = 1060  Fidelity = 0.97093736
# T = 1070  Fidelity = 0.94759781
# T = 1080  Fidelity = 0.97394771
# T = 1090  Fidelity = 0.96787214
# T = 1100  Fidelity = 0.94479088
# T = 1200  Fidelity = 0.91798951
# T = 1300  Fidelity = 0.97438959
# T = 1400  Fidelity = 0.93684973
# T = 1500  Fidelity = 0.90612995
# T = 2000  Fidelity = 0.94603894
# T = 2100  Fidelity = 0.98884058
# T = 2110  Fidelity = 0.97987403
# T = 2120  Fidelity = 0.98058373
# T = 2130  Fidelity = 0.97375329
# T = 2140  Fidelity = 0.96735817
# T = 2150  Fidelity = 0.95468872
# T = 2160  Fidelity = 0.96001090
# T = 2170  Fidelity = 0.97592784
# T = 2180  Fidelity = 0.96179148
# T = 2190  Fidelity = 0.97595164
# T = 2200  Fidelity = 0.96844519
# T = 2300  Fidelity = 0.89078686
# T = 2400  Fidelity = 0.89007524
# T = 2500  Fidelity = 0.93929906
# T = 2600  Fidelity = 0.86132491
# T = 2700  Fidelity = 0.84351900
# T = 2800  Fidelity = 0.93032982
# T = 2900  Fidelity = 0.95756978
# T = 3000  Fidelity = 0.93716956
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.50815198e-02
# P0     = 0.93716956
# P1     = 0.00004398
# P0+P1  = 0.93721353
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.02270955
# T = 2     Fidelity = 0.09263524
# T = 5     Fidelity = 0.42622714
# T = 10    Fidelity = 0.47783900
# T = 20    Fidelity = 0.49290822
# T = 30    Fidelity = 0.49422655
# T = 40    Fidelity = 0.49488010
# T = 50    Fidelity = 0.49673409
# T = 75    Fidelity = 0.49468023
# T = 100   Fidelity = 0.49577284
# T = 125   Fidelity = 0.49335022
# T = 150   Fidelity = 0.49536704
# T = 175   Fidelity = 0.49167365
# T = 200   Fidelity = 0.49020448
# T = 225   Fidelity = 0.48925767
# T = 250   Fidelity = 0.48819739
# T = 275   Fidelity = 0.48341353
# T = 300   Fidelity = 0.48049933
# T = 400   Fidelity = 0.45893292
# T = 500   Fidelity = 0.44118267
# T = 600   Fidelity = 0.44565694
# T = 700   Fidelity = 0.42421183
# T = 800   Fidelity = 0.40561694
# T = 900   Fidelity = 0.40516848
# T = 1000  Fidelity = 0.36644393
# T = 1010  Fidelity = 0.37261524
# T = 1020  Fidelity = 0.37265217
# T = 1030  Fidelity = 0.36675885
# T = 1040  Fidelity = 0.37218008
# T = 1050  Fidelity = 0.36204349
# T = 1060  Fidelity = 0.36279974
# T = 1070  Fidelity = 0.36385586
# T = 1080  Fidelity = 0.36442221
# T = 1090  Fidelity = 0.35694803
# T = 1100  Fidelity = 0.35303469
# T = 1200  Fidelity = 0.34391027
# T = 1300  Fidelity = 0.31783626
# T = 1400  Fidelity = 0.26268317
# T = 1500  Fidelity = 0.27992907
# T = 2000  Fidelity = 0.19430076
# T = 2100  Fidelity = 0.18742494
# T = 2110  Fidelity = 0.18125465
# T = 2120  Fidelity = 0.17806748
# T = 2130  Fidelity = 0.17398229
# T = 2140  Fidelity = 0.17813111
# T = 2150  Fidelity = 0.17562209
# T = 2160  Fidelity = 0.17282779
# T = 2170  Fidelity = 0.16768428
# T = 2180  Fidelity = 0.16893695
# T = 2190  Fidelity = 0.16668503
# T = 2200  Fidelity = 0.16349687
# T = 2300  Fidelity = 0.15270776
# T = 2400  Fidelity = 0.10957375
# T = 2500  Fidelity = 0.12950893
# T = 2600  Fidelity = 0.12017442
# T = 2700  Fidelity = 0.10817109
# T = 2800  Fidelity = 0.09461340
# T = 2900  Fidelity = 0.09157777
# T = 3000  Fidelity = 0.08350410
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.35220086e-03
# P0     = 0.08350410
# P1     = 0.41418378
# P0+P1  = 0.49768788
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07018746e-03
# T = 1     Fidelity = 0.02882010
# T = 2     Fidelity = 0.08555321
# T = 5     Fidelity = 0.22661591
# T = 10    Fidelity = 0.24400210
# T = 20    Fidelity = 0.26817182
# T = 30    Fidelity = 0.26757556
# T = 40    Fidelity = 0.26810999
# T = 50    Fidelity = 0.27113569
# T = 75    Fidelity = 0.27170037
# T = 100   Fidelity = 0.27250865
# T = 125   Fidelity = 0.27239643
# T = 150   Fidelity = 0.27266509
# T = 175   Fidelity = 0.27260212
# T = 200   Fidelity = 0.27845387
# T = 225   Fidelity = 0.27650863
# T = 250   Fidelity = 0.27005628
# T = 275   Fidelity = 0.27433632
# T = 300   Fidelity = 0.27629126
# T = 400   Fidelity = 0.29322562
# T = 500   Fidelity = 0.26094556
# T = 600   Fidelity = 0.27291454
# T = 700   Fidelity = 0.27057661
# T = 800   Fidelity = 0.24310276
# T = 900   Fidelity = 0.24054371
# T = 1000  Fidelity = 0.26277855
# T = 1010  Fidelity = 0.26514581
# T = 1020  Fidelity = 0.26629551
# T = 1030  Fidelity = 0.28865970
# T = 1040  Fidelity = 0.27162585
# T = 1050  Fidelity = 0.28704671
# T = 1060  Fidelity = 0.33350349
# T = 1070  Fidelity = 0.22446058
# T = 1080  Fidelity = 0.25415713
# T = 1090  Fidelity = 0.25390521
# T = 1100  Fidelity = 0.30519156
# T = 1200  Fidelity = 0.31898781
# T = 1300  Fidelity = 0.29698487
# T = 1400  Fidelity = 0.30239307
# T = 1500  Fidelity = 0.20993785
# T = 2000  Fidelity = 0.26898039
# T = 2100  Fidelity = 0.19366252
# T = 2110  Fidelity = 0.28956565
# T = 2120  Fidelity = 0.28495031
# T = 2130  Fidelity = 0.21840737
# T = 2140  Fidelity = 0.35653517
# T = 2150  Fidelity = 0.21433948
# T = 2160  Fidelity = 0.28409007
# T = 2170  Fidelity = 0.23375277
# T = 2180  Fidelity = 0.28398268
# T = 2190  Fidelity = 0.28437306
# T = 2200  Fidelity = 0.27467405
# T = 2300  Fidelity = 0.29362579
# T = 2400  Fidelity = 0.23943731
# T = 2500  Fidelity = 0.29131322
# T = 2600  Fidelity = 0.28898931
# T = 2700  Fidelity = 0.25339479
# T = 2800  Fidelity = 0.23468091
# T = 2900  Fidelity = 0.25233810
# T = 3000  Fidelity = 0.23243843
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.59823390e-03
# P0     = 0.23243843
# P1     = 0.24456172
# P0+P1  = 0.47700015
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.80171521e-04
# T = 1     Fidelity = 0.03888536
# T = 2     Fidelity = 0.09376747
# T = 5     Fidelity = 0.22956955
# T = 10    Fidelity = 0.24167165
# T = 20    Fidelity = 0.26250947
# T = 30    Fidelity = 0.26947984
# T = 40    Fidelity = 0.26755323
# T = 50    Fidelity = 0.27371533
# T = 75    Fidelity = 0.27654939
# T = 100   Fidelity = 0.28034051
# T = 125   Fidelity = 0.28549523
# T = 150   Fidelity = 0.29042544
# T = 175   Fidelity = 0.29859049
# T = 200   Fidelity = 0.29687138
# T = 225   Fidelity = 0.30143443
# T = 250   Fidelity = 0.30001975
# T = 275   Fidelity = 0.29791092
# T = 300   Fidelity = 0.30689943
# T = 400   Fidelity = 0.35512183
# T = 500   Fidelity = 0.28594504
# T = 600   Fidelity = 0.32701998
# T = 700   Fidelity = 0.23797688
# T = 800   Fidelity = 0.37507435
# T = 900   Fidelity = 0.37614014
# T = 1000  Fidelity = 0.35126839
# T = 1010  Fidelity = 0.37724364
# T = 1020  Fidelity = 0.39666401
# T = 1030  Fidelity = 0.34983615
# T = 1040  Fidelity = 0.27928019
# T = 1050  Fidelity = 0.26743081
# T = 1060  Fidelity = 0.29573858
# T = 1070  Fidelity = 0.32691921
# T = 1080  Fidelity = 0.38738689
# T = 1090  Fidelity = 0.41210373
# T = 1100  Fidelity = 0.28436524
# T = 1200  Fidelity = 0.27090209
# T = 1300  Fidelity = 0.41261705
# T = 1400  Fidelity = 0.29057655
# T = 1500  Fidelity = 0.41796596
# T = 2000  Fidelity = 0.40711987
# T = 2100  Fidelity = 0.33937882
# T = 2110  Fidelity = 0.41418648
# T = 2120  Fidelity = 0.38885636
# T = 2130  Fidelity = 0.37706084
# T = 2140  Fidelity = 0.44775816
# T = 2150  Fidelity = 0.37267312
# T = 2160  Fidelity = 0.35346509
# T = 2170  Fidelity = 0.31969614
# T = 2180  Fidelity = 0.30797943
# T = 2190  Fidelity = 0.44556868
# T = 2200  Fidelity = 0.31120897
# T = 2300  Fidelity = 0.42562406
# T = 2400  Fidelity = 0.36232129
# T = 2500  Fidelity = 0.43529849
# T = 2600  Fidelity = 0.41121741
# T = 2700  Fidelity = 0.35748515
# T = 2800  Fidelity = 0.37963636
# T = 2900  Fidelity = 0.40689411
# T = 3000  Fidelity = 0.41204260
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.38933834e-03
# P0     = 0.41204260
# P1     = 0.40448329
# P0+P1  = 0.81652589
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 9.40449540e-04
# T = 1     Fidelity = 0.04545846
# T = 2     Fidelity = 0.09514887
# T = 5     Fidelity = 0.22649885
# T = 10    Fidelity = 0.24120763
# T = 20    Fidelity = 0.26353465
# T = 30    Fidelity = 0.28697227
# T = 40    Fidelity = 0.29519386
# T = 50    Fidelity = 0.29406312
# T = 75    Fidelity = 0.31634431
# T = 100   Fidelity = 0.32191659
# T = 125   Fidelity = 0.33135906
# T = 150   Fidelity = 0.34335770
# T = 175   Fidelity = 0.34550546
# T = 200   Fidelity = 0.35505449
# T = 225   Fidelity = 0.36137093
# T = 250   Fidelity = 0.36222539
# T = 275   Fidelity = 0.37482153
# T = 300   Fidelity = 0.37363356
# T = 400   Fidelity = 0.34293214
# T = 500   Fidelity = 0.37985013
# T = 600   Fidelity = 0.42345943
# T = 700   Fidelity = 0.43307984
# T = 800   Fidelity = 0.44935988
# T = 900   Fidelity = 0.45351025
# T = 1000  Fidelity = 0.48153702
# T = 1010  Fidelity = 0.42428015
# T = 1020  Fidelity = 0.41049156
# T = 1030  Fidelity = 0.46650543
# T = 1040  Fidelity = 0.49672613
# T = 1050  Fidelity = 0.48217468
# T = 1060  Fidelity = 0.42782772
# T = 1070  Fidelity = 0.37365158
# T = 1080  Fidelity = 0.45069733
# T = 1090  Fidelity = 0.49120951
# T = 1100  Fidelity = 0.39621964
# T = 1200  Fidelity = 0.48518473
# T = 1300  Fidelity = 0.50554202
# T = 1400  Fidelity = 0.47475635
# T = 1500  Fidelity = 0.48192621
# T = 2000  Fidelity = 0.49302768
# T = 2100  Fidelity = 0.51047995
# T = 2110  Fidelity = 0.49951301
# T = 2120  Fidelity = 0.48046741
# T = 2130  Fidelity = 0.50347104
# T = 2140  Fidelity = 0.48293685
# T = 2150  Fidelity = 0.47543110
# T = 2160  Fidelity = 0.47622034
# T = 2170  Fidelity = 0.47096056
# T = 2180  Fidelity = 0.44926555
# T = 2190  Fidelity = 0.48266653
# T = 2200  Fidelity = 0.47361482
# T = 2300  Fidelity = 0.53333352
# T = 2400  Fidelity = 0.54727303
# T = 2500  Fidelity = 0.50709352
# T = 2600  Fidelity = 0.53730541
# T = 2700  Fidelity = 0.55852800
# T = 2800  Fidelity = 0.54063112
# T = 2900  Fidelity = 0.57706415
# T = 3000  Fidelity = 0.57922366
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.24416809e-03
# P0     = 0.57922366
# P1     = 0.40903227
# P0+P1  = 0.98825593
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 9.13233454e-04
# T = 1     Fidelity = 0.04801532
# T = 2     Fidelity = 0.09212748
# T = 5     Fidelity = 0.23658773
# T = 10    Fidelity = 0.26071299
# T = 20    Fidelity = 0.28622105
# T = 30    Fidelity = 0.30913706
# T = 40    Fidelity = 0.33177937
# T = 50    Fidelity = 0.34969457
# T = 75    Fidelity = 0.37000836
# T = 100   Fidelity = 0.38608198
# T = 125   Fidelity = 0.40522374
# T = 150   Fidelity = 0.41386734
# T = 175   Fidelity = 0.42404927
# T = 200   Fidelity = 0.43535393
# T = 225   Fidelity = 0.43939656
# T = 250   Fidelity = 0.44767938
# T = 275   Fidelity = 0.45594736
# T = 300   Fidelity = 0.45431556
# T = 400   Fidelity = 0.47370256
# T = 500   Fidelity = 0.45798430
# T = 600   Fidelity = 0.49603457
# T = 700   Fidelity = 0.49479342
# T = 800   Fidelity = 0.51987254
# T = 900   Fidelity = 0.52728311
# T = 1000  Fidelity = 0.49805141
# T = 1010  Fidelity = 0.52542531
# T = 1020  Fidelity = 0.50737342
# T = 1030  Fidelity = 0.50008197
# T = 1040  Fidelity = 0.52441163
# T = 1050  Fidelity = 0.52755200
# T = 1060  Fidelity = 0.50125028
# T = 1070  Fidelity = 0.53066020
# T = 1080  Fidelity = 0.52517620
# T = 1090  Fidelity = 0.53710046
# T = 1100  Fidelity = 0.52204198
# T = 1200  Fidelity = 0.52022996
# T = 1300  Fidelity = 0.53871568
# T = 1400  Fidelity = 0.50686753
# T = 1500  Fidelity = 0.54152561
# T = 2000  Fidelity = 0.56756019
# T = 2100  Fidelity = 0.58021396
# T = 2110  Fidelity = 0.57700043
# T = 2120  Fidelity = 0.57222888
# T = 2130  Fidelity = 0.56524472
# T = 2140  Fidelity = 0.57168490
# T = 2150  Fidelity = 0.57374537
# T = 2160  Fidelity = 0.58549375
# T = 2170  Fidelity = 0.57987340
# T = 2180  Fidelity = 0.56217196
# T = 2190  Fidelity = 0.57492687
# T = 2200  Fidelity = 0.56708015
# T = 2300  Fidelity = 0.54948213
# T = 2400  Fidelity = 0.59749917
# T = 2500  Fidelity = 0.58271804
# T = 2600  Fidelity = 0.50231000
# T = 2700  Fidelity = 0.54614998
# T = 2800  Fidelity = 0.54130262
# T = 2900  Fidelity = 0.55237531
# T = 3000  Fidelity = 0.47749698
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.13588693e-03
# P0     = 0.47749698
# P1     = 0.30205067
# P0+P1  = 0.77954765
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.91554516e-04
# T = 1     Fidelity = 0.04992982
# T = 2     Fidelity = 0.09016040
# T = 5     Fidelity = 0.25410014
# T = 10    Fidelity = 0.29209219
# T = 20    Fidelity = 0.33316154
# T = 30    Fidelity = 0.36077675
# T = 40    Fidelity = 0.38137852
# T = 50    Fidelity = 0.39776152
# T = 75    Fidelity = 0.42718488
# T = 100   Fidelity = 0.44697045
# T = 125   Fidelity = 0.46128256
# T = 150   Fidelity = 0.47213571
# T = 175   Fidelity = 0.48065146
# T = 200   Fidelity = 0.48731295
# T = 225   Fidelity = 0.49289586
# T = 250   Fidelity = 0.49735386
# T = 275   Fidelity = 0.50087974
# T = 300   Fidelity = 0.50347137
# T = 400   Fidelity = 0.50706962
# T = 500   Fidelity = 0.51896587
# T = 600   Fidelity = 0.51618967
# T = 700   Fidelity = 0.52563255
# T = 800   Fidelity = 0.51668555
# T = 900   Fidelity = 0.53958924
# T = 1000  Fidelity = 0.52858229
# T = 1010  Fidelity = 0.54382018
# T = 1020  Fidelity = 0.53277950
# T = 1030  Fidelity = 0.53475944
# T = 1040  Fidelity = 0.54522146
# T = 1050  Fidelity = 0.54072829
# T = 1060  Fidelity = 0.52161115
# T = 1070  Fidelity = 0.54050237
# T = 1080  Fidelity = 0.52774420
# T = 1090  Fidelity = 0.54897902
# T = 1100  Fidelity = 0.53551998
# T = 1200  Fidelity = 0.54060559
# T = 1300  Fidelity = 0.55801690
# T = 1400  Fidelity = 0.51377622
# T = 1500  Fidelity = 0.54671352
# T = 2000  Fidelity = 0.49813350
# T = 2100  Fidelity = 0.49963754
# T = 2110  Fidelity = 0.55172027
# T = 2120  Fidelity = 0.51655829
# T = 2130  Fidelity = 0.51653128
# T = 2140  Fidelity = 0.53242204
# T = 2150  Fidelity = 0.50847899
# T = 2160  Fidelity = 0.50422393
# T = 2170  Fidelity = 0.51714822
# T = 2180  Fidelity = 0.50976040
# T = 2190  Fidelity = 0.51340025
# T = 2200  Fidelity = 0.46113960
# T = 2300  Fidelity = 0.56128976
# T = 2400  Fidelity = 0.56519101
# T = 2500  Fidelity = 0.54090878
# T = 2600  Fidelity = 0.58770907
# T = 2700  Fidelity = 0.60764229
# T = 2800  Fidelity = 0.58290977
# T = 2900  Fidelity = 0.63139109
# T = 3000  Fidelity = 0.63150542
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.05026245e-03
# P0     = 0.63150542
# P1     = 0.35192301
# P0+P1  = 0.98342843
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 8.73711147e-04
# T = 1     Fidelity = 0.05400263
# T = 2     Fidelity = 0.09263383
# T = 5     Fidelity = 0.27827150
# T = 10    Fidelity = 0.33017277
# T = 20    Fidelity = 0.38721217
# T = 30    Fidelity = 0.41854573
# T = 40    Fidelity = 0.43869065
# T = 50    Fidelity = 0.45255480
# T = 75    Fidelity = 0.47378314
# T = 100   Fidelity = 0.48598776
# T = 125   Fidelity = 0.49397945
# T = 150   Fidelity = 0.49950301
# T = 175   Fidelity = 0.50337374
# T = 200   Fidelity = 0.50601558
# T = 225   Fidelity = 0.50814591
# T = 250   Fidelity = 0.50978598
# T = 275   Fidelity = 0.51127534
# T = 300   Fidelity = 0.51234069
# T = 400   Fidelity = 0.50450166
# T = 500   Fidelity = 0.51442561
# T = 600   Fidelity = 0.52793015
# T = 700   Fidelity = 0.52496888
# T = 800   Fidelity = 0.52634179
# T = 900   Fidelity = 0.52594910
# T = 1000  Fidelity = 0.52609430
# T = 1010  Fidelity = 0.54991409
# T = 1020  Fidelity = 0.54214329
# T = 1030  Fidelity = 0.54490893
# T = 1040  Fidelity = 0.55004799
# T = 1050  Fidelity = 0.52969126
# T = 1060  Fidelity = 0.55016704
# T = 1070  Fidelity = 0.55111868
# T = 1080  Fidelity = 0.52367770
# T = 1090  Fidelity = 0.53499766
# T = 1100  Fidelity = 0.54442706
# T = 1200  Fidelity = 0.54489086
# T = 1300  Fidelity = 0.52816055
# T = 1400  Fidelity = 0.53413217
# T = 1500  Fidelity = 0.53458284
# T = 2000  Fidelity = 0.56584376
# T = 2100  Fidelity = 0.58607811
# T = 2110  Fidelity = 0.60628452
# T = 2120  Fidelity = 0.59764589
# T = 2130  Fidelity = 0.60543886
# T = 2140  Fidelity = 0.61113528
# T = 2150  Fidelity = 0.60275307
# T = 2160  Fidelity = 0.60089900
# T = 2170  Fidelity = 0.59533295
# T = 2180  Fidelity = 0.60138725
# T = 2190  Fidelity = 0.61169581
# T = 2200  Fidelity = 0.60310656
# T = 2300  Fidelity = 0.61091733
# T = 2400  Fidelity = 0.62022661
# T = 2500  Fidelity = 0.62178027
# T = 2600  Fidelity = 0.58962579
# T = 2700  Fidelity = 0.62942304
# T = 2800  Fidelity = 0.61503966
# T = 2900  Fidelity = 0.64332155
# T = 3000  Fidelity = 0.62811578
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.78208763e-04
# P0     = 0.62811578
# P1     = 0.33645544
# P0+P1  = 0.96457121
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 8.58553719e-04
# T = 1     Fidelity = 0.05944839
# T = 2     Fidelity = 0.09781383
# T = 5     Fidelity = 0.30530139
# T = 10    Fidelity = 0.36763119
# T = 20    Fidelity = 0.42481418
# T = 30    Fidelity = 0.45335905
# T = 40    Fidelity = 0.47229656
# T = 50    Fidelity = 0.48548686
# T = 75    Fidelity = 0.50047829
# T = 100   Fidelity = 0.50471310
# T = 125   Fidelity = 0.50875739
# T = 150   Fidelity = 0.51148681
# T = 175   Fidelity = 0.51288854
# T = 200   Fidelity = 0.51494033
# T = 225   Fidelity = 0.51635618
# T = 250   Fidelity = 0.51736010
# T = 275   Fidelity = 0.51898873
# T = 300   Fidelity = 0.51945304
# T = 400   Fidelity = 0.51633288
# T = 500   Fidelity = 0.52384133
# T = 600   Fidelity = 0.53271581
# T = 700   Fidelity = 0.53804731
# T = 800   Fidelity = 0.53844674
# T = 900   Fidelity = 0.54820179
# T = 1000  Fidelity = 0.53194231
# T = 1010  Fidelity = 0.55535648
# T = 1020  Fidelity = 0.53910902
# T = 1030  Fidelity = 0.56099623
# T = 1040  Fidelity = 0.54122026
# T = 1050  Fidelity = 0.55550518
# T = 1060  Fidelity = 0.54628601
# T = 1070  Fidelity = 0.54122401
# T = 1080  Fidelity = 0.53830814
# T = 1090  Fidelity = 0.55048029
# T = 1100  Fidelity = 0.55872895
# T = 1200  Fidelity = 0.54335906
# T = 1300  Fidelity = 0.53259806
# T = 1400  Fidelity = 0.53462094
# T = 1500  Fidelity = 0.54816651
# T = 2000  Fidelity = 0.60204418
# T = 2100  Fidelity = 0.60568552
# T = 2110  Fidelity = 0.60850136
# T = 2120  Fidelity = 0.61928207
# T = 2130  Fidelity = 0.61519809
# T = 2140  Fidelity = 0.62183154
# T = 2150  Fidelity = 0.59122317
# T = 2160  Fidelity = 0.60019432
# T = 2170  Fidelity = 0.61719705
# T = 2180  Fidelity = 0.60737962
# T = 2190  Fidelity = 0.61962114
# T = 2200  Fidelity = 0.61416522
# T = 2300  Fidelity = 0.62371486
# T = 2400  Fidelity = 0.62243138
# T = 2500  Fidelity = 0.63147466
# T = 2600  Fidelity = 0.63226820
# T = 2700  Fidelity = 0.59250921
# T = 2800  Fidelity = 0.61615957
# T = 2900  Fidelity = 0.63220314
# T = 3000  Fidelity = 0.65571560
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.17642281e-04
# P0     = 0.65571560
# P1     = 0.32653142
# P0+P1  = 0.98224702
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99351122
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.89712392
# T = 2     Fidelity = 0.95265783
# T = 5     Fidelity = 0.98531775
# T = 10    Fidelity = 0.99485743
#
# Minimum T for Fidelity >= 0.99 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.31621635e+00
# T = 1     Fidelity = 0.10107260
# T = 2     Fidelity = 0.29752384
# T = 5     Fidelity = 0.80706304
# T = 10    Fidelity = 0.99298221
#
# Minimum T for Fidelity >= 0.99 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.40805723e+00
# T = 1     Fidelity = 0.13263673
# T = 2     Fidelity = 0.37848659
# T = 5     Fidelity = 0.80796055
# T = 10    Fidelity = 0.92117247
# T = 20    Fidelity = 0.99607909
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.23645352
# T = 2     Fidelity = 0.53326254
# T = 5     Fidelity = 0.91879597
# T = 10    Fidelity = 0.98337758
# T = 20    Fidelity = 0.99329957
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.30529366
# T = 2     Fidelity = 0.59379585
# T = 5     Fidelity = 0.91579991
# T = 10    Fidelity = 0.98267113
# T = 20    Fidelity = 0.99367838
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.36139818
# T = 2     Fidelity = 0.63582923
# T = 5     Fidelity = 0.93294782
# T = 10    Fidelity = 0.98447959
# T = 20    Fidelity = 0.99497341
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.40228414
# T = 2     Fidelity = 0.65979948
# T = 5     Fidelity = 0.93959291
# T = 10    Fidelity = 0.98300212
# T = 20    Fidelity = 0.99625271
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.43975783
# T = 2     Fidelity = 0.68166940
# T = 5     Fidelity = 0.94415261
# T = 10    Fidelity = 0.98200955
# T = 20    Fidelity = 0.99727483
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.47164178
# T = 2     Fidelity = 0.69848601
# T = 5     Fidelity = 0.94941506
# T = 10    Fidelity = 0.98131456
# T = 20    Fidelity = 0.99820084
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     None      0.9788009103      3.07240439e-04    0.702485    0.0         0.702485
# Symmetric      0.311     175       0.9975522833      1.17908350e-06    None        None        None
# Symmetric      0.522     125       0.9959571016      2.94880930e-07    None        None        None
# Symmetric      0.733     100       0.9998450180      1.58119033e-07    None        None        None
# Symmetric      0.944     75        0.9978313766      6.89654582e-08    None        None        None
# Symmetric      1.156     50        0.9960843462      1.17592584e-07    None        None        None
# Symmetric      1.367     50        0.9913346169      2.47961127e-07    None        None        None
# Symmetric      1.578     50        0.9947554909      3.56990589e-07    None        None        None
# Symmetric      1.789     40        0.9938365126      2.45005899e-06    None        None        None
# Symmetric      2.000     40        0.9999220422      1.44257094e-05    None        None        None
# Weak SSB optimised0.100     None      0.9896085429      8.67181393e-01    0.946129    0.02854     0.974668
# Weak SSB optimised0.311     None      0.9863129415      5.19764834e-01    0.96767     0.016884    0.984554
# Weak SSB optimised0.522     20        0.9931594083      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     20        0.9991735013      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     20        0.9942264330      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     125       0.9912410592      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     1020      0.9915466736      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     900       0.9939635216      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     1020      0.9946530940      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     225       0.9910610091      2.48783584e-01    None        None        None
# Weak SSB       0.100     150       0.9904368657      1.81947687e-02    None        None        None
# Weak SSB       0.311     None      0.9888405839      1.51771385e-02    0.93717     4.4e-05     0.937214
# Weak SSB       0.522     None      0.4967340930      1.05614584e-03    0.083504    0.414184    0.497688
# Weak SSB       0.733     None      0.3565351657      1.07018746e-03    0.232438    0.244562    0.477
# Weak SSB       0.944     None      0.4477581623      9.80171521e-04    0.412043    0.404483    0.816526
# Weak SSB       1.156     None      0.5792236643      9.40449540e-04    0.579224    0.409032    0.988256
# Weak SSB       1.367     None      0.5974991683      9.13233454e-04    0.477497    0.302051    0.779548
# Weak SSB       1.578     None      0.6315054199      8.91554516e-04    0.631505    0.351923    0.983428
# Weak SSB       1.789     None      0.6433215548      8.73711147e-04    0.628116    0.336455    0.964571
# Weak SSB       2.000     None      0.6557156048      8.58553719e-04    0.655716    0.326531    0.982247
# Strong SSB     0.100     1         0.9935112225      3.59472102e+00    None        None        None
# Strong SSB     0.311     10        0.9948574344      1.58498916e+00    None        None        None
# Strong SSB     0.522     10        0.9929822090      1.31621635e+00    None        None        None
# Strong SSB     0.733     20        0.9960790874      1.40805723e+00    None        None        None
# Strong SSB     0.944     20        0.9932995730      1.38481786e+00    None        None        None
# Strong SSB     1.156     20        0.9936783827      1.34302163e+00    None        None        None
# Strong SSB     1.367     20        0.9949734140      1.29217279e+00    None        None        None
# Strong SSB     1.578     20        0.9962527069      1.23335459e+00    None        None        None
# Strong SSB     1.789     20        0.9972748282      1.17426012e+00    None        None        None
# Strong SSB     2.000     20        0.9982008419      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.1556
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7333

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ', color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
