# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 0.00005

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722526063296
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Hamiltonian Variational Ansatz (Improved Asymmetric HVA)
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector 
from qiskit_algorithms import VQE 
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B
# ============================================================
# Physics-inspired HVA for mI² < 0
# ============================================================

def grouped_hva_asymm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):

        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 3*nq + 3

    params = ParameterVector(
        "θ",
        nparams_per_layer * layers
    )

    for l in range(layers):

        offset = l * nparams_per_layer

        θx  = params[offset : offset+nq]

        θy  = params[offset+nq : offset+2*nq]

        θz  = params[offset+2*nq : offset+3*nq]

        θxx = params[offset+3*nq]

        θyy = params[offset+3*nq+1]

        θzz = params[offset+3*nq+2]

        # ----------------------------------------------------
        # RX sector
        # ----------------------------------------------------

        for q in range(nq):

            qc.rx(2*θx[q], q)

        # ----------------------------------------------------
        # RY sector
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(2*θy[q], q)

        # ----------------------------------------------------
        # RZ sector
        # ----------------------------------------------------

        for q in range(nq):

            qc.rz(2*θz[q], q)

        # ----------------------------------------------------
        # XX sector
        # ----------------------------------------------------

        for q in range(0, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        # ----------------------------------------------------
        # YY sector
        # ----------------------------------------------------

        for q in range(0, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        for q in range(1, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        # ----------------------------------------------------
        # ZZ sector
        # ----------------------------------------------------

        for q in range(0, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

    return qc

# %%
# ============================================================
# Hamiltonian Variational Ansatz (Improved HVA)
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector

# ============================================================
# Physics-inspired HVA
# ============================================================

def grouped_hva_symm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    # RX, RY, RZ on every qubit
    # one shared XX, YY, ZZ angle

    nparams_per_layer = 3*nq + 3

    params = ParameterVector(
        "θ",
        nparams_per_layer * layers
    )

    for l in range(layers):

        offset = l * nparams_per_layer

        θx  = params[offset : offset+nq]

        θy  = params[offset+nq : offset+2*nq]

        θz  = params[offset+2*nq : offset+3*nq]

        θxx = params[offset+3*nq]

        θyy = params[offset+3*nq+1]

        θzz = params[offset+3*nq+2]

        # ====================================================
        # X rotations
        # ====================================================

        for q in range(nq):

            qc.rx(2*θx[q], q)

        # ====================================================
        # Y rotations
        # ====================================================

        for q in range(nq):

            qc.ry(2*θy[q], q)

        # ====================================================
        # Z rotations
        # ====================================================

        for q in range(nq):

            qc.rz(2*θz[q], q)

        # ====================================================
        # XX block
        # ====================================================

        for q in range(0, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        # ====================================================
        # YY block
        # ====================================================

        for q in range(0, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        for q in range(1, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        # ====================================================
        # ZZ block
        # ====================================================

        for q in range(0, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

    return qc

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Multi-parameter scan
# HVA + warm-start continuation + overlap tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0

# Default depth
layers = 4

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
  {
       "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-4
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#" * 80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#" * 80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "=" * 60)
        print(f"Running λ = {lam:.3f}")
        print("=" * 60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(
            Hloc_sparse
        )

        # ----------------------------------------------------
        # Dense Hamiltonian
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(
            H_op
        )

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ====================================================
        # Adaptive depth near critical region
        # ====================================================

        

        # ====================================================
        # Ansatz
        # ====================================================

        if mI2 < 0:

            ansatz = grouped_hva_asymm(
                nq=nqubits,
                layers=layers
            )

        else:

            ansatz = grouped_hva_symm(
                nq=nqubits,
                layers=layers
            )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)



        
        # ====================================================
        # Weak SSB:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )
        # ====================================================
        # Weak SSB optimized:
        # warm-start + overlap tracking
        # ====================================================

        
        # ====================================================
        # Symmetric + Strong SSB
        # ====================================================

        else:

            print(
                "\nRunning ordinary HVA-VQE...\n"
            )

            initial_point = (
                0.01 * np.random.randn(
                    ansatz.num_parameters
                )
            )

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = (
                vqe.compute_minimum_eigenvalue(
                    H_pauli_shifted
                )
            )

            best_energy = (
                result.eigenvalue.real
                + identity_shift
            )

            optimal_circuit = (
                ansatz.assign_parameters(
                    result.optimal_parameters
                )
            )

            best_state = (
                Statevector.from_instruction(
                    optimal_circuit
                ).data
            )

            best_fidelity = np.abs(
                np.vdot(
                    psi_exact,
                    best_state
                )
            )**2

            best_overlap = 1.0

        # ====================================================
        # Final VQE data
        # ====================================================

        E_vqe = best_energy
        F = best_fidelity

        # ====================================================
        # Store results
        # ====================================================

        data = {

            "case": label,

            "lambda": lam,

            "mI2": mI2,

            "f": f,
            'psi_vqe': best_state,

            "E_exact": E_exact,

            "E_vqe": E_vqe,

            "error": abs(
                E_exact - E_vqe
            ),

            "fidelity": F,

            "tracking_overlap": best_overlap,

            "layers": layers
        }

        case_results.append(data)
        all_results.append(data)

        # ====================================================
        # Print
        # ====================================================

        print("\nFINAL SELECTED STATE")

        print(
            f"Exact energy     : "
            f"{E_exact:.12f}"
        )

        print(
            f"VQE energy       : "
            f"{E_vqe:.12f}"
        )

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(
            f"Fidelity         : "
            f"{F:.12f}"
        )

        print(
            f"Tracking overlap : "
            f"{best_overlap:.12f}"
        )

        print(
            f"Layers            : "
            f"{layers}"
        )

        print(
            f"Pauli terms       : "
            f"{len(H_pauli_shifted.paulis)}"
        )

    # ========================================================
    # Summary
    # ========================================================

    print("\n")
    print("=" * 140)
    print(f"SUMMARY : {label}")
    print("=" * 140)

    print(
        f"{'lambda':<12}"
        f"{'Exact E':<20}"
        f"{'VQE E':<20}"
        f"{'Error':<18}"
        f"{'Fidelity':<18}"
        f"{'TrackOverlap':<18}"
        f"{'Layers':<10}"
    )

    print("=" * 140)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
            f"{r['E_vqe']:<20.10f}"
            f"{r['error']:<18.4e}"
            f"{r['fidelity']:<18.10f}"
            f"{r['tracking_overlap']:<18.10f}"
            f"{r['layers']:<10}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running ordinary HVA-VQE...
# /home/semin/jupyter/qiskit_env/lib/python3.12/site-packages/qiskit_algorithms/optimizers/scipy_optimizer.py:162: OptimizeWarning: Unknown solver options: iprint
#   raw_result = minimize(
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161838975
# Energy error     : 1.108164e-07
# Fidelity         : 0.999999980199
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 106
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641603419
# Energy error     : 1.760722e-07
# Fidelity         : 0.999999964969
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030500001496
# Energy error     : 6.917019e-07
# Fidelity         : 0.999999813121
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041827883944
# Energy error     : 3.561683e-06
# Fidelity         : 0.999999244979
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052687322807
# Energy error     : 2.779046e-06
# Fidelity         : 0.999999500023
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063141096591
# Energy error     : 7.307820e-06
# Fidelity         : 0.999998391957
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073232572899
# Energy error     : 1.691913e-05
# Fidelity         : 0.999997108143
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082988214465
# Energy error     : 2.206265e-05
# Fidelity         : 0.999995595890
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092424728524
# Energy error     : 9.220417e-06
# Fidelity         : 0.999998750407
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101635576257
# Energy error     : 4.614751e-05
# Fidelity         : 0.999991299888
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
#
# ============================================================================================================================================
# SUMMARY : Symmetric
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      1.0061617282        1.0061618390        1.1082e-07        0.9999999802      1.0000000000      4
# 0.3111      1.0186414273        1.0186416034        1.7607e-07        0.9999999650      1.0000000000      4
# 0.5222      1.0304993098        1.0305000015        6.9170e-07        0.9999998131      1.0000000000      4
# 0.7333      1.0418243223        1.0418278839        3.5617e-06        0.9999992450      1.0000000000      4
# 0.9444      1.0526845438        1.0526873228        2.7790e-06        0.9999995000      1.0000000000      4
# 1.1556      1.0631337888        1.0631410966        7.3078e-06        0.9999983920      1.0000000000      4
# 1.3667      1.0732156538        1.0732325729        1.6919e-05        0.9999971081      1.0000000000      4
# 1.5778      1.0829661518        1.0829882145        2.2063e-05        0.9999955959      1.0000000000      4
# 1.7889      1.0924155081        1.0924247285        9.2204e-06        0.9999987504      1.0000000000      4
# 2.0000      1.1015894287        1.1016355763        4.6148e-05        0.9999912999      1.0000000000      4
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.036570736476
# Fidelity = 0.996818265835
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -17.050941649764
# Fidelity = 0.998315031195
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -17.049118093339
# Fidelity = 0.998099637306
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -17.049806497605
# Fidelity = 0.998592754405
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -17.049610461350
# Fidelity = 0.997731714920
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.050941649764
# Energy error     : 1.375170e-02
# Fidelity         : 0.998315031195
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.061964480737
# Fidelity = 0.991413990020
# Overlap  = 0.817425396279
#
# Restart 1
# Energy   = -9.051802230998
# Fidelity = 0.988563751420
# Overlap  = 0.816256218884
#
# Restart 2
# Energy   = -9.063684714028
# Fidelity = 0.993311306303
# Overlap  = 0.818996861601
#
# Restart 3
# Energy   = -9.062916233626
# Fidelity = 0.992074825475
# Overlap  = 0.818486512792
#
# Restart 4
# Energy   = -9.057033998741
# Fidelity = 0.990119960300
# Overlap  = 0.819558383306
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.063684714028
# Energy error     : 1.676520e-02
# Fidelity         : 0.993311306303
# Tracking overlap : 0.818996861601
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.688021423935
# Fidelity = 0.995579809251
# Overlap  = 0.064016017680
#
# Restart 1
# Energy   = -4.672141976222
# Fidelity = 0.984184740219
# Overlap  = 0.068775666321
#
# Restart 2
# Energy   = -4.676571152481
# Fidelity = 0.987541564203
# Overlap  = 0.067841905291
#
# Restart 3
# Energy   = -4.673666201771
# Fidelity = 0.989419948572
# Overlap  = 0.067427188056
#
# Restart 4
# Energy   = -4.683421639685
# Fidelity = 0.993003102733
# Overlap  = 0.066349757970
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.688021423935
# Energy error     : 1.317355e-02
# Fidelity         : 0.995579809251
# Tracking overlap : 0.064016017680
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.003416010101
# Fidelity = 0.997337020568
# Overlap  = 0.656234169263
#
# Restart 1
# Energy   = -2.996819803560
# Fidelity = 0.993038929228
# Overlap  = 0.654986784430
#
# Restart 2
# Energy   = -2.999724803271
# Fidelity = 0.993087297417
# Overlap  = 0.649482310436
#
# Restart 3
# Energy   = -2.997385247749
# Fidelity = 0.995004454293
# Overlap  = 0.643595019600
#
# Restart 4
# Energy   = -2.987685198828
# Fidelity = 0.986032395684
# Overlap  = 0.647002149354
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.003416010101
# Energy error     : 8.115342e-03
# Fidelity         : 0.997337020568
# Tracking overlap : 0.656234169263
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.078688979189
# Fidelity = 0.998711890689
# Overlap  = 0.830766474342
#
# Restart 1
# Energy   = -2.069601202224
# Fidelity = 0.993239313657
# Overlap  = 0.825044404580
#
# Restart 2
# Energy   = -2.067947587308
# Fidelity = 0.992571935009
# Overlap  = 0.825712727077
#
# Restart 3
# Energy   = -2.068828759053
# Fidelity = 0.992045622884
# Overlap  = 0.828666083159
#
# Restart 4
# Energy   = -2.067181842646
# Fidelity = 0.989028036745
# Overlap  = 0.828095149542
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.078688979189
# Energy error     : 4.876744e-03
# Fidelity         : 0.998711890689
# Tracking overlap : 0.830766474342
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.502891506460
# Fidelity = 0.999601822731
# Overlap  = 0.898718785869
#
# Restart 1
# Energy   = -1.493691774744
# Fidelity = 0.992424596870
# Overlap  = 0.882008328582
#
# Restart 2
# Energy   = -1.493870683179
# Fidelity = 0.994558044984
# Overlap  = 0.886283897309
#
# Restart 3
# Energy   = -1.490419533111
# Fidelity = 0.989208793132
# Overlap  = 0.877902981662
#
# Restart 4
# Energy   = -1.489359128946
# Fidelity = 0.988670073843
# Overlap  = 0.876358500750
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.502891506460
# Energy error     : 1.596366e-03
# Fidelity         : 0.999601822731
# Tracking overlap : 0.898718785869
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118240074606
# Fidelity = 0.999845271607
# Overlap  = 0.920783013331
#
# Restart 1
# Energy   = -1.112365390483
# Fidelity = 0.995876739577
# Overlap  = 0.903383145932
#
# Restart 2
# Energy   = -1.109934711010
# Fidelity = 0.993400115284
# Overlap  = 0.898063058991
#
# Restart 3
# Energy   = -1.110226824037
# Fidelity = 0.995395927117
# Overlap  = 0.903638408722
#
# Restart 4
# Energy   = -1.113041826256
# Fidelity = 0.996813093762
# Overlap  = 0.909616483084
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118240074606
# Energy error     : 8.596558e-04
# Fidelity         : 0.999845271607
# Tracking overlap : 0.920783013331
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.852775810433
# Fidelity = 0.999918485930
# Overlap  = 0.937459591128
#
# Restart 1
# Energy   = -0.848663644402
# Fidelity = 0.996895153730
# Overlap  = 0.920096589133
#
# Restart 2
# Energy   = -0.848471539199
# Fidelity = 0.996898477145
# Overlap  = 0.921074721170
#
# Restart 3
# Energy   = -0.845129452465
# Fidelity = 0.995593161016
# Overlap  = 0.919297800807
#
# Restart 4
# Energy   = -0.848211085531
# Fidelity = 0.996672399337
# Overlap  = 0.921269860563
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.852775810433
# Energy error     : 5.562436e-04
# Fidelity         : 0.999918485930
# Tracking overlap : 0.937459591128
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663217554878
# Fidelity = 0.999954777007
# Overlap  = 0.960002872296
#
# Restart 1
# Energy   = -0.659176950947
# Fidelity = 0.997141623633
# Overlap  = 0.945017494184
#
# Restart 2
# Energy   = -0.659274181654
# Fidelity = 0.997921917360
# Overlap  = 0.948095675742
#
# Restart 3
# Energy   = -0.659635151180
# Fidelity = 0.997223664077
# Overlap  = 0.945380432864
#
# Restart 4
# Energy   = -0.658076078563
# Fidelity = 0.996920191595
# Overlap  = 0.943956129888
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663217554878
# Energy error     : 3.425867e-04
# Fidelity         : 0.999954777007
# Tracking overlap : 0.960002872296
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.521943655492
# Fidelity = 0.999979872391
# Overlap  = 0.975828218475
#
# Restart 1
# Energy   = -0.519472005699
# Fidelity = 0.998533520042
# Overlap  = 0.967541190991
#
# Restart 2
# Energy   = -0.519569467900
# Fidelity = 0.998759262043
# Overlap  = 0.968713370018
#
# Restart 3
# Energy   = -0.520482105667
# Fidelity = 0.999427462945
# Overlap  = 0.971782493207
#
# Restart 4
# Energy   = -0.520373709276
# Fidelity = 0.999458564820
# Overlap  = 0.972490799032
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.521943655492
# Energy error     : 1.961088e-04
# Fidelity         : 0.999979872391
# Tracking overlap : 0.975828218475
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB optimised
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -17.0646933519      -17.0509416498      1.3752e-02        0.9983150312      1.0000000000      4
# 0.3111      -9.0804499123       -9.0636847140       1.6765e-02        0.9933113063      0.8189968616      4
# 0.5222      -4.7011949726       -4.6880214239       1.3174e-02        0.9955798093      0.0640160177      4
# 0.7333      -3.0115313516       -3.0034160101       8.1153e-03        0.9973370206      0.6562341693      4
# 0.9444      -2.0835657235       -2.0786889792       4.8767e-03        0.9987118907      0.8307664743      4
# 1.1556      -1.5044878727       -1.5028915065       1.5964e-03        0.9996018227      0.8987187859      4
# 1.3667      -1.1190997304       -1.1182400746       8.5966e-04        0.9998452716      0.9207830133      4
# 1.5778      -0.8533320540       -0.8527758104       5.5624e-04        0.9999184859      0.9374595911      4
# 1.7889      -0.6635601415       -0.6632175549       3.4259e-04        0.9999547770      0.9600028723      4
# 2.0000      -0.5221397643       -0.5219436555       1.9611e-04        0.9999798724      0.9758282185      4
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 0.0001
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.936453200262
# Fidelity = 0.999350889379
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.881649771597
# Fidelity = 0.991872928062
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.917437593243
# Fidelity = 0.997278775679
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.926446629814
# Fidelity = 0.998126265330
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.920827486890
# Fidelity = 0.997494923631
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902685020
# VQE energy       : -16.936453200262
# Energy error     : 7.449485e-03
# Fidelity         : 0.999350889379
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 158
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.890005841634
# Fidelity = 0.999213099563
# Overlap  = 0.874621845145
#
# Restart 1
# Energy   = -8.876678549481
# Fidelity = 0.994643042732
# Overlap  = 0.879502325526
#
# Restart 2
# Energy   = -8.881250560683
# Fidelity = 0.996078923659
# Overlap  = 0.878509575855
#
# Restart 3
# Energy   = -8.876983469614
# Fidelity = 0.995948953365
# Overlap  = 0.880219943629
#
# Restart 4
# Energy   = -8.875804207388
# Fidelity = 0.994771178418
# Overlap  = 0.898448868825
#
# FINAL SELECTED STATE
# Exact energy     : -8.892069658534
# VQE energy       : -8.890005841634
# Energy error     : 2.063817e-03
# Fidelity         : 0.999213099563
# Tracking overlap : 0.874621845145
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.378658551206
# Fidelity = 0.820257236264
# Overlap  = 0.048605086231
#
# Restart 1
# Energy   = -4.369864201418
# Fidelity = 0.076303968646
# Overlap  = 0.000628139514
#
# Restart 2
# Energy   = -4.368103645658
# Fidelity = 0.126255177267
# Overlap  = 0.002449147392
#
# Restart 3
# Energy   = -4.367680256808
# Fidelity = 0.028783478494
# Overlap  = 0.000023934845
#
# Restart 4
# Energy   = -4.367177485770
# Fidelity = 0.012301654017
# Overlap  = 0.000002718015
#
# FINAL SELECTED STATE
# Exact energy     : -4.379329565434
# VQE energy       : -4.378658551206
# Energy error     : 6.710142e-04
# Fidelity         : 0.820257236264
# Tracking overlap : 0.048605086231
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.741424552417
# Fidelity = 0.000052563028
# Overlap  = 0.659820954480
#
# Restart 1
# Energy   = -2.744236132878
# Fidelity = 0.917711577127
# Overlap  = 0.000654128256
#
# Restart 2
# Energy   = -2.746547489758
# Fidelity = 0.970165260641
# Overlap  = 0.000378665690
#
# Restart 3
# Energy   = -2.747312110960
# Fidelity = 0.991917481444
# Overlap  = 0.000010964603
#
# Restart 4
# Energy   = -2.744557427599
# Fidelity = 0.925192047225
# Overlap  = 0.000233199557
#
# FINAL SELECTED STATE
# Exact energy     : -2.749826501443
# VQE energy       : -2.746547489758
# Energy error     : 3.279012e-03
# Fidelity         : 0.970165260641
# Tracking overlap : 0.000378665690
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874422614774
# Fidelity = 0.998515655960
# Overlap  = 0.796251910883
#
# Restart 1
# Energy   = -1.871862496178
# Fidelity = 0.983339144404
# Overlap  = 0.736617414348
#
# Restart 2
# Energy   = -1.873598055185
# Fidelity = 0.998360266602
# Overlap  = 0.788155979009
#
# Restart 3
# Energy   = -1.873479021416
# Fidelity = 0.992273199940
# Overlap  = 0.754341286985
#
# Restart 4
# Energy   = -1.871896823809
# Fidelity = 0.988603491861
# Overlap  = 0.758956399050
#
# FINAL SELECTED STATE
# Exact energy     : -1.874705890824
# VQE energy       : -1.874422614774
# Energy error     : 2.832761e-04
# Fidelity         : 0.998515655960
# Tracking overlap : 0.796251910883
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348695137948
# Fidelity = 0.999258396969
# Overlap  = 0.890896047677
#
# Restart 1
# Energy   = -1.346059135141
# Fidelity = 0.988599084924
# Overlap  = 0.882344359398
#
# Restart 2
# Energy   = -1.348346907099
# Fidelity = 0.999537023501
# Overlap  = 0.894611475413
#
# Restart 3
# Energy   = -1.348378687272
# Fidelity = 0.999238893066
# Overlap  = 0.892662581655
#
# Restart 4
# Energy   = -1.348045122027
# Fidelity = 0.999623200455
# Overlap  = 0.893682919414
#
# FINAL SELECTED STATE
# Exact energy     : -1.348823187245
# VQE energy       : -1.348346907099
# Energy error     : 4.762801e-04
# Fidelity         : 0.999537023501
# Tracking overlap : 0.894611475413
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.009271553352
# Fidelity = 0.998478874841
# Overlap  = 0.935896687698
#
# Restart 1
# Energy   = -1.007660800840
# Fidelity = 0.997777815399
# Overlap  = 0.931471655977
#
# Restart 2
# Energy   = -1.009537391382
# Fidelity = 0.998185277114
# Overlap  = 0.936437180119
#
# Restart 3
# Energy   = -1.008369122576
# Fidelity = 0.998424972493
# Overlap  = 0.935554983573
#
# Restart 4
# Energy   = -1.009481168045
# Fidelity = 0.999075285081
# Overlap  = 0.936225890829
#
# FINAL SELECTED STATE
# Exact energy     : -1.010440164101
# VQE energy       : -1.009537391382
# Energy error     : 9.027727e-04
# Fidelity         : 0.998185277114
# Tracking overlap : 0.936437180119
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.778741301045
# Fidelity = 0.999603237061
# Overlap  = 0.962029192390
#
# Restart 1
# Energy   = -0.776244569014
# Fidelity = 0.997690595285
# Overlap  = 0.958346452021
#
# Restart 2
# Energy   = -0.777770453715
# Fidelity = 0.999116614343
# Overlap  = 0.960397767003
#
# Restart 3
# Energy   = -0.776900218013
# Fidelity = 0.996640584963
# Overlap  = 0.957498403359
#
# Restart 4
# Energy   = -0.776774909739
# Fidelity = 0.998750009894
# Overlap  = 0.958518990521
#
# FINAL SELECTED STATE
# Exact energy     : -0.779140149474
# VQE energy       : -0.778741301045
# Energy error     : 3.988484e-04
# Fidelity         : 0.999603237061
# Tracking overlap : 0.962029192390
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611493640830
# Fidelity = 0.999857327279
# Overlap  = 0.977583272709
#
# Restart 1
# Energy   = -0.610147312962
# Fidelity = 0.999367101643
# Overlap  = 0.975870460024
#
# Restart 2
# Energy   = -0.609429240562
# Fidelity = 0.998251852189
# Overlap  = 0.973403336678
#
# Restart 3
# Energy   = -0.609756182884
# Fidelity = 0.998583198449
# Overlap  = 0.974492317587
#
# Restart 4
# Energy   = -0.610219329277
# Fidelity = 0.999315595268
# Overlap  = 0.975886142320
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723602270
# VQE energy       : -0.611493640830
# Energy error     : 2.299614e-04
# Fidelity         : 0.999857327279
# Tracking overlap : 0.977583272709
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484155600657
# Fidelity = 0.999922625604
# Overlap  = 0.986479609398
#
# Restart 1
# Energy   = -0.483299341488
# Fidelity = 0.999786670144
# Overlap  = 0.985352120761
#
# Restart 2
# Energy   = -0.483449980220
# Fidelity = 0.999859907312
# Overlap  = 0.985749851181
#
# Restart 3
# Energy   = -0.482586961678
# Fidelity = 0.999453157670
# Overlap  = 0.984904418507
#
# Restart 4
# Energy   = -0.482637817746
# Fidelity = 0.998837215539
# Overlap  = 0.984232465192
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295546782
# VQE energy       : -0.484155600657
# Energy error     : 1.399461e-04
# Fidelity         : 0.999922625604
# Tracking overlap : 0.986479609398
# Layers            : 4
# Pauli terms       : 160
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9439026850      -16.9364532003      7.4495e-03        0.9993508894      1.0000000000      4
# 0.3111      -8.8920696585       -8.8900058416       2.0638e-03        0.9992130996      0.8746218451      4
# 0.5222      -4.3793295654       -4.3786585512       6.7101e-04        0.8202572363      0.0486050862      4
# 0.7333      -2.7498265014       -2.7465474898       3.2790e-03        0.9701652606      0.0003786657      4
# 0.9444      -1.8747058908       -1.8744226148       2.8328e-04        0.9985156560      0.7962519109      4
# 1.1556      -1.3488231872       -1.3483469071       4.7628e-04        0.9995370235      0.8946114754      4
# 1.3667      -1.0104401641       -1.0095373914       9.0277e-04        0.9981852771      0.9364371801      4
# 1.5778      -0.7791401495       -0.7787413010       3.9885e-04        0.9996032371      0.9620291924      4
# 1.7889      -0.6117236023       -0.6114936408       2.2996e-04        0.9998573273      0.9775832727      4
# 2.0000      -0.4842955468       -0.4841556007       1.3995e-04        0.9999226256      0.9864796094      4
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.752995090999
# Fidelity = 0.997869069969
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -20.748692659346
# Fidelity = 0.997758335661
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -20.749708513843
# Fidelity = 0.997507704256
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -20.730288655886
# Fidelity = 0.995539250560
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -20.750252018755
# Fidelity = 0.997457884599
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.752995090999
# Energy error     : 2.433335e-02
# Fidelity         : 0.997869069969
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.816214021000
# Fidelity = 0.997201622385
# Overlap  = 0.853345330786
#
# Restart 1
# Energy   = -12.810452338409
# Fidelity = 0.995568925996
# Overlap  = 0.852825475212
#
# Restart 2
# Energy   = -12.807815839894
# Fidelity = 0.995420853315
# Overlap  = 0.857795732584
#
# Restart 3
# Energy   = -12.802874565590
# Fidelity = 0.995347291435
# Overlap  = 0.857485053345
#
# Restart 4
# Energy   = -12.816559813541
# Fidelity = 0.997065614765
# Overlap  = 0.854309147436
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.816559813541
# Energy error     : 1.988133e-02
# Fidelity         : 0.997065614765
# Tracking overlap : 0.854309147436
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.687621493916
# Fidelity = 0.992074468881
# Overlap  = 0.167613800939
#
# Restart 1
# Energy   = -7.680494578487
# Fidelity = 0.991323949982
# Overlap  = 0.170678033850
#
# Restart 2
# Energy   = -7.684161416181
# Fidelity = 0.991408267249
# Overlap  = 0.161484485080
#
# Restart 3
# Energy   = -7.687239730900
# Fidelity = 0.992253055644
# Overlap  = 0.162215073736
#
# Restart 4
# Energy   = -7.702258832678
# Fidelity = 0.995716242966
# Overlap  = 0.159228892239
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.702258832678
# Energy error     : 2.845753e-02
# Fidelity         : 0.995716242966
# Tracking overlap : 0.159228892239
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.524085024770
# Fidelity = 0.997807936990
# Overlap  = 0.646848050531
#
# Restart 1
# Energy   = -5.522230125816
# Fidelity = 0.996910232549
# Overlap  = 0.659790061191
#
# Restart 2
# Energy   = -5.524368897587
# Fidelity = 0.997944381994
# Overlap  = 0.647260547402
#
# Restart 3
# Energy   = -5.524829605039
# Fidelity = 0.997822952802
# Overlap  = 0.648969112826
#
# Restart 4
# Energy   = -5.521705434260
# Fidelity = 0.997259144919
# Overlap  = 0.637007093391
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.524829605039
# Energy error     : 1.331923e-02
# Fidelity         : 0.997822952802
# Tracking overlap : 0.648969112826
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.270504143506
# Fidelity = 0.999279298053
# Overlap  = 0.825377752107
#
# Restart 1
# Energy   = -4.260509222754
# Fidelity = 0.997350045737
# Overlap  = 0.811534430306
#
# Restart 2
# Energy   = -4.243924982134
# Fidelity = 0.993511843910
# Overlap  = 0.813623652528
#
# Restart 3
# Energy   = -4.258379430322
# Fidelity = 0.997217093701
# Overlap  = 0.816238138421
#
# Restart 4
# Energy   = -4.260245759819
# Fidelity = 0.997578202821
# Overlap  = 0.814643518481
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.270504143506
# Energy error     : 5.509649e-03
# Fidelity         : 0.999279298053
# Tracking overlap : 0.825377752107
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.445486684767
# Fidelity = 0.999647475417
# Overlap  = 0.903986156852
#
# Restart 1
# Energy   = -3.427062289557
# Fidelity = 0.995808201249
# Overlap  = 0.898434533372
#
# Restart 2
# Energy   = -3.444441862946
# Fidelity = 0.999449333649
# Overlap  = 0.902883043762
#
# Restart 3
# Energy   = -3.440403893199
# Fidelity = 0.998875668200
# Overlap  = 0.901009065659
#
# Restart 4
# Energy   = -3.442912173128
# Fidelity = 0.999216763550
# Overlap  = 0.900060576149
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.445486684767
# Energy error     : 3.193701e-03
# Fidelity         : 0.999647475417
# Tracking overlap : 0.903986156852
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.859239791637
# Fidelity = 0.999829244386
# Overlap  = 0.942334589924
#
# Restart 1
# Energy   = -2.856497290570
# Fidelity = 0.999446097723
# Overlap  = 0.942157480326
#
# Restart 2
# Energy   = -2.845684594307
# Fidelity = 0.997736608615
# Overlap  = 0.937596715601
#
# Restart 3
# Energy   = -2.844947522140
# Fidelity = 0.997068792119
# Overlap  = 0.937894939911
#
# Restart 4
# Energy   = -2.840511604659
# Fidelity = 0.996318685052
# Overlap  = 0.931201308497
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.859239791637
# Energy error     : 1.592474e-03
# Fidelity         : 0.999829244386
# Tracking overlap : 0.942334589924
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.418481362063
# Fidelity = 0.999837507149
# Overlap  = 0.962392989883
#
# Restart 1
# Energy   = -2.399006008310
# Fidelity = 0.996043556370
# Overlap  = 0.953351544400
#
# Restart 2
# Energy   = -2.399494338018
# Fidelity = 0.996133393217
# Overlap  = 0.956392387058
#
# Restart 3
# Energy   = -2.407127537551
# Fidelity = 0.998187379113
# Overlap  = 0.956820321186
#
# Restart 4
# Energy   = -2.404051333786
# Fidelity = 0.996956963165
# Overlap  = 0.956018939341
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.418481362063
# Energy error     : 1.609167e-03
# Fidelity         : 0.999837507149
# Tracking overlap : 0.962392989883
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.074531002645
# Fidelity = 0.999820287850
# Overlap  = 0.973824445907
#
# Restart 1
# Energy   = -2.064161477757
# Fidelity = 0.998343550766
# Overlap  = 0.968606589844
#
# Restart 2
# Energy   = -2.053123602342
# Fidelity = 0.995888674225
# Overlap  = 0.964403850324
#
# Restart 3
# Energy   = -2.062024394767
# Fidelity = 0.997489071336
# Overlap  = 0.966830478343
#
# Restart 4
# Energy   = -2.045163392883
# Fidelity = 0.994084804758
# Overlap  = 0.959611066033
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.074531002645
# Energy error     : 1.781565e-03
# Fidelity         : 0.999820287850
# Tracking overlap : 0.973824445907
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.798241248497
# Fidelity = 0.999819860137
# Overlap  = 0.981196580622
#
# Restart 1
# Energy   = -1.786370308043
# Fidelity = 0.997650575272
# Overlap  = 0.976159681862
#
# Restart 2
# Energy   = -1.782551668803
# Fidelity = 0.996919475124
# Overlap  = 0.979065190428
#
# Restart 3
# Energy   = -1.783762466884
# Fidelity = 0.996845783848
# Overlap  = 0.973631207666
#
# Restart 4
# Energy   = -1.789437239302
# Fidelity = 0.998198680429
# Overlap  = 0.978160516990
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.798241248497
# Energy error     : 1.832018e-03
# Fidelity         : 0.999819860137
# Tracking overlap : 0.981196580622
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Strong SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -20.7773284453      -20.7529950910      2.4333e-02        0.9978690700      1.0000000000      4
# 0.3111      -12.8364411428      -12.8165598135      1.9881e-02        0.9970656148      0.8543091474      4
# 0.5222      -7.7307163648       -7.7022588327       2.8458e-02        0.9957162430      0.1592288922      4
# 0.7333      -5.5381488307       -5.5248296050       1.3319e-02        0.9978229528      0.6489691128      4
# 0.9444      -4.2760137929       -4.2705041435       5.5096e-03        0.9992792981      0.8253777521      4
# 1.1556      -3.4486803854       -3.4454866848       3.1937e-03        0.9996474754      0.9039861569      4
# 1.3667      -2.8608322652       -2.8592397916       1.5925e-03        0.9998292444      0.9423345899      4
# 1.5778      -2.4200905293       -2.4184813621       1.6092e-03        0.9998375071      0.9623929899      4
# 1.7889      -2.0763125676       -2.0745310026       1.7816e-03        0.9998202878      0.9738244459      4
# 2.0000      -1.8000732662       -1.7982412485       1.8320e-03        0.9998198601      0.9811965806      4

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#
plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HVA_Floc vs lambda different f.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    
    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,
        'psi_vqe': psi_vqe,
        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119767
# T = 2     Fidelity = 0.99733347
# T = 5     Fidelity = 0.99892232
# T = 10    Fidelity = 0.99960367
# T = 20    Fidelity = 0.99995409
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98267936
# T = 2     Fidelity = 0.99772112
# T = 5     Fidelity = 0.99899533
# T = 10    Fidelity = 0.99966148
# T = 20    Fidelity = 0.99995785
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394024
# T = 2     Fidelity = 0.99802385
# T = 5     Fidelity = 0.99905535
# T = 10    Fidelity = 0.99971717
# T = 20    Fidelity = 0.99995035
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98504488
# T = 2     Fidelity = 0.99826857
# T = 5     Fidelity = 0.99911057
# T = 10    Fidelity = 0.99976876
# T = 20    Fidelity = 0.99994193
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98599628
# T = 2     Fidelity = 0.99846232
# T = 5     Fidelity = 0.99915756
# T = 10    Fidelity = 0.99981381
# T = 20    Fidelity = 0.99993824
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98686967
# T = 2     Fidelity = 0.99863030
# T = 5     Fidelity = 0.99920922
# T = 10    Fidelity = 0.99985440
# T = 20    Fidelity = 0.99994230
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98761006
# T = 2     Fidelity = 0.99875704
# T = 5     Fidelity = 0.99924809
# T = 10    Fidelity = 0.99988426
# T = 20    Fidelity = 0.99994916
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98830389
# T = 2     Fidelity = 0.99887063
# T = 5     Fidelity = 0.99929164
# T = 10    Fidelity = 0.99990758
#
# Minimum T for Fidelity >= 0.9999 : 10
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98894115
# T = 2     Fidelity = 0.99897204
# T = 5     Fidelity = 0.99933915
# T = 10    Fidelity = 0.99992978
#
# Minimum T for Fidelity >= 0.9999 : 10
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98944792
# T = 2     Fidelity = 0.99902988
# T = 5     Fidelity = 0.99935988
# T = 10    Fidelity = 0.99993263
#
# Minimum T for Fidelity >= 0.9999 : 10
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000004
# T = 2     Fidelity = 0.00000005
# T = 5     Fidelity = 0.00038922
# T = 10    Fidelity = 0.00044313
# T = 20    Fidelity = 0.01205705
# T = 30    Fidelity = 0.08171601
# T = 40    Fidelity = 0.18472517
# T = 50    Fidelity = 0.42368906
# T = 75    Fidelity = 0.56799627
# T = 100   Fidelity = 0.72569886
# T = 125   Fidelity = 0.80345751
# T = 150   Fidelity = 0.83336670
# T = 175   Fidelity = 0.90367145
# T = 200   Fidelity = 0.91691648
# T = 225   Fidelity = 0.96480299
# T = 250   Fidelity = 0.89044962
# T = 275   Fidelity = 0.96649924
# T = 300   Fidelity = 0.85499272
# T = 400   Fidelity = 0.98003006
# T = 500   Fidelity = 0.95946252
# T = 600   Fidelity = 0.95669556
# T = 700   Fidelity = 0.62969348
# T = 800   Fidelity = 0.83354039
# T = 900   Fidelity = 0.82460318
# T = 1000  Fidelity = 0.66602672
# T = 1010  Fidelity = 0.57992117
# T = 1020  Fidelity = 0.61557775
# T = 1030  Fidelity = 0.69542566
# T = 1040  Fidelity = 0.72231150
# T = 1050  Fidelity = 0.78643698
# T = 1060  Fidelity = 0.91468696
# T = 1070  Fidelity = 0.77314217
# T = 1080  Fidelity = 0.78606025
# T = 1090  Fidelity = 0.71677357
# T = 1100  Fidelity = 0.38637845
# T = 1200  Fidelity = 0.58938919
# T = 1300  Fidelity = 0.48395215
# T = 1400  Fidelity = 0.72035601
# T = 1500  Fidelity = 0.46077069
# T = 2000  Fidelity = 0.93328809
# T = 2100  Fidelity = 0.70808878
# T = 2110  Fidelity = 0.57045652
# T = 2120  Fidelity = 0.47400425
# T = 2130  Fidelity = 0.39616983
# T = 2140  Fidelity = 0.49479332
# T = 2150  Fidelity = 0.41769721
# T = 2160  Fidelity = 0.62838515
# T = 2170  Fidelity = 0.51705293
# T = 2180  Fidelity = 0.49679892
# T = 2190  Fidelity = 0.50179012
# T = 2200  Fidelity = 0.35960694
# T = 2300  Fidelity = 0.77222616
# T = 2400  Fidelity = 0.21688570
# T = 2500  Fidelity = 0.75347329
# T = 2600  Fidelity = 0.43313962
# T = 2700  Fidelity = 0.55584516
# T = 2800  Fidelity = 0.84784282
# T = 2900  Fidelity = 0.64444987
# T = 3000  Fidelity = 0.82536676
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00976726e+00
# P0     = 0.82536676
# P1     = 0.05978635
# P0+P1  = 0.88515311
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000041
# T = 2     Fidelity = 0.00000036
# T = 5     Fidelity = 0.00042656
# T = 10    Fidelity = 0.06485708
# T = 20    Fidelity = 0.21417556
# T = 30    Fidelity = 0.61326676
# T = 40    Fidelity = 0.33587858
# T = 50    Fidelity = 0.77652075
# T = 75    Fidelity = 0.73750074
# T = 100   Fidelity = 0.78836974
# T = 125   Fidelity = 0.87317107
# T = 150   Fidelity = 0.87216523
# T = 175   Fidelity = 0.89433295
# T = 200   Fidelity = 0.91941965
# T = 225   Fidelity = 0.93027481
# T = 250   Fidelity = 0.93978001
# T = 275   Fidelity = 0.94811380
# T = 300   Fidelity = 0.94799162
# T = 400   Fidelity = 0.97087617
# T = 500   Fidelity = 0.97215695
# T = 600   Fidelity = 0.81901498
# T = 700   Fidelity = 0.81572859
# T = 800   Fidelity = 0.87682176
# T = 900   Fidelity = 0.71709522
# T = 1000  Fidelity = 0.75639749
# T = 1010  Fidelity = 0.87395489
# T = 1020  Fidelity = 0.84750969
# T = 1030  Fidelity = 0.90857260
# T = 1040  Fidelity = 0.83647987
# T = 1050  Fidelity = 0.85363101
# T = 1060  Fidelity = 0.74110063
# T = 1070  Fidelity = 0.77714596
# T = 1080  Fidelity = 0.52528295
# T = 1090  Fidelity = 0.68876088
# T = 1100  Fidelity = 0.53119810
# T = 1200  Fidelity = 0.77377644
# T = 1300  Fidelity = 0.81133699
# T = 1400  Fidelity = 0.94304359
# T = 1500  Fidelity = 0.85317701
# T = 2000  Fidelity = 0.60568185
# T = 2100  Fidelity = 0.60427902
# T = 2110  Fidelity = 0.66972472
# T = 2120  Fidelity = 0.80839411
# T = 2130  Fidelity = 0.95982134
# T = 2140  Fidelity = 0.76678298
# T = 2150  Fidelity = 0.81684689
# T = 2160  Fidelity = 0.90093225
# T = 2170  Fidelity = 0.58200867
# T = 2180  Fidelity = 0.89240295
# T = 2190  Fidelity = 0.59517056
# T = 2200  Fidelity = 0.47012925
# T = 2300  Fidelity = 0.49036645
# T = 2400  Fidelity = 0.65114771
# T = 2500  Fidelity = 0.30737426
# T = 2600  Fidelity = 0.91001730
# T = 2700  Fidelity = 0.84108748
# T = 2800  Fidelity = 0.85738095
# T = 2900  Fidelity = 0.84078951
# T = 3000  Fidelity = 0.87744013
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02946706e+00
# P0     = 0.87744013
# P1     = 0.00990154
# P0+P1  = 0.88734167
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00004106
# T = 2     Fidelity = 0.00038095
# T = 5     Fidelity = 0.02047283
# T = 10    Fidelity = 0.21741829
# T = 20    Fidelity = 0.59314588
# T = 30    Fidelity = 0.65741190
# T = 40    Fidelity = 0.78525588
# T = 50    Fidelity = 0.82127827
# T = 75    Fidelity = 0.92018252
# T = 100   Fidelity = 0.96324830
# T = 125   Fidelity = 0.98110312
# T = 150   Fidelity = 0.98751670
# T = 175   Fidelity = 0.99157849
# T = 200   Fidelity = 0.99243354
# T = 225   Fidelity = 0.99329839
# T = 250   Fidelity = 0.99083518
# T = 275   Fidelity = 0.98572322
# T = 300   Fidelity = 0.98546795
# T = 400   Fidelity = 0.96925940
# T = 500   Fidelity = 0.92445215
# T = 600   Fidelity = 0.89531134
# T = 700   Fidelity = 0.94467339
# T = 800   Fidelity = 0.90850568
# T = 900   Fidelity = 0.86276783
# T = 1000  Fidelity = 0.74227904
# T = 1010  Fidelity = 0.65853546
# T = 1020  Fidelity = 0.87203566
# T = 1030  Fidelity = 0.53755454
# T = 1040  Fidelity = 0.94859033
# T = 1050  Fidelity = 0.69311956
# T = 1060  Fidelity = 0.84207767
# T = 1070  Fidelity = 0.93500421
# T = 1080  Fidelity = 0.78719793
# T = 1090  Fidelity = 0.98149951
# T = 1100  Fidelity = 0.92739956
# T = 1200  Fidelity = 0.93294764
# T = 1300  Fidelity = 0.91984603
# T = 1400  Fidelity = 0.92674281
# T = 1500  Fidelity = 0.96301812
# T = 2000  Fidelity = 0.85669659
# T = 2100  Fidelity = 0.82123367
# T = 2110  Fidelity = 0.69895416
# T = 2120  Fidelity = 0.86985186
# T = 2130  Fidelity = 0.93640850
# T = 2140  Fidelity = 0.86239872
# T = 2150  Fidelity = 0.88230610
# T = 2160  Fidelity = 0.74745614
# T = 2170  Fidelity = 0.73691879
# T = 2180  Fidelity = 0.79017215
# T = 2190  Fidelity = 0.77209290
# T = 2200  Fidelity = 0.67939756
# T = 2300  Fidelity = 0.73042607
# T = 2400  Fidelity = 0.87046113
# T = 2500  Fidelity = 0.86474395
# T = 2600  Fidelity = 0.78783897
# T = 2700  Fidelity = 0.94389426
# T = 2800  Fidelity = 0.97087097
# T = 2900  Fidelity = 0.96641744
# T = 3000  Fidelity = 0.94896851
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04808582e+00
# P0     = 0.94896851
# P1     = 0.00079584
# P0+P1  = 0.94976435
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00121998
# T = 2     Fidelity = 0.00524746
# T = 5     Fidelity = 0.06227382
# T = 10    Fidelity = 0.27541064
# T = 20    Fidelity = 0.67964196
# T = 30    Fidelity = 0.73744395
# T = 40    Fidelity = 0.81495438
# T = 50    Fidelity = 0.88493383
# T = 75    Fidelity = 0.95250465
# T = 100   Fidelity = 0.97955627
# T = 125   Fidelity = 0.99054937
# T = 150   Fidelity = 0.99416871
# T = 175   Fidelity = 0.99562101
# T = 200   Fidelity = 0.99538139
# T = 225   Fidelity = 0.99364937
# T = 250   Fidelity = 0.99487308
# T = 275   Fidelity = 0.98795668
# T = 300   Fidelity = 0.99107562
# T = 400   Fidelity = 0.97934583
# T = 500   Fidelity = 0.98572001
# T = 600   Fidelity = 0.91120980
# T = 700   Fidelity = 0.90936305
# T = 800   Fidelity = 0.94492722
# T = 900   Fidelity = 0.97704706
# T = 1000  Fidelity = 0.89186069
# T = 1010  Fidelity = 0.94411533
# T = 1020  Fidelity = 0.93893415
# T = 1030  Fidelity = 0.98225927
# T = 1040  Fidelity = 0.97667183
# T = 1050  Fidelity = 0.98205057
# T = 1060  Fidelity = 0.97355058
# T = 1070  Fidelity = 0.97978752
# T = 1080  Fidelity = 0.95688601
# T = 1090  Fidelity = 0.97686088
# T = 1100  Fidelity = 0.97072334
# T = 1200  Fidelity = 0.98022139
# T = 1300  Fidelity = 0.98330314
# T = 1400  Fidelity = 0.94212223
# T = 1500  Fidelity = 0.98088413
# T = 2000  Fidelity = 0.90667009
# T = 2100  Fidelity = 0.95766796
# T = 2110  Fidelity = 0.97432523
# T = 2120  Fidelity = 0.97531435
# T = 2130  Fidelity = 0.93904179
# T = 2140  Fidelity = 0.94090222
# T = 2150  Fidelity = 0.94823446
# T = 2160  Fidelity = 0.89480120
# T = 2170  Fidelity = 0.85481521
# T = 2180  Fidelity = 0.86415261
# T = 2190  Fidelity = 0.79523545
# T = 2200  Fidelity = 0.77201384
# T = 2300  Fidelity = 0.76372413
# T = 2400  Fidelity = 0.89760254
# T = 2500  Fidelity = 0.96583566
# T = 2600  Fidelity = 0.96860992
# T = 2700  Fidelity = 0.88461862
# T = 2800  Fidelity = 0.90496891
# T = 2900  Fidelity = 0.87850708
# T = 3000  Fidelity = 0.92809686
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06578123e+00
# P0     = 0.92809686
# P1     = 0.00317951
# P0+P1  = 0.93127637
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00937075
# T = 2     Fidelity = 0.02538853
# T = 5     Fidelity = 0.12890496
# T = 10    Fidelity = 0.34184207
# T = 20    Fidelity = 0.66572850
# T = 30    Fidelity = 0.79740872
# T = 40    Fidelity = 0.85916600
# T = 50    Fidelity = 0.90803481
# T = 75    Fidelity = 0.96883821
# T = 100   Fidelity = 0.98831255
# T = 125   Fidelity = 0.99413879
# T = 150   Fidelity = 0.99679288
# T = 175   Fidelity = 0.99738110
# T = 200   Fidelity = 0.99595848
# T = 225   Fidelity = 0.99530719
# T = 250   Fidelity = 0.99521298
# T = 275   Fidelity = 0.99070575
# T = 300   Fidelity = 0.99147487
# T = 400   Fidelity = 0.97585490
# T = 500   Fidelity = 0.98744087
# T = 600   Fidelity = 0.86027141
# T = 700   Fidelity = 0.97678322
# T = 800   Fidelity = 0.98720232
# T = 900   Fidelity = 0.95211468
# T = 1000  Fidelity = 0.96427602
# T = 1010  Fidelity = 0.99132010
# T = 1020  Fidelity = 0.98835027
# T = 1030  Fidelity = 0.98657935
# T = 1040  Fidelity = 0.98102659
# T = 1050  Fidelity = 0.99132427
# T = 1060  Fidelity = 0.97820995
# T = 1070  Fidelity = 0.98985597
# T = 1080  Fidelity = 0.98208010
# T = 1090  Fidelity = 0.98467777
# T = 1100  Fidelity = 0.98752500
# T = 1200  Fidelity = 0.89955873
# T = 1300  Fidelity = 0.98607948
# T = 1400  Fidelity = 0.97876265
# T = 1500  Fidelity = 0.97146931
# T = 2000  Fidelity = 0.96573175
# T = 2100  Fidelity = 0.97017301
# T = 2110  Fidelity = 0.95985010
# T = 2120  Fidelity = 0.98191799
# T = 2130  Fidelity = 0.97777700
# T = 2140  Fidelity = 0.97935225
# T = 2150  Fidelity = 0.97927231
# T = 2160  Fidelity = 0.96763186
# T = 2170  Fidelity = 0.95757085
# T = 2180  Fidelity = 0.94034870
# T = 2190  Fidelity = 0.91548255
# T = 2200  Fidelity = 0.87965256
# T = 2300  Fidelity = 0.82533929
# T = 2400  Fidelity = 0.88544552
# T = 2500  Fidelity = 0.95378947
# T = 2600  Fidelity = 0.97596229
# T = 2700  Fidelity = 0.97310741
# T = 2800  Fidelity = 0.94335997
# T = 2900  Fidelity = 0.95738447
# T = 3000  Fidelity = 0.97827319
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08267455e+00
# P0     = 0.97827319
# P1     = 0.00191169
# P0+P1  = 0.98018488
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03562956
# T = 2     Fidelity = 0.07573583
# T = 5     Fidelity = 0.22545043
# T = 10    Fidelity = 0.42847000
# T = 20    Fidelity = 0.67467372
# T = 30    Fidelity = 0.79651675
# T = 40    Fidelity = 0.86657751
# T = 50    Fidelity = 0.91461613
# T = 75    Fidelity = 0.97713520
# T = 100   Fidelity = 0.99398149
# T = 125   Fidelity = 0.99606824
# T = 150   Fidelity = 0.99603707
# T = 175   Fidelity = 0.99662490
# T = 200   Fidelity = 0.99586493
# T = 225   Fidelity = 0.99598705
# T = 250   Fidelity = 0.99349642
# T = 275   Fidelity = 0.99268275
# T = 300   Fidelity = 0.99157131
# T = 400   Fidelity = 0.98786067
# T = 500   Fidelity = 0.98621833
# T = 600   Fidelity = 0.92024814
# T = 700   Fidelity = 0.97676462
# T = 800   Fidelity = 0.97612949
# T = 900   Fidelity = 0.95580490
# T = 1000  Fidelity = 0.93670226
# T = 1010  Fidelity = 0.96332131
# T = 1020  Fidelity = 0.95399826
# T = 1030  Fidelity = 0.96708553
# T = 1040  Fidelity = 0.95692030
# T = 1050  Fidelity = 0.97378382
# T = 1060  Fidelity = 0.98017655
# T = 1070  Fidelity = 0.97961979
# T = 1080  Fidelity = 0.96873638
# T = 1090  Fidelity = 0.97767168
# T = 1100  Fidelity = 0.97539207
# T = 1200  Fidelity = 0.97359615
# T = 1300  Fidelity = 0.96149221
# T = 1400  Fidelity = 0.98824870
# T = 1500  Fidelity = 0.97737355
# T = 2000  Fidelity = 0.97359605
# T = 2100  Fidelity = 0.89705844
# T = 2110  Fidelity = 0.92648562
# T = 2120  Fidelity = 0.94589496
# T = 2130  Fidelity = 0.92518760
# T = 2140  Fidelity = 0.96956000
# T = 2150  Fidelity = 0.97944527
# T = 2160  Fidelity = 0.98238290
# T = 2170  Fidelity = 0.95542556
# T = 2180  Fidelity = 0.96524601
# T = 2190  Fidelity = 0.97493802
# T = 2200  Fidelity = 0.96122197
# T = 2300  Fidelity = 0.84834907
# T = 2400  Fidelity = 0.92170746
# T = 2500  Fidelity = 0.96064989
# T = 2600  Fidelity = 0.97321753
# T = 2700  Fidelity = 0.97801209
# T = 2800  Fidelity = 0.91073821
# T = 2900  Fidelity = 0.95187612
# T = 3000  Fidelity = 0.98003852
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.09886174e+00
# P0     = 0.98003852
# P1     = 0.00417864
# P0+P1  = 0.98421716
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09562397
# T = 2     Fidelity = 0.17458316
# T = 5     Fidelity = 0.36688270
# T = 10    Fidelity = 0.55752928
# T = 20    Fidelity = 0.74334733
# T = 30    Fidelity = 0.83205966
# T = 40    Fidelity = 0.88346381
# T = 50    Fidelity = 0.91726487
# T = 75    Fidelity = 0.96471007
# T = 100   Fidelity = 0.98383495
# T = 125   Fidelity = 0.99131912
# T = 150   Fidelity = 0.99388572
# T = 175   Fidelity = 0.99391210
# T = 200   Fidelity = 0.99312760
# T = 225   Fidelity = 0.99324122
# T = 250   Fidelity = 0.99297331
# T = 275   Fidelity = 0.99349230
# T = 300   Fidelity = 0.98989582
# T = 400   Fidelity = 0.98074298
# T = 500   Fidelity = 0.96728603
# T = 600   Fidelity = 0.93021454
# T = 700   Fidelity = 0.98221986
# T = 800   Fidelity = 0.98360514
# T = 900   Fidelity = 0.97670569
# T = 1000  Fidelity = 0.96871175
# T = 1010  Fidelity = 0.98251302
# T = 1020  Fidelity = 0.95905630
# T = 1030  Fidelity = 0.98260119
# T = 1040  Fidelity = 0.96991733
# T = 1050  Fidelity = 0.98174943
# T = 1060  Fidelity = 0.97217825
# T = 1070  Fidelity = 0.98236616
# T = 1080  Fidelity = 0.98135625
# T = 1090  Fidelity = 0.96398620
# T = 1100  Fidelity = 0.97790370
# T = 1200  Fidelity = 0.98682811
# T = 1300  Fidelity = 0.94538468
# T = 1400  Fidelity = 0.96688214
# T = 1500  Fidelity = 0.98925605
# T = 2000  Fidelity = 0.95922330
# T = 2100  Fidelity = 0.96983407
# T = 2110  Fidelity = 0.96361628
# T = 2120  Fidelity = 0.95154982
# T = 2130  Fidelity = 0.93343678
# T = 2140  Fidelity = 0.94218025
# T = 2150  Fidelity = 0.93286797
# T = 2160  Fidelity = 0.94563297
# T = 2170  Fidelity = 0.94149626
# T = 2180  Fidelity = 0.93146127
# T = 2190  Fidelity = 0.97060934
# T = 2200  Fidelity = 0.97885684
# T = 2300  Fidelity = 0.82270569
# T = 2400  Fidelity = 0.88715033
# T = 2500  Fidelity = 0.98015323
# T = 2600  Fidelity = 0.95853026
# T = 2700  Fidelity = 0.98749116
# T = 2800  Fidelity = 0.96040937
# T = 2900  Fidelity = 0.97200245
# T = 3000  Fidelity = 0.96168948
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.11442047e+00
# P0     = 0.96168948
# P1     = 0.00014753
# P0+P1  = 0.96183701
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19239500
# T = 2     Fidelity = 0.31403728
# T = 5     Fidelity = 0.52613941
# T = 10    Fidelity = 0.69193047
# T = 20    Fidelity = 0.82681685
# T = 30    Fidelity = 0.88623297
# T = 40    Fidelity = 0.92059119
# T = 50    Fidelity = 0.94226264
# T = 75    Fidelity = 0.96911560
# T = 100   Fidelity = 0.98201837
# T = 125   Fidelity = 0.98794982
# T = 150   Fidelity = 0.99102022
# T = 175   Fidelity = 0.99272891
# T = 200   Fidelity = 0.99197348
# T = 225   Fidelity = 0.99313202
# T = 250   Fidelity = 0.99468292
# T = 275   Fidelity = 0.99290734
# T = 300   Fidelity = 0.99086807
# T = 400   Fidelity = 0.99222862
# T = 500   Fidelity = 0.98070316
# T = 600   Fidelity = 0.93747779
# T = 700   Fidelity = 0.97528823
# T = 800   Fidelity = 0.97855217
# T = 900   Fidelity = 0.97565430
# T = 1000  Fidelity = 0.97867509
# T = 1010  Fidelity = 0.98558527
# T = 1020  Fidelity = 0.97561162
# T = 1030  Fidelity = 0.98621136
# T = 1040  Fidelity = 0.98434176
# T = 1050  Fidelity = 0.98216960
# T = 1060  Fidelity = 0.97727147
# T = 1070  Fidelity = 0.97745440
# T = 1080  Fidelity = 0.98463072
# T = 1090  Fidelity = 0.98385227
# T = 1100  Fidelity = 0.96917291
# T = 1200  Fidelity = 0.95621219
# T = 1300  Fidelity = 0.98824298
# T = 1400  Fidelity = 0.96783984
# T = 1500  Fidelity = 0.97178840
# T = 2000  Fidelity = 0.96657797
# T = 2100  Fidelity = 0.98075990
# T = 2110  Fidelity = 0.98039212
# T = 2120  Fidelity = 0.97129083
# T = 2130  Fidelity = 0.95488082
# T = 2140  Fidelity = 0.96723014
# T = 2150  Fidelity = 0.95638621
# T = 2160  Fidelity = 0.94891605
# T = 2170  Fidelity = 0.95608709
# T = 2180  Fidelity = 0.95838018
# T = 2190  Fidelity = 0.96007646
# T = 2200  Fidelity = 0.95423218
# T = 2300  Fidelity = 0.94521780
# T = 2400  Fidelity = 0.94916735
# T = 2500  Fidelity = 0.96024130
# T = 2600  Fidelity = 0.96530274
# T = 2700  Fidelity = 0.97777685
# T = 2800  Fidelity = 0.97237042
# T = 2900  Fidelity = 0.98476692
# T = 3000  Fidelity = 0.96333328
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.12941480e+00
# P0     = 0.96333328
# P1     = 0.00046142
# P0+P1  = 0.96379471
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30129374
# T = 2     Fidelity = 0.45479744
# T = 5     Fidelity = 0.66197292
# T = 10    Fidelity = 0.79848812
# T = 20    Fidelity = 0.89439536
# T = 30    Fidelity = 0.93322000
# T = 40    Fidelity = 0.95492705
# T = 50    Fidelity = 0.96705768
# T = 75    Fidelity = 0.98298104
# T = 100   Fidelity = 0.98936279
# T = 125   Fidelity = 0.99275939
# T = 150   Fidelity = 0.99432246
# T = 175   Fidelity = 0.99535497
# T = 200   Fidelity = 0.99387768
# T = 225   Fidelity = 0.99551992
# T = 250   Fidelity = 0.99630804
# T = 275   Fidelity = 0.99628104
# T = 300   Fidelity = 0.99058967
# T = 400   Fidelity = 0.98563283
# T = 500   Fidelity = 0.96762525
# T = 600   Fidelity = 0.95382207
# T = 700   Fidelity = 0.98786555
# T = 800   Fidelity = 0.98434225
# T = 900   Fidelity = 0.99391649
# T = 1000  Fidelity = 0.98496698
# T = 1010  Fidelity = 0.97690665
# T = 1020  Fidelity = 0.98694242
# T = 1030  Fidelity = 0.98350936
# T = 1040  Fidelity = 0.99386275
# T = 1050  Fidelity = 0.97523282
# T = 1060  Fidelity = 0.98995990
# T = 1070  Fidelity = 0.96351675
# T = 1080  Fidelity = 0.98914982
# T = 1090  Fidelity = 0.97508622
# T = 1100  Fidelity = 0.98034153
# T = 1200  Fidelity = 0.95521939
# T = 1300  Fidelity = 0.98822992
# T = 1400  Fidelity = 0.98683590
# T = 1500  Fidelity = 0.97953563
# T = 2000  Fidelity = 0.98726182
# T = 2100  Fidelity = 0.97590735
# T = 2110  Fidelity = 0.97546732
# T = 2120  Fidelity = 0.95575616
# T = 2130  Fidelity = 0.98242674
# T = 2140  Fidelity = 0.98850359
# T = 2150  Fidelity = 0.98712018
# T = 2160  Fidelity = 0.96385621
# T = 2170  Fidelity = 0.94672143
# T = 2180  Fidelity = 0.97677289
# T = 2190  Fidelity = 0.98444592
# T = 2200  Fidelity = 0.97941996
# T = 2300  Fidelity = 0.97917501
# T = 2400  Fidelity = 0.96206778
# T = 2500  Fidelity = 0.97181049
# T = 2600  Fidelity = 0.96663424
# T = 2700  Fidelity = 0.98716108
# T = 2800  Fidelity = 0.99146908
# T = 2900  Fidelity = 0.98841202
# T = 3000  Fidelity = 0.97582901
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.14389834e+00
# P0     = 0.97582901
# P1     = 0.00292382
# P0+P1  = 0.97875283
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40222695
# T = 2     Fidelity = 0.57275798
# T = 5     Fidelity = 0.76030692
# T = 10    Fidelity = 0.86898507
# T = 20    Fidelity = 0.93637061
# T = 30    Fidelity = 0.96210735
# T = 40    Fidelity = 0.97423422
# T = 50    Fidelity = 0.98202656
# T = 75    Fidelity = 0.99116807
# T = 100   Fidelity = 0.99473627
# T = 125   Fidelity = 0.99630700
# T = 150   Fidelity = 0.99716063
# T = 175   Fidelity = 0.99788301
# T = 200   Fidelity = 0.99498635
# T = 225   Fidelity = 0.99790150
# T = 250   Fidelity = 0.99754624
# T = 275   Fidelity = 0.99685003
# T = 300   Fidelity = 0.99284187
# T = 400   Fidelity = 0.98211646
# T = 500   Fidelity = 0.99023170
# T = 600   Fidelity = 0.98114810
# T = 700   Fidelity = 0.99576611
# T = 800   Fidelity = 0.99517720
# T = 900   Fidelity = 0.97948803
# T = 1000  Fidelity = 0.99152525
# T = 1010  Fidelity = 0.96399270
# T = 1020  Fidelity = 0.99134210
# T = 1030  Fidelity = 0.96929782
# T = 1040  Fidelity = 0.99586694
# T = 1050  Fidelity = 0.97382859
# T = 1060  Fidelity = 0.98341995
# T = 1070  Fidelity = 0.96750380
# T = 1080  Fidelity = 0.95234826
# T = 1090  Fidelity = 0.97257216
# T = 1100  Fidelity = 0.94970097
# T = 1200  Fidelity = 0.98648081
# T = 1300  Fidelity = 0.99030685
# T = 1400  Fidelity = 0.98940090
# T = 1500  Fidelity = 0.98410240
# T = 2000  Fidelity = 0.98136510
# T = 2100  Fidelity = 0.97615477
# T = 2110  Fidelity = 0.98318071
# T = 2120  Fidelity = 0.95180326
# T = 2130  Fidelity = 0.95872192
# T = 2140  Fidelity = 0.98663039
# T = 2150  Fidelity = 0.98847987
# T = 2160  Fidelity = 0.97795930
# T = 2170  Fidelity = 0.95562644
# T = 2180  Fidelity = 0.97869098
# T = 2190  Fidelity = 0.98675974
# T = 2200  Fidelity = 0.98417662
# T = 2300  Fidelity = 0.99070507
# T = 2400  Fidelity = 0.98877099
# T = 2500  Fidelity = 0.98582692
# T = 2600  Fidelity = 0.98412794
# T = 2700  Fidelity = 0.97384548
# T = 2800  Fidelity = 0.99470037
# T = 2900  Fidelity = 0.97917245
# T = 3000  Fidelity = 0.98583153
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.15791659e+00
# P0     = 0.98583153
# P1     = 0.00381499
# P0+P1  = 0.98964652
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.36752113e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00059481
# T = 10    Fidelity = 0.00010077
# T = 20    Fidelity = 0.00396847
# T = 30    Fidelity = 0.05392558
# T = 40    Fidelity = 0.12154263
# T = 50    Fidelity = 0.21308482
# T = 75    Fidelity = 0.57996289
# T = 100   Fidelity = 0.76233411
# T = 125   Fidelity = 0.73389352
# T = 150   Fidelity = 0.86903731
# T = 175   Fidelity = 0.91156124
# T = 200   Fidelity = 0.87281753
# T = 225   Fidelity = 0.95051633
# T = 250   Fidelity = 0.98328201
# T = 275   Fidelity = 0.98300762
# T = 300   Fidelity = 0.86113795
# T = 400   Fidelity = 0.91237583
# T = 500   Fidelity = 0.92601836
# T = 600   Fidelity = 0.91914879
# T = 700   Fidelity = 0.91146006
# T = 800   Fidelity = 0.82008871
# T = 900   Fidelity = 0.78378171
# T = 1000  Fidelity = 0.67121006
# T = 1010  Fidelity = 0.52185239
# T = 1020  Fidelity = 0.57470558
# T = 1030  Fidelity = 0.75347749
# T = 1040  Fidelity = 0.89932735
# T = 1050  Fidelity = 0.85807107
# T = 1060  Fidelity = 0.83409288
# T = 1070  Fidelity = 0.70109686
# T = 1080  Fidelity = 0.54454129
# T = 1090  Fidelity = 0.51272667
# T = 1100  Fidelity = 0.55171399
# T = 1200  Fidelity = 0.67190919
# T = 1300  Fidelity = 0.58696614
# T = 1400  Fidelity = 0.66895667
# T = 1500  Fidelity = 0.28903886
# T = 2000  Fidelity = 0.11153164
# T = 2100  Fidelity = 0.68118573
# T = 2110  Fidelity = 0.68156360
# T = 2120  Fidelity = 0.73154228
# T = 2130  Fidelity = 0.81440554
# T = 2140  Fidelity = 0.85697419
# T = 2150  Fidelity = 0.92323730
# T = 2160  Fidelity = 0.90681525
# T = 2170  Fidelity = 0.86775630
# T = 2180  Fidelity = 0.77855081
# T = 2190  Fidelity = 0.40691196
# T = 2200  Fidelity = 0.25759230
# T = 2300  Fidelity = 0.55456565
# T = 2400  Fidelity = 0.82808065
# T = 2500  Fidelity = 0.90324210
# T = 2600  Fidelity = 0.80784298
# T = 2700  Fidelity = 0.81254037
# T = 2800  Fidelity = 0.34996207
# T = 2900  Fidelity = 0.88706245
# T = 3000  Fidelity = 0.74605559
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00970921e+00
# P0     = 0.74605559
# P1     = 0.03850797
# P0+P1  = 0.78456356
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.12924856e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000006
# T = 5     Fidelity = 0.00018912
# T = 10    Fidelity = 0.04116068
# T = 20    Fidelity = 0.42020395
# T = 30    Fidelity = 0.49030762
# T = 40    Fidelity = 0.64160756
# T = 50    Fidelity = 0.64398551
# T = 75    Fidelity = 0.88008552
# T = 100   Fidelity = 0.90202584
# T = 125   Fidelity = 0.87175005
# T = 150   Fidelity = 0.88551744
# T = 175   Fidelity = 0.91975025
# T = 200   Fidelity = 0.94096105
# T = 225   Fidelity = 0.95437608
# T = 250   Fidelity = 0.94808451
# T = 275   Fidelity = 0.95815799
# T = 300   Fidelity = 0.93938111
# T = 400   Fidelity = 0.97183370
# T = 500   Fidelity = 0.95227374
# T = 600   Fidelity = 0.92496811
# T = 700   Fidelity = 0.56209956
# T = 800   Fidelity = 0.62138628
# T = 900   Fidelity = 0.68332079
# T = 1000  Fidelity = 0.89694143
# T = 1010  Fidelity = 0.57266100
# T = 1020  Fidelity = 0.85018157
# T = 1030  Fidelity = 0.84646516
# T = 1040  Fidelity = 0.71478725
# T = 1050  Fidelity = 0.86010742
# T = 1060  Fidelity = 0.56949354
# T = 1070  Fidelity = 0.81116869
# T = 1080  Fidelity = 0.62845339
# T = 1090  Fidelity = 0.82126748
# T = 1100  Fidelity = 0.71074429
# T = 1200  Fidelity = 0.61628850
# T = 1300  Fidelity = 0.59563531
# T = 1400  Fidelity = 0.54429615
# T = 1500  Fidelity = 0.70619468
# T = 2000  Fidelity = 0.49750655
# T = 2100  Fidelity = 0.69678389
# T = 2110  Fidelity = 0.67578531
# T = 2120  Fidelity = 0.81658710
# T = 2130  Fidelity = 0.65995983
# T = 2140  Fidelity = 0.58287288
# T = 2150  Fidelity = 0.79396055
# T = 2160  Fidelity = 0.52642657
# T = 2170  Fidelity = 0.68544646
# T = 2180  Fidelity = 0.64874417
# T = 2190  Fidelity = 0.75861728
# T = 2200  Fidelity = 0.49801654
# T = 2300  Fidelity = 0.67238464
# T = 2400  Fidelity = 0.67336760
# T = 2500  Fidelity = 0.67394574
# T = 2600  Fidelity = 0.72762105
# T = 2700  Fidelity = 0.76775444
# T = 2800  Fidelity = 0.78985074
# T = 2900  Fidelity = 0.51846619
# T = 3000  Fidelity = 0.54811693
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02931057e+00
# P0     = 0.54811693
# P1     = 0.22190179
# P0+P1  = 0.77001873
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00001218
# T = 2     Fidelity = 0.00016813
# T = 5     Fidelity = 0.01428926
# T = 10    Fidelity = 0.17086077
# T = 20    Fidelity = 0.44251279
# T = 30    Fidelity = 0.33963442
# T = 40    Fidelity = 0.54675861
# T = 50    Fidelity = 0.43857506
# T = 75    Fidelity = 0.49336475
# T = 100   Fidelity = 0.50299669
# T = 125   Fidelity = 0.50298672
# T = 150   Fidelity = 0.50216841
# T = 175   Fidelity = 0.50141000
# T = 200   Fidelity = 0.49699810
# T = 225   Fidelity = 0.50876578
# T = 250   Fidelity = 0.50137091
# T = 275   Fidelity = 0.48745678
# T = 300   Fidelity = 0.48752929
# T = 400   Fidelity = 0.49832931
# T = 500   Fidelity = 0.30910062
# T = 600   Fidelity = 0.50966301
# T = 700   Fidelity = 0.38941995
# T = 800   Fidelity = 0.53510246
# T = 900   Fidelity = 0.53156361
# T = 1000  Fidelity = 0.70261464
# T = 1010  Fidelity = 0.39805600
# T = 1020  Fidelity = 0.40395462
# T = 1030  Fidelity = 0.47197536
# T = 1040  Fidelity = 0.50003767
# T = 1050  Fidelity = 0.46895403
# T = 1060  Fidelity = 0.37088213
# T = 1070  Fidelity = 0.56280633
# T = 1080  Fidelity = 0.26887447
# T = 1090  Fidelity = 0.27804318
# T = 1100  Fidelity = 0.61287439
# T = 1200  Fidelity = 0.29401437
# T = 1300  Fidelity = 0.55391058
# T = 1400  Fidelity = 0.53900759
# T = 1500  Fidelity = 0.36590558
# T = 2000  Fidelity = 0.29477094
# T = 2100  Fidelity = 0.20760151
# T = 2110  Fidelity = 0.55708370
# T = 2120  Fidelity = 0.47772508
# T = 2130  Fidelity = 0.50620351
# T = 2140  Fidelity = 0.32937454
# T = 2150  Fidelity = 0.45157914
# T = 2160  Fidelity = 0.39191750
# T = 2170  Fidelity = 0.39708831
# T = 2180  Fidelity = 0.53648094
# T = 2190  Fidelity = 0.19832233
# T = 2200  Fidelity = 0.49149957
# T = 2300  Fidelity = 0.53993590
# T = 2400  Fidelity = 0.49519689
# T = 2500  Fidelity = 0.46609676
# T = 2600  Fidelity = 0.46802911
# T = 2700  Fidelity = 0.57839232
# T = 2800  Fidelity = 0.60919077
# T = 2900  Fidelity = 0.46479739
# T = 3000  Fidelity = 0.43817105
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.43817105
# P1     = 0.05121539
# P0+P1  = 0.48938645
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.03672155e-03
# T = 1     Fidelity = 0.00286240
# T = 2     Fidelity = 0.01209887
# T = 5     Fidelity = 0.08328779
# T = 10    Fidelity = 0.22126674
# T = 20    Fidelity = 0.31462060
# T = 30    Fidelity = 0.37131222
# T = 40    Fidelity = 0.52928527
# T = 50    Fidelity = 0.56316539
# T = 75    Fidelity = 0.48583072
# T = 100   Fidelity = 0.50759648
# T = 125   Fidelity = 0.50898756
# T = 150   Fidelity = 0.50919700
# T = 175   Fidelity = 0.50643513
# T = 200   Fidelity = 0.51664397
# T = 225   Fidelity = 0.51004659
# T = 250   Fidelity = 0.50624255
# T = 275   Fidelity = 0.51370875
# T = 300   Fidelity = 0.48433074
# T = 400   Fidelity = 0.50092315
# T = 500   Fidelity = 0.54329170
# T = 600   Fidelity = 0.49871373
# T = 700   Fidelity = 0.43916847
# T = 800   Fidelity = 0.45068849
# T = 900   Fidelity = 0.51466371
# T = 1000  Fidelity = 0.76380887
# T = 1010  Fidelity = 0.45056582
# T = 1020  Fidelity = 0.13282545
# T = 1030  Fidelity = 0.54070469
# T = 1040  Fidelity = 0.77296740
# T = 1050  Fidelity = 0.59431769
# T = 1060  Fidelity = 0.48663876
# T = 1070  Fidelity = 0.49864169
# T = 1080  Fidelity = 0.42584710
# T = 1090  Fidelity = 0.25496774
# T = 1100  Fidelity = 0.71977624
# T = 1200  Fidelity = 0.58425562
# T = 1300  Fidelity = 0.45903105
# T = 1400  Fidelity = 0.52564978
# T = 1500  Fidelity = 0.53982494
# T = 2000  Fidelity = 0.46591240
# T = 2100  Fidelity = 0.53082923
# T = 2110  Fidelity = 0.56613944
# T = 2120  Fidelity = 0.48254305
# T = 2130  Fidelity = 0.40716334
# T = 2140  Fidelity = 0.56789746
# T = 2150  Fidelity = 0.77189725
# T = 2160  Fidelity = 0.45437324
# T = 2170  Fidelity = 0.25969072
# T = 2180  Fidelity = 0.50400510
# T = 2190  Fidelity = 0.69431789
# T = 2200  Fidelity = 0.62757395
# T = 2300  Fidelity = 0.81411533
# T = 2400  Fidelity = 0.54941655
# T = 2500  Fidelity = 0.52294927
# T = 2600  Fidelity = 0.57249689
# T = 2700  Fidelity = 0.47000464
# T = 2800  Fidelity = 0.55938089
# T = 2900  Fidelity = 0.32944301
# T = 3000  Fidelity = 0.46419243
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.46419243
# P1     = 0.01548524
# P0+P1  = 0.47967767
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.41475042e-03
# T = 1     Fidelity = 0.02409865
# T = 2     Fidelity = 0.06522676
# T = 5     Fidelity = 0.21910369
# T = 10    Fidelity = 0.40665912
# T = 20    Fidelity = 0.52887985
# T = 30    Fidelity = 0.49752136
# T = 40    Fidelity = 0.50355534
# T = 50    Fidelity = 0.54882505
# T = 75    Fidelity = 0.60805758
# T = 100   Fidelity = 0.60651012
# T = 125   Fidelity = 0.61153095
# T = 150   Fidelity = 0.61552893
# T = 175   Fidelity = 0.61891664
# T = 200   Fidelity = 0.62597225
# T = 225   Fidelity = 0.62880725
# T = 250   Fidelity = 0.63255046
# T = 275   Fidelity = 0.62956420
# T = 300   Fidelity = 0.64567490
# T = 400   Fidelity = 0.59380091
# T = 500   Fidelity = 0.65340293
# T = 600   Fidelity = 0.67738752
# T = 700   Fidelity = 0.59511987
# T = 800   Fidelity = 0.71383750
# T = 900   Fidelity = 0.60948091
# T = 1000  Fidelity = 0.48810301
# T = 1010  Fidelity = 0.76075938
# T = 1020  Fidelity = 0.85226866
# T = 1030  Fidelity = 0.75142481
# T = 1040  Fidelity = 0.53068968
# T = 1050  Fidelity = 0.47598573
# T = 1060  Fidelity = 0.65106993
# T = 1070  Fidelity = 0.77804455
# T = 1080  Fidelity = 0.82209812
# T = 1090  Fidelity = 0.55755548
# T = 1100  Fidelity = 0.40230356
# T = 1200  Fidelity = 0.46127047
# T = 1300  Fidelity = 0.54240776
# T = 1400  Fidelity = 0.77111209
# T = 1500  Fidelity = 0.68251812
# T = 2000  Fidelity = 0.77591841
# T = 2100  Fidelity = 0.82137167
# T = 2110  Fidelity = 0.81160649
# T = 2120  Fidelity = 0.55393748
# T = 2130  Fidelity = 0.65758137
# T = 2140  Fidelity = 0.71461025
# T = 2150  Fidelity = 0.83368643
# T = 2160  Fidelity = 0.84892807
# T = 2170  Fidelity = 0.78404264
# T = 2180  Fidelity = 0.53489184
# T = 2190  Fidelity = 0.57233992
# T = 2200  Fidelity = 0.70196525
# T = 2300  Fidelity = 0.76884509
# T = 2400  Fidelity = 0.75651273
# T = 2500  Fidelity = 0.82933993
# T = 2600  Fidelity = 0.73291796
# T = 2700  Fidelity = 0.78051004
# T = 2800  Fidelity = 0.76440478
# T = 2900  Fidelity = 0.70070614
# T = 3000  Fidelity = 0.75348383
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.75348383
# P1     = 0.00127288
# P0+P1  = 0.75475671
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50213251e-02
# T = 1     Fidelity = 0.08274851
# T = 2     Fidelity = 0.17474639
# T = 5     Fidelity = 0.39197371
# T = 10    Fidelity = 0.58555006
# T = 20    Fidelity = 0.71363742
# T = 30    Fidelity = 0.72009078
# T = 40    Fidelity = 0.71289609
# T = 50    Fidelity = 0.71864697
# T = 75    Fidelity = 0.74401805
# T = 100   Fidelity = 0.76234980
# T = 125   Fidelity = 0.77517050
# T = 150   Fidelity = 0.78574656
# T = 175   Fidelity = 0.79495299
# T = 200   Fidelity = 0.80412118
# T = 225   Fidelity = 0.81041192
# T = 250   Fidelity = 0.81604670
# T = 275   Fidelity = 0.82588355
# T = 300   Fidelity = 0.81749606
# T = 400   Fidelity = 0.87433850
# T = 500   Fidelity = 0.87055956
# T = 600   Fidelity = 0.79428718
# T = 700   Fidelity = 0.82813809
# T = 800   Fidelity = 0.84459236
# T = 900   Fidelity = 0.85221975
# T = 1000  Fidelity = 0.87680739
# T = 1010  Fidelity = 0.79392384
# T = 1020  Fidelity = 0.77895270
# T = 1030  Fidelity = 0.86800866
# T = 1040  Fidelity = 0.95135633
# T = 1050  Fidelity = 0.97299717
# T = 1060  Fidelity = 0.93462337
# T = 1070  Fidelity = 0.82920983
# T = 1080  Fidelity = 0.84157413
# T = 1090  Fidelity = 0.76866498
# T = 1100  Fidelity = 0.82740749
# T = 1200  Fidelity = 0.79751134
# T = 1300  Fidelity = 0.95553783
# T = 1400  Fidelity = 0.85415802
# T = 1500  Fidelity = 0.92803531
# T = 2000  Fidelity = 0.85923157
# T = 2100  Fidelity = 0.86713623
# T = 2110  Fidelity = 0.86731247
# T = 2120  Fidelity = 0.92124227
# T = 2130  Fidelity = 0.86399373
# T = 2140  Fidelity = 0.88022468
# T = 2150  Fidelity = 0.80853672
# T = 2160  Fidelity = 0.83651721
# T = 2170  Fidelity = 0.95340903
# T = 2180  Fidelity = 0.93759881
# T = 2190  Fidelity = 0.93692460
# T = 2200  Fidelity = 0.94030705
# T = 2300  Fidelity = 0.94956124
# T = 2400  Fidelity = 0.97226507
# T = 2500  Fidelity = 0.96356202
# T = 2600  Fidelity = 0.98680666
# T = 2700  Fidelity = 0.96861226
# T = 2800  Fidelity = 0.95195148
# T = 2900  Fidelity = 0.85418111
# T = 3000  Fidelity = 0.97177269
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.09849352e+00
# P0     = 0.97177269
# P1     = 0.00057591
# P0+P1  = 0.97234860
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77221454e-02
# T = 1     Fidelity = 0.17536511
# T = 2     Fidelity = 0.31566395
# T = 5     Fidelity = 0.55428135
# T = 10    Fidelity = 0.72358817
# T = 20    Fidelity = 0.82794504
# T = 30    Fidelity = 0.85152790
# T = 40    Fidelity = 0.85736480
# T = 50    Fidelity = 0.86303505
# T = 75    Fidelity = 0.88041211
# T = 100   Fidelity = 0.89668775
# T = 125   Fidelity = 0.90807458
# T = 150   Fidelity = 0.91637575
# T = 175   Fidelity = 0.92399646
# T = 200   Fidelity = 0.93312394
# T = 225   Fidelity = 0.93409893
# T = 250   Fidelity = 0.93425513
# T = 275   Fidelity = 0.94366605
# T = 300   Fidelity = 0.93376078
# T = 400   Fidelity = 0.94758447
# T = 500   Fidelity = 0.95069342
# T = 600   Fidelity = 0.95859632
# T = 700   Fidelity = 0.91377159
# T = 800   Fidelity = 0.92607813
# T = 900   Fidelity = 0.94499878
# T = 1000  Fidelity = 0.93787961
# T = 1010  Fidelity = 0.95019212
# T = 1020  Fidelity = 0.95510128
# T = 1030  Fidelity = 0.97708642
# T = 1040  Fidelity = 0.99294525
# T = 1050  Fidelity = 0.96769572
# T = 1060  Fidelity = 0.96417518
# T = 1070  Fidelity = 0.95337134
# T = 1080  Fidelity = 0.93766749
# T = 1090  Fidelity = 0.95091483
# T = 1100  Fidelity = 0.94180853
# T = 1200  Fidelity = 0.96862080
# T = 1300  Fidelity = 0.95382600
# T = 1400  Fidelity = 0.92837527
# T = 1500  Fidelity = 0.97236723
# T = 2000  Fidelity = 0.98240859
# T = 2100  Fidelity = 0.97983412
# T = 2110  Fidelity = 0.92352308
# T = 2120  Fidelity = 0.90482750
# T = 2130  Fidelity = 0.89283280
# T = 2140  Fidelity = 0.94041398
# T = 2150  Fidelity = 0.98046001
# T = 2160  Fidelity = 0.93546082
# T = 2170  Fidelity = 0.98402080
# T = 2180  Fidelity = 0.98529914
# T = 2190  Fidelity = 0.95351447
# T = 2200  Fidelity = 0.93726449
# T = 2300  Fidelity = 0.93914604
# T = 2400  Fidelity = 0.87237615
# T = 2500  Fidelity = 0.94124533
# T = 2600  Fidelity = 0.79184576
# T = 2700  Fidelity = 0.92396600
# T = 2800  Fidelity = 0.93664943
# T = 2900  Fidelity = 0.86044745
# T = 3000  Fidelity = 0.92138535
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.11402411e+00
# P0     = 0.92138535
# P1     = 0.00115791
# P0+P1  = 0.92254326
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20187623e-01
# T = 1     Fidelity = 0.28022066
# T = 2     Fidelity = 0.45263080
# T = 5     Fidelity = 0.68112637
# T = 10    Fidelity = 0.81876306
# T = 20    Fidelity = 0.89615146
# T = 30    Fidelity = 0.91760461
# T = 40    Fidelity = 0.92895647
# T = 50    Fidelity = 0.93762249
# T = 75    Fidelity = 0.95131958
# T = 100   Fidelity = 0.96158743
# T = 125   Fidelity = 0.96799629
# T = 150   Fidelity = 0.97386660
# T = 175   Fidelity = 0.97552142
# T = 200   Fidelity = 0.98134419
# T = 225   Fidelity = 0.97777875
# T = 250   Fidelity = 0.98085880
# T = 275   Fidelity = 0.97858725
# T = 300   Fidelity = 0.97958640
# T = 400   Fidelity = 0.97463716
# T = 500   Fidelity = 0.95310422
# T = 600   Fidelity = 0.93762864
# T = 700   Fidelity = 0.97941433
# T = 800   Fidelity = 0.98404611
# T = 900   Fidelity = 0.98884543
# T = 1000  Fidelity = 0.97886807
# T = 1010  Fidelity = 0.97106658
# T = 1020  Fidelity = 0.99525012
# T = 1030  Fidelity = 0.96673866
# T = 1040  Fidelity = 0.98822298
# T = 1050  Fidelity = 0.95991932
# T = 1060  Fidelity = 0.98949739
# T = 1070  Fidelity = 0.98987048
# T = 1080  Fidelity = 0.98436226
# T = 1090  Fidelity = 0.99072598
# T = 1100  Fidelity = 0.97401609
# T = 1200  Fidelity = 0.97258622
# T = 1300  Fidelity = 0.96868476
# T = 1400  Fidelity = 0.97418188
# T = 1500  Fidelity = 0.97154857
# T = 2000  Fidelity = 0.88763548
# T = 2100  Fidelity = 0.94642343
# T = 2110  Fidelity = 0.93830615
# T = 2120  Fidelity = 0.97907868
# T = 2130  Fidelity = 0.98136989
# T = 2140  Fidelity = 0.96689697
# T = 2150  Fidelity = 0.98022496
# T = 2160  Fidelity = 0.93451872
# T = 2170  Fidelity = 0.95032620
# T = 2180  Fidelity = 0.93002971
# T = 2190  Fidelity = 0.97143025
# T = 2200  Fidelity = 0.98762475
# T = 2300  Fidelity = 0.98418548
# T = 2400  Fidelity = 0.97750523
# T = 2500  Fidelity = 0.96627909
# T = 2600  Fidelity = 0.94786081
# T = 2700  Fidelity = 0.97765657
# T = 2800  Fidelity = 0.98088891
# T = 2900  Fidelity = 0.97036649
# T = 3000  Fidelity = 0.97438087
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.12899592e+00
# P0     = 0.97438087
# P1     = 0.00028124
# P0+P1  = 0.97466211
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405779e-01
# T = 1     Fidelity = 0.37903940
# T = 2     Fidelity = 0.56675652
# T = 5     Fidelity = 0.77018055
# T = 10    Fidelity = 0.87899436
# T = 20    Fidelity = 0.93512277
# T = 30    Fidelity = 0.95262357
# T = 40    Fidelity = 0.96384077
# T = 50    Fidelity = 0.96952594
# T = 75    Fidelity = 0.97944067
# T = 100   Fidelity = 0.98498973
# T = 125   Fidelity = 0.98822285
# T = 150   Fidelity = 0.99056789
# T = 175   Fidelity = 0.99125379
# T = 200   Fidelity = 0.99310754
# T = 225   Fidelity = 0.99152594
# T = 250   Fidelity = 0.99210687
# T = 275   Fidelity = 0.99348940
# T = 300   Fidelity = 0.99503536
# T = 400   Fidelity = 0.98443549
# T = 500   Fidelity = 0.98381321
# T = 600   Fidelity = 0.95618433
# T = 700   Fidelity = 0.98760967
# T = 800   Fidelity = 0.99096305
# T = 900   Fidelity = 0.98424579
# T = 1000  Fidelity = 0.99346493
# T = 1010  Fidelity = 0.99186338
# T = 1020  Fidelity = 0.99070499
# T = 1030  Fidelity = 0.97050215
# T = 1040  Fidelity = 0.97595759
# T = 1050  Fidelity = 0.98451044
# T = 1060  Fidelity = 0.97475048
# T = 1070  Fidelity = 0.98414424
# T = 1080  Fidelity = 0.96505908
# T = 1090  Fidelity = 0.95438501
# T = 1100  Fidelity = 0.96236078
# T = 1200  Fidelity = 0.95831380
# T = 1300  Fidelity = 0.97819756
# T = 1400  Fidelity = 0.96060082
# T = 1500  Fidelity = 0.98115465
# T = 2000  Fidelity = 0.98465432
# T = 2100  Fidelity = 0.98223602
# T = 2110  Fidelity = 0.99176383
# T = 2120  Fidelity = 0.98908373
# T = 2130  Fidelity = 0.99929900
# T = 2140  Fidelity = 0.97242250
# T = 2150  Fidelity = 0.97111238
# T = 2160  Fidelity = 0.98096417
# T = 2170  Fidelity = 0.98176634
# T = 2180  Fidelity = 0.99615095
# T = 2190  Fidelity = 0.97852012
# T = 2200  Fidelity = 0.97228857
# T = 2300  Fidelity = 0.97062473
# T = 2400  Fidelity = 0.99289793
# T = 2500  Fidelity = 0.96711793
# T = 2600  Fidelity = 0.97785878
# T = 2700  Fidelity = 0.99449829
# T = 2800  Fidelity = 0.98653843
# T = 2900  Fidelity = 0.94963715
# T = 3000  Fidelity = 0.95203164
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.14346139e+00
# P0     = 0.95203164
# P1     = 0.00009197
# P0+P1  = 0.95212360
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843475e-01
# T = 1     Fidelity = 0.46387579
# T = 2     Fidelity = 0.65550330
# T = 5     Fidelity = 0.83094356
# T = 10    Fidelity = 0.91701787
# T = 20    Fidelity = 0.95846798
# T = 30    Fidelity = 0.97278977
# T = 40    Fidelity = 0.97902986
# T = 50    Fidelity = 0.98359257
# T = 75    Fidelity = 0.99013933
# T = 100   Fidelity = 0.99334745
# ...
# T = 30    Fidelity = 0.99622381
# T = 40    Fidelity = 0.99587517
# T = 50    Fidelity = 0.99873403
# T = 75    Fidelity = 0.99914279
# T = 100   Fidelity = 0.99926992
# T = 125   Fidelity = 0.99931407
# T = 150   Fidelity = 0.99922837
# T = 175   Fidelity = 0.99875532
# T = 200   Fidelity = 0.99748061
# T = 225   Fidelity = 0.99747656
# T = 250   Fidelity = 0.99297865
# T = 275   Fidelity = 0.99786558
# T = 300   Fidelity = 0.98917006
# T = 400   Fidelity = 0.99783840
# T = 500   Fidelity = 0.92238588
# T = 600   Fidelity = 0.92684011
# T = 700   Fidelity = 0.90708423
# T = 800   Fidelity = 0.99077313
# T = 900   Fidelity = 0.99606493
# T = 1000  Fidelity = 0.95662111
# T = 1010  Fidelity = 0.96189635
# T = 1020  Fidelity = 0.97025837
# T = 1030  Fidelity = 0.97001731
# T = 1040  Fidelity = 0.95757551
# T = 1050  Fidelity = 0.95776724
# T = 1060  Fidelity = 0.95569486
# T = 1070  Fidelity = 0.96469151
# T = 1080  Fidelity = 0.96991547
# T = 1090  Fidelity = 0.95449323
# T = 1100  Fidelity = 0.96565681
# T = 1200  Fidelity = 0.97268794
# T = 1300  Fidelity = 0.95245610
# T = 1400  Fidelity = 0.85601476
# T = 1500  Fidelity = 0.97706199
# T = 2000  Fidelity = 0.98368686
# T = 2100  Fidelity = 0.95259809
# T = 2110  Fidelity = 0.93912608
# T = 2120  Fidelity = 0.92594234
# T = 2130  Fidelity = 0.97920145
# T = 2140  Fidelity = 0.87359419
# T = 2150  Fidelity = 0.91510901
# T = 2160  Fidelity = 0.80900573
# T = 2170  Fidelity = 0.87705916
# T = 2180  Fidelity = 0.93946076
# T = 2190  Fidelity = 0.93912398
# T = 2200  Fidelity = 0.98044736
# T = 2300  Fidelity = 0.96023758
# T = 2400  Fidelity = 0.94320796
# T = 2500  Fidelity = 0.95337941
# T = 2600  Fidelity = 0.97619496
# T = 2700  Fidelity = 0.90015569
# T = 2800  Fidelity = 0.94955462
# T = 2900  Fidelity = 0.93387057
# T = 3000  Fidelity = 0.95502522
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.13360063e+00
# P0     = 0.95502522
# P1     = 0.03989599
# P0+P1  = 0.99492121
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04394345
# T = 2     Fidelity = 0.11000652
# T = 5     Fidelity = 0.63711727
# T = 10    Fidelity = 0.97173610
# T = 20    Fidelity = 0.99251258
# T = 30    Fidelity = 0.99703390
# T = 40    Fidelity = 0.99657436
# T = 50    Fidelity = 0.99900278
# T = 75    Fidelity = 0.99938232
# T = 100   Fidelity = 0.99947882
# T = 125   Fidelity = 0.99951194
# T = 150   Fidelity = 0.99943780
# T = 175   Fidelity = 0.99843691
# T = 200   Fidelity = 0.99714948
# T = 225   Fidelity = 0.99775177
# T = 250   Fidelity = 0.99376559
# T = 275   Fidelity = 0.99230968
# T = 300   Fidelity = 0.99764128
# T = 400   Fidelity = 0.99825531
# T = 500   Fidelity = 0.96462974
# T = 600   Fidelity = 0.89225578
# T = 700   Fidelity = 0.72700978
# T = 800   Fidelity = 0.99593033
# T = 900   Fidelity = 0.99786081
# T = 1000  Fidelity = 0.96481792
# T = 1010  Fidelity = 0.96952458
# T = 1020  Fidelity = 0.95712746
# T = 1030  Fidelity = 0.96076690
# T = 1040  Fidelity = 0.95896516
# T = 1050  Fidelity = 0.97120428
# T = 1060  Fidelity = 0.97203679
# T = 1070  Fidelity = 0.96427311
# T = 1080  Fidelity = 0.96432092
# T = 1090  Fidelity = 0.93902461
# T = 1100  Fidelity = 0.97514825
# T = 1200  Fidelity = 0.95930291
# T = 1300  Fidelity = 0.97847348
# T = 1400  Fidelity = 0.83457132
# T = 1500  Fidelity = 0.97956905
# T = 2000  Fidelity = 0.86976779
# T = 2100  Fidelity = 0.91781393
# T = 2110  Fidelity = 0.77397179
# T = 2120  Fidelity = 0.92663390
# T = 2130  Fidelity = 0.89637788
# T = 2140  Fidelity = 0.94659792
# T = 2150  Fidelity = 0.99328777
# T = 2160  Fidelity = 0.96346174
# T = 2170  Fidelity = 0.98551505
# T = 2180  Fidelity = 0.97103089
# T = 2190  Fidelity = 0.97112570
# T = 2200  Fidelity = 0.98315718
# T = 2300  Fidelity = 0.96970119
# T = 2400  Fidelity = 0.97999790
# T = 2500  Fidelity = 0.91667808
# T = 2600  Fidelity = 0.90490541
# T = 2700  Fidelity = 0.91479059
# T = 2800  Fidelity = 0.95436839
# T = 2900  Fidelity = 0.98098885
# T = 3000  Fidelity = 0.93782887
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.15174389e+00
# P0     = 0.93782887
# P1     = 0.05498152
# P0+P1  = 0.99281039
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07548284
# T = 2     Fidelity = 0.16395742
# T = 5     Fidelity = 0.69568837
# T = 10    Fidelity = 0.96906236
# T = 20    Fidelity = 0.99304750
# T = 30    Fidelity = 0.99745097
# T = 40    Fidelity = 0.99699844
# T = 50    Fidelity = 0.99905649
# T = 75    Fidelity = 0.99944209
# T = 100   Fidelity = 0.99952562
# T = 125   Fidelity = 0.99954101
# T = 150   Fidelity = 0.99946151
# T = 175   Fidelity = 0.99858518
# T = 200   Fidelity = 0.99737897
# T = 225   Fidelity = 0.99710281
# T = 250   Fidelity = 0.99564536
# T = 275   Fidelity = 0.98746964
# T = 300   Fidelity = 0.99695525
# T = 400   Fidelity = 0.99824137
# T = 500   Fidelity = 0.99121737
# T = 600   Fidelity = 0.97281178
# T = 700   Fidelity = 0.89482698
# T = 800   Fidelity = 0.99741705
# T = 900   Fidelity = 0.99793213
# T = 1000  Fidelity = 0.99045356
# T = 1010  Fidelity = 0.97273442
# T = 1020  Fidelity = 0.98516999
# T = 1030  Fidelity = 0.97229765
# T = 1040  Fidelity = 0.97502828
# T = 1050  Fidelity = 0.96793966
# T = 1060  Fidelity = 0.96065832
# T = 1070  Fidelity = 0.95730937
# T = 1080  Fidelity = 0.96097239
# T = 1090  Fidelity = 0.96688631
# T = 1100  Fidelity = 0.98561214
# T = 1200  Fidelity = 0.94522918
# T = 1300  Fidelity = 0.97715889
# T = 1400  Fidelity = 0.94060206
# T = 1500  Fidelity = 0.99634143
# T = 2000  Fidelity = 0.98230981
# T = 2100  Fidelity = 0.98162463
# T = 2110  Fidelity = 0.94134101
# T = 2120  Fidelity = 0.97415058
# T = 2130  Fidelity = 0.98016661
# T = 2140  Fidelity = 0.98625137
# T = 2150  Fidelity = 0.98003517
# T = 2160  Fidelity = 0.97854447
# T = 2170  Fidelity = 0.98367853
# T = 2180  Fidelity = 0.97233858
# T = 2190  Fidelity = 0.98735221
# T = 2200  Fidelity = 0.97766942
# T = 2300  Fidelity = 0.99242361
# T = 2400  Fidelity = 0.97503683
# T = 2500  Fidelity = 0.98787940
# T = 2600  Fidelity = 0.94602338
# T = 2700  Fidelity = 0.96086255
# T = 2800  Fidelity = 0.98980126
# T = 2900  Fidelity = 0.97745990
# T = 3000  Fidelity = 0.98347871
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.16881119e+00
# P0     = 0.98347871
# P1     = 0.00816823
# P0+P1  = 0.99164694
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11432009
# T = 2     Fidelity = 0.22140264
# T = 5     Fidelity = 0.74221191
# T = 10    Fidelity = 0.96728850
# T = 20    Fidelity = 0.99346716
# T = 30    Fidelity = 0.99761608
# T = 40    Fidelity = 0.99720077
# T = 50    Fidelity = 0.99905757
# T = 75    Fidelity = 0.99940479
# T = 100   Fidelity = 0.99953303
# T = 125   Fidelity = 0.99954532
# T = 150   Fidelity = 0.99937549
# T = 175   Fidelity = 0.99846156
# T = 200   Fidelity = 0.99745914
# T = 225   Fidelity = 0.99606812
# T = 250   Fidelity = 0.99577857
# T = 275   Fidelity = 0.99485033
# T = 300   Fidelity = 0.99842793
# T = 400   Fidelity = 0.99837029
# T = 500   Fidelity = 0.99674996
# T = 600   Fidelity = 0.91433852
# T = 700   Fidelity = 0.98051098
# T = 800   Fidelity = 0.99617769
# T = 900   Fidelity = 0.99843106
# T = 1000  Fidelity = 0.99675647
# T = 1010  Fidelity = 0.99467546
# T = 1020  Fidelity = 0.97623647
# T = 1030  Fidelity = 0.96851961
# T = 1040  Fidelity = 0.99135467
# T = 1050  Fidelity = 0.98888585
# T = 1060  Fidelity = 0.98528557
# T = 1070  Fidelity = 0.98511132
# T = 1080  Fidelity = 0.98890892
# T = 1090  Fidelity = 0.96437594
# T = 1100  Fidelity = 0.97436896
# T = 1200  Fidelity = 0.94552908
# T = 1300  Fidelity = 0.99338881
# T = 1400  Fidelity = 0.99447988
# T = 1500  Fidelity = 0.99682916
# T = 2000  Fidelity = 0.99032396
# T = 2100  Fidelity = 0.99296672
# T = 2110  Fidelity = 0.99274768
# T = 2120  Fidelity = 0.98966988
# T = 2130  Fidelity = 0.97789354
# T = 2140  Fidelity = 0.98714510
# T = 2150  Fidelity = 0.98442835
# T = 2160  Fidelity = 0.99545686
# T = 2170  Fidelity = 0.97775482
# T = 2180  Fidelity = 0.98953313
# T = 2190  Fidelity = 0.97031791
# T = 2200  Fidelity = 0.98857948
# T = 2300  Fidelity = 0.98879142
# T = 2400  Fidelity = 0.97065192
# T = 2500  Fidelity = 0.98634893
# T = 2600  Fidelity = 0.95942949
# T = 2700  Fidelity = 0.90379522
# T = 2800  Fidelity = 0.97695775
# T = 2900  Fidelity = 0.99537741
# T = 3000  Fidelity = 0.98288797
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.18496501e+00
# P0     = 0.98288797
# P1     = 0.01543586
# P0+P1  = 0.99832383
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15743371
# T = 2     Fidelity = 0.27939840
# T = 5     Fidelity = 0.78041625
# T = 10    Fidelity = 0.96667646
# T = 20    Fidelity = 0.99373960
# T = 30    Fidelity = 0.99774222
# T = 40    Fidelity = 0.99736349
# T = 50    Fidelity = 0.99908455
# T = 75    Fidelity = 0.99936825
# T = 100   Fidelity = 0.99947754
# T = 125   Fidelity = 0.99948774
# T = 150   Fidelity = 0.99941755
# T = 175   Fidelity = 0.99848643
# T = 200   Fidelity = 0.99782083
# T = 225   Fidelity = 0.99584242
# T = 250   Fidelity = 0.99621729
# T = 275   Fidelity = 0.99316387
# T = 300   Fidelity = 0.99525926
# T = 400   Fidelity = 0.99815968
# T = 500   Fidelity = 0.99642372
# T = 600   Fidelity = 0.97099570
# T = 700   Fidelity = 0.96935036
# T = 800   Fidelity = 0.99794746
# T = 900   Fidelity = 0.99582963
# T = 1000  Fidelity = 0.99790397
# T = 1010  Fidelity = 0.99605549
# T = 1020  Fidelity = 0.99434766
# T = 1030  Fidelity = 0.98361834
# T = 1040  Fidelity = 0.99050391
# T = 1050  Fidelity = 0.98806248
# T = 1060  Fidelity = 0.98678601
# T = 1070  Fidelity = 0.98833121
# T = 1080  Fidelity = 0.98746925
# T = 1090  Fidelity = 0.99337809
# T = 1100  Fidelity = 0.98590505
# T = 1200  Fidelity = 0.95112919
# T = 1300  Fidelity = 0.96341940
# T = 1400  Fidelity = 0.97670366
# T = 1500  Fidelity = 0.99750558
# T = 2000  Fidelity = 0.98860320
# T = 2100  Fidelity = 0.98132225
# T = 2110  Fidelity = 0.97644198
# T = 2120  Fidelity = 0.99201329
# T = 2130  Fidelity = 0.99654180
# T = 2140  Fidelity = 0.99605621
# T = 2150  Fidelity = 0.99549643
# T = 2160  Fidelity = 0.99513398
# T = 2170  Fidelity = 0.98631360
# T = 2180  Fidelity = 0.99572739
# T = 2190  Fidelity = 0.99349124
# T = 2200  Fidelity = 0.99317392
# T = 2300  Fidelity = 0.97666070
# T = 2400  Fidelity = 0.99074780
# T = 2500  Fidelity = 0.96675960
# T = 2600  Fidelity = 0.98644228
# T = 2700  Fidelity = 0.90667650
# T = 2800  Fidelity = 0.99299348
# T = 2900  Fidelity = 0.99292915
# T = 3000  Fidelity = 0.97787316
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.20033197e+00
# P0     = 0.97787316
# P1     = 0.01768575
# P0+P1  = 0.99555890
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     20        0.9999540898      1.00972087e+00    None        None        None
# Symmetric      0.311     20        0.9999578522      1.02934439e+00    None        None        None
# Symmetric      0.522     20        0.9999503504      1.04790824e+00    None        None        None
# Symmetric      0.733     20        0.9999419256      1.06556366e+00    None        None        None
# Symmetric      0.944     20        0.9999382431      1.08242773e+00    None        None        None
# Symmetric      1.156     20        0.9999422968      1.09859358e+00    None        None        None
# Symmetric      1.367     20        0.9999491604      1.11413694e+00    None        None        None
# Symmetric      1.578     10        0.9999075804      1.12912045e+00    None        None        None
# Symmetric      1.789     10        0.9999297781      1.14359670e+00    None        None        None
# Symmetric      2.000     10        0.9999326321      1.15761039e+00    None        None        None
# Weak SSB optimised0.100     None      0.9800300608      2.42819099e-01    0.825367    0.059786    0.885153
# Weak SSB optimised0.311     None      0.9721569541      2.61171322e-01    0.87744     0.009902    0.887342
# Weak SSB optimised0.522     None      0.9932983938      2.64873214e-01    0.948969    0.000796    0.949764
# Weak SSB optimised0.733     None      0.9956210055      2.64154074e-01    0.928097    0.00318     0.931276
# Weak SSB optimised0.944     None      0.9973810973      2.26024680e-01    0.978273    0.001912    0.980185
# Weak SSB optimised1.156     None      0.9966248999      2.01656789e-01    0.980039    0.004179    0.984217
# Weak SSB optimised1.367     None      0.9939121044      1.93673930e-01    0.961689    0.000148    0.961837
# Weak SSB optimised1.578     None      0.9946829229      2.03071995e-01    0.963333    0.000461    0.963795
# Weak SSB optimised1.789     None      0.9963080395      2.25515049e-01    0.975829    0.002924    0.978753
# Weak SSB optimised2.000     None      0.9979015013      2.55131735e-01    0.985832    0.003815    0.989647
# Weak SSB       0.100     None      0.9832820056      1.36752113e-03    0.746056    0.038508    0.784564
# Weak SSB       0.311     None      0.9718336978      1.12924856e-03    0.548117    0.221902    0.770019
# Weak SSB       0.522     None      0.7026146422      1.05614584e-03    0.438171    0.051215    0.489386
# Weak SSB       0.733     None      0.8141153312      1.03672155e-03    0.464192    0.015485    0.479678
# Weak SSB       0.944     None      0.8522686577      4.41475042e-03    0.753484    0.001273    0.754757
# Weak SSB       1.156     None      0.9868066609      2.50213251e-02    0.971773    0.000576    0.972349
# Weak SSB       1.367     None      0.9929452485      6.77221454e-02    0.921385    0.001158    0.922543
# Weak SSB       1.578     None      0.9952501242      1.20187623e-01    0.974381    0.000281    0.974662
# Weak SSB       1.789     None      0.9992990008      1.71405779e-01    0.952032    9.2e-05     0.952124
# Weak SSB       2.000     None      0.9968168442      2.18843475e-01    0.991356    4.6e-05     0.991402
# Strong SSB     0.100     None      0.9978905857      6.07266718e-01    0.941811    0.009667    0.951478
# Strong SSB     0.311     None      0.9974707584      7.22062439e-01    0.763991    0.225243    0.989234
# Strong SSB     0.522     None      0.9943106485      7.78318602e-01    0.949555    0.039744    0.989299
# Strong SSB     0.733     None      0.9977075954      8.15979742e-01    0.832097    0.162841    0.994938
# Strong SSB     0.944     None      0.9989758065      8.44059983e-01    0.936684    0.057355    0.994039
# Strong SSB     1.156     None      0.9993140680      8.66317759e-01    0.955025    0.039896    0.994921
# Strong SSB     1.367     None      0.9995119382      8.84605280e-01    0.937829    0.054982    0.99281
# Strong SSB     1.578     None      0.9995410116      8.99986623e-01    0.983479    0.008168    0.991647
# Strong SSB     1.789     None      0.9995453224      9.13089337e-01    0.982888    0.015436    0.998324
# Strong SSB     2.000     None      0.9994877376      9.24370129e-01    0.977873    0.017686    0.995559

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HVA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
#============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_list,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_list,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_list,
    d2M_strong,
    d3M_strong
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 9
#       5 # First derivatives
#       6
#       7 dM_sym = np.gradient(M_sym, lambda_sym)
#       8
# ----> 9 dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)
#      10
#      11 dM_strong = np.gradient(M_strong, lambda_strong)
#      12
#
# File ~/jupyter/qiskit_env/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:1268, in gradient(f, axis, edge_order, *varargs)
#    1265 diffx = np.diff(distances)
#    1266 # if distances are constant reduce to the scalar case
#    1267 # since it brings a consistent speedup
# -> 1268 if (diffx == diffx[0]).all():
#    1269     diffx = diffx[0]
#    1270 dx[i] = diffx
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
print(type(lambda_weak_opt))
print(type(M_weak_opt))

print("len(lambda_weak_opt) =", len(lambda_weak_opt))
print("len(M_weak_opt) =", len(M_weak_opt))

print(lambda_weak_opt)
print(M_weak_opt)
# Out:
# <class 'list'>
# <class 'list'>
# len(lambda_weak_opt) = 0
# len(M_weak_opt) = 0
# []
# []

# %%
from collections import defaultdict
import numpy as np

stats = defaultdict(lambda: {"total": 0, "valid": 0})

for r in adiabatic_results:
    case = r["case"]
    stats[case]["total"] += 1

    Tmin = r["Tmin"]
    if Tmin is not None and not np.isnan(Tmin):
        stats[case]["valid"] += 1

print(stats)
# Out:
# defaultdict(<function <lambda> at 0x7d2560fa0f40>, {'Symmetric': {'total': 10, 'valid': 10}, 'Weak SSB optimised': {'total': 10, 'valid': 0}, 'Weak SSB': {'total': 10, 'valid': 0}, 'Strong SSB': {'total': 10, 'valid': 0}})

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=1$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)


    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan
    
lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009558
# T = 10    Fidelity = 0.00119310
# T = 20    Fidelity = 0.02687568
# T = 30    Fidelity = 0.09667488
# T = 40    Fidelity = 0.19609868
# T = 50    Fidelity = 0.31173320
# T = 75    Fidelity = 0.56619597
# T = 100   Fidelity = 0.72002212
# T = 125   Fidelity = 0.80739243
# T = 150   Fidelity = 0.86470597
# T = 175   Fidelity = 0.90864838
# T = 200   Fidelity = 0.94630062
# T = 225   Fidelity = 0.96686820
# T = 250   Fidelity = 0.95352330
# T = 275   Fidelity = 0.98204152
# T = 300   Fidelity = 0.96281884
# T = 400   Fidelity = 0.95496936
# T = 500   Fidelity = 0.93802352
# T = 600   Fidelity = 0.90702742
# T = 700   Fidelity = 0.99336067
# T = 800   Fidelity = 0.88211263
# T = 900   Fidelity = 0.67081820
# T = 1000  Fidelity = 0.76124242
# T = 1010  Fidelity = 0.87209685
# T = 1020  Fidelity = 0.82047179
# T = 1030  Fidelity = 0.90416283
# T = 1040  Fidelity = 0.81843704
# T = 1050  Fidelity = 0.77373010
# T = 1060  Fidelity = 0.59629710
# T = 1070  Fidelity = 0.64731902
# T = 1080  Fidelity = 0.71160718
# T = 1090  Fidelity = 0.80434541
# T = 1100  Fidelity = 0.64121696
# T = 1200  Fidelity = 0.87764907
# T = 1300  Fidelity = 0.81448567
# T = 1400  Fidelity = 0.65853384
# T = 1500  Fidelity = 0.36171856
# T = 2000  Fidelity = 0.20604657
# T = 2100  Fidelity = 0.77827863
# T = 2110  Fidelity = 0.86698935
# T = 2120  Fidelity = 0.94094596
# T = 2130  Fidelity = 0.87708257
# T = 2140  Fidelity = 0.79862261
# T = 2150  Fidelity = 0.74737901
# T = 2160  Fidelity = 0.66371344
# T = 2170  Fidelity = 0.69124832
# T = 2180  Fidelity = 0.61753995
# T = 2190  Fidelity = 0.48795049
# T = 2200  Fidelity = 0.38199917
# T = 2300  Fidelity = 0.58957350
# T = 2400  Fidelity = 0.97875447
# T = 2500  Fidelity = 0.61427238
# T = 2600  Fidelity = 0.79745242
# T = 2700  Fidelity = 0.86053629
# T = 2800  Fidelity = 0.88648347
# T = 2900  Fidelity = 0.92149086
# T = 3000  Fidelity = 0.45461763
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.32464937e-02
# P0     = 0.45461763
# P1     = 0.00000000
# P0+P1  = 0.45461763
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624068e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144424
# T = 10    Fidelity = 0.10202434
# T = 20    Fidelity = 0.52980134
# T = 30    Fidelity = 0.63895599
# T = 40    Fidelity = 0.76793401
# T = 50    Fidelity = 0.88384386
# T = 75    Fidelity = 0.94226509
# T = 100   Fidelity = 0.97306396
# T = 125   Fidelity = 0.99693257
# T = 150   Fidelity = 0.99506757
# T = 175   Fidelity = 0.99792781
# T = 200   Fidelity = 0.99964984
# T = 225   Fidelity = 0.99880428
# T = 250   Fidelity = 0.99933702
# T = 275   Fidelity = 0.99915744
# T = 300   Fidelity = 0.99935629
# T = 400   Fidelity = 0.98848645
# T = 500   Fidelity = 0.92890763
# T = 600   Fidelity = 0.29374076
# T = 700   Fidelity = 0.76586945
# T = 800   Fidelity = 0.95607693
# T = 900   Fidelity = 0.84980708
# T = 1000  Fidelity = 0.96446562
# T = 1010  Fidelity = 0.92980862
# T = 1020  Fidelity = 0.96474882
# T = 1030  Fidelity = 0.82435767
# T = 1040  Fidelity = 0.89909173
# T = 1050  Fidelity = 0.71117556
# T = 1060  Fidelity = 0.83492702
# T = 1070  Fidelity = 0.82110184
# T = 1080  Fidelity = 0.83116895
# T = 1090  Fidelity = 0.83604605
# T = 1100  Fidelity = 0.90335513
# T = 1200  Fidelity = 0.11064397
# T = 1300  Fidelity = 0.84988548
# T = 1400  Fidelity = 0.80189986
# T = 1500  Fidelity = 0.79836958
# T = 2000  Fidelity = 0.98845497
# T = 2100  Fidelity = 0.95201460
# T = 2110  Fidelity = 0.93241089
# T = 2120  Fidelity = 0.85637866
# T = 2130  Fidelity = 0.74634166
# T = 2140  Fidelity = 0.84560565
# T = 2150  Fidelity = 0.71672116
# T = 2160  Fidelity = 0.86684917
# T = 2170  Fidelity = 0.92311259
# T = 2180  Fidelity = 0.96427562
# T = 2190  Fidelity = 0.88521838
# T = 2200  Fidelity = 0.98717211
# T = 2300  Fidelity = 0.92782138
# T = 2400  Fidelity = 0.06857706
# T = 2500  Fidelity = 0.84587449
# T = 2600  Fidelity = 0.52767125
# T = 2700  Fidelity = 0.79177534
# T = 2800  Fidelity = 0.53863271
# T = 2900  Fidelity = 0.51447957
# T = 3000  Fidelity = 0.51356619
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 2.31378602e-03
# P0     = 0.51356619
# P1     = 0.00000000
# P0+P1  = 0.51356619
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043129e-07
# T = 1     Fidelity = 0.00005020
# T = 2     Fidelity = 0.00043616
# T = 5     Fidelity = 0.02724654
# T = 10    Fidelity = 0.28403208
# T = 20    Fidelity = 0.77882875
# T = 30    Fidelity = 0.80541637
# T = 40    Fidelity = 0.95120888
# T = 50    Fidelity = 0.93700169
# T = 75    Fidelity = 0.99144315
# T = 100   Fidelity = 0.99986629
# T = 125   Fidelity = 0.99944007
# T = 150   Fidelity = 0.99904940
# T = 175   Fidelity = 0.99924285
# T = 200   Fidelity = 0.99945270
# T = 225   Fidelity = 0.99949933
# T = 250   Fidelity = 0.99890033
# T = 275   Fidelity = 0.99612827
# T = 300   Fidelity = 0.99705383
# T = 400   Fidelity = 0.99511610
# T = 500   Fidelity = 0.88106921
# T = 600   Fidelity = 0.88041601
# T = 700   Fidelity = 0.92098368
# T = 800   Fidelity = 0.96566741
# T = 900   Fidelity = 0.82209356
# T = 1000  Fidelity = 0.91769691
# T = 1010  Fidelity = 0.86195603
# T = 1020  Fidelity = 0.92763460
# T = 1030  Fidelity = 0.69513410
# T = 1040  Fidelity = 0.72661883
# T = 1050  Fidelity = 0.83864720
# T = 1060  Fidelity = 0.63688632
# T = 1070  Fidelity = 0.82242094
# T = 1080  Fidelity = 0.97330358
# T = 1090  Fidelity = 0.88951350
# T = 1100  Fidelity = 0.92650255
# T = 1200  Fidelity = 0.75828664
# T = 1300  Fidelity = 0.87494813
# T = 1400  Fidelity = 0.93568065
# T = 1500  Fidelity = 0.95348930
# T = 2000  Fidelity = 0.98224104
# T = 2100  Fidelity = 0.86491833
# T = 2110  Fidelity = 0.89725959
# T = 2120  Fidelity = 0.87989035
# T = 2130  Fidelity = 0.74496147
# T = 2140  Fidelity = 0.93563502
# T = 2150  Fidelity = 0.89305561
# T = 2160  Fidelity = 0.92600700
# T = 2170  Fidelity = 0.85546847
# T = 2180  Fidelity = 0.91097151
# T = 2190  Fidelity = 0.99174404
# T = 2200  Fidelity = 0.85493815
# T = 2300  Fidelity = 0.98181747
# T = 2400  Fidelity = 0.79968377
# T = 2500  Fidelity = 0.98519368
# T = 2600  Fidelity = 0.94604665
# T = 2700  Fidelity = 0.97626003
# T = 2800  Fidelity = 0.98325130
# T = 2900  Fidelity = 0.84016100
# T = 3000  Fidelity = 0.88894230
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 4.34903186e-07
# P0     = 0.88894230
# P1     = 0.00000001
# P0+P1  = 0.88894232
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155120
# T = 2     Fidelity = 0.00639465
# T = 5     Fidelity = 0.08480217
# T = 10    Fidelity = 0.38784447
# T = 20    Fidelity = 0.90883841
# T = 30    Fidelity = 0.89421410
# T = 40    Fidelity = 0.97222070
# T = 50    Fidelity = 0.99231856
# T = 75    Fidelity = 0.99922645
# T = 100   Fidelity = 0.99951411
# T = 125   Fidelity = 0.99949741
# T = 150   Fidelity = 0.99952802
# T = 175   Fidelity = 0.99955861
# T = 200   Fidelity = 0.99956682
# T = 225   Fidelity = 0.99929881
# T = 250   Fidelity = 0.99852720
# T = 275   Fidelity = 0.99867136
# T = 300   Fidelity = 0.99707352
# T = 400   Fidelity = 0.99357610
# T = 500   Fidelity = 0.98383269
# T = 600   Fidelity = 0.95927153
# T = 700   Fidelity = 0.97670159
# T = 800   Fidelity = 0.96520759
# T = 900   Fidelity = 0.90688723
# T = 1000  Fidelity = 0.97966288
# T = 1010  Fidelity = 0.94484815
# T = 1020  Fidelity = 0.89884196
# T = 1030  Fidelity = 0.94041862
# T = 1040  Fidelity = 0.69071117
# T = 1050  Fidelity = 0.63017146
# T = 1060  Fidelity = 0.82033851
# T = 1070  Fidelity = 0.51623655
# T = 1080  Fidelity = 0.53453173
# T = 1090  Fidelity = 0.81932668
# T = 1100  Fidelity = 0.67514616
# T = 1200  Fidelity = 0.95029369
# T = 1300  Fidelity = 0.96850385
# T = 1400  Fidelity = 0.94798315
# T = 1500  Fidelity = 0.95586882
# T = 2000  Fidelity = 0.98408429
# T = 2100  Fidelity = 0.98593922
# T = 2110  Fidelity = 0.94905987
# T = 2120  Fidelity = 0.68594841
# T = 2130  Fidelity = 0.75503675
# T = 2140  Fidelity = 0.93816857
# T = 2150  Fidelity = 0.78558225
# T = 2160  Fidelity = 0.81648473
# T = 2170  Fidelity = 0.88915309
# T = 2180  Fidelity = 0.73056202
# T = 2190  Fidelity = 0.53069618
# T = 2200  Fidelity = 0.79820307
# T = 2300  Fidelity = 0.84922951
# T = 2400  Fidelity = 0.95471335
# T = 2500  Fidelity = 0.98788045
# T = 2600  Fidelity = 0.92781381
# T = 2700  Fidelity = 0.94254111
# T = 2800  Fidelity = 0.95688488
# T = 2900  Fidelity = 0.96940513
# T = 3000  Fidelity = 0.92484259
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.23425681e-06
# P0     = 0.92484259
# P1     = 0.00000001
# P0+P1  = 0.92484260
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01057886
# T = 2     Fidelity = 0.02894503
# T = 5     Fidelity = 0.16448921
# T = 10    Fidelity = 0.46784248
# T = 20    Fidelity = 0.92252560
# T = 30    Fidelity = 0.97978574
# T = 40    Fidelity = 0.97237659
# T = 50    Fidelity = 0.99388014
# T = 75    Fidelity = 0.99721138
# T = 100   Fidelity = 0.99909662
# T = 125   Fidelity = 0.99948416
# T = 150   Fidelity = 0.99955593
# T = 175   Fidelity = 0.99957311
# T = 200   Fidelity = 0.99955111
# T = 225   Fidelity = 0.99830731
# T = 250   Fidelity = 0.99974712
# T = 275   Fidelity = 0.99954340
# T = 300   Fidelity = 0.99878843
# T = 400   Fidelity = 0.96450616
# T = 500   Fidelity = 0.99787814
# T = 600   Fidelity = 0.97692602
# T = 700   Fidelity = 0.99524981
# T = 800   Fidelity = 0.87870078
# T = 900   Fidelity = 0.85511301
# T = 1000  Fidelity = 0.68920650
# T = 1010  Fidelity = 0.70818077
# T = 1020  Fidelity = 0.82616994
# T = 1030  Fidelity = 0.81914813
# T = 1040  Fidelity = 0.84958293
# T = 1050  Fidelity = 0.97321857
# T = 1060  Fidelity = 0.93180745
# T = 1070  Fidelity = 0.92446927
# T = 1080  Fidelity = 0.99456473
# T = 1090  Fidelity = 0.98601644
# T = 1100  Fidelity = 0.93150959
# T = 1200  Fidelity = 0.97027922
# T = 1300  Fidelity = 0.94814235
# T = 1400  Fidelity = 0.97769636
# T = 1500  Fidelity = 0.98759892
# T = 2000  Fidelity = 0.80760719
# T = 2100  Fidelity = 0.98774109
# T = 2110  Fidelity = 0.98407613
# T = 2120  Fidelity = 0.99916291
# T = 2130  Fidelity = 0.93890325
# T = 2140  Fidelity = 0.89442627
# T = 2150  Fidelity = 0.99419142
# T = 2160  Fidelity = 0.99174646
# T = 2170  Fidelity = 0.99548270
# T = 2180  Fidelity = 0.97033063
# T = 2190  Fidelity = 0.99576639
# T = 2200  Fidelity = 0.87350834
# T = 2300  Fidelity = 0.97991934
# T = 2400  Fidelity = 0.95748073
# T = 2500  Fidelity = 0.91873484
# T = 2600  Fidelity = 0.87795137
# T = 2700  Fidelity = 0.99118626
# T = 2800  Fidelity = 0.97071961
# T = 2900  Fidelity = 0.99439565
# T = 3000  Fidelity = 0.91184144
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 2.43145527e-04
# P0     = 0.91184144
# P1     = 0.00000001
# P0+P1  = 0.91184145
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03666897
# T = 2     Fidelity = 0.07740868
# T = 5     Fidelity = 0.25990095
# T = 10    Fidelity = 0.54098409
# T = 20    Fidelity = 0.90447747
# T = 30    Fidelity = 0.99651127
# T = 40    Fidelity = 0.99548434
# T = 50    Fidelity = 0.99311639
# T = 75    Fidelity = 0.99891328
# T = 100   Fidelity = 0.99895801
# T = 125   Fidelity = 0.99937551
# T = 150   Fidelity = 0.99956640
# T = 175   Fidelity = 0.99954287
# T = 200   Fidelity = 0.99966597
# T = 225   Fidelity = 0.99967521
# T = 250   Fidelity = 0.99950305
# T = 275   Fidelity = 0.99924606
# T = 300   Fidelity = 0.99698013
# T = 400   Fidelity = 0.99737305
# T = 500   Fidelity = 0.99675862
# T = 600   Fidelity = 0.96114655
# T = 700   Fidelity = 0.94916242
# T = 800   Fidelity = 0.87155676
# T = 900   Fidelity = 0.90725398
# T = 1000  Fidelity = 0.94416277
# T = 1010  Fidelity = 0.98930474
# T = 1020  Fidelity = 0.97223580
# T = 1030  Fidelity = 0.98940196
# T = 1040  Fidelity = 0.99372906
# T = 1050  Fidelity = 0.99487021
# T = 1060  Fidelity = 0.99478772
# T = 1070  Fidelity = 0.99051425
# T = 1080  Fidelity = 0.99643075
# T = 1090  Fidelity = 0.98457368
# T = 1100  Fidelity = 0.99487534
# T = 1200  Fidelity = 0.98642732
# T = 1300  Fidelity = 0.99107462
# T = 1400  Fidelity = 0.97068904
# T = 1500  Fidelity = 0.95679713
# T = 2000  Fidelity = 0.97006108
# T = 2100  Fidelity = 0.98551092
# T = 2110  Fidelity = 0.99406435
# T = 2120  Fidelity = 0.98611999
# T = 2130  Fidelity = 0.96590638
# T = 2140  Fidelity = 0.99036118
# T = 2150  Fidelity = 0.97883738
# T = 2160  Fidelity = 0.96955980
# T = 2170  Fidelity = 0.98636155
# T = 2180  Fidelity = 0.97386616
# T = 2190  Fidelity = 0.95341322
# T = 2200  Fidelity = 0.99146901
# T = 2300  Fidelity = 0.94345673
# T = 2400  Fidelity = 0.99301121
# T = 2500  Fidelity = 0.99409163
# T = 2600  Fidelity = 0.92880841
# T = 2700  Fidelity = 0.95932337
# T = 2800  Fidelity = 0.91736934
# T = 2900  Fidelity = 0.91278159
# T = 3000  Fidelity = 0.97333854
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.85715182e-03
# P0     = 0.97333854
# P1     = 0.00000011
# P0+P1  = 0.97333865
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08777284
# T = 2     Fidelity = 0.15531863
# T = 5     Fidelity = 0.36745779
# T = 10    Fidelity = 0.61616486
# T = 20    Fidelity = 0.89398753
# T = 30    Fidelity = 0.98166784
# T = 40    Fidelity = 0.99755064
# T = 50    Fidelity = 0.99744426
# T = 75    Fidelity = 0.99779496
# T = 100   Fidelity = 0.99895101
# T = 125   Fidelity = 0.99919413
# T = 150   Fidelity = 0.99945909
# T = 175   Fidelity = 0.99950931
# T = 200   Fidelity = 0.99945387
# T = 225   Fidelity = 0.99962666
# T = 250   Fidelity = 0.99959890
# T = 275   Fidelity = 0.99912402
# T = 300   Fidelity = 0.99730339
# T = 400   Fidelity = 0.99558789
# T = 500   Fidelity = 0.99654676
# T = 600   Fidelity = 0.98096605
# T = 700   Fidelity = 0.91187817
# T = 800   Fidelity = 0.94693955
# T = 900   Fidelity = 0.82690270
# T = 1000  Fidelity = 0.99746178
# T = 1010  Fidelity = 0.99835075
# T = 1020  Fidelity = 0.99668964
# T = 1030  Fidelity = 0.99201468
# T = 1040  Fidelity = 0.99600988
# T = 1050  Fidelity = 0.99501038
# T = 1060  Fidelity = 0.98823136
# T = 1070  Fidelity = 0.98670170
# T = 1080  Fidelity = 0.98758605
# T = 1090  Fidelity = 0.98910888
# T = 1100  Fidelity = 0.99858924
# T = 1200  Fidelity = 0.99702701
# T = 1300  Fidelity = 0.97798572
# T = 1400  Fidelity = 0.98026438
# T = 1500  Fidelity = 0.93222663
# T = 2000  Fidelity = 0.98197687
# T = 2100  Fidelity = 0.99540431
# T = 2110  Fidelity = 0.97331237
# T = 2120  Fidelity = 0.98950566
# T = 2130  Fidelity = 0.98938572
# T = 2140  Fidelity = 0.94154869
# T = 2150  Fidelity = 0.95240935
# T = 2160  Fidelity = 0.98702627
# T = 2170  Fidelity = 0.99182923
# T = 2180  Fidelity = 0.96631119
# T = 2190  Fidelity = 0.98837324
# T = 2200  Fidelity = 0.97367394
# T = 2300  Fidelity = 0.98987250
# T = 2400  Fidelity = 0.99345281
# T = 2500  Fidelity = 0.98832261
# T = 2600  Fidelity = 0.95013778
# T = 2700  Fidelity = 0.79270752
# T = 2800  Fidelity = 0.99377376
# T = 2900  Fidelity = 0.99877353
# T = 3000  Fidelity = 0.98431654
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 7.28366396e-03
# P0     = 0.98431654
# P1     = 0.00000001
# P0+P1  = 0.98431655
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16572932
# T = 2     Fidelity = 0.25905067
# T = 5     Fidelity = 0.48150952
# T = 10    Fidelity = 0.69440861
# T = 20    Fidelity = 0.90354865
# T = 30    Fidelity = 0.97293487
# T = 40    Fidelity = 0.99114326
# T = 50    Fidelity = 0.99505956
# T = 75    Fidelity = 0.99762498
# T = 100   Fidelity = 0.99862422
# T = 125   Fidelity = 0.99898607
# T = 150   Fidelity = 0.99926305
# T = 175   Fidelity = 0.99944861
# T = 200   Fidelity = 0.99953807
# T = 225   Fidelity = 0.99954472
# T = 250   Fidelity = 0.99953627
# T = 275   Fidelity = 0.99925505
# T = 300   Fidelity = 0.99661873
# T = 400   Fidelity = 0.99637786
# T = 500   Fidelity = 0.99372033
# T = 600   Fidelity = 0.99084548
# T = 700   Fidelity = 0.96641588
# T = 800   Fidelity = 0.94022348
# T = 900   Fidelity = 0.98011444
# T = 1000  Fidelity = 0.99262814
# T = 1010  Fidelity = 0.99493361
# T = 1020  Fidelity = 0.99280046
# T = 1030  Fidelity = 0.99127096
# T = 1040  Fidelity = 0.99521998
# T = 1050  Fidelity = 0.99577682
# T = 1060  Fidelity = 0.99588738
# T = 1070  Fidelity = 0.99515036
# T = 1080  Fidelity = 0.99891612
# T = 1090  Fidelity = 0.98910545
# T = 1100  Fidelity = 0.99831879
# T = 1200  Fidelity = 0.99199148
# T = 1300  Fidelity = 0.99236877
# T = 1400  Fidelity = 0.99561354
# T = 1500  Fidelity = 0.93940004
# T = 2000  Fidelity = 0.99567070
# T = 2100  Fidelity = 0.98859185
# T = 2110  Fidelity = 0.98207127
# T = 2120  Fidelity = 0.99936660
# T = 2130  Fidelity = 0.99750782
# T = 2140  Fidelity = 0.98702618
# T = 2150  Fidelity = 0.98168588
# T = 2160  Fidelity = 0.99252616
# T = 2170  Fidelity = 0.98321131
# T = 2180  Fidelity = 0.99066048
# T = 2190  Fidelity = 0.99623739
# T = 2200  Fidelity = 0.98024956
# T = 2300  Fidelity = 0.98379790
# T = 2400  Fidelity = 0.99589112
# T = 2500  Fidelity = 0.84958627
# T = 2600  Fidelity = 0.82574887
# T = 2700  Fidelity = 0.98255292
# T = 2800  Fidelity = 0.99824873
# T = 2900  Fidelity = 0.99459374
# T = 3000  Fidelity = 0.95907663
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.91268343e-02
# P0     = 0.95907663
# P1     = 0.00000035
# P0+P1  = 0.95907698
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26383971
# T = 2     Fidelity = 0.37674753
# T = 5     Fidelity = 0.59249214
# T = 10    Fidelity = 0.76993161
# T = 20    Fidelity = 0.92539700
# T = 30    Fidelity = 0.97247891
# T = 40    Fidelity = 0.98680968
# T = 50    Fidelity = 0.99322794
# T = 75    Fidelity = 0.99712161
# T = 100   Fidelity = 0.99829642
# T = 125   Fidelity = 0.99883933
# T = 150   Fidelity = 0.99913387
# T = 175   Fidelity = 0.99927654
# T = 200   Fidelity = 0.99940542
# T = 225   Fidelity = 0.99949596
# T = 250   Fidelity = 0.99927763
# T = 275   Fidelity = 0.99932616
# T = 300   Fidelity = 0.99703390
# T = 400   Fidelity = 0.99656342
# T = 500   Fidelity = 0.99297264
# T = 600   Fidelity = 0.99384687
# T = 700   Fidelity = 0.98813448
# T = 800   Fidelity = 0.90985835
# T = 900   Fidelity = 0.99834463
# T = 1000  Fidelity = 0.99696615
# T = 1010  Fidelity = 0.99755886
# T = 1020  Fidelity = 0.99850092
# T = 1030  Fidelity = 0.99051601
# T = 1040  Fidelity = 0.99830637
# T = 1050  Fidelity = 0.99743056
# T = 1060  Fidelity = 0.99564828
# T = 1070  Fidelity = 0.99142827
# T = 1080  Fidelity = 0.99965321
# T = 1090  Fidelity = 0.99271870
# T = 1100  Fidelity = 0.99845563
# T = 1200  Fidelity = 0.99885984
# T = 1300  Fidelity = 0.98506406
# T = 1400  Fidelity = 0.97914400
# T = 1500  Fidelity = 0.99137571
# T = 2000  Fidelity = 0.99474085
# T = 2100  Fidelity = 0.99927007
# T = 2110  Fidelity = 0.98233470
# T = 2120  Fidelity = 0.99167407
# T = 2130  Fidelity = 0.99320507
# T = 2140  Fidelity = 0.99906797
# T = 2150  Fidelity = 0.97776354
# T = 2160  Fidelity = 0.97915397
# T = 2170  Fidelity = 0.99198942
# T = 2180  Fidelity = 0.99771338
# T = 2190  Fidelity = 0.98699270
# T = 2200  Fidelity = 0.98972811
# T = 2300  Fidelity = 0.97696844
# T = 2400  Fidelity = 0.93212679
# T = 2500  Fidelity = 0.88396200
# T = 2600  Fidelity = 0.99010611
# T = 2700  Fidelity = 0.99933932
# T = 2800  Fidelity = 0.99447126
# T = 2900  Fidelity = 0.97886840
# T = 3000  Fidelity = 0.99835349
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 3.86332944e-02
# P0     = 0.99835349
# P1     = 0.00000003
# P0+P1  = 0.99835353
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36890160
# T = 2     Fidelity = 0.49288816
# T = 5     Fidelity = 0.69016460
# T = 10    Fidelity = 0.83507119
# T = 20    Fidelity = 0.94697643
# T = 30    Fidelity = 0.97601738
# T = 40    Fidelity = 0.98833597
# T = 50    Fidelity = 0.99293189
# T = 75    Fidelity = 0.99693711
# T = 100   Fidelity = 0.99823110
# T = 125   Fidelity = 0.99885270
# T = 150   Fidelity = 0.99920619
# T = 175   Fidelity = 0.99943186
# T = 200   Fidelity = 0.99952167
# T = 225   Fidelity = 0.99951450
# T = 250   Fidelity = 0.99895841
# T = 275   Fidelity = 0.99902167
# T = 300   Fidelity = 0.99805429
# T = 400   Fidelity = 0.99731713
# T = 500   Fidelity = 0.99606844
# T = 600   Fidelity = 0.98320856
# T = 700   Fidelity = 0.98766865
# T = 800   Fidelity = 0.88512722
# T = 900   Fidelity = 0.99592010
# T = 1000  Fidelity = 0.99915866
# T = 1010  Fidelity = 0.99847949
# T = 1020  Fidelity = 0.99447249
# T = 1030  Fidelity = 0.99268816
# T = 1040  Fidelity = 0.99834332
# T = 1050  Fidelity = 0.99840396
# T = 1060  Fidelity = 0.99518916
# T = 1070  Fidelity = 0.99412231
# T = 1080  Fidelity = 0.99908265
# T = 1090  Fidelity = 0.98829507
# T = 1100  Fidelity = 0.99401137
# T = 1200  Fidelity = 0.99747602
# T = 1300  Fidelity = 0.99630761
# T = 1400  Fidelity = 0.99243644
# T = 1500  Fidelity = 0.99289168
# T = 2000  Fidelity = 0.99160559
# T = 2100  Fidelity = 0.99126805
# T = 2110  Fidelity = 0.99426277
# T = 2120  Fidelity = 0.98759657
# T = 2130  Fidelity = 0.96898602
# T = 2140  Fidelity = 0.99408085
# T = 2150  Fidelity = 0.98684388
# T = 2160  Fidelity = 0.99128104
# T = 2170  Fidelity = 0.97949163
# T = 2180  Fidelity = 0.99754514
# T = 2190  Fidelity = 0.99223408
# T = 2200  Fidelity = 0.98358737
# T = 2300  Fidelity = 0.97214809
# T = 2400  Fidelity = 0.95309788
# T = 2500  Fidelity = 0.99810235
# T = 2600  Fidelity = 0.99372025
# T = 2700  Fidelity = 0.99608945
# T = 2800  Fidelity = 0.99405086
# T = 2900  Fidelity = 0.98778318
# T = 3000  Fidelity = 0.96008672
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 6.51311241e-02
# P0     = 0.96008672
# P1     = 0.00000081
# P0+P1  = 0.96008753
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.62014168
# T = 2     Fidelity = 0.64851512
# T = 5     Fidelity = 0.70455375
# T = 10    Fidelity = 0.75874085
# T = 20    Fidelity = 0.82471622
# T = 30    Fidelity = 0.86522195
# T = 40    Fidelity = 0.89349306
# T = 50    Fidelity = 0.91385951
# T = 75    Fidelity = 0.94544453
# T = 100   Fidelity = 0.96291430
# T = 125   Fidelity = 0.97187589
# T = 150   Fidelity = 0.97700174
# T = 175   Fidelity = 0.97929320
# T = 200   Fidelity = 0.98475794
# T = 225   Fidelity = 0.97622551
# T = 250   Fidelity = 0.98319109
# T = 275   Fidelity = 0.95409318
# T = 300   Fidelity = 0.93747162
# T = 400   Fidelity = 0.96932840
# T = 500   Fidelity = 0.97571792
# T = 600   Fidelity = 0.94353243
# T = 700   Fidelity = 0.81274365
# T = 800   Fidelity = 0.93806913
# T = 900   Fidelity = 0.98175692
# T = 1000  Fidelity = 0.97406553
# T = 1010  Fidelity = 0.95405533
# T = 1020  Fidelity = 0.94156636
# T = 1030  Fidelity = 0.95540460
# T = 1040  Fidelity = 0.96693694
# T = 1050  Fidelity = 0.96354144
# T = 1060  Fidelity = 0.96549108
# T = 1070  Fidelity = 0.97028455
# T = 1080  Fidelity = 0.98642726
# T = 1090  Fidelity = 0.98956865
# T = 1100  Fidelity = 0.98294494
# T = 1200  Fidelity = 0.98590596
# T = 1300  Fidelity = 0.97140504
# T = 1400  Fidelity = 0.85169040
# T = 1500  Fidelity = 0.91425440
# T = 2000  Fidelity = 0.93867087
# T = 2100  Fidelity = 0.88525370
# T = 2110  Fidelity = 0.88071091
# T = 2120  Fidelity = 0.85210607
# T = 2130  Fidelity = 0.83677939
# T = 2140  Fidelity = 0.83773396
# T = 2150  Fidelity = 0.84346149
# T = 2160  Fidelity = 0.85559369
# T = 2170  Fidelity = 0.87352765
# T = 2180  Fidelity = 0.87279301
# T = 2190  Fidelity = 0.87842295
# T = 2200  Fidelity = 0.89445543
# T = 2300  Fidelity = 0.92464705
# T = 2400  Fidelity = 0.95738522
# T = 2500  Fidelity = 0.97298728
# T = 2600  Fidelity = 0.98378313
# T = 2700  Fidelity = 0.96923764
# T = 2800  Fidelity = 0.89338009
# T = 2900  Fidelity = 0.88543432
# T = 3000  Fidelity = 0.95858855
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.25474723e-01
# P0     = 0.95858855
# P1     = 0.02924609
# P0+P1  = 0.98783465
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.71151063
# T = 2     Fidelity = 0.71975623
# T = 5     Fidelity = 0.74879478
# T = 10    Fidelity = 0.77985740
# T = 20    Fidelity = 0.81691900
# T = 30    Fidelity = 0.84114788
# T = 40    Fidelity = 0.85902539
# T = 50    Fidelity = 0.87336242
# T = 75    Fidelity = 0.89952774
# T = 100   Fidelity = 0.91786786
# T = 125   Fidelity = 0.93175648
# T = 150   Fidelity = 0.94062275
# T = 175   Fidelity = 0.95131810
# T = 200   Fidelity = 0.95622512
# T = 225   Fidelity = 0.96114961
# T = 250   Fidelity = 0.96077245
# T = 275   Fidelity = 0.97268472
# T = 300   Fidelity = 0.97257772
# T = 400   Fidelity = 0.97675840
# T = 500   Fidelity = 0.96558978
# T = 600   Fidelity = 0.97114386
# T = 700   Fidelity = 0.98016626
# T = 800   Fidelity = 0.94400860
# T = 900   Fidelity = 0.91831121
# T = 1000  Fidelity = 0.91377551
# T = 1010  Fidelity = 0.91261249
# T = 1020  Fidelity = 0.90881273
# T = 1030  Fidelity = 0.90744991
# T = 1040  Fidelity = 0.90272891
# T = 1050  Fidelity = 0.90266926
# T = 1060  Fidelity = 0.90178177
# T = 1070  Fidelity = 0.90412832
# T = 1080  Fidelity = 0.90290515
# T = 1090  Fidelity = 0.90459609
# T = 1100  Fidelity = 0.90149594
# T = 1200  Fidelity = 0.92478132
# T = 1300  Fidelity = 0.95630612
# T = 1400  Fidelity = 0.96317621
# T = 1500  Fidelity = 0.96773494
# T = 2000  Fidelity = 0.95156448
# T = 2100  Fidelity = 0.94299627
# T = 2110  Fidelity = 0.94740426
# T = 2120  Fidelity = 0.94908647
# T = 2130  Fidelity = 0.94872862
# T = 2140  Fidelity = 0.94469545
# T = 2150  Fidelity = 0.94707006
# T = 2160  Fidelity = 0.94480361
# T = 2170  Fidelity = 0.94160231
# T = 2180  Fidelity = 0.93827031
# T = 2190  Fidelity = 0.93393721
# T = 2200  Fidelity = 0.93424625
# T = 2300  Fidelity = 0.90338865
# T = 2400  Fidelity = 0.96319311
# T = 2500  Fidelity = 0.97215268
# T = 2600  Fidelity = 0.93920584
# T = 2700  Fidelity = 0.92299826
# T = 2800  Fidelity = 0.92819738
# T = 2900  Fidelity = 0.94036903
# T = 3000  Fidelity = 0.95779772
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.71621181e-01
# P0     = 0.95779772
# P1     = 0.01962715
# P0+P1  = 0.97742486
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.98608528
# T = 2     Fidelity = 0.99341831
# T = 5     Fidelity = 0.99497184
# T = 10    Fidelity = 0.99548727
# T = 20    Fidelity = 0.99553914
# T = 30    Fidelity = 0.99555912
# T = 40    Fidelity = 0.99556695
# T = 50    Fidelity = 0.99554749
# T = 75    Fidelity = 0.99556087
# T = 100   Fidelity = 0.99557853
# T = 125   Fidelity = 0.99560506
# T = 150   Fidelity = 0.99561876
# T = 175   Fidelity = 0.99449582
# T = 200   Fidelity = 0.99517796
# T = 225   Fidelity = 0.99520556
# T = 250   Fidelity = 0.99547235
# T = 275   Fidelity = 0.99556376
# T = 300   Fidelity = 0.99553989
# T = 400   Fidelity = 0.99535160
# T = 500   Fidelity = 0.99557156
# T = 600   Fidelity = 0.99525921
# T = 700   Fidelity = 0.99495446
# T = 800   Fidelity = 0.99535668
# T = 900   Fidelity = 0.99516250
# T = 1000  Fidelity = 0.99516169
# T = 1010  Fidelity = 0.99503234
# T = 1020  Fidelity = 0.99540498
# T = 1030  Fidelity = 0.99522842
# T = 1040  Fidelity = 0.99581591
# T = 1050  Fidelity = 0.99600864
# T = 1060  Fidelity = 0.99594911
# T = 1070  Fidelity = 0.99490308
# T = 1080  Fidelity = 0.99582264
# T = 1090  Fidelity = 0.99569468
# T = 1100  Fidelity = 0.99570227
# T = 1200  Fidelity = 0.99463737
# T = 1300  Fidelity = 0.99516561
# T = 1400  Fidelity = 0.99595651
# T = 1500  Fidelity = 0.99562505
# T = 2000  Fidelity = 0.99553415
# T = 2100  Fidelity = 0.99477493
# T = 2110  Fidelity = 0.99494739
# T = 2120  Fidelity = 0.99568328
# T = 2130  Fidelity = 0.99581700
# T = 2140  Fidelity = 0.99492870
# T = 2150  Fidelity = 0.99539172
# T = 2160  Fidelity = 0.99557743
# T = 2170  Fidelity = 0.99563116
# T = 2180  Fidelity = 0.99529517
# T = 2190  Fidelity = 0.99480459
# T = 2200  Fidelity = 0.99519687
# T = 2300  Fidelity = 0.99549752
# T = 2400  Fidelity = 0.99497500
# T = 2500  Fidelity = 0.99519847
# T = 2600  Fidelity = 0.99557160
# T = 2700  Fidelity = 0.99547913
# T = 2800  Fidelity = 0.99500268
# T = 2900  Fidelity = 0.99463837
# T = 3000  Fidelity = 0.99589730
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 6.49620533e-01
# P0     = 0.99589730
# P1     = 0.00001887
# P0+P1  = 0.99591617
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98378100
# T = 2     Fidelity = 0.99327311
# T = 5     Fidelity = 0.99574192
# T = 10    Fidelity = 0.99675874
# T = 20    Fidelity = 0.99702315
# T = 30    Fidelity = 0.99711226
# T = 40    Fidelity = 0.99716330
# T = 50    Fidelity = 0.99721123
# T = 75    Fidelity = 0.99725269
# T = 100   Fidelity = 0.99729151
# T = 125   Fidelity = 0.99732089
# T = 150   Fidelity = 0.99724240
# T = 175   Fidelity = 0.99664489
# T = 200   Fidelity = 0.99720625
# T = 225   Fidelity = 0.99682664
# T = 250   Fidelity = 0.99665520
# T = 275   Fidelity = 0.99753464
# T = 300   Fidelity = 0.99772485
# T = 400   Fidelity = 0.99704838
# T = 500   Fidelity = 0.99576272
# T = 600   Fidelity = 0.99702277
# T = 700   Fidelity = 0.99650783
# T = 800   Fidelity = 0.99723871
# T = 900   Fidelity = 0.99771416
# T = 1000  Fidelity = 0.99603920
# T = 1010  Fidelity = 0.99669887
# T = 1020  Fidelity = 0.99688195
# T = 1030  Fidelity = 0.99689174
# T = 1040  Fidelity = 0.99672601
# T = 1050  Fidelity = 0.99654853
# T = 1060  Fidelity = 0.99675887
# T = 1070  Fidelity = 0.99705163
# T = 1080  Fidelity = 0.99716233
# T = 1090  Fidelity = 0.99707175
# T = 1100  Fidelity = 0.99683451
# T = 1200  Fidelity = 0.99708687
# T = 1300  Fidelity = 0.99729951
# T = 1400  Fidelity = 0.99714440
# T = 1500  Fidelity = 0.99675284
# T = 2000  Fidelity = 0.99664787
# T = 2100  Fidelity = 0.99685529
# T = 2110  Fidelity = 0.99615233
# T = 2120  Fidelity = 0.99664649
# T = 2130  Fidelity = 0.99687175
# T = 2140  Fidelity = 0.99702157
# T = 2150  Fidelity = 0.99656473
# T = 2160  Fidelity = 0.99643122
# T = 2170  Fidelity = 0.99696550
# T = 2180  Fidelity = 0.99723612
# T = 2190  Fidelity = 0.99678941
# T = 2200  Fidelity = 0.99696288
# T = 2300  Fidelity = 0.99703171
# T = 2400  Fidelity = 0.99716818
# T = 2500  Fidelity = 0.99694590
# T = 2600  Fidelity = 0.99701973
# T = 2700  Fidelity = 0.99700747
# T = 2800  Fidelity = 0.99696368
# T = 2900  Fidelity = 0.99723725
# T = 3000  Fidelity = 0.99667660
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 5.37111683e-01
# P0     = 0.99667660
# P1     = 0.00000101
# P0+P1  = 0.99667761
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97616119
# T = 2     Fidelity = 0.98798144
# T = 5     Fidelity = 0.99339380
# T = 10    Fidelity = 0.99487740
# T = 20    Fidelity = 0.99581598
# T = 30    Fidelity = 0.99630406
# T = 40    Fidelity = 0.99657374
# T = 50    Fidelity = 0.99679869
# T = 75    Fidelity = 0.99708001
# T = 100   Fidelity = 0.99731284
# T = 125   Fidelity = 0.99743102
# T = 150   Fidelity = 0.99747405
# T = 175   Fidelity = 0.99779405
# T = 200   Fidelity = 0.99731353
# T = 225   Fidelity = 0.99748582
# T = 250   Fidelity = 0.99740083
# T = 275   Fidelity = 0.99753594
# T = 300   Fidelity = 0.99792289
# T = 400   Fidelity = 0.99784060
# T = 500   Fidelity = 0.99793552
# T = 600   Fidelity = 0.99748165
# T = 700   Fidelity = 0.99770222
# T = 800   Fidelity = 0.99841545
# T = 900   Fidelity = 0.99805972
# T = 1000  Fidelity = 0.99822571
# T = 1010  Fidelity = 0.99846554
# T = 1020  Fidelity = 0.99841367
# T = 1030  Fidelity = 0.99832524
# T = 1040  Fidelity = 0.99827756
# T = 1050  Fidelity = 0.99848629
# T = 1060  Fidelity = 0.99839159
# T = 1070  Fidelity = 0.99785384
# T = 1080  Fidelity = 0.99816846
# T = 1090  Fidelity = 0.99811549
# T = 1100  Fidelity = 0.99859193
# T = 1200  Fidelity = 0.99814143
# T = 1300  Fidelity = 0.99774402
# T = 1400  Fidelity = 0.99806664
# T = 1500  Fidelity = 0.99819157
# T = 2000  Fidelity = 0.99790840
# T = 2100  Fidelity = 0.99803555
# T = 2110  Fidelity = 0.99749171
# T = 2120  Fidelity = 0.99835083
# T = 2130  Fidelity = 0.99812140
# T = 2140  Fidelity = 0.99826681
# T = 2150  Fidelity = 0.99763655
# T = 2160  Fidelity = 0.99823930
# T = 2170  Fidelity = 0.99792230
# T = 2180  Fidelity = 0.99857614
# T = 2190  Fidelity = 0.99844565
# T = 2200  Fidelity = 0.99813176
# T = 2300  Fidelity = 0.99800497
# T = 2400  Fidelity = 0.99786877
# T = 2500  Fidelity = 0.99774442
# T = 2600  Fidelity = 0.99794700
# T = 2700  Fidelity = 0.99827517
# T = 2800  Fidelity = 0.99789727
# T = 2900  Fidelity = 0.99838699
# T = 3000  Fidelity = 0.99801113
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 4.63104472e-01
# P0     = 0.99801113
# P1     = 0.00004889
# P0+P1  = 0.99806002
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.94657446
# T = 2     Fidelity = 0.96291117
# T = 5     Fidelity = 0.97507545
# T = 10    Fidelity = 0.97923741
# T = 20    Fidelity = 0.98321080
# T = 30    Fidelity = 0.98594531
# T = 40    Fidelity = 0.98739297
# T = 50    Fidelity = 0.98850951
# T = 75    Fidelity = 0.99067902
# T = 100   Fidelity = 0.99219377
# T = 125   Fidelity = 0.99328358
# T = 150   Fidelity = 0.99408280
# T = 175   Fidelity = 0.99461808
# T = 200   Fidelity = 0.99490195
# T = 225   Fidelity = 0.99543692
# T = 250   Fidelity = 0.99561047
# T = 275   Fidelity = 0.99615180
# T = 300   Fidelity = 0.99640309
# T = 400   Fidelity = 0.99712901
# T = 500   Fidelity = 0.99789975
# T = 600   Fidelity = 0.99849611
# T = 700   Fidelity = 0.99859299
# T = 800   Fidelity = 0.99885371
# T = 900   Fidelity = 0.99803573
# T = 1000  Fidelity = 0.99849958
# T = 1010  Fidelity = 0.99887156
# T = 1020  Fidelity = 0.99876861
# T = 1030  Fidelity = 0.99860278
# T = 1040  Fidelity = 0.99879887
# T = 1050  Fidelity = 0.99883647
# T = 1060  Fidelity = 0.99870541
# T = 1070  Fidelity = 0.99844595
# T = 1080  Fidelity = 0.99857943
# T = 1090  Fidelity = 0.99812732
# T = 1100  Fidelity = 0.99776520
# T = 1200  Fidelity = 0.99736813
# T = 1300  Fidelity = 0.99736219
# T = 1400  Fidelity = 0.99812472
# T = 1500  Fidelity = 0.99824418
# T = 2000  Fidelity = 0.99419084
# T = 2100  Fidelity = 0.99389186
# T = 2110  Fidelity = 0.99364635
# T = 2120  Fidelity = 0.99339393
# T = 2130  Fidelity = 0.99395282
# T = 2140  Fidelity = 0.99417931
# T = 2150  Fidelity = 0.99447643
# T = 2160  Fidelity = 0.99486112
# T = 2170  Fidelity = 0.99459099
# T = 2180  Fidelity = 0.99492209
# T = 2190  Fidelity = 0.99493544
# T = 2200  Fidelity = 0.99468499
# T = 2300  Fidelity = 0.99390469
# T = 2400  Fidelity = 0.99399657
# T = 2500  Fidelity = 0.99464458
# T = 2600  Fidelity = 0.99535680
# T = 2700  Fidelity = 0.99551055
# T = 2800  Fidelity = 0.99667715
# T = 2900  Fidelity = 0.99626821
# T = 3000  Fidelity = 0.99593947
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 4.08487218e-01
# P0     = 0.99593947
# P1     = 0.00200688
# P0+P1  = 0.99794635
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.87695214
# T = 2     Fidelity = 0.89989001
# T = 5     Fidelity = 0.92431195
# T = 10    Fidelity = 0.93459868
# T = 20    Fidelity = 0.94919049
# T = 30    Fidelity = 0.95594478
# T = 40    Fidelity = 0.96177425
# T = 50    Fidelity = 0.96535121
# T = 75    Fidelity = 0.97243552
# T = 100   Fidelity = 0.97729075
# T = 125   Fidelity = 0.98062398
# T = 150   Fidelity = 0.98308361
# T = 175   Fidelity = 0.98513967
# T = 200   Fidelity = 0.98658460
# T = 225   Fidelity = 0.98788481
# T = 250   Fidelity = 0.98903197
# T = 275   Fidelity = 0.99014011
# T = 300   Fidelity = 0.99075901
# T = 400   Fidelity = 0.99331210
# T = 500   Fidelity = 0.99423368
# T = 600   Fidelity = 0.99507538
# T = 700   Fidelity = 0.99635622
# T = 800   Fidelity = 0.99654337
# T = 900   Fidelity = 0.99684953
# T = 1000  Fidelity = 0.99680060
# T = 1010  Fidelity = 0.99671791
# T = 1020  Fidelity = 0.99623169
# T = 1030  Fidelity = 0.99654500
# T = 1040  Fidelity = 0.99640887
# T = 1050  Fidelity = 0.99630491
# T = 1060  Fidelity = 0.99601422
# T = 1070  Fidelity = 0.99620513
# T = 1080  Fidelity = 0.99596431
# T = 1090  Fidelity = 0.99589202
# T = 1100  Fidelity = 0.99576512
# T = 1200  Fidelity = 0.99747993
# T = 1300  Fidelity = 0.99594799
# T = 1400  Fidelity = 0.99396681
# T = 1500  Fidelity = 0.99536939
# T = 2000  Fidelity = 0.99385090
# T = 2100  Fidelity = 0.98675326
# T = 2110  Fidelity = 0.98684897
# T = 2120  Fidelity = 0.98764425
# T = 2130  Fidelity = 0.98666447
# T = 2140  Fidelity = 0.98591420
# T = 2150  Fidelity = 0.98547801
# T = 2160  Fidelity = 0.98562803
# T = 2170  Fidelity = 0.98511992
# T = 2180  Fidelity = 0.98541397
# T = 2190  Fidelity = 0.98507189
# T = 2200  Fidelity = 0.98470383
# T = 2300  Fidelity = 0.98205806
# T = 2400  Fidelity = 0.98296207
# T = 2500  Fidelity = 0.98333022
# T = 2600  Fidelity = 0.98694994
# T = 2700  Fidelity = 0.98709633
# T = 2800  Fidelity = 0.98708260
# T = 2900  Fidelity = 0.98966936
# T = 3000  Fidelity = 0.98275075
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 3.65257542e-01
# P0     = 0.98275075
# P1     = 0.00493311
# P0+P1  = 0.98768386
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78648482
# T = 2     Fidelity = 0.81690159
# T = 5     Fidelity = 0.85599083
# T = 10    Fidelity = 0.87792243
# T = 20    Fidelity = 0.90957992
# T = 30    Fidelity = 0.92397970
# T = 40    Fidelity = 0.93475743
# T = 50    Fidelity = 0.94328963
# T = 75    Fidelity = 0.95722398
# T = 100   Fidelity = 0.96626868
# T = 125   Fidelity = 0.97251016
# T = 150   Fidelity = 0.97701580
# T = 175   Fidelity = 0.98064668
# T = 200   Fidelity = 0.98307883
# T = 225   Fidelity = 0.98500341
# T = 250   Fidelity = 0.98707356
# T = 275   Fidelity = 0.98851452
# T = 300   Fidelity = 0.98978596
# T = 400   Fidelity = 0.99285477
# T = 500   Fidelity = 0.99350026
# T = 600   Fidelity = 0.99516680
# T = 700   Fidelity = 0.99680660
# T = 800   Fidelity = 0.99669368
# T = 900   Fidelity = 0.99628514
# T = 1000  Fidelity = 0.99590898
# T = 1010  Fidelity = 0.99590293
# T = 1020  Fidelity = 0.99611085
# T = 1030  Fidelity = 0.99646849
# T = 1040  Fidelity = 0.99592452
# T = 1050  Fidelity = 0.99503758
# T = 1060  Fidelity = 0.99461909
# T = 1070  Fidelity = 0.99407103
# T = 1080  Fidelity = 0.99351147
# T = 1090  Fidelity = 0.99361487
# T = 1100  Fidelity = 0.99347429
# T = 1200  Fidelity = 0.99575757
# T = 1300  Fidelity = 0.98655410
# T = 1400  Fidelity = 0.98385269
# T = 1500  Fidelity = 0.99016148
# T = 2000  Fidelity = 0.99776409
# T = 2100  Fidelity = 0.99336670
# T = 2110  Fidelity = 0.99263369
# T = 2120  Fidelity = 0.99509179
# T = 2130  Fidelity = 0.99709894
# T = 2140  Fidelity = 0.99609617
# T = 2150  Fidelity = 0.99819223
# T = 2160  Fidelity = 0.99825152
# T = 2170  Fidelity = 0.99664288
# T = 2180  Fidelity = 0.99638840
# T = 2190  Fidelity = 0.99674704
# T = 2200  Fidelity = 0.99404000
# T = 2300  Fidelity = 0.97937437
# T = 2400  Fidelity = 0.96583048
# T = 2500  Fidelity = 0.96592479
# T = 2600  Fidelity = 0.96773291
# T = 2700  Fidelity = 0.96860137
# T = 2800  Fidelity = 0.96716147
# T = 2900  Fidelity = 0.97729525
# T = 3000  Fidelity = 0.98835337
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 3.29331980e-01
# P0     = 0.98835337
# P1     = 0.00713756
# P0+P1  = 0.99549093
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.71985275
# T = 2     Fidelity = 0.75654820
# T = 5     Fidelity = 0.80711413
# T = 10    Fidelity = 0.84339792
# T = 20    Fidelity = 0.89190827
# T = 30    Fidelity = 0.91339278
# T = 40    Fidelity = 0.93034345
# T = 50    Fidelity = 0.94003039
# T = 75    Fidelity = 0.95882583
# T = 100   Fidelity = 0.97007252
# T = 125   Fidelity = 0.97729554
# T = 150   Fidelity = 0.98217443
# T = 175   Fidelity = 0.98560661
# T = 200   Fidelity = 0.98792775
# T = 225   Fidelity = 0.98970981
# T = 250   Fidelity = 0.99114948
# T = 275   Fidelity = 0.99233277
# T = 300   Fidelity = 0.99292664
# T = 400   Fidelity = 0.99538522
# T = 500   Fidelity = 0.99575946
# T = 600   Fidelity = 0.99590822
# T = 700   Fidelity = 0.99766603
# T = 800   Fidelity = 0.99789381
# T = 900   Fidelity = 0.99718397
# T = 1000  Fidelity = 0.99352063
# T = 1010  Fidelity = 0.99288176
# T = 1020  Fidelity = 0.99207666
# T = 1030  Fidelity = 0.99127532
# T = 1040  Fidelity = 0.99111296
# T = 1050  Fidelity = 0.99196179
# T = 1060  Fidelity = 0.99320455
# T = 1070  Fidelity = 0.99418939
# T = 1080  Fidelity = 0.99447650
# T = 1090  Fidelity = 0.99511368
# T = 1100  Fidelity = 0.99561198
# T = 1200  Fidelity = 0.98111733
# T = 1300  Fidelity = 0.98444272
# T = 1400  Fidelity = 0.99465744
# T = 1500  Fidelity = 0.99407210
# T = 2000  Fidelity = 0.99385377
# T = 2100  Fidelity = 0.99200694
# T = 2110  Fidelity = 0.99435478
# T = 2120  Fidelity = 0.99458190
# T = 2130  Fidelity = 0.99161689
# T = 2140  Fidelity = 0.99349592
# T = 2150  Fidelity = 0.99592594
# T = 2160  Fidelity = 0.99268338
# T = 2170  Fidelity = 0.99133462
# T = 2180  Fidelity = 0.99529887
# T = 2190  Fidelity = 0.99559524
# T = 2200  Fidelity = 0.99759000
# T = 2300  Fidelity = 0.99611928
# T = 2400  Fidelity = 0.96228197
# T = 2500  Fidelity = 0.94541075
# T = 2600  Fidelity = 0.95937074
# T = 2700  Fidelity = 0.96412748
# T = 2800  Fidelity = 0.98265409
# T = 2900  Fidelity = 0.99093411
# T = 3000  Fidelity = 0.99244564
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 2.99484431e-01
# P0     = 0.99244564
# P1     = 0.00554894
# P0+P1  = 0.99799458
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.69216449
# T = 2     Fidelity = 0.73439783
# T = 5     Fidelity = 0.79298311
# T = 10    Fidelity = 0.84070027
# T = 20    Fidelity = 0.90351060
# T = 30    Fidelity = 0.92716074
# T = 40    Fidelity = 0.94586002
# T = 50    Fidelity = 0.95672128
# T = 75    Fidelity = 0.97346474
# T = 100   Fidelity = 0.98233649
# T = 125   Fidelity = 0.98752697
# T = 150   Fidelity = 0.99074081
# T = 175   Fidelity = 0.99282781
# T = 200   Fidelity = 0.99405949
# T = 225   Fidelity = 0.99515976
# T = 250   Fidelity = 0.99588589
# T = 275   Fidelity = 0.99646917
# T = 300   Fidelity = 0.99701254
# T = 400   Fidelity = 0.99757871
# T = 500   Fidelity = 0.99740988
# T = 600   Fidelity = 0.99790735
# T = 700   Fidelity = 0.99875110
# T = 800   Fidelity = 0.99552657
# T = 900   Fidelity = 0.99521477
# T = 1000  Fidelity = 0.99487736
# T = 1010  Fidelity = 0.99482659
# T = 1020  Fidelity = 0.99340668
# T = 1030  Fidelity = 0.99094717
# T = 1040  Fidelity = 0.98769567
# T = 1050  Fidelity = 0.98507293
# T = 1060  Fidelity = 0.98290846
# T = 1070  Fidelity = 0.98126594
# T = 1080  Fidelity = 0.97954323
# T = 1090  Fidelity = 0.97829649
# T = 1100  Fidelity = 0.97734157
# T = 1200  Fidelity = 0.98908587
# T = 1300  Fidelity = 0.99592096
# T = 1400  Fidelity = 0.99713060
# T = 1500  Fidelity = 0.99769469
# T = 2000  Fidelity = 0.99543010
# T = 2100  Fidelity = 0.99393671
# T = 2110  Fidelity = 0.99434337
# T = 2120  Fidelity = 0.99484371
# T = 2130  Fidelity = 0.99484278
# T = 2140  Fidelity = 0.99542847
# T = 2150  Fidelity = 0.99541331
# T = 2160  Fidelity = 0.99453079
# T = 2170  Fidelity = 0.99254749
# T = 2180  Fidelity = 0.98929867
# T = 2190  Fidelity = 0.98515523
# T = 2200  Fidelity = 0.98652163
# T = 2300  Fidelity = 0.98022516
# T = 2400  Fidelity = 0.92247758
# T = 2500  Fidelity = 0.96390086
# T = 2600  Fidelity = 0.98918452
# T = 2700  Fidelity = 0.99354945
# T = 2800  Fidelity = 0.99557820
# T = 2900  Fidelity = 0.99529247
# T = 3000  Fidelity = 0.99476626
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 2.76704400e-01
# P0     = 0.99476626
# P1     = 0.00081309
# P0+P1  = 0.99557935
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.35126357e-02
# T = 1     Fidelity = 0.59297670
# T = 2     Fidelity = 0.63830593
# T = 5     Fidelity = 0.71965636
# T = 10    Fidelity = 0.79693103
# T = 20    Fidelity = 0.87821941
# T = 30    Fidelity = 0.92027372
# T = 40    Fidelity = 0.94472435
# T = 50    Fidelity = 0.95932848
# T = 75    Fidelity = 0.97778449
# T = 100   Fidelity = 0.98494622
# T = 125   Fidelity = 0.98628878
# T = 150   Fidelity = 0.98893942
# T = 175   Fidelity = 0.98796490
# T = 200   Fidelity = 0.97777863
# T = 225   Fidelity = 0.99150400
# T = 250   Fidelity = 0.95506399
# T = 275   Fidelity = 0.98834294
# T = 300   Fidelity = 0.95436947
# T = 400   Fidelity = 0.93255403
# T = 500   Fidelity = 0.96778791
# T = 600   Fidelity = 0.97082708
# T = 700   Fidelity = 0.90566478
# T = 800   Fidelity = 0.97419376
# T = 900   Fidelity = 0.99067888
# T = 1000  Fidelity = 0.99403247
# T = 1010  Fidelity = 0.98832728
# T = 1020  Fidelity = 0.99283723
# T = 1030  Fidelity = 0.99444211
# T = 1040  Fidelity = 0.98353849
# T = 1050  Fidelity = 0.95909189
# T = 1060  Fidelity = 0.94716775
# T = 1070  Fidelity = 0.93594295
# T = 1080  Fidelity = 0.92034820
# T = 1090  Fidelity = 0.88801337
# T = 1100  Fidelity = 0.88005950
# T = 1200  Fidelity = 0.88714827
# T = 1300  Fidelity = 0.96889576
# T = 1400  Fidelity = 0.97803254
# T = 1500  Fidelity = 0.94089097
# T = 2000  Fidelity = 0.99099803
# T = 2100  Fidelity = 0.98228298
# T = 2110  Fidelity = 0.97766264
# T = 2120  Fidelity = 0.96536254
# T = 2130  Fidelity = 0.95192374
# T = 2140  Fidelity = 0.95630595
# T = 2150  Fidelity = 0.98710931
# T = 2160  Fidelity = 0.99454773
# T = 2170  Fidelity = 0.99651042
# T = 2180  Fidelity = 0.99120612
# T = 2190  Fidelity = 0.98536710
# T = 2200  Fidelity = 0.98140046
# T = 2300  Fidelity = 0.86458025
# T = 2400  Fidelity = 0.96918050
# T = 2500  Fidelity = 0.95672941
# T = 2600  Fidelity = 0.90195173
# T = 2700  Fidelity = 0.96496144
# T = 2800  Fidelity = 0.96517621
# T = 2900  Fidelity = 0.90814134
# T = 3000  Fidelity = 0.96771295
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.33751607e-02
# P0     = 0.96771295
# P1     = 0.00005312
# P0+P1  = 0.96776607
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# ...
# T = 30    Fidelity = 0.99964199
# T = 40    Fidelity = 0.99964646
# T = 50    Fidelity = 0.99964460
# T = 75    Fidelity = 0.99965022
# T = 100   Fidelity = 0.99964803
# T = 125   Fidelity = 0.99963436
# T = 150   Fidelity = 0.99960085
# T = 175   Fidelity = 0.99932917
# T = 200   Fidelity = 0.99929710
# T = 225   Fidelity = 0.99915818
# T = 250   Fidelity = 0.99955424
# T = 275   Fidelity = 0.99958431
# T = 300   Fidelity = 0.99959268
# T = 400   Fidelity = 0.99945554
# T = 500   Fidelity = 0.99954441
# T = 600   Fidelity = 0.99954098
# T = 700   Fidelity = 0.99962407
# T = 800   Fidelity = 0.99954425
# T = 900   Fidelity = 0.99944526
# T = 1000  Fidelity = 0.99951117
# T = 1010  Fidelity = 0.99941463
# T = 1020  Fidelity = 0.99961410
# T = 1030  Fidelity = 0.99941632
# T = 1040  Fidelity = 0.99954971
# T = 1050  Fidelity = 0.99949525
# T = 1060  Fidelity = 0.99941837
# T = 1070  Fidelity = 0.99947439
# T = 1080  Fidelity = 0.99957564
# T = 1090  Fidelity = 0.99960389
# T = 1100  Fidelity = 0.99959525
# T = 1200  Fidelity = 0.99956521
# T = 1300  Fidelity = 0.99957203
# T = 1400  Fidelity = 0.99943874
# T = 1500  Fidelity = 0.99951575
# T = 2000  Fidelity = 0.99948255
# T = 2100  Fidelity = 0.99954691
# T = 2110  Fidelity = 0.99946175
# T = 2120  Fidelity = 0.99956869
# T = 2130  Fidelity = 0.99952033
# T = 2140  Fidelity = 0.99956410
# T = 2150  Fidelity = 0.99957301
# T = 2160  Fidelity = 0.99939342
# T = 2170  Fidelity = 0.99951614
# T = 2180  Fidelity = 0.99942359
# T = 2190  Fidelity = 0.99954641
# T = 2200  Fidelity = 0.99954834
# T = 2300  Fidelity = 0.99943208
# T = 2400  Fidelity = 0.99950436
# T = 2500  Fidelity = 0.99949243
# T = 2600  Fidelity = 0.99929806
# T = 2700  Fidelity = 0.99948300
# T = 2800  Fidelity = 0.99954820
# T = 2900  Fidelity = 0.99948445
# T = 3000  Fidelity = 0.99946344
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43410205e+00
# P0     = 0.99946344
# P1     = 0.00000216
# P0+P1  = 0.99946560
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99101174
# T = 2     Fidelity = 0.99740993
# T = 5     Fidelity = 0.99924897
# T = 10    Fidelity = 0.99969649
# T = 20    Fidelity = 0.99978721
# T = 30    Fidelity = 0.99981725
# T = 40    Fidelity = 0.99982978
# T = 50    Fidelity = 0.99983231
# T = 75    Fidelity = 0.99983385
# T = 100   Fidelity = 0.99983293
# T = 125   Fidelity = 0.99982715
# T = 150   Fidelity = 0.99979177
# T = 175   Fidelity = 0.99945621
# T = 200   Fidelity = 0.99952299
# T = 225   Fidelity = 0.99942477
# T = 250   Fidelity = 0.99974293
# T = 275   Fidelity = 0.99974308
# T = 300   Fidelity = 0.99976294
# T = 400   Fidelity = 0.99966016
# T = 500   Fidelity = 0.99964941
# T = 600   Fidelity = 0.99967181
# T = 700   Fidelity = 0.99967598
# T = 800   Fidelity = 0.99965676
# T = 900   Fidelity = 0.99963354
# T = 1000  Fidelity = 0.99944114
# T = 1010  Fidelity = 0.99975178
# T = 1020  Fidelity = 0.99965781
# T = 1030  Fidelity = 0.99974613
# T = 1040  Fidelity = 0.99963820
# T = 1050  Fidelity = 0.99966921
# T = 1060  Fidelity = 0.99979367
# T = 1070  Fidelity = 0.99978286
# T = 1080  Fidelity = 0.99975458
# T = 1090  Fidelity = 0.99971794
# T = 1100  Fidelity = 0.99979023
# T = 1200  Fidelity = 0.99969952
# T = 1300  Fidelity = 0.99961707
# T = 1400  Fidelity = 0.99950067
# T = 1500  Fidelity = 0.99958754
# T = 2000  Fidelity = 0.99958208
# T = 2100  Fidelity = 0.99976669
# T = 2110  Fidelity = 0.99975860
# T = 2120  Fidelity = 0.99974926
# T = 2130  Fidelity = 0.99962962
# T = 2140  Fidelity = 0.99968854
# T = 2150  Fidelity = 0.99974262
# T = 2160  Fidelity = 0.99965524
# T = 2170  Fidelity = 0.99978980
# T = 2180  Fidelity = 0.99961475
# T = 2190  Fidelity = 0.99979069
# T = 2200  Fidelity = 0.99958603
# T = 2300  Fidelity = 0.99968487
# T = 2400  Fidelity = 0.99965727
# T = 2500  Fidelity = 0.99960952
# T = 2600  Fidelity = 0.99971698
# T = 2700  Fidelity = 0.99956802
# T = 2800  Fidelity = 0.99958199
# T = 2900  Fidelity = 0.99957681
# T = 3000  Fidelity = 0.99973412
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41860745e+00
# P0     = 0.99973412
# P1     = 0.00000154
# P0+P1  = 0.99973565
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98960290
# T = 2     Fidelity = 0.99665315
# T = 5     Fidelity = 0.99904788
# T = 10    Fidelity = 0.99963860
# T = 20    Fidelity = 0.99976698
# T = 30    Fidelity = 0.99980336
# T = 40    Fidelity = 0.99982126
# T = 50    Fidelity = 0.99982954
# T = 75    Fidelity = 0.99983553
# T = 100   Fidelity = 0.99983473
# T = 125   Fidelity = 0.99982795
# T = 150   Fidelity = 0.99980565
# T = 175   Fidelity = 0.99959739
# T = 200   Fidelity = 0.99944950
# T = 225   Fidelity = 0.99945177
# T = 250   Fidelity = 0.99967928
# T = 275   Fidelity = 0.99976037
# T = 300   Fidelity = 0.99978887
# T = 400   Fidelity = 0.99966174
# T = 500   Fidelity = 0.99934091
# T = 600   Fidelity = 0.99970717
# T = 700   Fidelity = 0.99972663
# T = 800   Fidelity = 0.99969823
# T = 900   Fidelity = 0.99961258
# T = 1000  Fidelity = 0.99936559
# T = 1010  Fidelity = 0.99966482
# T = 1020  Fidelity = 0.99966479
# T = 1030  Fidelity = 0.99968591
# T = 1040  Fidelity = 0.99968466
# T = 1050  Fidelity = 0.99968990
# T = 1060  Fidelity = 0.99962119
# T = 1070  Fidelity = 0.99968166
# T = 1080  Fidelity = 0.99968715
# T = 1090  Fidelity = 0.99964946
# T = 1100  Fidelity = 0.99969927
# T = 1200  Fidelity = 0.99956691
# T = 1300  Fidelity = 0.99963419
# T = 1400  Fidelity = 0.99953622
# T = 1500  Fidelity = 0.99954603
# T = 2000  Fidelity = 0.99938066
# T = 2100  Fidelity = 0.99971891
# T = 2110  Fidelity = 0.99975899
# T = 2120  Fidelity = 0.99970202
# T = 2130  Fidelity = 0.99945983
# T = 2140  Fidelity = 0.99961382
# T = 2150  Fidelity = 0.99969131
# T = 2160  Fidelity = 0.99974988
# T = 2170  Fidelity = 0.99972386
# T = 2180  Fidelity = 0.99974050
# T = 2190  Fidelity = 0.99967983
# T = 2200  Fidelity = 0.99965732
# T = 2300  Fidelity = 0.99955826
# T = 2400  Fidelity = 0.99960044
# T = 2500  Fidelity = 0.99953263
# T = 2600  Fidelity = 0.99963579
# T = 2700  Fidelity = 0.99966799
# T = 2800  Fidelity = 0.99962321
# T = 2900  Fidelity = 0.99969351
# T = 3000  Fidelity = 0.99959332
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.39938753e+00
# P0     = 0.99959332
# P1     = 0.00009226
# P0+P1  = 0.99968558
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98776354
# T = 2     Fidelity = 0.99567544
# T = 5     Fidelity = 0.99877086
# T = 10    Fidelity = 0.99952837
# T = 20    Fidelity = 0.99971635
# T = 30    Fidelity = 0.99976748
# T = 40    Fidelity = 0.99979045
# T = 50    Fidelity = 0.99980495
# T = 75    Fidelity = 0.99981808
# T = 100   Fidelity = 0.99982050
# T = 125   Fidelity = 0.99981306
# T = 150   Fidelity = 0.99977778
# T = 175   Fidelity = 0.99949474
# T = 200   Fidelity = 0.99948579
# T = 225   Fidelity = 0.99951418
# T = 250   Fidelity = 0.99943016
# T = 275   Fidelity = 0.99974063
# T = 300   Fidelity = 0.99973812
# T = 400   Fidelity = 0.99963181
# T = 500   Fidelity = 0.99888571
# T = 600   Fidelity = 0.99967433
# T = 700   Fidelity = 0.99961683
# T = 800   Fidelity = 0.99970002
# T = 900   Fidelity = 0.99962577
# T = 1000  Fidelity = 0.99932685
# T = 1010  Fidelity = 0.99937299
# T = 1020  Fidelity = 0.99930886
# T = 1030  Fidelity = 0.99928212
# T = 1040  Fidelity = 0.99941940
# T = 1050  Fidelity = 0.99935198
# T = 1060  Fidelity = 0.99944292
# T = 1070  Fidelity = 0.99957454
# T = 1080  Fidelity = 0.99965303
# T = 1090  Fidelity = 0.99953302
# T = 1100  Fidelity = 0.99965340
# T = 1200  Fidelity = 0.99968362
# T = 1300  Fidelity = 0.99966025
# T = 1400  Fidelity = 0.99961187
# T = 1500  Fidelity = 0.99948756
# T = 2000  Fidelity = 0.99948108
# T = 2100  Fidelity = 0.99949025
# T = 2110  Fidelity = 0.99954151
# T = 2120  Fidelity = 0.99953957
# T = 2130  Fidelity = 0.99956844
# T = 2140  Fidelity = 0.99970869
# T = 2150  Fidelity = 0.99948270
# T = 2160  Fidelity = 0.99962004
# T = 2170  Fidelity = 0.99966837
# T = 2180  Fidelity = 0.99969526
# T = 2190  Fidelity = 0.99978783
# T = 2200  Fidelity = 0.99964585
# T = 2300  Fidelity = 0.99962092
# T = 2400  Fidelity = 0.99952810
# T = 2500  Fidelity = 0.99947068
# T = 2600  Fidelity = 0.99960403
# T = 2700  Fidelity = 0.99968344
# T = 2800  Fidelity = 0.99959483
# T = 2900  Fidelity = 0.99965232
# T = 3000  Fidelity = 0.99952203
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.37860722e+00
# P0     = 0.99952203
# P1     = 0.00010023
# P0+P1  = 0.99962226
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98596549
# T = 2     Fidelity = 0.99468639
# T = 5     Fidelity = 0.99852306
# T = 10    Fidelity = 0.99942999
# T = 20    Fidelity = 0.99968842
# T = 30    Fidelity = 0.99975594
# T = 40    Fidelity = 0.99978261
# T = 50    Fidelity = 0.99979692
# T = 75    Fidelity = 0.99981550
# T = 100   Fidelity = 0.99981765
# T = 125   Fidelity = 0.99981131
# T = 150   Fidelity = 0.99977338
# T = 175   Fidelity = 0.99939392
# T = 200   Fidelity = 0.99945492
# T = 225   Fidelity = 0.99957140
# T = 250   Fidelity = 0.99956975
# T = 275   Fidelity = 0.99964299
# T = 300   Fidelity = 0.99975006
# T = 400   Fidelity = 0.99965978
# T = 500   Fidelity = 0.99924615
# T = 600   Fidelity = 0.99966154
# T = 700   Fidelity = 0.99961137
# T = 800   Fidelity = 0.99964199
# T = 900   Fidelity = 0.99964545
# T = 1000  Fidelity = 0.99936754
# T = 1010  Fidelity = 0.99935500
# T = 1020  Fidelity = 0.99925691
# T = 1030  Fidelity = 0.99948354
# T = 1040  Fidelity = 0.99945155
# T = 1050  Fidelity = 0.99927868
# T = 1060  Fidelity = 0.99910362
# T = 1070  Fidelity = 0.99917262
# T = 1080  Fidelity = 0.99921316
# T = 1090  Fidelity = 0.99937652
# T = 1100  Fidelity = 0.99954248
# T = 1200  Fidelity = 0.99962280
# T = 1300  Fidelity = 0.99966555
# T = 1400  Fidelity = 0.99954098
# T = 1500  Fidelity = 0.99953476
# T = 2000  Fidelity = 0.99965744
# T = 2100  Fidelity = 0.99948515
# T = 2110  Fidelity = 0.99947791
# T = 2120  Fidelity = 0.99952709
# T = 2130  Fidelity = 0.99948248
# T = 2140  Fidelity = 0.99958348
# T = 2150  Fidelity = 0.99946079
# T = 2160  Fidelity = 0.99939794
# T = 2170  Fidelity = 0.99946820
# T = 2180  Fidelity = 0.99949527
# T = 2190  Fidelity = 0.99943718
# T = 2200  Fidelity = 0.99938298
# T = 2300  Fidelity = 0.99960270
# T = 2400  Fidelity = 0.99957648
# T = 2500  Fidelity = 0.99954611
# T = 2600  Fidelity = 0.99960075
# T = 2700  Fidelity = 0.99963632
# T = 2800  Fidelity = 0.99935719
# T = 2900  Fidelity = 0.99958319
# T = 3000  Fidelity = 0.99956989
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.35708887e+00
# P0     = 0.99956989
# P1     = 0.00006255
# P0+P1  = 0.99963244
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     None      0.9933606686      2.15534848e-04    0.454618    0.0         0.454618
# Symmetric      0.311     None      0.9996498405      1.15624068e-06    0.513566    0.0         0.513566
# Symmetric      0.522     None      0.9998662940      3.42043129e-07    0.888942    0.0         0.888942
# Symmetric      0.733     None      0.9995668162      1.41278093e-05    0.924843    0.0         0.924843
# Symmetric      0.944     None      0.9997471245      3.35131121e-04    0.911841    0.0         0.911841
# Symmetric      1.156     None      0.9996752062      2.39158790e-03    0.973339    0.0         0.973339
# Symmetric      1.367     None      0.9996266593      8.93695212e-03    0.984317    0.0         0.984317
# Symmetric      1.578     None      0.9995447211      2.26116126e-02    0.959077    0.0         0.959077
# Symmetric      1.789     None      0.9996532095      4.43232760e-02    0.998353    0.0         0.998354
# Symmetric      2.000     None      0.9995216713      7.29248761e-02    0.960087    1e-06       0.960088
# Weak SSB optimised0.100     None      0.9895686491      8.65519637e-01    0.958589    0.029246    0.987835
# Weak SSB optimised0.311     None      0.9801662581      5.19764834e-01    0.957798    0.019627    0.977425
# Weak SSB optimised0.522     None      0.9960086403      3.21398905e-01    0.995897    1.9e-05     0.995916
# Weak SSB optimised0.733     None      0.9977248467      2.64154074e-01    0.996677    1e-06       0.996678
# Weak SSB optimised0.944     None      0.9985919260      2.26024680e-01    0.998011    4.9e-05     0.99806
# Weak SSB optimised1.156     None      0.9988715554      2.01656789e-01    0.995939    0.002007    0.997946
# Weak SSB optimised1.367     None      0.9974799250      1.93673930e-01    0.982751    0.004933    0.987684
# Weak SSB optimised1.578     None      0.9982515197      2.03071995e-01    0.988353    0.007138    0.995491
# Weak SSB optimised1.789     None      0.9978938069      2.25515049e-01    0.992446    0.005549    0.997995
# Weak SSB optimised2.000     None      0.9987511001      2.54594564e-01    0.994766    0.000813    0.995579
# Weak SSB       0.100     None      0.9965104200      1.35126357e-02    0.967713    5.3e-05     0.967766
# Weak SSB       0.311     None      0.9913415616      2.91075005e-03    0.986945    0.001325    0.98827
# Weak SSB       0.522     None      0.2712127207      1.05614584e-03    0.263482    0.236235    0.499717
# Weak SSB       0.733     None      0.4155191685      1.05944621e-03    0.402218    0.153257    0.555475
# Weak SSB       0.944     None      0.5972334305      9.57867035e-04    0.590351    0.195621    0.785972
# Weak SSB       1.156     None      0.9962738944      2.03605669e-03    0.962798    0.001347    0.964145
# Weak SSB       1.367     None      0.9947041364      7.34955504e-03    0.861912    0.00125     0.863163
# Weak SSB       1.578     None      0.9989612783      1.92117516e-02    0.998961    0.000261    0.999222
# Weak SSB       1.789     None      0.9981674440      3.87769083e-02    0.988792    8.3e-05     0.988876
# Weak SSB       2.000     None      0.9993900479      6.53490673e-02    0.997987    4.4e-05     0.99803
# Strong SSB     0.100     None      0.9979295497      3.59472102e+00    0.99682     0.000144    0.996964
# Strong SSB     0.311     None      0.9974321891      1.58498916e+00    0.996655    0.000109    0.996764
# Strong SSB     0.522     None      0.9957945846      1.42665601e+00    0.995391    0.000473    0.995864
# Strong SSB     0.733     None      0.9978926191      1.41121208e+00    0.997642    0.000124    0.997767
# Strong SSB     0.944     None      0.9993299604      1.38481786e+00    0.999076    2e-06       0.999078
# Strong SSB     1.156     None      0.9996502213      1.34302163e+00    0.999463    2e-06       0.999466
# Strong SSB     1.367     None      0.9998338542      1.29217279e+00    0.999734    2e-06       0.999736
# Strong SSB     1.578     None      0.9998355331      1.23335459e+00    0.999593    9.2e-05     0.999686
# Strong SSB     1.789     None      0.9998205001      1.17426012e+00    0.999522    0.0001      0.999622
# Strong SSB     2.000     None      0.9998176535      1.12109308e+00    0.99957     6.3e-05     0.999632

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',
        color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$d^2\langle\phi\rangle/d\lambda^2$')

plt.title(r'Inflection-point analysis $m_0^2=-1$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 7
#       3 # ============================================================
#       4
#       5 # First derivatives
#       6
# ----> 7 dM_sym = np.gradient(M_sym, lambda_sym)
#       8
#       9 dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)
#      10
#
# File ~/jupyter/qiskit_env/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:1268, in gradient(f, axis, edge_order, *varargs)
#    1265 diffx = np.diff(distances)
#    1266 # if distances are constant reduce to the scalar case
#    1267 # since it brings a consistent speedup
# -> 1268 if (diffx == diffx[0]).all():
#    1269     diffx = diffx[0]
#    1270 dx[i] = diffx
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Start of m0^2=-2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
# ============================================================


plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=-2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ==================optimised==========================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
