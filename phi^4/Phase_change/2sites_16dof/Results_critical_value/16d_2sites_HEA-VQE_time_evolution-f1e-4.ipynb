# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # -------------------------------------------------------- kjacvbnm,./qwertyuiopp//÷//

 
    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756816
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Genuine Qiskit VQE on shifted Pauli Hamiltonian
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SPSA

from qiskit.primitives import StatevectorEstimator


# ============================================================
# Variational circuit
# ============================================================

def variational_circuit(nq, layers):

    qc = QuantumCircuit(nq)

    nparams = 2 * nq * layers

    params = ParameterVector("θ", nparams)

    p = 0

    for l in range(layers):

        # ----------------------------------------------------
        # Single-qubit rotations
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(params[p], q)
            qc.rz(params[p + 1], q)

            p += 2

        # ----------------------------------------------------
        # Entanglement layer
        # ----------------------------------------------------

        if l != layers - 1:

            # even bonds
            if l % 2 == 0:

                for q in range(0, nq - 1, 2):
                    qc.cz(q, q + 1)

            # odd bonds
            else:

                for q in range(1, nq - 1, 2):
                    qc.cz(q, q + 1)

    return qc


# ============================================================
# Ansatz
# ============================================================

nqubits = 8

# start modestly
layers = 8

ansatz = variational_circuit(
    nqubits,
    layers
)

# ============================================================
# Estimator
# ============================================================

estimator = StatevectorEstimator()

# ============================================================
# Optimizer
# ============================================================

optimizer = SPSA(
    maxiter=5000
)

# ============================================================
# VQE
# ============================================================
initial_point = 0.01 * np.random.randn(
    ansatz.num_parameters
)
vqe = VQE(
    estimator=estimator,
    ansatz=ansatz,
    optimizer=optimizer,
    initial_point=initial_point
)

# ============================================================
# Run VQE
# ============================================================

print("\nRunning VQE...\n")

result = vqe.compute_minimum_eigenvalue(
    H_pauli_shifted
)

# ============================================================
# Shifted energy
# ============================================================

E_shifted = result.eigenvalue.real

# ============================================================
# Physical energy
# ============================================================

E_vqe = E_shifted + identity_shift

# ============================================================
# Optimal parameters
# ============================================================

optimal_params = result.optimal_parameters

# ============================================================
# Optimized circuit
# ============================================================

optimal_circuit = ansatz.assign_parameters(
    optimal_params
)

# ============================================================
# VQE state
# ============================================================

psi_vqe = Statevector.from_instruction(
    optimal_circuit
).data

# ============================================================
# Fidelity
# ============================================================

Fidelity = np.abs(
    np.vdot(psi_loc, psi_vqe)
)**2

# ============================================================
# Results
# ============================================================

print("\n================================")
print("Exact energy :", E0_loc)
print("VQE energy   :", E_vqe)
print("Energy error :", abs(E_vqe - E0_loc))
print("Fidelity     :", Fidelity)
print("Layers        :", layers)
print("Pauli terms   :", len(H_pauli_shifted))
print("================================")
# Out:
# Running VQE...
#
#
# ================================
# Exact energy : 1.0554722545756816
# VQE energy   : 1.0685167552906938
# Energy error : 0.013044500715012175
# Fidelity     : 0.9970642044655929
# Layers        : 8
# Pauli terms   : 111
# ================================

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Robust VQE with eigenstate tracking
# ============================================================
import numpy as np

from scipy.sparse import identity, kron

from qiskit.quantum_info import (
    Statevector,
    Operator,
    SparsePauliOp
)

from qiskit.primitives import StatevectorEstimator

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B
def run_robust_vqe(

    H_sparse,

    nq,

    layers,

    n_restarts,

    energy_tol,

    previous_state=None,

    previous_optimal_point=None
):

    nqubits = nq

    # --------------------------------------------------------
    # Exact ground state
    # --------------------------------------------------------

    E_exact, psi_exact = exact_ground_state(H_sparse)

    # --------------------------------------------------------
    # Convert Hamiltonian
    # --------------------------------------------------------

    H_dense = H_sparse.toarray()

    H_op = Operator(H_dense)

    H_pauli = SparsePauliOp.from_operator(H_op)

    coeffs = H_pauli.coeffs

    paulis = H_pauli.paulis

    new_coeffs = []

    new_paulis = []

    identity_shift = 0.0

    for p, c in zip(paulis, coeffs):

        if str(p) == 'I' * nqubits:

            identity_shift += np.real(c)

        else:

            new_paulis.append(p)

            new_coeffs.append(c)

    H_pauli_shifted = SparsePauliOp(

        new_paulis,

        coeffs=new_coeffs
    )

    # --------------------------------------------------------
    # Ansatz
    # --------------------------------------------------------

    ansatz = variational_circuit(

        nq=nqubits,

        layers=layers
    )

    estimator = StatevectorEstimator()

    optimizer = L_BFGS_B(maxiter=1000)

    # ========================================================
    # Multiple restarts
    # ========================================================

    trial_results = []

    for trial in range(n_restarts):

        # ----------------------------------------------------
        # Initial point
        # ----------------------------------------------------

        if trial == 0 and previous_optimal_point is not None:

            initial_point = previous_optimal_point

        else:

            initial_point = 0.01 * np.random.randn(

                ansatz.num_parameters
            )

        # ----------------------------------------------------
        # VQE
        # ----------------------------------------------------

        vqe = VQE(

            estimator=estimator,

            ansatz=ansatz,

            optimizer=optimizer,

            initial_point=initial_point
        )

        result = vqe.compute_minimum_eigenvalue(

            H_pauli_shifted
        )

        E_trial = (

            np.real(result.eigenvalue)

            + identity_shift
        )

        # ----------------------------------------------------
        # Trial state
        # ----------------------------------------------------

        qc_trial = ansatz.assign_parameters(

            result.optimal_parameters
        )

        psi_trial = Statevector.from_instruction(

            qc_trial

        ).data

        # ----------------------------------------------------
        # Overlap tracking
        # ----------------------------------------------------

        if previous_state is None:

            overlap = 1.0

        else:

            overlap = abs(np.vdot(

                previous_state,

                psi_trial

            ))**2

        trial_results.append({

            'energy': E_trial,

            'overlap': overlap,

            'state': psi_trial,

            'result': result
        })

    # ========================================================
    # Hybrid selection
    # ========================================================

    energies = np.array([

        t['energy']

        for t in trial_results
    ])

    E_min = np.min(energies)

    filtered_candidates = [

        t for t in trial_results

        if (t['energy'] - E_min) < energy_tol
    ]

    best_candidate = max(

        filtered_candidates,

        key=lambda x: x['overlap']
    )

    # ========================================================
    # Outputs
    # ========================================================

    # ========================================================
    # Final outputs
    # ========================================================

    psi_vqe = best_candidate['state']

    E_vqe = best_candidate['energy']

    optimal_point = (

        best_candidate['result'].optimal_point
    )

    tracking_overlap = best_candidate['overlap']

    F = fidelity(

    psi_exact,

    psi_vqe
    )

    return {

        "E_exact": E_exact,

        "E_vqe": E_vqe,

        "psi_vqe": psi_vqe,

        "fidelity": F,

        "tracking_overlap": tracking_overlap,

        "optimal_point": optimal_point,

        "state_for_tracking": psi_vqe
    }

# %%
nq_site = 4

nqubits = 2 * nq_site

mu = 1.0

layers = 8

# ============================================================
# VQE settings
# ============================================================

n_restarts = 5

energy_tol = 1e-3

# ============================================================
# Parameter sets
# ============================================================

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ============================================================
# Lambda scan
# ============================================================

lambda_list = np.linspace(0.1, 2.0, 10)

# ============================================================
# Storage
# ============================================================

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]

    mI2 = params["mI2"]

    f = params["f"]

    print("\n")
    print("#"*80)

    print(f"CASE: {label}")

    print(f"mI² = {mI2},  f = {f}")

    print("#"*80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None

    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "="*60)

        print(f"Running λ = {lam:.3f}")

        print("="*60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(

            nq=nq_site,

            mu=mu,

            mI2=mI2,

            lam=lam,

            f=f
        )

        # ====================================================
        # Run robust VQE
        # ====================================================

        vqe_data = run_robust_vqe(

            H_sparse=Hloc_sparse,

            nq=nqubits,

            layers=layers,

            n_restarts=n_restarts,

            energy_tol=energy_tol,

            previous_state=previous_state,

            previous_optimal_point=previous_optimal_point
        )

        # ====================================================
        # Extract outputs
        # ====================================================

        E_exact = vqe_data["E_exact"]

        E_vqe = vqe_data["E_vqe"]

        psi_vqe = vqe_data["psi_vqe"]

        F = vqe_data["fidelity"]

        tracking_overlap = vqe_data["tracking_overlap"]

        # ----------------------------------------------------
        # Update tracking
        # ----------------------------------------------------

        previous_state = vqe_data["state_for_tracking"]

        previous_optimal_point = (

            vqe_data["optimal_point"]
        )

        # ----------------------------------------------------
        # Store
        # ----------------------------------------------------

        data = {

            'case': label,

            'lambda': lam,

            'mI2': mI2,

            'f': f,

            'E_exact': E_exact,

            'E_vqe': E_vqe,

            'error': abs(E_exact - E_vqe),

            'fidelity': F,

            'tracking_overlap': tracking_overlap,

            'psi_vqe': psi_vqe
        }

        case_results.append(data)

        all_results.append(data)

        # ----------------------------------------------------
        # Print
        # ----------------------------------------------------

        print("\nFINAL SELECTED STATE")

        print(f"Exact energy     : {E_exact:.12f}")

        print(f"VQE energy       : {E_vqe:.12f}")

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(f"Fidelity         : {F:.12f}")

        print(
            f"Tracking overlap : "
            f"{tracking_overlap:.12f}"
        )

    # ========================================================
    # Case summary
    # ========================================================

    print("\n")

    print("="*110)

    print(f"SUMMARY : {label}")

    print("="*110)

    print(

        f"{'lambda':<12} "
        f"{'Exact E':<18} "
        f"{'VQE E':<18} "
        f"{'Error':<15} "
        f"{'Fidelity':<15} "
        f"{'TrackOverlap':<15}"
    )

    print("="*110)

    for r in case_results:

        print(

            f"{r['lambda']:<12.4f} "
            f"{r['E_exact']:<18.10f} "
            f"{r['E_vqe']:<18.10f} "
            f"{r['error']:<15.4e} "
            f"{r['fidelity']:<15.10f} "
            f"{r['tracking_overlap']:<15.10f}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161742097
# Energy error     : 1.393797e-08
# Fidelity         : 0.999999972152
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641467032
# Energy error     : 3.968449e-08
# Fidelity         : 0.999999993147
# Tracking overlap : 0.999849020035
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030499447366
# Energy error     : 1.375715e-07
# Fidelity         : 0.999999971183
# Tracking overlap : 0.999876134279
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041824421055
# Energy error     : 9.879416e-08
# Fidelity         : 0.999999976626
# Tracking overlap : 0.999895904199
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052684703793
# Energy error     : 1.600311e-07
# Fidelity         : 0.999999977340
# Tracking overlap : 0.999910653070
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063134026512
# Energy error     : 2.377421e-07
# Fidelity         : 0.999999975236
# Tracking overlap : 0.999922529623
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073215997984
# Energy error     : 3.442135e-07
# Fidelity         : 0.999999966271
# Tracking overlap : 0.999931861696
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082966550373
# Energy error     : 3.985577e-07
# Fidelity         : 0.999999970551
# Tracking overlap : 0.999939583089
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092416002501
# Energy error     : 4.943934e-07
# Fidelity         : 0.999999948832
# Tracking overlap : 0.999945936139
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101589928555
# Energy error     : 4.998117e-07
# Fidelity         : 0.999999960291
# Tracking overlap : 0.999951183910
#
#
# ==============================================================================================================
# SUMMARY : Symmetric
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       1.0061617282       1.0061617421       1.3938e-08      0.9999999722    1.0000000000
# 0.3111       1.0186414273       1.0186414670       3.9684e-08      0.9999999931    0.9998490200
# 0.5222       1.0304993098       1.0304994474       1.3757e-07      0.9999999712    0.9998761343
# 0.7333       1.0418243223       1.0418244211       9.8794e-08      0.9999999766    0.9998959042
# 0.9444       1.0526845438       1.0526847038       1.6003e-07      0.9999999773    0.9999106531
# 1.1556       1.0631337888       1.0631340265       2.3774e-07      0.9999999752    0.9999225296
# 1.3667       1.0732156538       1.0732159980       3.4421e-07      0.9999999663    0.9999318617
# 1.5778       1.0829661518       1.0829665504       3.9856e-07      0.9999999706    0.9999395831
# 1.7889       1.0924155081       1.0924160025       4.9439e-07      0.9999999488    0.9999459361
# 2.0000       1.1015894287       1.1015899286       4.9981e-07      0.9999999603    0.9999511839
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.064299455581
# Energy error     : 3.938963e-04
# Fidelity         : 0.999930187311
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.078501336155
# Energy error     : 1.948576e-03
# Fidelity         : 0.999548091743
# Tracking overlap : 0.801205826872
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.700990873134
# Energy error     : 2.040995e-04
# Fidelity         : 0.999942639020
# Tracking overlap : 0.070873865498
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.011393575929
# Energy error     : 1.377757e-04
# Fidelity         : 0.999962054559
# Tracking overlap : 0.653576899845
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.083545210183
# Energy error     : 2.051327e-05
# Fidelity         : 0.999993598806
# Tracking overlap : 0.832490010410
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503593660475
# Energy error     : 8.942123e-04
# Fidelity         : 0.999821711563
# Tracking overlap : 0.896081962365
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118783563877
# Energy error     : 3.161665e-04
# Fidelity         : 0.999926103945
# Tracking overlap : 0.917630792815
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.853284919620
# Energy error     : 4.713438e-05
# Fidelity         : 0.999992773702
# Tracking overlap : 0.937348838514
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663538638098
# Energy error     : 2.150344e-05
# Fidelity         : 0.999996874127
# Tracking overlap : 0.959147556193
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.522121801523
# Energy error     : 1.796278e-05
# Fidelity         : 0.999997617850
# Tracking overlap : 0.975648644031
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB optimised
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -17.0646933519     -17.0642994556     3.9390e-04      0.9999301873    1.0000000000
# 0.3111       -9.0804499123      -9.0785013362      1.9486e-03      0.9995480917    0.8012058269
# 0.5222       -4.7011949726      -4.7009908731      2.0410e-04      0.9999426390    0.0708738655
# 0.7333       -3.0115313516      -3.0113935759      1.3778e-04      0.9999620546    0.6535768998
# 0.9444       -2.0835657235      -2.0835452102      2.0513e-05      0.9999935988    0.8324900104
# 1.1556       -1.5044878727      -1.5035936605      8.9421e-04      0.9998217116    0.8960819624
# 1.3667       -1.1190997304      -1.1187835639      3.1617e-04      0.9999261039    0.9176307928
# 1.5778       -0.8533320540      -0.8532849196      4.7134e-05      0.9999927737    0.9373488385
# 1.7889       -0.6635601415      -0.6635386381      2.1503e-05      0.9999968741    0.9591475562
# 2.0000       -0.5221397643      -0.5221218015      1.7963e-05      0.9999976178    0.9756486440
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.776922989907
# Energy error     : 4.054554e-04
# Fidelity         : 0.999962739926
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.835410796630
# Energy error     : 1.030346e-03
# Fidelity         : 0.999842386781
# Tracking overlap : 0.849112195111
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.730327394301
# Energy error     : 3.889705e-04
# Fidelity         : 0.999938092020
# Tracking overlap : 0.165957180051
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.538105265370
# Energy error     : 4.356533e-05
# Fidelity         : 0.999995923872
# Tracking overlap : 0.634978886885
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.276008408710
# Energy error     : 5.384219e-06
# Fidelity         : 0.999999196017
# Tracking overlap : 0.822346108441
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.447845418791
# Energy error     : 8.349666e-04
# Fidelity         : 0.999880672938
# Tracking overlap : 0.904899491691
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.859685172037
# Energy error     : 1.147093e-03
# Fidelity         : 0.999867539862
# Tracking overlap : 0.941683650477
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.420000299308
# Energy error     : 9.022997e-05
# Fidelity         : 0.999991606175
# Tracking overlap : 0.962108305296
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.076288858538
# Energy error     : 2.370908e-05
# Fidelity         : 0.999998132900
# Tracking overlap : 0.973922181953
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.800058388444
# Energy error     : 1.487777e-05
# Fidelity         : 0.999998534110
# Tracking overlap : 0.981252167450
#
#
# ==============================================================================================================
# SUMMARY : Strong SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -20.7773284453     -20.7769229899     4.0546e-04      0.9999627399    1.0000000000
# 0.3111       -12.8364411428     -12.8354107966     1.0303e-03      0.9998423868    0.8491121951
# 0.5222       -7.7307163648      -7.7303273943      3.8897e-04      0.9999380920    0.1659571801
# 0.7333       -5.5381488307      -5.5381052654      4.3565e-05      0.9999959239    0.6349788869
# 0.9444       -4.2760137929      -4.2760084087      5.3842e-06      0.9999991960    0.8223461084
# 1.1556       -3.4486803854      -3.4478454188      8.3497e-04      0.9998806729    0.9048994917
# 1.3667       -2.8608322652      -2.8596851720      1.1471e-03      0.9998675399    0.9416836505
# 1.5778       -2.4200905293      -2.4200002993      9.0230e-05      0.9999916062    0.9621083053
# 1.7889       -2.0763125676      -2.0762888585      2.3709e-05      0.9999981329    0.9739221820
# 2.0000       -1.8000732662      -1.8000583884      1.4878e-05      0.9999985341    0.9812521675

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------


plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HEA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HEA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119390
# T = 2     Fidelity = 0.99733191
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98267872
# T = 2     Fidelity = 0.99772106
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98395286
# T = 2     Fidelity = 0.99802827
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98504965
# T = 2     Fidelity = 0.99827126
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98600481
# T = 2     Fidelity = 0.99846559
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98685945
# T = 2     Fidelity = 0.99862793
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762643
# T = 2     Fidelity = 0.99876358
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98831387
# T = 2     Fidelity = 0.99887614
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893982
# T = 2     Fidelity = 0.99897196
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98950265
# T = 2     Fidelity = 0.99905115
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00037949
# T = 10    Fidelity = 0.00053533
# T = 20    Fidelity = 0.01172295
# T = 30    Fidelity = 0.08128542
# T = 40    Fidelity = 0.18876211
# T = 50    Fidelity = 0.42917615
# T = 75    Fidelity = 0.56759481
# T = 100   Fidelity = 0.72839909
# T = 125   Fidelity = 0.80798245
# T = 150   Fidelity = 0.83708620
# T = 175   Fidelity = 0.90629527
# T = 200   Fidelity = 0.91925488
# T = 225   Fidelity = 0.96697846
# T = 250   Fidelity = 0.89101329
# T = 275   Fidelity = 0.96880141
# T = 300   Fidelity = 0.85622480
# T = 400   Fidelity = 0.98053703
# T = 500   Fidelity = 0.96074269
# T = 600   Fidelity = 0.95873643
# T = 700   Fidelity = 0.62956323
# T = 800   Fidelity = 0.83520138
# T = 900   Fidelity = 0.82285076
# T = 1000  Fidelity = 0.66449426
# T = 1010  Fidelity = 0.57967295
# T = 1020  Fidelity = 0.61914312
# T = 1030  Fidelity = 0.69817461
# T = 1040  Fidelity = 0.72148375
# T = 1050  Fidelity = 0.78700224
# T = 1060  Fidelity = 0.91719849
# T = 1070  Fidelity = 0.77673623
# T = 1080  Fidelity = 0.78786043
# T = 1090  Fidelity = 0.71226350
# T = 1100  Fidelity = 0.38087286
# T = 1200  Fidelity = 0.59282873
# T = 1300  Fidelity = 0.48308942
# T = 1400  Fidelity = 0.71913733
# T = 1500  Fidelity = 0.46490295
# T = 2000  Fidelity = 0.93521740
# T = 2100  Fidelity = 0.70773010
# T = 2110  Fidelity = 0.56795326
# T = 2120  Fidelity = 0.47335946
# T = 2130  Fidelity = 0.39810236
# T = 2140  Fidelity = 0.49600178
# T = 2150  Fidelity = 0.41748501
# T = 2160  Fidelity = 0.62962736
# T = 2170  Fidelity = 0.52167997
# T = 2180  Fidelity = 0.49494038
# T = 2190  Fidelity = 0.50067094
# T = 2200  Fidelity = 0.35900342
# T = 2300  Fidelity = 0.77447596
# T = 2400  Fidelity = 0.21853881
# T = 2500  Fidelity = 0.75760751
# T = 2600  Fidelity = 0.43577832
# T = 2700  Fidelity = 0.55774630
# T = 2800  Fidelity = 0.85256844
# T = 2900  Fidelity = 0.64784678
# T = 3000  Fidelity = 0.82611218
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00976726e+00
# P0     = 0.82611218
# P1     = 0.05944163
# P0+P1  = 0.88555381
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.00045532
# T = 10    Fidelity = 0.06849457
# T = 20    Fidelity = 0.22820874
# T = 30    Fidelity = 0.62435631
# T = 40    Fidelity = 0.37843165
# T = 50    Fidelity = 0.79012614
# T = 75    Fidelity = 0.74958243
# T = 100   Fidelity = 0.79865804
# T = 125   Fidelity = 0.87753698
# T = 150   Fidelity = 0.88409943
# T = 175   Fidelity = 0.90294893
# T = 200   Fidelity = 0.92670832
# T = 225   Fidelity = 0.93843617
# T = 250   Fidelity = 0.94653884
# T = 275   Fidelity = 0.95140763
# T = 300   Fidelity = 0.94677021
# T = 400   Fidelity = 0.97057144
# T = 500   Fidelity = 0.97017950
# T = 600   Fidelity = 0.82147508
# T = 700   Fidelity = 0.80025530
# T = 800   Fidelity = 0.84484507
# T = 900   Fidelity = 0.72421756
# T = 1000  Fidelity = 0.78131807
# T = 1010  Fidelity = 0.89784546
# T = 1020  Fidelity = 0.87180619
# T = 1030  Fidelity = 0.93217936
# T = 1040  Fidelity = 0.86148099
# T = 1050  Fidelity = 0.87343637
# T = 1060  Fidelity = 0.76230269
# T = 1070  Fidelity = 0.79403201
# T = 1080  Fidelity = 0.54608174
# T = 1090  Fidelity = 0.69261685
# T = 1100  Fidelity = 0.57110466
# T = 1200  Fidelity = 0.79936679
# T = 1300  Fidelity = 0.83572340
# T = 1400  Fidelity = 0.93603131
# T = 1500  Fidelity = 0.85100406
# T = 2000  Fidelity = 0.59086722
# T = 2100  Fidelity = 0.60430858
# T = 2110  Fidelity = 0.68098895
# T = 2120  Fidelity = 0.82988235
# T = 2130  Fidelity = 0.95928643
# T = 2140  Fidelity = 0.77112123
# T = 2150  Fidelity = 0.84660498
# T = 2160  Fidelity = 0.87805400
# T = 2170  Fidelity = 0.61776343
# T = 2180  Fidelity = 0.89774190
# T = 2190  Fidelity = 0.58216499
# T = 2200  Fidelity = 0.49871577
# T = 2300  Fidelity = 0.51856839
# T = 2400  Fidelity = 0.68947328
# T = 2500  Fidelity = 0.34178451
# T = 2600  Fidelity = 0.93294888
# T = 2700  Fidelity = 0.86598443
# T = 2800  Fidelity = 0.86056590
# T = 2900  Fidelity = 0.82236670
# T = 3000  Fidelity = 0.86624911
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02946706e+00
# P0     = 0.86624911
# P1     = 0.01353085
# P0+P1  = 0.87977997
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00003662
# T = 2     Fidelity = 0.00032609
# T = 5     Fidelity = 0.02050587
# T = 10    Fidelity = 0.22198156
# T = 20    Fidelity = 0.58878822
# T = 30    Fidelity = 0.66168051
# T = 40    Fidelity = 0.78998918
# T = 50    Fidelity = 0.82281533
# T = 75    Fidelity = 0.92703874
# T = 100   Fidelity = 0.96744103
# T = 125   Fidelity = 0.98437017
# T = 150   Fidelity = 0.99248189
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00114935
# T = 2     Fidelity = 0.00476606
# T = 5     Fidelity = 0.06207519
# T = 10    Fidelity = 0.28409306
# T = 20    Fidelity = 0.68032302
# T = 30    Fidelity = 0.73473118
# T = 40    Fidelity = 0.82170991
# T = 50    Fidelity = 0.88759613
# T = 75    Fidelity = 0.95490663
# T = 100   Fidelity = 0.98253919
# T = 125   Fidelity = 0.99303451
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00849485
# T = 2     Fidelity = 0.02333371
# T = 5     Fidelity = 0.12483595
# T = 10    Fidelity = 0.34164598
# T = 20    Fidelity = 0.67160665
# T = 30    Fidelity = 0.79930650
# T = 40    Fidelity = 0.85979990
# T = 50    Fidelity = 0.90966055
# T = 75    Fidelity = 0.97047510
# T = 100   Fidelity = 0.98962734
# T = 125   Fidelity = 0.99613924
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03413808
# T = 2     Fidelity = 0.07300915
# T = 5     Fidelity = 0.22133022
# T = 10    Fidelity = 0.42611236
# T = 20    Fidelity = 0.67709159
# T = 30    Fidelity = 0.80034589
# T = 40    Fidelity = 0.87029809
# T = 50    Fidelity = 0.91776934
# T = 75    Fidelity = 0.97856308
# T = 100   Fidelity = 0.99458007
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09498925
# T = 2     Fidelity = 0.17306052
# T = 5     Fidelity = 0.36409393
# T = 10    Fidelity = 0.55420287
# T = 20    Fidelity = 0.74128026
# T = 30    Fidelity = 0.83158716
# T = 40    Fidelity = 0.88418205
# T = 50    Fidelity = 0.91871249
# T = 75    Fidelity = 0.96651674
# T = 100   Fidelity = 0.98515296
# T = 125   Fidelity = 0.99220367
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19082732
# T = 2     Fidelity = 0.31225104
# T = 5     Fidelity = 0.52467652
# T = 10    Fidelity = 0.69142464
# T = 20    Fidelity = 0.82757560
# T = 30    Fidelity = 0.88747196
# T = 40    Fidelity = 0.92197319
# T = 50    Fidelity = 0.94364440
# T = 75    Fidelity = 0.97017121
# T = 100   Fidelity = 0.98270433
# T = 125   Fidelity = 0.98837557
# T = 150   Fidelity = 0.99133442
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30050136
# T = 2     Fidelity = 0.45400355
# T = 5     Fidelity = 0.66145404
# T = 10    Fidelity = 0.79836035
# T = 20    Fidelity = 0.89461560
# T = 30    Fidelity = 0.93351591
# T = 40    Fidelity = 0.95523824
# T = 50    Fidelity = 0.96735038
# T = 75    Fidelity = 0.98319153
# T = 100   Fidelity = 0.98950131
# T = 125   Fidelity = 0.99285466
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40212345
# T = 2     Fidelity = 0.57266700
# T = 5     Fidelity = 0.76033026
# T = 10    Fidelity = 0.86910603
# T = 20    Fidelity = 0.93658902
# T = 30    Fidelity = 0.96234122
# T = 40    Fidelity = 0.97445501
# T = 50    Fidelity = 0.98221704
# T = 75    Fidelity = 0.99128630
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00083273
# T = 10    Fidelity = 0.06384756
# T = 20    Fidelity = 0.45576626
# T = 30    Fidelity = 0.88058323
# T = 40    Fidelity = 0.96772644
# T = 50    Fidelity = 0.99159356
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000242
# T = 5     Fidelity = 0.02497054
# T = 10    Fidelity = 0.90131306
# T = 20    Fidelity = 0.96770017
# T = 30    Fidelity = 0.99630218
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00005261
# T = 2     Fidelity = 0.00078412
# T = 5     Fidelity = 0.18872446
# T = 10    Fidelity = 0.98836270
# T = 20    Fidelity = 0.99520314
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00123870
# T = 2     Fidelity = 0.00812998
# T = 5     Fidelity = 0.34554198
# T = 10    Fidelity = 0.98664563
# T = 20    Fidelity = 0.99352560
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00700756
# T = 2     Fidelity = 0.02899688
# T = 5     Fidelity = 0.47048275
# T = 10    Fidelity = 0.98166988
# T = 20    Fidelity = 0.99295275
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02088265
# T = 2     Fidelity = 0.06415508
# T = 5     Fidelity = 0.56425994
# T = 10    Fidelity = 0.97624235
# T = 20    Fidelity = 0.99245738
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04396100
# T = 2     Fidelity = 0.11084443
# T = 5     Fidelity = 0.63852015
# T = 10    Fidelity = 0.97224186
# T = 20    Fidelity = 0.99273119
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07533753
# T = 2     Fidelity = 0.16381472
# T = 5     Fidelity = 0.69634759
# T = 10    Fidelity = 0.96946004
# T = 20    Fidelity = 0.99319730
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11364798
# T = 2     Fidelity = 0.22076916
# T = 5     Fidelity = 0.74280788
# T = 10    Fidelity = 0.96775672
# T = 20    Fidelity = 0.99357103
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15656406
# T = 2     Fidelity = 0.27861892
# T = 5     Fidelity = 0.78119772
# T = 10    Fidelity = 0.96729171
# T = 20    Fidelity = 0.99387411
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9973319074      1.00972087e+00    None        None        None
# Symmetric      0.311     2         0.9977210640      1.02934439e+00    None        None        None
# Symmetric      0.522     2         0.9980282731      1.04790824e+00    None        None        None
# Symmetric      0.733     2         0.9982712644      1.06556366e+00    None        None        None
# Symmetric      0.944     2         0.9984655928      1.08242773e+00    None        None        None
# Symmetric      1.156     2         0.9986279334      1.09859358e+00    None        None        None
# Symmetric      1.367     2         0.9987635828      1.11413694e+00    None        None        None
# Symmetric      1.578     2         0.9988761428      1.12912045e+00    None        None        None
# Symmetric      1.789     2         0.9989719578      1.14359670e+00    None        None        None
# Symmetric      2.000     2         0.9990511479      1.15761039e+00    None        None        None
# Weak SSB optimised0.100     None      0.9805370329      2.42819099e-01    0.826112    0.059442    0.885554
# Weak SSB optimised0.311     None      0.9705714358      2.61171322e-01    0.866249    0.013531    0.87978
# Weak SSB optimised0.522     150       0.9924818917      2.64873214e-01    None        None        None
# Weak SSB optimised0.733     125       0.9930345145      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     125       0.9961392447      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     100       0.9945800691      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9922036660      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     150       0.9913344209      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9928546564      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     75        0.9912862994      2.55131735e-01    None        None        None
# Strong SSB     0.100     50        0.9915935620      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9963021816      7.22062439e-01    None        None        None
# Strong SSB     0.522     20        0.9952031393      7.78318602e-01    None        None        None
# Strong SSB     0.733     20        0.9935256036      8.15979742e-01    None        None        None
# Strong SSB     0.944     20        0.9929527523      8.44059983e-01    None        None        None
# Strong SSB     1.156     20        0.9924573830      8.66317759e-01    None        None        None
# Strong SSB     1.367     20        0.9927311878      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9931973030      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9935710303      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9938741087      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        color=case_colors[case],
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=1$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color="blue")

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color="green")

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB', color="red")

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='blue'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='green'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='red'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_0^2=1$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Starting of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96520920
# T = 2     Fidelity = 0.99334278
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.03626623e+00
# T = 1     Fidelity = 0.96805518
# T = 2     Fidelity = 0.99422031
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05846299e+00
# T = 1     Fidelity = 0.97050403
# T = 2     Fidelity = 0.99491757
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07916278e+00
# T = 1     Fidelity = 0.97261277
# T = 2     Fidelity = 0.99547238
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.09862393e+00
# T = 1     Fidelity = 0.97444979
# T = 2     Fidelity = 0.99591868
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.11703633e+00
# T = 1     Fidelity = 0.97609178
# T = 2     Fidelity = 0.99629240
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.13454489e+00
# T = 1     Fidelity = 0.97756320
# T = 2     Fidelity = 0.99660579
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.15126343e+00
# T = 1     Fidelity = 0.97888005
# T = 2     Fidelity = 0.99686714
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.16728342e+00
# T = 1     Fidelity = 0.98007693
# T = 2     Fidelity = 0.99709065
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98115102
# T = 2     Fidelity = 0.99727675
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000152
# T = 10    Fidelity = 0.00047018
# T = 20    Fidelity = 0.00574177
# T = 30    Fidelity = 0.01823113
# T = 40    Fidelity = 0.06159649
# T = 50    Fidelity = 0.16070900
# T = 75    Fidelity = 0.32252234
# T = 100   Fidelity = 0.48118758
# T = 125   Fidelity = 0.62886429
# T = 150   Fidelity = 0.72429245
# T = 175   Fidelity = 0.79383793
# T = 200   Fidelity = 0.83514940
# T = 225   Fidelity = 0.84687418
# T = 250   Fidelity = 0.85553315
# T = 275   Fidelity = 0.71802396
# T = 300   Fidelity = 0.79222007
# T = 400   Fidelity = 0.93094993
# T = 500   Fidelity = 0.91040316
# T = 600   Fidelity = 0.89304964
# T = 700   Fidelity = 0.81667704
# T = 800   Fidelity = 0.64636520
# T = 900   Fidelity = 0.74787737
# T = 1000  Fidelity = 0.62991234
# T = 1010  Fidelity = 0.62224395
# T = 1020  Fidelity = 0.70059218
# T = 1030  Fidelity = 0.67216326
# T = 1040  Fidelity = 0.25547071
# T = 1050  Fidelity = 0.41848810
# T = 1060  Fidelity = 0.49978626
# T = 1070  Fidelity = 0.47181653
# T = 1080  Fidelity = 0.56600305
# T = 1090  Fidelity = 0.54901347
# T = 1100  Fidelity = 0.75507326
# T = 1200  Fidelity = 0.22328453
# T = 1300  Fidelity = 0.25231169
# T = 1400  Fidelity = 0.65176289
# T = 1500  Fidelity = 0.48356832
# T = 2000  Fidelity = 0.33800265
# T = 2100  Fidelity = 0.88864138
# T = 2110  Fidelity = 0.81488102
# T = 2120  Fidelity = 0.77028077
# T = 2130  Fidelity = 0.74758858
# T = 2140  Fidelity = 0.54482222
# T = 2150  Fidelity = 0.75819654
# T = 2160  Fidelity = 0.56156941
# T = 2170  Fidelity = 0.63621854
# T = 2180  Fidelity = 0.70267167
# T = 2190  Fidelity = 0.53261972
# T = 2200  Fidelity = 0.53062612
# T = 2300  Fidelity = 0.33855398
# T = 2400  Fidelity = 0.51781758
# T = 2500  Fidelity = 0.52712188
# T = 2600  Fidelity = 0.30710047
# T = 2700  Fidelity = 0.24665311
# T = 2800  Fidelity = 0.53887495
# T = 2900  Fidelity = 0.50528734
# T = 3000  Fidelity = 0.91788194
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91788194
# P1     = 0.00922181
# P0+P1  = 0.92710375
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61673084e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00001551
# T = 10    Fidelity = 0.00290941
# T = 20    Fidelity = 0.22289077
# T = 30    Fidelity = 0.29852458
# T = 40    Fidelity = 0.34631915
# T = 50    Fidelity = 0.71158205
# T = 75    Fidelity = 0.77513064
# T = 100   Fidelity = 0.67115544
# T = 125   Fidelity = 0.86372561
# T = 150   Fidelity = 0.77699112
# T = 175   Fidelity = 0.90702951
# T = 200   Fidelity = 0.96382865
# T = 225   Fidelity = 0.88755797
# T = 250   Fidelity = 0.96330524
# T = 275   Fidelity = 0.94519157
# T = 300   Fidelity = 0.93325602
# T = 400   Fidelity = 0.96599623
# T = 500   Fidelity = 0.96111998
# T = 600   Fidelity = 0.87093114
# T = 700   Fidelity = 0.62733487
# T = 800   Fidelity = 0.79377706
# T = 900   Fidelity = 0.73722430
# T = 1000  Fidelity = 0.83912960
# T = 1010  Fidelity = 0.80286357
# T = 1020  Fidelity = 0.84657619
# T = 1030  Fidelity = 0.74807867
# T = 1040  Fidelity = 0.71244944
# T = 1050  Fidelity = 0.68872909
# T = 1060  Fidelity = 0.55448056
# T = 1070  Fidelity = 0.52909554
# T = 1080  Fidelity = 0.64786773
# T = 1090  Fidelity = 0.51792327
# T = 1100  Fidelity = 0.49580714
# T = 1200  Fidelity = 0.89054451
# T = 1300  Fidelity = 0.67048361
# T = 1400  Fidelity = 0.81822175
# T = 1500  Fidelity = 0.91506424
# T = 2000  Fidelity = 0.62088266
# T = 2100  Fidelity = 0.48929517
# T = 2110  Fidelity = 0.76304196
# T = 2120  Fidelity = 0.72205171
# T = 2130  Fidelity = 0.56676380
# T = 2140  Fidelity = 0.48681254
# T = 2150  Fidelity = 0.62209158
# T = 2160  Fidelity = 0.54331513
# T = 2170  Fidelity = 0.42643243
# T = 2180  Fidelity = 0.50115993
# T = 2190  Fidelity = 0.81370139
# T = 2200  Fidelity = 0.61443727
# T = 2300  Fidelity = 0.66380955
# T = 2400  Fidelity = 0.59231348
# T = 2500  Fidelity = 0.82619242
# T = 2600  Fidelity = 0.62040048
# T = 2700  Fidelity = 0.88675204
# T = 2800  Fidelity = 0.64886522
# T = 2900  Fidelity = 0.69146144
# T = 3000  Fidelity = 0.86401528
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43053089e+00
# P0     = 0.86401528
# P1     = 0.03986241
# P0+P1  = 0.90387769
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64768458e-01
# T = 1     Fidelity = 0.00000987
# T = 2     Fidelity = 0.00014929
# T = 5     Fidelity = 0.00347166
# T = 10    Fidelity = 0.05102580
# T = 20    Fidelity = 0.41080508
# T = 30    Fidelity = 0.59440875
# T = 40    Fidelity = 0.58189566
# T = 50    Fidelity = 0.72488904
# T = 75    Fidelity = 0.81394791
# T = 100   Fidelity = 0.89305153
# T = 125   Fidelity = 0.94394983
# T = 150   Fidelity = 0.96739107
# T = 175   Fidelity = 0.97772674
# T = 200   Fidelity = 0.98533051
# T = 225   Fidelity = 0.98716559
# T = 250   Fidelity = 0.99137684
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00049820
# T = 2     Fidelity = 0.00289409
# T = 5     Fidelity = 0.02085531
# T = 10    Fidelity = 0.11090341
# T = 20    Fidelity = 0.42442930
# T = 30    Fidelity = 0.66109148
# T = 40    Fidelity = 0.73189114
# T = 50    Fidelity = 0.76236718
# T = 75    Fidelity = 0.88518333
# T = 100   Fidelity = 0.93287476
# T = 125   Fidelity = 0.96609455
# T = 150   Fidelity = 0.98139150
# T = 175   Fidelity = 0.98895673
# T = 200   Fidelity = 0.99265240
#
# Minimum T for Fidelity >= 0.99 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00482145
# T = 2     Fidelity = 0.01664419
# T = 5     Fidelity = 0.06225364
# T = 10    Fidelity = 0.18576222
# T = 20    Fidelity = 0.44909908
# T = 30    Fidelity = 0.64680008
# T = 40    Fidelity = 0.75623321
# T = 50    Fidelity = 0.81838056
# T = 75    Fidelity = 0.91084570
# T = 100   Fidelity = 0.95910168
# T = 125   Fidelity = 0.97967064
# T = 150   Fidelity = 0.98964105
# T = 175   Fidelity = 0.99325970
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.02303742
# T = 2     Fidelity = 0.05769131
# T = 5     Fidelity = 0.14256096
# T = 10    Fidelity = 0.29255053
# T = 20    Fidelity = 0.51718525
# T = 30    Fidelity = 0.66376483
# T = 40    Fidelity = 0.75702198
# T = 50    Fidelity = 0.82069759
# T = 75    Fidelity = 0.91733817
# T = 100   Fidelity = 0.96569462
# T = 125   Fidelity = 0.98707125
# T = 150   Fidelity = 0.99469511
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.07178494
# T = 2     Fidelity = 0.14618343
# T = 5     Fidelity = 0.27575970
# T = 10    Fidelity = 0.44300672
# T = 20    Fidelity = 0.63604724
# T = 30    Fidelity = 0.74212347
# T = 40    Fidelity = 0.80893057
# T = 50    Fidelity = 0.85604928
# T = 75    Fidelity = 0.92554317
# T = 100   Fidelity = 0.96120694
# T = 125   Fidelity = 0.97993219
# T = 150   Fidelity = 0.98819515
# T = 175   Fidelity = 0.99214264
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.15459394
# T = 2     Fidelity = 0.27504199
# T = 5     Fidelity = 0.43707553
# T = 10    Fidelity = 0.60278900
# T = 20    Fidelity = 0.76075740
# T = 30    Fidelity = 0.83540408
# T = 40    Fidelity = 0.87993445
# T = 50    Fidelity = 0.90964705
# T = 75    Fidelity = 0.95162968
# T = 100   Fidelity = 0.97284560
# T = 125   Fidelity = 0.98357670
# T = 150   Fidelity = 0.98873456
# T = 175   Fidelity = 0.99244845
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.25449346
# T = 2     Fidelity = 0.41126261
# T = 5     Fidelity = 0.58322067
# T = 10    Fidelity = 0.73041296
# T = 20    Fidelity = 0.85249188
# T = 30    Fidelity = 0.90347062
# T = 40    Fidelity = 0.93186002
# T = 50    Fidelity = 0.94948852
# T = 75    Fidelity = 0.97419184
# T = 100   Fidelity = 0.98529954
# T = 125   Fidelity = 0.99079529
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.35070548
# T = 2     Fidelity = 0.52871215
# T = 5     Fidelity = 0.69427938
# T = 10    Fidelity = 0.81767169
# T = 20    Fidelity = 0.90995502
# T = 30    Fidelity = 0.94408469
# T = 40    Fidelity = 0.96190699
# T = 50    Fidelity = 0.97276413
# T = 75    Fidelity = 0.98643913
# T = 100   Fidelity = 0.99219459
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.06623659e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00011894
# T = 10    Fidelity = 0.00638425
# T = 20    Fidelity = 0.15716134
# T = 30    Fidelity = 0.48663516
# T = 40    Fidelity = 0.76113126
# T = 50    Fidelity = 0.90747171
# T = 75    Fidelity = 0.99417000
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.20609288e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000017
# T = 5     Fidelity = 0.00111960
# T = 10    Fidelity = 0.18544484
# T = 20    Fidelity = 0.88853696
# T = 30    Fidelity = 0.96907923
# T = 40    Fidelity = 0.99607938
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.76105909e-01
# T = 1     Fidelity = 0.00000404
# T = 2     Fidelity = 0.00014578
# T = 5     Fidelity = 0.03222580
# T = 10    Fidelity = 0.56596648
# T = 20    Fidelity = 0.90504677
# T = 30    Fidelity = 0.99230614
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.12909217e-01
# T = 1     Fidelity = 0.00019341
# T = 2     Fidelity = 0.00242181
# T = 5     Fidelity = 0.10906156
# T = 10    Fidelity = 0.69714971
# T = 20    Fidelity = 0.94964808
# T = 30    Fidelity = 0.99070763
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.40169449e-01
# T = 1     Fidelity = 0.00166868
# T = 2     Fidelity = 0.01140828
# T = 5     Fidelity = 0.20675126
# T = 10    Fidelity = 0.76556047
# T = 20    Fidelity = 0.97047591
# T = 30    Fidelity = 0.99048109
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.61748289e-01
# T = 1     Fidelity = 0.00658179
# T = 2     Fidelity = 0.03038997
# T = 5     Fidelity = 0.30372348
# T = 10    Fidelity = 0.80596278
# T = 20    Fidelity = 0.97966496
# T = 30    Fidelity = 0.99034399
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.79340685e-01
# T = 1     Fidelity = 0.01686507
# T = 2     Fidelity = 0.05979508
# T = 5     Fidelity = 0.39447129
# T = 10    Fidelity = 0.83483794
# T = 20    Fidelity = 0.98416149
# T = 30    Fidelity = 0.99093323
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.94021606e-01
# T = 1     Fidelity = 0.03345543
# T = 2     Fidelity = 0.09733395
# T = 5     Fidelity = 0.47336125
# T = 10    Fidelity = 0.85658238
# T = 20    Fidelity = 0.98588754
# T = 30    Fidelity = 0.99162850
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.06402712e-01
# T = 1     Fidelity = 0.05660211
# T = 2     Fidelity = 0.14153553
# T = 5     Fidelity = 0.54227193
# T = 10    Fidelity = 0.87419994
# T = 20    Fidelity = 0.98627347
# T = 30    Fidelity = 0.99219809
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.17036009e-01
# T = 1     Fidelity = 0.08540946
# T = 2     Fidelity = 0.18972708
# T = 5     Fidelity = 0.60202905
# T = 10    Fidelity = 0.88954939
# T = 20    Fidelity = 0.98626667
# T = 30    Fidelity = 0.99273258
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9933427802      1.01220263e+00    None        None        None
# Symmetric      0.311     2         0.9942203072      1.03626623e+00    None        None        None
# Symmetric      0.522     2         0.9949175679      1.05846299e+00    None        None        None
# Symmetric      0.733     2         0.9954723831      1.07916278e+00    None        None        None
# Symmetric      0.944     2         0.9959186755      1.09862393e+00    None        None        None
# Symmetric      1.156     2         0.9962924034      1.11703633e+00    None        None        None
# Symmetric      1.367     2         0.9966057874      1.13454489e+00    None        None        None
# Symmetric      1.578     2         0.9968671446      1.15126343e+00    None        None        None
# Symmetric      1.789     2         0.9970906520      1.16728342e+00    None        None        None
# Symmetric      2.000     2         0.9972767462      1.18267976e+00    None        None        None
# Weak SSB optimised0.100     None      0.9309499329      2.43127858e-01    0.917882    0.009222    0.927104
# Weak SSB optimised0.311     None      0.9659962312      2.61673084e-01    0.864015    0.039862    0.903878
# Weak SSB optimised0.522     250       0.9913768442      2.64768458e-01    None        None        None
# Weak SSB optimised0.733     200       0.9926524034      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     175       0.9932597035      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     150       0.9946951107      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     175       0.9921426409      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     175       0.9924484505      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9907952894      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     100       0.9921945851      2.55131735e-01    None        None        None
# Strong SSB     0.100     75        0.9941699980      6.06623659e-01    None        None        None
# Strong SSB     0.311     40        0.9960793791      7.20609288e-01    None        None        None
# Strong SSB     0.522     30        0.9923061371      7.76105909e-01    None        None        None
# Strong SSB     0.733     30        0.9907076308      8.12909217e-01    None        None        None
# Strong SSB     0.944     30        0.9904810947      8.40169449e-01    None        None        None
# Strong SSB     1.156     30        0.9903439880      8.61748289e-01    None        None        None
# Strong SSB     1.367     30        0.9909332257      8.79340685e-01    None        None        None
# Strong SSB     1.578     30        0.9916285046      8.94021606e-01    None        None        None
# Strong SSB     1.789     30        0.9921980910      9.06402712e-01    None        None        None
# Strong SSB     2.000     30        0.9927325779      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap,  $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009558
# T = 10    Fidelity = 0.00119338
# T = 20    Fidelity = 0.02687364
# T = 30    Fidelity = 0.09666935
# T = 40    Fidelity = 0.19609112
# T = 50    Fidelity = 0.31173570
# T = 75    Fidelity = 0.56619211
# T = 100   Fidelity = 0.72001264
# T = 125   Fidelity = 0.80738121
# T = 150   Fidelity = 0.86469562
# T = 175   Fidelity = 0.90864133
# T = 200   Fidelity = 0.94629620
# T = 225   Fidelity = 0.96686768
# T = 250   Fidelity = 0.95352206
# T = 275   Fidelity = 0.98204480
# T = 300   Fidelity = 0.96282397
# T = 400   Fidelity = 0.95497458
# T = 500   Fidelity = 0.93802484
# T = 600   Fidelity = 0.90703554
# T = 700   Fidelity = 0.99336275
#
# Minimum T for Fidelity >= 0.99 : 700
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624069e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144482
# T = 10    Fidelity = 0.10202128
# T = 20    Fidelity = 0.52980277
# T = 30    Fidelity = 0.63895567
# T = 40    Fidelity = 0.76793298
# T = 50    Fidelity = 0.88384393
# T = 75    Fidelity = 0.94226587
# T = 100   Fidelity = 0.97306336
# T = 125   Fidelity = 0.99693254
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043132e-07
# T = 1     Fidelity = 0.00005022
# T = 2     Fidelity = 0.00043602
# T = 5     Fidelity = 0.02724808
# T = 10    Fidelity = 0.28406711
# T = 20    Fidelity = 0.77879987
# T = 30    Fidelity = 0.80544987
# T = 40    Fidelity = 0.95119663
# T = 50    Fidelity = 0.93702054
# T = 75    Fidelity = 0.99144230
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155015
# T = 2     Fidelity = 0.00639309
# T = 5     Fidelity = 0.08480390
# T = 10    Fidelity = 0.38786681
# T = 20    Fidelity = 0.90881769
# T = 30    Fidelity = 0.89422912
# T = 40    Fidelity = 0.97223018
# T = 50    Fidelity = 0.99231547
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01057939
# T = 2     Fidelity = 0.02893008
# T = 5     Fidelity = 0.16449298
# T = 10    Fidelity = 0.46787687
# T = 20    Fidelity = 0.92254295
# T = 30    Fidelity = 0.97977705
# T = 40    Fidelity = 0.97236630
# T = 50    Fidelity = 0.99387715
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03667771
# T = 2     Fidelity = 0.07740599
# T = 5     Fidelity = 0.25992049
# T = 10    Fidelity = 0.54100826
# T = 20    Fidelity = 0.90448867
# T = 30    Fidelity = 0.99651375
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08776305
# T = 2     Fidelity = 0.15531146
# T = 5     Fidelity = 0.36741137
# T = 10    Fidelity = 0.61610180
# T = 20    Fidelity = 0.89396586
# T = 30    Fidelity = 0.98167480
# T = 40    Fidelity = 0.99755671
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16578458
# T = 2     Fidelity = 0.25894955
# T = 5     Fidelity = 0.48155609
# T = 10    Fidelity = 0.69439042
# T = 20    Fidelity = 0.90353263
# T = 30    Fidelity = 0.97294422
# T = 40    Fidelity = 0.99115149
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26388720
# T = 2     Fidelity = 0.37661121
# T = 5     Fidelity = 0.59254998
# T = 10    Fidelity = 0.76989525
# T = 20    Fidelity = 0.92536415
# T = 30    Fidelity = 0.97251329
# T = 40    Fidelity = 0.98679371
# T = 50    Fidelity = 0.99323437
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36880708
# T = 2     Fidelity = 0.49274962
# T = 5     Fidelity = 0.69001966
# T = 10    Fidelity = 0.83496684
# T = 20    Fidelity = 0.94706471
# T = 30    Fidelity = 0.97597036
# T = 40    Fidelity = 0.98837713
# T = 50    Fidelity = 0.99291475
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.62226183
# T = 2     Fidelity = 0.65108788
# T = 5     Fidelity = 0.70766645
# T = 10    Fidelity = 0.76237560
# T = 20    Fidelity = 0.82890369
# T = 30    Fidelity = 0.86962202
# T = 40    Fidelity = 0.89802919
# T = 50    Fidelity = 0.91825293
# T = 75    Fidelity = 0.94943135
# T = 100   Fidelity = 0.96631075
# T = 125   Fidelity = 0.97472553
# T = 150   Fidelity = 0.98088943
# T = 175   Fidelity = 0.98179040
# T = 200   Fidelity = 0.98723101
# T = 225   Fidelity = 0.97847468
# T = 250   Fidelity = 0.98547177
# T = 275   Fidelity = 0.95566539
# T = 300   Fidelity = 0.93878812
# T = 400   Fidelity = 0.97096539
# T = 500   Fidelity = 0.97603489
# T = 600   Fidelity = 0.94373422
# T = 700   Fidelity = 0.81213196
# T = 800   Fidelity = 0.94249564
# T = 900   Fidelity = 0.98441677
# T = 1000  Fidelity = 0.97574072
# T = 1010  Fidelity = 0.95569221
# T = 1020  Fidelity = 0.94290423
# T = 1030  Fidelity = 0.95695597
# T = 1040  Fidelity = 0.96837632
# T = 1050  Fidelity = 0.96514226
# T = 1060  Fidelity = 0.96743201
# T = 1070  Fidelity = 0.97125163
# T = 1080  Fidelity = 0.98801485
# T = 1090  Fidelity = 0.99144102
#
# Minimum T for Fidelity >= 0.99 : 1090
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.75205918
# T = 2     Fidelity = 0.76214898
# T = 5     Fidelity = 0.79107301
# T = 10    Fidelity = 0.82184022
# T = 20    Fidelity = 0.85701128
# T = 30    Fidelity = 0.87878542
# T = 40    Fidelity = 0.89414647
# T = 50    Fidelity = 0.90599694
# T = 75    Fidelity = 0.92682832
# T = 100   Fidelity = 0.94062664
# T = 125   Fidelity = 0.95017201
# T = 150   Fidelity = 0.95620116
# T = 175   Fidelity = 0.96314791
# T = 200   Fidelity = 0.96484355
# T = 225   Fidelity = 0.96784179
# T = 250   Fidelity = 0.96703829
# T = 275   Fidelity = 0.96971137
# T = 300   Fidelity = 0.97194252
# T = 400   Fidelity = 0.97695935
# T = 500   Fidelity = 0.96235155
# T = 600   Fidelity = 0.95987363
# T = 700   Fidelity = 0.97729889
# T = 800   Fidelity = 0.92350375
# T = 900   Fidelity = 0.91506998
# T = 1000  Fidelity = 0.93290620
# T = 1010  Fidelity = 0.93381178
# T = 1020  Fidelity = 0.93307306
# T = 1030  Fidelity = 0.93226276
# T = 1040  Fidelity = 0.92908471
# T = 1050  Fidelity = 0.92799976
# T = 1060  Fidelity = 0.92659273
# T = 1070  Fidelity = 0.92771441
# T = 1080  Fidelity = 0.92718540
# T = 1090  Fidelity = 0.92868801
# T = 1100  Fidelity = 0.92814637
# T = 1200  Fidelity = 0.94895565
# T = 1300  Fidelity = 0.97154151
# T = 1400  Fidelity = 0.97639893
# T = 1500  Fidelity = 0.96734483
# T = 2000  Fidelity = 0.94133366
# T = 2100  Fidelity = 0.95470814
# T = 2110  Fidelity = 0.95684076
# T = 2120  Fidelity = 0.95832573
# T = 2130  Fidelity = 0.95952859
# T = 2140  Fidelity = 0.95751983
# T = 2150  Fidelity = 0.95810267
# T = 2160  Fidelity = 0.95449409
# T = 2170  Fidelity = 0.95287360
# T = 2180  Fidelity = 0.94783758
# T = 2190  Fidelity = 0.94673342
# T = 2200  Fidelity = 0.94653922
# T = 2300  Fidelity = 0.93136031
# T = 2400  Fidelity = 0.98086598
# T = 2500  Fidelity = 0.98254918
# T = 2600  Fidelity = 0.96147252
# T = 2700  Fidelity = 0.94741693
# T = 2800  Fidelity = 0.92755869
# T = 2900  Fidelity = 0.92560220
# T = 3000  Fidelity = 0.94260564
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.71621181e-01
# P0     = 0.94260564
# P1     = 0.03655993
# P0+P1  = 0.97916557
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.99084174
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98773557
# T = 2     Fidelity = 0.99676494
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97972680
# T = 2     Fidelity = 0.99124165
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.95039423
# T = 2     Fidelity = 0.96652585
# T = 5     Fidelity = 0.97807996
# T = 10    Fidelity = 0.98191515
# T = 20    Fidelity = 0.98556984
# T = 30    Fidelity = 0.98806645
# T = 40    Fidelity = 0.98934580
# T = 50    Fidelity = 0.99034181
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.88013418
# T = 2     Fidelity = 0.90315958
# T = 5     Fidelity = 0.92735104
# T = 10    Fidelity = 0.93745861
# T = 20    Fidelity = 0.95172400
# T = 30    Fidelity = 0.95829324
# T = 40    Fidelity = 0.96394903
# T = 50    Fidelity = 0.96739658
# T = 75    Fidelity = 0.97420963
# T = 100   Fidelity = 0.97884223
# T = 125   Fidelity = 0.98200910
# T = 150   Fidelity = 0.98433050
# T = 175   Fidelity = 0.98625287
# T = 200   Fidelity = 0.98761689
# T = 225   Fidelity = 0.98873936
# T = 250   Fidelity = 0.98985117
# T = 275   Fidelity = 0.99081944
#
# Minimum T for Fidelity >= 0.99 : 275
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78855111
# T = 2     Fidelity = 0.81874258
# T = 5     Fidelity = 0.85736284
# T = 10    Fidelity = 0.87906308
# T = 20    Fidelity = 0.91039965
# T = 30    Fidelity = 0.92463237
# T = 40    Fidelity = 0.93526442
# T = 50    Fidelity = 0.94368232
# T = 75    Fidelity = 0.95742505
# T = 100   Fidelity = 0.96633950
# T = 125   Fidelity = 0.97249188
# T = 150   Fidelity = 0.97691451
# T = 175   Fidelity = 0.98050539
# T = 200   Fidelity = 0.98288335
# T = 225   Fidelity = 0.98481132
# T = 250   Fidelity = 0.98682967
# T = 275   Fidelity = 0.98824705
# T = 300   Fidelity = 0.98952329
# T = 400   Fidelity = 0.99258755
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.72037150
# T = 2     Fidelity = 0.75696837
# T = 5     Fidelity = 0.80734935
# T = 10    Fidelity = 0.84353837
# T = 20    Fidelity = 0.89193697
# T = 30    Fidelity = 0.91337489
# T = 40    Fidelity = 0.93029375
# T = 50    Fidelity = 0.93995858
# T = 75    Fidelity = 0.95872076
# T = 100   Fidelity = 0.96995484
# T = 125   Fidelity = 0.97717728
# T = 150   Fidelity = 0.98205133
# T = 175   Fidelity = 0.98548735
# T = 200   Fidelity = 0.98779890
# T = 225   Fidelity = 0.98958613
# T = 250   Fidelity = 0.99103912
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.69246941
# T = 2     Fidelity = 0.73464245
# T = 5     Fidelity = 0.79311152
# T = 10    Fidelity = 0.84072390
# T = 20    Fidelity = 0.90343776
# T = 30    Fidelity = 0.92705051
# T = 40    Fidelity = 0.94571814
# T = 50    Fidelity = 0.95657814
# T = 75    Fidelity = 0.97331144
# T = 100   Fidelity = 0.98218866
# T = 125   Fidelity = 0.98739071
# T = 150   Fidelity = 0.99062054
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99429522
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.99426196
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.42665601e+00
# T = 1     Fidelity = 0.99373302
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41121208e+00
# T = 1     Fidelity = 0.99397420
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.99329066
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.99216991
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99102783
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98987709
# T = 2     Fidelity = 0.99686930
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98830205
# T = 2     Fidelity = 0.99603872
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98659252
# T = 2     Fidelity = 0.99509181
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     700       0.9933627484      2.15534848e-04    None        None        None
# Symmetric      0.311     125       0.9969325444      1.15624069e-06    None        None        None
# Symmetric      0.522     75        0.9914423009      3.42043132e-07    None        None        None
# Symmetric      0.733     50        0.9923154662      1.41278093e-05    None        None        None
# Symmetric      0.944     50        0.9938771493      3.35131121e-04    None        None        None
# Symmetric      1.156     30        0.9965137532      2.39158790e-03    None        None        None
# Symmetric      1.367     40        0.9975567095      8.93695212e-03    None        None        None
# Symmetric      1.578     40        0.9911514917      2.26116126e-02    None        None        None
# Symmetric      1.789     50        0.9932343678      4.43232760e-02    None        None        None
# Symmetric      2.000     50        0.9929147526      7.29248761e-02    None        None        None
# Weak SSB optimised0.100     1090      0.9914410241      8.65519637e-01    None        None        None
# Weak SSB optimised0.311     None      0.9825491753      5.19764834e-01    0.942606    0.03656     0.979166
# Weak SSB optimised0.522     1         0.9908417439      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     2         0.9967649391      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     2         0.9912416539      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     50        0.9903418060      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     275       0.9908194401      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     400       0.9925875538      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     250       0.9910391239      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     150       0.9906205358      2.54594564e-01    None        None        None
# Strong SSB     0.100     1         0.9942952197      3.59472102e+00    None        None        None
# Strong SSB     0.311     1         0.9942619614      1.58498916e+00    None        None        None
# Strong SSB     0.522     1         0.9937330214      1.42665601e+00    None        None        None
# Strong SSB     0.733     1         0.9939742013      1.41121208e+00    None        None        None
# Strong SSB     0.944     1         0.9932906555      1.38481786e+00    None        None        None
# Strong SSB     1.156     1         0.9921699126      1.34302163e+00    None        None        None
# Strong SSB     1.367     1         0.9910278295      1.29217279e+00    None        None        None
# Strong SSB     1.578     2         0.9968692966      1.23335459e+00    None        None        None
# Strong SSB     1.789     2         0.9960387176      1.17426012e+00    None        None        None
# Strong SSB     2.000     2         0.9950918076      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================



case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
# Define colors for each case
case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

    
for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()


plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-2.0

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000295
# T = 10    Fidelity = 0.00027926
# T = 20    Fidelity = 0.00630197
# T = 30    Fidelity = 0.02604050
# T = 40    Fidelity = 0.06582699
# T = 50    Fidelity = 0.12447907
# T = 75    Fidelity = 0.30903245
# T = 100   Fidelity = 0.46391851
# T = 125   Fidelity = 0.64204625
# T = 150   Fidelity = 0.69157654
# T = 175   Fidelity = 0.77468788
# T = 200   Fidelity = 0.83394856
# T = 225   Fidelity = 0.81460444
# T = 250   Fidelity = 0.90535617
# T = 275   Fidelity = 0.91625914
# T = 300   Fidelity = 0.86715042
# T = 400   Fidelity = 0.97880090
# T = 500   Fidelity = 0.86744220
# T = 600   Fidelity = 0.89637427
# T = 700   Fidelity = 0.86506749
# T = 800   Fidelity = 0.84095298
# T = 900   Fidelity = 0.91561558
# T = 1000  Fidelity = 0.78789327
# T = 1010  Fidelity = 0.86617448
# T = 1020  Fidelity = 0.76218381
# T = 1030  Fidelity = 0.71446357
# T = 1040  Fidelity = 0.60474928
# T = 1050  Fidelity = 0.44975181
# T = 1060  Fidelity = 0.49369241
# T = 1070  Fidelity = 0.46201988
# T = 1080  Fidelity = 0.54278293
# T = 1090  Fidelity = 0.59940154
# T = 1100  Fidelity = 0.58203151
# T = 1200  Fidelity = 0.69558110
# T = 1300  Fidelity = 0.53378994
# T = 1400  Fidelity = 0.88370182
# T = 1500  Fidelity = 0.75104987
# T = 2000  Fidelity = 0.48181092
# T = 2100  Fidelity = 0.34343474
# T = 2110  Fidelity = 0.54051638
# T = 2120  Fidelity = 0.62151890
# T = 2130  Fidelity = 0.58570134
# T = 2140  Fidelity = 0.55836376
# T = 2150  Fidelity = 0.44171792
# T = 2160  Fidelity = 0.59534155
# T = 2170  Fidelity = 0.54223851
# T = 2180  Fidelity = 0.58481240
# T = 2190  Fidelity = 0.64417936
# T = 2200  Fidelity = 0.57757096
# T = 2300  Fidelity = 0.89031682
# T = 2400  Fidelity = 0.61186726
# T = 2500  Fidelity = 0.43003565
# T = 2600  Fidelity = 0.69223087
# T = 2700  Fidelity = 0.84404352
# T = 2800  Fidelity = 0.79491052
# T = 2900  Fidelity = 0.77013564
# T = 3000  Fidelity = 0.70247782
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.79379555e-02
# P0     = 0.70247782
# P1     = 0.00000000
# P0+P1  = 0.70247782
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.17908350e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00030526
# T = 10    Fidelity = 0.01973101
# T = 20    Fidelity = 0.35206780
# T = 30    Fidelity = 0.52578784
# T = 40    Fidelity = 0.54423532
# T = 50    Fidelity = 0.70351683
# T = 75    Fidelity = 0.85009152
# T = 100   Fidelity = 0.92374848
# T = 125   Fidelity = 0.95513517
# T = 150   Fidelity = 0.97617788
# T = 175   Fidelity = 0.99755163
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.94880929e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.01013746
# T = 10    Fidelity = 0.29392450
# T = 20    Fidelity = 0.47645727
# T = 30    Fidelity = 0.65916291
# T = 40    Fidelity = 0.84254606
# T = 50    Fidelity = 0.88341469
# T = 75    Fidelity = 0.96313127
# T = 100   Fidelity = 0.98781922
# T = 125   Fidelity = 0.99596166
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.58119073e-07
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000815
# T = 5     Fidelity = 0.06264614
# T = 10    Fidelity = 0.29630693
# T = 20    Fidelity = 0.55805029
# T = 30    Fidelity = 0.72697291
# T = 40    Fidelity = 0.83533017
# T = 50    Fidelity = 0.91100189
# T = 75    Fidelity = 0.98046269
# T = 100   Fidelity = 0.99984439
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.89654645e-08
# T = 1     Fidelity = 0.00000138
# T = 2     Fidelity = 0.00013185
# T = 5     Fidelity = 0.11159851
# T = 10    Fidelity = 0.49004317
# T = 20    Fidelity = 0.76516981
# T = 30    Fidelity = 0.88756332
# T = 40    Fidelity = 0.94380615
# T = 50    Fidelity = 0.97009594
# T = 75    Fidelity = 0.99783039
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.17592608e-07
# T = 1     Fidelity = 0.00002205
# T = 2     Fidelity = 0.00081351
# T = 5     Fidelity = 0.15753848
# T = 10    Fidelity = 0.62743252
# T = 20    Fidelity = 0.87767652
# T = 30    Fidelity = 0.95887053
# T = 40    Fidelity = 0.98613018
# T = 50    Fidelity = 0.99608515
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 2.47961107e-07
# T = 1     Fidelity = 0.00014363
# T = 2     Fidelity = 0.00277494
# T = 5     Fidelity = 0.19659145
# T = 10    Fidelity = 0.73840391
# T = 20    Fidelity = 0.93001159
# T = 30    Fidelity = 0.97197683
# T = 40    Fidelity = 0.98585203
# T = 50    Fidelity = 0.99133269
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 3.56990608e-07
# T = 1     Fidelity = 0.00057620
# T = 2     Fidelity = 0.00690755
# T = 5     Fidelity = 0.23187743
# T = 10    Fidelity = 0.80830925
# T = 20    Fidelity = 0.93689656
# T = 30    Fidelity = 0.96371963
# T = 40    Fidelity = 0.98388466
# T = 50    Fidelity = 0.99475687
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.45005900e-06
# T = 1     Fidelity = 0.00169000
# T = 2     Fidelity = 0.01404677
# T = 5     Fidelity = 0.26488468
# T = 10    Fidelity = 0.84406665
# T = 20    Fidelity = 0.92518932
# T = 30    Fidelity = 0.96897020
# T = 40    Fidelity = 0.99383490
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396254
# T = 2     Fidelity = 0.02467519
# T = 5     Fidelity = 0.29523373
# T = 10    Fidelity = 0.85798974
# T = 20    Fidelity = 0.92053191
# T = 30    Fidelity = 0.98399930
# T = 40    Fidelity = 0.99992223
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.62846515
# T = 2     Fidelity = 0.65713018
# T = 5     Fidelity = 0.71292443
# T = 10    Fidelity = 0.76644212
# T = 20    Fidelity = 0.83209287
# T = 30    Fidelity = 0.87177110
# T = 40    Fidelity = 0.90010084
# T = 50    Fidelity = 0.91989738
# T = 75    Fidelity = 0.95059913
# T = 100   Fidelity = 0.96477538
# T = 125   Fidelity = 0.97381131
# T = 150   Fidelity = 0.98152875
# T = 175   Fidelity = 0.97974339
# T = 200   Fidelity = 0.98397179
# T = 225   Fidelity = 0.97865609
# T = 250   Fidelity = 0.98490595
# T = 275   Fidelity = 0.95114513
# T = 300   Fidelity = 0.94011291
# T = 400   Fidelity = 0.97924155
# T = 500   Fidelity = 0.97581427
# T = 600   Fidelity = 0.92998214
# T = 700   Fidelity = 0.81747674
# T = 800   Fidelity = 0.95168582
# T = 900   Fidelity = 0.98244369
# T = 1000  Fidelity = 0.95644119
# T = 1010  Fidelity = 0.95764862
# T = 1020  Fidelity = 0.95814618
# T = 1030  Fidelity = 0.95727634
# T = 1040  Fidelity = 0.96130924
# T = 1050  Fidelity = 0.95749443
# T = 1060  Fidelity = 0.97376532
# T = 1070  Fidelity = 0.98726722
# T = 1080  Fidelity = 0.98963011
# T = 1090  Fidelity = 0.98097818
# T = 1100  Fidelity = 0.97308602
# T = 1200  Fidelity = 0.98520379
# T = 1300  Fidelity = 0.96697552
# T = 1400  Fidelity = 0.84319659
# T = 1500  Fidelity = 0.91521215
# T = 2000  Fidelity = 0.95455311
# T = 2100  Fidelity = 0.87112318
# T = 2110  Fidelity = 0.84826877
# T = 2120  Fidelity = 0.84952457
# T = 2130  Fidelity = 0.85117076
# T = 2140  Fidelity = 0.85393589
# T = 2150  Fidelity = 0.84961870
# T = 2160  Fidelity = 0.86405146
# T = 2170  Fidelity = 0.87706641
# T = 2180  Fidelity = 0.88495859
# T = 2190  Fidelity = 0.89564093
# T = 2200  Fidelity = 0.91177756
# T = 2300  Fidelity = 0.97244177
# T = 2400  Fidelity = 0.97223320
# T = 2500  Fidelity = 0.94341529
# T = 2600  Fidelity = 0.97687765
# T = 2700  Fidelity = 0.97307855
# T = 2800  Fidelity = 0.88776748
# T = 2900  Fidelity = 0.90030361
# T = 3000  Fidelity = 0.94645577
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.33549253e-01
# P0     = 0.94645577
# P1     = 0.02829557
# P0+P1  = 0.97475134
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.70558114
# T = 2     Fidelity = 0.77570143
# T = 5     Fidelity = 0.82394020
# T = 10    Fidelity = 0.85321150
# T = 20    Fidelity = 0.88087657
# T = 30    Fidelity = 0.89808351
# T = 40    Fidelity = 0.91108519
# T = 50    Fidelity = 0.92058073
# T = 75    Fidelity = 0.93738368
# T = 100   Fidelity = 0.94805861
# T = 125   Fidelity = 0.95351545
# T = 150   Fidelity = 0.95809499
# T = 175   Fidelity = 0.96490931
# T = 200   Fidelity = 0.97171541
# T = 225   Fidelity = 0.96459290
# T = 250   Fidelity = 0.96628050
# T = 275   Fidelity = 0.97177014
# T = 300   Fidelity = 0.96365219
# T = 400   Fidelity = 0.96832179
# T = 500   Fidelity = 0.96168462
# T = 600   Fidelity = 0.96310572
# T = 700   Fidelity = 0.96559404
# T = 800   Fidelity = 0.93687939
# T = 900   Fidelity = 0.92393705
# T = 1000  Fidelity = 0.93687261
# T = 1010  Fidelity = 0.93643451
# T = 1020  Fidelity = 0.94015092
# T = 1030  Fidelity = 0.94778997
# T = 1040  Fidelity = 0.94030246
# T = 1050  Fidelity = 0.95293148
# T = 1060  Fidelity = 0.95754485
# T = 1070  Fidelity = 0.93233108
# T = 1080  Fidelity = 0.94838491
# T = 1090  Fidelity = 0.92746464
# T = 1100  Fidelity = 0.93001519
# T = 1200  Fidelity = 0.95651267
# T = 1300  Fidelity = 0.96047841
# T = 1400  Fidelity = 0.97712178
# T = 1500  Fidelity = 0.98578871
# T = 2000  Fidelity = 0.94401205
# T = 2100  Fidelity = 0.95270326
# T = 2110  Fidelity = 0.95256857
# T = 2120  Fidelity = 0.95605350
# T = 2130  Fidelity = 0.94586068
# T = 2140  Fidelity = 0.96163844
# T = 2150  Fidelity = 0.95713975
# T = 2160  Fidelity = 0.95512656
# T = 2170  Fidelity = 0.96075876
# T = 2180  Fidelity = 0.92997733
# T = 2190  Fidelity = 0.94427651
# T = 2200  Fidelity = 0.94206417
# T = 2300  Fidelity = 0.94743810
# T = 2400  Fidelity = 0.97599919
# T = 2500  Fidelity = 0.96901998
# T = 2600  Fidelity = 0.96189682
# T = 2700  Fidelity = 0.94696667
# T = 2800  Fidelity = 0.93753705
# T = 2900  Fidelity = 0.91089066
# T = 3000  Fidelity = 0.96653249
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.30329715e-01
# P0     = 0.96653249
# P1     = 0.01840684
# P0+P1  = 0.98493933
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.05156695
# T = 2     Fidelity = 0.19652215
# T = 5     Fidelity = 0.84863518
# T = 10    Fidelity = 0.97000012
# T = 20    Fidelity = 0.99323073
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.11297474
# T = 2     Fidelity = 0.33318531
# T = 5     Fidelity = 0.84566578
# T = 10    Fidelity = 0.91467842
# T = 20    Fidelity = 0.99915683
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.16845962
# T = 2     Fidelity = 0.40054016
# T = 5     Fidelity = 0.89913551
# T = 10    Fidelity = 0.94665693
# T = 20    Fidelity = 0.99428780
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.20995990
# T = 2     Fidelity = 0.42929135
# T = 5     Fidelity = 0.87823879
# T = 10    Fidelity = 0.92182419
# T = 20    Fidelity = 0.97175066
# T = 30    Fidelity = 0.98002256
# T = 40    Fidelity = 0.97978531
# T = 50    Fidelity = 0.98421696
# T = 75    Fidelity = 0.98661649
# T = 100   Fidelity = 0.98932718
# T = 125   Fidelity = 0.99185575
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.21757519
# T = 2     Fidelity = 0.40459596
# T = 5     Fidelity = 0.82684120
# T = 10    Fidelity = 0.86603976
# T = 20    Fidelity = 0.90867480
# T = 30    Fidelity = 0.93508490
# T = 40    Fidelity = 0.94708990
# T = 50    Fidelity = 0.94894651
# T = 75    Fidelity = 0.96222800
# T = 100   Fidelity = 0.96557286
# T = 125   Fidelity = 0.97409260
# T = 150   Fidelity = 0.97558085
# T = 175   Fidelity = 0.97945768
# T = 200   Fidelity = 0.98201254
# T = 225   Fidelity = 0.98240110
# T = 250   Fidelity = 0.98609897
# T = 275   Fidelity = 0.98507883
# T = 300   Fidelity = 0.98798399
# T = 400   Fidelity = 0.95394027
# T = 500   Fidelity = 0.96691060
# T = 600   Fidelity = 0.98188997
# T = 700   Fidelity = 0.96987048
# T = 800   Fidelity = 0.96761599
# T = 900   Fidelity = 0.98304331
# T = 1000  Fidelity = 0.97138210
# T = 1010  Fidelity = 0.98747499
# T = 1020  Fidelity = 0.99151972
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.20107890
# T = 2     Fidelity = 0.34983777
# T = 5     Fidelity = 0.74508942
# T = 10    Fidelity = 0.79277749
# T = 20    Fidelity = 0.83551651
# T = 30    Fidelity = 0.86303078
# T = 40    Fidelity = 0.88661505
# T = 50    Fidelity = 0.90605574
# T = 75    Fidelity = 0.93034437
# T = 100   Fidelity = 0.94156162
# T = 125   Fidelity = 0.95485203
# T = 150   Fidelity = 0.96240248
# T = 175   Fidelity = 0.96692460
# T = 200   Fidelity = 0.97272258
# T = 225   Fidelity = 0.97580589
# T = 250   Fidelity = 0.97835011
# T = 275   Fidelity = 0.98202602
# T = 300   Fidelity = 0.98233638
# T = 400   Fidelity = 0.95680742
# T = 500   Fidelity = 0.97136960
# T = 600   Fidelity = 0.98349789
# T = 700   Fidelity = 0.96713722
# T = 800   Fidelity = 0.97370783
# T = 900   Fidelity = 0.99377449
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.18043634
# T = 2     Fidelity = 0.29866741
# T = 5     Fidelity = 0.67123218
# T = 10    Fidelity = 0.73306326
# T = 20    Fidelity = 0.79398360
# T = 30    Fidelity = 0.83001507
# T = 40    Fidelity = 0.85650060
# T = 50    Fidelity = 0.87768630
# T = 75    Fidelity = 0.91506689
# T = 100   Fidelity = 0.93892799
# T = 125   Fidelity = 0.95482242
# T = 150   Fidelity = 0.96550353
# T = 175   Fidelity = 0.97260312
# T = 200   Fidelity = 0.97745208
# T = 225   Fidelity = 0.98058567
# T = 250   Fidelity = 0.98392909
# T = 275   Fidelity = 0.98648530
# T = 300   Fidelity = 0.98820350
# T = 400   Fidelity = 0.97343126
# T = 500   Fidelity = 0.97297650
# T = 600   Fidelity = 0.98564241
# T = 700   Fidelity = 0.98633160
# T = 800   Fidelity = 0.98673100
# T = 900   Fidelity = 0.98952731
# T = 1000  Fidelity = 0.98257702
# T = 1010  Fidelity = 0.97167017
# T = 1020  Fidelity = 0.99460468
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.48783584e-01
# T = 1     Fidelity = 0.16429267
# T = 2     Fidelity = 0.26155134
# T = 5     Fidelity = 0.62026948
# T = 10    Fidelity = 0.69471956
# T = 20    Fidelity = 0.77254414
# T = 30    Fidelity = 0.82164723
# T = 40    Fidelity = 0.85814847
# T = 50    Fidelity = 0.88620958
# T = 75    Fidelity = 0.93169803
# T = 100   Fidelity = 0.95678932
# T = 125   Fidelity = 0.97130446
# T = 150   Fidelity = 0.98003768
# T = 175   Fidelity = 0.98548777
# T = 200   Fidelity = 0.98852810
# T = 225   Fidelity = 0.99102219
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99358655
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.89797708
# T = 2     Fidelity = 0.95328675
# T = 5     Fidelity = 0.98569840
# T = 10    Fidelity = 0.99506035
#
# Minimum T for Fidelity >= 0.99 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.31621635e+00
# T = 1     Fidelity = 0.10157086
# T = 2     Fidelity = 0.29859669
# T = 5     Fidelity = 0.80777760
# T = 10    Fidelity = 0.99318686
#
# Minimum T for Fidelity >= 0.99 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.40805723e+00
# T = 1     Fidelity = 0.13235908
# T = 2     Fidelity = 0.38003362
# T = 5     Fidelity = 0.80818818
# T = 10    Fidelity = 0.92209718
# T = 20    Fidelity = 0.99610070
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.23636811
# T = 2     Fidelity = 0.53322798
# T = 5     Fidelity = 0.91873651
# T = 10    Fidelity = 0.98338392
# T = 20    Fidelity = 0.99329091
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.30545977
# T = 2     Fidelity = 0.59285679
# T = 5     Fidelity = 0.91557520
# T = 10    Fidelity = 0.98256282
# T = 20    Fidelity = 0.99355990
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.36096058
# T = 2     Fidelity = 0.63573938
# T = 5     Fidelity = 0.93271775
# T = 10    Fidelity = 0.98427749
# T = 20    Fidelity = 0.99479889
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.40230074
# T = 2     Fidelity = 0.66005268
# T = 5     Fidelity = 0.93968562
# T = 10    Fidelity = 0.98305598
# T = 20    Fidelity = 0.99627887
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.43974341
# T = 2     Fidelity = 0.68181164
# T = 5     Fidelity = 0.94421547
# T = 10    Fidelity = 0.98206354
# T = 20    Fidelity = 0.99729435
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.47121139
# T = 2     Fidelity = 0.69843270
# T = 5     Fidelity = 0.94931061
# T = 10    Fidelity = 0.98139907
# T = 20    Fidelity = 0.99819498
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     None      0.9788008982      3.07240439e-04    0.702478    0.0         0.702478
# Symmetric      0.311     175       0.9975516266      1.17908350e-06    None        None        None
# Symmetric      0.522     125       0.9959616576      2.94880929e-07    None        None        None
# Symmetric      0.733     100       0.9998443930      1.58119073e-07    None        None        None
# Symmetric      0.944     75        0.9978303898      6.89654645e-08    None        None        None
# Symmetric      1.156     50        0.9960851488      1.17592608e-07    None        None        None
# Symmetric      1.367     50        0.9913326882      2.47961107e-07    None        None        None
# Symmetric      1.578     50        0.9947568722      3.56990608e-07    None        None        None
# Symmetric      1.789     40        0.9938348971      2.45005900e-06    None        None        None
# Symmetric      2.000     40        0.9999222293      1.44257094e-05    None        None        None
# Weak SSB optimised0.100     None      0.9896301075      8.67181393e-01    0.946456    0.028296    0.974751
# Weak SSB optimised0.311     None      0.9857887091      5.19764834e-01    0.966532    0.018407    0.984939
# Weak SSB optimised0.522     20        0.9932307297      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     20        0.9991568263      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     20        0.9942877964      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     125       0.9918557536      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     1020      0.9915197203      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     900       0.9937744921      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     1020      0.9946046819      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     225       0.9910221909      2.48783584e-01    None        None        None
# Strong SSB     0.100     1         0.9935865451      3.59472102e+00    None        None        None
# Strong SSB     0.311     10        0.9950603507      1.58498916e+00    None        None        None
# Strong SSB     0.522     10        0.9931868636      1.31621635e+00    None        None        None
# Strong SSB     0.733     20        0.9961006956      1.40805723e+00    None        None        None
# Strong SSB     0.944     20        0.9932909143      1.38481786e+00    None        None        None
# Strong SSB     1.156     20        0.9935598999      1.34302163e+00    None        None        None
# Strong SSB     1.367     20        0.9947988878      1.29217279e+00    None        None        None
# Strong SSB     1.578     20        0.9962788743      1.23335459e+00    None        None        None
# Strong SSB     1.789     20        0.9972943468      1.17426012e+00    None        None        None
# Strong SSB     2.000     20        0.9981949824      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.1556
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7333

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ', color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
