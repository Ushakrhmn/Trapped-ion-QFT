# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # -------------------------------------------------------- kjacvbnm,./qwertyuiopp//÷//

 
    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756816
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Genuine Qiskit VQE on shifted Pauli Hamiltonian
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SPSA

from qiskit.primitives import StatevectorEstimator


# ============================================================
# Variational circuit
# ============================================================

def variational_circuit(nq, layers):

    qc = QuantumCircuit(nq)

    nparams = 2 * nq * layers

    params = ParameterVector("θ", nparams)

    p = 0

    for l in range(layers):

        # ----------------------------------------------------
        # Single-qubit rotations
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(params[p], q)
            qc.rz(params[p + 1], q)

            p += 2

        # ----------------------------------------------------
        # Entanglement layer
        # ----------------------------------------------------

        if l != layers - 1:

            # even bonds
            if l % 2 == 0:

                for q in range(0, nq - 1, 2):
                    qc.cz(q, q + 1)

            # odd bonds
            else:

                for q in range(1, nq - 1, 2):
                    qc.cz(q, q + 1)

    return qc


# ============================================================
# Ansatz
# ============================================================

nqubits = 8

# start modestly
layers = 8

ansatz = variational_circuit(
    nqubits,
    layers
)

# ============================================================
# Estimator
# ============================================================

estimator = StatevectorEstimator()

# ============================================================
# Optimizer
# ============================================================

optimizer = SPSA(
    maxiter=5000
)

# ============================================================
# VQE
# ============================================================
initial_point = 0.01 * np.random.randn(
    ansatz.num_parameters
)
vqe = VQE(
    estimator=estimator,
    ansatz=ansatz,
    optimizer=optimizer,
    initial_point=initial_point
)

# ============================================================
# Run VQE
# ============================================================

print("\nRunning VQE...\n")

result = vqe.compute_minimum_eigenvalue(
    H_pauli_shifted
)

# ============================================================
# Shifted energy
# ============================================================

E_shifted = result.eigenvalue.real

# ============================================================
# Physical energy
# ============================================================

E_vqe = E_shifted + identity_shift

# ============================================================
# Optimal parameters
# ============================================================

optimal_params = result.optimal_parameters

# ============================================================
# Optimized circuit
# ============================================================

optimal_circuit = ansatz.assign_parameters(
    optimal_params
)

# ============================================================
# VQE state
# ============================================================

psi_vqe = Statevector.from_instruction(
    optimal_circuit
).data

# ============================================================
# Fidelity
# ============================================================

Fidelity = np.abs(
    np.vdot(psi_loc, psi_vqe)
)**2

# ============================================================
# Results
# ============================================================

print("\n================================")
print("Exact energy :", E0_loc)
print("VQE energy   :", E_vqe)
print("Energy error :", abs(E_vqe - E0_loc))
print("Fidelity     :", Fidelity)
print("Layers        :", layers)
print("Pauli terms   :", len(H_pauli_shifted))
print("================================")
# Out:
# Running VQE...
#
#
# ================================
# Exact energy : 1.0554722545756816
# VQE energy   : 1.0701496422678645
# Energy error : 0.014677387692182853
# Fidelity     : 0.9953147234077293
# Layers        : 8
# Pauli terms   : 111
# ================================

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Robust VQE with eigenstate tracking
# ============================================================
import numpy as np

from scipy.sparse import identity, kron

from qiskit.quantum_info import (
    Statevector,
    Operator,
    SparsePauliOp
)

from qiskit.primitives import StatevectorEstimator

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B
def run_robust_vqe(

    H_sparse,

    nq,

    layers,

    n_restarts,

    energy_tol,

    previous_state=None,

    previous_optimal_point=None
):

    nqubits = nq

    # --------------------------------------------------------
    # Exact ground state
    # --------------------------------------------------------

    E_exact, psi_exact = exact_ground_state(H_sparse)

    # --------------------------------------------------------
    # Convert Hamiltonian
    # --------------------------------------------------------

    H_dense = H_sparse.toarray()

    H_op = Operator(H_dense)

    H_pauli = SparsePauliOp.from_operator(H_op)

    coeffs = H_pauli.coeffs

    paulis = H_pauli.paulis

    new_coeffs = []

    new_paulis = []

    identity_shift = 0.0

    for p, c in zip(paulis, coeffs):

        if str(p) == 'I' * nqubits:

            identity_shift += np.real(c)

        else:

            new_paulis.append(p)

            new_coeffs.append(c)

    H_pauli_shifted = SparsePauliOp(

        new_paulis,

        coeffs=new_coeffs
    )

    # --------------------------------------------------------
    # Ansatz
    # --------------------------------------------------------

    ansatz = variational_circuit(

        nq=nqubits,

        layers=layers
    )

    estimator = StatevectorEstimator()

    optimizer = L_BFGS_B(maxiter=1000)

    # ========================================================
    # Multiple restarts
    # ========================================================

    trial_results = []

    for trial in range(n_restarts):

        # ----------------------------------------------------
        # Initial point
        # ----------------------------------------------------

        if trial == 0 and previous_optimal_point is not None:

            initial_point = previous_optimal_point

        else:

            initial_point = 0.01 * np.random.randn(

                ansatz.num_parameters
            )

        # ----------------------------------------------------
        # VQE
        # ----------------------------------------------------

        vqe = VQE(

            estimator=estimator,

            ansatz=ansatz,

            optimizer=optimizer,

            initial_point=initial_point
        )

        result = vqe.compute_minimum_eigenvalue(

            H_pauli_shifted
        )

        E_trial = (

            np.real(result.eigenvalue)

            + identity_shift
        )

        # ----------------------------------------------------
        # Trial state
        # ----------------------------------------------------

        qc_trial = ansatz.assign_parameters(

            result.optimal_parameters
        )

        psi_trial = Statevector.from_instruction(

            qc_trial

        ).data

        # ----------------------------------------------------
        # Overlap tracking
        # ----------------------------------------------------

        if previous_state is None:

            overlap = 1.0

        else:

            overlap = abs(np.vdot(

                previous_state,

                psi_trial

            ))**2

        trial_results.append({

            'energy': E_trial,

            'overlap': overlap,

            'state': psi_trial,

            'result': result
        })

    # ========================================================
    # Hybrid selection
    # ========================================================

    energies = np.array([

        t['energy']

        for t in trial_results
    ])

    E_min = np.min(energies)

    filtered_candidates = [

        t for t in trial_results

        if (t['energy'] - E_min) < energy_tol
    ]

    best_candidate = max(

        filtered_candidates,

        key=lambda x: x['overlap']
    )

    # ========================================================
    # Outputs
    # ========================================================

    # ========================================================
    # Final outputs
    # ========================================================

    psi_vqe = best_candidate['state']

    E_vqe = best_candidate['energy']

    optimal_point = (

        best_candidate['result'].optimal_point
    )

    tracking_overlap = best_candidate['overlap']

    F = fidelity(

    psi_exact,

    psi_vqe
    )

    return {

        "E_exact": E_exact,

        "E_vqe": E_vqe,

        "psi_vqe": psi_vqe,

        "fidelity": F,

        "tracking_overlap": tracking_overlap,

        "optimal_point": optimal_point,

        "state_for_tracking": psi_vqe
    }

# %%
nq_site = 4

nqubits = 2 * nq_site

mu = 1.0

layers = 8

# ============================================================
# VQE settings
# ============================================================

n_restarts = 5

energy_tol = 1e-3

# ============================================================
# Parameter sets
# ============================================================

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
    {
       "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-4
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ============================================================
# Lambda scan
# ============================================================

lambda_list = np.linspace(0.1, 2.0, 10)

# ============================================================
# Storage
# ============================================================

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]

    mI2 = params["mI2"]

    f = params["f"]

    print("\n")
    print("#"*80)

    print(f"CASE: {label}")

    print(f"mI² = {mI2},  f = {f}")

    print("#"*80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None

    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "="*60)

        print(f"Running λ = {lam:.3f}")

        print("="*60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(

            nq=nq_site,

            mu=mu,

            mI2=mI2,

            lam=lam,

            f=f
        )

        # ====================================================
        # Run robust VQE
        # ====================================================

        vqe_data = run_robust_vqe(

            H_sparse=Hloc_sparse,

            nq=nqubits,

            layers=layers,

            n_restarts=n_restarts,

            energy_tol=energy_tol,

            previous_state=previous_state,

            previous_optimal_point=previous_optimal_point
        )

        # ====================================================
        # Extract outputs
        # ====================================================

        E_exact = vqe_data["E_exact"]

        E_vqe = vqe_data["E_vqe"]

        psi_vqe = vqe_data["psi_vqe"]

        F = vqe_data["fidelity"]

        tracking_overlap = vqe_data["tracking_overlap"]

        # ----------------------------------------------------
        # Update tracking
        # ----------------------------------------------------

        previous_state = vqe_data["state_for_tracking"]

        previous_optimal_point = (

            vqe_data["optimal_point"]
        )

        # ----------------------------------------------------
        # Store
        # ----------------------------------------------------

        data = {

            'case': label,

            'lambda': lam,

            'mI2': mI2,

            'f': f,

            'E_exact': E_exact,

            'E_vqe': E_vqe,

            'error': abs(E_exact - E_vqe),

            'fidelity': F,

            'tracking_overlap': tracking_overlap,

            'psi_vqe': psi_vqe
        }

        case_results.append(data)

        all_results.append(data)

        # ----------------------------------------------------
        # Print
        # ----------------------------------------------------

        print("\nFINAL SELECTED STATE")

        print(f"Exact energy     : {E_exact:.12f}")

        print(f"VQE energy       : {E_vqe:.12f}")

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(f"Fidelity         : {F:.12f}")

        print(
            f"Tracking overlap : "
            f"{tracking_overlap:.12f}"
        )

    # ========================================================
    # Case summary
    # ========================================================

    print("\n")

    print("="*110)

    print(f"SUMMARY : {label}")

    print("="*110)

    print(

        f"{'lambda':<12} "
        f"{'Exact E':<18} "
        f"{'VQE E':<18} "
        f"{'Error':<15} "
        f"{'Fidelity':<15} "
        f"{'TrackOverlap':<15}"
    )

    print("="*110)

    for r in case_results:

        print(

            f"{r['lambda']:<12.4f} "
            f"{r['E_exact']:<18.10f} "
            f"{r['E_vqe']:<18.10f} "
            f"{r['error']:<15.4e} "
            f"{r['fidelity']:<15.10f} "
            f"{r['tracking_overlap']:<15.10f}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
# /home/semin/jupyter/qiskit_env/lib/python3.12/site-packages/qiskit_algorithms/optimizers/scipy_optimizer.py:162: OptimizeWarning: Unknown solver options: iprint
#   raw_result = minimize(
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161818485
# Energy error     : 9.032547e-08
# Fidelity         : 0.999999953820
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641486589
# Energy error     : 5.924196e-08
# Fidelity         : 0.999999979848
# Tracking overlap : 0.999849858175
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030499382086
# Energy error     : 7.229189e-08
# Fidelity         : 0.999999981536
# Tracking overlap : 0.999876001221
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041824418351
# Energy error     : 9.608984e-08
# Fidelity         : 0.999999982981
# Tracking overlap : 0.999895846682
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052684726451
# Energy error     : 1.826894e-07
# Fidelity         : 0.999999975448
# Tracking overlap : 0.999910804782
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063134040735
# Energy error     : 2.519648e-07
# Fidelity         : 0.999999973063
# Tracking overlap : 0.999922549850
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073215991710
# Energy error     : 3.379389e-07
# Fidelity         : 0.999999969251
# Tracking overlap : 0.999931868909
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082966663945
# Energy error     : 5.121303e-07
# Fidelity         : 0.999999956003
# Tracking overlap : 0.999939531807
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092416023891
# Energy error     : 5.157832e-07
# Fidelity         : 0.999999957023
# Tracking overlap : 0.999945845726
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101589981069
# Energy error     : 5.523259e-07
# Fidelity         : 0.999999956098
# Tracking overlap : 0.999951196596
#
#
# ==============================================================================================================
# SUMMARY : Symmetric
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       1.0061617282       1.0061618185       9.0325e-08      0.9999999538    1.0000000000
# 0.3111       1.0186414273       1.0186414866       5.9242e-08      0.9999999798    0.9998498582
# 0.5222       1.0304993098       1.0304993821       7.2292e-08      0.9999999815    0.9998760012
# 0.7333       1.0418243223       1.0418244184       9.6090e-08      0.9999999830    0.9998958467
# 0.9444       1.0526845438       1.0526847265       1.8269e-07      0.9999999754    0.9999108048
# 1.1556       1.0631337888       1.0631340407       2.5196e-07      0.9999999731    0.9999225499
# 1.3667       1.0732156538       1.0732159917       3.3794e-07      0.9999999693    0.9999318689
# 1.5778       1.0829661518       1.0829666639       5.1213e-07      0.9999999560    0.9999395318
# 1.7889       1.0924155081       1.0924160239       5.1578e-07      0.9999999570    0.9999458457
# 2.0000       1.1015894287       1.1015899811       5.5233e-07      0.9999999561    0.9999511966
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.064204008454
# Energy error     : 4.893434e-04
# Fidelity         : 0.999917853597
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.076430710357
# Energy error     : 4.019202e-03
# Fidelity         : 0.998532828698
# Tracking overlap : 0.814523181293
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.701050581617
# Energy error     : 1.443910e-04
# Fidelity         : 0.999973852652
# Tracking overlap : 0.066345145183
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.011519670233
# Energy error     : 1.168139e-05
# Fidelity         : 0.999997630146
# Tracking overlap : 0.654739353051
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.083477398071
# Energy error     : 8.832538e-05
# Fidelity         : 0.999984214675
# Tracking overlap : 0.831737627398
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503959519732
# Energy error     : 5.283530e-04
# Fidelity         : 0.999881443576
# Tracking overlap : 0.895601740431
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118963960649
# Energy error     : 1.357698e-04
# Fidelity         : 0.999979436227
# Tracking overlap : 0.917587762375
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.853297720206
# Energy error     : 3.433380e-05
# Fidelity         : 0.999995454352
# Tracking overlap : 0.937150816574
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663533849723
# Energy error     : 2.629182e-05
# Fidelity         : 0.999995968170
# Tracking overlap : 0.958977442103
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.522110332893
# Energy error     : 2.943141e-05
# Fidelity         : 0.999995705085
# Tracking overlap : 0.975943266417
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB optimised
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -17.0646933519     -17.0642040085     4.8934e-04      0.9999178536    1.0000000000
# 0.3111       -9.0804499123      -9.0764307104      4.0192e-03      0.9985328287    0.8145231813
# 0.5222       -4.7011949726      -4.7010505816      1.4439e-04      0.9999738527    0.0663451452
# 0.7333       -3.0115313516      -3.0115196702      1.1681e-05      0.9999976301    0.6547393531
# 0.9444       -2.0835657235      -2.0834773981      8.8325e-05      0.9999842147    0.8317376274
# 1.1556       -1.5044878727      -1.5039595197      5.2835e-04      0.9998814436    0.8956017404
# 1.3667       -1.1190997304      -1.1189639606      1.3577e-04      0.9999794362    0.9175877624
# 1.5778       -0.8533320540      -0.8532977202      3.4334e-05      0.9999954544    0.9371508166
# 1.7889       -0.6635601415      -0.6635338497      2.6292e-05      0.9999959682    0.9589774421
# 2.0000       -0.5221397643      -0.5221103329      2.9431e-05      0.9999957051    0.9759432664
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 0.0001
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902685020
# VQE energy       : -16.943753348216
# Energy error     : 1.493368e-04
# Fidelity         : 0.999972987292
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -8.892069658534
# VQE energy       : -8.891879822085
# Energy error     : 1.898364e-04
# Fidelity         : 0.999944240116
# Tracking overlap : 0.875780900768
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.379329565434
# VQE energy       : -4.379113756931
# Energy error     : 2.158085e-04
# Fidelity         : 0.808954931678
# Tracking overlap : 0.048923431027
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.749826501443
# VQE energy       : -2.749797432785
# Energy error     : 2.906866e-05
# Fidelity         : 0.994043755083
# Tracking overlap : 0.000000018363
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.874705890824
# VQE energy       : -1.874703566280
# Energy error     : 2.324544e-06
# Fidelity         : 0.999928513697
# Tracking overlap : 0.821465526745
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.348823187245
# VQE energy       : -1.348806088047
# Energy error     : 1.709920e-05
# Fidelity         : 0.999983574495
# Tracking overlap : 0.895207053156
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.010440164101
# VQE energy       : -1.010439484648
# Energy error     : 6.794533e-07
# Fidelity         : 0.999999740546
# Tracking overlap : 0.936699388422
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.779140149474
# VQE energy       : -0.779140041656
# Energy error     : 1.078173e-07
# Fidelity         : 0.999999945027
# Tracking overlap : 0.962790283697
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723602270
# VQE energy       : -0.611372354039
# Energy error     : 3.512482e-04
# Fidelity         : 0.999933722246
# Tracking overlap : 0.978046176509
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295546782
# VQE energy       : -0.484293049269
# Energy error     : 2.497513e-06
# Fidelity         : 0.999999557534
# Tracking overlap : 0.986109539954
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -16.9439026850     -16.9437533482     1.4934e-04      0.9999729873    1.0000000000
# 0.3111       -8.8920696585      -8.8918798221      1.8984e-04      0.9999442401    0.8757809008
# 0.5222       -4.3793295654      -4.3791137569      2.1581e-04      0.8089549317    0.0489234310
# 0.7333       -2.7498265014      -2.7497974328      2.9069e-05      0.9940437551    0.0000000184
# 0.9444       -1.8747058908      -1.8747035663      2.3245e-06      0.9999285137    0.8214655267
# 1.1556       -1.3488231872      -1.3488060880      1.7099e-05      0.9999835745    0.8952070532
# 1.3667       -1.0104401641      -1.0104394846      6.7945e-07      0.9999997405    0.9366993884
# 1.5778       -0.7791401495      -0.7791400417      1.0782e-07      0.9999999450    0.9627902837
# 1.7889       -0.6117236023      -0.6113723540      3.5125e-04      0.9999337222    0.9780461765
# 2.0000       -0.4842955468      -0.4842930493      2.4975e-06      0.9999995575    0.9861095400
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.776956196638
# Energy error     : 3.722486e-04
# Fidelity         : 0.999965124278
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.835750605566
# Energy error     : 6.905373e-04
# Fidelity         : 0.999894257308
# Tracking overlap : 0.849734339630
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.730067071986
# Energy error     : 6.492928e-04
# Fidelity         : 0.999896183663
# Tracking overlap : 0.166020990733
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.537994149819
# Energy error     : 1.546809e-04
# Fidelity         : 0.999985191646
# Tracking overlap : 0.635258967502
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.276005046445
# Energy error     : 8.746484e-06
# Fidelity         : 0.999999008386
# Tracking overlap : 0.822313292074
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.448001007906
# Energy error     : 6.793775e-04
# Fidelity         : 0.999907275314
# Tracking overlap : 0.905572167688
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.860691535871
# Energy error     : 1.407293e-04
# Fidelity         : 0.999987246284
# Tracking overlap : 0.941272290589
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529279
# VQE energy       : -2.420068732789
# Energy error     : 2.179649e-05
# Fidelity         : 0.999998405879
# Tracking overlap : 0.962125948164
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.076297261715
# Energy error     : 1.530590e-05
# Fidelity         : 0.999998894443
# Tracking overlap : 0.973955532717
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.800059856054
# Energy error     : 1.341016e-05
# Fidelity         : 0.999999063714
# Tracking overlap : 0.981151350837
#
#
# ==============================================================================================================
# SUMMARY : Strong SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -20.7773284453     -20.7769561966     3.7225e-04      0.9999651243    1.0000000000
# 0.3111       -12.8364411428     -12.8357506056     6.9054e-04      0.9998942573    0.8497343396
# 0.5222       -7.7307163648      -7.7300670720      6.4929e-04      0.9998961837    0.1660209907
# 0.7333       -5.5381488307      -5.5379941498      1.5468e-04      0.9999851916    0.6352589675
# 0.9444       -4.2760137929      -4.2760050464      8.7465e-06      0.9999990084    0.8223132921
# 1.1556       -3.4486803854      -3.4480010079      6.7938e-04      0.9999072753    0.9055721677
# 1.3667       -2.8608322652      -2.8606915359      1.4073e-04      0.9999872463    0.9412722906
# 1.5778       -2.4200905293      -2.4200687328      2.1796e-05      0.9999984059    0.9621259482
# 1.7889       -2.0763125676      -2.0762972617      1.5306e-05      0.9999988944    0.9739555327
# 2.0000       -1.8000732662      -1.8000598561      1.3410e-05      0.9999990637    0.9811513508

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------


plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HEA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HEA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119334
# T = 2     Fidelity = 0.99733047
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98267512
# T = 2     Fidelity = 0.99771958
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394388
# T = 2     Fidelity = 0.99802498
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98504765
# T = 2     Fidelity = 0.99827042
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98600249
# T = 2     Fidelity = 0.99846479
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98686361
# T = 2     Fidelity = 0.99862931
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762720
# T = 2     Fidelity = 0.99876383
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98831057
# T = 2     Fidelity = 0.99887522
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893053
# T = 2     Fidelity = 0.99896922
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98950204
# T = 2     Fidelity = 0.99905096
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00038050
# T = 10    Fidelity = 0.00053407
# T = 20    Fidelity = 0.01183982
# T = 30    Fidelity = 0.08149596
# T = 40    Fidelity = 0.18877231
# T = 50    Fidelity = 0.42889840
# T = 75    Fidelity = 0.56714866
# T = 100   Fidelity = 0.72849730
# T = 125   Fidelity = 0.80794949
# T = 150   Fidelity = 0.83702068
# T = 175   Fidelity = 0.90629772
# T = 200   Fidelity = 0.91944528
# T = 225   Fidelity = 0.96698871
# T = 250   Fidelity = 0.89101385
# T = 275   Fidelity = 0.96878920
# T = 300   Fidelity = 0.85596075
# T = 400   Fidelity = 0.98044124
# T = 500   Fidelity = 0.96067701
# T = 600   Fidelity = 0.95866638
# T = 700   Fidelity = 0.62952091
# T = 800   Fidelity = 0.83504648
# T = 900   Fidelity = 0.82273365
# T = 1000  Fidelity = 0.66457855
# T = 1010  Fidelity = 0.57940447
# T = 1020  Fidelity = 0.61895393
# T = 1030  Fidelity = 0.69823961
# T = 1040  Fidelity = 0.72170225
# T = 1050  Fidelity = 0.78710545
# T = 1060  Fidelity = 0.91731409
# T = 1070  Fidelity = 0.77651473
# T = 1080  Fidelity = 0.78792690
# T = 1090  Fidelity = 0.71243104
# T = 1100  Fidelity = 0.38077864
# T = 1200  Fidelity = 0.59308454
# T = 1300  Fidelity = 0.48327985
# T = 1400  Fidelity = 0.71920683
# T = 1500  Fidelity = 0.46490391
# T = 2000  Fidelity = 0.93537498
# T = 2100  Fidelity = 0.70797703
# T = 2110  Fidelity = 0.56774097
# T = 2120  Fidelity = 0.47345679
# T = 2130  Fidelity = 0.39790504
# T = 2140  Fidelity = 0.49610508
# T = 2150  Fidelity = 0.41754745
# T = 2160  Fidelity = 0.62991807
# T = 2170  Fidelity = 0.52188020
# T = 2180  Fidelity = 0.49509821
# T = 2190  Fidelity = 0.50074641
# T = 2200  Fidelity = 0.35859140
# T = 2300  Fidelity = 0.77467570
# T = 2400  Fidelity = 0.21837853
# T = 2500  Fidelity = 0.75765774
# T = 2600  Fidelity = 0.43568976
# T = 2700  Fidelity = 0.55729422
# T = 2800  Fidelity = 0.85256152
# T = 2900  Fidelity = 0.64781689
# T = 3000  Fidelity = 0.82626444
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00976726e+00
# P0     = 0.82626444
# P1     = 0.05933923
# P0+P1  = 0.88560367
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000003
# T = 5     Fidelity = 0.00047532
# T = 10    Fidelity = 0.06741848
# T = 20    Fidelity = 0.21959038
# T = 30    Fidelity = 0.63045757
# T = 40    Fidelity = 0.36240973
# T = 50    Fidelity = 0.79151117
# T = 75    Fidelity = 0.74745857
# T = 100   Fidelity = 0.80145588
# T = 125   Fidelity = 0.87920623
# T = 150   Fidelity = 0.88463256
# T = 175   Fidelity = 0.90442229
# T = 200   Fidelity = 0.92856022
# T = 225   Fidelity = 0.93889526
# T = 250   Fidelity = 0.94788500
# T = 275   Fidelity = 0.95292007
# T = 300   Fidelity = 0.94719371
# T = 400   Fidelity = 0.97364526
# T = 500   Fidelity = 0.97413449
# T = 600   Fidelity = 0.82349502
# T = 700   Fidelity = 0.80293122
# T = 800   Fidelity = 0.85411008
# T = 900   Fidelity = 0.72097757
# T = 1000  Fidelity = 0.77247450
# T = 1010  Fidelity = 0.88939470
# T = 1020  Fidelity = 0.85942734
# T = 1030  Fidelity = 0.92243486
# T = 1040  Fidelity = 0.85222021
# T = 1050  Fidelity = 0.86703042
# T = 1060  Fidelity = 0.74947443
# T = 1070  Fidelity = 0.78861344
# T = 1080  Fidelity = 0.53240227
# T = 1090  Fidelity = 0.68892178
# T = 1100  Fidelity = 0.55987041
# T = 1200  Fidelity = 0.78989694
# T = 1300  Fidelity = 0.83136961
# T = 1400  Fidelity = 0.93563868
# T = 1500  Fidelity = 0.85437250
# T = 2000  Fidelity = 0.59040135
# T = 2100  Fidelity = 0.60352095
# T = 2110  Fidelity = 0.67784975
# T = 2120  Fidelity = 0.81801108
# T = 2130  Fidelity = 0.96030632
# T = 2140  Fidelity = 0.76533912
# T = 2150  Fidelity = 0.83704098
# T = 2160  Fidelity = 0.88554073
# T = 2170  Fidelity = 0.60197284
# T = 2180  Fidelity = 0.89631318
# T = 2190  Fidelity = 0.58038538
# T = 2200  Fidelity = 0.48854726
# T = 2300  Fidelity = 0.50724860
# T = 2400  Fidelity = 0.67638963
# T = 2500  Fidelity = 0.33093836
# T = 2600  Fidelity = 0.92172759
# T = 2700  Fidelity = 0.85832757
# T = 2800  Fidelity = 0.85736095
# T = 2900  Fidelity = 0.83031575
# T = 3000  Fidelity = 0.87621672
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02946706e+00
# P0     = 0.87621672
# P1     = 0.01248779
# P0+P1  = 0.88870452
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00003720
# T = 2     Fidelity = 0.00031980
# T = 5     Fidelity = 0.02049406
# T = 10    Fidelity = 0.22206747
# T = 20    Fidelity = 0.58950095
# T = 30    Fidelity = 0.66092942
# T = 40    Fidelity = 0.79038480
# T = 50    Fidelity = 0.82260895
# T = 75    Fidelity = 0.92705687
# T = 100   Fidelity = 0.96745643
# T = 125   Fidelity = 0.98435151
# T = 150   Fidelity = 0.99246433
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00114990
# T = 2     Fidelity = 0.00475536
# T = 5     Fidelity = 0.06200924
# T = 10    Fidelity = 0.28436805
# T = 20    Fidelity = 0.68066339
# T = 30    Fidelity = 0.73434304
# T = 40    Fidelity = 0.82198402
# T = 50    Fidelity = 0.88764532
# T = 75    Fidelity = 0.95505134
# T = 100   Fidelity = 0.98257758
# T = 125   Fidelity = 0.99311103
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00847252
# T = 2     Fidelity = 0.02329764
# T = 5     Fidelity = 0.12481090
# T = 10    Fidelity = 0.34176839
# T = 20    Fidelity = 0.67187945
# T = 30    Fidelity = 0.79951457
# T = 40    Fidelity = 0.85986880
# T = 50    Fidelity = 0.90965188
# T = 75    Fidelity = 0.97046717
# T = 100   Fidelity = 0.98965142
# T = 125   Fidelity = 0.99614533
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03405484
# T = 2     Fidelity = 0.07309256
# T = 5     Fidelity = 0.22181125
# T = 10    Fidelity = 0.42683031
# T = 20    Fidelity = 0.67715493
# T = 30    Fidelity = 0.80000065
# T = 40    Fidelity = 0.87003902
# T = 50    Fidelity = 0.91771550
# T = 75    Fidelity = 0.97878017
# T = 100   Fidelity = 0.99474266
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09444179
# T = 2     Fidelity = 0.17278819
# T = 5     Fidelity = 0.36458980
# T = 10    Fidelity = 0.55559655
# T = 20    Fidelity = 0.74277883
# T = 30    Fidelity = 0.83255958
# T = 40    Fidelity = 0.88471077
# T = 50    Fidelity = 0.91894389
# T = 75    Fidelity = 0.96642151
# T = 100   Fidelity = 0.98504303
# T = 125   Fidelity = 0.99214828
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19083371
# T = 2     Fidelity = 0.31233061
# T = 5     Fidelity = 0.52478914
# T = 10    Fidelity = 0.69150550
# T = 20    Fidelity = 0.82756756
# T = 30    Fidelity = 0.88743311
# T = 40    Fidelity = 0.92193764
# T = 50    Fidelity = 0.94362387
# T = 75    Fidelity = 0.97019084
# T = 100   Fidelity = 0.98274441
# T = 125   Fidelity = 0.98842169
# T = 150   Fidelity = 0.99137749
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30074743
# T = 2     Fidelity = 0.45435153
# T = 5     Fidelity = 0.66181552
# T = 10    Fidelity = 0.79865120
# T = 20    Fidelity = 0.89475318
# T = 30    Fidelity = 0.93355098
# T = 40    Fidelity = 0.95520658
# T = 50    Fidelity = 0.96727481
# T = 75    Fidelity = 0.98307864
# T = 100   Fidelity = 0.98939382
# T = 125   Fidelity = 0.99276467
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40188856
# T = 2     Fidelity = 0.57232238
# T = 5     Fidelity = 0.75997889
# T = 10    Fidelity = 0.86881464
# T = 20    Fidelity = 0.93645066
# T = 30    Fidelity = 0.96230235
# T = 40    Fidelity = 0.97448271
# T = 50    Fidelity = 0.98228100
# T = 75    Fidelity = 0.99137662
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.36752113e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063638
# T = 10    Fidelity = 0.00011477
# T = 20    Fidelity = 0.00401668
# T = 30    Fidelity = 0.05557670
# T = 40    Fidelity = 0.12224233
# T = 50    Fidelity = 0.21121288
# T = 75    Fidelity = 0.58030423
# T = 100   Fidelity = 0.76459985
# T = 125   Fidelity = 0.73493429
# T = 150   Fidelity = 0.86880595
# T = 175   Fidelity = 0.91259002
# T = 200   Fidelity = 0.87349721
# T = 225   Fidelity = 0.95054453
# T = 250   Fidelity = 0.98433551
# T = 275   Fidelity = 0.98530199
# T = 300   Fidelity = 0.86187869
# T = 400   Fidelity = 0.91409755
# T = 500   Fidelity = 0.92685299
# T = 600   Fidelity = 0.91949651
# T = 700   Fidelity = 0.91475931
# T = 800   Fidelity = 0.82061231
# T = 900   Fidelity = 0.78153451
# T = 1000  Fidelity = 0.67221883
# T = 1010  Fidelity = 0.52143660
# T = 1020  Fidelity = 0.57333137
# T = 1030  Fidelity = 0.75209569
# T = 1040  Fidelity = 0.89710023
# T = 1050  Fidelity = 0.85676162
# T = 1060  Fidelity = 0.83290763
# T = 1070  Fidelity = 0.70175577
# T = 1080  Fidelity = 0.54450703
# T = 1090  Fidelity = 0.51424502
# T = 1100  Fidelity = 0.55303065
# T = 1200  Fidelity = 0.67044356
# T = 1300  Fidelity = 0.58627335
# T = 1400  Fidelity = 0.67254886
# T = 1500  Fidelity = 0.29166841
# T = 2000  Fidelity = 0.11278384
# T = 2100  Fidelity = 0.68460579
# T = 2110  Fidelity = 0.68310142
# T = 2120  Fidelity = 0.73089330
# T = 2130  Fidelity = 0.81281155
# T = 2140  Fidelity = 0.85445132
# T = 2150  Fidelity = 0.92115710
# T = 2160  Fidelity = 0.90462491
# T = 2170  Fidelity = 0.86520285
# T = 2180  Fidelity = 0.77644335
# T = 2190  Fidelity = 0.40697918
# T = 2200  Fidelity = 0.26053038
# T = 2300  Fidelity = 0.55527921
# T = 2400  Fidelity = 0.82756205
# T = 2500  Fidelity = 0.90706218
# T = 2600  Fidelity = 0.80645899
# T = 2700  Fidelity = 0.80973893
# T = 2800  Fidelity = 0.35141843
# T = 2900  Fidelity = 0.89046565
# T = 3000  Fidelity = 0.74227697
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00970921e+00
# P0     = 0.74227697
# P1     = 0.04166144
# P0+P1  = 0.78393841
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.12924856e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00018458
# T = 10    Fidelity = 0.04088715
# T = 20    Fidelity = 0.42048938
# T = 30    Fidelity = 0.49090712
# T = 40    Fidelity = 0.64132046
# T = 50    Fidelity = 0.64430555
# T = 75    Fidelity = 0.88047342
# T = 100   Fidelity = 0.90153148
# T = 125   Fidelity = 0.87121092
# T = 150   Fidelity = 0.88508199
# T = 175   Fidelity = 0.91945404
# T = 200   Fidelity = 0.94049253
# T = 225   Fidelity = 0.95408334
# T = 250   Fidelity = 0.94772329
# T = 275   Fidelity = 0.95832318
# T = 300   Fidelity = 0.93982144
# T = 400   Fidelity = 0.97424741
# T = 500   Fidelity = 0.95632404
# T = 600   Fidelity = 0.92835351
# T = 700   Fidelity = 0.56320215
# T = 800   Fidelity = 0.61945340
# T = 900   Fidelity = 0.67961486
# T = 1000  Fidelity = 0.89281653
# T = 1010  Fidelity = 0.57015004
# T = 1020  Fidelity = 0.84595962
# T = 1030  Fidelity = 0.84266121
# T = 1040  Fidelity = 0.71159198
# T = 1050  Fidelity = 0.85599791
# T = 1060  Fidelity = 0.56713367
# T = 1070  Fidelity = 0.80953876
# T = 1080  Fidelity = 0.62685418
# T = 1090  Fidelity = 0.81941174
# T = 1100  Fidelity = 0.70887570
# T = 1200  Fidelity = 0.61777299
# T = 1300  Fidelity = 0.60127609
# T = 1400  Fidelity = 0.54958609
# T = 1500  Fidelity = 0.71087893
# T = 2000  Fidelity = 0.50100465
# T = 2100  Fidelity = 0.70513905
# T = 2110  Fidelity = 0.68483293
# T = 2120  Fidelity = 0.82685392
# T = 2130  Fidelity = 0.66908961
# T = 2140  Fidelity = 0.59187083
# T = 2150  Fidelity = 0.80505563
# T = 2160  Fidelity = 0.53444834
# T = 2170  Fidelity = 0.69578179
# T = 2180  Fidelity = 0.65925672
# T = 2190  Fidelity = 0.77006037
# T = 2200  Fidelity = 0.50611574
# T = 2300  Fidelity = 0.67872260
# T = 2400  Fidelity = 0.67302020
# T = 2500  Fidelity = 0.66481788
# T = 2600  Fidelity = 0.71821267
# T = 2700  Fidelity = 0.76010363
# T = 2800  Fidelity = 0.79306006
# T = 2900  Fidelity = 0.52605089
# T = 3000  Fidelity = 0.55953567
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02931057e+00
# P0     = 0.55953567
# P1     = 0.20838682
# P0+P1  = 0.76792249
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00001183
# T = 2     Fidelity = 0.00016900
# T = 5     Fidelity = 0.01433524
# T = 10    Fidelity = 0.17120341
# T = 20    Fidelity = 0.44272327
# T = 30    Fidelity = 0.34004848
# T = 40    Fidelity = 0.54715132
# T = 50    Fidelity = 0.43876682
# T = 75    Fidelity = 0.49352909
# T = 100   Fidelity = 0.50303883
# T = 125   Fidelity = 0.50288788
# T = 150   Fidelity = 0.50193939
# T = 175   Fidelity = 0.50105315
# T = 200   Fidelity = 0.49650669
# T = 225   Fidelity = 0.50815056
# T = 250   Fidelity = 0.50062648
# T = 275   Fidelity = 0.48662259
# T = 300   Fidelity = 0.48654883
# T = 400   Fidelity = 0.49686343
# T = 500   Fidelity = 0.30742844
# T = 600   Fidelity = 0.50720429
# T = 700   Fidelity = 0.38702670
# T = 800   Fidelity = 0.53183707
# T = 900   Fidelity = 0.52768049
# T = 1000  Fidelity = 0.69805462
# T = 1010  Fidelity = 0.39511291
# T = 1020  Fidelity = 0.40000550
# T = 1030  Fidelity = 0.46773406
# T = 1040  Fidelity = 0.49555227
# T = 1050  Fidelity = 0.46516304
# T = 1060  Fidelity = 0.36740427
# T = 1070  Fidelity = 0.55851804
# T = 1080  Fidelity = 0.26627234
# T = 1090  Fidelity = 0.27501623
# T = 1100  Fidelity = 0.60841442
# T = 1200  Fidelity = 0.29103955
# T = 1300  Fidelity = 0.55038915
# T = 1400  Fidelity = 0.53305983
# T = 1500  Fidelity = 0.36054252
# T = 2000  Fidelity = 0.28906328
# T = 2100  Fidelity = 0.20214198
# T = 2110  Fidelity = 0.54821941
# T = 2120  Fidelity = 0.46929768
# T = 2130  Fidelity = 0.49812426
# T = 2140  Fidelity = 0.32246935
# T = 2150  Fidelity = 0.44329638
# T = 2160  Fidelity = 0.38422787
# T = 2170  Fidelity = 0.38873833
# T = 2180  Fidelity = 0.52917565
# T = 2190  Fidelity = 0.19274458
# T = 2200  Fidelity = 0.48309149
# T = 2300  Fidelity = 0.53168155
# T = 2400  Fidelity = 0.48583371
# T = 2500  Fidelity = 0.45738130
# T = 2600  Fidelity = 0.45755121
# T = 2700  Fidelity = 0.56718148
# T = 2800  Fidelity = 0.59665999
# T = 2900  Fidelity = 0.45409513
# T = 3000  Fidelity = 0.42672492
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.42672492
# P1     = 0.06105217
# P0+P1  = 0.48777709
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.03672155e-03
# T = 1     Fidelity = 0.00307121
# T = 2     Fidelity = 0.01238985
# T = 5     Fidelity = 0.08438854
# T = 10    Fidelity = 0.22345646
# T = 20    Fidelity = 0.31773976
# T = 30    Fidelity = 0.38304767
# T = 40    Fidelity = 0.54971869
# T = 50    Fidelity = 0.58068348
# T = 75    Fidelity = 0.50032174
# T = 100   Fidelity = 0.52169004
# T = 125   Fidelity = 0.52325933
# T = 150   Fidelity = 0.52305653
# T = 175   Fidelity = 0.51982574
# T = 200   Fidelity = 0.53011974
# T = 225   Fidelity = 0.52266015
# T = 250   Fidelity = 0.51799029
# T = 275   Fidelity = 0.52623413
# T = 300   Fidelity = 0.49475512
# T = 400   Fidelity = 0.50927669
# T = 500   Fidelity = 0.55328077
# T = 600   Fidelity = 0.50787189
# T = 700   Fidelity = 0.44194594
# T = 800   Fidelity = 0.45194435
# T = 900   Fidelity = 0.53372841
# T = 1000  Fidelity = 0.77622152
# T = 1010  Fidelity = 0.44411606
# T = 1020  Fidelity = 0.12565101
# T = 1030  Fidelity = 0.56060399
# T = 1040  Fidelity = 0.79061085
# T = 1050  Fidelity = 0.59298489
# T = 1060  Fidelity = 0.48543983
# T = 1070  Fidelity = 0.49761868
# T = 1080  Fidelity = 0.42055247
# T = 1090  Fidelity = 0.25496083
# T = 1100  Fidelity = 0.74108985
# T = 1200  Fidelity = 0.58416180
# T = 1300  Fidelity = 0.45415699
# T = 1400  Fidelity = 0.52259512
# T = 1500  Fidelity = 0.53717609
# T = 2000  Fidelity = 0.45817663
# T = 2100  Fidelity = 0.51591420
# T = 2110  Fidelity = 0.55367795
# T = 2120  Fidelity = 0.46781156
# T = 2130  Fidelity = 0.39318339
# T = 2140  Fidelity = 0.56254199
# T = 2150  Fidelity = 0.76796891
# T = 2160  Fidelity = 0.43736903
# T = 2170  Fidelity = 0.24373535
# T = 2180  Fidelity = 0.49676032
# T = 2190  Fidelity = 0.68859076
# T = 2200  Fidelity = 0.61399735
# T = 2300  Fidelity = 0.81735464
# T = 2400  Fidelity = 0.53211684
# T = 2500  Fidelity = 0.50164707
# T = 2600  Fidelity = 0.55254275
# T = 2700  Fidelity = 0.44694165
# T = 2800  Fidelity = 0.53623035
# T = 2900  Fidelity = 0.30502528
# T = 3000  Fidelity = 0.43890380
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.43890380
# P1     = 0.02388387
# P0+P1  = 0.46278767
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.41475042e-03
# T = 1     Fidelity = 0.02405029
# T = 2     Fidelity = 0.06514694
# T = 5     Fidelity = 0.21902036
# T = 10    Fidelity = 0.40679651
# T = 20    Fidelity = 0.52932027
# T = 30    Fidelity = 0.49785314
# T = 40    Fidelity = 0.50386369
# T = 50    Fidelity = 0.54927143
# T = 75    Fidelity = 0.60863718
# T = 100   Fidelity = 0.60704646
# T = 125   Fidelity = 0.61204919
# T = 150   Fidelity = 0.61601785
# T = 175   Fidelity = 0.61936322
# T = 200   Fidelity = 0.62638992
# T = 225   Fidelity = 0.62921831
# T = 250   Fidelity = 0.63297426
# T = 275   Fidelity = 0.62984597
# T = 300   Fidelity = 0.64605322
# T = 400   Fidelity = 0.59391342
# T = 500   Fidelity = 0.65343383
# T = 600   Fidelity = 0.67713238
# T = 700   Fidelity = 0.59465268
# T = 800   Fidelity = 0.71349127
# T = 900   Fidelity = 0.60856614
# T = 1000  Fidelity = 0.48720521
# T = 1010  Fidelity = 0.76017303
# T = 1020  Fidelity = 0.85147410
# T = 1030  Fidelity = 0.75056680
# T = 1040  Fidelity = 0.52966508
# T = 1050  Fidelity = 0.47478651
# T = 1060  Fidelity = 0.65021312
# T = 1070  Fidelity = 0.77730508
# T = 1080  Fidelity = 0.82145900
# T = 1090  Fidelity = 0.55645614
# T = 1100  Fidelity = 0.40086630
# T = 1200  Fidelity = 0.46014305
# T = 1300  Fidelity = 0.54117590
# T = 1400  Fidelity = 0.76946727
# T = 1500  Fidelity = 0.68059557
# T = 2000  Fidelity = 0.77323210
# T = 2100  Fidelity = 0.81900441
# T = 2110  Fidelity = 0.80881853
# T = 2120  Fidelity = 0.55135812
# T = 2130  Fidelity = 0.65537388
# T = 2140  Fidelity = 0.71226409
# T = 2150  Fidelity = 0.83124230
# T = 2160  Fidelity = 0.84627568
# T = 2170  Fidelity = 0.78135481
# T = 2180  Fidelity = 0.53237107
# T = 2190  Fidelity = 0.56993583
# T = 2200  Fidelity = 0.69969292
# T = 2300  Fidelity = 0.76660447
# T = 2400  Fidelity = 0.75368877
# T = 2500  Fidelity = 0.82619645
# T = 2600  Fidelity = 0.73019851
# T = 2700  Fidelity = 0.77748351
# T = 2800  Fidelity = 0.76121049
# T = 2900  Fidelity = 0.69745899
# T = 3000  Fidelity = 0.75033814
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.75033814
# P1     = 0.00482545
# P0+P1  = 0.75516359
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50213251e-02
# T = 1     Fidelity = 0.08250368
# T = 2     Fidelity = 0.17449272
# T = 5     Fidelity = 0.39171724
# T = 10    Fidelity = 0.58534650
# T = 20    Fidelity = 0.71362831
# T = 30    Fidelity = 0.72016961
# T = 40    Fidelity = 0.71296021
# T = 50    Fidelity = 0.71869909
# T = 75    Fidelity = 0.74407926
# T = 100   Fidelity = 0.76242197
# T = 125   Fidelity = 0.77524743
# T = 150   Fidelity = 0.78584707
# T = 175   Fidelity = 0.79497622
# T = 200   Fidelity = 0.80422310
# T = 225   Fidelity = 0.81040362
# T = 250   Fidelity = 0.81597402
# T = 275   Fidelity = 0.82619946
# T = 300   Fidelity = 0.81740659
# T = 400   Fidelity = 0.87422065
# T = 500   Fidelity = 0.87080723
# T = 600   Fidelity = 0.79406184
# T = 700   Fidelity = 0.82758626
# T = 800   Fidelity = 0.84476977
# T = 900   Fidelity = 0.85216707
# T = 1000  Fidelity = 0.87667133
# T = 1010  Fidelity = 0.79379767
# T = 1020  Fidelity = 0.77911841
# T = 1030  Fidelity = 0.86812313
# T = 1040  Fidelity = 0.95151896
# T = 1050  Fidelity = 0.97310995
# T = 1060  Fidelity = 0.93472189
# T = 1070  Fidelity = 0.82889968
# T = 1080  Fidelity = 0.84154466
# T = 1090  Fidelity = 0.76904732
# T = 1100  Fidelity = 0.82759339
# T = 1200  Fidelity = 0.79792507
# T = 1300  Fidelity = 0.95546119
# T = 1400  Fidelity = 0.85398405
# T = 1500  Fidelity = 0.92812449
# T = 2000  Fidelity = 0.85935407
# T = 2100  Fidelity = 0.86727432
# T = 2110  Fidelity = 0.86707335
# T = 2120  Fidelity = 0.92130915
# T = 2130  Fidelity = 0.86387226
# T = 2140  Fidelity = 0.88034324
# T = 2150  Fidelity = 0.80878481
# T = 2160  Fidelity = 0.83675878
# T = 2170  Fidelity = 0.95397381
# T = 2180  Fidelity = 0.93758107
# T = 2190  Fidelity = 0.93706806
# T = 2200  Fidelity = 0.94064456
# T = 2300  Fidelity = 0.95019136
# T = 2400  Fidelity = 0.97253110
# T = 2500  Fidelity = 0.96423841
# T = 2600  Fidelity = 0.98742679
# T = 2700  Fidelity = 0.96903427
# T = 2800  Fidelity = 0.95219775
# T = 2900  Fidelity = 0.85464632
# T = 3000  Fidelity = 0.97230905
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.09849352e+00
# P0     = 0.97230905
# P1     = 0.00011307
# P0+P1  = 0.97242212
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77221454e-02
# T = 1     Fidelity = 0.17552523
# T = 2     Fidelity = 0.31611673
# T = 5     Fidelity = 0.55525617
# T = 10    Fidelity = 0.72492018
# T = 20    Fidelity = 0.82948601
# T = 30    Fidelity = 0.85312686
# T = 40    Fidelity = 0.85899064
# T = 50    Fidelity = 0.86468034
# T = 75    Fidelity = 0.88210013
# T = 100   Fidelity = 0.89839902
# T = 125   Fidelity = 0.90980215
# T = 150   Fidelity = 0.91811402
# T = 175   Fidelity = 0.92575005
# T = 200   Fidelity = 0.93482709
# T = 225   Fidelity = 0.93590610
# T = 250   Fidelity = 0.93617684
# T = 275   Fidelity = 0.94545991
# T = 300   Fidelity = 0.93549695
# T = 400   Fidelity = 0.94951133
# T = 500   Fidelity = 0.95252249
# T = 600   Fidelity = 0.96024223
# T = 700   Fidelity = 0.91551590
# T = 800   Fidelity = 0.92796482
# T = 900   Fidelity = 0.94693914
# T = 1000  Fidelity = 0.93970443
# T = 1010  Fidelity = 0.95195597
# T = 1020  Fidelity = 0.95694361
# T = 1030  Fidelity = 0.97883879
# T = 1040  Fidelity = 0.99489590
#
# Minimum T for Fidelity >= 0.99 : 1040
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20187623e-01
# T = 1     Fidelity = 0.28022373
# T = 2     Fidelity = 0.45267694
# T = 5     Fidelity = 0.68128778
# T = 10    Fidelity = 0.81900455
# T = 20    Fidelity = 0.89647541
# T = 30    Fidelity = 0.91796472
# T = 40    Fidelity = 0.92933314
# T = 50    Fidelity = 0.93800616
# T = 75    Fidelity = 0.95171053
# T = 100   Fidelity = 0.96198177
# T = 125   Fidelity = 0.96840016
# T = 150   Fidelity = 0.97426224
# T = 175   Fidelity = 0.97592199
# T = 200   Fidelity = 0.98173045
# T = 225   Fidelity = 0.97816724
# T = 250   Fidelity = 0.98128907
# T = 275   Fidelity = 0.97901843
# T = 300   Fidelity = 0.97998006
# T = 400   Fidelity = 0.97508017
# T = 500   Fidelity = 0.95357693
# T = 600   Fidelity = 0.93805386
# T = 700   Fidelity = 0.97975308
# T = 800   Fidelity = 0.98444592
# T = 900   Fidelity = 0.98924538
# T = 1000  Fidelity = 0.97928334
# T = 1010  Fidelity = 0.97151457
# T = 1020  Fidelity = 0.99567548
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405779e-01
# T = 1     Fidelity = 0.37810920
# T = 2     Fidelity = 0.56564937
# T = 5     Fidelity = 0.76928099
# T = 10    Fidelity = 0.87849623
# T = 20    Fidelity = 0.93497426
# T = 30    Fidelity = 0.95256929
# T = 40    Fidelity = 0.96383323
# T = 50    Fidelity = 0.96954857
# T = 75    Fidelity = 0.97950332
# T = 100   Fidelity = 0.98506722
# T = 125   Fidelity = 0.98832254
# T = 150   Fidelity = 0.99065863
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843475e-01
# T = 1     Fidelity = 0.46389464
# T = 2     Fidelity = 0.65545608
# T = 5     Fidelity = 0.83091050
# T = 10    Fidelity = 0.91700436
# T = 20    Fidelity = 0.95849251
# T = 30    Fidelity = 0.97282814
# T = 40    Fidelity = 0.97907712
# T = 50    Fidelity = 0.98364477
# T = 75    Fidelity = 0.99020011
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00082750
# T = 10    Fidelity = 0.06381257
# T = 20    Fidelity = 0.45588311
# T = 30    Fidelity = 0.88060674
# T = 40    Fidelity = 0.96768819
# T = 50    Fidelity = 0.99160960
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000226
# T = 5     Fidelity = 0.02514794
# T = 10    Fidelity = 0.90074885
# T = 20    Fidelity = 0.96765433
# T = 30    Fidelity = 0.99642583
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00005223
# T = 2     Fidelity = 0.00078430
# T = 5     Fidelity = 0.18879094
# T = 10    Fidelity = 0.98853745
# T = 20    Fidelity = 0.99524923
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00123942
# T = 2     Fidelity = 0.00814156
# T = 5     Fidelity = 0.34557759
# T = 10    Fidelity = 0.98665868
# T = 20    Fidelity = 0.99353130
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00700135
# T = 2     Fidelity = 0.02899045
# T = 5     Fidelity = 0.47066986
# T = 10    Fidelity = 0.98171058
# T = 20    Fidelity = 0.99297099
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02070591
# T = 2     Fidelity = 0.06353207
# T = 5     Fidelity = 0.56323362
# T = 10    Fidelity = 0.97599778
# T = 20    Fidelity = 0.99222149
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04383440
# T = 2     Fidelity = 0.11057850
# T = 5     Fidelity = 0.63951171
# T = 10    Fidelity = 0.97273406
# T = 20    Fidelity = 0.99298493
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07536624
# T = 2     Fidelity = 0.16384565
# T = 5     Fidelity = 0.69632937
# T = 10    Fidelity = 0.96947319
# T = 20    Fidelity = 0.99321398
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11360464
# T = 2     Fidelity = 0.22073981
# T = 5     Fidelity = 0.74284249
# T = 10    Fidelity = 0.96778381
# T = 20    Fidelity = 0.99356824
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15668360
# T = 2     Fidelity = 0.27877979
# T = 5     Fidelity = 0.78121920
# T = 10    Fidelity = 0.96728681
# T = 20    Fidelity = 0.99388776
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9973304667      1.00972087e+00    None        None        None
# Symmetric      0.311     2         0.9977195832      1.02934439e+00    None        None        None
# Symmetric      0.522     2         0.9980249772      1.04790824e+00    None        None        None
# Symmetric      0.733     2         0.9982704239      1.06556366e+00    None        None        None
# Symmetric      0.944     2         0.9984647944      1.08242773e+00    None        None        None
# Symmetric      1.156     2         0.9986293138      1.09859358e+00    None        None        None
# Symmetric      1.367     2         0.9987638272      1.11413694e+00    None        None        None
# Symmetric      1.578     2         0.9988752197      1.12912045e+00    None        None        None
# Symmetric      1.789     2         0.9989692206      1.14359670e+00    None        None        None
# Symmetric      2.000     2         0.9990509551      1.15761039e+00    None        None        None
# Weak SSB optimised0.100     None      0.9804412440      2.42819099e-01    0.826264    0.059339    0.885604
# Weak SSB optimised0.311     None      0.9741344904      2.61171322e-01    0.876217    0.012488    0.888705
# Weak SSB optimised0.522     150       0.9924643285      2.64873214e-01    None        None        None
# Weak SSB optimised0.733     125       0.9931110281      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     125       0.9961453341      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     100       0.9947426632      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9921482793      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     150       0.9913774853      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9927646689      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     75        0.9913766218      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9853019920      1.36752113e-03    0.742277    0.041661    0.783938
# Weak SSB       0.311     None      0.9742474070      1.12924856e-03    0.559536    0.208387    0.767922
# Weak SSB       0.522     None      0.6980546171      1.05614584e-03    0.426725    0.061052    0.487777
# Weak SSB       0.733     None      0.8173546376      1.03672155e-03    0.438904    0.023884    0.462788
# Weak SSB       0.944     None      0.8514741007      4.41475042e-03    0.750338    0.004825    0.755164
# Weak SSB       1.156     None      0.9874267910      2.50213251e-02    0.972309    0.000113    0.972422
# Weak SSB       1.367     1040      0.9948959040      6.77221454e-02    None        None        None
# Weak SSB       1.578     1020      0.9956754849      1.20187623e-01    None        None        None
# Weak SSB       1.789     150       0.9906586253      1.71405779e-01    None        None        None
# Weak SSB       2.000     75        0.9902001086      2.18843475e-01    None        None        None
# Strong SSB     0.100     50        0.9916095986      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9964258298      7.22062439e-01    None        None        None
# Strong SSB     0.522     20        0.9952492255      7.78318602e-01    None        None        None
# Strong SSB     0.733     20        0.9935313039      8.15979742e-01    None        None        None
# Strong SSB     0.944     20        0.9929709882      8.44059983e-01    None        None        None
# Strong SSB     1.156     20        0.9922214884      8.66317759e-01    None        None        None
# Strong SSB     1.367     20        0.9929849350      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9932139821      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9935682401      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9938877573      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        color=case_colors[case],
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=1$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color="blue")

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color="green")

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB', color="red")

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='blue'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='green'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='red'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)



plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_0^2=1$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Starting of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96521009
# T = 2     Fidelity = 0.99334047
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.03626623e+00
# T = 1     Fidelity = 0.96804876
# T = 2     Fidelity = 0.99421735
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05846299e+00
# T = 1     Fidelity = 0.97048657
# T = 2     Fidelity = 0.99491073
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07916278e+00
# T = 1     Fidelity = 0.97260913
# T = 2     Fidelity = 0.99547067
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.09862393e+00
# T = 1     Fidelity = 0.97444539
# T = 2     Fidelity = 0.99591699
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.11703633e+00
# T = 1     Fidelity = 0.97609955
# T = 2     Fidelity = 0.99629533
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.13454489e+00
# T = 1     Fidelity = 0.97756468
# T = 2     Fidelity = 0.99660631
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.15126343e+00
# T = 1     Fidelity = 0.97887343
# T = 2     Fidelity = 0.99686514
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.16728342e+00
# T = 1     Fidelity = 0.98005932
# T = 2     Fidelity = 0.99708470
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98115004
# T = 2     Fidelity = 0.99727634
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000155
# T = 10    Fidelity = 0.00046388
# T = 20    Fidelity = 0.00575117
# T = 30    Fidelity = 0.01838110
# T = 40    Fidelity = 0.06174253
# T = 50    Fidelity = 0.16059342
# T = 75    Fidelity = 0.32207181
# T = 100   Fidelity = 0.48103444
# T = 125   Fidelity = 0.62866288
# T = 150   Fidelity = 0.72411985
# T = 175   Fidelity = 0.79394779
# T = 200   Fidelity = 0.83502753
# T = 225   Fidelity = 0.84686531
# T = 250   Fidelity = 0.85560891
# T = 275   Fidelity = 0.71812163
# T = 300   Fidelity = 0.79232785
# T = 400   Fidelity = 0.93096563
# T = 500   Fidelity = 0.91034110
# T = 600   Fidelity = 0.89298539
# T = 700   Fidelity = 0.81649072
# T = 800   Fidelity = 0.64642921
# T = 900   Fidelity = 0.74824152
# T = 1000  Fidelity = 0.63033094
# T = 1010  Fidelity = 0.62220707
# T = 1020  Fidelity = 0.70062938
# T = 1030  Fidelity = 0.67207518
# T = 1040  Fidelity = 0.25563123
# T = 1050  Fidelity = 0.41837345
# T = 1060  Fidelity = 0.49960539
# T = 1070  Fidelity = 0.47180825
# T = 1080  Fidelity = 0.56561932
# T = 1090  Fidelity = 0.54892720
# T = 1100  Fidelity = 0.75532371
# T = 1200  Fidelity = 0.22326569
# T = 1300  Fidelity = 0.25205265
# T = 1400  Fidelity = 0.65135718
# T = 1500  Fidelity = 0.48329730
# T = 2000  Fidelity = 0.33793732
# T = 2100  Fidelity = 0.88897291
# T = 2110  Fidelity = 0.81453232
# T = 2120  Fidelity = 0.77061618
# T = 2130  Fidelity = 0.74780780
# T = 2140  Fidelity = 0.54469381
# T = 2150  Fidelity = 0.75800120
# T = 2160  Fidelity = 0.56151634
# T = 2170  Fidelity = 0.63597732
# T = 2180  Fidelity = 0.70262698
# T = 2190  Fidelity = 0.53266964
# T = 2200  Fidelity = 0.53064403
# T = 2300  Fidelity = 0.33858625
# T = 2400  Fidelity = 0.51761058
# T = 2500  Fidelity = 0.52729087
# T = 2600  Fidelity = 0.30714987
# T = 2700  Fidelity = 0.24685220
# T = 2800  Fidelity = 0.53861088
# T = 2900  Fidelity = 0.50468487
# T = 3000  Fidelity = 0.91807356
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91807356
# P1     = 0.00925300
# P0+P1  = 0.92732656
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61673084e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000002
# T = 5     Fidelity = 0.00001437
# T = 10    Fidelity = 0.00298025
# T = 20    Fidelity = 0.21926394
# T = 30    Fidelity = 0.28786965
# T = 40    Fidelity = 0.35051722
# T = 50    Fidelity = 0.70866206
# T = 75    Fidelity = 0.78271354
# T = 100   Fidelity = 0.66266867
# T = 125   Fidelity = 0.86372554
# T = 150   Fidelity = 0.77915500
# T = 175   Fidelity = 0.89865338
# T = 200   Fidelity = 0.96762195
# T = 225   Fidelity = 0.88889349
# T = 250   Fidelity = 0.96198869
# T = 275   Fidelity = 0.95128700
# T = 300   Fidelity = 0.93425741
# T = 400   Fidelity = 0.96928671
# T = 500   Fidelity = 0.96589104
# T = 600   Fidelity = 0.87428270
# T = 700   Fidelity = 0.62738158
# T = 800   Fidelity = 0.79917756
# T = 900   Fidelity = 0.74057721
# T = 1000  Fidelity = 0.82921167
# T = 1010  Fidelity = 0.78923443
# T = 1020  Fidelity = 0.83885693
# T = 1030  Fidelity = 0.73873409
# T = 1040  Fidelity = 0.69685642
# T = 1050  Fidelity = 0.68417222
# T = 1060  Fidelity = 0.55010440
# T = 1070  Fidelity = 0.51695702
# T = 1080  Fidelity = 0.64459019
# T = 1090  Fidelity = 0.51293247
# T = 1100  Fidelity = 0.48426426
# T = 1200  Fidelity = 0.88337738
# T = 1300  Fidelity = 0.66165234
# T = 1400  Fidelity = 0.81212403
# T = 1500  Fidelity = 0.91922648
# T = 2000  Fidelity = 0.62957917
# T = 2100  Fidelity = 0.47693866
# T = 2110  Fidelity = 0.76032197
# T = 2120  Fidelity = 0.73083154
# T = 2130  Fidelity = 0.56159628
# T = 2140  Fidelity = 0.47524816
# T = 2150  Fidelity = 0.62539826
# T = 2160  Fidelity = 0.54453407
# T = 2170  Fidelity = 0.42193698
# T = 2180  Fidelity = 0.48823497
# T = 2190  Fidelity = 0.81699264
# T = 2200  Fidelity = 0.62245906
# T = 2300  Fidelity = 0.65811956
# T = 2400  Fidelity = 0.58467739
# T = 2500  Fidelity = 0.82715356
# T = 2600  Fidelity = 0.60737653
# T = 2700  Fidelity = 0.88232729
# T = 2800  Fidelity = 0.64902116
# T = 2900  Fidelity = 0.70334618
# T = 3000  Fidelity = 0.87135674
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43053089e+00
# P0     = 0.87135674
# P1     = 0.03764073
# P0+P1  = 0.90899747
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64768458e-01
# T = 1     Fidelity = 0.00001016
# T = 2     Fidelity = 0.00014640
# T = 5     Fidelity = 0.00344236
# T = 10    Fidelity = 0.05110072
# T = 20    Fidelity = 0.41008831
# T = 30    Fidelity = 0.59472744
# T = 40    Fidelity = 0.58244488
# T = 50    Fidelity = 0.72398606
# T = 75    Fidelity = 0.81376883
# T = 100   Fidelity = 0.89316804
# T = 125   Fidelity = 0.94399618
# T = 150   Fidelity = 0.96741080
# T = 175   Fidelity = 0.97764897
# T = 200   Fidelity = 0.98532411
# T = 225   Fidelity = 0.98715550
# T = 250   Fidelity = 0.99145606
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00049929
# T = 2     Fidelity = 0.00288957
# T = 5     Fidelity = 0.02081342
# T = 10    Fidelity = 0.11087087
# T = 20    Fidelity = 0.42510726
# T = 30    Fidelity = 0.66179932
# T = 40    Fidelity = 0.73177033
# T = 50    Fidelity = 0.76195717
# T = 75    Fidelity = 0.88540558
# T = 100   Fidelity = 0.93292408
# T = 125   Fidelity = 0.96621739
# T = 150   Fidelity = 0.98145225
# T = 175   Fidelity = 0.98898743
# T = 200   Fidelity = 0.99278564
#
# Minimum T for Fidelity >= 0.99 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00480434
# T = 2     Fidelity = 0.01661148
# T = 5     Fidelity = 0.06220257
# T = 10    Fidelity = 0.18575319
# T = 20    Fidelity = 0.44924968
# T = 30    Fidelity = 0.64705113
# T = 40    Fidelity = 0.75652469
# T = 50    Fidelity = 0.81863417
# T = 75    Fidelity = 0.91086663
# T = 100   Fidelity = 0.95904331
# T = 125   Fidelity = 0.97964221
# T = 150   Fidelity = 0.98965360
# T = 175   Fidelity = 0.99327407
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.02296323
# T = 2     Fidelity = 0.05770349
# T = 5     Fidelity = 0.14285308
# T = 10    Fidelity = 0.29320348
# T = 20    Fidelity = 0.51775824
# T = 30    Fidelity = 0.66385314
# T = 40    Fidelity = 0.75674570
# T = 50    Fidelity = 0.82029047
# T = 75    Fidelity = 0.91715261
# T = 100   Fidelity = 0.96579131
# T = 125   Fidelity = 0.98728841
# T = 150   Fidelity = 0.99490728
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.07127936
# T = 2     Fidelity = 0.14578148
# T = 5     Fidelity = 0.27586435
# T = 10    Fidelity = 0.44392805
# T = 20    Fidelity = 0.63769687
# T = 30    Fidelity = 0.74371391
# T = 40    Fidelity = 0.81023134
# T = 50    Fidelity = 0.85703725
# T = 75    Fidelity = 0.92597045
# T = 100   Fidelity = 0.96133618
# T = 125   Fidelity = 0.97991520
# T = 150   Fidelity = 0.98821178
# T = 175   Fidelity = 0.99208641
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.15458812
# T = 2     Fidelity = 0.27509381
# T = 5     Fidelity = 0.43718416
# T = 10    Fidelity = 0.60289389
# T = 20    Fidelity = 0.76079453
# T = 30    Fidelity = 0.83538741
# T = 40    Fidelity = 0.87989075
# T = 50    Fidelity = 0.90959581
# T = 75    Fidelity = 0.95159221
# T = 100   Fidelity = 0.97283311
# T = 125   Fidelity = 0.98358316
# T = 150   Fidelity = 0.98875559
# T = 175   Fidelity = 0.99246922
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.25471962
# T = 2     Fidelity = 0.41159553
# T = 5     Fidelity = 0.58359309
# T = 10    Fidelity = 0.73076895
# T = 20    Fidelity = 0.85275178
# T = 30    Fidelity = 0.90364694
# T = 40    Fidelity = 0.93196739
# T = 50    Fidelity = 0.94954449
# T = 75    Fidelity = 0.97416791
# T = 100   Fidelity = 0.98524152
# T = 125   Fidelity = 0.99072806
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.35047875
# T = 2     Fidelity = 0.52838098
# T = 5     Fidelity = 0.69391740
# T = 10    Fidelity = 0.81731637
# T = 20    Fidelity = 0.90968805
# T = 30    Fidelity = 0.94390251
# T = 40    Fidelity = 0.96179427
# T = 50    Fidelity = 0.97269993
# T = 75    Fidelity = 0.98644780
# T = 100   Fidelity = 0.99223131
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.40037050e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000116
# T = 10    Fidelity = 0.00113771
# T = 20    Fidelity = 0.00651019
# T = 30    Fidelity = 0.02780934
# T = 40    Fidelity = 0.11881686
# T = 50    Fidelity = 0.09119939
# T = 75    Fidelity = 0.30308690
# T = 100   Fidelity = 0.53455076
# T = 125   Fidelity = 0.55315802
# T = 150   Fidelity = 0.69229836
# T = 175   Fidelity = 0.80289011
# T = 200   Fidelity = 0.78733615
# T = 225   Fidelity = 0.85511539
# T = 250   Fidelity = 0.93618153
# T = 275   Fidelity = 0.73912480
# T = 300   Fidelity = 0.74328471
# T = 400   Fidelity = 0.95571452
# T = 500   Fidelity = 0.95221615
# T = 600   Fidelity = 0.96852764
# T = 700   Fidelity = 0.85565849
# T = 800   Fidelity = 0.83708819
# T = 900   Fidelity = 0.56700028
# T = 1000  Fidelity = 0.69830467
# T = 1010  Fidelity = 0.63501235
# T = 1020  Fidelity = 0.61040089
# T = 1030  Fidelity = 0.63147958
# T = 1040  Fidelity = 0.75860984
# T = 1050  Fidelity = 0.62003007
# T = 1060  Fidelity = 0.68077478
# T = 1070  Fidelity = 0.48143299
# T = 1080  Fidelity = 0.80549511
# T = 1090  Fidelity = 0.65979691
# T = 1100  Fidelity = 0.25729609
# T = 1200  Fidelity = 0.74505735
# T = 1300  Fidelity = 0.51571723
# T = 1400  Fidelity = 0.35203050
# T = 1500  Fidelity = 0.77852534
# T = 2000  Fidelity = 0.50061506
# T = 2100  Fidelity = 0.78856396
# T = 2110  Fidelity = 0.60441020
# T = 2120  Fidelity = 0.75403160
# T = 2130  Fidelity = 0.76865949
# T = 2140  Fidelity = 0.63066930
# T = 2150  Fidelity = 0.32748834
# T = 2160  Fidelity = 0.49910163
# T = 2170  Fidelity = 0.20006671
# T = 2180  Fidelity = 0.19567176
# T = 2190  Fidelity = 0.12328711
# T = 2200  Fidelity = 0.21512977
# T = 2300  Fidelity = 0.51657972
# T = 2400  Fidelity = 0.82088897
# T = 2500  Fidelity = 0.86492178
# T = 2600  Fidelity = 0.95789459
# T = 2700  Fidelity = 0.58044346
# T = 2800  Fidelity = 0.44977073
# T = 2900  Fidelity = 0.84289127
# T = 3000  Fidelity = 0.91276041
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41951501e+00
# P0     = 0.91276041
# P1     = 0.01913520
# P0+P1  = 0.93189561
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.13564004e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00000733
# T = 10    Fidelity = 0.00113254
# T = 20    Fidelity = 0.19635758
# T = 30    Fidelity = 0.53113839
# T = 40    Fidelity = 0.08283239
# T = 50    Fidelity = 0.71286090
# T = 75    Fidelity = 0.50876376
# T = 100   Fidelity = 0.68297935
# T = 125   Fidelity = 0.91733855
# T = 150   Fidelity = 0.91698571
# T = 175   Fidelity = 0.86847817
# T = 200   Fidelity = 0.91314348
# T = 225   Fidelity = 0.95265702
# T = 250   Fidelity = 0.95220944
# T = 275   Fidelity = 0.94132801
# T = 300   Fidelity = 0.96791344
# T = 400   Fidelity = 0.91856422
# T = 500   Fidelity = 0.94861127
# T = 600   Fidelity = 0.88180691
# T = 700   Fidelity = 0.93665946
# T = 800   Fidelity = 0.55585172
# T = 900   Fidelity = 0.78699089
# T = 1000  Fidelity = 0.38932536
# T = 1010  Fidelity = 0.86985081
# T = 1020  Fidelity = 0.74086275
# T = 1030  Fidelity = 0.59806588
# T = 1040  Fidelity = 0.76902463
# T = 1050  Fidelity = 0.85525371
# T = 1060  Fidelity = 0.82458620
# T = 1070  Fidelity = 0.78693934
# T = 1080  Fidelity = 0.53302053
# T = 1090  Fidelity = 0.84459585
# T = 1100  Fidelity = 0.74347100
# T = 1200  Fidelity = 0.87702448
# T = 1300  Fidelity = 0.16460158
# T = 1400  Fidelity = 0.76010427
# T = 1500  Fidelity = 0.46995958
# T = 2000  Fidelity = 0.82897945
# T = 2100  Fidelity = 0.50511193
# T = 2110  Fidelity = 0.42799473
# T = 2120  Fidelity = 0.57170122
# T = 2130  Fidelity = 0.73684722
# T = 2140  Fidelity = 0.67051817
# T = 2150  Fidelity = 0.68068263
# T = 2160  Fidelity = 0.81974466
# T = 2170  Fidelity = 0.73236859
# T = 2180  Fidelity = 0.51446779
# T = 2190  Fidelity = 0.53833516
# T = 2200  Fidelity = 0.78391435
# T = 2300  Fidelity = 0.76786304
# T = 2400  Fidelity = 0.66115540
# T = 2500  Fidelity = 0.82486124
# T = 2600  Fidelity = 0.26545601
# T = 2700  Fidelity = 0.11300507
# T = 2800  Fidelity = 0.50852557
# T = 2900  Fidelity = 0.54411516
# T = 3000  Fidelity = 0.74919367
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43049943e+00
# P0     = 0.74919367
# P1     = 0.08543172
# P0+P1  = 0.83462539
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00000155
# T = 2     Fidelity = 0.00007282
# T = 5     Fidelity = 0.00176063
# T = 10    Fidelity = 0.03349372
# T = 20    Fidelity = 0.35786932
# T = 30    Fidelity = 0.61458314
# T = 40    Fidelity = 0.36336131
# T = 50    Fidelity = 0.26412237
# T = 75    Fidelity = 0.57944184
# T = 100   Fidelity = 0.44172796
# T = 125   Fidelity = 0.52885566
# T = 150   Fidelity = 0.48159700
# T = 175   Fidelity = 0.50029057
# T = 200   Fidelity = 0.47662756
# T = 225   Fidelity = 0.51530112
# T = 250   Fidelity = 0.48944548
# T = 275   Fidelity = 0.48696316
# T = 300   Fidelity = 0.51218416
# T = 400   Fidelity = 0.50796233
# T = 500   Fidelity = 0.43259932
# T = 600   Fidelity = 0.39888737
# T = 700   Fidelity = 0.27775546
# T = 800   Fidelity = 0.29502869
# T = 900   Fidelity = 0.50630939
# T = 1000  Fidelity = 0.43274359
# T = 1010  Fidelity = 0.28262768
# T = 1020  Fidelity = 0.60117809
# T = 1030  Fidelity = 0.78568032
# T = 1040  Fidelity = 0.61911318
# T = 1050  Fidelity = 0.06737811
# T = 1060  Fidelity = 0.22234168
# T = 1070  Fidelity = 0.61778891
# T = 1080  Fidelity = 0.79394879
# T = 1090  Fidelity = 0.48269622
# T = 1100  Fidelity = 0.19694383
# T = 1200  Fidelity = 0.80868924
# T = 1300  Fidelity = 0.44761024
# T = 1400  Fidelity = 0.22440594
# T = 1500  Fidelity = 0.28578239
# T = 2000  Fidelity = 0.43378650
# T = 2100  Fidelity = 0.17154104
# T = 2110  Fidelity = 0.24589418
# T = 2120  Fidelity = 0.47923668
# T = 2130  Fidelity = 0.53871297
# T = 2140  Fidelity = 0.45386938
# T = 2150  Fidelity = 0.17462596
# T = 2160  Fidelity = 0.37518092
# T = 2170  Fidelity = 0.73595539
# T = 2180  Fidelity = 0.69250348
# T = 2190  Fidelity = 0.41700043
# T = 2200  Fidelity = 0.20051511
# T = 2300  Fidelity = 0.53610010
# T = 2400  Fidelity = 0.69675003
# T = 2500  Fidelity = 0.72193198
# T = 2600  Fidelity = 0.61265596
# T = 2700  Fidelity = 0.56687445
# T = 2800  Fidelity = 0.58540706
# T = 2900  Fidelity = 0.22746552
# T = 3000  Fidelity = 0.41444477
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44121779e+00
# P0     = 0.41444477
# P1     = 0.03000212
# P0+P1  = 0.44444688
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05663390e-03
# T = 1     Fidelity = 0.00180943
# T = 2     Fidelity = 0.00875595
# T = 5     Fidelity = 0.04031238
# T = 10    Fidelity = 0.14625814
# T = 20    Fidelity = 0.35531263
# T = 30    Fidelity = 0.38155740
# T = 40    Fidelity = 0.32520124
# T = 50    Fidelity = 0.32605528
# T = 75    Fidelity = 0.55880834
# T = 100   Fidelity = 0.55996647
# T = 125   Fidelity = 0.50575844
# T = 150   Fidelity = 0.52354032
# T = 175   Fidelity = 0.52808029
# T = 200   Fidelity = 0.52065836
# T = 225   Fidelity = 0.49568570
# T = 250   Fidelity = 0.49576425
# T = 275   Fidelity = 0.49749840
# T = 300   Fidelity = 0.48303497
# T = 400   Fidelity = 0.51240321
# T = 500   Fidelity = 0.50169420
# T = 600   Fidelity = 0.55964129
# T = 700   Fidelity = 0.53694825
# T = 800   Fidelity = 0.58801281
# T = 900   Fidelity = 0.65790143
# T = 1000  Fidelity = 0.63633384
# T = 1010  Fidelity = 0.55497940
# T = 1020  Fidelity = 0.51265620
# T = 1030  Fidelity = 0.29624516
# T = 1040  Fidelity = 0.13344204
# T = 1050  Fidelity = 0.32276211
# T = 1060  Fidelity = 0.53413940
# T = 1070  Fidelity = 0.81489527
# T = 1080  Fidelity = 0.83721473
# T = 1090  Fidelity = 0.63364616
# T = 1100  Fidelity = 0.58351135
# T = 1200  Fidelity = 0.83209859
# T = 1300  Fidelity = 0.72019685
# T = 1400  Fidelity = 0.48569477
# T = 1500  Fidelity = 0.65070410
# T = 2000  Fidelity = 0.46527894
# T = 2100  Fidelity = 0.47563519
# T = 2110  Fidelity = 0.16639196
# T = 2120  Fidelity = 0.19780493
# T = 2130  Fidelity = 0.35508444
# T = 2140  Fidelity = 0.49194409
# T = 2150  Fidelity = 0.42718659
# T = 2160  Fidelity = 0.57090378
# T = 2170  Fidelity = 0.51671930
# T = 2180  Fidelity = 0.64298074
# T = 2190  Fidelity = 0.60978559
# T = 2200  Fidelity = 0.66574044
# T = 2300  Fidelity = 0.57968790
# T = 2400  Fidelity = 0.35172119
# T = 2500  Fidelity = 0.72020606
# T = 2600  Fidelity = 0.68643459
# T = 2700  Fidelity = 0.68101834
# T = 2800  Fidelity = 0.60813155
# T = 2900  Fidelity = 0.39784302
# T = 3000  Fidelity = 0.40904899
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.45168821e+00
# P0     = 0.40904899
# P1     = 0.01164858
# P0+P1  = 0.42069757
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 5.88899605e-03
# T = 1     Fidelity = 0.01683298
# T = 2     Fidelity = 0.05151853
# T = 5     Fidelity = 0.13905094
# T = 10    Fidelity = 0.31434566
# T = 20    Fidelity = 0.55033390
# T = 30    Fidelity = 0.62699131
# T = 40    Fidelity = 0.61101265
# T = 50    Fidelity = 0.57954152
# T = 75    Fidelity = 0.55886298
# T = 100   Fidelity = 0.60020444
# T = 125   Fidelity = 0.62826738
# T = 150   Fidelity = 0.63560244
# T = 175   Fidelity = 0.64415988
# T = 200   Fidelity = 0.64397593
# T = 225   Fidelity = 0.67548994
# T = 250   Fidelity = 0.68039321
# T = 275   Fidelity = 0.67202569
# T = 300   Fidelity = 0.68404871
# T = 400   Fidelity = 0.70736279
# T = 500   Fidelity = 0.60542767
# T = 600   Fidelity = 0.55942316
# T = 700   Fidelity = 0.72621176
# T = 800   Fidelity = 0.76631765
# T = 900   Fidelity = 0.58819451
# T = 1000  Fidelity = 0.64491524
# T = 1010  Fidelity = 0.71510631
# T = 1020  Fidelity = 0.81871902
# T = 1030  Fidelity = 0.82720443
# T = 1040  Fidelity = 0.75613912
# T = 1050  Fidelity = 0.67539150
# T = 1060  Fidelity = 0.62757103
# T = 1070  Fidelity = 0.53844600
# T = 1080  Fidelity = 0.48053651
# T = 1090  Fidelity = 0.56546181
# T = 1100  Fidelity = 0.67645647
# T = 1200  Fidelity = 0.52286579
# T = 1300  Fidelity = 0.67853231
# T = 1400  Fidelity = 0.73878015
# T = 1500  Fidelity = 0.85094167
# T = 2000  Fidelity = 0.80499403
# T = 2100  Fidelity = 0.68729433
# T = 2110  Fidelity = 0.69280498
# T = 2120  Fidelity = 0.61630227
# T = 2130  Fidelity = 0.63416868
# T = 2140  Fidelity = 0.68527438
# T = 2150  Fidelity = 0.87050416
# T = 2160  Fidelity = 0.87348175
# T = 2170  Fidelity = 0.85534767
# T = 2180  Fidelity = 0.76842881
# T = 2190  Fidelity = 0.63551396
# T = 2200  Fidelity = 0.63862151
# T = 2300  Fidelity = 0.66503548
# T = 2400  Fidelity = 0.71672220
# T = 2500  Fidelity = 0.78680765
# T = 2600  Fidelity = 0.40426398
# T = 2700  Fidelity = 0.82302994
# T = 2800  Fidelity = 0.60576121
# T = 2900  Fidelity = 0.72384154
# T = 3000  Fidelity = 0.81732546
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.46192674e+00
# P0     = 0.81732546
# P1     = 0.00221700
# P0+P1  = 0.81954246
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 3.15736806e-02
# T = 1     Fidelity = 0.06360454
# T = 2     Fidelity = 0.14744274
# T = 5     Fidelity = 0.29201968
# T = 10    Fidelity = 0.49789530
# T = 20    Fidelity = 0.70600468
# T = 30    Fidelity = 0.78163121
# T = 40    Fidelity = 0.79721028
# T = 50    Fidelity = 0.79495513
# T = 75    Fidelity = 0.78959710
# T = 100   Fidelity = 0.79651452
# T = 125   Fidelity = 0.80620658
# T = 150   Fidelity = 0.81384166
# T = 175   Fidelity = 0.82331931
# T = 200   Fidelity = 0.82916458
# T = 225   Fidelity = 0.83516886
# T = 250   Fidelity = 0.84629988
# T = 275   Fidelity = 0.83502921
# T = 300   Fidelity = 0.85855818
# T = 400   Fidelity = 0.85798514
# T = 500   Fidelity = 0.82493447
# T = 600   Fidelity = 0.83353728
# T = 700   Fidelity = 0.69567565
# T = 800   Fidelity = 0.93244805
# T = 900   Fidelity = 0.87084709
# T = 1000  Fidelity = 0.87103062
# T = 1010  Fidelity = 0.88469672
# T = 1020  Fidelity = 0.84341903
# T = 1030  Fidelity = 0.78478081
# T = 1040  Fidelity = 0.81712249
# T = 1050  Fidelity = 0.88084112
# T = 1060  Fidelity = 0.89102134
# T = 1070  Fidelity = 0.92611336
# T = 1080  Fidelity = 0.96650022
# T = 1090  Fidelity = 0.97759174
# T = 1100  Fidelity = 0.97806508
# T = 1200  Fidelity = 0.83701674
# T = 1300  Fidelity = 0.92397266
# T = 1400  Fidelity = 0.72159957
# T = 1500  Fidelity = 0.89039268
# T = 2000  Fidelity = 0.88128009
# T = 2100  Fidelity = 0.78969872
# T = 2110  Fidelity = 0.79085820
# T = 2120  Fidelity = 0.73341958
# T = 2130  Fidelity = 0.70566244
# T = 2140  Fidelity = 0.83676709
# T = 2150  Fidelity = 0.95907225
# T = 2160  Fidelity = 0.89159738
# T = 2170  Fidelity = 0.88426926
# T = 2180  Fidelity = 0.94184744
# T = 2190  Fidelity = 0.87868667
# T = 2200  Fidelity = 0.93883013
# T = 2300  Fidelity = 0.90399168
# T = 2400  Fidelity = 0.96117448
# T = 2500  Fidelity = 0.94085425
# T = 2600  Fidelity = 0.86815737
# T = 2700  Fidelity = 0.92447502
# T = 2800  Fidelity = 0.95704214
# T = 2900  Fidelity = 0.76136160
# T = 3000  Fidelity = 0.94985593
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.47194767e+00
# P0     = 0.94985593
# P1     = 0.00006538
# P0+P1  = 0.94992131
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.80738351e-02
# T = 1     Fidelity = 0.14356432
# T = 2     Fidelity = 0.27842780
# T = 5     Fidelity = 0.45576298
# T = 10    Fidelity = 0.65319490
# T = 20    Fidelity = 0.81523189
# T = 30    Fidelity = 0.87209368
# T = 40    Fidelity = 0.89379043
# T = 50    Fidelity = 0.90254949
# T = 75    Fidelity = 0.91317545
# T = 100   Fidelity = 0.92131180
# T = 125   Fidelity = 0.92936509
# T = 150   Fidelity = 0.93575145
# T = 175   Fidelity = 0.94382958
# T = 200   Fidelity = 0.95003509
# T = 225   Fidelity = 0.93682148
# T = 250   Fidelity = 0.94517673
# T = 275   Fidelity = 0.94892373
# T = 300   Fidelity = 0.96257425
# T = 400   Fidelity = 0.95833627
# T = 500   Fidelity = 0.93469505
# T = 600   Fidelity = 0.94624243
# T = 700   Fidelity = 0.89650476
# T = 800   Fidelity = 0.94202887
# T = 900   Fidelity = 0.93777879
# T = 1000  Fidelity = 0.92649231
# T = 1010  Fidelity = 0.97161764
# T = 1020  Fidelity = 0.97409627
# T = 1030  Fidelity = 0.94038263
# T = 1040  Fidelity = 0.96697493
# T = 1050  Fidelity = 0.98323727
# T = 1060  Fidelity = 0.98492424
# T = 1070  Fidelity = 0.98094946
# T = 1080  Fidelity = 0.98523373
# T = 1090  Fidelity = 0.92959747
# T = 1100  Fidelity = 0.96990881
# T = 1200  Fidelity = 0.93186535
# T = 1300  Fidelity = 0.95523790
# T = 1400  Fidelity = 0.91277451
# T = 1500  Fidelity = 0.96769255
# T = 2000  Fidelity = 0.91241235
# T = 2100  Fidelity = 0.92690797
# T = 2110  Fidelity = 0.92481644
# T = 2120  Fidelity = 0.88629964
# T = 2130  Fidelity = 0.94592417
# T = 2140  Fidelity = 0.90970564
# T = 2150  Fidelity = 0.93506780
# T = 2160  Fidelity = 0.91108845
# T = 2170  Fidelity = 0.94469983
# T = 2180  Fidelity = 0.89563274
# T = 2190  Fidelity = 0.94291678
# T = 2200  Fidelity = 0.89535315
# T = 2300  Fidelity = 0.96995344
# T = 2400  Fidelity = 0.89484716
# T = 2500  Fidelity = 0.95303753
# T = 2600  Fidelity = 0.94549595
# T = 2700  Fidelity = 0.93126420
# T = 2800  Fidelity = 0.93850283
# T = 2900  Fidelity = 0.95163181
# T = 3000  Fidelity = 0.90477844
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.48176382e+00
# P0     = 0.90477844
# P1     = 0.00000099
# P0+P1  = 0.90477943
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.28699899e-01
# T = 1     Fidelity = 0.23819543
# T = 2     Fidelity = 0.40973509
# T = 5     Fidelity = 0.59338519
# T = 10    Fidelity = 0.76311261
# T = 20    Fidelity = 0.88380638
# T = 30    Fidelity = 0.92425401
# T = 40    Fidelity = 0.94152385
# T = 50    Fidelity = 0.95042665
# T = 75    Fidelity = 0.96136356
# T = 100   Fidelity = 0.96919494
# T = 125   Fidelity = 0.97453284
# T = 150   Fidelity = 0.97834459
# T = 175   Fidelity = 0.98225076
# T = 200   Fidelity = 0.98475055
# T = 225   Fidelity = 0.97029564
# T = 250   Fidelity = 0.97592385
# T = 275   Fidelity = 0.97925016
# T = 300   Fidelity = 0.98566795
# T = 400   Fidelity = 0.98140540
# T = 500   Fidelity = 0.97343357
# T = 600   Fidelity = 0.91541363
# T = 700   Fidelity = 0.93516457
# T = 800   Fidelity = 0.98623059
# T = 900   Fidelity = 0.99323426
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.76942225e-01
# T = 1     Fidelity = 0.33005730
# T = 2     Fidelity = 0.52169981
# T = 5     Fidelity = 0.69583899
# T = 10    Fidelity = 0.83499788
# T = 20    Fidelity = 0.92512175
# T = 30    Fidelity = 0.95405488
# T = 40    Fidelity = 0.96588603
# T = 50    Fidelity = 0.97216628
# T = 75    Fidelity = 0.98202758
# T = 100   Fidelity = 0.98632375
# T = 125   Fidelity = 0.98955285
# T = 150   Fidelity = 0.99193796
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.20505613e-01
# T = 1     Fidelity = 0.41291910
# T = 2     Fidelity = 0.61282362
# T = 5     Fidelity = 0.77094982
# T = 10    Fidelity = 0.88309673
# T = 20    Fidelity = 0.95116156
# T = 30    Fidelity = 0.97141986
# T = 40    Fidelity = 0.97939979
# T = 50    Fidelity = 0.98442478
# T = 75    Fidelity = 0.99018968
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.06623659e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00011816
# T = 10    Fidelity = 0.00638379
# T = 20    Fidelity = 0.15729392
# T = 30    Fidelity = 0.48678949
# T = 40    Fidelity = 0.76118220
# T = 50    Fidelity = 0.90746597
# T = 75    Fidelity = 0.99417696
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.20609288e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000016
# T = 5     Fidelity = 0.00112294
# T = 10    Fidelity = 0.18600199
# T = 20    Fidelity = 0.88916690
# T = 30    Fidelity = 0.96906919
# T = 40    Fidelity = 0.99618858
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.76105909e-01
# T = 1     Fidelity = 0.00000392
# T = 2     Fidelity = 0.00014367
# T = 5     Fidelity = 0.03245907
# T = 10    Fidelity = 0.56544648
# T = 20    Fidelity = 0.90527192
# T = 30    Fidelity = 0.99234993
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.12909217e-01
# T = 1     Fidelity = 0.00019330
# T = 2     Fidelity = 0.00242489
# T = 5     Fidelity = 0.10913421
# T = 10    Fidelity = 0.69713336
# T = 20    Fidelity = 0.94968462
# T = 30    Fidelity = 0.99071509
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.40169449e-01
# T = 1     Fidelity = 0.00166646
# T = 2     Fidelity = 0.01140100
# T = 5     Fidelity = 0.20683022
# T = 10    Fidelity = 0.76572953
# T = 20    Fidelity = 0.97051132
# T = 30    Fidelity = 0.99050823
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.61748289e-01
# T = 1     Fidelity = 0.00651372
# T = 2     Fidelity = 0.03003991
# T = 5     Fidelity = 0.30222410
# T = 10    Fidelity = 0.80550806
# T = 20    Fidelity = 0.97924725
# T = 30    Fidelity = 0.99011807
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.79340685e-01
# T = 1     Fidelity = 0.01678345
# T = 2     Fidelity = 0.05954682
# T = 5     Fidelity = 0.39476777
# T = 10    Fidelity = 0.83578647
# T = 20    Fidelity = 0.98449188
# T = 30    Fidelity = 0.99122301
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.94021606e-01
# T = 1     Fidelity = 0.03347643
# T = 2     Fidelity = 0.09736389
# T = 5     Fidelity = 0.47336029
# T = 10    Fidelity = 0.85658347
# T = 20    Fidelity = 0.98590678
# T = 30    Fidelity = 0.99164744
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.06402712e-01
# T = 1     Fidelity = 0.05658012
# T = 2     Fidelity = 0.14151359
# T = 5     Fidelity = 0.54226779
# T = 10    Fidelity = 0.87424394
# T = 20    Fidelity = 0.98628407
# T = 30    Fidelity = 0.99220521
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.17036009e-01
# T = 1     Fidelity = 0.08549633
# T = 2     Fidelity = 0.18987216
# T = 5     Fidelity = 0.60214924
# T = 10    Fidelity = 0.88955538
# T = 20    Fidelity = 0.98627277
# T = 30    Fidelity = 0.99274162
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9933404708      1.01220263e+00    None        None        None
# Symmetric      0.311     2         0.9942173532      1.03626623e+00    None        None        None
# Symmetric      0.522     2         0.9949107274      1.05846299e+00    None        None        None
# Symmetric      0.733     2         0.9954706694      1.07916278e+00    None        None        None
# Symmetric      0.944     2         0.9959169945      1.09862393e+00    None        None        None
# Symmetric      1.156     2         0.9962953259      1.11703633e+00    None        None        None
# Symmetric      1.367     2         0.9966063099      1.13454489e+00    None        None        None
# Symmetric      1.578     2         0.9968651416      1.15126343e+00    None        None        None
# Symmetric      1.789     2         0.9970846974      1.16728342e+00    None        None        None
# Symmetric      2.000     2         0.9972763392      1.18267976e+00    None        None        None
# Weak SSB optimised0.100     None      0.9309656319      2.43127858e-01    0.918074    0.009253    0.927327
# Weak SSB optimised0.311     None      0.9692867078      2.61673084e-01    0.871357    0.037641    0.908997
# Weak SSB optimised0.522     250       0.9914560565      2.64768458e-01    None        None        None
# Weak SSB optimised0.733     200       0.9927856441      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     175       0.9932740697      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     150       0.9949072784      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     175       0.9920864145      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     175       0.9924692153      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9907280627      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     100       0.9922313125      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9685276398      1.40037050e-03    0.91276     0.019135    0.931896
# Weak SSB       0.311     None      0.9679134376      1.13564004e-03    0.749194    0.085432    0.834625
# Weak SSB       0.522     None      0.8086892366      1.05614584e-03    0.414445    0.030002    0.444447
# Weak SSB       0.733     None      0.8372147255      1.05663390e-03    0.409049    0.011649    0.420698
# Weak SSB       0.944     None      0.8734817505      5.88899605e-03    0.817325    0.002217    0.819542
# Weak SSB       1.156     None      0.9780650761      3.15736806e-02    0.949856    6.5e-05     0.949921
# Weak SSB       1.367     None      0.9852337321      7.80738351e-02    0.904778    1e-06       0.904779
# Weak SSB       1.578     900       0.9932342639      1.28699899e-01    None        None        None
# Weak SSB       1.789     150       0.9919379581      1.76942225e-01    None        None        None
# Weak SSB       2.000     75        0.9901896846      2.20505613e-01    None        None        None
# Strong SSB     0.100     75        0.9941769620      6.06623659e-01    None        None        None
# Strong SSB     0.311     40        0.9961885828      7.20609288e-01    None        None        None
# Strong SSB     0.522     30        0.9923499290      7.76105909e-01    None        None        None
# Strong SSB     0.733     30        0.9907150875      8.12909217e-01    None        None        None
# Strong SSB     0.944     30        0.9905082340      8.40169449e-01    None        None        None
# Strong SSB     1.156     30        0.9901180733      8.61748289e-01    None        None        None
# Strong SSB     1.367     30        0.9912230132      8.79340685e-01    None        None        None
# Strong SSB     1.578     30        0.9916474373      8.94021606e-01    None        None        None
# Strong SSB     1.789     30        0.9922052065      9.06402712e-01    None        None        None
# Strong SSB     2.000     30        0.9927416194      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap,  $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009558
# T = 10    Fidelity = 0.00119283
# T = 20    Fidelity = 0.02688101
# T = 30    Fidelity = 0.09665967
# T = 40    Fidelity = 0.19607214
# T = 50    Fidelity = 0.31172404
# T = 75    Fidelity = 0.56616443
# T = 100   Fidelity = 0.71998423
# T = 125   Fidelity = 0.80735968
# T = 150   Fidelity = 0.86468343
# T = 175   Fidelity = 0.90863849
# T = 200   Fidelity = 0.94629672
# T = 225   Fidelity = 0.96687483
# T = 250   Fidelity = 0.95353017
# T = 275   Fidelity = 0.98205315
# T = 300   Fidelity = 0.96283431
# T = 400   Fidelity = 0.95497818
# T = 500   Fidelity = 0.93801461
# T = 600   Fidelity = 0.90704933
# T = 700   Fidelity = 0.99336631
#
# Minimum T for Fidelity >= 0.99 : 700
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624068e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144461
# T = 10    Fidelity = 0.10201747
# T = 20    Fidelity = 0.52978825
# T = 30    Fidelity = 0.63897018
# T = 40    Fidelity = 0.76793409
# T = 50    Fidelity = 0.88383649
# T = 75    Fidelity = 0.94227186
# T = 100   Fidelity = 0.97306088
# T = 125   Fidelity = 0.99693193
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043128e-07
# T = 1     Fidelity = 0.00005023
# T = 2     Fidelity = 0.00043645
# T = 5     Fidelity = 0.02724432
# T = 10    Fidelity = 0.28404337
# T = 20    Fidelity = 0.77881465
# T = 30    Fidelity = 0.80542868
# T = 40    Fidelity = 0.95120125
# T = 50    Fidelity = 0.93700956
# T = 75    Fidelity = 0.99144552
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155046
# T = 2     Fidelity = 0.00639352
# T = 5     Fidelity = 0.08480032
# T = 10    Fidelity = 0.38785488
# T = 20    Fidelity = 0.90882380
# T = 30    Fidelity = 0.89422604
# T = 40    Fidelity = 0.97222667
# T = 50    Fidelity = 0.99231720
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01058014
# T = 2     Fidelity = 0.02893146
# T = 5     Fidelity = 0.16449192
# T = 10    Fidelity = 0.46787111
# T = 20    Fidelity = 0.92253792
# T = 30    Fidelity = 0.97977922
# T = 40    Fidelity = 0.97236923
# T = 50    Fidelity = 0.99387831
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03667391
# T = 2     Fidelity = 0.07740205
# T = 5     Fidelity = 0.25991777
# T = 10    Fidelity = 0.54100645
# T = 20    Fidelity = 0.90448871
# T = 30    Fidelity = 0.99651401
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08776170
# T = 2     Fidelity = 0.15530990
# T = 5     Fidelity = 0.36741062
# T = 10    Fidelity = 0.61609979
# T = 20    Fidelity = 0.89396384
# T = 30    Fidelity = 0.98167409
# T = 40    Fidelity = 0.99755695
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16578725
# T = 2     Fidelity = 0.25895577
# T = 5     Fidelity = 0.48156511
# T = 10    Fidelity = 0.69440164
# T = 20    Fidelity = 0.90353476
# T = 30    Fidelity = 0.97294062
# T = 40    Fidelity = 0.99115200
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26391923
# T = 2     Fidelity = 0.37663062
# T = 5     Fidelity = 0.59258134
# T = 10    Fidelity = 0.76993232
# T = 20    Fidelity = 0.92535147
# T = 30    Fidelity = 0.97251174
# T = 40    Fidelity = 0.98679989
# T = 50    Fidelity = 0.99322870
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36881272
# T = 2     Fidelity = 0.49275162
# T = 5     Fidelity = 0.69002225
# T = 10    Fidelity = 0.83497025
# T = 20    Fidelity = 0.94706295
# T = 30    Fidelity = 0.97597142
# T = 40    Fidelity = 0.98837657
# T = 50    Fidelity = 0.99291520
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.62211341
# T = 2     Fidelity = 0.65092262
# T = 5     Fidelity = 0.70750310
# T = 10    Fidelity = 0.76223648
# T = 20    Fidelity = 0.82880560
# T = 30    Fidelity = 0.86955550
# T = 40    Fidelity = 0.89797263
# T = 50    Fidelity = 0.91822865
# T = 75    Fidelity = 0.94947314
# T = 100   Fidelity = 0.96634788
# T = 125   Fidelity = 0.97472365
# T = 150   Fidelity = 0.98089884
# T = 175   Fidelity = 0.98178404
# T = 200   Fidelity = 0.98725122
# T = 225   Fidelity = 0.97853658
# T = 250   Fidelity = 0.98550779
# T = 275   Fidelity = 0.95565698
# T = 300   Fidelity = 0.93877951
# T = 400   Fidelity = 0.97097157
# T = 500   Fidelity = 0.97604948
# T = 600   Fidelity = 0.94365083
# T = 700   Fidelity = 0.81194032
# T = 800   Fidelity = 0.94248726
# T = 900   Fidelity = 0.98443597
# T = 1000  Fidelity = 0.97574030
# T = 1010  Fidelity = 0.95568719
# T = 1020  Fidelity = 0.94291644
# T = 1030  Fidelity = 0.95698859
# T = 1040  Fidelity = 0.96834052
# T = 1050  Fidelity = 0.96520123
# T = 1060  Fidelity = 0.96736867
# T = 1070  Fidelity = 0.97124743
# T = 1080  Fidelity = 0.98802056
# T = 1090  Fidelity = 0.99143898
#
# Minimum T for Fidelity >= 0.99 : 1090
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.73487816
# T = 2     Fidelity = 0.74465573
# T = 5     Fidelity = 0.77454291
# T = 10    Fidelity = 0.80653712
# T = 20    Fidelity = 0.84370629
# T = 30    Fidelity = 0.86707775
# T = 40    Fidelity = 0.88378253
# T = 50    Fidelity = 0.89681679
# T = 75    Fidelity = 0.91990839
# T = 100   Fidelity = 0.93553337
# T = 125   Fidelity = 0.94638321
# T = 150   Fidelity = 0.95358578
# T = 175   Fidelity = 0.96254598
# T = 200   Fidelity = 0.96425784
# T = 225   Fidelity = 0.96734780
# T = 250   Fidelity = 0.96872915
# T = 275   Fidelity = 0.97019370
# T = 300   Fidelity = 0.97302083
# T = 400   Fidelity = 0.97941744
# T = 500   Fidelity = 0.96496331
# T = 600   Fidelity = 0.96301767
# T = 700   Fidelity = 0.98143347
# T = 800   Fidelity = 0.93129405
# T = 900   Fidelity = 0.91493200
# T = 1000  Fidelity = 0.92557286
# T = 1010  Fidelity = 0.92598321
# T = 1020  Fidelity = 0.92482727
# T = 1030  Fidelity = 0.92343951
# T = 1040  Fidelity = 0.91975086
# T = 1050  Fidelity = 0.91846024
# T = 1060  Fidelity = 0.91740271
# T = 1070  Fidelity = 0.91854907
# T = 1080  Fidelity = 0.91703540
# T = 1090  Fidelity = 0.91946662
# T = 1100  Fidelity = 0.91810585
# T = 1200  Fidelity = 0.94099854
# T = 1300  Fidelity = 0.96698279
# T = 1400  Fidelity = 0.97302710
# T = 1500  Fidelity = 0.96885732
# T = 2000  Fidelity = 0.94302363
# T = 2100  Fidelity = 0.95210392
# T = 2110  Fidelity = 0.95323988
# T = 2120  Fidelity = 0.95384041
# T = 2130  Fidelity = 0.95563201
# T = 2140  Fidelity = 0.95334999
# T = 2150  Fidelity = 0.95366443
# T = 2160  Fidelity = 0.94952174
# T = 2170  Fidelity = 0.94712313
# T = 2180  Fidelity = 0.94150613
# T = 2190  Fidelity = 0.94033271
# T = 2200  Fidelity = 0.93931791
# T = 2300  Fidelity = 0.92189868
# T = 2400  Fidelity = 0.97767114
# T = 2500  Fidelity = 0.97806046
# T = 2600  Fidelity = 0.95454872
# T = 2700  Fidelity = 0.94218279
# T = 2800  Fidelity = 0.92909466
# T = 2900  Fidelity = 0.93414692
# T = 3000  Fidelity = 0.94999713
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.71621181e-01
# P0     = 0.94999713
# P1     = 0.03023089
# P0+P1  = 0.98022802
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.99090836
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98785126
# T = 2     Fidelity = 0.99684757
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97983390
# T = 2     Fidelity = 0.99130694
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.95037598
# T = 2     Fidelity = 0.96644167
# T = 5     Fidelity = 0.97799835
# T = 10    Fidelity = 0.98185371
# T = 20    Fidelity = 0.98555645
# T = 30    Fidelity = 0.98808730
# T = 40    Fidelity = 0.98938766
# T = 50    Fidelity = 0.99039354
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.88003398
# T = 2     Fidelity = 0.90280824
# T = 5     Fidelity = 0.92693430
# T = 10    Fidelity = 0.93700386
# T = 20    Fidelity = 0.95130271
# T = 30    Fidelity = 0.95788299
# T = 40    Fidelity = 0.96356758
# T = 50    Fidelity = 0.96703321
# T = 75    Fidelity = 0.97389157
# T = 100   Fidelity = 0.97856169
# T = 125   Fidelity = 0.98175624
# T = 150   Fidelity = 0.98409716
# T = 175   Fidelity = 0.98602874
# T = 200   Fidelity = 0.98737941
# T = 225   Fidelity = 0.98861000
# T = 250   Fidelity = 0.98972257
# T = 275   Fidelity = 0.99066543
#
# Minimum T for Fidelity >= 0.99 : 275
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78863798
# T = 2     Fidelity = 0.81881036
# T = 5     Fidelity = 0.85744643
# T = 10    Fidelity = 0.87914721
# T = 20    Fidelity = 0.91048860
# T = 30    Fidelity = 0.92472615
# T = 40    Fidelity = 0.93535892
# T = 50    Fidelity = 0.94377710
# T = 75    Fidelity = 0.95751708
# T = 100   Fidelity = 0.96642817
# T = 125   Fidelity = 0.97257592
# T = 150   Fidelity = 0.97699432
# T = 175   Fidelity = 0.98058280
# T = 200   Fidelity = 0.98293309
# T = 225   Fidelity = 0.98489495
# T = 250   Fidelity = 0.98689321
# T = 275   Fidelity = 0.98828721
# T = 300   Fidelity = 0.98955431
# T = 400   Fidelity = 0.99261429
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.71987716
# T = 2     Fidelity = 0.75647668
# T = 5     Fidelity = 0.80689570
# T = 10    Fidelity = 0.84312959
# T = 20    Fidelity = 0.89160311
# T = 30    Fidelity = 0.91308244
# T = 40    Fidelity = 0.93004185
# T = 50    Fidelity = 0.93973255
# T = 75    Fidelity = 0.95855341
# T = 100   Fidelity = 0.96982873
# T = 125   Fidelity = 0.97708073
# T = 150   Fidelity = 0.98197702
# T = 175   Fidelity = 0.98542983
# T = 200   Fidelity = 0.98775345
# T = 225   Fidelity = 0.98955228
# T = 250   Fidelity = 0.99101352
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.69316297
# T = 2     Fidelity = 0.73533026
# T = 5     Fidelity = 0.79375985
# T = 10    Fidelity = 0.84128550
# T = 20    Fidelity = 0.90385146
# T = 30    Fidelity = 0.92739787
# T = 40    Fidelity = 0.94598920
# T = 50    Fidelity = 0.95681142
# T = 75    Fidelity = 0.97346223
# T = 100   Fidelity = 0.98228844
# T = 125   Fidelity = 0.98745751
# T = 150   Fidelity = 0.99066504
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.35126357e-02
# T = 1     Fidelity = 0.59202005
# T = 2     Fidelity = 0.63710757
# T = 5     Fidelity = 0.71827144
# T = 10    Fidelity = 0.79552463
# T = 20    Fidelity = 0.87713782
# T = 30    Fidelity = 0.91984054
# T = 40    Fidelity = 0.94500771
# T = 50    Fidelity = 0.96050070
# T = 75    Fidelity = 0.97944461
# T = 100   Fidelity = 0.98527227
# T = 125   Fidelity = 0.98641473
# T = 150   Fidelity = 0.98959207
# T = 175   Fidelity = 0.98861291
# T = 200   Fidelity = 0.97818144
# T = 225   Fidelity = 0.99174788
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.91075005e-03
# T = 1     Fidelity = 0.44015832
# T = 2     Fidelity = 0.45327362
# T = 5     Fidelity = 0.49386776
# T = 10    Fidelity = 0.54500680
# T = 20    Fidelity = 0.61072749
# T = 30    Fidelity = 0.65619810
# T = 40    Fidelity = 0.69099855
# T = 50    Fidelity = 0.71886197
# T = 75    Fidelity = 0.76974082
# T = 100   Fidelity = 0.80335630
# T = 125   Fidelity = 0.82866004
# T = 150   Fidelity = 0.84660471
# T = 175   Fidelity = 0.85760797
# T = 200   Fidelity = 0.87679655
# T = 225   Fidelity = 0.88279474
# T = 250   Fidelity = 0.88881270
# T = 275   Fidelity = 0.88170926
# T = 300   Fidelity = 0.89497548
# T = 400   Fidelity = 0.91984235
# T = 500   Fidelity = 0.94299420
# T = 600   Fidelity = 0.95054544
# T = 700   Fidelity = 0.79589346
# T = 800   Fidelity = 0.77423183
# T = 900   Fidelity = 0.83767245
# T = 1000  Fidelity = 0.91634541
# T = 1010  Fidelity = 0.90090533
# T = 1020  Fidelity = 0.89157645
# T = 1030  Fidelity = 0.90680879
# T = 1040  Fidelity = 0.93269085
# T = 1050  Fidelity = 0.94415938
# T = 1060  Fidelity = 0.93639085
# T = 1070  Fidelity = 0.91860722
# T = 1080  Fidelity = 0.90494899
# T = 1090  Fidelity = 0.89553440
# T = 1100  Fidelity = 0.90940009
# T = 1200  Fidelity = 0.92822907
# T = 1300  Fidelity = 0.94969681
# T = 1400  Fidelity = 0.97427427
# T = 1500  Fidelity = 0.87136399
# T = 2000  Fidelity = 0.85839300
# T = 2100  Fidelity = 0.93731358
# T = 2110  Fidelity = 0.93744346
# T = 2120  Fidelity = 0.94911099
# T = 2130  Fidelity = 0.96316257
# T = 2140  Fidelity = 0.97594341
# T = 2150  Fidelity = 0.98702240
# T = 2160  Fidelity = 0.99175822
#
# Minimum T for Fidelity >= 0.99 : 2160
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.25232247
# T = 2     Fidelity = 0.25421211
# T = 5     Fidelity = 0.25467971
# T = 10    Fidelity = 0.25486477
# T = 20    Fidelity = 0.25491496
# T = 30    Fidelity = 0.25494690
# T = 40    Fidelity = 0.25502858
# T = 50    Fidelity = 0.25507597
# T = 75    Fidelity = 0.25526602
# T = 100   Fidelity = 0.25539934
# T = 125   Fidelity = 0.25539251
# T = 150   Fidelity = 0.25539013
# T = 175   Fidelity = 0.25376687
# T = 200   Fidelity = 0.25623646
# T = 225   Fidelity = 0.25403597
# T = 250   Fidelity = 0.25583808
# T = 275   Fidelity = 0.25560949
# T = 300   Fidelity = 0.25602200
# T = 400   Fidelity = 0.25422281
# T = 500   Fidelity = 0.25580767
# T = 600   Fidelity = 0.25586661
# T = 700   Fidelity = 0.25960120
# T = 800   Fidelity = 0.25732186
# T = 900   Fidelity = 0.25247554
# T = 1000  Fidelity = 0.25697462
# T = 1010  Fidelity = 0.25839563
# T = 1020  Fidelity = 0.25424998
# T = 1030  Fidelity = 0.25792228
# T = 1040  Fidelity = 0.25923673
# T = 1050  Fidelity = 0.25889103
# T = 1060  Fidelity = 0.25576097
# T = 1070  Fidelity = 0.25482710
# T = 1080  Fidelity = 0.25604627
# T = 1090  Fidelity = 0.25435153
# T = 1100  Fidelity = 0.25398163
# T = 1200  Fidelity = 0.25622292
# T = 1300  Fidelity = 0.25785601
# T = 1400  Fidelity = 0.25718706
# T = 1500  Fidelity = 0.25683903
# T = 2000  Fidelity = 0.25708421
# T = 2100  Fidelity = 0.25749156
# T = 2110  Fidelity = 0.25543632
# T = 2120  Fidelity = 0.25568585
# T = 2130  Fidelity = 0.25764428
# T = 2140  Fidelity = 0.25641895
# T = 2150  Fidelity = 0.25840797
# T = 2160  Fidelity = 0.25632420
# T = 2170  Fidelity = 0.25741921
# T = 2180  Fidelity = 0.25613964
# T = 2190  Fidelity = 0.25686831
# T = 2200  Fidelity = 0.25791967
# T = 2300  Fidelity = 0.25693015
# T = 2400  Fidelity = 0.25512964
# T = 2500  Fidelity = 0.25801151
# T = 2600  Fidelity = 0.25868344
# T = 2700  Fidelity = 0.25621838
# T = 2800  Fidelity = 0.25574267
# T = 2900  Fidelity = 0.25292027
# T = 3000  Fidelity = 0.25224402
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.29930120e-03
# P0     = 0.25224402
# P1     = 0.24724411
# P0+P1  = 0.49948813
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05944621e-03
# T = 1     Fidelity = 0.25693131
# T = 2     Fidelity = 0.26024162
# T = 5     Fidelity = 0.26222066
# T = 10    Fidelity = 0.26273809
# T = 20    Fidelity = 0.26404709
# T = 30    Fidelity = 0.26452393
# T = 40    Fidelity = 0.26500480
# T = 50    Fidelity = 0.26561714
# T = 75    Fidelity = 0.26657024
# T = 100   Fidelity = 0.26726072
# T = 125   Fidelity = 0.26786533
# T = 150   Fidelity = 0.26847761
# T = 175   Fidelity = 0.26834190
# T = 200   Fidelity = 0.26911977
# T = 225   Fidelity = 0.26986387
# T = 250   Fidelity = 0.27015857
# T = 275   Fidelity = 0.27012255
# T = 300   Fidelity = 0.27217067
# T = 400   Fidelity = 0.27233957
# T = 500   Fidelity = 0.27503504
# T = 600   Fidelity = 0.27639329
# T = 700   Fidelity = 0.27479977
# T = 800   Fidelity = 0.27772219
# T = 900   Fidelity = 0.27448058
# T = 1000  Fidelity = 0.27810692
# T = 1010  Fidelity = 0.27491765
# T = 1020  Fidelity = 0.27280096
# T = 1030  Fidelity = 0.28369335
# T = 1040  Fidelity = 0.27335572
# T = 1050  Fidelity = 0.28512435
# T = 1060  Fidelity = 0.28296711
# T = 1070  Fidelity = 0.28005307
# T = 1080  Fidelity = 0.27751886
# T = 1090  Fidelity = 0.27783425
# T = 1100  Fidelity = 0.27942889
# T = 1200  Fidelity = 0.27937050
# T = 1300  Fidelity = 0.27927947
# T = 1400  Fidelity = 0.27762774
# T = 1500  Fidelity = 0.27781019
# T = 2000  Fidelity = 0.29150019
# T = 2100  Fidelity = 0.28814280
# T = 2110  Fidelity = 0.28557831
# T = 2120  Fidelity = 0.28986469
# T = 2130  Fidelity = 0.29298466
# T = 2140  Fidelity = 0.29331843
# T = 2150  Fidelity = 0.29230971
# T = 2160  Fidelity = 0.29003542
# T = 2170  Fidelity = 0.28855485
# T = 2180  Fidelity = 0.28820418
# T = 2190  Fidelity = 0.28712534
# T = 2200  Fidelity = 0.28822541
# T = 2300  Fidelity = 0.28693816
# T = 2400  Fidelity = 0.28836656
# T = 2500  Fidelity = 0.28783449
# T = 2600  Fidelity = 0.29068872
# T = 2700  Fidelity = 0.28908686
# T = 2800  Fidelity = 0.28544922
# T = 2900  Fidelity = 0.28375153
# T = 3000  Fidelity = 0.28385052
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.07434343e-03
# P0     = 0.28385052
# P1     = 0.25374609
# P0+P1  = 0.53759660
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.57867035e-04
# T = 1     Fidelity = 0.31256050
# T = 2     Fidelity = 0.32049092
# T = 5     Fidelity = 0.33016443
# T = 10    Fidelity = 0.33409340
# T = 20    Fidelity = 0.33936526
# T = 30    Fidelity = 0.34414751
# T = 40    Fidelity = 0.34771012
# T = 50    Fidelity = 0.35012423
# T = 75    Fidelity = 0.35645697
# T = 100   Fidelity = 0.36124208
# T = 125   Fidelity = 0.36518392
# T = 150   Fidelity = 0.36892218
# T = 175   Fidelity = 0.37249823
# T = 200   Fidelity = 0.37543154
# T = 225   Fidelity = 0.37815986
# T = 250   Fidelity = 0.38109277
# T = 275   Fidelity = 0.38372859
# T = 300   Fidelity = 0.38633150
# T = 400   Fidelity = 0.39582370
# T = 500   Fidelity = 0.40387077
# T = 600   Fidelity = 0.41946620
# T = 700   Fidelity = 0.42310283
# T = 800   Fidelity = 0.43015098
# T = 900   Fidelity = 0.42470588
# T = 1000  Fidelity = 0.44186951
# T = 1010  Fidelity = 0.44449901
# T = 1020  Fidelity = 0.44563679
# T = 1030  Fidelity = 0.44764506
# T = 1040  Fidelity = 0.44993972
# T = 1050  Fidelity = 0.45004028
# T = 1060  Fidelity = 0.44863477
# T = 1070  Fidelity = 0.45484974
# T = 1080  Fidelity = 0.45791435
# T = 1090  Fidelity = 0.45964545
# T = 1100  Fidelity = 0.45268301
# T = 1200  Fidelity = 0.44167962
# T = 1300  Fidelity = 0.44441146
# T = 1400  Fidelity = 0.46572783
# T = 1500  Fidelity = 0.47781677
# T = 2000  Fidelity = 0.48551713
# T = 2100  Fidelity = 0.48701564
# T = 2110  Fidelity = 0.48441730
# T = 2120  Fidelity = 0.48465067
# T = 2130  Fidelity = 0.48057359
# T = 2140  Fidelity = 0.48624460
# T = 2150  Fidelity = 0.47990390
# T = 2160  Fidelity = 0.48128670
# T = 2170  Fidelity = 0.48671211
# T = 2180  Fidelity = 0.49086783
# T = 2190  Fidelity = 0.49851445
# T = 2200  Fidelity = 0.50638219
# T = 2300  Fidelity = 0.51752842
# T = 2400  Fidelity = 0.53720561
# T = 2500  Fidelity = 0.54233769
# T = 2600  Fidelity = 0.55020614
# T = 2700  Fidelity = 0.57950964
# T = 2800  Fidelity = 0.57844851
# T = 2900  Fidelity = 0.59115010
# T = 3000  Fidelity = 0.58450354
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.57706167e-04
# P0     = 0.58450354
# P1     = 0.20164027
# P0+P1  = 0.78614381
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.03605669e-03
# T = 1     Fidelity = 0.47344129
# T = 2     Fidelity = 0.49468893
# T = 5     Fidelity = 0.52682743
# T = 10    Fidelity = 0.54294419
# T = 20    Fidelity = 0.56962544
# T = 30    Fidelity = 0.58567706
# T = 40    Fidelity = 0.60093566
# T = 50    Fidelity = 0.61133585
# T = 75    Fidelity = 0.63531814
# T = 100   Fidelity = 0.65478281
# T = 125   Fidelity = 0.67039265
# T = 150   Fidelity = 0.68414631
# T = 175   Fidelity = 0.69693974
# T = 200   Fidelity = 0.70805936
# T = 225   Fidelity = 0.71818300
# T = 250   Fidelity = 0.72791347
# T = 275   Fidelity = 0.73673311
# T = 300   Fidelity = 0.74522923
# T = 400   Fidelity = 0.77393976
# T = 500   Fidelity = 0.79753794
# T = 600   Fidelity = 0.80418437
# T = 700   Fidelity = 0.82945687
# T = 800   Fidelity = 0.85902040
# T = 900   Fidelity = 0.87919442
# T = 1000  Fidelity = 0.87799433
# T = 1010  Fidelity = 0.88522956
# T = 1020  Fidelity = 0.89144244
# T = 1030  Fidelity = 0.89791115
# T = 1040  Fidelity = 0.90183625
# T = 1050  Fidelity = 0.90318961
# T = 1060  Fidelity = 0.90193768
# T = 1070  Fidelity = 0.89948680
# T = 1080  Fidelity = 0.89706594
# T = 1090  Fidelity = 0.89407686
# T = 1100  Fidelity = 0.89013400
# T = 1200  Fidelity = 0.88210056
# T = 1300  Fidelity = 0.93495211
# T = 1400  Fidelity = 0.91174294
# T = 1500  Fidelity = 0.88343938
# T = 2000  Fidelity = 0.92408573
# T = 2100  Fidelity = 0.89543845
# T = 2110  Fidelity = 0.89382830
# T = 2120  Fidelity = 0.88567980
# T = 2130  Fidelity = 0.88195584
# T = 2140  Fidelity = 0.88954658
# T = 2150  Fidelity = 0.90118138
# T = 2160  Fidelity = 0.90669131
# T = 2170  Fidelity = 0.90540167
# T = 2180  Fidelity = 0.90229909
# T = 2190  Fidelity = 0.90360483
# T = 2200  Fidelity = 0.91067223
# T = 2300  Fidelity = 0.91135715
# T = 2400  Fidelity = 0.93154681
# T = 2500  Fidelity = 0.96638955
# T = 2600  Fidelity = 0.96637915
# T = 2700  Fidelity = 0.98548485
# T = 2800  Fidelity = 0.99753006
#
# Minimum T for Fidelity >= 0.99 : 2800
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.34955504e-03
# T = 1     Fidelity = 0.51036257
# T = 2     Fidelity = 0.54345648
# T = 5     Fidelity = 0.59712294
# T = 10    Fidelity = 0.63027393
# T = 20    Fidelity = 0.68216223
# T = 30    Fidelity = 0.71508629
# T = 40    Fidelity = 0.73726516
# T = 50    Fidelity = 0.75692225
# T = 75    Fidelity = 0.79596588
# T = 100   Fidelity = 0.82420356
# T = 125   Fidelity = 0.84587499
# T = 150   Fidelity = 0.86366539
# T = 175   Fidelity = 0.87878299
# T = 200   Fidelity = 0.89132923
# T = 225   Fidelity = 0.90218110
# T = 250   Fidelity = 0.91109206
# T = 275   Fidelity = 0.91947597
# T = 300   Fidelity = 0.92684401
# T = 400   Fidelity = 0.94811871
# T = 500   Fidelity = 0.96150187
# T = 600   Fidelity = 0.97033897
# T = 700   Fidelity = 0.96750732
# T = 800   Fidelity = 0.98537502
# T = 900   Fidelity = 0.98845820
# T = 1000  Fidelity = 0.99400384
#
# Minimum T for Fidelity >= 0.99 : 1000
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.92117516e-02
# T = 1     Fidelity = 0.54943794
# T = 2     Fidelity = 0.59333101
# T = 5     Fidelity = 0.66450258
# T = 10    Fidelity = 0.71997418
# T = 20    Fidelity = 0.78257897
# T = 30    Fidelity = 0.82297357
# T = 40    Fidelity = 0.85184645
# T = 50    Fidelity = 0.87324622
# T = 75    Fidelity = 0.90854658
# T = 100   Fidelity = 0.93098779
# T = 125   Fidelity = 0.94632785
# T = 150   Fidelity = 0.95731813
# T = 175   Fidelity = 0.96527211
# T = 200   Fidelity = 0.97135322
# T = 225   Fidelity = 0.97584122
# T = 250   Fidelity = 0.97965506
# T = 275   Fidelity = 0.98256538
# T = 300   Fidelity = 0.98507253
# T = 400   Fidelity = 0.99066644
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 3.87769083e-02
# T = 1     Fidelity = 0.60017493
# T = 2     Fidelity = 0.65325607
# T = 5     Fidelity = 0.73582467
# T = 10    Fidelity = 0.80599399
# T = 20    Fidelity = 0.86819609
# T = 30    Fidelity = 0.90327736
# T = 40    Fidelity = 0.92612308
# T = 50    Fidelity = 0.94210897
# T = 75    Fidelity = 0.96455111
# T = 100   Fidelity = 0.97686130
# T = 125   Fidelity = 0.98398498
# T = 150   Fidelity = 0.98818134
# T = 175   Fidelity = 0.99059405
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 6.53490673e-02
# T = 1     Fidelity = 0.65427155
# T = 2     Fidelity = 0.71392200
# T = 5     Fidelity = 0.80123060
# T = 10    Fidelity = 0.87223440
# T = 20    Fidelity = 0.92459586
# T = 30    Fidelity = 0.95034131
# T = 40    Fidelity = 0.96543303
# T = 50    Fidelity = 0.97500354
# T = 75    Fidelity = 0.98639036
# T = 100   Fidelity = 0.99178369
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99428023
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.99426405
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.42665601e+00
# T = 1     Fidelity = 0.99371255
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41121208e+00
# T = 1     Fidelity = 0.99394397
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.99330264
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.99238320
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99121802
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98986444
# T = 2     Fidelity = 0.99686182
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98831201
# T = 2     Fidelity = 0.99604342
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98654244
# T = 2     Fidelity = 0.99506125
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     700       0.9933663131      2.15534848e-04    None        None        None
# Symmetric      0.311     125       0.9969319252      1.15624068e-06    None        None        None
# Symmetric      0.522     75        0.9914455181      3.42043128e-07    None        None        None
# Symmetric      0.733     50        0.9923172006      1.41278093e-05    None        None        None
# Symmetric      0.944     50        0.9938783136      3.35131121e-04    None        None        None
# Symmetric      1.156     30        0.9965140059      2.39158790e-03    None        None        None
# Symmetric      1.367     40        0.9975569511      8.93695212e-03    None        None        None
# Symmetric      1.578     40        0.9911519971      2.26116126e-02    None        None        None
# Symmetric      1.789     50        0.9932286974      4.43232760e-02    None        None        None
# Symmetric      2.000     50        0.9929152015      7.29248761e-02    None        None        None
# Weak SSB optimised0.100     1090      0.9914389821      8.65519637e-01    None        None        None
# Weak SSB optimised0.311     None      0.9814334704      5.19764834e-01    0.949997    0.030231    0.980228
# Weak SSB optimised0.522     1         0.9909083611      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     2         0.9968475710      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     2         0.9913069368      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     50        0.9903935368      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     275       0.9906654327      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     400       0.9926142942      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     250       0.9910135152      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     150       0.9906650376      2.54594564e-01    None        None        None
# Weak SSB       0.100     225       0.9917478836      1.35126357e-02    None        None        None
# Weak SSB       0.311     2160      0.9917582226      2.91075005e-03    None        None        None
# Weak SSB       0.522     None      0.2596011983      1.05614584e-03    0.252244    0.247244    0.499488
# Weak SSB       0.733     None      0.2933184338      1.05944621e-03    0.283851    0.253746    0.537597
# Weak SSB       0.944     None      0.5911500986      9.57867035e-04    0.584504    0.20164     0.786144
# Weak SSB       1.156     2800      0.9975300590      2.03605669e-03    None        None        None
# Weak SSB       1.367     1000      0.9940038396      7.34955504e-03    None        None        None
# Weak SSB       1.578     400       0.9906664448      1.92117516e-02    None        None        None
# Weak SSB       1.789     175       0.9905940520      3.87769083e-02    None        None        None
# Weak SSB       2.000     100       0.9917836928      6.53490673e-02    None        None        None
# Strong SSB     0.100     1         0.9942802318      3.59472102e+00    None        None        None
# Strong SSB     0.311     1         0.9942640536      1.58498916e+00    None        None        None
# Strong SSB     0.522     1         0.9937125477      1.42665601e+00    None        None        None
# Strong SSB     0.733     1         0.9939439663      1.41121208e+00    None        None        None
# Strong SSB     0.944     1         0.9933026405      1.38481786e+00    None        None        None
# Strong SSB     1.156     1         0.9923831979      1.34302163e+00    None        None        None
# Strong SSB     1.367     1         0.9912180213      1.29217279e+00    None        None        None
# Strong SSB     1.578     2         0.9968618209      1.23335459e+00    None        None        None
# Strong SSB     1.789     2         0.9960434229      1.17426012e+00    None        None        None
# Strong SSB     2.000     2         0.9950612538      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================



case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
# Define colors for each case
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

    
for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()


plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-2.0

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000295
# T = 10    Fidelity = 0.00027883
# T = 20    Fidelity = 0.00630080
# T = 30    Fidelity = 0.02604778
# T = 40    Fidelity = 0.06583063
# T = 50    Fidelity = 0.12448068
# T = 75    Fidelity = 0.30902359
# T = 100   Fidelity = 0.46390169
# T = 125   Fidelity = 0.64202738
# T = 150   Fidelity = 0.69155646
# T = 175   Fidelity = 0.77466453
# T = 200   Fidelity = 0.83392506
# T = 225   Fidelity = 0.81458338
# T = 250   Fidelity = 0.90533943
# T = 275   Fidelity = 0.91624227
# T = 300   Fidelity = 0.86712844
# T = 400   Fidelity = 0.97880075
# T = 500   Fidelity = 0.86746075
# T = 600   Fidelity = 0.89638776
# T = 700   Fidelity = 0.86506498
# T = 800   Fidelity = 0.84096315
# T = 900   Fidelity = 0.91560004
# T = 1000  Fidelity = 0.78790494
# T = 1010  Fidelity = 0.86616488
# T = 1020  Fidelity = 0.76217351
# T = 1030  Fidelity = 0.71446702
# T = 1040  Fidelity = 0.60477243
# T = 1050  Fidelity = 0.44977957
# T = 1060  Fidelity = 0.49370521
# T = 1070  Fidelity = 0.46200188
# T = 1080  Fidelity = 0.54276916
# T = 1090  Fidelity = 0.59940065
# T = 1100  Fidelity = 0.58205539
# T = 1200  Fidelity = 0.69559468
# T = 1300  Fidelity = 0.53380169
# T = 1400  Fidelity = 0.88369956
# T = 1500  Fidelity = 0.75106742
# T = 2000  Fidelity = 0.48184137
# T = 2100  Fidelity = 0.34343551
# T = 2110  Fidelity = 0.54053935
# T = 2120  Fidelity = 0.62152175
# T = 2130  Fidelity = 0.58567597
# T = 2140  Fidelity = 0.55836170
# T = 2150  Fidelity = 0.44172872
# T = 2160  Fidelity = 0.59536606
# T = 2170  Fidelity = 0.54223411
# T = 2180  Fidelity = 0.58478779
# T = 2190  Fidelity = 0.64417589
# T = 2200  Fidelity = 0.57758178
# T = 2300  Fidelity = 0.89032870
# T = 2400  Fidelity = 0.61186868
# T = 2500  Fidelity = 0.43001660
# T = 2600  Fidelity = 0.69222879
# T = 2700  Fidelity = 0.84406033
# T = 2800  Fidelity = 0.79488847
# T = 2900  Fidelity = 0.77013459
# T = 3000  Fidelity = 0.70249419
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.79379555e-02
# P0     = 0.70249419
# P1     = 0.00000001
# P0+P1  = 0.70249419
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.17908350e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00030525
# T = 10    Fidelity = 0.01973264
# T = 20    Fidelity = 0.35206925
# T = 30    Fidelity = 0.52577617
# T = 40    Fidelity = 0.54422101
# T = 50    Fidelity = 0.70350476
# T = 75    Fidelity = 0.85008633
# T = 100   Fidelity = 0.92375530
# T = 125   Fidelity = 0.95513736
# T = 150   Fidelity = 0.97617368
# T = 175   Fidelity = 0.99755126
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.94880935e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.01013690
# T = 10    Fidelity = 0.29395571
# T = 20    Fidelity = 0.47649384
# T = 30    Fidelity = 0.65919072
# T = 40    Fidelity = 0.84256840
# T = 50    Fidelity = 0.88343432
# T = 75    Fidelity = 0.96311956
# T = 100   Fidelity = 0.98782656
# T = 125   Fidelity = 0.99595730
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.58119060e-07
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000815
# T = 5     Fidelity = 0.06264135
# T = 10    Fidelity = 0.29631565
# T = 20    Fidelity = 0.55806262
# T = 30    Fidelity = 0.72698070
# T = 40    Fidelity = 0.83533082
# T = 50    Fidelity = 0.91099763
# T = 75    Fidelity = 0.98046567
# T = 100   Fidelity = 0.99984467
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.89654476e-08
# T = 1     Fidelity = 0.00000138
# T = 2     Fidelity = 0.00013186
# T = 5     Fidelity = 0.11159426
# T = 10    Fidelity = 0.49005284
# T = 20    Fidelity = 0.76517083
# T = 30    Fidelity = 0.88755804
# T = 40    Fidelity = 0.94380331
# T = 50    Fidelity = 0.97009755
# T = 75    Fidelity = 0.99783123
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.17592585e-07
# T = 1     Fidelity = 0.00002205
# T = 2     Fidelity = 0.00081340
# T = 5     Fidelity = 0.15754632
# T = 10    Fidelity = 0.62742166
# T = 20    Fidelity = 0.87768680
# T = 30    Fidelity = 0.95887198
# T = 40    Fidelity = 0.98612628
# T = 50    Fidelity = 0.99608599
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 2.47961131e-07
# T = 1     Fidelity = 0.00014361
# T = 2     Fidelity = 0.00277484
# T = 5     Fidelity = 0.19659326
# T = 10    Fidelity = 0.73840338
# T = 20    Fidelity = 0.93001297
# T = 30    Fidelity = 0.97197575
# T = 40    Fidelity = 0.98585266
# T = 50    Fidelity = 0.99133244
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 3.56990600e-07
# T = 1     Fidelity = 0.00057596
# T = 2     Fidelity = 0.00690864
# T = 5     Fidelity = 0.23187012
# T = 10    Fidelity = 0.80830247
# T = 20    Fidelity = 0.93690113
# T = 30    Fidelity = 0.96371752
# T = 40    Fidelity = 0.98388511
# T = 50    Fidelity = 0.99475767
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.45005899e-06
# T = 1     Fidelity = 0.00169069
# T = 2     Fidelity = 0.01404922
# T = 5     Fidelity = 0.26487569
# T = 10    Fidelity = 0.84403904
# T = 20    Fidelity = 0.92521131
# T = 30    Fidelity = 0.96895760
# T = 40    Fidelity = 0.99384071
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396303
# T = 2     Fidelity = 0.02467479
# T = 5     Fidelity = 0.29523268
# T = 10    Fidelity = 0.85798676
# T = 20    Fidelity = 0.92053383
# T = 30    Fidelity = 0.98399875
# T = 40    Fidelity = 0.99992228
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.62831953
# T = 2     Fidelity = 0.65696391
# T = 5     Fidelity = 0.71276159
# T = 10    Fidelity = 0.76630310
# T = 20    Fidelity = 0.83199382
# T = 30    Fidelity = 0.87169943
# T = 40    Fidelity = 0.90007420
# T = 50    Fidelity = 0.91986740
# T = 75    Fidelity = 0.95061485
# T = 100   Fidelity = 0.96476737
# T = 125   Fidelity = 0.97385408
# T = 150   Fidelity = 0.98158893
# T = 175   Fidelity = 0.97982382
# T = 200   Fidelity = 0.98403420
# T = 225   Fidelity = 0.97861791
# T = 250   Fidelity = 0.98490877
# T = 275   Fidelity = 0.95110133
# T = 300   Fidelity = 0.94009930
# T = 400   Fidelity = 0.97934174
# T = 500   Fidelity = 0.97583014
# T = 600   Fidelity = 0.92997350
# T = 700   Fidelity = 0.81727038
# T = 800   Fidelity = 0.95169710
# T = 900   Fidelity = 0.98246638
# T = 1000  Fidelity = 0.95638981
# T = 1010  Fidelity = 0.95767442
# T = 1020  Fidelity = 0.95816097
# T = 1030  Fidelity = 0.95728674
# T = 1040  Fidelity = 0.96134584
# T = 1050  Fidelity = 0.95746581
# T = 1060  Fidelity = 0.97377030
# T = 1070  Fidelity = 0.98731662
# T = 1080  Fidelity = 0.98960030
# T = 1090  Fidelity = 0.98107836
# T = 1100  Fidelity = 0.97312073
# T = 1200  Fidelity = 0.98517817
# T = 1300  Fidelity = 0.96695231
# T = 1400  Fidelity = 0.84306445
# T = 1500  Fidelity = 0.91508957
# T = 2000  Fidelity = 0.95449816
# T = 2100  Fidelity = 0.87104811
# T = 2110  Fidelity = 0.84814086
# T = 2120  Fidelity = 0.84939440
# T = 2130  Fidelity = 0.85096382
# T = 2140  Fidelity = 0.85374389
# T = 2150  Fidelity = 0.84956813
# T = 2160  Fidelity = 0.86391242
# T = 2170  Fidelity = 0.87690535
# T = 2180  Fidelity = 0.88493888
# T = 2190  Fidelity = 0.89559683
# T = 2200  Fidelity = 0.91175388
# T = 2300  Fidelity = 0.97253466
# T = 2400  Fidelity = 0.97221176
# T = 2500  Fidelity = 0.94341336
# T = 2600  Fidelity = 0.97688157
# T = 2700  Fidelity = 0.97305022
# T = 2800  Fidelity = 0.88770096
# T = 2900  Fidelity = 0.90027166
# T = 3000  Fidelity = 0.94653217
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.33549253e-01
# P0     = 0.94653217
# P1     = 0.02823485
# P0+P1  = 0.97476701
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.69565909
# T = 2     Fidelity = 0.76295508
# T = 5     Fidelity = 0.80948975
# T = 10    Fidelity = 0.83873295
# T = 20    Fidelity = 0.86796590
# T = 30    Fidelity = 0.88667104
# T = 40    Fidelity = 0.90104606
# T = 50    Fidelity = 0.91163019
# T = 75    Fidelity = 0.93064969
# T = 100   Fidelity = 0.94310115
# T = 125   Fidelity = 0.94992116
# T = 150   Fidelity = 0.95553449
# T = 175   Fidelity = 0.96488883
# T = 200   Fidelity = 0.97109848
# T = 225   Fidelity = 0.96537880
# T = 250   Fidelity = 0.96743766
# T = 275   Fidelity = 0.97112672
# T = 300   Fidelity = 0.96428387
# T = 400   Fidelity = 0.97087131
# T = 500   Fidelity = 0.96450123
# T = 600   Fidelity = 0.96649283
# T = 700   Fidelity = 0.96870341
# T = 800   Fidelity = 0.94484340
# T = 900   Fidelity = 0.92272442
# T = 1000  Fidelity = 0.92932708
# T = 1010  Fidelity = 0.92871553
# T = 1020  Fidelity = 0.93169722
# T = 1030  Fidelity = 0.94058431
# T = 1040  Fidelity = 0.93172989
# T = 1050  Fidelity = 0.94463297
# T = 1060  Fidelity = 0.94991373
# T = 1070  Fidelity = 0.92333350
# T = 1080  Fidelity = 0.94011720
# T = 1090  Fidelity = 0.91804091
# T = 1100  Fidelity = 0.92150660
# T = 1200  Fidelity = 0.94890760
# T = 1300  Fidelity = 0.95761973
# T = 1400  Fidelity = 0.97474626
# T = 1500  Fidelity = 0.98766907
# T = 2000  Fidelity = 0.94637988
# T = 2100  Fidelity = 0.95015392
# T = 2110  Fidelity = 0.94902346
# T = 2120  Fidelity = 0.95213828
# T = 2130  Fidelity = 0.94030562
# T = 2140  Fidelity = 0.95667137
# T = 2150  Fidelity = 0.95242764
# T = 2160  Fidelity = 0.94923181
# T = 2170  Fidelity = 0.95507970
# T = 2180  Fidelity = 0.92462056
# T = 2190  Fidelity = 0.93873555
# T = 2200  Fidelity = 0.93637761
# T = 2300  Fidelity = 0.93912798
# T = 2400  Fidelity = 0.97230681
# T = 2500  Fidelity = 0.96495320
# T = 2600  Fidelity = 0.95408781
# T = 2700  Fidelity = 0.94205084
# T = 2800  Fidelity = 0.93957327
# T = 2900  Fidelity = 0.91557511
# T = 3000  Fidelity = 0.97096705
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.30329715e-01
# P0     = 0.97096705
# P1     = 0.01393022
# P0+P1  = 0.98489727
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.05149287
# T = 2     Fidelity = 0.19692499
# T = 5     Fidelity = 0.84901608
# T = 10    Fidelity = 0.97010779
# T = 20    Fidelity = 0.99329973
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.11303886
# T = 2     Fidelity = 0.33355303
# T = 5     Fidelity = 0.84577635
# T = 10    Fidelity = 0.91481717
# T = 20    Fidelity = 0.99918198
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.16818122
# T = 2     Fidelity = 0.40026773
# T = 5     Fidelity = 0.89897128
# T = 10    Fidelity = 0.94666229
# T = 20    Fidelity = 0.99432172
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.21019751
# T = 2     Fidelity = 0.42971516
# T = 5     Fidelity = 0.87817651
# T = 10    Fidelity = 0.92159110
# T = 20    Fidelity = 0.97163891
# T = 30    Fidelity = 0.97998366
# T = 40    Fidelity = 0.97971642
# T = 50    Fidelity = 0.98426694
# T = 75    Fidelity = 0.98668550
# T = 100   Fidelity = 0.98940337
# T = 125   Fidelity = 0.99193920
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.21681482
# T = 2     Fidelity = 0.40382052
# T = 5     Fidelity = 0.82615608
# T = 10    Fidelity = 0.86541730
# T = 20    Fidelity = 0.90795548
# T = 30    Fidelity = 0.93450431
# T = 40    Fidelity = 0.94657398
# T = 50    Fidelity = 0.94841708
# T = 75    Fidelity = 0.96177769
# T = 100   Fidelity = 0.96516081
# T = 125   Fidelity = 0.97374545
# T = 150   Fidelity = 0.97526611
# T = 175   Fidelity = 0.97913274
# T = 200   Fidelity = 0.98172506
# T = 225   Fidelity = 0.98216163
# T = 250   Fidelity = 0.98584123
# T = 275   Fidelity = 0.98488194
# T = 300   Fidelity = 0.98783883
# T = 400   Fidelity = 0.95364866
# T = 500   Fidelity = 0.96674198
# T = 600   Fidelity = 0.98234188
# T = 700   Fidelity = 0.96964747
# T = 800   Fidelity = 0.96747254
# T = 900   Fidelity = 0.98293261
# T = 1000  Fidelity = 0.97135846
# T = 1010  Fidelity = 0.98756458
# T = 1020  Fidelity = 0.99181173
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.20093320
# T = 2     Fidelity = 0.34981802
# T = 5     Fidelity = 0.74510889
# T = 10    Fidelity = 0.79283490
# T = 20    Fidelity = 0.83559570
# T = 30    Fidelity = 0.86313504
# T = 40    Fidelity = 0.88672914
# T = 50    Fidelity = 0.90616844
# T = 75    Fidelity = 0.93045410
# T = 100   Fidelity = 0.94167213
# T = 125   Fidelity = 0.95495718
# T = 150   Fidelity = 0.96250240
# T = 175   Fidelity = 0.96701709
# T = 200   Fidelity = 0.97280189
# T = 225   Fidelity = 0.97589765
# T = 250   Fidelity = 0.97841783
# T = 275   Fidelity = 0.98209073
# T = 300   Fidelity = 0.98236731
# T = 400   Fidelity = 0.95688242
# T = 500   Fidelity = 0.97140172
# T = 600   Fidelity = 0.98357220
# T = 700   Fidelity = 0.96719119
# T = 800   Fidelity = 0.97371702
# T = 900   Fidelity = 0.99380729
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.18018925
# T = 2     Fidelity = 0.29828902
# T = 5     Fidelity = 0.67069359
# T = 10    Fidelity = 0.73254807
# T = 20    Fidelity = 0.79352277
# T = 30    Fidelity = 0.82960927
# T = 40    Fidelity = 0.85614310
# T = 50    Fidelity = 0.87737189
# T = 75    Fidelity = 0.91483913
# T = 100   Fidelity = 0.93876292
# T = 125   Fidelity = 0.95470322
# T = 150   Fidelity = 0.96541725
# T = 175   Fidelity = 0.97254092
# T = 200   Fidelity = 0.97741038
# T = 225   Fidelity = 0.98055909
# T = 250   Fidelity = 0.98390693
# T = 275   Fidelity = 0.98647573
# T = 300   Fidelity = 0.98820031
# T = 400   Fidelity = 0.97345170
# T = 500   Fidelity = 0.97299935
# T = 600   Fidelity = 0.98565808
# T = 700   Fidelity = 0.98637220
# T = 800   Fidelity = 0.98676121
# T = 900   Fidelity = 0.98957284
# T = 1000  Fidelity = 0.98263213
# T = 1010  Fidelity = 0.97169783
# T = 1020  Fidelity = 0.99462879
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.48783584e-01
# T = 1     Fidelity = 0.16455623
# T = 2     Fidelity = 0.26202925
# T = 5     Fidelity = 0.62103516
# T = 10    Fidelity = 0.69545561
# T = 20    Fidelity = 0.77317583
# T = 30    Fidelity = 0.82216955
# T = 40    Fidelity = 0.85857232
# T = 50    Fidelity = 0.88655083
# T = 75    Fidelity = 0.93189155
# T = 100   Fidelity = 0.95689489
# T = 125   Fidelity = 0.97135832
# T = 150   Fidelity = 0.98005916
# T = 175   Fidelity = 0.98549245
# T = 200   Fidelity = 0.98852207
# T = 225   Fidelity = 0.99101146
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.81947687e-02
# T = 1     Fidelity = 0.60242867
# T = 2     Fidelity = 0.64640306
# T = 5     Fidelity = 0.72434082
# T = 10    Fidelity = 0.80008857
# T = 20    Fidelity = 0.88083139
# T = 30    Fidelity = 0.92305136
# T = 40    Fidelity = 0.94762439
# T = 50    Fidelity = 0.96263639
# T = 75    Fidelity = 0.98130714
# T = 100   Fidelity = 0.98429464
# T = 125   Fidelity = 0.98482692
# T = 150   Fidelity = 0.99055794
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.51771385e-02
# T = 1     Fidelity = 0.54132279
# T = 2     Fidelity = 0.58402209
# T = 5     Fidelity = 0.62777607
# T = 10    Fidelity = 0.66502807
# T = 20    Fidelity = 0.72265828
# T = 30    Fidelity = 0.76453180
# T = 40    Fidelity = 0.79700521
# T = 50    Fidelity = 0.82098495
# T = 75    Fidelity = 0.86866174
# T = 100   Fidelity = 0.89943276
# T = 125   Fidelity = 0.91925070
# T = 150   Fidelity = 0.93375352
# T = 175   Fidelity = 0.94142537
# T = 200   Fidelity = 0.94226028
# T = 225   Fidelity = 0.94995373
# T = 250   Fidelity = 0.94158551
# T = 275   Fidelity = 0.93122746
# T = 300   Fidelity = 0.94519614
# T = 400   Fidelity = 0.96680789
# T = 500   Fidelity = 0.94965768
# T = 600   Fidelity = 0.95712180
# T = 700   Fidelity = 0.83469952
# T = 800   Fidelity = 0.87201722
# T = 900   Fidelity = 0.88448243
# T = 1000  Fidelity = 0.88133685
# T = 1010  Fidelity = 0.93270842
# T = 1020  Fidelity = 0.90801809
# T = 1030  Fidelity = 0.94412941
# T = 1040  Fidelity = 0.94726949
# T = 1050  Fidelity = 0.96166583
# T = 1060  Fidelity = 0.97103096
# T = 1070  Fidelity = 0.94768811
# T = 1080  Fidelity = 0.97397031
# T = 1090  Fidelity = 0.96792527
# T = 1100  Fidelity = 0.94491846
# T = 1200  Fidelity = 0.91792045
# T = 1300  Fidelity = 0.97471502
# T = 1400  Fidelity = 0.93679368
# T = 1500  Fidelity = 0.90628427
# T = 2000  Fidelity = 0.94626493
# T = 2100  Fidelity = 0.98889634
# T = 2110  Fidelity = 0.97960192
# T = 2120  Fidelity = 0.98073179
# T = 2130  Fidelity = 0.97362830
# T = 2140  Fidelity = 0.96792537
# T = 2150  Fidelity = 0.95514784
# T = 2160  Fidelity = 0.96056757
# T = 2170  Fidelity = 0.97655356
# T = 2180  Fidelity = 0.96227216
# T = 2190  Fidelity = 0.97613176
# T = 2200  Fidelity = 0.96828368
# T = 2300  Fidelity = 0.89139660
# T = 2400  Fidelity = 0.88999418
# T = 2500  Fidelity = 0.93944432
# T = 2600  Fidelity = 0.86122907
# T = 2700  Fidelity = 0.84395759
# T = 2800  Fidelity = 0.93064676
# T = 2900  Fidelity = 0.95791222
# T = 3000  Fidelity = 0.93716009
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.50815198e-02
# P0     = 0.93716009
# P1     = 0.00000923
# P0+P1  = 0.93716931
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.02268645
# T = 2     Fidelity = 0.09256338
# T = 5     Fidelity = 0.42587100
# T = 10    Fidelity = 0.47742200
# T = 20    Fidelity = 0.49247181
# T = 30    Fidelity = 0.49378708
# T = 40    Fidelity = 0.49443901
# T = 50    Fidelity = 0.49629074
# T = 75    Fidelity = 0.49423587
# T = 100   Fidelity = 0.49532487
# T = 125   Fidelity = 0.49290071
# T = 150   Fidelity = 0.49491313
# T = 175   Fidelity = 0.49121812
# T = 200   Fidelity = 0.48974577
# T = 225   Fidelity = 0.48879294
# T = 250   Fidelity = 0.48772445
# T = 275   Fidelity = 0.48294676
# T = 300   Fidelity = 0.48002892
# T = 400   Fidelity = 0.45843261
# T = 500   Fidelity = 0.44067935
# T = 600   Fidelity = 0.44509771
# T = 700   Fidelity = 0.42362902
# T = 800   Fidelity = 0.40497711
# T = 900   Fidelity = 0.40446384
# T = 1000  Fidelity = 0.36572378
# T = 1010  Fidelity = 0.37187744
# T = 1020  Fidelity = 0.37190521
# T = 1030  Fidelity = 0.36601029
# T = 1040  Fidelity = 0.37142753
# T = 1050  Fidelity = 0.36129119
# T = 1060  Fidelity = 0.36205623
# T = 1070  Fidelity = 0.36308051
# T = 1080  Fidelity = 0.36365791
# T = 1090  Fidelity = 0.35617735
# T = 1100  Fidelity = 0.35227094
# T = 1200  Fidelity = 0.34309157
# T = 1300  Fidelity = 0.31694174
# T = 1400  Fidelity = 0.26196414
# T = 1500  Fidelity = 0.27901869
# T = 2000  Fidelity = 0.19320755
# T = 2100  Fidelity = 0.18627663
# T = 2110  Fidelity = 0.18010681
# T = 2120  Fidelity = 0.17692203
# T = 2130  Fidelity = 0.17284262
# T = 2140  Fidelity = 0.17698532
# T = 2150  Fidelity = 0.17449001
# T = 2160  Fidelity = 0.17166616
# T = 2170  Fidelity = 0.16652864
# T = 2180  Fidelity = 0.16779798
# T = 2190  Fidelity = 0.16555570
# T = 2200  Fidelity = 0.16238469
# T = 2300  Fidelity = 0.15151395
# T = 2400  Fidelity = 0.10862014
# T = 2500  Fidelity = 0.12827664
# T = 2600  Fidelity = 0.11893664
# T = 2700  Fidelity = 0.10692551
# T = 2800  Fidelity = 0.09336819
# T = 2900  Fidelity = 0.09028848
# T = 3000  Fidelity = 0.08217235
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.35220086e-03
# P0     = 0.08217235
# P1     = 0.41545026
# P0+P1  = 0.49762261
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07018746e-03
# T = 1     Fidelity = 0.02879791
# T = 2     Fidelity = 0.08549344
# T = 5     Fidelity = 0.22649931
# T = 10    Fidelity = 0.24388914
# T = 20    Fidelity = 0.26806459
# T = 30    Fidelity = 0.26746339
# T = 40    Fidelity = 0.26800281
# T = 50    Fidelity = 0.27102478
# T = 75    Fidelity = 0.27159041
# T = 100   Fidelity = 0.27239971
# T = 125   Fidelity = 0.27228809
# T = 150   Fidelity = 0.27255702
# T = 175   Fidelity = 0.27249383
# T = 200   Fidelity = 0.27834479
# T = 225   Fidelity = 0.27639915
# T = 250   Fidelity = 0.26994970
# T = 275   Fidelity = 0.27422925
# T = 300   Fidelity = 0.27618315
# T = 400   Fidelity = 0.29311776
# T = 500   Fidelity = 0.26084583
# T = 600   Fidelity = 0.27280370
# T = 700   Fidelity = 0.27046529
# T = 800   Fidelity = 0.24300329
# T = 900   Fidelity = 0.24044085
# T = 1000  Fidelity = 0.26266438
# T = 1010  Fidelity = 0.26503260
# T = 1020  Fidelity = 0.26618053
# T = 1030  Fidelity = 0.28854443
# T = 1040  Fidelity = 0.27151799
# T = 1050  Fidelity = 0.28693999
# T = 1060  Fidelity = 0.33338646
# T = 1070  Fidelity = 0.22436675
# T = 1080  Fidelity = 0.25407075
# T = 1090  Fidelity = 0.25380343
# T = 1100  Fidelity = 0.30508652
# T = 1200  Fidelity = 0.31886831
# T = 1300  Fidelity = 0.29687302
# T = 1400  Fidelity = 0.30226696
# T = 1500  Fidelity = 0.20985298
# T = 2000  Fidelity = 0.26885980
# T = 2100  Fidelity = 0.19355513
# T = 2110  Fidelity = 0.28944438
# T = 2120  Fidelity = 0.28483191
# T = 2130  Fidelity = 0.21830735
# T = 2140  Fidelity = 0.35640280
# T = 2150  Fidelity = 0.21424358
# T = 2160  Fidelity = 0.28397640
# T = 2170  Fidelity = 0.23365174
# T = 2180  Fidelity = 0.28387854
# T = 2190  Fidelity = 0.28426011
# T = 2200  Fidelity = 0.27457176
# T = 2300  Fidelity = 0.29349950
# T = 2400  Fidelity = 0.23932787
# T = 2500  Fidelity = 0.29119724
# T = 2600  Fidelity = 0.28886169
# T = 2700  Fidelity = 0.25328430
# T = 2800  Fidelity = 0.23457499
# T = 2900  Fidelity = 0.25221683
# T = 3000  Fidelity = 0.23231634
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.59823390e-03
# P0     = 0.23231634
# P1     = 0.24465830
# P0+P1  = 0.47697464
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.80171521e-04
# T = 1     Fidelity = 0.03890310
# T = 2     Fidelity = 0.09380761
# T = 5     Fidelity = 0.22967878
# T = 10    Fidelity = 0.24178523
# T = 20    Fidelity = 0.26263926
# T = 30    Fidelity = 0.26961077
# T = 40    Fidelity = 0.26768535
# T = 50    Fidelity = 0.27384898
# T = 75    Fidelity = 0.27668397
# T = 100   Fidelity = 0.28047602
# T = 125   Fidelity = 0.28563264
# T = 150   Fidelity = 0.29056356
# T = 175   Fidelity = 0.29872930
# T = 200   Fidelity = 0.29701050
# T = 225   Fidelity = 0.30157627
# T = 250   Fidelity = 0.30015965
# T = 275   Fidelity = 0.29805057
# T = 300   Fidelity = 0.30704054
# T = 400   Fidelity = 0.35526316
# T = 500   Fidelity = 0.28607670
# T = 600   Fidelity = 0.32715976
# T = 700   Fidelity = 0.23809706
# T = 800   Fidelity = 0.37522589
# T = 900   Fidelity = 0.37628119
# T = 1000  Fidelity = 0.35140316
# T = 1010  Fidelity = 0.37738540
# T = 1020  Fidelity = 0.39681619
# T = 1030  Fidelity = 0.34997814
# T = 1040  Fidelity = 0.27940549
# T = 1050  Fidelity = 0.26755193
# T = 1060  Fidelity = 0.29586625
# T = 1070  Fidelity = 0.32705573
# T = 1080  Fidelity = 0.38753575
# T = 1090  Fidelity = 0.41225574
# T = 1100  Fidelity = 0.28448459
# T = 1200  Fidelity = 0.27102351
# T = 1300  Fidelity = 0.41275754
# T = 1400  Fidelity = 0.29069866
# T = 1500  Fidelity = 0.41809876
# T = 2000  Fidelity = 0.40724882
# T = 2100  Fidelity = 0.33949473
# T = 2110  Fidelity = 0.41430940
# T = 2120  Fidelity = 0.38896871
# T = 2130  Fidelity = 0.37718051
# T = 2140  Fidelity = 0.44788203
# T = 2150  Fidelity = 0.37277656
# T = 2160  Fidelity = 0.35357435
# T = 2170  Fidelity = 0.31979375
# T = 2180  Fidelity = 0.30809345
# T = 2190  Fidelity = 0.44568888
# T = 2200  Fidelity = 0.31129955
# T = 2300  Fidelity = 0.42574546
# T = 2400  Fidelity = 0.36242916
# T = 2500  Fidelity = 0.43539637
# T = 2600  Fidelity = 0.41131774
# T = 2700  Fidelity = 0.35757307
# T = 2800  Fidelity = 0.37973786
# T = 2900  Fidelity = 0.40700637
# T = 3000  Fidelity = 0.41214976
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.38933834e-03
# P0     = 0.41214976
# P1     = 0.40437891
# P0+P1  = 0.81652867
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 9.40449540e-04
# T = 1     Fidelity = 0.04605001
# T = 2     Fidelity = 0.09620273
# T = 5     Fidelity = 0.22877616
# T = 10    Fidelity = 0.24355253
# T = 20    Fidelity = 0.26597290
# T = 30    Fidelity = 0.28951590
# T = 40    Fidelity = 0.29776589
# T = 50    Fidelity = 0.29662047
# T = 75    Fidelity = 0.31897308
# T = 100   Fidelity = 0.32454295
# T = 125   Fidelity = 0.33400635
# T = 150   Fidelity = 0.34602250
# T = 175   Fidelity = 0.34814712
# T = 200   Fidelity = 0.35770489
# T = 225   Fidelity = 0.36400977
# T = 250   Fidelity = 0.36483075
# T = 275   Fidelity = 0.37742951
# T = 300   Fidelity = 0.37620083
# T = 400   Fidelity = 0.34500333
# T = 500   Fidelity = 0.38212235
# T = 600   Fidelity = 0.42547071
# T = 700   Fidelity = 0.43464577
# T = 800   Fidelity = 0.45066080
# T = 900   Fidelity = 0.45470912
# T = 1000  Fidelity = 0.48234021
# T = 1010  Fidelity = 0.42508536
# T = 1020  Fidelity = 0.41107159
# T = 1030  Fidelity = 0.46699448
# T = 1040  Fidelity = 0.49732375
# T = 1050  Fidelity = 0.48284077
# T = 1060  Fidelity = 0.42821491
# T = 1070  Fidelity = 0.37392734
# T = 1080  Fidelity = 0.45117298
# T = 1090  Fidelity = 0.49148546
# T = 1100  Fidelity = 0.39665537
# T = 1200  Fidelity = 0.48497729
# T = 1300  Fidelity = 0.50520887
# T = 1400  Fidelity = 0.47423268
# T = 1500  Fidelity = 0.48066356
# T = 2000  Fidelity = 0.49040904
# T = 2100  Fidelity = 0.50765145
# T = 2110  Fidelity = 0.49674880
# T = 2120  Fidelity = 0.47770239
# T = 2130  Fidelity = 0.50061921
# T = 2140  Fidelity = 0.48015389
# T = 2150  Fidelity = 0.47266572
# T = 2160  Fidelity = 0.47333786
# T = 2170  Fidelity = 0.46812635
# T = 2180  Fidelity = 0.44650838
# T = 2190  Fidelity = 0.47977859
# T = 2200  Fidelity = 0.47073194
# T = 2300  Fidelity = 0.53012805
# T = 2400  Fidelity = 0.54404417
# T = 2500  Fidelity = 0.50397623
# T = 2600  Fidelity = 0.53412809
# T = 2700  Fidelity = 0.55542507
# T = 2800  Fidelity = 0.53772895
# T = 2900  Fidelity = 0.57421914
# T = 3000  Fidelity = 0.57660359
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.24416809e-03
# P0     = 0.57660359
# P1     = 0.41171277
# P0+P1  = 0.98831636
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 9.13233454e-04
# T = 1     Fidelity = 0.04796904
# T = 2     Fidelity = 0.09208648
# T = 5     Fidelity = 0.23646517
# T = 10    Fidelity = 0.26058434
# T = 20    Fidelity = 0.28608095
# T = 30    Fidelity = 0.30898497
# T = 40    Fidelity = 0.33161894
# T = 50    Fidelity = 0.34952801
# T = 75    Fidelity = 0.36983319
# T = 100   Fidelity = 0.38590108
# T = 125   Fidelity = 0.40503861
# T = 150   Fidelity = 0.41368192
# T = 175   Fidelity = 0.42386424
# T = 200   Fidelity = 0.43517415
# T = 225   Fidelity = 0.43922436
# T = 250   Fidelity = 0.44751156
# T = 275   Fidelity = 0.45578973
# T = 300   Fidelity = 0.45416994
# T = 400   Fidelity = 0.47360744
# T = 500   Fidelity = 0.45797330
# T = 600   Fidelity = 0.49609606
# T = 700   Fidelity = 0.49491784
# T = 800   Fidelity = 0.52005849
# T = 900   Fidelity = 0.52748362
# T = 1000  Fidelity = 0.49823639
# T = 1010  Fidelity = 0.52562368
# T = 1020  Fidelity = 0.50756730
# T = 1030  Fidelity = 0.50026396
# T = 1040  Fidelity = 0.52459683
# T = 1050  Fidelity = 0.52773750
# T = 1060  Fidelity = 0.50143818
# T = 1070  Fidelity = 0.53084140
# T = 1080  Fidelity = 0.52534326
# T = 1090  Fidelity = 0.53726294
# T = 1100  Fidelity = 0.52220952
# T = 1200  Fidelity = 0.52033503
# T = 1300  Fidelity = 0.53875471
# T = 1400  Fidelity = 0.50682924
# T = 1500  Fidelity = 0.54140761
# T = 2000  Fidelity = 0.56744020
# T = 2100  Fidelity = 0.58016460
# T = 2110  Fidelity = 0.57695902
# T = 2120  Fidelity = 0.57220085
# T = 2130  Fidelity = 0.56521884
# T = 2140  Fidelity = 0.57165828
# T = 2150  Fidelity = 0.57373505
# T = 2160  Fidelity = 0.58549652
# T = 2170  Fidelity = 0.57988153
# T = 2180  Fidelity = 0.56217818
# T = 2190  Fidelity = 0.57494295
# T = 2200  Fidelity = 0.56710805
# T = 2300  Fidelity = 0.54957269
# T = 2400  Fidelity = 0.59766002
# T = 2500  Fidelity = 0.58291098
# T = 2600  Fidelity = 0.50249513
# T = 2700  Fidelity = 0.54631179
# T = 2800  Fidelity = 0.54142748
# T = 2900  Fidelity = 0.55243402
# T = 3000  Fidelity = 0.47748737
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.13588693e-03
# P0     = 0.47748737
# P1     = 0.30206834
# P0+P1  = 0.77955571
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.91554516e-04
# T = 1     Fidelity = 0.05038394
# T = 2     Fidelity = 0.09083316
# T = 5     Fidelity = 0.25558046
# T = 10    Fidelity = 0.29368610
# T = 20    Fidelity = 0.33484500
# T = 30    Fidelity = 0.36247140
# T = 40    Fidelity = 0.38304718
# T = 50    Fidelity = 0.39937897
# T = 75    Fidelity = 0.42860490
# T = 100   Fidelity = 0.44810143
# T = 125   Fidelity = 0.46205624
# T = 150   Fidelity = 0.47250695
# T = 175   Fidelity = 0.48058789
# T = 200   Fidelity = 0.48682075
# T = 225   Fidelity = 0.49199662
# T = 250   Fidelity = 0.49607936
# T = 275   Fidelity = 0.49928657
# T = 300   Fidelity = 0.50160485
# T = 400   Fidelity = 0.50516559
# T = 500   Fidelity = 0.51838221
# T = 600   Fidelity = 0.51727274
# T = 700   Fidelity = 0.52770751
# T = 800   Fidelity = 0.51820465
# T = 900   Fidelity = 0.53952847
# T = 1000  Fidelity = 0.52701378
# T = 1010  Fidelity = 0.54205162
# T = 1020  Fidelity = 0.53103138
# T = 1030  Fidelity = 0.53285457
# T = 1040  Fidelity = 0.54322656
# T = 1050  Fidelity = 0.53872475
# T = 1060  Fidelity = 0.51971297
# T = 1070  Fidelity = 0.53846651
# T = 1080  Fidelity = 0.52570153
# T = 1090  Fidelity = 0.54688875
# T = 1100  Fidelity = 0.53352403
# T = 1200  Fidelity = 0.53962245
# T = 1300  Fidelity = 0.55872542
# T = 1400  Fidelity = 0.51568829
# T = 1500  Fidelity = 0.54849006
# T = 2000  Fidelity = 0.49840913
# T = 2100  Fidelity = 0.50131984
# T = 2110  Fidelity = 0.55356608
# T = 2120  Fidelity = 0.51831982
# T = 2130  Fidelity = 0.51833966
# T = 2140  Fidelity = 0.53428696
# T = 2150  Fidelity = 0.51043085
# T = 2160  Fidelity = 0.50609589
# T = 2170  Fidelity = 0.51903511
# T = 2180  Fidelity = 0.51162198
# T = 2190  Fidelity = 0.51512777
# T = 2200  Fidelity = 0.46279564
# T = 2300  Fidelity = 0.56190894
# T = 2400  Fidelity = 0.56404314
# T = 2500  Fidelity = 0.53900085
# T = 2600  Fidelity = 0.58638525
# T = 2700  Fidelity = 0.60774805
# T = 2800  Fidelity = 0.58457967
# T = 2900  Fidelity = 0.63333311
# T = 3000  Fidelity = 0.63230150
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.05026245e-03
# P0     = 0.63230150
# P1     = 0.35110995
# P0+P1  = 0.98341145
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 8.73711147e-04
# T = 1     Fidelity = 0.05462796
# T = 2     Fidelity = 0.09353107
# T = 5     Fidelity = 0.27983541
# T = 10    Fidelity = 0.33167018
# T = 20    Fidelity = 0.38848786
# T = 30    Fidelity = 0.41954864
# T = 40    Fidelity = 0.43936726
# T = 50    Fidelity = 0.45288015
# T = 75    Fidelity = 0.47316574
# T = 100   Fidelity = 0.48446628
# T = 125   Fidelity = 0.49175314
# T = 150   Fidelity = 0.49690304
# T = 175   Fidelity = 0.50080588
# T = 200   Fidelity = 0.50385845
# T = 225   Fidelity = 0.50674918
# T = 250   Fidelity = 0.50940287
# T = 275   Fidelity = 0.51194496
# T = 300   Fidelity = 0.51395077
# T = 400   Fidelity = 0.50640908
# T = 500   Fidelity = 0.51261193
# T = 600   Fidelity = 0.52608605
# T = 700   Fidelity = 0.52680685
# T = 800   Fidelity = 0.52790859
# T = 900   Fidelity = 0.52401612
# T = 1000  Fidelity = 0.52450491
# T = 1010  Fidelity = 0.54872047
# T = 1020  Fidelity = 0.54143430
# T = 1030  Fidelity = 0.54456382
# T = 1040  Fidelity = 0.55010539
# T = 1050  Fidelity = 0.53004864
# T = 1060  Fidelity = 0.55103523
# T = 1070  Fidelity = 0.55227449
# T = 1080  Fidelity = 0.52534323
# T = 1090  Fidelity = 0.53685354
# T = 1100  Fidelity = 0.54647738
# T = 1200  Fidelity = 0.54619687
# T = 1300  Fidelity = 0.52596511
# T = 1400  Fidelity = 0.53309726
# T = 1500  Fidelity = 0.53681889
# T = 2000  Fidelity = 0.56621058
# T = 2100  Fidelity = 0.58360148
# T = 2110  Fidelity = 0.60368927
# T = 2120  Fidelity = 0.59511140
# T = 2130  Fidelity = 0.60308353
# T = 2140  Fidelity = 0.60890047
# T = 2150  Fidelity = 0.60078358
# T = 2160  Fidelity = 0.59922826
# T = 2170  Fidelity = 0.59404908
# T = 2180  Fidelity = 0.60035847
# T = 2190  Fidelity = 0.61115800
# T = 2200  Fidelity = 0.60287208
# T = 2300  Fidelity = 0.61340633
# T = 2400  Fidelity = 0.62012168
# T = 2500  Fidelity = 0.61933511
# T = 2600  Fidelity = 0.58989331
# T = 2700  Fidelity = 0.63189100
# T = 2800  Fidelity = 0.61459264
# T = 2900  Fidelity = 0.64087036
# T = 3000  Fidelity = 0.62881259
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.78208763e-04
# P0     = 0.62881259
# P1     = 0.33566185
# P0+P1  = 0.96447444
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 8.58553719e-04
# T = 1     Fidelity = 0.05947549
# T = 2     Fidelity = 0.09785926
# T = 5     Fidelity = 0.30542562
# T = 10    Fidelity = 0.36777111
# T = 20    Fidelity = 0.42496606
# T = 30    Fidelity = 0.45351306
# T = 40    Fidelity = 0.47244374
# T = 50    Fidelity = 0.48561792
# T = 75    Fidelity = 0.50053261
# T = 100   Fidelity = 0.50466663
# T = 125   Fidelity = 0.50862783
# T = 150   Fidelity = 0.51132574
# T = 175   Fidelity = 0.51276009
# T = 200   Fidelity = 0.51489482
# T = 225   Fidelity = 0.51641835
# T = 250   Fidelity = 0.51749463
# T = 275   Fidelity = 0.51915019
# T = 300   Fidelity = 0.51956552
# T = 400   Fidelity = 0.51618329
# T = 500   Fidelity = 0.52399259
# T = 600   Fidelity = 0.53261497
# T = 700   Fidelity = 0.53807397
# T = 800   Fidelity = 0.53850966
# T = 900   Fidelity = 0.54808335
# T = 1000  Fidelity = 0.53210223
# T = 1010  Fidelity = 0.55549874
# T = 1020  Fidelity = 0.53922208
# T = 1030  Fidelity = 0.56108968
# T = 1040  Fidelity = 0.54128476
# T = 1050  Fidelity = 0.55552289
# T = 1060  Fidelity = 0.54627037
# T = 1070  Fidelity = 0.54115478
# T = 1080  Fidelity = 0.53821113
# T = 1090  Fidelity = 0.55035313
# T = 1100  Fidelity = 0.55858623
# T = 1200  Fidelity = 0.54345125
# T = 1300  Fidelity = 0.53258576
# T = 1400  Fidelity = 0.53456823
# T = 1500  Fidelity = 0.54828130
# T = 2000  Fidelity = 0.60211008
# T = 2100  Fidelity = 0.60554976
# T = 2110  Fidelity = 0.60839551
# T = 2120  Fidelity = 0.61920768
# T = 2130  Fidelity = 0.61516890
# T = 2140  Fidelity = 0.62183526
# T = 2150  Fidelity = 0.59126911
# T = 2160  Fidelity = 0.60027165
# T = 2170  Fidelity = 0.61731137
# T = 2180  Fidelity = 0.60751709
# T = 2190  Fidelity = 0.61977176
# T = 2200  Fidelity = 0.61432128
# T = 2300  Fidelity = 0.62358190
# T = 2400  Fidelity = 0.62250803
# T = 2500  Fidelity = 0.63147340
# T = 2600  Fidelity = 0.63218640
# T = 2700  Fidelity = 0.59263157
# T = 2800  Fidelity = 0.61600737
# T = 2900  Fidelity = 0.63233454
# T = 3000  Fidelity = 0.65564292
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.17642281e-04
# P0     = 0.65564292
# P1     = 0.32660357
# P0+P1  = 0.98224649
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99354625
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.89793501
# T = 2     Fidelity = 0.95323571
# T = 5     Fidelity = 0.98562899
# T = 10    Fidelity = 0.99503422
#
# Minimum T for Fidelity >= 0.99 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.31621635e+00
# T = 1     Fidelity = 0.10131127
# T = 2     Fidelity = 0.29795400
# T = 5     Fidelity = 0.80739365
# T = 10    Fidelity = 0.99308243
#
# Minimum T for Fidelity >= 0.99 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.40805723e+00
# T = 1     Fidelity = 0.13236167
# T = 2     Fidelity = 0.38002692
# T = 5     Fidelity = 0.80817435
# T = 10    Fidelity = 0.92201079
# T = 20    Fidelity = 0.99609257
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.23634986
# T = 2     Fidelity = 0.53321318
# T = 5     Fidelity = 0.91871376
# T = 10    Fidelity = 0.98335178
# T = 20    Fidelity = 0.99327545
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.30592894
# T = 2     Fidelity = 0.59386614
# T = 5     Fidelity = 0.91640473
# T = 10    Fidelity = 0.98287004
# T = 20    Fidelity = 0.99383419
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.36087680
# T = 2     Fidelity = 0.63479695
# T = 5     Fidelity = 0.93246050
# T = 10    Fidelity = 0.98422810
# T = 20    Fidelity = 0.99482993
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.40229991
# T = 2     Fidelity = 0.65994517
# T = 5     Fidelity = 0.93966318
# T = 10    Fidelity = 0.98303316
# T = 20    Fidelity = 0.99627575
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.43990744
# T = 2     Fidelity = 0.68183853
# T = 5     Fidelity = 0.94426512
# T = 10    Fidelity = 0.98204946
# T = 20    Fidelity = 0.99730278
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.47114057
# T = 2     Fidelity = 0.69836272
# T = 5     Fidelity = 0.94925013
# T = 10    Fidelity = 0.98137291
# T = 20    Fidelity = 0.99818250
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     None      0.9788007547      3.07240439e-04    0.702494    0.0         0.702494
# Symmetric      0.311     175       0.9975512605      1.17908350e-06    None        None        None
# Symmetric      0.522     125       0.9959573019      2.94880935e-07    None        None        None
# Symmetric      0.733     100       0.9998446740      1.58119060e-07    None        None        None
# Symmetric      0.944     75        0.9978312325      6.89654476e-08    None        None        None
# Symmetric      1.156     50        0.9960859906      1.17592585e-07    None        None        None
# Symmetric      1.367     50        0.9913324422      2.47961131e-07    None        None        None
# Symmetric      1.578     50        0.9947576709      3.56990600e-07    None        None        None
# Symmetric      1.789     40        0.9938407085      2.45005899e-06    None        None        None
# Symmetric      2.000     40        0.9999222759      1.44257094e-05    None        None        None
# Weak SSB optimised0.100     None      0.9896002984      8.67181393e-01    0.946532    0.028235    0.974767
# Weak SSB optimised0.311     None      0.9876690704      5.19764834e-01    0.970967    0.01393     0.984897
# Weak SSB optimised0.522     20        0.9932997279      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     20        0.9991819795      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     20        0.9943217166      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     125       0.9919391952      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     1020      0.9918117259      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     900       0.9938072859      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     1020      0.9946287919      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     225       0.9910114621      2.48783584e-01    None        None        None
# Weak SSB       0.100     150       0.9905579418      1.81947687e-02    None        None        None
# Weak SSB       0.311     None      0.9888963415      1.51771385e-02    0.93716     9e-06       0.937169
# Weak SSB       0.522     None      0.4962907438      1.05614584e-03    0.082172    0.41545     0.497623
# Weak SSB       0.733     None      0.3564028009      1.07018746e-03    0.232316    0.244658    0.476975
# Weak SSB       0.944     None      0.4478820269      9.80171521e-04    0.41215     0.404379    0.816529
# Weak SSB       1.156     None      0.5766035873      9.40449540e-04    0.576604    0.411713    0.988316
# Weak SSB       1.367     None      0.5976600214      9.13233454e-04    0.477487    0.302068    0.779556
# Weak SSB       1.578     None      0.6333331136      8.91554516e-04    0.632302    0.35111     0.983411
# Weak SSB       1.789     None      0.6408703627      8.73711147e-04    0.628813    0.335662    0.964474
# Weak SSB       2.000     None      0.6556429245      8.58553719e-04    0.655643    0.326604    0.982246
# Strong SSB     0.100     1         0.9935462469      3.59472102e+00    None        None        None
# Strong SSB     0.311     10        0.9950342227      1.58498916e+00    None        None        None
# Strong SSB     0.522     10        0.9930824345      1.31621635e+00    None        None        None
# Strong SSB     0.733     20        0.9960925702      1.40805723e+00    None        None        None
# Strong SSB     0.944     20        0.9932754518      1.38481786e+00    None        None        None
# Strong SSB     1.156     20        0.9938341866      1.34302163e+00    None        None        None
# Strong SSB     1.367     20        0.9948299339      1.29217279e+00    None        None        None
# Strong SSB     1.578     20        0.9962757513      1.23335459e+00    None        None        None
# Strong SSB     1.789     20        0.9973027754      1.17426012e+00    None        None        None
# Strong SSB     2.000     20        0.9981825009      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.1556
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7333

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ', color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
