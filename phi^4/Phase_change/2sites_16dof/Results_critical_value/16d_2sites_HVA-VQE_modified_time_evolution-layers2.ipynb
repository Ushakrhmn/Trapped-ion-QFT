# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 0.00005

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722526063431
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Hamiltonian Variational Ansatz (Improved Asymmetric HVA)
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector 
from qiskit_algorithms import VQE 
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B
# ============================================================
# Physics-inspired HVA for mI² < 0
# ============================================================

def grouped_hva_asymm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):

        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 3*nq + 3

    params = ParameterVector(
        "θ",
        nparams_per_layer * layers
    )

    for l in range(layers):

        offset = l * nparams_per_layer

        θx  = params[offset : offset+nq]

        θy  = params[offset+nq : offset+2*nq]

        θz  = params[offset+2*nq : offset+3*nq]

        θxx = params[offset+3*nq]

        θyy = params[offset+3*nq+1]

        θzz = params[offset+3*nq+2]

        # ----------------------------------------------------
        # RX sector
        # ----------------------------------------------------

        for q in range(nq):

            qc.rx(2*θx[q], q)

        # ----------------------------------------------------
        # RY sector
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(2*θy[q], q)

        # ----------------------------------------------------
        # RZ sector
        # ----------------------------------------------------

        for q in range(nq):

            qc.rz(2*θz[q], q)

        # ----------------------------------------------------
        # XX sector
        # ----------------------------------------------------

        for q in range(0, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        # ----------------------------------------------------
        # YY sector
        # ----------------------------------------------------

        for q in range(0, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        for q in range(1, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        # ----------------------------------------------------
        # ZZ sector
        # ----------------------------------------------------

        for q in range(0, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

    return qc

# %%
# ============================================================
# Hamiltonian Variational Ansatz (Improved HVA)
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector

# ============================================================
# Physics-inspired HVA
# ============================================================

def grouped_hva_symm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    # RX, RY, RZ on every qubit
    # one shared XX, YY, ZZ angle

    nparams_per_layer = 3*nq + 3

    params = ParameterVector(
        "θ",
        nparams_per_layer * layers
    )

    for l in range(layers):

        offset = l * nparams_per_layer

        θx  = params[offset : offset+nq]

        θy  = params[offset+nq : offset+2*nq]

        θz  = params[offset+2*nq : offset+3*nq]

        θxx = params[offset+3*nq]

        θyy = params[offset+3*nq+1]

        θzz = params[offset+3*nq+2]

        # ====================================================
        # X rotations
        # ====================================================

        for q in range(nq):

            qc.rx(2*θx[q], q)

        # ====================================================
        # Y rotations
        # ====================================================

        for q in range(nq):

            qc.ry(2*θy[q], q)

        # ====================================================
        # Z rotations
        # ====================================================

        for q in range(nq):

            qc.rz(2*θz[q], q)

        # ====================================================
        # XX block
        # ====================================================

        for q in range(0, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        # ====================================================
        # YY block
        # ====================================================

        for q in range(0, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        for q in range(1, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        # ====================================================
        # ZZ block
        # ====================================================

        for q in range(0, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

    return qc

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Multi-parameter scan
# HVA + warm-start continuation + overlap tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0

# Default depth
layers = 4

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
  {
       "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-4
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#" * 80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#" * 80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "=" * 60)
        print(f"Running λ = {lam:.3f}")
        print("=" * 60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(
            Hloc_sparse
        )

        # ----------------------------------------------------
        # Dense Hamiltonian
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(
            H_op
        )

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ====================================================
        # Adaptive depth near critical region
        # ====================================================

        

        # ====================================================
        # Ansatz
        # ====================================================

        if mI2 < 0:

            ansatz = grouped_hva_asymm(
                nq=nqubits,
                layers=layers
            )

        else:

            ansatz = grouped_hva_symm(
                nq=nqubits,
                layers=layers
            )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)



        
        # ====================================================
        # Weak SSB:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )
        # ====================================================
        # Weak SSB optimized:
        # warm-start + overlap tracking
        # ====================================================

        
        # ====================================================
        # Symmetric + Strong SSB
        # ====================================================

        else:

            print(
                "\nRunning ordinary HVA-VQE...\n"
            )

            initial_point = (
                0.01 * np.random.randn(
                    ansatz.num_parameters
                )
            )

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = (
                vqe.compute_minimum_eigenvalue(
                    H_pauli_shifted
                )
            )

            best_energy = (
                result.eigenvalue.real
                + identity_shift
            )

            optimal_circuit = (
                ansatz.assign_parameters(
                    result.optimal_parameters
                )
            )

            best_state = (
                Statevector.from_instruction(
                    optimal_circuit
                ).data
            )

            best_fidelity = np.abs(
                np.vdot(
                    psi_exact,
                    best_state
                )
            )**2

            best_overlap = 1.0

        # ====================================================
        # Final VQE data
        # ====================================================

        E_vqe = best_energy
        F = best_fidelity

        # ====================================================
        # Store results
        # ====================================================

        data = {

            "case": label,

            "lambda": lam,

            "mI2": mI2,

            "f": f,
            'psi_vqe': best_state,

            "E_exact": E_exact,

            "E_vqe": E_vqe,

            "error": abs(
                E_exact - E_vqe
            ),

            "fidelity": F,

            "tracking_overlap": best_overlap,

            "layers": layers
        }

        case_results.append(data)
        all_results.append(data)

        # ====================================================
        # Print
        # ====================================================

        print("\nFINAL SELECTED STATE")

        print(
            f"Exact energy     : "
            f"{E_exact:.12f}"
        )

        print(
            f"VQE energy       : "
            f"{E_vqe:.12f}"
        )

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(
            f"Fidelity         : "
            f"{F:.12f}"
        )

        print(
            f"Tracking overlap : "
            f"{best_overlap:.12f}"
        )

        print(
            f"Layers            : "
            f"{layers}"
        )

        print(
            f"Pauli terms       : "
            f"{len(H_pauli_shifted.paulis)}"
        )

    # ========================================================
    # Summary
    # ========================================================

    print("\n")
    print("=" * 140)
    print(f"SUMMARY : {label}")
    print("=" * 140)

    print(
        f"{'lambda':<12}"
        f"{'Exact E':<20}"
        f"{'VQE E':<20}"
        f"{'Error':<18}"
        f"{'Fidelity':<18}"
        f"{'TrackOverlap':<18}"
        f"{'Layers':<10}"
    )

    print("=" * 140)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
            f"{r['E_vqe']:<20.10f}"
            f"{r['error']:<18.4e}"
            f"{r['fidelity']:<18.10f}"
            f"{r['tracking_overlap']:<18.10f}"
            f"{r['layers']:<10}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161744847
# Energy error     : 1.668833e-08
# Fidelity         : 0.999999989847
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 106
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641567267
# Energy error     : 1.399199e-07
# Fidelity         : 0.999999976043
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030500376897
# Energy error     : 1.067103e-06
# Fidelity         : 0.999999753859
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041826388111
# Energy error     : 2.065850e-06
# Fidelity         : 0.999999531497
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052688877170
# Energy error     : 4.333408e-06
# Fidelity         : 0.999999314760
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063145950571
# Energy error     : 1.216180e-05
# Fidelity         : 0.999997554742
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073227524233
# Energy error     : 1.187046e-05
# Fidelity         : 0.999997395611
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082991340684
# Energy error     : 2.518887e-05
# Fidelity         : 0.999996023584
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092417052074
# Energy error     : 1.543966e-06
# Fidelity         : 0.999999784960
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101600454459
# Energy error     : 1.102572e-05
# Fidelity         : 0.999998872789
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
#
# ============================================================================================================================================
# SUMMARY : Symmetric
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      1.0061617282        1.0061617448        1.6688e-08        0.9999999898      1.0000000000      4
# 0.3111      1.0186414273        1.0186415673        1.3992e-07        0.9999999760      1.0000000000      4
# 0.5222      1.0304993098        1.0305003769        1.0671e-06        0.9999997539      1.0000000000      4
# 0.7333      1.0418243223        1.0418263881        2.0659e-06        0.9999995315      1.0000000000      4
# 0.9444      1.0526845438        1.0526888772        4.3334e-06        0.9999993148      1.0000000000      4
# 1.1556      1.0631337888        1.0631459506        1.2162e-05        0.9999975547      1.0000000000      4
# 1.3667      1.0732156538        1.0732275242        1.1870e-05        0.9999973956      1.0000000000      4
# 1.5778      1.0829661518        1.0829913407        2.5189e-05        0.9999960236      1.0000000000      4
# 1.7889      1.0924155081        1.0924170521        1.5440e-06        0.9999997850      1.0000000000      4
# 2.0000      1.1015894287        1.1016004545        1.1026e-05        0.9999988728      1.0000000000      4
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.026907356332
# Fidelity = 0.995749096828
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -17.036496355185
# Fidelity = 0.996879914932
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -17.046447945116
# Fidelity = 0.997786172240
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -17.037496059954
# Fidelity = 0.997322323194
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -17.048784094628
# Fidelity = 0.997935955058
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.048784094628
# Energy error     : 1.590926e-02
# Fidelity         : 0.997935955058
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.066757333226
# Fidelity = 0.996306144643
# Overlap  = 0.804157472224
#
# Restart 1
# Energy   = -9.049752003613
# Fidelity = 0.985342868240
# Overlap  = 0.830035205574
#
# Restart 2
# Energy   = -9.068768792391
# Fidelity = 0.995877397671
# Overlap  = 0.803784808421
#
# Restart 3
# Energy   = -9.056862201528
# Fidelity = 0.991615918098
# Overlap  = 0.810419597780
#
# Restart 4
# Energy   = -9.050561135768
# Fidelity = 0.983466940502
# Overlap  = 0.831211224515
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.068768792391
# Energy error     : 1.168112e-02
# Fidelity         : 0.995877397671
# Tracking overlap : 0.803784808421
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.659240525226
# Fidelity = 0.977343167179
# Overlap  = 0.075920031023
#
# Restart 1
# Energy   = -4.671322401161
# Fidelity = 0.986749762118
# Overlap  = 0.070402953590
#
# Restart 2
# Energy   = -4.673667331033
# Fidelity = 0.984638174288
# Overlap  = 0.071204560718
#
# Restart 3
# Energy   = -4.675190894729
# Fidelity = 0.985068480472
# Overlap  = 0.071930958386
#
# Restart 4
# Energy   = -4.680533886538
# Fidelity = 0.991633286291
# Overlap  = 0.070141932188
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.680533886538
# Energy error     : 2.066109e-02
# Fidelity         : 0.991633286291
# Tracking overlap : 0.070141932188
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.998025584007
# Fidelity = 0.994937117690
# Overlap  = 0.653710338206
#
# Restart 1
# Energy   = -3.000993811858
# Fidelity = 0.996547909344
# Overlap  = 0.653893156232
#
# Restart 2
# Energy   = -2.984155144707
# Fidelity = 0.981110507853
# Overlap  = 0.662565265377
#
# Restart 3
# Energy   = -2.996523754099
# Fidelity = 0.992434700395
# Overlap  = 0.659378703042
#
# Restart 4
# Energy   = -2.995038616036
# Fidelity = 0.993570633384
# Overlap  = 0.644763450365
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.000993811858
# Energy error     : 1.053754e-02
# Fidelity         : 0.996547909344
# Tracking overlap : 0.653893156232
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.081295719883
# Fidelity = 0.999516839019
# Overlap  = 0.836399682652
#
# Restart 1
# Energy   = -2.073090724537
# Fidelity = 0.995403045775
# Overlap  = 0.825295977725
#
# Restart 2
# Energy   = -2.061172944069
# Fidelity = 0.987141550910
# Overlap  = 0.817629656849
#
# Restart 3
# Energy   = -2.069141565429
# Fidelity = 0.991267695830
# Overlap  = 0.827393602032
#
# Restart 4
# Energy   = -2.063049954407
# Fidelity = 0.986928416325
# Overlap  = 0.823134353043
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.081295719883
# Energy error     : 2.270004e-03
# Fidelity         : 0.999516839019
# Tracking overlap : 0.836399682652
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.503731713036
# Fidelity = 0.999873269715
# Overlap  = 0.897869801206
#
# Restart 1
# Energy   = -1.493497844153
# Fidelity = 0.994263390023
# Overlap  = 0.881607655288
#
# Restart 2
# Energy   = -1.494836959352
# Fidelity = 0.994938151552
# Overlap  = 0.885309314659
#
# Restart 3
# Energy   = -1.495331677993
# Fidelity = 0.994370185137
# Overlap  = 0.881227056453
#
# Restart 4
# Energy   = -1.491745005822
# Fidelity = 0.991588943374
# Overlap  = 0.876168723672
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503731713036
# Energy error     : 7.561597e-04
# Fidelity         : 0.999873269715
# Tracking overlap : 0.897869801206
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118524956098
# Fidelity = 0.999872717546
# Overlap  = 0.917778652866
#
# Restart 1
# Energy   = -1.113338196510
# Fidelity = 0.997588509958
# Overlap  = 0.907048228752
#
# Restart 2
# Energy   = -1.111917306006
# Fidelity = 0.995979552219
# Overlap  = 0.899817890268
#
# Restart 3
# Energy   = -1.111247544551
# Fidelity = 0.994228249493
# Overlap  = 0.893777508971
#
# Restart 4
# Energy   = -1.111949647068
# Fidelity = 0.995549001162
# Overlap  = 0.899241561596
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118524956098
# Energy error     : 5.747743e-04
# Fidelity         : 0.999872717546
# Tracking overlap : 0.917778652866
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.852905196670
# Fidelity = 0.999926524763
# Overlap  = 0.938547771536
#
# Restart 1
# Energy   = -0.846742247715
# Fidelity = 0.995818764947
# Overlap  = 0.917952275265
#
# Restart 2
# Energy   = -0.845197844616
# Fidelity = 0.992893789509
# Overlap  = 0.907316689338
#
# Restart 3
# Energy   = -0.849066763770
# Fidelity = 0.998033780969
# Overlap  = 0.929210892815
#
# Restart 4
# Energy   = -0.848049394228
# Fidelity = 0.997884530771
# Overlap  = 0.925154042001
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.852905196670
# Energy error     : 4.268573e-04
# Fidelity         : 0.999926524763
# Tracking overlap : 0.938547771536
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663274132062
# Fidelity = 0.999949252425
# Overlap  = 0.958844582487
#
# Restart 1
# Energy   = -0.660332747654
# Fidelity = 0.998721764312
# Overlap  = 0.951046791595
#
# Restart 2
# Energy   = -0.659186963758
# Fidelity = 0.997416640665
# Overlap  = 0.944312481273
#
# Restart 3
# Energy   = -0.660622787784
# Fidelity = 0.998164330057
# Overlap  = 0.949051645709
#
# Restart 4
# Energy   = -0.659615961159
# Fidelity = 0.997561515976
# Overlap  = 0.947138171566
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663274132062
# Energy error     : 2.860095e-04
# Fidelity         : 0.999949252425
# Tracking overlap : 0.958844582487
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.521948388682
# Fidelity = 0.999958690910
# Overlap  = 0.975338724857
#
# Restart 1
# Energy   = -0.520253203680
# Fidelity = 0.999381534053
# Overlap  = 0.972148948890
#
# Restart 2
# Energy   = -0.519076096544
# Fidelity = 0.998331366644
# Overlap  = 0.966442656678
#
# Restart 3
# Energy   = -0.519916777595
# Fidelity = 0.999076234276
# Overlap  = 0.969999842197
#
# Restart 4
# Energy   = -0.519462540019
# Fidelity = 0.999043287809
# Overlap  = 0.970604749834
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.521948388682
# Energy error     : 1.913756e-04
# Fidelity         : 0.999958690910
# Tracking overlap : 0.975338724857
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB optimised
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -17.0646933519      -17.0487840946      1.5909e-02        0.9979359551      1.0000000000      4
# 0.3111      -9.0804499123       -9.0687687924       1.1681e-02        0.9958773977      0.8037848084      4
# 0.5222      -4.7011949726       -4.6805338865       2.0661e-02        0.9916332863      0.0701419322      4
# 0.7333      -3.0115313516       -3.0009938119       1.0538e-02        0.9965479093      0.6538931562      4
# 0.9444      -2.0835657235       -2.0812957199       2.2700e-03        0.9995168390      0.8363996827      4
# 1.1556      -1.5044878727       -1.5037317130       7.5616e-04        0.9998732697      0.8978698012      4
# 1.3667      -1.1190997304       -1.1185249561       5.7477e-04        0.9998727175      0.9177786529      4
# 1.5778      -0.8533320540       -0.8529051967       4.2686e-04        0.9999265248      0.9385477715      4
# 1.7889      -0.6635601415       -0.6632741321       2.8601e-04        0.9999492524      0.9588445825      4
# 2.0000      -0.5221397643       -0.5219483887       1.9138e-04        0.9999586909      0.9753387249      4
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 0.0001
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.935223893903
# Fidelity = 0.998996516949
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.920907335495
# Fidelity = 0.997755631079
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.924012185622
# Fidelity = 0.997617005026
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.936642723411
# Fidelity = 0.999190374124
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.928805815121
# Fidelity = 0.998403249383
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902685020
# VQE energy       : -16.936642723411
# Energy error     : 7.259962e-03
# Fidelity         : 0.999190374124
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 158
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.890768427058
# Fidelity = 0.999525784481
# Overlap  = 0.874095142893
#
# Restart 1
# Energy   = -8.878789535387
# Fidelity = 0.997321175651
# Overlap  = 0.876589685258
#
# Restart 2
# Energy   = -8.887275409808
# Fidelity = 0.997963034947
# Overlap  = 0.885937966473
#
# Restart 3
# Energy   = -8.885250717807
# Fidelity = 0.997896875315
# Overlap  = 0.880302024318
#
# Restart 4
# Energy   = -8.862435842284
# Fidelity = 0.989476989429
# Overlap  = 0.906147927213
#
# FINAL SELECTED STATE
# Exact energy     : -8.892069658534
# VQE energy       : -8.890768427058
# Energy error     : 1.301231e-03
# Fidelity         : 0.999525784481
# Tracking overlap : 0.874095142893
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.378567198314
# Fidelity = 0.787915884165
# Overlap  = 0.049428764411
#
# Restart 1
# Energy   = -4.369059163876
# Fidelity = 0.186633516363
# Overlap  = 0.005205728588
#
# Restart 2
# Energy   = -4.372352652550
# Fidelity = 0.813702369554
# Overlap  = 0.049180474334
#
# Restart 3
# Energy   = -4.372920491343
# Fidelity = 0.062900274061
# Overlap  = 0.002869836184
#
# Restart 4
# Energy   = -4.358588002526
# Fidelity = 0.020190569914
# Overlap  = 0.000012135844
#
# FINAL SELECTED STATE
# Exact energy     : -4.379329565434
# VQE energy       : -4.378567198314
# Energy error     : 7.623671e-04
# Fidelity         : 0.787915884165
# Tracking overlap : 0.049428764411
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.741291460271
# Fidelity = 0.000011537733
# Overlap  = 0.656280979558
#
# Restart 1
# Energy   = -2.746796031727
# Fidelity = 0.989401961673
# Overlap  = 0.000024881511
#
# Restart 2
# Energy   = -2.748148310525
# Fidelity = 0.971143078614
# Overlap  = 0.000003698527
#
# Restart 3
# Energy   = -2.745707764836
# Fidelity = 0.898545648721
# Overlap  = 0.001182686598
#
# Restart 4
# Energy   = -2.744587602933
# Fidelity = 0.903943089479
# Overlap  = 0.000466279855
#
# FINAL SELECTED STATE
# Exact energy     : -2.749826501443
# VQE energy       : -2.748148310525
# Energy error     : 1.678191e-03
# Fidelity         : 0.971143078614
# Tracking overlap : 0.000003698527
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874593833173
# Fidelity = 0.998803992154
# Overlap  = 0.817760675557
#
# Restart 1
# Energy   = -1.872686001333
# Fidelity = 0.983992369924
# Overlap  = 0.814605559879
#
# Restart 2
# Energy   = -1.872589399543
# Fidelity = 0.988093657405
# Overlap  = 0.817527510345
#
# Restart 3
# Energy   = -1.872414691263
# Fidelity = 0.987043499076
# Overlap  = 0.808968992188
#
# Restart 4
# Energy   = -1.873070402339
# Fidelity = 0.993040776817
# Overlap  = 0.814837575991
#
# FINAL SELECTED STATE
# Exact energy     : -1.874705890824
# VQE energy       : -1.874593833173
# Energy error     : 1.120577e-04
# Fidelity         : 0.998803992154
# Tracking overlap : 0.817760675557
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348766642923
# Fidelity = 0.999965655943
# Overlap  = 0.894400999033
#
# Restart 1
# Energy   = -1.347500969477
# Fidelity = 0.996549827914
# Overlap  = 0.891952610345
#
# Restart 2
# Energy   = -1.345767506137
# Fidelity = 0.992863359042
# Overlap  = 0.881127532439
#
# Restart 3
# Energy   = -1.347143018979
# Fidelity = 0.997323027165
# Overlap  = 0.887814554192
#
# Restart 4
# Energy   = -1.347806597239
# Fidelity = 0.997797454238
# Overlap  = 0.892532221101
#
# FINAL SELECTED STATE
# Exact energy     : -1.348823187245
# VQE energy       : -1.348766642923
# Energy error     : 5.654432e-05
# Fidelity         : 0.999965655943
# Tracking overlap : 0.894400999033
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.010034126375
# Fidelity = 0.999599209283
# Overlap  = 0.936681531807
#
# Restart 1
# Energy   = -1.009185932272
# Fidelity = 0.999140974350
# Overlap  = 0.934849085505
#
# Restart 2
# Energy   = -1.008568960919
# Fidelity = 0.997426368242
# Overlap  = 0.935502556551
#
# Restart 3
# Energy   = -1.009188982200
# Fidelity = 0.999132401883
# Overlap  = 0.935751231701
#
# Restart 4
# Energy   = -1.009591313120
# Fidelity = 0.998249419165
# Overlap  = 0.935283129349
#
# FINAL SELECTED STATE
# Exact energy     : -1.010440164101
# VQE energy       : -1.010034126375
# Energy error     : 4.060377e-04
# Fidelity         : 0.999599209283
# Tracking overlap : 0.936681531807
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.778727532734
# Fidelity = 0.999784280761
# Overlap  = 0.962857217370
#
# Restart 1
# Energy   = -0.775424430870
# Fidelity = 0.996184320873
# Overlap  = 0.955909794834
#
# Restart 2
# Energy   = -0.776907819173
# Fidelity = 0.999250242551
# Overlap  = 0.960584142914
#
# Restart 3
# Energy   = -0.776353807309
# Fidelity = 0.998397118358
# Overlap  = 0.958247593117
#
# Restart 4
# Energy   = -0.777635016804
# Fidelity = 0.999446772946
# Overlap  = 0.960500973555
#
# FINAL SELECTED STATE
# Exact energy     : -0.779140149474
# VQE energy       : -0.778727532734
# Energy error     : 4.126167e-04
# Fidelity         : 0.999784280761
# Tracking overlap : 0.962857217370
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611446839242
# Fidelity = 0.999870609282
# Overlap  = 0.977891029047
#
# Restart 1
# Energy   = -0.610034437787
# Fidelity = 0.998172725794
# Overlap  = 0.975683744853
#
# Restart 2
# Energy   = -0.610468986427
# Fidelity = 0.999279459786
# Overlap  = 0.976973076629
#
# Restart 3
# Energy   = -0.610855900957
# Fidelity = 0.999466615499
# Overlap  = 0.976966607654
#
# Restart 4
# Energy   = -0.611287212245
# Fidelity = 0.999751177313
# Overlap  = 0.977461626523
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723602270
# VQE energy       : -0.611446839242
# Energy error     : 2.767630e-04
# Fidelity         : 0.999870609282
# Tracking overlap : 0.977891029047
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484125934308
# Fidelity = 0.999955785316
# Overlap  = 0.986194648419
#
# Restart 1
# Energy   = -0.482451626326
# Fidelity = 0.999338706171
# Overlap  = 0.984140720184
#
# Restart 2
# Energy   = -0.483316994266
# Fidelity = 0.999521090954
# Overlap  = 0.985185515973
#
# Restart 3
# Energy   = -0.482851349931
# Fidelity = 0.999015197324
# Overlap  = 0.984465581147
#
# Restart 4
# Energy   = -0.483399199074
# Fidelity = 0.999367386564
# Overlap  = 0.984572679493
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295546782
# VQE energy       : -0.484125934308
# Energy error     : 1.696125e-04
# Fidelity         : 0.999955785316
# Tracking overlap : 0.986194648419
# Layers            : 4
# Pauli terms       : 160
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9439026850      -16.9366427234      7.2600e-03        0.9991903741      1.0000000000      4
# 0.3111      -8.8920696585       -8.8907684271       1.3012e-03        0.9995257845      0.8740951429      4
# 0.5222      -4.3793295654       -4.3785671983       7.6237e-04        0.7879158842      0.0494287644      4
# 0.7333      -2.7498265014       -2.7481483105       1.6782e-03        0.9711430786      0.0000036985      4
# 0.9444      -1.8747058908       -1.8745938332       1.1206e-04        0.9988039922      0.8177606756      4
# 1.1556      -1.3488231872       -1.3487666429       5.6544e-05        0.9999656559      0.8944009990      4
# 1.3667      -1.0104401641       -1.0100341264       4.0604e-04        0.9995992093      0.9366815318      4
# 1.5778      -0.7791401495       -0.7787275327       4.1262e-04        0.9997842808      0.9628572174      4
# 1.7889      -0.6117236023       -0.6114468392       2.7676e-04        0.9998706093      0.9778910290      4
# 2.0000      -0.4842955468       -0.4841259343       1.6961e-04        0.9999557853      0.9861946484      4
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.745808436328
# Fidelity = 0.996607799533
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -20.740865855025
# Fidelity = 0.996463758167
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -20.749828291275
# Fidelity = 0.997648009359
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -20.747828483924
# Fidelity = 0.997395699054
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -20.757120233960
# Fidelity = 0.998137158788
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.757120233960
# Energy error     : 2.020821e-02
# Fidelity         : 0.998137158788
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.811155891437
# Fidelity = 0.996244914480
# Overlap  = 0.854100343333
#
# Restart 1
# Energy   = -12.796148846469
# Fidelity = 0.994240548775
# Overlap  = 0.857714588265
#
# Restart 2
# Energy   = -12.790241402524
# Fidelity = 0.993502509867
# Overlap  = 0.870162253568
#
# Restart 3
# Energy   = -12.803922155466
# Fidelity = 0.995124026961
# Overlap  = 0.860145398546
#
# Restart 4
# Energy   = -12.790393951868
# Fidelity = 0.993086681714
# Overlap  = 0.861996940742
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.811155891437
# Energy error     : 2.528525e-02
# Fidelity         : 0.996244914480
# Tracking overlap : 0.854100343333
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.669624864297
# Fidelity = 0.989530914715
# Overlap  = 0.171546028785
#
# Restart 1
# Energy   = -7.667268952735
# Fidelity = 0.988153854607
# Overlap  = 0.167317872621
#
# Restart 2
# Energy   = -7.681795047683
# Fidelity = 0.990790084359
# Overlap  = 0.167494512365
#
# Restart 3
# Energy   = -7.656421065999
# Fidelity = 0.986169479682
# Overlap  = 0.173522796030
#
# Restart 4
# Energy   = -7.682371887613
# Fidelity = 0.992324160498
# Overlap  = 0.173379066256
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.682371887613
# Energy error     : 4.834448e-02
# Fidelity         : 0.992324160498
# Tracking overlap : 0.173379066256
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.510775803523
# Fidelity = 0.995298326513
# Overlap  = 0.628714800188
#
# Restart 1
# Energy   = -5.494071248871
# Fidelity = 0.990217145430
# Overlap  = 0.626515391333
#
# Restart 2
# Energy   = -5.501236137532
# Fidelity = 0.993181347137
# Overlap  = 0.621606602569
#
# Restart 3
# Energy   = -5.502937890645
# Fidelity = 0.993533647194
# Overlap  = 0.621131928672
#
# Restart 4
# Energy   = -5.512158864210
# Fidelity = 0.995534713946
# Overlap  = 0.627830616873
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.512158864210
# Energy error     : 2.598997e-02
# Fidelity         : 0.995534713946
# Tracking overlap : 0.627830616873
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.266640243869
# Fidelity = 0.998653775562
# Overlap  = 0.815911324188
#
# Restart 1
# Energy   = -4.252903513565
# Fidelity = 0.995860083307
# Overlap  = 0.820913025341
#
# Restart 2
# Energy   = -4.260736953472
# Fidelity = 0.997726991211
# Overlap  = 0.813549769305
#
# Restart 3
# Energy   = -4.257404570749
# Fidelity = 0.996802831574
# Overlap  = 0.814465160135
#
# Restart 4
# Energy   = -4.258992328162
# Fidelity = 0.997274414401
# Overlap  = 0.820458806955
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.266640243869
# Energy error     : 9.373549e-03
# Fidelity         : 0.998653775562
# Tracking overlap : 0.815911324188
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.446424371971
# Fidelity = 0.999743521850
# Overlap  = 0.908762451573
#
# Restart 1
# Energy   = -3.434892933721
# Fidelity = 0.997603077945
# Overlap  = 0.909353484585
#
# Restart 2
# Energy   = -3.423943195121
# Fidelity = 0.994995271454
# Overlap  = 0.901448799829
#
# Restart 3
# Energy   = -3.438619468777
# Fidelity = 0.997805758915
# Overlap  = 0.908746384870
#
# Restart 4
# Energy   = -3.444173344267
# Fidelity = 0.999442303396
# Overlap  = 0.907829765615
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.446424371971
# Energy error     : 2.256013e-03
# Fidelity         : 0.999743521850
# Tracking overlap : 0.908762451573
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.858811986003
# Fidelity = 0.999752419540
# Overlap  = 0.942751488636
#
# Restart 1
# Energy   = -2.849608436638
# Fidelity = 0.998517650456
# Overlap  = 0.941890258195
#
# Restart 2
# Energy   = -2.852607102793
# Fidelity = 0.998864424500
# Overlap  = 0.941368458248
#
# Restart 3
# Energy   = -2.857609768882
# Fidelity = 0.999588343834
# Overlap  = 0.941352935264
#
# Restart 4
# Energy   = -2.840501371951
# Fidelity = 0.996377544898
# Overlap  = 0.931841759707
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.858811986003
# Energy error     : 2.020279e-03
# Fidelity         : 0.999752419540
# Tracking overlap : 0.942751488636
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.418125184671
# Fidelity = 0.999767644685
# Overlap  = 0.962619719275
#
# Restart 1
# Energy   = -2.400566499359
# Fidelity = 0.996467288665
# Overlap  = 0.957653307351
#
# Restart 2
# Energy   = -2.397385215522
# Fidelity = 0.995905107252
# Overlap  = 0.955296588077
#
# Restart 3
# Energy   = -2.401956994377
# Fidelity = 0.996673664474
# Overlap  = 0.951635060696
#
# Restart 4
# Energy   = -2.395349250927
# Fidelity = 0.995706953930
# Overlap  = 0.951364745247
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.418125184671
# Energy error     : 1.965345e-03
# Fidelity         : 0.999767644685
# Tracking overlap : 0.962619719275
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.074721108614
# Fidelity = 0.999823904969
# Overlap  = 0.973761534850
#
# Restart 1
# Energy   = -2.059931621027
# Fidelity = 0.998094837900
# Overlap  = 0.970570717808
#
# Restart 2
# Energy   = -2.062777164184
# Fidelity = 0.997737610563
# Overlap  = 0.966641603453
#
# Restart 3
# Energy   = -2.064524939486
# Fidelity = 0.997763861084
# Overlap  = 0.966618473083
#
# Restart 4
# Energy   = -2.058920571960
# Fidelity = 0.996159215132
# Overlap  = 0.965753738297
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.074721108614
# Energy error     : 1.591459e-03
# Fidelity         : 0.999823904969
# Tracking overlap : 0.973761534850
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.798702744581
# Fidelity = 0.999856612975
# Overlap  = 0.981798412536
#
# Restart 1
# Energy   = -1.780661890030
# Fidelity = 0.996177829780
# Overlap  = 0.973248009027
#
# Restart 2
# Energy   = -1.783132162001
# Fidelity = 0.996977671711
# Overlap  = 0.972957273945
#
# Restart 3
# Energy   = -1.784533052233
# Fidelity = 0.997603115643
# Overlap  = 0.976544976631
#
# Restart 4
# Energy   = -1.789850227657
# Fidelity = 0.998477151401
# Overlap  = 0.977243821006
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.798702744581
# Energy error     : 1.370522e-03
# Fidelity         : 0.999856612975
# Tracking overlap : 0.981798412536
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Strong SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -20.7773284453      -20.7571202340      2.0208e-02        0.9981371588      1.0000000000      4
# 0.3111      -12.8364411428      -12.8111558914      2.5285e-02        0.9962449145      0.8541003433      4
# 0.5222      -7.7307163648       -7.6823718876       4.8344e-02        0.9923241605      0.1733790663      4
# 0.7333      -5.5381488307       -5.5121588642       2.5990e-02        0.9955347139      0.6278306169      4
# 0.9444      -4.2760137929       -4.2666402439       9.3735e-03        0.9986537756      0.8159113242      4
# 1.1556      -3.4486803854       -3.4464243720       2.2560e-03        0.9997435219      0.9087624516      4
# 1.3667      -2.8608322652       -2.8588119860       2.0203e-03        0.9997524195      0.9427514886      4
# 1.5778      -2.4200905293       -2.4181251847       1.9653e-03        0.9997676447      0.9626197193      4
# 1.7889      -2.0763125676       -2.0747211086       1.5915e-03        0.9998239050      0.9737615348      4
# 2.0000      -1.8000732662       -1.7987027446       1.3705e-03        0.9998566130      0.9817984125      4

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#
plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HVA_Floc vs lambda different f.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    
    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,
        'psi_vqe': psi_vqe,
        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119709
# T = 2     Fidelity = 0.99733303
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98268021
# T = 2     Fidelity = 0.99772142
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394553
# T = 2     Fidelity = 0.99802527
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98503532
# T = 2     Fidelity = 0.99826564
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98600363
# T = 2     Fidelity = 0.99846374
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98685099
# T = 2     Fidelity = 0.99862415
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762201
# T = 2     Fidelity = 0.99876049
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98831387
# T = 2     Fidelity = 0.99887385
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98894646
# T = 2     Fidelity = 0.99897372
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98947999
# T = 2     Fidelity = 0.99904403
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000008
# T = 2     Fidelity = 0.00000003
# T = 5     Fidelity = 0.00039067
# T = 10    Fidelity = 0.00055718
# T = 20    Fidelity = 0.01214056
# T = 30    Fidelity = 0.08016827
# T = 40    Fidelity = 0.18879688
# T = 50    Fidelity = 0.43136194
# T = 75    Fidelity = 0.56457945
# T = 100   Fidelity = 0.73160897
# T = 125   Fidelity = 0.79939421
# T = 150   Fidelity = 0.83934389
# T = 175   Fidelity = 0.90042512
# T = 200   Fidelity = 0.92138577
# T = 225   Fidelity = 0.96402662
# T = 250   Fidelity = 0.89146172
# T = 275   Fidelity = 0.96608117
# T = 300   Fidelity = 0.85857609
# T = 400   Fidelity = 0.97950090
# T = 500   Fidelity = 0.96162292
# T = 600   Fidelity = 0.96084565
# T = 700   Fidelity = 0.61887372
# T = 800   Fidelity = 0.83394324
# T = 900   Fidelity = 0.82974666
# T = 1000  Fidelity = 0.66512930
# T = 1010  Fidelity = 0.57682171
# T = 1020  Fidelity = 0.62341551
# T = 1030  Fidelity = 0.70180584
# T = 1040  Fidelity = 0.71814297
# T = 1050  Fidelity = 0.79073546
# T = 1060  Fidelity = 0.91828546
# T = 1070  Fidelity = 0.77742077
# T = 1080  Fidelity = 0.78983379
# T = 1090  Fidelity = 0.71241816
# T = 1100  Fidelity = 0.38514390
# T = 1200  Fidelity = 0.59330784
# T = 1300  Fidelity = 0.48718780
# T = 1400  Fidelity = 0.71247213
# T = 1500  Fidelity = 0.45945515
# T = 2000  Fidelity = 0.93713034
# T = 2100  Fidelity = 0.70784789
# T = 2110  Fidelity = 0.56602556
# T = 2120  Fidelity = 0.46659374
# T = 2130  Fidelity = 0.38965804
# T = 2140  Fidelity = 0.48962301
# T = 2150  Fidelity = 0.40926606
# T = 2160  Fidelity = 0.62184080
# T = 2170  Fidelity = 0.52175940
# T = 2180  Fidelity = 0.49472504
# T = 2190  Fidelity = 0.50400120
# T = 2200  Fidelity = 0.35371912
# T = 2300  Fidelity = 0.77660969
# T = 2400  Fidelity = 0.22263988
# T = 2500  Fidelity = 0.75846833
# T = 2600  Fidelity = 0.43801395
# T = 2700  Fidelity = 0.55163246
# T = 2800  Fidelity = 0.84593835
# T = 2900  Fidelity = 0.64017889
# T = 3000  Fidelity = 0.83061452
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00976726e+00
# P0     = 0.83061452
# P1     = 0.05741332
# P0+P1  = 0.88802784
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000010
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00047591
# T = 10    Fidelity = 0.06773964
# T = 20    Fidelity = 0.21841049
# T = 30    Fidelity = 0.62278889
# T = 40    Fidelity = 0.35298554
# T = 50    Fidelity = 0.79047984
# T = 75    Fidelity = 0.74343989
# T = 100   Fidelity = 0.79656958
# T = 125   Fidelity = 0.87793901
# T = 150   Fidelity = 0.88056033
# T = 175   Fidelity = 0.90001853
# T = 200   Fidelity = 0.92442017
# T = 225   Fidelity = 0.93427829
# T = 250   Fidelity = 0.94548671
# T = 275   Fidelity = 0.95006060
# T = 300   Fidelity = 0.94974705
# T = 400   Fidelity = 0.97173633
# T = 500   Fidelity = 0.97418416
# T = 600   Fidelity = 0.83446563
# T = 700   Fidelity = 0.81479606
# T = 800   Fidelity = 0.86728533
# T = 900   Fidelity = 0.72072314
# T = 1000  Fidelity = 0.76543990
# T = 1010  Fidelity = 0.88439441
# T = 1020  Fidelity = 0.85328492
# T = 1030  Fidelity = 0.91516653
# T = 1040  Fidelity = 0.84122349
# T = 1050  Fidelity = 0.86341656
# T = 1060  Fidelity = 0.74568597
# T = 1070  Fidelity = 0.78153012
# T = 1080  Fidelity = 0.53100050
# T = 1090  Fidelity = 0.67429162
# T = 1100  Fidelity = 0.54800679
# T = 1200  Fidelity = 0.78160119
# T = 1300  Fidelity = 0.82367711
# T = 1400  Fidelity = 0.94181308
# T = 1500  Fidelity = 0.85685367
# T = 2000  Fidelity = 0.59323496
# T = 2100  Fidelity = 0.60706619
# T = 2110  Fidelity = 0.68405028
# T = 2120  Fidelity = 0.81460188
# T = 2130  Fidelity = 0.95646151
# T = 2140  Fidelity = 0.76352519
# T = 2150  Fidelity = 0.82152638
# T = 2160  Fidelity = 0.89028399
# T = 2170  Fidelity = 0.58955609
# T = 2180  Fidelity = 0.88849291
# T = 2190  Fidelity = 0.57976729
# T = 2200  Fidelity = 0.47680630
# T = 2300  Fidelity = 0.48188526
# T = 2400  Fidelity = 0.66198018
# T = 2500  Fidelity = 0.32037129
# T = 2600  Fidelity = 0.91849884
# T = 2700  Fidelity = 0.85120853
# T = 2800  Fidelity = 0.86387147
# T = 2900  Fidelity = 0.84127653
# T = 3000  Fidelity = 0.87574459
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02946706e+00
# P0     = 0.87574459
# P1     = 0.01092733
# P0+P1  = 0.88667192
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00006699
# T = 2     Fidelity = 0.00047273
# T = 5     Fidelity = 0.01768284
# T = 10    Fidelity = 0.20827015
# T = 20    Fidelity = 0.59345336
# T = 30    Fidelity = 0.64972813
# T = 40    Fidelity = 0.78540018
# T = 50    Fidelity = 0.81110261
# T = 75    Fidelity = 0.91786799
# T = 100   Fidelity = 0.95930088
# T = 125   Fidelity = 0.97568184
# T = 150   Fidelity = 0.98279318
# T = 175   Fidelity = 0.98731188
# T = 200   Fidelity = 0.98762932
# T = 225   Fidelity = 0.98878185
# T = 250   Fidelity = 0.98725354
# T = 275   Fidelity = 0.98094516
# T = 300   Fidelity = 0.97887115
# T = 400   Fidelity = 0.96843224
# T = 500   Fidelity = 0.92849926
# T = 600   Fidelity = 0.88439933
# T = 700   Fidelity = 0.93491628
# T = 800   Fidelity = 0.90344923
# T = 900   Fidelity = 0.85317384
# T = 1000  Fidelity = 0.74853227
# T = 1010  Fidelity = 0.65042027
# T = 1020  Fidelity = 0.87261901
# T = 1030  Fidelity = 0.53046001
# T = 1040  Fidelity = 0.94221536
# T = 1050  Fidelity = 0.68448228
# T = 1060  Fidelity = 0.83904678
# T = 1070  Fidelity = 0.92882858
# T = 1080  Fidelity = 0.78599367
# T = 1090  Fidelity = 0.98020614
# T = 1100  Fidelity = 0.93392810
# T = 1200  Fidelity = 0.93390391
# T = 1300  Fidelity = 0.92062494
# T = 1400  Fidelity = 0.92682349
# T = 1500  Fidelity = 0.95722026
# T = 2000  Fidelity = 0.85399823
# T = 2100  Fidelity = 0.80788653
# T = 2110  Fidelity = 0.70922052
# T = 2120  Fidelity = 0.86723648
# T = 2130  Fidelity = 0.93419309
# T = 2140  Fidelity = 0.85863269
# T = 2150  Fidelity = 0.87719347
# T = 2160  Fidelity = 0.73368218
# T = 2170  Fidelity = 0.73554702
# T = 2180  Fidelity = 0.78772066
# T = 2190  Fidelity = 0.76377340
# T = 2200  Fidelity = 0.68351088
# T = 2300  Fidelity = 0.73188243
# T = 2400  Fidelity = 0.86644103
# T = 2500  Fidelity = 0.86578316
# T = 2600  Fidelity = 0.77397721
# T = 2700  Fidelity = 0.94341470
# T = 2800  Fidelity = 0.96734885
# T = 2900  Fidelity = 0.96069608
# T = 3000  Fidelity = 0.94067856
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04808582e+00
# P0     = 0.94067856
# P1     = 0.00082265
# P0+P1  = 0.94150121
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00115575
# T = 2     Fidelity = 0.00527345
# T = 5     Fidelity = 0.06470213
# T = 10    Fidelity = 0.28077587
# T = 20    Fidelity = 0.67726037
# T = 30    Fidelity = 0.73687731
# T = 40    Fidelity = 0.81383724
# T = 50    Fidelity = 0.88592945
# T = 75    Fidelity = 0.95182876
# T = 100   Fidelity = 0.97877137
# T = 125   Fidelity = 0.98953382
# T = 150   Fidelity = 0.99322613
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00868678
# T = 2     Fidelity = 0.02415793
# T = 5     Fidelity = 0.12727935
# T = 10    Fidelity = 0.34345465
# T = 20    Fidelity = 0.66829800
# T = 30    Fidelity = 0.79617208
# T = 40    Fidelity = 0.85846053
# T = 50    Fidelity = 0.90902981
# T = 75    Fidelity = 0.97008805
# T = 100   Fidelity = 0.98874919
# T = 125   Fidelity = 0.99520581
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03436053
# T = 2     Fidelity = 0.07373236
# T = 5     Fidelity = 0.22322853
# T = 10    Fidelity = 0.42915088
# T = 20    Fidelity = 0.67981070
# T = 30    Fidelity = 0.80128580
# T = 40    Fidelity = 0.86976596
# T = 50    Fidelity = 0.91652941
# T = 75    Fidelity = 0.97753440
# T = 100   Fidelity = 0.99430798
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09548004
# T = 2     Fidelity = 0.17369317
# T = 5     Fidelity = 0.36461953
# T = 10    Fidelity = 0.55408957
# T = 20    Fidelity = 0.73955446
# T = 30    Fidelity = 0.82897780
# T = 40    Fidelity = 0.88140191
# T = 50    Fidelity = 0.91618872
# T = 75    Fidelity = 0.96520263
# T = 100   Fidelity = 0.98465724
# T = 125   Fidelity = 0.99198158
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19140183
# T = 2     Fidelity = 0.31258726
# T = 5     Fidelity = 0.52453510
# T = 10    Fidelity = 0.69081743
# T = 20    Fidelity = 0.82686477
# T = 30    Fidelity = 0.88697227
# T = 40    Fidelity = 0.92168364
# T = 50    Fidelity = 0.94351801
# T = 75    Fidelity = 0.97028724
# T = 100   Fidelity = 0.98286013
# T = 125   Fidelity = 0.98851463
# T = 150   Fidelity = 0.99141180
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30141261
# T = 2     Fidelity = 0.45493843
# T = 5     Fidelity = 0.66213475
# T = 10    Fidelity = 0.79869198
# T = 20    Fidelity = 0.89455245
# T = 30    Fidelity = 0.93327526
# T = 40    Fidelity = 0.95490731
# T = 50    Fidelity = 0.96697968
# T = 75    Fidelity = 0.98284173
# T = 100   Fidelity = 0.98921842
# T = 125   Fidelity = 0.99262825
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40374508
# T = 2     Fidelity = 0.57456429
# T = 5     Fidelity = 0.76193971
# T = 10    Fidelity = 0.87021337
# T = 20    Fidelity = 0.93698729
# T = 30    Fidelity = 0.96235520
# T = 40    Fidelity = 0.97423470
# T = 50    Fidelity = 0.98187888
# T = 75    Fidelity = 0.99087956
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.36752113e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00065072
# T = 10    Fidelity = 0.00010868
# T = 20    Fidelity = 0.00391723
# T = 30    Fidelity = 0.05478752
# T = 40    Fidelity = 0.12224850
# T = 50    Fidelity = 0.21150158
# T = 75    Fidelity = 0.57797919
# T = 100   Fidelity = 0.76492744
# T = 125   Fidelity = 0.73501652
# T = 150   Fidelity = 0.86701094
# T = 175   Fidelity = 0.91083761
# T = 200   Fidelity = 0.87376431
# T = 225   Fidelity = 0.95020594
# T = 250   Fidelity = 0.98357102
# T = 275   Fidelity = 0.98414029
# T = 300   Fidelity = 0.86075915
# T = 400   Fidelity = 0.91385619
# T = 500   Fidelity = 0.92766170
# T = 600   Fidelity = 0.91794970
# T = 700   Fidelity = 0.91375420
# T = 800   Fidelity = 0.82048320
# T = 900   Fidelity = 0.78143285
# T = 1000  Fidelity = 0.67016868
# T = 1010  Fidelity = 0.51904112
# T = 1020  Fidelity = 0.57181826
# T = 1030  Fidelity = 0.75130507
# T = 1040  Fidelity = 0.89672421
# T = 1050  Fidelity = 0.85707478
# T = 1060  Fidelity = 0.83482921
# T = 1070  Fidelity = 0.70400399
# T = 1080  Fidelity = 0.54447280
# T = 1090  Fidelity = 0.51495989
# T = 1100  Fidelity = 0.55415401
# T = 1200  Fidelity = 0.67082609
# T = 1300  Fidelity = 0.58543733
# T = 1400  Fidelity = 0.67032277
# T = 1500  Fidelity = 0.29301530
# T = 2000  Fidelity = 0.11302176
# T = 2100  Fidelity = 0.68080780
# T = 2110  Fidelity = 0.68185003
# T = 2120  Fidelity = 0.72853489
# T = 2130  Fidelity = 0.80953457
# T = 2140  Fidelity = 0.85132506
# T = 2150  Fidelity = 0.91823336
# T = 2160  Fidelity = 0.90505354
# T = 2170  Fidelity = 0.86764009
# T = 2180  Fidelity = 0.77882375
# T = 2190  Fidelity = 0.40837571
# T = 2200  Fidelity = 0.26181548
# T = 2300  Fidelity = 0.55594002
# T = 2400  Fidelity = 0.82365546
# T = 2500  Fidelity = 0.90675254
# T = 2600  Fidelity = 0.80653450
# T = 2700  Fidelity = 0.80745528
# T = 2800  Fidelity = 0.34934915
# T = 2900  Fidelity = 0.89209331
# T = 3000  Fidelity = 0.74532269
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00970921e+00
# P0     = 0.74532269
# P1     = 0.03786529
# P0+P1  = 0.78318798
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.12924856e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000009
# T = 5     Fidelity = 0.00018189
# T = 10    Fidelity = 0.04112919
# T = 20    Fidelity = 0.41980700
# T = 30    Fidelity = 0.49032441
# T = 40    Fidelity = 0.64193747
# T = 50    Fidelity = 0.64338452
# T = 75    Fidelity = 0.87983499
# T = 100   Fidelity = 0.90199985
# T = 125   Fidelity = 0.87125970
# T = 150   Fidelity = 0.88451800
# T = 175   Fidelity = 0.91860467
# T = 200   Fidelity = 0.93954522
# T = 225   Fidelity = 0.95271717
# T = 250   Fidelity = 0.94658648
# T = 275   Fidelity = 0.95641268
# T = 300   Fidelity = 0.93752508
# T = 400   Fidelity = 0.97135282
# T = 500   Fidelity = 0.95457594
# T = 600   Fidelity = 0.92974472
# T = 700   Fidelity = 0.56574657
# T = 800   Fidelity = 0.62328323
# T = 900   Fidelity = 0.67967511
# T = 1000  Fidelity = 0.89029781
# T = 1010  Fidelity = 0.56713857
# T = 1020  Fidelity = 0.84347302
# T = 1030  Fidelity = 0.83962251
# T = 1040  Fidelity = 0.70868980
# T = 1050  Fidelity = 0.85391178
# T = 1060  Fidelity = 0.56514498
# T = 1070  Fidelity = 0.80504038
# T = 1080  Fidelity = 0.62281754
# T = 1090  Fidelity = 0.81573115
# T = 1100  Fidelity = 0.70531497
# T = 1200  Fidelity = 0.61376914
# T = 1300  Fidelity = 0.59802428
# T = 1400  Fidelity = 0.55043324
# T = 1500  Fidelity = 0.71193028
# T = 2000  Fidelity = 0.49534093
# T = 2100  Fidelity = 0.69867710
# T = 2110  Fidelity = 0.68006641
# T = 2120  Fidelity = 0.82103609
# T = 2130  Fidelity = 0.66435631
# T = 2140  Fidelity = 0.58877871
# T = 2150  Fidelity = 0.80093094
# T = 2160  Fidelity = 0.53179056
# T = 2170  Fidelity = 0.69413664
# T = 2180  Fidelity = 0.65639872
# T = 2190  Fidelity = 0.76838423
# T = 2200  Fidelity = 0.50516066
# T = 2300  Fidelity = 0.68320931
# T = 2400  Fidelity = 0.68115963
# T = 2500  Fidelity = 0.67088575
# T = 2600  Fidelity = 0.72318790
# T = 2700  Fidelity = 0.75421103
# T = 2800  Fidelity = 0.78468773
# T = 2900  Fidelity = 0.52079317
# T = 3000  Fidelity = 0.55825479
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02931057e+00
# P0     = 0.55825479
# P1     = 0.21185036
# P0+P1  = 0.77010515
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00001140
# T = 2     Fidelity = 0.00016801
# T = 5     Fidelity = 0.01427370
# T = 10    Fidelity = 0.17072859
# T = 20    Fidelity = 0.44185745
# T = 30    Fidelity = 0.33904264
# T = 40    Fidelity = 0.54617901
# T = 50    Fidelity = 0.43762732
# T = 75    Fidelity = 0.49249608
# T = 100   Fidelity = 0.50213548
# T = 125   Fidelity = 0.50208427
# T = 150   Fidelity = 0.50121929
# T = 175   Fidelity = 0.50042545
# T = 200   Fidelity = 0.49596509
# T = 225   Fidelity = 0.50761601
# T = 250   Fidelity = 0.50020653
# T = 275   Fidelity = 0.48631350
# T = 300   Fidelity = 0.48629192
# T = 400   Fidelity = 0.49692503
# T = 500   Fidelity = 0.30773527
# T = 600   Fidelity = 0.50730236
# T = 700   Fidelity = 0.38767310
# T = 800   Fidelity = 0.53308643
# T = 900   Fidelity = 0.52865129
# T = 1000  Fidelity = 0.69853750
# T = 1010  Fidelity = 0.39757122
# T = 1020  Fidelity = 0.40057253
# T = 1030  Fidelity = 0.46926991
# T = 1040  Fidelity = 0.49694758
# T = 1050  Fidelity = 0.46759863
# T = 1060  Fidelity = 0.36749249
# T = 1070  Fidelity = 0.56060727
# T = 1080  Fidelity = 0.26753809
# T = 1090  Fidelity = 0.27572953
# T = 1100  Fidelity = 0.61052092
# T = 1200  Fidelity = 0.29282217
# T = 1300  Fidelity = 0.55362225
# T = 1400  Fidelity = 0.53559784
# T = 1500  Fidelity = 0.36321334
# T = 2000  Fidelity = 0.29260179
# T = 2100  Fidelity = 0.20267123
# T = 2110  Fidelity = 0.55173151
# T = 2120  Fidelity = 0.47241104
# T = 2130  Fidelity = 0.50308632
# T = 2140  Fidelity = 0.32610037
# T = 2150  Fidelity = 0.44786463
# T = 2160  Fidelity = 0.38837325
# T = 2170  Fidelity = 0.39123854
# T = 2180  Fidelity = 0.53490289
# T = 2190  Fidelity = 0.19507887
# T = 2200  Fidelity = 0.48377142
# T = 2300  Fidelity = 0.53649336
# T = 2400  Fidelity = 0.49109138
# T = 2500  Fidelity = 0.46170824
# T = 2600  Fidelity = 0.45998477
# T = 2700  Fidelity = 0.57367584
# T = 2800  Fidelity = 0.60073817
# T = 2900  Fidelity = 0.46096679
# T = 3000  Fidelity = 0.43243340
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.43243340
# P1     = 0.05510414
# P0+P1  = 0.48753754
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.03672155e-03
# T = 1     Fidelity = 0.00319524
# T = 2     Fidelity = 0.01260395
# T = 5     Fidelity = 0.08410976
# T = 10    Fidelity = 0.22140838
# T = 20    Fidelity = 0.31421774
# T = 30    Fidelity = 0.37970699
# T = 40    Fidelity = 0.54462252
# T = 50    Fidelity = 0.57506533
# T = 75    Fidelity = 0.49546066
# T = 100   Fidelity = 0.51661980
# T = 125   Fidelity = 0.51806651
# T = 150   Fidelity = 0.51778465
# T = 175   Fidelity = 0.51449721
# T = 200   Fidelity = 0.52466380
# T = 225   Fidelity = 0.51721154
# T = 250   Fidelity = 0.51257155
# T = 275   Fidelity = 0.52040499
# T = 300   Fidelity = 0.48916882
# T = 400   Fidelity = 0.50362406
# T = 500   Fidelity = 0.54656505
# T = 600   Fidelity = 0.50216234
# T = 700   Fidelity = 0.43600049
# T = 800   Fidelity = 0.44588582
# T = 900   Fidelity = 0.52267230
# T = 1000  Fidelity = 0.76605150
# T = 1010  Fidelity = 0.44022898
# T = 1020  Fidelity = 0.12309535
# T = 1030  Fidelity = 0.54832017
# T = 1040  Fidelity = 0.77827183
# T = 1050  Fidelity = 0.58717555
# T = 1060  Fidelity = 0.47809351
# T = 1070  Fidelity = 0.49009509
# T = 1080  Fidelity = 0.41466419
# T = 1090  Fidelity = 0.24849231
# T = 1100  Fidelity = 0.72770464
# T = 1200  Fidelity = 0.57773535
# T = 1300  Fidelity = 0.44627054
# T = 1400  Fidelity = 0.51331160
# T = 1500  Fidelity = 0.52632835
# T = 2000  Fidelity = 0.44544546
# T = 2100  Fidelity = 0.50611691
# T = 2110  Fidelity = 0.54131991
# T = 2120  Fidelity = 0.45662255
# T = 2130  Fidelity = 0.38185607
# T = 2140  Fidelity = 0.54668685
# T = 2150  Fidelity = 0.75420147
# T = 2160  Fidelity = 0.43255995
# T = 2170  Fidelity = 0.23636911
# T = 2180  Fidelity = 0.48106725
# T = 2190  Fidelity = 0.67116204
# T = 2200  Fidelity = 0.60367864
# T = 2300  Fidelity = 0.79993612
# T = 2400  Fidelity = 0.52259753
# T = 2500  Fidelity = 0.49200858
# T = 2600  Fidelity = 0.53843257
# T = 2700  Fidelity = 0.43675297
# T = 2800  Fidelity = 0.52206152
# T = 2900  Fidelity = 0.29910368
# T = 3000  Fidelity = 0.42389885
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.42389885
# P1     = 0.03800551
# P0+P1  = 0.46190435
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.41475042e-03
# T = 1     Fidelity = 0.02407444
# T = 2     Fidelity = 0.06522974
# T = 5     Fidelity = 0.21916419
# T = 10    Fidelity = 0.40687645
# T = 20    Fidelity = 0.52922267
# T = 30    Fidelity = 0.49773253
# T = 40    Fidelity = 0.50374818
# T = 50    Fidelity = 0.54912564
# T = 75    Fidelity = 0.60842784
# T = 100   Fidelity = 0.60680107
# T = 125   Fidelity = 0.61176150
# T = 150   Fidelity = 0.61569085
# T = 175   Fidelity = 0.61900432
# T = 200   Fidelity = 0.62598891
# T = 225   Fidelity = 0.62877242
# T = 250   Fidelity = 0.63244738
# T = 275   Fidelity = 0.62929438
# T = 300   Fidelity = 0.64549405
# T = 400   Fidelity = 0.59320019
# T = 500   Fidelity = 0.65250378
# T = 600   Fidelity = 0.67610014
# T = 700   Fidelity = 0.59345716
# T = 800   Fidelity = 0.71191182
# T = 900   Fidelity = 0.60720333
# T = 1000  Fidelity = 0.48571658
# T = 1010  Fidelity = 0.75816536
# T = 1020  Fidelity = 0.84955425
# T = 1030  Fidelity = 0.74903430
# T = 1040  Fidelity = 0.52825096
# T = 1050  Fidelity = 0.47340057
# T = 1060  Fidelity = 0.64830173
# T = 1070  Fidelity = 0.77531160
# T = 1080  Fidelity = 0.81949952
# T = 1090  Fidelity = 0.55514300
# T = 1100  Fidelity = 0.39970781
# T = 1200  Fidelity = 0.45846393
# T = 1300  Fidelity = 0.53927432
# T = 1400  Fidelity = 0.76705541
# T = 1500  Fidelity = 0.67820724
# T = 2000  Fidelity = 0.77024004
# T = 2100  Fidelity = 0.81539429
# T = 2110  Fidelity = 0.80544104
# T = 2120  Fidelity = 0.54868856
# T = 2130  Fidelity = 0.65207563
# T = 2140  Fidelity = 0.70882784
# T = 2150  Fidelity = 0.82760652
# T = 2160  Fidelity = 0.84264749
# T = 2170  Fidelity = 0.77825482
# T = 2180  Fidelity = 0.52966319
# T = 2190  Fidelity = 0.56694224
# T = 2200  Fidelity = 0.69623026
# T = 2300  Fidelity = 0.76385305
# T = 2400  Fidelity = 0.74993291
# T = 2500  Fidelity = 0.82224228
# T = 2600  Fidelity = 0.72633474
# T = 2700  Fidelity = 0.77340019
# T = 2800  Fidelity = 0.75718562
# T = 2900  Fidelity = 0.69344612
# T = 3000  Fidelity = 0.74607599
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.74607599
# P1     = 0.00893974
# P0+P1  = 0.75501574
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50213251e-02
# T = 1     Fidelity = 0.08280560
# T = 2     Fidelity = 0.17498002
# T = 5     Fidelity = 0.39236548
# T = 10    Fidelity = 0.58585254
# T = 20    Fidelity = 0.71377792
# T = 30    Fidelity = 0.72019677
# T = 40    Fidelity = 0.71298508
# T = 50    Fidelity = 0.71873091
# T = 75    Fidelity = 0.74410422
# T = 100   Fidelity = 0.76243866
# T = 125   Fidelity = 0.77525940
# T = 150   Fidelity = 0.78585354
# T = 175   Fidelity = 0.79500428
# T = 200   Fidelity = 0.80418959
# T = 225   Fidelity = 0.81044949
# T = 250   Fidelity = 0.81600065
# T = 275   Fidelity = 0.82610130
# T = 300   Fidelity = 0.81747884
# T = 400   Fidelity = 0.87428140
# T = 500   Fidelity = 0.87058916
# T = 600   Fidelity = 0.79417969
# T = 700   Fidelity = 0.82801831
# T = 800   Fidelity = 0.84468770
# T = 900   Fidelity = 0.85231329
# T = 1000  Fidelity = 0.87682477
# T = 1010  Fidelity = 0.79383727
# T = 1020  Fidelity = 0.77902253
# T = 1030  Fidelity = 0.86815736
# T = 1040  Fidelity = 0.95151453
# T = 1050  Fidelity = 0.97303572
# T = 1060  Fidelity = 0.93468200
# T = 1070  Fidelity = 0.82913109
# T = 1080  Fidelity = 0.84158013
# T = 1090  Fidelity = 0.76874197
# T = 1100  Fidelity = 0.82749476
# T = 1200  Fidelity = 0.79761291
# T = 1300  Fidelity = 0.95566733
# T = 1400  Fidelity = 0.85425215
# T = 1500  Fidelity = 0.92822146
# T = 2000  Fidelity = 0.85960503
# T = 2100  Fidelity = 0.86748112
# T = 2110  Fidelity = 0.86751314
# T = 2120  Fidelity = 0.92152818
# T = 2130  Fidelity = 0.86418388
# T = 2140  Fidelity = 0.88057445
# T = 2150  Fidelity = 0.80899394
# T = 2160  Fidelity = 0.83691401
# T = 2170  Fidelity = 0.95391979
# T = 2180  Fidelity = 0.93784596
# T = 2190  Fidelity = 0.93724644
# T = 2200  Fidelity = 0.94075293
# T = 2300  Fidelity = 0.95007443
# T = 2400  Fidelity = 0.97264191
# T = 2500  Fidelity = 0.96416297
# T = 2600  Fidelity = 0.98735880
# T = 2700  Fidelity = 0.96908301
# T = 2800  Fidelity = 0.95240689
# T = 2900  Fidelity = 0.85475450
# T = 3000  Fidelity = 0.97233240
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.09849352e+00
# P0     = 0.97233240
# P1     = 0.00014241
# P0+P1  = 0.97247481
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77221454e-02
# T = 1     Fidelity = 0.17587965
# T = 2     Fidelity = 0.31632373
# T = 5     Fidelity = 0.55512990
# T = 10    Fidelity = 0.72445195
# T = 20    Fidelity = 0.82892035
# T = 30    Fidelity = 0.85262052
# T = 40    Fidelity = 0.85852642
# T = 50    Fidelity = 0.86424227
# T = 75    Fidelity = 0.88168154
# T = 100   Fidelity = 0.89799108
# T = 125   Fidelity = 0.90939587
# T = 150   Fidelity = 0.91770535
# T = 175   Fidelity = 0.92532750
# T = 200   Fidelity = 0.93449764
# T = 225   Fidelity = 0.93543856
# T = 250   Fidelity = 0.93563754
# T = 275   Fidelity = 0.94496093
# T = 300   Fidelity = 0.93513243
# T = 400   Fidelity = 0.94894597
# T = 500   Fidelity = 0.95210734
# T = 600   Fidelity = 0.95996617
# T = 700   Fidelity = 0.91540827
# T = 800   Fidelity = 0.92741985
# T = 900   Fidelity = 0.94643599
# T = 1000  Fidelity = 0.93932241
# T = 1010  Fidelity = 0.95133771
# T = 1020  Fidelity = 0.95638345
# T = 1030  Fidelity = 0.97856148
# T = 1040  Fidelity = 0.99445253
#
# Minimum T for Fidelity >= 0.99 : 1040
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20187623e-01
# T = 1     Fidelity = 0.28028764
# T = 2     Fidelity = 0.45280696
# T = 5     Fidelity = 0.68134603
# T = 10    Fidelity = 0.81896077
# T = 20    Fidelity = 0.89633562
# T = 30    Fidelity = 0.91779467
# T = 40    Fidelity = 0.92915025
# T = 50    Fidelity = 0.93781638
# T = 75    Fidelity = 0.95151383
# T = 100   Fidelity = 0.96177847
# T = 125   Fidelity = 0.96819479
# T = 150   Fidelity = 0.97404768
# T = 175   Fidelity = 0.97570455
# T = 200   Fidelity = 0.98151643
# T = 225   Fidelity = 0.97791624
# T = 250   Fidelity = 0.98107095
# T = 275   Fidelity = 0.97876863
# T = 300   Fidelity = 0.97977088
# T = 400   Fidelity = 0.97480051
# T = 500   Fidelity = 0.95334199
# T = 600   Fidelity = 0.93774854
# T = 700   Fidelity = 0.97955717
# T = 800   Fidelity = 0.98421805
# T = 900   Fidelity = 0.98898980
# T = 1000  Fidelity = 0.97902809
# T = 1010  Fidelity = 0.97127315
# T = 1020  Fidelity = 0.99546333
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405779e-01
# T = 1     Fidelity = 0.37845615
# T = 2     Fidelity = 0.56608371
# T = 5     Fidelity = 0.76963102
# T = 10    Fidelity = 0.87867144
# T = 20    Fidelity = 0.93500377
# T = 30    Fidelity = 0.95256106
# T = 40    Fidelity = 0.96380550
# T = 50    Fidelity = 0.96950859
# T = 75    Fidelity = 0.97944455
# T = 100   Fidelity = 0.98500102
# T = 125   Fidelity = 0.98824334
# T = 150   Fidelity = 0.99058756
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843475e-01
# T = 1     Fidelity = 0.46430314
# T = 2     Fidelity = 0.65592201
# T = 5     Fidelity = 0.83126441
# T = 10    Fidelity = 0.91720629
# T = 20    Fidelity = 0.95856732
# T = 30    Fidelity = 0.97286229
# T = 40    Fidelity = 0.97908929
# T = 50    Fidelity = 0.98364520
# T = 75    Fidelity = 0.99018034
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000003
# T = 2     Fidelity = 0.00000004
# T = 5     Fidelity = 0.00071335
# T = 10    Fidelity = 0.06453580
# T = 20    Fidelity = 0.45638603
# T = 30    Fidelity = 0.87591636
# T = 40    Fidelity = 0.96807216
# T = 50    Fidelity = 0.98899759
# T = 75    Fidelity = 0.99581040
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000011
# T = 2     Fidelity = 0.00000215
# T = 5     Fidelity = 0.02532360
# T = 10    Fidelity = 0.89315658
# T = 20    Fidelity = 0.96614745
# T = 30    Fidelity = 0.99307676
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00007811
# T = 2     Fidelity = 0.00066145
# T = 5     Fidelity = 0.18283311
# T = 10    Fidelity = 0.97957954
# T = 20    Fidelity = 0.98690507
# T = 30    Fidelity = 0.98341912
# T = 40    Fidelity = 0.98579722
# T = 50    Fidelity = 0.99019218
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00121665
# T = 2     Fidelity = 0.00814103
# T = 5     Fidelity = 0.33924773
# T = 10    Fidelity = 0.98162858
# T = 20    Fidelity = 0.98900679
# T = 30    Fidelity = 0.98903585
# T = 40    Fidelity = 0.99033984
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00710932
# T = 2     Fidelity = 0.02937781
# T = 5     Fidelity = 0.46673171
# T = 10    Fidelity = 0.97893134
# T = 20    Fidelity = 0.99154192
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02107099
# T = 2     Fidelity = 0.06477690
# T = 5     Fidelity = 0.56328260
# T = 10    Fidelity = 0.97544191
# T = 20    Fidelity = 0.99219393
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04415303
# T = 2     Fidelity = 0.11107593
# T = 5     Fidelity = 0.63665559
# T = 10    Fidelity = 0.97149677
# T = 20    Fidelity = 0.99251603
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07595433
# T = 2     Fidelity = 0.16519116
# T = 5     Fidelity = 0.69635273
# T = 10    Fidelity = 0.96928830
# T = 20    Fidelity = 0.99317846
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11430445
# T = 2     Fidelity = 0.22187271
# T = 5     Fidelity = 0.74208635
# T = 10    Fidelity = 0.96723550
# T = 20    Fidelity = 0.99335344
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15664430
# T = 2     Fidelity = 0.27848772
# T = 5     Fidelity = 0.78031666
# T = 10    Fidelity = 0.96686212
# T = 20    Fidelity = 0.99362210
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9973330265      1.00972087e+00    None        None        None
# Symmetric      0.311     2         0.9977214246      1.02934439e+00    None        None        None
# Symmetric      0.522     2         0.9980252747      1.04790824e+00    None        None        None
# Symmetric      0.733     2         0.9982656415      1.06556366e+00    None        None        None
# Symmetric      0.944     2         0.9984637370      1.08242773e+00    None        None        None
# Symmetric      1.156     2         0.9986241541      1.09859358e+00    None        None        None
# Symmetric      1.367     2         0.9987604866      1.11413694e+00    None        None        None
# Symmetric      1.578     2         0.9988738493      1.12912045e+00    None        None        None
# Symmetric      1.789     2         0.9989737170      1.14359670e+00    None        None        None
# Symmetric      2.000     2         0.9990440253      1.15761039e+00    None        None        None
# Weak SSB optimised0.100     None      0.9795008976      2.42819099e-01    0.830615    0.057413    0.888028
# Weak SSB optimised0.311     None      0.9741841600      2.61171322e-01    0.875745    0.010927    0.886672
# Weak SSB optimised0.522     None      0.9887818482      2.64873214e-01    0.940679    0.000823    0.941501
# Weak SSB optimised0.733     150       0.9932261332      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     125       0.9952058138      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     100       0.9943079798      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9919815795      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     150       0.9914117969      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9926282488      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     75        0.9908795562      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9841402943      1.36752113e-03    0.745323    0.037865    0.783188
# Weak SSB       0.311     None      0.9713528227      1.12924856e-03    0.558255    0.21185     0.770105
# Weak SSB       0.522     None      0.6985374950      1.05614584e-03    0.432433    0.055104    0.487538
# Weak SSB       0.733     None      0.7999361154      1.03672155e-03    0.423899    0.038006    0.461904
# Weak SSB       0.944     None      0.8495542493      4.41475042e-03    0.746076    0.00894     0.755016
# Weak SSB       1.156     None      0.9873587998      2.50213251e-02    0.972332    0.000142    0.972475
# Weak SSB       1.367     1040      0.9944525284      6.77221454e-02    None        None        None
# Weak SSB       1.578     1020      0.9954633301      1.20187623e-01    None        None        None
# Weak SSB       1.789     150       0.9905875637      1.71405779e-01    None        None        None
# Weak SSB       2.000     75        0.9901803400      2.18843475e-01    None        None        None
# Strong SSB     0.100     75        0.9958103983      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9930767566      7.22062439e-01    None        None        None
# Strong SSB     0.522     50        0.9901921794      7.78318602e-01    None        None        None
# Strong SSB     0.733     40        0.9903398417      8.15979742e-01    None        None        None
# Strong SSB     0.944     20        0.9915419235      8.44059983e-01    None        None        None
# Strong SSB     1.156     20        0.9921939304      8.66317759e-01    None        None        None
# Strong SSB     1.367     20        0.9925160291      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9931784628      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9933534402      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9936220981      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HVA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
#============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_list,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_list,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_list,
    d2M_strong,
    d3M_strong
)

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=1$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96521562
# T = 2     Fidelity = 0.99334508
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.03626623e+00
# T = 1     Fidelity = 0.96805861
# T = 2     Fidelity = 0.99422116
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05846299e+00
# T = 1     Fidelity = 0.97048921
# T = 2     Fidelity = 0.99491153
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07916278e+00
# T = 1     Fidelity = 0.97258618
# T = 2     Fidelity = 0.99546120
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.09862393e+00
# T = 1     Fidelity = 0.97444801
# T = 2     Fidelity = 0.99591552
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.11703633e+00
# T = 1     Fidelity = 0.97607400
# T = 2     Fidelity = 0.99628652
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.13454489e+00
# T = 1     Fidelity = 0.97755553
# T = 2     Fidelity = 0.99660180
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.15126343e+00
# T = 1     Fidelity = 0.97887883
# T = 2     Fidelity = 0.99686603
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.16728342e+00
# T = 1     Fidelity = 0.98009106
# T = 2     Fidelity = 0.99709411
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98110509
# T = 2     Fidelity = 0.99726274
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000007
# T = 2     Fidelity = 0.00000005
# T = 5     Fidelity = 0.00000200
# T = 10    Fidelity = 0.00037412
# T = 20    Fidelity = 0.00543243
# T = 30    Fidelity = 0.01820125
# T = 40    Fidelity = 0.06268557
# T = 50    Fidelity = 0.16412885
# T = 75    Fidelity = 0.32418598
# T = 100   Fidelity = 0.48256034
# T = 125   Fidelity = 0.62939715
# T = 150   Fidelity = 0.73164601
# T = 175   Fidelity = 0.79803553
# T = 200   Fidelity = 0.83850192
# T = 225   Fidelity = 0.85239351
# T = 250   Fidelity = 0.86019838
# T = 275   Fidelity = 0.72157338
# T = 300   Fidelity = 0.79283558
# T = 400   Fidelity = 0.93257955
# T = 500   Fidelity = 0.91377673
# T = 600   Fidelity = 0.89332352
# T = 700   Fidelity = 0.80816443
# T = 800   Fidelity = 0.64421391
# T = 900   Fidelity = 0.74981810
# T = 1000  Fidelity = 0.63385827
# T = 1010  Fidelity = 0.62602800
# T = 1020  Fidelity = 0.70390444
# T = 1030  Fidelity = 0.66638320
# T = 1040  Fidelity = 0.25205892
# T = 1050  Fidelity = 0.42512546
# T = 1060  Fidelity = 0.50141576
# T = 1070  Fidelity = 0.46607178
# T = 1080  Fidelity = 0.56453712
# T = 1090  Fidelity = 0.54883734
# T = 1100  Fidelity = 0.75413136
# T = 1200  Fidelity = 0.22174786
# T = 1300  Fidelity = 0.24787230
# T = 1400  Fidelity = 0.64547042
# T = 1500  Fidelity = 0.48087096
# T = 2000  Fidelity = 0.33458246
# T = 2100  Fidelity = 0.88932620
# T = 2110  Fidelity = 0.81658568
# T = 2120  Fidelity = 0.76210573
# T = 2130  Fidelity = 0.74821750
# T = 2140  Fidelity = 0.53570169
# T = 2150  Fidelity = 0.75147947
# T = 2160  Fidelity = 0.55375698
# T = 2170  Fidelity = 0.63547795
# T = 2180  Fidelity = 0.70056148
# T = 2190  Fidelity = 0.52928280
# T = 2200  Fidelity = 0.52302917
# T = 2300  Fidelity = 0.33967013
# T = 2400  Fidelity = 0.51700827
# T = 2500  Fidelity = 0.52650149
# T = 2600  Fidelity = 0.30935561
# T = 2700  Fidelity = 0.24743617
# T = 2800  Fidelity = 0.53820405
# T = 2900  Fidelity = 0.49416777
# T = 3000  Fidelity = 0.91517356
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91517356
# P1     = 0.01122609
# P0+P1  = 0.92639965
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61673084e-01
# T = 1     Fidelity = 0.00000014
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00001356
# T = 10    Fidelity = 0.00297054
# T = 20    Fidelity = 0.21276000
# T = 30    Fidelity = 0.28568861
# T = 40    Fidelity = 0.35305286
# T = 50    Fidelity = 0.69641388
# T = 75    Fidelity = 0.78751364
# T = 100   Fidelity = 0.64441943
# T = 125   Fidelity = 0.85743231
# T = 150   Fidelity = 0.77303703
# T = 175   Fidelity = 0.88720199
# T = 200   Fidelity = 0.96509988
# T = 225   Fidelity = 0.88521697
# T = 250   Fidelity = 0.96047562
# T = 275   Fidelity = 0.95150870
# T = 300   Fidelity = 0.93152798
# T = 400   Fidelity = 0.96916995
# T = 500   Fidelity = 0.96127192
# T = 600   Fidelity = 0.88067582
# T = 700   Fidelity = 0.62695526
# T = 800   Fidelity = 0.80733154
# T = 900   Fidelity = 0.73747749
# T = 1000  Fidelity = 0.82249092
# T = 1010  Fidelity = 0.79068033
# T = 1020  Fidelity = 0.82703601
# T = 1030  Fidelity = 0.73079589
# T = 1040  Fidelity = 0.69805607
# T = 1050  Fidelity = 0.66870746
# T = 1060  Fidelity = 0.54701793
# T = 1070  Fidelity = 0.51563608
# T = 1080  Fidelity = 0.62875536
# T = 1090  Fidelity = 0.51212528
# T = 1100  Fidelity = 0.47889575
# T = 1200  Fidelity = 0.87373569
# T = 1300  Fidelity = 0.65714624
# T = 1400  Fidelity = 0.80496854
# T = 1500  Fidelity = 0.92045721
# T = 2000  Fidelity = 0.63138726
# T = 2100  Fidelity = 0.48148252
# T = 2110  Fidelity = 0.75696576
# T = 2120  Fidelity = 0.72671225
# T = 2130  Fidelity = 0.55998628
# T = 2140  Fidelity = 0.47297398
# T = 2150  Fidelity = 0.61428182
# T = 2160  Fidelity = 0.54497754
# T = 2170  Fidelity = 0.43213791
# T = 2180  Fidelity = 0.46489379
# T = 2190  Fidelity = 0.82041318
# T = 2200  Fidelity = 0.62865246
# T = 2300  Fidelity = 0.65896744
# T = 2400  Fidelity = 0.56582602
# T = 2500  Fidelity = 0.84391368
# T = 2600  Fidelity = 0.58982678
# T = 2700  Fidelity = 0.87631165
# T = 2800  Fidelity = 0.62767619
# T = 2900  Fidelity = 0.70892265
# T = 3000  Fidelity = 0.87322448
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43053089e+00
# P0     = 0.87322448
# P1     = 0.03802110
# P0+P1  = 0.91124558
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64768458e-01
# T = 1     Fidelity = 0.00002226
# T = 2     Fidelity = 0.00025778
# T = 5     Fidelity = 0.00348521
# T = 10    Fidelity = 0.04215847
# T = 20    Fidelity = 0.40829130
# T = 30    Fidelity = 0.60983122
# T = 40    Fidelity = 0.56213007
# T = 50    Fidelity = 0.71288093
# T = 75    Fidelity = 0.80090240
# T = 100   Fidelity = 0.88149942
# T = 125   Fidelity = 0.93659194
# T = 150   Fidelity = 0.95968034
# T = 175   Fidelity = 0.96747514
# T = 200   Fidelity = 0.97796187
# T = 225   Fidelity = 0.97737642
# T = 250   Fidelity = 0.98810805
# T = 275   Fidelity = 0.98452193
# T = 300   Fidelity = 0.97993894
# T = 400   Fidelity = 0.97332245
# T = 500   Fidelity = 0.91703642
# T = 600   Fidelity = 0.87344572
# T = 700   Fidelity = 0.86168943
# T = 800   Fidelity = 0.81506785
# T = 900   Fidelity = 0.82140897
# T = 1000  Fidelity = 0.67937121
# T = 1010  Fidelity = 0.48741180
# T = 1020  Fidelity = 0.64611227
# T = 1030  Fidelity = 0.78326313
# T = 1040  Fidelity = 0.50930324
# T = 1050  Fidelity = 0.55506820
# T = 1060  Fidelity = 0.88760386
# T = 1070  Fidelity = 0.76991653
# T = 1080  Fidelity = 0.58964996
# T = 1090  Fidelity = 0.75348467
# T = 1100  Fidelity = 0.92280517
# T = 1200  Fidelity = 0.91590385
# T = 1300  Fidelity = 0.87252181
# T = 1400  Fidelity = 0.87673607
# T = 1500  Fidelity = 0.81783344
# T = 2000  Fidelity = 0.86908699
# T = 2100  Fidelity = 0.52586576
# T = 2110  Fidelity = 0.65347608
# T = 2120  Fidelity = 0.61043252
# T = 2130  Fidelity = 0.62789741
# T = 2140  Fidelity = 0.71422990
# T = 2150  Fidelity = 0.81268772
# T = 2160  Fidelity = 0.72429511
# T = 2170  Fidelity = 0.62762794
# T = 2180  Fidelity = 0.53619410
# T = 2190  Fidelity = 0.56223566
# T = 2200  Fidelity = 0.58682510
# T = 2300  Fidelity = 0.64321390
# T = 2400  Fidelity = 0.85667057
# T = 2500  Fidelity = 0.87531852
# T = 2600  Fidelity = 0.88351174
# T = 2700  Fidelity = 0.95477546
# T = 2800  Fidelity = 0.81250366
# T = 2900  Fidelity = 0.91537493
# T = 3000  Fidelity = 0.87714784
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44126768e+00
# P0     = 0.87714784
# P1     = 0.01050504
# P0+P1  = 0.88765288
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00048481
# T = 2     Fidelity = 0.00317279
# T = 5     Fidelity = 0.02251449
# T = 10    Fidelity = 0.11283117
# T = 20    Fidelity = 0.41509155
# T = 30    Fidelity = 0.65606617
# T = 40    Fidelity = 0.73655919
# T = 50    Fidelity = 0.76227609
# T = 75    Fidelity = 0.88122967
# T = 100   Fidelity = 0.92970915
# T = 125   Fidelity = 0.96225424
# T = 150   Fidelity = 0.97724425
# T = 175   Fidelity = 0.98532429
# T = 200   Fidelity = 0.98940241
# T = 225   Fidelity = 0.98594180
# T = 250   Fidelity = 0.98774563
# T = 275   Fidelity = 0.98624835
# T = 300   Fidelity = 0.98244120
# T = 400   Fidelity = 0.94341927
# T = 500   Fidelity = 0.94520673
# T = 600   Fidelity = 0.56356237
# T = 700   Fidelity = 0.95959903
# T = 800   Fidelity = 0.89258876
# T = 900   Fidelity = 0.96273131
# T = 1000  Fidelity = 0.73599974
# T = 1010  Fidelity = 0.74441432
# T = 1020  Fidelity = 0.85662269
# T = 1030  Fidelity = 0.88664908
# T = 1040  Fidelity = 0.84381603
# T = 1050  Fidelity = 0.92006947
# T = 1060  Fidelity = 0.95054052
# T = 1070  Fidelity = 0.95076746
# T = 1080  Fidelity = 0.95321864
# T = 1090  Fidelity = 0.92274769
# T = 1100  Fidelity = 0.95613052
# T = 1200  Fidelity = 0.70564252
# T = 1300  Fidelity = 0.97644059
# T = 1400  Fidelity = 0.96263536
# T = 1500  Fidelity = 0.95416144
# T = 2000  Fidelity = 0.78928443
# T = 2100  Fidelity = 0.87960538
# T = 2110  Fidelity = 0.90031448
# T = 2120  Fidelity = 0.85877155
# T = 2130  Fidelity = 0.83974132
# T = 2140  Fidelity = 0.81974365
# T = 2150  Fidelity = 0.79341768
# T = 2160  Fidelity = 0.80305939
# T = 2170  Fidelity = 0.76998788
# T = 2180  Fidelity = 0.77986503
# T = 2190  Fidelity = 0.76098202
# T = 2200  Fidelity = 0.74967979
# T = 2300  Fidelity = 0.72749826
# T = 2400  Fidelity = 0.87201288
# T = 2500  Fidelity = 0.94962330
# T = 2600  Fidelity = 0.95432139
# T = 2700  Fidelity = 0.89206928
# T = 2800  Fidelity = 0.96571916
# T = 2900  Fidelity = 0.93000897
# T = 3000  Fidelity = 0.72760804
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.45175456e+00
# P0     = 0.72760804
# P1     = 0.00779180
# P0+P1  = 0.73539985
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00494235
# T = 2     Fidelity = 0.01723769
# T = 5     Fidelity = 0.06403672
# T = 10    Fidelity = 0.18875987
# T = 20    Fidelity = 0.45003369
# T = 30    Fidelity = 0.64444195
# T = 40    Fidelity = 0.75244462
# T = 50    Fidelity = 0.81483171
# T = 75    Fidelity = 0.90954973
# T = 100   Fidelity = 0.95902454
# T = 125   Fidelity = 0.97939464
# T = 150   Fidelity = 0.98880835
# T = 175   Fidelity = 0.99239014
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.02320417
# T = 2     Fidelity = 0.05826108
# T = 5     Fidelity = 0.14391786
# T = 10    Fidelity = 0.29509312
# T = 20    Fidelity = 0.52092901
# T = 30    Fidelity = 0.66732928
# T = 40    Fidelity = 0.75962470
# T = 50    Fidelity = 0.82213588
# T = 75    Fidelity = 0.91665700
# T = 100   Fidelity = 0.96444999
# T = 125   Fidelity = 0.98620900
# T = 150   Fidelity = 0.99440234
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.07218626
# T = 2     Fidelity = 0.14677368
# T = 5     Fidelity = 0.27644192
# T = 10    Fidelity = 0.44352997
# T = 20    Fidelity = 0.63567576
# T = 30    Fidelity = 0.74086090
# T = 40    Fidelity = 0.80699535
# T = 50    Fidelity = 0.85372073
# T = 75    Fidelity = 0.92313531
# T = 100   Fidelity = 0.95937674
# T = 125   Fidelity = 0.97876557
# T = 150   Fidelity = 0.98757657
# T = 175   Fidelity = 0.99177864
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.15510196
# T = 2     Fidelity = 0.27545551
# T = 5     Fidelity = 0.43714439
# T = 10    Fidelity = 0.60236274
# T = 20    Fidelity = 0.75995584
# T = 30    Fidelity = 0.83460147
# T = 40    Fidelity = 0.87924564
# T = 50    Fidelity = 0.90909304
# T = 75    Fidelity = 0.95135354
# T = 100   Fidelity = 0.97274706
# T = 125   Fidelity = 0.98355900
# T = 150   Fidelity = 0.98876872
# T = 175   Fidelity = 0.99252576
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.25534288
# T = 2     Fidelity = 0.41222564
# T = 5     Fidelity = 0.58403868
# T = 10    Fidelity = 0.73096875
# T = 20    Fidelity = 0.85269606
# T = 30    Fidelity = 0.90348329
# T = 40    Fidelity = 0.93174896
# T = 50    Fidelity = 0.94929846
# T = 75    Fidelity = 0.97391158
# T = 100   Fidelity = 0.98500778
# T = 125   Fidelity = 0.99052299
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.35226911
# T = 2     Fidelity = 0.53061962
# T = 5     Fidelity = 0.69606136
# T = 10    Fidelity = 0.81914666
# T = 20    Fidelity = 0.91087001
# T = 30    Fidelity = 0.94462709
# T = 40    Fidelity = 0.96217970
# T = 50    Fidelity = 0.97285455
# T = 75    Fidelity = 0.98628077
# T = 100   Fidelity = 0.99195121
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.40037050e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000128
# T = 10    Fidelity = 0.00111797
# T = 20    Fidelity = 0.00651036
# T = 30    Fidelity = 0.02742847
# T = 40    Fidelity = 0.11919621
# T = 50    Fidelity = 0.08992677
# T = 75    Fidelity = 0.30237498
# T = 100   Fidelity = 0.53367169
# T = 125   Fidelity = 0.55239934
# T = 150   Fidelity = 0.69301109
# T = 175   Fidelity = 0.80362775
# T = 200   Fidelity = 0.78727249
# T = 225   Fidelity = 0.85479845
# T = 250   Fidelity = 0.93657541
# T = 275   Fidelity = 0.73909641
# T = 300   Fidelity = 0.74313874
# T = 400   Fidelity = 0.95480307
# T = 500   Fidelity = 0.95009882
# T = 600   Fidelity = 0.96814090
# T = 700   Fidelity = 0.85563960
# T = 800   Fidelity = 0.83584041
# T = 900   Fidelity = 0.56780281
# T = 1000  Fidelity = 0.69537361
# T = 1010  Fidelity = 0.63415047
# T = 1020  Fidelity = 0.61071468
# T = 1030  Fidelity = 0.63237267
# T = 1040  Fidelity = 0.75868546
# T = 1050  Fidelity = 0.62032518
# T = 1060  Fidelity = 0.68169305
# T = 1070  Fidelity = 0.48132175
# T = 1080  Fidelity = 0.80500032
# T = 1090  Fidelity = 0.65979924
# T = 1100  Fidelity = 0.25799961
# T = 1200  Fidelity = 0.74506367
# T = 1300  Fidelity = 0.51388455
# T = 1400  Fidelity = 0.35315658
# T = 1500  Fidelity = 0.77954981
# T = 2000  Fidelity = 0.50073047
# T = 2100  Fidelity = 0.78542350
# T = 2110  Fidelity = 0.60211369
# T = 2120  Fidelity = 0.75360984
# T = 2130  Fidelity = 0.76991490
# T = 2140  Fidelity = 0.63127603
# T = 2150  Fidelity = 0.32807513
# T = 2160  Fidelity = 0.49862554
# T = 2170  Fidelity = 0.20047655
# T = 2180  Fidelity = 0.19591139
# T = 2190  Fidelity = 0.12388792
# T = 2200  Fidelity = 0.21531626
# T = 2300  Fidelity = 0.51740072
# T = 2400  Fidelity = 0.81903884
# T = 2500  Fidelity = 0.86621815
# T = 2600  Fidelity = 0.95810730
# T = 2700  Fidelity = 0.57861914
# T = 2800  Fidelity = 0.44904930
# T = 2900  Fidelity = 0.84220143
# T = 3000  Fidelity = 0.91021611
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41951501e+00
# P0     = 0.91021611
# P1     = 0.02129286
# P0+P1  = 0.93150897
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.13564004e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000002
# T = 5     Fidelity = 0.00000763
# T = 10    Fidelity = 0.00111400
# T = 20    Fidelity = 0.19743080
# T = 30    Fidelity = 0.53012736
# T = 40    Fidelity = 0.08384270
# T = 50    Fidelity = 0.71196055
# T = 75    Fidelity = 0.50841467
# T = 100   Fidelity = 0.68401010
# T = 125   Fidelity = 0.91779263
# T = 150   Fidelity = 0.91650511
# T = 175   Fidelity = 0.86758260
# T = 200   Fidelity = 0.91224926
# T = 225   Fidelity = 0.95141719
# T = 250   Fidelity = 0.95131916
# T = 275   Fidelity = 0.94044164
# T = 300   Fidelity = 0.96643293
# T = 400   Fidelity = 0.91548076
# T = 500   Fidelity = 0.94648003
# T = 600   Fidelity = 0.88161629
# T = 700   Fidelity = 0.93685521
# T = 800   Fidelity = 0.55711583
# T = 900   Fidelity = 0.78853869
# T = 1000  Fidelity = 0.38994949
# T = 1010  Fidelity = 0.87109200
# T = 1020  Fidelity = 0.74092782
# T = 1030  Fidelity = 0.59875016
# T = 1040  Fidelity = 0.76865607
# T = 1050  Fidelity = 0.85506742
# T = 1060  Fidelity = 0.82507905
# T = 1070  Fidelity = 0.78597565
# T = 1080  Fidelity = 0.53312505
# T = 1090  Fidelity = 0.84354203
# T = 1100  Fidelity = 0.74440139
# T = 1200  Fidelity = 0.87564683
# T = 1300  Fidelity = 0.16346653
# T = 1400  Fidelity = 0.75821185
# T = 1500  Fidelity = 0.46772158
# T = 2000  Fidelity = 0.83004073
# T = 2100  Fidelity = 0.50404768
# T = 2110  Fidelity = 0.42515073
# T = 2120  Fidelity = 0.56717323
# T = 2130  Fidelity = 0.73181313
# T = 2140  Fidelity = 0.66648022
# T = 2150  Fidelity = 0.67525599
# T = 2160  Fidelity = 0.81629107
# T = 2170  Fidelity = 0.72798686
# T = 2180  Fidelity = 0.50996611
# T = 2190  Fidelity = 0.53563706
# T = 2200  Fidelity = 0.77890603
# T = 2300  Fidelity = 0.76150284
# T = 2400  Fidelity = 0.65798652
# T = 2500  Fidelity = 0.82483836
# T = 2600  Fidelity = 0.26789593
# T = 2700  Fidelity = 0.11405435
# T = 2800  Fidelity = 0.50956554
# T = 2900  Fidelity = 0.54841237
# T = 3000  Fidelity = 0.74655492
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43049943e+00
# P0     = 0.74655492
# P1     = 0.08623550
# P0+P1  = 0.83279042
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00000146
# T = 2     Fidelity = 0.00007218
# T = 5     Fidelity = 0.00175277
# T = 10    Fidelity = 0.03337140
# T = 20    Fidelity = 0.35717081
# T = 30    Fidelity = 0.61346527
# T = 40    Fidelity = 0.36220333
# T = 50    Fidelity = 0.26338466
# T = 75    Fidelity = 0.57807576
# T = 100   Fidelity = 0.44084879
# T = 125   Fidelity = 0.52790887
# T = 150   Fidelity = 0.48071704
# T = 175   Fidelity = 0.49946782
# T = 200   Fidelity = 0.47584024
# T = 225   Fidelity = 0.51461205
# T = 250   Fidelity = 0.48881867
# T = 275   Fidelity = 0.48633885
# T = 300   Fidelity = 0.51160253
# T = 400   Fidelity = 0.50756817
# T = 500   Fidelity = 0.43248598
# T = 600   Fidelity = 0.39909160
# T = 700   Fidelity = 0.27816523
# T = 800   Fidelity = 0.29516097
# T = 900   Fidelity = 0.50667404
# T = 1000  Fidelity = 0.43384579
# T = 1010  Fidelity = 0.28275693
# T = 1020  Fidelity = 0.60095418
# T = 1030  Fidelity = 0.78651273
# T = 1040  Fidelity = 0.62089838
# T = 1050  Fidelity = 0.06805689
# T = 1060  Fidelity = 0.22170989
# T = 1070  Fidelity = 0.61706018
# T = 1080  Fidelity = 0.79413158
# T = 1090  Fidelity = 0.48385415
# T = 1100  Fidelity = 0.19785002
# T = 1200  Fidelity = 0.81028800
# T = 1300  Fidelity = 0.45032852
# T = 1400  Fidelity = 0.22644833
# T = 1500  Fidelity = 0.28708505
# T = 2000  Fidelity = 0.43514740
# T = 2100  Fidelity = 0.17374311
# T = 2110  Fidelity = 0.24640438
# T = 2120  Fidelity = 0.48026719
# T = 2130  Fidelity = 0.54078908
# T = 2140  Fidelity = 0.45736896
# T = 2150  Fidelity = 0.17571324
# T = 2160  Fidelity = 0.37503057
# T = 2170  Fidelity = 0.73782038
# T = 2180  Fidelity = 0.69725813
# T = 2190  Fidelity = 0.42151311
# T = 2200  Fidelity = 0.20263344
# T = 2300  Fidelity = 0.54015948
# T = 2400  Fidelity = 0.69926963
# T = 2500  Fidelity = 0.72360125
# T = 2600  Fidelity = 0.61233854
# T = 2700  Fidelity = 0.57340248
# T = 2800  Fidelity = 0.59015146
# T = 2900  Fidelity = 0.23045837
# T = 3000  Fidelity = 0.41968569
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44121779e+00
# P0     = 0.41968569
# P1     = 0.02641212
# P0+P1  = 0.44609781
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05663390e-03
# T = 1     Fidelity = 0.00190318
# T = 2     Fidelity = 0.00896813
# T = 5     Fidelity = 0.04043719
# T = 10    Fidelity = 0.14534067
# T = 20    Fidelity = 0.35188156
# T = 30    Fidelity = 0.37751392
# T = 40    Fidelity = 0.32210193
# T = 50    Fidelity = 0.32322777
# T = 75    Fidelity = 0.55328104
# T = 100   Fidelity = 0.55470895
# T = 125   Fidelity = 0.50085078
# T = 150   Fidelity = 0.51836855
# T = 175   Fidelity = 0.52277985
# T = 200   Fidelity = 0.51535376
# T = 225   Fidelity = 0.49068196
# T = 250   Fidelity = 0.49063449
# T = 275   Fidelity = 0.49252028
# T = 300   Fidelity = 0.47807516
# T = 400   Fidelity = 0.50660154
# T = 500   Fidelity = 0.49594821
# T = 600   Fidelity = 0.55382651
# T = 700   Fidelity = 0.53055011
# T = 800   Fidelity = 0.58123526
# T = 900   Fidelity = 0.64976777
# T = 1000  Fidelity = 0.62804378
# T = 1010  Fidelity = 0.54846759
# T = 1020  Fidelity = 0.50720984
# T = 1030  Fidelity = 0.29339915
# T = 1040  Fidelity = 0.13021450
# T = 1050  Fidelity = 0.31532828
# T = 1060  Fidelity = 0.52422518
# T = 1070  Fidelity = 0.80269271
# T = 1080  Fidelity = 0.82603358
# T = 1090  Fidelity = 0.62573677
# T = 1100  Fidelity = 0.57587452
# T = 1200  Fidelity = 0.81970581
# T = 1300  Fidelity = 0.71186371
# T = 1400  Fidelity = 0.47856392
# T = 1500  Fidelity = 0.64034664
# T = 2000  Fidelity = 0.45488903
# T = 2100  Fidelity = 0.47058019
# T = 2110  Fidelity = 0.16468320
# T = 2120  Fidelity = 0.19150630
# T = 2130  Fidelity = 0.34553803
# T = 2140  Fidelity = 0.48021263
# T = 2150  Fidelity = 0.41606636
# T = 2160  Fidelity = 0.55849263
# T = 2170  Fidelity = 0.50530558
# T = 2180  Fidelity = 0.62914432
# T = 2190  Fidelity = 0.59680644
# T = 2200  Fidelity = 0.65204683
# T = 2300  Fidelity = 0.56778394
# T = 2400  Fidelity = 0.33969524
# T = 2500  Fidelity = 0.70409589
# T = 2600  Fidelity = 0.67368639
# T = 2700  Fidelity = 0.67028860
# T = 2800  Fidelity = 0.59431945
# T = 2900  Fidelity = 0.38725723
# T = 3000  Fidelity = 0.40016104
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.45168821e+00
# P0     = 0.40016104
# P1     = 0.02302277
# P0+P1  = 0.42318381
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 5.88899605e-03
# T = 1     Fidelity = 0.01685056
# T = 2     Fidelity = 0.05158301
# T = 5     Fidelity = 0.13917605
# T = 10    Fidelity = 0.31447883
# T = 20    Fidelity = 0.55033044
# T = 30    Fidelity = 0.62687602
# T = 40    Fidelity = 0.61086752
# T = 50    Fidelity = 0.57940498
# T = 75    Fidelity = 0.55872036
# T = 100   Fidelity = 0.60000961
# T = 125   Fidelity = 0.62803349
# T = 150   Fidelity = 0.63533826
# T = 175   Fidelity = 0.64388715
# T = 200   Fidelity = 0.64366890
# T = 225   Fidelity = 0.67511020
# T = 250   Fidelity = 0.67997365
# T = 275   Fidelity = 0.67155602
# T = 300   Fidelity = 0.68360003
# T = 400   Fidelity = 0.70680237
# T = 500   Fidelity = 0.60473073
# T = 600   Fidelity = 0.55872818
# T = 700   Fidelity = 0.72547948
# T = 800   Fidelity = 0.76513619
# T = 900   Fidelity = 0.58723986
# T = 1000  Fidelity = 0.64362708
# T = 1010  Fidelity = 0.71373510
# T = 1020  Fidelity = 0.81724286
# T = 1030  Fidelity = 0.82594060
# T = 1040  Fidelity = 0.75497586
# T = 1050  Fidelity = 0.67418517
# T = 1060  Fidelity = 0.62646266
# T = 1070  Fidelity = 0.53750323
# T = 1080  Fidelity = 0.47945541
# T = 1090  Fidelity = 0.56417692
# T = 1100  Fidelity = 0.67500796
# T = 1200  Fidelity = 0.52153722
# T = 1300  Fidelity = 0.67725816
# T = 1400  Fidelity = 0.73697037
# T = 1500  Fidelity = 0.84903776
# T = 2000  Fidelity = 0.80265908
# T = 2100  Fidelity = 0.68496759
# T = 2110  Fidelity = 0.69044484
# T = 2120  Fidelity = 0.61402998
# T = 2130  Fidelity = 0.63186745
# T = 2140  Fidelity = 0.68281210
# T = 2150  Fidelity = 0.86779318
# T = 2160  Fidelity = 0.87090075
# T = 2170  Fidelity = 0.85281560
# T = 2180  Fidelity = 0.76607332
# T = 2190  Fidelity = 0.63344959
# T = 2200  Fidelity = 0.63636984
# T = 2300  Fidelity = 0.66273085
# T = 2400  Fidelity = 0.71450284
# T = 2500  Fidelity = 0.78419821
# T = 2600  Fidelity = 0.40229784
# T = 2700  Fidelity = 0.82030586
# T = 2800  Fidelity = 0.60314728
# T = 2900  Fidelity = 0.72081953
# T = 3000  Fidelity = 0.81408956
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.46192674e+00
# P0     = 0.81408956
# P1     = 0.00515378
# P0+P1  = 0.81924334
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 3.15736806e-02
# T = 1     Fidelity = 0.06385796
# T = 2     Fidelity = 0.14788849
# T = 5     Fidelity = 0.29263339
# T = 10    Fidelity = 0.49852720
# T = 20    Fidelity = 0.70637928
# T = 30    Fidelity = 0.78179534
# T = 40    Fidelity = 0.79727336
# T = 50    Fidelity = 0.79498352
# T = 75    Fidelity = 0.78961589
# T = 100   Fidelity = 0.79652687
# T = 125   Fidelity = 0.80621527
# T = 150   Fidelity = 0.81384898
# T = 175   Fidelity = 0.82333958
# T = 200   Fidelity = 0.82918074
# T = 225   Fidelity = 0.83518764
# T = 250   Fidelity = 0.84622867
# T = 275   Fidelity = 0.83505271
# T = 300   Fidelity = 0.85858057
# T = 400   Fidelity = 0.85783809
# T = 500   Fidelity = 0.82497618
# T = 600   Fidelity = 0.83345799
# T = 700   Fidelity = 0.69603644
# T = 800   Fidelity = 0.93250049
# T = 900   Fidelity = 0.87076059
# T = 1000  Fidelity = 0.87096732
# T = 1010  Fidelity = 0.88474361
# T = 1020  Fidelity = 0.84370896
# T = 1030  Fidelity = 0.78484607
# T = 1040  Fidelity = 0.81689799
# T = 1050  Fidelity = 0.88076358
# T = 1060  Fidelity = 0.89098791
# T = 1070  Fidelity = 0.92620026
# T = 1080  Fidelity = 0.96633358
# T = 1090  Fidelity = 0.97755096
# T = 1100  Fidelity = 0.97808943
# T = 1200  Fidelity = 0.83674089
# T = 1300  Fidelity = 0.92394606
# T = 1400  Fidelity = 0.72172778
# T = 1500  Fidelity = 0.89041562
# T = 2000  Fidelity = 0.88154979
# T = 2100  Fidelity = 0.78964199
# T = 2110  Fidelity = 0.79094053
# T = 2120  Fidelity = 0.73369932
# T = 2130  Fidelity = 0.70619074
# T = 2140  Fidelity = 0.83708731
# T = 2150  Fidelity = 0.95922069
# T = 2160  Fidelity = 0.89206718
# T = 2170  Fidelity = 0.88463656
# T = 2180  Fidelity = 0.94217666
# T = 2190  Fidelity = 0.87894538
# T = 2200  Fidelity = 0.93893671
# T = 2300  Fidelity = 0.90384587
# T = 2400  Fidelity = 0.96132005
# T = 2500  Fidelity = 0.94047334
# T = 2600  Fidelity = 0.86808065
# T = 2700  Fidelity = 0.92451894
# T = 2800  Fidelity = 0.95687003
# T = 2900  Fidelity = 0.76178074
# T = 3000  Fidelity = 0.94967451
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.47194767e+00
# P0     = 0.94967451
# P1     = 0.00008448
# P0+P1  = 0.94975899
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.80738351e-02
# T = 1     Fidelity = 0.14390139
# T = 2     Fidelity = 0.27871934
# T = 5     Fidelity = 0.45579234
# T = 10    Fidelity = 0.65287984
# T = 20    Fidelity = 0.81465733
# T = 30    Fidelity = 0.87149427
# T = 40    Fidelity = 0.89322292
# T = 50    Fidelity = 0.90201828
# T = 75    Fidelity = 0.91269615
# T = 100   Fidelity = 0.92084756
# T = 125   Fidelity = 0.92891586
# T = 150   Fidelity = 0.93530274
# T = 175   Fidelity = 0.94344749
# T = 200   Fidelity = 0.94964543
# T = 225   Fidelity = 0.93631942
# T = 250   Fidelity = 0.94461269
# T = 275   Fidelity = 0.94846547
# T = 300   Fidelity = 0.96209731
# T = 400   Fidelity = 0.95773226
# T = 500   Fidelity = 0.93410669
# T = 600   Fidelity = 0.94568347
# T = 700   Fidelity = 0.89649998
# T = 800   Fidelity = 0.94152081
# T = 900   Fidelity = 0.93727530
# T = 1000  Fidelity = 0.92630876
# T = 1010  Fidelity = 0.97130243
# T = 1020  Fidelity = 0.97366955
# T = 1030  Fidelity = 0.93967069
# T = 1040  Fidelity = 0.96649811
# T = 1050  Fidelity = 0.98286551
# T = 1060  Fidelity = 0.98448885
# T = 1070  Fidelity = 0.98032786
# T = 1080  Fidelity = 0.98462576
# T = 1090  Fidelity = 0.92901275
# T = 1100  Fidelity = 0.96975781
# T = 1200  Fidelity = 0.93113679
# T = 1300  Fidelity = 0.95451267
# T = 1400  Fidelity = 0.91283143
# T = 1500  Fidelity = 0.96707722
# T = 2000  Fidelity = 0.91164043
# T = 2100  Fidelity = 0.92685960
# T = 2110  Fidelity = 0.92481056
# T = 2120  Fidelity = 0.88622589
# T = 2130  Fidelity = 0.94550213
# T = 2140  Fidelity = 0.90916468
# T = 2150  Fidelity = 0.93438198
# T = 2160  Fidelity = 0.91080599
# T = 2170  Fidelity = 0.94441279
# T = 2180  Fidelity = 0.89512836
# T = 2190  Fidelity = 0.94229678
# T = 2200  Fidelity = 0.89491480
# T = 2300  Fidelity = 0.96960222
# T = 2400  Fidelity = 0.89400834
# T = 2500  Fidelity = 0.95275320
# T = 2600  Fidelity = 0.94521357
# T = 2700  Fidelity = 0.93079084
# T = 2800  Fidelity = 0.93836472
# T = 2900  Fidelity = 0.95115508
# T = 3000  Fidelity = 0.90436112
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.48176382e+00
# P0     = 0.90436112
# P1     = 0.00032790
# P0+P1  = 0.90468902
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.28699899e-01
# T = 1     Fidelity = 0.23824704
# T = 2     Fidelity = 0.40985797
# T = 5     Fidelity = 0.59348333
# T = 10    Fidelity = 0.76312349
# T = 20    Fidelity = 0.88370639
# T = 30    Fidelity = 0.92410242
# T = 40    Fidelity = 0.94134890
# T = 50    Fidelity = 0.95024052
# T = 75    Fidelity = 0.96116348
# T = 100   Fidelity = 0.96898762
# T = 125   Fidelity = 0.97431947
# T = 150   Fidelity = 0.97813392
# T = 175   Fidelity = 0.98204319
# T = 200   Fidelity = 0.98453337
# T = 225   Fidelity = 0.97006481
# T = 250   Fidelity = 0.97570010
# T = 275   Fidelity = 0.97905944
# T = 300   Fidelity = 0.98547479
# T = 400   Fidelity = 0.98113964
# T = 500   Fidelity = 0.97328604
# T = 600   Fidelity = 0.91509272
# T = 700   Fidelity = 0.93503930
# T = 800   Fidelity = 0.98596257
# T = 900   Fidelity = 0.99300348
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.76942225e-01
# T = 1     Fidelity = 0.33037684
# T = 2     Fidelity = 0.52212588
# T = 5     Fidelity = 0.69624301
# T = 10    Fidelity = 0.83526668
# T = 20    Fidelity = 0.92521088
# T = 30    Fidelity = 0.95407007
# T = 40    Fidelity = 0.96587029
# T = 50    Fidelity = 0.97213181
# T = 75    Fidelity = 0.98196932
# T = 100   Fidelity = 0.98625114
# T = 125   Fidelity = 0.98946862
# T = 150   Fidelity = 0.99187193
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.20505613e-01
# T = 1     Fidelity = 0.41330639
# T = 2     Fidelity = 0.61328709
# T = 5     Fidelity = 0.77136133
# T = 10    Fidelity = 0.88338142
# T = 20    Fidelity = 0.95129379
# T = 30    Fidelity = 0.97148707
# T = 40    Fidelity = 0.97943549
# T = 50    Fidelity = 0.98443812
# T = 75    Fidelity = 0.99017730
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.06623659e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000003
# T = 5     Fidelity = 0.00010397
# T = 10    Fidelity = 0.00596270
# T = 20    Fidelity = 0.15843170
# T = 30    Fidelity = 0.48897402
# T = 40    Fidelity = 0.76300791
# T = 50    Fidelity = 0.90857248
# T = 75    Fidelity = 0.99091393
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.20609288e-01
# T = 1     Fidelity = 0.00000004
# T = 2     Fidelity = 0.00000017
# T = 5     Fidelity = 0.00110623
# T = 10    Fidelity = 0.19524654
# T = 20    Fidelity = 0.88831194
# T = 30    Fidelity = 0.96801714
# T = 40    Fidelity = 0.99279885
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.76105909e-01
# T = 1     Fidelity = 0.00001501
# T = 2     Fidelity = 0.00012561
# T = 5     Fidelity = 0.03096672
# T = 10    Fidelity = 0.55932026
# T = 20    Fidelity = 0.89288166
# T = 30    Fidelity = 0.98429659
# T = 40    Fidelity = 0.97985989
# T = 50    Fidelity = 0.98468248
# T = 75    Fidelity = 0.98949924
# T = 100   Fidelity = 0.99057429
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.12909217e-01
# T = 1     Fidelity = 0.00016678
# T = 2     Fidelity = 0.00241510
# T = 5     Fidelity = 0.10673405
# T = 10    Fidelity = 0.68873673
# T = 20    Fidelity = 0.94536879
# T = 30    Fidelity = 0.98574568
# T = 40    Fidelity = 0.98772272
# T = 50    Fidelity = 0.99011574
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.40169449e-01
# T = 1     Fidelity = 0.00165909
# T = 2     Fidelity = 0.01152396
# T = 5     Fidelity = 0.20707414
# T = 10    Fidelity = 0.75880971
# T = 20    Fidelity = 0.96945218
# T = 30    Fidelity = 0.98840543
# T = 40    Fidelity = 0.99288246
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.61748289e-01
# T = 1     Fidelity = 0.00663969
# T = 2     Fidelity = 0.03074509
# T = 5     Fidelity = 0.30439250
# T = 10    Fidelity = 0.80420593
# T = 20    Fidelity = 0.97935918
# T = 30    Fidelity = 0.98991275
# T = 40    Fidelity = 0.99518856
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.79340685e-01
# T = 1     Fidelity = 0.01693124
# T = 2     Fidelity = 0.06002227
# T = 5     Fidelity = 0.39369546
# T = 10    Fidelity = 0.83310093
# T = 20    Fidelity = 0.98380572
# T = 30    Fidelity = 0.99058428
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.94021606e-01
# T = 1     Fidelity = 0.03379437
# T = 2     Fidelity = 0.09838804
# T = 5     Fidelity = 0.47444224
# T = 10    Fidelity = 0.85634803
# T = 20    Fidelity = 0.98588026
# T = 30    Fidelity = 0.99158013
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.06402712e-01
# T = 1     Fidelity = 0.05703752
# T = 2     Fidelity = 0.14255042
# T = 5     Fidelity = 0.54260126
# T = 10    Fidelity = 0.87343552
# T = 20    Fidelity = 0.98595399
# T = 30    Fidelity = 0.99193111
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.17036009e-01
# T = 1     Fidelity = 0.08549589
# T = 2     Fidelity = 0.18972954
# T = 5     Fidelity = 0.60128408
# T = 10    Fidelity = 0.88886953
# T = 20    Fidelity = 0.98595286
# T = 30    Fidelity = 0.99248252
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9933450838      1.01220263e+00    None        None        None
# Symmetric      0.311     2         0.9942211585      1.03626623e+00    None        None        None
# Symmetric      0.522     2         0.9949115309      1.05846299e+00    None        None        None
# Symmetric      0.733     2         0.9954611954      1.07916278e+00    None        None        None
# Symmetric      0.944     2         0.9959155207      1.09862393e+00    None        None        None
# Symmetric      1.156     2         0.9962865195      1.11703633e+00    None        None        None
# Symmetric      1.367     2         0.9966017970      1.13454489e+00    None        None        None
# Symmetric      1.578     2         0.9968660329      1.15126343e+00    None        None        None
# Symmetric      1.789     2         0.9970941108      1.16728342e+00    None        None        None
# Symmetric      2.000     2         0.9972627396      1.18267976e+00    None        None        None
# Weak SSB optimised0.100     None      0.9325795482      2.43127858e-01    0.915174    0.011226    0.9264
# Weak SSB optimised0.311     None      0.9691699494      2.61673084e-01    0.873224    0.038021    0.911246
# Weak SSB optimised0.522     None      0.9881080460      2.64768458e-01    0.877148    0.010505    0.887653
# Weak SSB optimised0.733     None      0.9894024054      2.64154074e-01    0.727608    0.007792    0.7354
# Weak SSB optimised0.944     175       0.9923901433      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     150       0.9944023353      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     175       0.9917786364      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     175       0.9925257624      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9905229867      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     100       0.9919512123      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9681408975      1.40037050e-03    0.910216    0.021293    0.931509
# Weak SSB       0.311     None      0.9664329263      1.13564004e-03    0.746555    0.086235    0.83279
# Weak SSB       0.522     None      0.8102880043      1.05614584e-03    0.419686    0.026412    0.446098
# Weak SSB       0.733     None      0.8260335848      1.05663390e-03    0.400161    0.023023    0.423184
# Weak SSB       0.944     None      0.8709007451      5.88899605e-03    0.81409     0.005154    0.819243
# Weak SSB       1.156     None      0.9780894276      3.15736806e-02    0.949675    8.4e-05     0.949759
# Weak SSB       1.367     None      0.9846257550      7.80738351e-02    0.904361    0.000328    0.904689
# Weak SSB       1.578     900       0.9930034755      1.28699899e-01    None        None        None
# Weak SSB       1.789     150       0.9918719341      1.76942225e-01    None        None        None
# Weak SSB       2.000     75        0.9901772959      2.20505613e-01    None        None        None
# Strong SSB     0.100     75        0.9909139271      6.06623659e-01    None        None        None
# Strong SSB     0.311     40        0.9927988535      7.20609288e-01    None        None        None
# Strong SSB     0.522     100       0.9905742908      7.76105909e-01    None        None        None
# Strong SSB     0.733     50        0.9901157382      8.12909217e-01    None        None        None
# Strong SSB     0.944     40        0.9928824578      8.40169449e-01    None        None        None
# Strong SSB     1.156     40        0.9951885582      8.61748289e-01    None        None        None
# Strong SSB     1.367     30        0.9905842775      8.79340685e-01    None        None        None
# Strong SSB     1.578     30        0.9915801269      8.94021606e-01    None        None        None
# Strong SSB     1.789     30        0.9919311119      9.06402712e-01    None        None        None
# Strong SSB     2.000     30        0.9924825232      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)


    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan
    
lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009564
# T = 10    Fidelity = 0.00119347
# T = 20    Fidelity = 0.02687640
# T = 30    Fidelity = 0.09667283
# T = 40    Fidelity = 0.19609241
# T = 50    Fidelity = 0.31172895
# T = 75    Fidelity = 0.56618857
# T = 100   Fidelity = 0.72001441
# T = 125   Fidelity = 0.80738628
# T = 150   Fidelity = 0.86470242
# T = 175   Fidelity = 0.90864728
# T = 200   Fidelity = 0.94630075
# T = 225   Fidelity = 0.96687021
# T = 250   Fidelity = 0.95352554
# T = 275   Fidelity = 0.98204357
# T = 300   Fidelity = 0.96282129
# T = 400   Fidelity = 0.95497018
# T = 500   Fidelity = 0.93802160
# T = 600   Fidelity = 0.90703114
# T = 700   Fidelity = 0.99336162
#
# Minimum T for Fidelity >= 0.99 : 700
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624068e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144431
# T = 10    Fidelity = 0.10202565
# T = 20    Fidelity = 0.52980287
# T = 30    Fidelity = 0.63895353
# T = 40    Fidelity = 0.76793384
# T = 50    Fidelity = 0.88384520
# T = 75    Fidelity = 0.94226399
# T = 100   Fidelity = 0.97306442
# T = 125   Fidelity = 0.99693260
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043113e-07
# T = 1     Fidelity = 0.00005029
# T = 2     Fidelity = 0.00043636
# T = 5     Fidelity = 0.02724436
# T = 10    Fidelity = 0.28404532
# T = 20    Fidelity = 0.77880561
# T = 30    Fidelity = 0.80543477
# T = 40    Fidelity = 0.95119760
# T = 50    Fidelity = 0.93701360
# T = 75    Fidelity = 0.99144610
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155160
# T = 2     Fidelity = 0.00639548
# T = 5     Fidelity = 0.08479928
# T = 10    Fidelity = 0.38781495
# T = 20    Fidelity = 0.90884024
# T = 30    Fidelity = 0.89422488
# T = 40    Fidelity = 0.97221024
# T = 50    Fidelity = 0.99232476
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01058275
# T = 2     Fidelity = 0.02894327
# T = 5     Fidelity = 0.16446000
# T = 10    Fidelity = 0.46780121
# T = 20    Fidelity = 0.92252837
# T = 30    Fidelity = 0.97979508
# T = 40    Fidelity = 0.97237090
# T = 50    Fidelity = 0.99387522
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03666854
# T = 2     Fidelity = 0.07742917
# T = 5     Fidelity = 0.25993028
# T = 10    Fidelity = 0.54101971
# T = 20    Fidelity = 0.90449271
# T = 30    Fidelity = 0.99651387
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08775769
# T = 2     Fidelity = 0.15533235
# T = 5     Fidelity = 0.36740416
# T = 10    Fidelity = 0.61610327
# T = 20    Fidelity = 0.89396793
# T = 30    Fidelity = 0.98167462
# T = 40    Fidelity = 0.99755438
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16572281
# T = 2     Fidelity = 0.25898771
# T = 5     Fidelity = 0.48151093
# T = 10    Fidelity = 0.69437056
# T = 20    Fidelity = 0.90351634
# T = 30    Fidelity = 0.97294672
# T = 40    Fidelity = 0.99114853
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26388537
# T = 2     Fidelity = 0.37671772
# T = 5     Fidelity = 0.59248810
# T = 10    Fidelity = 0.76993471
# T = 20    Fidelity = 0.92540089
# T = 30    Fidelity = 0.97247864
# T = 40    Fidelity = 0.98681040
# T = 50    Fidelity = 0.99323002
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36883968
# T = 2     Fidelity = 0.49270845
# T = 5     Fidelity = 0.69010871
# T = 10    Fidelity = 0.83495089
# T = 20    Fidelity = 0.94705036
# T = 30    Fidelity = 0.97598414
# T = 40    Fidelity = 0.98836366
# T = 50    Fidelity = 0.99292393
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.61114444
# T = 2     Fidelity = 0.63991291
# T = 5     Fidelity = 0.69668305
# T = 10    Fidelity = 0.75221100
# T = 20    Fidelity = 0.82047572
# T = 30    Fidelity = 0.86269632
# T = 40    Fidelity = 0.89230543
# T = 50    Fidelity = 0.91348260
# T = 75    Fidelity = 0.94658256
# T = 100   Fidelity = 0.96429796
# T = 125   Fidelity = 0.97348474
# T = 150   Fidelity = 0.98065861
# T = 175   Fidelity = 0.98084819
# T = 200   Fidelity = 0.98629483
# T = 225   Fidelity = 0.97732659
# T = 250   Fidelity = 0.98424557
# T = 275   Fidelity = 0.95505616
# T = 300   Fidelity = 0.93900734
# T = 400   Fidelity = 0.97088655
# T = 500   Fidelity = 0.97485747
# T = 600   Fidelity = 0.94391979
# T = 700   Fidelity = 0.80365119
# T = 800   Fidelity = 0.93916015
# T = 900   Fidelity = 0.98452331
# T = 1000  Fidelity = 0.97648523
# T = 1010  Fidelity = 0.95615197
# T = 1020  Fidelity = 0.94287639
# T = 1030  Fidelity = 0.95716519
# T = 1040  Fidelity = 0.96910540
# T = 1050  Fidelity = 0.96456620
# T = 1060  Fidelity = 0.96705316
# T = 1070  Fidelity = 0.97104216
# T = 1080  Fidelity = 0.98713622
# T = 1090  Fidelity = 0.99113809
#
# Minimum T for Fidelity >= 0.99 : 1090
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.72882812
# T = 2     Fidelity = 0.73731434
# T = 5     Fidelity = 0.76640464
# T = 10    Fidelity = 0.79778936
# T = 20    Fidelity = 0.83441070
# T = 30    Fidelity = 0.85762987
# T = 40    Fidelity = 0.87445782
# T = 50    Fidelity = 0.88778844
# T = 75    Fidelity = 0.91183556
# T = 100   Fidelity = 0.92827901
# T = 125   Fidelity = 0.94004286
# T = 150   Fidelity = 0.94773170
# T = 175   Fidelity = 0.95818690
# T = 200   Fidelity = 0.96063740
# T = 225   Fidelity = 0.96476591
# T = 250   Fidelity = 0.96218194
# T = 275   Fidelity = 0.96788285
# T = 300   Fidelity = 0.97432145
# T = 400   Fidelity = 0.98187668
# T = 500   Fidelity = 0.96479402
# T = 600   Fidelity = 0.96578094
# T = 700   Fidelity = 0.98257871
# T = 800   Fidelity = 0.93729595
# T = 900   Fidelity = 0.91251909
# T = 1000  Fidelity = 0.91930317
# T = 1010  Fidelity = 0.91993299
# T = 1020  Fidelity = 0.91770368
# T = 1030  Fidelity = 0.91581873
# T = 1040  Fidelity = 0.91237250
# T = 1050  Fidelity = 0.91064823
# T = 1060  Fidelity = 0.90805112
# T = 1070  Fidelity = 0.90989491
# T = 1080  Fidelity = 0.91034696
# T = 1090  Fidelity = 0.91223805
# T = 1100  Fidelity = 0.91190701
# T = 1200  Fidelity = 0.92979236
# T = 1300  Fidelity = 0.96062786
# T = 1400  Fidelity = 0.97043641
# T = 1500  Fidelity = 0.96562195
# T = 2000  Fidelity = 0.94778832
# T = 2100  Fidelity = 0.94655883
# T = 2110  Fidelity = 0.94712599
# T = 2120  Fidelity = 0.94861525
# T = 2130  Fidelity = 0.94920380
# T = 2140  Fidelity = 0.94601472
# T = 2150  Fidelity = 0.94556501
# T = 2160  Fidelity = 0.94096281
# T = 2170  Fidelity = 0.94002371
# T = 2180  Fidelity = 0.93568174
# T = 2190  Fidelity = 0.93534333
# T = 2200  Fidelity = 0.93511309
# T = 2300  Fidelity = 0.91079506
# T = 2400  Fidelity = 0.97146820
# T = 2500  Fidelity = 0.97258015
# T = 2600  Fidelity = 0.94691495
# T = 2700  Fidelity = 0.93512420
# T = 2800  Fidelity = 0.92870334
# T = 2900  Fidelity = 0.93691137
# T = 3000  Fidelity = 0.95677493
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.71621181e-01
# P0     = 0.95677493
# P1     = 0.02395161
# P0+P1  = 0.98072654
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.98302621
# T = 2     Fidelity = 0.99040851
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98357630
# T = 2     Fidelity = 0.99264179
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97826144
# T = 2     Fidelity = 0.98971223
# T = 5     Fidelity = 0.99466002
#
# Minimum T for Fidelity >= 0.99 : 5
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.94906850
# T = 2     Fidelity = 0.96514655
# T = 5     Fidelity = 0.97679616
# T = 10    Fidelity = 0.98065363
# T = 20    Fidelity = 0.98437626
# T = 30    Fidelity = 0.98693170
# T = 40    Fidelity = 0.98823247
# T = 50    Fidelity = 0.98926025
# T = 75    Fidelity = 0.99124419
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.87779069
# T = 2     Fidelity = 0.90092248
# T = 5     Fidelity = 0.92554043
# T = 10    Fidelity = 0.93588551
# T = 20    Fidelity = 0.95046713
# T = 30    Fidelity = 0.95727534
# T = 40    Fidelity = 0.96309268
# T = 50    Fidelity = 0.96668518
# T = 75    Fidelity = 0.97374483
# T = 100   Fidelity = 0.97856793
# T = 125   Fidelity = 0.98187694
# T = 150   Fidelity = 0.98428391
# T = 175   Fidelity = 0.98628591
# T = 200   Fidelity = 0.98773281
# T = 225   Fidelity = 0.98891231
# T = 250   Fidelity = 0.99007726
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78907523
# T = 2     Fidelity = 0.81921787
# T = 5     Fidelity = 0.85800717
# T = 10    Fidelity = 0.87969848
# T = 20    Fidelity = 0.91099267
# T = 30    Fidelity = 0.92518827
# T = 40    Fidelity = 0.93578521
# T = 50    Fidelity = 0.94417009
# T = 75    Fidelity = 0.95784229
# T = 100   Fidelity = 0.96669922
# T = 125   Fidelity = 0.97280504
# T = 150   Fidelity = 0.97717641
# T = 175   Fidelity = 0.98071139
# T = 200   Fidelity = 0.98308890
# T = 225   Fidelity = 0.98503029
# T = 250   Fidelity = 0.98700659
# T = 275   Fidelity = 0.98836144
# T = 300   Fidelity = 0.98960214
# T = 400   Fidelity = 0.99257325
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.71938284
# T = 2     Fidelity = 0.75593333
# T = 5     Fidelity = 0.80651349
# T = 10    Fidelity = 0.84283258
# T = 20    Fidelity = 0.89140377
# T = 30    Fidelity = 0.91293231
# T = 40    Fidelity = 0.92993114
# T = 50    Fidelity = 0.93964873
# T = 75    Fidelity = 0.95851984
# T = 100   Fidelity = 0.96982374
# T = 125   Fidelity = 0.97708885
# T = 150   Fidelity = 0.98199389
# T = 175   Fidelity = 0.98547374
# T = 200   Fidelity = 0.98779325
# T = 225   Fidelity = 0.98957065
# T = 250   Fidelity = 0.99104238
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.68994428
# T = 2     Fidelity = 0.73210658
# T = 5     Fidelity = 0.79083233
# T = 10    Fidelity = 0.83879010
# T = 20    Fidelity = 0.90204528
# T = 30    Fidelity = 0.92588865
# T = 40    Fidelity = 0.94482471
# T = 50    Fidelity = 0.95580861
# T = 75    Fidelity = 0.97281740
# T = 100   Fidelity = 0.98186281
# T = 125   Fidelity = 0.98717015
# T = 150   Fidelity = 0.99046201
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.35126357e-02
# T = 1     Fidelity = 0.59084122
# T = 2     Fidelity = 0.63594938
# T = 5     Fidelity = 0.71728484
# T = 10    Fidelity = 0.79485874
# T = 20    Fidelity = 0.87704036
# T = 30    Fidelity = 0.92009615
# T = 40    Fidelity = 0.94532194
# T = 50    Fidelity = 0.96056634
# T = 75    Fidelity = 0.97821136
# T = 100   Fidelity = 0.98374853
# T = 125   Fidelity = 0.98609414
# T = 150   Fidelity = 0.98909206
# T = 175   Fidelity = 0.98729440
# T = 200   Fidelity = 0.97719222
# T = 225   Fidelity = 0.99122192
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.91075005e-03
# T = 1     Fidelity = 0.43765246
# T = 2     Fidelity = 0.45077804
# T = 5     Fidelity = 0.49116611
# T = 10    Fidelity = 0.54178204
# T = 20    Fidelity = 0.60651732
# T = 30    Fidelity = 0.65112072
# T = 40    Fidelity = 0.68518669
# T = 50    Fidelity = 0.71244965
# T = 75    Fidelity = 0.76248460
# T = 100   Fidelity = 0.79624012
# T = 125   Fidelity = 0.82258860
# T = 150   Fidelity = 0.84209425
# T = 175   Fidelity = 0.85530027
# T = 200   Fidelity = 0.87641945
# T = 225   Fidelity = 0.88536314
# T = 250   Fidelity = 0.89286595
# T = 275   Fidelity = 0.88736582
# T = 300   Fidelity = 0.90081819
# T = 400   Fidelity = 0.92109206
# T = 500   Fidelity = 0.93804834
# T = 600   Fidelity = 0.94724046
# T = 700   Fidelity = 0.79831846
# T = 800   Fidelity = 0.77582405
# T = 900   Fidelity = 0.83475547
# T = 1000  Fidelity = 0.91419534
# T = 1010  Fidelity = 0.89912638
# T = 1020  Fidelity = 0.89020983
# T = 1030  Fidelity = 0.90589784
# T = 1040  Fidelity = 0.93215508
# T = 1050  Fidelity = 0.94353012
# T = 1060  Fidelity = 0.93576691
# T = 1070  Fidelity = 0.91830225
# T = 1080  Fidelity = 0.90539432
# T = 1090  Fidelity = 0.89633880
# T = 1100  Fidelity = 0.91094945
# T = 1200  Fidelity = 0.92937428
# T = 1300  Fidelity = 0.94787754
# T = 1400  Fidelity = 0.97323344
# T = 1500  Fidelity = 0.87155206
# T = 2000  Fidelity = 0.85852638
# T = 2100  Fidelity = 0.93620980
# T = 2110  Fidelity = 0.93640539
# T = 2120  Fidelity = 0.94813728
# T = 2130  Fidelity = 0.96228742
# T = 2140  Fidelity = 0.97503949
# T = 2150  Fidelity = 0.98595010
# T = 2160  Fidelity = 0.99063625
#
# Minimum T for Fidelity >= 0.99 : 2160
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.23428510
# T = 2     Fidelity = 0.23593639
# T = 5     Fidelity = 0.23631904
# T = 10    Fidelity = 0.23645437
# T = 20    Fidelity = 0.23648729
# T = 30    Fidelity = 0.23651001
# T = 40    Fidelity = 0.23658557
# T = 50    Fidelity = 0.23662931
# T = 75    Fidelity = 0.23680565
# T = 100   Fidelity = 0.23692876
# T = 125   Fidelity = 0.23691959
# T = 150   Fidelity = 0.23690985
# T = 175   Fidelity = 0.23534602
# T = 200   Fidelity = 0.23768659
# T = 225   Fidelity = 0.23555789
# T = 250   Fidelity = 0.23732338
# T = 275   Fidelity = 0.23712602
# T = 300   Fidelity = 0.23750960
# T = 400   Fidelity = 0.23574393
# T = 500   Fidelity = 0.23727953
# T = 600   Fidelity = 0.23734630
# T = 700   Fidelity = 0.24088792
# T = 800   Fidelity = 0.23873717
# T = 900   Fidelity = 0.23401822
# T = 1000  Fidelity = 0.23839870
# T = 1010  Fidelity = 0.23970967
# T = 1020  Fidelity = 0.23575837
# T = 1030  Fidelity = 0.23921292
# T = 1040  Fidelity = 0.24053131
# T = 1050  Fidelity = 0.24018654
# T = 1060  Fidelity = 0.23711184
# T = 1070  Fidelity = 0.23629288
# T = 1080  Fidelity = 0.23740543
# T = 1090  Fidelity = 0.23576373
# T = 1100  Fidelity = 0.23547247
# T = 1200  Fidelity = 0.23762554
# T = 1300  Fidelity = 0.23919043
# T = 1400  Fidelity = 0.23849977
# T = 1500  Fidelity = 0.23816449
# T = 2000  Fidelity = 0.23844124
# T = 2100  Fidelity = 0.23872763
# T = 2110  Fidelity = 0.23681549
# T = 2120  Fidelity = 0.23703688
# T = 2130  Fidelity = 0.23890400
# T = 2140  Fidelity = 0.23775928
# T = 2150  Fidelity = 0.23966377
# T = 2160  Fidelity = 0.23765998
# T = 2170  Fidelity = 0.23869083
# T = 2180  Fidelity = 0.23746061
# T = 2190  Fidelity = 0.23819811
# T = 2200  Fidelity = 0.23915249
# T = 2300  Fidelity = 0.23815673
# T = 2400  Fidelity = 0.23650002
# T = 2500  Fidelity = 0.23926261
# T = 2600  Fidelity = 0.23994407
# T = 2700  Fidelity = 0.23749840
# T = 2800  Fidelity = 0.23697104
# T = 2900  Fidelity = 0.23432269
# T = 3000  Fidelity = 0.23360665
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.29930120e-03
# P0     = 0.23360665
# P1     = 0.26542219
# P0+P1  = 0.49902885
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05944621e-03
# T = 1     Fidelity = 0.20150202
# T = 2     Fidelity = 0.20432027
# T = 5     Fidelity = 0.20612971
# T = 10    Fidelity = 0.20662153
# T = 20    Fidelity = 0.20779299
# T = 30    Fidelity = 0.20822015
# T = 40    Fidelity = 0.20864995
# T = 50    Fidelity = 0.20919175
# T = 75    Fidelity = 0.21003797
# T = 100   Fidelity = 0.21065138
# T = 125   Fidelity = 0.21118848
# T = 150   Fidelity = 0.21173555
# T = 175   Fidelity = 0.21162112
# T = 200   Fidelity = 0.21231800
# T = 225   Fidelity = 0.21301063
# T = 250   Fidelity = 0.21325751
# T = 275   Fidelity = 0.21320727
# T = 300   Fidelity = 0.21504103
# T = 400   Fidelity = 0.21521971
# T = 500   Fidelity = 0.21761342
# T = 600   Fidelity = 0.21881318
# T = 700   Fidelity = 0.21743160
# T = 800   Fidelity = 0.22004227
# T = 900   Fidelity = 0.21720468
# T = 1000  Fidelity = 0.22048630
# T = 1010  Fidelity = 0.21762935
# T = 1020  Fidelity = 0.21577068
# T = 1030  Fidelity = 0.22543322
# T = 1040  Fidelity = 0.21627790
# T = 1050  Fidelity = 0.22678102
# T = 1060  Fidelity = 0.22481282
# T = 1070  Fidelity = 0.22217531
# T = 1080  Fidelity = 0.21989516
# T = 1090  Fidelity = 0.22017432
# T = 1100  Fidelity = 0.22161323
# T = 1200  Fidelity = 0.22157114
# T = 1300  Fidelity = 0.22155692
# T = 1400  Fidelity = 0.22016701
# T = 1500  Fidelity = 0.22032541
# T = 2000  Fidelity = 0.23270755
# T = 2100  Fidelity = 0.22968744
# T = 2110  Fidelity = 0.22746060
# T = 2120  Fidelity = 0.23128115
# T = 2130  Fidelity = 0.23410449
# T = 2140  Fidelity = 0.23438738
# T = 2150  Fidelity = 0.23347604
# T = 2160  Fidelity = 0.23140200
# T = 2170  Fidelity = 0.23008558
# T = 2180  Fidelity = 0.22977236
# T = 2190  Fidelity = 0.22882959
# T = 2200  Fidelity = 0.22980523
# T = 2300  Fidelity = 0.22874050
# T = 2400  Fidelity = 0.23002249
# T = 2500  Fidelity = 0.22958549
# T = 2600  Fidelity = 0.23208481
# T = 2700  Fidelity = 0.23072491
# T = 2800  Fidelity = 0.22752524
# T = 2900  Fidelity = 0.22607092
# T = 3000  Fidelity = 0.22621067
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.07434343e-03
# P0     = 0.22621067
# P1     = 0.31041582
# P0+P1  = 0.53662650
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.57867035e-04
# T = 1     Fidelity = 0.29543840
# T = 2     Fidelity = 0.30306567
# T = 5     Fidelity = 0.31245225
# T = 10    Fidelity = 0.31627891
# T = 20    Fidelity = 0.32142433
# T = 30    Fidelity = 0.32609127
# T = 40    Fidelity = 0.32957465
# T = 50    Fidelity = 0.33193846
# T = 75    Fidelity = 0.33814002
# T = 100   Fidelity = 0.34283621
# T = 125   Fidelity = 0.34671662
# T = 150   Fidelity = 0.35040188
# T = 175   Fidelity = 0.35392713
# T = 200   Fidelity = 0.35683894
# T = 225   Fidelity = 0.35954491
# T = 250   Fidelity = 0.36245660
# T = 275   Fidelity = 0.36507774
# T = 300   Fidelity = 0.36767449
# T = 400   Fidelity = 0.37719368
# T = 500   Fidelity = 0.38534211
# T = 600   Fidelity = 0.40093598
# T = 700   Fidelity = 0.40477989
# T = 800   Fidelity = 0.41218808
# T = 900   Fidelity = 0.40718497
# T = 1000  Fidelity = 0.42460294
# T = 1010  Fidelity = 0.42722897
# T = 1020  Fidelity = 0.42837320
# T = 1030  Fidelity = 0.43036939
# T = 1040  Fidelity = 0.43264531
# T = 1050  Fidelity = 0.43278497
# T = 1060  Fidelity = 0.43139846
# T = 1070  Fidelity = 0.43762340
# T = 1080  Fidelity = 0.44053148
# T = 1090  Fidelity = 0.44228025
# T = 1100  Fidelity = 0.43563541
# T = 1200  Fidelity = 0.42517166
# T = 1300  Fidelity = 0.42873700
# T = 1400  Fidelity = 0.45028567
# T = 1500  Fidelity = 0.46252131
# T = 2000  Fidelity = 0.47324522
# T = 2100  Fidelity = 0.47544566
# T = 2110  Fidelity = 0.47293884
# T = 2120  Fidelity = 0.47326627
# T = 2130  Fidelity = 0.46940767
# T = 2140  Fidelity = 0.47503499
# T = 2150  Fidelity = 0.46891445
# T = 2160  Fidelity = 0.47047996
# T = 2170  Fidelity = 0.47597729
# T = 2180  Fidelity = 0.48011336
# T = 2190  Fidelity = 0.48765930
# T = 2200  Fidelity = 0.49554973
# T = 2300  Fidelity = 0.50727843
# T = 2400  Fidelity = 0.52715257
# T = 2500  Fidelity = 0.53281762
# T = 2600  Fidelity = 0.54135210
# T = 2700  Fidelity = 0.57088864
# T = 2800  Fidelity = 0.57014658
# T = 2900  Fidelity = 0.58316839
# T = 3000  Fidelity = 0.57676310
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.57706167e-04
# P0     = 0.57676310
# P1     = 0.20928782
# P0+P1  = 0.78605092
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.03605669e-03
# T = 1     Fidelity = 0.47382410
# T = 2     Fidelity = 0.49510648
# T = 5     Fidelity = 0.52732332
# T = 10    Fidelity = 0.54346245
# T = 20    Fidelity = 0.57016660
# T = 30    Fidelity = 0.58622821
# T = 40    Fidelity = 0.60149049
# T = 50    Fidelity = 0.61189258
# T = 75    Fidelity = 0.63587362
# T = 100   Fidelity = 0.65533085
# T = 125   Fidelity = 0.67092914
# T = 150   Fidelity = 0.68466860
# T = 175   Fidelity = 0.69744475
# T = 200   Fidelity = 0.70853426
# T = 225   Fidelity = 0.71864438
# T = 250   Fidelity = 0.72835230
# T = 275   Fidelity = 0.73714252
# T = 300   Fidelity = 0.74561797
# T = 400   Fidelity = 0.77418950
# T = 500   Fidelity = 0.79766132
# T = 600   Fidelity = 0.80416709
# T = 700   Fidelity = 0.82936693
# T = 800   Fidelity = 0.85884678
# T = 900   Fidelity = 0.87891629
# T = 1000  Fidelity = 0.87767291
# T = 1010  Fidelity = 0.88490783
# T = 1020  Fidelity = 0.89114938
# T = 1030  Fidelity = 0.89759297
# T = 1040  Fidelity = 0.90151563
# T = 1050  Fidelity = 0.90288511
# T = 1060  Fidelity = 0.90163368
# T = 1070  Fidelity = 0.89916406
# T = 1080  Fidelity = 0.89672889
# T = 1090  Fidelity = 0.89374478
# T = 1100  Fidelity = 0.88982258
# T = 1200  Fidelity = 0.88178150
# T = 1300  Fidelity = 0.93466378
# T = 1400  Fidelity = 0.91156779
# T = 1500  Fidelity = 0.88329551
# T = 2000  Fidelity = 0.92400976
# T = 2100  Fidelity = 0.89539377
# T = 2110  Fidelity = 0.89378868
# T = 2120  Fidelity = 0.88564546
# T = 2130  Fidelity = 0.88192396
# T = 2140  Fidelity = 0.88949241
# T = 2150  Fidelity = 0.90111153
# T = 2160  Fidelity = 0.90663722
# T = 2170  Fidelity = 0.90534634
# T = 2180  Fidelity = 0.90223832
# T = 2190  Fidelity = 0.90354620
# T = 2200  Fidelity = 0.91060015
# T = 2300  Fidelity = 0.91124623
# T = 2400  Fidelity = 0.93142266
# T = 2500  Fidelity = 0.96625185
# T = 2600  Fidelity = 0.96622874
# T = 2700  Fidelity = 0.98535764
# T = 2800  Fidelity = 0.99742232
#
# Minimum T for Fidelity >= 0.99 : 2800
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.34955504e-03
# T = 1     Fidelity = 0.51076158
# T = 2     Fidelity = 0.54391027
# T = 5     Fidelity = 0.59761079
# T = 10    Fidelity = 0.63072461
# T = 20    Fidelity = 0.68251149
# T = 30    Fidelity = 0.71532445
# T = 40    Fidelity = 0.73739388
# T = 50    Fidelity = 0.75693517
# T = 75    Fidelity = 0.79569406
# T = 100   Fidelity = 0.82365543
# T = 125   Fidelity = 0.84507653
# T = 150   Fidelity = 0.86264661
# T = 175   Fidelity = 0.87757687
# T = 200   Fidelity = 0.89002352
# T = 225   Fidelity = 0.90080868
# T = 250   Fidelity = 0.90969220
# T = 275   Fidelity = 0.91810828
# T = 300   Fidelity = 0.92554967
# T = 400   Fidelity = 0.94729870
# T = 500   Fidelity = 0.96100925
# T = 600   Fidelity = 0.96969883
# T = 700   Fidelity = 0.96684417
# T = 800   Fidelity = 0.98471912
# T = 900   Fidelity = 0.98802302
# T = 1000  Fidelity = 0.99358579
#
# Minimum T for Fidelity >= 0.99 : 1000
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.92117516e-02
# T = 1     Fidelity = 0.54943745
# T = 2     Fidelity = 0.59330732
# T = 5     Fidelity = 0.66446926
# T = 10    Fidelity = 0.71991989
# T = 20    Fidelity = 0.78246926
# T = 30    Fidelity = 0.82280763
# T = 40    Fidelity = 0.85162542
# T = 50    Fidelity = 0.87297474
# T = 75    Fidelity = 0.90817885
# T = 100   Fidelity = 0.93058165
# T = 125   Fidelity = 0.94594171
# T = 150   Fidelity = 0.95697785
# T = 175   Fidelity = 0.96497884
# T = 200   Fidelity = 0.97109724
# T = 225   Fidelity = 0.97558888
# T = 250   Fidelity = 0.97939698
# T = 275   Fidelity = 0.98227514
# T = 300   Fidelity = 0.98478010
# T = 400   Fidelity = 0.99043577
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 3.87769083e-02
# T = 1     Fidelity = 0.60017659
# T = 2     Fidelity = 0.65323026
# T = 5     Fidelity = 0.73583311
# T = 10    Fidelity = 0.80599814
# T = 20    Fidelity = 0.86817524
# T = 30    Fidelity = 0.90323392
# T = 40    Fidelity = 0.92606217
# T = 50    Fidelity = 0.94203649
# T = 75    Fidelity = 0.96447370
# T = 100   Fidelity = 0.97679168
# T = 125   Fidelity = 0.98391099
# T = 150   Fidelity = 0.98810456
# T = 175   Fidelity = 0.99048858
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 6.53490673e-02
# T = 1     Fidelity = 0.65424418
# T = 2     Fidelity = 0.71387396
# T = 5     Fidelity = 0.80121609
# T = 10    Fidelity = 0.87222611
# T = 20    Fidelity = 0.92457534
# T = 30    Fidelity = 0.95030936
# T = 40    Fidelity = 0.96539688
# T = 50    Fidelity = 0.97496768
# T = 75    Fidelity = 0.98635367
# T = 100   Fidelity = 0.99173984
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99146585
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.98820287
# T = 2     Fidelity = 0.98911919
# T = 5     Fidelity = 0.99382919
#
# Minimum T for Fidelity >= 0.99 : 5
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.42665601e+00
# T = 1     Fidelity = 0.98544269
# T = 2     Fidelity = 0.99149155
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41121208e+00
# T = 1     Fidelity = 0.98790501
# T = 2     Fidelity = 0.99387916
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.99099133
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.99178837
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99072138
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98943449
# T = 2     Fidelity = 0.99646446
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98790952
# T = 2     Fidelity = 0.99577248
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98641834
# T = 2     Fidelity = 0.99497786
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     700       0.9933616209      2.15534848e-04    None        None        None
# Symmetric      0.311     125       0.9969326022      1.15624068e-06    None        None        None
# Symmetric      0.522     75        0.9914460956      3.42043113e-07    None        None        None
# Symmetric      0.733     50        0.9923247571      1.41278093e-05    None        None        None
# Symmetric      0.944     50        0.9938752229      3.35131121e-04    None        None        None
# Symmetric      1.156     30        0.9965138679      2.39158790e-03    None        None        None
# Symmetric      1.367     40        0.9975543755      8.93695212e-03    None        None        None
# Symmetric      1.578     40        0.9911485341      2.26116126e-02    None        None        None
# Symmetric      1.789     50        0.9932300232      4.43232760e-02    None        None        None
# Symmetric      2.000     50        0.9929239299      7.29248761e-02    None        None        None
# Weak SSB optimised0.100     1090      0.9911380874      8.65519637e-01    None        None        None
# Weak SSB optimised0.311     None      0.9825787141      5.19764834e-01    0.956775    0.023952    0.980727
# Weak SSB optimised0.522     2         0.9904085078      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     2         0.9926417913      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     5         0.9946600232      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     75        0.9912441931      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     250       0.9900772554      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     400       0.9925732462      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     250       0.9910423819      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     150       0.9904620112      2.54594564e-01    None        None        None
# Weak SSB       0.100     225       0.9912219187      1.35126357e-02    None        None        None
# Weak SSB       0.311     2160      0.9906362531      2.91075005e-03    None        None        None
# Weak SSB       0.522     None      0.2408879222      1.05614584e-03    0.233607    0.265422    0.499029
# Weak SSB       0.733     None      0.2343873831      1.05944621e-03    0.226211    0.310416    0.536626
# Weak SSB       0.944     None      0.5831683937      9.57867035e-04    0.576763    0.209288    0.786051
# Weak SSB       1.156     2800      0.9974223234      2.03605669e-03    None        None        None
# Weak SSB       1.367     1000      0.9935857924      7.34955504e-03    None        None        None
# Weak SSB       1.578     400       0.9904357739      1.92117516e-02    None        None        None
# Weak SSB       1.789     175       0.9904885801      3.87769083e-02    None        None        None
# Weak SSB       2.000     100       0.9917398386      6.53490673e-02    None        None        None
# Strong SSB     0.100     1         0.9914658497      3.59472102e+00    None        None        None
# Strong SSB     0.311     5         0.9938291901      1.58498916e+00    None        None        None
# Strong SSB     0.522     2         0.9914915474      1.42665601e+00    None        None        None
# Strong SSB     0.733     2         0.9938791611      1.41121208e+00    None        None        None
# Strong SSB     0.944     1         0.9909913339      1.38481786e+00    None        None        None
# Strong SSB     1.156     1         0.9917883722      1.34302163e+00    None        None        None
# Strong SSB     1.367     1         0.9907213767      1.29217279e+00    None        None        None
# Strong SSB     1.578     2         0.9964644553      1.23335459e+00    None        None        None
# Strong SSB     1.789     2         0.9957724824      1.17426012e+00    None        None        None
# Strong SSB     2.000     2         0.9949778569      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',
        color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=-1$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Start of m0^2=-2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000294
# T = 10    Fidelity = 0.00027937
# T = 20    Fidelity = 0.00630206
# T = 30    Fidelity = 0.02604352
# T = 40    Fidelity = 0.06582320
# T = 50    Fidelity = 0.12447439
# T = 75    Fidelity = 0.30902349
# T = 100   Fidelity = 0.46391005
# T = 125   Fidelity = 0.64203940
# T = 150   Fidelity = 0.69157156
# T = 175   Fidelity = 0.77468614
# T = 200   Fidelity = 0.83394932
# T = 225   Fidelity = 0.81460428
# T = 250   Fidelity = 0.90535686
# T = 275   Fidelity = 0.91626044
# T = 300   Fidelity = 0.86715265
# T = 400   Fidelity = 0.97879992
# T = 500   Fidelity = 0.86744349
# T = 600   Fidelity = 0.89637883
# T = 700   Fidelity = 0.86506090
# T = 800   Fidelity = 0.84095681
# T = 900   Fidelity = 0.91561527
# T = 1000  Fidelity = 0.78788892
# T = 1010  Fidelity = 0.86617227
# T = 1020  Fidelity = 0.76218763
# T = 1030  Fidelity = 0.71447148
# T = 1040  Fidelity = 0.60475104
# T = 1050  Fidelity = 0.44974749
# T = 1060  Fidelity = 0.49368392
# T = 1070  Fidelity = 0.46201431
# T = 1080  Fidelity = 0.54278797
# T = 1090  Fidelity = 0.59940782
# T = 1100  Fidelity = 0.58202927
# T = 1200  Fidelity = 0.69558555
# T = 1300  Fidelity = 0.53379756
# T = 1400  Fidelity = 0.88370474
# T = 1500  Fidelity = 0.75105298
# T = 2000  Fidelity = 0.48181035
# T = 2100  Fidelity = 0.34344210
# T = 2110  Fidelity = 0.54051221
# T = 2120  Fidelity = 0.62151047
# T = 2130  Fidelity = 0.58570151
# T = 2140  Fidelity = 0.55837220
# T = 2150  Fidelity = 0.44172127
# T = 2160  Fidelity = 0.59533725
# T = 2170  Fidelity = 0.54223119
# T = 2180  Fidelity = 0.58481399
# T = 2190  Fidelity = 0.64418625
# T = 2200  Fidelity = 0.57757394
# T = 2300  Fidelity = 0.89031370
# T = 2400  Fidelity = 0.61186000
# T = 2500  Fidelity = 0.43003523
# T = 2600  Fidelity = 0.69222606
# T = 2700  Fidelity = 0.84404180
# T = 2800  Fidelity = 0.79491117
# T = 2900  Fidelity = 0.77012963
# T = 3000  Fidelity = 0.70247459
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.79379555e-02
# P0     = 0.70247459
# P1     = 0.00000000
# P0+P1  = 0.70247459
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.17908351e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00030532
# T = 10    Fidelity = 0.01973194
# T = 20    Fidelity = 0.35206773
# T = 30    Fidelity = 0.52579003
# T = 40    Fidelity = 0.54423953
# T = 50    Fidelity = 0.70352091
# T = 75    Fidelity = 0.85009126
# T = 100   Fidelity = 0.92374651
# T = 125   Fidelity = 0.95513512
# T = 150   Fidelity = 0.97617909
# T = 175   Fidelity = 0.99755135
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.94880926e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.01013818
# T = 10    Fidelity = 0.29394465
# T = 20    Fidelity = 0.47648874
# T = 30    Fidelity = 0.65918346
# T = 40    Fidelity = 0.84256225
# T = 50    Fidelity = 0.88342899
# T = 75    Fidelity = 0.96312285
# T = 100   Fidelity = 0.98782483
# T = 125   Fidelity = 0.99595799
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.58119085e-07
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000816
# T = 5     Fidelity = 0.06262331
# T = 10    Fidelity = 0.29635314
# T = 20    Fidelity = 0.55810874
# T = 30    Fidelity = 0.72699804
# T = 40    Fidelity = 0.83531862
# T = 50    Fidelity = 0.91097372
# T = 75    Fidelity = 0.98047504
# T = 100   Fidelity = 0.99984540
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.89654431e-08
# T = 1     Fidelity = 0.00000139
# T = 2     Fidelity = 0.00013188
# T = 5     Fidelity = 0.11157061
# T = 10    Fidelity = 0.49009758
# T = 20    Fidelity = 0.76522482
# T = 30    Fidelity = 0.88756034
# T = 40    Fidelity = 0.94377590
# T = 50    Fidelity = 0.97008445
# T = 75    Fidelity = 0.99783213
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.17592562e-07
# T = 1     Fidelity = 0.00002201
# T = 2     Fidelity = 0.00081609
# T = 5     Fidelity = 0.15755922
# T = 10    Fidelity = 0.62742851
# T = 20    Fidelity = 0.87766835
# T = 30    Fidelity = 0.95887513
# T = 40    Fidelity = 0.98612952
# T = 50    Fidelity = 0.99608067
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 2.47961144e-07
# T = 1     Fidelity = 0.00014376
# T = 2     Fidelity = 0.00277890
# T = 5     Fidelity = 0.19660566
# T = 10    Fidelity = 0.73840746
# T = 20    Fidelity = 0.93000577
# T = 30    Fidelity = 0.97197574
# T = 40    Fidelity = 0.98584857
# T = 50    Fidelity = 0.99133025
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 3.56990610e-07
# T = 1     Fidelity = 0.00057506
# T = 2     Fidelity = 0.00692402
# T = 5     Fidelity = 0.23191947
# T = 10    Fidelity = 0.80830958
# T = 20    Fidelity = 0.93688434
# T = 30    Fidelity = 0.96371828
# T = 40    Fidelity = 0.98388109
# T = 50    Fidelity = 0.99475025
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.45005900e-06
# T = 1     Fidelity = 0.00169083
# T = 2     Fidelity = 0.01405929
# T = 5     Fidelity = 0.26479206
# T = 10    Fidelity = 0.84407909
# T = 20    Fidelity = 0.92520542
# T = 30    Fidelity = 0.96896108
# T = 40    Fidelity = 0.99383749
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396154
# T = 2     Fidelity = 0.02468317
# T = 5     Fidelity = 0.29528974
# T = 10    Fidelity = 0.85797671
# T = 20    Fidelity = 0.92050744
# T = 30    Fidelity = 0.98401390
# T = 40    Fidelity = 0.99992037
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.61694270
# T = 2     Fidelity = 0.64538293
# T = 5     Fidelity = 0.70171083
# T = 10    Fidelity = 0.75613786
# T = 20    Fidelity = 0.82361595
# T = 30    Fidelity = 0.86474409
# T = 40    Fidelity = 0.89440849
# T = 50    Fidelity = 0.91512423
# T = 75    Fidelity = 0.94761858
# T = 100   Fidelity = 0.96219626
# T = 125   Fidelity = 0.97214213
# T = 150   Fidelity = 0.98113382
# T = 175   Fidelity = 0.97897859
# T = 200   Fidelity = 0.98334428
# T = 225   Fidelity = 0.97784740
# T = 250   Fidelity = 0.98386861
# T = 275   Fidelity = 0.95132622
# T = 300   Fidelity = 0.93977791
# T = 400   Fidelity = 0.97832452
# T = 500   Fidelity = 0.97462011
# T = 600   Fidelity = 0.92925165
# T = 700   Fidelity = 0.80806718
# T = 800   Fidelity = 0.94833071
# T = 900   Fidelity = 0.98206584
# T = 1000  Fidelity = 0.95580477
# T = 1010  Fidelity = 0.95845451
# T = 1020  Fidelity = 0.95911466
# T = 1030  Fidelity = 0.95729139
# T = 1040  Fidelity = 0.96157553
# T = 1050  Fidelity = 0.95684626
# T = 1060  Fidelity = 0.97316180
# T = 1070  Fidelity = 0.98766302
# T = 1080  Fidelity = 0.98920293
# T = 1090  Fidelity = 0.98138151
# T = 1100  Fidelity = 0.97318773
# T = 1200  Fidelity = 0.98468723
# T = 1300  Fidelity = 0.96596818
# T = 1400  Fidelity = 0.83546047
# T = 1500  Fidelity = 0.91259983
# T = 2000  Fidelity = 0.95269906
# T = 2100  Fidelity = 0.86809362
# T = 2110  Fidelity = 0.84230038
# T = 2120  Fidelity = 0.84137895
# T = 2130  Fidelity = 0.84280803
# T = 2140  Fidelity = 0.84385283
# T = 2150  Fidelity = 0.84054187
# T = 2160  Fidelity = 0.85517654
# T = 2170  Fidelity = 0.86887845
# T = 2180  Fidelity = 0.87775658
# T = 2190  Fidelity = 0.88915594
# T = 2200  Fidelity = 0.90726488
# T = 2300  Fidelity = 0.97240129
# T = 2400  Fidelity = 0.97281903
# T = 2500  Fidelity = 0.94286153
# T = 2600  Fidelity = 0.97703612
# T = 2700  Fidelity = 0.97194575
# T = 2800  Fidelity = 0.88503715
# T = 2900  Fidelity = 0.89400771
# T = 3000  Fidelity = 0.94799687
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.33549253e-01
# P0     = 0.94799687
# P1     = 0.02611284
# P0+P1  = 0.97410971
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.69657052
# T = 2     Fidelity = 0.76092295
# T = 5     Fidelity = 0.80404796
# T = 10    Fidelity = 0.83096710
# T = 20    Fidelity = 0.85896993
# T = 30    Fidelity = 0.87743742
# T = 40    Fidelity = 0.89185825
# T = 50    Fidelity = 0.90270380
# T = 75    Fidelity = 0.92263372
# T = 100   Fidelity = 0.93577776
# T = 125   Fidelity = 0.94290269
# T = 150   Fidelity = 0.94974629
# T = 175   Fidelity = 0.95955917
# T = 200   Fidelity = 0.96677950
# T = 225   Fidelity = 0.96372577
# T = 250   Fidelity = 0.96093850
# T = 275   Fidelity = 0.97099334
# T = 300   Fidelity = 0.96619729
# T = 400   Fidelity = 0.97462536
# T = 500   Fidelity = 0.96518952
# T = 600   Fidelity = 0.96792171
# T = 700   Fidelity = 0.97281269
# T = 800   Fidelity = 0.95093991
# T = 900   Fidelity = 0.92115772
# T = 1000  Fidelity = 0.92463406
# T = 1010  Fidelity = 0.92230338
# T = 1020  Fidelity = 0.92581931
# T = 1030  Fidelity = 0.93254810
# T = 1040  Fidelity = 0.92325491
# T = 1050  Fidelity = 0.93670786
# T = 1060  Fidelity = 0.94341063
# T = 1070  Fidelity = 0.91559041
# T = 1080  Fidelity = 0.93159010
# T = 1090  Fidelity = 0.91225330
# T = 1100  Fidelity = 0.91333536
# T = 1200  Fidelity = 0.94038751
# T = 1300  Fidelity = 0.95497142
# T = 1400  Fidelity = 0.97453297
# T = 1500  Fidelity = 0.98516397
# T = 2000  Fidelity = 0.95166895
# T = 2100  Fidelity = 0.94379131
# T = 2110  Fidelity = 0.94225128
# T = 2120  Fidelity = 0.94479480
# T = 2130  Fidelity = 0.93445939
# T = 2140  Fidelity = 0.95011827
# T = 2150  Fidelity = 0.94536330
# T = 2160  Fidelity = 0.94563470
# T = 2170  Fidelity = 0.95139909
# T = 2180  Fidelity = 0.92088562
# T = 2190  Fidelity = 0.93720818
# T = 2200  Fidelity = 0.93449673
# T = 2300  Fidelity = 0.93128867
# T = 2400  Fidelity = 0.96715982
# T = 2500  Fidelity = 0.95992237
# T = 2600  Fidelity = 0.95003784
# T = 2700  Fidelity = 0.93513187
# T = 2800  Fidelity = 0.93948835
# T = 2900  Fidelity = 0.92078074
# T = 3000  Fidelity = 0.97373536
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.30329715e-01
# P0     = 0.97373536
# P1     = 0.01103257
# P0+P1  = 0.98476793
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.05101286
# T = 2     Fidelity = 0.19415481
# T = 5     Fidelity = 0.84936024
# T = 10    Fidelity = 0.96445526
# T = 20    Fidelity = 0.98662616
# T = 30    Fidelity = 0.99012669
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.10871325
# T = 2     Fidelity = 0.32807740
# T = 5     Fidelity = 0.83573883
# T = 10    Fidelity = 0.90883528
# T = 20    Fidelity = 0.99619631
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.16645650
# T = 2     Fidelity = 0.40018479
# T = 5     Fidelity = 0.89701912
# T = 10    Fidelity = 0.94519012
# T = 20    Fidelity = 0.99299328
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.20919193
# T = 2     Fidelity = 0.42866172
# T = 5     Fidelity = 0.87668797
# T = 10    Fidelity = 0.92014786
# T = 20    Fidelity = 0.97006662
# T = 30    Fidelity = 0.97864943
# T = 40    Fidelity = 0.97834795
# T = 50    Fidelity = 0.98278682
# T = 75    Fidelity = 0.98526557
# T = 100   Fidelity = 0.98811218
# T = 125   Fidelity = 0.99078073
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.21552485
# T = 2     Fidelity = 0.40169331
# T = 5     Fidelity = 0.82400321
# T = 10    Fidelity = 0.86350540
# T = 20    Fidelity = 0.90696152
# T = 30    Fidelity = 0.93392260
# T = 40    Fidelity = 0.94601290
# T = 50    Fidelity = 0.94795878
# T = 75    Fidelity = 0.96174149
# T = 100   Fidelity = 0.96522613
# T = 125   Fidelity = 0.97394101
# T = 150   Fidelity = 0.97561882
# T = 175   Fidelity = 0.97948239
# T = 200   Fidelity = 0.98229216
# T = 225   Fidelity = 0.98270644
# T = 250   Fidelity = 0.98632250
# T = 275   Fidelity = 0.98551239
# T = 300   Fidelity = 0.98839545
# T = 400   Fidelity = 0.95378347
# T = 500   Fidelity = 0.96808100
# T = 600   Fidelity = 0.98255901
# T = 700   Fidelity = 0.97072833
# T = 800   Fidelity = 0.96801894
# T = 900   Fidelity = 0.98355903
# T = 1000  Fidelity = 0.97189085
# T = 1010  Fidelity = 0.98810663
# T = 1020  Fidelity = 0.99239525
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19964705
# T = 2     Fidelity = 0.34897780
# T = 5     Fidelity = 0.74503873
# T = 10    Fidelity = 0.79300763
# T = 20    Fidelity = 0.83612966
# T = 30    Fidelity = 0.86373978
# T = 40    Fidelity = 0.88725047
# T = 50    Fidelity = 0.90667061
# T = 75    Fidelity = 0.93088692
# T = 100   Fidelity = 0.94205239
# T = 125   Fidelity = 0.95527860
# T = 150   Fidelity = 0.96277826
# T = 175   Fidelity = 0.96726602
# T = 200   Fidelity = 0.97308457
# T = 225   Fidelity = 0.97604524
# T = 250   Fidelity = 0.97858916
# T = 275   Fidelity = 0.98219708
# T = 300   Fidelity = 0.98248558
# T = 400   Fidelity = 0.95710107
# T = 500   Fidelity = 0.97137461
# T = 600   Fidelity = 0.98344919
# T = 700   Fidelity = 0.96722007
# T = 800   Fidelity = 0.97357050
# T = 900   Fidelity = 0.99384442
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.17900855
# T = 2     Fidelity = 0.29730957
# T = 5     Fidelity = 0.66988784
# T = 10    Fidelity = 0.73190006
# T = 20    Fidelity = 0.79314138
# T = 30    Fidelity = 0.82938948
# T = 40    Fidelity = 0.85598521
# T = 50    Fidelity = 0.87727793
# T = 75    Fidelity = 0.91483418
# T = 100   Fidelity = 0.93880784
# T = 125   Fidelity = 0.95477631
# T = 150   Fidelity = 0.96548917
# T = 175   Fidelity = 0.97263728
# T = 200   Fidelity = 0.97754166
# T = 225   Fidelity = 0.98068299
# T = 250   Fidelity = 0.98394547
# T = 275   Fidelity = 0.98657966
# T = 300   Fidelity = 0.98832810
# T = 400   Fidelity = 0.97351033
# T = 500   Fidelity = 0.97311743
# T = 600   Fidelity = 0.98560140
# T = 700   Fidelity = 0.98635184
# T = 800   Fidelity = 0.98683326
# T = 900   Fidelity = 0.98971684
# T = 1000  Fidelity = 0.98285106
# T = 1010  Fidelity = 0.97162753
# T = 1020  Fidelity = 0.99456940
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.48783584e-01
# T = 1     Fidelity = 0.16274898
# T = 2     Fidelity = 0.25938776
# T = 5     Fidelity = 0.61735210
# T = 10    Fidelity = 0.69200904
# T = 20    Fidelity = 0.77034619
# T = 30    Fidelity = 0.81991553
# T = 40    Fidelity = 0.85677181
# T = 50    Fidelity = 0.88513334
# T = 75    Fidelity = 0.93113032
# T = 100   Fidelity = 0.95650785
# T = 125   Fidelity = 0.97118405
# T = 150   Fidelity = 0.98000694
# T = 175   Fidelity = 0.98551257
# T = 200   Fidelity = 0.98856049
# T = 225   Fidelity = 0.99106996
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.81947687e-02
# T = 1     Fidelity = 0.60150972
# T = 2     Fidelity = 0.64543447
# T = 5     Fidelity = 0.72344282
# T = 10    Fidelity = 0.79942171
# T = 20    Fidelity = 0.88059653
# T = 30    Fidelity = 0.92306882
# T = 40    Fidelity = 0.94757654
# T = 50    Fidelity = 0.96246497
# T = 75    Fidelity = 0.98020397
# T = 100   Fidelity = 0.98356860
# T = 125   Fidelity = 0.98455308
# T = 150   Fidelity = 0.98970104
# T = 175   Fidelity = 0.98791320
# T = 200   Fidelity = 0.97834905
# T = 225   Fidelity = 0.98800372
# T = 250   Fidelity = 0.96068492
# T = 275   Fidelity = 0.98949112
# T = 300   Fidelity = 0.94592629
# T = 400   Fidelity = 0.88843198
# T = 500   Fidelity = 0.95598929
# T = 600   Fidelity = 0.94375855
# T = 700   Fidelity = 0.93796184
# T = 800   Fidelity = 0.96228484
# T = 900   Fidelity = 0.99069401
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.51771385e-02
# T = 1     Fidelity = 0.53959134
# T = 2     Fidelity = 0.58240157
# T = 5     Fidelity = 0.62634944
# T = 10    Fidelity = 0.66395493
# T = 20    Fidelity = 0.72166136
# T = 30    Fidelity = 0.76341903
# T = 40    Fidelity = 0.79582096
# T = 50    Fidelity = 0.81966521
# T = 75    Fidelity = 0.86739012
# T = 100   Fidelity = 0.89860020
# T = 125   Fidelity = 0.91877167
# T = 150   Fidelity = 0.93371791
# T = 175   Fidelity = 0.94142364
# T = 200   Fidelity = 0.94141521
# T = 225   Fidelity = 0.94941977
# T = 250   Fidelity = 0.94089800
# T = 275   Fidelity = 0.93050693
# T = 300   Fidelity = 0.94454329
# T = 400   Fidelity = 0.96651363
# T = 500   Fidelity = 0.94937668
# T = 600   Fidelity = 0.95670235
# T = 700   Fidelity = 0.83500197
# T = 800   Fidelity = 0.87153282
# T = 900   Fidelity = 0.88351164
# T = 1000  Fidelity = 0.88165170
# T = 1010  Fidelity = 0.93237939
# T = 1020  Fidelity = 0.90789630
# T = 1030  Fidelity = 0.94349405
# T = 1040  Fidelity = 0.94664673
# T = 1050  Fidelity = 0.96150152
# T = 1060  Fidelity = 0.97112095
# T = 1070  Fidelity = 0.94736970
# T = 1080  Fidelity = 0.97373553
# T = 1090  Fidelity = 0.96770480
# T = 1100  Fidelity = 0.94475794
# T = 1200  Fidelity = 0.91783437
# T = 1300  Fidelity = 0.97351847
# T = 1400  Fidelity = 0.93658415
# T = 1500  Fidelity = 0.90547733
# T = 2000  Fidelity = 0.94557129
# T = 2100  Fidelity = 0.98892440
# T = 2110  Fidelity = 0.97933206
# T = 2120  Fidelity = 0.98026146
# T = 2130  Fidelity = 0.97334575
# T = 2140  Fidelity = 0.96733721
# T = 2150  Fidelity = 0.95440919
# T = 2160  Fidelity = 0.95927714
# T = 2170  Fidelity = 0.97537330
# T = 2180  Fidelity = 0.96159080
# T = 2190  Fidelity = 0.97610232
# T = 2200  Fidelity = 0.96842428
# T = 2300  Fidelity = 0.89085949
# T = 2400  Fidelity = 0.88968984
# T = 2500  Fidelity = 0.93837490
# T = 2600  Fidelity = 0.86062818
# T = 2700  Fidelity = 0.84377018
# T = 2800  Fidelity = 0.92993526
# T = 2900  Fidelity = 0.95719585
# T = 3000  Fidelity = 0.93695324
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.50815198e-02
# P0     = 0.93695324
# P1     = 0.00010164
# P0+P1  = 0.93705488
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.02245903
# T = 2     Fidelity = 0.09159729
# T = 5     Fidelity = 0.42178795
# T = 10    Fidelity = 0.47272149
# T = 20    Fidelity = 0.48764946
# T = 30    Fidelity = 0.48904341
# T = 40    Fidelity = 0.48981129
# T = 50    Fidelity = 0.49176253
# T = 75    Fidelity = 0.49002231
# T = 100   Fidelity = 0.49139260
# T = 125   Fidelity = 0.48929675
# T = 150   Fidelity = 0.49157130
# T = 175   Fidelity = 0.48820022
# T = 200   Fidelity = 0.48701371
# T = 225   Fidelity = 0.48631571
# T = 250   Fidelity = 0.48547293
# T = 275   Fidelity = 0.48110678
# T = 300   Fidelity = 0.47846910
# T = 400   Fidelity = 0.45762836
# T = 500   Fidelity = 0.44093744
# T = 600   Fidelity = 0.44613139
# T = 700   Fidelity = 0.42544414
# T = 800   Fidelity = 0.40699974
# T = 900   Fidelity = 0.40685823
# T = 1000  Fidelity = 0.36814891
# T = 1010  Fidelity = 0.37462186
# T = 1020  Fidelity = 0.37473470
# T = 1030  Fidelity = 0.36867369
# T = 1040  Fidelity = 0.37421519
# T = 1050  Fidelity = 0.36414862
# T = 1060  Fidelity = 0.36498430
# T = 1070  Fidelity = 0.36572497
# T = 1080  Fidelity = 0.36659103
# T = 1090  Fidelity = 0.35888203
# T = 1100  Fidelity = 0.35528911
# T = 1200  Fidelity = 0.34610675
# T = 1300  Fidelity = 0.31924064
# T = 1400  Fidelity = 0.26550055
# T = 1500  Fidelity = 0.28196072
# T = 2000  Fidelity = 0.19388311
# T = 2100  Fidelity = 0.18636778
# T = 2110  Fidelity = 0.17984756
# T = 2120  Fidelity = 0.17651740
# T = 2130  Fidelity = 0.17270034
# T = 2140  Fidelity = 0.17673666
# T = 2150  Fidelity = 0.17450642
# T = 2160  Fidelity = 0.17126851
# T = 2170  Fidelity = 0.16574496
# T = 2180  Fidelity = 0.16734623
# T = 2190  Fidelity = 0.16528905
# T = 2200  Fidelity = 0.16225592
# T = 2300  Fidelity = 0.14997922
# T = 2400  Fidelity = 0.10840563
# T = 2500  Fidelity = 0.12588982
# T = 2600  Fidelity = 0.11611832
# T = 2700  Fidelity = 0.10311124
# T = 2800  Fidelity = 0.08906266
# T = 2900  Fidelity = 0.08476491
# T = 3000  Fidelity = 0.07557380
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.35220086e-03
# P0     = 0.07557380
# P1     = 0.42090745
# P0+P1  = 0.49648124
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07018746e-03
# T = 1     Fidelity = 0.02239949
# T = 2     Fidelity = 0.06677983
# T = 5     Fidelity = 0.17803095
# T = 10    Fidelity = 0.19202410
# T = 20    Fidelity = 0.21219629
# T = 30    Fidelity = 0.21147522
# T = 40    Fidelity = 0.21215119
# T = 50    Fidelity = 0.21457227
# T = 75    Fidelity = 0.21515412
# T = 100   Fidelity = 0.21594377
# T = 125   Fidelity = 0.21587431
# T = 150   Fidelity = 0.21608020
# T = 175   Fidelity = 0.21596967
# T = 200   Fidelity = 0.22117201
# T = 225   Fidelity = 0.21937325
# T = 250   Fidelity = 0.21367303
# T = 275   Fidelity = 0.21751313
# T = 300   Fidelity = 0.21931330
# T = 400   Fidelity = 0.23428981
# T = 500   Fidelity = 0.20721619
# T = 600   Fidelity = 0.21599725
# T = 700   Fidelity = 0.21426333
# T = 800   Fidelity = 0.19073326
# T = 900   Fidelity = 0.18817077
# T = 1000  Fidelity = 0.20704382
# T = 1010  Fidelity = 0.20980819
# T = 1020  Fidelity = 0.21108528
# T = 1030  Fidelity = 0.23053388
# T = 1040  Fidelity = 0.21530546
# T = 1050  Fidelity = 0.22859778
# T = 1060  Fidelity = 0.26963300
# T = 1070  Fidelity = 0.17479397
# T = 1080  Fidelity = 0.20061825
# T = 1090  Fidelity = 0.19876860
# T = 1100  Fidelity = 0.24496137
# T = 1200  Fidelity = 0.25805279
# T = 1300  Fidelity = 0.23720811
# T = 1400  Fidelity = 0.24268036
# T = 1500  Fidelity = 0.16178115
# T = 2000  Fidelity = 0.21214998
# T = 2100  Fidelity = 0.14761397
# T = 2110  Fidelity = 0.22992874
# T = 2120  Fidelity = 0.22605980
# T = 2130  Fidelity = 0.16990538
# T = 2140  Fidelity = 0.29147278
# T = 2150  Fidelity = 0.16468522
# T = 2160  Fidelity = 0.22511203
# T = 2170  Fidelity = 0.18057431
# T = 2180  Fidelity = 0.22502572
# T = 2190  Fidelity = 0.22497844
# T = 2200  Fidelity = 0.21639095
# T = 2300  Fidelity = 0.23324707
# T = 2400  Fidelity = 0.18534992
# T = 2500  Fidelity = 0.23153727
# T = 2600  Fidelity = 0.22980752
# T = 2700  Fidelity = 0.19802467
# T = 2800  Fidelity = 0.18202450
# T = 2900  Fidelity = 0.19806495
# T = 3000  Fidelity = 0.18059767
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.59823390e-03
# P0     = 0.18059767
# P1     = 0.29792076
# P0+P1  = 0.47851843
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.80171521e-04
# T = 1     Fidelity = 0.03609467
# T = 2     Fidelity = 0.08713496
# T = 5     Fidelity = 0.21354781
# T = 10    Fidelity = 0.22484327
# T = 20    Fidelity = 0.24459269
# T = 30    Fidelity = 0.25130705
# T = 40    Fidelity = 0.24945037
# T = 50    Fidelity = 0.25540595
# T = 75    Fidelity = 0.25816187
# T = 100   Fidelity = 0.26183650
# T = 125   Fidelity = 0.26684167
# T = 150   Fidelity = 0.27163878
# T = 175   Fidelity = 0.27958673
# T = 200   Fidelity = 0.27791456
# T = 225   Fidelity = 0.28237592
# T = 250   Fidelity = 0.28102390
# T = 275   Fidelity = 0.27898098
# T = 300   Fidelity = 0.28767425
# T = 400   Fidelity = 0.33587557
# T = 500   Fidelity = 0.26857119
# T = 600   Fidelity = 0.30777074
# T = 700   Fidelity = 0.22171136
# T = 800   Fidelity = 0.35444292
# T = 900   Fidelity = 0.35658300
# T = 1000  Fidelity = 0.33234148
# T = 1010  Fidelity = 0.35781777
# T = 1020  Fidelity = 0.37642991
# T = 1030  Fidelity = 0.33010883
# T = 1040  Fidelity = 0.26172506
# T = 1050  Fidelity = 0.25085786
# T = 1060  Fidelity = 0.27847893
# T = 1070  Fidelity = 0.30856630
# T = 1080  Fidelity = 0.36688821
# T = 1090  Fidelity = 0.39133444
# T = 1100  Fidelity = 0.26782799
# T = 1200  Fidelity = 0.25417482
# T = 1300  Fidelity = 0.39260814
# T = 1400  Fidelity = 0.27369499
# T = 1500  Fidelity = 0.39928715
# T = 2000  Fidelity = 0.38891352
# T = 2100  Fidelity = 0.32320527
# T = 2110  Fidelity = 0.39727866
# T = 2120  Fidelity = 0.37283435
# T = 2130  Fidelity = 0.35997911
# T = 2140  Fidelity = 0.42982700
# T = 2150  Fidelity = 0.35753187
# T = 2160  Fidelity = 0.33777359
# T = 2170  Fidelity = 0.30609680
# T = 2180  Fidelity = 0.29285607
# T = 2190  Fidelity = 0.42875159
# T = 2200  Fidelity = 0.29769261
# T = 2300  Fidelity = 0.40873309
# T = 2400  Fidelity = 0.34694531
# T = 2500  Fidelity = 0.42066619
# T = 2600  Fidelity = 0.39595673
# T = 2700  Fidelity = 0.34456275
# T = 2800  Fidelity = 0.36510698
# T = 2900  Fidelity = 0.39088302
# T = 3000  Fidelity = 0.39694920
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.38933834e-03
# P0     = 0.39694920
# P1     = 0.41903997
# P0+P1  = 0.81598917
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 9.40449540e-04
# T = 1     Fidelity = 0.04602293
# T = 2     Fidelity = 0.09643251
# T = 5     Fidelity = 0.22972247
# T = 10    Fidelity = 0.24470507
# T = 20    Fidelity = 0.26729050
# T = 30    Fidelity = 0.29085025
# T = 40    Fidelity = 0.29914496
# T = 50    Fidelity = 0.29798405
# T = 75    Fidelity = 0.32037271
# T = 100   Fidelity = 0.32593587
# T = 125   Fidelity = 0.33540619
# T = 150   Fidelity = 0.34742249
# T = 175   Fidelity = 0.34953649
# T = 200   Fidelity = 0.35908403
# T = 225   Fidelity = 0.36535097
# T = 250   Fidelity = 0.36617522
# T = 275   Fidelity = 0.37879286
# T = 300   Fidelity = 0.37750569
# T = 400   Fidelity = 0.34593515
# T = 500   Fidelity = 0.38314991
# T = 600   Fidelity = 0.42646527
# T = 700   Fidelity = 0.43534729
# T = 800   Fidelity = 0.45129966
# T = 900   Fidelity = 0.45511430
# T = 1000  Fidelity = 0.48267343
# T = 1010  Fidelity = 0.42531108
# T = 1020  Fidelity = 0.41112358
# T = 1030  Fidelity = 0.46709886
# T = 1040  Fidelity = 0.49748734
# T = 1050  Fidelity = 0.48301300
# T = 1060  Fidelity = 0.42821302
# T = 1070  Fidelity = 0.37385846
# T = 1080  Fidelity = 0.45133098
# T = 1090  Fidelity = 0.49149783
# T = 1100  Fidelity = 0.39673273
# T = 1200  Fidelity = 0.48463602
# T = 1300  Fidelity = 0.50481656
# T = 1400  Fidelity = 0.47347068
# T = 1500  Fidelity = 0.47989067
# T = 2000  Fidelity = 0.48897931
# T = 2100  Fidelity = 0.50602240
# T = 2110  Fidelity = 0.49503337
# T = 2120  Fidelity = 0.47607747
# T = 2130  Fidelity = 0.49889848
# T = 2140  Fidelity = 0.47838077
# T = 2150  Fidelity = 0.47101541
# T = 2160  Fidelity = 0.47180448
# T = 2170  Fidelity = 0.46653560
# T = 2180  Fidelity = 0.44489853
# T = 2190  Fidelity = 0.47804809
# T = 2200  Fidelity = 0.46901562
# T = 2300  Fidelity = 0.52852717
# T = 2400  Fidelity = 0.54217842
# T = 2500  Fidelity = 0.50241726
# T = 2600  Fidelity = 0.53244568
# T = 2700  Fidelity = 0.55371305
# T = 2800  Fidelity = 0.53621280
# T = 2900  Fidelity = 0.57275137
# T = 3000  Fidelity = 0.57519057
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.24416809e-03
# P0     = 0.57519057
# P1     = 0.41304369
# P0+P1  = 0.98823426
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 9.13233454e-04
# T = 1     Fidelity = 0.04976058
# T = 2     Fidelity = 0.09548020
# T = 5     Fidelity = 0.24343213
# T = 10    Fidelity = 0.26783154
# T = 20    Fidelity = 0.29300120
# T = 30    Fidelity = 0.31532015
# T = 40    Fidelity = 0.33761074
# T = 50    Fidelity = 0.35520965
# T = 75    Fidelity = 0.37443824
# T = 100   Fidelity = 0.38906289
# T = 125   Fidelity = 0.40682444
# T = 150   Fidelity = 0.41403395
# T = 175   Fidelity = 0.42261896
# T = 200   Fidelity = 0.43255727
# T = 225   Fidelity = 0.43496649
# T = 250   Fidelity = 0.44170535
# T = 275   Fidelity = 0.44856859
# T = 300   Fidelity = 0.44551875
# T = 400   Fidelity = 0.46090175
# T = 500   Fidelity = 0.44215823
# T = 600   Fidelity = 0.47886043
# T = 700   Fidelity = 0.47914691
# T = 800   Fidelity = 0.50882733
# T = 900   Fidelity = 0.52189750
# T = 1000  Fidelity = 0.49895985
# T = 1010  Fidelity = 0.52712582
# T = 1020  Fidelity = 0.50934368
# T = 1030  Fidelity = 0.50359617
# T = 1040  Fidelity = 0.52797666
# T = 1050  Fidelity = 0.53204074
# T = 1060  Fidelity = 0.50631679
# T = 1070  Fidelity = 0.53582043
# T = 1080  Fidelity = 0.53129738
# T = 1090  Fidelity = 0.54365696
# T = 1100  Fidelity = 0.52933938
# T = 1200  Fidelity = 0.53287713
# T = 1300  Fidelity = 0.55403828
# T = 1400  Fidelity = 0.52352644
# T = 1500  Fidelity = 0.55670268
# T = 2000  Fidelity = 0.55548342
# T = 2100  Fidelity = 0.56439118
# T = 2110  Fidelity = 0.56135124
# T = 2120  Fidelity = 0.55661883
# T = 2130  Fidelity = 0.54889836
# T = 2140  Fidelity = 0.55565015
# T = 2150  Fidelity = 0.55759378
# T = 2160  Fidelity = 0.56852861
# T = 2170  Fidelity = 0.56308856
# T = 2180  Fidelity = 0.54535813
# T = 2190  Fidelity = 0.55779599
# T = 2200  Fidelity = 0.55000670
# T = 2300  Fidelity = 0.53352000
# T = 2400  Fidelity = 0.58435089
# T = 2500  Fidelity = 0.57435223
# T = 2600  Fidelity = 0.50056543
# T = 2700  Fidelity = 0.55075657
# T = 2800  Fidelity = 0.55114501
# T = 2900  Fidelity = 0.56610430
# T = 3000  Fidelity = 0.49210559
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.13588693e-03
# P0     = 0.49210559
# P1     = 0.28721936
# P0+P1  = 0.77932495
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.91554516e-04
# T = 1     Fidelity = 0.05177275
# T = 2     Fidelity = 0.09318685
# T = 5     Fidelity = 0.25967500
# T = 10    Fidelity = 0.29771244
# T = 20    Fidelity = 0.33833783
# T = 30    Fidelity = 0.36524191
# T = 40    Fidelity = 0.38508778
# T = 50    Fidelity = 0.40065756
# T = 75    Fidelity = 0.42777641
# T = 100   Fidelity = 0.44510479
# T = 125   Fidelity = 0.45697639
# T = 150   Fidelity = 0.46549232
# T = 175   Fidelity = 0.47193668
# T = 200   Fidelity = 0.47700090
# T = 225   Fidelity = 0.48123077
# T = 250   Fidelity = 0.48497933
# T = 275   Fidelity = 0.48848033
# T = 300   Fidelity = 0.49150262
# T = 400   Fidelity = 0.50229381
# T = 500   Fidelity = 0.52441031
# T = 600   Fidelity = 0.52801801
# T = 700   Fidelity = 0.53575232
# T = 800   Fidelity = 0.51789452
# T = 900   Fidelity = 0.53089311
# T = 1000  Fidelity = 0.51627950
# T = 1010  Fidelity = 0.53160545
# T = 1020  Fidelity = 0.52090493
# T = 1030  Fidelity = 0.52321222
# T = 1040  Fidelity = 0.53378923
# T = 1050  Fidelity = 0.53019767
# T = 1060  Fidelity = 0.51178696
# T = 1070  Fidelity = 0.53109218
# T = 1080  Fidelity = 0.51914718
# T = 1090  Fidelity = 0.54079187
# T = 1100  Fidelity = 0.52851694
# T = 1200  Fidelity = 0.54366239
# T = 1300  Fidelity = 0.56873085
# T = 1400  Fidelity = 0.52447526
# T = 1500  Fidelity = 0.55018472
# T = 2000  Fidelity = 0.50699723
# T = 2100  Fidelity = 0.51023008
# T = 2110  Fidelity = 0.56269996
# T = 2120  Fidelity = 0.52693309
# T = 2130  Fidelity = 0.52604841
# T = 2140  Fidelity = 0.54162861
# T = 2150  Fidelity = 0.51698057
# T = 2160  Fidelity = 0.51149595
# T = 2170  Fidelity = 0.52431836
# T = 2180  Fidelity = 0.51618311
# T = 2190  Fidelity = 0.51810751
# T = 2200  Fidelity = 0.46510537
# T = 2300  Fidelity = 0.55608624
# T = 2400  Fidelity = 0.55352362
# T = 2500  Fidelity = 0.53212545
# T = 2600  Fidelity = 0.58719408
# T = 2700  Fidelity = 0.61621048
# T = 2800  Fidelity = 0.59418555
# T = 2900  Fidelity = 0.63752461
# T = 3000  Fidelity = 0.62757534
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.05026245e-03
# P0     = 0.62757534
# P1     = 0.35585990
# P0+P1  = 0.98343524
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 8.73711147e-04
# T = 1     Fidelity = 0.05528002
# T = 2     Fidelity = 0.09451825
# T = 5     Fidelity = 0.28110425
# T = 10    Fidelity = 0.33276561
# T = 20    Fidelity = 0.38909829
# T = 30    Fidelity = 0.41957714
# T = 40    Fidelity = 0.43882755
# T = 50    Fidelity = 0.45178196
# T = 75    Fidelity = 0.47069155
# T = 100   Fidelity = 0.48096977
# T = 125   Fidelity = 0.48773097
# T = 150   Fidelity = 0.49295912
# T = 175   Fidelity = 0.49760612
# T = 200   Fidelity = 0.50191259
# T = 225   Fidelity = 0.50626660
# T = 250   Fidelity = 0.51064318
# T = 275   Fidelity = 0.51455322
# T = 300   Fidelity = 0.51755636
# T = 400   Fidelity = 0.50798590
# T = 500   Fidelity = 0.50873574
# T = 600   Fidelity = 0.52472832
# T = 700   Fidelity = 0.53062839
# T = 800   Fidelity = 0.52882717
# T = 900   Fidelity = 0.51999622
# T = 1000  Fidelity = 0.52394697
# T = 1010  Fidelity = 0.54868608
# T = 1020  Fidelity = 0.54180119
# T = 1030  Fidelity = 0.54596307
# T = 1040  Fidelity = 0.55174307
# T = 1050  Fidelity = 0.53244544
# T = 1060  Fidelity = 0.55379036
# T = 1070  Fidelity = 0.55569658
# T = 1080  Fidelity = 0.52870325
# T = 1090  Fidelity = 0.54057762
# T = 1100  Fidelity = 0.55038622
# T = 1200  Fidelity = 0.54649230
# T = 1300  Fidelity = 0.52207779
# T = 1400  Fidelity = 0.53304625
# T = 1500  Fidelity = 0.54070057
# T = 2000  Fidelity = 0.56509260
# T = 2100  Fidelity = 0.57996103
# T = 2110  Fidelity = 0.60009635
# T = 2120  Fidelity = 0.59210873
# T = 2130  Fidelity = 0.60037476
# T = 2140  Fidelity = 0.60679852
# T = 2150  Fidelity = 0.59911426
# T = 2160  Fidelity = 0.59817273
# T = 2170  Fidelity = 0.59361555
# T = 2180  Fidelity = 0.60032166
# T = 2190  Fidelity = 0.61212185
# T = 2200  Fidelity = 0.60418787
# T = 2300  Fidelity = 0.61703496
# T = 2400  Fidelity = 0.61838302
# T = 2500  Fidelity = 0.61619383
# T = 2600  Fidelity = 0.59203081
# T = 2700  Fidelity = 0.63503549
# T = 2800  Fidelity = 0.61230276
# T = 2900  Fidelity = 0.63800225
# T = 3000  Fidelity = 0.63130582
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.78208763e-04
# P0     = 0.63130582
# P1     = 0.33306443
# P0+P1  = 0.96437025
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 8.58553719e-04
# T = 1     Fidelity = 0.06003559
# T = 2     Fidelity = 0.09845557
# T = 5     Fidelity = 0.30608478
# T = 10    Fidelity = 0.36811221
# T = 20    Fidelity = 0.42455365
# T = 30    Fidelity = 0.45226110
# T = 40    Fidelity = 0.47036578
# T = 50    Fidelity = 0.48280536
# T = 75    Fidelity = 0.49664889
# T = 100   Fidelity = 0.50125780
# T = 125   Fidelity = 0.50703812
# T = 150   Fidelity = 0.51220913
# T = 175   Fidelity = 0.51576885
# T = 200   Fidelity = 0.51882665
# T = 225   Fidelity = 0.51959406
# T = 250   Fidelity = 0.51872164
# T = 275   Fidelity = 0.51783500
# T = 300   Fidelity = 0.51629699
# T = 400   Fidelity = 0.51788274
# T = 500   Fidelity = 0.52437567
# T = 600   Fidelity = 0.53025865
# T = 700   Fidelity = 0.54165194
# T = 800   Fidelity = 0.53470923
# T = 900   Fidelity = 0.55108803
# T = 1000  Fidelity = 0.53076969
# T = 1010  Fidelity = 0.55317677
# T = 1020  Fidelity = 0.53624900
# T = 1030  Fidelity = 0.55751879
# T = 1040  Fidelity = 0.53749169
# T = 1050  Fidelity = 0.55182722
# T = 1060  Fidelity = 0.54264237
# T = 1070  Fidelity = 0.53812705
# T = 1080  Fidelity = 0.53575820
# T = 1090  Fidelity = 0.54875994
# T = 1100  Fidelity = 0.55816808
# T = 1200  Fidelity = 0.54590778
# T = 1300  Fidelity = 0.52909996
# T = 1400  Fidelity = 0.53820998
# T = 1500  Fidelity = 0.54549321
# T = 2000  Fidelity = 0.59843457
# T = 2100  Fidelity = 0.60822504
# T = 2110  Fidelity = 0.61162178
# T = 2120  Fidelity = 0.62287510
# T = 2130  Fidelity = 0.61894038
# T = 2140  Fidelity = 0.62550163
# T = 2150  Fidelity = 0.59433691
# T = 2160  Fidelity = 0.60282277
# T = 2170  Fidelity = 0.61925032
# T = 2180  Fidelity = 0.60839233
# T = 2190  Fidelity = 0.61986221
# T = 2200  Fidelity = 0.61338985
# T = 2300  Fidelity = 0.62248044
# T = 2400  Fidelity = 0.62515440
# T = 2500  Fidelity = 0.62785858
# T = 2600  Fidelity = 0.63567671
# T = 2700  Fidelity = 0.59028980
# T = 2800  Fidelity = 0.61657223
# T = 2900  Fidelity = 0.63331853
# T = 3000  Fidelity = 0.65286506
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.17642281e-04
# P0     = 0.65286506
# P1     = 0.32933920
# P0+P1  = 0.98220426
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99094668
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.89669414
# T = 2     Fidelity = 0.95068940
# T = 5     Fidelity = 0.98160825
# T = 10    Fidelity = 0.99101070
#
# Minimum T for Fidelity >= 0.99 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.31621635e+00
# T = 1     Fidelity = 0.10351252
# T = 2     Fidelity = 0.29569167
# T = 5     Fidelity = 0.79908781
# T = 10    Fidelity = 0.98645074
# T = 20    Fidelity = 0.98807810
# T = 30    Fidelity = 0.99008362
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.40805723e+00
# T = 1     Fidelity = 0.13148222
# T = 2     Fidelity = 0.37875855
# T = 5     Fidelity = 0.79950378
# T = 10    Fidelity = 0.91758998
# T = 20    Fidelity = 0.99107939
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.23441214
# T = 2     Fidelity = 0.53231103
# T = 5     Fidelity = 0.91570443
# T = 10    Fidelity = 0.98330384
# T = 20    Fidelity = 0.99204728
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.30492133
# T = 2     Fidelity = 0.59448799
# T = 5     Fidelity = 0.91552694
# T = 10    Fidelity = 0.98294407
# T = 20    Fidelity = 0.99350993
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.35974363
# T = 2     Fidelity = 0.63524339
# T = 5     Fidelity = 0.93233434
# T = 10    Fidelity = 0.98454741
# T = 20    Fidelity = 0.99472203
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.40075795
# T = 2     Fidelity = 0.65866304
# T = 5     Fidelity = 0.93869962
# T = 10    Fidelity = 0.98259185
# T = 20    Fidelity = 0.99585858
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.43929283
# T = 2     Fidelity = 0.68216744
# T = 5     Fidelity = 0.94396400
# T = 10    Fidelity = 0.98199289
# T = 20    Fidelity = 0.99709583
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.47168661
# T = 2     Fidelity = 0.69855098
# T = 5     Fidelity = 0.94937859
# T = 10    Fidelity = 0.98139514
# T = 20    Fidelity = 0.99809882
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     None      0.9787999160      3.07240439e-04    0.702475    0.0         0.702475
# Symmetric      0.311     175       0.9975513524      1.17908351e-06    None        None        None
# Symmetric      0.522     125       0.9959579898      2.94880926e-07    None        None        None
# Symmetric      0.733     100       0.9998453992      1.58119085e-07    None        None        None
# Symmetric      0.944     75        0.9978321254      6.89654431e-08    None        None        None
# Symmetric      1.156     50        0.9960806679      1.17592562e-07    None        None        None
# Symmetric      1.367     50        0.9913302532      2.47961144e-07    None        None        None
# Symmetric      1.578     50        0.9947502482      3.56990610e-07    None        None        None
# Symmetric      1.789     40        0.9938374869      2.45005900e-06    None        None        None
# Symmetric      2.000     40        0.9999203702      1.44257094e-05    None        None        None
# Weak SSB optimised0.100     None      0.9892029343      8.67181393e-01    0.947997    0.026113    0.97411
# Weak SSB optimised0.311     None      0.9851639679      5.19764834e-01    0.973735    0.011033    0.984768
# Weak SSB optimised0.522     30        0.9901266853      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     20        0.9961963082      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     20        0.9929932816      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     125       0.9907807330      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     1020      0.9923952472      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     900       0.9938444169      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     1020      0.9945694026      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     225       0.9910699565      2.48783584e-01    None        None        None
# Weak SSB       0.100     900       0.9906940114      1.81947687e-02    None        None        None
# Weak SSB       0.311     None      0.9889244050      1.51771385e-02    0.936953    0.000102    0.937055
# Weak SSB       0.522     None      0.4917625288      1.05614584e-03    0.075574    0.420907    0.496481
# Weak SSB       0.733     None      0.2914727817      1.07018746e-03    0.180598    0.297921    0.478518
# Weak SSB       0.944     None      0.4298270001      9.80171521e-04    0.396949    0.41904     0.815989
# Weak SSB       1.156     None      0.5751905702      9.40449540e-04    0.575191    0.413044    0.988234
# Weak SSB       1.367     None      0.5843508931      9.13233454e-04    0.492106    0.287219    0.779325
# Weak SSB       1.578     None      0.6375246108      8.91554516e-04    0.627575    0.35586     0.983435
# Weak SSB       1.789     None      0.6380022535      8.73711147e-04    0.631306    0.333064    0.96437
# Weak SSB       2.000     None      0.6528650573      8.58553719e-04    0.652865    0.329339    0.982204
# Strong SSB     0.100     1         0.9909466753      3.59472102e+00    None        None        None
# Strong SSB     0.311     10        0.9910106990      1.58498916e+00    None        None        None
# Strong SSB     0.522     30        0.9900836169      1.31621635e+00    None        None        None
# Strong SSB     0.733     20        0.9910793904      1.40805723e+00    None        None        None
# Strong SSB     0.944     20        0.9920472849      1.38481786e+00    None        None        None
# Strong SSB     1.156     20        0.9935099302      1.34302163e+00    None        None        None
# Strong SSB     1.367     20        0.9947220312      1.29217279e+00    None        None        None
# Strong SSB     1.578     20        0.9958585832      1.23335459e+00    None        None        None
# Strong SSB     1.789     20        0.9970958321      1.17426012e+00    None        None        None
# Strong SSB     2.000     20        0.9980988249      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
# ============================================================


plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.1556
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7333

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=-2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ==================optimised==========================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
