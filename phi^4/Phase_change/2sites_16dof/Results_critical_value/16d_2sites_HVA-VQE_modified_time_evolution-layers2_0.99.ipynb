# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 0.00005

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.055472252606338
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Hamiltonian Variational Ansatz (Improved Asymmetric HVA)
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector 
from qiskit_algorithms import VQE 
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B
# ============================================================
# Physics-inspired HVA for mI² < 0
# ============================================================

def grouped_hva_asymm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):

        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 3*nq + 3

    params = ParameterVector(
        "θ",
        nparams_per_layer * layers
    )

    for l in range(layers):

        offset = l * nparams_per_layer

        θx  = params[offset : offset+nq]

        θy  = params[offset+nq : offset+2*nq]

        θz  = params[offset+2*nq : offset+3*nq]

        θxx = params[offset+3*nq]

        θyy = params[offset+3*nq+1]

        θzz = params[offset+3*nq+2]

        # ----------------------------------------------------
        # RX sector
        # ----------------------------------------------------

        for q in range(nq):

            qc.rx(2*θx[q], q)

        # ----------------------------------------------------
        # RY sector
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(2*θy[q], q)

        # ----------------------------------------------------
        # RZ sector
        # ----------------------------------------------------

        for q in range(nq):

            qc.rz(2*θz[q], q)

        # ----------------------------------------------------
        # XX sector
        # ----------------------------------------------------

        for q in range(0, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        # ----------------------------------------------------
        # YY sector
        # ----------------------------------------------------

        for q in range(0, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        for q in range(1, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        # ----------------------------------------------------
        # ZZ sector
        # ----------------------------------------------------

        for q in range(0, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

    return qc

# %%
# ============================================================
# Hamiltonian Variational Ansatz (Improved HVA)
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector

# ============================================================
# Physics-inspired HVA
# ============================================================

def grouped_hva_symm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    # RX, RY, RZ on every qubit
    # one shared XX, YY, ZZ angle

    nparams_per_layer = 3*nq + 3

    params = ParameterVector(
        "θ",
        nparams_per_layer * layers
    )

    for l in range(layers):

        offset = l * nparams_per_layer

        θx  = params[offset : offset+nq]

        θy  = params[offset+nq : offset+2*nq]

        θz  = params[offset+2*nq : offset+3*nq]

        θxx = params[offset+3*nq]

        θyy = params[offset+3*nq+1]

        θzz = params[offset+3*nq+2]

        # ====================================================
        # X rotations
        # ====================================================

        for q in range(nq):

            qc.rx(2*θx[q], q)

        # ====================================================
        # Y rotations
        # ====================================================

        for q in range(nq):

            qc.ry(2*θy[q], q)

        # ====================================================
        # Z rotations
        # ====================================================

        for q in range(nq):

            qc.rz(2*θz[q], q)

        # ====================================================
        # XX block
        # ====================================================

        for q in range(0, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rxx(2*θxx, q, q+1)

        # ====================================================
        # YY block
        # ====================================================

        for q in range(0, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        for q in range(1, nq-1, 2):

            qc.ryy(2*θyy, q, q+1)

        # ====================================================
        # ZZ block
        # ====================================================

        for q in range(0, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

        for q in range(1, nq-1, 2):

            qc.rzz(2*θzz, q, q+1)

    return qc

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Multi-parameter scan
# HVA + warm-start continuation + overlap tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0

# Default depth
layers = 4

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
  {
       "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-4
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#" * 80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#" * 80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "=" * 60)
        print(f"Running λ = {lam:.3f}")
        print("=" * 60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(
            Hloc_sparse
        )

        # ----------------------------------------------------
        # Dense Hamiltonian
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(
            H_op
        )

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ====================================================
        # Adaptive depth near critical region
        # ====================================================

        

        # ====================================================
        # Ansatz
        # ====================================================

        if mI2 < 0:

            ansatz = grouped_hva_asymm(
                nq=nqubits,
                layers=layers
            )

        else:

            ansatz = grouped_hva_symm(
                nq=nqubits,
                layers=layers
            )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)



        
        # ====================================================
        # Weak SSB:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )
        # ====================================================
        # Weak SSB optimized:
        # warm-start + overlap tracking
        # ====================================================

        
        # ====================================================
        # Symmetric + Strong SSB
        # ====================================================

        else:

            print(
                "\nRunning ordinary HVA-VQE...\n"
            )

            initial_point = (
                0.01 * np.random.randn(
                    ansatz.num_parameters
                )
            )

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = (
                vqe.compute_minimum_eigenvalue(
                    H_pauli_shifted
                )
            )

            best_energy = (
                result.eigenvalue.real
                + identity_shift
            )

            optimal_circuit = (
                ansatz.assign_parameters(
                    result.optimal_parameters
                )
            )

            best_state = (
                Statevector.from_instruction(
                    optimal_circuit
                ).data
            )

            best_fidelity = np.abs(
                np.vdot(
                    psi_exact,
                    best_state
                )
            )**2

            best_overlap = 1.0

        # ====================================================
        # Final VQE data
        # ====================================================

        E_vqe = best_energy
        F = best_fidelity

        # ====================================================
        # Store results
        # ====================================================

        data = {

            "case": label,

            "lambda": lam,

            "mI2": mI2,

            "f": f,
            'psi_vqe': best_state,

            "E_exact": E_exact,

            "E_vqe": E_vqe,

            "error": abs(
                E_exact - E_vqe
            ),

            "fidelity": F,

            "tracking_overlap": best_overlap,

            "layers": layers
        }

        case_results.append(data)
        all_results.append(data)

        # ====================================================
        # Print
        # ====================================================

        print("\nFINAL SELECTED STATE")

        print(
            f"Exact energy     : "
            f"{E_exact:.12f}"
        )

        print(
            f"VQE energy       : "
            f"{E_vqe:.12f}"
        )

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(
            f"Fidelity         : "
            f"{F:.12f}"
        )

        print(
            f"Tracking overlap : "
            f"{best_overlap:.12f}"
        )

        print(
            f"Layers            : "
            f"{layers}"
        )

        print(
            f"Pauli terms       : "
            f"{len(H_pauli_shifted.paulis)}"
        )

    # ========================================================
    # Summary
    # ========================================================

    print("\n")
    print("=" * 140)
    print(f"SUMMARY : {label}")
    print("=" * 140)

    print(
        f"{'lambda':<12}"
        f"{'Exact E':<20}"
        f"{'VQE E':<20}"
        f"{'Error':<18}"
        f"{'Fidelity':<18}"
        f"{'TrackOverlap':<18}"
        f"{'Layers':<10}"
    )

    print("=" * 140)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
            f"{r['E_vqe']:<20.10f}"
            f"{r['error']:<18.4e}"
            f"{r['fidelity']:<18.10f}"
            f"{r['tracking_overlap']:<18.10f}"
            f"{r['layers']:<10}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running ordinary HVA-VQE...
# /home/semin/jupyter/qiskit_env/lib/python3.12/site-packages/qiskit_algorithms/optimizers/scipy_optimizer.py:162: OptimizeWarning: Unknown solver options: iprint
#   raw_result = minimize(
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161835195
# Energy error     : 1.070356e-07
# Fidelity         : 0.999999971835
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 106
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641768596
# Energy error     : 3.412484e-07
# Fidelity         : 0.999999924609
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030500464849
# Energy error     : 1.155055e-06
# Fidelity         : 0.999999787856
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041825989133
# Energy error     : 1.666872e-06
# Fidelity         : 0.999999664295
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052685969941
# Energy error     : 1.426179e-06
# Fidelity         : 0.999999792729
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063145197794
# Energy error     : 1.140902e-05
# Fidelity         : 0.999997581410
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073219202901
# Energy error     : 3.549130e-06
# Fidelity         : 0.999999475216
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082992451119
# Energy error     : 2.629930e-05
# Fidelity         : 0.999996154022
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092439593168
# Energy error     : 2.408506e-05
# Fidelity         : 0.999996568495
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101599085012
# Energy error     : 9.656269e-06
# Fidelity         : 0.999998592319
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
#
# ============================================================================================================================================
# SUMMARY : Symmetric
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      1.0061617282        1.0061618352        1.0704e-07        0.9999999718      1.0000000000      4
# 0.3111      1.0186414273        1.0186417686        3.4125e-07        0.9999999246      1.0000000000      4
# 0.5222      1.0304993098        1.0305004648        1.1551e-06        0.9999997879      1.0000000000      4
# 0.7333      1.0418243223        1.0418259891        1.6669e-06        0.9999996643      1.0000000000      4
# 0.9444      1.0526845438        1.0526859699        1.4262e-06        0.9999997927      1.0000000000      4
# 1.1556      1.0631337888        1.0631451978        1.1409e-05        0.9999975814      1.0000000000      4
# 1.3667      1.0732156538        1.0732192029        3.5491e-06        0.9999994752      1.0000000000      4
# 1.5778      1.0829661518        1.0829924511        2.6299e-05        0.9999961540      1.0000000000      4
# 1.7889      1.0924155081        1.0924395932        2.4085e-05        0.9999965685      1.0000000000      4
# 2.0000      1.1015894287        1.1015990850        9.6563e-06        0.9999985923      1.0000000000      4
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.042079111544
# Fidelity = 0.997034618263
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -17.045149572703
# Fidelity = 0.997447960002
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -17.043546042006
# Fidelity = 0.996894202343
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -17.051186205941
# Fidelity = 0.998279207103
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -17.048826781925
# Fidelity = 0.997736390881
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.051186205941
# Energy error     : 1.350715e-02
# Fidelity         : 0.998279207103
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.068802051833
# Fidelity = 0.995104892906
# Overlap  = 0.808521234606
#
# Restart 1
# Energy   = -9.061882622636
# Fidelity = 0.991438493897
# Overlap  = 0.820046657648
#
# Restart 2
# Energy   = -9.064725933800
# Fidelity = 0.992453300910
# Overlap  = 0.818977926418
#
# Restart 3
# Energy   = -9.051683519418
# Fidelity = 0.990642648472
# Overlap  = 0.813730211968
#
# Restart 4
# Energy   = -9.062882403616
# Fidelity = 0.993813084577
# Overlap  = 0.818392663443
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.068802051833
# Energy error     : 1.164786e-02
# Fidelity         : 0.995104892906
# Tracking overlap : 0.808521234606
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.683283820229
# Fidelity = 0.991480702957
# Overlap  = 0.065476075746
#
# Restart 1
# Energy   = -4.680018570389
# Fidelity = 0.991317206128
# Overlap  = 0.067946960048
#
# Restart 2
# Energy   = -4.678692956700
# Fidelity = 0.990616850997
# Overlap  = 0.068334231448
#
# Restart 3
# Energy   = -4.678183819302
# Fidelity = 0.990594050298
# Overlap  = 0.068565060365
#
# Restart 4
# Energy   = -4.678495341916
# Fidelity = 0.991226334710
# Overlap  = 0.068849408118
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.683283820229
# Energy error     : 1.791115e-02
# Fidelity         : 0.991480702957
# Tracking overlap : 0.065476075746
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.005796274798
# Fidelity = 0.998145398779
# Overlap  = 0.661301118196
#
# Restart 1
# Energy   = -2.988926795828
# Fidelity = 0.990176734436
# Overlap  = 0.649337677011
#
# Restart 2
# Energy   = -2.996690989177
# Fidelity = 0.993396577398
# Overlap  = 0.656655469843
#
# Restart 3
# Energy   = -2.991453072429
# Fidelity = 0.990433916869
# Overlap  = 0.647627131792
#
# Restart 4
# Energy   = -2.994067328645
# Fidelity = 0.992629918668
# Overlap  = 0.650801215028
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.005796274798
# Energy error     : 5.735077e-03
# Fidelity         : 0.998145398779
# Tracking overlap : 0.661301118196
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.080725828141
# Fidelity = 0.999472783589
# Overlap  = 0.831223801869
#
# Restart 1
# Energy   = -2.070832765583
# Fidelity = 0.993174202733
# Overlap  = 0.821540290257
#
# Restart 2
# Energy   = -2.067893757590
# Fidelity = 0.992080116293
# Overlap  = 0.824551241850
#
# Restart 3
# Energy   = -2.059129500866
# Fidelity = 0.985380118046
# Overlap  = 0.811471496215
#
# Restart 4
# Energy   = -2.073830385637
# Fidelity = 0.995782447704
# Overlap  = 0.831506481901
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.080725828141
# Energy error     : 2.839895e-03
# Fidelity         : 0.999472783589
# Tracking overlap : 0.831223801869
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.503576547146
# Fidelity = 0.999852153464
# Overlap  = 0.898704950733
#
# Restart 1
# Energy   = -1.494623820919
# Fidelity = 0.992832894362
# Overlap  = 0.880075890136
#
# Restart 2
# Energy   = -1.487201712605
# Fidelity = 0.990884126079
# Overlap  = 0.882394291567
#
# Restart 3
# Energy   = -1.491941665667
# Fidelity = 0.989534760697
# Overlap  = 0.874923475070
#
# Restart 4
# Energy   = -1.496325455210
# Fidelity = 0.995459741712
# Overlap  = 0.888548152368
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503576547146
# Energy error     : 9.113256e-04
# Fidelity         : 0.999852153464
# Tracking overlap : 0.898704950733
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118608530460
# Fidelity = 0.999905250848
# Overlap  = 0.918729081410
#
# Restart 1
# Energy   = -1.111496058996
# Fidelity = 0.994711523078
# Overlap  = 0.898016542075
#
# Restart 2
# Energy   = -1.109564231187
# Fidelity = 0.991025750826
# Overlap  = 0.890663451771
#
# Restart 3
# Energy   = -1.112373779785
# Fidelity = 0.995055442013
# Overlap  = 0.900953108673
#
# Restart 4
# Energy   = -1.112251431129
# Fidelity = 0.995699230679
# Overlap  = 0.900144663610
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118608530460
# Energy error     : 4.912000e-04
# Fidelity         : 0.999905250848
# Tracking overlap : 0.918729081410
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.853013541112
# Fidelity = 0.999952896602
# Overlap  = 0.937654525848
#
# Restart 1
# Energy   = -0.848558007364
# Fidelity = 0.996804569120
# Overlap  = 0.921345067259
#
# Restart 2
# Energy   = -0.849120763611
# Fidelity = 0.996457240367
# Overlap  = 0.920031237566
#
# Restart 3
# Energy   = -0.847783117429
# Fidelity = 0.997042672631
# Overlap  = 0.920639664228
#
# Restart 4
# Energy   = -0.848128691248
# Fidelity = 0.997474102912
# Overlap  = 0.924702165356
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.853013541112
# Energy error     : 3.185129e-04
# Fidelity         : 0.999952896602
# Tracking overlap : 0.937654525848
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663341314778
# Fidelity = 0.999971625958
# Overlap  = 0.958985251888
#
# Restart 1
# Energy   = -0.660316027140
# Fidelity = 0.998268065291
# Overlap  = 0.948912183599
#
# Restart 2
# Energy   = -0.659166399955
# Fidelity = 0.997985085801
# Overlap  = 0.948717823517
#
# Restart 3
# Energy   = -0.656849384579
# Fidelity = 0.996190677205
# Overlap  = 0.940649236540
#
# Restart 4
# Energy   = -0.660078259299
# Fidelity = 0.998172896191
# Overlap  = 0.949468487164
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663341314778
# Energy error     : 2.188268e-04
# Fidelity         : 0.999971625958
# Tracking overlap : 0.958985251888
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.521982602151
# Fidelity = 0.999975039543
# Overlap  = 0.975446034143
#
# Restart 1
# Energy   = -0.518828630813
# Fidelity = 0.998695852413
# Overlap  = 0.968866914216
#
# Restart 2
# Energy   = -0.518406120417
# Fidelity = 0.998326713669
# Overlap  = 0.966553344214
#
# Restart 3
# Energy   = -0.520052088589
# Fidelity = 0.999058494995
# Overlap  = 0.969920637262
#
# Restart 4
# Energy   = -0.519410104314
# Fidelity = 0.998487984564
# Overlap  = 0.967466738321
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.521982602151
# Energy error     : 1.571621e-04
# Fidelity         : 0.999975039543
# Tracking overlap : 0.975446034143
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB optimised
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -17.0646933519      -17.0511862059      1.3507e-02        0.9982792071      1.0000000000      4
# 0.3111      -9.0804499123       -9.0688020518       1.1648e-02        0.9951048929      0.8085212346      4
# 0.5222      -4.7011949726       -4.6832838202       1.7911e-02        0.9914807030      0.0654760757      4
# 0.7333      -3.0115313516       -3.0057962748       5.7351e-03        0.9981453988      0.6613011182      4
# 0.9444      -2.0835657235       -2.0807258281       2.8399e-03        0.9994727836      0.8312238019      4
# 1.1556      -1.5044878727       -1.5035765471       9.1133e-04        0.9998521535      0.8987049507      4
# 1.3667      -1.1190997304       -1.1186085305       4.9120e-04        0.9999052508      0.9187290814      4
# 1.5778      -0.8533320540       -0.8530135411       3.1851e-04        0.9999528966      0.9376545258      4
# 1.7889      -0.6635601415       -0.6633413148       2.1883e-04        0.9999716260      0.9589852519      4
# 2.0000      -0.5221397643       -0.5219826022       1.5716e-04        0.9999750395      0.9754460341      4
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 0.0001
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.929108896057
# Fidelity = 0.998440016035
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.936747460010
# Fidelity = 0.999141566934
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.921093364737
# Fidelity = 0.996905331370
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.924641971007
# Fidelity = 0.997755152709
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.938982933631
# Fidelity = 0.999330771016
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902685020
# VQE energy       : -16.938982933631
# Energy error     : 4.919751e-03
# Fidelity         : 0.999330771016
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 158
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.890549609564
# Fidelity = 0.999412692980
# Overlap  = 0.876600899620
#
# Restart 1
# Energy   = -8.860165806302
# Fidelity = 0.992655883325
# Overlap  = 0.885536846887
#
# Restart 2
# Energy   = -8.850471790019
# Fidelity = 0.984549610250
# Overlap  = 0.875933789385
#
# Restart 3
# Energy   = -8.884079945312
# Fidelity = 0.997743557880
# Overlap  = 0.882239353372
#
# Restart 4
# Energy   = -8.870702549312
# Fidelity = 0.993091576373
# Overlap  = 0.876660925271
#
# FINAL SELECTED STATE
# Exact energy     : -8.892069658534
# VQE energy       : -8.890549609564
# Energy error     : 1.520049e-03
# Fidelity         : 0.999412692980
# Tracking overlap : 0.876600899620
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.378857297598
# Fidelity = 0.820742400772
# Overlap  = 0.048711475651
#
# Restart 1
# Energy   = -4.371391939237
# Fidelity = 0.016153847087
# Overlap  = 0.000000768465
#
# Restart 2
# Energy   = -4.371917781792
# Fidelity = 0.023277906079
# Overlap  = 0.000016783149
#
# Restart 3
# Energy   = -4.370419371012
# Fidelity = 0.010410427234
# Overlap  = 0.000001076500
#
# Restart 4
# Energy   = -4.370250111070
# Fidelity = 0.017932615560
# Overlap  = 0.000010198089
#
# FINAL SELECTED STATE
# Exact energy     : -4.379329565434
# VQE energy       : -4.378857297598
# Energy error     : 4.722678e-04
# Fidelity         : 0.820742400772
# Tracking overlap : 0.048711475651
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.741424713543
# Fidelity = 0.000022671505
# Overlap  = 0.658263739877
#
# Restart 1
# Energy   = -2.747875322283
# Fidelity = 0.996754578088
# Overlap  = 0.000047950746
#
# Restart 2
# Energy   = -2.743173773245
# Fidelity = 0.922998775843
# Overlap  = 0.000092975230
#
# Restart 3
# Energy   = -2.744688672540
# Fidelity = 0.909589090140
# Overlap  = 0.000325124937
#
# Restart 4
# Energy   = -2.748600796503
# Fidelity = 0.992582279564
# Overlap  = 0.000104331579
#
# FINAL SELECTED STATE
# Exact energy     : -2.749826501443
# VQE energy       : -2.748600796503
# Energy error     : 1.225705e-03
# Fidelity         : 0.992582279564
# Tracking overlap : 0.000104331579
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.873975626334
# Fidelity = 0.990022336661
# Overlap  = 0.819582823623
#
# Restart 1
# Energy   = -1.873648016530
# Fidelity = 0.993994182525
# Overlap  = 0.797825853073
#
# Restart 2
# Energy   = -1.871436332179
# Fidelity = 0.984825026307
# Overlap  = 0.769732795244
#
# Restart 3
# Energy   = -1.871083308280
# Fidelity = 0.981475916278
# Overlap  = 0.780541592073
#
# Restart 4
# Energy   = -1.873353045385
# Fidelity = 0.996336920753
# Overlap  = 0.800380449724
#
# FINAL SELECTED STATE
# Exact energy     : -1.874705890824
# VQE energy       : -1.873975626334
# Energy error     : 7.302645e-04
# Fidelity         : 0.990022336661
# Tracking overlap : 0.819582823623
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348347070194
# Fidelity = 0.997642329551
# Overlap  = 0.892192923122
#
# Restart 1
# Energy   = -1.348453642370
# Fidelity = 0.999728652992
# Overlap  = 0.887992684632
#
# Restart 2
# Energy   = -1.346246205935
# Fidelity = 0.993115216807
# Overlap  = 0.888816455050
#
# Restart 3
# Energy   = -1.347117375232
# Fidelity = 0.996606252420
# Overlap  = 0.890343291777
#
# Restart 4
# Energy   = -1.348311666632
# Fidelity = 0.999608673552
# Overlap  = 0.887666905532
#
# FINAL SELECTED STATE
# Exact energy     : -1.348823187245
# VQE energy       : -1.348347070194
# Energy error     : 4.761171e-04
# Fidelity         : 0.997642329551
# Tracking overlap : 0.892192923122
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.009940145211
# Fidelity = 0.999447036148
# Overlap  = 0.935347304726
#
# Restart 1
# Energy   = -1.002685401175
# Fidelity = 0.981635356819
# Overlap  = 0.905802304817
#
# Restart 2
# Energy   = -1.008501245067
# Fidelity = 0.995496527571
# Overlap  = 0.933290775193
#
# Restart 3
# Energy   = -1.008108537565
# Fidelity = 0.998061296573
# Overlap  = 0.930374818873
#
# Restart 4
# Energy   = -1.009350578511
# Fidelity = 0.998916006106
# Overlap  = 0.935406558035
#
# FINAL SELECTED STATE
# Exact energy     : -1.010440164101
# VQE energy       : -1.009350578511
# Energy error     : 1.089586e-03
# Fidelity         : 0.998916006106
# Tracking overlap : 0.935406558035
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.778625767247
# Fidelity = 0.999411717995
# Overlap  = 0.962025475915
#
# Restart 1
# Energy   = -0.777561584487
# Fidelity = 0.999469800699
# Overlap  = 0.960693235564
#
# Restart 2
# Energy   = -0.777512060807
# Fidelity = 0.998364305602
# Overlap  = 0.958397901728
#
# Restart 3
# Energy   = -0.775352856603
# Fidelity = 0.994474114848
# Overlap  = 0.955326077506
#
# Restart 4
# Energy   = -0.777452127661
# Fidelity = 0.999189740353
# Overlap  = 0.961654391737
#
# FINAL SELECTED STATE
# Exact energy     : -0.779140149474
# VQE energy       : -0.778625767247
# Energy error     : 5.143822e-04
# Fidelity         : 0.999411717995
# Tracking overlap : 0.962025475915
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611387720145
# Fidelity = 0.999766223525
# Overlap  = 0.977899616361
#
# Restart 1
# Energy   = -0.609862704308
# Fidelity = 0.999366432230
# Overlap  = 0.975674772978
#
# Restart 2
# Energy   = -0.610255194905
# Fidelity = 0.999686311021
# Overlap  = 0.977281932316
#
# Restart 3
# Energy   = -0.609901694887
# Fidelity = 0.997870531589
# Overlap  = 0.974556409109
#
# Restart 4
# Energy   = -0.610469413612
# Fidelity = 0.999536295390
# Overlap  = 0.976846055601
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723602270
# VQE energy       : -0.611387720145
# Energy error     : 3.358821e-04
# Fidelity         : 0.999766223525
# Tracking overlap : 0.977899616361
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484090066718
# Fidelity = 0.999901254966
# Overlap  = 0.986229094333
#
# Restart 1
# Energy   = -0.482225880021
# Fidelity = 0.999436191293
# Overlap  = 0.984034988501
#
# Restart 2
# Energy   = -0.483041404705
# Fidelity = 0.999362966361
# Overlap  = 0.985309591333
#
# Restart 3
# Energy   = -0.483395368643
# Fidelity = 0.999742017944
# Overlap  = 0.985555397070
#
# Restart 4
# Energy   = -0.483443071148
# Fidelity = 0.999815141586
# Overlap  = 0.985538473921
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295546782
# VQE energy       : -0.484090066718
# Energy error     : 2.054801e-04
# Fidelity         : 0.999901254966
# Tracking overlap : 0.986229094333
# Layers            : 4
# Pauli terms       : 160
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9439026850      -16.9389829336      4.9198e-03        0.9993307710      1.0000000000      4
# 0.3111      -8.8920696585       -8.8905496096       1.5200e-03        0.9994126930      0.8766008996      4
# 0.5222      -4.3793295654       -4.3788572976       4.7227e-04        0.8207424008      0.0487114757      4
# 0.7333      -2.7498265014       -2.7486007965       1.2257e-03        0.9925822796      0.0001043316      4
# 0.9444      -1.8747058908       -1.8739756263       7.3026e-04        0.9900223367      0.8195828236      4
# 1.1556      -1.3488231872       -1.3483470702       4.7612e-04        0.9976423296      0.8921929231      4
# 1.3667      -1.0104401641       -1.0093505785       1.0896e-03        0.9989160061      0.9354065580      4
# 1.5778      -0.7791401495       -0.7786257672       5.1438e-04        0.9994117180      0.9620254759      4
# 1.7889      -0.6117236023       -0.6113877201       3.3588e-04        0.9997662235      0.9778996164      4
# 2.0000      -0.4842955468       -0.4840900667       2.0548e-04        0.9999012550      0.9862290943      4
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.747364834890
# Fidelity = 0.997405076261
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -20.743451107966
# Fidelity = 0.996414368939
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -20.746579679378
# Fidelity = 0.997461715143
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -20.742343798893
# Fidelity = 0.996398296287
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -20.736137571055
# Fidelity = 0.995926224721
# Overlap  = 1.000000000000
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.747364834890
# Energy error     : 2.996361e-02
# Fidelity         : 0.997405076261
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.814842100004
# Fidelity = 0.997476746068
# Overlap  = 0.850939111842
#
# Restart 1
# Energy   = -12.815600818061
# Fidelity = 0.996504921927
# Overlap  = 0.851777117598
#
# Restart 2
# Energy   = -12.799117710237
# Fidelity = 0.994615021942
# Overlap  = 0.859834756911
#
# Restart 3
# Energy   = -12.798810664430
# Fidelity = 0.994055050146
# Overlap  = 0.859295531698
#
# Restart 4
# Energy   = -12.801427668414
# Fidelity = 0.994555090665
# Overlap  = 0.854938662152
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.815600818061
# Energy error     : 2.084032e-02
# Fidelity         : 0.996504921927
# Tracking overlap : 0.851777117598
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.690201958281
# Fidelity = 0.992773954473
# Overlap  = 0.160697189785
#
# Restart 1
# Energy   = -7.686266751814
# Fidelity = 0.992029347304
# Overlap  = 0.158808106822
#
# Restart 2
# Energy   = -7.689314729142
# Fidelity = 0.993054483508
# Overlap  = 0.166385500863
#
# Restart 3
# Energy   = -7.689217781544
# Fidelity = 0.992829204725
# Overlap  = 0.162208008521
#
# Restart 4
# Energy   = -7.685328284004
# Fidelity = 0.992230341638
# Overlap  = 0.164164774250
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.689314729142
# Energy error     : 4.140164e-02
# Fidelity         : 0.993054483508
# Tracking overlap : 0.166385500863
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.524720391976
# Fidelity = 0.997932562053
# Overlap  = 0.623307162615
#
# Restart 1
# Energy   = -5.522836594196
# Fidelity = 0.997571098152
# Overlap  = 0.629332281596
#
# Restart 2
# Energy   = -5.505185039791
# Fidelity = 0.993834827395
# Overlap  = 0.629292957343
#
# Restart 3
# Energy   = -5.515657496687
# Fidelity = 0.996427783550
# Overlap  = 0.631816783080
#
# Restart 4
# Energy   = -5.520750400397
# Fidelity = 0.997390142919
# Overlap  = 0.629774080464
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.524720391976
# Energy error     : 1.342844e-02
# Fidelity         : 0.997932562053
# Tracking overlap : 0.623307162615
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.267289940373
# Fidelity = 0.998778971837
# Overlap  = 0.825282250142
#
# Restart 1
# Energy   = -4.254218158082
# Fidelity = 0.996089413565
# Overlap  = 0.827668716600
#
# Restart 2
# Energy   = -4.256673534152
# Fidelity = 0.997322662990
# Overlap  = 0.823762407018
#
# Restart 3
# Energy   = -4.251027586016
# Fidelity = 0.994945884135
# Overlap  = 0.821467509802
#
# Restart 4
# Energy   = -4.253973907397
# Fidelity = 0.996457681543
# Overlap  = 0.827197555842
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.267289940373
# Energy error     : 8.723853e-03
# Fidelity         : 0.998778971837
# Tracking overlap : 0.825282250142
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.446340200213
# Fidelity = 0.999741755735
# Overlap  = 0.907953125904
#
# Restart 1
# Energy   = -3.442717503636
# Fidelity = 0.999276816251
# Overlap  = 0.906960980242
#
# Restart 2
# Energy   = -3.431445275976
# Fidelity = 0.996816230001
# Overlap  = 0.903042370919
#
# Restart 3
# Energy   = -3.414488324449
# Fidelity = 0.993105742959
# Overlap  = 0.899331905552
#
# Restart 4
# Energy   = -3.441214851504
# Fidelity = 0.998891881502
# Overlap  = 0.904260012186
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.446340200213
# Energy error     : 2.340185e-03
# Fidelity         : 0.999741755735
# Tracking overlap : 0.907953125904
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.859307313557
# Fidelity = 0.999832325776
# Overlap  = 0.942680292545
#
# Restart 1
# Energy   = -2.854353078598
# Fidelity = 0.999087657885
# Overlap  = 0.939561814665
#
# Restart 2
# Energy   = -2.852309024038
# Fidelity = 0.998904748598
# Overlap  = 0.943256963829
#
# Restart 3
# Energy   = -2.849684400363
# Fidelity = 0.997908666487
# Overlap  = 0.938017593602
#
# Restart 4
# Energy   = -2.839490194131
# Fidelity = 0.996630280629
# Overlap  = 0.938119009352
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.859307313557
# Energy error     : 1.524952e-03
# Fidelity         : 0.999832325776
# Tracking overlap : 0.942680292545
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.419127780089
# Fidelity = 0.999907961000
# Overlap  = 0.962712597891
#
# Restart 1
# Energy   = -2.398546287173
# Fidelity = 0.995639080975
# Overlap  = 0.951993778757
#
# Restart 2
# Energy   = -2.403011734009
# Fidelity = 0.996899796643
# Overlap  = 0.956125381780
#
# Restart 3
# Energy   = -2.403825194556
# Fidelity = 0.996898141578
# Overlap  = 0.957715186682
#
# Restart 4
# Energy   = -2.411034373951
# Fidelity = 0.998596855821
# Overlap  = 0.960397004948
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.419127780089
# Energy error     : 9.627492e-04
# Fidelity         : 0.999907961000
# Tracking overlap : 0.962712597891
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.075513207124
# Fidelity = 0.999929877444
# Overlap  = 0.974117526337
#
# Restart 1
# Energy   = -2.061783522131
# Fidelity = 0.996923648234
# Overlap  = 0.965070409918
#
# Restart 2
# Energy   = -2.058745822963
# Fidelity = 0.996996522629
# Overlap  = 0.965679049004
#
# Restart 3
# Energy   = -2.064874171132
# Fidelity = 0.998012143817
# Overlap  = 0.968041826103
#
# Restart 4
# Energy   = -2.061600465272
# Fidelity = 0.998030190357
# Overlap  = 0.969486084185
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.075513207124
# Energy error     : 7.993605e-04
# Fidelity         : 0.999929877444
# Tracking overlap : 0.974117526337
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.799256951646
# Fidelity = 0.999924007666
# Overlap  = 0.981074810527
#
# Restart 1
# Energy   = -1.786933048078
# Fidelity = 0.997861622031
# Overlap  = 0.975082336702
#
# Restart 2
# Energy   = -1.775954028459
# Fidelity = 0.995402952439
# Overlap  = 0.971641194350
#
# Restart 3
# Energy   = -1.777266184095
# Fidelity = 0.996188513740
# Overlap  = 0.972277477786
#
# Restart 4
# Energy   = -1.782927363605
# Fidelity = 0.997013162692
# Overlap  = 0.973797512547
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.799256951646
# Energy error     : 8.163146e-04
# Fidelity         : 0.999924007666
# Tracking overlap : 0.981074810527
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Strong SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -20.7773284453      -20.7473648349      2.9964e-02        0.9974050763      1.0000000000      4
# 0.3111      -12.8364411428      -12.8156008181      2.0840e-02        0.9965049219      0.8517771176      4
# 0.5222      -7.7307163648       -7.6893147291       4.1402e-02        0.9930544835      0.1663855009      4
# 0.7333      -5.5381488307       -5.5247203920       1.3428e-02        0.9979325621      0.6233071626      4
# 0.9444      -4.2760137929       -4.2672899404       8.7239e-03        0.9987789718      0.8252822501      4
# 1.1556      -3.4486803854       -3.4463402002       2.3402e-03        0.9997417557      0.9079531259      4
# 1.3667      -2.8608322652       -2.8593073136       1.5250e-03        0.9998323258      0.9426802925      4
# 1.5778      -2.4200905293       -2.4191277801       9.6275e-04        0.9999079610      0.9627125979      4
# 1.7889      -2.0763125676       -2.0755132071       7.9936e-04        0.9999298774      0.9741175263      4
# 2.0000      -1.8000732662       -1.7992569516       8.1631e-04        0.9999240077      0.9810748105      4

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#
plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HVA_Floc vs lambda different f.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    
    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,
        'psi_vqe': psi_vqe,
        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98120153
# T = 2     Fidelity = 0.99733503
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98268102
# T = 2     Fidelity = 0.99772196
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394175
# T = 2     Fidelity = 0.99802421
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98504079
# T = 2     Fidelity = 0.99826785
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98600418
# T = 2     Fidelity = 0.99846517
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98685100
# T = 2     Fidelity = 0.99862416
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762732
# T = 2     Fidelity = 0.99876342
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98830707
# T = 2     Fidelity = 0.99887184
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893540
# T = 2     Fidelity = 0.99896878
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98949971
# T = 2     Fidelity = 0.99904930
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00039285
# T = 10    Fidelity = 0.00045290
# T = 20    Fidelity = 0.01150509
# T = 30    Fidelity = 0.08406971
# T = 40    Fidelity = 0.18453594
# T = 50    Fidelity = 0.42970401
# T = 75    Fidelity = 0.56240175
# T = 100   Fidelity = 0.73458299
# T = 125   Fidelity = 0.79692328
# T = 150   Fidelity = 0.84180135
# T = 175   Fidelity = 0.90086721
# T = 200   Fidelity = 0.92404415
# T = 225   Fidelity = 0.96234625
# T = 250   Fidelity = 0.89522427
# T = 275   Fidelity = 0.96582665
# T = 300   Fidelity = 0.85987988
# T = 400   Fidelity = 0.98001052
# T = 500   Fidelity = 0.96228452
# T = 600   Fidelity = 0.95926980
# T = 700   Fidelity = 0.61698539
# T = 800   Fidelity = 0.83129698
# T = 900   Fidelity = 0.82405057
# T = 1000  Fidelity = 0.66420368
# T = 1010  Fidelity = 0.57845517
# T = 1020  Fidelity = 0.62233185
# T = 1030  Fidelity = 0.70022480
# T = 1040  Fidelity = 0.72245715
# T = 1050  Fidelity = 0.79246629
# T = 1060  Fidelity = 0.91744357
# T = 1070  Fidelity = 0.77606170
# T = 1080  Fidelity = 0.79379924
# T = 1090  Fidelity = 0.71432747
# T = 1100  Fidelity = 0.38960853
# T = 1200  Fidelity = 0.59459857
# T = 1300  Fidelity = 0.48577945
# T = 1400  Fidelity = 0.70958250
# T = 1500  Fidelity = 0.45788074
# T = 2000  Fidelity = 0.93840682
# T = 2100  Fidelity = 0.70957204
# T = 2110  Fidelity = 0.56507753
# T = 2120  Fidelity = 0.46815729
# T = 2130  Fidelity = 0.39210442
# T = 2140  Fidelity = 0.49306250
# T = 2150  Fidelity = 0.40934385
# T = 2160  Fidelity = 0.62659326
# T = 2170  Fidelity = 0.52230843
# T = 2180  Fidelity = 0.49016363
# T = 2190  Fidelity = 0.49975347
# T = 2200  Fidelity = 0.34930135
# T = 2300  Fidelity = 0.77650193
# T = 2400  Fidelity = 0.22297257
# T = 2500  Fidelity = 0.76025330
# T = 2600  Fidelity = 0.44116500
# T = 2700  Fidelity = 0.55184286
# T = 2800  Fidelity = 0.84719692
# T = 2900  Fidelity = 0.63752668
# T = 3000  Fidelity = 0.83482796
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00976726e+00
# P0     = 0.83482796
# P1     = 0.05944451
# P0+P1  = 0.89427247
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000010
# T = 2     Fidelity = 0.00000032
# T = 5     Fidelity = 0.00044125
# T = 10    Fidelity = 0.06716152
# T = 20    Fidelity = 0.20915589
# T = 30    Fidelity = 0.62299723
# T = 40    Fidelity = 0.34632101
# T = 50    Fidelity = 0.78375097
# T = 75    Fidelity = 0.73123735
# T = 100   Fidelity = 0.77933849
# T = 125   Fidelity = 0.86212567
# T = 150   Fidelity = 0.86631652
# T = 175   Fidelity = 0.88448074
# T = 200   Fidelity = 0.91062415
# T = 225   Fidelity = 0.92204430
# T = 250   Fidelity = 0.93337626
# T = 275   Fidelity = 0.93822680
# T = 300   Fidelity = 0.94053972
# T = 400   Fidelity = 0.96236425
# T = 500   Fidelity = 0.96952575
# T = 600   Fidelity = 0.83452043
# T = 700   Fidelity = 0.81678372
# T = 800   Fidelity = 0.86982764
# T = 900   Fidelity = 0.72946808
# T = 1000  Fidelity = 0.77725291
# T = 1010  Fidelity = 0.89591225
# T = 1020  Fidelity = 0.86428101
# T = 1030  Fidelity = 0.92245648
# T = 1040  Fidelity = 0.85033976
# T = 1050  Fidelity = 0.86698115
# T = 1060  Fidelity = 0.75236085
# T = 1070  Fidelity = 0.78326414
# T = 1080  Fidelity = 0.53275566
# T = 1090  Fidelity = 0.67287168
# T = 1100  Fidelity = 0.54772995
# T = 1200  Fidelity = 0.77941747
# T = 1300  Fidelity = 0.81804173
# T = 1400  Fidelity = 0.94011994
# T = 1500  Fidelity = 0.84346988
# T = 2000  Fidelity = 0.61331878
# T = 2100  Fidelity = 0.60693205
# T = 2110  Fidelity = 0.69669500
# T = 2120  Fidelity = 0.82839305
# T = 2130  Fidelity = 0.95566430
# T = 2140  Fidelity = 0.78558240
# T = 2150  Fidelity = 0.82185405
# T = 2160  Fidelity = 0.89793962
# T = 2170  Fidelity = 0.60335060
# T = 2180  Fidelity = 0.87540583
# T = 2190  Fidelity = 0.59851317
# T = 2200  Fidelity = 0.46749670
# T = 2300  Fidelity = 0.47832736
# T = 2400  Fidelity = 0.66046620
# T = 2500  Fidelity = 0.32705287
# T = 2600  Fidelity = 0.92327845
# T = 2700  Fidelity = 0.83838024
# T = 2800  Fidelity = 0.85912283
# T = 2900  Fidelity = 0.83286699
# T = 3000  Fidelity = 0.87234743
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02946706e+00
# P0     = 0.87234743
# P1     = 0.00823571
# P0+P1  = 0.88058315
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00004838
# T = 2     Fidelity = 0.00033498
# T = 5     Fidelity = 0.01953376
# T = 10    Fidelity = 0.21504121
# T = 20    Fidelity = 0.59146879
# T = 30    Fidelity = 0.65178227
# T = 40    Fidelity = 0.78757652
# T = 50    Fidelity = 0.81224495
# T = 75    Fidelity = 0.91781384
# T = 100   Fidelity = 0.95987167
# T = 125   Fidelity = 0.97592268
# T = 150   Fidelity = 0.98329241
# T = 175   Fidelity = 0.98779408
# T = 200   Fidelity = 0.98637953
# T = 225   Fidelity = 0.99004028
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00121919
# T = 2     Fidelity = 0.00503337
# T = 5     Fidelity = 0.06202387
# T = 10    Fidelity = 0.27802192
# T = 20    Fidelity = 0.67914456
# T = 30    Fidelity = 0.73829558
# T = 40    Fidelity = 0.81846761
# T = 50    Fidelity = 0.88457716
# T = 75    Fidelity = 0.95370905
# T = 100   Fidelity = 0.98019212
# T = 125   Fidelity = 0.99143269
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00869765
# T = 2     Fidelity = 0.02369931
# T = 5     Fidelity = 0.12535387
# T = 10    Fidelity = 0.34035383
# T = 20    Fidelity = 0.66852373
# T = 30    Fidelity = 0.79863698
# T = 40    Fidelity = 0.85988592
# T = 50    Fidelity = 0.90915632
# T = 75    Fidelity = 0.96967528
# T = 100   Fidelity = 0.98885420
# T = 125   Fidelity = 0.99529933
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03438455
# T = 2     Fidelity = 0.07378968
# T = 5     Fidelity = 0.22318431
# T = 10    Fidelity = 0.42860819
# T = 20    Fidelity = 0.67839446
# T = 30    Fidelity = 0.79992786
# T = 40    Fidelity = 0.86887289
# T = 50    Fidelity = 0.91606016
# T = 75    Fidelity = 0.97754731
# T = 100   Fidelity = 0.99426571
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09468455
# T = 2     Fidelity = 0.17283711
# T = 5     Fidelity = 0.36419628
# T = 10    Fidelity = 0.55456624
# T = 20    Fidelity = 0.74097615
# T = 30    Fidelity = 0.83053776
# T = 40    Fidelity = 0.88278631
# T = 50    Fidelity = 0.91727999
# T = 75    Fidelity = 0.96557062
# T = 100   Fidelity = 0.98468950
# T = 125   Fidelity = 0.99195573
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19080952
# T = 2     Fidelity = 0.31218768
# T = 5     Fidelity = 0.52442571
# T = 10    Fidelity = 0.69096215
# T = 20    Fidelity = 0.82682999
# T = 30    Fidelity = 0.88663814
# T = 40    Fidelity = 0.92117368
# T = 50    Fidelity = 0.94293121
# T = 75    Fidelity = 0.96973121
# T = 100   Fidelity = 0.98247465
# T = 125   Fidelity = 0.98827088
# T = 150   Fidelity = 0.99127273
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30086375
# T = 2     Fidelity = 0.45451776
# T = 5     Fidelity = 0.66196179
# T = 10    Fidelity = 0.79872260
# T = 20    Fidelity = 0.89466903
# T = 30    Fidelity = 0.93338720
# T = 40    Fidelity = 0.95500547
# T = 50    Fidelity = 0.96706068
# T = 75    Fidelity = 0.98289395
# T = 100   Fidelity = 0.98925438
# T = 125   Fidelity = 0.99266213
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40285137
# T = 2     Fidelity = 0.57352909
# T = 5     Fidelity = 0.76104269
# T = 10    Fidelity = 0.86954719
# T = 20    Fidelity = 0.93662440
# T = 30    Fidelity = 0.96216538
# T = 40    Fidelity = 0.97416213
# T = 50    Fidelity = 0.98188142
# T = 75    Fidelity = 0.99096757
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.36752113e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063828
# T = 10    Fidelity = 0.00011139
# T = 20    Fidelity = 0.00392865
# T = 30    Fidelity = 0.05566348
# T = 40    Fidelity = 0.12212276
# T = 50    Fidelity = 0.21078606
# T = 75    Fidelity = 0.58013743
# T = 100   Fidelity = 0.76393993
# T = 125   Fidelity = 0.73432124
# T = 150   Fidelity = 0.86833638
# T = 175   Fidelity = 0.91237708
# T = 200   Fidelity = 0.87339279
# T = 225   Fidelity = 0.94959462
# T = 250   Fidelity = 0.98281566
# T = 275   Fidelity = 0.98445603
# T = 300   Fidelity = 0.86178002
# T = 400   Fidelity = 0.91264438
# T = 500   Fidelity = 0.92580139
# T = 600   Fidelity = 0.92032453
# T = 700   Fidelity = 0.91441426
# T = 800   Fidelity = 0.81904659
# T = 900   Fidelity = 0.78128468
# T = 1000  Fidelity = 0.67300414
# T = 1010  Fidelity = 0.52136307
# T = 1020  Fidelity = 0.57409576
# T = 1030  Fidelity = 0.75316617
# T = 1040  Fidelity = 0.89717793
# T = 1050  Fidelity = 0.85599971
# T = 1060  Fidelity = 0.83226495
# T = 1070  Fidelity = 0.70141130
# T = 1080  Fidelity = 0.54317800
# T = 1090  Fidelity = 0.51178266
# T = 1100  Fidelity = 0.55178586
# T = 1200  Fidelity = 0.66930515
# T = 1300  Fidelity = 0.58644242
# T = 1400  Fidelity = 0.67197958
# T = 1500  Fidelity = 0.29038932
# T = 2000  Fidelity = 0.11321500
# T = 2100  Fidelity = 0.68396567
# T = 2110  Fidelity = 0.68285581
# T = 2120  Fidelity = 0.73288011
# T = 2130  Fidelity = 0.81546154
# T = 2140  Fidelity = 0.85538974
# T = 2150  Fidelity = 0.92138862
# T = 2160  Fidelity = 0.90461587
# T = 2170  Fidelity = 0.86473578
# T = 2180  Fidelity = 0.77544743
# T = 2190  Fidelity = 0.40593971
# T = 2200  Fidelity = 0.25863028
# T = 2300  Fidelity = 0.55505132
# T = 2400  Fidelity = 0.82918024
# T = 2500  Fidelity = 0.90436014
# T = 2600  Fidelity = 0.80325032
# T = 2700  Fidelity = 0.81228164
# T = 2800  Fidelity = 0.35130478
# T = 2900  Fidelity = 0.88640739
# T = 3000  Fidelity = 0.74256311
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00970921e+00
# P0     = 0.74256311
# P1     = 0.04107924
# P0+P1  = 0.78364235
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.12924856e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000005
# T = 5     Fidelity = 0.00017437
# T = 10    Fidelity = 0.04094424
# T = 20    Fidelity = 0.41978870
# T = 30    Fidelity = 0.49085338
# T = 40    Fidelity = 0.63908800
# T = 50    Fidelity = 0.64496795
# T = 75    Fidelity = 0.88089306
# T = 100   Fidelity = 0.90014591
# T = 125   Fidelity = 0.87052106
# T = 150   Fidelity = 0.88531282
# T = 175   Fidelity = 0.91968717
# T = 200   Fidelity = 0.94073858
# T = 225   Fidelity = 0.95464737
# T = 250   Fidelity = 0.94829956
# T = 275   Fidelity = 0.95931154
# T = 300   Fidelity = 0.94111893
# T = 400   Fidelity = 0.97560894
# T = 500   Fidelity = 0.95680039
# T = 600   Fidelity = 0.92576009
# T = 700   Fidelity = 0.56072995
# T = 800   Fidelity = 0.61458785
# T = 900   Fidelity = 0.68063492
# T = 1000  Fidelity = 0.89555939
# T = 1010  Fidelity = 0.57370855
# T = 1020  Fidelity = 0.84823975
# T = 1030  Fidelity = 0.84549726
# T = 1040  Fidelity = 0.71473513
# T = 1050  Fidelity = 0.85627521
# T = 1060  Fidelity = 0.56824095
# T = 1070  Fidelity = 0.81298263
# T = 1080  Fidelity = 0.63104128
# T = 1090  Fidelity = 0.82134718
# T = 1100  Fidelity = 0.71123075
# T = 1200  Fidelity = 0.62151627
# T = 1300  Fidelity = 0.60322241
# T = 1400  Fidelity = 0.54761471
# T = 1500  Fidelity = 0.71035396
# T = 2000  Fidelity = 0.50475462
# T = 2100  Fidelity = 0.70857837
# T = 2110  Fidelity = 0.68583883
# T = 2120  Fidelity = 0.82861542
# T = 2130  Fidelity = 0.67028788
# T = 2140  Fidelity = 0.59211957
# T = 2150  Fidelity = 0.80539968
# T = 2160  Fidelity = 0.53456521
# T = 2170  Fidelity = 0.69389759
# T = 2180  Fidelity = 0.65876287
# T = 2190  Fidelity = 0.76811200
# T = 2200  Fidelity = 0.50380945
# T = 2300  Fidelity = 0.67244879
# T = 2400  Fidelity = 0.66622146
# T = 2500  Fidelity = 0.66006348
# T = 2600  Fidelity = 0.71520299
# T = 2700  Fidelity = 0.76609037
# T = 2800  Fidelity = 0.79742684
# T = 2900  Fidelity = 0.52916161
# T = 3000  Fidelity = 0.55691517
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02931057e+00
# P0     = 0.55691517
# P1     = 0.20920977
# P0+P1  = 0.76612494
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00001177
# T = 2     Fidelity = 0.00016805
# T = 5     Fidelity = 0.01431531
# T = 10    Fidelity = 0.17117508
# T = 20    Fidelity = 0.44214451
# T = 30    Fidelity = 0.33997806
# T = 40    Fidelity = 0.54659980
# T = 50    Fidelity = 0.43851475
# T = 75    Fidelity = 0.49333206
# T = 100   Fidelity = 0.50292062
# T = 125   Fidelity = 0.50285654
# T = 150   Fidelity = 0.50201350
# T = 175   Fidelity = 0.50122039
# T = 200   Fidelity = 0.49675630
# T = 225   Fidelity = 0.50848905
# T = 250   Fidelity = 0.50108228
# T = 275   Fidelity = 0.48721779
# T = 300   Fidelity = 0.48715404
# T = 400   Fidelity = 0.49783374
# T = 500   Fidelity = 0.30868097
# T = 600   Fidelity = 0.50891256
# T = 700   Fidelity = 0.38907394
# T = 800   Fidelity = 0.53429416
# T = 900   Fidelity = 0.53080556
# T = 1000  Fidelity = 0.70164162
# T = 1010  Fidelity = 0.39705447
# T = 1020  Fidelity = 0.40320885
# T = 1030  Fidelity = 0.47087782
# T = 1040  Fidelity = 0.49897957
# T = 1050  Fidelity = 0.46757404
# T = 1060  Fidelity = 0.37073158
# T = 1070  Fidelity = 0.56167272
# T = 1080  Fidelity = 0.26836458
# T = 1090  Fidelity = 0.27750362
# T = 1100  Fidelity = 0.61170609
# T = 1200  Fidelity = 0.29294971
# T = 1300  Fidelity = 0.55329496
# T = 1400  Fidelity = 0.53768999
# T = 1500  Fidelity = 0.36471323
# T = 2000  Fidelity = 0.29341696
# T = 2100  Fidelity = 0.20705739
# T = 2110  Fidelity = 0.55577553
# T = 2120  Fidelity = 0.47644330
# T = 2130  Fidelity = 0.50448027
# T = 2140  Fidelity = 0.32803493
# T = 2150  Fidelity = 0.44966742
# T = 2160  Fidelity = 0.39020387
# T = 2170  Fidelity = 0.39553590
# T = 2180  Fidelity = 0.53501478
# T = 2190  Fidelity = 0.19722272
# T = 2200  Fidelity = 0.49074703
# T = 2300  Fidelity = 0.53776380
# T = 2400  Fidelity = 0.49324440
# T = 2500  Fidelity = 0.46426866
# T = 2600  Fidelity = 0.46644572
# T = 2700  Fidelity = 0.57595499
# T = 2800  Fidelity = 0.60691936
# T = 2900  Fidelity = 0.46218524
# T = 3000  Fidelity = 0.43563873
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.43563873
# P1     = 0.05289424
# P0+P1  = 0.48853297
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.03672155e-03
# T = 1     Fidelity = 0.00295906
# T = 2     Fidelity = 0.01197936
# T = 5     Fidelity = 0.08239313
# T = 10    Fidelity = 0.21873053
# T = 20    Fidelity = 0.31177358
# T = 30    Fidelity = 0.37944791
# T = 40    Fidelity = 0.54299827
# T = 50    Fidelity = 0.57136537
# T = 75    Fidelity = 0.49325725
# T = 100   Fidelity = 0.51352712
# T = 125   Fidelity = 0.51509227
# T = 150   Fidelity = 0.51470858
# T = 175   Fidelity = 0.51136208
# T = 200   Fidelity = 0.52130214
# T = 225   Fidelity = 0.51377733
# T = 250   Fidelity = 0.50909832
# T = 275   Fidelity = 0.51715575
# T = 300   Fidelity = 0.48623210
# T = 400   Fidelity = 0.49910069
# T = 500   Fidelity = 0.54139433
# T = 600   Fidelity = 0.49902109
# T = 700   Fidelity = 0.43215867
# T = 800   Fidelity = 0.44105988
# T = 900   Fidelity = 0.53124909
# T = 1000  Fidelity = 0.75424792
# T = 1010  Fidelity = 0.42485662
# T = 1020  Fidelity = 0.12361757
# T = 1030  Fidelity = 0.55800105
# T = 1040  Fidelity = 0.77376913
# T = 1050  Fidelity = 0.57126878
# T = 1060  Fidelity = 0.47328953
# T = 1070  Fidelity = 0.48279257
# T = 1080  Fidelity = 0.40661230
# T = 1090  Fidelity = 0.25529781
# T = 1100  Fidelity = 0.73126261
# T = 1200  Fidelity = 0.56407123
# T = 1300  Fidelity = 0.44238383
# T = 1400  Fidelity = 0.50926187
# T = 1500  Fidelity = 0.52631720
# T = 2000  Fidelity = 0.45211779
# T = 2100  Fidelity = 0.49687511
# T = 2110  Fidelity = 0.53741174
# T = 2120  Fidelity = 0.45435925
# T = 2130  Fidelity = 0.38580087
# T = 2140  Fidelity = 0.55622327
# T = 2150  Fidelity = 0.74151964
# T = 2160  Fidelity = 0.41340173
# T = 2170  Fidelity = 0.23718586
# T = 2180  Fidelity = 0.49330070
# T = 2190  Fidelity = 0.67523404
# T = 2200  Fidelity = 0.58895023
# T = 2300  Fidelity = 0.80058877
# T = 2400  Fidelity = 0.50761324
# T = 2500  Fidelity = 0.47943491
# T = 2600  Fidelity = 0.53593255
# T = 2700  Fidelity = 0.42825914
# T = 2800  Fidelity = 0.51895807
# T = 2900  Fidelity = 0.28740218
# T = 3000  Fidelity = 0.42865171
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.42865171
# P1     = 0.04966669
# P0+P1  = 0.47831841
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.41475042e-03
# T = 1     Fidelity = 0.02415758
# T = 2     Fidelity = 0.06505010
# T = 5     Fidelity = 0.21717839
# T = 10    Fidelity = 0.40117032
# T = 20    Fidelity = 0.52045230
# T = 30    Fidelity = 0.49075899
# T = 40    Fidelity = 0.49819754
# T = 50    Fidelity = 0.54360192
# T = 75    Fidelity = 0.60199214
# T = 100   Fidelity = 0.60046666
# T = 125   Fidelity = 0.60552629
# T = 150   Fidelity = 0.60949836
# T = 175   Fidelity = 0.61281384
# T = 200   Fidelity = 0.61994162
# T = 225   Fidelity = 0.62253608
# T = 250   Fidelity = 0.62640295
# T = 275   Fidelity = 0.62377435
# T = 300   Fidelity = 0.63889666
# T = 400   Fidelity = 0.58835577
# T = 500   Fidelity = 0.64836173
# T = 600   Fidelity = 0.67177645
# T = 700   Fidelity = 0.59130353
# T = 800   Fidelity = 0.70940377
# T = 900   Fidelity = 0.60377427
# T = 1000  Fidelity = 0.48597592
# T = 1010  Fidelity = 0.75724133
# T = 1020  Fidelity = 0.84516329
# T = 1030  Fidelity = 0.74073896
# T = 1040  Fidelity = 0.52511577
# T = 1050  Fidelity = 0.47350933
# T = 1060  Fidelity = 0.64935440
# T = 1070  Fidelity = 0.77152351
# T = 1080  Fidelity = 0.81310046
# T = 1090  Fidelity = 0.55023727
# T = 1100  Fidelity = 0.39942132
# T = 1200  Fidelity = 0.46047679
# T = 1300  Fidelity = 0.54033491
# T = 1400  Fidelity = 0.76521708
# T = 1500  Fidelity = 0.67840133
# T = 2000  Fidelity = 0.77201545
# T = 2100  Fidelity = 0.81916518
# T = 2110  Fidelity = 0.80669162
# T = 2120  Fidelity = 0.55197664
# T = 2130  Fidelity = 0.65764123
# T = 2140  Fidelity = 0.71502261
# T = 2150  Fidelity = 0.83157626
# T = 2160  Fidelity = 0.84550573
# T = 2170  Fidelity = 0.77675457
# T = 2180  Fidelity = 0.53371956
# T = 2190  Fidelity = 0.57401559
# T = 2200  Fidelity = 0.70276588
# T = 2300  Fidelity = 0.75851315
# T = 2400  Fidelity = 0.75523427
# T = 2500  Fidelity = 0.82705540
# T = 2600  Fidelity = 0.73124401
# T = 2700  Fidelity = 0.78134715
# T = 2800  Fidelity = 0.76251402
# T = 2900  Fidelity = 0.70168017
# T = 3000  Fidelity = 0.75545811
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.75545811
# P1     = 0.00510085
# P0+P1  = 0.76055896
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50213251e-02
# T = 1     Fidelity = 0.08250714
# T = 2     Fidelity = 0.17428471
# T = 5     Fidelity = 0.39073918
# T = 10    Fidelity = 0.58335897
# T = 20    Fidelity = 0.71099896
# T = 30    Fidelity = 0.71767887
# T = 40    Fidelity = 0.71066483
# T = 50    Fidelity = 0.71651110
# T = 75    Fidelity = 0.74196085
# T = 100   Fidelity = 0.76032000
# T = 125   Fidelity = 0.77316153
# T = 150   Fidelity = 0.78378165
# T = 175   Fidelity = 0.79292119
# T = 200   Fidelity = 0.80219821
# T = 225   Fidelity = 0.80834819
# T = 250   Fidelity = 0.81391532
# T = 275   Fidelity = 0.82416079
# T = 300   Fidelity = 0.81554987
# T = 400   Fidelity = 0.87241797
# T = 500   Fidelity = 0.86908448
# T = 600   Fidelity = 0.79302992
# T = 700   Fidelity = 0.82647327
# T = 800   Fidelity = 0.84368911
# T = 900   Fidelity = 0.85128768
# T = 1000  Fidelity = 0.87545696
# T = 1010  Fidelity = 0.79261821
# T = 1020  Fidelity = 0.77867837
# T = 1030  Fidelity = 0.86735330
# T = 1040  Fidelity = 0.94984667
# T = 1050  Fidelity = 0.97141575
# T = 1060  Fidelity = 0.93326145
# T = 1070  Fidelity = 0.82776118
# T = 1080  Fidelity = 0.84044697
# T = 1090  Fidelity = 0.76808322
# T = 1100  Fidelity = 0.82710607
# T = 1200  Fidelity = 0.79698655
# T = 1300  Fidelity = 0.95427904
# T = 1400  Fidelity = 0.85357092
# T = 1500  Fidelity = 0.92707207
# T = 2000  Fidelity = 0.85868884
# T = 2100  Fidelity = 0.86660227
# T = 2110  Fidelity = 0.86624148
# T = 2120  Fidelity = 0.92032868
# T = 2130  Fidelity = 0.86336948
# T = 2140  Fidelity = 0.87972193
# T = 2150  Fidelity = 0.80845437
# T = 2160  Fidelity = 0.83589734
# T = 2170  Fidelity = 0.95244348
# T = 2180  Fidelity = 0.93647583
# T = 2190  Fidelity = 0.93582156
# T = 2200  Fidelity = 0.93937071
# T = 2300  Fidelity = 0.94844838
# T = 2400  Fidelity = 0.97078664
# T = 2500  Fidelity = 0.96297847
# T = 2600  Fidelity = 0.98595018
# T = 2700  Fidelity = 0.96755173
# T = 2800  Fidelity = 0.95066986
# T = 2900  Fidelity = 0.85351092
# T = 3000  Fidelity = 0.97072478
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.09849352e+00
# P0     = 0.97072478
# P1     = 0.00084536
# P0+P1  = 0.97157014
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77221454e-02
# T = 1     Fidelity = 0.17596301
# T = 2     Fidelity = 0.31634461
# T = 5     Fidelity = 0.55514259
# T = 10    Fidelity = 0.72441715
# T = 20    Fidelity = 0.82863732
# T = 30    Fidelity = 0.85218874
# T = 40    Fidelity = 0.85804974
# T = 50    Fidelity = 0.86375619
# T = 75    Fidelity = 0.88119437
# T = 100   Fidelity = 0.89750055
# T = 125   Fidelity = 0.90890515
# T = 150   Fidelity = 0.91722527
# T = 175   Fidelity = 0.92487375
# T = 200   Fidelity = 0.93403360
# T = 225   Fidelity = 0.93499683
# T = 250   Fidelity = 0.93508708
# T = 275   Fidelity = 0.94451209
# T = 300   Fidelity = 0.93484339
# T = 400   Fidelity = 0.94836341
# T = 500   Fidelity = 0.95193224
# T = 600   Fidelity = 0.95975358
# T = 700   Fidelity = 0.91503062
# T = 800   Fidelity = 0.92731219
# T = 900   Fidelity = 0.94626694
# T = 1000  Fidelity = 0.93918180
# T = 1010  Fidelity = 0.95110224
# T = 1020  Fidelity = 0.95596423
# T = 1030  Fidelity = 0.97787095
# T = 1040  Fidelity = 0.99387967
#
# Minimum T for Fidelity >= 0.99 : 1040
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20187623e-01
# T = 1     Fidelity = 0.28153215
# T = 2     Fidelity = 0.45409215
# T = 5     Fidelity = 0.68232474
# T = 10    Fidelity = 0.81934000
# T = 20    Fidelity = 0.89618689
# T = 30    Fidelity = 0.91751763
# T = 40    Fidelity = 0.92883450
# T = 50    Fidelity = 0.93747946
# T = 75    Fidelity = 0.95116729
# T = 100   Fidelity = 0.96142242
# T = 125   Fidelity = 0.96783524
# T = 150   Fidelity = 0.97370362
# T = 175   Fidelity = 0.97531369
# T = 200   Fidelity = 0.98127872
# T = 225   Fidelity = 0.97751380
# T = 250   Fidelity = 0.98053141
# T = 275   Fidelity = 0.97825678
# T = 300   Fidelity = 0.97958857
# T = 400   Fidelity = 0.97412859
# T = 500   Fidelity = 0.95299642
# T = 600   Fidelity = 0.93667487
# T = 700   Fidelity = 0.97950655
# T = 800   Fidelity = 0.98391382
# T = 900   Fidelity = 0.98856812
# T = 1000  Fidelity = 0.97830028
# T = 1010  Fidelity = 0.97086107
# T = 1020  Fidelity = 0.99514816
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405779e-01
# T = 1     Fidelity = 0.37937916
# T = 2     Fidelity = 0.56725829
# T = 5     Fidelity = 0.77067560
# T = 10    Fidelity = 0.87934621
# T = 20    Fidelity = 0.93528205
# T = 30    Fidelity = 0.95271209
# T = 40    Fidelity = 0.96388915
# T = 50    Fidelity = 0.96954866
# T = 75    Fidelity = 0.97943036
# T = 100   Fidelity = 0.98496161
# T = 125   Fidelity = 0.98817883
# T = 150   Fidelity = 0.99052092
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843475e-01
# T = 1     Fidelity = 0.46490191
# T = 2     Fidelity = 0.65637178
# T = 5     Fidelity = 0.83150139
# T = 10    Fidelity = 0.91722717
# T = 20    Fidelity = 0.95850036
# T = 30    Fidelity = 0.97278058
# T = 40    Fidelity = 0.97900577
# T = 50    Fidelity = 0.98356321
# T = 75    Fidelity = 0.99009969
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000041
# T = 2     Fidelity = 0.00000088
# T = 5     Fidelity = 0.00066600
# T = 10    Fidelity = 0.06627187
# T = 20    Fidelity = 0.45590228
# T = 30    Fidelity = 0.87712020
# T = 40    Fidelity = 0.96701364
# T = 50    Fidelity = 0.98816220
# T = 75    Fidelity = 0.99535198
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000105
# T = 5     Fidelity = 0.02575360
# T = 10    Fidelity = 0.89444810
# T = 20    Fidelity = 0.96587252
# T = 30    Fidelity = 0.99365551
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00007495
# T = 2     Fidelity = 0.00055321
# T = 5     Fidelity = 0.18955002
# T = 10    Fidelity = 0.98201060
# T = 20    Fidelity = 0.98813293
# T = 30    Fidelity = 0.98434148
# T = 40    Fidelity = 0.98700848
# T = 50    Fidelity = 0.99089539
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00117515
# T = 2     Fidelity = 0.00839742
# T = 5     Fidelity = 0.33664555
# T = 10    Fidelity = 0.98320788
# T = 20    Fidelity = 0.99086940
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00744226
# T = 2     Fidelity = 0.02949844
# T = 5     Fidelity = 0.46518103
# T = 10    Fidelity = 0.97937002
# T = 20    Fidelity = 0.99180485
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02100485
# T = 2     Fidelity = 0.06445995
# T = 5     Fidelity = 0.56430018
# T = 10    Fidelity = 0.97574362
# T = 20    Fidelity = 0.99236119
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04406405
# T = 2     Fidelity = 0.11028600
# T = 5     Fidelity = 0.63712552
# T = 10    Fidelity = 0.97165059
# T = 20    Fidelity = 0.99256001
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07570249
# T = 2     Fidelity = 0.16374625
# T = 5     Fidelity = 0.69551052
# T = 10    Fidelity = 0.96908380
# T = 20    Fidelity = 0.99310451
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11404949
# T = 2     Fidelity = 0.22092143
# T = 5     Fidelity = 0.74261638
# T = 10    Fidelity = 0.96760491
# T = 20    Fidelity = 0.99356117
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15744439
# T = 2     Fidelity = 0.27936145
# T = 5     Fidelity = 0.78076827
# T = 10    Fidelity = 0.96696650
# T = 20    Fidelity = 0.99385901
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9973350270      1.00972087e+00    None        None        None
# Symmetric      0.311     2         0.9977219589      1.02934439e+00    None        None        None
# Symmetric      0.522     2         0.9980242059      1.04790824e+00    None        None        None
# Symmetric      0.733     2         0.9982678542      1.06556366e+00    None        None        None
# Symmetric      0.944     2         0.9984651700      1.08242773e+00    None        None        None
# Symmetric      1.156     2         0.9986241624      1.09859358e+00    None        None        None
# Symmetric      1.367     2         0.9987634239      1.11413694e+00    None        None        None
# Symmetric      1.578     2         0.9988718383      1.12912045e+00    None        None        None
# Symmetric      1.789     2         0.9989687828      1.14359670e+00    None        None        None
# Symmetric      2.000     2         0.9990493035      1.15761039e+00    None        None        None
# Weak SSB optimised0.100     None      0.9800105216      2.42819099e-01    0.834828    0.059445    0.894272
# Weak SSB optimised0.311     None      0.9695257459      2.61171322e-01    0.872347    0.008236    0.880583
# Weak SSB optimised0.522     225       0.9900402827      2.64873214e-01    None        None        None
# Weak SSB optimised0.733     125       0.9914326899      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     125       0.9952993294      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     100       0.9942657132      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9919557274      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     150       0.9912727340      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9926621303      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     75        0.9909675671      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9844560279      1.36752113e-03    0.742563    0.041079    0.783642
# Weak SSB       0.311     None      0.9756089402      1.12924856e-03    0.556915    0.20921     0.766125
# Weak SSB       0.522     None      0.7016416229      1.05614584e-03    0.435639    0.052894    0.488533
# Weak SSB       0.733     None      0.8005887702      1.03672155e-03    0.428652    0.049667    0.478318
# Weak SSB       0.944     None      0.8455057306      4.41475042e-03    0.755458    0.005101    0.760559
# Weak SSB       1.156     None      0.9859501834      2.50213251e-02    0.970725    0.000845    0.97157
# Weak SSB       1.367     1040      0.9938796709      6.77221454e-02    None        None        None
# Weak SSB       1.578     1020      0.9951481591      1.20187623e-01    None        None        None
# Weak SSB       1.789     150       0.9905209197      1.71405779e-01    None        None        None
# Weak SSB       2.000     75        0.9900996926      2.18843475e-01    None        None        None
# Strong SSB     0.100     75        0.9953519820      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9936555067      7.22062439e-01    None        None        None
# Strong SSB     0.522     50        0.9908953869      7.78318602e-01    None        None        None
# Strong SSB     0.733     20        0.9908693969      8.15979742e-01    None        None        None
# Strong SSB     0.944     20        0.9918048533      8.44059983e-01    None        None        None
# Strong SSB     1.156     20        0.9923611921      8.66317759e-01    None        None        None
# Strong SSB     1.367     20        0.9925600087      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9931045065      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9935611672      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9938590128      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HVA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
#============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_list,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_list,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_list,
    d2M_strong,
    d3M_strong
)

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=1$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96522373
# T = 2     Fidelity = 0.99334907
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.03626623e+00
# T = 1     Fidelity = 0.96806047
# T = 2     Fidelity = 0.99422216
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05846299e+00
# T = 1     Fidelity = 0.97048240
# T = 2     Fidelity = 0.99490924
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07916278e+00
# T = 1     Fidelity = 0.97259503
# T = 2     Fidelity = 0.99546545
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.09862393e+00
# T = 1     Fidelity = 0.97444823
# T = 2     Fidelity = 0.99591789
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.11703633e+00
# T = 1     Fidelity = 0.97607304
# T = 2     Fidelity = 0.99628638
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.13454489e+00
# T = 1     Fidelity = 0.97756441
# T = 2     Fidelity = 0.99660578
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.15126343e+00
# T = 1     Fidelity = 0.97886592
# T = 2     Fidelity = 0.99686152
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.16728342e+00
# T = 1     Fidelity = 0.98006704
# T = 2     Fidelity = 0.99708721
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98114693
# T = 2     Fidelity = 0.99727422
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000153
# T = 10    Fidelity = 0.00040963
# T = 20    Fidelity = 0.00603778
# T = 30    Fidelity = 0.01810886
# T = 40    Fidelity = 0.06104660
# T = 50    Fidelity = 0.15857595
# T = 75    Fidelity = 0.32088204
# T = 100   Fidelity = 0.48444359
# T = 125   Fidelity = 0.63176593
# T = 150   Fidelity = 0.72747055
# T = 175   Fidelity = 0.80312228
# T = 200   Fidelity = 0.84211750
# T = 225   Fidelity = 0.85295889
# T = 250   Fidelity = 0.86542225
# T = 275   Fidelity = 0.72350672
# T = 300   Fidelity = 0.79651757
# T = 400   Fidelity = 0.93534029
# T = 500   Fidelity = 0.91464841
# T = 600   Fidelity = 0.89450525
# T = 700   Fidelity = 0.80606371
# T = 800   Fidelity = 0.64076675
# T = 900   Fidelity = 0.74942858
# T = 1000  Fidelity = 0.63590744
# T = 1010  Fidelity = 0.62580052
# T = 1020  Fidelity = 0.70364800
# T = 1030  Fidelity = 0.67000664
# T = 1040  Fidelity = 0.25791147
# T = 1050  Fidelity = 0.42217931
# T = 1060  Fidelity = 0.49901312
# T = 1070  Fidelity = 0.47040007
# T = 1080  Fidelity = 0.56273413
# T = 1090  Fidelity = 0.54961996
# T = 1100  Fidelity = 0.75322409
# T = 1200  Fidelity = 0.21984310
# T = 1300  Fidelity = 0.24527952
# T = 1400  Fidelity = 0.64167415
# T = 1500  Fidelity = 0.47776609
# T = 2000  Fidelity = 0.33740332
# T = 2100  Fidelity = 0.89232018
# T = 2110  Fidelity = 0.81247161
# T = 2120  Fidelity = 0.76727458
# T = 2130  Fidelity = 0.74469968
# T = 2140  Fidelity = 0.53218902
# T = 2150  Fidelity = 0.74697933
# T = 2160  Fidelity = 0.55177407
# T = 2170  Fidelity = 0.62974938
# T = 2180  Fidelity = 0.69044547
# T = 2190  Fidelity = 0.52300777
# T = 2200  Fidelity = 0.53100723
# T = 2300  Fidelity = 0.33833177
# T = 2400  Fidelity = 0.51809945
# T = 2500  Fidelity = 0.53018881
# T = 2600  Fidelity = 0.30914332
# T = 2700  Fidelity = 0.25077452
# T = 2800  Fidelity = 0.54021819
# T = 2900  Fidelity = 0.48849338
# T = 3000  Fidelity = 0.91807130
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91807130
# P1     = 0.01083593
# P0+P1  = 0.92890723
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61673084e-01
# T = 1     Fidelity = 0.00000009
# T = 2     Fidelity = 0.00000013
# T = 5     Fidelity = 0.00001588
# T = 10    Fidelity = 0.00293490
# T = 20    Fidelity = 0.20982529
# T = 30    Fidelity = 0.27969734
# T = 40    Fidelity = 0.34678426
# T = 50    Fidelity = 0.69747728
# T = 75    Fidelity = 0.77726409
# T = 100   Fidelity = 0.62522167
# T = 125   Fidelity = 0.85158083
# T = 150   Fidelity = 0.75621454
# T = 175   Fidelity = 0.87893116
# T = 200   Fidelity = 0.95983109
# T = 225   Fidelity = 0.87084788
# T = 250   Fidelity = 0.95178482
# T = 275   Fidelity = 0.94003249
# T = 300   Fidelity = 0.91835294
# T = 400   Fidelity = 0.96279098
# T = 500   Fidelity = 0.95387566
# T = 600   Fidelity = 0.87502726
# T = 700   Fidelity = 0.61737233
# T = 800   Fidelity = 0.80147565
# T = 900   Fidelity = 0.75592449
# T = 1000  Fidelity = 0.83670193
# T = 1010  Fidelity = 0.80349409
# T = 1020  Fidelity = 0.83054521
# T = 1030  Fidelity = 0.74256247
# T = 1040  Fidelity = 0.70767682
# T = 1050  Fidelity = 0.66450635
# T = 1060  Fidelity = 0.55918206
# T = 1070  Fidelity = 0.51707255
# T = 1080  Fidelity = 0.62445864
# T = 1090  Fidelity = 0.52691856
# T = 1100  Fidelity = 0.47213139
# T = 1200  Fidelity = 0.87012253
# T = 1300  Fidelity = 0.64971883
# T = 1400  Fidelity = 0.79934071
# T = 1500  Fidelity = 0.91911552
# T = 2000  Fidelity = 0.63351188
# T = 2100  Fidelity = 0.49004061
# T = 2110  Fidelity = 0.75514081
# T = 2120  Fidelity = 0.74109933
# T = 2130  Fidelity = 0.56860460
# T = 2140  Fidelity = 0.48718744
# T = 2150  Fidelity = 0.60236213
# T = 2160  Fidelity = 0.55658232
# T = 2170  Fidelity = 0.44475876
# T = 2180  Fidelity = 0.46838181
# T = 2190  Fidelity = 0.80592345
# T = 2200  Fidelity = 0.64103957
# T = 2300  Fidelity = 0.64546796
# T = 2400  Fidelity = 0.56750057
# T = 2500  Fidelity = 0.84166451
# T = 2600  Fidelity = 0.58659550
# T = 2700  Fidelity = 0.87431088
# T = 2800  Fidelity = 0.61122787
# T = 2900  Fidelity = 0.69260589
# T = 3000  Fidelity = 0.86744185
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43053089e+00
# P0     = 0.86744185
# P1     = 0.03255555
# P0+P1  = 0.89999740
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64768458e-01
# T = 1     Fidelity = 0.00001565
# T = 2     Fidelity = 0.00016098
# T = 5     Fidelity = 0.00337553
# T = 10    Fidelity = 0.04737320
# T = 20    Fidelity = 0.40397633
# T = 30    Fidelity = 0.60242421
# T = 40    Fidelity = 0.57652709
# T = 50    Fidelity = 0.71041176
# T = 75    Fidelity = 0.80364225
# T = 100   Fidelity = 0.88705807
# T = 125   Fidelity = 0.93687753
# T = 150   Fidelity = 0.95955161
# T = 175   Fidelity = 0.96615113
# T = 200   Fidelity = 0.97963553
# T = 225   Fidelity = 0.97935116
# T = 250   Fidelity = 0.98607754
# T = 275   Fidelity = 0.98032756
# T = 300   Fidelity = 0.97994031
# T = 400   Fidelity = 0.97281593
# T = 500   Fidelity = 0.91714376
# T = 600   Fidelity = 0.87860707
# T = 700   Fidelity = 0.85412720
# T = 800   Fidelity = 0.80767469
# T = 900   Fidelity = 0.81609030
# T = 1000  Fidelity = 0.66747269
# T = 1010  Fidelity = 0.48609287
# T = 1020  Fidelity = 0.65386527
# T = 1030  Fidelity = 0.78464659
# T = 1040  Fidelity = 0.51190191
# T = 1050  Fidelity = 0.56518131
# T = 1060  Fidelity = 0.88495601
# T = 1070  Fidelity = 0.78376721
# T = 1080  Fidelity = 0.59453645
# T = 1090  Fidelity = 0.74842861
# T = 1100  Fidelity = 0.91552034
# T = 1200  Fidelity = 0.91292253
# T = 1300  Fidelity = 0.87045589
# T = 1400  Fidelity = 0.86940994
# T = 1500  Fidelity = 0.81587764
# T = 2000  Fidelity = 0.86758022
# T = 2100  Fidelity = 0.51941912
# T = 2110  Fidelity = 0.66111221
# T = 2120  Fidelity = 0.60861892
# T = 2130  Fidelity = 0.62739692
# T = 2140  Fidelity = 0.70533724
# T = 2150  Fidelity = 0.81936197
# T = 2160  Fidelity = 0.71622276
# T = 2170  Fidelity = 0.62151401
# T = 2180  Fidelity = 0.55189261
# T = 2190  Fidelity = 0.54767954
# T = 2200  Fidelity = 0.59499766
# T = 2300  Fidelity = 0.64420033
# T = 2400  Fidelity = 0.85865154
# T = 2500  Fidelity = 0.88215414
# T = 2600  Fidelity = 0.88929748
# T = 2700  Fidelity = 0.96223727
# T = 2800  Fidelity = 0.80837558
# T = 2900  Fidelity = 0.90972872
# T = 3000  Fidelity = 0.87999042
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44126768e+00
# P0     = 0.87999042
# P1     = 0.00965331
# P0+P1  = 0.88964373
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00053452
# T = 2     Fidelity = 0.00308507
# T = 5     Fidelity = 0.02136812
# T = 10    Fidelity = 0.10945776
# T = 20    Fidelity = 0.41532425
# T = 30    Fidelity = 0.65700144
# T = 40    Fidelity = 0.73494481
# T = 50    Fidelity = 0.76501231
# T = 75    Fidelity = 0.88152391
# T = 100   Fidelity = 0.93083942
# T = 125   Fidelity = 0.96501963
# T = 150   Fidelity = 0.97896056
# T = 175   Fidelity = 0.98733345
# T = 200   Fidelity = 0.99071915
#
# Minimum T for Fidelity >= 0.99 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00493630
# T = 2     Fidelity = 0.01693988
# T = 5     Fidelity = 0.06284973
# T = 10    Fidelity = 0.18589989
# T = 20    Fidelity = 0.44689246
# T = 30    Fidelity = 0.64381409
# T = 40    Fidelity = 0.75408637
# T = 50    Fidelity = 0.81722517
# T = 75    Fidelity = 0.91016411
# T = 100   Fidelity = 0.95840975
# T = 125   Fidelity = 0.97885648
# T = 150   Fidelity = 0.98869979
# T = 175   Fidelity = 0.99219842
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.02321843
# T = 2     Fidelity = 0.05831168
# T = 5     Fidelity = 0.14397859
# T = 10    Fidelity = 0.29498005
# T = 20    Fidelity = 0.52012490
# T = 30    Fidelity = 0.66597511
# T = 40    Fidelity = 0.75807505
# T = 50    Fidelity = 0.82066953
# T = 75    Fidelity = 0.91584798
# T = 100   Fidelity = 0.96420903
# T = 125   Fidelity = 0.98621690
# T = 150   Fidelity = 0.99439769
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.07148701
# T = 2     Fidelity = 0.14589698
# T = 5     Fidelity = 0.27572208
# T = 10    Fidelity = 0.44339101
# T = 20    Fidelity = 0.63653252
# T = 30    Fidelity = 0.74217001
# T = 40    Fidelity = 0.80846596
# T = 50    Fidelity = 0.85518805
# T = 75    Fidelity = 0.92429192
# T = 100   Fidelity = 0.96009102
# T = 125   Fidelity = 0.97912799
# T = 150   Fidelity = 0.98770993
# T = 175   Fidelity = 0.99172520
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.15457394
# T = 2     Fidelity = 0.27499452
# T = 5     Fidelity = 0.43692442
# T = 10    Fidelity = 0.60250051
# T = 20    Fidelity = 0.76025597
# T = 30    Fidelity = 0.83476519
# T = 40    Fidelity = 0.87921413
# T = 50    Fidelity = 0.90890193
# T = 75    Fidelity = 0.95095636
# T = 100   Fidelity = 0.97231951
# T = 125   Fidelity = 0.98319346
# T = 150   Fidelity = 0.98846429
# T = 175   Fidelity = 0.99223613
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.25482421
# T = 2     Fidelity = 0.41175265
# T = 5     Fidelity = 0.58376189
# T = 10    Fidelity = 0.73091517
# T = 20    Fidelity = 0.85280628
# T = 30    Fidelity = 0.90361988
# T = 40    Fidelity = 0.93188031
# T = 50    Fidelity = 0.94942123
# T = 75    Fidelity = 0.97400617
# T = 100   Fidelity = 0.98508500
# T = 125   Fidelity = 0.99058866
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.35140510
# T = 2     Fidelity = 0.52958119
# T = 5     Fidelity = 0.69508758
# T = 10    Fidelity = 0.81833791
# T = 20    Fidelity = 0.91031712
# T = 30    Fidelity = 0.94423226
# T = 40    Fidelity = 0.96190259
# T = 50    Fidelity = 0.97266467
# T = 75    Fidelity = 0.98622699
# T = 100   Fidelity = 0.99196209
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.40037050e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000118
# T = 10    Fidelity = 0.00112513
# T = 20    Fidelity = 0.00650195
# T = 30    Fidelity = 0.02763698
# T = 40    Fidelity = 0.11861124
# T = 50    Fidelity = 0.09072882
# T = 75    Fidelity = 0.30317835
# T = 100   Fidelity = 0.53423099
# T = 125   Fidelity = 0.55147610
# T = 150   Fidelity = 0.69154084
# T = 175   Fidelity = 0.80306808
# T = 200   Fidelity = 0.78769178
# T = 225   Fidelity = 0.85479783
# T = 250   Fidelity = 0.93566546
# T = 275   Fidelity = 0.73824618
# T = 300   Fidelity = 0.74266843
# T = 400   Fidelity = 0.95507371
# T = 500   Fidelity = 0.95227261
# T = 600   Fidelity = 0.96721468
# T = 700   Fidelity = 0.85561707
# T = 800   Fidelity = 0.83614980
# T = 900   Fidelity = 0.56601630
# T = 1000  Fidelity = 0.69826504
# T = 1010  Fidelity = 0.63557560
# T = 1020  Fidelity = 0.61093443
# T = 1030  Fidelity = 0.63158876
# T = 1040  Fidelity = 0.75784745
# T = 1050  Fidelity = 0.61883084
# T = 1060  Fidelity = 0.67914348
# T = 1070  Fidelity = 0.47975828
# T = 1080  Fidelity = 0.80417387
# T = 1090  Fidelity = 0.65901369
# T = 1100  Fidelity = 0.25732122
# T = 1200  Fidelity = 0.74400448
# T = 1300  Fidelity = 0.51528998
# T = 1400  Fidelity = 0.35121263
# T = 1500  Fidelity = 0.77770676
# T = 2000  Fidelity = 0.50044678
# T = 2100  Fidelity = 0.78960338
# T = 2110  Fidelity = 0.60428227
# T = 2120  Fidelity = 0.75455918
# T = 2130  Fidelity = 0.76988234
# T = 2140  Fidelity = 0.63037025
# T = 2150  Fidelity = 0.32646459
# T = 2160  Fidelity = 0.49790752
# T = 2170  Fidelity = 0.19921215
# T = 2180  Fidelity = 0.19512920
# T = 2190  Fidelity = 0.12311842
# T = 2200  Fidelity = 0.21581451
# T = 2300  Fidelity = 0.51655241
# T = 2400  Fidelity = 0.82137553
# T = 2500  Fidelity = 0.86310135
# T = 2600  Fidelity = 0.95833606
# T = 2700  Fidelity = 0.57963304
# T = 2800  Fidelity = 0.44865606
# T = 2900  Fidelity = 0.84462854
# T = 3000  Fidelity = 0.91106423
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41951501e+00
# P0     = 0.91106423
# P1     = 0.02172910
# P0+P1  = 0.93279332
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.13564004e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00000645
# T = 10    Fidelity = 0.00111701
# T = 20    Fidelity = 0.19597511
# T = 30    Fidelity = 0.52997363
# T = 40    Fidelity = 0.08171194
# T = 50    Fidelity = 0.71459395
# T = 75    Fidelity = 0.50892730
# T = 100   Fidelity = 0.68131277
# T = 125   Fidelity = 0.91577582
# T = 150   Fidelity = 0.91686770
# T = 175   Fidelity = 0.86877204
# T = 200   Fidelity = 0.91350741
# T = 225   Fidelity = 0.95327077
# T = 250   Fidelity = 0.95262708
# T = 275   Fidelity = 0.94128442
# T = 300   Fidelity = 0.96836848
# T = 400   Fidelity = 0.92073519
# T = 500   Fidelity = 0.94986925
# T = 600   Fidelity = 0.88002343
# T = 700   Fidelity = 0.93498934
# T = 800   Fidelity = 0.55360308
# T = 900   Fidelity = 0.78628788
# T = 1000  Fidelity = 0.38948372
# T = 1010  Fidelity = 0.87031102
# T = 1020  Fidelity = 0.74124013
# T = 1030  Fidelity = 0.59775493
# T = 1040  Fidelity = 0.77011424
# T = 1050  Fidelity = 0.85535205
# T = 1060  Fidelity = 0.82486973
# T = 1070  Fidelity = 0.78912961
# T = 1080  Fidelity = 0.53291870
# T = 1090  Fidelity = 0.84640668
# T = 1100  Fidelity = 0.74239295
# T = 1200  Fidelity = 0.87824056
# T = 1300  Fidelity = 0.16596986
# T = 1400  Fidelity = 0.76002011
# T = 1500  Fidelity = 0.47183768
# T = 2000  Fidelity = 0.82862002
# T = 2100  Fidelity = 0.50634694
# T = 2110  Fidelity = 0.43076070
# T = 2120  Fidelity = 0.57607685
# T = 2130  Fidelity = 0.74211780
# T = 2140  Fidelity = 0.67412648
# T = 2150  Fidelity = 0.68569536
# T = 2160  Fidelity = 0.82219819
# T = 2170  Fidelity = 0.73619364
# T = 2180  Fidelity = 0.51790646
# T = 2190  Fidelity = 0.53977000
# T = 2200  Fidelity = 0.78670396
# T = 2300  Fidelity = 0.77133716
# T = 2400  Fidelity = 0.66139557
# T = 2500  Fidelity = 0.82296432
# T = 2600  Fidelity = 0.26233833
# T = 2700  Fidelity = 0.11145355
# T = 2800  Fidelity = 0.50974610
# T = 2900  Fidelity = 0.54001391
# T = 3000  Fidelity = 0.75288092
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43049943e+00
# P0     = 0.75288092
# P1     = 0.08341431
# P0+P1  = 0.83629523
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00000155
# T = 2     Fidelity = 0.00007229
# T = 5     Fidelity = 0.00175539
# T = 10    Fidelity = 0.03346511
# T = 20    Fidelity = 0.35770483
# T = 30    Fidelity = 0.61380641
# T = 40    Fidelity = 0.36288197
# T = 50    Fidelity = 0.26415277
# T = 75    Fidelity = 0.57893543
# T = 100   Fidelity = 0.44148183
# T = 125   Fidelity = 0.52863862
# T = 150   Fidelity = 0.48150284
# T = 175   Fidelity = 0.50020815
# T = 200   Fidelity = 0.47666215
# T = 225   Fidelity = 0.51531319
# T = 250   Fidelity = 0.48953819
# T = 275   Fidelity = 0.48715234
# T = 300   Fidelity = 0.51251103
# T = 400   Fidelity = 0.50837552
# T = 500   Fidelity = 0.43326839
# T = 600   Fidelity = 0.39974735
# T = 700   Fidelity = 0.27865824
# T = 800   Fidelity = 0.29635929
# T = 900   Fidelity = 0.50815919
# T = 1000  Fidelity = 0.43443937
# T = 1010  Fidelity = 0.28437395
# T = 1020  Fidelity = 0.60365349
# T = 1030  Fidelity = 0.78764917
# T = 1040  Fidelity = 0.61961965
# T = 1050  Fidelity = 0.06770456
# T = 1060  Fidelity = 0.22413052
# T = 1070  Fidelity = 0.62020349
# T = 1080  Fidelity = 0.79583062
# T = 1090  Fidelity = 0.48395261
# T = 1100  Fidelity = 0.19828184
# T = 1200  Fidelity = 0.81018619
# T = 1300  Fidelity = 0.44734774
# T = 1400  Fidelity = 0.22550788
# T = 1500  Fidelity = 0.28817771
# T = 2000  Fidelity = 0.43802641
# T = 2100  Fidelity = 0.17358975
# T = 2110  Fidelity = 0.24969237
# T = 2120  Fidelity = 0.48438854
# T = 2130  Fidelity = 0.54345259
# T = 2140  Fidelity = 0.45724841
# T = 2150  Fidelity = 0.17751794
# T = 2160  Fidelity = 0.37968064
# T = 2170  Fidelity = 0.74120981
# T = 2180  Fidelity = 0.69608014
# T = 2190  Fidelity = 0.41925728
# T = 2200  Fidelity = 0.20320040
# T = 2300  Fidelity = 0.53959173
# T = 2400  Fidelity = 0.70304985
# T = 2500  Fidelity = 0.72789209
# T = 2600  Fidelity = 0.61821268
# T = 2700  Fidelity = 0.56948439
# T = 2800  Fidelity = 0.59076884
# T = 2900  Fidelity = 0.23137220
# T = 3000  Fidelity = 0.41912018
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44121779e+00
# P0     = 0.41912018
# P1     = 0.02449804
# P0+P1  = 0.44361822
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05663390e-03
# T = 1     Fidelity = 0.00173477
# T = 2     Fidelity = 0.00845161
# T = 5     Fidelity = 0.03920951
# T = 10    Fidelity = 0.14293044
# T = 20    Fidelity = 0.34704941
# T = 30    Fidelity = 0.37221905
# T = 40    Fidelity = 0.31880437
# T = 50    Fidelity = 0.32234825
# T = 75    Fidelity = 0.55188390
# T = 100   Fidelity = 0.55081363
# T = 125   Fidelity = 0.49790021
# T = 150   Fidelity = 0.51570391
# T = 175   Fidelity = 0.51984833
# T = 200   Fidelity = 0.51227806
# T = 225   Fidelity = 0.48806583
# T = 250   Fidelity = 0.48833142
# T = 275   Fidelity = 0.48937413
# T = 300   Fidelity = 0.47546145
# T = 400   Fidelity = 0.50474686
# T = 500   Fidelity = 0.49376826
# T = 600   Fidelity = 0.54797747
# T = 700   Fidelity = 0.52825933
# T = 800   Fidelity = 0.57388473
# T = 900   Fidelity = 0.64323969
# T = 1000  Fidelity = 0.62401275
# T = 1010  Fidelity = 0.54005122
# T = 1020  Fidelity = 0.49743312
# T = 1030  Fidelity = 0.28659920
# T = 1040  Fidelity = 0.13443221
# T = 1050  Fidelity = 0.32484666
# T = 1060  Fidelity = 0.53201444
# T = 1070  Fidelity = 0.80415952
# T = 1080  Fidelity = 0.81890495
# T = 1090  Fidelity = 0.61810966
# T = 1100  Fidelity = 0.57066867
# T = 1200  Fidelity = 0.82059764
# T = 1300  Fidelity = 0.70352127
# T = 1400  Fidelity = 0.47523238
# T = 1500  Fidelity = 0.63739824
# T = 2000  Fidelity = 0.46108256
# T = 2100  Fidelity = 0.45537399
# T = 2110  Fidelity = 0.15755298
# T = 2120  Fidelity = 0.19806442
# T = 2130  Fidelity = 0.35364186
# T = 2140  Fidelity = 0.48604699
# T = 2150  Fidelity = 0.42443830
# T = 2160  Fidelity = 0.56400549
# T = 2170  Fidelity = 0.50850596
# T = 2180  Fidelity = 0.63457869
# T = 2190  Fidelity = 0.59969033
# T = 2200  Fidelity = 0.65557767
# T = 2300  Fidelity = 0.56754038
# T = 2400  Fidelity = 0.35637227
# T = 2500  Fidelity = 0.71146101
# T = 2600  Fidelity = 0.66992902
# T = 2700  Fidelity = 0.65907547
# T = 2800  Fidelity = 0.59549421
# T = 2900  Fidelity = 0.39222901
# T = 3000  Fidelity = 0.39761625
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.45168821e+00
# P0     = 0.39761625
# P1     = 0.03555986
# P0+P1  = 0.43317611
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 5.88899605e-03
# T = 1     Fidelity = 0.01693082
# T = 2     Fidelity = 0.05151738
# T = 5     Fidelity = 0.13827506
# T = 10    Fidelity = 0.31092194
# T = 20    Fidelity = 0.54193623
# T = 30    Fidelity = 0.61665474
# T = 40    Fidelity = 0.60111896
# T = 50    Fidelity = 0.57090050
# T = 75    Fidelity = 0.55222595
# T = 100   Fidelity = 0.59361416
# T = 125   Fidelity = 0.62145658
# T = 150   Fidelity = 0.62870087
# T = 175   Fidelity = 0.63730004
# T = 200   Fidelity = 0.63731875
# T = 225   Fidelity = 0.66813833
# T = 250   Fidelity = 0.67326383
# T = 275   Fidelity = 0.66519314
# T = 300   Fidelity = 0.67677594
# T = 400   Fidelity = 0.70050860
# T = 500   Fidelity = 0.59981616
# T = 600   Fidelity = 0.55679633
# T = 700   Fidelity = 0.71956174
# T = 800   Fidelity = 0.76119119
# T = 900   Fidelity = 0.58376545
# T = 1000  Fidelity = 0.64259200
# T = 1010  Fidelity = 0.71027917
# T = 1020  Fidelity = 0.81256472
# T = 1030  Fidelity = 0.82048721
# T = 1040  Fidelity = 0.74804036
# T = 1050  Fidelity = 0.66882400
# T = 1060  Fidelity = 0.62035372
# T = 1070  Fidelity = 0.53436856
# T = 1080  Fidelity = 0.47992973
# T = 1090  Fidelity = 0.56337443
# T = 1100  Fidelity = 0.67368716
# T = 1200  Fidelity = 0.52011420
# T = 1300  Fidelity = 0.67208303
# T = 1400  Fidelity = 0.73629216
# T = 1500  Fidelity = 0.84431107
# T = 2000  Fidelity = 0.80023319
# T = 2100  Fidelity = 0.68591631
# T = 2110  Fidelity = 0.69140478
# T = 2120  Fidelity = 0.61536251
# T = 2130  Fidelity = 0.63445608
# T = 2140  Fidelity = 0.68634792
# T = 2150  Fidelity = 0.86798959
# T = 2160  Fidelity = 0.86927416
# T = 2170  Fidelity = 0.84990505
# T = 2180  Fidelity = 0.76425838
# T = 2190  Fidelity = 0.63417576
# T = 2200  Fidelity = 0.63794191
# T = 2300  Fidelity = 0.66362803
# T = 2400  Fidelity = 0.71267735
# T = 2500  Fidelity = 0.78586104
# T = 2600  Fidelity = 0.40622548
# T = 2700  Fidelity = 0.82131647
# T = 2800  Fidelity = 0.60645081
# T = 2900  Fidelity = 0.72638686
# T = 3000  Fidelity = 0.81870197
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.46192674e+00
# P0     = 0.81870197
# P1     = 0.00533113
# P0+P1  = 0.82403310
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 3.15736806e-02
# T = 1     Fidelity = 0.06362203
# T = 2     Fidelity = 0.14731695
# T = 5     Fidelity = 0.29144607
# T = 10    Fidelity = 0.49644401
# T = 20    Fidelity = 0.70353305
# T = 30    Fidelity = 0.77886927
# T = 40    Fidelity = 0.79447283
# T = 50    Fidelity = 0.79231902
# T = 75    Fidelity = 0.78717905
# T = 100   Fidelity = 0.79420737
# T = 125   Fidelity = 0.80396031
# T = 150   Fidelity = 0.81164002
# T = 175   Fidelity = 0.82119499
# T = 200   Fidelity = 0.82706009
# T = 225   Fidelity = 0.83306551
# T = 250   Fidelity = 0.84422987
# T = 275   Fidelity = 0.83305206
# T = 300   Fidelity = 0.85641755
# T = 400   Fidelity = 0.85620189
# T = 500   Fidelity = 0.82345017
# T = 600   Fidelity = 0.83194862
# T = 700   Fidelity = 0.69487941
# T = 800   Fidelity = 0.93035911
# T = 900   Fidelity = 0.86916285
# T = 1000  Fidelity = 0.86947428
# T = 1010  Fidelity = 0.88353490
# T = 1020  Fidelity = 0.84212171
# T = 1030  Fidelity = 0.78366513
# T = 1040  Fidelity = 0.81595449
# T = 1050  Fidelity = 0.87973793
# T = 1060  Fidelity = 0.88982132
# T = 1070  Fidelity = 0.92447250
# T = 1080  Fidelity = 0.96438300
# T = 1090  Fidelity = 0.97561616
# T = 1100  Fidelity = 0.97633518
# T = 1200  Fidelity = 0.83591263
# T = 1300  Fidelity = 0.92254618
# T = 1400  Fidelity = 0.72141635
# T = 1500  Fidelity = 0.88885756
# T = 2000  Fidelity = 0.88045583
# T = 2100  Fidelity = 0.78917588
# T = 2110  Fidelity = 0.79052328
# T = 2120  Fidelity = 0.73322892
# T = 2130  Fidelity = 0.70517676
# T = 2140  Fidelity = 0.83576858
# T = 2150  Fidelity = 0.95756097
# T = 2160  Fidelity = 0.89028011
# T = 2170  Fidelity = 0.88299848
# T = 2180  Fidelity = 0.94025272
# T = 2190  Fidelity = 0.87703437
# T = 2200  Fidelity = 0.93693303
# T = 2300  Fidelity = 0.90242318
# T = 2400  Fidelity = 0.95962423
# T = 2500  Fidelity = 0.93916122
# T = 2600  Fidelity = 0.86739168
# T = 2700  Fidelity = 0.92314577
# T = 2800  Fidelity = 0.95560191
# T = 2900  Fidelity = 0.76008967
# T = 3000  Fidelity = 0.94808369
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.47194767e+00
# P0     = 0.94808369
# P1     = 0.00082823
# P0+P1  = 0.94891192
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.80738351e-02
# T = 1     Fidelity = 0.14397799
# T = 2     Fidelity = 0.27874960
# T = 5     Fidelity = 0.45580728
# T = 10    Fidelity = 0.65289657
# T = 20    Fidelity = 0.81453935
# T = 30    Fidelity = 0.87121249
# T = 40    Fidelity = 0.89283289
# T = 50    Fidelity = 0.90156869
# T = 75    Fidelity = 0.91219660
# T = 100   Fidelity = 0.92033857
# T = 125   Fidelity = 0.92839787
# T = 150   Fidelity = 0.93478256
# T = 175   Fidelity = 0.94287889
# T = 200   Fidelity = 0.94902231
# T = 225   Fidelity = 0.93595485
# T = 250   Fidelity = 0.94389780
# T = 275   Fidelity = 0.94801354
# T = 300   Fidelity = 0.96168443
# T = 400   Fidelity = 0.95704514
# T = 500   Fidelity = 0.93359085
# T = 600   Fidelity = 0.94563484
# T = 700   Fidelity = 0.89638303
# T = 800   Fidelity = 0.94109793
# T = 900   Fidelity = 0.93715849
# T = 1000  Fidelity = 0.92581399
# T = 1010  Fidelity = 0.97102702
# T = 1020  Fidelity = 0.97344626
# T = 1030  Fidelity = 0.93917126
# T = 1040  Fidelity = 0.96566170
# T = 1050  Fidelity = 0.98198997
# T = 1060  Fidelity = 0.98402892
# T = 1070  Fidelity = 0.97976683
# T = 1080  Fidelity = 0.98408515
# T = 1090  Fidelity = 0.92847176
# T = 1100  Fidelity = 0.96920959
# T = 1200  Fidelity = 0.93117373
# T = 1300  Fidelity = 0.95394537
# T = 1400  Fidelity = 0.91245775
# T = 1500  Fidelity = 0.96668364
# T = 2000  Fidelity = 0.91101097
# T = 2100  Fidelity = 0.92613220
# T = 2110  Fidelity = 0.92413956
# T = 2120  Fidelity = 0.88604030
# T = 2130  Fidelity = 0.94526437
# T = 2140  Fidelity = 0.90903819
# T = 2150  Fidelity = 0.93415585
# T = 2160  Fidelity = 0.91034815
# T = 2170  Fidelity = 0.94403287
# T = 2180  Fidelity = 0.89497100
# T = 2190  Fidelity = 0.94198340
# T = 2200  Fidelity = 0.89468564
# T = 2300  Fidelity = 0.96891298
# T = 2400  Fidelity = 0.89302402
# T = 2500  Fidelity = 0.95163777
# T = 2600  Fidelity = 0.94437746
# T = 2700  Fidelity = 0.92966423
# T = 2800  Fidelity = 0.93738233
# T = 2900  Fidelity = 0.95081475
# T = 3000  Fidelity = 0.90368544
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.48176382e+00
# P0     = 0.90368544
# P1     = 0.00071624
# P0+P1  = 0.90440169
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.28699899e-01
# T = 1     Fidelity = 0.23941042
# T = 2     Fidelity = 0.41118302
# T = 5     Fidelity = 0.59464741
# T = 10    Fidelity = 0.76383715
# T = 20    Fidelity = 0.88380335
# T = 30    Fidelity = 0.92392892
# T = 40    Fidelity = 0.94106574
# T = 50    Fidelity = 0.94991357
# T = 75    Fidelity = 0.96078879
# T = 100   Fidelity = 0.96860504
# T = 125   Fidelity = 0.97391541
# T = 150   Fidelity = 0.97777066
# T = 175   Fidelity = 0.98169984
# T = 200   Fidelity = 0.98424389
# T = 225   Fidelity = 0.96970746
# T = 250   Fidelity = 0.97509115
# T = 275   Fidelity = 0.97883387
# T = 300   Fidelity = 0.98524407
# T = 400   Fidelity = 0.98051491
# T = 500   Fidelity = 0.97333942
# T = 600   Fidelity = 0.91390969
# T = 700   Fidelity = 0.93522598
# T = 800   Fidelity = 0.98528042
# T = 900   Fidelity = 0.99263595
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.76942225e-01
# T = 1     Fidelity = 0.33121736
# T = 2     Fidelity = 0.52325411
# T = 5     Fidelity = 0.69739210
# T = 10    Fidelity = 0.83615809
# T = 20    Fidelity = 0.92567823
# T = 30    Fidelity = 0.95432239
# T = 40    Fidelity = 0.96601999
# T = 50    Fidelity = 0.97222078
# T = 75    Fidelity = 0.98197417
# T = 100   Fidelity = 0.98621112
# T = 125   Fidelity = 0.98940395
# T = 150   Fidelity = 0.99181434
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.20505613e-01
# T = 1     Fidelity = 0.41389526
# T = 2     Fidelity = 0.61380678
# T = 5     Fidelity = 0.77168502
# T = 10    Fidelity = 0.88350092
# T = 20    Fidelity = 0.95125026
# T = 30    Fidelity = 0.97140843
# T = 40    Fidelity = 0.97934424
# T = 50    Fidelity = 0.98433966
# T = 75    Fidelity = 0.99007834
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.06623659e-01
# T = 1     Fidelity = 0.00000021
# T = 2     Fidelity = 0.00000035
# T = 5     Fidelity = 0.00016106
# T = 10    Fidelity = 0.00628829
# T = 20    Fidelity = 0.15811667
# T = 30    Fidelity = 0.48857972
# T = 40    Fidelity = 0.76167164
# T = 50    Fidelity = 0.90743697
# T = 75    Fidelity = 0.99032924
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.20609288e-01
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000002
# T = 5     Fidelity = 0.00113241
# T = 10    Fidelity = 0.19473108
# T = 20    Fidelity = 0.89010817
# T = 30    Fidelity = 0.96778791
# T = 40    Fidelity = 0.99336829
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.76105909e-01
# T = 1     Fidelity = 0.00001288
# T = 2     Fidelity = 0.00008041
# T = 5     Fidelity = 0.03250662
# T = 10    Fidelity = 0.56091353
# T = 20    Fidelity = 0.89634713
# T = 30    Fidelity = 0.98530399
# T = 40    Fidelity = 0.98089059
# T = 50    Fidelity = 0.98556071
# T = 75    Fidelity = 0.99007395
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.12909217e-01
# T = 1     Fidelity = 0.00016031
# T = 2     Fidelity = 0.00258062
# T = 5     Fidelity = 0.10647083
# T = 10    Fidelity = 0.68572832
# T = 20    Fidelity = 0.94676553
# T = 30    Fidelity = 0.98712736
# T = 40    Fidelity = 0.98912360
# T = 50    Fidelity = 0.99156708
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.40169449e-01
# T = 1     Fidelity = 0.00181096
# T = 2     Fidelity = 0.01174193
# T = 5     Fidelity = 0.20539334
# T = 10    Fidelity = 0.75879802
# T = 20    Fidelity = 0.96971986
# T = 30    Fidelity = 0.98869337
# T = 40    Fidelity = 0.99317042
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.61748289e-01
# T = 1     Fidelity = 0.00661861
# T = 2     Fidelity = 0.03051247
# T = 5     Fidelity = 0.30454560
# T = 10    Fidelity = 0.80510259
# T = 20    Fidelity = 0.97960746
# T = 30    Fidelity = 0.99008654
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.79340685e-01
# T = 1     Fidelity = 0.01689725
# T = 2     Fidelity = 0.05945157
# T = 5     Fidelity = 0.39318429
# T = 10    Fidelity = 0.83364262
# T = 20    Fidelity = 0.98383063
# T = 30    Fidelity = 0.99064568
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.94021606e-01
# T = 1     Fidelity = 0.03368711
# T = 2     Fidelity = 0.09735569
# T = 5     Fidelity = 0.47271425
# T = 10    Fidelity = 0.85590160
# T = 20    Fidelity = 0.98569708
# T = 30    Fidelity = 0.99147942
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.06402712e-01
# T = 1     Fidelity = 0.05688194
# T = 2     Fidelity = 0.14169251
# T = 5     Fidelity = 0.54223802
# T = 10    Fidelity = 0.87401995
# T = 20    Fidelity = 0.98620709
# T = 30    Fidelity = 0.99215767
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.17036009e-01
# T = 1     Fidelity = 0.08605972
# T = 2     Fidelity = 0.19044552
# T = 5     Fidelity = 0.60219081
# T = 10    Fidelity = 0.88914177
# T = 20    Fidelity = 0.98611295
# T = 30    Fidelity = 0.99264938
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9933490689      1.01220263e+00    None        None        None
# Symmetric      0.311     2         0.9942221570      1.03626623e+00    None        None        None
# Symmetric      0.522     2         0.9949092435      1.05846299e+00    None        None        None
# Symmetric      0.733     2         0.9954654503      1.07916278e+00    None        None        None
# Symmetric      0.944     2         0.9959178899      1.09862393e+00    None        None        None
# Symmetric      1.156     2         0.9962863750      1.11703633e+00    None        None        None
# Symmetric      1.367     2         0.9966057774      1.13454489e+00    None        None        None
# Symmetric      1.578     2         0.9968615216      1.15126343e+00    None        None        None
# Symmetric      1.789     2         0.9970872121      1.16728342e+00    None        None        None
# Symmetric      2.000     2         0.9972742226      1.18267976e+00    None        None        None
# Weak SSB optimised0.100     None      0.9353402926      2.43127858e-01    0.918071    0.010836    0.928907
# Weak SSB optimised0.311     None      0.9627909832      2.61673084e-01    0.867442    0.032556    0.899997
# Weak SSB optimised0.522     None      0.9860775449      2.64768458e-01    0.87999     0.009653    0.889644
# Weak SSB optimised0.733     200       0.9907191489      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     175       0.9921984220      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     150       0.9943976940      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     175       0.9917252026      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     175       0.9922361267      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9905886559      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     100       0.9919620910      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9672146805      1.40037050e-03    0.911064    0.021729    0.932793
# Weak SSB       0.311     None      0.9683684841      1.13564004e-03    0.752881    0.083414    0.836295
# Weak SSB       0.522     None      0.8101861896      1.05614584e-03    0.41912     0.024498    0.443618
# Weak SSB       0.733     None      0.8205976442      1.05663390e-03    0.397616    0.03556     0.433176
# Weak SSB       0.944     None      0.8692741574      5.88899605e-03    0.818702    0.005331    0.824033
# Weak SSB       1.156     None      0.9763351751      3.15736806e-02    0.948084    0.000828    0.948912
# Weak SSB       1.367     None      0.9840851476      7.80738351e-02    0.903685    0.000716    0.904402
# Weak SSB       1.578     900       0.9926359529      1.28699899e-01    None        None        None
# Weak SSB       1.789     150       0.9918143418      1.76942225e-01    None        None        None
# Weak SSB       2.000     75        0.9900783409      2.20505613e-01    None        None        None
# Strong SSB     0.100     75        0.9903292438      6.06623659e-01    None        None        None
# Strong SSB     0.311     40        0.9933682896      7.20609288e-01    None        None        None
# Strong SSB     0.522     75        0.9900739516      7.76105909e-01    None        None        None
# Strong SSB     0.733     50        0.9915670799      8.12909217e-01    None        None        None
# Strong SSB     0.944     40        0.9931704165      8.40169449e-01    None        None        None
# Strong SSB     1.156     30        0.9900865365      8.61748289e-01    None        None        None
# Strong SSB     1.367     30        0.9906456766      8.79340685e-01    None        None        None
# Strong SSB     1.578     30        0.9914794182      8.94021606e-01    None        None        None
# Strong SSB     1.789     30        0.9921576720      9.06402712e-01    None        None        None
# Strong SSB     2.000     30        0.9926493801      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)


    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan
    
lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009572
# T = 10    Fidelity = 0.00119308
# T = 20    Fidelity = 0.02687514
# T = 30    Fidelity = 0.09668098
# T = 40    Fidelity = 0.19610477
# T = 50    Fidelity = 0.31172827
# T = 75    Fidelity = 0.56619553
# T = 100   Fidelity = 0.72002833
# T = 125   Fidelity = 0.80740206
# T = 150   Fidelity = 0.86471582
# T = 175   Fidelity = 0.90865626
# T = 200   Fidelity = 0.94630646
# T = 225   Fidelity = 0.96686970
# T = 250   Fidelity = 0.95352600
# T = 275   Fidelity = 0.98203898
# T = 300   Fidelity = 0.96281418
# T = 400   Fidelity = 0.95496391
# T = 500   Fidelity = 0.93802121
# T = 600   Fidelity = 0.90702066
# T = 700   Fidelity = 0.99335893
#
# Minimum T for Fidelity >= 0.99 : 700
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624067e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144388
# T = 10    Fidelity = 0.10202820
# T = 20    Fidelity = 0.52981073
# T = 30    Fidelity = 0.63894713
# T = 40    Fidelity = 0.76792835
# T = 50    Fidelity = 0.88385154
# T = 75    Fidelity = 0.94226169
# T = 100   Fidelity = 0.97306430
# T = 125   Fidelity = 0.99693351
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043122e-07
# T = 1     Fidelity = 0.00005023
# T = 2     Fidelity = 0.00043592
# T = 5     Fidelity = 0.02724577
# T = 10    Fidelity = 0.28403302
# T = 20    Fidelity = 0.77882019
# T = 30    Fidelity = 0.80542219
# T = 40    Fidelity = 0.95120526
# T = 50    Fidelity = 0.93700566
# T = 75    Fidelity = 0.99144424
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155083
# T = 2     Fidelity = 0.00639692
# T = 5     Fidelity = 0.08480478
# T = 10    Fidelity = 0.38783818
# T = 20    Fidelity = 0.90883287
# T = 30    Fidelity = 0.89422370
# T = 40    Fidelity = 0.97221801
# T = 50    Fidelity = 0.99232084
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01057926
# T = 2     Fidelity = 0.02893287
# T = 5     Fidelity = 0.16449687
# T = 10    Fidelity = 0.46786783
# T = 20    Fidelity = 0.92254116
# T = 30    Fidelity = 0.97977869
# T = 40    Fidelity = 0.97236694
# T = 50    Fidelity = 0.99387685
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03666505
# T = 2     Fidelity = 0.07743960
# T = 5     Fidelity = 0.25992083
# T = 10    Fidelity = 0.54100868
# T = 20    Fidelity = 0.90448660
# T = 30    Fidelity = 0.99651300
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08775704
# T = 2     Fidelity = 0.15533912
# T = 5     Fidelity = 0.36738494
# T = 10    Fidelity = 0.61608464
# T = 20    Fidelity = 0.89396572
# T = 30    Fidelity = 0.98168035
# T = 40    Fidelity = 0.99755714
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16574439
# T = 2     Fidelity = 0.25901028
# T = 5     Fidelity = 0.48152364
# T = 10    Fidelity = 0.69439976
# T = 20    Fidelity = 0.90353242
# T = 30    Fidelity = 0.97293804
# T = 40    Fidelity = 0.99114715
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26382197
# T = 2     Fidelity = 0.37663055
# T = 5     Fidelity = 0.59253548
# T = 10    Fidelity = 0.76987142
# T = 20    Fidelity = 0.92535881
# T = 30    Fidelity = 0.97251632
# T = 40    Fidelity = 0.98678578
# T = 50    Fidelity = 0.99323307
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36881751
# T = 2     Fidelity = 0.49276964
# T = 5     Fidelity = 0.69001943
# T = 10    Fidelity = 0.83497846
# T = 20    Fidelity = 0.94705760
# T = 30    Fidelity = 0.97597241
# T = 40    Fidelity = 0.98837425
# T = 50    Fidelity = 0.99291451
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.60463159
# T = 2     Fidelity = 0.63357144
# T = 5     Fidelity = 0.69106651
# T = 10    Fidelity = 0.74725162
# T = 20    Fidelity = 0.81652542
# T = 30    Fidelity = 0.85959968
# T = 40    Fidelity = 0.88991887
# T = 50    Fidelity = 0.91192462
# T = 75    Fidelity = 0.94592175
# T = 100   Fidelity = 0.96466726
# T = 125   Fidelity = 0.97366214
# T = 150   Fidelity = 0.98032540
# T = 175   Fidelity = 0.98196667
# T = 200   Fidelity = 0.98751905
# T = 225   Fidelity = 0.97913548
# T = 250   Fidelity = 0.98629399
# T = 275   Fidelity = 0.95557091
# T = 300   Fidelity = 0.93943440
# T = 400   Fidelity = 0.97281901
# T = 500   Fidelity = 0.97680150
# T = 600   Fidelity = 0.94490170
# T = 700   Fidelity = 0.79971388
# T = 800   Fidelity = 0.93953365
# T = 900   Fidelity = 0.98547669
# T = 1000  Fidelity = 0.97715647
# T = 1010  Fidelity = 0.95686023
# T = 1020  Fidelity = 0.94414538
# T = 1030  Fidelity = 0.95831404
# T = 1040  Fidelity = 0.97002352
# T = 1050  Fidelity = 0.96641306
# T = 1060  Fidelity = 0.96757068
# T = 1070  Fidelity = 0.97169448
# T = 1080  Fidelity = 0.98855735
# T = 1090  Fidelity = 0.99219912
#
# Minimum T for Fidelity >= 0.99 : 1090
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.73276858
# T = 2     Fidelity = 0.73997669
# T = 5     Fidelity = 0.76642855
# T = 10    Fidelity = 0.79610477
# T = 20    Fidelity = 0.83029891
# T = 30    Fidelity = 0.85184617
# T = 40    Fidelity = 0.86750287
# T = 50    Fidelity = 0.87991200
# T = 75    Fidelity = 0.90240768
# T = 100   Fidelity = 0.91833384
# T = 125   Fidelity = 0.92982268
# T = 150   Fidelity = 0.93739327
# T = 175   Fidelity = 0.94833373
# T = 200   Fidelity = 0.95118509
# T = 225   Fidelity = 0.95623142
# T = 250   Fidelity = 0.95120731
# T = 275   Fidelity = 0.95770248
# T = 300   Fidelity = 0.96690211
# T = 400   Fidelity = 0.97635670
# T = 500   Fidelity = 0.95926637
# T = 600   Fidelity = 0.96430859
# T = 700   Fidelity = 0.98208379
# T = 800   Fidelity = 0.94195721
# T = 900   Fidelity = 0.92498560
# T = 1000  Fidelity = 0.93081083
# T = 1010  Fidelity = 0.93096005
# T = 1020  Fidelity = 0.92804185
# T = 1030  Fidelity = 0.92523002
# T = 1040  Fidelity = 0.92070716
# T = 1050  Fidelity = 0.91669138
# T = 1060  Fidelity = 0.91200713
# T = 1070  Fidelity = 0.91377240
# T = 1080  Fidelity = 0.91509800
# T = 1090  Fidelity = 0.91582750
# T = 1100  Fidelity = 0.91638745
# T = 1200  Fidelity = 0.92631974
# T = 1300  Fidelity = 0.95522315
# T = 1400  Fidelity = 0.96388189
# T = 1500  Fidelity = 0.95612880
# T = 2000  Fidelity = 0.95689641
# T = 2100  Fidelity = 0.95466105
# T = 2110  Fidelity = 0.95548957
# T = 2120  Fidelity = 0.95739627
# T = 2130  Fidelity = 0.95767687
# T = 2140  Fidelity = 0.95326146
# T = 2150  Fidelity = 0.95290638
# T = 2160  Fidelity = 0.94781190
# T = 2170  Fidelity = 0.94726214
# T = 2180  Fidelity = 0.94130766
# T = 2190  Fidelity = 0.94230392
# T = 2200  Fidelity = 0.94101328
# T = 2300  Fidelity = 0.91338638
# T = 2400  Fidelity = 0.96772264
# T = 2500  Fidelity = 0.97146032
# T = 2600  Fidelity = 0.94385485
# T = 2700  Fidelity = 0.92704720
# T = 2800  Fidelity = 0.91464967
# T = 2900  Fidelity = 0.92760850
# T = 3000  Fidelity = 0.95723311
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.71621181e-01
# P0     = 0.95723311
# P1     = 0.02374125
# P0+P1  = 0.98097436
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.98163509
# T = 2     Fidelity = 0.98921399
# T = 5     Fidelity = 0.99100022
#
# Minimum T for Fidelity >= 0.99 : 5
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98485998
# T = 2     Fidelity = 0.99430837
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97786732
# T = 2     Fidelity = 0.98968657
# T = 5     Fidelity = 0.99491171
#
# Minimum T for Fidelity >= 0.99 : 5
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.94868158
# T = 2     Fidelity = 0.96478096
# T = 5     Fidelity = 0.97650964
# T = 10    Fidelity = 0.98043276
# T = 20    Fidelity = 0.98421520
# T = 30    Fidelity = 0.98681304
# T = 40    Fidelity = 0.98814918
# T = 50    Fidelity = 0.98919954
# T = 75    Fidelity = 0.99123358
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.87865004
# T = 2     Fidelity = 0.90161381
# T = 5     Fidelity = 0.92602160
# T = 10    Fidelity = 0.93624631
# T = 20    Fidelity = 0.95069502
# T = 30    Fidelity = 0.95740622
# T = 40    Fidelity = 0.96317437
# T = 50    Fidelity = 0.96671895
# T = 75    Fidelity = 0.97370915
# T = 100   Fidelity = 0.97848094
# T = 125   Fidelity = 0.98174997
# T = 150   Fidelity = 0.98414288
# T = 175   Fidelity = 0.98611911
# T = 200   Fidelity = 0.98748930
# T = 225   Fidelity = 0.98878699
# T = 250   Fidelity = 0.98987030
# T = 275   Fidelity = 0.99092899
#
# Minimum T for Fidelity >= 0.99 : 275
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78790908
# T = 2     Fidelity = 0.81818923
# T = 5     Fidelity = 0.85698486
# T = 10    Fidelity = 0.87878444
# T = 20    Fidelity = 0.91024715
# T = 30    Fidelity = 0.92456196
# T = 40    Fidelity = 0.93525312
# T = 50    Fidelity = 0.94372184
# T = 75    Fidelity = 0.95753838
# T = 100   Fidelity = 0.96650187
# T = 125   Fidelity = 0.97267559
# T = 150   Fidelity = 0.97713248
# T = 175   Fidelity = 0.98072660
# T = 200   Fidelity = 0.98312321
# T = 225   Fidelity = 0.98507391
# T = 250   Fidelity = 0.98707563
# T = 275   Fidelity = 0.98848341
# T = 300   Fidelity = 0.98972558
# T = 400   Fidelity = 0.99280592
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.71929429
# T = 2     Fidelity = 0.75592039
# T = 5     Fidelity = 0.80644813
# T = 10    Fidelity = 0.84276369
# T = 20    Fidelity = 0.89134427
# T = 30    Fidelity = 0.91288475
# T = 40    Fidelity = 0.92989066
# T = 50    Fidelity = 0.93961433
# T = 75    Fidelity = 0.95849695
# T = 100   Fidelity = 0.96980924
# T = 125   Fidelity = 0.97708187
# T = 150   Fidelity = 0.98200108
# T = 175   Fidelity = 0.98546528
# T = 200   Fidelity = 0.98780291
# T = 225   Fidelity = 0.98959436
# T = 250   Fidelity = 0.99105419
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.69077199
# T = 2     Fidelity = 0.73300776
# T = 5     Fidelity = 0.79169986
# T = 10    Fidelity = 0.83957465
# T = 20    Fidelity = 0.90266449
# T = 30    Fidelity = 0.92644061
# T = 40    Fidelity = 0.94528661
# T = 50    Fidelity = 0.95622220
# T = 75    Fidelity = 0.97312811
# T = 100   Fidelity = 0.98210210
# T = 125   Fidelity = 0.98736076
# T = 150   Fidelity = 0.99062008
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.35126357e-02
# T = 1     Fidelity = 0.59256462
# T = 2     Fidelity = 0.63763169
# T = 5     Fidelity = 0.71868558
# T = 10    Fidelity = 0.79569234
# T = 20    Fidelity = 0.87671160
# T = 30    Fidelity = 0.91881712
# T = 40    Fidelity = 0.94360913
# T = 50    Fidelity = 0.95891317
# T = 75    Fidelity = 0.97868819
# T = 100   Fidelity = 0.98523488
# T = 125   Fidelity = 0.98592779
# T = 150   Fidelity = 0.98838075
# T = 175   Fidelity = 0.98788757
# T = 200   Fidelity = 0.97788022
# T = 225   Fidelity = 0.99099086
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.91075005e-03
# T = 1     Fidelity = 0.44181321
# T = 2     Fidelity = 0.45494420
# T = 5     Fidelity = 0.49574913
# T = 10    Fidelity = 0.54733010
# T = 20    Fidelity = 0.61383698
# T = 30    Fidelity = 0.65994972
# T = 40    Fidelity = 0.69524135
# T = 50    Fidelity = 0.72345859
# T = 75    Fidelity = 0.77457495
# T = 100   Fidelity = 0.80750579
# T = 125   Fidelity = 0.83146778
# T = 150   Fidelity = 0.84786953
# T = 175   Fidelity = 0.85698884
# T = 200   Fidelity = 0.87429496
# T = 225   Fidelity = 0.87855217
# T = 250   Fidelity = 0.88371145
# T = 275   Fidelity = 0.87571090
# T = 300   Fidelity = 0.88970624
# T = 400   Fidelity = 0.92033756
# T = 500   Fidelity = 0.94643129
# T = 600   Fidelity = 0.95143219
# T = 700   Fidelity = 0.79265356
# T = 800   Fidelity = 0.77298743
# T = 900   Fidelity = 0.83997420
# T = 1000  Fidelity = 0.91650449
# T = 1010  Fidelity = 0.90069524
# T = 1020  Fidelity = 0.89090858
# T = 1030  Fidelity = 0.90593747
# T = 1040  Fidelity = 0.93162806
# T = 1050  Fidelity = 0.94300005
# T = 1060  Fidelity = 0.93552893
# T = 1070  Fidelity = 0.91766322
# T = 1080  Fidelity = 0.90365070
# T = 1090  Fidelity = 0.89368829
# T = 1100  Fidelity = 0.90700342
# T = 1200  Fidelity = 0.92699952
# T = 1300  Fidelity = 0.95056636
# T = 1400  Fidelity = 0.97378245
# T = 1500  Fidelity = 0.87047564
# T = 2000  Fidelity = 0.85786896
# T = 2100  Fidelity = 0.93732342
# T = 2110  Fidelity = 0.93746543
# T = 2120  Fidelity = 0.94919211
# T = 2130  Fidelity = 0.96280476
# T = 2140  Fidelity = 0.97558493
# T = 2150  Fidelity = 0.98671467
# T = 2160  Fidelity = 0.99157170
#
# Minimum T for Fidelity >= 0.99 : 2160
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.26406891
# T = 2     Fidelity = 0.26614577
# T = 5     Fidelity = 0.26665184
# T = 10    Fidelity = 0.26685742
# T = 20    Fidelity = 0.26690776
# T = 30    Fidelity = 0.26693573
# T = 40    Fidelity = 0.26701748
# T = 50    Fidelity = 0.26706608
# T = 75    Fidelity = 0.26725464
# T = 100   Fidelity = 0.26738597
# T = 125   Fidelity = 0.26737829
# T = 150   Fidelity = 0.26736971
# T = 175   Fidelity = 0.26571029
# T = 200   Fidelity = 0.26818700
# T = 225   Fidelity = 0.26595558
# T = 250   Fidelity = 0.26781774
# T = 275   Fidelity = 0.26758036
# T = 300   Fidelity = 0.26799062
# T = 400   Fidelity = 0.26613698
# T = 500   Fidelity = 0.26771876
# T = 600   Fidelity = 0.26783261
# T = 700   Fidelity = 0.27157514
# T = 800   Fidelity = 0.26931039
# T = 900   Fidelity = 0.26432479
# T = 1000  Fidelity = 0.26890661
# T = 1010  Fidelity = 0.27033107
# T = 1020  Fidelity = 0.26614349
# T = 1030  Fidelity = 0.26980931
# T = 1040  Fidelity = 0.27119851
# T = 1050  Fidelity = 0.27085926
# T = 1060  Fidelity = 0.26756689
# T = 1070  Fidelity = 0.26672594
# T = 1080  Fidelity = 0.26791943
# T = 1090  Fidelity = 0.26617471
# T = 1100  Fidelity = 0.26582573
# T = 1200  Fidelity = 0.26813492
# T = 1300  Fidelity = 0.26978766
# T = 1400  Fidelity = 0.26904894
# T = 1500  Fidelity = 0.26868481
# T = 2000  Fidelity = 0.26895593
# T = 2100  Fidelity = 0.26931258
# T = 2110  Fidelity = 0.26724697
# T = 2120  Fidelity = 0.26752903
# T = 2130  Fidelity = 0.26947211
# T = 2140  Fidelity = 0.26830112
# T = 2150  Fidelity = 0.27030601
# T = 2160  Fidelity = 0.26818686
# T = 2170  Fidelity = 0.26923374
# T = 2180  Fidelity = 0.26794605
# T = 2190  Fidelity = 0.26874935
# T = 2200  Fidelity = 0.26974388
# T = 2300  Fidelity = 0.26871287
# T = 2400  Fidelity = 0.26692964
# T = 2500  Fidelity = 0.26983409
# T = 2600  Fidelity = 0.27058845
# T = 2700  Fidelity = 0.26801307
# T = 2800  Fidelity = 0.26744340
# T = 2900  Fidelity = 0.26455763
# T = 3000  Fidelity = 0.26384263
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.29930120e-03
# P0     = 0.26384263
# P1     = 0.23566931
# P0+P1  = 0.49951194
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05944621e-03
# T = 1     Fidelity = 0.32692918
# T = 2     Fidelity = 0.33119737
# T = 5     Fidelity = 0.33357688
# T = 10    Fidelity = 0.33434888
# T = 20    Fidelity = 0.33595029
# T = 30    Fidelity = 0.33652329
# T = 40    Fidelity = 0.33715009
# T = 50    Fidelity = 0.33787696
# T = 75    Fidelity = 0.33907508
# T = 100   Fidelity = 0.33997062
# T = 125   Fidelity = 0.34075041
# T = 150   Fidelity = 0.34151563
# T = 175   Fidelity = 0.34144502
# T = 200   Fidelity = 0.34237723
# T = 225   Fidelity = 0.34336081
# T = 250   Fidelity = 0.34378521
# T = 275   Fidelity = 0.34388277
# T = 300   Fidelity = 0.34633607
# T = 400   Fidelity = 0.34679082
# T = 500   Fidelity = 0.34974940
# T = 600   Fidelity = 0.35164130
# T = 700   Fidelity = 0.35056347
# T = 800   Fidelity = 0.35379662
# T = 900   Fidelity = 0.35053905
# T = 1000  Fidelity = 0.35534620
# T = 1010  Fidelity = 0.35072061
# T = 1020  Fidelity = 0.34894135
# T = 1030  Fidelity = 0.36053197
# T = 1040  Fidelity = 0.35048406
# T = 1050  Fidelity = 0.36328851
# T = 1060  Fidelity = 0.36008403
# T = 1070  Fidelity = 0.35686452
# T = 1080  Fidelity = 0.35430858
# T = 1090  Fidelity = 0.35489354
# T = 1100  Fidelity = 0.35686891
# T = 1200  Fidelity = 0.35649825
# T = 1300  Fidelity = 0.35660747
# T = 1400  Fidelity = 0.35540497
# T = 1500  Fidelity = 0.35557457
# T = 2000  Fidelity = 0.37228065
# T = 2100  Fidelity = 0.36783666
# T = 2110  Fidelity = 0.36571011
# T = 2120  Fidelity = 0.37070691
# T = 2130  Fidelity = 0.37409738
# T = 2140  Fidelity = 0.37412715
# T = 2150  Fidelity = 0.37279778
# T = 2160  Fidelity = 0.37008267
# T = 2170  Fidelity = 0.36869582
# T = 2180  Fidelity = 0.36834813
# T = 2190  Fidelity = 0.36732814
# T = 2200  Fidelity = 0.36859586
# T = 2300  Fidelity = 0.36741020
# T = 2400  Fidelity = 0.36887794
# T = 2500  Fidelity = 0.36853321
# T = 2600  Fidelity = 0.37129585
# T = 2700  Fidelity = 0.36953131
# T = 2800  Fidelity = 0.36590223
# T = 2900  Fidelity = 0.36426600
# T = 3000  Fidelity = 0.36474845
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.07434343e-03
# P0     = 0.36474845
# P1     = 0.18449563
# P0+P1  = 0.54924408
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.57867035e-04
# T = 1     Fidelity = 0.35870553
# T = 2     Fidelity = 0.36776698
# T = 5     Fidelity = 0.37843935
# T = 10    Fidelity = 0.38285667
# T = 20    Fidelity = 0.38885004
# T = 30    Fidelity = 0.39424898
# T = 40    Fidelity = 0.39836080
# T = 50    Fidelity = 0.40120438
# T = 75    Fidelity = 0.40856062
# T = 100   Fidelity = 0.41420894
# T = 125   Fidelity = 0.41894630
# T = 150   Fidelity = 0.42344409
# T = 175   Fidelity = 0.42776110
# T = 200   Fidelity = 0.43131846
# T = 225   Fidelity = 0.43470721
# T = 250   Fidelity = 0.43823089
# T = 275   Fidelity = 0.44149333
# T = 300   Fidelity = 0.44469732
# T = 400   Fidelity = 0.45627713
# T = 500   Fidelity = 0.46623716
# T = 600   Fidelity = 0.48428147
# T = 700   Fidelity = 0.48863950
# T = 800   Fidelity = 0.49751913
# T = 900   Fidelity = 0.49206330
# T = 1000  Fidelity = 0.51124556
# T = 1010  Fidelity = 0.51401845
# T = 1020  Fidelity = 0.51530710
# T = 1030  Fidelity = 0.51734495
# T = 1040  Fidelity = 0.51980566
# T = 1050  Fidelity = 0.51998640
# T = 1060  Fidelity = 0.51827073
# T = 1070  Fidelity = 0.52510336
# T = 1080  Fidelity = 0.52802597
# T = 1090  Fidelity = 0.53007101
# T = 1100  Fidelity = 0.52287454
# T = 1200  Fidelity = 0.51116049
# T = 1300  Fidelity = 0.51470994
# T = 1400  Fidelity = 0.53732735
# T = 1500  Fidelity = 0.54968599
# T = 2000  Fidelity = 0.55517209
# T = 2100  Fidelity = 0.55590976
# T = 2110  Fidelity = 0.55309168
# T = 2120  Fidelity = 0.55325966
# T = 2130  Fidelity = 0.54875472
# T = 2140  Fidelity = 0.55467450
# T = 2150  Fidelity = 0.54789782
# T = 2160  Fidelity = 0.54913639
# T = 2170  Fidelity = 0.55468253
# T = 2180  Fidelity = 0.55900181
# T = 2190  Fidelity = 0.56702269
# T = 2200  Fidelity = 0.57522932
# T = 2300  Fidelity = 0.58573916
# T = 2400  Fidelity = 0.60531673
# T = 2500  Fidelity = 0.60950601
# T = 2600  Fidelity = 0.61637465
# T = 2700  Fidelity = 0.64569029
# T = 2800  Fidelity = 0.64356390
# T = 2900  Fidelity = 0.65552027
# T = 3000  Fidelity = 0.64768044
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.57706167e-04
# P0     = 0.64768044
# P1     = 0.14237583
# P0+P1  = 0.79005627
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.03605669e-03
# T = 1     Fidelity = 0.47550375
# T = 2     Fidelity = 0.49705714
# T = 5     Fidelity = 0.52952247
# T = 10    Fidelity = 0.54586169
# T = 20    Fidelity = 0.57287248
# T = 30    Fidelity = 0.58925386
# T = 40    Fidelity = 0.60479621
# T = 50    Fidelity = 0.61548300
# T = 75    Fidelity = 0.64011122
# T = 100   Fidelity = 0.66018792
# T = 125   Fidelity = 0.67636427
# T = 150   Fidelity = 0.69063930
# T = 175   Fidelity = 0.70390991
# T = 200   Fidelity = 0.71548190
# T = 225   Fidelity = 0.72602537
# T = 250   Fidelity = 0.73610290
# T = 275   Fidelity = 0.74525727
# T = 300   Fidelity = 0.75403096
# T = 400   Fidelity = 0.78338993
# T = 500   Fidelity = 0.80696218
# T = 600   Fidelity = 0.81288409
# T = 700   Fidelity = 0.83700270
# T = 800   Fidelity = 0.86495499
# T = 900   Fidelity = 0.88324985
# T = 1000  Fidelity = 0.88021618
# T = 1010  Fidelity = 0.88725479
# T = 1020  Fidelity = 0.89329402
# T = 1030  Fidelity = 0.89954216
# T = 1040  Fidelity = 0.90330050
# T = 1050  Fidelity = 0.90451306
# T = 1060  Fidelity = 0.90310690
# T = 1070  Fidelity = 0.90045643
# T = 1080  Fidelity = 0.89792088
# T = 1090  Fidelity = 0.89479326
# T = 1100  Fidelity = 0.89072177
# T = 1200  Fidelity = 0.88130903
# T = 1300  Fidelity = 0.93293353
# T = 1400  Fidelity = 0.90931951
# T = 1500  Fidelity = 0.88094371
# T = 2000  Fidelity = 0.92307903
# T = 2100  Fidelity = 0.89476343
# T = 2110  Fidelity = 0.89320434
# T = 2120  Fidelity = 0.88507308
# T = 2130  Fidelity = 0.88132685
# T = 2140  Fidelity = 0.88885744
# T = 2150  Fidelity = 0.90044542
# T = 2160  Fidelity = 0.90595306
# T = 2170  Fidelity = 0.90463568
# T = 2180  Fidelity = 0.90154449
# T = 2190  Fidelity = 0.90282569
# T = 2200  Fidelity = 0.90984807
# T = 2300  Fidelity = 0.91034036
# T = 2400  Fidelity = 0.92995105
# T = 2500  Fidelity = 0.96419882
# T = 2600  Fidelity = 0.96379703
# T = 2700  Fidelity = 0.98232893
# T = 2800  Fidelity = 0.99402623
#
# Minimum T for Fidelity >= 0.99 : 2800
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.34955504e-03
# T = 1     Fidelity = 0.51080961
# T = 2     Fidelity = 0.54404302
# T = 5     Fidelity = 0.59793487
# T = 10    Fidelity = 0.63117904
# T = 20    Fidelity = 0.68324276
# T = 30    Fidelity = 0.71627795
# T = 40    Fidelity = 0.73855708
# T = 50    Fidelity = 0.75829997
# T = 75    Fidelity = 0.79746961
# T = 100   Fidelity = 0.82573111
# T = 125   Fidelity = 0.84733647
# T = 150   Fidelity = 0.86496805
# T = 175   Fidelity = 0.87978816
# T = 200   Fidelity = 0.89209582
# T = 225   Fidelity = 0.90265568
# T = 250   Fidelity = 0.91119833
# T = 275   Fidelity = 0.91928380
# T = 300   Fidelity = 0.92636975
# T = 400   Fidelity = 0.94701879
# T = 500   Fidelity = 0.96071374
# T = 600   Fidelity = 0.96966387
# T = 700   Fidelity = 0.96679129
# T = 800   Fidelity = 0.98422543
# T = 900   Fidelity = 0.98731298
# T = 1000  Fidelity = 0.99305049
#
# Minimum T for Fidelity >= 0.99 : 1000
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.92117516e-02
# T = 1     Fidelity = 0.54902773
# T = 2     Fidelity = 0.59298956
# T = 5     Fidelity = 0.66440929
# T = 10    Fidelity = 0.71995688
# T = 20    Fidelity = 0.78266590
# T = 30    Fidelity = 0.82311242
# T = 40    Fidelity = 0.85199670
# T = 50    Fidelity = 0.87338755
# T = 75    Fidelity = 0.90859305
# T = 100   Fidelity = 0.93086127
# T = 125   Fidelity = 0.94602240
# T = 150   Fidelity = 0.95687137
# T = 175   Fidelity = 0.96477347
# T = 200   Fidelity = 0.97085469
# T = 225   Fidelity = 0.97538192
# T = 250   Fidelity = 0.97920116
# T = 275   Fidelity = 0.98211696
# T = 300   Fidelity = 0.98458166
# T = 400   Fidelity = 0.99012204
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 3.87769083e-02
# T = 1     Fidelity = 0.60015784
# T = 2     Fidelity = 0.65317093
# T = 5     Fidelity = 0.73590608
# T = 10    Fidelity = 0.80612911
# T = 20    Fidelity = 0.86833527
# T = 30    Fidelity = 0.90338808
# T = 40    Fidelity = 0.92619258
# T = 50    Fidelity = 0.94212881
# T = 75    Fidelity = 0.96447072
# T = 100   Fidelity = 0.97674695
# T = 125   Fidelity = 0.98386771
# T = 150   Fidelity = 0.98805667
# T = 175   Fidelity = 0.99039526
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 6.53490673e-02
# T = 1     Fidelity = 0.65420432
# T = 2     Fidelity = 0.71383919
# T = 5     Fidelity = 0.80128170
# T = 10    Fidelity = 0.87227797
# T = 20    Fidelity = 0.92461758
# T = 30    Fidelity = 0.95033287
# T = 40    Fidelity = 0.96539747
# T = 50    Fidelity = 0.97494572
# T = 75    Fidelity = 0.98631361
# T = 100   Fidelity = 0.99169792
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99098844
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.98882253
# T = 2     Fidelity = 0.98981054
# T = 5     Fidelity = 0.99451747
#
# Minimum T for Fidelity >= 0.99 : 5
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.42665601e+00
# T = 1     Fidelity = 0.98777573
# T = 2     Fidelity = 0.99272212
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41121208e+00
# T = 1     Fidelity = 0.99137926
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.99124731
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.99189598
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99086804
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98958138
# T = 2     Fidelity = 0.99670614
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98800690
# T = 2     Fidelity = 0.99585283
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98615792
# T = 2     Fidelity = 0.99481501
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     700       0.9933589261      2.15534848e-04    None        None        None
# Symmetric      0.311     125       0.9969335089      1.15624067e-06    None        None        None
# Symmetric      0.522     75        0.9914442416      3.42043122e-07    None        None        None
# Symmetric      0.733     50        0.9923208410      1.41278093e-05    None        None        None
# Symmetric      0.944     50        0.9938768464      3.35131121e-04    None        None        None
# Symmetric      1.156     30        0.9965130038      2.39158790e-03    None        None        None
# Symmetric      1.367     40        0.9975571404      8.93695212e-03    None        None        None
# Symmetric      1.578     40        0.9911471467      2.26116126e-02    None        None        None
# Symmetric      1.789     50        0.9932330696      4.43232760e-02    None        None        None
# Symmetric      2.000     50        0.9929145071      7.29248761e-02    None        None        None
# Weak SSB optimised0.100     1090      0.9921991211      8.65519637e-01    None        None        None
# Weak SSB optimised0.311     None      0.9820837902      5.19764834e-01    0.957233    0.023741    0.980974
# Weak SSB optimised0.522     5         0.9910002160      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     2         0.9943083728      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     5         0.9949117079      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     75        0.9912335793      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     275       0.9909289929      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     400       0.9928059188      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     250       0.9910541897      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     150       0.9906200785      2.54594564e-01    None        None        None
# Weak SSB       0.100     225       0.9909908575      1.35126357e-02    None        None        None
# Weak SSB       0.311     2160      0.9915716959      2.91075005e-03    None        None        None
# Weak SSB       0.522     None      0.2715751382      1.05614584e-03    0.263843    0.235669    0.499512
# Weak SSB       0.733     None      0.3741271454      1.05944621e-03    0.364748    0.184496    0.549244
# Weak SSB       0.944     None      0.6555202703      9.57867035e-04    0.64768     0.142376    0.790056
# Weak SSB       1.156     2800      0.9940262287      2.03605669e-03    None        None        None
# Weak SSB       1.367     1000      0.9930504859      7.34955504e-03    None        None        None
# Weak SSB       1.578     400       0.9901220418      1.92117516e-02    None        None        None
# Weak SSB       1.789     175       0.9903952646      3.87769083e-02    None        None        None
# Weak SSB       2.000     100       0.9916979177      6.53490673e-02    None        None        None
# Strong SSB     0.100     1         0.9909884393      3.59472102e+00    None        None        None
# Strong SSB     0.311     5         0.9945174742      1.58498916e+00    None        None        None
# Strong SSB     0.522     2         0.9927221190      1.42665601e+00    None        None        None
# Strong SSB     0.733     1         0.9913792616      1.41121208e+00    None        None        None
# Strong SSB     0.944     1         0.9912473107      1.38481786e+00    None        None        None
# Strong SSB     1.156     1         0.9918959795      1.34302163e+00    None        None        None
# Strong SSB     1.367     1         0.9908680411      1.29217279e+00    None        None        None
# Strong SSB     1.578     2         0.9967061389      1.23335459e+00    None        None        None
# Strong SSB     1.789     2         0.9958528253      1.17426012e+00    None        None        None
# Strong SSB     2.000     2         0.9948150131      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',
        color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$d^2\langle\phi\rangle/d\lambda^2$')

plt.title(r'Inflection-point analysis $m_0^2=-1$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Start of m0^2=-2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000294
# T = 10    Fidelity = 0.00027909
# T = 20    Fidelity = 0.00630410
# T = 30    Fidelity = 0.02604285
# T = 40    Fidelity = 0.06581614
# T = 50    Fidelity = 0.12446835
# T = 75    Fidelity = 0.30901662
# T = 100   Fidelity = 0.46390436
# T = 125   Fidelity = 0.64203910
# T = 150   Fidelity = 0.69157439
# T = 175   Fidelity = 0.77469495
# T = 200   Fidelity = 0.83395942
# T = 225   Fidelity = 0.81461368
# T = 250   Fidelity = 0.90536570
# T = 275   Fidelity = 0.91626904
# T = 300   Fidelity = 0.86716430
# T = 400   Fidelity = 0.97879940
# T = 500   Fidelity = 0.86743898
# T = 600   Fidelity = 0.89637900
# T = 700   Fidelity = 0.86505377
# T = 800   Fidelity = 0.84096181
# T = 900   Fidelity = 0.91561735
# T = 1000  Fidelity = 0.78788455
# T = 1010  Fidelity = 0.86617071
# T = 1020  Fidelity = 0.76220150
# T = 1030  Fidelity = 0.71448008
# T = 1040  Fidelity = 0.60474356
# T = 1050  Fidelity = 0.44973345
# T = 1060  Fidelity = 0.49366780
# T = 1070  Fidelity = 0.46201215
# T = 1080  Fidelity = 0.54280360
# T = 1090  Fidelity = 0.59941233
# T = 1100  Fidelity = 0.58201513
# T = 1200  Fidelity = 0.69558604
# T = 1300  Fidelity = 0.53380288
# T = 1400  Fidelity = 0.88370926
# T = 1500  Fidelity = 0.75105070
# T = 2000  Fidelity = 0.48180471
# T = 2100  Fidelity = 0.34345125
# T = 2110  Fidelity = 0.54049775
# T = 2120  Fidelity = 0.62150014
# T = 2130  Fidelity = 0.58571228
# T = 2140  Fidelity = 0.55838469
# T = 2150  Fidelity = 0.44171597
# T = 2160  Fidelity = 0.59532284
# T = 2170  Fidelity = 0.54222301
# T = 2180  Fidelity = 0.58482500
# T = 2190  Fidelity = 0.64419856
# T = 2200  Fidelity = 0.57757140
# T = 2300  Fidelity = 0.89030504
# T = 2400  Fidelity = 0.61185121
# T = 2500  Fidelity = 0.43004257
# T = 2600  Fidelity = 0.69221896
# T = 2700  Fidelity = 0.84403504
# T = 2800  Fidelity = 0.79491936
# T = 2900  Fidelity = 0.77012310
# T = 3000  Fidelity = 0.70246189
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.79379555e-02
# P0     = 0.70246189
# P1     = 0.00000000
# P0+P1  = 0.70246189
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.17908351e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00030536
# T = 10    Fidelity = 0.01973082
# T = 20    Fidelity = 0.35207362
# T = 30    Fidelity = 0.52579949
# T = 40    Fidelity = 0.54424853
# T = 50    Fidelity = 0.70352559
# T = 75    Fidelity = 0.85009735
# T = 100   Fidelity = 0.92374368
# T = 125   Fidelity = 0.95513172
# T = 150   Fidelity = 0.97618144
# T = 175   Fidelity = 0.99755207
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.94880941e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.01013777
# T = 10    Fidelity = 0.29395756
# T = 20    Fidelity = 0.47649934
# T = 30    Fidelity = 0.65919758
# T = 40    Fidelity = 0.84257266
# T = 50    Fidelity = 0.88343802
# T = 75    Fidelity = 0.96311819
# T = 100   Fidelity = 0.98782677
# T = 125   Fidelity = 0.99595725
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.58119101e-07
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000818
# T = 5     Fidelity = 0.06263362
# T = 10    Fidelity = 0.29633268
# T = 20    Fidelity = 0.55808554
# T = 30    Fidelity = 0.72699160
# T = 40    Fidelity = 0.83532544
# T = 50    Fidelity = 0.91098606
# T = 75    Fidelity = 0.98047101
# T = 100   Fidelity = 0.99984522
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.89654494e-08
# T = 1     Fidelity = 0.00000138
# T = 2     Fidelity = 0.00013187
# T = 5     Fidelity = 0.11159874
# T = 10    Fidelity = 0.49004965
# T = 20    Fidelity = 0.76517400
# T = 30    Fidelity = 0.88756250
# T = 40    Fidelity = 0.94380305
# T = 50    Fidelity = 0.97009487
# T = 75    Fidelity = 0.99783037
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.17592590e-07
# T = 1     Fidelity = 0.00002204
# T = 2     Fidelity = 0.00081713
# T = 5     Fidelity = 0.15755826
# T = 10    Fidelity = 0.62743900
# T = 20    Fidelity = 0.87767035
# T = 30    Fidelity = 0.95887186
# T = 40    Fidelity = 0.98613055
# T = 50    Fidelity = 0.99608147
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 2.47961151e-07
# T = 1     Fidelity = 0.00014372
# T = 2     Fidelity = 0.00277863
# T = 5     Fidelity = 0.19658414
# T = 10    Fidelity = 0.73842768
# T = 20    Fidelity = 0.92999990
# T = 30    Fidelity = 0.97197932
# T = 40    Fidelity = 0.98585252
# T = 50    Fidelity = 0.99132908
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 3.56990602e-07
# T = 1     Fidelity = 0.00057570
# T = 2     Fidelity = 0.00692602
# T = 5     Fidelity = 0.23189761
# T = 10    Fidelity = 0.80830289
# T = 20    Fidelity = 0.93688947
# T = 30    Fidelity = 0.96371830
# T = 40    Fidelity = 0.98387894
# T = 50    Fidelity = 0.99475437
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.45005899e-06
# T = 1     Fidelity = 0.00168605
# T = 2     Fidelity = 0.01406599
# T = 5     Fidelity = 0.26490315
# T = 10    Fidelity = 0.84406610
# T = 20    Fidelity = 0.92517773
# T = 30    Fidelity = 0.96897198
# T = 40    Fidelity = 0.99382950
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396447
# T = 2     Fidelity = 0.02468197
# T = 5     Fidelity = 0.29522776
# T = 10    Fidelity = 0.85797642
# T = 20    Fidelity = 0.92053925
# T = 30    Fidelity = 0.98399495
# T = 40    Fidelity = 0.99992119
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.61043698
# T = 2     Fidelity = 0.63944421
# T = 5     Fidelity = 0.69629757
# T = 10    Fidelity = 0.75136933
# T = 20    Fidelity = 0.81981148
# T = 30    Fidelity = 0.86179554
# T = 40    Fidelity = 0.89210612
# T = 50    Fidelity = 0.91348324
# T = 75    Fidelity = 0.94716217
# T = 100   Fidelity = 0.96271627
# T = 125   Fidelity = 0.97361997
# T = 150   Fidelity = 0.98097498
# T = 175   Fidelity = 0.97996060
# T = 200   Fidelity = 0.98434989
# T = 225   Fidelity = 0.97883632
# T = 250   Fidelity = 0.98476642
# T = 275   Fidelity = 0.95144038
# T = 300   Fidelity = 0.94007028
# T = 400   Fidelity = 0.98092429
# T = 500   Fidelity = 0.97723021
# T = 600   Fidelity = 0.93087151
# T = 700   Fidelity = 0.80430689
# T = 800   Fidelity = 0.94857674
# T = 900   Fidelity = 0.98322188
# T = 1000  Fidelity = 0.95721592
# T = 1010  Fidelity = 0.95897280
# T = 1020  Fidelity = 0.96020661
# T = 1030  Fidelity = 0.95873992
# T = 1040  Fidelity = 0.96217520
# T = 1050  Fidelity = 0.95810029
# T = 1060  Fidelity = 0.97407177
# T = 1070  Fidelity = 0.98868291
# T = 1080  Fidelity = 0.99087783
#
# Minimum T for Fidelity >= 0.99 : 1080
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.70629732
# T = 2     Fidelity = 0.76902728
# T = 5     Fidelity = 0.80928417
# T = 10    Fidelity = 0.83234543
# T = 20    Fidelity = 0.85659520
# T = 30    Fidelity = 0.87290559
# T = 40    Fidelity = 0.88600399
# T = 50    Fidelity = 0.89569751
# T = 75    Fidelity = 0.91413535
# T = 100   Fidelity = 0.92691758
# T = 125   Fidelity = 0.93277740
# T = 150   Fidelity = 0.93949862
# T = 175   Fidelity = 0.94828152
# T = 200   Fidelity = 0.95688964
# T = 225   Fidelity = 0.95410689
# T = 250   Fidelity = 0.94900406
# T = 275   Fidelity = 0.96283416
# T = 300   Fidelity = 0.95851026
# T = 400   Fidelity = 0.97006659
# T = 500   Fidelity = 0.96039686
# T = 600   Fidelity = 0.96500427
# T = 700   Fidelity = 0.97394935
# T = 800   Fidelity = 0.95573146
# T = 900   Fidelity = 0.93242009
# T = 1000  Fidelity = 0.93589453
# T = 1010  Fidelity = 0.93213105
# T = 1020  Fidelity = 0.93397474
# T = 1030  Fidelity = 0.93967567
# T = 1040  Fidelity = 0.92896663
# T = 1050  Fidelity = 0.94172144
# T = 1060  Fidelity = 0.94943343
# T = 1070  Fidelity = 0.91969498
# T = 1080  Fidelity = 0.93581053
# T = 1090  Fidelity = 0.91756635
# T = 1100  Fidelity = 0.91671749
# T = 1200  Fidelity = 0.93707737
# T = 1300  Fidelity = 0.94997804
# T = 1400  Fidelity = 0.97121110
# T = 1500  Fidelity = 0.98001771
# T = 2000  Fidelity = 0.96326429
# T = 2100  Fidelity = 0.95207240
# T = 2110  Fidelity = 0.94947616
# T = 2120  Fidelity = 0.94970714
# T = 2130  Fidelity = 0.93939318
# T = 2140  Fidelity = 0.95607595
# T = 2150  Fidelity = 0.95149343
# T = 2160  Fidelity = 0.95301095
# T = 2170  Fidelity = 0.95754271
# T = 2180  Fidelity = 0.92621834
# T = 2190  Fidelity = 0.94379338
# T = 2200  Fidelity = 0.94059587
# T = 2300  Fidelity = 0.93437636
# T = 2400  Fidelity = 0.96312482
# T = 2500  Fidelity = 0.96248521
# T = 2600  Fidelity = 0.94832104
# T = 2700  Fidelity = 0.92690721
# T = 2800  Fidelity = 0.92661775
# T = 2900  Fidelity = 0.90794075
# T = 3000  Fidelity = 0.97596766
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.30329715e-01
# P0     = 0.97596766
# P1     = 0.01072723
# P0+P1  = 0.98669489
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.05102828
# T = 2     Fidelity = 0.19115032
# T = 5     Fidelity = 0.83914008
# T = 10    Fidelity = 0.95977193
# T = 20    Fidelity = 0.98420339
# T = 30    Fidelity = 0.98853352
# T = 40    Fidelity = 0.98903594
# T = 50    Fidelity = 0.99034023
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.11217414
# T = 2     Fidelity = 0.32837639
# T = 5     Fidelity = 0.84222153
# T = 10    Fidelity = 0.91155088
# T = 20    Fidelity = 0.99740790
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.16468494
# T = 2     Fidelity = 0.39664058
# T = 5     Fidelity = 0.89485460
# T = 10    Fidelity = 0.94454216
# T = 20    Fidelity = 0.99337912
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.20873768
# T = 2     Fidelity = 0.42863600
# T = 5     Fidelity = 0.87626889
# T = 10    Fidelity = 0.91993405
# T = 20    Fidelity = 0.97003148
# T = 30    Fidelity = 0.97855080
# T = 40    Fidelity = 0.97829589
# T = 50    Fidelity = 0.98278483
# T = 75    Fidelity = 0.98529194
# T = 100   Fidelity = 0.98814748
# T = 125   Fidelity = 0.99083841
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.21556884
# T = 2     Fidelity = 0.40247997
# T = 5     Fidelity = 0.82471710
# T = 10    Fidelity = 0.86430356
# T = 20    Fidelity = 0.90737094
# T = 30    Fidelity = 0.93406102
# T = 40    Fidelity = 0.94619905
# T = 50    Fidelity = 0.94805430
# T = 75    Fidelity = 0.96167930
# T = 100   Fidelity = 0.96512333
# T = 125   Fidelity = 0.97379242
# T = 150   Fidelity = 0.97541932
# T = 175   Fidelity = 0.97925654
# T = 200   Fidelity = 0.98192361
# T = 225   Fidelity = 0.98237611
# T = 250   Fidelity = 0.98601082
# T = 275   Fidelity = 0.98517859
# T = 300   Fidelity = 0.98817577
# T = 400   Fidelity = 0.95373992
# T = 500   Fidelity = 0.96754576
# T = 600   Fidelity = 0.98230762
# T = 700   Fidelity = 0.97027141
# T = 800   Fidelity = 0.96782643
# T = 900   Fidelity = 0.98337803
# T = 1000  Fidelity = 0.97191942
# T = 1010  Fidelity = 0.98791222
# T = 1020  Fidelity = 0.99200386
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.20022388
# T = 2     Fidelity = 0.34961523
# T = 5     Fidelity = 0.74456166
# T = 10    Fidelity = 0.79241832
# T = 20    Fidelity = 0.83536908
# T = 30    Fidelity = 0.86300181
# T = 40    Fidelity = 0.88669271
# T = 50    Fidelity = 0.90619796
# T = 75    Fidelity = 0.93053098
# T = 100   Fidelity = 0.94182044
# T = 125   Fidelity = 0.95515207
# T = 150   Fidelity = 0.96270225
# T = 175   Fidelity = 0.96726679
# T = 200   Fidelity = 0.97307706
# T = 225   Fidelity = 0.97608151
# T = 250   Fidelity = 0.97864132
# T = 275   Fidelity = 0.98230550
# T = 300   Fidelity = 0.98266989
# T = 400   Fidelity = 0.95719687
# T = 500   Fidelity = 0.97173369
# T = 600   Fidelity = 0.98372998
# T = 700   Fidelity = 0.96739695
# T = 800   Fidelity = 0.97383762
# T = 900   Fidelity = 0.99396788
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.17951264
# T = 2     Fidelity = 0.29794200
# T = 5     Fidelity = 0.67010293
# T = 10    Fidelity = 0.73206567
# T = 20    Fidelity = 0.79319190
# T = 30    Fidelity = 0.82935388
# T = 40    Fidelity = 0.85595096
# T = 50    Fidelity = 0.87723671
# T = 75    Fidelity = 0.91479610
# T = 100   Fidelity = 0.93877633
# T = 125   Fidelity = 0.95474709
# T = 150   Fidelity = 0.96547374
# T = 175   Fidelity = 0.97261862
# T = 200   Fidelity = 0.97746690
# T = 225   Fidelity = 0.98060889
# T = 250   Fidelity = 0.98400364
# T = 275   Fidelity = 0.98654142
# T = 300   Fidelity = 0.98828388
# T = 400   Fidelity = 0.97351360
# T = 500   Fidelity = 0.97302660
# T = 600   Fidelity = 0.98570747
# T = 700   Fidelity = 0.98636968
# T = 800   Fidelity = 0.98685195
# T = 900   Fidelity = 0.98961470
# T = 1000  Fidelity = 0.98262014
# T = 1010  Fidelity = 0.97170286
# T = 1020  Fidelity = 0.99462172
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.48783584e-01
# T = 1     Fidelity = 0.16328047
# T = 2     Fidelity = 0.26045576
# T = 5     Fidelity = 0.61856594
# T = 10    Fidelity = 0.69320069
# T = 20    Fidelity = 0.77139590
# T = 30    Fidelity = 0.82079706
# T = 40    Fidelity = 0.85754189
# T = 50    Fidelity = 0.88579587
# T = 75    Fidelity = 0.93158550
# T = 100   Fidelity = 0.95682707
# T = 125   Fidelity = 0.97141352
# T = 150   Fidelity = 0.98017909
# T = 175   Fidelity = 0.98563592
# T = 200   Fidelity = 0.98869083
# T = 225   Fidelity = 0.99116087
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.81947687e-02
# T = 1     Fidelity = 0.60284174
# T = 2     Fidelity = 0.64678348
# T = 5     Fidelity = 0.72458801
# T = 10    Fidelity = 0.80010873
# T = 20    Fidelity = 0.88036550
# T = 30    Fidelity = 0.92211691
# T = 40    Fidelity = 0.94640314
# T = 50    Fidelity = 0.96135887
# T = 75    Fidelity = 0.98069530
# T = 100   Fidelity = 0.98405013
# T = 125   Fidelity = 0.98411831
# T = 150   Fidelity = 0.98971114
# T = 175   Fidelity = 0.98836548
# T = 200   Fidelity = 0.97858520
# T = 225   Fidelity = 0.98789430
# T = 250   Fidelity = 0.96094308
# T = 275   Fidelity = 0.98971703
# T = 300   Fidelity = 0.94586764
# T = 400   Fidelity = 0.88845609
# T = 500   Fidelity = 0.95619550
# T = 600   Fidelity = 0.94402764
# T = 700   Fidelity = 0.93813031
# T = 800   Fidelity = 0.96256276
# T = 900   Fidelity = 0.99092504
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.51771385e-02
# T = 1     Fidelity = 0.54300615
# T = 2     Fidelity = 0.58528060
# T = 5     Fidelity = 0.62862237
# T = 10    Fidelity = 0.66531617
# T = 20    Fidelity = 0.72270964
# T = 30    Fidelity = 0.76459788
# T = 40    Fidelity = 0.79709131
# T = 50    Fidelity = 0.82117448
# T = 75    Fidelity = 0.86875664
# T = 100   Fidelity = 0.89929940
# T = 125   Fidelity = 0.91853265
# T = 150   Fidelity = 0.93288898
# T = 175   Fidelity = 0.94087444
# T = 200   Fidelity = 0.94221249
# T = 225   Fidelity = 0.94975212
# T = 250   Fidelity = 0.94108402
# T = 275   Fidelity = 0.93119180
# T = 300   Fidelity = 0.94517293
# T = 400   Fidelity = 0.96655945
# T = 500   Fidelity = 0.94906642
# T = 600   Fidelity = 0.95651200
# T = 700   Fidelity = 0.83323573
# T = 800   Fidelity = 0.87127325
# T = 900   Fidelity = 0.88472141
# T = 1000  Fidelity = 0.87998120
# T = 1010  Fidelity = 0.93200613
# T = 1020  Fidelity = 0.90719910
# T = 1030  Fidelity = 0.94389108
# T = 1040  Fidelity = 0.94691237
# T = 1050  Fidelity = 0.96101977
# T = 1060  Fidelity = 0.96995848
# T = 1070  Fidelity = 0.94692920
# T = 1080  Fidelity = 0.97337049
# T = 1090  Fidelity = 0.96729491
# T = 1100  Fidelity = 0.94413335
# T = 1200  Fidelity = 0.91683964
# T = 1300  Fidelity = 0.97529144
# T = 1400  Fidelity = 0.93615401
# T = 1500  Fidelity = 0.90625320
# T = 2000  Fidelity = 0.94642320
# T = 2100  Fidelity = 0.98755459
# T = 2110  Fidelity = 0.97900961
# T = 2120  Fidelity = 0.98018868
# T = 2130  Fidelity = 0.97341625
# T = 2140  Fidelity = 0.96758907
# T = 2150  Fidelity = 0.95517725
# T = 2160  Fidelity = 0.96130698
# T = 2170  Fidelity = 0.97713455
# T = 2180  Fidelity = 0.96228219
# T = 2190  Fidelity = 0.97503820
# T = 2200  Fidelity = 0.96664261
# T = 2300  Fidelity = 0.89128524
# T = 2400  Fidelity = 0.88910036
# T = 2500  Fidelity = 0.93982564
# T = 2600  Fidelity = 0.86099125
# T = 2700  Fidelity = 0.84308363
# T = 2800  Fidelity = 0.93038680
# T = 2900  Fidelity = 0.95785859
# T = 3000  Fidelity = 0.93640159
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.50815198e-02
# P0     = 0.93640159
# P1     = 0.00015197
# P0+P1  = 0.93655355
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.02289424
# T = 2     Fidelity = 0.09304645
# T = 5     Fidelity = 0.42743003
# T = 10    Fidelity = 0.47949477
# T = 20    Fidelity = 0.49472774
# T = 30    Fidelity = 0.49617380
# T = 40    Fidelity = 0.49696291
# T = 50    Fidelity = 0.49894843
# T = 75    Fidelity = 0.49721899
# T = 100   Fidelity = 0.49863421
# T = 125   Fidelity = 0.49653489
# T = 150   Fidelity = 0.49888765
# T = 175   Fidelity = 0.49550940
# T = 200   Fidelity = 0.49436774
# T = 225   Fidelity = 0.49372807
# T = 250   Fidelity = 0.49305639
# T = 275   Fidelity = 0.48849613
# T = 300   Fidelity = 0.48586568
# T = 400   Fidelity = 0.46556552
# T = 500   Fidelity = 0.44878221
# T = 600   Fidelity = 0.45474554
# T = 700   Fidelity = 0.43420940
# T = 800   Fidelity = 0.41655697
# T = 900   Fidelity = 0.41714921
# T = 1000  Fidelity = 0.37898065
# T = 1010  Fidelity = 0.38542591
# T = 1020  Fidelity = 0.38543069
# T = 1030  Fidelity = 0.37964284
# T = 1040  Fidelity = 0.38536742
# T = 1050  Fidelity = 0.37488675
# T = 1060  Fidelity = 0.37594704
# T = 1070  Fidelity = 0.37716206
# T = 1080  Fidelity = 0.37771769
# T = 1090  Fidelity = 0.37041933
# T = 1100  Fidelity = 0.36624990
# T = 1200  Fidelity = 0.35792735
# T = 1300  Fidelity = 0.33247888
# T = 1400  Fidelity = 0.27459675
# T = 1500  Fidelity = 0.29460501
# T = 2000  Fidelity = 0.20952184
# T = 2100  Fidelity = 0.20272179
# T = 2110  Fidelity = 0.19658214
# T = 2120  Fidelity = 0.19312553
# T = 2130  Fidelity = 0.18869969
# T = 2140  Fidelity = 0.19338191
# T = 2150  Fidelity = 0.19058737
# T = 2160  Fidelity = 0.18765666
# T = 2170  Fidelity = 0.18263971
# T = 2180  Fidelity = 0.18387600
# T = 2190  Fidelity = 0.18146822
# T = 2200  Fidelity = 0.17809302
# T = 2300  Fidelity = 0.16744087
# T = 2400  Fidelity = 0.12119306
# T = 2500  Fidelity = 0.14322815
# T = 2600  Fidelity = 0.13376741
# T = 2700  Fidelity = 0.12063047
# T = 2800  Fidelity = 0.10672898
# T = 2900  Fidelity = 0.10344068
# T = 3000  Fidelity = 0.09443249
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.35220086e-03
# P0     = 0.09443249
# P1     = 0.40329761
# P0+P1  = 0.49773010
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07018746e-03
# T = 1     Fidelity = 0.03616108
# T = 2     Fidelity = 0.10750190
# T = 5     Fidelity = 0.28538253
# T = 10    Fidelity = 0.30770942
# T = 20    Fidelity = 0.33935662
# T = 30    Fidelity = 0.33787501
# T = 40    Fidelity = 0.33919814
# T = 50    Fidelity = 0.34252747
# T = 75    Fidelity = 0.34336292
# T = 100   Fidelity = 0.34434293
# T = 125   Fidelity = 0.34445983
# T = 150   Fidelity = 0.34470138
# T = 175   Fidelity = 0.34480083
# T = 200   Fidelity = 0.35227536
# T = 225   Fidelity = 0.34902415
# T = 250   Fidelity = 0.34168777
# T = 275   Fidelity = 0.34652637
# T = 300   Fidelity = 0.34863160
# T = 400   Fidelity = 0.36785454
# T = 500   Fidelity = 0.33137804
# T = 600   Fidelity = 0.34644524
# T = 700   Fidelity = 0.34464892
# T = 800   Fidelity = 0.30398709
# T = 900   Fidelity = 0.30554605
# T = 1000  Fidelity = 0.33492753
# T = 1010  Fidelity = 0.33740142
# T = 1020  Fidelity = 0.34069985
# T = 1030  Fidelity = 0.36467051
# T = 1040  Fidelity = 0.34529754
# T = 1050  Fidelity = 0.36101522
# T = 1060  Fidelity = 0.41321649
# T = 1070  Fidelity = 0.29404625
# T = 1080  Fidelity = 0.31842964
# T = 1090  Fidelity = 0.32393310
# T = 1100  Fidelity = 0.37829796
# T = 1200  Fidelity = 0.39588408
# T = 1300  Fidelity = 0.37162550
# T = 1400  Fidelity = 0.38159470
# T = 1500  Fidelity = 0.27345959
# T = 2000  Fidelity = 0.35030029
# T = 2100  Fidelity = 0.26026735
# T = 2110  Fidelity = 0.36787938
# T = 2120  Fidelity = 0.36619554
# T = 2130  Fidelity = 0.27983410
# T = 2140  Fidelity = 0.44650643
# T = 2150  Fidelity = 0.28631190
# T = 2160  Fidelity = 0.36205086
# T = 2170  Fidelity = 0.30698371
# T = 2180  Fidelity = 0.35854365
# T = 2190  Fidelity = 0.36334191
# T = 2200  Fidelity = 0.34869279
# T = 2300  Fidelity = 0.37628116
# T = 2400  Fidelity = 0.31379990
# T = 2500  Fidelity = 0.37219811
# T = 2600  Fidelity = 0.37116556
# T = 2700  Fidelity = 0.33205846
# T = 2800  Fidelity = 0.30389035
# T = 2900  Fidelity = 0.32501563
# T = 3000  Fidelity = 0.30253716
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.59823390e-03
# P0     = 0.30253716
# P1     = 0.18319472
# P0+P1  = 0.48573188
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.80171521e-04
# T = 1     Fidelity = 0.04646169
# T = 2     Fidelity = 0.11273766
# T = 5     Fidelity = 0.27493611
# T = 10    Fidelity = 0.29003129
# T = 20    Fidelity = 0.31496633
# T = 30    Fidelity = 0.32226359
# T = 40    Fidelity = 0.32054111
# T = 50    Fidelity = 0.32781444
# T = 75    Fidelity = 0.33129527
# T = 100   Fidelity = 0.33564897
# T = 125   Fidelity = 0.34151143
# T = 150   Fidelity = 0.34735035
# T = 175   Fidelity = 0.35688046
# T = 200   Fidelity = 0.35487897
# T = 225   Fidelity = 0.36027807
# T = 250   Fidelity = 0.35927897
# T = 275   Fidelity = 0.35668981
# T = 300   Fidelity = 0.36668019
# T = 400   Fidelity = 0.42363565
# T = 500   Fidelity = 0.34862735
# T = 600   Fidelity = 0.39300412
# T = 700   Fidelity = 0.29388693
# T = 800   Fidelity = 0.44106342
# T = 900   Fidelity = 0.45020179
# T = 1000  Fidelity = 0.42413946
# T = 1010  Fidelity = 0.45125726
# T = 1020  Fidelity = 0.46811900
# T = 1030  Fidelity = 0.41399241
# T = 1040  Fidelity = 0.33876632
# T = 1050  Fidelity = 0.32831162
# T = 1060  Fidelity = 0.35934203
# T = 1070  Fidelity = 0.39182685
# T = 1080  Fidelity = 0.45889716
# T = 1090  Fidelity = 0.48851146
# T = 1100  Fidelity = 0.34997180
# T = 1200  Fidelity = 0.33412379
# T = 1300  Fidelity = 0.49088015
# T = 1400  Fidelity = 0.35672881
# T = 1500  Fidelity = 0.49673669
# T = 2000  Fidelity = 0.48635377
# T = 2100  Fidelity = 0.41217687
# T = 2110  Fidelity = 0.49398025
# T = 2120  Fidelity = 0.46959570
# T = 2130  Fidelity = 0.45417206
# T = 2140  Fidelity = 0.53143584
# T = 2150  Fidelity = 0.45163504
# T = 2160  Fidelity = 0.43088476
# T = 2170  Fidelity = 0.39321472
# T = 2180  Fidelity = 0.37800268
# T = 2190  Fidelity = 0.53015224
# T = 2200  Fidelity = 0.38398201
# T = 2300  Fidelity = 0.50876565
# T = 2400  Fidelity = 0.44029638
# T = 2500  Fidelity = 0.51747102
# T = 2600  Fidelity = 0.49300661
# T = 2700  Fidelity = 0.43388250
# T = 2800  Fidelity = 0.45912929
# T = 2900  Fidelity = 0.48765475
# T = 3000  Fidelity = 0.49117960
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.38933834e-03
# P0     = 0.49117960
# P1     = 0.32479385
# P0+P1  = 0.81597344
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 9.40449540e-04
# T = 1     Fidelity = 0.04756345
# T = 2     Fidelity = 0.09942644
# T = 5     Fidelity = 0.23679652
# T = 10    Fidelity = 0.25257157
# T = 20    Fidelity = 0.27687266
# T = 30    Fidelity = 0.30129597
# T = 40    Fidelity = 0.30968593
# T = 50    Fidelity = 0.30894178
# T = 75    Fidelity = 0.33268366
# T = 100   Fidelity = 0.33935783
# T = 125   Fidelity = 0.34958989
# T = 150   Fidelity = 0.36277393
# T = 175   Fidelity = 0.36570196
# T = 200   Fidelity = 0.37604444
# T = 225   Fidelity = 0.38336183
# T = 250   Fidelity = 0.38474501
# T = 275   Fidelity = 0.39830149
# T = 300   Fidelity = 0.39807121
# T = 400   Fidelity = 0.36908993
# T = 500   Fidelity = 0.40645159
# T = 600   Fidelity = 0.45368193
# T = 700   Fidelity = 0.46507781
# T = 800   Fidelity = 0.48223759
# T = 900   Fidelity = 0.48626242
# T = 1000  Fidelity = 0.51466513
# T = 1010  Fidelity = 0.45568346
# T = 1020  Fidelity = 0.44100606
# T = 1030  Fidelity = 0.49868400
# T = 1040  Fidelity = 0.52964507
# T = 1050  Fidelity = 0.51439902
# T = 1060  Fidelity = 0.45783664
# T = 1070  Fidelity = 0.40202468
# T = 1080  Fidelity = 0.48187871
# T = 1090  Fidelity = 0.52277517
# T = 1100  Fidelity = 0.42557626
# T = 1200  Fidelity = 0.51473943
# T = 1300  Fidelity = 0.53470996
# T = 1400  Fidelity = 0.50093875
# T = 1500  Fidelity = 0.50388639
# T = 2000  Fidelity = 0.49777859
# T = 2100  Fidelity = 0.51155084
# T = 2110  Fidelity = 0.50012722
# T = 2120  Fidelity = 0.48101847
# T = 2130  Fidelity = 0.50246069
# T = 2140  Fidelity = 0.48119288
# T = 2150  Fidelity = 0.47444194
# T = 2160  Fidelity = 0.47539712
# T = 2170  Fidelity = 0.46850542
# T = 2180  Fidelity = 0.44710839
# T = 2190  Fidelity = 0.47906404
# T = 2200  Fidelity = 0.46948010
# T = 2300  Fidelity = 0.52457218
# T = 2400  Fidelity = 0.53429346
# T = 2500  Fidelity = 0.49211216
# T = 2600  Fidelity = 0.51698737
# T = 2700  Fidelity = 0.53493073
# T = 2800  Fidelity = 0.51492821
# T = 2900  Fidelity = 0.54824451
# T = 3000  Fidelity = 0.54825261
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.24416809e-03
# P0     = 0.54825261
# P1     = 0.43938072
# P0+P1  = 0.98763333
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 9.13233454e-04
# T = 1     Fidelity = 0.04956162
# T = 2     Fidelity = 0.09735291
# T = 5     Fidelity = 0.24870045
# T = 10    Fidelity = 0.27440232
# T = 20    Fidelity = 0.30186307
# T = 30    Fidelity = 0.32617952
# T = 40    Fidelity = 0.34997293
# T = 50    Fidelity = 0.36880452
# T = 75    Fidelity = 0.39062837
# T = 100   Fidelity = 0.40815730
# T = 125   Fidelity = 0.42857036
# T = 150   Fidelity = 0.43800051
# T = 175   Fidelity = 0.44883393
# T = 200   Fidelity = 0.46069995
# T = 225   Fidelity = 0.46455379
# T = 250   Fidelity = 0.47290083
# T = 275   Fidelity = 0.48084110
# T = 300   Fidelity = 0.47845058
# T = 400   Fidelity = 0.49331218
# T = 500   Fidelity = 0.46909692
# T = 600   Fidelity = 0.49870812
# T = 700   Fidelity = 0.48785750
# T = 800   Fidelity = 0.50277898
# T = 900   Fidelity = 0.50358773
# T = 1000  Fidelity = 0.47198718
# T = 1010  Fidelity = 0.49882687
# T = 1020  Fidelity = 0.48100932
# T = 1030  Fidelity = 0.47410035
# T = 1040  Fidelity = 0.49786297
# T = 1050  Fidelity = 0.50100973
# T = 1060  Fidelity = 0.47519029
# T = 1070  Fidelity = 0.50467037
# T = 1080  Fidelity = 0.49927090
# T = 1090  Fidelity = 0.51063607
# T = 1100  Fidelity = 0.49630883
# T = 1200  Fidelity = 0.49900597
# T = 1300  Fidelity = 0.52414709
# T = 1400  Fidelity = 0.50151132
# T = 1500  Fidelity = 0.54675768
# T = 2000  Fidelity = 0.58924694
# T = 2100  Fidelity = 0.59535978
# T = 2110  Fidelity = 0.59150431
# T = 2120  Fidelity = 0.58511654
# T = 2130  Fidelity = 0.57729155
# T = 2140  Fidelity = 0.58350770
# T = 2150  Fidelity = 0.58441745
# T = 2160  Fidelity = 0.59545280
# T = 2170  Fidelity = 0.58855855
# T = 2180  Fidelity = 0.57049806
# T = 2190  Fidelity = 0.58220166
# T = 2200  Fidelity = 0.57291596
# T = 2300  Fidelity = 0.54613651
# T = 2400  Fidelity = 0.58424051
# T = 2500  Fidelity = 0.56288200
# T = 2600  Fidelity = 0.47935030
# T = 2700  Fidelity = 0.52129206
# T = 2800  Fidelity = 0.51899647
# T = 2900  Fidelity = 0.53523285
# T = 3000  Fidelity = 0.47037983
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.13588693e-03
# P0     = 0.47037983
# P1     = 0.30906523
# P0+P1  = 0.77944507
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.91554516e-04
# T = 1     Fidelity = 0.05116074
# T = 2     Fidelity = 0.09426286
# T = 5     Fidelity = 0.26467359
# T = 10    Fidelity = 0.30446158
# T = 20    Fidelity = 0.34775648
# T = 30    Fidelity = 0.37699678
# T = 40    Fidelity = 0.39885151
# T = 50    Fidelity = 0.41626928
# T = 75    Fidelity = 0.44752369
# T = 100   Fidelity = 0.46807612
# T = 125   Fidelity = 0.48208236
# T = 150   Fidelity = 0.49162766
# T = 175   Fidelity = 0.49786537
# T = 200   Fidelity = 0.50147828
# T = 225   Fidelity = 0.50319668
# T = 250   Fidelity = 0.50326201
# T = 275   Fidelity = 0.50232092
# T = 300   Fidelity = 0.50005640
# T = 400   Fidelity = 0.48827083
# T = 500   Fidelity = 0.49803275
# T = 600   Fidelity = 0.50797544
# T = 700   Fidelity = 0.53564237
# T = 800   Fidelity = 0.53761264
# T = 900   Fidelity = 0.55693850
# T = 1000  Fidelity = 0.52946217
# T = 1010  Fidelity = 0.54276511
# T = 1020  Fidelity = 0.53033074
# T = 1030  Fidelity = 0.53001302
# T = 1040  Fidelity = 0.53810015
# T = 1050  Fidelity = 0.53193124
# T = 1060  Fidelity = 0.51144917
# T = 1070  Fidelity = 0.52897062
# T = 1080  Fidelity = 0.51528747
# T = 1090  Fidelity = 0.53368664
# T = 1100  Fidelity = 0.51993421
# T = 1200  Fidelity = 0.51904266
# T = 1300  Fidelity = 0.54582690
# T = 1400  Fidelity = 0.52040050
# T = 1500  Fidelity = 0.56634279
# T = 2000  Fidelity = 0.48417400
# T = 2100  Fidelity = 0.50228761
# T = 2110  Fidelity = 0.55617531
# T = 2120  Fidelity = 0.52192047
# T = 2130  Fidelity = 0.52382858
# T = 2140  Fidelity = 0.54144521
# T = 2150  Fidelity = 0.51946741
# T = 2160  Fidelity = 0.51671450
# T = 2170  Fidelity = 0.53080259
# T = 2180  Fidelity = 0.52396193
# T = 2190  Fidelity = 0.52970766
# T = 2200  Fidelity = 0.47751900
# T = 2300  Fidelity = 0.58064552
# T = 2400  Fidelity = 0.57151448
# T = 2500  Fidelity = 0.52963019
# T = 2600  Fidelity = 0.56788073
# T = 2700  Fidelity = 0.59120221
# T = 2800  Fidelity = 0.58450079
# T = 2900  Fidelity = 0.64762568
# T = 3000  Fidelity = 0.65182825
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.05026245e-03
# P0     = 0.65182825
# P1     = 0.33115953
# P0+P1  = 0.98298778
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 8.73711147e-04
# T = 1     Fidelity = 0.05514680
# T = 2     Fidelity = 0.09611842
# T = 5     Fidelity = 0.28690818
# T = 10    Fidelity = 0.33999554
# T = 20    Fidelity = 0.39815761
# T = 30    Fidelity = 0.42985874
# T = 40    Fidelity = 0.44990343
# T = 50    Fidelity = 0.46331214
# T = 75    Fidelity = 0.48214950
# T = 100   Fidelity = 0.49049098
# T = 125   Fidelity = 0.49378547
# T = 150   Fidelity = 0.49457617
# T = 175   Fidelity = 0.49437970
# T = 200   Fidelity = 0.49433486
# T = 225   Fidelity = 0.49564316
# T = 250   Fidelity = 0.49853706
# T = 275   Fidelity = 0.50287280
# T = 300   Fidelity = 0.50820994
# T = 400   Fidelity = 0.51596363
# T = 500   Fidelity = 0.51738980
# T = 600   Fidelity = 0.51597956
# T = 700   Fidelity = 0.52280366
# T = 800   Fidelity = 0.53838866
# T = 900   Fidelity = 0.52697548
# T = 1000  Fidelity = 0.51420296
# T = 1010  Fidelity = 0.53755843
# T = 1020  Fidelity = 0.53034957
# T = 1030  Fidelity = 0.53381457
# T = 1040  Fidelity = 0.54010527
# T = 1050  Fidelity = 0.52097233
# T = 1060  Fidelity = 0.54284013
# T = 1070  Fidelity = 0.54512457
# T = 1080  Fidelity = 0.52047548
# T = 1090  Fidelity = 0.53325697
# T = 1100  Fidelity = 0.54412725
# T = 1200  Fidelity = 0.55691895
# T = 1300  Fidelity = 0.52706190
# T = 1400  Fidelity = 0.52234504
# T = 1500  Fidelity = 0.53620571
# T = 2000  Fidelity = 0.57649644
# T = 2100  Fidelity = 0.58046202
# T = 2110  Fidelity = 0.59913540
# T = 2120  Fidelity = 0.58880166
# T = 2130  Fidelity = 0.59536338
# T = 2140  Fidelity = 0.60016583
# T = 2150  Fidelity = 0.59139105
# T = 2160  Fidelity = 0.58901143
# T = 2170  Fidelity = 0.58330229
# T = 2180  Fidelity = 0.58978258
# T = 2190  Fidelity = 0.60031295
# T = 2200  Fidelity = 0.59267400
# T = 2300  Fidelity = 0.61726403
# T = 2400  Fidelity = 0.63015179
# T = 2500  Fidelity = 0.61468684
# T = 2600  Fidelity = 0.58074998
# T = 2700  Fidelity = 0.63738025
# T = 2800  Fidelity = 0.62317727
# T = 2900  Fidelity = 0.63452126
# T = 3000  Fidelity = 0.62087644
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.78208763e-04
# P0     = 0.62087644
# P1     = 0.34368373
# P0+P1  = 0.96456017
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 8.58553719e-04
# T = 1     Fidelity = 0.05994627
# T = 2     Fidelity = 0.09961706
# T = 5     Fidelity = 0.31005869
# T = 10    Fidelity = 0.37341507
# T = 20    Fidelity = 0.43169901
# T = 30    Fidelity = 0.46075889
# T = 40    Fidelity = 0.47974340
# T = 50    Fidelity = 0.49250665
# T = 75    Fidelity = 0.50445614
# T = 100   Fidelity = 0.50395837
# T = 125   Fidelity = 0.50351284
# T = 150   Fidelity = 0.50384240
# T = 175   Fidelity = 0.50591937
# T = 200   Fidelity = 0.51147061
# T = 225   Fidelity = 0.51780921
# T = 250   Fidelity = 0.52309082
# T = 275   Fidelity = 0.52669154
# T = 300   Fidelity = 0.52596934
# T = 400   Fidelity = 0.50868481
# T = 500   Fidelity = 0.53042125
# T = 600   Fidelity = 0.52897797
# T = 700   Fidelity = 0.53790798
# T = 800   Fidelity = 0.54243068
# T = 900   Fidelity = 0.54142623
# T = 1000  Fidelity = 0.53940106
# T = 1010  Fidelity = 0.56278492
# T = 1020  Fidelity = 0.54568917
# T = 1030  Fidelity = 0.56647019
# T = 1040  Fidelity = 0.54541427
# T = 1050  Fidelity = 0.55789798
# T = 1060  Fidelity = 0.54689329
# T = 1070  Fidelity = 0.53937008
# T = 1080  Fidelity = 0.53503410
# T = 1090  Fidelity = 0.54542577
# T = 1100  Fidelity = 0.55248281
# T = 1200  Fidelity = 0.54649540
# T = 1300  Fidelity = 0.53333257
# T = 1400  Fidelity = 0.53064302
# T = 1500  Fidelity = 0.55463404
# T = 2000  Fidelity = 0.60657925
# T = 2100  Fidelity = 0.59870369
# T = 2110  Fidelity = 0.60267196
# T = 2120  Fidelity = 0.61452129
# T = 2130  Fidelity = 0.61215316
# T = 2140  Fidelity = 0.62046025
# T = 2150  Fidelity = 0.59190619
# T = 2160  Fidelity = 0.60269887
# T = 2170  Fidelity = 0.62139100
# T = 2180  Fidelity = 0.61320081
# T = 2190  Fidelity = 0.62638454
# T = 2200  Fidelity = 0.62149536
# T = 2300  Fidelity = 0.61795767
# T = 2400  Fidelity = 0.62480035
# T = 2500  Fidelity = 0.63284718
# T = 2600  Fidelity = 0.62726089
# T = 2700  Fidelity = 0.59889716
# T = 2800  Fidelity = 0.60917437
# T = 2900  Fidelity = 0.63745792
# T = 3000  Fidelity = 0.65344803
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.17642281e-04
# P0     = 0.65344803
# P1     = 0.32862635
# P0+P1  = 0.98207438
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99101529
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.89670837
# T = 2     Fidelity = 0.95091886
# T = 5     Fidelity = 0.98188258
# T = 10    Fidelity = 0.99127715
#
# Minimum T for Fidelity >= 0.99 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.31621635e+00
# T = 1     Fidelity = 0.10057992
# T = 2     Fidelity = 0.29215951
# T = 5     Fidelity = 0.80159476
# T = 10    Fidelity = 0.98685905
# T = 20    Fidelity = 0.98879409
# T = 30    Fidelity = 0.99079451
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.40805723e+00
# T = 1     Fidelity = 0.12823344
# T = 2     Fidelity = 0.37851526
# T = 5     Fidelity = 0.80180198
# T = 10    Fidelity = 0.92424496
# T = 20    Fidelity = 0.99244156
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.23141023
# T = 2     Fidelity = 0.53220438
# T = 5     Fidelity = 0.91528273
# T = 10    Fidelity = 0.98318866
# T = 20    Fidelity = 0.99201711
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.30333919
# T = 2     Fidelity = 0.59381587
# T = 5     Fidelity = 0.91489530
# T = 10    Fidelity = 0.98284039
# T = 20    Fidelity = 0.99337998
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.35971876
# T = 2     Fidelity = 0.63563901
# T = 5     Fidelity = 0.93248838
# T = 10    Fidelity = 0.98468984
# T = 20    Fidelity = 0.99484480
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.40118874
# T = 2     Fidelity = 0.65965234
# T = 5     Fidelity = 0.93929665
# T = 10    Fidelity = 0.98305070
# T = 20    Fidelity = 0.99614230
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.43913999
# T = 2     Fidelity = 0.68129331
# T = 5     Fidelity = 0.94383839
# T = 10    Fidelity = 0.98189604
# T = 20    Fidelity = 0.99715442
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.47010902
# T = 2     Fidelity = 0.69783493
# T = 5     Fidelity = 0.94875397
# T = 10    Fidelity = 0.98122590
# T = 20    Fidelity = 0.99803705
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     None      0.9787994026      3.07240439e-04    0.702462    0.0         0.702462
# Symmetric      0.311     175       0.9975520686      1.17908351e-06    None        None        None
# Symmetric      0.522     125       0.9959572547      2.94880941e-07    None        None        None
# Symmetric      0.733     100       0.9998452184      1.58119101e-07    None        None        None
# Symmetric      0.944     75        0.9978303681      6.89654494e-08    None        None        None
# Symmetric      1.156     50        0.9960814716      1.17592590e-07    None        None        None
# Symmetric      1.367     50        0.9913290763      2.47961151e-07    None        None        None
# Symmetric      1.578     50        0.9947543682      3.56990602e-07    None        None        None
# Symmetric      1.789     40        0.9938294982      2.45005899e-06    None        None        None
# Symmetric      2.000     40        0.9999211909      1.44257094e-05    None        None        None
# Weak SSB optimised0.100     1080      0.9908778321      8.67181393e-01    None        None        None
# Weak SSB optimised0.311     None      0.9800177070      5.19764834e-01    0.975968    0.010727    0.986695
# Weak SSB optimised0.522     50        0.9903402320      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     20        0.9974079029      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     20        0.9933791165      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     125       0.9908384052      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     1020      0.9920038596      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     900       0.9939678847      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     1020      0.9946217237      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     225       0.9911608712      2.48783584e-01    None        None        None
# Weak SSB       0.100     900       0.9909250417      1.81947687e-02    None        None        None
# Weak SSB       0.311     None      0.9875545859      1.51771385e-02    0.936402    0.000152    0.936554
# Weak SSB       0.522     None      0.4989484302      1.05614584e-03    0.094432    0.403298    0.49773
# Weak SSB       0.733     None      0.4465064323      1.07018746e-03    0.302537    0.183195    0.485732
# Weak SSB       0.944     None      0.5314358372      9.80171521e-04    0.49118     0.324794    0.815973
# Weak SSB       1.156     None      0.5482526103      9.40449540e-04    0.548253    0.439381    0.987633
# Weak SSB       1.367     None      0.5954528049      9.13233454e-04    0.47038     0.309065    0.779445
# Weak SSB       1.578     None      0.6518282550      8.91554516e-04    0.651828    0.33116     0.982988
# Weak SSB       1.789     None      0.6373802513      8.73711147e-04    0.620876    0.343684    0.96456
# Weak SSB       2.000     None      0.6534480310      8.58553719e-04    0.653448    0.328626    0.982074
# Strong SSB     0.100     1         0.9910152885      3.59472102e+00    None        None        None
# Strong SSB     0.311     10        0.9912771480      1.58498916e+00    None        None        None
# Strong SSB     0.522     30        0.9907945105      1.31621635e+00    None        None        None
# Strong SSB     0.733     20        0.9924415612      1.40805723e+00    None        None        None
# Strong SSB     0.944     20        0.9920171094      1.38481786e+00    None        None        None
# Strong SSB     1.156     20        0.9933799807      1.34302163e+00    None        None        None
# Strong SSB     1.367     20        0.9948448004      1.29217279e+00    None        None        None
# Strong SSB     1.578     20        0.9961423047      1.23335459e+00    None        None        None
# Strong SSB     1.789     20        0.9971544192      1.17426012e+00    None        None        None
# Strong SSB     2.000     20        0.9980370494      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
# ============================================================


plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.1556
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7333

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=-2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ==================optimised==========================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
