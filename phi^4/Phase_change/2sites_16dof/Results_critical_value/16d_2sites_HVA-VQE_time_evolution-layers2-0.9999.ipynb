# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 0.00005

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722526063347
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_asymm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------
    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):
            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_symm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Multi-parameter scan
# HVA + warm-start continuation + overlap tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0

# Default depth
layers = 4

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
  {
       "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-4
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#" * 80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#" * 80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "=" * 60)
        print(f"Running λ = {lam:.3f}")
        print("=" * 60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(
            Hloc_sparse
        )

        # ----------------------------------------------------
        # Dense Hamiltonian
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(
            H_op
        )

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ====================================================
        # Adaptive depth near critical region
        # ====================================================

        

        # ====================================================
        # Ansatz
        # ====================================================

        if mI2 < 0:

            ansatz = grouped_hva_asymm(
                nq=nqubits,
                layers=layers
            )

        else:

            ansatz = grouped_hva_symm(
                nq=nqubits,
                layers=layers
            )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)



        
        # ====================================================
        # Weak SSB:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )
        # ====================================================
        # Weak SSB optimized:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )

        # ====================================================
        # Symmetric + Strong SSB
        # ====================================================

        else:

            print(
                "\nRunning ordinary HVA-VQE...\n"
            )

            initial_point = (
                0.01 * np.random.randn(
                    ansatz.num_parameters
                )
            )

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = (
                vqe.compute_minimum_eigenvalue(
                    H_pauli_shifted
                )
            )

            best_energy = (
                result.eigenvalue.real
                + identity_shift
            )

            optimal_circuit = (
                ansatz.assign_parameters(
                    result.optimal_parameters
                )
            )

            best_state = (
                Statevector.from_instruction(
                    optimal_circuit
                ).data
            )

            best_fidelity = np.abs(
                np.vdot(
                    psi_exact,
                    best_state
                )
            )**2

            best_overlap = 1.0

        # ====================================================
        # Final VQE data
        # ====================================================

        E_vqe = best_energy
        F = best_fidelity

        # ====================================================
        # Store results
        # ====================================================

        data = {

            "case": label,

            "lambda": lam,

            "mI2": mI2,

            "f": f,
            'psi_vqe': best_state,

            "E_exact": E_exact,

            "E_vqe": E_vqe,

            "error": abs(
                E_exact - E_vqe
            ),

            "fidelity": F,

            "tracking_overlap": best_overlap,

            "layers": layers
        }

        case_results.append(data)
        all_results.append(data)

        # ====================================================
        # Print
        # ====================================================

        print("\nFINAL SELECTED STATE")

        print(
            f"Exact energy     : "
            f"{E_exact:.12f}"
        )

        print(
            f"VQE energy       : "
            f"{E_vqe:.12f}"
        )

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(
            f"Fidelity         : "
            f"{F:.12f}"
        )

        print(
            f"Tracking overlap : "
            f"{best_overlap:.12f}"
        )

        print(
            f"Layers            : "
            f"{layers}"
        )

        print(
            f"Pauli terms       : "
            f"{len(H_pauli_shifted.paulis)}"
        )

    # ========================================================
    # Summary
    # ========================================================

    print("\n")
    print("=" * 140)
    print(f"SUMMARY : {label}")
    print("=" * 140)

    print(
        f"{'lambda':<12}"
        f"{'Exact E':<20}"
        f"{'VQE E':<20}"
        f"{'Error':<18}"
        f"{'Fidelity':<18}"
        f"{'TrackOverlap':<18}"
        f"{'Layers':<10}"
    )

    print("=" * 140)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
            f"{r['E_vqe']:<20.10f}"
            f"{r['error']:<18.4e}"
            f"{r['fidelity']:<18.10f}"
            f"{r['tracking_overlap']:<18.10f}"
            f"{r['layers']:<10}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running ordinary HVA-VQE...
# /home/semin/jupyter/qiskit_env/lib/python3.12/site-packages/qiskit_algorithms/optimizers/scipy_optimizer.py:162: OptimizeWarning: Unknown solver options: iprint
#   raw_result = minimize(
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006162204924
# Energy error     : 4.767646e-07
# Fidelity         : 0.999999902130
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 106
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018642804760
# Energy error     : 1.377413e-06
# Fidelity         : 0.999999792052
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030508384018
# Energy error     : 9.074224e-06
# Fidelity         : 0.999998549190
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041842685574
# Energy error     : 1.836331e-05
# Fidelity         : 0.999997302487
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052697105643
# Energy error     : 1.256188e-05
# Fidelity         : 0.999998296903
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063155475173
# Energy error     : 2.168640e-05
# Fidelity         : 0.999991587901
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073219238941
# Energy error     : 3.585170e-06
# Fidelity         : 0.999999650360
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082976076192
# Energy error     : 9.924377e-06
# Fidelity         : 0.999999036362
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092429781282
# Energy error     : 1.427317e-05
# Fidelity         : 0.999996914552
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101591468560
# Energy error     : 2.039817e-06
# Fidelity         : 0.999999714648
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
#
# ============================================================================================================================================
# SUMMARY : Symmetric
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      1.0061617282        1.0061622049        4.7676e-07        0.9999999021      1.0000000000      4
# 0.3111      1.0186414273        1.0186428048        1.3774e-06        0.9999997921      1.0000000000      4
# 0.5222      1.0304993098        1.0305083840        9.0742e-06        0.9999985492      1.0000000000      4
# 0.7333      1.0418243223        1.0418426856        1.8363e-05        0.9999973025      1.0000000000      4
# 0.9444      1.0526845438        1.0526971056        1.2562e-05        0.9999982969      1.0000000000      4
# 1.1556      1.0631337888        1.0631554752        2.1686e-05        0.9999915879      1.0000000000      4
# 1.3667      1.0732156538        1.0732192389        3.5852e-06        0.9999996504      1.0000000000      4
# 1.5778      1.0829661518        1.0829760762        9.9244e-06        0.9999990364      1.0000000000      4
# 1.7889      1.0924155081        1.0924297813        1.4273e-05        0.9999969146      1.0000000000      4
# 2.0000      1.1015894287        1.1015914686        2.0398e-06        0.9999997146      1.0000000000      4
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.053033067203
# Fidelity = 0.998392941168
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -17.050328082672
# Fidelity = 0.996133974472
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -17.040372520971
# Fidelity = 0.997053879089
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -17.061949682792
# Fidelity = 0.999538144501
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -17.063296782947
# Fidelity = 0.999784576134
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.064037931120
# Fidelity = 0.999887917681
# Overlap  = 0.999899319262
#
# Restart 1
# Energy   = -17.045602335606
# Fidelity = 0.996196207585
# Overlap  = 0.996513692233
#
# Restart 2
# Energy   = -17.001557340814
# Fidelity = 0.993360058507
# Overlap  = 0.994089451988
#
# Restart 3
# Energy   = -17.046694821246
# Fidelity = 0.997154021420
# Overlap  = 0.997132439924
#
# Restart 4
# Energy   = -17.063140357503
# Fidelity = 0.999702810467
# Overlap  = 0.999675707498
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.064037931120
# Energy error     : 6.554207e-04
# Fidelity         : 0.999887917681
# Tracking overlap : 0.999899319262
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.061076915157
# Fidelity = 0.992546057621
# Overlap  = 0.830301154905
#
# Restart 1
# Energy   = -9.030090559194
# Fidelity = 0.980426915421
# Overlap  = 0.845701158760
#
# Restart 2
# Energy   = -9.053236614449
# Fidelity = 0.984662861918
# Overlap  = 0.829303381548
#
# Restart 3
# Energy   = -9.041806884533
# Fidelity = 0.980571972119
# Overlap  = 0.833527661544
#
# Restart 4
# Energy   = -9.054949854335
# Fidelity = 0.986259591189
# Overlap  = 0.828689362448
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.069858915292
# Fidelity = 0.996230151680
# Overlap  = 0.997577235724
#
# Restart 1
# Energy   = -9.057024410566
# Fidelity = 0.988175794979
# Overlap  = 0.996614396020
#
# Restart 2
# Energy   = -9.049137047872
# Fidelity = 0.984175890273
# Overlap  = 0.994372363718
#
# Restart 3
# Energy   = -9.054898682743
# Fidelity = 0.985381185357
# Overlap  = 0.994779100432
#
# Restart 4
# Energy   = -9.049996534451
# Fidelity = 0.982816274067
# Overlap  = 0.994444939585
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.069858915292
# Energy error     : 1.059100e-02
# Fidelity         : 0.996230151680
# Tracking overlap : 0.997577235724
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.676546988097
# Fidelity = 0.986425393477
# Overlap  = 0.066161767057
#
# Restart 1
# Energy   = -4.658230008120
# Fidelity = 0.973652512133
# Overlap  = 0.071930111987
#
# Restart 2
# Energy   = -4.659856488036
# Fidelity = 0.974959592233
# Overlap  = 0.071843022021
#
# Restart 3
# Energy   = -4.662083787741
# Fidelity = 0.978006816431
# Overlap  = 0.071425316439
#
# Restart 4
# Energy   = -4.656591662319
# Fidelity = 0.971794017069
# Overlap  = 0.072553828703
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.683289092867
# Fidelity = 0.990368303706
# Overlap  = 0.997598514354
#
# Restart 1
# Energy   = -4.665423811604
# Fidelity = 0.980415487241
# Overlap  = 0.989228398638
#
# Restart 2
# Energy   = -4.673005651479
# Fidelity = 0.984136243420
# Overlap  = 0.997353563677
#
# Restart 3
# Energy   = -4.656190910169
# Fidelity = 0.971584943676
# Overlap  = 0.988731745801
#
# Restart 4
# Energy   = -4.666016454288
# Fidelity = 0.979197651439
# Overlap  = 0.991648709340
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.683289092867
# Energy error     : 1.790588e-02
# Fidelity         : 0.990368303706
# Tracking overlap : 0.997598514354
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.002702715519
# Fidelity = 0.996948488914
# Overlap  = 0.652600127387
#
# Restart 1
# Energy   = -2.992655459004
# Fidelity = 0.992842039100
# Overlap  = 0.642057894332
#
# Restart 2
# Energy   = -2.992183995391
# Fidelity = 0.992313659443
# Overlap  = 0.639456585939
#
# Restart 3
# Energy   = -3.000328601931
# Fidelity = 0.995831113596
# Overlap  = 0.651380344016
#
# Restart 4
# Energy   = -2.974332392412
# Fidelity = 0.985076478952
# Overlap  = 0.606078367652
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.003485229459
# Fidelity = 0.997196885851
# Overlap  = 0.999878651515
#
# Restart 1
# Energy   = -3.003146931134
# Fidelity = 0.997532698299
# Overlap  = 0.997790306470
#
# Restart 2
# Energy   = -2.993761391867
# Fidelity = 0.993636631406
# Overlap  = 0.996531325265
#
# Restart 3
# Energy   = -2.993069331896
# Fidelity = 0.993151023464
# Overlap  = 0.996378912377
#
# Restart 4
# Energy   = -2.983539575090
# Fidelity = 0.989278742951
# Overlap  = 0.993214068980
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.003485229459
# Energy error     : 8.046122e-03
# Fidelity         : 0.997196885851
# Tracking overlap : 0.999878651515
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.081596952680
# Fidelity = 0.999580629261
# Overlap  = 0.834578911815
#
# Restart 1
# Energy   = -2.077369905589
# Fidelity = 0.998391683684
# Overlap  = 0.823633053430
#
# Restart 2
# Energy   = -2.061717790402
# Fidelity = 0.985434467360
# Overlap  = 0.811745233769
#
# Restart 3
# Energy   = -2.077413869415
# Fidelity = 0.998263575629
# Overlap  = 0.823335831048
#
# Restart 4
# Energy   = -2.078293910716
# Fidelity = 0.998799473934
# Overlap  = 0.826874617642
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.081670456720
# Fidelity = 0.999604463541
# Overlap  = 0.999983165811
#
# Restart 1
# Energy   = -2.076881619215
# Fidelity = 0.998506649580
# Overlap  = 0.999003573626
#
# Restart 2
# Energy   = -2.078452439612
# Fidelity = 0.998811728352
# Overlap  = 0.999223838480
#
# Restart 3
# Energy   = -2.077133639854
# Fidelity = 0.998416806181
# Overlap  = 0.998889333147
#
# Restart 4
# Energy   = -2.078379201984
# Fidelity = 0.998720149240
# Overlap  = 0.999028017607
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.081670456720
# Energy error     : 1.895267e-03
# Fidelity         : 0.999604463541
# Tracking overlap : 0.999983165811
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.503125503038
# Fidelity = 0.999771302929
# Overlap  = 0.898852032000
#
# Restart 1
# Energy   = -1.501914038728
# Fidelity = 0.999575961434
# Overlap  = 0.897170556782
#
# Restart 2
# Energy   = -1.502467247452
# Fidelity = 0.999670042311
# Overlap  = 0.897420794317
#
# Restart 3
# Energy   = -1.501894463372
# Fidelity = 0.999568022156
# Overlap  = 0.896531080765
#
# Restart 4
# Energy   = -1.501771710226
# Fidelity = 0.999120823865
# Overlap  = 0.895581000833
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.504001047545
# Fidelity = 0.999919111853
# Overlap  = 0.999821727157
#
# Restart 1
# Energy   = -1.502597228817
# Fidelity = 0.999660970617
# Overlap  = 0.999846469894
#
# Restart 2
# Energy   = -1.503151770383
# Fidelity = 0.999794124167
# Overlap  = 0.999875912990
#
# Restart 3
# Energy   = -1.502098327351
# Fidelity = 0.999591479604
# Overlap  = 0.999818598604
#
# Restart 4
# Energy   = -1.502419330708
# Fidelity = 0.999396878786
# Overlap  = 0.999661798301
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503151770383
# Energy error     : 1.336102e-03
# Fidelity         : 0.999794124167
# Tracking overlap : 0.999875912990
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118335023985
# Fidelity = 0.999883294903
# Overlap  = 0.918294980381
#
# Restart 1
# Energy   = -1.113624488648
# Fidelity = 0.997935887441
# Overlap  = 0.911342325940
#
# Restart 2
# Energy   = -1.105041166954
# Fidelity = 0.990144993443
# Overlap  = 0.892940270339
#
# Restart 3
# Energy   = -1.114612337797
# Fidelity = 0.999208801708
# Overlap  = 0.917410782462
#
# Restart 4
# Energy   = -1.114807628424
# Fidelity = 0.999310086147
# Overlap  = 0.918172945029
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118669773757
# Fidelity = 0.999928176912
# Overlap  = 0.999920906923
#
# Restart 1
# Energy   = -1.108769976150
# Fidelity = 0.992682211203
# Overlap  = 0.993434578995
#
# Restart 2
# Energy   = -1.107698109495
# Fidelity = 0.992623331734
# Overlap  = 0.993265177594
#
# Restart 3
# Energy   = -1.108003132644
# Fidelity = 0.992399302423
# Overlap  = 0.992992369836
#
# Restart 4
# Energy   = -1.115186558665
# Fidelity = 0.999368782553
# Overlap  = 0.999435504538
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118669773757
# Energy error     : 4.299567e-04
# Fidelity         : 0.999928176912
# Tracking overlap : 0.999920906923
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.852953428361
# Fidelity = 0.999944481454
# Overlap  = 0.937364233647
#
# Restart 1
# Energy   = -0.849280376550
# Fidelity = 0.999250985142
# Overlap  = 0.932471282430
#
# Restart 2
# Energy   = -0.846244201111
# Fidelity = 0.996338907120
# Overlap  = 0.920814788945
#
# Restart 3
# Energy   = -0.840629632150
# Fidelity = 0.990661099536
# Overlap  = 0.902992657479
#
# Restart 4
# Energy   = -0.847371076705
# Fidelity = 0.996276438229
# Overlap  = 0.924253304223
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.852989085355
# Fidelity = 0.999947951334
# Overlap  = 0.999994237502
#
# Restart 1
# Energy   = -0.849221691198
# Fidelity = 0.999215838968
# Overlap  = 0.999325016415
#
# Restart 2
# Energy   = -0.845715334632
# Fidelity = 0.995248368220
# Overlap  = 0.995588758295
#
# Restart 3
# Energy   = -0.845409052039
# Fidelity = 0.996591900025
# Overlap  = 0.996952647124
#
# Restart 4
# Energy   = -0.848466204954
# Fidelity = 0.998843227789
# Overlap  = 0.998995788196
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.852989085355
# Energy error     : 3.429686e-04
# Fidelity         : 0.999947951334
# Tracking overlap : 0.999994237502
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663313051296
# Fidelity = 0.999965846563
# Overlap  = 0.959147617805
#
# Restart 1
# Energy   = -0.656422730392
# Fidelity = 0.995574640063
# Overlap  = 0.940278805130
#
# Restart 2
# Energy   = -0.657082661409
# Fidelity = 0.997011529536
# Overlap  = 0.945325891535
#
# Restart 3
# Energy   = -0.656476494784
# Fidelity = 0.995857990896
# Overlap  = 0.940586668170
#
# Restart 4
# Energy   = -0.656429983472
# Fidelity = 0.996201484916
# Overlap  = 0.942312771549
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663317962315
# Fidelity = 0.999967432109
# Overlap  = 0.999998693299
#
# Restart 1
# Energy   = -0.657241933387
# Fidelity = 0.997054997865
# Overlap  = 0.997308955951
#
# Restart 2
# Energy   = -0.656066280161
# Fidelity = 0.995790314777
# Overlap  = 0.996142653468
#
# Restart 3
# Energy   = -0.656043301475
# Fidelity = 0.995597849121
# Overlap  = 0.995969536366
#
# Restart 4
# Energy   = -0.656630603265
# Fidelity = 0.996047351709
# Overlap  = 0.996396354647
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663317962315
# Energy error     : 2.421792e-04
# Fidelity         : 0.999967432109
# Tracking overlap : 0.999998693299
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.521966936648
# Fidelity = 0.999976361844
# Overlap  = 0.975970531727
#
# Restart 1
# Energy   = -0.518575899990
# Fidelity = 0.998653362832
# Overlap  = 0.968653890910
#
# Restart 2
# Energy   = -0.518112129295
# Fidelity = 0.998103974942
# Overlap  = 0.966919050791
#
# Restart 3
# Energy   = -0.518098609227
# Fidelity = 0.998031332014
# Overlap  = 0.967150602081
#
# Restart 4
# Energy   = -0.517666195554
# Fidelity = 0.997826341625
# Overlap  = 0.966112228823
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.521979146869
# Fidelity = 0.999979868351
# Overlap  = 0.999995274469
#
# Restart 1
# Energy   = -0.520084161996
# Fidelity = 0.999612718464
# Overlap  = 0.999660411579
#
# Restart 2
# Energy   = -0.518837478317
# Fidelity = 0.998342269762
# Overlap  = 0.998415641343
#
# Restart 3
# Energy   = -0.517937539853
# Fidelity = 0.997991921186
# Overlap  = 0.998140151300
#
# Restart 4
# Energy   = -0.518092304477
# Fidelity = 0.998293204225
# Overlap  = 0.998418930652
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.521979146869
# Energy error     : 1.606174e-04
# Fidelity         : 0.999979868351
# Tracking overlap : 0.999995274469
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB optimised
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -17.0646933519      -17.0640379311      6.5542e-04        0.9998879177      0.9998993193      4
# 0.3111      -9.0804499123       -9.0698589153       1.0591e-02        0.9962301517      0.9975772357      4
# 0.5222      -4.7011949726       -4.6832890929       1.7906e-02        0.9903683037      0.9975985144      4
# 0.7333      -3.0115313516       -3.0034852295       8.0461e-03        0.9971968859      0.9998786515      4
# 0.9444      -2.0835657235       -2.0816704567       1.8953e-03        0.9996044635      0.9999831658      4
# 1.1556      -1.5044878727       -1.5031517704       1.3361e-03        0.9997941242      0.9998759130      4
# 1.3667      -1.1190997304       -1.1186697738       4.2996e-04        0.9999281769      0.9999209069      4
# 1.5778      -0.8533320540       -0.8529890854       3.4297e-04        0.9999479513      0.9999942375      4
# 1.7889      -0.6635601415       -0.6633179623       2.4218e-04        0.9999674321      0.9999986933      4
# 2.0000      -0.5221397643       -0.5219791469       1.6062e-04        0.9999798684      0.9999952745      4
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 0.0001
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.943727160711
# Fidelity = 0.999971013503
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.943799276371
# Fidelity = 0.999980027363
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.941997900560
# Fidelity = 0.999749972758
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.939675893643
# Fidelity = 0.999547517063
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.943537325750
# Fidelity = 0.999944301541
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.943899351841
# Fidelity = 0.999999183250
# Overlap  = 0.999971890744
#
# Restart 1
# Energy   = -16.914017974819
# Fidelity = 0.994561796445
# Overlap  = 0.994278144047
#
# Restart 2
# Energy   = -16.898235605861
# Fidelity = 0.994936669316
# Overlap  = 0.995067825298
#
# Restart 3
# Energy   = -16.938415128636
# Fidelity = 0.999186408498
# Overlap  = 0.999073699759
#
# Restart 4
# Energy   = -16.943038035246
# Fidelity = 0.999894540860
# Overlap  = 0.999858379403
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902685020
# VQE energy       : -16.943899351841
# Energy error     : 3.333179e-06
# Fidelity         : 0.999999183250
# Tracking overlap : 0.999971890744
# Layers            : 4
# Pauli terms       : 158
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.892050308054
# Fidelity = 0.999985403601
# Overlap  = 0.875539747835
#
# Restart 1
# Energy   = -8.206712732740
# Fidelity = 0.000000031383
# Overlap  = 0.000000014837
#
# Restart 2
# Energy   = -8.206460801499
# Fidelity = 0.000000000001
# Overlap  = 0.000000000001
#
# Restart 3
# Energy   = -8.549285055493
# Fidelity = 0.000331523043
# Overlap  = 0.000270636426
#
# Restart 4
# Energy   = -8.891921545116
# Fidelity = 0.999959174424
# Overlap  = 0.875813851315
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.892008473752
# Fidelity = 0.999988408801
# Overlap  = 0.999969460842
#
# Restart 1
# Energy   = -8.549230489393
# Fidelity = 0.000004751600
# Overlap  = 0.000010687175
#
# Restart 2
# Energy   = -8.549203288382
# Fidelity = 0.000002480953
# Overlap  = 0.000003079537
#
# Restart 3
# Energy   = -8.549278291609
# Fidelity = 0.000000209086
# Overlap  = 0.000001109028
#
# Restart 4
# Energy   = -8.548960882037
# Fidelity = 0.000098017372
# Overlap  = 0.000109264440
#
# FINAL SELECTED STATE
# Exact energy     : -8.892069658534
# VQE energy       : -8.892008473752
# Energy error     : 6.118478e-05
# Fidelity         : 0.999988408801
# Tracking overlap : 0.999969460842
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379058373737
# Fidelity = 0.803333795372
# Overlap  = 0.049158928893
#
# Restart 1
# Energy   = -4.377411226129
# Fidelity = 0.010348303645
# Overlap  = 0.000000000004
#
# Restart 2
# Energy   = -4.377420405447
# Fidelity = 0.010311846611
# Overlap  = 0.000000000026
#
# Restart 3
# Energy   = -4.377426977522
# Fidelity = 0.010585292423
# Overlap  = 0.000000000001
#
# Restart 4
# Energy   = -4.377415340135
# Fidelity = 0.010527611285
# Overlap  = 0.000000000005
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379088033084
# Fidelity = 0.804395535160
# Overlap  = 0.999972691157
#
# Restart 1
# Energy   = -4.377415312907
# Fidelity = 0.010171066129
# Overlap  = 0.000000001441
#
# Restart 2
# Energy   = -4.377421907419
# Fidelity = 0.010723461626
# Overlap  = 0.000000000931
#
# Restart 3
# Energy   = -4.377434954217
# Fidelity = 0.010673324371
# Overlap  = 0.000000000228
#
# Restart 4
# Energy   = -4.377408539740
# Fidelity = 0.010437615232
# Overlap  = 0.000000000325
#
# FINAL SELECTED STATE
# Exact energy     : -4.379329565434
# VQE energy       : -4.379088033084
# Energy error     : 2.415324e-04
# Fidelity         : 0.804395535160
# Tracking overlap : 0.999972691157
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.741464647233
# Fidelity = 0.000018942040
# Overlap  = 0.660787265212
#
# Restart 1
# Energy   = -2.749744891585
# Fidelity = 0.991921446940
# Overlap  = 0.000000000190
#
# Restart 2
# Energy   = -2.749760051699
# Fidelity = 0.991723836390
# Overlap  = 0.000000000026
#
# Restart 3
# Energy   = -2.749765912348
# Fidelity = 0.991184952218
# Overlap  = 0.000000000211
#
# Restart 4
# Energy   = -2.749772671992
# Fidelity = 0.991286061634
# Overlap  = 0.000000000514
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.749785681702
# Fidelity = 0.991555353781
# Overlap  = 0.999989995607
#
# Restart 1
# Energy   = -2.749782596155
# Fidelity = 0.992032840953
# Overlap  = 0.999966827873
#
# Restart 2
# Energy   = -2.749767765666
# Fidelity = 0.990988641230
# Overlap  = 0.999982926977
#
# Restart 3
# Energy   = -2.749763195963
# Fidelity = 0.991391477605
# Overlap  = 0.999986014375
#
# Restart 4
# Energy   = -2.749714208291
# Fidelity = 0.991198689430
# Overlap  = 0.999961809706
#
# FINAL SELECTED STATE
# Exact energy     : -2.749826501443
# VQE energy       : -2.749785681702
# Energy error     : 4.081974e-05
# Fidelity         : 0.991555353781
# Tracking overlap : 0.999989995607
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874692514749
# Fidelity = 0.999548674856
# Overlap  = 0.821489733442
#
# Restart 1
# Energy   = -1.870638111010
# Fidelity = 0.998856119338
# Overlap  = 0.810408410608
#
# Restart 2
# Energy   = -1.874692892213
# Fidelity = 0.999719569187
# Overlap  = 0.821712170974
#
# Restart 3
# Energy   = -1.872822563193
# Fidelity = 0.998995291514
# Overlap  = 0.813862373795
#
# Restart 4
# Energy   = -1.873756172337
# Fidelity = 0.999366056331
# Overlap  = 0.818249199053
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874700600183
# Fidelity = 0.999729155924
# Overlap  = 0.999997990845
#
# Restart 1
# Energy   = -1.871586106758
# Fidelity = 0.999027646061
# Overlap  = 0.999271873901
#
# Restart 2
# Energy   = -1.871288114196
# Fidelity = 0.998787687930
# Overlap  = 0.999153134412
#
# Restart 3
# Energy   = -1.874653525502
# Fidelity = 0.999708941943
# Overlap  = 0.999958168427
#
# Restart 4
# Energy   = -1.871348669765
# Fidelity = 0.998801504733
# Overlap  = 0.999145250024
#
# FINAL SELECTED STATE
# Exact energy     : -1.874705890824
# VQE energy       : -1.874700600183
# Energy error     : 5.290641e-06
# Fidelity         : 0.999729155924
# Tracking overlap : 0.999997990845
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348177280676
# Fidelity = 0.999751898221
# Overlap  = 0.896624848667
#
# Restart 1
# Energy   = -1.348292482578
# Fidelity = 0.999815290502
# Overlap  = 0.896182459218
#
# Restart 2
# Energy   = -1.348265828237
# Fidelity = 0.999797630449
# Overlap  = 0.896186713132
#
# Restart 3
# Energy   = -1.348584643574
# Fidelity = 0.999870151439
# Overlap  = 0.896384976543
#
# Restart 4
# Energy   = -1.348340937133
# Fidelity = 0.999876178418
# Overlap  = 0.896190121921
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348710801590
# Fidelity = 0.999877227660
# Overlap  = 0.999829239192
#
# Restart 1
# Energy   = -1.348175382486
# Fidelity = 0.999853253262
# Overlap  = 0.999880037419
#
# Restart 2
# Energy   = -1.348220574998
# Fidelity = 0.999856026157
# Overlap  = 0.999931587879
#
# Restart 3
# Energy   = -1.348204063526
# Fidelity = 0.999835016923
# Overlap  = 0.999945833656
#
# Restart 4
# Energy   = -1.348256108074
# Fidelity = 0.999847176886
# Overlap  = 0.999944080140
#
# FINAL SELECTED STATE
# Exact energy     : -1.348823187245
# VQE energy       : -1.348204063526
# Energy error     : 6.191237e-04
# Fidelity         : 0.999835016923
# Tracking overlap : 0.999945833656
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.007215510050
# Fidelity = 0.999454988614
# Overlap  = 0.935259362223
#
# Restart 1
# Energy   = -1.008540284441
# Fidelity = 0.999562881120
# Overlap  = 0.935643090005
#
# Restart 2
# Energy   = -1.007163260817
# Fidelity = 0.999447521812
# Overlap  = 0.935432252781
#
# Restart 3
# Energy   = -1.007144242154
# Fidelity = 0.999457154038
# Overlap  = 0.935540963218
#
# Restart 4
# Energy   = -1.006839201228
# Fidelity = 0.999396444022
# Overlap  = 0.935186340283
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.008744452373
# Fidelity = 0.999733811301
# Overlap  = 0.999896035887
#
# Restart 1
# Energy   = -1.007171420608
# Fidelity = 0.999433393338
# Overlap  = 0.999574281351
#
# Restart 2
# Energy   = -1.008403723840
# Fidelity = 0.999401887232
# Overlap  = 0.999221859032
#
# Restart 3
# Energy   = -1.007367898386
# Fidelity = 0.999509720578
# Overlap  = 0.999557147401
#
# Restart 4
# Energy   = -1.007166835324
# Fidelity = 0.999463271990
# Overlap  = 0.999576584081
#
# FINAL SELECTED STATE
# Exact energy     : -1.010440164101
# VQE energy       : -1.008744452373
# Energy error     : 1.695712e-03
# Fidelity         : 0.999733811301
# Tracking overlap : 0.999896035887
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.777461136419
# Fidelity = 0.999753337978
# Overlap  = 0.962470328779
#
# Restart 1
# Energy   = -0.775812657320
# Fidelity = 0.999490861345
# Overlap  = 0.961187647086
#
# Restart 2
# Energy   = -0.776045675021
# Fidelity = 0.999518196869
# Overlap  = 0.961607519212
#
# Restart 3
# Energy   = -0.775805994925
# Fidelity = 0.999485827421
# Overlap  = 0.961218920419
#
# Restart 4
# Energy   = -0.775810511875
# Fidelity = 0.999487586941
# Overlap  = 0.961148387504
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.777643348679
# Fidelity = 0.999751872008
# Overlap  = 0.999942754706
#
# Restart 1
# Energy   = -0.775788667725
# Fidelity = 0.999494770215
# Overlap  = 0.999726966715
#
# Restart 2
# Energy   = -0.775837891850
# Fidelity = 0.999496376090
# Overlap  = 0.999724288191
#
# Restart 3
# Energy   = -0.775803629566
# Fidelity = 0.999511739698
# Overlap  = 0.999731479518
#
# Restart 4
# Energy   = -0.775796463782
# Fidelity = 0.999500903809
# Overlap  = 0.999735237265
#
# FINAL SELECTED STATE
# Exact energy     : -0.779140149474
# VQE energy       : -0.777643348679
# Energy error     : 1.496801e-03
# Fidelity         : 0.999751872008
# Tracking overlap : 0.999942754706
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611381001492
# Fidelity = 0.999932860171
# Overlap  = 0.977738621023
#
# Restart 1
# Energy   = -0.609496749843
# Fidelity = 0.999683709707
# Overlap  = 0.976869700554
#
# Restart 2
# Energy   = -0.609523861899
# Fidelity = 0.999692951847
# Overlap  = 0.976893438080
#
# Restart 3
# Energy   = -0.609502168058
# Fidelity = 0.999683588865
# Overlap  = 0.976882024308
#
# Restart 4
# Energy   = -0.609510038322
# Fidelity = 0.999687444935
# Overlap  = 0.976894153126
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611719754736
# Fidelity = 0.999996952596
# Overlap  = 0.999921547564
#
# Restart 1
# Energy   = -0.609472240624
# Fidelity = 0.999683326585
# Overlap  = 0.999751767626
#
# Restart 2
# Energy   = -0.609513553826
# Fidelity = 0.999692019633
# Overlap  = 0.999764823595
#
# Restart 3
# Energy   = -0.609509968110
# Fidelity = 0.999685136932
# Overlap  = 0.999753159343
#
# Restart 4
# Energy   = -0.609516415718
# Fidelity = 0.999693052828
# Overlap  = 0.999752887476
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723602270
# VQE energy       : -0.611719754736
# Energy error     : 3.847534e-06
# Fidelity         : 0.999996952596
# Tracking overlap : 0.999921547564
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484291360588
# Fidelity = 0.999998070740
# Overlap  = 0.986413532510
#
# Restart 1
# Energy   = -0.483109848454
# Fidelity = 0.999846985765
# Overlap  = 0.985399516173
#
# Restart 2
# Energy   = -0.483110580650
# Fidelity = 0.999840870179
# Overlap  = 0.985377210170
#
# Restart 3
# Energy   = -0.483109566024
# Fidelity = 0.999844299660
# Overlap  = 0.985377827065
#
# Restart 4
# Energy   = -0.483113029786
# Fidelity = 0.999846843405
# Overlap  = 0.985392588080
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484293285054
# Fidelity = 0.999998955418
# Overlap  = 0.999999559931
#
# Restart 1
# Energy   = -0.483110764917
# Fidelity = 0.999845797564
# Overlap  = 0.999842931920
#
# Restart 2
# Energy   = -0.483117341475
# Fidelity = 0.999847852061
# Overlap  = 0.999845458222
#
# Restart 3
# Energy   = -0.483112323126
# Fidelity = 0.999842828349
# Overlap  = 0.999839554559
#
# Restart 4
# Energy   = -0.483116145672
# Fidelity = 0.999848052100
# Overlap  = 0.999846401211
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295546782
# VQE energy       : -0.484293285054
# Energy error     : 2.261728e-06
# Fidelity         : 0.999998955418
# Tracking overlap : 0.999999559931
# Layers            : 4
# Pauli terms       : 160
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9439026850      -16.9438993518      3.3332e-06        0.9999991832      0.9999718907      4
# 0.3111      -8.8920696585       -8.8920084738       6.1185e-05        0.9999884088      0.9999694608      4
# 0.5222      -4.3793295654       -4.3790880331       2.4153e-04        0.8043955352      0.9999726912      4
# 0.7333      -2.7498265014       -2.7497856817       4.0820e-05        0.9915553538      0.9999899956      4
# 0.9444      -1.8747058908       -1.8747006002       5.2906e-06        0.9997291559      0.9999979908      4
# 1.1556      -1.3488231872       -1.3482040635       6.1912e-04        0.9998350169      0.9999458337      4
# 1.3667      -1.0104401641       -1.0087444524       1.6957e-03        0.9997338113      0.9998960359      4
# 1.5778      -0.7791401495       -0.7776433487       1.4968e-03        0.9997518720      0.9999427547      4
# 1.7889      -0.6117236023       -0.6117197547       3.8475e-06        0.9999969526      0.9999215476      4
# 2.0000      -0.4842955468       -0.4842932851       2.2617e-06        0.9999989554      0.9999995599      4
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.730903047856
# Fidelity = 0.995124597299
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -20.757844894460
# Fidelity = 0.997787804746
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -20.745244127762
# Fidelity = 0.995985186977
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -20.719149930422
# Fidelity = 0.992815436739
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -20.758449844130
# Fidelity = 0.998239482828
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.765897231693
# Fidelity = 0.998838720091
# Overlap  = 0.999259866657
#
# Restart 1
# Energy   = -20.756850431545
# Fidelity = 0.997754550208
# Overlap  = 0.999479368591
#
# Restart 2
# Energy   = -20.696503487895
# Fidelity = 0.991373891645
# Overlap  = 0.993409237544
#
# Restart 3
# Energy   = -20.698691626229
# Fidelity = 0.991613665435
# Overlap  = 0.993341057606
#
# Restart 4
# Energy   = -20.757902641889
# Fidelity = 0.997933218449
# Overlap  = 0.999236441097
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.765897231693
# Energy error     : 1.143121e-02
# Fidelity         : 0.998838720091
# Tracking overlap : 0.999259866657
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.814893992134
# Fidelity = 0.995994580148
# Overlap  = 0.859151073039
#
# Restart 1
# Energy   = -12.813425671228
# Fidelity = 0.995458834705
# Overlap  = 0.858901666910
#
# Restart 2
# Energy   = -12.807366240269
# Fidelity = 0.994740542580
# Overlap  = 0.856873912928
#
# Restart 3
# Energy   = -12.811048111478
# Fidelity = 0.995340557584
# Overlap  = 0.857254715177
#
# Restart 4
# Energy   = -12.808503330112
# Fidelity = 0.994715780035
# Overlap  = 0.862240393482
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.821555500318
# Fidelity = 0.997202278663
# Overlap  = 0.999021027667
#
# Restart 1
# Energy   = -12.812329955840
# Fidelity = 0.995692889106
# Overlap  = 0.998596768946
#
# Restart 2
# Energy   = -12.813200404922
# Fidelity = 0.995567322857
# Overlap  = 0.999134331575
#
# Restart 3
# Energy   = -12.812975783638
# Fidelity = 0.995725548344
# Overlap  = 0.999152724871
#
# Restart 4
# Energy   = -12.813606513673
# Fidelity = 0.995948914464
# Overlap  = 0.998921314595
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.821555500318
# Energy error     : 1.488564e-02
# Fidelity         : 0.997202278663
# Tracking overlap : 0.999021027667
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.666548315880
# Fidelity = 0.986511276977
# Overlap  = 0.168531592884
#
# Restart 1
# Energy   = -7.675383559665
# Fidelity = 0.988365495273
# Overlap  = 0.165463752903
#
# Restart 2
# Energy   = -7.630420481454
# Fidelity = 0.977108428962
# Overlap  = 0.178094362922
#
# Restart 3
# Energy   = -7.670699040982
# Fidelity = 0.987356046285
# Overlap  = 0.167259923148
#
# Restart 4
# Energy   = -7.647305602035
# Fidelity = 0.982932048165
# Overlap  = 0.169253265518
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.692848713953
# Fidelity = 0.992535014500
# Overlap  = 0.994796505649
#
# Restart 1
# Energy   = -7.631379309489
# Fidelity = 0.979449078913
# Overlap  = 0.989804525340
#
# Restart 2
# Energy   = -7.622304900809
# Fidelity = 0.976176578070
# Overlap  = 0.984446132183
#
# Restart 3
# Energy   = -7.613892041499
# Fidelity = 0.972859183670
# Overlap  = 0.987004638666
#
# Restart 4
# Energy   = -7.684279339427
# Fidelity = 0.990946297090
# Overlap  = 0.990493469769
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.692848713953
# Energy error     : 3.786765e-02
# Fidelity         : 0.992535014500
# Tracking overlap : 0.994796505649
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.522648509634
# Fidelity = 0.997641358696
# Overlap  = 0.627247906095
#
# Restart 1
# Energy   = -5.485014647364
# Fidelity = 0.989274027673
# Overlap  = 0.593115260085
#
# Restart 2
# Energy   = -5.470203996951
# Fidelity = 0.985977965927
# Overlap  = 0.602116489937
#
# Restart 3
# Energy   = -5.510441870007
# Fidelity = 0.995127262993
# Overlap  = 0.616282430175
#
# Restart 4
# Energy   = -5.499260914954
# Fidelity = 0.992616312868
# Overlap  = 0.609084703443
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.524418456524
# Fidelity = 0.997927921585
# Overlap  = 0.999486004985
#
# Restart 1
# Energy   = -5.501919734920
# Fidelity = 0.993866113335
# Overlap  = 0.995227859158
#
# Restart 2
# Energy   = -5.495126347138
# Fidelity = 0.992099564296
# Overlap  = 0.994247538171
#
# Restart 3
# Energy   = -5.483248354645
# Fidelity = 0.989014061987
# Overlap  = 0.991786374883
#
# Restart 4
# Energy   = -5.502197617086
# Fidelity = 0.993649493459
# Overlap  = 0.995582833392
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.524418456524
# Energy error     : 1.373037e-02
# Fidelity         : 0.997927921585
# Tracking overlap : 0.999486004985
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.273553498567
# Fidelity = 0.999690498311
# Overlap  = 0.827413653180
#
# Restart 1
# Energy   = -4.255789342854
# Fidelity = 0.996359009005
# Overlap  = 0.805724871111
#
# Restart 2
# Energy   = -4.258911412266
# Fidelity = 0.997118049832
# Overlap  = 0.809338193759
#
# Restart 3
# Energy   = -4.259262256561
# Fidelity = 0.997093996107
# Overlap  = 0.807506180411
#
# Restart 4
# Energy   = -4.251715880781
# Fidelity = 0.995732059104
# Overlap  = 0.804065176805
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.274795097421
# Fidelity = 0.999875018566
# Overlap  = 0.999861926222
#
# Restart 1
# Energy   = -4.257755436860
# Fidelity = 0.996699649140
# Overlap  = 0.997140940465
#
# Restart 2
# Energy   = -4.257410019334
# Fidelity = 0.996923901229
# Overlap  = 0.997420401301
#
# Restart 3
# Energy   = -4.246561789895
# Fidelity = 0.993286075557
# Overlap  = 0.994361011362
#
# Restart 4
# Energy   = -4.254856032496
# Fidelity = 0.996044099531
# Overlap  = 0.996799556604
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.274795097421
# Energy error     : 1.218696e-03
# Fidelity         : 0.999875018566
# Tracking overlap : 0.999861926222
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.446913452821
# Fidelity = 0.999758769895
# Overlap  = 0.906044084047
#
# Restart 1
# Energy   = -3.444666299657
# Fidelity = 0.999483781464
# Overlap  = 0.901430246296
#
# Restart 2
# Energy   = -3.445074403013
# Fidelity = 0.999549750830
# Overlap  = 0.902024203582
#
# Restart 3
# Energy   = -3.444325225521
# Fidelity = 0.999464794387
# Overlap  = 0.904039675990
#
# Restart 4
# Energy   = -3.445359436277
# Fidelity = 0.999582660814
# Overlap  = 0.901933135907
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.448211447486
# Fidelity = 0.999951911400
# Overlap  = 0.999767016832
#
# Restart 1
# Energy   = -3.445004139322
# Fidelity = 0.999552886734
# Overlap  = 0.999591189385
#
# Restart 2
# Energy   = -3.444529264455
# Fidelity = 0.999476093850
# Overlap  = 0.999473947013
#
# Restart 3
# Energy   = -3.445021916138
# Fidelity = 0.999553886014
# Overlap  = 0.999623640318
#
# Restart 4
# Energy   = -3.443650386152
# Fidelity = 0.999335468886
# Overlap  = 0.999553889791
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.448211447486
# Energy error     : 4.689379e-04
# Fidelity         : 0.999951911400
# Tracking overlap : 0.999767016832
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.859944931652
# Fidelity = 0.999897340573
# Overlap  = 0.942828471380
#
# Restart 1
# Energy   = -2.854009185467
# Fidelity = 0.998912454802
# Overlap  = 0.942851755175
#
# Restart 2
# Energy   = -2.855652011328
# Fidelity = 0.999262292472
# Overlap  = 0.942763565123
#
# Restart 3
# Energy   = -2.855936480120
# Fidelity = 0.999256051060
# Overlap  = 0.941407773109
#
# Restart 4
# Energy   = -2.854595303594
# Fidelity = 0.998963245174
# Overlap  = 0.941714914835
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.860265395751
# Fidelity = 0.999942813605
# Overlap  = 0.999961656552
#
# Restart 1
# Energy   = -2.852799434269
# Fidelity = 0.998853330386
# Overlap  = 0.999003916057
#
# Restart 2
# Energy   = -2.854595160030
# Fidelity = 0.998950328792
# Overlap  = 0.999111434684
#
# Restart 3
# Energy   = -2.857071065172
# Fidelity = 0.999481724903
# Overlap  = 0.999519645232
#
# Restart 4
# Energy   = -2.850276127666
# Fidelity = 0.998246279706
# Overlap  = 0.998413649330
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.860265395751
# Energy error     : 5.668694e-04
# Fidelity         : 0.999942813605
# Tracking overlap : 0.999961656552
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.418768193291
# Fidelity = 0.999858840748
# Overlap  = 0.962410693559
#
# Restart 1
# Energy   = -2.412294381916
# Fidelity = 0.998813124303
# Overlap  = 0.959821101525
#
# Restart 2
# Energy   = -2.411731190750
# Fidelity = 0.998728271402
# Overlap  = 0.959136875581
#
# Restart 3
# Energy   = -2.411776201511
# Fidelity = 0.998771171132
# Overlap  = 0.959925976562
#
# Restart 4
# Energy   = -2.409079198827
# Fidelity = 0.998278325168
# Overlap  = 0.958667208295
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.418989014680
# Fidelity = 0.999878487728
# Overlap  = 0.999980899103
#
# Restart 1
# Energy   = -2.408446326811
# Fidelity = 0.998309088606
# Overlap  = 0.998477406786
#
# Restart 2
# Energy   = -2.409690670485
# Fidelity = 0.998384391277
# Overlap  = 0.998539530346
#
# Restart 3
# Energy   = -2.409402208690
# Fidelity = 0.998358187149
# Overlap  = 0.998565886199
#
# Restart 4
# Energy   = -2.409354376981
# Fidelity = 0.998359401973
# Overlap  = 0.998535284679
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.418989014680
# Energy error     : 1.101515e-03
# Fidelity         : 0.999878487728
# Tracking overlap : 0.999980899103
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.074852081455
# Fidelity = 0.999843312561
# Overlap  = 0.973765731196
#
# Restart 1
# Energy   = -2.066470534997
# Fidelity = 0.998548562584
# Overlap  = 0.969777581321
#
# Restart 2
# Energy   = -2.066239604672
# Fidelity = 0.998548047811
# Overlap  = 0.969656683500
#
# Restart 3
# Energy   = -2.066281736661
# Fidelity = 0.998558032558
# Overlap  = 0.969781702656
#
# Restart 4
# Energy   = -2.066568870607
# Fidelity = 0.998568128840
# Overlap  = 0.969956664955
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.075156802461
# Fidelity = 0.999872749632
# Overlap  = 0.999968099043
#
# Restart 1
# Energy   = -2.066638020885
# Fidelity = 0.998582304017
# Overlap  = 0.998824266982
#
# Restart 2
# Energy   = -2.066490293517
# Fidelity = 0.998557108869
# Overlap  = 0.998794268589
#
# Restart 3
# Energy   = -2.066475391601
# Fidelity = 0.998542645195
# Overlap  = 0.998784938251
#
# Restart 4
# Energy   = -2.066924723021
# Fidelity = 0.998647410169
# Overlap  = 0.998858760853
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.075156802461
# Energy error     : 1.155765e-03
# Fidelity         : 0.999872749632
# Tracking overlap : 0.999968099043
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.798940325434
# Fidelity = 0.999877213767
# Overlap  = 0.981099650954
#
# Restart 1
# Energy   = -1.762208353354
# Fidelity = 0.989802983552
# Overlap  = 0.962166656317
#
# Restart 2
# Energy   = -1.792936819476
# Fidelity = 0.999011509601
# Overlap  = 0.977820236250
#
# Restart 3
# Energy   = -1.792853075505
# Fidelity = 0.998994500174
# Overlap  = 0.978058421512
#
# Restart 4
# Energy   = -1.793010184644
# Fidelity = 0.999030383203
# Overlap  = 0.977966104171
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.799002014830
# Fidelity = 0.999885456689
# Overlap  = 0.999990984970
#
# Restart 1
# Energy   = -1.792900431242
# Fidelity = 0.999002598461
# Overlap  = 0.999179336297
#
# Restart 2
# Energy   = -1.792804614510
# Fidelity = 0.999010436029
# Overlap  = 0.999186450763
#
# Restart 3
# Energy   = -1.730170201743
# Fidelity = 0.980041006107
# Overlap  = 0.980595536548
#
# Restart 4
# Energy   = -1.730158368950
# Fidelity = 0.980051683775
# Overlap  = 0.980628012135
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.799002014830
# Energy error     : 1.071251e-03
# Fidelity         : 0.999885456689
# Tracking overlap : 0.999990984970
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Strong SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -20.7773284453      -20.7658972317      1.1431e-02        0.9988387201      0.9992598667      4
# 0.3111      -12.8364411428      -12.8215555003      1.4886e-02        0.9972022787      0.9990210277      4
# 0.5222      -7.7307163648       -7.6928487140       3.7868e-02        0.9925350145      0.9947965056      4
# 0.7333      -5.5381488307       -5.5244184565       1.3730e-02        0.9979279216      0.9994860050      4
# 0.9444      -4.2760137929       -4.2747950974       1.2187e-03        0.9998750186      0.9998619262      4
# 1.1556      -3.4486803854       -3.4482114475       4.6894e-04        0.9999519114      0.9997670168      4
# 1.3667      -2.8608322652       -2.8602653958       5.6687e-04        0.9999428136      0.9999616566      4
# 1.5778      -2.4200905293       -2.4189890147       1.1015e-03        0.9998784877      0.9999808991      4
# 1.7889      -2.0763125676       -2.0751568025       1.1558e-03        0.9998727496      0.9999680990      4
# 2.0000      -1.8000732662       -1.7990020148       1.0713e-03        0.9998854567      0.9999909850      4

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#
plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HVA_Floc vs lambda different f.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    
    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,
        'psi_vqe': psi_vqe,
        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119084
# T = 2     Fidelity = 0.99733169
# T = 5     Fidelity = 0.99892098
# T = 10    Fidelity = 0.99960326
# T = 20    Fidelity = 0.99995399
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98267668
# T = 2     Fidelity = 0.99772053
# T = 5     Fidelity = 0.99899484
# T = 10    Fidelity = 0.99966134
# T = 20    Fidelity = 0.99995768
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98393754
# T = 2     Fidelity = 0.99802299
# T = 5     Fidelity = 0.99905445
# T = 10    Fidelity = 0.99971625
# T = 20    Fidelity = 0.99994925
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98503479
# T = 2     Fidelity = 0.99826481
# T = 5     Fidelity = 0.99910726
# T = 10    Fidelity = 0.99976690
# T = 20    Fidelity = 0.99993987
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98601230
# T = 2     Fidelity = 0.99846667
# T = 5     Fidelity = 0.99916083
# T = 10    Fidelity = 0.99981467
# T = 20    Fidelity = 0.99993836
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98683832
# T = 2     Fidelity = 0.99861350
# T = 5     Fidelity = 0.99919354
# T = 10    Fidelity = 0.99984257
# T = 20    Fidelity = 0.99993213
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98763202
# T = 2     Fidelity = 0.99876483
# T = 5     Fidelity = 0.99925451
# T = 10    Fidelity = 0.99988708
# T = 20    Fidelity = 0.99995175
#
# Minimum T for Fidelity >= 0.9999 : 20
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98831066
# T = 2     Fidelity = 0.99887446
# T = 5     Fidelity = 0.99929626
# T = 10    Fidelity = 0.99991191
#
# Minimum T for Fidelity >= 0.9999 : 10
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893526
# T = 2     Fidelity = 0.99896902
# T = 5     Fidelity = 0.99933715
# T = 10    Fidelity = 0.99992823
#
# Minimum T for Fidelity >= 0.9999 : 10
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98950678
# T = 2     Fidelity = 0.99905227
# T = 5     Fidelity = 0.99938171
# T = 10    Fidelity = 0.99994438
#
# Minimum T for Fidelity >= 0.9999 : 10
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00037791
# T = 10    Fidelity = 0.00053374
# T = 20    Fidelity = 0.01187947
# T = 30    Fidelity = 0.08170004
# T = 40    Fidelity = 0.18827948
# T = 50    Fidelity = 0.42858830
# T = 75    Fidelity = 0.56666756
# T = 100   Fidelity = 0.72908483
# T = 125   Fidelity = 0.80759415
# T = 150   Fidelity = 0.83697377
# T = 175   Fidelity = 0.90620500
# T = 200   Fidelity = 0.91963106
# T = 225   Fidelity = 0.96679845
# T = 250   Fidelity = 0.89099130
# T = 275   Fidelity = 0.96868830
# T = 300   Fidelity = 0.85608733
# T = 400   Fidelity = 0.98034882
# T = 500   Fidelity = 0.96074902
# T = 600   Fidelity = 0.95874425
# T = 700   Fidelity = 0.62924991
# T = 800   Fidelity = 0.83500416
# T = 900   Fidelity = 0.82244439
# T = 1000  Fidelity = 0.66473938
# T = 1010  Fidelity = 0.57975441
# T = 1020  Fidelity = 0.61895946
# T = 1030  Fidelity = 0.69809818
# T = 1040  Fidelity = 0.72186045
# T = 1050  Fidelity = 0.78746415
# T = 1060  Fidelity = 0.91750247
# T = 1070  Fidelity = 0.77634480
# T = 1080  Fidelity = 0.78829968
# T = 1090  Fidelity = 0.71282130
# T = 1100  Fidelity = 0.38123513
# T = 1200  Fidelity = 0.59310985
# T = 1300  Fidelity = 0.48376217
# T = 1400  Fidelity = 0.71883306
# T = 1500  Fidelity = 0.46497681
# T = 2000  Fidelity = 0.93569986
# T = 2100  Fidelity = 0.70825747
# T = 2110  Fidelity = 0.56794962
# T = 2120  Fidelity = 0.47374244
# T = 2130  Fidelity = 0.39808184
# T = 2140  Fidelity = 0.49663587
# T = 2150  Fidelity = 0.41777580
# T = 2160  Fidelity = 0.63062780
# T = 2170  Fidelity = 0.52254514
# T = 2180  Fidelity = 0.49493303
# T = 2190  Fidelity = 0.50066132
# T = 2200  Fidelity = 0.35809275
# T = 2300  Fidelity = 0.77497657
# T = 2400  Fidelity = 0.21843102
# T = 2500  Fidelity = 0.75783321
# T = 2600  Fidelity = 0.43609485
# T = 2700  Fidelity = 0.55768753
# T = 2800  Fidelity = 0.85260251
# T = 2900  Fidelity = 0.64773486
# T = 3000  Fidelity = 0.82649679
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00976726e+00
# P0     = 0.82649679
# P1     = 0.05946723
# P0+P1  = 0.88596402
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000008
# T = 2     Fidelity = 0.00000024
# T = 5     Fidelity = 0.00050030
# T = 10    Fidelity = 0.06610488
# T = 20    Fidelity = 0.21811763
# T = 30    Fidelity = 0.62677872
# T = 40    Fidelity = 0.35252836
# T = 50    Fidelity = 0.78555961
# T = 75    Fidelity = 0.74616869
# T = 100   Fidelity = 0.80036746
# T = 125   Fidelity = 0.88016803
# T = 150   Fidelity = 0.88276620
# T = 175   Fidelity = 0.90400726
# T = 200   Fidelity = 0.92882490
# T = 225   Fidelity = 0.93702490
# T = 250   Fidelity = 0.94673590
# T = 275   Fidelity = 0.95265694
# T = 300   Fidelity = 0.94909942
# T = 400   Fidelity = 0.97341425
# T = 500   Fidelity = 0.97435837
# T = 600   Fidelity = 0.82378472
# T = 700   Fidelity = 0.80834085
# T = 800   Fidelity = 0.86324893
# T = 900   Fidelity = 0.71384457
# T = 1000  Fidelity = 0.76418617
# T = 1010  Fidelity = 0.87914884
# T = 1020  Fidelity = 0.85045820
# T = 1030  Fidelity = 0.91394750
# T = 1040  Fidelity = 0.84197142
# T = 1050  Fidelity = 0.86035011
# T = 1060  Fidelity = 0.74362529
# T = 1070  Fidelity = 0.78305571
# T = 1080  Fidelity = 0.52765097
# T = 1090  Fidelity = 0.68711644
# T = 1100  Fidelity = 0.54408313
# T = 1200  Fidelity = 0.78443201
# T = 1300  Fidelity = 0.82461823
# T = 1400  Fidelity = 0.93757345
# T = 1500  Fidelity = 0.85699786
# T = 2000  Fidelity = 0.59257076
# T = 2100  Fidelity = 0.60261647
# T = 2110  Fidelity = 0.66897665
# T = 2120  Fidelity = 0.81137214
# T = 2130  Fidelity = 0.95991601
# T = 2140  Fidelity = 0.76017361
# T = 2150  Fidelity = 0.82795610
# T = 2160  Fidelity = 0.89041699
# T = 2170  Fidelity = 0.59000327
# T = 2180  Fidelity = 0.89683018
# T = 2190  Fidelity = 0.58096182
# T = 2200  Fidelity = 0.48305478
# T = 2300  Fidelity = 0.49573996
# T = 2400  Fidelity = 0.66633764
# T = 2500  Fidelity = 0.32064057
# T = 2600  Fidelity = 0.91604127
# T = 2700  Fidelity = 0.85405196
# T = 2800  Fidelity = 0.85913857
# T = 2900  Fidelity = 0.83889195
# T = 3000  Fidelity = 0.87770550
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02946706e+00
# P0     = 0.87770550
# P1     = 0.01233094
# P0+P1  = 0.89003644
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00004060
# T = 2     Fidelity = 0.00033265
# T = 5     Fidelity = 0.01949447
# T = 10    Fidelity = 0.21353929
# T = 20    Fidelity = 0.59035615
# T = 30    Fidelity = 0.65223134
# T = 40    Fidelity = 0.78495401
# T = 50    Fidelity = 0.81190974
# T = 75    Fidelity = 0.91757068
# T = 100   Fidelity = 0.95844857
# T = 125   Fidelity = 0.97474873
# T = 150   Fidelity = 0.98240475
# T = 175   Fidelity = 0.98667512
# T = 200   Fidelity = 0.98547677
# T = 225   Fidelity = 0.98770530
# T = 250   Fidelity = 0.98641676
# T = 275   Fidelity = 0.97924129
# T = 300   Fidelity = 0.97988720
# T = 400   Fidelity = 0.96794444
# T = 500   Fidelity = 0.92274939
# T = 600   Fidelity = 0.88800836
# T = 700   Fidelity = 0.93564154
# T = 800   Fidelity = 0.90167284
# T = 900   Fidelity = 0.86044855
# T = 1000  Fidelity = 0.73951124
# T = 1010  Fidelity = 0.65473790
# T = 1020  Fidelity = 0.86814662
# T = 1030  Fidelity = 0.53714212
# T = 1040  Fidelity = 0.93942151
# T = 1050  Fidelity = 0.68918462
# T = 1060  Fidelity = 0.83378494
# T = 1070  Fidelity = 0.92926614
# T = 1080  Fidelity = 0.78252880
# T = 1090  Fidelity = 0.97851158
# T = 1100  Fidelity = 0.92779290
# T = 1200  Fidelity = 0.92923341
# T = 1300  Fidelity = 0.91658846
# T = 1400  Fidelity = 0.92231527
# T = 1500  Fidelity = 0.95587550
# T = 2000  Fidelity = 0.85779254
# T = 2100  Fidelity = 0.81172641
# T = 2110  Fidelity = 0.70124858
# T = 2120  Fidelity = 0.86554017
# T = 2130  Fidelity = 0.93221276
# T = 2140  Fidelity = 0.85986509
# T = 2150  Fidelity = 0.87868569
# T = 2160  Fidelity = 0.73751432
# T = 2170  Fidelity = 0.73413602
# T = 2180  Fidelity = 0.78874940
# T = 2190  Fidelity = 0.76345247
# T = 2200  Fidelity = 0.67825993
# T = 2300  Fidelity = 0.72728064
# T = 2400  Fidelity = 0.86410826
# T = 2500  Fidelity = 0.86342134
# T = 2600  Fidelity = 0.77595504
# T = 2700  Fidelity = 0.93897112
# T = 2800  Fidelity = 0.96365549
# T = 2900  Fidelity = 0.96127017
# T = 3000  Fidelity = 0.94085933
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04808582e+00
# P0     = 0.94085933
# P1     = 0.00088981
# P0+P1  = 0.94174914
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00124556
# T = 2     Fidelity = 0.00504733
# T = 5     Fidelity = 0.06226612
# T = 10    Fidelity = 0.27833534
# T = 20    Fidelity = 0.67766072
# T = 30    Fidelity = 0.73583731
# T = 40    Fidelity = 0.81680553
# T = 50    Fidelity = 0.88551270
# T = 75    Fidelity = 0.95204087
# T = 100   Fidelity = 0.97961520
# T = 125   Fidelity = 0.99007593
# T = 150   Fidelity = 0.99401165
# T = 175   Fidelity = 0.99549005
# T = 200   Fidelity = 0.99486726
# T = 225   Fidelity = 0.99332700
# T = 250   Fidelity = 0.99349310
# T = 275   Fidelity = 0.98676269
# T = 300   Fidelity = 0.99094746
# T = 400   Fidelity = 0.98096618
# T = 500   Fidelity = 0.98588855
# T = 600   Fidelity = 0.91099342
# T = 700   Fidelity = 0.90949631
# T = 800   Fidelity = 0.94728710
# T = 900   Fidelity = 0.97710500
# T = 1000  Fidelity = 0.88765182
# T = 1010  Fidelity = 0.94406970
# T = 1020  Fidelity = 0.94079492
# T = 1030  Fidelity = 0.98111918
# T = 1040  Fidelity = 0.97631958
# T = 1050  Fidelity = 0.98253258
# T = 1060  Fidelity = 0.97223030
# T = 1070  Fidelity = 0.97719712
# T = 1080  Fidelity = 0.95778165
# T = 1090  Fidelity = 0.97828227
# T = 1100  Fidelity = 0.96692575
# T = 1200  Fidelity = 0.97959515
# T = 1300  Fidelity = 0.98466445
# T = 1400  Fidelity = 0.94162098
# T = 1500  Fidelity = 0.98029845
# T = 2000  Fidelity = 0.90364158
# T = 2100  Fidelity = 0.95880797
# T = 2110  Fidelity = 0.97410254
# T = 2120  Fidelity = 0.97654443
# T = 2130  Fidelity = 0.93812888
# T = 2140  Fidelity = 0.93967342
# T = 2150  Fidelity = 0.94761136
# T = 2160  Fidelity = 0.89635993
# T = 2170  Fidelity = 0.85969431
# T = 2180  Fidelity = 0.86280720
# T = 2190  Fidelity = 0.79010293
# T = 2200  Fidelity = 0.76979987
# T = 2300  Fidelity = 0.75961835
# T = 2400  Fidelity = 0.89580336
# T = 2500  Fidelity = 0.96351495
# T = 2600  Fidelity = 0.96924027
# T = 2700  Fidelity = 0.87983003
# T = 2800  Fidelity = 0.90909309
# T = 2900  Fidelity = 0.88409272
# T = 3000  Fidelity = 0.93061020
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06578123e+00
# P0     = 0.93061020
# P1     = 0.00315288
# P0+P1  = 0.93376309
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00858792
# T = 2     Fidelity = 0.02367801
# T = 5     Fidelity = 0.12581792
# T = 10    Fidelity = 0.34189314
# T = 20    Fidelity = 0.66990160
# T = 30    Fidelity = 0.79869800
# T = 40    Fidelity = 0.85967636
# T = 50    Fidelity = 0.90928213
# T = 75    Fidelity = 0.97005137
# T = 100   Fidelity = 0.98908016
# T = 125   Fidelity = 0.99562176
# T = 150   Fidelity = 0.99794776
# T = 175   Fidelity = 0.99834841
# T = 200   Fidelity = 0.99732663
# T = 225   Fidelity = 0.99704568
# T = 250   Fidelity = 0.99604005
# T = 275   Fidelity = 0.99231622
# T = 300   Fidelity = 0.99202218
# T = 400   Fidelity = 0.97806451
# T = 500   Fidelity = 0.98900379
# T = 600   Fidelity = 0.85485838
# T = 700   Fidelity = 0.97912045
# T = 800   Fidelity = 0.98638894
# T = 900   Fidelity = 0.95365790
# T = 1000  Fidelity = 0.96700419
# T = 1010  Fidelity = 0.99219574
# T = 1020  Fidelity = 0.99030777
# T = 1030  Fidelity = 0.98631048
# T = 1040  Fidelity = 0.98182089
# T = 1050  Fidelity = 0.99194226
# T = 1060  Fidelity = 0.98047962
# T = 1070  Fidelity = 0.99014832
# T = 1080  Fidelity = 0.98480507
# T = 1090  Fidelity = 0.98450147
# T = 1100  Fidelity = 0.98777402
# T = 1200  Fidelity = 0.89525462
# T = 1300  Fidelity = 0.98910990
# T = 1400  Fidelity = 0.97943086
# T = 1500  Fidelity = 0.97243555
# T = 2000  Fidelity = 0.96488545
# T = 2100  Fidelity = 0.96940209
# T = 2110  Fidelity = 0.96096859
# T = 2120  Fidelity = 0.98123334
# T = 2130  Fidelity = 0.97865350
# T = 2140  Fidelity = 0.98073344
# T = 2150  Fidelity = 0.97929977
# T = 2160  Fidelity = 0.96791389
# T = 2170  Fidelity = 0.95601151
# T = 2180  Fidelity = 0.94316160
# T = 2190  Fidelity = 0.92131419
# T = 2200  Fidelity = 0.88416016
# T = 2300  Fidelity = 0.82433336
# T = 2400  Fidelity = 0.88858123
# T = 2500  Fidelity = 0.95580833
# T = 2600  Fidelity = 0.98013105
# T = 2700  Fidelity = 0.97772729
# T = 2800  Fidelity = 0.94379361
# T = 2900  Fidelity = 0.95987063
# T = 3000  Fidelity = 0.98120159
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08267455e+00
# P0     = 0.98120159
# P1     = 0.00250965
# P0+P1  = 0.98371124
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03449033
# T = 2     Fidelity = 0.07384261
# T = 5     Fidelity = 0.22313476
# T = 10    Fidelity = 0.42842247
# T = 20    Fidelity = 0.67800999
# T = 30    Fidelity = 0.79962657
# T = 40    Fidelity = 0.86880615
# T = 50    Fidelity = 0.91619201
# T = 75    Fidelity = 0.97782755
# T = 100   Fidelity = 0.99440207
# T = 125   Fidelity = 0.99662726
# T = 150   Fidelity = 0.99662549
# T = 175   Fidelity = 0.99721254
# T = 200   Fidelity = 0.99609926
# T = 225   Fidelity = 0.99636758
# T = 250   Fidelity = 0.99378250
# T = 275   Fidelity = 0.99323218
# T = 300   Fidelity = 0.99231553
# T = 400   Fidelity = 0.98909285
# T = 500   Fidelity = 0.98652751
# T = 600   Fidelity = 0.92156067
# T = 700   Fidelity = 0.97723416
# T = 800   Fidelity = 0.97640502
# T = 900   Fidelity = 0.95672854
# T = 1000  Fidelity = 0.93617578
# T = 1010  Fidelity = 0.96438607
# T = 1020  Fidelity = 0.95371635
# T = 1030  Fidelity = 0.96768679
# T = 1040  Fidelity = 0.95829959
# T = 1050  Fidelity = 0.97355243
# T = 1060  Fidelity = 0.97946584
# T = 1070  Fidelity = 0.97991996
# T = 1080  Fidelity = 0.96978988
# T = 1090  Fidelity = 0.97655846
# T = 1100  Fidelity = 0.97491541
# T = 1200  Fidelity = 0.97350818
# T = 1300  Fidelity = 0.95984993
# T = 1400  Fidelity = 0.98754629
# T = 1500  Fidelity = 0.97677436
# T = 2000  Fidelity = 0.97204564
# T = 2100  Fidelity = 0.90066097
# T = 2110  Fidelity = 0.92933840
# T = 2120  Fidelity = 0.94715797
# T = 2130  Fidelity = 0.92723321
# T = 2140  Fidelity = 0.97078784
# T = 2150  Fidelity = 0.97791795
# T = 2160  Fidelity = 0.98189081
# T = 2170  Fidelity = 0.95761438
# T = 2180  Fidelity = 0.96527833
# T = 2190  Fidelity = 0.97445715
# T = 2200  Fidelity = 0.96151294
# T = 2300  Fidelity = 0.85015706
# T = 2400  Fidelity = 0.92261987
# T = 2500  Fidelity = 0.96186343
# T = 2600  Fidelity = 0.97264381
# T = 2700  Fidelity = 0.97950165
# T = 2800  Fidelity = 0.91095867
# T = 2900  Fidelity = 0.95304691
# T = 3000  Fidelity = 0.98132620
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.09886174e+00
# P0     = 0.98132620
# P1     = 0.00373926
# P0+P1  = 0.98506545
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09525262
# T = 2     Fidelity = 0.17385284
# T = 5     Fidelity = 0.36562037
# T = 10    Fidelity = 0.55599663
# T = 20    Fidelity = 0.74204363
# T = 30    Fidelity = 0.83128440
# T = 40    Fidelity = 0.88326507
# T = 50    Fidelity = 0.91754723
# T = 75    Fidelity = 0.96553028
# T = 100   Fidelity = 0.98458869
# T = 125   Fidelity = 0.99187737
# T = 150   Fidelity = 0.99434151
# T = 175   Fidelity = 0.99433879
# T = 200   Fidelity = 0.99351514
# T = 225   Fidelity = 0.99373280
# T = 250   Fidelity = 0.99330432
# T = 275   Fidelity = 0.99369814
# T = 300   Fidelity = 0.99021207
# T = 400   Fidelity = 0.98111219
# T = 500   Fidelity = 0.96771325
# T = 600   Fidelity = 0.93032627
# T = 700   Fidelity = 0.98269523
# T = 800   Fidelity = 0.98389058
# T = 900   Fidelity = 0.97663680
# T = 1000  Fidelity = 0.96860874
# T = 1010  Fidelity = 0.98252913
# T = 1020  Fidelity = 0.95903807
# T = 1030  Fidelity = 0.98257267
# T = 1040  Fidelity = 0.97027344
# T = 1050  Fidelity = 0.98194177
# T = 1060  Fidelity = 0.97206701
# T = 1070  Fidelity = 0.98249043
# T = 1080  Fidelity = 0.98185945
# T = 1090  Fidelity = 0.96403142
# T = 1100  Fidelity = 0.97772272
# T = 1200  Fidelity = 0.98692786
# T = 1300  Fidelity = 0.94559255
# T = 1400  Fidelity = 0.96745392
# T = 1500  Fidelity = 0.98892642
# T = 2000  Fidelity = 0.96025054
# T = 2100  Fidelity = 0.97061913
# T = 2110  Fidelity = 0.96411285
# T = 2120  Fidelity = 0.95159177
# T = 2130  Fidelity = 0.93264457
# T = 2140  Fidelity = 0.94086832
# T = 2150  Fidelity = 0.93186744
# T = 2160  Fidelity = 0.94455367
# T = 2170  Fidelity = 0.94051039
# T = 2180  Fidelity = 0.93071913
# T = 2190  Fidelity = 0.97063618
# T = 2200  Fidelity = 0.97932969
# T = 2300  Fidelity = 0.82309109
# T = 2400  Fidelity = 0.88616114
# T = 2500  Fidelity = 0.98053875
# T = 2600  Fidelity = 0.95819290
# T = 2700  Fidelity = 0.98776974
# T = 2800  Fidelity = 0.96041390
# T = 2900  Fidelity = 0.97209615
# T = 3000  Fidelity = 0.96181452
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.11442047e+00
# P0     = 0.96181452
# P1     = 0.00016131
# P0+P1  = 0.96197583
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19182624
# T = 2     Fidelity = 0.31364667
# T = 5     Fidelity = 0.52611261
# T = 10    Fidelity = 0.69247739
# T = 20    Fidelity = 0.82786524
# T = 30    Fidelity = 0.88727877
# T = 40    Fidelity = 0.92149140
# T = 50    Fidelity = 0.94299782
# T = 75    Fidelity = 0.96944583
# T = 100   Fidelity = 0.98210811
# T = 125   Fidelity = 0.98791713
# T = 150   Fidelity = 0.99095292
# T = 175   Fidelity = 0.99264823
# T = 200   Fidelity = 0.99189101
# T = 225   Fidelity = 0.99305914
# T = 250   Fidelity = 0.99449813
# T = 275   Fidelity = 0.99272511
# T = 300   Fidelity = 0.99083863
# T = 400   Fidelity = 0.99194252
# T = 500   Fidelity = 0.98067907
# T = 600   Fidelity = 0.93704785
# T = 700   Fidelity = 0.97531835
# T = 800   Fidelity = 0.97846425
# T = 900   Fidelity = 0.97576674
# T = 1000  Fidelity = 0.97886019
# T = 1010  Fidelity = 0.98582707
# T = 1020  Fidelity = 0.97548199
# T = 1030  Fidelity = 0.98583405
# T = 1040  Fidelity = 0.98445493
# T = 1050  Fidelity = 0.98252337
# T = 1060  Fidelity = 0.97726668
# T = 1070  Fidelity = 0.97725681
# T = 1080  Fidelity = 0.98448257
# T = 1090  Fidelity = 0.98372684
# T = 1100  Fidelity = 0.96923236
# T = 1200  Fidelity = 0.95656337
# T = 1300  Fidelity = 0.98804471
# T = 1400  Fidelity = 0.96757899
# T = 1500  Fidelity = 0.97218864
# T = 2000  Fidelity = 0.96605057
# T = 2100  Fidelity = 0.98052103
# T = 2110  Fidelity = 0.97982317
# T = 2120  Fidelity = 0.97073954
# T = 2130  Fidelity = 0.95462632
# T = 2140  Fidelity = 0.96700307
# T = 2150  Fidelity = 0.95649276
# T = 2160  Fidelity = 0.94911346
# T = 2170  Fidelity = 0.95641062
# T = 2180  Fidelity = 0.95893143
# T = 2190  Fidelity = 0.96097332
# T = 2200  Fidelity = 0.95506873
# T = 2300  Fidelity = 0.94477794
# T = 2400  Fidelity = 0.94967204
# T = 2500  Fidelity = 0.95980641
# T = 2600  Fidelity = 0.96496128
# T = 2700  Fidelity = 0.97826487
# T = 2800  Fidelity = 0.97305891
# T = 2900  Fidelity = 0.98484139
# T = 3000  Fidelity = 0.96322048
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.12941480e+00
# P0     = 0.96322048
# P1     = 0.00042550
# P0+P1  = 0.96364598
#
# Minimum T for Fidelity >= 0.9999 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30151556
# T = 2     Fidelity = 0.45543916
# T = 5     Fidelity = 0.66287789
# T = 10    Fidelity = 0.79945556
# T = 20    Fidelity = 0.89504388
# T = 30    Fidelity = 0.93351125
# T = 40    Fidelity = 0.95496005
# T = 50    Fidelity = 0.96689959
# KeyboardInterrupt

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HVA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)

# %%
#============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_list,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_list,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_list,
    d2M_strong,
    d3M_strong
)

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=1$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)


    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan
    
lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',
        color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=-1$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Start of m0^2=-2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.9999

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.9999 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
# ============================================================


plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.9999$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=-2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ==================optimised==========================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
