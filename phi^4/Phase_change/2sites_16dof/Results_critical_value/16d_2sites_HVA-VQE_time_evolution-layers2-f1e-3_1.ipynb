# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # --------------------------------------------------------

    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 0.00005

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722526063431
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_asymm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------
    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):
            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
# ============================================================
# Hamiltonian Variational Ansatz (HVA) VQE
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit.primitives import StatevectorEstimator
from qiskit_algorithms.optimizers import L_BFGS_B

# ============================================================
# Physics-Inspired HVA for Scalar Field Hamiltonian
# ============================================================

def grouped_hva_symm(nq, layers):

    qc = QuantumCircuit(nq)

    # --------------------------------------------------------
    # Tiny symmetry-breaking seed
    # --------------------------------------------------------

    for q in range(nq):
        qc.ry(0.01, q)

    # --------------------------------------------------------
    # Parameters
    # --------------------------------------------------------

    nparams_per_layer = 2 * nq + 1

    params = ParameterVector(
    "θ",
    nparams_per_layer * layers
    )

    p = 0

    for l in range(layers):
        offset = l * nparams_per_layer
        θx = params[offset : offset + nq]
        

        θz = params[offset + nq : offset + 2 * nq]

        

        θzz = params[offset + 2 * nq]
        

        # ----------------------------------------------------
        # X sector
        # exp(-i θ Σ X)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rx(2 * θx[q], q)

        # ----------------------------------------------------
        # Z sector
        # exp(-i θ Σ Z)
        # ----------------------------------------------------

        for q in range(nq):
            qc.rz(2 * θz[q], q)

        # ----------------------------------------------------
        # ZZ sector
        # exp(-i θ Σ ZZ)
        # ----------------------------------------------------

        # Even bonds
        for q in range(0, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        # Odd bonds
        for q in range(1, nq - 1, 2):

            qc.cx(q, q + 1)
            qc.rz(2 * θzz, q + 1)
            qc.cx(q, q + 1)

        p += 3

    return qc

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Multi-parameter scan
# HVA + warm-start continuation + overlap tracking
# ============================================================

from qiskit.quantum_info import Statevector
from qiskit_algorithms.optimizers import L_BFGS_B

# ------------------------------------------------------------
# Fixed parameters
# ------------------------------------------------------------

nq_site = 4
nqubits = 2 * nq_site

mu = 1.0

# Default depth
layers = 4

# ------------------------------------------------------------
# Number of VQE restarts
# ------------------------------------------------------------

n_restarts = 5

# ------------------------------------------------------------
# Energy tolerance
# ------------------------------------------------------------

energy_tol = 1e-3

# ------------------------------------------------------------
# Parameter sets
# ------------------------------------------------------------

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
  {
       "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1e-4
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ------------------------------------------------------------
# Lambda values
# ------------------------------------------------------------

lambda_list = np.linspace(0.1, 2.0, 10)

# ------------------------------------------------------------
# Storage
# ------------------------------------------------------------

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2 = params["mI2"]
    f = params["f"]

    print("\n")
    print("#" * 80)
    print(f"CASE: {label}")
    print(f"mI² = {mI2},  f = {f}")
    print("#" * 80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None
    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "=" * 60)
        print(f"Running λ = {lam:.3f}")
        print("=" * 60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        # ----------------------------------------------------
        # Exact ground state
        # ----------------------------------------------------

        E_exact, psi_exact = exact_ground_state(
            Hloc_sparse
        )

        # ----------------------------------------------------
        # Dense Hamiltonian
        # ----------------------------------------------------

        H_dense = Hloc_sparse.toarray()

        # ----------------------------------------------------
        # Convert to Pauli form
        # ----------------------------------------------------

        H_op = Operator(H_dense)

        H_pauli = SparsePauliOp.from_operator(
            H_op
        )

        # ----------------------------------------------------
        # Remove identity shift
        # ----------------------------------------------------

        coeffs = H_pauli.coeffs
        paulis = H_pauli.paulis

        new_coeffs = []
        new_paulis = []

        identity_shift = 0.0

        for p, c in zip(paulis, coeffs):

            if str(p) == 'I' * nqubits:

                identity_shift += np.real(c)

            else:

                new_paulis.append(p)
                new_coeffs.append(c)

        H_pauli_shifted = SparsePauliOp(
            new_paulis,
            coeffs=new_coeffs
        )

        # ====================================================
        # Adaptive depth near critical region
        # ====================================================

        

        # ====================================================
        # Ansatz
        # ====================================================

        if mI2 < 0:

            ansatz = grouped_hva_asymm(
                nq=nqubits,
                layers=layers
            )

        else:

            ansatz = grouped_hva_symm(
                nq=nqubits,
                layers=layers
            )

        # ----------------------------------------------------
        # Estimator
        # ----------------------------------------------------

        estimator = StatevectorEstimator()

        # ----------------------------------------------------
        # Optimizer
        # ----------------------------------------------------

        optimizer = L_BFGS_B(maxiter=1000)



        
        # ====================================================
        # Weak SSB:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )
        # ====================================================
        # Weak SSB optimized:
        # warm-start + overlap tracking
        # ====================================================

        if mI2 < 0 :

            print(
                "\nRunning HVA-VQE "
                "with warm-start tracking...\n"
            )

            candidate_states = []

            # ------------------------------------------------
            # Multiple restarts
            # ------------------------------------------------

            for trial in range(n_restarts):

                print(f"\nRestart {trial}")

                # --------------------------------------------
                # Initial point
                # --------------------------------------------

                if (
                    trial == 0
                    and previous_optimal_point is not None
                ):

                    initial_point = (
                        previous_optimal_point
                    )

                else:

                    initial_point = (
                        0.01 * np.random.randn(
                            ansatz.num_parameters
                        )
                    )

                # --------------------------------------------
                # VQE
                # --------------------------------------------

                vqe = VQE(
                    estimator=estimator,
                    ansatz=ansatz,
                    optimizer=optimizer,
                    initial_point=initial_point
                )

                result = (
                    vqe.compute_minimum_eigenvalue(
                        H_pauli_shifted
                    )
                )

                # --------------------------------------------
                # Physical energy
                # --------------------------------------------

                E_trial = (
                    result.eigenvalue.real
                    + identity_shift
                )

                # --------------------------------------------
                # Trial circuit
                # --------------------------------------------

                qc_trial = (
                    ansatz.assign_parameters(
                        result.optimal_parameters
                    )
                )

                # --------------------------------------------
                # Trial state
                # --------------------------------------------

                psi_trial = (
                    Statevector.from_instruction(
                        qc_trial
                    ).data
                )

                # --------------------------------------------
                # Fidelity
                # --------------------------------------------

                fidelity_trial = np.abs(
                    np.vdot(
                        psi_exact,
                        psi_trial
                    )
                )**2

                # --------------------------------------------
                # Overlap tracking
                # --------------------------------------------

                if previous_state is None:

                    overlap = 1.0

                else:

                    overlap = np.abs(
                        np.vdot(
                            previous_state,
                            psi_trial
                        )
                    )**2

                print(
                    f"Energy   = {E_trial:.12f}"
                )

                print(
                    f"Fidelity = {fidelity_trial:.12f}"
                )

                print(
                    f"Overlap  = {overlap:.12f}"
                )

                # --------------------------------------------
                # Store candidate
                # --------------------------------------------

                candidate_states.append({

                    "energy": E_trial,
                    "state": psi_trial,
                    "result": result,
                    "fidelity": fidelity_trial,
                    "overlap": overlap

                })

            # ------------------------------------------------
            # Minimum energy
            # ------------------------------------------------

            min_energy = min(
                c["energy"]
                for c in candidate_states
            )

            # ------------------------------------------------
            # Low-energy manifold
            # ------------------------------------------------

            filtered_candidates = [

                c for c in candidate_states

                if (
                    c["energy"] - min_energy
                ) < energy_tol
            ]

            # ------------------------------------------------
            # Select maximum overlap
            # ------------------------------------------------

            best_candidate = max(

                filtered_candidates,

                key=lambda x: x["overlap"]

            )

            # ------------------------------------------------
            # Final selected state
            # ------------------------------------------------

            best_energy = (
                best_candidate["energy"]
            )

            best_state = (
                best_candidate["state"]
            )

            best_result = (
                best_candidate["result"]
            )

            best_fidelity = (
                best_candidate["fidelity"]
            )

            best_overlap = (
                best_candidate["overlap"]
            )

            # ------------------------------------------------
            # Update tracking variables
            # ------------------------------------------------

            previous_state = best_state.copy()

            previous_optimal_point = (
                best_result.optimal_point
            )

        # ====================================================
        # Symmetric + Strong SSB
        # ====================================================

        else:

            print(
                "\nRunning ordinary HVA-VQE...\n"
            )

            initial_point = (
                0.01 * np.random.randn(
                    ansatz.num_parameters
                )
            )

            vqe = VQE(
                estimator=estimator,
                ansatz=ansatz,
                optimizer=optimizer,
                initial_point=initial_point
            )

            result = (
                vqe.compute_minimum_eigenvalue(
                    H_pauli_shifted
                )
            )

            best_energy = (
                result.eigenvalue.real
                + identity_shift
            )

            optimal_circuit = (
                ansatz.assign_parameters(
                    result.optimal_parameters
                )
            )

            best_state = (
                Statevector.from_instruction(
                    optimal_circuit
                ).data
            )

            best_fidelity = np.abs(
                np.vdot(
                    psi_exact,
                    best_state
                )
            )**2

            best_overlap = 1.0

        # ====================================================
        # Final VQE data
        # ====================================================

        E_vqe = best_energy
        F = best_fidelity

        # ====================================================
        # Store results
        # ====================================================

        data = {

            "case": label,

            "lambda": lam,

            "mI2": mI2,

            "f": f,
            'psi_vqe': best_state,

            "E_exact": E_exact,

            "E_vqe": E_vqe,

            "error": abs(
                E_exact - E_vqe
            ),

            "fidelity": F,

            "tracking_overlap": best_overlap,

            "layers": layers
        }

        case_results.append(data)
        all_results.append(data)

        # ====================================================
        # Print
        # ====================================================

        print("\nFINAL SELECTED STATE")

        print(
            f"Exact energy     : "
            f"{E_exact:.12f}"
        )

        print(
            f"VQE energy       : "
            f"{E_vqe:.12f}"
        )

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(
            f"Fidelity         : "
            f"{F:.12f}"
        )

        print(
            f"Tracking overlap : "
            f"{best_overlap:.12f}"
        )

        print(
            f"Layers            : "
            f"{layers}"
        )

        print(
            f"Pauli terms       : "
            f"{len(H_pauli_shifted.paulis)}"
        )

    # ========================================================
    # Summary
    # ========================================================

    print("\n")
    print("=" * 140)
    print(f"SUMMARY : {label}")
    print("=" * 140)

    print(
        f"{'lambda':<12}"
        f"{'Exact E':<20}"
        f"{'VQE E':<20}"
        f"{'Error':<18}"
        f"{'Fidelity':<18}"
        f"{'TrackOverlap':<18}"
        f"{'Layers':<10}"
    )

    print("=" * 140)

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
            f"{r['E_vqe']:<20.10f}"
            f"{r['error']:<18.4e}"
            f"{r['fidelity']:<18.10f}"
            f"{r['tracking_overlap']:<18.10f}"
            f"{r['layers']:<10}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161964956
# Energy error     : 2.367965e-07
# Fidelity         : 0.999999941398
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 106
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018643311088
# Energy error     : 1.883741e-06
# Fidelity         : 0.999999621156
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030500744663
# Energy error     : 1.434869e-06
# Fidelity         : 0.999999811980
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041833932460
# Energy error     : 9.610199e-06
# Fidelity         : 0.999998596509
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052686007492
# Energy error     : 1.463730e-06
# Fidelity         : 0.999999781926
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063137269951
# Energy error     : 3.481181e-06
# Fidelity         : 0.999999491680
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073216784194
# Energy error     : 1.130423e-06
# Fidelity         : 0.999999864948
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082971172066
# Energy error     : 5.020251e-06
# Fidelity         : 0.999999364193
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092429936961
# Energy error     : 1.442885e-05
# Fidelity         : 0.999998147183
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running ordinary HVA-VQE...
#
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101591322278
# Energy error     : 1.893535e-06
# Fidelity         : 0.999999884445
# Tracking overlap : 1.000000000000
# Layers            : 4
# Pauli terms       : 108
#
#
# ============================================================================================================================================
# SUMMARY : Symmetric
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      1.0061617282        1.0061619650        2.3680e-07        0.9999999414      1.0000000000      4
# 0.3111      1.0186414273        1.0186433111        1.8837e-06        0.9999996212      1.0000000000      4
# 0.5222      1.0304993098        1.0305007447        1.4349e-06        0.9999998120      1.0000000000      4
# 0.7333      1.0418243223        1.0418339325        9.6102e-06        0.9999985965      1.0000000000      4
# 0.9444      1.0526845438        1.0526860075        1.4637e-06        0.9999997819      1.0000000000      4
# 1.1556      1.0631337888        1.0631372700        3.4812e-06        0.9999994917      1.0000000000      4
# 1.3667      1.0732156538        1.0732167842        1.1304e-06        0.9999998649      1.0000000000      4
# 1.5778      1.0829661518        1.0829711721        5.0203e-06        0.9999993642      1.0000000000      4
# 1.7889      1.0924155081        1.0924299370        1.4429e-05        0.9999981472      1.0000000000      4
# 2.0000      1.1015894287        1.1015913223        1.8935e-06        0.9999998844      1.0000000000      4
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.063543699764
# Fidelity = 0.999822964165
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.992175747205
# Fidelity = 0.991598009878
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -17.058578907675
# Fidelity = 0.999311002811
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.926078662189
# Fidelity = 0.984331156506
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.995782221987
# Fidelity = 0.992196920692
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -17.064060922893
# Fidelity = 0.999894282175
# Overlap  = 0.999943323938
#
# Restart 1
# Energy   = -17.007700323034
# Fidelity = 0.992319384847
# Overlap  = 0.992109430340
#
# Restart 2
# Energy   = -17.062929423490
# Fidelity = 0.999753045331
# Overlap  = 0.999787003904
#
# Restart 3
# Energy   = -17.033545124770
# Fidelity = 0.995980356095
# Overlap  = 0.996338926276
#
# Restart 4
# Energy   = -17.014668262005
# Fidelity = 0.993020217876
# Overlap  = 0.993301822183
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.064060922893
# Energy error     : 6.324290e-04
# Fidelity         : 0.999894282175
# Tracking overlap : 0.999943323938
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.048828079537
# Fidelity = 0.983351910042
# Overlap  = 0.830854399483
#
# Restart 1
# Energy   = -9.057134924338
# Fidelity = 0.987333239564
# Overlap  = 0.828955889404
#
# Restart 2
# Energy   = -9.042068812044
# Fidelity = 0.985751276153
# Overlap  = 0.836690532779
#
# Restart 3
# Energy   = -9.058022549738
# Fidelity = 0.987884417739
# Overlap  = 0.824763311504
#
# Restart 4
# Energy   = -9.058500049331
# Fidelity = 0.988608549808
# Overlap  = 0.830528658803
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -9.067867869898
# Fidelity = 0.994578754735
# Overlap  = 0.997568966067
#
# Restart 1
# Energy   = -9.005887514175
# Fidelity = 0.969301441545
# Overlap  = 0.986027816337
#
# Restart 2
# Energy   = -9.054893492243
# Fidelity = 0.984876620950
# Overlap  = 0.994591565722
#
# Restart 3
# Energy   = -9.061118025813
# Fidelity = 0.992925394995
# Overlap  = 0.994353157902
#
# Restart 4
# Energy   = -9.057218176654
# Fidelity = 0.988914451162
# Overlap  = 0.999479647367
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.067867869898
# Energy error     : 1.258204e-02
# Fidelity         : 0.994578754735
# Tracking overlap : 0.997568966067
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.668363039246
# Fidelity = 0.981713504650
# Overlap  = 0.069915941062
#
# Restart 1
# Energy   = -4.675763268548
# Fidelity = 0.987084888875
# Overlap  = 0.066404913951
#
# Restart 2
# Energy   = -4.656081834111
# Fidelity = 0.971456902064
# Overlap  = 0.070886834755
#
# Restart 3
# Energy   = -4.657005648621
# Fidelity = 0.972702088342
# Overlap  = 0.072230621492
#
# Restart 4
# Energy   = -4.672753164233
# Fidelity = 0.985159219554
# Overlap  = 0.067860248760
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.685148712803
# Fidelity = 0.992232504397
# Overlap  = 0.995857739096
#
# Restart 1
# Energy   = -4.670122183523
# Fidelity = 0.983978441478
# Overlap  = 0.994697027086
#
# Restart 2
# Energy   = -4.676049382080
# Fidelity = 0.988285034437
# Overlap  = 0.997428861143
#
# Restart 3
# Energy   = -4.661279395453
# Fidelity = 0.975734882191
# Overlap  = 0.993345676779
#
# Restart 4
# Energy   = -4.655744056245
# Fidelity = 0.970788303947
# Overlap  = 0.989718202916
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.685148712803
# Energy error     : 1.604626e-02
# Fidelity         : 0.992232504397
# Tracking overlap : 0.995857739096
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.005436505193
# Fidelity = 0.998167357154
# Overlap  = 0.654619124229
#
# Restart 1
# Energy   = -2.993096057537
# Fidelity = 0.992872392318
# Overlap  = 0.642675551400
#
# Restart 2
# Energy   = -2.970520301942
# Fidelity = 0.979817868515
# Overlap  = 0.599533264935
#
# Restart 3
# Energy   = -2.993715706538
# Fidelity = 0.993730024660
# Overlap  = 0.644338679061
#
# Restart 4
# Energy   = -2.973945425239
# Fidelity = 0.982137016282
# Overlap  = 0.591966582313
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.006959641592
# Fidelity = 0.998727939195
# Overlap  = 0.999394151893
#
# Restart 1
# Energy   = -2.984486402929
# Fidelity = 0.991024225901
# Overlap  = 0.992774046330
#
# Restart 2
# Energy   = -2.995798675659
# Fidelity = 0.994317219598
# Overlap  = 0.996832211693
#
# Restart 3
# Energy   = -3.002206201690
# Fidelity = 0.996623389639
# Overlap  = 0.997755290796
#
# Restart 4
# Energy   = -2.979119561187
# Fidelity = 0.983858439372
# Overlap  = 0.984633931246
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.006959641592
# Energy error     : 4.571710e-03
# Fidelity         : 0.998727939195
# Tracking overlap : 0.999394151893
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.082593792181
# Fidelity = 0.999830434110
# Overlap  = 0.836197781091
#
# Restart 1
# Energy   = -2.078876572751
# Fidelity = 0.998812078243
# Overlap  = 0.825359681874
#
# Restart 2
# Energy   = -2.076674926867
# Fidelity = 0.998315763154
# Overlap  = 0.822441802799
#
# Restart 3
# Energy   = -2.076825643292
# Fidelity = 0.997470153178
# Overlap  = 0.827100533148
#
# Restart 4
# Energy   = -2.076162485417
# Fidelity = 0.994291192998
# Overlap  = 0.832722599801
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.082995045076
# Fidelity = 0.999909509493
# Overlap  = 0.999909238951
#
# Restart 1
# Energy   = -2.069667306608
# Fidelity = 0.991305008599
# Overlap  = 0.991631408768
#
# Restart 2
# Energy   = -2.079271603650
# Fidelity = 0.998966004641
# Overlap  = 0.999111373204
#
# Restart 3
# Energy   = -2.077381788318
# Fidelity = 0.998505009917
# Overlap  = 0.998660954509
#
# Restart 4
# Energy   = -2.078983677186
# Fidelity = 0.998833517642
# Overlap  = 0.998852024355
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.082995045076
# Energy error     : 5.706784e-04
# Fidelity         : 0.999909509493
# Tracking overlap : 0.999909238951
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.502740973527
# Fidelity = 0.999710546117
# Overlap  = 0.896295692251
#
# Restart 1
# Energy   = -1.502680459554
# Fidelity = 0.999738894374
# Overlap  = 0.896330993281
#
# Restart 2
# Energy   = -1.501848330034
# Fidelity = 0.999489589805
# Overlap  = 0.895673107853
#
# Restart 3
# Energy   = -1.502285651526
# Fidelity = 0.999620280844
# Overlap  = 0.896235419890
#
# Restart 4
# Energy   = -1.501190845057
# Fidelity = 0.998532462001
# Overlap  = 0.895647888097
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.503396342391
# Fidelity = 0.999827498715
# Overlap  = 0.999894577868
#
# Restart 1
# Energy   = -1.497035250984
# Fidelity = 0.996266146422
# Overlap  = 0.996605485015
#
# Restart 2
# Energy   = -1.501864215176
# Fidelity = 0.999580441573
# Overlap  = 0.999754530628
#
# Restart 3
# Energy   = -1.502171791980
# Fidelity = 0.999628728904
# Overlap  = 0.999852894322
#
# Restart 4
# Energy   = -1.502187436288
# Fidelity = 0.999499719289
# Overlap  = 0.999604435317
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503396342391
# Energy error     : 1.091530e-03
# Fidelity         : 0.999827498715
# Tracking overlap : 0.999894577868
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.117433381616
# Fidelity = 0.999512617775
# Overlap  = 0.915294164726
#
# Restart 1
# Energy   = -1.115125686575
# Fidelity = 0.999295497573
# Overlap  = 0.915509069936
#
# Restart 2
# Energy   = -1.114646308177
# Fidelity = 0.999259840163
# Overlap  = 0.915465101627
#
# Restart 3
# Energy   = -1.114973471353
# Fidelity = 0.999367848528
# Overlap  = 0.917297328119
#
# Restart 4
# Energy   = -1.107394665947
# Fidelity = 0.994094106700
# Overlap  = 0.910861520421
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.118689566054
# Fidelity = 0.999938808086
# Overlap  = 0.999654553014
#
# Restart 1
# Energy   = -1.114959012176
# Fidelity = 0.999328158654
# Overlap  = 0.999562249577
#
# Restart 2
# Energy   = -1.112164147312
# Fidelity = 0.995738398787
# Overlap  = 0.996740242818
#
# Restart 3
# Energy   = -1.110468349050
# Fidelity = 0.995812631911
# Overlap  = 0.996141215086
#
# Restart 4
# Energy   = -1.114445996575
# Fidelity = 0.999286502470
# Overlap  = 0.999322379387
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118689566054
# Energy error     : 4.101644e-04
# Fidelity         : 0.999938808086
# Tracking overlap : 0.999654553014
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.852939467644
# Fidelity = 0.999950461949
# Overlap  = 0.937669586050
#
# Restart 1
# Energy   = -0.843910217165
# Fidelity = 0.993143842512
# Overlap  = 0.914314189534
#
# Restart 2
# Energy   = -0.840282469466
# Fidelity = 0.990365818553
# Overlap  = 0.901439260445
#
# Restart 3
# Energy   = -0.848436168840
# Fidelity = 0.998770924800
# Overlap  = 0.931291673029
#
# Restart 4
# Energy   = -0.847423297698
# Fidelity = 0.998012399388
# Overlap  = 0.927542339022
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.853004004101
# Fidelity = 0.999953646658
# Overlap  = 0.999987837931
#
# Restart 1
# Energy   = -0.846869749120
# Fidelity = 0.997948230743
# Overlap  = 0.997987050296
#
# Restart 2
# Energy   = -0.845238936047
# Fidelity = 0.994972138414
# Overlap  = 0.994932814647
#
# Restart 3
# Energy   = -0.848600395572
# Fidelity = 0.998915063835
# Overlap  = 0.998980654114
#
# Restart 4
# Energy   = -0.847074777788
# Fidelity = 0.998466468616
# Overlap  = 0.998560819737
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.853004004101
# Energy error     : 3.280499e-04
# Fidelity         : 0.999953646658
# Tracking overlap : 0.999987837931
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663327767466
# Fidelity = 0.999969584922
# Overlap  = 0.959134030805
#
# Restart 1
# Energy   = -0.657337254255
# Fidelity = 0.996144520488
# Overlap  = 0.941988061975
#
# Restart 2
# Energy   = -0.655907307866
# Fidelity = 0.995523093636
# Overlap  = 0.940160535122
#
# Restart 3
# Energy   = -0.660707505611
# Fidelity = 0.999500864787
# Overlap  = 0.955580979716
#
# Restart 4
# Energy   = -0.657988233123
# Fidelity = 0.997302572836
# Overlap  = 0.947524553454
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.663344435942
# Fidelity = 0.999973098783
# Overlap  = 0.999996696168
#
# Restart 1
# Energy   = -0.656436267558
# Fidelity = 0.995967559616
# Overlap  = 0.996277041859
#
# Restart 2
# Energy   = -0.659431712400
# Fidelity = 0.998609520401
# Overlap  = 0.998716312740
#
# Restart 3
# Energy   = -0.660364085329
# Fidelity = 0.999315917773
# Overlap  = 0.999398033003
#
# Restart 4
# Energy   = -0.658820300129
# Fidelity = 0.997826162943
# Overlap  = 0.997945187823
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663344435942
# Energy error     : 2.157056e-04
# Fidelity         : 0.999973098783
# Tracking overlap : 0.999996696168
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.522000120716
# Fidelity = 0.999981949244
# Overlap  = 0.975793261444
#
# Restart 1
# Energy   = -0.517724532738
# Fidelity = 0.997814488288
# Overlap  = 0.966090739180
#
# Restart 2
# Energy   = -0.517151804342
# Fidelity = 0.997205513947
# Overlap  = 0.964055959200
#
# Restart 3
# Energy   = -0.517361277832
# Fidelity = 0.997548220043
# Overlap  = 0.965136972699
#
# Restart 4
# Energy   = -0.517793160362
# Fidelity = 0.997882133526
# Overlap  = 0.966246580603
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.522002795660
# Fidelity = 0.999984269966
# Overlap  = 0.999999190323
#
# Restart 1
# Energy   = -0.517847764677
# Fidelity = 0.997850449223
# Overlap  = 0.998039054800
#
# Restart 2
# Energy   = -0.518117424529
# Fidelity = 0.998090149223
# Overlap  = 0.998252941731
#
# Restart 3
# Energy   = -0.518051988615
# Fidelity = 0.998182166583
# Overlap  = 0.998339954581
#
# Restart 4
# Energy   = -0.517800411960
# Fidelity = 0.997906385693
# Overlap  = 0.998077874259
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.522002795660
# Energy error     : 1.369686e-04
# Fidelity         : 0.999984269966
# Tracking overlap : 0.999999190323
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB optimised
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -17.0646933519      -17.0640609229      6.3243e-04        0.9998942822      0.9999433239      4
# 0.3111      -9.0804499123       -9.0678678699       1.2582e-02        0.9945787547      0.9975689661      4
# 0.5222      -4.7011949726       -4.6851487128       1.6046e-02        0.9922325044      0.9958577391      4
# 0.7333      -3.0115313516       -3.0069596416       4.5717e-03        0.9987279392      0.9993941519      4
# 0.9444      -2.0835657235       -2.0829950451       5.7068e-04        0.9999095095      0.9999092390      4
# 1.1556      -1.5044878727       -1.5033963424       1.0915e-03        0.9998274987      0.9998945779      4
# 1.3667      -1.1190997304       -1.1186895661       4.1016e-04        0.9999388081      0.9996545530      4
# 1.5778      -0.8533320540       -0.8530040041       3.2805e-04        0.9999536467      0.9999878379      4
# 1.7889      -0.6635601415       -0.6633444359       2.1571e-04        0.9999730988      0.9999966962      4
# 2.0000      -0.5221397643       -0.5220027957       1.3697e-04        0.9999842700      0.9999991903      4
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = 0.0001
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.943244209580
# Fidelity = 0.999890736971
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -16.942885732398
# Fidelity = 0.999821519405
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -16.943506228963
# Fidelity = 0.999939723783
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -16.860470099715
# Fidelity = 0.990303827733
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -16.943320069661
# Fidelity = 0.999883014833
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -16.943899436917
# Fidelity = 0.999999317324
# Overlap  = 0.999895196959
#
# Restart 1
# Energy   = -16.913966549868
# Fidelity = 0.995159678466
# Overlap  = 0.994857743035
#
# Restart 2
# Energy   = -16.171461545030
# Fidelity = 0.000019460906
# Overlap  = 0.000034189198
#
# Restart 3
# Energy   = -16.943614214217
# Fidelity = 0.999931696956
# Overlap  = 0.999836214383
#
# Restart 4
# Energy   = -16.875619450668
# Fidelity = 0.991849206922
# Overlap  = 0.992382424830
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902685020
# VQE energy       : -16.943899436917
# Energy error     : 3.248103e-06
# Fidelity         : 0.999999317324
# Tracking overlap : 0.999895196959
# Layers            : 4
# Pauli terms       : 158
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.892068238663
# Fidelity = 0.999998834308
# Overlap  = 0.875684399827
#
# Restart 1
# Energy   = -8.549263855853
# Fidelity = 0.000004409011
# Overlap  = 0.000003513041
#
# Restart 2
# Energy   = -8.891944512890
# Fidelity = 0.999970638554
# Overlap  = 0.875753011722
#
# Restart 3
# Energy   = -8.889749616303
# Fidelity = 0.999311219386
# Overlap  = 0.870453955742
#
# Restart 4
# Energy   = -8.885561629504
# Fidelity = 0.997330303050
# Overlap  = 0.879341471444
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -8.892025574397
# Fidelity = 0.999989495816
# Overlap  = 0.999972254735
#
# Restart 1
# Energy   = -8.891355074987
# Fidelity = 0.999764309062
# Overlap  = 0.999726981907
#
# Restart 2
# Energy   = -8.892034948955
# Fidelity = 0.999994392525
# Overlap  = 0.999971418464
#
# Restart 3
# Energy   = -8.891943462324
# Fidelity = 0.999985479545
# Overlap  = 0.999952994883
#
# Restart 4
# Energy   = -8.892030680803
# Fidelity = 0.999973541113
# Overlap  = 0.999944764279
#
# FINAL SELECTED STATE
# Exact energy     : -8.892069658534
# VQE energy       : -8.892025574397
# Energy error     : 4.408414e-05
# Fidelity         : 0.999989495816
# Tracking overlap : 0.999972254735
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379064379676
# Fidelity = 0.808507697733
# Overlap  = 0.049186024103
#
# Restart 1
# Energy   = -4.377418808373
# Fidelity = 0.010537891409
# Overlap  = 0.000000000045
#
# Restart 2
# Energy   = -4.377409463276
# Fidelity = 0.010491533014
# Overlap  = 0.000000000011
#
# Restart 3
# Energy   = -4.377366995669
# Fidelity = 0.010309538455
# Overlap  = 0.000000000442
#
# Restart 4
# Energy   = -4.377402822013
# Fidelity = 0.010326206825
# Overlap  = 0.000000000013
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.379087263278
# Fidelity = 0.808359186074
# Overlap  = 0.999992622156
#
# Restart 1
# Energy   = -4.377384412190
# Fidelity = 0.010732016052
# Overlap  = 0.000000000725
#
# Restart 2
# Energy   = -4.377373981771
# Fidelity = 0.010812190219
# Overlap  = 0.000000001053
#
# Restart 3
# Energy   = -4.377413496246
# Fidelity = 0.010206337846
# Overlap  = 0.000000000025
#
# Restart 4
# Energy   = -4.377434614952
# Fidelity = 0.010676937032
# Overlap  = 0.000000000187
#
# FINAL SELECTED STATE
# Exact energy     : -4.379329565434
# VQE energy       : -4.379087263278
# Energy error     : 2.423022e-04
# Fidelity         : 0.808359186074
# Tracking overlap : 0.999992622156
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.741412828407
# Fidelity = 0.000017037814
# Overlap  = 0.660563245459
#
# Restart 1
# Energy   = -2.749703214457
# Fidelity = 0.992085510378
# Overlap  = 0.000000001255
#
# Restart 2
# Energy   = -2.749776708081
# Fidelity = 0.991566733708
# Overlap  = 0.000000000670
#
# Restart 3
# Energy   = -2.749758991728
# Fidelity = 0.991749375931
# Overlap  = 0.000000000472
#
# Restart 4
# Energy   = -2.749764700715
# Fidelity = 0.990937446420
# Overlap  = 0.000000000014
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.749737798106
# Fidelity = 0.992282800362
# Overlap  = 0.999963572142
#
# Restart 1
# Energy   = -2.749762074575
# Fidelity = 0.992001900703
# Overlap  = 0.999918512137
#
# Restart 2
# Energy   = -2.749791989349
# Fidelity = 0.992280072627
# Overlap  = 0.999927814692
#
# Restart 3
# Energy   = -2.749767049922
# Fidelity = 0.991108836558
# Overlap  = 0.999880341534
#
# Restart 4
# Energy   = -2.749766098177
# Fidelity = 0.991015231387
# Overlap  = 0.999904108322
#
# FINAL SELECTED STATE
# Exact energy     : -2.749826501443
# VQE energy       : -2.749737798106
# Energy error     : 8.870334e-05
# Fidelity         : 0.992282800362
# Tracking overlap : 0.999963572142
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874667439367
# Fidelity = 0.999727013453
# Overlap  = 0.821144135510
#
# Restart 1
# Energy   = -1.874659620227
# Fidelity = 0.999711866499
# Overlap  = 0.819977670027
#
# Restart 2
# Energy   = -1.874681559263
# Fidelity = 0.999643432748
# Overlap  = 0.820864022617
#
# Restart 3
# Energy   = -1.872632452001
# Fidelity = 0.998829836733
# Overlap  = 0.809106381348
#
# Restart 4
# Energy   = -1.874680268099
# Fidelity = 0.999656139194
# Overlap  = 0.821151709264
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.874694880346
# Fidelity = 0.999691488176
# Overlap  = 0.999993196025
#
# Restart 1
# Energy   = -1.874636039886
# Fidelity = 0.999684524404
# Overlap  = 0.999958913700
#
# Restart 2
# Energy   = -1.874481613450
# Fidelity = 0.999768210222
# Overlap  = 0.999864109555
#
# Restart 3
# Energy   = -1.871559213187
# Fidelity = 0.998983462570
# Overlap  = 0.999265548697
#
# Restart 4
# Energy   = -1.870421529674
# Fidelity = 0.998631093171
# Overlap  = 0.998933881126
#
# FINAL SELECTED STATE
# Exact energy     : -1.874705890824
# VQE energy       : -1.874694880346
# Energy error     : 1.101048e-05
# Fidelity         : 0.999691488176
# Tracking overlap : 0.999993196025
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348795948505
# Fidelity = 0.999963552937
# Overlap  = 0.894818466990
#
# Restart 1
# Energy   = -1.348131229832
# Fidelity = 0.999807192512
# Overlap  = 0.895868303777
#
# Restart 2
# Energy   = -1.348629948465
# Fidelity = 0.999948992975
# Overlap  = 0.895302910269
#
# Restart 3
# Energy   = -1.348168168376
# Fidelity = 0.999783047985
# Overlap  = 0.896303171125
#
# Restart 4
# Energy   = -1.348140742273
# Fidelity = 0.999830986018
# Overlap  = 0.896354558188
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.348220658313
# Fidelity = 0.999867887351
# Overlap  = 0.999958388342
#
# Restart 1
# Energy   = -1.348072205154
# Fidelity = 0.999818723525
# Overlap  = 0.999945167493
#
# Restart 2
# Energy   = -1.348041869277
# Fidelity = 0.999838133008
# Overlap  = 0.999938374485
#
# Restart 3
# Energy   = -1.348246387199
# Fidelity = 0.999818046882
# Overlap  = 0.999952152315
#
# Restart 4
# Energy   = -1.348354239631
# Fidelity = 0.999865978630
# Overlap  = 0.999948696597
#
# FINAL SELECTED STATE
# Exact energy     : -1.348823187245
# VQE energy       : -1.348220658313
# Energy error     : 6.025289e-04
# Fidelity         : 0.999867887351
# Tracking overlap : 0.999958388342
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.007186563183
# Fidelity = 0.999459003672
# Overlap  = 0.935668408777
#
# Restart 1
# Energy   = -1.007193110144
# Fidelity = 0.999431025096
# Overlap  = 0.935539426298
#
# Restart 2
# Energy   = -1.007233974067
# Fidelity = 0.999448100074
# Overlap  = 0.935627059421
#
# Restart 3
# Energy   = -1.007033403961
# Fidelity = 0.999442553932
# Overlap  = 0.935390886057
#
# Restart 4
# Energy   = -1.007139113257
# Fidelity = 0.999438965913
# Overlap  = 0.935384066691
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.008505011862
# Fidelity = 0.999655831505
# Overlap  = 0.999773751526
#
# Restart 1
# Energy   = -1.007333716153
# Fidelity = 0.999467894912
# Overlap  = 0.999921776557
#
# Restart 2
# Energy   = -1.007097639587
# Fidelity = 0.999405117885
# Overlap  = 0.999958469671
#
# Restart 3
# Energy   = -1.007124631425
# Fidelity = 0.999434220142
# Overlap  = 0.999952183384
#
# Restart 4
# Energy   = -1.007155010969
# Fidelity = 0.999447885505
# Overlap  = 0.999975587774
#
# FINAL SELECTED STATE
# Exact energy     : -1.010440164101
# VQE energy       : -1.008505011862
# Energy error     : 1.935152e-03
# Fidelity         : 0.999655831505
# Tracking overlap : 0.999773751526
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.777514919738
# Fidelity = 0.999757970072
# Overlap  = 0.962469482185
#
# Restart 1
# Energy   = -0.775791300433
# Fidelity = 0.999498557394
# Overlap  = 0.961217820313
#
# Restart 2
# Energy   = -0.775873810859
# Fidelity = 0.999504236266
# Overlap  = 0.961173550625
#
# Restart 3
# Energy   = -0.775827879795
# Fidelity = 0.999488678506
# Overlap  = 0.961223406955
#
# Restart 4
# Energy   = -0.775765483605
# Fidelity = 0.999499626150
# Overlap  = 0.961153535277
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.778933800168
# Fidelity = 0.999956509863
# Overlap  = 0.999769722882
#
# Restart 1
# Energy   = -0.775879104050
# Fidelity = 0.999527738581
# Overlap  = 0.999706487570
#
# Restart 2
# Energy   = -0.775806469371
# Fidelity = 0.999490269797
# Overlap  = 0.999733575813
#
# Restart 3
# Energy   = -0.775811263565
# Fidelity = 0.999486720440
# Overlap  = 0.999737843978
#
# Restart 4
# Energy   = -0.775805511663
# Fidelity = 0.999485662989
# Overlap  = 0.999739631070
#
# FINAL SELECTED STATE
# Exact energy     : -0.779140149474
# VQE energy       : -0.778933800168
# Energy error     : 2.063493e-04
# Fidelity         : 0.999956509863
# Tracking overlap : 0.999769722882
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611716518218
# Fidelity = 0.999990513327
# Overlap  = 0.977278941378
#
# Restart 1
# Energy   = -0.609509087234
# Fidelity = 0.999684474823
# Overlap  = 0.975431105033
#
# Restart 2
# Energy   = -0.609520087474
# Fidelity = 0.999682577110
# Overlap  = 0.975453082083
#
# Restart 3
# Energy   = -0.609464566114
# Fidelity = 0.999679674954
# Overlap  = 0.975423561202
#
# Restart 4
# Energy   = -0.609512737454
# Fidelity = 0.999687450789
# Overlap  = 0.975483377339
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.611718706413
# Fidelity = 0.999992655107
# Overlap  = 0.999999653672
#
# Restart 1
# Energy   = -0.609479782658
# Fidelity = 0.999682523198
# Overlap  = 0.999683262362
#
# Restart 2
# Energy   = -0.609484452095
# Fidelity = 0.999685888890
# Overlap  = 0.999680766709
#
# Restart 3
# Energy   = -0.609555882831
# Fidelity = 0.999694294112
# Overlap  = 0.999686370853
#
# Restart 4
# Energy   = -0.609493795882
# Fidelity = 0.999693278917
# Overlap  = 0.999685027506
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723602270
# VQE energy       : -0.611718706413
# Energy error     : 4.895857e-06
# Fidelity         : 0.999992655107
# Tracking overlap : 0.999999653672
# Layers            : 4
# Pauli terms       : 160
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484290534037
# Fidelity = 0.999995677173
# Overlap  = 0.986386391027
#
# Restart 1
# Energy   = -0.483113011457
# Fidelity = 0.999842328507
# Overlap  = 0.985406131999
#
# Restart 2
# Energy   = -0.483111365601
# Fidelity = 0.999844535344
# Overlap  = 0.985394624195
#
# Restart 3
# Energy   = -0.483113318811
# Fidelity = 0.999842694829
# Overlap  = 0.985403763836
#
# Restart 4
# Energy   = -0.483113427540
# Fidelity = 0.999846243957
# Overlap  = 0.985394588031
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -0.484291429065
# Fidelity = 0.999996117958
# Overlap  = 0.999999901321
#
# Restart 1
# Energy   = -0.483115302681
# Fidelity = 0.999847614430
# Overlap  = 0.999842765065
#
# Restart 2
# Energy   = -0.483114620842
# Fidelity = 0.999842786427
# Overlap  = 0.999842576705
#
# Restart 3
# Energy   = -0.483104488396
# Fidelity = 0.999844511141
# Overlap  = 0.999844586532
#
# Restart 4
# Energy   = -0.483112404439
# Fidelity = 0.999843683094
# Overlap  = 0.999843595510
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295546782
# VQE energy       : -0.484291429065
# Energy error     : 4.117717e-06
# Fidelity         : 0.999996117958
# Tracking overlap : 0.999999901321
# Layers            : 4
# Pauli terms       : 160
#
#
# ============================================================================================================================================
# SUMMARY : Weak SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -16.9439026850      -16.9438994369      3.2481e-06        0.9999993173      0.9998951970      4
# 0.3111      -8.8920696585       -8.8920255744       4.4084e-05        0.9999894958      0.9999722547      4
# 0.5222      -4.3793295654       -4.3790872633       2.4230e-04        0.8083591861      0.9999926222      4
# 0.7333      -2.7498265014       -2.7497377981       8.8703e-05        0.9922828004      0.9999635721      4
# 0.9444      -1.8747058908       -1.8746948803       1.1010e-05        0.9996914882      0.9999931960      4
# 1.1556      -1.3488231872       -1.3482206583       6.0253e-04        0.9998678874      0.9999583883      4
# 1.3667      -1.0104401641       -1.0085050119       1.9352e-03        0.9996558315      0.9997737515      4
# 1.5778      -0.7791401495       -0.7789338002       2.0635e-04        0.9999565099      0.9997697229      4
# 1.7889      -0.6117236023       -0.6117187064       4.8959e-06        0.9999926551      0.9999996537      4
# 2.0000      -0.4842955468       -0.4842914291       4.1177e-06        0.9999961180      0.9999999013      4
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.755928430408
# Fidelity = 0.997689914353
# Overlap  = 1.000000000000
#
# Restart 1
# Energy   = -20.746297843512
# Fidelity = 0.996432078653
# Overlap  = 1.000000000000
#
# Restart 2
# Energy   = -20.586074064626
# Fidelity = 0.979507942867
# Overlap  = 1.000000000000
#
# Restart 3
# Energy   = -20.715652702917
# Fidelity = 0.993175905863
# Overlap  = 1.000000000000
#
# Restart 4
# Energy   = -20.738940547718
# Fidelity = 0.995609603629
# Overlap  = 1.000000000000
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -20.761491380852
# Fidelity = 0.998189476588
# Overlap  = 0.999608061017
#
# Restart 1
# Energy   = -20.753777052806
# Fidelity = 0.997339495757
# Overlap  = 0.998842369909
#
# Restart 2
# Energy   = -20.741229261960
# Fidelity = 0.995927451958
# Overlap  = 0.997093770786
#
# Restart 3
# Energy   = -20.736589429219
# Fidelity = 0.994849548420
# Overlap  = 0.997339731636
#
# Restart 4
# Energy   = -20.752824568051
# Fidelity = 0.997052954938
# Overlap  = 0.998565021174
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.761491380852
# Energy error     : 1.583706e-02
# Fidelity         : 0.998189476588
# Tracking overlap : 0.999608061017
# Layers            : 4
# Pauli terms       : 170
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.813339392261
# Fidelity = 0.995558837361
# Overlap  = 0.859064153048
#
# Restart 1
# Energy   = -12.808386007152
# Fidelity = 0.995000147480
# Overlap  = 0.857559428573
#
# Restart 2
# Energy   = -12.814223615199
# Fidelity = 0.995686901930
# Overlap  = 0.855664943519
#
# Restart 3
# Energy   = -12.698591873592
# Fidelity = 0.974239717084
# Overlap  = 0.877758270804
#
# Restart 4
# Energy   = -12.808913873051
# Fidelity = 0.994949341721
# Overlap  = 0.858417066932
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -12.815327823184
# Fidelity = 0.995907566458
# Overlap  = 0.999834463438
#
# Restart 1
# Energy   = -12.810121125718
# Fidelity = 0.995069006278
# Overlap  = 0.999350977211
#
# Restart 2
# Energy   = -12.809746268774
# Fidelity = 0.995020706228
# Overlap  = 0.999522857394
#
# Restart 3
# Energy   = -12.811649908493
# Fidelity = 0.995343253242
# Overlap  = 0.999336295952
#
# Restart 4
# Energy   = -12.809974205472
# Fidelity = 0.995063857521
# Overlap  = 0.999670663982
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.815327823184
# Energy error     : 2.111332e-02
# Fidelity         : 0.995907566458
# Tracking overlap : 0.999834463438
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.628297534089
# Fidelity = 0.976602794548
# Overlap  = 0.174347121150
#
# Restart 1
# Energy   = -7.650786522426
# Fidelity = 0.983267718343
# Overlap  = 0.167186157802
#
# Restart 2
# Energy   = -7.673735417605
# Fidelity = 0.988370959550
# Overlap  = 0.166975296656
#
# Restart 3
# Energy   = -7.618617438906
# Fidelity = 0.974821735350
# Overlap  = 0.172663043128
#
# Restart 4
# Energy   = -7.632419799454
# Fidelity = 0.978542538750
# Overlap  = 0.171792044198
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -7.686532863099
# Fidelity = 0.992280483713
# Overlap  = 0.997185035710
#
# Restart 1
# Energy   = -7.608913008961
# Fidelity = 0.971618164384
# Overlap  = 0.987220775306
#
# Restart 2
# Energy   = -7.611967317170
# Fidelity = 0.973138229465
# Overlap  = 0.989306203040
#
# Restart 3
# Energy   = -7.630674546500
# Fidelity = 0.977287120111
# Overlap  = 0.990611283225
#
# Restart 4
# Energy   = -7.614836996321
# Fidelity = 0.974100089072
# Overlap  = 0.988828068477
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.686532863099
# Energy error     : 4.418350e-02
# Fidelity         : 0.992280483713
# Tracking overlap : 0.997185035710
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.520980145446
# Fidelity = 0.997678636084
# Overlap  = 0.630477259656
#
# Restart 1
# Energy   = -5.482867738620
# Fidelity = 0.989548541222
# Overlap  = 0.615097194164
#
# Restart 2
# Energy   = -5.491534932551
# Fidelity = 0.990848183636
# Overlap  = 0.620107153923
#
# Restart 3
# Energy   = -5.467862159763
# Fidelity = 0.985255790584
# Overlap  = 0.602479220448
#
# Restart 4
# Energy   = -5.502318966713
# Fidelity = 0.993338811311
# Overlap  = 0.616172447946
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -5.522872019419
# Fidelity = 0.998041541748
# Overlap  = 0.999306873841
#
# Restart 1
# Energy   = -5.484785362643
# Fidelity = 0.989742663442
# Overlap  = 0.993760644539
#
# Restart 2
# Energy   = -5.469774723763
# Fidelity = 0.985618579295
# Overlap  = 0.990350585620
#
# Restart 3
# Energy   = -5.475931940775
# Fidelity = 0.987399963332
# Overlap  = 0.991724550315
#
# Restart 4
# Energy   = -5.485765714665
# Fidelity = 0.989875270293
# Overlap  = 0.993629265425
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.522872019419
# Energy error     : 1.527681e-02
# Fidelity         : 0.998041541748
# Tracking overlap : 0.999306873841
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.271175693685
# Fidelity = 0.999402263047
# Overlap  = 0.828203073409
#
# Restart 1
# Energy   = -4.251946052932
# Fidelity = 0.994558057558
# Overlap  = 0.798136525031
#
# Restart 2
# Energy   = -4.254647915253
# Fidelity = 0.995458327174
# Overlap  = 0.800911512657
#
# Restart 3
# Energy   = -4.250297434280
# Fidelity = 0.994955980579
# Overlap  = 0.798184382038
#
# Restart 4
# Energy   = -4.256233207515
# Fidelity = 0.996204150803
# Overlap  = 0.804835619152
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -4.272107568504
# Fidelity = 0.999565169652
# Overlap  = 0.999797752975
#
# Restart 1
# Energy   = -4.256414807099
# Fidelity = 0.996270197487
# Overlap  = 0.996919074628
#
# Restart 2
# Energy   = -4.250192426157
# Fidelity = 0.994254187111
# Overlap  = 0.995612395124
#
# Restart 3
# Energy   = -4.257039317190
# Fidelity = 0.996768594472
# Overlap  = 0.997748649544
#
# Restart 4
# Energy   = -4.247059114323
# Fidelity = 0.993280182944
# Overlap  = 0.994508573329
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.272107568504
# Energy error     : 3.906224e-03
# Fidelity         : 0.999565169652
# Tracking overlap : 0.999797752975
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.445960324922
# Fidelity = 0.999664806525
# Overlap  = 0.906207753247
#
# Restart 1
# Energy   = -3.443680009275
# Fidelity = 0.999339094761
# Overlap  = 0.905103295558
#
# Restart 2
# Energy   = -3.444547484249
# Fidelity = 0.999465867712
# Overlap  = 0.903748709659
#
# Restart 3
# Energy   = -3.444393885777
# Fidelity = 0.999443023466
# Overlap  = 0.903572660503
#
# Restart 4
# Energy   = -3.444899613797
# Fidelity = 0.999513140524
# Overlap  = 0.904362314059
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -3.446610225510
# Fidelity = 0.999751814109
# Overlap  = 0.999923537620
#
# Restart 1
# Energy   = -3.444885890308
# Fidelity = 0.999517856298
# Overlap  = 0.999676521897
#
# Restart 2
# Energy   = -3.444540767533
# Fidelity = 0.999469617267
# Overlap  = 0.999589896381
#
# Restart 3
# Energy   = -3.443942992809
# Fidelity = 0.999400202678
# Overlap  = 0.999664626803
#
# Restart 4
# Energy   = -3.444364296247
# Fidelity = 0.999440186825
# Overlap  = 0.999761685697
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.446610225510
# Energy error     : 2.070160e-03
# Fidelity         : 0.999751814109
# Tracking overlap : 0.999923537620
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.856701573421
# Fidelity = 0.999366886913
# Overlap  = 0.943150025620
#
# Restart 1
# Energy   = -2.856329806340
# Fidelity = 0.999298506592
# Overlap  = 0.942814068033
#
# Restart 2
# Energy   = -2.855276749753
# Fidelity = 0.999183133317
# Overlap  = 0.943260687392
#
# Restart 3
# Energy   = -2.852672249407
# Fidelity = 0.998822081104
# Overlap  = 0.943035864828
#
# Restart 4
# Energy   = -2.855732997733
# Fidelity = 0.999187507317
# Overlap  = 0.944566356936
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.859835961438
# Fidelity = 0.999899942288
# Overlap  = 0.999394231300
#
# Restart 1
# Energy   = -2.856235258643
# Fidelity = 0.999338278088
# Overlap  = 0.999704211312
#
# Restart 2
# Energy   = -2.854232248557
# Fidelity = 0.998913935273
# Overlap  = 0.999746506846
#
# Restart 3
# Energy   = -2.853724611268
# Fidelity = 0.998847841165
# Overlap  = 0.999730494618
#
# Restart 4
# Energy   = -2.856717256911
# Fidelity = 0.999387937910
# Overlap  = 0.999445584605
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.859835961438
# Energy error     : 9.963037e-04
# Fidelity         : 0.999899942288
# Tracking overlap : 0.999394231300
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.417925857060
# Fidelity = 0.999765400214
# Overlap  = 0.962440198226
#
# Restart 1
# Energy   = -2.409520286405
# Fidelity = 0.998460634994
# Overlap  = 0.960182212769
#
# Restart 2
# Energy   = -2.414213383039
# Fidelity = 0.999156834216
# Overlap  = 0.960310974496
#
# Restart 3
# Energy   = -2.409863558420
# Fidelity = 0.998428435577
# Overlap  = 0.959932976373
#
# Restart 4
# Energy   = -2.410637891058
# Fidelity = 0.998564458665
# Overlap  = 0.959188254038
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.418029899792
# Fidelity = 0.999784283393
# Overlap  = 0.999991007135
#
# Restart 1
# Energy   = -2.411662009846
# Fidelity = 0.998815748476
# Overlap  = 0.999097092012
#
# Restart 2
# Energy   = -2.409160681829
# Fidelity = 0.998352113894
# Overlap  = 0.998809681425
#
# Restart 3
# Energy   = -2.411217939344
# Fidelity = 0.998740038147
# Overlap  = 0.999028983584
#
# Restart 4
# Energy   = -2.409716534559
# Fidelity = 0.998488830765
# Overlap  = 0.998920716431
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.418029899792
# Energy error     : 2.060629e-03
# Fidelity         : 0.999784283393
# Tracking overlap : 0.999991007135
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.073577188217
# Fidelity = 0.999719069875
# Overlap  = 0.973785725057
#
# Restart 1
# Energy   = -2.067010599775
# Fidelity = 0.998615567794
# Overlap  = 0.970368452642
#
# Restart 2
# Energy   = -2.066346711143
# Fidelity = 0.998498744946
# Overlap  = 0.969572158549
#
# Restart 3
# Energy   = -2.066464430582
# Fidelity = 0.998557191372
# Overlap  = 0.970454250863
#
# Restart 4
# Energy   = -2.066531148533
# Fidelity = 0.998575612879
# Overlap  = 0.970066043453
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -2.073649630338
# Fidelity = 0.999729934821
# Overlap  = 0.999996114401
#
# Restart 1
# Energy   = -2.066615507579
# Fidelity = 0.998575968822
# Overlap  = 0.999089617902
#
# Restart 2
# Energy   = -2.066595464107
# Fidelity = 0.998585946879
# Overlap  = 0.999106152180
#
# Restart 3
# Energy   = -2.066081974830
# Fidelity = 0.998492966110
# Overlap  = 0.999002152012
#
# Restart 4
# Energy   = -2.066550245675
# Fidelity = 0.998565588227
# Overlap  = 0.999082599090
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.073649630338
# Energy error     : 2.662937e-03
# Fidelity         : 0.999729934821
# Tracking overlap : 0.999996114401
# Layers            : 4
# Pauli terms       : 172
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.797415024017
# Fidelity = 0.999728527794
# Overlap  = 0.981096364924
#
# Restart 1
# Energy   = -1.789373182265
# Fidelity = 0.997992074949
# Overlap  = 0.976302916134
#
# Restart 2
# Energy   = -1.792896299838
# Fidelity = 0.999011426545
# Overlap  = 0.978509389965
#
# Restart 3
# Energy   = -1.792983352512
# Fidelity = 0.999022886104
# Overlap  = 0.978498800554
#
# Restart 4
# Energy   = -1.793122105539
# Fidelity = 0.999056238419
# Overlap  = 0.978560353128
#
# Running HVA-VQE with warm-start tracking...
#
#
# Restart 0
# Energy   = -1.797467697475
# Fidelity = 0.999737512868
# Overlap  = 0.999996938860
#
# Restart 1
# Energy   = -1.792950967089
# Fidelity = 0.999010242704
# Overlap  = 0.999436617390
#
# Restart 2
# Energy   = -1.792994546224
# Fidelity = 0.999028238362
# Overlap  = 0.999454817395
#
# Restart 3
# Energy   = -1.792911586466
# Fidelity = 0.999004779522
# Overlap  = 0.999437860173
#
# Restart 4
# Energy   = -1.793256883276
# Fidelity = 0.999085950840
# Overlap  = 0.999472021919
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.797467697475
# Energy error     : 2.605569e-03
# Fidelity         : 0.999737512868
# Tracking overlap : 0.999996938860
# Layers            : 4
# Pauli terms       : 172
#
#
# ============================================================================================================================================
# SUMMARY : Strong SSB
# ============================================================================================================================================
# lambda      Exact E             VQE E               Error             Fidelity          TrackOverlap      Layers
# ============================================================================================================================================
# 0.1000      -20.7773284453      -20.7614913809      1.5837e-02        0.9981894766      0.9996080610      4
# 0.3111      -12.8364411428      -12.8153278232      2.1113e-02        0.9959075665      0.9998344634      4
# 0.5222      -7.7307163648       -7.6865328631       4.4184e-02        0.9922804837      0.9971850357      4
# 0.7333      -5.5381488307       -5.5228720194       1.5277e-02        0.9980415417      0.9993068738      4
# 0.9444      -4.2760137929       -4.2721075685       3.9062e-03        0.9995651697      0.9997977530      4
# 1.1556      -3.4486803854       -3.4466102255       2.0702e-03        0.9997518141      0.9999235376      4
# 1.3667      -2.8608322652       -2.8598359614       9.9630e-04        0.9998999423      0.9993942313      4
# 1.5778      -2.4200905293       -2.4180298998       2.0606e-03        0.9997842834      0.9999910071      4
# 1.7889      -2.0763125676       -2.0736496303       2.6629e-03        0.9997299348      0.9999961144      4
# 2.0000      -1.8000732662       -1.7974676975       2.6056e-03        0.9997375129      0.9999969389      4

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#
plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        color=case_colors[label],
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HVA_Floc vs lambda different f.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    
    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,
        'psi_vqe': psi_vqe,
        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119454
# T = 2     Fidelity = 0.99733228
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98268153
# T = 2     Fidelity = 0.99772230
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394393
# T = 2     Fidelity = 0.99802450
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98503659
# T = 2     Fidelity = 0.99826624
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98600488
# T = 2     Fidelity = 0.99846527
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98685588
# T = 2     Fidelity = 0.99862668
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762388
# T = 2     Fidelity = 0.99876274
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98831118
# T = 2     Fidelity = 0.99887486
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98897468
# T = 2     Fidelity = 0.99898070
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98950754
# T = 2     Fidelity = 0.99905251
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00037875
# T = 10    Fidelity = 0.00053165
# T = 20    Fidelity = 0.01185063
# T = 30    Fidelity = 0.08178748
# T = 40    Fidelity = 0.18840543
# T = 50    Fidelity = 0.42868629
# T = 75    Fidelity = 0.56655858
# T = 100   Fidelity = 0.72886110
# T = 125   Fidelity = 0.80771581
# T = 150   Fidelity = 0.83713589
# T = 175   Fidelity = 0.90617424
# T = 200   Fidelity = 0.91962309
# T = 225   Fidelity = 0.96682511
# T = 250   Fidelity = 0.89115811
# T = 275   Fidelity = 0.96869633
# T = 300   Fidelity = 0.85600004
# T = 400   Fidelity = 0.98047483
# T = 500   Fidelity = 0.96074530
# T = 600   Fidelity = 0.95863639
# T = 700   Fidelity = 0.62930839
# T = 800   Fidelity = 0.83491747
# T = 900   Fidelity = 0.82242382
# T = 1000  Fidelity = 0.66465199
# T = 1010  Fidelity = 0.57964563
# T = 1020  Fidelity = 0.61894421
# T = 1030  Fidelity = 0.69785773
# T = 1040  Fidelity = 0.72169445
# T = 1050  Fidelity = 0.78738667
# T = 1060  Fidelity = 0.91743123
# T = 1070  Fidelity = 0.77625857
# T = 1080  Fidelity = 0.78823419
# T = 1090  Fidelity = 0.71276291
# T = 1100  Fidelity = 0.38120686
# T = 1200  Fidelity = 0.59302537
# T = 1300  Fidelity = 0.48328816
# T = 1400  Fidelity = 0.71890643
# T = 1500  Fidelity = 0.46485716
# T = 2000  Fidelity = 0.93562721
# T = 2100  Fidelity = 0.70822197
# T = 2110  Fidelity = 0.56780098
# T = 2120  Fidelity = 0.47366980
# T = 2130  Fidelity = 0.39779306
# T = 2140  Fidelity = 0.49631395
# T = 2150  Fidelity = 0.41769524
# T = 2160  Fidelity = 0.63052458
# T = 2170  Fidelity = 0.52210317
# T = 2180  Fidelity = 0.49476465
# T = 2190  Fidelity = 0.50068308
# T = 2200  Fidelity = 0.35826482
# T = 2300  Fidelity = 0.77482907
# T = 2400  Fidelity = 0.21842873
# T = 2500  Fidelity = 0.75779490
# T = 2600  Fidelity = 0.43590224
# T = 2700  Fidelity = 0.55735309
# T = 2800  Fidelity = 0.85255237
# T = 2900  Fidelity = 0.64759373
# T = 3000  Fidelity = 0.82639255
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00976726e+00
# P0     = 0.82639255
# P1     = 0.05954570
# P0+P1  = 0.88593825
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000013
# T = 5     Fidelity = 0.00048382
# T = 10    Fidelity = 0.06584362
# T = 20    Fidelity = 0.22090205
# T = 30    Fidelity = 0.61795566
# T = 40    Fidelity = 0.34495633
# T = 50    Fidelity = 0.78254713
# T = 75    Fidelity = 0.74276348
# T = 100   Fidelity = 0.79341400
# T = 125   Fidelity = 0.87791259
# T = 150   Fidelity = 0.87762229
# T = 175   Fidelity = 0.89818330
# T = 200   Fidelity = 0.92367094
# T = 225   Fidelity = 0.93212213
# T = 250   Fidelity = 0.94295710
# T = 275   Fidelity = 0.94887865
# T = 300   Fidelity = 0.95051895
# T = 400   Fidelity = 0.97124070
# T = 500   Fidelity = 0.97481334
# T = 600   Fidelity = 0.83140260
# T = 700   Fidelity = 0.82014840
# T = 800   Fidelity = 0.87420088
# T = 900   Fidelity = 0.71233756
# T = 1000  Fidelity = 0.76389354
# T = 1010  Fidelity = 0.87771313
# T = 1020  Fidelity = 0.84919803
# T = 1030  Fidelity = 0.90886099
# T = 1040  Fidelity = 0.83723270
# T = 1050  Fidelity = 0.85648797
# T = 1060  Fidelity = 0.74319851
# T = 1070  Fidelity = 0.77991918
# T = 1080  Fidelity = 0.52891236
# T = 1090  Fidelity = 0.67929058
# T = 1100  Fidelity = 0.53659261
# T = 1200  Fidelity = 0.77677981
# T = 1300  Fidelity = 0.81701308
# T = 1400  Fidelity = 0.94240527
# T = 1500  Fidelity = 0.85481974
# T = 2000  Fidelity = 0.59745781
# T = 2100  Fidelity = 0.60580469
# T = 2110  Fidelity = 0.67506618
# T = 2120  Fidelity = 0.81116718
# T = 2130  Fidelity = 0.95627935
# T = 2140  Fidelity = 0.76273458
# T = 2150  Fidelity = 0.81596998
# T = 2160  Fidelity = 0.89610875
# T = 2170  Fidelity = 0.58538661
# T = 2180  Fidelity = 0.88849707
# T = 2190  Fidelity = 0.58742115
# T = 2200  Fidelity = 0.47146075
# T = 2300  Fidelity = 0.47418163
# T = 2400  Fidelity = 0.65585528
# T = 2500  Fidelity = 0.30934366
# T = 2600  Fidelity = 0.91599951
# T = 2700  Fidelity = 0.84812628
# T = 2800  Fidelity = 0.86645794
# T = 2900  Fidelity = 0.84772288
# T = 3000  Fidelity = 0.87439458
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02946706e+00
# P0     = 0.87439458
# P1     = 0.01182603
# P0+P1  = 0.88622061
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00004500
# T = 2     Fidelity = 0.00028657
# T = 5     Fidelity = 0.01959702
# T = 10    Fidelity = 0.21410878
# T = 20    Fidelity = 0.59183297
# T = 30    Fidelity = 0.65427715
# T = 40    Fidelity = 0.78648144
# T = 50    Fidelity = 0.81296839
# T = 75    Fidelity = 0.91931468
# T = 100   Fidelity = 0.96052797
# T = 125   Fidelity = 0.97639501
# T = 150   Fidelity = 0.98435710
# T = 175   Fidelity = 0.98837388
# T = 200   Fidelity = 0.98792844
# T = 225   Fidelity = 0.98917605
# T = 250   Fidelity = 0.98876241
# T = 275   Fidelity = 0.98038510
# T = 300   Fidelity = 0.98070724
# T = 400   Fidelity = 0.96877124
# T = 500   Fidelity = 0.92439595
# T = 600   Fidelity = 0.89003353
# T = 700   Fidelity = 0.93842974
# T = 800   Fidelity = 0.90267316
# T = 900   Fidelity = 0.86175934
# T = 1000  Fidelity = 0.74073785
# T = 1010  Fidelity = 0.65708284
# T = 1020  Fidelity = 0.86860540
# T = 1030  Fidelity = 0.53687389
# T = 1040  Fidelity = 0.94183642
# T = 1050  Fidelity = 0.69146465
# T = 1060  Fidelity = 0.83407761
# T = 1070  Fidelity = 0.93007923
# T = 1080  Fidelity = 0.78287086
# T = 1090  Fidelity = 0.97991751
# T = 1100  Fidelity = 0.92779373
# T = 1200  Fidelity = 0.93217464
# T = 1300  Fidelity = 0.91578934
# T = 1400  Fidelity = 0.92550623
# T = 1500  Fidelity = 0.95932105
# T = 2000  Fidelity = 0.85749345
# T = 2100  Fidelity = 0.80949119
# T = 2110  Fidelity = 0.70295745
# T = 2120  Fidelity = 0.86599254
# T = 2130  Fidelity = 0.93478049
# T = 2140  Fidelity = 0.86421885
# T = 2150  Fidelity = 0.87866084
# T = 2160  Fidelity = 0.73909135
# T = 2170  Fidelity = 0.73643615
# T = 2180  Fidelity = 0.78590407
# T = 2190  Fidelity = 0.76472730
# T = 2200  Fidelity = 0.67818777
# T = 2300  Fidelity = 0.72784857
# T = 2400  Fidelity = 0.86511953
# T = 2500  Fidelity = 0.86297785
# T = 2600  Fidelity = 0.77782122
# T = 2700  Fidelity = 0.94207963
# T = 2800  Fidelity = 0.96768015
# T = 2900  Fidelity = 0.96314487
# T = 3000  Fidelity = 0.94381284
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04808582e+00
# P0     = 0.94381284
# P1     = 0.00087473
# P0+P1  = 0.94468757
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00116961
# T = 2     Fidelity = 0.00482982
# T = 5     Fidelity = 0.06186011
# T = 10    Fidelity = 0.28066380
# T = 20    Fidelity = 0.67960330
# T = 30    Fidelity = 0.73607491
# T = 40    Fidelity = 0.81820093
# T = 50    Fidelity = 0.88682594
# T = 75    Fidelity = 0.95355837
# T = 100   Fidelity = 0.98102621
# T = 125   Fidelity = 0.99162781
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00852218
# T = 2     Fidelity = 0.02342018
# T = 5     Fidelity = 0.12509259
# T = 10    Fidelity = 0.34170424
# T = 20    Fidelity = 0.67138596
# T = 30    Fidelity = 0.79957355
# T = 40    Fidelity = 0.86000485
# T = 50    Fidelity = 0.90958705
# T = 75    Fidelity = 0.97038717
# T = 100   Fidelity = 0.98954294
# T = 125   Fidelity = 0.99605359
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03437796
# T = 2     Fidelity = 0.07343270
# T = 5     Fidelity = 0.22218459
# T = 10    Fidelity = 0.42709445
# T = 20    Fidelity = 0.67709090
# T = 30    Fidelity = 0.79940585
# T = 40    Fidelity = 0.86900714
# T = 50    Fidelity = 0.91656411
# T = 75    Fidelity = 0.97812179
# T = 100   Fidelity = 0.99447810
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09486649
# T = 2     Fidelity = 0.17323772
# T = 5     Fidelity = 0.36487747
# T = 10    Fidelity = 0.55540779
# T = 20    Fidelity = 0.74178229
# T = 30    Fidelity = 0.83118704
# T = 40    Fidelity = 0.88326177
# T = 50    Fidelity = 0.91760323
# T = 75    Fidelity = 0.96565198
# T = 100   Fidelity = 0.98469479
# T = 125   Fidelity = 0.99195885
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19164131
# T = 2     Fidelity = 0.31341632
# T = 5     Fidelity = 0.52587979
# T = 10    Fidelity = 0.69225628
# T = 20    Fidelity = 0.82760708
# T = 30    Fidelity = 0.88701100
# T = 40    Fidelity = 0.92125088
# T = 50    Fidelity = 0.94280113
# T = 75    Fidelity = 0.96936063
# T = 100   Fidelity = 0.98209846
# T = 125   Fidelity = 0.98794237
# T = 150   Fidelity = 0.99099558
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30136913
# T = 2     Fidelity = 0.45517486
# T = 5     Fidelity = 0.66252555
# T = 10    Fidelity = 0.79907844
# T = 20    Fidelity = 0.89470942
# T = 30    Fidelity = 0.93325248
# T = 40    Fidelity = 0.95477380
# T = 50    Fidelity = 0.96678034
# T = 75    Fidelity = 0.98261470
# T = 100   Fidelity = 0.98902828
# T = 125   Fidelity = 0.99249003
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40261222
# T = 2     Fidelity = 0.57328342
# T = 5     Fidelity = 0.76084156
# T = 10    Fidelity = 0.86942719
# T = 20    Fidelity = 0.93662918
# T = 30    Fidelity = 0.96223145
# T = 40    Fidelity = 0.97426118
# T = 50    Fidelity = 0.98198964
# T = 75    Fidelity = 0.99106526
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.36752113e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063675
# T = 10    Fidelity = 0.00011413
# T = 20    Fidelity = 0.00399453
# T = 30    Fidelity = 0.05552973
# T = 40    Fidelity = 0.12241103
# T = 50    Fidelity = 0.21143976
# T = 75    Fidelity = 0.58040959
# T = 100   Fidelity = 0.76489598
# T = 125   Fidelity = 0.73487719
# T = 150   Fidelity = 0.86855229
# T = 175   Fidelity = 0.91265234
# T = 200   Fidelity = 0.87379428
# T = 225   Fidelity = 0.95058395
# T = 250   Fidelity = 0.98423703
# T = 275   Fidelity = 0.98520479
# T = 300   Fidelity = 0.86182052
# T = 400   Fidelity = 0.91397844
# T = 500   Fidelity = 0.92716479
# T = 600   Fidelity = 0.91965534
# T = 700   Fidelity = 0.91449244
# T = 800   Fidelity = 0.82093699
# T = 900   Fidelity = 0.78167360
# T = 1000  Fidelity = 0.67231968
# T = 1010  Fidelity = 0.52161212
# T = 1020  Fidelity = 0.57355721
# T = 1030  Fidelity = 0.75252147
# T = 1040  Fidelity = 0.89749018
# T = 1050  Fidelity = 0.85703139
# T = 1060  Fidelity = 0.83325648
# T = 1070  Fidelity = 0.70195886
# T = 1080  Fidelity = 0.54480086
# T = 1090  Fidelity = 0.51436728
# T = 1100  Fidelity = 0.55273969
# T = 1200  Fidelity = 0.67069406
# T = 1300  Fidelity = 0.58630872
# T = 1400  Fidelity = 0.67226965
# T = 1500  Fidelity = 0.29179280
# T = 2000  Fidelity = 0.11283850
# T = 2100  Fidelity = 0.68399651
# T = 2110  Fidelity = 0.68255494
# T = 2120  Fidelity = 0.73058504
# T = 2130  Fidelity = 0.81299936
# T = 2140  Fidelity = 0.85502734
# T = 2150  Fidelity = 0.92182557
# T = 2160  Fidelity = 0.90530139
# T = 2170  Fidelity = 0.86572993
# T = 2180  Fidelity = 0.77664645
# T = 2190  Fidelity = 0.40701252
# T = 2200  Fidelity = 0.26076242
# T = 2300  Fidelity = 0.55592398
# T = 2400  Fidelity = 0.82728309
# T = 2500  Fidelity = 0.90652985
# T = 2600  Fidelity = 0.80687784
# T = 2700  Fidelity = 0.81005646
# T = 2800  Fidelity = 0.35086673
# T = 2900  Fidelity = 0.89039648
# T = 3000  Fidelity = 0.74269242
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.00970921e+00
# P0     = 0.74269242
# P1     = 0.04147709
# P0+P1  = 0.78416951
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.12924856e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00018119
# T = 10    Fidelity = 0.04089152
# T = 20    Fidelity = 0.42104477
# T = 30    Fidelity = 0.49013647
# T = 40    Fidelity = 0.64145959
# T = 50    Fidelity = 0.64397718
# T = 75    Fidelity = 0.88074668
# T = 100   Fidelity = 0.90151979
# T = 125   Fidelity = 0.87119569
# T = 150   Fidelity = 0.88526736
# T = 175   Fidelity = 0.91969555
# T = 200   Fidelity = 0.94075101
# T = 225   Fidelity = 0.95449771
# T = 250   Fidelity = 0.94798021
# T = 275   Fidelity = 0.95874636
# T = 300   Fidelity = 0.94035779
# T = 400   Fidelity = 0.97441347
# T = 500   Fidelity = 0.95598054
# T = 600   Fidelity = 0.92757558
# T = 700   Fidelity = 0.56269736
# T = 800   Fidelity = 0.61913137
# T = 900   Fidelity = 0.68052615
# T = 1000  Fidelity = 0.89421891
# T = 1010  Fidelity = 0.57125016
# T = 1020  Fidelity = 0.84731672
# T = 1030  Fidelity = 0.84426541
# T = 1040  Fidelity = 0.71294308
# T = 1050  Fidelity = 0.85698244
# T = 1060  Fidelity = 0.56827278
# T = 1070  Fidelity = 0.81139557
# T = 1080  Fidelity = 0.62779416
# T = 1090  Fidelity = 0.82002133
# T = 1100  Fidelity = 0.71013794
# T = 1200  Fidelity = 0.61815482
# T = 1300  Fidelity = 0.60069767
# T = 1400  Fidelity = 0.54766884
# T = 1500  Fidelity = 0.71013403
# T = 2000  Fidelity = 0.50145738
# T = 2100  Fidelity = 0.70504719
# T = 2110  Fidelity = 0.68401646
# T = 2120  Fidelity = 0.82575085
# T = 2130  Fidelity = 0.66868642
# T = 2140  Fidelity = 0.59040888
# T = 2150  Fidelity = 0.80450834
# T = 2160  Fidelity = 0.53304195
# T = 2170  Fidelity = 0.69460080
# T = 2180  Fidelity = 0.65805859
# T = 2190  Fidelity = 0.76833871
# T = 2200  Fidelity = 0.50491227
# T = 2300  Fidelity = 0.67653853
# T = 2400  Fidelity = 0.67185857
# T = 2500  Fidelity = 0.66540693
# T = 2600  Fidelity = 0.71896664
# T = 2700  Fidelity = 0.76247470
# T = 2800  Fidelity = 0.79422248
# T = 2900  Fidelity = 0.52515749
# T = 3000  Fidelity = 0.55744884
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.02931057e+00
# P0     = 0.55744884
# P1     = 0.21023162
# P0+P1  = 0.76768046
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00001182
# T = 2     Fidelity = 0.00016899
# T = 5     Fidelity = 0.01433632
# T = 10    Fidelity = 0.17119361
# T = 20    Fidelity = 0.44274082
# T = 30    Fidelity = 0.34001887
# T = 40    Fidelity = 0.54717248
# T = 50    Fidelity = 0.43876271
# T = 75    Fidelity = 0.49354015
# T = 100   Fidelity = 0.50306411
# T = 125   Fidelity = 0.50292437
# T = 150   Fidelity = 0.50198458
# T = 175   Fidelity = 0.50110792
# T = 200   Fidelity = 0.49657314
# T = 225   Fidelity = 0.50821945
# T = 250   Fidelity = 0.50070924
# T = 275   Fidelity = 0.48671187
# T = 300   Fidelity = 0.48664686
# T = 400   Fidelity = 0.49699668
# T = 500   Fidelity = 0.30754741
# T = 600   Fidelity = 0.50735836
# T = 700   Fidelity = 0.38720479
# T = 800   Fidelity = 0.53210634
# T = 900   Fidelity = 0.52794726
# T = 1000  Fidelity = 0.69833988
# T = 1010  Fidelity = 0.39540911
# T = 1020  Fidelity = 0.40023075
# T = 1030  Fidelity = 0.46802703
# T = 1040  Fidelity = 0.49585146
# T = 1050  Fidelity = 0.46548664
# T = 1060  Fidelity = 0.36760030
# T = 1070  Fidelity = 0.55886766
# T = 1080  Fidelity = 0.26648851
# T = 1090  Fidelity = 0.27520708
# T = 1100  Fidelity = 0.60876862
# T = 1200  Fidelity = 0.29127202
# T = 1300  Fidelity = 0.55077583
# T = 1400  Fidelity = 0.53347991
# T = 1500  Fidelity = 0.36092136
# T = 2000  Fidelity = 0.28949049
# T = 2100  Fidelity = 0.20239713
# T = 2110  Fidelity = 0.54881647
# T = 2120  Fidelity = 0.46984759
# T = 2130  Fidelity = 0.49875368
# T = 2140  Fidelity = 0.32295354
# T = 2150  Fidelity = 0.44388817
# T = 2160  Fidelity = 0.38475397
# T = 2170  Fidelity = 0.38918284
# T = 2180  Fidelity = 0.52982936
# T = 2190  Fidelity = 0.19307232
# T = 2200  Fidelity = 0.48352268
# T = 2300  Fidelity = 0.53228017
# T = 2400  Fidelity = 0.48651006
# T = 2500  Fidelity = 0.45796216
# T = 2600  Fidelity = 0.45813259
# T = 2700  Fidelity = 0.56801098
# T = 2800  Fidelity = 0.59740114
# T = 2900  Fidelity = 0.45486237
# T = 3000  Fidelity = 0.42747269
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.42747269
# P1     = 0.06032703
# P0+P1  = 0.48779972
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.03672155e-03
# T = 1     Fidelity = 0.00306412
# T = 2     Fidelity = 0.01237417
# T = 5     Fidelity = 0.08437288
# T = 10    Fidelity = 0.22356144
# T = 20    Fidelity = 0.31780076
# T = 30    Fidelity = 0.38294712
# T = 40    Fidelity = 0.54972275
# T = 50    Fidelity = 0.58069080
# T = 75    Fidelity = 0.50026639
# T = 100   Fidelity = 0.52160750
# T = 125   Fidelity = 0.52314963
# T = 150   Fidelity = 0.52292188
# T = 175   Fidelity = 0.51967039
# T = 200   Fidelity = 0.52994370
# T = 225   Fidelity = 0.52244038
# T = 250   Fidelity = 0.51775814
# T = 275   Fidelity = 0.52599229
# T = 300   Fidelity = 0.49449849
# T = 400   Fidelity = 0.50894004
# T = 500   Fidelity = 0.55282485
# T = 600   Fidelity = 0.50723688
# T = 700   Fidelity = 0.44140797
# T = 800   Fidelity = 0.45130432
# T = 900   Fidelity = 0.53271035
# T = 1000  Fidelity = 0.77546639
# T = 1010  Fidelity = 0.44365718
# T = 1020  Fidelity = 0.12518190
# T = 1030  Fidelity = 0.55949815
# T = 1040  Fidelity = 0.78952807
# T = 1050  Fidelity = 0.59230340
# T = 1060  Fidelity = 0.48458440
# T = 1070  Fidelity = 0.49685822
# T = 1080  Fidelity = 0.41983876
# T = 1090  Fidelity = 0.25408205
# T = 1100  Fidelity = 0.73978600
# T = 1200  Fidelity = 0.58340372
# T = 1300  Fidelity = 0.45310474
# T = 1400  Fidelity = 0.52137659
# T = 1500  Fidelity = 0.53570063
# T = 2000  Fidelity = 0.45627168
# T = 2100  Fidelity = 0.51432966
# T = 2110  Fidelity = 0.55187788
# T = 2120  Fidelity = 0.46607012
# T = 2130  Fidelity = 0.39140891
# T = 2140  Fidelity = 0.56036292
# T = 2150  Fidelity = 0.76623698
# T = 2160  Fidelity = 0.43639979
# T = 2170  Fidelity = 0.24248325
# T = 2180  Fidelity = 0.49457708
# T = 2190  Fidelity = 0.68624308
# T = 2200  Fidelity = 0.61240710
# T = 2300  Fidelity = 0.81499342
# T = 2400  Fidelity = 0.53064481
# T = 2500  Fidelity = 0.49994191
# T = 2600  Fidelity = 0.55028468
# T = 2700  Fidelity = 0.44512968
# T = 2800  Fidelity = 0.53390150
# T = 2900  Fidelity = 0.30364610
# T = 3000  Fidelity = 0.43644098
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.43644098
# P1     = 0.02628097
# P0+P1  = 0.46272195
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.41475042e-03
# T = 1     Fidelity = 0.02404548
# T = 2     Fidelity = 0.06514137
# T = 5     Fidelity = 0.21902357
# T = 10    Fidelity = 0.40682549
# T = 20    Fidelity = 0.52936144
# T = 30    Fidelity = 0.49787071
# T = 40    Fidelity = 0.50386704
# T = 50    Fidelity = 0.54927262
# T = 75    Fidelity = 0.60863319
# T = 100   Fidelity = 0.60702906
# T = 125   Fidelity = 0.61201797
# T = 150   Fidelity = 0.61597280
# T = 175   Fidelity = 0.61930486
# T = 200   Fidelity = 0.62631466
# T = 225   Fidelity = 0.62913405
# T = 250   Fidelity = 0.63287365
# T = 275   Fidelity = 0.62972473
# T = 300   Fidelity = 0.64593082
# T = 400   Fidelity = 0.59372699
# T = 500   Fidelity = 0.65316527
# T = 600   Fidelity = 0.67680698
# T = 700   Fidelity = 0.59426393
# T = 800   Fidelity = 0.71300460
# T = 900   Fidelity = 0.60810556
# T = 1000  Fidelity = 0.48670443
# T = 1010  Fidelity = 0.75952935
# T = 1020  Fidelity = 0.85084750
# T = 1030  Fidelity = 0.75010568
# T = 1040  Fidelity = 0.52920136
# T = 1050  Fidelity = 0.47428117
# T = 1060  Fidelity = 0.64956982
# T = 1070  Fidelity = 0.77667996
# T = 1080  Fidelity = 0.82086659
# T = 1090  Fidelity = 0.55601726
# T = 1100  Fidelity = 0.40042191
# T = 1200  Fidelity = 0.45955666
# T = 1300  Fidelity = 0.54051541
# T = 1400  Fidelity = 0.76863695
# T = 1500  Fidelity = 0.67975093
# T = 2000  Fidelity = 0.77211999
# T = 2100  Fidelity = 0.81772873
# T = 2110  Fidelity = 0.80761092
# T = 2120  Fidelity = 0.55037199
# T = 2130  Fidelity = 0.65421821
# T = 2140  Fidelity = 0.71103771
# T = 2150  Fidelity = 0.82995012
# T = 2160  Fidelity = 0.84498032
# T = 2170  Fidelity = 0.78025324
# T = 2180  Fidelity = 0.53136287
# T = 2190  Fidelity = 0.56881651
# T = 2200  Fidelity = 0.69845456
# T = 2300  Fidelity = 0.76565885
# T = 2400  Fidelity = 0.75235229
# T = 2500  Fidelity = 0.82476103
# T = 2600  Fidelity = 0.72885488
# T = 2700  Fidelity = 0.77599619
# T = 2800  Fidelity = 0.75976191
# T = 2900  Fidelity = 0.69600346
# T = 3000  Fidelity = 0.74878492
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.74878492
# P1     = 0.00632536
# P0+P1  = 0.75511028
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50213251e-02
# T = 1     Fidelity = 0.08304433
# T = 2     Fidelity = 0.17510826
# T = 5     Fidelity = 0.39219757
# T = 10    Fidelity = 0.58559130
# T = 20    Fidelity = 0.71368562
# T = 30    Fidelity = 0.72016157
# T = 40    Fidelity = 0.71295471
# T = 50    Fidelity = 0.71869705
# T = 75    Fidelity = 0.74406013
# T = 100   Fidelity = 0.76237796
# T = 125   Fidelity = 0.77518204
# T = 150   Fidelity = 0.78572865
# T = 175   Fidelity = 0.79492872
# T = 200   Fidelity = 0.80408244
# T = 225   Fidelity = 0.81028265
# T = 250   Fidelity = 0.81599541
# T = 275   Fidelity = 0.82569194
# T = 300   Fidelity = 0.81729810
# T = 400   Fidelity = 0.87423343
# T = 500   Fidelity = 0.87047431
# T = 600   Fidelity = 0.79393824
# T = 700   Fidelity = 0.82785024
# T = 800   Fidelity = 0.84434860
# T = 900   Fidelity = 0.85188409
# T = 1000  Fidelity = 0.87646245
# T = 1010  Fidelity = 0.79358886
# T = 1020  Fidelity = 0.77886013
# T = 1030  Fidelity = 0.86785268
# T = 1040  Fidelity = 0.95126098
# T = 1050  Fidelity = 0.97284283
# T = 1060  Fidelity = 0.93444581
# T = 1070  Fidelity = 0.82886136
# T = 1080  Fidelity = 0.84124851
# T = 1090  Fidelity = 0.76849914
# T = 1100  Fidelity = 0.82739873
# T = 1200  Fidelity = 0.79729727
# T = 1300  Fidelity = 0.95533760
# T = 1400  Fidelity = 0.85400229
# T = 1500  Fidelity = 0.92804837
# T = 2000  Fidelity = 0.85941289
# T = 2100  Fidelity = 0.86730716
# T = 2110  Fidelity = 0.86734991
# T = 2120  Fidelity = 0.92142212
# T = 2130  Fidelity = 0.86417866
# T = 2140  Fidelity = 0.88052115
# T = 2150  Fidelity = 0.80873531
# T = 2160  Fidelity = 0.83684023
# T = 2170  Fidelity = 0.95375578
# T = 2180  Fidelity = 0.93798075
# T = 2190  Fidelity = 0.93728716
# T = 2200  Fidelity = 0.94053855
# T = 2300  Fidelity = 0.94986094
# T = 2400  Fidelity = 0.97264064
# T = 2500  Fidelity = 0.96400082
# T = 2600  Fidelity = 0.98715266
# T = 2700  Fidelity = 0.96918913
# T = 2800  Fidelity = 0.95225255
# T = 2900  Fidelity = 0.85462419
# T = 3000  Fidelity = 0.97234419
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.09849352e+00
# P0     = 0.97234419
# P1     = 0.00006914
# P0+P1  = 0.97241333
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77221454e-02
# T = 1     Fidelity = 0.17725138
# T = 2     Fidelity = 0.31798991
# T = 5     Fidelity = 0.55671516
# T = 10    Fidelity = 0.72544246
# T = 20    Fidelity = 0.82925393
# T = 30    Fidelity = 0.85276501
# T = 40    Fidelity = 0.85862681
# T = 50    Fidelity = 0.86434341
# T = 75    Fidelity = 0.88175440
# T = 100   Fidelity = 0.89803910
# T = 125   Fidelity = 0.90941467
# T = 150   Fidelity = 0.91771027
# T = 175   Fidelity = 0.92535057
# T = 200   Fidelity = 0.93454803
# T = 225   Fidelity = 0.93543931
# T = 250   Fidelity = 0.93540109
# T = 275   Fidelity = 0.94475744
# T = 300   Fidelity = 0.93538100
# T = 400   Fidelity = 0.94840426
# T = 500   Fidelity = 0.95241714
# T = 600   Fidelity = 0.96078133
# T = 700   Fidelity = 0.91636180
# T = 800   Fidelity = 0.92774640
# T = 900   Fidelity = 0.94675733
# T = 1000  Fidelity = 0.94002919
# T = 1010  Fidelity = 0.95121531
# T = 1020  Fidelity = 0.95597321
# T = 1030  Fidelity = 0.97882704
# T = 1040  Fidelity = 0.99467188
#
# Minimum T for Fidelity >= 0.99 : 1040
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20187623e-01
# T = 1     Fidelity = 0.27916912
# T = 2     Fidelity = 0.45154222
# T = 5     Fidelity = 0.68038646
# T = 10    Fidelity = 0.81862395
# T = 20    Fidelity = 0.89644639
# T = 30    Fidelity = 0.91797006
# T = 40    Fidelity = 0.92934004
# T = 50    Fidelity = 0.93802002
# T = 75    Fidelity = 0.95171759
# T = 100   Fidelity = 0.96199988
# T = 125   Fidelity = 0.96841599
# T = 150   Fidelity = 0.97428416
# T = 175   Fidelity = 0.97600087
# T = 200   Fidelity = 0.98166180
# T = 225   Fidelity = 0.97833984
# T = 250   Fidelity = 0.98145789
# T = 275   Fidelity = 0.97915643
# T = 300   Fidelity = 0.97991399
# T = 400   Fidelity = 0.97538180
# T = 500   Fidelity = 0.95332849
# T = 600   Fidelity = 0.93862389
# T = 700   Fidelity = 0.97965159
# T = 800   Fidelity = 0.98437608
# T = 900   Fidelity = 0.98934864
# T = 1000  Fidelity = 0.97969618
# T = 1010  Fidelity = 0.97132669
# T = 1020  Fidelity = 0.99558213
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405779e-01
# T = 1     Fidelity = 0.37879436
# T = 2     Fidelity = 0.56656735
# T = 5     Fidelity = 0.77016566
# T = 10    Fidelity = 0.87913109
# T = 20    Fidelity = 0.93531392
# T = 30    Fidelity = 0.95280877
# T = 40    Fidelity = 0.96401982
# T = 50    Fidelity = 0.96970005
# T = 75    Fidelity = 0.97961030
# T = 100   Fidelity = 0.98515343
# T = 125   Fidelity = 0.98839110
# T = 150   Fidelity = 0.99072750
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843475e-01
# T = 1     Fidelity = 0.46388130
# T = 2     Fidelity = 0.65547849
# T = 5     Fidelity = 0.83094875
# T = 10    Fidelity = 0.91704488
# T = 20    Fidelity = 0.95851760
# T = 30    Fidelity = 0.97284600
# T = 40    Fidelity = 0.97909013
# T = 50    Fidelity = 0.98365499
# T = 75    Fidelity = 0.99020594
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000028
# T = 5     Fidelity = 0.00073989
# T = 10    Fidelity = 0.06462436
# T = 20    Fidelity = 0.45551079
# T = 30    Fidelity = 0.87772596
# T = 40    Fidelity = 0.96678168
# T = 50    Fidelity = 0.98951924
# T = 75    Fidelity = 0.99559711
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000121
# T = 5     Fidelity = 0.02641720
# T = 10    Fidelity = 0.89301471
# T = 20    Fidelity = 0.96585135
# T = 30    Fidelity = 0.99303124
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00006955
# T = 2     Fidelity = 0.00070805
# T = 5     Fidelity = 0.18613558
# T = 10    Fidelity = 0.98184436
# T = 20    Fidelity = 0.98804795
# T = 30    Fidelity = 0.98309543
# T = 40    Fidelity = 0.98676825
# T = 50    Fidelity = 0.98988981
# T = 75    Fidelity = 0.99083234
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00135744
# T = 2     Fidelity = 0.00845003
# T = 5     Fidelity = 0.33896452
# T = 10    Fidelity = 0.98449744
# T = 20    Fidelity = 0.99173436
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00709325
# T = 2     Fidelity = 0.02941949
# T = 5     Fidelity = 0.47089972
# T = 10    Fidelity = 0.98141963
# T = 20    Fidelity = 0.99288835
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02095802
# T = 2     Fidelity = 0.06443440
# T = 5     Fidelity = 0.56334560
# T = 10    Fidelity = 0.97551126
# T = 20    Fidelity = 0.99217494
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04410779
# T = 2     Fidelity = 0.11074898
# T = 5     Fidelity = 0.63809179
# T = 10    Fidelity = 0.97220109
# T = 20    Fidelity = 0.99280449
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07610365
# T = 2     Fidelity = 0.16435801
# T = 5     Fidelity = 0.69504869
# T = 10    Fidelity = 0.96886532
# T = 20    Fidelity = 0.99307198
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11479589
# T = 2     Fidelity = 0.22183964
# T = 5     Fidelity = 0.74167122
# T = 10    Fidelity = 0.96698645
# T = 20    Fidelity = 0.99337639
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15817888
# T = 2     Fidelity = 0.28024243
# T = 5     Fidelity = 0.78052481
# T = 10    Fidelity = 0.96661482
# T = 20    Fidelity = 0.99374056
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9973322828      1.00972087e+00    None        None        None
# Symmetric      0.311     2         0.9977222991      1.02934439e+00    None        None        None
# Symmetric      0.522     2         0.9980245025      1.04790824e+00    None        None        None
# Symmetric      0.733     2         0.9982662369      1.06556366e+00    None        None        None
# Symmetric      0.944     2         0.9984652656      1.08242773e+00    None        None        None
# Symmetric      1.156     2         0.9986266827      1.09859358e+00    None        None        None
# Symmetric      1.367     2         0.9987627449      1.11413694e+00    None        None        None
# Symmetric      1.578     2         0.9988748636      1.12912045e+00    None        None        None
# Symmetric      1.789     2         0.9989806978      1.14359670e+00    None        None        None
# Symmetric      2.000     2         0.9990525081      1.15761039e+00    None        None        None
# Weak SSB optimised0.100     None      0.9804748349      2.42819099e-01    0.826393    0.059546    0.885938
# Weak SSB optimised0.311     None      0.9748133400      2.61171322e-01    0.874395    0.011826    0.886221
# Weak SSB optimised0.522     None      0.9891760461      2.64873214e-01    0.943813    0.000875    0.944688
# Weak SSB optimised0.733     125       0.9916278079      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     125       0.9960535937      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     100       0.9944781016      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9919588546      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     150       0.9909955783      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9924900326      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     75        0.9910652623      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9852047896      1.36752113e-03    0.742692    0.041477    0.78417
# Weak SSB       0.311     None      0.9744134742      1.12924856e-03    0.557449    0.210232    0.76768
# Weak SSB       0.522     None      0.6983398796      1.05614584e-03    0.427473    0.060327    0.4878
# Weak SSB       0.733     None      0.8149934178      1.03672155e-03    0.436441    0.026281    0.462722
# Weak SSB       0.944     None      0.8508475049      4.41475042e-03    0.748785    0.006325    0.75511
# Weak SSB       1.156     None      0.9871526591      2.50213251e-02    0.972344    6.9e-05     0.972413
# Weak SSB       1.367     1040      0.9946718762      6.77221454e-02    None        None        None
# Weak SSB       1.578     1020      0.9955821304      1.20187623e-01    None        None        None
# Weak SSB       1.789     150       0.9907275011      1.71405779e-01    None        None        None
# Weak SSB       2.000     75        0.9902059444      2.18843475e-01    None        None        None
# Strong SSB     0.100     75        0.9955971058      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9930312359      7.22062439e-01    None        None        None
# Strong SSB     0.522     75        0.9908323395      7.78318602e-01    None        None        None
# Strong SSB     0.733     20        0.9917343644      8.15979742e-01    None        None        None
# Strong SSB     0.944     20        0.9928883499      8.44059983e-01    None        None        None
# Strong SSB     1.156     20        0.9921749381      8.66317759e-01    None        None        None
# Strong SSB     1.367     20        0.9928044853      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9930719760      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9933763918      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9937405597      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HVA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'psi_vqe', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
#============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_list,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_list,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_list,
    d2M_strong,
    d3M_strong
)

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=1$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96521010
# T = 2     Fidelity = 0.99334352
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.03626623e+00
# T = 1     Fidelity = 0.96805768
# T = 2     Fidelity = 0.99422277
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05846299e+00
# T = 1     Fidelity = 0.97048701
# T = 2     Fidelity = 0.99490996
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07916278e+00
# T = 1     Fidelity = 0.97258459
# T = 2     Fidelity = 0.99546263
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.09862393e+00
# T = 1     Fidelity = 0.97445151
# T = 2     Fidelity = 0.99591840
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.11703633e+00
# T = 1     Fidelity = 0.97608257
# T = 2     Fidelity = 0.99628986
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.13454489e+00
# T = 1     Fidelity = 0.97755830
# T = 2     Fidelity = 0.99660409
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.15126343e+00
# T = 1     Fidelity = 0.97887525
# T = 2     Fidelity = 0.99686497
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.16728342e+00
# T = 1     Fidelity = 0.98014687
# T = 2     Fidelity = 0.99711126
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98116029
# T = 2     Fidelity = 0.99727978
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000157
# T = 10    Fidelity = 0.00046749
# T = 20    Fidelity = 0.00576300
# T = 30    Fidelity = 0.01839430
# T = 40    Fidelity = 0.06160133
# T = 50    Fidelity = 0.16061549
# T = 75    Fidelity = 0.32179379
# T = 100   Fidelity = 0.48118395
# T = 125   Fidelity = 0.62862772
# T = 150   Fidelity = 0.72380852
# T = 175   Fidelity = 0.79451028
# T = 200   Fidelity = 0.83529776
# T = 225   Fidelity = 0.84692361
# T = 250   Fidelity = 0.85588724
# T = 275   Fidelity = 0.71831160
# T = 300   Fidelity = 0.79255078
# T = 400   Fidelity = 0.93109099
# T = 500   Fidelity = 0.91045320
# T = 600   Fidelity = 0.89310013
# T = 700   Fidelity = 0.81623773
# T = 800   Fidelity = 0.64603327
# T = 900   Fidelity = 0.74823768
# T = 1000  Fidelity = 0.63045018
# T = 1010  Fidelity = 0.62210276
# T = 1020  Fidelity = 0.70081957
# T = 1030  Fidelity = 0.67217899
# T = 1040  Fidelity = 0.25611756
# T = 1050  Fidelity = 0.41832296
# T = 1060  Fidelity = 0.49916688
# T = 1070  Fidelity = 0.47186212
# T = 1080  Fidelity = 0.56554117
# T = 1090  Fidelity = 0.54923942
# T = 1100  Fidelity = 0.75548107
# T = 1200  Fidelity = 0.22311191
# T = 1300  Fidelity = 0.25167481
# T = 1400  Fidelity = 0.65115820
# T = 1500  Fidelity = 0.48304044
# T = 2000  Fidelity = 0.33801132
# T = 2100  Fidelity = 0.88944075
# T = 2110  Fidelity = 0.81439483
# T = 2120  Fidelity = 0.77065817
# T = 2130  Fidelity = 0.74780847
# T = 2140  Fidelity = 0.54420254
# T = 2150  Fidelity = 0.75756986
# T = 2160  Fidelity = 0.56147298
# T = 2170  Fidelity = 0.63555322
# T = 2180  Fidelity = 0.70214112
# T = 2190  Fidelity = 0.53217001
# T = 2200  Fidelity = 0.53088444
# T = 2300  Fidelity = 0.33819530
# T = 2400  Fidelity = 0.51722387
# T = 2500  Fidelity = 0.52767739
# T = 2600  Fidelity = 0.30718811
# T = 2700  Fidelity = 0.24702725
# T = 2800  Fidelity = 0.53862265
# T = 2900  Fidelity = 0.50393382
# T = 3000  Fidelity = 0.91819109
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91819109
# P1     = 0.00930156
# P0+P1  = 0.92749264
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61673084e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000003
# T = 5     Fidelity = 0.00001565
# T = 10    Fidelity = 0.00312264
# T = 20    Fidelity = 0.20941064
# T = 30    Fidelity = 0.28797485
# T = 40    Fidelity = 0.34639742
# T = 50    Fidelity = 0.69411701
# T = 75    Fidelity = 0.78449330
# T = 100   Fidelity = 0.63782985
# T = 125   Fidelity = 0.84974698
# T = 150   Fidelity = 0.76947139
# T = 175   Fidelity = 0.88058049
# T = 200   Fidelity = 0.96438378
# T = 225   Fidelity = 0.88279325
# T = 250   Fidelity = 0.95839684
# T = 275   Fidelity = 0.95451101
# T = 300   Fidelity = 0.93062802
# T = 400   Fidelity = 0.97249791
# T = 500   Fidelity = 0.96343581
# T = 600   Fidelity = 0.89374000
# T = 700   Fidelity = 0.62256656
# T = 800   Fidelity = 0.81575591
# T = 900   Fidelity = 0.73665226
# T = 1000  Fidelity = 0.81820231
# T = 1010  Fidelity = 0.78855874
# T = 1020  Fidelity = 0.82757491
# T = 1030  Fidelity = 0.71939424
# T = 1040  Fidelity = 0.70090268
# T = 1050  Fidelity = 0.66266405
# T = 1060  Fidelity = 0.54513133
# T = 1070  Fidelity = 0.51527220
# T = 1080  Fidelity = 0.62072206
# T = 1090  Fidelity = 0.51373448
# T = 1100  Fidelity = 0.47571087
# T = 1200  Fidelity = 0.86753765
# T = 1300  Fidelity = 0.66368283
# T = 1400  Fidelity = 0.80443013
# T = 1500  Fidelity = 0.91994036
# T = 2000  Fidelity = 0.63341172
# T = 2100  Fidelity = 0.47862387
# T = 2110  Fidelity = 0.75501581
# T = 2120  Fidelity = 0.72788865
# T = 2130  Fidelity = 0.56249378
# T = 2140  Fidelity = 0.46576141
# T = 2150  Fidelity = 0.61145293
# T = 2160  Fidelity = 0.54619130
# T = 2170  Fidelity = 0.43569357
# T = 2180  Fidelity = 0.44996242
# T = 2190  Fidelity = 0.82806082
# T = 2200  Fidelity = 0.63355637
# T = 2300  Fidelity = 0.65930104
# T = 2400  Fidelity = 0.56436630
# T = 2500  Fidelity = 0.85055040
# T = 2600  Fidelity = 0.58475416
# T = 2700  Fidelity = 0.86898768
# T = 2800  Fidelity = 0.62749562
# T = 2900  Fidelity = 0.71205041
# T = 3000  Fidelity = 0.87336720
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43053089e+00
# P0     = 0.87336720
# P1     = 0.03808215
# P0+P1  = 0.91144935
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64768458e-01
# T = 1     Fidelity = 0.00001500
# T = 2     Fidelity = 0.00012628
# T = 5     Fidelity = 0.00329754
# T = 10    Fidelity = 0.04789604
# T = 20    Fidelity = 0.40228122
# T = 30    Fidelity = 0.60251607
# T = 40    Fidelity = 0.57347427
# T = 50    Fidelity = 0.71564254
# T = 75    Fidelity = 0.80430239
# T = 100   Fidelity = 0.88705666
# T = 125   Fidelity = 0.93691689
# T = 150   Fidelity = 0.96044494
# T = 175   Fidelity = 0.96864442
# T = 200   Fidelity = 0.97925348
# T = 225   Fidelity = 0.97970887
# T = 250   Fidelity = 0.98560424
# T = 275   Fidelity = 0.98239492
# T = 300   Fidelity = 0.97986303
# T = 400   Fidelity = 0.97499733
# T = 500   Fidelity = 0.91242367
# T = 600   Fidelity = 0.87628436
# T = 700   Fidelity = 0.86200824
# T = 800   Fidelity = 0.82089675
# T = 900   Fidelity = 0.81266608
# T = 1000  Fidelity = 0.66901702
# T = 1010  Fidelity = 0.48699841
# T = 1020  Fidelity = 0.65400300
# T = 1030  Fidelity = 0.77926641
# T = 1040  Fidelity = 0.50761404
# T = 1050  Fidelity = 0.56844111
# T = 1060  Fidelity = 0.88716207
# T = 1070  Fidelity = 0.77265266
# T = 1080  Fidelity = 0.60024554
# T = 1090  Fidelity = 0.75283049
# T = 1100  Fidelity = 0.91812201
# T = 1200  Fidelity = 0.91280200
# T = 1300  Fidelity = 0.87305036
# T = 1400  Fidelity = 0.87474664
# T = 1500  Fidelity = 0.81550370
# T = 2000  Fidelity = 0.87661624
# T = 2100  Fidelity = 0.51642971
# T = 2110  Fidelity = 0.66048443
# T = 2120  Fidelity = 0.61577653
# T = 2130  Fidelity = 0.62575199
# T = 2140  Fidelity = 0.70776245
# T = 2150  Fidelity = 0.81964566
# T = 2160  Fidelity = 0.72179145
# T = 2170  Fidelity = 0.61781143
# T = 2180  Fidelity = 0.54891349
# T = 2190  Fidelity = 0.55450791
# T = 2200  Fidelity = 0.59200119
# T = 2300  Fidelity = 0.64914021
# T = 2400  Fidelity = 0.85066292
# T = 2500  Fidelity = 0.87308727
# T = 2600  Fidelity = 0.88662531
# T = 2700  Fidelity = 0.95875243
# T = 2800  Fidelity = 0.80733131
# T = 2900  Fidelity = 0.91418760
# T = 3000  Fidelity = 0.88116104
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44126768e+00
# P0     = 0.88116104
# P1     = 0.00990771
# P0+P1  = 0.89106876
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00050431
# T = 2     Fidelity = 0.00293680
# T = 5     Fidelity = 0.02095023
# T = 10    Fidelity = 0.10980909
# T = 20    Fidelity = 0.41887924
# T = 30    Fidelity = 0.65875291
# T = 40    Fidelity = 0.73411509
# T = 50    Fidelity = 0.76279612
# T = 75    Fidelity = 0.88327982
# T = 100   Fidelity = 0.93126686
# T = 125   Fidelity = 0.96461517
# T = 150   Fidelity = 0.97963315
# T = 175   Fidelity = 0.98756456
# T = 200   Fidelity = 0.99091883
#
# Minimum T for Fidelity >= 0.99 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00483593
# T = 2     Fidelity = 0.01670314
# T = 5     Fidelity = 0.06243115
# T = 10    Fidelity = 0.18595427
# T = 20    Fidelity = 0.44884476
# T = 30    Fidelity = 0.64648799
# T = 40    Fidelity = 0.75626872
# T = 50    Fidelity = 0.81866383
# T = 75    Fidelity = 0.91084088
# T = 100   Fidelity = 0.95892018
# T = 125   Fidelity = 0.97950646
# T = 150   Fidelity = 0.98948150
# T = 175   Fidelity = 0.99312208
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.02321443
# T = 2     Fidelity = 0.05805989
# T = 5     Fidelity = 0.14325067
# T = 10    Fidelity = 0.29364598
# T = 20    Fidelity = 0.51828883
# T = 30    Fidelity = 0.66424848
# T = 40    Fidelity = 0.75677394
# T = 50    Fidelity = 0.81987958
# T = 75    Fidelity = 0.91607481
# T = 100   Fidelity = 0.96481735
# T = 125   Fidelity = 0.98672225
# T = 150   Fidelity = 0.99460490
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.07164700
# T = 2     Fidelity = 0.14624527
# T = 5     Fidelity = 0.27629215
# T = 10    Fidelity = 0.44415869
# T = 20    Fidelity = 0.63737836
# T = 30    Fidelity = 0.74296649
# T = 40    Fidelity = 0.80918516
# T = 50    Fidelity = 0.85581908
# T = 75    Fidelity = 0.92470915
# T = 100   Fidelity = 0.96033563
# T = 125   Fidelity = 0.97925473
# T = 150   Fidelity = 0.98778114
# T = 175   Fidelity = 0.99182286
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.15531210
# T = 2     Fidelity = 0.27614454
# T = 5     Fidelity = 0.43834825
# T = 10    Fidelity = 0.60397191
# T = 20    Fidelity = 0.76144172
# T = 30    Fidelity = 0.83565600
# T = 40    Fidelity = 0.87985215
# T = 50    Fidelity = 0.90933211
# T = 75    Fidelity = 0.95101199
# T = 100   Fidelity = 0.97218401
# T = 125   Fidelity = 0.98297225
# T = 150   Fidelity = 0.98823630
# T = 175   Fidelity = 0.99205460
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.25529677
# T = 2     Fidelity = 0.41240474
# T = 5     Fidelity = 0.58439776
# T = 10    Fidelity = 0.73144210
# T = 20    Fidelity = 0.85309067
# T = 30    Fidelity = 0.90373979
# T = 40    Fidelity = 0.93187923
# T = 50    Fidelity = 0.94933917
# T = 75    Fidelity = 0.97382195
# T = 100   Fidelity = 0.98488192
# T = 125   Fidelity = 0.99040124
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.35117005
# T = 2     Fidelity = 0.52933031
# T = 5     Fidelity = 0.69485854
# T = 10    Fidelity = 0.81814818
# T = 20    Fidelity = 0.91021787
# T = 30    Fidelity = 0.94419938
# T = 40    Fidelity = 0.96191508
# T = 50    Fidelity = 0.97270536
# T = 75    Fidelity = 0.98629823
# T = 100   Fidelity = 0.99203699
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.40037050e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000117
# T = 10    Fidelity = 0.00113913
# T = 20    Fidelity = 0.00651082
# T = 30    Fidelity = 0.02772903
# T = 40    Fidelity = 0.11882816
# T = 50    Fidelity = 0.09124102
# T = 75    Fidelity = 0.30332578
# T = 100   Fidelity = 0.53462896
# T = 125   Fidelity = 0.55325996
# T = 150   Fidelity = 0.69244393
# T = 175   Fidelity = 0.80299389
# T = 200   Fidelity = 0.78736995
# T = 225   Fidelity = 0.85511928
# T = 250   Fidelity = 0.93628363
# T = 275   Fidelity = 0.73912897
# T = 300   Fidelity = 0.74321520
# T = 400   Fidelity = 0.95570908
# T = 500   Fidelity = 0.95211140
# T = 600   Fidelity = 0.96837379
# T = 700   Fidelity = 0.85562978
# T = 800   Fidelity = 0.83724955
# T = 900   Fidelity = 0.56693547
# T = 1000  Fidelity = 0.69818169
# T = 1010  Fidelity = 0.63514286
# T = 1020  Fidelity = 0.61062137
# T = 1030  Fidelity = 0.63144181
# T = 1040  Fidelity = 0.75867396
# T = 1050  Fidelity = 0.62033841
# T = 1060  Fidelity = 0.68098400
# T = 1070  Fidelity = 0.48130780
# T = 1080  Fidelity = 0.80522449
# T = 1090  Fidelity = 0.65955303
# T = 1100  Fidelity = 0.25723574
# T = 1200  Fidelity = 0.74501230
# T = 1300  Fidelity = 0.51579309
# T = 1400  Fidelity = 0.35194416
# T = 1500  Fidelity = 0.77868848
# T = 2000  Fidelity = 0.50031325
# T = 2100  Fidelity = 0.78889353
# T = 2110  Fidelity = 0.60450646
# T = 2120  Fidelity = 0.75421528
# T = 2130  Fidelity = 0.76869601
# T = 2140  Fidelity = 0.63059770
# T = 2150  Fidelity = 0.32756481
# T = 2160  Fidelity = 0.49930475
# T = 2170  Fidelity = 0.20000762
# T = 2180  Fidelity = 0.19545483
# T = 2190  Fidelity = 0.12322338
# T = 2200  Fidelity = 0.21529707
# T = 2300  Fidelity = 0.51655349
# T = 2400  Fidelity = 0.82105963
# T = 2500  Fidelity = 0.86465685
# T = 2600  Fidelity = 0.95832324
# T = 2700  Fidelity = 0.57980479
# T = 2800  Fidelity = 0.44954396
# T = 2900  Fidelity = 0.84340471
# T = 3000  Fidelity = 0.91249158
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41951501e+00
# P0     = 0.91249158
# P1     = 0.01935119
# P0+P1  = 0.93184277
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.13564004e-03
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00000707
# T = 10    Fidelity = 0.00112657
# T = 20    Fidelity = 0.19600559
# T = 30    Fidelity = 0.53160807
# T = 40    Fidelity = 0.08244643
# T = 50    Fidelity = 0.71283942
# T = 75    Fidelity = 0.50816166
# T = 100   Fidelity = 0.68259375
# T = 125   Fidelity = 0.91734200
# T = 150   Fidelity = 0.91723890
# T = 175   Fidelity = 0.86861686
# T = 200   Fidelity = 0.91331239
# T = 225   Fidelity = 0.95300106
# T = 250   Fidelity = 0.95260516
# T = 275   Fidelity = 0.94152235
# T = 300   Fidelity = 0.96823207
# T = 400   Fidelity = 0.91904454
# T = 500   Fidelity = 0.94865890
# T = 600   Fidelity = 0.88176541
# T = 700   Fidelity = 0.93616628
# T = 800   Fidelity = 0.55546693
# T = 900   Fidelity = 0.78681158
# T = 1000  Fidelity = 0.38976286
# T = 1010  Fidelity = 0.87057275
# T = 1020  Fidelity = 0.74143661
# T = 1030  Fidelity = 0.59845662
# T = 1040  Fidelity = 0.76994586
# T = 1050  Fidelity = 0.85631111
# T = 1060  Fidelity = 0.82543660
# T = 1070  Fidelity = 0.78827253
# T = 1080  Fidelity = 0.53362754
# T = 1090  Fidelity = 0.84563050
# T = 1100  Fidelity = 0.74419013
# T = 1200  Fidelity = 0.87826272
# T = 1300  Fidelity = 0.16480999
# T = 1400  Fidelity = 0.75958461
# T = 1500  Fidelity = 0.47015660
# T = 2000  Fidelity = 0.82980803
# T = 2100  Fidelity = 0.50618393
# T = 2110  Fidelity = 0.42901497
# T = 2120  Fidelity = 0.57307274
# T = 2130  Fidelity = 0.73837135
# T = 2140  Fidelity = 0.67187773
# T = 2150  Fidelity = 0.68192038
# T = 2160  Fidelity = 0.82127249
# T = 2170  Fidelity = 0.73322817
# T = 2180  Fidelity = 0.51581173
# T = 2190  Fidelity = 0.53952595
# T = 2200  Fidelity = 0.78437478
# T = 2300  Fidelity = 0.76849917
# T = 2400  Fidelity = 0.66023401
# T = 2500  Fidelity = 0.82339744
# T = 2600  Fidelity = 0.26394777
# T = 2700  Fidelity = 0.11238308
# T = 2800  Fidelity = 0.50898363
# T = 2900  Fidelity = 0.54453919
# T = 3000  Fidelity = 0.75072536
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43049943e+00
# P0     = 0.75072536
# P1     = 0.08378083
# P0+P1  = 0.83450619
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.00000155
# T = 2     Fidelity = 0.00007280
# T = 5     Fidelity = 0.00176077
# T = 10    Fidelity = 0.03349402
# T = 20    Fidelity = 0.35784521
# T = 30    Fidelity = 0.61459430
# T = 40    Fidelity = 0.36336204
# T = 50    Fidelity = 0.26410924
# T = 75    Fidelity = 0.57944089
# T = 100   Fidelity = 0.44174590
# T = 125   Fidelity = 0.52887754
# T = 150   Fidelity = 0.48162016
# T = 175   Fidelity = 0.50032475
# T = 200   Fidelity = 0.47666089
# T = 225   Fidelity = 0.51534589
# T = 250   Fidelity = 0.48950652
# T = 275   Fidelity = 0.48702086
# T = 300   Fidelity = 0.51224123
# T = 400   Fidelity = 0.50805059
# T = 500   Fidelity = 0.43270463
# T = 600   Fidelity = 0.39899708
# T = 700   Fidelity = 0.27786155
# T = 800   Fidelity = 0.29514105
# T = 900   Fidelity = 0.50647945
# T = 1000  Fidelity = 0.43295763
# T = 1010  Fidelity = 0.28274976
# T = 1020  Fidelity = 0.60135214
# T = 1030  Fidelity = 0.78594097
# T = 1040  Fidelity = 0.61936724
# T = 1050  Fidelity = 0.06744758
# T = 1060  Fidelity = 0.22240191
# T = 1070  Fidelity = 0.61793321
# T = 1080  Fidelity = 0.79416971
# T = 1090  Fidelity = 0.48289883
# T = 1100  Fidelity = 0.19709049
# T = 1200  Fidelity = 0.80901118
# T = 1300  Fidelity = 0.44785614
# T = 1400  Fidelity = 0.22461412
# T = 1500  Fidelity = 0.28600827
# T = 2000  Fidelity = 0.43410248
# T = 2100  Fidelity = 0.17178437
# T = 2110  Fidelity = 0.24611770
# T = 2120  Fidelity = 0.47957278
# T = 2130  Fidelity = 0.53910671
# T = 2140  Fidelity = 0.45428746
# T = 2150  Fidelity = 0.17483800
# T = 2160  Fidelity = 0.37539027
# T = 2170  Fidelity = 0.73638495
# T = 2180  Fidelity = 0.69304771
# T = 2190  Fidelity = 0.41743016
# T = 2200  Fidelity = 0.20077711
# T = 2300  Fidelity = 0.53656124
# T = 2400  Fidelity = 0.69727116
# T = 2500  Fidelity = 0.72234654
# T = 2600  Fidelity = 0.61297529
# T = 2700  Fidelity = 0.56742576
# T = 2800  Fidelity = 0.58598661
# T = 2900  Fidelity = 0.22784749
# T = 3000  Fidelity = 0.41499246
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44121779e+00
# P0     = 0.41499246
# P1     = 0.02951696
# P0+P1  = 0.44450942
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05663390e-03
# T = 1     Fidelity = 0.00180467
# T = 2     Fidelity = 0.00874234
# T = 5     Fidelity = 0.04028712
# T = 10    Fidelity = 0.14627805
# T = 20    Fidelity = 0.35550046
# T = 30    Fidelity = 0.38167474
# T = 40    Fidelity = 0.32515849
# T = 50    Fidelity = 0.32597452
# T = 75    Fidelity = 0.55880556
# T = 100   Fidelity = 0.55992265
# T = 125   Fidelity = 0.50569893
# T = 150   Fidelity = 0.52345667
# T = 175   Fidelity = 0.52800175
# T = 200   Fidelity = 0.52056286
# T = 225   Fidelity = 0.49553518
# T = 250   Fidelity = 0.49562777
# T = 275   Fidelity = 0.49731749
# T = 300   Fidelity = 0.48285485
# T = 400   Fidelity = 0.51217350
# T = 500   Fidelity = 0.50140440
# T = 600   Fidelity = 0.55920264
# T = 700   Fidelity = 0.53649633
# T = 800   Fidelity = 0.58764165
# T = 900   Fidelity = 0.65736846
# T = 1000  Fidelity = 0.63566577
# T = 1010  Fidelity = 0.55451639
# T = 1020  Fidelity = 0.51218024
# T = 1030  Fidelity = 0.29588194
# T = 1040  Fidelity = 0.13308325
# T = 1050  Fidelity = 0.32210729
# T = 1060  Fidelity = 0.53331841
# T = 1070  Fidelity = 0.81401029
# T = 1080  Fidelity = 0.83653397
# T = 1090  Fidelity = 0.63298525
# T = 1100  Fidelity = 0.58279660
# T = 1200  Fidelity = 0.83138673
# T = 1300  Fidelity = 0.71929817
# T = 1400  Fidelity = 0.48486768
# T = 1500  Fidelity = 0.64969643
# T = 2000  Fidelity = 0.46398486
# T = 2100  Fidelity = 0.47491633
# T = 2110  Fidelity = 0.16596330
# T = 2120  Fidelity = 0.19691425
# T = 2130  Fidelity = 0.35387305
# T = 2140  Fidelity = 0.49057470
# T = 2150  Fidelity = 0.42579969
# T = 2160  Fidelity = 0.56932547
# T = 2170  Fidelity = 0.51535999
# T = 2180  Fidelity = 0.64136179
# T = 2190  Fidelity = 0.60830710
# T = 2200  Fidelity = 0.66407688
# T = 2300  Fidelity = 0.57831131
# T = 2400  Fidelity = 0.35037189
# T = 2500  Fidelity = 0.71826805
# T = 2600  Fidelity = 0.68466347
# T = 2700  Fidelity = 0.67947742
# T = 2800  Fidelity = 0.60632579
# T = 2900  Fidelity = 0.39610917
# T = 3000  Fidelity = 0.40757350
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.45168821e+00
# P0     = 0.40757350
# P1     = 0.01330005
# P0+P1  = 0.42087355
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 5.88899605e-03
# T = 1     Fidelity = 0.01682911
# T = 2     Fidelity = 0.05151259
# T = 5     Fidelity = 0.13904809
# T = 10    Fidelity = 0.31436122
# T = 20    Fidelity = 0.55038369
# T = 30    Fidelity = 0.62704614
# T = 40    Fidelity = 0.61105452
# T = 50    Fidelity = 0.57956817
# T = 75    Fidelity = 0.55886991
# T = 100   Fidelity = 0.60020490
# T = 125   Fidelity = 0.62826081
# T = 150   Fidelity = 0.63558776
# T = 175   Fidelity = 0.64413413
# T = 200   Fidelity = 0.64393933
# T = 225   Fidelity = 0.67545178
# T = 250   Fidelity = 0.68034057
# T = 275   Fidelity = 0.67196470
# T = 300   Fidelity = 0.68397961
# T = 400   Fidelity = 0.70724851
# T = 500   Fidelity = 0.60528284
# T = 600   Fidelity = 0.55920613
# T = 700   Fidelity = 0.72598563
# T = 800   Fidelity = 0.76599831
# T = 900   Fidelity = 0.58789354
# T = 1000  Fidelity = 0.64452473
# T = 1010  Fidelity = 0.71472037
# T = 1020  Fidelity = 0.81831470
# T = 1030  Fidelity = 0.82681074
# T = 1040  Fidelity = 0.75579725
# T = 1050  Fidelity = 0.67504680
# T = 1060  Fidelity = 0.62726770
# T = 1070  Fidelity = 0.53811999
# T = 1080  Fidelity = 0.48016894
# T = 1090  Fidelity = 0.56507476
# T = 1100  Fidelity = 0.67601322
# T = 1200  Fidelity = 0.52248056
# T = 1300  Fidelity = 0.67811620
# T = 1400  Fidelity = 0.73822177
# T = 1500  Fidelity = 0.85034897
# T = 2000  Fidelity = 0.80423663
# T = 2100  Fidelity = 0.68651794
# T = 2110  Fidelity = 0.69200932
# T = 2120  Fidelity = 0.61555650
# T = 2130  Fidelity = 0.63339179
# T = 2140  Fidelity = 0.68445167
# T = 2150  Fidelity = 0.86960943
# T = 2160  Fidelity = 0.87261629
# T = 2170  Fidelity = 0.85451624
# T = 2180  Fidelity = 0.76762403
# T = 2190  Fidelity = 0.63475637
# T = 2200  Fidelity = 0.63783930
# T = 2300  Fidelity = 0.66422299
# T = 2400  Fidelity = 0.71593787
# T = 2500  Fidelity = 0.78587355
# T = 2600  Fidelity = 0.40361405
# T = 2700  Fidelity = 0.82208469
# T = 2800  Fidelity = 0.60485911
# T = 2900  Fidelity = 0.72279250
# T = 3000  Fidelity = 0.81618763
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.46192674e+00
# P0     = 0.81618763
# P1     = 0.00321882
# P0+P1  = 0.81940644
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 3.15736806e-02
# T = 1     Fidelity = 0.06407769
# T = 2     Fidelity = 0.14809042
# T = 5     Fidelity = 0.29259121
# T = 10    Fidelity = 0.49827321
# T = 20    Fidelity = 0.70619719
# T = 30    Fidelity = 0.78172538
# T = 40    Fidelity = 0.79725130
# T = 50    Fidelity = 0.79497493
# T = 75    Fidelity = 0.78960478
# T = 100   Fidelity = 0.79650399
# T = 125   Fidelity = 0.80619527
# T = 150   Fidelity = 0.81375930
# T = 175   Fidelity = 0.82329359
# T = 200   Fidelity = 0.82907761
# T = 225   Fidelity = 0.83522153
# T = 250   Fidelity = 0.84638232
# T = 275   Fidelity = 0.83456970
# T = 300   Fidelity = 0.85835030
# T = 400   Fidelity = 0.85788202
# T = 500   Fidelity = 0.82494137
# T = 600   Fidelity = 0.83326480
# T = 700   Fidelity = 0.69578766
# T = 800   Fidelity = 0.93227742
# T = 900   Fidelity = 0.87038068
# T = 1000  Fidelity = 0.87088626
# T = 1010  Fidelity = 0.88469025
# T = 1020  Fidelity = 0.84347006
# T = 1030  Fidelity = 0.78459342
# T = 1040  Fidelity = 0.81682782
# T = 1050  Fidelity = 0.88065622
# T = 1060  Fidelity = 0.89076892
# T = 1070  Fidelity = 0.92593412
# T = 1080  Fidelity = 0.96608200
# T = 1090  Fidelity = 0.97753661
# T = 1100  Fidelity = 0.97799548
# T = 1200  Fidelity = 0.83651042
# T = 1300  Fidelity = 0.92363151
# T = 1400  Fidelity = 0.72147036
# T = 1500  Fidelity = 0.89012870
# T = 2000  Fidelity = 0.88131689
# T = 2100  Fidelity = 0.78944475
# T = 2110  Fidelity = 0.79089230
# T = 2120  Fidelity = 0.73361564
# T = 2130  Fidelity = 0.70626467
# T = 2140  Fidelity = 0.83688473
# T = 2150  Fidelity = 0.95901156
# T = 2160  Fidelity = 0.89206927
# T = 2170  Fidelity = 0.88462576
# T = 2180  Fidelity = 0.94224638
# T = 2190  Fidelity = 0.87894845
# T = 2200  Fidelity = 0.93874374
# T = 2300  Fidelity = 0.90347406
# T = 2400  Fidelity = 0.96144826
# T = 2500  Fidelity = 0.94028526
# T = 2600  Fidelity = 0.86772975
# T = 2700  Fidelity = 0.92443482
# T = 2800  Fidelity = 0.95697429
# T = 2900  Fidelity = 0.76187543
# T = 3000  Fidelity = 0.94958337
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.47194767e+00
# P0     = 0.94958337
# P1     = 0.00006298
# P0+P1  = 0.94964635
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.80738351e-02
# T = 1     Fidelity = 0.14511859
# T = 2     Fidelity = 0.28038466
# T = 5     Fidelity = 0.45749115
# T = 10    Fidelity = 0.65423600
# T = 20    Fidelity = 0.81533562
# T = 30    Fidelity = 0.87182165
# T = 40    Fidelity = 0.89340151
# T = 50    Fidelity = 0.90213899
# T = 75    Fidelity = 0.91277741
# T = 100   Fidelity = 0.92089466
# T = 125   Fidelity = 0.92894688
# T = 150   Fidelity = 0.93532067
# T = 175   Fidelity = 0.94352059
# T = 200   Fidelity = 0.94968259
# T = 225   Fidelity = 0.93635135
# T = 250   Fidelity = 0.94417889
# T = 275   Fidelity = 0.94859284
# T = 300   Fidelity = 0.96220990
# T = 400   Fidelity = 0.95708356
# T = 500   Fidelity = 0.93355642
# T = 600   Fidelity = 0.94606541
# T = 700   Fidelity = 0.89796873
# T = 800   Fidelity = 0.94157313
# T = 900   Fidelity = 0.93755122
# T = 1000  Fidelity = 0.92662260
# T = 1010  Fidelity = 0.97183228
# T = 1020  Fidelity = 0.97412590
# T = 1030  Fidelity = 0.93912321
# T = 1040  Fidelity = 0.96606873
# T = 1050  Fidelity = 0.98265278
# T = 1060  Fidelity = 0.98489910
# T = 1070  Fidelity = 0.98024725
# T = 1080  Fidelity = 0.98447877
# T = 1090  Fidelity = 0.92855089
# T = 1100  Fidelity = 0.97029681
# T = 1200  Fidelity = 0.93131459
# T = 1300  Fidelity = 0.95385035
# T = 1400  Fidelity = 0.91402703
# T = 1500  Fidelity = 0.96716002
# T = 2000  Fidelity = 0.91060371
# T = 2100  Fidelity = 0.92761475
# T = 2110  Fidelity = 0.92590577
# T = 2120  Fidelity = 0.88770411
# T = 2130  Fidelity = 0.94619858
# T = 2140  Fidelity = 0.90984573
# T = 2150  Fidelity = 0.93446072
# T = 2160  Fidelity = 0.91121968
# T = 2170  Fidelity = 0.94513074
# T = 2180  Fidelity = 0.89584952
# T = 2190  Fidelity = 0.94231207
# T = 2200  Fidelity = 0.89532249
# T = 2300  Fidelity = 0.96990527
# T = 2400  Fidelity = 0.89277830
# T = 2500  Fidelity = 0.95243304
# T = 2600  Fidelity = 0.94489665
# T = 2700  Fidelity = 0.93006371
# T = 2800  Fidelity = 0.93875659
# T = 2900  Fidelity = 0.95153670
# T = 3000  Fidelity = 0.90447997
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.48176382e+00
# P0     = 0.90447997
# P1     = 0.00000994
# P0+P1  = 0.90448991
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.28699899e-01
# T = 1     Fidelity = 0.23723483
# T = 2     Fidelity = 0.40856433
# T = 5     Fidelity = 0.59233359
# T = 10    Fidelity = 0.76245940
# T = 20    Fidelity = 0.88364190
# T = 30    Fidelity = 0.92425234
# T = 40    Fidelity = 0.94156406
# T = 50    Fidelity = 0.95047325
# T = 75    Fidelity = 0.96141888
# T = 100   Fidelity = 0.96924369
# T = 125   Fidelity = 0.97459074
# T = 150   Fidelity = 0.97836039
# T = 175   Fidelity = 0.98219852
# T = 200   Fidelity = 0.98468299
# T = 225   Fidelity = 0.97043719
# T = 250   Fidelity = 0.97610373
# T = 275   Fidelity = 0.97918392
# T = 300   Fidelity = 0.98561092
# T = 400   Fidelity = 0.98176660
# T = 500   Fidelity = 0.97306577
# T = 600   Fidelity = 0.91592648
# T = 700   Fidelity = 0.93494827
# T = 800   Fidelity = 0.98651545
# T = 900   Fidelity = 0.99315096
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.76942225e-01
# T = 1     Fidelity = 0.33068085
# T = 2     Fidelity = 0.52256757
# T = 5     Fidelity = 0.69678137
# T = 10    Fidelity = 0.83578585
# T = 20    Fidelity = 0.92560674
# T = 30    Fidelity = 0.95437894
# T = 40    Fidelity = 0.96613082
# T = 50    Fidelity = 0.97236310
# T = 75    Fidelity = 0.98215681
# T = 100   Fidelity = 0.98641689
# T = 125   Fidelity = 0.98962570
# T = 150   Fidelity = 0.99202137
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.20505613e-01
# T = 1     Fidelity = 0.41290320
# T = 2     Fidelity = 0.61283305
# T = 5     Fidelity = 0.77098512
# T = 10    Fidelity = 0.88314010
# T = 20    Fidelity = 0.95119686
# T = 30    Fidelity = 0.97144537
# T = 40    Fidelity = 0.97941979
# T = 50    Fidelity = 0.98444065
# T = 75    Fidelity = 0.99019978
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.06623659e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000002
# T = 5     Fidelity = 0.00012906
# T = 10    Fidelity = 0.00608715
# T = 20    Fidelity = 0.15892823
# T = 30    Fidelity = 0.48868816
# T = 40    Fidelity = 0.76151616
# T = 50    Fidelity = 0.90718079
# T = 75    Fidelity = 0.99126930
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.20609288e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00103219
# T = 10    Fidelity = 0.19782950
# T = 20    Fidelity = 0.88965235
# T = 30    Fidelity = 0.96782945
# T = 40    Fidelity = 0.99268198
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.76105909e-01
# T = 1     Fidelity = 0.00000760
# T = 2     Fidelity = 0.00013594
# T = 5     Fidelity = 0.03105624
# T = 10    Fidelity = 0.55753048
# T = 20    Fidelity = 0.90011996
# T = 30    Fidelity = 0.98459858
# T = 40    Fidelity = 0.98001551
# T = 50    Fidelity = 0.98477857
# T = 75    Fidelity = 0.98905776
# T = 100   Fidelity = 0.99011246
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.12909217e-01
# T = 1     Fidelity = 0.00022368
# T = 2     Fidelity = 0.00258975
# T = 5     Fidelity = 0.10768440
# T = 10    Fidelity = 0.68843222
# T = 20    Fidelity = 0.94889919
# T = 30    Fidelity = 0.98814402
# T = 40    Fidelity = 0.99006475
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.40169449e-01
# T = 1     Fidelity = 0.00168586
# T = 2     Fidelity = 0.01157261
# T = 5     Fidelity = 0.20831456
# T = 10    Fidelity = 0.76447996
# T = 20    Fidelity = 0.97093279
# T = 30    Fidelity = 0.99023761
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.61748289e-01
# T = 1     Fidelity = 0.00659441
# T = 2     Fidelity = 0.03053968
# T = 5     Fidelity = 0.30395202
# T = 10    Fidelity = 0.80448759
# T = 20    Fidelity = 0.97930262
# T = 30    Fidelity = 0.98992662
# T = 40    Fidelity = 0.99520883
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.79340685e-01
# T = 1     Fidelity = 0.01694157
# T = 2     Fidelity = 0.05976095
# T = 5     Fidelity = 0.39403721
# T = 10    Fidelity = 0.83456560
# T = 20    Fidelity = 0.98421535
# T = 30    Fidelity = 0.99097355
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.94021606e-01
# T = 1     Fidelity = 0.03393215
# T = 2     Fidelity = 0.09788335
# T = 5     Fidelity = 0.47287390
# T = 10    Fidelity = 0.85545438
# T = 20    Fidelity = 0.98563789
# T = 30    Fidelity = 0.99141606
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.06402712e-01
# T = 1     Fidelity = 0.05737662
# T = 2     Fidelity = 0.14255671
# T = 5     Fidelity = 0.54228158
# T = 10    Fidelity = 0.87308079
# T = 20    Fidelity = 0.98586256
# T = 30    Fidelity = 0.99188198
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.17036009e-01
# T = 1     Fidelity = 0.08654546
# T = 2     Fidelity = 0.19124115
# T = 5     Fidelity = 0.60265897
# T = 10    Fidelity = 0.88876132
# T = 20    Fidelity = 0.98588119
# T = 30    Fidelity = 0.99244804
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9933435213      1.01220263e+00    None        None        None
# Symmetric      0.311     2         0.9942227661      1.03626623e+00    None        None        None
# Symmetric      0.522     2         0.9949099626      1.05846299e+00    None        None        None
# Symmetric      0.733     2         0.9954626300      1.07916278e+00    None        None        None
# Symmetric      0.944     2         0.9959184013      1.09862393e+00    None        None        None
# Symmetric      1.156     2         0.9962898556      1.11703633e+00    None        None        None
# Symmetric      1.367     2         0.9966040898      1.13454489e+00    None        None        None
# Symmetric      1.578     2         0.9968649720      1.15126343e+00    None        None        None
# Symmetric      1.789     2         0.9971112646      1.16728342e+00    None        None        None
# Symmetric      2.000     2         0.9972797789      1.18267976e+00    None        None        None
# Weak SSB optimised0.100     None      0.9310909887      2.43127858e-01    0.918191    0.009302    0.927493
# Weak SSB optimised0.311     None      0.9724979081      2.61673084e-01    0.873367    0.038082    0.911449
# Weak SSB optimised0.522     None      0.9856042434      2.64768458e-01    0.881161    0.009908    0.891069
# Weak SSB optimised0.733     200       0.9909188312      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     175       0.9931220816      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     150       0.9946049021      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     175       0.9918228570      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     175       0.9920546015      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9904012389      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     100       0.9920369860      2.55131735e-01    None        None        None
# Weak SSB       0.100     None      0.9683737864      1.40037050e-03    0.912492    0.019351    0.931843
# Weak SSB       0.311     None      0.9682320711      1.13564004e-03    0.750725    0.083781    0.834506
# Weak SSB       0.522     None      0.8090111751      1.05614584e-03    0.414992    0.029517    0.444509
# Weak SSB       0.733     None      0.8365339738      1.05663390e-03    0.407573    0.0133      0.420874
# Weak SSB       0.944     None      0.8726162909      5.88899605e-03    0.816188    0.003219    0.819406
# Weak SSB       1.156     None      0.9779954767      3.15736806e-02    0.949583    6.3e-05     0.949646
# Weak SSB       1.367     None      0.9848991008      7.80738351e-02    0.90448     1e-05       0.90449
# Weak SSB       1.578     900       0.9931509576      1.28699899e-01    None        None        None
# Weak SSB       1.789     150       0.9920213665      1.76942225e-01    None        None        None
# Weak SSB       2.000     75        0.9901997847      2.20505613e-01    None        None        None
# Strong SSB     0.100     75        0.9912693006      6.06623659e-01    None        None        None
# Strong SSB     0.311     40        0.9926819774      7.20609288e-01    None        None        None
# Strong SSB     0.522     100       0.9901124578      7.76105909e-01    None        None        None
# Strong SSB     0.733     40        0.9900647484      8.12909217e-01    None        None        None
# Strong SSB     0.944     30        0.9902376082      8.40169449e-01    None        None        None
# Strong SSB     1.156     40        0.9952088281      8.61748289e-01    None        None        None
# Strong SSB     1.367     30        0.9909735510      8.79340685e-01    None        None        None
# Strong SSB     1.578     30        0.9914160573      8.94021606e-01    None        None        None
# Strong SSB     1.789     30        0.9918819803      9.06402712e-01    None        None        None
# Strong SSB     2.000     30        0.9924480359      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)


    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan
    
lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

# %%
########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009572
# T = 10    Fidelity = 0.00119335
# T = 20    Fidelity = 0.02687192
# T = 30    Fidelity = 0.09666872
# T = 40    Fidelity = 0.19609681
# T = 50    Fidelity = 0.31173736
# T = 75    Fidelity = 0.56619493
# T = 100   Fidelity = 0.72001723
# T = 125   Fidelity = 0.80738573
# T = 150   Fidelity = 0.86469822
# T = 175   Fidelity = 0.90864231
# T = 200   Fidelity = 0.94629737
# T = 225   Fidelity = 0.96686611
# T = 250   Fidelity = 0.95352155
# T = 275   Fidelity = 0.98204340
# T = 300   Fidelity = 0.96282231
# T = 400   Fidelity = 0.95497367
# T = 500   Fidelity = 0.93802502
# T = 600   Fidelity = 0.90703302
# T = 700   Fidelity = 0.99336243
#
# Minimum T for Fidelity >= 0.99 : 700
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624068e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144379
# T = 10    Fidelity = 0.10202555
# T = 20    Fidelity = 0.52982876
# T = 30    Fidelity = 0.63893875
# T = 40    Fidelity = 0.76792858
# T = 50    Fidelity = 0.88385407
# T = 75    Fidelity = 0.94225886
# T = 100   Fidelity = 0.97306534
# T = 125   Fidelity = 0.99693417
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043113e-07
# T = 1     Fidelity = 0.00005041
# T = 2     Fidelity = 0.00043554
# T = 5     Fidelity = 0.02724130
# T = 10    Fidelity = 0.28402875
# T = 20    Fidelity = 0.77880737
# T = 30    Fidelity = 0.80543023
# T = 40    Fidelity = 0.95119979
# T = 50    Fidelity = 0.93701108
# T = 75    Fidelity = 0.99144674
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155098
# T = 2     Fidelity = 0.00639909
# T = 5     Fidelity = 0.08483209
# T = 10    Fidelity = 0.38786424
# T = 20    Fidelity = 0.90882633
# T = 30    Fidelity = 0.89422990
# T = 40    Fidelity = 0.97221645
# T = 50    Fidelity = 0.99231953
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01058353
# T = 2     Fidelity = 0.02892151
# T = 5     Fidelity = 0.16449866
# T = 10    Fidelity = 0.46788237
# T = 20    Fidelity = 0.92253994
# T = 30    Fidelity = 0.97977755
# T = 40    Fidelity = 0.97236634
# T = 50    Fidelity = 0.99387723
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03666270
# T = 2     Fidelity = 0.07744091
# T = 5     Fidelity = 0.25989105
# T = 10    Fidelity = 0.54099094
# T = 20    Fidelity = 0.90447414
# T = 30    Fidelity = 0.99651070
#
# Minimum T for Fidelity >= 0.99 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08776494
# T = 2     Fidelity = 0.15531492
# T = 5     Fidelity = 0.36741597
# T = 10    Fidelity = 0.61611013
# T = 20    Fidelity = 0.89397149
# T = 30    Fidelity = 0.98167589
# T = 40    Fidelity = 0.99755590
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16578787
# T = 2     Fidelity = 0.25896957
# T = 5     Fidelity = 0.48155021
# T = 10    Fidelity = 0.69440102
# T = 20    Fidelity = 0.90354195
# T = 30    Fidelity = 0.97294067
# T = 40    Fidelity = 0.99114918
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26378783
# T = 2     Fidelity = 0.37665108
# T = 5     Fidelity = 0.59238323
# T = 10    Fidelity = 0.76981720
# T = 20    Fidelity = 0.92543831
# T = 30    Fidelity = 0.97248307
# T = 40    Fidelity = 0.98678858
# T = 50    Fidelity = 0.99324673
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36878412
# T = 2     Fidelity = 0.49274259
# T = 5     Fidelity = 0.68999973
# T = 10    Fidelity = 0.83495393
# T = 20    Fidelity = 0.94707359
# T = 30    Fidelity = 0.97596415
# T = 40    Fidelity = 0.98838073
# T = 50    Fidelity = 0.99291170
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.62161156
# T = 2     Fidelity = 0.65040042
# T = 5     Fidelity = 0.70699787
# T = 10    Fidelity = 0.76176513
# T = 20    Fidelity = 0.82840026
# T = 30    Fidelity = 0.86920968
# T = 40    Fidelity = 0.89770280
# T = 50    Fidelity = 0.91799818
# T = 75    Fidelity = 0.94934877
# T = 100   Fidelity = 0.96631795
# T = 125   Fidelity = 0.97468156
# T = 150   Fidelity = 0.98085143
# T = 175   Fidelity = 0.98172795
# T = 200   Fidelity = 0.98727842
# T = 225   Fidelity = 0.97861991
# T = 250   Fidelity = 0.98554788
# T = 275   Fidelity = 0.95566882
# T = 300   Fidelity = 0.93878858
# T = 400   Fidelity = 0.97104924
# T = 500   Fidelity = 0.97616106
# T = 600   Fidelity = 0.94366251
# T = 700   Fidelity = 0.81163902
# T = 800   Fidelity = 0.94241022
# T = 900   Fidelity = 0.98445288
# T = 1000  Fidelity = 0.97579909
# T = 1010  Fidelity = 0.95571589
# T = 1020  Fidelity = 0.94299803
# T = 1030  Fidelity = 0.95702006
# T = 1040  Fidelity = 0.96838971
# T = 1050  Fidelity = 0.96528987
# T = 1060  Fidelity = 0.96738410
# T = 1070  Fidelity = 0.97126571
# T = 1080  Fidelity = 0.98806407
# T = 1090  Fidelity = 0.99148659
#
# Minimum T for Fidelity >= 0.99 : 1090
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.72506938
# T = 2     Fidelity = 0.73277583
# T = 5     Fidelity = 0.76089040
# T = 10    Fidelity = 0.79126506
# T = 20    Fidelity = 0.82714628
# T = 30    Fidelity = 0.85039433
# T = 40    Fidelity = 0.86751251
# T = 50    Fidelity = 0.88126936
# T = 75    Fidelity = 0.90616549
# T = 100   Fidelity = 0.92352946
# T = 125   Fidelity = 0.93579871
# T = 150   Fidelity = 0.94456412
# T = 175   Fidelity = 0.95626130
# T = 200   Fidelity = 0.95914959
# T = 225   Fidelity = 0.96424854
# T = 250   Fidelity = 0.95961633
# T = 275   Fidelity = 0.97105718
# T = 300   Fidelity = 0.97598639
# T = 400   Fidelity = 0.98127733
# T = 500   Fidelity = 0.96486895
# T = 600   Fidelity = 0.96965104
# T = 700   Fidelity = 0.98232813
# T = 800   Fidelity = 0.94054425
# T = 900   Fidelity = 0.91385339
# T = 1000  Fidelity = 0.91527294
# T = 1010  Fidelity = 0.91430058
# T = 1020  Fidelity = 0.91096213
# T = 1030  Fidelity = 0.91030096
# T = 1040  Fidelity = 0.90666452
# T = 1050  Fidelity = 0.90579073
# T = 1060  Fidelity = 0.90382960
# T = 1070  Fidelity = 0.90632605
# T = 1080  Fidelity = 0.90681516
# T = 1090  Fidelity = 0.90875065
# T = 1100  Fidelity = 0.90677395
# T = 1200  Fidelity = 0.92596999
# T = 1300  Fidelity = 0.95945206
# T = 1400  Fidelity = 0.96766426
# T = 1500  Fidelity = 0.96664509
# T = 2000  Fidelity = 0.95051184
# T = 2100  Fidelity = 0.94194801
# T = 2110  Fidelity = 0.94458417
# T = 2120  Fidelity = 0.94640296
# T = 2130  Fidelity = 0.94670487
# T = 2140  Fidelity = 0.94202196
# T = 2150  Fidelity = 0.94370018
# T = 2160  Fidelity = 0.94089719
# T = 2170  Fidelity = 0.93985769
# T = 2180  Fidelity = 0.93696332
# T = 2190  Fidelity = 0.93625821
# T = 2200  Fidelity = 0.93552062
# T = 2300  Fidelity = 0.90405125
# T = 2400  Fidelity = 0.96779252
# T = 2500  Fidelity = 0.97192969
# T = 2600  Fidelity = 0.94374044
# T = 2700  Fidelity = 0.92794899
# T = 2800  Fidelity = 0.93017619
# T = 2900  Fidelity = 0.93986196
# T = 3000  Fidelity = 0.95872724
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.71621181e-01
# P0     = 0.95872724
# P1     = 0.02102085
# P0+P1  = 0.97974809
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.98235048
# T = 2     Fidelity = 0.98997760
# T = 5     Fidelity = 0.99153271
#
# Minimum T for Fidelity >= 0.99 : 5
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98590763
# T = 2     Fidelity = 0.99519854
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97964175
# T = 2     Fidelity = 0.99113065
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.94920007
# T = 2     Fidelity = 0.96540752
# T = 5     Fidelity = 0.97715613
# T = 10    Fidelity = 0.98106440
# T = 20    Fidelity = 0.98479910
# T = 30    Fidelity = 0.98736967
# T = 40    Fidelity = 0.98869828
# T = 50    Fidelity = 0.98973247
# T = 75    Fidelity = 0.99173701
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.87874194
# T = 2     Fidelity = 0.90168304
# T = 5     Fidelity = 0.92601215
# T = 10    Fidelity = 0.93620603
# T = 20    Fidelity = 0.95064890
# T = 30    Fidelity = 0.95733911
# T = 40    Fidelity = 0.96309819
# T = 50    Fidelity = 0.96663075
# T = 75    Fidelity = 0.97360605
# T = 100   Fidelity = 0.97836684
# T = 125   Fidelity = 0.98162755
# T = 150   Fidelity = 0.98402187
# T = 175   Fidelity = 0.98599358
# T = 200   Fidelity = 0.98738417
# T = 225   Fidelity = 0.98864859
# T = 250   Fidelity = 0.98976252
# T = 275   Fidelity = 0.99076223
#
# Minimum T for Fidelity >= 0.99 : 275
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78672850
# T = 2     Fidelity = 0.81701263
# T = 5     Fidelity = 0.85587988
# T = 10    Fidelity = 0.87774951
# T = 20    Fidelity = 0.90933470
# T = 30    Fidelity = 0.92370913
# T = 40    Fidelity = 0.93446005
# T = 50    Fidelity = 0.94297844
# T = 75    Fidelity = 0.95689884
# T = 100   Fidelity = 0.96594244
# T = 125   Fidelity = 0.97218693
# T = 150   Fidelity = 0.97669910
# T = 175   Fidelity = 0.98034672
# T = 200   Fidelity = 0.98278015
# T = 225   Fidelity = 0.98473300
# T = 250   Fidelity = 0.98680108
# T = 275   Fidelity = 0.98825583
# T = 300   Fidelity = 0.98954821
# T = 400   Fidelity = 0.99266624
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.71838745
# T = 2     Fidelity = 0.75506915
# T = 5     Fidelity = 0.80567520
# T = 10    Fidelity = 0.84209494
# T = 20    Fidelity = 0.89082779
# T = 30    Fidelity = 0.91245126
# T = 40    Fidelity = 0.92953640
# T = 50    Fidelity = 0.93930842
# T = 75    Fidelity = 0.95829875
# T = 100   Fidelity = 0.96968367
# T = 125   Fidelity = 0.97700253
# T = 150   Fidelity = 0.98195668
# T = 175   Fidelity = 0.98543826
# T = 200   Fidelity = 0.98780256
# T = 225   Fidelity = 0.98962124
# T = 250   Fidelity = 0.99108044
#
# Minimum T for Fidelity >= 0.99 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.69132238
# T = 2     Fidelity = 0.73352963
# T = 5     Fidelity = 0.79212748
# T = 10    Fidelity = 0.83991234
# T = 20    Fidelity = 0.90288008
# T = 30    Fidelity = 0.92660358
# T = 40    Fidelity = 0.94539503
# T = 50    Fidelity = 0.95630870
# T = 75    Fidelity = 0.97316378
# T = 100   Fidelity = 0.98211091
# T = 125   Fidelity = 0.98735491
# T = 150   Fidelity = 0.99060653
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.35126357e-02
# T = 1     Fidelity = 0.59216868
# T = 2     Fidelity = 0.63725257
# T = 5     Fidelity = 0.71843758
# T = 10    Fidelity = 0.79572531
# T = 20    Fidelity = 0.87736176
# T = 30    Fidelity = 0.92001898
# T = 40    Fidelity = 0.94508359
# T = 50    Fidelity = 0.96046778
# T = 75    Fidelity = 0.97929857
# T = 100   Fidelity = 0.98528099
# T = 125   Fidelity = 0.98653901
# T = 150   Fidelity = 0.98960344
# T = 175   Fidelity = 0.98849494
# T = 200   Fidelity = 0.97825298
# T = 225   Fidelity = 0.99180071
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.91075005e-03
# T = 1     Fidelity = 0.44178200
# T = 2     Fidelity = 0.45487316
# T = 5     Fidelity = 0.49546970
# T = 10    Fidelity = 0.54662009
# T = 20    Fidelity = 0.61230214
# T = 30    Fidelity = 0.65769636
# T = 40    Fidelity = 0.69239348
# T = 50    Fidelity = 0.72011999
# T = 75    Fidelity = 0.77055832
# T = 100   Fidelity = 0.80364219
# T = 125   Fidelity = 0.82830973
# T = 150   Fidelity = 0.84576328
# T = 175   Fidelity = 0.85636941
# T = 200   Fidelity = 0.87511700
# T = 225   Fidelity = 0.88103803
# T = 250   Fidelity = 0.88726003
# T = 275   Fidelity = 0.88014165
# T = 300   Fidelity = 0.89411928
# T = 400   Fidelity = 0.92120078
# T = 500   Fidelity = 0.94400878
# T = 600   Fidelity = 0.95019521
# T = 700   Fidelity = 0.79511419
# T = 800   Fidelity = 0.77456467
# T = 900   Fidelity = 0.83841734
# T = 1000  Fidelity = 0.91635439
# T = 1010  Fidelity = 0.90084087
# T = 1020  Fidelity = 0.89131267
# T = 1030  Fidelity = 0.90640531
# T = 1040  Fidelity = 0.93221871
# T = 1050  Fidelity = 0.94352860
# T = 1060  Fidelity = 0.93588202
# T = 1070  Fidelity = 0.91819835
# T = 1080  Fidelity = 0.90459827
# T = 1090  Fidelity = 0.89511589
# T = 1100  Fidelity = 0.90886692
# T = 1200  Fidelity = 0.92837384
# T = 1300  Fidelity = 0.95004503
# T = 1400  Fidelity = 0.97433650
# T = 1500  Fidelity = 0.87100721
# T = 2000  Fidelity = 0.85864206
# T = 2100  Fidelity = 0.93754094
# T = 2110  Fidelity = 0.93766964
# T = 2120  Fidelity = 0.94934813
# T = 2130  Fidelity = 0.96325833
# T = 2140  Fidelity = 0.97602668
# T = 2150  Fidelity = 0.98704344
# T = 2160  Fidelity = 0.99175176
#
# Minimum T for Fidelity >= 0.99 : 2160
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.25177666
# T = 2     Fidelity = 0.25366202
# T = 5     Fidelity = 0.25413139
# T = 10    Fidelity = 0.25431570
# T = 20    Fidelity = 0.25436561
# T = 30    Fidelity = 0.25439692
# T = 40    Fidelity = 0.25447831
# T = 50    Fidelity = 0.25452555
# T = 75    Fidelity = 0.25471486
# T = 100   Fidelity = 0.25484823
# T = 125   Fidelity = 0.25484053
# T = 150   Fidelity = 0.25483722
# T = 175   Fidelity = 0.25321602
# T = 200   Fidelity = 0.25567807
# T = 225   Fidelity = 0.25348058
# T = 250   Fidelity = 0.25528554
# T = 275   Fidelity = 0.25505550
# T = 300   Fidelity = 0.25546711
# T = 400   Fidelity = 0.25366994
# T = 500   Fidelity = 0.25524602
# T = 600   Fidelity = 0.25531119
# T = 700   Fidelity = 0.25903238
# T = 800   Fidelity = 0.25676316
# T = 900   Fidelity = 0.25192103
# T = 1000  Fidelity = 0.25641260
# T = 1010  Fidelity = 0.25782981
# T = 1020  Fidelity = 0.25369088
# T = 1030  Fidelity = 0.25735075
# T = 1040  Fidelity = 0.25866772
# T = 1050  Fidelity = 0.25833199
# T = 1060  Fidelity = 0.25519190
# T = 1070  Fidelity = 0.25427139
# T = 1080  Fidelity = 0.25548356
# T = 1090  Fidelity = 0.25378526
# T = 1100  Fidelity = 0.25341316
# T = 1200  Fidelity = 0.25565733
# T = 1300  Fidelity = 0.25728553
# T = 1400  Fidelity = 0.25661466
# T = 1500  Fidelity = 0.25627238
# T = 2000  Fidelity = 0.25652188
# T = 2100  Fidelity = 0.25691793
# T = 2110  Fidelity = 0.25487278
# T = 2120  Fidelity = 0.25512251
# T = 2130  Fidelity = 0.25707021
# T = 2140  Fidelity = 0.25585622
# T = 2150  Fidelity = 0.25783730
# T = 2160  Fidelity = 0.25575538
# T = 2170  Fidelity = 0.25684562
# T = 2180  Fidelity = 0.25556957
# T = 2190  Fidelity = 0.25630283
# T = 2200  Fidelity = 0.25734805
# T = 2300  Fidelity = 0.25635786
# T = 2400  Fidelity = 0.25455975
# T = 2500  Fidelity = 0.25744188
# T = 2600  Fidelity = 0.25811381
# T = 2700  Fidelity = 0.25564199
# T = 2800  Fidelity = 0.25516402
# T = 2900  Fidelity = 0.25234255
# T = 3000  Fidelity = 0.25166347
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.29930120e-03
# P0     = 0.25166347
# P1     = 0.24780129
# P0+P1  = 0.49946476
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.05944621e-03
# T = 1     Fidelity = 0.24941684
# T = 2     Fidelity = 0.25261959
# T = 5     Fidelity = 0.25455445
# T = 10    Fidelity = 0.25506032
# T = 20    Fidelity = 0.25635337
# T = 30    Fidelity = 0.25682375
# T = 40    Fidelity = 0.25730114
# T = 50    Fidelity = 0.25790664
# T = 75    Fidelity = 0.25885239
# T = 100   Fidelity = 0.25953892
# T = 125   Fidelity = 0.26014028
# T = 150   Fidelity = 0.26075222
# T = 175   Fidelity = 0.26062184
# T = 200   Fidelity = 0.26138978
# T = 225   Fidelity = 0.26212633
# T = 250   Fidelity = 0.26243335
# T = 275   Fidelity = 0.26240228
# T = 300   Fidelity = 0.26442323
# T = 400   Fidelity = 0.26460521
# T = 500   Fidelity = 0.26726724
# T = 600   Fidelity = 0.26862890
# T = 700   Fidelity = 0.26709382
# T = 800   Fidelity = 0.26997849
# T = 900   Fidelity = 0.26679989
# T = 1000  Fidelity = 0.27042780
# T = 1010  Fidelity = 0.26721440
# T = 1020  Fidelity = 0.26515704
# T = 1030  Fidelity = 0.27588533
# T = 1040  Fidelity = 0.26576600
# T = 1050  Fidelity = 0.27735819
# T = 1060  Fidelity = 0.27517747
# T = 1070  Fidelity = 0.27230363
# T = 1080  Fidelity = 0.26982748
# T = 1090  Fidelity = 0.27015390
# T = 1100  Fidelity = 0.27173893
# T = 1200  Fidelity = 0.27166435
# T = 1300  Fidelity = 0.27158490
# T = 1400  Fidelity = 0.26999988
# T = 1500  Fidelity = 0.27018218
# T = 2000  Fidelity = 0.28379628
# T = 2100  Fidelity = 0.28044632
# T = 2110  Fidelity = 0.27796166
# T = 2120  Fidelity = 0.28220764
# T = 2130  Fidelity = 0.28528105
# T = 2140  Fidelity = 0.28558049
# T = 2150  Fidelity = 0.28457809
# T = 2160  Fidelity = 0.28232346
# T = 2170  Fidelity = 0.28086759
# T = 2180  Fidelity = 0.28053734
# T = 2190  Fidelity = 0.27947682
# T = 2200  Fidelity = 0.28057068
# T = 2300  Fidelity = 0.27931810
# T = 2400  Fidelity = 0.28072434
# T = 2500  Fidelity = 0.28021844
# T = 2600  Fidelity = 0.28301981
# T = 2700  Fidelity = 0.28143363
# T = 2800  Fidelity = 0.27788098
# T = 2900  Fidelity = 0.27622886
# T = 3000  Fidelity = 0.27635427
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.07434343e-03
# P0     = 0.27635427
# P1     = 0.26108541
# P0+P1  = 0.53743968
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.57867035e-04
# T = 1     Fidelity = 0.30563333
# T = 2     Fidelity = 0.31344755
# T = 5     Fidelity = 0.32301072
# T = 10    Fidelity = 0.32689345
# T = 20    Fidelity = 0.33210790
# T = 30    Fidelity = 0.33684239
# T = 40    Fidelity = 0.34037068
# T = 50    Fidelity = 0.34276321
# T = 75    Fidelity = 0.34904080
# T = 100   Fidelity = 0.35378830
# T = 125   Fidelity = 0.35770296
# T = 150   Fidelity = 0.36141715
# T = 175   Fidelity = 0.36497182
# T = 200   Fidelity = 0.36789383
# T = 225   Fidelity = 0.37061395
# T = 250   Fidelity = 0.37353549
# T = 275   Fidelity = 0.37616523
# T = 300   Fidelity = 0.37876545
# T = 400   Fidelity = 0.38824962
# T = 500   Fidelity = 0.39634095
# T = 600   Fidelity = 0.41193789
# T = 700   Fidelity = 0.41564215
# T = 800   Fidelity = 0.42282788
# T = 900   Fidelity = 0.41755788
# T = 1000  Fidelity = 0.43481807
# T = 1010  Fidelity = 0.43743970
# T = 1020  Fidelity = 0.43858874
# T = 1030  Fidelity = 0.44058245
# T = 1040  Fidelity = 0.44286821
# T = 1050  Fidelity = 0.44299734
# T = 1060  Fidelity = 0.44159033
# T = 1070  Fidelity = 0.44780216
# T = 1080  Fidelity = 0.45080673
# T = 1090  Fidelity = 0.45256140
# T = 1100  Fidelity = 0.44571333
# T = 1200  Fidelity = 0.43493030
# T = 1300  Fidelity = 0.43797952
# T = 1400  Fidelity = 0.45939064
# T = 1500  Fidelity = 0.47153287
# T = 2000  Fidelity = 0.48043875
# T = 2100  Fidelity = 0.48222146
# T = 2110  Fidelity = 0.47966577
# T = 2120  Fidelity = 0.47992781
# T = 2130  Fidelity = 0.47593416
# T = 2140  Fidelity = 0.48159675
# T = 2150  Fidelity = 0.47533896
# T = 2160  Fidelity = 0.47679161
# T = 2170  Fidelity = 0.48223864
# T = 2180  Fidelity = 0.48640607
# T = 2190  Fidelity = 0.49400772
# T = 2200  Fidelity = 0.50188470
# T = 2300  Fidelity = 0.51326468
# T = 2400  Fidelity = 0.53302132
# T = 2500  Fidelity = 0.53836004
# T = 2600  Fidelity = 0.54650369
# T = 2700  Fidelity = 0.57590872
# T = 2800  Fidelity = 0.57496199
# T = 2900  Fidelity = 0.58781809
# T = 3000  Fidelity = 0.58125648
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.57706167e-04
# P0     = 0.58125648
# P1     = 0.20484605
# P0+P1  = 0.78610253
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.03605669e-03
# T = 1     Fidelity = 0.47110493
# T = 2     Fidelity = 0.49236624
# T = 5     Fidelity = 0.52451874
# T = 10    Fidelity = 0.54064022
# T = 20    Fidelity = 0.56729675
# T = 30    Fidelity = 0.58333703
# T = 40    Fidelity = 0.59857957
# T = 50    Fidelity = 0.60897684
# T = 75    Fidelity = 0.63295956
# T = 100   Fidelity = 0.65243831
# T = 125   Fidelity = 0.66808114
# T = 150   Fidelity = 0.68186926
# T = 175   Fidelity = 0.69473442
# T = 200   Fidelity = 0.70584046
# T = 225   Fidelity = 0.71611262
# T = 250   Fidelity = 0.72592419
# T = 275   Fidelity = 0.73477241
# T = 300   Fidelity = 0.74341001
# T = 400   Fidelity = 0.77261636
# T = 500   Fidelity = 0.79668969
# T = 600   Fidelity = 0.80379720
# T = 700   Fidelity = 0.82961196
# T = 800   Fidelity = 0.85950528
# T = 900   Fidelity = 0.87996106
# T = 1000  Fidelity = 0.87900482
# T = 1010  Fidelity = 0.88624209
# T = 1020  Fidelity = 0.89253647
# T = 1030  Fidelity = 0.89895476
# T = 1040  Fidelity = 0.90280055
# T = 1050  Fidelity = 0.90428758
# T = 1060  Fidelity = 0.90298458
# T = 1070  Fidelity = 0.90047574
# T = 1080  Fidelity = 0.89805611
# T = 1090  Fidelity = 0.89509540
# T = 1100  Fidelity = 0.89118147
# T = 1200  Fidelity = 0.88303920
# T = 1300  Fidelity = 0.93585793
# T = 1400  Fidelity = 0.91253344
# T = 1500  Fidelity = 0.88395604
# T = 2000  Fidelity = 0.92404762
# T = 2100  Fidelity = 0.89553084
# T = 2110  Fidelity = 0.89397159
# T = 2120  Fidelity = 0.88573754
# T = 2130  Fidelity = 0.88211103
# T = 2140  Fidelity = 0.88972046
# T = 2150  Fidelity = 0.90131211
# T = 2160  Fidelity = 0.90677524
# T = 2170  Fidelity = 0.90552017
# T = 2180  Fidelity = 0.90242558
# T = 2190  Fidelity = 0.90381561
# T = 2200  Fidelity = 0.91084913
# T = 2300  Fidelity = 0.91152681
# T = 2400  Fidelity = 0.93179294
# T = 2500  Fidelity = 0.96673133
# T = 2600  Fidelity = 0.96670761
# T = 2700  Fidelity = 0.98581543
# T = 2800  Fidelity = 0.99779693
#
# Minimum T for Fidelity >= 0.99 : 2800
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.34955504e-03
# T = 1     Fidelity = 0.50983027
# T = 2     Fidelity = 0.54305196
# T = 5     Fidelity = 0.59700644
# T = 10    Fidelity = 0.63020987
# T = 20    Fidelity = 0.68217826
# T = 30    Fidelity = 0.71510599
# T = 40    Fidelity = 0.73729959
# T = 50    Fidelity = 0.75696295
# T = 75    Fidelity = 0.79601017
# T = 100   Fidelity = 0.82424021
# T = 125   Fidelity = 0.84590790
# T = 150   Fidelity = 0.86366356
# T = 175   Fidelity = 0.87869545
# T = 200   Fidelity = 0.89124720
# T = 225   Fidelity = 0.90207514
# T = 250   Fidelity = 0.91088152
# T = 275   Fidelity = 0.91925415
# T = 300   Fidelity = 0.92657304
# T = 400   Fidelity = 0.94774014
# T = 500   Fidelity = 0.96127871
# T = 600   Fidelity = 0.96998925
# T = 700   Fidelity = 0.96746385
# T = 800   Fidelity = 0.98504517
# T = 900   Fidelity = 0.98811429
# T = 1000  Fidelity = 0.99367032
#
# Minimum T for Fidelity >= 0.99 : 1000
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.92117516e-02
# T = 1     Fidelity = 0.54951354
# T = 2     Fidelity = 0.59337175
# T = 5     Fidelity = 0.66436489
# T = 10    Fidelity = 0.71982796
# T = 20    Fidelity = 0.78243224
# T = 30    Fidelity = 0.82285012
# T = 40    Fidelity = 0.85175734
# T = 50    Fidelity = 0.87318400
# T = 75    Fidelity = 0.90853731
# T = 100   Fidelity = 0.93100474
# T = 125   Fidelity = 0.94634934
# T = 150   Fidelity = 0.95732455
# T = 175   Fidelity = 0.96527634
# T = 200   Fidelity = 0.97134130
# T = 225   Fidelity = 0.97583564
# T = 250   Fidelity = 0.97963554
# T = 275   Fidelity = 0.98256532
# T = 300   Fidelity = 0.98507619
# T = 400   Fidelity = 0.99065019
#
# Minimum T for Fidelity >= 0.99 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 3.87769083e-02
# T = 1     Fidelity = 0.60017222
# T = 2     Fidelity = 0.65319220
# T = 5     Fidelity = 0.73584346
# T = 10    Fidelity = 0.80605515
# T = 20    Fidelity = 0.86828591
# T = 30    Fidelity = 0.90338261
# T = 40    Fidelity = 0.92623871
# T = 50    Fidelity = 0.94222786
# T = 75    Fidelity = 0.96465622
# T = 100   Fidelity = 0.97694295
# T = 125   Fidelity = 0.98405501
# T = 150   Fidelity = 0.98825698
# T = 175   Fidelity = 0.99063563
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 6.53490673e-02
# T = 1     Fidelity = 0.65426783
# T = 2     Fidelity = 0.71391166
# T = 5     Fidelity = 0.80121557
# T = 10    Fidelity = 0.87222695
# T = 20    Fidelity = 0.92459485
# T = 30    Fidelity = 0.95034385
# T = 40    Fidelity = 0.96543663
# T = 50    Fidelity = 0.97500649
# T = 75    Fidelity = 0.98639034
# T = 100   Fidelity = 0.99178430
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99160302
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.98814155
# T = 2     Fidelity = 0.98913939
# T = 5     Fidelity = 0.99394641
#
# Minimum T for Fidelity >= 0.99 : 5
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.42665601e+00
# T = 1     Fidelity = 0.98516253
# T = 2     Fidelity = 0.99108219
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41121208e+00
# T = 1     Fidelity = 0.99178825
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.99281539
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.99182866
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99098257
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98931572
# T = 2     Fidelity = 0.99646068
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98757666
# T = 2     Fidelity = 0.99552381
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98578561
# T = 2     Fidelity = 0.99451734
#
# Minimum T for Fidelity >= 0.99 : 2
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     700       0.9933624258      2.15534848e-04    None        None        None
# Symmetric      0.311     125       0.9969341676      1.15624068e-06    None        None        None
# Symmetric      0.522     75        0.9914467432      3.42043113e-07    None        None        None
# Symmetric      0.733     50        0.9923195253      1.41278093e-05    None        None        None
# Symmetric      0.944     50        0.9938772282      3.35131121e-04    None        None        None
# Symmetric      1.156     30        0.9965107021      2.39158790e-03    None        None        None
# Symmetric      1.367     40        0.9975559002      8.93695212e-03    None        None        None
# Symmetric      1.578     40        0.9911491816      2.26116126e-02    None        None        None
# Symmetric      1.789     50        0.9932467281      4.43232760e-02    None        None        None
# Symmetric      2.000     50        0.9929116951      7.29248761e-02    None        None        None
# Weak SSB optimised0.100     1090      0.9914865917      8.65519637e-01    None        None        None
# Weak SSB optimised0.311     None      0.9823281267      5.19764834e-01    0.958727    0.021021    0.979748
# Weak SSB optimised0.522     5         0.9915327112      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     2         0.9951985394      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     2         0.9911306490      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     75        0.9917370144      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     275       0.9907622277      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     400       0.9926662412      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     250       0.9910804433      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     150       0.9906065313      2.54594564e-01    None        None        None
# Weak SSB       0.100     225       0.9918007120      1.35126357e-02    None        None        None
# Weak SSB       0.311     2160      0.9917517625      2.91075005e-03    None        None        None
# Weak SSB       0.522     None      0.2590323803      1.05614584e-03    0.251663    0.247801    0.499465
# Weak SSB       0.733     None      0.2855804927      1.05944621e-03    0.276354    0.261085    0.53744
# Weak SSB       0.944     None      0.5878180893      9.57867035e-04    0.581256    0.204846    0.786103
# Weak SSB       1.156     2800      0.9977969318      2.03605669e-03    None        None        None
# Weak SSB       1.367     1000      0.9936703155      7.34955504e-03    None        None        None
# Weak SSB       1.578     400       0.9906501855      1.92117516e-02    None        None        None
# Weak SSB       1.789     175       0.9906356282      3.87769083e-02    None        None        None
# Weak SSB       2.000     100       0.9917843047      6.53490673e-02    None        None        None
# Strong SSB     0.100     1         0.9916030186      3.59472102e+00    None        None        None
# Strong SSB     0.311     5         0.9939464118      1.58498916e+00    None        None        None
# Strong SSB     0.522     2         0.9910821854      1.42665601e+00    None        None        None
# Strong SSB     0.733     1         0.9917882459      1.41121208e+00    None        None        None
# Strong SSB     0.944     1         0.9928153877      1.38481786e+00    None        None        None
# Strong SSB     1.156     1         0.9918286587      1.34302163e+00    None        None        None
# Strong SSB     1.367     1         0.9909825735      1.29217279e+00    None        None        None
# Strong SSB     1.578     2         0.9964606778      1.23335459e+00    None        None        None
# Strong SSB     1.789     2         0.9955238141      1.17426012e+00    None        None        None
# Strong SSB     2.000     2         0.9945173402      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',
        color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',
        color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',
        color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=-1$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Start of m0^2=-2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.99

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.99 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000295
# T = 10    Fidelity = 0.00027900
# T = 20    Fidelity = 0.00630284
# T = 30    Fidelity = 0.02603894
# T = 40    Fidelity = 0.06582562
# T = 50    Fidelity = 0.12447723
# T = 75    Fidelity = 0.30903241
# T = 100   Fidelity = 0.46391829
# T = 125   Fidelity = 0.64204873
# T = 150   Fidelity = 0.69157979
# T = 175   Fidelity = 0.77469129
# T = 200   Fidelity = 0.83395191
# T = 225   Fidelity = 0.81460815
# T = 250   Fidelity = 0.90535876
# T = 275   Fidelity = 0.91626175
# T = 300   Fidelity = 0.86715385
# T = 400   Fidelity = 0.97880159
# T = 500   Fidelity = 0.86744042
# T = 600   Fidelity = 0.89637397
# T = 700   Fidelity = 0.86506652
# T = 800   Fidelity = 0.84095336
# T = 900   Fidelity = 0.91561580
# T = 1000  Fidelity = 0.78789236
# T = 1010  Fidelity = 0.86617469
# T = 1020  Fidelity = 0.76218687
# T = 1030  Fidelity = 0.71446448
# T = 1040  Fidelity = 0.60474491
# T = 1050  Fidelity = 0.44974709
# T = 1060  Fidelity = 0.49368940
# T = 1070  Fidelity = 0.46201942
# T = 1080  Fidelity = 0.54278781
# T = 1090  Fidelity = 0.59940095
# T = 1100  Fidelity = 0.58202631
# T = 1200  Fidelity = 0.69558140
# T = 1300  Fidelity = 0.53378901
# T = 1400  Fidelity = 0.88370281
# T = 1500  Fidelity = 0.75104840
# T = 2000  Fidelity = 0.48180772
# T = 2100  Fidelity = 0.34343566
# T = 2110  Fidelity = 0.54051165
# T = 2120  Fidelity = 0.62151796
# T = 2130  Fidelity = 0.58570494
# T = 2140  Fidelity = 0.55836621
# T = 2150  Fidelity = 0.44171513
# T = 2160  Fidelity = 0.59533700
# T = 2170  Fidelity = 0.54223866
# T = 2180  Fidelity = 0.58481610
# T = 2190  Fidelity = 0.64418180
# T = 2200  Fidelity = 0.57756856
# T = 2300  Fidelity = 0.89031365
# T = 2400  Fidelity = 0.61186713
# T = 2500  Fidelity = 0.43003769
# T = 2600  Fidelity = 0.69223071
# T = 2700  Fidelity = 0.84404084
# T = 2800  Fidelity = 0.79491347
# T = 2900  Fidelity = 0.77013567
# T = 3000  Fidelity = 0.70247390
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.79379555e-02
# P0     = 0.70247390
# P1     = 0.00000000
# P0+P1  = 0.70247391
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.17908351e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00030471
# T = 10    Fidelity = 0.01972602
# T = 20    Fidelity = 0.35207004
# T = 30    Fidelity = 0.52580947
# T = 40    Fidelity = 0.54425705
# T = 50    Fidelity = 0.70353060
# T = 75    Fidelity = 0.85009880
# T = 100   Fidelity = 0.92374197
# T = 125   Fidelity = 0.95513109
# T = 150   Fidelity = 0.97618290
# T = 175   Fidelity = 0.99754894
#
# Minimum T for Fidelity >= 0.99 : 175
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.94880926e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.01013737
# T = 10    Fidelity = 0.29395272
# T = 20    Fidelity = 0.47649544
# T = 30    Fidelity = 0.65919006
# T = 40    Fidelity = 0.84256742
# T = 50    Fidelity = 0.88343347
# T = 75    Fidelity = 0.96312048
# T = 100   Fidelity = 0.98782662
# T = 125   Fidelity = 0.99595715
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.58119085e-07
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000821
# T = 5     Fidelity = 0.06263341
# T = 10    Fidelity = 0.29632732
# T = 20    Fidelity = 0.55807592
# T = 30    Fidelity = 0.72697924
# T = 40    Fidelity = 0.83531493
# T = 50    Fidelity = 0.91098354
# T = 75    Fidelity = 0.98046843
# T = 100   Fidelity = 0.99984478
#
# Minimum T for Fidelity >= 0.99 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.89654431e-08
# T = 1     Fidelity = 0.00000139
# T = 2     Fidelity = 0.00013149
# T = 5     Fidelity = 0.11159344
# T = 10    Fidelity = 0.49003995
# T = 20    Fidelity = 0.76516849
# T = 30    Fidelity = 0.88756251
# T = 40    Fidelity = 0.94380626
# T = 50    Fidelity = 0.97009623
# T = 75    Fidelity = 0.99783038
#
# Minimum T for Fidelity >= 0.99 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.17592562e-07
# T = 1     Fidelity = 0.00002191
# T = 2     Fidelity = 0.00081642
# T = 5     Fidelity = 0.15753337
# T = 10    Fidelity = 0.62745835
# T = 20    Fidelity = 0.87767504
# T = 30    Fidelity = 0.95886305
# T = 40    Fidelity = 0.98613374
# T = 50    Fidelity = 0.99608571
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 2.47961144e-07
# T = 1     Fidelity = 0.00014358
# T = 2     Fidelity = 0.00277549
# T = 5     Fidelity = 0.19658996
# T = 10    Fidelity = 0.73840201
# T = 20    Fidelity = 0.93000928
# T = 30    Fidelity = 0.97197915
# T = 40    Fidelity = 0.98585008
# T = 50    Fidelity = 0.99133372
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 3.56990610e-07
# T = 1     Fidelity = 0.00057622
# T = 2     Fidelity = 0.00691070
# T = 5     Fidelity = 0.23187098
# T = 10    Fidelity = 0.80831044
# T = 20    Fidelity = 0.93689418
# T = 30    Fidelity = 0.96372163
# T = 40    Fidelity = 0.98388151
# T = 50    Fidelity = 0.99475856
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.45005900e-06
# T = 1     Fidelity = 0.00168879
# T = 2     Fidelity = 0.01404906
# T = 5     Fidelity = 0.26483641
# T = 10    Fidelity = 0.84416317
# T = 20    Fidelity = 0.92513374
# T = 30    Fidelity = 0.96899952
# T = 40    Fidelity = 0.99381725
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396111
# T = 2     Fidelity = 0.02467438
# T = 5     Fidelity = 0.29523330
# T = 10    Fidelity = 0.85800354
# T = 20    Fidelity = 0.92052602
# T = 30    Fidelity = 0.98399998
# T = 40    Fidelity = 0.99992201
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.62783443
# T = 2     Fidelity = 0.65647752
# T = 5     Fidelity = 0.71227349
# T = 10    Fidelity = 0.76584429
# T = 20    Fidelity = 0.83159917
# T = 30    Fidelity = 0.87135093
# T = 40    Fidelity = 0.89977312
# T = 50    Fidelity = 0.91962957
# T = 75    Fidelity = 0.95048074
# T = 100   Fidelity = 0.96470126
# T = 125   Fidelity = 0.97387084
# T = 150   Fidelity = 0.98151940
# T = 175   Fidelity = 0.97982141
# T = 200   Fidelity = 0.98401971
# T = 225   Fidelity = 0.97865296
# T = 250   Fidelity = 0.98494971
# T = 275   Fidelity = 0.95113313
# T = 300   Fidelity = 0.94006969
# T = 400   Fidelity = 0.97948574
# T = 500   Fidelity = 0.97593015
# T = 600   Fidelity = 0.93010467
# T = 700   Fidelity = 0.81699253
# T = 800   Fidelity = 0.95158882
# T = 900   Fidelity = 0.98244203
# T = 1000  Fidelity = 0.95647197
# T = 1010  Fidelity = 0.95765497
# T = 1020  Fidelity = 0.95826072
# T = 1030  Fidelity = 0.95732463
# T = 1040  Fidelity = 0.96134456
# T = 1050  Fidelity = 0.95746900
# T = 1060  Fidelity = 0.97377617
# T = 1070  Fidelity = 0.98738454
# T = 1080  Fidelity = 0.98964664
# T = 1090  Fidelity = 0.98117474
# T = 1100  Fidelity = 0.97315949
# T = 1200  Fidelity = 0.98517213
# T = 1300  Fidelity = 0.96704508
# T = 1400  Fidelity = 0.84287854
# T = 1500  Fidelity = 0.91484805
# T = 2000  Fidelity = 0.95451825
# T = 2100  Fidelity = 0.87096984
# T = 2110  Fidelity = 0.84805063
# T = 2120  Fidelity = 0.84912678
# T = 2130  Fidelity = 0.85055105
# T = 2140  Fidelity = 0.85339776
# T = 2150  Fidelity = 0.84923184
# T = 2160  Fidelity = 0.86351225
# T = 2170  Fidelity = 0.87655666
# T = 2180  Fidelity = 0.88463484
# T = 2190  Fidelity = 0.89533488
# T = 2200  Fidelity = 0.91153678
# T = 2300  Fidelity = 0.97256642
# T = 2400  Fidelity = 0.97227492
# T = 2500  Fidelity = 0.94348106
# T = 2600  Fidelity = 0.97687718
# T = 2700  Fidelity = 0.97311243
# T = 2800  Fidelity = 0.88782840
# T = 2900  Fidelity = 0.89997027
# T = 3000  Fidelity = 0.94658014
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.33549253e-01
# P0     = 0.94658014
# P1     = 0.02817925
# P0+P1  = 0.97475939
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.69326434
# T = 2     Fidelity = 0.75569217
# T = 5     Fidelity = 0.79657004
# T = 10    Fidelity = 0.82303177
# T = 20    Fidelity = 0.85113984
# T = 30    Fidelity = 0.86993125
# T = 40    Fidelity = 0.88489718
# T = 50    Fidelity = 0.89611612
# T = 75    Fidelity = 0.91708784
# T = 100   Fidelity = 0.93110290
# T = 125   Fidelity = 0.93930304
# T = 150   Fidelity = 0.94602930
# T = 175   Fidelity = 0.95764740
# T = 200   Fidelity = 0.96564166
# T = 225   Fidelity = 0.96113187
# T = 250   Fidelity = 0.96157740
# T = 275   Fidelity = 0.97314606
# T = 300   Fidelity = 0.96877801
# T = 400   Fidelity = 0.97287974
# T = 500   Fidelity = 0.96380880
# T = 600   Fidelity = 0.97314987
# T = 700   Fidelity = 0.97383908
# T = 800   Fidelity = 0.95257410
# T = 900   Fidelity = 0.92371263
# T = 1000  Fidelity = 0.91805540
# T = 1010  Fidelity = 0.91636639
# T = 1020  Fidelity = 0.91961773
# T = 1030  Fidelity = 0.92705214
# T = 1040  Fidelity = 0.91859888
# T = 1050  Fidelity = 0.93398205
# T = 1060  Fidelity = 0.93875898
# T = 1070  Fidelity = 0.90995969
# T = 1080  Fidelity = 0.92684168
# T = 1090  Fidelity = 0.90647918
# T = 1100  Fidelity = 0.90657215
# T = 1200  Fidelity = 0.93863196
# T = 1300  Fidelity = 0.95532787
# T = 1400  Fidelity = 0.97020913
# T = 1500  Fidelity = 0.98547110
# T = 2000  Fidelity = 0.95206933
# T = 2100  Fidelity = 0.94063087
# T = 2110  Fidelity = 0.93722751
# T = 2120  Fidelity = 0.94316252
# T = 2130  Fidelity = 0.93377006
# T = 2140  Fidelity = 0.94879776
# T = 2150  Fidelity = 0.94725084
# T = 2160  Fidelity = 0.94655662
# T = 2170  Fidelity = 0.95113452
# T = 2180  Fidelity = 0.92103690
# T = 2190  Fidelity = 0.93612402
# T = 2200  Fidelity = 0.93109465
# T = 2300  Fidelity = 0.92502130
# T = 2400  Fidelity = 0.96364182
# T = 2500  Fidelity = 0.95875164
# T = 2600  Fidelity = 0.94772377
# T = 2700  Fidelity = 0.92853399
# T = 2800  Fidelity = 0.93828633
# T = 2900  Fidelity = 0.92232404
# T = 3000  Fidelity = 0.96985004
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.30329715e-01
# P0     = 0.96985004
# P1     = 0.00992018
# P0+P1  = 0.97977022
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.04947490
# T = 2     Fidelity = 0.18999222
# T = 5     Fidelity = 0.84387435
# T = 10    Fidelity = 0.96110492
# T = 20    Fidelity = 0.98528240
# T = 30    Fidelity = 0.98935940
# T = 40    Fidelity = 0.98989481
# T = 50    Fidelity = 0.99120119
#
# Minimum T for Fidelity >= 0.99 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.11037306
# T = 2     Fidelity = 0.33524200
# T = 5     Fidelity = 0.84017049
# T = 10    Fidelity = 0.91339083
# T = 20    Fidelity = 0.99818981
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.16761385
# T = 2     Fidelity = 0.40038232
# T = 5     Fidelity = 0.89841746
# T = 10    Fidelity = 0.94639930
# T = 20    Fidelity = 0.99424042
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.20915189
# T = 2     Fidelity = 0.42760324
# T = 5     Fidelity = 0.87666133
# T = 10    Fidelity = 0.92051133
# T = 20    Fidelity = 0.97080913
# T = 30    Fidelity = 0.97917168
# T = 40    Fidelity = 0.97895983
# T = 50    Fidelity = 0.98346302
# T = 75    Fidelity = 0.98594451
# T = 100   Fidelity = 0.98873860
# T = 125   Fidelity = 0.99136417
#
# Minimum T for Fidelity >= 0.99 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.21638178
# T = 2     Fidelity = 0.40289887
# T = 5     Fidelity = 0.82503533
# T = 10    Fidelity = 0.86438215
# T = 20    Fidelity = 0.90720908
# T = 30    Fidelity = 0.93393587
# T = 40    Fidelity = 0.94606164
# T = 50    Fidelity = 0.94791999
# T = 75    Fidelity = 0.96150450
# T = 100   Fidelity = 0.96494430
# T = 125   Fidelity = 0.97361768
# T = 150   Fidelity = 0.97522110
# T = 175   Fidelity = 0.97910238
# T = 200   Fidelity = 0.98176795
# T = 225   Fidelity = 0.98219678
# T = 250   Fidelity = 0.98593896
# T = 275   Fidelity = 0.98500779
# T = 300   Fidelity = 0.98794362
# T = 400   Fidelity = 0.95354919
# T = 500   Fidelity = 0.96724043
# T = 600   Fidelity = 0.98240978
# T = 700   Fidelity = 0.97010999
# T = 800   Fidelity = 0.96767408
# T = 900   Fidelity = 0.98318641
# T = 1000  Fidelity = 0.97168154
# T = 1010  Fidelity = 0.98779213
# T = 1020  Fidelity = 0.99198717
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.20009689
# T = 2     Fidelity = 0.34842839
# T = 5     Fidelity = 0.74323825
# T = 10    Fidelity = 0.79107182
# T = 20    Fidelity = 0.83409765
# T = 30    Fidelity = 0.86184236
# T = 40    Fidelity = 0.88561851
# T = 50    Fidelity = 0.90521134
# T = 75    Fidelity = 0.92969394
# T = 100   Fidelity = 0.94108108
# T = 125   Fidelity = 0.95452664
# T = 150   Fidelity = 0.96215594
# T = 175   Fidelity = 0.96676287
# T = 200   Fidelity = 0.97263880
# T = 225   Fidelity = 0.97574247
# T = 250   Fidelity = 0.97835749
# T = 275   Fidelity = 0.98206106
# T = 300   Fidelity = 0.98241807
# T = 400   Fidelity = 0.95691819
# T = 500   Fidelity = 0.97144261
# T = 600   Fidelity = 0.98369380
# T = 700   Fidelity = 0.96729994
# T = 800   Fidelity = 0.97391703
# T = 900   Fidelity = 0.99402228
#
# Minimum T for Fidelity >= 0.99 : 900
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.17952543
# T = 2     Fidelity = 0.29743944
# T = 5     Fidelity = 0.66930675
# T = 10    Fidelity = 0.73126488
# T = 20    Fidelity = 0.79246214
# T = 30    Fidelity = 0.82874760
# T = 40    Fidelity = 0.85545001
# T = 50    Fidelity = 0.87681933
# T = 75    Fidelity = 0.91454151
# T = 100   Fidelity = 0.93862962
# T = 125   Fidelity = 0.95467541
# T = 150   Fidelity = 0.96545096
# T = 175   Fidelity = 0.97261598
# T = 200   Fidelity = 0.97751314
# T = 225   Fidelity = 0.98069340
# T = 250   Fidelity = 0.98404159
# T = 275   Fidelity = 0.98661981
# T = 300   Fidelity = 0.98834038
# T = 400   Fidelity = 0.97364025
# T = 500   Fidelity = 0.97317726
# T = 600   Fidelity = 0.98577524
# T = 700   Fidelity = 0.98654838
# T = 800   Fidelity = 0.98689598
# T = 900   Fidelity = 0.98969714
# T = 1000  Fidelity = 0.98275238
# T = 1010  Fidelity = 0.97174808
# T = 1020  Fidelity = 0.99472504
#
# Minimum T for Fidelity >= 0.99 : 1020
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.48783584e-01
# T = 1     Fidelity = 0.16372561
# T = 2     Fidelity = 0.26084838
# T = 5     Fidelity = 0.61912337
# T = 10    Fidelity = 0.69366458
# T = 20    Fidelity = 0.77170764
# T = 30    Fidelity = 0.82101563
# T = 40    Fidelity = 0.85768489
# T = 50    Fidelity = 0.88588024
# T = 75    Fidelity = 0.93158382
# T = 100   Fidelity = 0.95678592
# T = 125   Fidelity = 0.97135469
# T = 150   Fidelity = 0.98011538
# T = 175   Fidelity = 0.98557390
# T = 200   Fidelity = 0.98861757
# T = 225   Fidelity = 0.99111140
#
# Minimum T for Fidelity >= 0.99 : 225
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.81947687e-02
# T = 1     Fidelity = 0.60255521
# T = 2     Fidelity = 0.64653507
# T = 5     Fidelity = 0.72447547
# T = 10    Fidelity = 0.80024606
# T = 20    Fidelity = 0.88100522
# T = 30    Fidelity = 0.92317658
# T = 40    Fidelity = 0.94766716
# T = 50    Fidelity = 0.96261321
# T = 75    Fidelity = 0.98123834
# T = 100   Fidelity = 0.98438142
# T = 125   Fidelity = 0.98495871
# T = 150   Fidelity = 0.99047844
#
# Minimum T for Fidelity >= 0.99 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.51771385e-02
# T = 1     Fidelity = 0.54179847
# T = 2     Fidelity = 0.58461290
# T = 5     Fidelity = 0.62842560
# T = 10    Fidelity = 0.66558439
# T = 20    Fidelity = 0.72306498
# T = 30    Fidelity = 0.76483291
# T = 40    Fidelity = 0.79721075
# T = 50    Fidelity = 0.82114414
# T = 75    Fidelity = 0.86866824
# T = 100   Fidelity = 0.89936310
# T = 125   Fidelity = 0.91904699
# T = 150   Fidelity = 0.93353172
# T = 175   Fidelity = 0.94135270
# T = 200   Fidelity = 0.94244369
# T = 225   Fidelity = 0.94987781
# T = 250   Fidelity = 0.94164627
# T = 275   Fidelity = 0.93119890
# T = 300   Fidelity = 0.94533552
# T = 400   Fidelity = 0.96719002
# T = 500   Fidelity = 0.94936687
# T = 600   Fidelity = 0.95733205
# T = 700   Fidelity = 0.83463592
# T = 800   Fidelity = 0.87205612
# T = 900   Fidelity = 0.88466080
# T = 1000  Fidelity = 0.88120840
# T = 1010  Fidelity = 0.93259809
# T = 1020  Fidelity = 0.90787460
# T = 1030  Fidelity = 0.94417421
# T = 1040  Fidelity = 0.94747625
# T = 1050  Fidelity = 0.96172281
# T = 1060  Fidelity = 0.97094622
# T = 1070  Fidelity = 0.94758892
# T = 1080  Fidelity = 0.97390384
# T = 1090  Fidelity = 0.96789694
# T = 1100  Fidelity = 0.94480390
# T = 1200  Fidelity = 0.91783836
# T = 1300  Fidelity = 0.97502650
# T = 1400  Fidelity = 0.93675748
# T = 1500  Fidelity = 0.90634817
# T = 2000  Fidelity = 0.94654734
# T = 2100  Fidelity = 0.98866109
# T = 2110  Fidelity = 0.97950502
# T = 2120  Fidelity = 0.98057236
# T = 2130  Fidelity = 0.97365882
# T = 2140  Fidelity = 0.96780120
# T = 2150  Fidelity = 0.95516043
# T = 2160  Fidelity = 0.96076744
# T = 2170  Fidelity = 0.97691441
# T = 2180  Fidelity = 0.96261126
# T = 2190  Fidelity = 0.97632275
# T = 2200  Fidelity = 0.96820289
# T = 2300  Fidelity = 0.89152313
# T = 2400  Fidelity = 0.88994467
# T = 2500  Fidelity = 0.93937582
# T = 2600  Fidelity = 0.86117257
# T = 2700  Fidelity = 0.84398865
# T = 2800  Fidelity = 0.93058457
# T = 2900  Fidelity = 0.95796703
# T = 3000  Fidelity = 0.93718015
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.50815198e-02
# P0     = 0.93718015
# P1     = 0.00002469
# P0+P1  = 0.93720484
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05614584e-03
# T = 1     Fidelity = 0.02267594
# T = 2     Fidelity = 0.09256626
# T = 5     Fidelity = 0.42581290
# T = 10    Fidelity = 0.47732439
# T = 20    Fidelity = 0.49237560
# T = 30    Fidelity = 0.49370232
# T = 40    Fidelity = 0.49436491
# T = 50    Fidelity = 0.49622823
# T = 75    Fidelity = 0.49420347
# T = 100   Fidelity = 0.49532113
# T = 125   Fidelity = 0.49292689
# T = 150   Fidelity = 0.49496798
# T = 175   Fidelity = 0.49130457
# T = 200   Fidelity = 0.48986159
# T = 225   Fidelity = 0.48893534
# T = 250   Fidelity = 0.48789260
# T = 275   Fidelity = 0.48315081
# T = 300   Fidelity = 0.48025842
# T = 400   Fidelity = 0.45873988
# T = 500   Fidelity = 0.44108076
# T = 600   Fidelity = 0.44561575
# T = 700   Fidelity = 0.42422969
# T = 800   Fidelity = 0.40561619
# T = 900   Fidelity = 0.40514654
# T = 1000  Fidelity = 0.36645725
# T = 1010  Fidelity = 0.37261416
# T = 1020  Fidelity = 0.37264032
# T = 1030  Fidelity = 0.36675894
# T = 1040  Fidelity = 0.37219105
# T = 1050  Fidelity = 0.36203076
# T = 1060  Fidelity = 0.36282607
# T = 1070  Fidelity = 0.36383252
# T = 1080  Fidelity = 0.36443063
# T = 1090  Fidelity = 0.35694751
# T = 1100  Fidelity = 0.35304464
# T = 1200  Fidelity = 0.34389218
# T = 1300  Fidelity = 0.31773510
# T = 1400  Fidelity = 0.26265757
# T = 1500  Fidelity = 0.27981002
# T = 2000  Fidelity = 0.19387745
# T = 2100  Fidelity = 0.18692521
# T = 2110  Fidelity = 0.18074809
# T = 2120  Fidelity = 0.17755082
# T = 2130  Fidelity = 0.17343502
# T = 2140  Fidelity = 0.17761686
# T = 2150  Fidelity = 0.17512026
# T = 2160  Fidelity = 0.17226715
# T = 2170  Fidelity = 0.16712665
# T = 2180  Fidelity = 0.16840979
# T = 2190  Fidelity = 0.16616813
# T = 2200  Fidelity = 0.16298542
# T = 2300  Fidelity = 0.15203906
# T = 2400  Fidelity = 0.10905143
# T = 2500  Fidelity = 0.12870748
# T = 2600  Fidelity = 0.11932721
# T = 2700  Fidelity = 0.10724025
# T = 2800  Fidelity = 0.09361505
# T = 2900  Fidelity = 0.09047928
# T = 3000  Fidelity = 0.08223030
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.35220086e-03
# P0     = 0.08223030
# P1     = 0.41535318
# P0+P1  = 0.49758348
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07018746e-03
# T = 1     Fidelity = 0.02793722
# T = 2     Fidelity = 0.08299282
# T = 5     Fidelity = 0.21999149
# T = 10    Fidelity = 0.23691934
# T = 20    Fidelity = 0.26042367
# T = 30    Fidelity = 0.25985797
# T = 40    Fidelity = 0.26035851
# T = 50    Fidelity = 0.26335098
# T = 75    Fidelity = 0.26391094
# T = 100   Fidelity = 0.26470285
# T = 125   Fidelity = 0.26459484
# T = 150   Fidelity = 0.26485515
# T = 175   Fidelity = 0.26480008
# T = 200   Fidelity = 0.27063268
# T = 225   Fidelity = 0.26864951
# T = 250   Fidelity = 0.26227800
# T = 275   Fidelity = 0.26649779
# T = 300   Fidelity = 0.26840916
# T = 400   Fidelity = 0.28514366
# T = 500   Fidelity = 0.25343567
# T = 600   Fidelity = 0.26512727
# T = 700   Fidelity = 0.26283743
# T = 800   Fidelity = 0.23576182
# T = 900   Fidelity = 0.23317661
# T = 1000  Fidelity = 0.25513195
# T = 1010  Fidelity = 0.25746367
# T = 1020  Fidelity = 0.25866157
# T = 1030  Fidelity = 0.28063334
# T = 1040  Fidelity = 0.26385885
# T = 1050  Fidelity = 0.27897733
# T = 1060  Fidelity = 0.32483749
# T = 1070  Fidelity = 0.21816045
# T = 1080  Fidelity = 0.24666689
# T = 1090  Fidelity = 0.24644642
# T = 1100  Fidelity = 0.29688794
# T = 1200  Fidelity = 0.31052282
# T = 1300  Fidelity = 0.28866408
# T = 1400  Fidelity = 0.29427393
# T = 1500  Fidelity = 0.20321810
# T = 2000  Fidelity = 0.26142636
# T = 2100  Fidelity = 0.18732158
# T = 2110  Fidelity = 0.28139680
# T = 2120  Fidelity = 0.27709599
# T = 2130  Fidelity = 0.21130968
# T = 2140  Fidelity = 0.34844304
# T = 2150  Fidelity = 0.20778267
# T = 2160  Fidelity = 0.27604716
# T = 2170  Fidelity = 0.22669319
# T = 2180  Fidelity = 0.27587658
# T = 2190  Fidelity = 0.27639339
# T = 2200  Fidelity = 0.26682848
# T = 2300  Fidelity = 0.28560169
# T = 2400  Fidelity = 0.23221373
# T = 2500  Fidelity = 0.28331465
# T = 2600  Fidelity = 0.28113769
# T = 2700  Fidelity = 0.24609392
# T = 2800  Fidelity = 0.22727423
# T = 2900  Fidelity = 0.24478104
# T = 3000  Fidelity = 0.22524452
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.59823390e-03
# P0     = 0.22524452
# P1     = 0.25185080
# P0+P1  = 0.47709532
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 9.80171521e-04
# T = 1     Fidelity = 0.03773007
# T = 2     Fidelity = 0.09107387
# T = 5     Fidelity = 0.22308934
# T = 10    Fidelity = 0.23492891
# T = 20    Fidelity = 0.25532123
# T = 30    Fidelity = 0.26218811
# T = 40    Fidelity = 0.26028585
# T = 50    Fidelity = 0.26636060
# T = 75    Fidelity = 0.26916332
# T = 100   Fidelity = 0.27290898
# T = 125   Fidelity = 0.27800178
# T = 150   Fidelity = 0.28287549
# T = 175   Fidelity = 0.29094987
# T = 200   Fidelity = 0.28925545
# T = 225   Fidelity = 0.29374822
# T = 250   Fidelity = 0.29239993
# T = 275   Fidelity = 0.29028357
# T = 300   Fidelity = 0.29917242
# T = 400   Fidelity = 0.34738689
# T = 500   Fidelity = 0.27884874
# T = 600   Fidelity = 0.31930870
# T = 700   Fidelity = 0.23135772
# T = 800   Fidelity = 0.36672508
# T = 900   Fidelity = 0.36825438
# T = 1000  Fidelity = 0.34363168
# T = 1010  Fidelity = 0.36938923
# T = 1020  Fidelity = 0.38841923
# T = 1030  Fidelity = 0.34191580
# T = 1040  Fidelity = 0.27226842
# T = 1050  Fidelity = 0.26066343
# T = 1060  Fidelity = 0.28865702
# T = 1070  Fidelity = 0.31940601
# T = 1080  Fidelity = 0.37911084
# T = 1090  Fidelity = 0.40374252
# T = 1100  Fidelity = 0.27771062
# T = 1200  Fidelity = 0.26418495
# T = 1300  Fidelity = 0.40457439
# T = 1400  Fidelity = 0.28370481
# T = 1500  Fidelity = 0.41032550
# T = 2000  Fidelity = 0.39972577
# T = 2100  Fidelity = 0.33277318
# T = 2110  Fidelity = 0.40729560
# T = 2120  Fidelity = 0.38232398
# T = 2130  Fidelity = 0.37013144
# T = 2140  Fidelity = 0.44045701
# T = 2150  Fidelity = 0.36645176
# T = 2160  Fidelity = 0.34707172
# T = 2170  Fidelity = 0.31405150
# T = 2180  Fidelity = 0.30170929
# T = 2190  Fidelity = 0.43869464
# T = 2200  Fidelity = 0.30569406
# T = 2300  Fidelity = 0.41871464
# T = 2400  Fidelity = 0.35598769
# T = 2500  Fidelity = 0.42926232
# T = 2600  Fidelity = 0.40502153
# T = 2700  Fidelity = 0.35208930
# T = 2800  Fidelity = 0.37367229
# T = 2900  Fidelity = 0.40038149
# T = 3000  Fidelity = 0.40581702
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.38933834e-03
# P0     = 0.40581702
# P1     = 0.41041219
# P0+P1  = 0.81622921
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 9.40449540e-04
# T = 1     Fidelity = 0.04483963
# T = 2     Fidelity = 0.09362329
# T = 5     Fidelity = 0.22382563
# T = 10    Fidelity = 0.23841087
# T = 20    Fidelity = 0.26063835
# T = 30    Fidelity = 0.28394477
# T = 40    Fidelity = 0.29213105
# T = 50    Fidelity = 0.29101484
# T = 75    Fidelity = 0.31321563
# T = 100   Fidelity = 0.31880004
# T = 125   Fidelity = 0.32822136
# T = 150   Fidelity = 0.34021079
# T = 175   Fidelity = 0.34238770
# T = 200   Fidelity = 0.35195995
# T = 225   Fidelity = 0.35831594
# T = 250   Fidelity = 0.35918727
# T = 275   Fidelity = 0.37180717
# T = 300   Fidelity = 0.37067121
# T = 400   Fidelity = 0.34059183
# T = 500   Fidelity = 0.37725379
# T = 600   Fidelity = 0.42122168
# T = 700   Fidelity = 0.43149839
# T = 800   Fidelity = 0.44807549
# T = 900   Fidelity = 0.45236199
# T = 1000  Fidelity = 0.48080479
# T = 1010  Fidelity = 0.42361147
# T = 1020  Fidelity = 0.41011993
# T = 1030  Fidelity = 0.46623410
# T = 1040  Fidelity = 0.49624395
# T = 1050  Fidelity = 0.48162793
# T = 1060  Fidelity = 0.42763529
# T = 1070  Fidelity = 0.37363606
# T = 1080  Fidelity = 0.45041741
# T = 1090  Fidelity = 0.49122784
# T = 1100  Fidelity = 0.39595127
# T = 1200  Fidelity = 0.48571552
# T = 1300  Fidelity = 0.50623067
# T = 1400  Fidelity = 0.47576771
# T = 1500  Fidelity = 0.48369174
# T = 2000  Fidelity = 0.49631845
# T = 2100  Fidelity = 0.51398830
# T = 2110  Fidelity = 0.50298449
# T = 2120  Fidelity = 0.48391743
# T = 2130  Fidelity = 0.50702785
# T = 2140  Fidelity = 0.48642145
# T = 2150  Fidelity = 0.47886025
# T = 2160  Fidelity = 0.47971830
# T = 2170  Fidelity = 0.47446444
# T = 2180  Fidelity = 0.45266142
# T = 2190  Fidelity = 0.48618853
# T = 2200  Fidelity = 0.47715024
# T = 2300  Fidelity = 0.53714541
# T = 2400  Fidelity = 0.55107690
# T = 2500  Fidelity = 0.51074857
# T = 2600  Fidelity = 0.54100032
# T = 2700  Fidelity = 0.56209979
# T = 2800  Fidelity = 0.54389956
# T = 2900  Fidelity = 0.58024927
# T = 3000  Fidelity = 0.58209206
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.24416809e-03
# P0     = 0.58209206
# P1     = 0.40599220
# P0+P1  = 0.98808426
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 9.13233454e-04
# T = 1     Fidelity = 0.04773031
# T = 2     Fidelity = 0.09206110
# T = 5     Fidelity = 0.23730431
# T = 10    Fidelity = 0.26170925
# T = 20    Fidelity = 0.28765164
# T = 30    Fidelity = 0.31078733
# T = 40    Fidelity = 0.33356800
# T = 50    Fidelity = 0.35160722
# T = 75    Fidelity = 0.37214086
# T = 100   Fidelity = 0.38844858
# T = 125   Fidelity = 0.40779365
# T = 150   Fidelity = 0.41658378
# T = 175   Fidelity = 0.42690402
# T = 200   Fidelity = 0.43835063
# T = 225   Fidelity = 0.44243475
# T = 250   Fidelity = 0.45081976
# T = 275   Fidelity = 0.45909475
# T = 300   Fidelity = 0.45744981
# T = 400   Fidelity = 0.47646329
# T = 500   Fidelity = 0.46002300
# T = 600   Fidelity = 0.49714566
# T = 700   Fidelity = 0.49451986
# T = 800   Fidelity = 0.51834760
# T = 900   Fidelity = 0.52461971
# T = 1000  Fidelity = 0.49461492
# T = 1010  Fidelity = 0.52197227
# T = 1020  Fidelity = 0.50406427
# T = 1030  Fidelity = 0.49680831
# T = 1040  Fidelity = 0.52090007
# T = 1050  Fidelity = 0.52403488
# T = 1060  Fidelity = 0.49802693
# T = 1070  Fidelity = 0.52737871
# T = 1080  Fidelity = 0.52164142
# T = 1090  Fidelity = 0.53337449
# T = 1100  Fidelity = 0.51850033
# T = 1200  Fidelity = 0.51710579
# T = 1300  Fidelity = 0.53624807
# T = 1400  Fidelity = 0.50535975
# T = 1500  Fidelity = 0.54128163
# T = 2000  Fidelity = 0.57061759
# T = 2100  Fidelity = 0.58241693
# T = 2110  Fidelity = 0.57927806
# T = 2120  Fidelity = 0.57435122
# T = 2130  Fidelity = 0.56721089
# T = 2140  Fidelity = 0.57352238
# T = 2150  Fidelity = 0.57555561
# T = 2160  Fidelity = 0.58735343
# T = 2170  Fidelity = 0.58163389
# T = 2180  Fidelity = 0.56379960
# T = 2190  Fidelity = 0.57635073
# T = 2200  Fidelity = 0.56823124
# T = 2300  Fidelity = 0.54974217
# T = 2400  Fidelity = 0.59642233
# T = 2500  Fidelity = 0.58050030
# T = 2600  Fidelity = 0.49952595
# T = 2700  Fidelity = 0.54293177
# T = 2800  Fidelity = 0.53799463
# T = 2900  Fidelity = 0.54944448
# T = 3000  Fidelity = 0.47602344
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.13588693e-03
# P0     = 0.47602344
# P1     = 0.30367777
# P0+P1  = 0.77970121
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.91554516e-04
# T = 1     Fidelity = 0.05018663
# T = 2     Fidelity = 0.09042743
# T = 5     Fidelity = 0.25434866
# T = 10    Fidelity = 0.29236862
# T = 20    Fidelity = 0.33357452
# T = 30    Fidelity = 0.36140679
# T = 40    Fidelity = 0.38225726
# T = 50    Fidelity = 0.39888438
# T = 75    Fidelity = 0.42889117
# T = 100   Fidelity = 0.44919903
# T = 125   Fidelity = 0.46394280
# T = 150   Fidelity = 0.47511140
# T = 175   Fidelity = 0.48380469
# T = 200   Fidelity = 0.49051608
# T = 225   Fidelity = 0.49597329
# T = 250   Fidelity = 0.50015848
# T = 275   Fidelity = 0.50328665
# T = 300   Fidelity = 0.50541582
# T = 400   Fidelity = 0.50628013
# T = 500   Fidelity = 0.51601512
# T = 600   Fidelity = 0.51316615
# T = 700   Fidelity = 0.52462734
# T = 800   Fidelity = 0.51833055
# T = 900   Fidelity = 0.54276646
# T = 1000  Fidelity = 0.53091703
# T = 1010  Fidelity = 0.54606234
# T = 1020  Fidelity = 0.53462751
# T = 1030  Fidelity = 0.53643371
# T = 1040  Fidelity = 0.54675881
# T = 1050  Fidelity = 0.54198546
# T = 1060  Fidelity = 0.52232922
# T = 1070  Fidelity = 0.54109655
# T = 1080  Fidelity = 0.52806130
# T = 1090  Fidelity = 0.54914272
# T = 1100  Fidelity = 0.53546596
# T = 1200  Fidelity = 0.53808038
# T = 1300  Fidelity = 0.55485530
# T = 1400  Fidelity = 0.51238285
# T = 1500  Fidelity = 0.54785536
# T = 2000  Fidelity = 0.49529172
# T = 2100  Fidelity = 0.49795083
# T = 2110  Fidelity = 0.55004443
# T = 2120  Fidelity = 0.51509375
# T = 2130  Fidelity = 0.51542747
# T = 2140  Fidelity = 0.53165114
# T = 2150  Fidelity = 0.50787353
# T = 2160  Fidelity = 0.50398957
# T = 2170  Fidelity = 0.51705145
# T = 2180  Fidelity = 0.50982771
# T = 2190  Fidelity = 0.51422589
# T = 2200  Fidelity = 0.46195700
# T = 2300  Fidelity = 0.56413188
# T = 2400  Fidelity = 0.56780970
# T = 2500  Fidelity = 0.54151797
# T = 2600  Fidelity = 0.58583244
# T = 2700  Fidelity = 0.60463567
# T = 2800  Fidelity = 0.58092950
# T = 2900  Fidelity = 0.63166976
# T = 3000  Fidelity = 0.63414192
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.05026245e-03
# P0     = 0.63414192
# P1     = 0.34933239
# P0+P1  = 0.98347431
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 8.73711147e-04
# T = 1     Fidelity = 0.05379596
# T = 2     Fidelity = 0.09240133
# T = 5     Fidelity = 0.27762084
# T = 10    Fidelity = 0.32956675
# T = 20    Fidelity = 0.38679723
# T = 30    Fidelity = 0.41839456
# T = 40    Fidelity = 0.43884268
# T = 50    Fidelity = 0.45302399
# T = 75    Fidelity = 0.47501644
# T = 100   Fidelity = 0.48784134
# T = 125   Fidelity = 0.49618330
# T = 150   Fidelity = 0.50171698
# T = 175   Fidelity = 0.50525463
# T = 200   Fidelity = 0.50725920
# T = 225   Fidelity = 0.50853627
# T = 250   Fidelity = 0.50930658
# T = 275   Fidelity = 0.50996172
# T = 300   Fidelity = 0.51040693
# T = 400   Fidelity = 0.50344464
# T = 500   Fidelity = 0.51639649
# T = 600   Fidelity = 0.52887007
# T = 700   Fidelity = 0.52287729
# T = 800   Fidelity = 0.52561557
# T = 900   Fidelity = 0.52806157
# T = 1000  Fidelity = 0.52665583
# T = 1010  Fidelity = 0.55007535
# T = 1020  Fidelity = 0.54197553
# T = 1030  Fidelity = 0.54439449
# T = 1040  Fidelity = 0.54919748
# T = 1050  Fidelity = 0.52851811
# T = 1060  Fidelity = 0.54868945
# T = 1070  Fidelity = 0.54945695
# T = 1080  Fidelity = 0.52178060
# T = 1090  Fidelity = 0.53292657
# T = 1100  Fidelity = 0.54226241
# T = 1200  Fidelity = 0.54450708
# T = 1300  Fidelity = 0.53031165
# T = 1400  Fidelity = 0.53424988
# T = 1500  Fidelity = 0.53246762
# T = 2000  Fidelity = 0.56625870
# T = 2100  Fidelity = 0.58815351
# T = 2110  Fidelity = 0.60825353
# T = 2120  Fidelity = 0.59946436
# T = 2130  Fidelity = 0.60706405
# T = 2140  Fidelity = 0.61250463
# T = 2150  Fidelity = 0.60379692
# T = 2160  Fidelity = 0.60160433
# T = 2170  Fidelity = 0.59571470
# T = 2180  Fidelity = 0.60140701
# T = 2190  Fidelity = 0.61134048
# T = 2200  Fidelity = 0.60244127
# T = 2300  Fidelity = 0.60889444
# T = 2400  Fidelity = 0.62105460
# T = 2500  Fidelity = 0.62369027
# T = 2600  Fidelity = 0.58864879
# T = 2700  Fidelity = 0.62756078
# T = 2800  Fidelity = 0.61620219
# T = 2900  Fidelity = 0.64510220
# T = 3000  Fidelity = 0.62680238
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.78208763e-04
# P0     = 0.62680238
# P1     = 0.33778225
# P0+P1  = 0.96458463
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 8.58553719e-04
# T = 1     Fidelity = 0.05927803
# T = 2     Fidelity = 0.09767638
# T = 5     Fidelity = 0.30490012
# T = 10    Fidelity = 0.36731266
# T = 20    Fidelity = 0.42474579
# T = 30    Fidelity = 0.45358839
# T = 40    Fidelity = 0.47284862
# T = 50    Fidelity = 0.48635098
# T = 75    Fidelity = 0.50187545
# T = 100   Fidelity = 0.50610137
# T = 125   Fidelity = 0.50958201
# T = 150   Fidelity = 0.51140943
# T = 175   Fidelity = 0.51194154
# T = 200   Fidelity = 0.51352105
# T = 225   Fidelity = 0.51499263
# T = 250   Fidelity = 0.51667484
# T = 275   Fidelity = 0.51921681
# T = 300   Fidelity = 0.52051251
# T = 400   Fidelity = 0.51592874
# T = 500   Fidelity = 0.52345204
# T = 600   Fidelity = 0.53377743
# T = 700   Fidelity = 0.53662844
# T = 800   Fidelity = 0.53982054
# T = 900   Fidelity = 0.54721445
# T = 1000  Fidelity = 0.53221201
# T = 1010  Fidelity = 0.55598770
# T = 1020  Fidelity = 0.54004280
# T = 1030  Fidelity = 0.56217691
# T = 1040  Fidelity = 0.54256706
# T = 1050  Fidelity = 0.55696024
# T = 1060  Fidelity = 0.54769222
# T = 1070  Fidelity = 0.54250159
# T = 1080  Fidelity = 0.53940851
# T = 1090  Fidelity = 0.55130693
# T = 1100  Fidelity = 0.55922914
# T = 1200  Fidelity = 0.54224359
# T = 1300  Fidelity = 0.53399184
# T = 1400  Fidelity = 0.53330029
# T = 1500  Fidelity = 0.54906516
# T = 2000  Fidelity = 0.60332747
# T = 2100  Fidelity = 0.60492028
# T = 2110  Fidelity = 0.60743282
# T = 2120  Fidelity = 0.61800785
# T = 2130  Fidelity = 0.61380339
# T = 2140  Fidelity = 0.62039531
# T = 2150  Fidelity = 0.58989322
# T = 2160  Fidelity = 0.59904844
# T = 2170  Fidelity = 0.61629019
# T = 2180  Fidelity = 0.60679225
# T = 2190  Fidelity = 0.61934429
# T = 2200  Fidelity = 0.61424129
# T = 2300  Fidelity = 0.62433602
# T = 2400  Fidelity = 0.62124028
# T = 2500  Fidelity = 0.63288087
# T = 2600  Fidelity = 0.63106388
# T = 2700  Fidelity = 0.59317511
# T = 2800  Fidelity = 0.61617674
# T = 2900  Fidelity = 0.63157604
# T = 3000  Fidelity = 0.65690310
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.17642281e-04
# P0     = 0.65690310
# P1     = 0.32533367
# P0+P1  = 0.98223677
#
# Minimum T for Fidelity >= 0.99 : None
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99104990
#
# Minimum T for Fidelity >= 0.99 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.89703656
# T = 2     Fidelity = 0.95105414
# T = 5     Fidelity = 0.98171492
# T = 10    Fidelity = 0.99095934
#
# Minimum T for Fidelity >= 0.99 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.31621635e+00
# T = 1     Fidelity = 0.09939542
# T = 2     Fidelity = 0.29276841
# T = 5     Fidelity = 0.79922154
# T = 10    Fidelity = 0.98544604
# T = 20    Fidelity = 0.98775195
# T = 30    Fidelity = 0.98997004
# T = 40    Fidelity = 0.99098839
#
# Minimum T for Fidelity >= 0.99 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.40805723e+00
# T = 1     Fidelity = 0.12793919
# T = 2     Fidelity = 0.37726591
# T = 5     Fidelity = 0.79958936
# T = 10    Fidelity = 0.92189472
# T = 20    Fidelity = 0.99258593
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.23371320
# T = 2     Fidelity = 0.53154426
# T = 5     Fidelity = 0.91664336
# T = 10    Fidelity = 0.98293607
# T = 20    Fidelity = 0.99255650
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.30496309
# T = 2     Fidelity = 0.59422328
# T = 5     Fidelity = 0.91561513
# T = 10    Fidelity = 0.98292309
# T = 20    Fidelity = 0.99354872
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.36044767
# T = 2     Fidelity = 0.63489199
# T = 5     Fidelity = 0.93237223
# T = 10    Fidelity = 0.98431822
# T = 20    Fidelity = 0.99477342
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.40042858
# T = 2     Fidelity = 0.65866847
# T = 5     Fidelity = 0.93877197
# T = 10    Fidelity = 0.98279545
# T = 20    Fidelity = 0.99591392
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.43740723
# T = 2     Fidelity = 0.68099468
# T = 5     Fidelity = 0.94321025
# T = 10    Fidelity = 0.98179100
# T = 20    Fidelity = 0.99687649
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.46822587
# T = 2     Fidelity = 0.69745506
# T = 5     Fidelity = 0.94808849
# T = 10    Fidelity = 0.98105212
# T = 20    Fidelity = 0.99777483
#
# Minimum T for Fidelity >= 0.99 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     None      0.9788015935      3.07240439e-04    0.702474    0.0         0.702474
# Symmetric      0.311     175       0.9975489393      1.17908351e-06    None        None        None
# Symmetric      0.522     125       0.9959571470      2.94880926e-07    None        None        None
# Symmetric      0.733     100       0.9998447754      1.58119085e-07    None        None        None
# Symmetric      0.944     75        0.9978303838      6.89654431e-08    None        None        None
# Symmetric      1.156     50        0.9960857143      1.17592562e-07    None        None        None
# Symmetric      1.367     50        0.9913337248      2.47961144e-07    None        None        None
# Symmetric      1.578     50        0.9947585556      3.56990610e-07    None        None        None
# Symmetric      1.789     40        0.9938172476      2.45005900e-06    None        None        None
# Symmetric      2.000     40        0.9999220082      1.44257094e-05    None        None        None
# Weak SSB optimised0.100     None      0.9896466430      8.67181393e-01    0.94658     0.028179    0.974759
# Weak SSB optimised0.311     None      0.9854710951      5.19764834e-01    0.96985     0.00992     0.97977
# Weak SSB optimised0.522     50        0.9912011931      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     20        0.9981898128      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     20        0.9942404191      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     125       0.9913641716      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     1020      0.9919871655      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     900       0.9940222818      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     1020      0.9947250415      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     225       0.9911114009      2.48783584e-01    None        None        None
# Weak SSB       0.100     150       0.9904784353      1.81947687e-02    None        None        None
# Weak SSB       0.311     None      0.9886610919      1.51771385e-02    0.93718     2.5e-05     0.937205
# Weak SSB       0.522     None      0.4962282320      1.05614584e-03    0.08223     0.415353    0.497583
# Weak SSB       0.733     None      0.3484430432      1.07018746e-03    0.225245    0.251851    0.477095
# Weak SSB       0.944     None      0.4404570123      9.80171521e-04    0.405817    0.410412    0.816229
# Weak SSB       1.156     None      0.5820920616      9.40449540e-04    0.582092    0.405992    0.988084
# Weak SSB       1.367     None      0.5964223327      9.13233454e-04    0.476023    0.303678    0.779701
# Weak SSB       1.578     None      0.6341419203      8.91554516e-04    0.634142    0.349332    0.983474
# Weak SSB       1.789     None      0.6451021964      8.73711147e-04    0.626802    0.337782    0.964585
# Weak SSB       2.000     None      0.6569031009      8.58553719e-04    0.656903    0.325334    0.982237
# Strong SSB     0.100     1         0.9910498989      3.59472102e+00    None        None        None
# Strong SSB     0.311     10        0.9909593395      1.58498916e+00    None        None        None
# Strong SSB     0.522     40        0.9909883903      1.31621635e+00    None        None        None
# Strong SSB     0.733     20        0.9925859287      1.40805723e+00    None        None        None
# Strong SSB     0.944     20        0.9925565038      1.38481786e+00    None        None        None
# Strong SSB     1.156     20        0.9935487210      1.34302163e+00    None        None        None
# Strong SSB     1.367     20        0.9947734207      1.29217279e+00    None        None        None
# Strong SSB     1.578     20        0.9959139226      1.23335459e+00    None        None        None
# Strong SSB     1.789     20        0.9968764875      1.17426012e+00    None        None        None
# Strong SSB     2.000     20        0.9977748301      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
# ============================================================


plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.99$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.1556
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7333

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)

########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis $m_0^2=-2$'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ==================optimised==========================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
