# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # -------------------------------------------------------- kjacvbnm,./qwertyuiopp//÷//

 
    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=-1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = -1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756983
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=-1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# -0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
# ============================================================
# Genuine Qiskit VQE on shifted Pauli Hamiltonian
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SPSA

from qiskit.primitives import StatevectorEstimator


# ============================================================
# Variational circuit
# ============================================================

def variational_circuit(nq, layers):

    qc = QuantumCircuit(nq)

    nparams = 2 * nq * layers

    params = ParameterVector("θ", nparams)

    p = 0

    for l in range(layers):

        # ----------------------------------------------------
        # Single-qubit rotations
        # ----------------------------------------------------

        for q in range(nq):

            qc.ry(params[p], q)
            qc.rz(params[p + 1], q)

            p += 2

        # ----------------------------------------------------
        # Entanglement layer
        # ----------------------------------------------------

        if l != layers - 1:

            # even bonds
            if l % 2 == 0:

                for q in range(0, nq - 1, 2):
                    qc.cz(q, q + 1)

            # odd bonds
            else:

                for q in range(1, nq - 1, 2):
                    qc.cz(q, q + 1)

    return qc


# ============================================================
# Ansatz
# ============================================================

nqubits = 8

# start modestly
layers = 8

ansatz = variational_circuit(
    nqubits,
    layers
)

# ============================================================
# Estimator
# ============================================================

estimator = StatevectorEstimator()

# ============================================================
# Optimizer
# ============================================================

optimizer = SPSA(
    maxiter=5000
)

# ============================================================
# VQE
# ============================================================
initial_point = 0.01 * np.random.randn(
    ansatz.num_parameters
)
vqe = VQE(
    estimator=estimator,
    ansatz=ansatz,
    optimizer=optimizer,
    initial_point=initial_point
)

# ============================================================
# Run VQE
# ============================================================

print("\nRunning VQE...\n")

result = vqe.compute_minimum_eigenvalue(
    H_pauli_shifted
)

# ============================================================
# Shifted energy
# ============================================================

E_shifted = result.eigenvalue.real

# ============================================================
# Physical energy
# ============================================================

E_vqe = E_shifted + identity_shift

# ============================================================
# Optimal parameters
# ============================================================

optimal_params = result.optimal_parameters

# ============================================================
# Optimized circuit
# ============================================================

optimal_circuit = ansatz.assign_parameters(
    optimal_params
)

# ============================================================
# VQE state
# ============================================================

psi_vqe = Statevector.from_instruction(
    optimal_circuit
).data

# ============================================================
# Fidelity
# ============================================================

Fidelity = np.abs(
    np.vdot(psi_loc, psi_vqe)
)**2

# ============================================================
# Results
# ============================================================

print("\n================================")
print("Exact energy :", E0_loc)
print("VQE energy   :", E_vqe)
print("Energy error :", abs(E_vqe - E0_loc))
print("Fidelity     :", Fidelity)
print("Layers        :", layers)
print("Pauli terms   :", len(H_pauli_shifted))
print("================================")
# Out:
# Running VQE...
#
#
# ================================
# Exact energy : 1.0554722545756983
# VQE energy   : 1.0689980921294397
# Energy error : 0.013525837553741482
# Fidelity     : 0.9958369976414915
# Layers        : 8
# Pauli terms   : 111
# ================================

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
# ============================================================
# Robust VQE with eigenstate tracking
# ============================================================
import numpy as np

from scipy.sparse import identity, kron

from qiskit.quantum_info import (
    Statevector,
    Operator,
    SparsePauliOp
)

from qiskit.primitives import StatevectorEstimator

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B
def run_robust_vqe(

    H_sparse,

    nq,

    layers,

    n_restarts,

    energy_tol,

    previous_state=None,

    previous_optimal_point=None
):

    nqubits = nq

    # --------------------------------------------------------
    # Exact ground state
    # --------------------------------------------------------

    E_exact, psi_exact = exact_ground_state(H_sparse)

    # --------------------------------------------------------
    # Convert Hamiltonian
    # --------------------------------------------------------

    H_dense = H_sparse.toarray()

    H_op = Operator(H_dense)

    H_pauli = SparsePauliOp.from_operator(H_op)

    coeffs = H_pauli.coeffs

    paulis = H_pauli.paulis

    new_coeffs = []

    new_paulis = []

    identity_shift = 0.0

    for p, c in zip(paulis, coeffs):

        if str(p) == 'I' * nqubits:

            identity_shift += np.real(c)

        else:

            new_paulis.append(p)

            new_coeffs.append(c)

    H_pauli_shifted = SparsePauliOp(

        new_paulis,

        coeffs=new_coeffs
    )

    # --------------------------------------------------------
    # Ansatz
    # --------------------------------------------------------

    ansatz = variational_circuit(

        nq=nqubits,

        layers=layers
    )

    estimator = StatevectorEstimator()

    optimizer = L_BFGS_B(maxiter=1000)

    # ========================================================
    # Multiple restarts
    # ========================================================

    trial_results = []

    for trial in range(n_restarts):

        # ----------------------------------------------------
        # Initial point
        # ----------------------------------------------------

        if trial == 0 and previous_optimal_point is not None:

            initial_point = previous_optimal_point

        else:

            initial_point = 0.01 * np.random.randn(

                ansatz.num_parameters
            )

        # ----------------------------------------------------
        # VQE
        # ----------------------------------------------------

        vqe = VQE(

            estimator=estimator,

            ansatz=ansatz,

            optimizer=optimizer,

            initial_point=initial_point
        )

        result = vqe.compute_minimum_eigenvalue(

            H_pauli_shifted
        )

        E_trial = (

            np.real(result.eigenvalue)

            + identity_shift
        )

        # ----------------------------------------------------
        # Trial state
        # ----------------------------------------------------

        qc_trial = ansatz.assign_parameters(

            result.optimal_parameters
        )

        psi_trial = Statevector.from_instruction(

            qc_trial

        ).data

        # ----------------------------------------------------
        # Overlap tracking
        # ----------------------------------------------------

        if previous_state is None:

            overlap = 1.0

        else:

            overlap = abs(np.vdot(

                previous_state,

                psi_trial

            ))**2

        trial_results.append({

            'energy': E_trial,

            'overlap': overlap,

            'state': psi_trial,

            'result': result
        })

    # ========================================================
    # Hybrid selection
    # ========================================================

    energies = np.array([

        t['energy']

        for t in trial_results
    ])

    E_min = np.min(energies)

    filtered_candidates = [

        t for t in trial_results

        if (t['energy'] - E_min) < energy_tol
    ]

    best_candidate = max(

        filtered_candidates,

        key=lambda x: x['overlap']
    )

    # ========================================================
    # Outputs
    # ========================================================

    # ========================================================
    # Final outputs
    # ========================================================

    psi_vqe = best_candidate['state']

    E_vqe = best_candidate['energy']

    optimal_point = (

        best_candidate['result'].optimal_point
    )

    tracking_overlap = best_candidate['overlap']

    F = fidelity(

    psi_exact,

    psi_vqe
    )

    return {

        "E_exact": E_exact,

        "E_vqe": E_vqe,

        "psi_vqe": psi_vqe,

        "fidelity": F,

        "tracking_overlap": tracking_overlap,

        "optimal_point": optimal_point,

        "state_for_tracking": psi_vqe
    }

# %%
nq_site = 4

nqubits = 2 * nq_site

mu = 1.0

layers = 8

# ============================================================
# VQE settings
# ============================================================

n_restarts = 5

energy_tol = 1e-3

# ============================================================
# Parameter sets
# ============================================================

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },

    {
        "label": "Weak SSB",
        "mI2": -1.0,
        "f": -1e-5
    },
    
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": -5*1e-2
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": -0.5
    }
]

# ============================================================
# Lambda scan
# ============================================================

lambda_list = np.linspace(0.1, 2.0, 10)

# ============================================================
# Storage
# ============================================================

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]

    mI2 = params["mI2"]

    f = params["f"]

    print("\n")
    print("#"*80)

    print(f"CASE: {label}")

    print(f"mI² = {mI2},  f = {f}")

    print("#"*80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------

    previous_state = None

    previous_optimal_point = None

    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "="*60)

        print(f"Running λ = {lam:.3f}")

        print("="*60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(

            nq=nq_site,

            mu=mu,

            mI2=mI2,

            lam=lam,

            f=f
        )

        # ====================================================
        # Run robust VQE
        # ====================================================

        vqe_data = run_robust_vqe(

            H_sparse=Hloc_sparse,

            nq=nqubits,

            layers=layers,

            n_restarts=n_restarts,

            energy_tol=energy_tol,

            previous_state=previous_state,

            previous_optimal_point=previous_optimal_point
        )

        # ====================================================
        # Extract outputs
        # ====================================================

        E_exact = vqe_data["E_exact"]

        E_vqe = vqe_data["E_vqe"]

        psi_vqe = vqe_data["psi_vqe"]

        F = vqe_data["fidelity"]

        tracking_overlap = vqe_data["tracking_overlap"]

        # ----------------------------------------------------
        # Update tracking
        # ----------------------------------------------------

        previous_state = vqe_data["state_for_tracking"]

        previous_optimal_point = (

            vqe_data["optimal_point"]
        )

        # ----------------------------------------------------
        # Store
        # ----------------------------------------------------

        data = {

            'case': label,

            'lambda': lam,

            'mI2': mI2,

            'f': f,

            'E_exact': E_exact,

            'E_vqe': E_vqe,

            'error': abs(E_exact - E_vqe),

            'fidelity': F,

            'tracking_overlap': tracking_overlap,

            'psi_vqe': psi_vqe
        }

        case_results.append(data)

        all_results.append(data)

        # ----------------------------------------------------
        # Print
        # ----------------------------------------------------

        print("\nFINAL SELECTED STATE")

        print(f"Exact energy     : {E_exact:.12f}")

        print(f"VQE energy       : {E_vqe:.12f}")

        print(
            f"Energy error     : "
            f"{abs(E_exact - E_vqe):.6e}"
        )

        print(f"Fidelity         : {F:.12f}")

        print(
            f"Tracking overlap : "
            f"{tracking_overlap:.12f}"
        )

    # ========================================================
    # Case summary
    # ========================================================

    print("\n")

    print("="*110)

    print(f"SUMMARY : {label}")

    print("="*110)

    print(

        f"{'lambda':<12} "
        f"{'Exact E':<18} "
        f"{'VQE E':<18} "
        f"{'Error':<15} "
        f"{'Fidelity':<15} "
        f"{'TrackOverlap':<15}"
    )

    print("="*110)

    for r in case_results:

        print(

            f"{r['lambda']:<12.4f} "
            f"{r['E_exact']:<18.10f} "
            f"{r['E_vqe']:<18.10f} "
            f"{r['error']:<15.4e} "
            f"{r['fidelity']:<15.10f} "
            f"{r['tracking_overlap']:<15.10f}"
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
# VQE energy       : 1.006161728114
# Energy error     : 4.515610e-11
# Fidelity         : 0.999999987225
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.018641427347
# VQE energy       : 1.018641587329
# Energy error     : 1.599823e-07
# Fidelity         : 0.999999950567
# Tracking overlap : 0.999849395533
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.030499309794
# VQE energy       : 1.030499436266
# Energy error     : 1.264716e-07
# Fidelity         : 0.999999964777
# Tracking overlap : 0.999876049994
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.041824322261
# VQE energy       : 1.041824428790
# Energy error     : 1.065288e-07
# Fidelity         : 0.999999973687
# Tracking overlap : 0.999895503072
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.052684543762
# VQE energy       : 1.052684683585
# Energy error     : 1.398230e-07
# Fidelity         : 0.999999984258
# Tracking overlap : 0.999910781434
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.063133788770
# VQE energy       : 1.063134023624
# Energy error     : 2.348543e-07
# Fidelity         : 0.999999977662
# Tracking overlap : 0.999922497001
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.073215653771
# VQE energy       : 1.073215992498
# Energy error     : 3.387273e-07
# Fidelity         : 0.999999969857
# Tracking overlap : 0.999931920537
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.082966151815
# VQE energy       : 1.082966635734
# Energy error     : 4.839192e-07
# Fidelity         : 0.999999945999
# Tracking overlap : 0.999939528385
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.092415508107
# VQE energy       : 1.092416046395
# Energy error     : 5.382870e-07
# Fidelity         : 0.999999944815
# Tracking overlap : 0.999945789365
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
# VQE energy       : 1.101590028454
# Energy error     : 5.997115e-07
# Fidelity         : 0.999999920789
# Tracking overlap : 0.999951298990
#
#
# ==============================================================================================================
# SUMMARY : Symmetric
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       1.0061617282       1.0061617281       4.5156e-11      0.9999999872    1.0000000000
# 0.3111       1.0186414273       1.0186415873       1.5998e-07      0.9999999506    0.9998493955
# 0.5222       1.0304993098       1.0304994363       1.2647e-07      0.9999999648    0.9998760500
# 0.7333       1.0418243223       1.0418244288       1.0653e-07      0.9999999737    0.9998955031
# 0.9444       1.0526845438       1.0526846836       1.3982e-07      0.9999999843    0.9999107814
# 1.1556       1.0631337888       1.0631340236       2.3485e-07      0.9999999777    0.9999224970
# 1.3667       1.0732156538       1.0732159925       3.3873e-07      0.9999999699    0.9999319205
# 1.5778       1.0829661518       1.0829666357       4.8392e-07      0.9999999460    0.9999395284
# 1.7889       1.0924155081       1.0924160464       5.3829e-07      0.9999999448    0.9999457894
# 2.0000       1.1015894287       1.1015900285       5.9971e-07      0.9999999208    0.9999512990
#
#
# ################################################################################
# CASE: Weak SSB
# mI² = -1.0,  f = -1e-05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -16.943902169977
# VQE energy       : -16.943764837768
# Energy error     : 1.373322e-04
# Fidelity         : 0.999986849751
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -8.892068720847
# VQE energy       : -8.891849677045
# Energy error     : 2.190438e-04
# Fidelity         : 0.999923004733
# Tracking overlap : 0.875770227160
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.379113856397
# VQE energy       : -4.379110375024
# Energy error     : 3.481373e-06
# Fidelity         : 0.997276279518
# Tracking overlap : 0.049089282030
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.749793396636
# VQE energy       : -2.749793090031
# Energy error     : 3.066052e-07
# Fidelity         : 0.999938899185
# Tracking overlap : 0.000000000014
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.874700666195
# VQE energy       : -1.874700584383
# Energy error     : 8.181202e-08
# Fidelity         : 0.999998400481
# Tracking overlap : 0.821478426963
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.348821613293
# VQE energy       : -1.348820957809
# Energy error     : 6.554842e-07
# Fidelity         : 0.999999863604
# Tracking overlap : 0.894886985343
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.010439481239
# VQE energy       : -1.010437373027
# Energy error     : 2.108212e-06
# Fidelity         : 0.999999222392
# Tracking overlap : 0.937007231497
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.779139779365
# VQE energy       : -0.779104492470
# Energy error     : 3.528689e-05
# Fidelity         : 0.999986741263
# Tracking overlap : 0.962801812700
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.611723370121
# VQE energy       : -0.611721156978
# Energy error     : 2.213143e-06
# Fidelity         : 0.999999554036
# Tracking overlap : 0.977782307439
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.484295385847
# VQE energy       : -0.484293980916
# Energy error     : 1.404930e-06
# Fidelity         : 0.999999749643
# Tracking overlap : 0.986389589356
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -16.9439021700     -16.9437648378     1.3733e-04      0.9999868498    1.0000000000
# 0.3111       -8.8920687208      -8.8918496770      2.1904e-04      0.9999230047    0.8757702272
# 0.5222       -4.3791138564      -4.3791103750      3.4814e-06      0.9972762795    0.0490892820
# 0.7333       -2.7497933966      -2.7497930900      3.0661e-07      0.9999388992    0.0000000000
# 0.9444       -1.8747006662      -1.8747005844      8.1812e-08      0.9999984005    0.8214784270
# 1.1556       -1.3488216133      -1.3488209578      6.5548e-07      0.9999998636    0.8948869853
# 1.3667       -1.0104394812      -1.0104373730      2.1082e-06      0.9999992224    0.9370072315
# 1.5778       -0.7791397794      -0.7791044925      3.5287e-05      0.9999867413    0.9628018127
# 1.7889       -0.6117233701      -0.6117211570      2.2131e-06      0.9999995540    0.9777823074
# 2.0000       -0.4842953858      -0.4842939809      1.4049e-06      0.9999997496    0.9863895894
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = -0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
# VQE energy       : -17.064142309764
# Energy error     : 5.510421e-04
# Fidelity         : 0.999898139772
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -9.080449912257
# VQE energy       : -9.078747402591
# Energy error     : 1.702510e-03
# Fidelity         : 0.999583301965
# Tracking overlap : 0.804912453500
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.701194972617
# VQE energy       : -4.701043015979
# Energy error     : 1.519566e-04
# Fidelity         : 0.999950807409
# Tracking overlap : 0.068791878298
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.011531351621
# VQE energy       : -3.011454767225
# Energy error     : 7.658440e-05
# Fidelity         : 0.999973753502
# Tracking overlap : 0.655227365604
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.083565723454
# VQE energy       : -2.083546332641
# Energy error     : 1.939081e-05
# Fidelity         : 0.999994634835
# Tracking overlap : 0.831051988165
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.504487872733
# VQE energy       : -1.503541320938
# Energy error     : 9.465518e-04
# Fidelity         : 0.999840180945
# Tracking overlap : 0.896483724718
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.119099730425
# VQE energy       : -1.118508058788
# Energy error     : 5.916716e-04
# Fidelity         : 0.999704786160
# Tracking overlap : 0.914129082890
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.853332054001
# VQE energy       : -0.853244356958
# Energy error     : 8.769704e-05
# Fidelity         : 0.999971111850
# Tracking overlap : 0.940284609766
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.663560141541
# VQE energy       : -0.663535256738
# Energy error     : 2.488480e-05
# Fidelity         : 0.999997098836
# Tracking overlap : 0.959310461849
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
# VQE energy       : -0.522120109349
# Energy error     : 1.965495e-05
# Fidelity         : 0.999997582212
# Tracking overlap : 0.975705501035
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB optimised
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -17.0646933519     -17.0641423098     5.5104e-04      0.9998981398    1.0000000000
# 0.3111       -9.0804499123      -9.0787474026      1.7025e-03      0.9995833020    0.8049124535
# 0.5222       -4.7011949726      -4.7010430160      1.5196e-04      0.9999508074    0.0687918783
# 0.7333       -3.0115313516      -3.0114547672      7.6584e-05      0.9999737535    0.6552273656
# 0.9444       -2.0835657235      -2.0835463326      1.9391e-05      0.9999946348    0.8310519882
# 1.1556       -1.5044878727      -1.5035413209      9.4655e-04      0.9998401809    0.8964837247
# 1.3667       -1.1190997304      -1.1185080588      5.9167e-04      0.9997047862    0.9141290829
# 1.5778       -0.8533320540      -0.8532443570      8.7697e-05      0.9999711119    0.9402846098
# 1.7889       -0.6635601415      -0.6635352567      2.4885e-05      0.9999970988    0.9593104618
# 2.0000       -0.5221397643      -0.5221201093      1.9655e-05      0.9999975822    0.9757055010
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = -0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
# VQE energy       : -20.777053027083
# Energy error     : 2.754182e-04
# Fidelity         : 0.999976183267
# Tracking overlap : 1.000000000000
#
# ============================================================
# Running λ = 0.311
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -12.836441142849
# VQE energy       : -12.836327934100
# Energy error     : 1.132087e-04
# Fidelity         : 0.999982274597
# Tracking overlap : 0.849171222540
#
# ============================================================
# Running λ = 0.522
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -7.730716364832
# VQE energy       : -7.729953820268
# Energy error     : 7.625446e-04
# Fidelity         : 0.999896904715
# Tracking overlap : 0.166877818460
#
# ============================================================
# Running λ = 0.733
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.538148830702
# VQE energy       : -5.538007499886
# Energy error     : 1.413308e-04
# Fidelity         : 0.999985489071
# Tracking overlap : 0.635120500503
#
# ============================================================
# Running λ = 0.944
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.276013792929
# VQE energy       : -4.276010329224
# Energy error     : 3.463704e-06
# Fidelity         : 0.999999668444
# Tracking overlap : 0.822560397730
#
# ============================================================
# Running λ = 1.156
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.448680385431
# VQE energy       : -3.448185217485
# Energy error     : 4.951679e-04
# Fidelity         : 0.999943881845
# Tracking overlap : 0.904925220512
#
# ============================================================
# Running λ = 1.367
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.860832265178
# VQE energy       : -2.860608056368
# Energy error     : 2.242088e-04
# Fidelity         : 0.999973417422
# Tracking overlap : 0.941563087921
#
# ============================================================
# Running λ = 1.578
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.420090529280
# VQE energy       : -2.419985595013
# Energy error     : 1.049343e-04
# Fidelity         : 0.999990593167
# Tracking overlap : 0.962076210050
#
# ============================================================
# Running λ = 1.789
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.076312567620
# VQE energy       : -2.076296594992
# Energy error     : 1.597263e-05
# Fidelity         : 0.999998315650
# Tracking overlap : 0.974104020913
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
# VQE energy       : -1.800063099964
# Energy error     : 1.016625e-05
# Fidelity         : 0.999999284595
# Tracking overlap : 0.981135437218
#
#
# ==============================================================================================================
# SUMMARY : Strong SSB
# ==============================================================================================================
# lambda       Exact E            VQE E              Error           Fidelity        TrackOverlap
# ==============================================================================================================
# 0.1000       -20.7773284453     -20.7770530271     2.7542e-04      0.9999761833    1.0000000000
# 0.3111       -12.8364411428     -12.8363279341     1.1321e-04      0.9999822746    0.8491712225
# 0.5222       -7.7307163648      -7.7299538203      7.6254e-04      0.9998969047    0.1668778185
# 0.7333       -5.5381488307      -5.5380074999      1.4133e-04      0.9999854891    0.6351205005
# 0.9444       -4.2760137929      -4.2760103292      3.4637e-06      0.9999996684    0.8225603977
# 1.1556       -3.4486803854      -3.4481852175      4.9517e-04      0.9999438818    0.9049252205
# 1.3667       -2.8608322652      -2.8606080564      2.2421e-04      0.9999734174    0.9415630879
# 1.5778       -2.4200905293      -2.4199855950      1.0493e-04      0.9999905932    0.9620762100
# 1.7889       -2.0763125676      -2.0762965950      1.5973e-05      0.9999983156    0.9741040209
# 2.0000       -1.8000732662      -1.8000631000      1.0166e-05      0.9999992846    0.9811354372

# %%
# ============================================================
# Plot : Fidelity vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ------------------------------------------------------------
# Collect data
# ------------------------------------------------------------

cases = {}

for r in all_results:

    label = r['case']

    if label not in cases:

        cases[label] = {
            'lambda': [],
            'fidelity': []
        }

    cases[label]['lambda'].append(r['lambda'])
    cases[label]['fidelity'].append(r['fidelity'])

# ------------------------------------------------------------
# Plot
# ------------------------------------------------------------

plt.figure(figsize=(8,6))

for label, data in cases.items():

    plt.plot(
        data['lambda'],
        data['fidelity'],
        marker='o',
        linewidth=2,
        label=label
    )

# ------------------------------------------------------------
# Labels
# ------------------------------------------------------------

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$F_{loc}$', fontsize=14)

plt.title(
    r'VQE Fidelity vs $\lambda$',
    fontsize=16
)

plt.grid(True)

plt.legend(fontsize=12)

plt.tight_layout()

plt.savefig(
    "HEA_F-loc vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %%
def find_lambda_c(lams, d2M, d3M, dM):

    best_lambda = np.nan
    best_response = -np.inf

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            # linear interpolation for d2M = 0
            x1, x2 = lams[i], lams[i+1]
            y1, y2 = d2M[i], d2M[i+1]

            lam = x1 - y1*(x2-x1)/(y2-y1)

            # interpolate dM at the same point
            dm = dM[i] + (dM[i+1]-dM[i])*(lam-x1)/(x2-x1)

            if abs(dm) > best_response:
                best_response = abs(dm)
                best_lambda = lam

    return best_lambda

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98118819
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98266922
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98396121
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98504539
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98600646
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98686045
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762416
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98830885
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893924
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98951040
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.13498607e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063719
# T = 10    Fidelity = 0.00011443
# T = 20    Fidelity = 0.00399124
# T = 30    Fidelity = 0.05555151
# T = 40    Fidelity = 0.12244107
# T = 50    Fidelity = 0.21150295
# T = 75    Fidelity = 0.58068501
# T = 100   Fidelity = 0.76534127
# T = 125   Fidelity = 0.73560467
# T = 150   Fidelity = 0.86963256
# T = 175   Fidelity = 0.91395427
# T = 200   Fidelity = 0.87535521
# T = 225   Fidelity = 0.95253178
# T = 250   Fidelity = 0.98643280
#
# Minimum T for Fidelity >= 0.97 : 250
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.22564919e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000006
# T = 5     Fidelity = 0.00018139
# T = 10    Fidelity = 0.04096686
# T = 20    Fidelity = 0.42094006
# T = 30    Fidelity = 0.49043595
# T = 40    Fidelity = 0.64137068
# T = 50    Fidelity = 0.64427170
# T = 75    Fidelity = 0.88093055
# T = 100   Fidelity = 0.90191222
# T = 125   Fidelity = 0.87192087
# T = 150   Fidelity = 0.88628577
# T = 175   Fidelity = 0.92110062
# T = 200   Fidelity = 0.94262348
# T = 225   Fidelity = 0.95689798
# T = 250   Fidelity = 0.95086013
# T = 275   Fidelity = 0.96223770
# T = 300   Fidelity = 0.94442042
# T = 400   Fidelity = 0.98179863
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.14483174e-04
# T = 1     Fidelity = 0.00001184
# T = 2     Fidelity = 0.00016907
# T = 5     Fidelity = 0.01433555
# T = 10    Fidelity = 0.17119464
# T = 20    Fidelity = 0.44273522
# T = 30    Fidelity = 0.34004204
# T = 40    Fidelity = 0.54717398
# T = 50    Fidelity = 0.43879018
# T = 75    Fidelity = 0.49359521
# T = 100   Fidelity = 0.50316142
# T = 125   Fidelity = 0.50308056
# T = 150   Fidelity = 0.50221489
# T = 175   Fidelity = 0.50142551
# T = 200   Fidelity = 0.49698466
# T = 225   Fidelity = 0.50876405
# T = 250   Fidelity = 0.50137133
# T = 275   Fidelity = 0.48749578
# T = 300   Fidelity = 0.48758162
# T = 400   Fidelity = 0.49867547
# T = 500   Fidelity = 0.30952399
# T = 600   Fidelity = 0.51098315
# T = 700   Fidelity = 0.39124551
# T = 800   Fidelity = 0.53873027
# T = 900   Fidelity = 0.53606150
# T = 1000  Fidelity = 0.70835934
# T = 1010  Fidelity = 0.40404230
# T = 1020  Fidelity = 0.40790055
# T = 1030  Fidelity = 0.47796813
# T = 1040  Fidelity = 0.50607529
# T = 1050  Fidelity = 0.47579609
# T = 1060  Fidelity = 0.37539698
# T = 1070  Fidelity = 0.57019392
# T = 1080  Fidelity = 0.27358153
# T = 1090  Fidelity = 0.28164113
# T = 1100  Fidelity = 0.62086427
# T = 1200  Fidelity = 0.29946465
# T = 1300  Fidelity = 0.56645053
# T = 1400  Fidelity = 0.55233532
# T = 1500  Fidelity = 0.37842120
# T = 2000  Fidelity = 0.31512295
# T = 2100  Fidelity = 0.22278888
# T = 2110  Fidelity = 0.58887952
# T = 2120  Fidelity = 0.50693552
# T = 2130  Fidelity = 0.53892840
# T = 2140  Fidelity = 0.35493792
# T = 2150  Fidelity = 0.48218707
# T = 2160  Fidelity = 0.42020280
# T = 2170  Fidelity = 0.42326585
# T = 2180  Fidelity = 0.57071732
# T = 2190  Fidelity = 0.21668887
# T = 2200  Fidelity = 0.51742180
# T = 2300  Fidelity = 0.57565808
# T = 2400  Fidelity = 0.53678134
# T = 2500  Fidelity = 0.50400227
# T = 2600  Fidelity = 0.51048884
# T = 2700  Fidelity = 0.63553163
# T = 2800  Fidelity = 0.66482368
# T = 2900  Fidelity = 0.52319282
# T = 3000  Fidelity = 0.49551097
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
# P0     = 0.49551097
# P1     = 0.00063615
# P0+P1  = 0.49614712
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.21982966e-04
# T = 1     Fidelity = 0.00307212
# T = 2     Fidelity = 0.01239178
# T = 5     Fidelity = 0.08439567
# T = 10    Fidelity = 0.22347346
# T = 20    Fidelity = 0.31776624
# T = 30    Fidelity = 0.38306991
# T = 40    Fidelity = 0.54977060
# T = 50    Fidelity = 0.58075730
# T = 75    Fidelity = 0.50038424
# T = 100   Fidelity = 0.52178252
# T = 125   Fidelity = 0.52337555
# T = 150   Fidelity = 0.52320453
# T = 175   Fidelity = 0.52000980
# T = 200   Fidelity = 0.53034897
# T = 225   Fidelity = 0.52293674
# T = 250   Fidelity = 0.51831774
# T = 275   Fidelity = 0.52662022
# T = 300   Fidelity = 0.49518111
# T = 400   Fidelity = 0.51004120
# T = 500   Fidelity = 0.55445667
# T = 600   Fidelity = 0.50913843
# T = 700   Fidelity = 0.44381131
# T = 800   Fidelity = 0.45443774
# T = 900   Fidelity = 0.53557952
# T = 1000  Fidelity = 0.78107576
# T = 1010  Fidelity = 0.44827148
# T = 1020  Fidelity = 0.12726939
# T = 1030  Fidelity = 0.56288172
# T = 1040  Fidelity = 0.79509784
# T = 1050  Fidelity = 0.59786571
# T = 1060  Fidelity = 0.48945383
# T = 1070  Fidelity = 0.50197136
# T = 1080  Fidelity = 0.42478381
# T = 1090  Fidelity = 0.25694854
# T = 1100  Fidelity = 0.74486864
# T = 1200  Fidelity = 0.58972580
# T = 1300  Fidelity = 0.45970322
# T = 1400  Fidelity = 0.52938054
# T = 1500  Fidelity = 0.54443284
# T = 2000  Fidelity = 0.46786790
# T = 2100  Fidelity = 0.53038324
# T = 2110  Fidelity = 0.56807116
# T = 2120  Fidelity = 0.48124361
# T = 2130  Fidelity = 0.40456890
# T = 2140  Fidelity = 0.57397314
# T = 2150  Fidelity = 0.78517183
# T = 2160  Fidelity = 0.45190583
# T = 2170  Fidelity = 0.25308493
# T = 2180  Fidelity = 0.50752078
# T = 2190  Fidelity = 0.70346487
# T = 2200  Fidelity = 0.63130451
# T = 2300  Fidelity = 0.83237419
# T = 2400  Fidelity = 0.55105000
# T = 2500  Fidelity = 0.52131886
# T = 2600  Fidelity = 0.57275601
# T = 2700  Fidelity = 0.46746424
# T = 2800  Fidelity = 0.55979559
# T = 2900  Fidelity = 0.32446620
# T = 3000  Fidelity = 0.46074599
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
# P0     = 0.46074599
# P1     = 0.00024332
# P0+P1  = 0.46098931
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.33063144e-03
# T = 1     Fidelity = 0.02405001
# T = 2     Fidelity = 0.06514847
# T = 5     Fidelity = 0.21903024
# T = 10    Fidelity = 0.40681951
# T = 20    Fidelity = 0.52935104
# T = 30    Fidelity = 0.49787392
# T = 40    Fidelity = 0.50387876
# T = 50    Fidelity = 0.54928873
# T = 75    Fidelity = 0.60866475
# T = 100   Fidelity = 0.60707884
# T = 125   Fidelity = 0.61208867
# T = 150   Fidelity = 0.61606702
# T = 175   Fidelity = 0.61942439
# T = 200   Fidelity = 0.62646497
# T = 225   Fidelity = 0.62930938
# T = 250   Fidelity = 0.63308147
# T = 275   Fidelity = 0.62996720
# T = 300   Fidelity = 0.64621181
# T = 400   Fidelity = 0.59413382
# T = 500   Fidelity = 0.65374336
# T = 600   Fidelity = 0.67757385
# T = 700   Fidelity = 0.59512390
# T = 800   Fidelity = 0.71410744
# T = 900   Fidelity = 0.60951321
# T = 1000  Fidelity = 0.48797211
# T = 1010  Fidelity = 0.76101209
# T = 1020  Fidelity = 0.85265106
# T = 1030  Fidelity = 0.75201536
# T = 1040  Fidelity = 0.53080926
# T = 1050  Fidelity = 0.47569625
# T = 1060  Fidelity = 0.65096314
# T = 1070  Fidelity = 0.77848793
# T = 1080  Fidelity = 0.82290176
# T = 1090  Fidelity = 0.55787049
# T = 1100  Fidelity = 0.40190522
# T = 1200  Fidelity = 0.46098509
# T = 1300  Fidelity = 0.54242342
# T = 1400  Fidelity = 0.77144720
# T = 1500  Fidelity = 0.68257298
# T = 2000  Fidelity = 0.77616742
# T = 2100  Fidelity = 0.82189021
# T = 2110  Fidelity = 0.81251733
# T = 2120  Fidelity = 0.55444651
# T = 2130  Fidelity = 0.65792906
# T = 2140  Fidelity = 0.71477335
# T = 2150  Fidelity = 0.83411941
# T = 2160  Fidelity = 0.84962962
# T = 2170  Fidelity = 0.78544269
# T = 2180  Fidelity = 0.53547952
# T = 2190  Fidelity = 0.57231275
# T = 2200  Fidelity = 0.70209448
# T = 2300  Fidelity = 0.77092002
# T = 2400  Fidelity = 0.75746506
# T = 2500  Fidelity = 0.83047356
# T = 2600  Fidelity = 0.73448551
# T = 2700  Fidelity = 0.78131300
# T = 2800  Fidelity = 0.76630173
# T = 2900  Fidelity = 0.70211952
# T = 3000  Fidelity = 0.75464510
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
# P0     = 0.75464510
# P1     = 0.00005535
# P0+P1  = 0.75470045
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50115281e-02
# T = 1     Fidelity = 0.08269221
# T = 2     Fidelity = 0.17487003
# T = 5     Fidelity = 0.39233173
# T = 10    Fidelity = 0.58593573
# T = 20    Fidelity = 0.71389352
# T = 30    Fidelity = 0.72027375
# T = 40    Fidelity = 0.71303218
# T = 50    Fidelity = 0.71876440
# T = 75    Fidelity = 0.74412890
# T = 100   Fidelity = 0.76245828
# T = 125   Fidelity = 0.77527487
# T = 150   Fidelity = 0.78586969
# T = 175   Fidelity = 0.79500674
# T = 200   Fidelity = 0.80419368
# T = 225   Fidelity = 0.81046135
# T = 250   Fidelity = 0.81599535
# T = 275   Fidelity = 0.82616821
# T = 300   Fidelity = 0.81747557
# T = 400   Fidelity = 0.87422974
# T = 500   Fidelity = 0.87059723
# T = 600   Fidelity = 0.79408441
# T = 700   Fidelity = 0.82786652
# T = 800   Fidelity = 0.84471932
# T = 900   Fidelity = 0.85230135
# T = 1000  Fidelity = 0.87686893
# T = 1010  Fidelity = 0.79393449
# T = 1020  Fidelity = 0.77899293
# T = 1030  Fidelity = 0.86814681
# T = 1040  Fidelity = 0.95158961
# T = 1050  Fidelity = 0.97309115
#
# Minimum T for Fidelity >= 0.97 : 1050
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77198754e-02
# T = 1     Fidelity = 0.17552239
# T = 2     Fidelity = 0.31615891
# T = 5     Fidelity = 0.55534936
# T = 10    Fidelity = 0.72504501
# T = 20    Fidelity = 0.82958063
# T = 30    Fidelity = 0.85318698
# T = 40    Fidelity = 0.85903334
# T = 50    Fidelity = 0.86471431
# T = 75    Fidelity = 0.88212439
# T = 100   Fidelity = 0.89841846
# T = 125   Fidelity = 0.90981873
# T = 150   Fidelity = 0.91812913
# T = 175   Fidelity = 0.92577004
# T = 200   Fidelity = 0.93482721
# T = 225   Fidelity = 0.93593244
# T = 250   Fidelity = 0.93620116
# T = 275   Fidelity = 0.94547652
# T = 300   Fidelity = 0.93551143
# T = 400   Fidelity = 0.94951023
# T = 500   Fidelity = 0.95254679
# T = 600   Fidelity = 0.96027106
# T = 700   Fidelity = 0.91549117
# T = 800   Fidelity = 0.92800233
# T = 900   Fidelity = 0.94696757
# T = 1000  Fidelity = 0.93972925
# T = 1010  Fidelity = 0.95199764
# T = 1020  Fidelity = 0.95694568
# T = 1030  Fidelity = 0.97881395
#
# Minimum T for Fidelity >= 0.97 : 1030
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20186803e-01
# T = 1     Fidelity = 0.28037419
# T = 2     Fidelity = 0.45285400
# T = 5     Fidelity = 0.68136909
# T = 10    Fidelity = 0.81903624
# T = 20    Fidelity = 0.89648659
# T = 30    Fidelity = 0.91796776
# T = 40    Fidelity = 0.92933280
# T = 50    Fidelity = 0.93800528
# T = 75    Fidelity = 0.95170873
# T = 100   Fidelity = 0.96197979
# T = 125   Fidelity = 0.96841175
# T = 150   Fidelity = 0.97426767
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405410e-01
# T = 1     Fidelity = 0.37884657
# T = 2     Fidelity = 0.56664129
# T = 5     Fidelity = 0.77023799
# T = 10    Fidelity = 0.87919048
# T = 20    Fidelity = 0.93535201
# T = 30    Fidelity = 0.95283824
# T = 40    Fidelity = 0.96404470
# T = 50    Fidelity = 0.96972177
# T = 75    Fidelity = 0.97962830
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843285e-01
# T = 1     Fidelity = 0.46389906
# T = 2     Fidelity = 0.65552105
# T = 5     Fidelity = 0.83099831
# T = 10    Fidelity = 0.91708806
# T = 20    Fidelity = 0.95854544
# T = 30    Fidelity = 0.97286766
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00037845
# T = 10    Fidelity = 0.00052822
# T = 20    Fidelity = 0.01190995
# T = 30    Fidelity = 0.08164359
# T = 40    Fidelity = 0.18832651
# T = 50    Fidelity = 0.42829607
# T = 75    Fidelity = 0.56700758
# T = 100   Fidelity = 0.72858596
# T = 125   Fidelity = 0.80814969
# T = 150   Fidelity = 0.83647186
# T = 175   Fidelity = 0.90652727
# T = 200   Fidelity = 0.91917045
# T = 225   Fidelity = 0.96697034
# T = 250   Fidelity = 0.89063545
# T = 275   Fidelity = 0.96876320
# T = 300   Fidelity = 0.85573356
# T = 400   Fidelity = 0.98022332
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000008
# T = 5     Fidelity = 0.00046993
# T = 10    Fidelity = 0.06837423
# T = 20    Fidelity = 0.22779039
# T = 30    Fidelity = 0.62242259
# T = 40    Fidelity = 0.37204080
# T = 50    Fidelity = 0.79016566
# T = 75    Fidelity = 0.75023084
# T = 100   Fidelity = 0.80008196
# T = 125   Fidelity = 0.88036667
# T = 150   Fidelity = 0.88518808
# T = 175   Fidelity = 0.90422023
# T = 200   Fidelity = 0.92803295
# T = 225   Fidelity = 0.93952440
# T = 250   Fidelity = 0.94829531
# T = 275   Fidelity = 0.95341409
# T = 300   Fidelity = 0.95060309
# T = 400   Fidelity = 0.97263047
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00003623
# T = 2     Fidelity = 0.00031726
# T = 5     Fidelity = 0.02049928
# T = 10    Fidelity = 0.22179915
# T = 20    Fidelity = 0.58997940
# T = 30    Fidelity = 0.66105579
# T = 40    Fidelity = 0.78997438
# T = 50    Fidelity = 0.82276681
# T = 75    Fidelity = 0.92687554
# T = 100   Fidelity = 0.96746608
# T = 125   Fidelity = 0.98441664
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00115331
# T = 2     Fidelity = 0.00473146
# T = 5     Fidelity = 0.06186244
# T = 10    Fidelity = 0.28456749
# T = 20    Fidelity = 0.68070971
# T = 30    Fidelity = 0.73440446
# T = 40    Fidelity = 0.82215481
# T = 50    Fidelity = 0.88735733
# T = 75    Fidelity = 0.95515960
# T = 100   Fidelity = 0.98250098
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00849035
# T = 2     Fidelity = 0.02336652
# T = 5     Fidelity = 0.12499251
# T = 10    Fidelity = 0.34184148
# T = 20    Fidelity = 0.67136386
# T = 30    Fidelity = 0.79909195
# T = 40    Fidelity = 0.85979084
# T = 50    Fidelity = 0.90970008
# T = 75    Fidelity = 0.97045473
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03400978
# T = 2     Fidelity = 0.07287357
# T = 5     Fidelity = 0.22124739
# T = 10    Fidelity = 0.42627888
# T = 20    Fidelity = 0.67765256
# T = 30    Fidelity = 0.80091041
# T = 40    Fidelity = 0.87068558
# T = 50    Fidelity = 0.91797002
# T = 75    Fidelity = 0.97852714
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09672010
# T = 2     Fidelity = 0.17597819
# T = 5     Fidelity = 0.36799045
# T = 10    Fidelity = 0.55747586
# T = 20    Fidelity = 0.74135101
# T = 30    Fidelity = 0.82900009
# T = 40    Fidelity = 0.87999285
# T = 50    Fidelity = 0.91387344
# T = 75    Fidelity = 0.96253471
# T = 100   Fidelity = 0.98269245
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19109300
# T = 2     Fidelity = 0.31262105
# T = 5     Fidelity = 0.52523120
# T = 10    Fidelity = 0.69206382
# T = 20    Fidelity = 0.82825836
# T = 30    Fidelity = 0.88803217
# T = 40    Fidelity = 0.92234376
# T = 50    Fidelity = 0.94383007
# T = 75    Fidelity = 0.97002596
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30071727
# T = 2     Fidelity = 0.45432312
# T = 5     Fidelity = 0.66177798
# T = 10    Fidelity = 0.79862570
# T = 20    Fidelity = 0.89474596
# T = 30    Fidelity = 0.93355119
# T = 40    Fidelity = 0.95521046
# T = 50    Fidelity = 0.96728026
# T = 75    Fidelity = 0.98308447
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40217781
# T = 2     Fidelity = 0.57270603
# T = 5     Fidelity = 0.76034556
# T = 10    Fidelity = 0.86909797
# T = 20    Fidelity = 0.93656159
# T = 30    Fidelity = 0.96230082
# T = 40    Fidelity = 0.97440825
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00083491
# T = 10    Fidelity = 0.06384705
# T = 20    Fidelity = 0.45559919
# T = 30    Fidelity = 0.88085278
# T = 40    Fidelity = 0.96753370
# T = 50    Fidelity = 0.99171101
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000204
# T = 5     Fidelity = 0.02497014
# T = 10    Fidelity = 0.89992702
# T = 20    Fidelity = 0.96750282
# T = 30    Fidelity = 0.99644917
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00005253
# T = 2     Fidelity = 0.00078218
# T = 5     Fidelity = 0.18887581
# T = 10    Fidelity = 0.98856299
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00124255
# T = 2     Fidelity = 0.00815410
# T = 5     Fidelity = 0.34564705
# T = 10    Fidelity = 0.98668249
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00700024
# T = 2     Fidelity = 0.02898680
# T = 5     Fidelity = 0.47061150
# T = 10    Fidelity = 0.98170250
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02083289
# T = 2     Fidelity = 0.06431579
# T = 5     Fidelity = 0.56553614
# T = 10    Fidelity = 0.97666730
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04382967
# T = 2     Fidelity = 0.11032531
# T = 5     Fidelity = 0.63834773
# T = 10    Fidelity = 0.97228892
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07541929
# T = 2     Fidelity = 0.16382140
# T = 5     Fidelity = 0.69607377
# T = 10    Fidelity = 0.96935579
# T = 20    Fidelity = 0.99318605
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11360493
# T = 2     Fidelity = 0.22085635
# T = 5     Fidelity = 0.74305012
# T = 10    Fidelity = 0.96787068
# T = 20    Fidelity = 0.99359351
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15663407
# T = 2     Fidelity = 0.27873627
# T = 5     Fidelity = 0.78124932
# T = 10    Fidelity = 0.96730715
# T = 20    Fidelity = 0.99388706
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     1         0.9811881881      1.00972087e+00    None        None        None
# Symmetric      0.311     1         0.9826692221      1.02934439e+00    None        None        None
# Symmetric      0.522     1         0.9839612143      1.04790824e+00    None        None        None
# Symmetric      0.733     1         0.9850453894      1.06556366e+00    None        None        None
# Symmetric      0.944     1         0.9860064577      1.08242773e+00    None        None        None
# Symmetric      1.156     1         0.9868604468      1.09859358e+00    None        None        None
# Symmetric      1.367     1         0.9876241559      1.11413694e+00    None        None        None
# Symmetric      1.578     1         0.9883088546      1.12912045e+00    None        None        None
# Symmetric      1.789     1         0.9889392443      1.14359670e+00    None        None        None
# Symmetric      2.000     1         0.9895104049      1.15761039e+00    None        None        None
# Weak SSB       0.100     250       0.9864328048      3.13498607e-04    None        None        None
# Weak SSB       0.311     400       0.9817986276      1.22564919e-04    None        None        None
# Weak SSB       0.522     None      0.7083593439      1.14483174e-04    0.495511    0.000636    0.496147
# Weak SSB       0.733     None      0.8323741933      2.21982966e-04    0.460746    0.000243    0.460989
# Weak SSB       0.944     None      0.8526510551      4.33063144e-03    0.754645    5.5e-05     0.7547
# Weak SSB       1.156     1050      0.9730911507      2.50115281e-02    None        None        None
# Weak SSB       1.367     1030      0.9788139545      6.77198754e-02    None        None        None
# Weak SSB       1.578     150       0.9742676733      1.20186803e-01    None        None        None
# Weak SSB       1.789     75        0.9796283004      1.71405410e-01    None        None        None
# Weak SSB       2.000     30        0.9728676615      2.18843285e-01    None        None        None
# Weak SSB optimised0.100     400       0.9802233159      2.42819099e-01    None        None        None
# Weak SSB optimised0.311     400       0.9726304741      2.61171322e-01    None        None        None
# Weak SSB optimised0.522     125       0.9844166365      2.64873214e-01    None        None        None
# Weak SSB optimised0.733     100       0.9825009808      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     75        0.9704547254      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     75        0.9785271418      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     100       0.9826924514      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     75        0.9700259612      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     75        0.9830844730      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     40        0.9744082467      2.55131735e-01    None        None        None
# Strong SSB     0.100     50        0.9917110139      6.07266718e-01    None        None        None
# Strong SSB     0.311     30        0.9964491657      7.22062439e-01    None        None        None
# Strong SSB     0.522     10        0.9885629903      7.78318602e-01    None        None        None
# Strong SSB     0.733     10        0.9866824901      8.15979742e-01    None        None        None
# Strong SSB     0.944     10        0.9817024969      8.44059983e-01    None        None        None
# Strong SSB     1.156     10        0.9766672966      8.66317759e-01    None        None        None
# Strong SSB     1.367     10        0.9722889164      8.84605280e-01    None        None        None
# Strong SSB     1.578     20        0.9931860545      8.99986623e-01    None        None        None
# Strong SSB     1.789     20        0.9935935071      9.13089337e-01    None        None        None
# Strong SSB     2.000     20        0.9938870576      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=1$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimized')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []

for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)

    elif case == "Strong SSB":

        M_strong.append(M)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_list)

dM_weak = np.gradient(M_weak_opt, lambda_list)

dM_strong = np.gradient(M_strong, lambda_list)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_list)

d2M_weak = np.gradient(dM_weak, lambda_list)

d2M_strong = np.gradient(dM_strong, lambda_list)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_list)

d3M_weak = np.gradient(d2M_weak, lambda_list)

d3M_strong = np.gradient(d2M_strong, lambda_list)




lamc_M_sym = find_lambda_c(
    lambda_list,
    d2M_sym,
    d3M_sym, dM_sym
)

lamc_M_weak = find_lambda_c(
    lambda_list,
    d2M_weak,
    d3M_weak, dM_weak
)

lamc_M_strong = find_lambda_c(
    lambda_list,
    d2M_strong,
    d3M_strong, dM_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_list,
    d2M_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_list,
    d2M_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_list,
    d2M_strong,
    '^-',
    label='Strong SSB'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_list,

    M_sym,

    'o-',

    label='Symmetric'
)

plt.plot(

    lambda_list,

    M_weak_opt,

    's-',

    label='Weak SSB optimized'
)

plt.plot(

    lambda_list,

    M_strong,

    '^-',

    label='Strong SSB'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_list,
    dM_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_list,
    dM_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_list,
    dM_strong,
    '^-',
    label='Strong SSB'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_0^2=1$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Starting of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96519947
# T = 2     Fidelity = 0.99333743
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.03626623e+00
# T = 1     Fidelity = 0.96803874
# T = 2     Fidelity = 0.99421232
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05846299e+00
# T = 1     Fidelity = 0.97051928
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07916278e+00
# T = 1     Fidelity = 0.97260491
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.09862393e+00
# T = 1     Fidelity = 0.97445282
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.11703633e+00
# T = 1     Fidelity = 0.97609345
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.13454489e+00
# T = 1     Fidelity = 0.97755878
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.15126343e+00
# T = 1     Fidelity = 0.97887087
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.16728342e+00
# T = 1     Fidelity = 0.98007611
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98116653
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 4.00578748e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000117
# T = 10    Fidelity = 0.00113766
# T = 20    Fidelity = 0.00651893
# T = 30    Fidelity = 0.02774068
# T = 40    Fidelity = 0.11886979
# T = 50    Fidelity = 0.09127454
# T = 75    Fidelity = 0.30335786
# T = 100   Fidelity = 0.53477741
# T = 125   Fidelity = 0.55349758
# T = 150   Fidelity = 0.69273880
# T = 175   Fidelity = 0.80339182
# T = 200   Fidelity = 0.78795835
# T = 225   Fidelity = 0.85588667
# T = 250   Fidelity = 0.93718258
# T = 275   Fidelity = 0.73996748
# T = 300   Fidelity = 0.74413523
# T = 400   Fidelity = 0.95740366
# T = 500   Fidelity = 0.95444341
# T = 600   Fidelity = 0.97120636
#
# Minimum T for Fidelity >= 0.97 : 600
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.22897118e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00000699
# T = 10    Fidelity = 0.00113347
# T = 20    Fidelity = 0.19597010
# T = 30    Fidelity = 0.53156816
# T = 40    Fidelity = 0.08249745
# T = 50    Fidelity = 0.71298875
# T = 75    Fidelity = 0.50844452
# T = 100   Fidelity = 0.68283007
# T = 125   Fidelity = 0.91761287
# T = 150   Fidelity = 0.91760081
# T = 175   Fidelity = 0.86915143
# T = 200   Fidelity = 0.91408400
# T = 225   Fidelity = 0.95406954
# T = 250   Fidelity = 0.95380956
# T = 275   Fidelity = 0.94294151
# T = 300   Fidelity = 0.97002561
#
# Minimum T for Fidelity >= 0.97 : 300
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.15176142e-04
# T = 1     Fidelity = 0.00000155
# T = 2     Fidelity = 0.00007286
# T = 5     Fidelity = 0.00176088
# T = 10    Fidelity = 0.03349274
# T = 20    Fidelity = 0.35786036
# T = 30    Fidelity = 0.61459795
# T = 40    Fidelity = 0.36337551
# T = 50    Fidelity = 0.26411813
# T = 75    Fidelity = 0.57947669
# T = 100   Fidelity = 0.44177392
# T = 125   Fidelity = 0.52894366
# T = 150   Fidelity = 0.48171288
# T = 175   Fidelity = 0.50045436
# T = 200   Fidelity = 0.47683466
# T = 225   Fidelity = 0.51557734
# T = 250   Fidelity = 0.48978320
# T = 275   Fidelity = 0.48734921
# T = 300   Fidelity = 0.51264738
# T = 400   Fidelity = 0.50878422
# T = 500   Fidelity = 0.43376197
# T = 600   Fidelity = 0.40036994
# T = 700   Fidelity = 0.27943441
# T = 800   Fidelity = 0.29718861
# T = 900   Fidelity = 0.51004512
# T = 1000  Fidelity = 0.43712794
# T = 1010  Fidelity = 0.28576201
# T = 1020  Fidelity = 0.60561543
# T = 1030  Fidelity = 0.79145287
# T = 1040  Fidelity = 0.62436492
# T = 1050  Fidelity = 0.06895957
# T = 1060  Fidelity = 0.22419849
# T = 1070  Fidelity = 0.62215998
# T = 1080  Fidelity = 0.79983251
# T = 1090  Fidelity = 0.48759988
# T = 1100  Fidelity = 0.20011455
# T = 1200  Fidelity = 0.81607207
# T = 1300  Fidelity = 0.45256686
# T = 1400  Fidelity = 0.22984565
# T = 1500  Fidelity = 0.29289879
# T = 2000  Fidelity = 0.44740529
# T = 2100  Fidelity = 0.18178491
# T = 2110  Fidelity = 0.25636046
# T = 2120  Fidelity = 0.49546713
# T = 2130  Fidelity = 0.55665433
# T = 2140  Fidelity = 0.47136711
# T = 2150  Fidelity = 0.18468495
# T = 2160  Fidelity = 0.38760313
# T = 2170  Fidelity = 0.75621046
# T = 2180  Fidelity = 0.71499280
# T = 2190  Fidelity = 0.43432827
# T = 2200  Fidelity = 0.21231421
# T = 2300  Fidelity = 0.55723481
# T = 2400  Fidelity = 0.72413046
# T = 2500  Fidelity = 0.74687534
# T = 2600  Fidelity = 0.63232246
# T = 2700  Fidelity = 0.59390973
# T = 2800  Fidelity = 0.61850589
# T = 2900  Fidelity = 0.24917286
# T = 3000  Fidelity = 0.44705435
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44121779e+00
# P0     = 0.44705435
# P1     = 0.00030088
# P0+P1  = 0.44735523
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.97449186e-04
# T = 1     Fidelity = 0.00181006
# T = 2     Fidelity = 0.00875766
# T = 5     Fidelity = 0.04031702
# T = 10    Fidelity = 0.14627172
# T = 20    Fidelity = 0.35535375
# T = 30    Fidelity = 0.38160448
# T = 40    Fidelity = 0.32523035
# T = 50    Fidelity = 0.32607048
# T = 75    Fidelity = 0.55886421
# T = 100   Fidelity = 0.56004535
# T = 125   Fidelity = 0.50583304
# T = 150   Fidelity = 0.52362717
# T = 175   Fidelity = 0.52818568
# T = 200   Fidelity = 0.52078362
# T = 225   Fidelity = 0.49581900
# T = 250   Fidelity = 0.49591392
# T = 275   Fidelity = 0.49768710
# T = 300   Fidelity = 0.48323408
# T = 400   Fidelity = 0.51271586
# T = 500   Fidelity = 0.50216300
# T = 600   Fidelity = 0.56042733
# T = 700   Fidelity = 0.53777244
# T = 800   Fidelity = 0.58941330
# T = 900   Fidelity = 0.65962600
# T = 1000  Fidelity = 0.63817142
# T = 1010  Fidelity = 0.55701267
# T = 1020  Fidelity = 0.51471528
# T = 1030  Fidelity = 0.29784397
# T = 1040  Fidelity = 0.13403532
# T = 1050  Fidelity = 0.32341042
# T = 1060  Fidelity = 0.53530447
# T = 1070  Fidelity = 0.81668965
# T = 1080  Fidelity = 0.83973377
# T = 1090  Fidelity = 0.63609655
# T = 1100  Fidelity = 0.58581085
# T = 1200  Fidelity = 0.83345498
# T = 1300  Fidelity = 0.72308186
# T = 1400  Fidelity = 0.48869233
# T = 1500  Fidelity = 0.65457820
# T = 2000  Fidelity = 0.46955940
# T = 2100  Fidelity = 0.48259416
# T = 2110  Fidelity = 0.17030389
# T = 2120  Fidelity = 0.20059888
# T = 2130  Fidelity = 0.35906397
# T = 2140  Fidelity = 0.49729750
# T = 2150  Fidelity = 0.43204973
# T = 2160  Fidelity = 0.57694209
# T = 2170  Fidelity = 0.52303425
# T = 2180  Fidelity = 0.64957570
# T = 2190  Fidelity = 0.61664995
# T = 2200  Fidelity = 0.67238651
# T = 2300  Fidelity = 0.58712929
# T = 2400  Fidelity = 0.35437591
# T = 2500  Fidelity = 0.72786667
# T = 2600  Fidelity = 0.69666597
# T = 2700  Fidelity = 0.69285399
# T = 2800  Fidelity = 0.61869659
# T = 2900  Fidelity = 0.40623372
# T = 3000  Fidelity = 0.41955816
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.45168821e+00
# P0     = 0.41955816
# P1     = 0.00011730
# P0+P1  = 0.41967546
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 5.82831771e-03
# T = 1     Fidelity = 0.01683268
# T = 2     Fidelity = 0.05151939
# T = 5     Fidelity = 0.13905654
# T = 10    Fidelity = 0.31436363
# T = 20    Fidelity = 0.55037214
# T = 30    Fidelity = 0.62703506
# T = 40    Fidelity = 0.61105168
# T = 50    Fidelity = 0.57957316
# T = 75    Fidelity = 0.55888490
# T = 100   Fidelity = 0.60022923
# T = 125   Fidelity = 0.62829667
# T = 150   Fidelity = 0.63563566
# T = 175   Fidelity = 0.64419759
# T = 200   Fidelity = 0.64401689
# T = 225   Fidelity = 0.67554190
# T = 250   Fidelity = 0.68045238
# T = 275   Fidelity = 0.67208607
# T = 300   Fidelity = 0.68412194
# T = 400   Fidelity = 0.70747019
# T = 500   Fidelity = 0.60556323
# T = 600   Fidelity = 0.55954425
# T = 700   Fidelity = 0.72647530
# T = 800   Fidelity = 0.76657603
# T = 900   Fidelity = 0.58858274
# T = 1000  Fidelity = 0.64521745
# T = 1010  Fidelity = 0.71553607
# T = 1020  Fidelity = 0.81917654
# T = 1030  Fidelity = 0.82774675
# T = 1040  Fidelity = 0.75676524
# T = 1050  Fidelity = 0.67595628
# T = 1060  Fidelity = 0.62818458
# T = 1070  Fidelity = 0.53897747
# T = 1080  Fidelity = 0.48085721
# T = 1090  Fidelity = 0.56581521
# T = 1100  Fidelity = 0.67684702
# T = 1200  Fidelity = 0.52333305
# T = 1300  Fidelity = 0.67935932
# T = 1400  Fidelity = 0.73933062
# T = 1500  Fidelity = 0.85199298
# T = 2000  Fidelity = 0.80653263
# T = 2100  Fidelity = 0.68860779
# T = 2110  Fidelity = 0.69421400
# T = 2120  Fidelity = 0.61760726
# T = 2130  Fidelity = 0.63539998
# T = 2140  Fidelity = 0.68614005
# T = 2150  Fidelity = 0.87176726
# T = 2160  Fidelity = 0.87507224
# T = 2170  Fidelity = 0.85717229
# T = 2180  Fidelity = 0.77023242
# T = 2190  Fidelity = 0.63712761
# T = 2200  Fidelity = 0.64001651
# T = 2300  Fidelity = 0.66672778
# T = 2400  Fidelity = 0.71885788
# T = 2500  Fidelity = 0.78834960
# T = 2600  Fidelity = 0.40555984
# T = 2700  Fidelity = 0.82470699
# T = 2800  Fidelity = 0.60772357
# T = 2900  Fidelity = 0.72546564
# T = 3000  Fidelity = 0.81925291
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.46192674e+00
# P0     = 0.81925291
# P1     = 0.00002686
# P0+P1  = 0.81927977
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 3.15665395e-02
# T = 1     Fidelity = 0.06375862
# T = 2     Fidelity = 0.14776476
# T = 5     Fidelity = 0.29255584
# T = 10    Fidelity = 0.49855430
# T = 20    Fidelity = 0.70650360
# T = 30    Fidelity = 0.78192430
# T = 40    Fidelity = 0.79737881
# T = 50    Fidelity = 0.79506559
# T = 75    Fidelity = 0.78966664
# T = 100   Fidelity = 0.79656689
# T = 125   Fidelity = 0.80624728
# T = 150   Fidelity = 0.81388460
# T = 175   Fidelity = 0.82334742
# T = 200   Fidelity = 0.82919290
# T = 225   Fidelity = 0.83520183
# T = 250   Fidelity = 0.84622283
# T = 275   Fidelity = 0.83512557
# T = 300   Fidelity = 0.85863572
# T = 400   Fidelity = 0.85780820
# T = 500   Fidelity = 0.82486703
# T = 600   Fidelity = 0.83340324
# T = 700   Fidelity = 0.69586588
# T = 800   Fidelity = 0.93254902
# T = 900   Fidelity = 0.87079749
# T = 1000  Fidelity = 0.87094875
# T = 1010  Fidelity = 0.88465368
# T = 1020  Fidelity = 0.84367935
# T = 1030  Fidelity = 0.78488425
# T = 1040  Fidelity = 0.81694049
# T = 1050  Fidelity = 0.88071827
# T = 1060  Fidelity = 0.89098900
# T = 1070  Fidelity = 0.92622730
# T = 1080  Fidelity = 0.96643028
# T = 1090  Fidelity = 0.97753700
#
# Minimum T for Fidelity >= 0.97 : 1090
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.80721241e-02
# T = 1     Fidelity = 0.14355890
# T = 2     Fidelity = 0.27845317
# T = 5     Fidelity = 0.45583628
# T = 10    Fidelity = 0.65331109
# T = 20    Fidelity = 0.81535387
# T = 30    Fidelity = 0.87219092
# T = 40    Fidelity = 0.89386454
# T = 50    Fidelity = 0.90260706
# T = 75    Fidelity = 0.91321288
# T = 100   Fidelity = 0.92134130
# T = 125   Fidelity = 0.92938766
# T = 150   Fidelity = 0.93577173
# T = 175   Fidelity = 0.94383455
# T = 200   Fidelity = 0.95003714
# T = 225   Fidelity = 0.93685373
# T = 250   Fidelity = 0.94518273
# T = 275   Fidelity = 0.94894341
# T = 300   Fidelity = 0.96260113
# T = 400   Fidelity = 0.95833839
# T = 500   Fidelity = 0.93471139
# T = 600   Fidelity = 0.94632039
# T = 700   Fidelity = 0.89651545
# T = 800   Fidelity = 0.94203432
# T = 900   Fidelity = 0.93782289
# T = 1000  Fidelity = 0.92643952
# T = 1010  Fidelity = 0.97163423
#
# Minimum T for Fidelity >= 0.97 : 1010
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.28699324e-01
# T = 1     Fidelity = 0.23834403
# T = 2     Fidelity = 0.40991516
# T = 5     Fidelity = 0.59350525
# T = 10    Fidelity = 0.76316396
# T = 20    Fidelity = 0.88382521
# T = 30    Fidelity = 0.92426497
# T = 40    Fidelity = 0.94153074
# T = 50    Fidelity = 0.95043141
# T = 75    Fidelity = 0.96136701
# T = 100   Fidelity = 0.96919917
# T = 125   Fidelity = 0.97454843
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.76942005e-01
# T = 1     Fidelity = 0.33073007
# T = 2     Fidelity = 0.52263579
# T = 5     Fidelity = 0.69685706
# T = 10    Fidelity = 0.83585410
# T = 20    Fidelity = 0.92565606
# T = 30    Fidelity = 0.95441588
# T = 40    Fidelity = 0.96616108
# T = 50    Fidelity = 0.97238944
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.20505465e-01
# T = 1     Fidelity = 0.41291705
# T = 2     Fidelity = 0.61286762
# T = 5     Fidelity = 0.77103491
# T = 10    Fidelity = 0.88318920
# T = 20    Fidelity = 0.95123331
# T = 30    Fidelity = 0.97147279
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000154
# T = 10    Fidelity = 0.00046729
# T = 20    Fidelity = 0.00574883
# T = 30    Fidelity = 0.01851180
# T = 40    Fidelity = 0.06163595
# T = 50    Fidelity = 0.16037388
# T = 75    Fidelity = 0.32123495
# T = 100   Fidelity = 0.48106268
# T = 125   Fidelity = 0.62837380
# T = 150   Fidelity = 0.72316577
# T = 175   Fidelity = 0.79363898
# T = 200   Fidelity = 0.83466610
# T = 225   Fidelity = 0.84609848
# T = 250   Fidelity = 0.85535166
# T = 275   Fidelity = 0.71788001
# T = 300   Fidelity = 0.79201429
# T = 400   Fidelity = 0.93060051
# T = 500   Fidelity = 0.91000308
# T = 600   Fidelity = 0.89298706
# T = 700   Fidelity = 0.81703612
# T = 800   Fidelity = 0.64610510
# T = 900   Fidelity = 0.74787248
# T = 1000  Fidelity = 0.63049431
# T = 1010  Fidelity = 0.62244748
# T = 1020  Fidelity = 0.69992677
# T = 1030  Fidelity = 0.67188375
# T = 1040  Fidelity = 0.25632343
# T = 1050  Fidelity = 0.41840430
# T = 1060  Fidelity = 0.49869046
# T = 1070  Fidelity = 0.47181776
# T = 1080  Fidelity = 0.56545563
# T = 1090  Fidelity = 0.54859381
# T = 1100  Fidelity = 0.75620327
# T = 1200  Fidelity = 0.22291298
# T = 1300  Fidelity = 0.25187741
# T = 1400  Fidelity = 0.65193537
# T = 1500  Fidelity = 0.48349923
# T = 2000  Fidelity = 0.33791566
# T = 2100  Fidelity = 0.88944444
# T = 2110  Fidelity = 0.81384520
# T = 2120  Fidelity = 0.77121366
# T = 2130  Fidelity = 0.74782375
# T = 2140  Fidelity = 0.54531094
# T = 2150  Fidelity = 0.75806657
# T = 2160  Fidelity = 0.56245631
# T = 2170  Fidelity = 0.63618580
# T = 2180  Fidelity = 0.70283102
# T = 2190  Fidelity = 0.53233601
# T = 2200  Fidelity = 0.53129548
# T = 2300  Fidelity = 0.33801532
# T = 2400  Fidelity = 0.51793575
# T = 2500  Fidelity = 0.52751325
# T = 2600  Fidelity = 0.30726906
# T = 2700  Fidelity = 0.24690596
# T = 2800  Fidelity = 0.53868274
# T = 2900  Fidelity = 0.50476826
# T = 3000  Fidelity = 0.91820514
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91820514
# P1     = 0.00924653
# P0+P1  = 0.92745168
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61673084e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00001613
# T = 10    Fidelity = 0.00293620
# T = 20    Fidelity = 0.21901263
# T = 30    Fidelity = 0.29814597
# T = 40    Fidelity = 0.34994864
# T = 50    Fidelity = 0.70671392
# T = 75    Fidelity = 0.77993299
# T = 100   Fidelity = 0.66518150
# T = 125   Fidelity = 0.86218512
# T = 150   Fidelity = 0.77800595
# T = 175   Fidelity = 0.90228530
# T = 200   Fidelity = 0.96544230
# T = 225   Fidelity = 0.88960015
# T = 250   Fidelity = 0.96458044
# T = 275   Fidelity = 0.94936343
# T = 300   Fidelity = 0.93514519
# T = 400   Fidelity = 0.96923173
# T = 500   Fidelity = 0.96322675
# T = 600   Fidelity = 0.87754073
# T = 700   Fidelity = 0.62879228
# T = 800   Fidelity = 0.80145801
# T = 900   Fidelity = 0.73518863
# T = 1000  Fidelity = 0.83338086
# T = 1010  Fidelity = 0.79815375
# T = 1020  Fidelity = 0.84257767
# T = 1030  Fidelity = 0.74187622
# T = 1040  Fidelity = 0.71026992
# T = 1050  Fidelity = 0.68196258
# T = 1060  Fidelity = 0.55088357
# T = 1070  Fidelity = 0.52572685
# T = 1080  Fidelity = 0.64139293
# T = 1090  Fidelity = 0.51626193
# T = 1100  Fidelity = 0.49209233
# T = 1200  Fidelity = 0.88624611
# T = 1300  Fidelity = 0.67006323
# T = 1400  Fidelity = 0.81633465
# T = 1500  Fidelity = 0.91771853
# T = 2000  Fidelity = 0.62393693
# T = 2100  Fidelity = 0.48719932
# T = 2110  Fidelity = 0.76328120
# T = 2120  Fidelity = 0.72179129
# T = 2130  Fidelity = 0.56392204
# T = 2140  Fidelity = 0.48194990
# T = 2150  Fidelity = 0.62062066
# T = 2160  Fidelity = 0.54304057
# T = 2170  Fidelity = 0.42875849
# T = 2180  Fidelity = 0.48832607
# T = 2190  Fidelity = 0.81822991
# T = 2200  Fidelity = 0.61813764
# T = 2300  Fidelity = 0.66530589
# T = 2400  Fidelity = 0.58570567
# T = 2500  Fidelity = 0.83432496
# T = 2600  Fidelity = 0.61180515
# T = 2700  Fidelity = 0.88450679
# T = 2800  Fidelity = 0.64426320
# T = 2900  Fidelity = 0.69946393
# T = 3000  Fidelity = 0.86892243
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43053089e+00
# P0     = 0.86892243
# P1     = 0.03964271
# P0+P1  = 0.90856514
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64768458e-01
# T = 1     Fidelity = 0.00000976
# T = 2     Fidelity = 0.00014417
# T = 5     Fidelity = 0.00344882
# T = 10    Fidelity = 0.05111805
# T = 20    Fidelity = 0.40992220
# T = 30    Fidelity = 0.59550170
# T = 40    Fidelity = 0.58204012
# T = 50    Fidelity = 0.72390275
# T = 75    Fidelity = 0.81379854
# T = 100   Fidelity = 0.89304324
# T = 125   Fidelity = 0.94398984
# T = 150   Fidelity = 0.96742687
# T = 175   Fidelity = 0.97760460
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00050144
# T = 2     Fidelity = 0.00287772
# T = 5     Fidelity = 0.02073128
# T = 10    Fidelity = 0.11085757
# T = 20    Fidelity = 0.42557339
# T = 30    Fidelity = 0.66192395
# T = 40    Fidelity = 0.73164883
# T = 50    Fidelity = 0.76202679
# T = 75    Fidelity = 0.88523908
# T = 100   Fidelity = 0.93297967
# T = 125   Fidelity = 0.96630448
# T = 150   Fidelity = 0.98136831
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00481635
# T = 2     Fidelity = 0.01666114
# T = 5     Fidelity = 0.06234800
# T = 10    Fidelity = 0.18599808
# T = 20    Fidelity = 0.44923584
# T = 30    Fidelity = 0.64661613
# T = 40    Fidelity = 0.75590454
# T = 50    Fidelity = 0.81810650
# T = 75    Fidelity = 0.91084981
# T = 100   Fidelity = 0.95913295
# T = 125   Fidelity = 0.97965704
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.02292994
# T = 2     Fidelity = 0.05755466
# T = 5     Fidelity = 0.14242504
# T = 10    Fidelity = 0.29251933
# T = 20    Fidelity = 0.51747664
# T = 30    Fidelity = 0.66428884
# T = 40    Fidelity = 0.75763910
# T = 50    Fidelity = 0.82129670
# T = 75    Fidelity = 0.91767020
# T = 100   Fidelity = 0.96577412
# T = 125   Fidelity = 0.98703457
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.07325188
# T = 2     Fidelity = 0.14883202
# T = 5     Fidelity = 0.27952575
# T = 10    Fidelity = 0.44735847
# T = 20    Fidelity = 0.63925656
# T = 30    Fidelity = 0.74352344
# T = 40    Fidelity = 0.80857697
# T = 50    Fidelity = 0.85426695
# T = 75    Fidelity = 0.92183817
# T = 100   Fidelity = 0.95733497
# T = 125   Fidelity = 0.97676523
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.15482365
# T = 2     Fidelity = 0.27540371
# T = 5     Fidelity = 0.43755495
# T = 10    Fidelity = 0.60337986
# T = 20    Fidelity = 0.76146434
# T = 30    Fidelity = 0.83613295
# T = 40    Fidelity = 0.88061383
# T = 50    Fidelity = 0.91023136
# T = 75    Fidelity = 0.95193619
# T = 100   Fidelity = 0.97293032
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.25469674
# T = 2     Fidelity = 0.41156895
# T = 5     Fidelity = 0.58355694
# T = 10    Fidelity = 0.73073612
# T = 20    Fidelity = 0.85273373
# T = 30    Fidelity = 0.90363908
# T = 40    Fidelity = 0.93196540
# T = 50    Fidelity = 0.94954620
# T = 75    Fidelity = 0.97417380
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.35075818
# T = 2     Fidelity = 0.52876262
# T = 5     Fidelity = 0.69430465
# T = 10    Fidelity = 0.81767998
# T = 20    Fidelity = 0.90994650
# T = 30    Fidelity = 0.94406760
# T = 40    Fidelity = 0.96188130
# T = 50    Fidelity = 0.97273408
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.06623659e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00011859
# T = 10    Fidelity = 0.00636260
# T = 20    Fidelity = 0.15725652
# T = 30    Fidelity = 0.48663309
# T = 40    Fidelity = 0.76090390
# T = 50    Fidelity = 0.90723727
# T = 75    Fidelity = 0.99423910
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.20609288e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000011
# T = 5     Fidelity = 0.00112462
# T = 10    Fidelity = 0.18570896
# T = 20    Fidelity = 0.88897533
# T = 30    Fidelity = 0.96887153
# T = 40    Fidelity = 0.99616220
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.76105909e-01
# T = 1     Fidelity = 0.00000396
# T = 2     Fidelity = 0.00014290
# T = 5     Fidelity = 0.03249467
# T = 10    Fidelity = 0.56551313
# T = 20    Fidelity = 0.90543526
# T = 30    Fidelity = 0.99237708
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.12909217e-01
# T = 1     Fidelity = 0.00019423
# T = 2     Fidelity = 0.00243174
# T = 5     Fidelity = 0.10916730
# T = 10    Fidelity = 0.69714365
# T = 20    Fidelity = 0.94977770
# T = 30    Fidelity = 0.99073319
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.40169449e-01
# T = 1     Fidelity = 0.00166621
# T = 2     Fidelity = 0.01140112
# T = 5     Fidelity = 0.20678382
# T = 10    Fidelity = 0.76571088
# T = 20    Fidelity = 0.97048295
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.61748289e-01
# T = 1     Fidelity = 0.00655732
# T = 2     Fidelity = 0.03044279
# T = 5     Fidelity = 0.30464048
# T = 10    Fidelity = 0.80698834
# T = 20    Fidelity = 0.98000489
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.79340685e-01
# T = 1     Fidelity = 0.01678714
# T = 2     Fidelity = 0.05943696
# T = 5     Fidelity = 0.39383795
# T = 10    Fidelity = 0.83486533
# T = 20    Fidelity = 0.98415286
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.94021606e-01
# T = 1     Fidelity = 0.03350429
# T = 2     Fidelity = 0.09735942
# T = 5     Fidelity = 0.47319164
# T = 10    Fidelity = 0.85635668
# T = 20    Fidelity = 0.98584576
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.06402712e-01
# T = 1     Fidelity = 0.05658347
# T = 2     Fidelity = 0.14159579
# T = 5     Fidelity = 0.54248140
# T = 10    Fidelity = 0.87440919
# T = 20    Fidelity = 0.98633705
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.17036009e-01
# T = 1     Fidelity = 0.08546241
# T = 2     Fidelity = 0.18982967
# T = 5     Fidelity = 0.60213699
# T = 10    Fidelity = 0.88958512
# T = 20    Fidelity = 0.98628151
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9933374285      1.01220263e+00    None        None        None
# Symmetric      0.311     2         0.9942123249      1.03626623e+00    None        None        None
# Symmetric      0.522     1         0.9705192768      1.05846299e+00    None        None        None
# Symmetric      0.733     1         0.9726049073      1.07916278e+00    None        None        None
# Symmetric      0.944     1         0.9744528199      1.09862393e+00    None        None        None
# Symmetric      1.156     1         0.9760934475      1.11703633e+00    None        None        None
# Symmetric      1.367     1         0.9775587811      1.13454489e+00    None        None        None
# Symmetric      1.578     1         0.9788708671      1.15126343e+00    None        None        None
# Symmetric      1.789     1         0.9800761053      1.16728342e+00    None        None        None
# Symmetric      2.000     1         0.9811665326      1.18267976e+00    None        None        None
# Weak SSB       0.100     600       0.9712063608      4.00578748e-04    None        None        None
# Weak SSB       0.311     300       0.9700256114      1.22897118e-04    None        None        None
# Weak SSB       0.522     None      0.8160720731      1.15176142e-04    0.447054    0.000301    0.447355
# Weak SSB       0.733     None      0.8397337715      2.97449186e-04    0.419558    0.000117    0.419675
# Weak SSB       0.944     None      0.8750722443      5.82831771e-03    0.819253    2.7e-05     0.81928
# Weak SSB       1.156     1090      0.9775370015      3.15665395e-02    None        None        None
# Weak SSB       1.367     1010      0.9716342265      7.80721241e-02    None        None        None
# Weak SSB       1.578     125       0.9745484313      1.28699324e-01    None        None        None
# Weak SSB       1.789     50        0.9723894350      1.76942005e-01    None        None        None
# Weak SSB       2.000     30        0.9714727920      2.20505465e-01    None        None        None
# Weak SSB optimised0.100     None      0.9306005052      2.43127858e-01    0.918205    0.009247    0.927452
# Weak SSB optimised0.311     None      0.9692317313      2.61673084e-01    0.868922    0.039643    0.908565
# Weak SSB optimised0.522     175       0.9776045961      2.64768458e-01    None        None        None
# Weak SSB optimised0.733     150       0.9813683052      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     125       0.9796570429      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     125       0.9870345696      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9767652269      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     100       0.9729303215      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     75        0.9741738030      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     50        0.9727340761      2.55131735e-01    None        None        None
# Strong SSB     0.100     75        0.9942391000      6.06623659e-01    None        None        None
# Strong SSB     0.311     40        0.9961622036      7.20609288e-01    None        None        None
# Strong SSB     0.522     30        0.9923770785      7.76105909e-01    None        None        None
# Strong SSB     0.733     30        0.9907331918      8.12909217e-01    None        None        None
# Strong SSB     0.944     20        0.9704829513      8.40169449e-01    None        None        None
# Strong SSB     1.156     20        0.9800048923      8.61748289e-01    None        None        None
# Strong SSB     1.367     20        0.9841528559      8.79340685e-01    None        None        None
# Strong SSB     1.578     20        0.9858457566      8.94021606e-01    None        None        None
# Strong SSB     1.789     20        0.9863370546      9.06402712e-01    None        None        None
# Strong SSB     2.000     20        0.9862815136      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimized')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)




lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym, dM_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak, dM_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong, dM_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimized'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009555
# T = 10    Fidelity = 0.00119357
# T = 20    Fidelity = 0.02687547
# T = 30    Fidelity = 0.09665571
# T = 40    Fidelity = 0.19607480
# T = 50    Fidelity = 0.31173902
# T = 75    Fidelity = 0.56618090
# T = 100   Fidelity = 0.71999211
# T = 125   Fidelity = 0.80735879
# T = 150   Fidelity = 0.86467675
# T = 175   Fidelity = 0.90862895
# T = 200   Fidelity = 0.94628881
# T = 225   Fidelity = 0.96686829
# T = 250   Fidelity = 0.95352192
# T = 275   Fidelity = 0.98205178
#
# Minimum T for Fidelity >= 0.97 : 275
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624066e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144381
# T = 10    Fidelity = 0.10201351
# T = 20    Fidelity = 0.52976102
# T = 30    Fidelity = 0.63899650
# T = 40    Fidelity = 0.76793533
# T = 50    Fidelity = 0.88382414
# T = 75    Fidelity = 0.94228211
# T = 100   Fidelity = 0.97305652
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043128e-07
# T = 1     Fidelity = 0.00005019
# T = 2     Fidelity = 0.00043602
# T = 5     Fidelity = 0.02725350
# T = 10    Fidelity = 0.28410069
# T = 20    Fidelity = 0.77879030
# T = 30    Fidelity = 0.80546902
# T = 40    Fidelity = 0.95119315
# T = 50    Fidelity = 0.93703015
# T = 75    Fidelity = 0.99143798
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155051
# T = 2     Fidelity = 0.00639403
# T = 5     Fidelity = 0.08479939
# T = 10    Fidelity = 0.38784709
# T = 20    Fidelity = 0.90882545
# T = 30    Fidelity = 0.89422706
# T = 40    Fidelity = 0.97222394
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01057847
# T = 2     Fidelity = 0.02892998
# T = 5     Fidelity = 0.16449317
# T = 10    Fidelity = 0.46787974
# T = 20    Fidelity = 0.92254661
# T = 30    Fidelity = 0.97977566
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03667541
# T = 2     Fidelity = 0.07740729
# T = 5     Fidelity = 0.25991700
# T = 10    Fidelity = 0.54100711
# T = 20    Fidelity = 0.90448773
# T = 30    Fidelity = 0.99651359
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08776499
# T = 2     Fidelity = 0.15531512
# T = 5     Fidelity = 0.36741484
# T = 10    Fidelity = 0.61610910
# T = 20    Fidelity = 0.89397142
# T = 30    Fidelity = 0.98167623
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16580094
# T = 2     Fidelity = 0.25895032
# T = 5     Fidelity = 0.48157434
# T = 10    Fidelity = 0.69441059
# T = 20    Fidelity = 0.90353560
# T = 30    Fidelity = 0.97293792
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26389210
# T = 2     Fidelity = 0.37661575
# T = 5     Fidelity = 0.59255065
# T = 10    Fidelity = 0.76990079
# T = 20    Fidelity = 0.92536413
# T = 30    Fidelity = 0.97251190
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36878460
# T = 2     Fidelity = 0.49272584
# T = 5     Fidelity = 0.68999018
# T = 10    Fidelity = 0.83494318
# T = 20    Fidelity = 0.94707998
# T = 30    Fidelity = 0.97596032
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.33865795e-02
# T = 1     Fidelity = 0.59492958
# T = 2     Fidelity = 0.64023329
# T = 5     Fidelity = 0.72180250
# T = 10    Fidelity = 0.79942294
# T = 20    Fidelity = 0.88126523
# T = 30    Fidelity = 0.92381174
# T = 40    Fidelity = 0.94860392
# T = 50    Fidelity = 0.96362708
# T = 75    Fidelity = 0.98160987
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.33760034e-03
# T = 1     Fidelity = 0.48960622
# T = 2     Fidelity = 0.50409857
# T = 5     Fidelity = 0.54911549
# T = 10    Fidelity = 0.60583881
# T = 20    Fidelity = 0.67863679
# T = 30    Fidelity = 0.72885030
# T = 40    Fidelity = 0.76710836
# T = 50    Fidelity = 0.79754198
# T = 75    Fidelity = 0.85228315
# T = 100   Fidelity = 0.88716952
# T = 125   Fidelity = 0.91217260
# T = 150   Fidelity = 0.92871586
# T = 175   Fidelity = 0.93727399
# T = 200   Fidelity = 0.95440385
# T = 225   Fidelity = 0.95717151
# T = 250   Fidelity = 0.96003365
# T = 275   Fidelity = 0.94847509
# T = 300   Fidelity = 0.95960691
# T = 400   Fidelity = 0.97356984
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.28632798e-04
# T = 1     Fidelity = 0.24999644
# T = 2     Fidelity = 0.25185457
# T = 5     Fidelity = 0.25231060
# T = 10    Fidelity = 0.25249208
# T = 20    Fidelity = 0.25254158
# T = 30    Fidelity = 0.25257261
# T = 40    Fidelity = 0.25265403
# T = 50    Fidelity = 0.25270216
# T = 75    Fidelity = 0.25289079
# T = 100   Fidelity = 0.25302368
# T = 125   Fidelity = 0.25301664
# T = 150   Fidelity = 0.25301731
# T = 175   Fidelity = 0.25144133
# T = 200   Fidelity = 0.25382381
# T = 225   Fidelity = 0.25165216
# T = 250   Fidelity = 0.25345526
# T = 275   Fidelity = 0.25324707
# T = 300   Fidelity = 0.25365163
# T = 400   Fidelity = 0.25183354
# T = 500   Fidelity = 0.25330317
# T = 600   Fidelity = 0.25354703
# T = 700   Fidelity = 0.25663027
# T = 800   Fidelity = 0.25505470
# T = 900   Fidelity = 0.25039168
# T = 1000  Fidelity = 0.25517648
# T = 1010  Fidelity = 0.25537294
# T = 1020  Fidelity = 0.25223753
# T = 1030  Fidelity = 0.25441023
# T = 1040  Fidelity = 0.25625441
# T = 1050  Fidelity = 0.25577317
# T = 1060  Fidelity = 0.25216617
# T = 1070  Fidelity = 0.25327946
# T = 1080  Fidelity = 0.25330007
# T = 1090  Fidelity = 0.25181711
# T = 1100  Fidelity = 0.25187175
# T = 1200  Fidelity = 0.25480523
# T = 1300  Fidelity = 0.25550169
# T = 1400  Fidelity = 0.25383041
# T = 1500  Fidelity = 0.25360034
# T = 2000  Fidelity = 0.25535416
# T = 2100  Fidelity = 0.25420760
# T = 2110  Fidelity = 0.25312590
# T = 2120  Fidelity = 0.25390964
# T = 2130  Fidelity = 0.25464314
# T = 2140  Fidelity = 0.25468660
# T = 2150  Fidelity = 0.25532421
# T = 2160  Fidelity = 0.25464365
# T = 2170  Fidelity = 0.25402264
# T = 2180  Fidelity = 0.25349405
# T = 2190  Fidelity = 0.25578190
# T = 2200  Fidelity = 0.25459914
# T = 2300  Fidelity = 0.25368578
# T = 2400  Fidelity = 0.25382149
# T = 2500  Fidelity = 0.25461449
# T = 2600  Fidelity = 0.25764983
# T = 2700  Fidelity = 0.25470394
# T = 2800  Fidelity = 0.25278420
# T = 2900  Fidelity = 0.25155795
# T = 3000  Fidelity = 0.25088817
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.29930841e-04
# P0     = 0.25088817
# P1     = 0.24716743
# P0+P1  = 0.49805560
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07617225e-04
# T = 1     Fidelity = 0.26801611
# T = 2     Fidelity = 0.27148478
# T = 5     Fidelity = 0.27357655
# T = 10    Fidelity = 0.27412002
# T = 20    Fidelity = 0.27550617
# T = 30    Fidelity = 0.27601236
# T = 40    Fidelity = 0.27652019
# T = 50    Fidelity = 0.27716975
# T = 75    Fidelity = 0.27817850
# T = 100   Fidelity = 0.27890785
# T = 125   Fidelity = 0.27954661
# T = 150   Fidelity = 0.28019334
# T = 175   Fidelity = 0.28004942
# T = 200   Fidelity = 0.28087269
# T = 225   Fidelity = 0.28165634
# T = 250   Fidelity = 0.28195991
# T = 275   Fidelity = 0.28188442
# T = 300   Fidelity = 0.28401993
# T = 400   Fidelity = 0.28420866
# T = 500   Fidelity = 0.28706313
# T = 600   Fidelity = 0.28856826
# T = 700   Fidelity = 0.28656744
# T = 800   Fidelity = 0.28968501
# T = 900   Fidelity = 0.28623222
# T = 1000  Fidelity = 0.28962461
# T = 1010  Fidelity = 0.28796353
# T = 1020  Fidelity = 0.28489335
# T = 1030  Fidelity = 0.29604907
# T = 1040  Fidelity = 0.28454317
# T = 1050  Fidelity = 0.29703858
# T = 1060  Fidelity = 0.29548815
# T = 1070  Fidelity = 0.29217277
# T = 1080  Fidelity = 0.28941490
# T = 1090  Fidelity = 0.28964630
# T = 1100  Fidelity = 0.29102050
# T = 1200  Fidelity = 0.29126130
# T = 1300  Fidelity = 0.29102457
# T = 1400  Fidelity = 0.28895978
# T = 1500  Fidelity = 0.29008663
# T = 2000  Fidelity = 0.30192060
# T = 2100  Fidelity = 0.30026489
# T = 2110  Fidelity = 0.29678299
# T = 2120  Fidelity = 0.30068767
# T = 2130  Fidelity = 0.30397116
# T = 2140  Fidelity = 0.30482111
# T = 2150  Fidelity = 0.30401438
# T = 2160  Fidelity = 0.30191697
# T = 2170  Fidelity = 0.29991586
# T = 2180  Fidelity = 0.29954333
# T = 2190  Fidelity = 0.29822260
# T = 2200  Fidelity = 0.29907604
# T = 2300  Fidelity = 0.29784695
# T = 2400  Fidelity = 0.29947182
# T = 2500  Fidelity = 0.29928811
# T = 2600  Fidelity = 0.30239588
# T = 2700  Fidelity = 0.30031766
# T = 2800  Fidelity = 0.29603662
# T = 2900  Fidelity = 0.29421787
# T = 3000  Fidelity = 0.29392009
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.07826512e-04
# P0     = 0.29392009
# P1     = 0.24494529
# P0+P1  = 0.53886538
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.61167872e-04
# T = 1     Fidelity = 0.47264974
# T = 2     Fidelity = 0.48470429
# T = 5     Fidelity = 0.49946331
# T = 10    Fidelity = 0.50546222
# T = 20    Fidelity = 0.51351379
# T = 30    Fidelity = 0.52081747
# T = 40    Fidelity = 0.52625206
# T = 50    Fidelity = 0.52993475
# T = 75    Fidelity = 0.53957264
# T = 100   Fidelity = 0.54684031
# T = 125   Fidelity = 0.55279997
# T = 150   Fidelity = 0.55841073
# T = 175   Fidelity = 0.56376185
# T = 200   Fidelity = 0.56813816
# T = 225   Fidelity = 0.57216214
# T = 250   Fidelity = 0.57645577
# T = 275   Fidelity = 0.58028848
# T = 300   Fidelity = 0.58407045
# T = 400   Fidelity = 0.59757988
# T = 500   Fidelity = 0.60842948
# T = 600   Fidelity = 0.63026821
# T = 700   Fidelity = 0.63432919
# T = 800   Fidelity = 0.64226212
# T = 900   Fidelity = 0.63183498
# T = 1000  Fidelity = 0.65440414
# T = 1010  Fidelity = 0.65787762
# T = 1020  Fidelity = 0.65919960
# T = 1030  Fidelity = 0.66245350
# T = 1040  Fidelity = 0.66533449
# T = 1050  Fidelity = 0.66462513
# T = 1060  Fidelity = 0.66438391
# T = 1070  Fidelity = 0.66891929
# T = 1080  Fidelity = 0.67785497
# T = 1090  Fidelity = 0.67865476
# T = 1100  Fidelity = 0.66548385
# T = 1200  Fidelity = 0.64856532
# T = 1300  Fidelity = 0.64761445
# T = 1400  Fidelity = 0.67509021
# T = 1500  Fidelity = 0.68944625
# T = 2000  Fidelity = 0.67794086
# T = 2100  Fidelity = 0.67474261
# T = 2110  Fidelity = 0.67159146
# T = 2120  Fidelity = 0.67077904
# T = 2130  Fidelity = 0.66309225
# T = 2140  Fidelity = 0.67367546
# T = 2150  Fidelity = 0.66388167
# T = 2160  Fidelity = 0.66278302
# T = 2170  Fidelity = 0.66929731
# T = 2180  Fidelity = 0.67600189
# T = 2190  Fidelity = 0.68829766
# T = 2200  Fidelity = 0.69688456
# T = 2300  Fidelity = 0.70666191
# T = 2400  Fidelity = 0.72936768
# T = 2500  Fidelity = 0.73188329
# T = 2600  Fidelity = 0.73610462
# T = 2700  Fidelity = 0.77459965
# T = 2800  Fidelity = 0.76568004
# T = 2900  Fidelity = 0.77672791
# T = 3000  Fidelity = 0.76467454
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 2.60193315e-04
# P0     = 0.76467454
# P1     = 0.02156861
# P0+P1  = 0.78624315
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.86673133e-03
# T = 1     Fidelity = 0.49164640
# T = 2     Fidelity = 0.51374816
# T = 5     Fidelity = 0.54724673
# T = 10    Fidelity = 0.56404138
# T = 20    Fidelity = 0.59184464
# T = 30    Fidelity = 0.60856542
# T = 40    Fidelity = 0.62445314
# T = 50    Fidelity = 0.63527240
# T = 75    Fidelity = 0.66020185
# T = 100   Fidelity = 0.68038405
# T = 125   Fidelity = 0.69651395
# T = 150   Fidelity = 0.71068081
# T = 175   Fidelity = 0.72380535
# T = 200   Fidelity = 0.73514824
# T = 225   Fidelity = 0.74540836
# T = 250   Fidelity = 0.75523462
# T = 275   Fidelity = 0.76406445
# T = 300   Fidelity = 0.77251669
# T = 400   Fidelity = 0.80046804
# T = 500   Fidelity = 0.82259152
# T = 600   Fidelity = 0.82671551
# T = 700   Fidelity = 0.84971632
# T = 800   Fidelity = 0.87713606
# T = 900   Fidelity = 0.89451167
# T = 1000  Fidelity = 0.89010139
# T = 1010  Fidelity = 0.89721407
# T = 1020  Fidelity = 0.90323779
# T = 1030  Fidelity = 0.90954231
# T = 1040  Fidelity = 0.91321574
# T = 1050  Fidelity = 0.91434651
# T = 1060  Fidelity = 0.91277432
# T = 1070  Fidelity = 0.90999863
# T = 1080  Fidelity = 0.90723476
# T = 1090  Fidelity = 0.90398489
# T = 1100  Fidelity = 0.89968413
# T = 1200  Fidelity = 0.88925677
# T = 1300  Fidelity = 0.94032850
# T = 1400  Fidelity = 0.91506014
# T = 1500  Fidelity = 0.88530602
# T = 2000  Fidelity = 0.92433882
# T = 2100  Fidelity = 0.89586704
# T = 2110  Fidelity = 0.89435767
# T = 2120  Fidelity = 0.88621482
# T = 2130  Fidelity = 0.88239920
# T = 2140  Fidelity = 0.88995339
# T = 2150  Fidelity = 0.90166711
# T = 2160  Fidelity = 0.90727152
# T = 2170  Fidelity = 0.90606100
# T = 2180  Fidelity = 0.90286953
# T = 2190  Fidelity = 0.90420113
# T = 2200  Fidelity = 0.91123455
# T = 2300  Fidelity = 0.91223770
# T = 2400  Fidelity = 0.93287864
# T = 2500  Fidelity = 0.96773614
# T = 2600  Fidelity = 0.96755439
# T = 2700  Fidelity = 0.98658370
#
# Minimum T for Fidelity >= 0.97 : 2700
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.31352271e-03
# T = 1     Fidelity = 0.51144265
# T = 2     Fidelity = 0.54460078
# T = 5     Fidelity = 0.59838676
# T = 10    Fidelity = 0.63161869
# T = 20    Fidelity = 0.68362736
# T = 30    Fidelity = 0.71662407
# T = 40    Fidelity = 0.73884405
# T = 50    Fidelity = 0.75852977
# T = 75    Fidelity = 0.79760097
# T = 100   Fidelity = 0.82581087
# T = 125   Fidelity = 0.84741118
# T = 150   Fidelity = 0.86509641
# T = 175   Fidelity = 0.88008353
# T = 200   Fidelity = 0.89248467
# T = 225   Fidelity = 0.90318246
# T = 250   Fidelity = 0.91193373
# T = 275   Fidelity = 0.92016457
# T = 300   Fidelity = 0.92738763
# T = 400   Fidelity = 0.94824858
# T = 500   Fidelity = 0.96150704
# T = 600   Fidelity = 0.97038299
#
# Minimum T for Fidelity >= 0.97 : 600
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.92005942e-02
# T = 1     Fidelity = 0.54947074
# T = 2     Fidelity = 0.59341989
# T = 5     Fidelity = 0.66460740
# T = 10    Fidelity = 0.72011140
# T = 20    Fidelity = 0.78273574
# T = 30    Fidelity = 0.82313713
# T = 40    Fidelity = 0.85201130
# T = 50    Fidelity = 0.87340479
# T = 75    Fidelity = 0.90867544
# T = 100   Fidelity = 0.93107504
# T = 125   Fidelity = 0.94637778
# T = 150   Fidelity = 0.95733516
# T = 175   Fidelity = 0.96528687
# T = 200   Fidelity = 0.97135364
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 3.87723930e-02
# T = 1     Fidelity = 0.60021323
# T = 2     Fidelity = 0.65323360
# T = 5     Fidelity = 0.73589001
# T = 10    Fidelity = 0.80610808
# T = 20    Fidelity = 0.86833420
# T = 30    Fidelity = 0.90342092
# T = 40    Fidelity = 0.92626596
# T = 50    Fidelity = 0.94224522
# T = 75    Fidelity = 0.96466104
# T = 100   Fidelity = 0.97694934
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 6.53468672e-02
# T = 1     Fidelity = 0.65428796
# T = 2     Fidelity = 0.71392601
# T = 5     Fidelity = 0.80123097
# T = 10    Fidelity = 0.87224553
# T = 20    Fidelity = 0.92460964
# T = 30    Fidelity = 0.95035347
# T = 40    Fidelity = 0.96544281
# T = 50    Fidelity = 0.97501159
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.62283206
# T = 2     Fidelity = 0.65165956
# T = 5     Fidelity = 0.70824500
# T = 10    Fidelity = 0.76292632
# T = 20    Fidelity = 0.82935119
# T = 30    Fidelity = 0.86996863
# T = 40    Fidelity = 0.89828721
# T = 50    Fidelity = 0.91842108
# T = 75    Fidelity = 0.94952452
# T = 100   Fidelity = 0.96633394
# T = 125   Fidelity = 0.97458851
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.74572681
# T = 2     Fidelity = 0.75548045
# T = 5     Fidelity = 0.78465549
# T = 10    Fidelity = 0.81566021
# T = 20    Fidelity = 0.85132600
# T = 30    Fidelity = 0.87363967
# T = 40    Fidelity = 0.88955458
# T = 50    Fidelity = 0.90195177
# T = 75    Fidelity = 0.92397995
# T = 100   Fidelity = 0.93867075
# T = 125   Fidelity = 0.94907063
# T = 150   Fidelity = 0.95566311
# T = 175   Fidelity = 0.96304305
# T = 200   Fidelity = 0.96563650
# T = 225   Fidelity = 0.96904649
# T = 250   Fidelity = 0.96735015
# T = 275   Fidelity = 0.97216143
#
# Minimum T for Fidelity >= 0.97 : 275
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.99083854
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98782427
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97967287
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.95066760
# T = 2     Fidelity = 0.96674306
# T = 5     Fidelity = 0.97824079
#
# Minimum T for Fidelity >= 0.97 : 5
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.87360554
# T = 2     Fidelity = 0.89694261
# T = 5     Fidelity = 0.92175813
# T = 10    Fidelity = 0.93230012
# T = 20    Fidelity = 0.94722384
# T = 30    Fidelity = 0.95423003
# T = 40    Fidelity = 0.96024225
# T = 50    Fidelity = 0.96397537
# T = 75    Fidelity = 0.97134687
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78795940
# T = 2     Fidelity = 0.81810525
# T = 5     Fidelity = 0.85670375
# T = 10    Fidelity = 0.87836736
# T = 20    Fidelity = 0.90970228
# T = 30    Fidelity = 0.92393691
# T = 40    Fidelity = 0.93457984
# T = 50    Fidelity = 0.94301038
# T = 75    Fidelity = 0.95679683
# T = 100   Fidelity = 0.96575317
# T = 125   Fidelity = 0.97194844
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.71988060
# T = 2     Fidelity = 0.75648983
# T = 5     Fidelity = 0.80689693
# T = 10    Fidelity = 0.84313221
# T = 20    Fidelity = 0.89160453
# T = 30    Fidelity = 0.91308191
# T = 40    Fidelity = 0.93004073
# T = 50    Fidelity = 0.93973030
# T = 75    Fidelity = 0.95854998
# T = 100   Fidelity = 0.96982551
# T = 125   Fidelity = 0.97707667
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.69231656
# T = 2     Fidelity = 0.73449370
# T = 5     Fidelity = 0.79297901
# T = 10    Fidelity = 0.84060931
# T = 20    Fidelity = 0.90335563
# T = 30    Fidelity = 0.92698312
# T = 40    Fidelity = 0.94566837
# T = 50    Fidelity = 0.95653662
# T = 75    Fidelity = 0.97328791
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99429126
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.99425153
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.42665601e+00
# T = 1     Fidelity = 0.99371998
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41121208e+00
# T = 1     Fidelity = 0.99393156
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.99330661
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.99226566
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99118356
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98983407
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98830819
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98656177
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     275       0.9820517822      2.15534848e-04    None        None        None
# Symmetric      0.311     100       0.9730565152      1.15624066e-06    None        None        None
# Symmetric      0.522     75        0.9914379765      3.42043128e-07    None        None        None
# Symmetric      0.733     40        0.9722239395      1.41278093e-05    None        None        None
# Symmetric      0.944     30        0.9797756592      3.35131121e-04    None        None        None
# Symmetric      1.156     30        0.9965135869      2.39158790e-03    None        None        None
# Symmetric      1.367     30        0.9816762329      8.93695212e-03    None        None        None
# Symmetric      1.578     30        0.9729379176      2.26116126e-02    None        None        None
# Symmetric      1.789     30        0.9725119044      4.43232760e-02    None        None        None
# Symmetric      2.000     30        0.9759603158      7.29248761e-02    None        None        None
# Weak SSB       0.100     75        0.9816098656      1.33865795e-02    None        None        None
# Weak SSB       0.311     400       0.9735698358      2.33760034e-03    None        None        None
# Weak SSB       0.522     None      0.2576498332      1.28632798e-04    0.250888    0.247167    0.498056
# Weak SSB       0.733     None      0.3048211099      1.07617225e-04    0.29392     0.244945    0.538865
# Weak SSB       0.944     None      0.7767279081      2.61167872e-04    0.764675    0.021569    0.786243
# Weak SSB       1.156     2700      0.9865837014      1.86673133e-03    None        None        None
# Weak SSB       1.367     600       0.9703829929      7.31352271e-03    None        None        None
# Weak SSB       1.578     200       0.9713536447      1.92005942e-02    None        None        None
# Weak SSB       1.789     100       0.9769493374      3.87723930e-02    None        None        None
# Weak SSB       2.000     50        0.9750115861      6.53468672e-02    None        None        None
# Weak SSB optimised0.100     125       0.9745885084      8.65519637e-01    None        None        None
# Weak SSB optimised0.311     275       0.9721614282      5.19764834e-01    None        None        None
# Weak SSB optimised0.522     1         0.9908385428      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     1         0.9878242686      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     1         0.9796728742      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     5         0.9782407884      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     75        0.9713468686      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     125       0.9719484436      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9770766742      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     75        0.9732879148      2.54594564e-01    None        None        None
# Strong SSB     0.100     1         0.9942912560      3.59472102e+00    None        None        None
# Strong SSB     0.311     1         0.9942515348      1.58498916e+00    None        None        None
# Strong SSB     0.522     1         0.9937199834      1.42665601e+00    None        None        None
# Strong SSB     0.733     1         0.9939315570      1.41121208e+00    None        None        None
# Strong SSB     0.944     1         0.9933066139      1.38481786e+00    None        None        None
# Strong SSB     1.156     1         0.9922656562      1.34302163e+00    None        None        None
# Strong SSB     1.367     1         0.9911835572      1.29217279e+00    None        None        None
# Strong SSB     1.578     1         0.9898340651      1.23335459e+00    None        None        None
# Strong SSB     1.789     1         0.9883081916      1.17426012e+00    None        None        None
# Strong SSB     2.000     1         0.9865617651      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimized')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)




lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym, dM_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak, dM_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong, dM_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimized'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Start of m0^2=-2.0

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_vqe = data['psi_vqe']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000295
# T = 10    Fidelity = 0.00027915
# T = 20    Fidelity = 0.00630003
# T = 30    Fidelity = 0.02604193
# T = 40    Fidelity = 0.06583422
# T = 50    Fidelity = 0.12448897
# T = 75    Fidelity = 0.30904182
# T = 100   Fidelity = 0.46392361
# T = 125   Fidelity = 0.64204595
# T = 150   Fidelity = 0.69157242
# T = 175   Fidelity = 0.77467521
# T = 200   Fidelity = 0.83393308
# T = 225   Fidelity = 0.81459147
# T = 250   Fidelity = 0.90534387
# T = 275   Fidelity = 0.91624647
# T = 300   Fidelity = 0.86713298
# T = 400   Fidelity = 0.97880285
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.17908351e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00030522
# T = 10    Fidelity = 0.01973675
# T = 20    Fidelity = 0.35207405
# T = 30    Fidelity = 0.52575693
# T = 40    Fidelity = 0.54419747
# T = 50    Fidelity = 0.70348435
# T = 75    Fidelity = 0.85007762
# T = 100   Fidelity = 0.92376718
# T = 125   Fidelity = 0.95514061
# T = 150   Fidelity = 0.97616678
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.94880927e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.01014269
# T = 10    Fidelity = 0.29389403
# T = 20    Fidelity = 0.47641992
# T = 30    Fidelity = 0.65913624
# T = 40    Fidelity = 0.84252444
# T = 50    Fidelity = 0.88339527
# T = 75    Fidelity = 0.96314282
# T = 100   Fidelity = 0.98781140
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.58119042e-07
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000816
# T = 5     Fidelity = 0.06263935
# T = 10    Fidelity = 0.29632346
# T = 20    Fidelity = 0.55807005
# T = 30    Fidelity = 0.72698259
# T = 40    Fidelity = 0.83532749
# T = 50    Fidelity = 0.91099313
# T = 75    Fidelity = 0.98046699
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.89654440e-08
# T = 1     Fidelity = 0.00000138
# T = 2     Fidelity = 0.00013187
# T = 5     Fidelity = 0.11160164
# T = 10    Fidelity = 0.49003708
# T = 20    Fidelity = 0.76516979
# T = 30    Fidelity = 0.88756716
# T = 40    Fidelity = 0.94380783
# T = 50    Fidelity = 0.97009462
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.17592579e-07
# T = 1     Fidelity = 0.00002204
# T = 2     Fidelity = 0.00081369
# T = 5     Fidelity = 0.15753997
# T = 10    Fidelity = 0.62743090
# T = 20    Fidelity = 0.87767929
# T = 30    Fidelity = 0.95887046
# T = 40    Fidelity = 0.98612932
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 2.47961090e-07
# T = 1     Fidelity = 0.00014359
# T = 2     Fidelity = 0.00277534
# T = 5     Fidelity = 0.19658836
# T = 10    Fidelity = 0.73840313
# T = 20    Fidelity = 0.93000883
# T = 30    Fidelity = 0.97197941
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 3.56990601e-07
# T = 1     Fidelity = 0.00057649
# T = 2     Fidelity = 0.00690686
# T = 5     Fidelity = 0.23187420
# T = 10    Fidelity = 0.80829760
# T = 20    Fidelity = 0.93690416
# T = 30    Fidelity = 0.96371570
# T = 40    Fidelity = 0.98388595
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.45005900e-06
# T = 1     Fidelity = 0.00169019
# T = 2     Fidelity = 0.01404681
# T = 5     Fidelity = 0.26488192
# T = 10    Fidelity = 0.84406419
# T = 20    Fidelity = 0.92519212
# T = 30    Fidelity = 0.96896857
# T = 40    Fidelity = 0.99383557
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396257
# T = 2     Fidelity = 0.02466855
# T = 5     Fidelity = 0.29524540
# T = 10    Fidelity = 0.85801228
# T = 20    Fidelity = 0.92051950
# T = 30    Fidelity = 0.98400192
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.80997252e-02
# T = 1     Fidelity = 0.60408881
# T = 2     Fidelity = 0.64818903
# T = 5     Fidelity = 0.72633945
# T = 10    Fidelity = 0.80228479
# T = 20    Fidelity = 0.88311530
# T = 30    Fidelity = 0.92515930
# T = 40    Fidelity = 0.94941475
# T = 50    Fidelity = 0.96408709
# T = 75    Fidelity = 0.98214454
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.50638569e-02
# T = 1     Fidelity = 0.54365953
# T = 2     Fidelity = 0.58661910
# T = 5     Fidelity = 0.63057034
# T = 10    Fidelity = 0.66784012
# T = 20    Fidelity = 0.72548349
# T = 30    Fidelity = 0.76732239
# T = 40    Fidelity = 0.79968882
# T = 50    Fidelity = 0.82355554
# T = 75    Fidelity = 0.87069478
# T = 100   Fidelity = 0.90083638
# T = 125   Fidelity = 0.91998599
# T = 150   Fidelity = 0.93395809
# T = 175   Fidelity = 0.94144467
# T = 200   Fidelity = 0.94244955
# T = 225   Fidelity = 0.94982506
# T = 250   Fidelity = 0.94170058
# T = 275   Fidelity = 0.93133955
# T = 300   Fidelity = 0.94541181
# T = 400   Fidelity = 0.96711144
# T = 500   Fidelity = 0.94933157
# T = 600   Fidelity = 0.95721072
# T = 700   Fidelity = 0.83444901
# T = 800   Fidelity = 0.87203331
# T = 900   Fidelity = 0.88476350
# T = 1000  Fidelity = 0.88113636
# T = 1010  Fidelity = 0.93283516
# T = 1020  Fidelity = 0.90767566
# T = 1030  Fidelity = 0.94421010
# T = 1040  Fidelity = 0.94740714
# T = 1050  Fidelity = 0.96158007
# T = 1060  Fidelity = 0.97101184
#
# Minimum T for Fidelity >= 0.97 : 1060
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.29389510e-04
# T = 1     Fidelity = 0.02292388
# T = 2     Fidelity = 0.09352836
# T = 5     Fidelity = 0.43025925
# T = 10    Fidelity = 0.48235778
# T = 20    Fidelity = 0.49760098
# T = 30    Fidelity = 0.49900043
# T = 40    Fidelity = 0.49976417
# T = 50    Fidelity = 0.50177334
# T = 75    Fidelity = 0.50015837
# T = 100   Fidelity = 0.50190614
# T = 125   Fidelity = 0.50029118
# T = 150   Fidelity = 0.50334106
# T = 175   Fidelity = 0.50079771
# T = 200   Fidelity = 0.50070958
# T = 225   Fidelity = 0.50128665
# T = 250   Fidelity = 0.50190078
# T = 275   Fidelity = 0.49900021
# T = 300   Fidelity = 0.49809358
# T = 400   Fidelity = 0.48542440
# T = 500   Fidelity = 0.47915745
# T = 600   Fidelity = 0.49920665
# T = 700   Fidelity = 0.49331042
# T = 800   Fidelity = 0.49013973
# T = 900   Fidelity = 0.50856510
# T = 1000  Fidelity = 0.48623417
# T = 1010  Fidelity = 0.49753147
# T = 1020  Fidelity = 0.49857101
# T = 1030  Fidelity = 0.49450778
# T = 1040  Fidelity = 0.50373729
# T = 1050  Fidelity = 0.49240014
# T = 1060  Fidelity = 0.49773661
# T = 1070  Fidelity = 0.49958498
# T = 1080  Fidelity = 0.50465133
# T = 1090  Fidelity = 0.49635810
# T = 1100  Fidelity = 0.49483740
# T = 1200  Fidelity = 0.50684677
# T = 1300  Fidelity = 0.49722826
# T = 1400  Fidelity = 0.43846462
# T = 1500  Fidelity = 0.49694862
# T = 2000  Fidelity = 0.49293390
# T = 2100  Fidelity = 0.50532025
# T = 2110  Fidelity = 0.49942463
# T = 2120  Fidelity = 0.49546485
# T = 2130  Fidelity = 0.48560559
# T = 2140  Fidelity = 0.49912436
# T = 2150  Fidelity = 0.50184893
# T = 2160  Fidelity = 0.49381343
# T = 2170  Fidelity = 0.48308149
# T = 2180  Fidelity = 0.49814333
# T = 2190  Fidelity = 0.49699555
# T = 2200  Fidelity = 0.49085753
# T = 2300  Fidelity = 0.48573663
# T = 2400  Fidelity = 0.42238880
# T = 2500  Fidelity = 0.49609973
# T = 2600  Fidelity = 0.50229425
# T = 2700  Fidelity = 0.48990818
# T = 2800  Fidelity = 0.48929921
# T = 2900  Fidelity = 0.48878464
# T = 3000  Fidelity = 0.47462193
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.15023181e-03
# P0     = 0.47462193
# P1     = 0.00893849
# P0+P1  = 0.48356042
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.10289833e-04
# T = 1     Fidelity = 0.03589871
# T = 2     Fidelity = 0.10676355
# T = 5     Fidelity = 0.28280436
# T = 10    Fidelity = 0.30458857
# T = 20    Fidelity = 0.33482188
# T = 30    Fidelity = 0.33409528
# T = 40    Fidelity = 0.33475503
# T = 50    Fidelity = 0.33858492
# T = 75    Fidelity = 0.33931309
# T = 100   Fidelity = 0.34037864
# T = 125   Fidelity = 0.34026017
# T = 150   Fidelity = 0.34066580
# T = 175   Fidelity = 0.34054881
# T = 200   Fidelity = 0.34789152
# T = 225   Fidelity = 0.34573908
# T = 250   Fidelity = 0.33776019
# T = 275   Fidelity = 0.34318185
# T = 300   Fidelity = 0.34582166
# T = 400   Fidelity = 0.36748117
# T = 500   Fidelity = 0.32758907
# T = 600   Fidelity = 0.34284480
# T = 700   Fidelity = 0.34028737
# T = 800   Fidelity = 0.31037700
# T = 900   Fidelity = 0.30699912
# T = 1000  Fidelity = 0.33469619
# T = 1010  Fidelity = 0.33835310
# T = 1020  Fidelity = 0.33723437
# T = 1030  Fidelity = 0.36707622
# T = 1040  Fidelity = 0.34676336
# T = 1050  Fidelity = 0.36767111
# T = 1060  Fidelity = 0.42719053
# T = 1070  Fidelity = 0.28092317
# T = 1080  Fidelity = 0.32773448
# T = 1090  Fidelity = 0.32445733
# T = 1100  Fidelity = 0.39362486
# T = 1200  Fidelity = 0.41017225
# T = 1300  Fidelity = 0.38534483
# T = 1400  Fidelity = 0.38865336
# T = 1500  Fidelity = 0.27364166
# T = 2000  Fidelity = 0.34943904
# T = 2100  Fidelity = 0.25360089
# T = 2110  Fidelity = 0.38541266
# T = 2120  Fidelity = 0.37536226
# T = 2130  Fidelity = 0.30084815
# T = 2140  Fidelity = 0.45123113
# T = 2150  Fidelity = 0.27990143
# T = 2160  Fidelity = 0.37617060
# T = 2170  Fidelity = 0.30735048
# T = 2180  Fidelity = 0.38553195
# T = 2190  Fidelity = 0.37741512
# T = 2200  Fidelity = 0.36349740
# T = 2300  Fidelity = 0.38506892
# T = 2400  Fidelity = 0.31442672
# T = 2500  Fidelity = 0.37772610
# T = 2600  Fidelity = 0.37871450
# T = 2700  Fidelity = 0.32780032
# T = 2800  Fidelity = 0.32210811
# T = 2900  Fidelity = 0.33477987
# T = 3000  Fidelity = 0.31375164
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.69459506e-04
# P0     = 0.31375164
# P1     = 0.16569604
# P0+P1  = 0.47944768
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.04207670e-04
# T = 1     Fidelity = 0.04066931
# T = 2     Fidelity = 0.09811777
# T = 5     Fidelity = 0.24035728
# T = 10    Fidelity = 0.25304807
# T = 20    Fidelity = 0.27497763
# T = 30    Fidelity = 0.28238048
# T = 40    Fidelity = 0.28032815
# T = 50    Fidelity = 0.28684557
# T = 75    Fidelity = 0.28985379
# T = 100   Fidelity = 0.29389705
# T = 125   Fidelity = 0.29938428
# T = 150   Fidelity = 0.30459764
# T = 175   Fidelity = 0.31314791
# T = 200   Fidelity = 0.31157878
# T = 225   Fidelity = 0.31633506
# T = 250   Fidelity = 0.31479935
# T = 275   Fidelity = 0.31274246
# T = 300   Fidelity = 0.32235045
# T = 400   Fidelity = 0.37128868
# T = 500   Fidelity = 0.29871647
# T = 600   Fidelity = 0.34327944
# T = 700   Fidelity = 0.25166363
# T = 800   Fidelity = 0.39754896
# T = 900   Fidelity = 0.39317044
# T = 1000  Fidelity = 0.36853838
# T = 1010  Fidelity = 0.39445379
# T = 1020  Fidelity = 0.41713410
# T = 1030  Fidelity = 0.37428426
# T = 1040  Fidelity = 0.30009135
# T = 1050  Fidelity = 0.28466223
# T = 1060  Fidelity = 0.31429332
# T = 1070  Fidelity = 0.34919428
# T = 1080  Fidelity = 0.41173784
# T = 1090  Fidelity = 0.43170014
# T = 1100  Fidelity = 0.29646756
# T = 1200  Fidelity = 0.28804285
# T = 1300  Fidelity = 0.43291057
# T = 1400  Fidelity = 0.31206569
# T = 1500  Fidelity = 0.43294100
# T = 2000  Fidelity = 0.43170985
# T = 2100  Fidelity = 0.36778930
# T = 2110  Fidelity = 0.43734164
# T = 2120  Fidelity = 0.40509189
# T = 2130  Fidelity = 0.40734506
# T = 2140  Fidelity = 0.46878418
# T = 2150  Fidelity = 0.37980857
# T = 2160  Fidelity = 0.37049795
# T = 2170  Fidelity = 0.32733662
# T = 2180  Fidelity = 0.33787473
# T = 2190  Fidelity = 0.45805355
# T = 2200  Fidelity = 0.32130473
# T = 2300  Fidelity = 0.44855875
# T = 2400  Fidelity = 0.38512774
# T = 2500  Fidelity = 0.44187200
# T = 2600  Fidelity = 0.43296245
# T = 2700  Fidelity = 0.37031162
# T = 2800  Fidelity = 0.40084227
# T = 2900  Fidelity = 0.43991652
# T = 3000  Fidelity = 0.44649864
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.39396699e-04
# P0     = 0.44649864
# P1     = 0.38085950
# P0+P1  = 0.82735815
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.00641152e-04
# T = 1     Fidelity = 0.04492087
# T = 2     Fidelity = 0.09406872
# T = 5     Fidelity = 0.22414951
# T = 10    Fidelity = 0.23875129
# T = 20    Fidelity = 0.26092484
# T = 30    Fidelity = 0.28426188
# T = 40    Fidelity = 0.29248180
# T = 50    Fidelity = 0.29135251
# T = 75    Fidelity = 0.31354622
# T = 100   Fidelity = 0.31906502
# T = 125   Fidelity = 0.32851166
# T = 150   Fidelity = 0.34039402
# T = 175   Fidelity = 0.34250640
# T = 200   Fidelity = 0.35197881
# T = 225   Fidelity = 0.35812196
# T = 250   Fidelity = 0.35906109
# T = 275   Fidelity = 0.37150613
# T = 300   Fidelity = 0.37001477
# T = 400   Fidelity = 0.33695329
# T = 500   Fidelity = 0.37730347
# T = 600   Fidelity = 0.41843110
# T = 700   Fidelity = 0.42052759
# T = 800   Fidelity = 0.43763545
# T = 900   Fidelity = 0.44585824
# T = 1000  Fidelity = 0.47135079
# T = 1010  Fidelity = 0.41596088
# T = 1020  Fidelity = 0.39657004
# T = 1030  Fidelity = 0.44898278
# T = 1040  Fidelity = 0.48137385
# T = 1050  Fidelity = 0.46869623
# T = 1060  Fidelity = 0.41030965
# T = 1070  Fidelity = 0.36016442
# T = 1080  Fidelity = 0.44194764
# T = 1090  Fidelity = 0.47378915
# T = 1100  Fidelity = 0.38900133
# T = 1200  Fidelity = 0.46397041
# T = 1300  Fidelity = 0.48850608
# T = 1400  Fidelity = 0.45974307
# T = 1500  Fidelity = 0.46019173
# T = 2000  Fidelity = 0.45782116
# T = 2100  Fidelity = 0.47301024
# T = 2110  Fidelity = 0.46077926
# T = 2120  Fidelity = 0.44532947
# T = 2130  Fidelity = 0.45839207
# T = 2140  Fidelity = 0.43783968
# T = 2150  Fidelity = 0.43890146
# T = 2160  Fidelity = 0.44203797
# T = 2170  Fidelity = 0.42417302
# T = 2180  Fidelity = 0.41475294
# T = 2190  Fidelity = 0.43962432
# T = 2200  Fidelity = 0.43326731
# T = 2300  Fidelity = 0.48314777
# T = 2400  Fidelity = 0.49645449
# T = 2500  Fidelity = 0.46333626
# T = 2600  Fidelity = 0.48041055
# T = 2700  Fidelity = 0.49902220
# T = 2800  Fidelity = 0.47443434
# T = 2900  Fidelity = 0.50474814
# T = 3000  Fidelity = 0.50530376
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.24417142e-04
# P0     = 0.50530376
# P1     = 0.48594696
# P0+P1  = 0.99125073
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 9.79040346e-05
# T = 1     Fidelity = 0.04763028
# T = 2     Fidelity = 0.09143960
# T = 5     Fidelity = 0.23509886
# T = 10    Fidelity = 0.25915211
# T = 20    Fidelity = 0.28458559
# T = 30    Fidelity = 0.30744507
# T = 40    Fidelity = 0.33004481
# T = 50    Fidelity = 0.34793229
# T = 75    Fidelity = 0.36822895
# T = 100   Fidelity = 0.38416969
# T = 125   Fidelity = 0.40316429
# T = 150   Fidelity = 0.41168878
# T = 175   Fidelity = 0.42158125
# T = 200   Fidelity = 0.43263958
# T = 225   Fidelity = 0.43643134
# T = 250   Fidelity = 0.44423165
# T = 275   Fidelity = 0.45219950
# T = 300   Fidelity = 0.45019108
# T = 400   Fidelity = 0.46914472
# T = 500   Fidelity = 0.44855112
# T = 600   Fidelity = 0.48381283
# T = 700   Fidelity = 0.48019908
# T = 800   Fidelity = 0.49719103
# T = 900   Fidelity = 0.50011775
# T = 1000  Fidelity = 0.46767725
# T = 1010  Fidelity = 0.49408882
# T = 1020  Fidelity = 0.47589775
# T = 1030  Fidelity = 0.46642675
# T = 1040  Fidelity = 0.49055361
# T = 1050  Fidelity = 0.49201036
# T = 1060  Fidelity = 0.46751327
# T = 1070  Fidelity = 0.49805205
# T = 1080  Fidelity = 0.49120922
# T = 1090  Fidelity = 0.50123331
# T = 1100  Fidelity = 0.48740856
# T = 1200  Fidelity = 0.47991367
# T = 1300  Fidelity = 0.49545144
# T = 1400  Fidelity = 0.46371354
# T = 1500  Fidelity = 0.48482703
# T = 2000  Fidelity = 0.49466007
# T = 2100  Fidelity = 0.50628783
# T = 2110  Fidelity = 0.50332155
# T = 2120  Fidelity = 0.49364586
# T = 2130  Fidelity = 0.49048377
# T = 2140  Fidelity = 0.49810849
# T = 2150  Fidelity = 0.50206860
# T = 2160  Fidelity = 0.50672270
# T = 2170  Fidelity = 0.50355069
# T = 2180  Fidelity = 0.48961503
# T = 2190  Fidelity = 0.49570379
# T = 2200  Fidelity = 0.49045442
# T = 2300  Fidelity = 0.47469247
# T = 2400  Fidelity = 0.51047944
# T = 2500  Fidelity = 0.49355263
# T = 2600  Fidelity = 0.43070088
# T = 2700  Fidelity = 0.45388585
# T = 2800  Fidelity = 0.45070382
# T = 2900  Fidelity = 0.46254788
# T = 3000  Fidelity = 0.40128792
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.13589115e-04
# P0     = 0.40128792
# P1     = 0.38192911
# P0+P1  = 0.78321703
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 9.56243266e-05
# T = 1     Fidelity = 0.05012269
# T = 2     Fidelity = 0.09026325
# T = 5     Fidelity = 0.25433831
# T = 10    Fidelity = 0.29239480
# T = 20    Fidelity = 0.33354980
# T = 30    Fidelity = 0.36118139
# T = 40    Fidelity = 0.38177121
# T = 50    Fidelity = 0.39810967
# T = 75    Fidelity = 0.42727306
# T = 100   Fidelity = 0.44660661
# T = 125   Fidelity = 0.46028487
# T = 150   Fidelity = 0.47034600
# T = 175   Fidelity = 0.47791873
# T = 200   Fidelity = 0.48356257
# T = 225   Fidelity = 0.48799914
# T = 250   Fidelity = 0.49123886
# T = 275   Fidelity = 0.49352466
# T = 300   Fidelity = 0.49481196
# T = 400   Fidelity = 0.49238143
# T = 500   Fidelity = 0.50040912
# T = 600   Fidelity = 0.49355826
# T = 700   Fidelity = 0.49930692
# T = 800   Fidelity = 0.48696829
# T = 900   Fidelity = 0.50424102
# T = 1000  Fidelity = 0.48911131
# T = 1010  Fidelity = 0.50338858
# T = 1020  Fidelity = 0.49327413
# T = 1030  Fidelity = 0.49307839
# T = 1040  Fidelity = 0.50341383
# T = 1050  Fidelity = 0.49758389
# T = 1060  Fidelity = 0.47853351
# T = 1070  Fidelity = 0.49818900
# T = 1080  Fidelity = 0.48660485
# T = 1090  Fidelity = 0.50318222
# T = 1100  Fidelity = 0.49337069
# T = 1200  Fidelity = 0.49242079
# T = 1300  Fidelity = 0.50514509
# T = 1400  Fidelity = 0.45818684
# T = 1500  Fidelity = 0.48940711
# T = 2000  Fidelity = 0.42660347
# T = 2100  Fidelity = 0.42932026
# T = 2110  Fidelity = 0.47369757
# T = 2120  Fidelity = 0.44385322
# T = 2130  Fidelity = 0.44449628
# T = 2140  Fidelity = 0.45693156
# T = 2150  Fidelity = 0.42887621
# T = 2160  Fidelity = 0.42205034
# T = 2170  Fidelity = 0.44134181
# T = 2180  Fidelity = 0.43998326
# T = 2190  Fidelity = 0.42443946
# T = 2200  Fidelity = 0.38892625
# T = 2300  Fidelity = 0.47319972
# T = 2400  Fidelity = 0.47013993
# T = 2500  Fidelity = 0.43178436
# T = 2600  Fidelity = 0.48797195
# T = 2700  Fidelity = 0.49267852
# T = 2800  Fidelity = 0.46405267
# T = 2900  Fidelity = 0.50617833
# T = 3000  Fidelity = 0.50863686
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.05026659e-04
# P0     = 0.50863686
# P1     = 0.47773652
# P0+P1  = 0.98637338
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.37092431e-05
# T = 1     Fidelity = 0.05472250
# T = 2     Fidelity = 0.09389439
# T = 5     Fidelity = 0.28212376
# T = 10    Fidelity = 0.33477006
# T = 20    Fidelity = 0.39258957
# T = 30    Fidelity = 0.42427342
# T = 40    Fidelity = 0.44455567
# T = 50    Fidelity = 0.45841493
# T = 75    Fidelity = 0.47921649
# T = 100   Fidelity = 0.49059111
# T = 125   Fidelity = 0.49747945
# T = 150   Fidelity = 0.50172909
# T = 175   Fidelity = 0.50424566
# T = 200   Fidelity = 0.50552257
# T = 225   Fidelity = 0.50634460
# T = 250   Fidelity = 0.50677337
# T = 275   Fidelity = 0.50710091
# T = 300   Fidelity = 0.50707739
# T = 400   Fidelity = 0.49479807
# T = 500   Fidelity = 0.50016932
# T = 600   Fidelity = 0.50816654
# T = 700   Fidelity = 0.50129039
# T = 800   Fidelity = 0.49748168
# T = 900   Fidelity = 0.49369432
# T = 1000  Fidelity = 0.48916003
# T = 1010  Fidelity = 0.51125108
# T = 1020  Fidelity = 0.50352544
# T = 1030  Fidelity = 0.50471977
# T = 1040  Fidelity = 0.51005136
# T = 1050  Fidelity = 0.49075959
# T = 1060  Fidelity = 0.50956771
# T = 1070  Fidelity = 0.51053845
# T = 1080  Fidelity = 0.47988873
# T = 1090  Fidelity = 0.49504108
# T = 1100  Fidelity = 0.50454651
# T = 1200  Fidelity = 0.50076742
# T = 1300  Fidelity = 0.47873745
# T = 1400  Fidelity = 0.47986614
# T = 1500  Fidelity = 0.48019830
# T = 2000  Fidelity = 0.48805732
# T = 2100  Fidelity = 0.49744892
# T = 2110  Fidelity = 0.51579336
# T = 2120  Fidelity = 0.50805941
# T = 2130  Fidelity = 0.51366507
# T = 2140  Fidelity = 0.51834975
# T = 2150  Fidelity = 0.51238081
# T = 2160  Fidelity = 0.50568706
# T = 2170  Fidelity = 0.50309221
# T = 2180  Fidelity = 0.51041122
# T = 2190  Fidelity = 0.51464736
# T = 2200  Fidelity = 0.50853614
# T = 2300  Fidelity = 0.51286151
# T = 2400  Fidelity = 0.51626314
# T = 2500  Fidelity = 0.51598588
# T = 2600  Fidelity = 0.48144284
# T = 2700  Fidelity = 0.51322447
# T = 2800  Fidelity = 0.49437056
# T = 2900  Fidelity = 0.51952937
# T = 3000  Fidelity = 0.50684842
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.78352675e-05
# P0     = 0.50684842
# P1     = 0.45999979
# P0+P1  = 0.96684821
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.20598135e-05
# T = 1     Fidelity = 0.06521987
# T = 2     Fidelity = 0.10733874
# T = 5     Fidelity = 0.33519620
# T = 10    Fidelity = 0.40366613
# T = 20    Fidelity = 0.46640419
# T = 30    Fidelity = 0.49759022
# T = 40    Fidelity = 0.51811349
# T = 50    Fidelity = 0.53220762
# T = 75    Fidelity = 0.54730344
# T = 100   Fidelity = 0.55036184
# T = 125   Fidelity = 0.55317254
# T = 150   Fidelity = 0.55461426
# T = 175   Fidelity = 0.55478062
# T = 200   Fidelity = 0.55577121
# T = 225   Fidelity = 0.55608023
# T = 250   Fidelity = 0.55591333
# T = 275   Fidelity = 0.55629429
# T = 300   Fidelity = 0.55530916
# T = 400   Fidelity = 0.54624631
# T = 500   Fidelity = 0.54956810
# T = 600   Fidelity = 0.55269978
# T = 700   Fidelity = 0.55316043
# T = 800   Fidelity = 0.54807554
# T = 900   Fidelity = 0.55340015
# T = 1000  Fidelity = 0.53155043
# T = 1010  Fidelity = 0.55569616
# T = 1020  Fidelity = 0.53823615
# T = 1030  Fidelity = 0.55991649
# T = 1040  Fidelity = 0.53862789
# T = 1050  Fidelity = 0.55341054
# T = 1060  Fidelity = 0.54380147
# T = 1070  Fidelity = 0.53631947
# T = 1080  Fidelity = 0.53467502
# T = 1090  Fidelity = 0.54723434
# T = 1100  Fidelity = 0.55270938
# T = 1200  Fidelity = 0.53701218
# T = 1300  Fidelity = 0.52081631
# T = 1400  Fidelity = 0.51734416
# T = 1500  Fidelity = 0.52350600
# T = 2000  Fidelity = 0.55320591
# T = 2100  Fidelity = 0.55569297
# T = 2110  Fidelity = 0.55432426
# T = 2120  Fidelity = 0.56524955
# T = 2130  Fidelity = 0.56084342
# T = 2140  Fidelity = 0.56662622
# T = 2150  Fidelity = 0.53452004
# T = 2160  Fidelity = 0.54910372
# T = 2170  Fidelity = 0.56327653
# T = 2180  Fidelity = 0.54933347
# T = 2190  Fidelity = 0.56239570
# T = 2200  Fidelity = 0.55748700
# T = 2300  Fidelity = 0.56033615
# T = 2400  Fidelity = 0.55706278
# T = 2500  Fidelity = 0.55747223
# T = 2600  Fidelity = 0.55752709
# T = 2700  Fidelity = 0.51907520
# T = 2800  Fidelity = 0.53678496
# T = 2900  Fidelity = 0.54546084
# T = 3000  Fidelity = 0.56257815
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.23373761e-05
# P0     = 0.56257815
# P1     = 0.42025162
# P0+P1  = 0.98282977
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.62900729
# T = 2     Fidelity = 0.65770178
# T = 5     Fidelity = 0.71350104
# T = 10    Fidelity = 0.76699438
# T = 20    Fidelity = 0.83253967
# T = 30    Fidelity = 0.87211894
# T = 40    Fidelity = 0.90036946
# T = 50    Fidelity = 0.92009711
# T = 75    Fidelity = 0.95067716
# T = 100   Fidelity = 0.96471493
# T = 125   Fidelity = 0.97383194
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.70161974
# T = 2     Fidelity = 0.77056938
# T = 5     Fidelity = 0.81770765
# T = 10    Fidelity = 0.84681026
# T = 20    Fidelity = 0.87500490
# T = 30    Fidelity = 0.89282618
# T = 40    Fidelity = 0.90642805
# T = 50    Fidelity = 0.91646698
# T = 75    Fidelity = 0.93446111
# T = 100   Fidelity = 0.94594122
# T = 125   Fidelity = 0.95234519
# T = 150   Fidelity = 0.95763029
# T = 175   Fidelity = 0.96452562
# T = 200   Fidelity = 0.97230674
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.05158885
# T = 2     Fidelity = 0.19612481
# T = 5     Fidelity = 0.84854294
# T = 10    Fidelity = 0.96994806
# T = 20    Fidelity = 0.99324139
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.11314630
# T = 2     Fidelity = 0.33338162
# T = 5     Fidelity = 0.84587703
# T = 10    Fidelity = 0.91473548
# T = 20    Fidelity = 0.99913294
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.16811626
# T = 2     Fidelity = 0.40068814
# T = 5     Fidelity = 0.89895667
# T = 10    Fidelity = 0.94661246
# T = 20    Fidelity = 0.99422578
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.20994421
# T = 2     Fidelity = 0.42962005
# T = 5     Fidelity = 0.87850951
# T = 10    Fidelity = 0.92207354
# T = 20    Fidelity = 0.97185925
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.21594954
# T = 2     Fidelity = 0.40073132
# T = 5     Fidelity = 0.82073934
# T = 10    Fidelity = 0.85987412
# T = 20    Fidelity = 0.90304320
# T = 30    Fidelity = 0.93038321
# T = 40    Fidelity = 0.94280446
# T = 50    Fidelity = 0.94471609
# T = 75    Fidelity = 0.95897837
# T = 100   Fidelity = 0.96260856
# T = 125   Fidelity = 0.97169096
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.20070321
# T = 2     Fidelity = 0.34943501
# T = 5     Fidelity = 0.74435506
# T = 10    Fidelity = 0.79208647
# T = 20    Fidelity = 0.83474955
# T = 30    Fidelity = 0.86216928
# T = 40    Fidelity = 0.88574744
# T = 50    Fidelity = 0.90522030
# T = 75    Fidelity = 0.92957475
# T = 100   Fidelity = 0.94081744
# T = 125   Fidelity = 0.95416852
# T = 150   Fidelity = 0.96177453
# T = 175   Fidelity = 0.96632526
# T = 200   Fidelity = 0.97216759
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.18031709
# T = 2     Fidelity = 0.29836920
# T = 5     Fidelity = 0.67073801
# T = 10    Fidelity = 0.73256541
# T = 20    Fidelity = 0.79352370
# T = 30    Fidelity = 0.82960874
# T = 40    Fidelity = 0.85614043
# T = 50    Fidelity = 0.87736736
# T = 75    Fidelity = 0.91483229
# T = 100   Fidelity = 0.93875522
# T = 125   Fidelity = 0.95469519
# T = 150   Fidelity = 0.96540690
# T = 175   Fidelity = 0.97252964
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.48783584e-01
# T = 1     Fidelity = 0.16423323
# T = 2     Fidelity = 0.26149955
# T = 5     Fidelity = 0.62013684
# T = 10    Fidelity = 0.69459065
# T = 20    Fidelity = 0.77243287
# T = 30    Fidelity = 0.82156118
# T = 40    Fidelity = 0.85808443
# T = 50    Fidelity = 0.88616456
# T = 75    Fidelity = 0.93168325
# T = 100   Fidelity = 0.95679041
# T = 125   Fidelity = 0.97131331
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99353910
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.89731351
# T = 2     Fidelity = 0.95288106
# T = 5     Fidelity = 0.98564180
#
# Minimum T for Fidelity >= 0.97 : 5
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.31621635e+00
# T = 1     Fidelity = 0.10117502
# T = 2     Fidelity = 0.29791019
# T = 5     Fidelity = 0.80745062
# T = 10    Fidelity = 0.99304308
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.40805723e+00
# T = 1     Fidelity = 0.13216950
# T = 2     Fidelity = 0.38016967
# T = 5     Fidelity = 0.80799948
# T = 10    Fidelity = 0.92195183
# T = 20    Fidelity = 0.99606089
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.23643323
# T = 2     Fidelity = 0.53324492
# T = 5     Fidelity = 0.91876993
# T = 10    Fidelity = 0.98335540
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.30517022
# T = 2     Fidelity = 0.59262854
# T = 5     Fidelity = 0.91535853
# T = 10    Fidelity = 0.98235546
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.36143976
# T = 2     Fidelity = 0.63555346
# T = 5     Fidelity = 0.93292583
# T = 10    Fidelity = 0.98451162
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.40210794
# T = 2     Fidelity = 0.65995297
# T = 5     Fidelity = 0.93961977
# T = 10    Fidelity = 0.98309209
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.44001777
# T = 2     Fidelity = 0.68178924
# T = 5     Fidelity = 0.94425383
# T = 10    Fidelity = 0.98198098
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.47121417
# T = 2     Fidelity = 0.69838741
# T = 5     Fidelity = 0.94927762
# T = 10    Fidelity = 0.98137002
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     400       0.9788028467      3.07240439e-04    None        None        None
# Symmetric      0.311     150       0.9761667823      1.17908351e-06    None        None        None
# Symmetric      0.522     100       0.9878113969      2.94880927e-07    None        None        None
# Symmetric      0.733     75        0.9804669886      1.58119042e-07    None        None        None
# Symmetric      0.944     50        0.9700946202      6.89654440e-08    None        None        None
# Symmetric      1.156     40        0.9861293210      1.17592579e-07    None        None        None
# Symmetric      1.367     30        0.9719794132      2.47961090e-07    None        None        None
# Symmetric      1.578     40        0.9838859539      3.56990601e-07    None        None        None
# Symmetric      1.789     40        0.9938355651      2.45005900e-06    None        None        None
# Symmetric      2.000     30        0.9840019219      1.44257094e-05    None        None        None
# Weak SSB       0.100     75        0.9821445434      1.80997252e-02    None        None        None
# Weak SSB       0.311     1060      0.9710118401      1.50638569e-02    None        None        None
# Weak SSB       0.522     None      0.5085650988      1.29389510e-04    0.474622    0.008938    0.48356
# Weak SSB       0.733     None      0.4512311332      1.10289833e-04    0.313752    0.165696    0.479448
# Weak SSB       0.944     None      0.4687841808      1.04207670e-04    0.446499    0.38086     0.827358
# Weak SSB       1.156     None      0.5053037639      1.00641152e-04    0.505304    0.485947    0.991251
# Weak SSB       1.367     None      0.5104794386      9.79040346e-05    0.401288    0.381929    0.783217
# Weak SSB       1.578     None      0.5086368643      9.56243266e-05    0.508637    0.477737    0.986373
# Weak SSB       1.789     None      0.5195293714      9.37092431e-05    0.506848    0.46        0.966848
# Weak SSB       2.000     None      0.5666262203      9.20598135e-05    0.562578    0.420252    0.98283
# Weak SSB optimised0.100     125       0.9738319365      8.67181393e-01    None        None        None
# Weak SSB optimised0.311     200       0.9723067401      5.19764834e-01    None        None        None
# Weak SSB optimised0.522     20        0.9932413851      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     20        0.9991329367      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     20        0.9942257815      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     20        0.9718592453      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9716909644      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     200       0.9721675941      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     175       0.9725296407      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     125       0.9713133092      2.48783584e-01    None        None        None
# Strong SSB     0.100     1         0.9935390978      3.59472102e+00    None        None        None
# Strong SSB     0.311     5         0.9856417955      1.58498916e+00    None        None        None
# Strong SSB     0.522     10        0.9930430779      1.31621635e+00    None        None        None
# Strong SSB     0.733     20        0.9960608949      1.40805723e+00    None        None        None
# Strong SSB     0.944     10        0.9833554049      1.38481786e+00    None        None        None
# Strong SSB     1.156     10        0.9823554624      1.34302163e+00    None        None        None
# Strong SSB     1.367     10        0.9845116204      1.29217279e+00    None        None        None
# Strong SSB     1.578     10        0.9830920908      1.23335459e+00    None        None        None
# Strong SSB     1.789     10        0.9819809751      1.17426012e+00    None        None        None
# Strong SSB     2.000     10        0.9813700242      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.1556
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7333

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimized')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, m_{0}^{2}=-2.0')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_vqe = match['psi_vqe']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_vqe,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)




lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym, dM_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak, dM_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong, dM_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimized'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimized'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
