# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # -------------------------------------------------------- 

 
    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756936
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
nq_site = 4

nqubits = 2 * nq_site

mu = 1.0

layers = 8


# ============================================================
# Parameter sets
# ============================================================

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
     {
        "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1*1e-5
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ============================================================
# Lambda scan
# ============================================================

lambda_list = np.linspace(0.1, 2.0, 10)

# ============================================================
# Storage
# ============================================================

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]
    mI2   = params["mI2"]
    f     = params["f"]

    case_results = []

    # Loop over lambda
    for lam in lambda_list:

        Hloc_sparse = two_site_hloc(
            nq=nq_site,
            mu=mu,
            mI2=mI2,
            lam=lam,
            f=f
        )

        E_exact, psi_exact = exact_ground_state(Hloc_sparse)

        data = {
            'case': label,
            'lambda': lam,
            'mI2': mI2,
            'f': f,
            'E_exact': E_exact,
            'psi_exact': psi_exact
        }

        case_results.append(data)
        all_results.append(data)

    # Print summary
    print("\n")
    print("="*60)
    print(f"SUMMARY : {label}")
    print("="*60)

    print(f"{'lambda':<12}{'Exact E':<20}")

    for r in case_results:

        print(
            f"{r['lambda']:<12.4f}"
            f"{r['E_exact']:<20.10f}"
        )
# Out:
# ============================================================
# SUMMARY : Symmetric
# ============================================================
# lambda      Exact E
# 0.1000      1.0061617282
# 0.3111      1.0186414273
# 0.5222      1.0304993098
# 0.7333      1.0418243223
# 0.9444      1.0526845438
# 1.1556      1.0631337888
# 1.3667      1.0732156538
# 1.5778      1.0829661518
# 1.7889      1.0924155081
# 2.0000      1.1015894287
#
#
# ============================================================
# SUMMARY : Weak SSB
# ============================================================
# lambda      Exact E
# 0.1000      -16.9439021700
# 0.3111      -8.8920687208
# 0.5222      -4.3791138564
# 0.7333      -2.7497933966
# 0.9444      -1.8747006662
# 1.1556      -1.3488216133
# 1.3667      -1.0104394812
# 1.5778      -0.7791397794
# 1.7889      -0.6117233701
# 2.0000      -0.4842953858
#
#
# ============================================================
# SUMMARY : Weak SSB optimised
# ============================================================
# lambda      Exact E
# 0.1000      -17.0646933519
# 0.3111      -9.0804499123
# 0.5222      -4.7011949726
# 0.7333      -3.0115313516
# 0.9444      -2.0835657235
# 1.1556      -1.5044878727
# 1.3667      -1.1190997304
# 1.5778      -0.8533320540
# 1.7889      -0.6635601415
# 2.0000      -0.5221397643
#
#
# ============================================================
# SUMMARY : Strong SSB
# ============================================================
# lambda      Exact E
# 0.1000      -20.7773284453
# 0.3111      -12.8364411428
# 0.5222      -7.7307163648
# 0.7333      -5.5381488307
# 0.9444      -4.2760137929
# 1.1556      -3.4486803854
# 1.3667      -2.8608322652
# 1.5778      -2.4200905293
# 1.7889      -2.0763125676
# 2.0000      -1.8000732662

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================
#from qiskit.quantum_info import Statevector
def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    

    dt = T / nsteps

    # Initial state is already a NumPy vector
    psi = initial_state.copy()

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # Matrix-vector multiplication
        psi = U @ psi

    return psi

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

def fidelity(psi1, psi2):

    #Fidelity between two pure state vectors.
    
    return np.abs(np.vdot(psi1, psi2))**2


# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_exact = data['psi_exact']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

#    P0 = None
#    P1 = None
 #   P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

#        P0 = np.abs(np.vdot(psi0, psi_T))**2
#        P1 = np.abs(np.vdot(psi1, psi_T))**2
 #       P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
#        print(f"P0     = {P0:.8f}")
#        print(f"P1     = {P1:.8f}")
#        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

#        'P0': P0,
#        'P1': P1,
#        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
#    f"{'P0':<12}"
#    f"{'P1':<12}"
#    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
#        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
#        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
#        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119774
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.02934439e+00
# T = 1     Fidelity = 0.98268039
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.04790824e+00
# T = 1     Fidelity = 0.98394512
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.06556366e+00
# T = 1     Fidelity = 0.98504182
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.08242773e+00
# T = 1     Fidelity = 0.98600497
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.09859358e+00
# T = 1     Fidelity = 0.98685949
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.11413694e+00
# T = 1     Fidelity = 0.98762402
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.12912045e+00
# T = 1     Fidelity = 0.98831288
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.14359670e+00
# T = 1     Fidelity = 0.98893734
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98950639
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.13498607e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00063686
# T = 10    Fidelity = 0.00011405
# T = 20    Fidelity = 0.00399918
# T = 30    Fidelity = 0.05554960
# T = 40    Fidelity = 0.12243128
# T = 50    Fidelity = 0.21148331
# T = 75    Fidelity = 0.58062444
# T = 100   Fidelity = 0.76538421
# T = 125   Fidelity = 0.73560373
# T = 150   Fidelity = 0.86961537
# T = 175   Fidelity = 0.91395123
# T = 200   Fidelity = 0.87536588
# T = 225   Fidelity = 0.95254304
# T = 250   Fidelity = 0.98643370
#
# Minimum T for Fidelity >= 0.97 : 250
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.22564919e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00018126
# T = 10    Fidelity = 0.04089578
# T = 20    Fidelity = 0.42105279
# T = 30    Fidelity = 0.49016683
# T = 40    Fidelity = 0.64152560
# T = 50    Fidelity = 0.64405809
# T = 75    Fidelity = 0.88099003
# T = 100   Fidelity = 0.90198422
# T = 125   Fidelity = 0.87189939
# T = 150   Fidelity = 0.88628991
# T = 175   Fidelity = 0.92112073
# T = 200   Fidelity = 0.94264423
# T = 225   Fidelity = 0.95691717
# T = 250   Fidelity = 0.95093619
# T = 275   Fidelity = 0.96232337
# T = 300   Fidelity = 0.94452043
# T = 400   Fidelity = 0.98186410
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.14483174e-04
# T = 1     Fidelity = 0.00001188
# T = 2     Fidelity = 0.00016912
# T = 5     Fidelity = 0.01433467
# T = 10    Fidelity = 0.17107594
# T = 20    Fidelity = 0.44260423
# T = 30    Fidelity = 0.34018269
# T = 40    Fidelity = 0.54697878
# T = 50    Fidelity = 0.43888805
# T = 75    Fidelity = 0.49360020
# T = 100   Fidelity = 0.50315925
# T = 125   Fidelity = 0.50308618
# T = 150   Fidelity = 0.50222753
# T = 175   Fidelity = 0.50144321
# T = 200   Fidelity = 0.49701799
# T = 225   Fidelity = 0.50876069
# T = 250   Fidelity = 0.50139197
# T = 275   Fidelity = 0.48755462
# T = 300   Fidelity = 0.48763111
# T = 400   Fidelity = 0.49871437
# T = 500   Fidelity = 0.31002117
# T = 600   Fidelity = 0.51084701
# T = 700   Fidelity = 0.39154240
# T = 800   Fidelity = 0.53868216
# T = 900   Fidelity = 0.53609933
# T = 1000  Fidelity = 0.70761905
# T = 1010  Fidelity = 0.40394459
# T = 1020  Fidelity = 0.40818374
# T = 1030  Fidelity = 0.47805101
# T = 1040  Fidelity = 0.50619696
# T = 1050  Fidelity = 0.47559012
# T = 1060  Fidelity = 0.37552320
# T = 1070  Fidelity = 0.56995205
# T = 1080  Fidelity = 0.27368445
# T = 1090  Fidelity = 0.28204647
# T = 1100  Fidelity = 0.62046805
# T = 1200  Fidelity = 0.29939713
# T = 1300  Fidelity = 0.56553188
# T = 1400  Fidelity = 0.55231987
# T = 1500  Fidelity = 0.37879942
# T = 2000  Fidelity = 0.31534701
# T = 2100  Fidelity = 0.22351069
# T = 2110  Fidelity = 0.58886135
# T = 2120  Fidelity = 0.50720666
# T = 2130  Fidelity = 0.53885092
# T = 2140  Fidelity = 0.35543213
# T = 2150  Fidelity = 0.48241384
# T = 2160  Fidelity = 0.42059660
# T = 2170  Fidelity = 0.42381315
# T = 2180  Fidelity = 0.56995957
# T = 2190  Fidelity = 0.21740451
# T = 2200  Fidelity = 0.51754314
# T = 2300  Fidelity = 0.57510682
# T = 2400  Fidelity = 0.53687610
# T = 2500  Fidelity = 0.50407220
# T = 2600  Fidelity = 0.51089382
# T = 2700  Fidelity = 0.63521213
# T = 2800  Fidelity = 0.66491526
# T = 2900  Fidelity = 0.52322443
# T = 3000  Fidelity = 0.49589036
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.04785498e+00
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.21982966e-04
# T = 1     Fidelity = 0.00307203
# T = 2     Fidelity = 0.01239142
# T = 5     Fidelity = 0.08439417
# T = 10    Fidelity = 0.22347343
# T = 20    Fidelity = 0.31777523
# T = 30    Fidelity = 0.38307737
# T = 40    Fidelity = 0.54976874
# T = 50    Fidelity = 0.58075309
# T = 75    Fidelity = 0.50038760
# T = 100   Fidelity = 0.52178438
# T = 125   Fidelity = 0.52337798
# T = 150   Fidelity = 0.52320757
# T = 175   Fidelity = 0.52001363
# T = 200   Fidelity = 0.53035306
# T = 225   Fidelity = 0.52294121
# T = 250   Fidelity = 0.51832358
# T = 275   Fidelity = 0.52662562
# T = 300   Fidelity = 0.49519034
# T = 400   Fidelity = 0.51004928
# T = 500   Fidelity = 0.55446170
# T = 600   Fidelity = 0.50915332
# T = 700   Fidelity = 0.44383217
# T = 800   Fidelity = 0.45445985
# T = 900   Fidelity = 0.53561726
# T = 1000  Fidelity = 0.78106830
# T = 1010  Fidelity = 0.44826463
# T = 1020  Fidelity = 0.12730037
# T = 1030  Fidelity = 0.56292020
# T = 1040  Fidelity = 0.79510172
# T = 1050  Fidelity = 0.59785934
# T = 1060  Fidelity = 0.48948307
# T = 1070  Fidelity = 0.50199185
# T = 1080  Fidelity = 0.42480194
# T = 1090  Fidelity = 0.25699652
# T = 1100  Fidelity = 0.74489617
# T = 1200  Fidelity = 0.58973186
# T = 1300  Fidelity = 0.45973828
# T = 1400  Fidelity = 0.52942064
# T = 1500  Fidelity = 0.54448493
# T = 2000  Fidelity = 0.46794154
# T = 2100  Fidelity = 0.53042813
# T = 2110  Fidelity = 0.56813284
# T = 2120  Fidelity = 0.48130759
# T = 2130  Fidelity = 0.40464212
# T = 2140  Fidelity = 0.57406285
# T = 2150  Fidelity = 0.78519578
# T = 2160  Fidelity = 0.45190844
# T = 2170  Fidelity = 0.25314526
# T = 2180  Fidelity = 0.50761625
# T = 2190  Fidelity = 0.70354352
# T = 2200  Fidelity = 0.63133635
# T = 2300  Fidelity = 0.83241753
# T = 2400  Fidelity = 0.55108113
# T = 2500  Fidelity = 0.52136187
# T = 2600  Fidelity = 0.57283296
# T = 2700  Fidelity = 0.46752512
# T = 2800  Fidelity = 0.55987469
# T = 2900  Fidelity = 0.32450436
# T = 3000  Fidelity = 0.46084674
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.06549312e+00
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 4.33063144e-03
# T = 1     Fidelity = 0.02405073
# T = 2     Fidelity = 0.06514982
# T = 5     Fidelity = 0.21903355
# T = 10    Fidelity = 0.40682284
# T = 20    Fidelity = 0.52935066
# T = 30    Fidelity = 0.49787351
# T = 40    Fidelity = 0.50387945
# T = 50    Fidelity = 0.54928947
# T = 75    Fidelity = 0.60866508
# T = 100   Fidelity = 0.60707924
# T = 125   Fidelity = 0.61208914
# T = 150   Fidelity = 0.61606763
# T = 175   Fidelity = 0.61942519
# T = 200   Fidelity = 0.62646601
# T = 225   Fidelity = 0.62931022
# T = 250   Fidelity = 0.63308148
# T = 275   Fidelity = 0.62996826
# T = 300   Fidelity = 0.64621237
# T = 400   Fidelity = 0.59413547
# T = 500   Fidelity = 0.65374647
# T = 600   Fidelity = 0.67757800
# T = 700   Fidelity = 0.59512867
# T = 800   Fidelity = 0.71411180
# T = 900   Fidelity = 0.60951803
# T = 1000  Fidelity = 0.48797695
# T = 1010  Fidelity = 0.76101922
# T = 1020  Fidelity = 0.85265950
# T = 1030  Fidelity = 0.75201993
# T = 1040  Fidelity = 0.53081286
# T = 1050  Fidelity = 0.47570359
# T = 1060  Fidelity = 0.65097075
# T = 1070  Fidelity = 0.77849334
# T = 1080  Fidelity = 0.82290595
# T = 1090  Fidelity = 0.55787525
# T = 1100  Fidelity = 0.40191276
# T = 1200  Fidelity = 0.46099083
# T = 1300  Fidelity = 0.54243051
# T = 1400  Fidelity = 0.77145675
# T = 1500  Fidelity = 0.68258337
# T = 2000  Fidelity = 0.77618412
# T = 2100  Fidelity = 0.82190454
# T = 2110  Fidelity = 0.81253125
# T = 2120  Fidelity = 0.55445819
# T = 2130  Fidelity = 0.65794020
# T = 2140  Fidelity = 0.71478635
# T = 2150  Fidelity = 0.83413402
# T = 2160  Fidelity = 0.84964442
# T = 2170  Fidelity = 0.78545420
# T = 2180  Fidelity = 0.53549075
# T = 2190  Fidelity = 0.57232669
# T = 2200  Fidelity = 0.70210794
# T = 2300  Fidelity = 0.77092866
# T = 2400  Fidelity = 0.75747932
# T = 2500  Fidelity = 0.83049031
# T = 2600  Fidelity = 0.73449745
# T = 2700  Fidelity = 0.78133075
# T = 2800  Fidelity = 0.76631546
# T = 2900  Fidelity = 0.70213540
# T = 3000  Fidelity = 0.75466237
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.08234168e+00
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.50115281e-02
# T = 1     Fidelity = 0.08269294
# T = 2     Fidelity = 0.17488023
# T = 5     Fidelity = 0.39234243
# T = 10    Fidelity = 0.58593923
# T = 20    Fidelity = 0.71389228
# T = 30    Fidelity = 0.72027243
# T = 40    Fidelity = 0.71303106
# T = 50    Fidelity = 0.71876345
# T = 75    Fidelity = 0.74412847
# T = 100   Fidelity = 0.76245830
# T = 125   Fidelity = 0.77527547
# T = 150   Fidelity = 0.78587198
# T = 175   Fidelity = 0.79500688
# T = 200   Fidelity = 0.80419188
# T = 225   Fidelity = 0.81045964
# T = 250   Fidelity = 0.81599227
# T = 275   Fidelity = 0.82617594
# T = 300   Fidelity = 0.81747410
# T = 400   Fidelity = 0.87422346
# T = 500   Fidelity = 0.87059833
# T = 600   Fidelity = 0.79407621
# T = 700   Fidelity = 0.82786134
# T = 800   Fidelity = 0.84471937
# T = 900   Fidelity = 0.85229383
# T = 1000  Fidelity = 0.87687257
# T = 1010  Fidelity = 0.79393473
# T = 1020  Fidelity = 0.77899389
# T = 1030  Fidelity = 0.86814591
# T = 1040  Fidelity = 0.95158769
# T = 1050  Fidelity = 0.97309029
#
# Minimum T for Fidelity >= 0.97 : 1050
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 6.77198754e-02
# T = 1     Fidelity = 0.17554122
# T = 2     Fidelity = 0.31614598
# T = 5     Fidelity = 0.55528595
# T = 10    Fidelity = 0.72494135
# T = 20    Fidelity = 0.82949608
# T = 30    Fidelity = 0.85313244
# T = 40    Fidelity = 0.85899454
# T = 50    Fidelity = 0.86468366
# T = 75    Fidelity = 0.88210276
# T = 100   Fidelity = 0.89840168
# T = 125   Fidelity = 0.90980490
# T = 150   Fidelity = 0.91811646
# T = 175   Fidelity = 0.92575435
# T = 200   Fidelity = 0.93482984
# T = 225   Fidelity = 0.93591228
# T = 250   Fidelity = 0.93618777
# T = 275   Fidelity = 0.94546103
# T = 300   Fidelity = 0.93550242
# T = 400   Fidelity = 0.94951417
# T = 500   Fidelity = 0.95253423
# T = 600   Fidelity = 0.96025404
# T = 700   Fidelity = 0.91552991
# T = 800   Fidelity = 0.92797074
# T = 900   Fidelity = 0.94695052
# T = 1000  Fidelity = 0.93971419
# T = 1010  Fidelity = 0.95195492
# T = 1020  Fidelity = 0.95694173
# T = 1030  Fidelity = 0.97884321
#
# Minimum T for Fidelity >= 0.97 : 1030
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.20186803e-01
# T = 1     Fidelity = 0.28023389
# T = 2     Fidelity = 0.45269702
# T = 5     Fidelity = 0.68131240
# T = 10    Fidelity = 0.81902718
# T = 20    Fidelity = 0.89648949
# T = 30    Fidelity = 0.91797388
# T = 40    Fidelity = 0.92933988
# T = 50    Fidelity = 0.93801169
# T = 75    Fidelity = 0.95171444
# T = 100   Fidelity = 0.96198491
# T = 125   Fidelity = 0.96840284
# T = 150   Fidelity = 0.97426450
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.71405410e-01
# T = 1     Fidelity = 0.37876795
# T = 2     Fidelity = 0.56653501
# T = 5     Fidelity = 0.77013860
# T = 10    Fidelity = 0.87911701
# T = 20    Fidelity = 0.93531281
# T = 30    Fidelity = 0.95281193
# T = 40    Fidelity = 0.96402524
# T = 50    Fidelity = 0.96970692
# T = 75    Fidelity = 0.97961892
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.18843285e-01
# T = 1     Fidelity = 0.46387812
# T = 2     Fidelity = 0.65548053
# T = 5     Fidelity = 0.83095531
# T = 10    Fidelity = 0.91705359
# T = 20    Fidelity = 0.95852566
# T = 30    Fidelity = 0.97285358
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00038179
# T = 10    Fidelity = 0.00054402
# T = 20    Fidelity = 0.01169811
# T = 30    Fidelity = 0.08028339
# T = 40    Fidelity = 0.18957706
# T = 50    Fidelity = 0.42968446
# T = 75    Fidelity = 0.56797234
# T = 100   Fidelity = 0.72731121
# T = 125   Fidelity = 0.80887444
# T = 150   Fidelity = 0.83744632
# T = 175   Fidelity = 0.90619411
# T = 200   Fidelity = 0.91903801
# T = 225   Fidelity = 0.96741094
# T = 250   Fidelity = 0.89096667
# T = 275   Fidelity = 0.96901882
# T = 300   Fidelity = 0.85591728
# T = 400   Fidelity = 0.98094483
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61171322e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000013
# T = 5     Fidelity = 0.00046694
# T = 10    Fidelity = 0.06863276
# T = 20    Fidelity = 0.22990017
# T = 30    Fidelity = 0.62131518
# T = 40    Fidelity = 0.37863849
# T = 50    Fidelity = 0.79011645
# T = 75    Fidelity = 0.75086731
# T = 100   Fidelity = 0.79898434
# T = 125   Fidelity = 0.87892180
# T = 150   Fidelity = 0.88494475
# T = 175   Fidelity = 0.90346838
# T = 200   Fidelity = 0.92695865
# T = 225   Fidelity = 0.93902326
# T = 250   Fidelity = 0.94745048
# T = 275   Fidelity = 0.95242702
# T = 300   Fidelity = 0.94917513
# T = 400   Fidelity = 0.97112965
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64873214e-01
# T = 1     Fidelity = 0.00003687
# T = 2     Fidelity = 0.00032197
# T = 5     Fidelity = 0.02051174
# T = 10    Fidelity = 0.22193030
# T = 20    Fidelity = 0.58959682
# T = 30    Fidelity = 0.66093676
# T = 40    Fidelity = 0.79035738
# T = 50    Fidelity = 0.82266320
# T = 75    Fidelity = 0.92706186
# T = 100   Fidelity = 0.96749019
# T = 125   Fidelity = 0.98440227
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00115010
# T = 2     Fidelity = 0.00475224
# T = 5     Fidelity = 0.06198055
# T = 10    Fidelity = 0.28435237
# T = 20    Fidelity = 0.68082002
# T = 30    Fidelity = 0.73426015
# T = 40    Fidelity = 0.82199051
# T = 50    Fidelity = 0.88767410
# T = 75    Fidelity = 0.95507801
# T = 100   Fidelity = 0.98257509
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00847599
# T = 2     Fidelity = 0.02332966
# T = 5     Fidelity = 0.12491572
# T = 10    Fidelity = 0.34186521
# T = 20    Fidelity = 0.67169217
# T = 30    Fidelity = 0.79927778
# T = 40    Fidelity = 0.85981077
# T = 50    Fidelity = 0.90969644
# T = 75    Fidelity = 0.97048658
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.03399460
# T = 2     Fidelity = 0.07306297
# T = 5     Fidelity = 0.22208234
# T = 10    Fidelity = 0.42787652
# T = 20    Fidelity = 0.67903770
# T = 30    Fidelity = 0.80139300
# T = 40    Fidelity = 0.87059092
# T = 50    Fidelity = 0.91765911
# T = 75    Fidelity = 0.97836076
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.09422866
# T = 2     Fidelity = 0.17235018
# T = 5     Fidelity = 0.36386315
# T = 10    Fidelity = 0.55477690
# T = 20    Fidelity = 0.74213208
# T = 30    Fidelity = 0.83218854
# T = 40    Fidelity = 0.88460722
# T = 50    Fidelity = 0.91904822
# T = 75    Fidelity = 0.96675306
# T = 100   Fidelity = 0.98534864
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.19070416
# T = 2     Fidelity = 0.31210253
# T = 5     Fidelity = 0.52451239
# T = 10    Fidelity = 0.69127438
# T = 20    Fidelity = 0.82748382
# T = 30    Fidelity = 0.88745951
# T = 40    Fidelity = 0.92203315
# T = 50    Fidelity = 0.94375882
# T = 75    Fidelity = 0.97034804
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.30061289
# T = 2     Fidelity = 0.45422313
# T = 5     Fidelity = 0.66172166
# T = 10    Fidelity = 0.79861037
# T = 20    Fidelity = 0.89474854
# T = 30    Fidelity = 0.93355548
# T = 40    Fidelity = 0.95521640
# T = 50    Fidelity = 0.96728756
# T = 75    Fidelity = 0.98309558
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40211198
# T = 2     Fidelity = 0.57263453
# T = 5     Fidelity = 0.76028096
# T = 10    Fidelity = 0.86904680
# T = 20    Fidelity = 0.93652161
# T = 30    Fidelity = 0.96227353
# T = 40    Fidelity = 0.97439241
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000008
# T = 5     Fidelity = 0.00083241
# T = 10    Fidelity = 0.06385295
# T = 20    Fidelity = 0.45561586
# T = 30    Fidelity = 0.88090302
# T = 40    Fidelity = 0.96753909
# T = 50    Fidelity = 0.99173612
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.22062439e-01
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000202
# T = 5     Fidelity = 0.02493409
# T = 10    Fidelity = 0.89982764
# T = 20    Fidelity = 0.96738028
# T = 30    Fidelity = 0.99647052
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.78318602e-01
# T = 1     Fidelity = 0.00005264
# T = 2     Fidelity = 0.00078888
# T = 5     Fidelity = 0.18908022
# T = 10    Fidelity = 0.98848968
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.15979742e-01
# T = 1     Fidelity = 0.00123901
# T = 2     Fidelity = 0.00812919
# T = 5     Fidelity = 0.34556214
# T = 10    Fidelity = 0.98665822
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.44059983e-01
# T = 1     Fidelity = 0.00700299
# T = 2     Fidelity = 0.02898396
# T = 5     Fidelity = 0.47055191
# T = 10    Fidelity = 0.98169208
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.66317759e-01
# T = 1     Fidelity = 0.02078392
# T = 2     Fidelity = 0.06415831
# T = 5     Fidelity = 0.56546436
# T = 10    Fidelity = 0.97652975
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.84605280e-01
# T = 1     Fidelity = 0.04383625
# T = 2     Fidelity = 0.11049490
# T = 5     Fidelity = 0.63870644
# T = 10    Fidelity = 0.97242241
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.99986623e-01
# T = 1     Fidelity = 0.07536581
# T = 2     Fidelity = 0.16385492
# T = 5     Fidelity = 0.69636412
# T = 10    Fidelity = 0.96948603
# T = 20    Fidelity = 0.99321901
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.13089337e-01
# T = 1     Fidelity = 0.11363954
# T = 2     Fidelity = 0.22080980
# T = 5     Fidelity = 0.74291146
# T = 10    Fidelity = 0.96781240
# T = 20    Fidelity = 0.99358654
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.24370129e-01
# T = 1     Fidelity = 0.15668612
# T = 2     Fidelity = 0.27880488
# T = 5     Fidelity = 0.78126728
# T = 10    Fidelity = 0.96730973
# T = 20    Fidelity = 0.99389702
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min
# ====================================================================================================================================================================================
# Symmetric      0.100     1         0.9811977442      1.00972087e+00
# Symmetric      0.311     1         0.9826803920      1.02934439e+00
# Symmetric      0.522     1         0.9839451208      1.04790824e+00
# Symmetric      0.733     1         0.9850418234      1.06556366e+00
# Symmetric      0.944     1         0.9860049719      1.08242773e+00
# Symmetric      1.156     1         0.9868594879      1.09859358e+00
# Symmetric      1.367     1         0.9876240151      1.11413694e+00
# Symmetric      1.578     1         0.9883128808      1.12912045e+00
# Symmetric      1.789     1         0.9889373380      1.14359670e+00
# Symmetric      2.000     1         0.9895063874      1.15761039e+00
# Weak SSB       0.100     250       0.9864336987      3.13498607e-04
# Weak SSB       0.311     400       0.9818640982      1.22564919e-04
# Weak SSB       0.522     None      0.7076190488      1.14483174e-04
# Weak SSB       0.733     None      0.8324175326      2.21982966e-04
# Weak SSB       0.944     None      0.8526594987      4.33063144e-03
# Weak SSB       1.156     1050      0.9730902939      2.50115281e-02
# Weak SSB       1.367     1030      0.9788432126      6.77198754e-02
# Weak SSB       1.578     150       0.9742644971      1.20186803e-01
# Weak SSB       1.789     75        0.9796189152      1.71405410e-01
# Weak SSB       2.000     30        0.9728535767      2.18843285e-01
# Weak SSB optimised0.100     400       0.9809448341      2.42819099e-01
# Weak SSB optimised0.311     400       0.9711296517      2.61171322e-01
# Weak SSB optimised0.522     125       0.9844022720      2.64873214e-01
# Weak SSB optimised0.733     100       0.9825750878      2.64154074e-01
# Weak SSB optimised0.944     75        0.9704865819      2.26024680e-01
# Weak SSB optimised1.156     75        0.9783607595      2.01656789e-01
# Weak SSB optimised1.367     100       0.9853486380      1.93673930e-01
# Weak SSB optimised1.578     75        0.9703480358      2.03071995e-01
# Weak SSB optimised1.789     75        0.9830955813      2.25515049e-01
# Weak SSB optimised2.000     40        0.9743924077      2.55131735e-01
# Strong SSB     0.100     50        0.9917361242      6.07266718e-01
# Strong SSB     0.311     30        0.9964705179      7.22062439e-01
# Strong SSB     0.522     10        0.9884896779      7.78318602e-01
# Strong SSB     0.733     10        0.9866582207      8.15979742e-01
# Strong SSB     0.944     10        0.9816920846      8.44059983e-01
# Strong SSB     1.156     10        0.9765297519      8.66317759e-01
# Strong SSB     1.367     10        0.9724224064      8.84605280e-01
# Strong SSB     1.578     20        0.9932190118      8.99986623e-01
# Strong SSB     1.789     20        0.9935865420      9.13089337e-01
# Strong SSB     2.000     20        0.9938970179      9.24370129e-01

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        color=case_colors[case],
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=1$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color="blue")

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color="green")

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB', color="red")

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []

for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

   # Exact ground state of H_loc
    psi_exact = match['psi_exact']

# Adiabatic evolution starts from the exact local ground state
    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)

    elif case == "Strong SSB":

        M_strong.append(M)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_list)

dM_weak = np.gradient(M_weak_opt, lambda_list)

dM_strong = np.gradient(M_strong, lambda_list)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_list)

d2M_weak = np.gradient(dM_weak, lambda_list)

d2M_strong = np.gradient(dM_strong, lambda_list)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_list)

d3M_weak = np.gradient(d2M_weak, lambda_list)

d3M_strong = np.gradient(d2M_strong, lambda_list)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_list,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_list,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_list,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_list,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='blue'
)
line2, = plt.plot(
    lambda_list,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='green'
)

line3, = plt.plot(
    lambda_list,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='red'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_list,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_list,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_list,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_list,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_list,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_list,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_0^2=1$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Starting of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_exact = data['psi_exact']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96521661
# T = 2     Fidelity = 0.99334594
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.03626623e+00
# T = 1     Fidelity = 0.96805918
# T = 2     Fidelity = 0.99422130
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.05846299e+00
# T = 1     Fidelity = 0.97048938
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07916278e+00
# T = 1     Fidelity = 0.97259833
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.09862393e+00
# T = 1     Fidelity = 0.97445011
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.11703633e+00
# T = 1     Fidelity = 0.97609169
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.13454489e+00
# T = 1     Fidelity = 0.97755854
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.15126343e+00
# T = 1     Fidelity = 0.97887816
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.16728342e+00
# T = 1     Fidelity = 0.98007228
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98115836
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 4.00578748e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000117
# T = 10    Fidelity = 0.00113918
# T = 20    Fidelity = 0.00651178
# T = 30    Fidelity = 0.02774047
# T = 40    Fidelity = 0.11882923
# T = 50    Fidelity = 0.09123430
# T = 75    Fidelity = 0.30336972
# T = 100   Fidelity = 0.53477163
# T = 125   Fidelity = 0.55347568
# T = 150   Fidelity = 0.69280860
# T = 175   Fidelity = 0.80350088
# T = 200   Fidelity = 0.78797904
# T = 225   Fidelity = 0.85589625
# T = 250   Fidelity = 0.93722543
# T = 275   Fidelity = 0.73999732
# T = 300   Fidelity = 0.74411320
# T = 400   Fidelity = 0.95738805
# T = 500   Fidelity = 0.95445722
# T = 600   Fidelity = 0.97119964
#
# Minimum T for Fidelity >= 0.97 : 600
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.22897118e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00000707
# T = 10    Fidelity = 0.00112683
# T = 20    Fidelity = 0.19601745
# T = 30    Fidelity = 0.53161878
# T = 40    Fidelity = 0.08246453
# T = 50    Fidelity = 0.71286928
# T = 75    Fidelity = 0.50823255
# T = 100   Fidelity = 0.68276397
# T = 125   Fidelity = 0.91765618
# T = 150   Fidelity = 0.91767332
# T = 175   Fidelity = 0.86918936
# T = 200   Fidelity = 0.91409858
# T = 225   Fidelity = 0.95403028
# T = 250   Fidelity = 0.95386516
# T = 275   Fidelity = 0.94304176
# T = 300   Fidelity = 0.97007200
#
# Minimum T for Fidelity >= 0.97 : 300
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.15176142e-04
# T = 1     Fidelity = 0.00000157
# T = 2     Fidelity = 0.00007289
# T = 5     Fidelity = 0.00176167
# T = 10    Fidelity = 0.03348163
# T = 20    Fidelity = 0.35749534
# T = 30    Fidelity = 0.61389147
# T = 40    Fidelity = 0.36335937
# T = 50    Fidelity = 0.26451590
# T = 75    Fidelity = 0.57915849
# T = 100   Fidelity = 0.44193926
# T = 125   Fidelity = 0.52885532
# T = 150   Fidelity = 0.48177293
# T = 175   Fidelity = 0.50046800
# T = 200   Fidelity = 0.47691571
# T = 225   Fidelity = 0.51554267
# T = 250   Fidelity = 0.48982206
# T = 275   Fidelity = 0.48740863
# T = 300   Fidelity = 0.51261527
# T = 400   Fidelity = 0.50878211
# T = 500   Fidelity = 0.43396174
# T = 600   Fidelity = 0.40062020
# T = 700   Fidelity = 0.27978802
# T = 800   Fidelity = 0.29766755
# T = 900   Fidelity = 0.51006981
# T = 1000  Fidelity = 0.43728367
# T = 1010  Fidelity = 0.28622803
# T = 1020  Fidelity = 0.60526600
# T = 1030  Fidelity = 0.79038965
# T = 1040  Fidelity = 0.62315971
# T = 1050  Fidelity = 0.06913469
# T = 1060  Fidelity = 0.22457351
# T = 1070  Fidelity = 0.62150166
# T = 1080  Fidelity = 0.79823789
# T = 1090  Fidelity = 0.48683623
# T = 1100  Fidelity = 0.20062241
# T = 1200  Fidelity = 0.81450806
# T = 1300  Fidelity = 0.45109923
# T = 1400  Fidelity = 0.23003099
# T = 1500  Fidelity = 0.29341645
# T = 2000  Fidelity = 0.44775831
# T = 2100  Fidelity = 0.18203574
# T = 2110  Fidelity = 0.25711196
# T = 2120  Fidelity = 0.49570190
# T = 2130  Fidelity = 0.55641295
# T = 2140  Fidelity = 0.47112473
# T = 2150  Fidelity = 0.18537437
# T = 2160  Fidelity = 0.38798812
# T = 2170  Fidelity = 0.75532973
# T = 2180  Fidelity = 0.71382018
# T = 2190  Fidelity = 0.43379405
# T = 2200  Fidelity = 0.21285146
# T = 2300  Fidelity = 0.55665722
# T = 2400  Fidelity = 0.72367045
# T = 2500  Fidelity = 0.74610335
# T = 2600  Fidelity = 0.63180330
# T = 2700  Fidelity = 0.59240595
# T = 2800  Fidelity = 0.61784845
# T = 2900  Fidelity = 0.24967480
# T = 3000  Fidelity = 0.44695589
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.44121779e+00
# P0     = 0.44695589
# P1     = 0.00264421
# P0+P1  = 0.44960010
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.97449186e-04
# T = 1     Fidelity = 0.00181000
# T = 2     Fidelity = 0.00875738
# T = 5     Fidelity = 0.04031576
# T = 10    Fidelity = 0.14626815
# T = 20    Fidelity = 0.35534907
# T = 30    Fidelity = 0.38160613
# T = 40    Fidelity = 0.32523934
# T = 50    Fidelity = 0.32608233
# T = 75    Fidelity = 0.55886225
# T = 100   Fidelity = 0.56004293
# T = 125   Fidelity = 0.50583577
# T = 150   Fidelity = 0.52362907
# T = 175   Fidelity = 0.52818773
# T = 200   Fidelity = 0.52078652
# T = 225   Fidelity = 0.49582382
# T = 250   Fidelity = 0.49592014
# T = 275   Fidelity = 0.49769173
# T = 300   Fidelity = 0.48324201
# T = 400   Fidelity = 0.51272406
# T = 500   Fidelity = 0.50217333
# T = 600   Fidelity = 0.56042188
# T = 700   Fidelity = 0.53778337
# T = 800   Fidelity = 0.58941559
# T = 900   Fidelity = 0.65962698
# T = 1000  Fidelity = 0.63818116
# T = 1010  Fidelity = 0.55701942
# T = 1020  Fidelity = 0.51471620
# T = 1030  Fidelity = 0.29785842
# T = 1040  Fidelity = 0.13406648
# T = 1050  Fidelity = 0.32344132
# T = 1060  Fidelity = 0.53532831
# T = 1070  Fidelity = 0.81668528
# T = 1080  Fidelity = 0.83971884
# T = 1090  Fidelity = 0.63609824
# T = 1100  Fidelity = 0.58582092
# T = 1200  Fidelity = 0.83344139
# T = 1300  Fidelity = 0.72307489
# T = 1400  Fidelity = 0.48871858
# T = 1500  Fidelity = 0.65460280
# T = 2000  Fidelity = 0.46961452
# T = 2100  Fidelity = 0.48260009
# T = 2110  Fidelity = 0.17032073
# T = 2120  Fidelity = 0.20065090
# T = 2130  Fidelity = 0.35912599
# T = 2140  Fidelity = 0.49735605
# T = 2150  Fidelity = 0.43210930
# T = 2160  Fidelity = 0.57699733
# T = 2170  Fidelity = 0.52308947
# T = 2180  Fidelity = 0.64962941
# T = 2190  Fidelity = 0.61669565
# T = 2200  Fidelity = 0.67243233
# T = 2300  Fidelity = 0.58717355
# T = 2400  Fidelity = 0.35444674
# T = 2500  Fidelity = 0.72792141
# T = 2600  Fidelity = 0.69670450
# T = 2700  Fidelity = 0.69288112
# T = 2800  Fidelity = 0.61875329
# T = 2900  Fidelity = 0.40630440
# T = 3000  Fidelity = 0.41961657
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.45168821e+00
# P0     = 0.41961657
# P1     = 0.00012834
# P0+P1  = 0.41974491
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 5.82831771e-03
# T = 1     Fidelity = 0.01683324
# T = 2     Fidelity = 0.05152055
# T = 5     Fidelity = 0.13905898
# T = 10    Fidelity = 0.31436748
# T = 20    Fidelity = 0.55037432
# T = 30    Fidelity = 0.62703472
# T = 40    Fidelity = 0.61105073
# T = 50    Fidelity = 0.57957276
# T = 75    Fidelity = 0.55888537
# T = 100   Fidelity = 0.60022948
# T = 125   Fidelity = 0.62829684
# T = 150   Fidelity = 0.63563582
# T = 175   Fidelity = 0.64419838
# T = 200   Fidelity = 0.64401764
# T = 225   Fidelity = 0.67554171
# T = 250   Fidelity = 0.68045168
# T = 275   Fidelity = 0.67208530
# T = 300   Fidelity = 0.68412163
# T = 400   Fidelity = 0.70747226
# T = 500   Fidelity = 0.60556222
# T = 600   Fidelity = 0.55954777
# T = 700   Fidelity = 0.72648106
# T = 800   Fidelity = 0.76657890
# T = 900   Fidelity = 0.58858575
# T = 1000  Fidelity = 0.64522176
# T = 1010  Fidelity = 0.71553851
# T = 1020  Fidelity = 0.81918002
# T = 1030  Fidelity = 0.82775342
# T = 1040  Fidelity = 0.75676939
# T = 1050  Fidelity = 0.67595925
# T = 1060  Fidelity = 0.62818506
# T = 1070  Fidelity = 0.53898303
# T = 1080  Fidelity = 0.48086277
# T = 1090  Fidelity = 0.56581807
# T = 1100  Fidelity = 0.67685089
# T = 1200  Fidelity = 0.52333346
# T = 1300  Fidelity = 0.67936518
# T = 1400  Fidelity = 0.73933539
# T = 1500  Fidelity = 0.85199919
# T = 2000  Fidelity = 0.80653946
# T = 2100  Fidelity = 0.68861536
# T = 2110  Fidelity = 0.69422182
# T = 2120  Fidelity = 0.61761311
# T = 2130  Fidelity = 0.63540744
# T = 2140  Fidelity = 0.68614767
# T = 2150  Fidelity = 0.87177603
# T = 2160  Fidelity = 0.87508212
# T = 2170  Fidelity = 0.85717919
# T = 2180  Fidelity = 0.77024037
# T = 2190  Fidelity = 0.63713756
# T = 2200  Fidelity = 0.64002543
# T = 2300  Fidelity = 0.66673658
# T = 2400  Fidelity = 0.71886821
# T = 2500  Fidelity = 0.78836173
# T = 2600  Fidelity = 0.40556425
# T = 2700  Fidelity = 0.82471934
# T = 2800  Fidelity = 0.60773072
# T = 2900  Fidelity = 0.72547767
# T = 3000  Fidelity = 0.81926652
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.46192674e+00
# P0     = 0.81926652
# P1     = 0.00001634
# P0+P1  = 0.81928286
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 3.15665395e-02
# T = 1     Fidelity = 0.06375851
# T = 2     Fidelity = 0.14777200
# T = 5     Fidelity = 0.29256795
# T = 10    Fidelity = 0.49856202
# T = 20    Fidelity = 0.70650367
# T = 30    Fidelity = 0.78192280
# T = 40    Fidelity = 0.79737739
# T = 50    Fidelity = 0.79506444
# T = 75    Fidelity = 0.78966607
# T = 100   Fidelity = 0.79656687
# T = 125   Fidelity = 0.80624738
# T = 150   Fidelity = 0.81388695
# T = 175   Fidelity = 0.82334818
# T = 200   Fidelity = 0.82919493
# T = 225   Fidelity = 0.83520096
# T = 250   Fidelity = 0.84622215
# T = 275   Fidelity = 0.83513644
# T = 300   Fidelity = 0.85863412
# T = 400   Fidelity = 0.85780328
# T = 500   Fidelity = 0.82487045
# T = 600   Fidelity = 0.83339634
# T = 700   Fidelity = 0.69585658
# T = 800   Fidelity = 0.93254324
# T = 900   Fidelity = 0.87079284
# T = 1000  Fidelity = 0.87094223
# T = 1010  Fidelity = 0.88465452
# T = 1020  Fidelity = 0.84368095
# T = 1030  Fidelity = 0.78488464
# T = 1040  Fidelity = 0.81694093
# T = 1050  Fidelity = 0.88071965
# T = 1060  Fidelity = 0.89099709
# T = 1070  Fidelity = 0.92622838
# T = 1080  Fidelity = 0.96643087
# T = 1090  Fidelity = 0.97753497
#
# Minimum T for Fidelity >= 0.97 : 1090
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.80721241e-02
# T = 1     Fidelity = 0.14357781
# T = 2     Fidelity = 0.27845407
# T = 5     Fidelity = 0.45579445
# T = 10    Fidelity = 0.65322172
# T = 20    Fidelity = 0.81524818
# T = 30    Fidelity = 0.87210399
# T = 40    Fidelity = 0.89379758
# T = 50    Fidelity = 0.90255490
# T = 75    Fidelity = 0.91317913
# T = 100   Fidelity = 0.92131478
# T = 125   Fidelity = 0.92936703
# T = 150   Fidelity = 0.93575382
# T = 175   Fidelity = 0.94383190
# T = 200   Fidelity = 0.95003860
# T = 225   Fidelity = 0.93682228
# T = 250   Fidelity = 0.94518266
# T = 275   Fidelity = 0.94892613
# T = 300   Fidelity = 0.96257636
# T = 400   Fidelity = 0.95833596
# T = 500   Fidelity = 0.93470157
# T = 600   Fidelity = 0.94625153
# T = 700   Fidelity = 0.89651224
# T = 800   Fidelity = 0.94202892
# T = 900   Fidelity = 0.93778161
# T = 1000  Fidelity = 0.92648697
# T = 1010  Fidelity = 0.97162500
#
# Minimum T for Fidelity >= 0.97 : 1010
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.28699324e-01
# T = 1     Fidelity = 0.23820403
# T = 2     Fidelity = 0.40975228
# T = 5     Fidelity = 0.59340908
# T = 10    Fidelity = 0.76313759
# T = 20    Fidelity = 0.88382567
# T = 30    Fidelity = 0.92426790
# T = 40    Fidelity = 0.94153424
# T = 50    Fidelity = 0.95043491
# T = 75    Fidelity = 0.96136904
# T = 100   Fidelity = 0.96919897
# T = 125   Fidelity = 0.97453615
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.76942005e-01
# T = 1     Fidelity = 0.33065726
# T = 2     Fidelity = 0.52253587
# T = 5     Fidelity = 0.69675045
# T = 10    Fidelity = 0.83576433
# T = 20    Fidelity = 0.92559931
# T = 30    Fidelity = 0.95437831
# T = 40    Fidelity = 0.96613347
# T = 50    Fidelity = 0.97236777
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.20505465e-01
# T = 1     Fidelity = 0.41289950
# T = 2     Fidelity = 0.61283307
# T = 5     Fidelity = 0.77099030
# T = 10    Fidelity = 0.88314824
# T = 20    Fidelity = 0.95120558
# T = 30    Fidelity = 0.97145343
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000149
# T = 10    Fidelity = 0.00047332
# T = 20    Fidelity = 0.00569862
# T = 30    Fidelity = 0.01813085
# T = 40    Fidelity = 0.06193818
# T = 50    Fidelity = 0.16170465
# T = 75    Fidelity = 0.32402788
# T = 100   Fidelity = 0.48071385
# T = 125   Fidelity = 0.62846430
# T = 150   Fidelity = 0.72560861
# T = 175   Fidelity = 0.79321597
# T = 200   Fidelity = 0.83461999
# T = 225   Fidelity = 0.84735507
# T = 250   Fidelity = 0.85438463
# T = 275   Fidelity = 0.71767815
# T = 300   Fidelity = 0.79193144
# T = 400   Fidelity = 0.93093367
# T = 500   Fidelity = 0.91058678
# T = 600   Fidelity = 0.89282403
# T = 700   Fidelity = 0.81714713
# T = 800   Fidelity = 0.64758495
# T = 900   Fidelity = 0.74801514
# T = 1000  Fidelity = 0.62831941
# T = 1010  Fidelity = 0.62101533
# T = 1020  Fidelity = 0.70167591
# T = 1030  Fidelity = 0.67261045
# T = 1040  Fidelity = 0.25365841
# T = 1050  Fidelity = 0.41791175
# T = 1060  Fidelity = 0.50070953
# T = 1070  Fidelity = 0.47186165
# T = 1080  Fidelity = 0.56672806
# T = 1090  Fidelity = 0.54978659
# T = 1100  Fidelity = 0.75368710
# T = 1200  Fidelity = 0.22441469
# T = 1300  Fidelity = 0.25298838
# T = 1400  Fidelity = 0.65236795
# T = 1500  Fidelity = 0.48377233
# T = 2000  Fidelity = 0.33824690
# T = 2100  Fidelity = 0.88744521
# T = 2110  Fidelity = 0.81705806
# T = 2120  Fidelity = 0.76938758
# T = 2130  Fidelity = 0.74849092
# T = 2140  Fidelity = 0.54525989
# T = 2150  Fidelity = 0.75889288
# T = 2160  Fidelity = 0.56105991
# T = 2170  Fidelity = 0.63703445
# T = 2180  Fidelity = 0.70410324
# T = 2190  Fidelity = 0.53384483
# T = 2200  Fidelity = 0.52888515
# T = 2300  Fidelity = 0.33928010
# T = 2400  Fidelity = 0.51618409
# T = 2500  Fidelity = 0.52613070
# T = 2600  Fidelity = 0.30616832
# T = 2700  Fidelity = 0.24573201
# T = 2800  Fidelity = 0.53839521
# T = 2900  Fidelity = 0.50677933
# T = 3000  Fidelity = 0.91728000
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91728000
# P1     = 0.00917301
# P0+P1  = 0.92645300
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.61673084e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000003
# T = 5     Fidelity = 0.00001676
# T = 10    Fidelity = 0.00289006
# T = 20    Fidelity = 0.22173241
# T = 30    Fidelity = 0.30114659
# T = 40    Fidelity = 0.34874794
# T = 50    Fidelity = 0.70888204
# T = 75    Fidelity = 0.77608897
# T = 100   Fidelity = 0.66964599
# T = 125   Fidelity = 0.86316978
# T = 150   Fidelity = 0.77739155
# T = 175   Fidelity = 0.90667661
# T = 200   Fidelity = 0.96392446
# T = 225   Fidelity = 0.88875907
# T = 250   Fidelity = 0.96469277
# T = 275   Fidelity = 0.94609832
# T = 300   Fidelity = 0.93416134
# T = 400   Fidelity = 0.96702085
# T = 500   Fidelity = 0.96145417
# T = 600   Fidelity = 0.87382994
# T = 700   Fidelity = 0.62845665
# T = 800   Fidelity = 0.79724455
# T = 900   Fidelity = 0.73551730
# T = 1000  Fidelity = 0.83835583
# T = 1010  Fidelity = 0.80279253
# T = 1020  Fidelity = 0.84654641
# T = 1030  Fidelity = 0.74761459
# T = 1040  Fidelity = 0.71437695
# T = 1050  Fidelity = 0.68657008
# T = 1060  Fidelity = 0.55324121
# T = 1070  Fidelity = 0.52954718
# T = 1080  Fidelity = 0.64569890
# T = 1090  Fidelity = 0.51775145
# T = 1100  Fidelity = 0.49672153
# T = 1200  Fidelity = 0.89010950
# T = 1300  Fidelity = 0.67194414
# T = 1400  Fidelity = 0.81838818
# T = 1500  Fidelity = 0.91612445
# T = 2000  Fidelity = 0.62087049
# T = 2100  Fidelity = 0.49096755
# T = 2110  Fidelity = 0.76429983
# T = 2120  Fidelity = 0.72039029
# T = 2130  Fidelity = 0.56585177
# T = 2140  Fidelity = 0.48706075
# T = 2150  Fidelity = 0.62091318
# T = 2160  Fidelity = 0.54255911
# T = 2170  Fidelity = 0.42889661
# T = 2180  Fidelity = 0.49772369
# T = 2190  Fidelity = 0.81534171
# T = 2200  Fidelity = 0.61529832
# T = 2300  Fidelity = 0.66582085
# T = 2400  Fidelity = 0.59112182
# T = 2500  Fidelity = 0.83049454
# T = 2600  Fidelity = 0.61870045
# T = 2700  Fidelity = 0.88727030
# T = 2800  Fidelity = 0.64606125
# T = 2900  Fidelity = 0.69323381
# T = 3000  Fidelity = 0.86542864
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43053089e+00
# P0     = 0.86542864
# P1     = 0.03999300
# P0+P1  = 0.90542164
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.64768458e-01
# T = 1     Fidelity = 0.00001000
# T = 2     Fidelity = 0.00014721
# T = 5     Fidelity = 0.00345685
# T = 10    Fidelity = 0.05108843
# T = 20    Fidelity = 0.41006983
# T = 30    Fidelity = 0.59481553
# T = 40    Fidelity = 0.58240223
# T = 50    Fidelity = 0.72402288
# T = 75    Fidelity = 0.81382397
# T = 100   Fidelity = 0.89316329
# T = 125   Fidelity = 0.94402975
# T = 150   Fidelity = 0.96744429
# T = 175   Fidelity = 0.97769398
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.00049946
# T = 2     Fidelity = 0.00288799
# T = 5     Fidelity = 0.02079989
# T = 10    Fidelity = 0.11082434
# T = 20    Fidelity = 0.42515913
# T = 30    Fidelity = 0.66201807
# T = 40    Fidelity = 0.73186447
# T = 50    Fidelity = 0.76187676
# T = 75    Fidelity = 0.88542570
# T = 100   Fidelity = 0.93293124
# T = 125   Fidelity = 0.96623121
# T = 150   Fidelity = 0.98146153
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.00480750
# T = 2     Fidelity = 0.01663292
# T = 5     Fidelity = 0.06227755
# T = 10    Fidelity = 0.18589729
# T = 20    Fidelity = 0.44931921
# T = 30    Fidelity = 0.64690619
# T = 40    Fidelity = 0.75623211
# T = 50    Fidelity = 0.81835429
# T = 75    Fidelity = 0.91087746
# T = 100   Fidelity = 0.95912204
# T = 125   Fidelity = 0.97967754
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.02291922
# T = 2     Fidelity = 0.05767093
# T = 5     Fidelity = 0.14292952
# T = 10    Fidelity = 0.29374162
# T = 20    Fidelity = 0.51937276
# T = 30    Fidelity = 0.66597950
# T = 40    Fidelity = 0.75879274
# T = 50    Fidelity = 0.82192114
# T = 75    Fidelity = 0.91752947
# T = 100   Fidelity = 0.96550267
# T = 125   Fidelity = 0.98694329
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.07110798
# T = 2     Fidelity = 0.14540289
# T = 5     Fidelity = 0.27523946
# T = 10    Fidelity = 0.44311432
# T = 20    Fidelity = 0.63683557
# T = 30    Fidelity = 0.74295533
# T = 40    Fidelity = 0.80962528
# T = 50    Fidelity = 0.85659921
# T = 75    Fidelity = 0.92589513
# T = 100   Fidelity = 0.96148491
# T = 125   Fidelity = 0.98015509
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.15447648
# T = 2     Fidelity = 0.27488771
# T = 5     Fidelity = 0.43691107
# T = 10    Fidelity = 0.60260884
# T = 20    Fidelity = 0.76058519
# T = 30    Fidelity = 0.83526062
# T = 40    Fidelity = 0.87983537
# T = 50    Fidelity = 0.90959559
# T = 75    Fidelity = 0.95167539
# T = 100   Fidelity = 0.97294292
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.25459420
# T = 2     Fidelity = 0.41145944
# T = 5     Fidelity = 0.58348135
# T = 10    Fidelity = 0.73069996
# T = 20    Fidelity = 0.85272965
# T = 30    Fidelity = 0.90364128
# T = 40    Fidelity = 0.93196890
# T = 50    Fidelity = 0.94955105
# T = 75    Fidelity = 0.97418025
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.35069489
# T = 2     Fidelity = 0.52868622
# T = 5     Fidelity = 0.69423794
# T = 10    Fidelity = 0.81762334
# T = 20    Fidelity = 0.90989962
# T = 30    Fidelity = 0.94402604
# T = 40    Fidelity = 0.96184770
# T = 50    Fidelity = 0.97270745
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.06623659e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00011937
# T = 10    Fidelity = 0.00637588
# T = 20    Fidelity = 0.15727830
# T = 30    Fidelity = 0.48664560
# T = 40    Fidelity = 0.76091240
# T = 50    Fidelity = 0.90722153
# T = 75    Fidelity = 0.99428008
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 7.20609288e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000011
# T = 5     Fidelity = 0.00112865
# T = 10    Fidelity = 0.18548588
# T = 20    Fidelity = 0.88901111
# T = 30    Fidelity = 0.96873902
# T = 40    Fidelity = 0.99617635
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 7.76105909e-01
# T = 1     Fidelity = 0.00000399
# T = 2     Fidelity = 0.00014613
# T = 5     Fidelity = 0.03236252
# T = 10    Fidelity = 0.56662887
# T = 20    Fidelity = 0.90586630
# T = 30    Fidelity = 0.99244138
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 8.12909217e-01
# T = 1     Fidelity = 0.00019352
# T = 2     Fidelity = 0.00242167
# T = 5     Fidelity = 0.10905287
# T = 10    Fidelity = 0.69721691
# T = 20    Fidelity = 0.94965348
# T = 30    Fidelity = 0.99072264
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 8.40169449e-01
# T = 1     Fidelity = 0.00166737
# T = 2     Fidelity = 0.01140118
# T = 5     Fidelity = 0.20674223
# T = 10    Fidelity = 0.76567097
# T = 20    Fidelity = 0.97047075
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 8.61748289e-01
# T = 1     Fidelity = 0.00653469
# T = 2     Fidelity = 0.03032710
# T = 5     Fidelity = 0.30451029
# T = 10    Fidelity = 0.80679787
# T = 20    Fidelity = 0.97990781
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.79340685e-01
# T = 1     Fidelity = 0.01679579
# T = 2     Fidelity = 0.05953449
# T = 5     Fidelity = 0.39421916
# T = 10    Fidelity = 0.83511476
# T = 20    Fidelity = 0.98427143
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 8.94021606e-01
# T = 1     Fidelity = 0.03347575
# T = 2     Fidelity = 0.09736883
# T = 5     Fidelity = 0.47338914
# T = 10    Fidelity = 0.85661007
# T = 20    Fidelity = 0.98591469
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.06402712e-01
# T = 1     Fidelity = 0.05660328
# T = 2     Fidelity = 0.14156623
# T = 5     Fidelity = 0.54235854
# T = 10    Fidelity = 0.87429667
# T = 20    Fidelity = 0.98630802
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.17036009e-01
# T = 1     Fidelity = 0.08549911
# T = 2     Fidelity = 0.18988850
# T = 5     Fidelity = 0.60219397
# T = 10    Fidelity = 0.88959494
# T = 20    Fidelity = 0.98628824
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     2         0.9933459359      1.01220263e+00    None        None        None
# Symmetric      0.311     2         0.9942212982      1.03626623e+00    None        None        None
# Symmetric      0.522     1         0.9704893831      1.05846299e+00    None        None        None
# Symmetric      0.733     1         0.9725983301      1.07916278e+00    None        None        None
# Symmetric      0.944     1         0.9744501124      1.09862393e+00    None        None        None
# Symmetric      1.156     1         0.9760916862      1.11703633e+00    None        None        None
# Symmetric      1.367     1         0.9775585403      1.13454489e+00    None        None        None
# Symmetric      1.578     1         0.9788781642      1.15126343e+00    None        None        None
# Symmetric      1.789     1         0.9800722827      1.16728342e+00    None        None        None
# Symmetric      2.000     1         0.9811583551      1.18267976e+00    None        None        None
# Weak SSB       0.100     600       0.9711996442      4.00578748e-04    None        None        None
# Weak SSB       0.311     300       0.9700719961      1.22897118e-04    None        None        None
# Weak SSB       0.522     None      0.8145080627      1.15176142e-04    0.446956    0.002644    0.4496
# Weak SSB       0.733     None      0.8397188420      2.97449186e-04    0.419617    0.000128    0.419745
# Weak SSB       0.944     None      0.8750821200      5.82831771e-03    0.819267    1.6e-05     0.819283
# Weak SSB       1.156     1090      0.9775349662      3.15665395e-02    None        None        None
# Weak SSB       1.367     1010      0.9716250010      7.80721241e-02    None        None        None
# Weak SSB       1.578     125       0.9745361488      1.28699324e-01    None        None        None
# Weak SSB       1.789     50        0.9723677689      1.76942005e-01    None        None        None
# Weak SSB       2.000     30        0.9714534280      2.20505465e-01    None        None        None
# Weak SSB optimised0.100     None      0.9309336746      2.43127858e-01    0.91728     0.009173    0.926453
# Weak SSB optimised0.311     None      0.9670208500      2.61673084e-01    0.865429    0.039993    0.905422
# Weak SSB optimised0.522     175       0.9776939805      2.64768458e-01    None        None        None
# Weak SSB optimised0.733     150       0.9814615257      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     125       0.9796775438      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     125       0.9869432934      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9801550862      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     100       0.9729429234      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     75        0.9741802466      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     50        0.9727074474      2.55131735e-01    None        None        None
# Strong SSB     0.100     75        0.9942800802      6.06623659e-01    None        None        None
# Strong SSB     0.311     40        0.9961763546      7.20609288e-01    None        None        None
# Strong SSB     0.522     30        0.9924413761      7.76105909e-01    None        None        None
# Strong SSB     0.733     30        0.9907226352      8.12909217e-01    None        None        None
# Strong SSB     0.944     20        0.9704707532      8.40169449e-01    None        None        None
# Strong SSB     1.156     20        0.9799078055      8.61748289e-01    None        None        None
# Strong SSB     1.367     20        0.9842714316      8.79340685e-01    None        None        None
# Strong SSB     1.578     20        0.9859146868      8.94021606e-01    None        None        None
# Strong SSB     1.789     20        0.9863080200      9.06402712e-01    None        None        None
# Strong SSB     2.000     20        0.9862882406      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap,  $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_exact = match['psi_exact']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )
    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_exact = data['psi_exact']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009561
# T = 10    Fidelity = 0.00119308
# T = 20    Fidelity = 0.02687515
# T = 30    Fidelity = 0.09667486
# T = 40    Fidelity = 0.19609881
# T = 50    Fidelity = 0.31173180
# T = 75    Fidelity = 0.56619425
# T = 100   Fidelity = 0.72002097
# T = 125   Fidelity = 0.80739193
# T = 150   Fidelity = 0.86470591
# T = 175   Fidelity = 0.90864875
# T = 200   Fidelity = 0.94630112
# T = 225   Fidelity = 0.96686865
# T = 250   Fidelity = 0.95352375
# T = 275   Fidelity = 0.98204188
#
# Minimum T for Fidelity >= 0.97 : 275
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.15624067e-06
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000045
# T = 5     Fidelity = 0.00144442
# T = 10    Fidelity = 0.10202503
# T = 20    Fidelity = 0.52980261
# T = 30    Fidelity = 0.63895322
# T = 40    Fidelity = 0.76793386
# T = 50    Fidelity = 0.88384534
# T = 75    Fidelity = 0.94226388
# T = 100   Fidelity = 0.97306448
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.42043132e-07
# T = 1     Fidelity = 0.00005024
# T = 2     Fidelity = 0.00043635
# T = 5     Fidelity = 0.02724419
# T = 10    Fidelity = 0.28404350
# T = 20    Fidelity = 0.77881228
# T = 30    Fidelity = 0.80543144
# T = 40    Fidelity = 0.95120082
# T = 50    Fidelity = 0.93701095
# T = 75    Fidelity = 0.99144527
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41278093e-05
# T = 1     Fidelity = 0.00155087
# T = 2     Fidelity = 0.00639467
# T = 5     Fidelity = 0.08479713
# T = 10    Fidelity = 0.38783213
# T = 20    Fidelity = 0.90883200
# T = 30    Fidelity = 0.89422561
# T = 40    Fidelity = 0.97221875
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 3.35131121e-04
# T = 1     Fidelity = 0.01057973
# T = 2     Fidelity = 0.02893049
# T = 5     Fidelity = 0.16449335
# T = 10    Fidelity = 0.46787752
# T = 20    Fidelity = 0.92254320
# T = 30    Fidelity = 0.97977694
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.39158790e-03
# T = 1     Fidelity = 0.03667803
# T = 2     Fidelity = 0.07740765
# T = 5     Fidelity = 0.25991942
# T = 10    Fidelity = 0.54100873
# T = 20    Fidelity = 0.90448860
# T = 30    Fidelity = 0.99651372
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 8.93695212e-03
# T = 1     Fidelity = 0.08776786
# T = 2     Fidelity = 0.15531495
# T = 5     Fidelity = 0.36741624
# T = 10    Fidelity = 0.61610981
# T = 20    Fidelity = 0.89397180
# T = 30    Fidelity = 0.98167620
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.26116126e-02
# T = 1     Fidelity = 0.16578992
# T = 2     Fidelity = 0.25894858
# T = 5     Fidelity = 0.48156117
# T = 10    Fidelity = 0.69439405
# T = 20    Fidelity = 0.90353226
# T = 30    Fidelity = 0.97294307
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 4.43232760e-02
# T = 1     Fidelity = 0.26389921
# T = 2     Fidelity = 0.37661641
# T = 5     Fidelity = 0.59255881
# T = 10    Fidelity = 0.76990597
# T = 20    Fidelity = 0.92536060
# T = 30    Fidelity = 0.97251289
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36879749
# T = 2     Fidelity = 0.49274105
# T = 5     Fidelity = 0.69000583
# T = 10    Fidelity = 0.83495730
# T = 20    Fidelity = 0.94707142
# T = 30    Fidelity = 0.97596588
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.33865795e-02
# T = 1     Fidelity = 0.59495380
# T = 2     Fidelity = 0.64025456
# T = 5     Fidelity = 0.72182186
# T = 10    Fidelity = 0.79944047
# T = 20    Fidelity = 0.88128161
# T = 30    Fidelity = 0.92383358
# T = 40    Fidelity = 0.94862514
# T = 50    Fidelity = 0.96365634
# T = 75    Fidelity = 0.98162023
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 2.33760034e-03
# T = 1     Fidelity = 0.48965471
# T = 2     Fidelity = 0.50416199
# T = 5     Fidelity = 0.54915402
# T = 10    Fidelity = 0.60586231
# T = 20    Fidelity = 0.67863819
# T = 30    Fidelity = 0.72884220
# T = 40    Fidelity = 0.76709834
# T = 50    Fidelity = 0.79753474
# T = 75    Fidelity = 0.85228338
# T = 100   Fidelity = 0.88721188
# T = 125   Fidelity = 0.91225732
# T = 150   Fidelity = 0.92880248
# T = 175   Fidelity = 0.93734226
# T = 200   Fidelity = 0.95451340
# T = 225   Fidelity = 0.95733200
# T = 250   Fidelity = 0.96019902
# T = 275   Fidelity = 0.94857247
# T = 300   Fidelity = 0.95972821
# T = 400   Fidelity = 0.97361592
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.28632798e-04
# T = 1     Fidelity = 0.28798587
# T = 2     Fidelity = 0.29012961
# T = 5     Fidelity = 0.29064549
# T = 10    Fidelity = 0.29085018
# T = 20    Fidelity = 0.29090444
# T = 30    Fidelity = 0.29093789
# T = 40    Fidelity = 0.29102512
# T = 50    Fidelity = 0.29107672
# T = 75    Fidelity = 0.29127853
# T = 100   Fidelity = 0.29142071
# T = 125   Fidelity = 0.29141304
# T = 150   Fidelity = 0.29141326
# T = 175   Fidelity = 0.28971974
# T = 200   Fidelity = 0.29226968
# T = 225   Fidelity = 0.28994128
# T = 250   Fidelity = 0.29187846
# T = 275   Fidelity = 0.29165661
# T = 300   Fidelity = 0.29209218
# T = 400   Fidelity = 0.29014260
# T = 500   Fidelity = 0.29171362
# T = 600   Fidelity = 0.29197724
# T = 700   Fidelity = 0.29527381
# T = 800   Fidelity = 0.29358987
# T = 900   Fidelity = 0.28859838
# T = 1000  Fidelity = 0.29372160
# T = 1010  Fidelity = 0.29392897
# T = 1020  Fidelity = 0.29057438
# T = 1030  Fidelity = 0.29289826
# T = 1040  Fidelity = 0.29487097
# T = 1050  Fidelity = 0.29435703
# T = 1060  Fidelity = 0.29049322
# T = 1070  Fidelity = 0.29168793
# T = 1080  Fidelity = 0.29171280
# T = 1090  Fidelity = 0.29012146
# T = 1100  Fidelity = 0.29018008
# T = 1200  Fidelity = 0.29332203
# T = 1300  Fidelity = 0.29406559
# T = 1400  Fidelity = 0.29227300
# T = 1500  Fidelity = 0.29203140
# T = 2000  Fidelity = 0.29390691
# T = 2100  Fidelity = 0.29268201
# T = 2110  Fidelity = 0.29152436
# T = 2120  Fidelity = 0.29236268
# T = 2130  Fidelity = 0.29314611
# T = 2140  Fidelity = 0.29319405
# T = 2150  Fidelity = 0.29387621
# T = 2160  Fidelity = 0.29315038
# T = 2170  Fidelity = 0.29247968
# T = 2180  Fidelity = 0.29191160
# T = 2190  Fidelity = 0.29436255
# T = 2200  Fidelity = 0.29309716
# T = 2300  Fidelity = 0.29212116
# T = 2400  Fidelity = 0.29227095
# T = 2500  Fidelity = 0.29311026
# T = 2600  Fidelity = 0.29636170
# T = 2700  Fidelity = 0.29321064
# T = 2800  Fidelity = 0.29115454
# T = 2900  Fidelity = 0.28983595
# T = 3000  Fidelity = 0.28912660
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.29930841e-04
# P0     = 0.28912660
# P1     = 0.21180786
# P0+P1  = 0.50093445
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.07617225e-04
# T = 1     Fidelity = 0.27343365
# T = 2     Fidelity = 0.27696433
# T = 5     Fidelity = 0.27908427
# T = 10    Fidelity = 0.27963536
# T = 20    Fidelity = 0.28103578
# T = 30    Fidelity = 0.28154709
# T = 40    Fidelity = 0.28205993
# T = 50    Fidelity = 0.28271594
# T = 75    Fidelity = 0.28373457
# T = 100   Fidelity = 0.28447100
# T = 125   Fidelity = 0.28511594
# T = 150   Fidelity = 0.28576894
# T = 175   Fidelity = 0.28562256
# T = 200   Fidelity = 0.28645362
# T = 225   Fidelity = 0.28724448
# T = 250   Fidelity = 0.28755067
# T = 275   Fidelity = 0.28747548
# T = 300   Fidelity = 0.28963089
# T = 400   Fidelity = 0.28982055
# T = 500   Fidelity = 0.29270266
# T = 600   Fidelity = 0.29422127
# T = 700   Fidelity = 0.29219744
# T = 800   Fidelity = 0.29534630
# T = 900   Fidelity = 0.29185877
# T = 1000  Fidelity = 0.29527909
# T = 1010  Fidelity = 0.29360612
# T = 1020  Fidelity = 0.29050446
# T = 1030  Fidelity = 0.30176791
# T = 1040  Fidelity = 0.29014476
# T = 1050  Fidelity = 0.30276030
# T = 1060  Fidelity = 0.30120048
# T = 1070  Fidelity = 0.29785406
# T = 1080  Fidelity = 0.29506912
# T = 1090  Fidelity = 0.29530151
# T = 1100  Fidelity = 0.29668772
# T = 1200  Fidelity = 0.29693140
# T = 1300  Fidelity = 0.29669141
# T = 1400  Fidelity = 0.29460270
# T = 1500  Fidelity = 0.29573935
# T = 2000  Fidelity = 0.30766878
# T = 2100  Fidelity = 0.30600426
# T = 2110  Fidelity = 0.30248312
# T = 2120  Fidelity = 0.30642029
# T = 2130  Fidelity = 0.30973518
# T = 2140  Fidelity = 0.31059725
# T = 2150  Fidelity = 0.30978448
# T = 2160  Fidelity = 0.30766901
# T = 2170  Fidelity = 0.30564698
# T = 2180  Fidelity = 0.30527203
# T = 2190  Fidelity = 0.30393727
# T = 2200  Fidelity = 0.30479803
# T = 2300  Fidelity = 0.30355374
# T = 2400  Fidelity = 0.30519397
# T = 2500  Fidelity = 0.30500645
# T = 2600  Fidelity = 0.30814453
# T = 2700  Fidelity = 0.30604604
# T = 2800  Fidelity = 0.30172041
# T = 2900  Fidelity = 0.29987919
# T = 3000  Fidelity = 0.29957143
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.07826512e-04
# P0     = 0.29957143
# P1     = 0.23937319
# P0+P1  = 0.53894462
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.61167872e-04
# T = 1     Fidelity = 0.47294600
# T = 2     Fidelity = 0.48500606
# T = 5     Fidelity = 0.49977111
# T = 10    Fidelity = 0.50577195
# T = 20    Fidelity = 0.51382592
# T = 30    Fidelity = 0.52113171
# T = 40    Fidelity = 0.52656781
# T = 50    Fidelity = 0.53025149
# T = 75    Fidelity = 0.53989190
# T = 100   Fidelity = 0.54716133
# T = 125   Fidelity = 0.55312231
# T = 150   Fidelity = 0.55873424
# T = 175   Fidelity = 0.56408637
# T = 200   Fidelity = 0.56846346
# T = 225   Fidelity = 0.57248770
# T = 250   Fidelity = 0.57678192
# T = 275   Fidelity = 0.58061501
# T = 300   Fidelity = 0.58439764
# T = 400   Fidelity = 0.59790705
# T = 500   Fidelity = 0.60875578
# T = 600   Fidelity = 0.63059466
# T = 700   Fidelity = 0.63465298
# T = 800   Fidelity = 0.64258063
# T = 900   Fidelity = 0.63214599
# T = 1000  Fidelity = 0.65471123
# T = 1010  Fidelity = 0.65818460
# T = 1020  Fidelity = 0.65950670
# T = 1030  Fidelity = 0.66276086
# T = 1040  Fidelity = 0.66564196
# T = 1050  Fidelity = 0.66493205
# T = 1060  Fidelity = 0.66469087
# T = 1070  Fidelity = 0.66922511
# T = 1080  Fidelity = 0.67816427
# T = 1090  Fidelity = 0.67896319
# T = 1100  Fidelity = 0.66578700
# T = 1200  Fidelity = 0.64885954
# T = 1300  Fidelity = 0.64789407
# T = 1400  Fidelity = 0.67536601
# T = 1500  Fidelity = 0.68971883
# T = 2000  Fidelity = 0.67815599
# T = 2100  Fidelity = 0.67494371
# T = 2110  Fidelity = 0.67179102
# T = 2120  Fidelity = 0.67097573
# T = 2130  Fidelity = 0.66328574
# T = 2140  Fidelity = 0.67386907
# T = 2150  Fidelity = 0.66407225
# T = 2160  Fidelity = 0.66297014
# T = 2170  Fidelity = 0.66948273
# T = 2180  Fidelity = 0.67618760
# T = 2190  Fidelity = 0.68848462
# T = 2200  Fidelity = 0.69706968
# T = 2300  Fidelity = 0.70683462
# T = 2400  Fidelity = 0.72953448
# T = 2500  Fidelity = 0.73203800
# T = 2600  Fidelity = 0.73624480
# T = 2700  Fidelity = 0.77473210
# T = 2800  Fidelity = 0.76580399
# T = 2900  Fidelity = 0.77684158
# T = 3000  Fidelity = 0.76478087
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 2.60193315e-04
# P0     = 0.76478087
# P1     = 0.02146366
# P0+P1  = 0.78624452
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.86673133e-03
# T = 1     Fidelity = 0.49163843
# T = 2     Fidelity = 0.51374414
# T = 5     Fidelity = 0.54724246
# T = 10    Fidelity = 0.56403820
# T = 20    Fidelity = 0.59184194
# T = 30    Fidelity = 0.60856280
# T = 40    Fidelity = 0.62445054
# T = 50    Fidelity = 0.63526979
# T = 75    Fidelity = 0.66019922
# T = 100   Fidelity = 0.68038147
# T = 125   Fidelity = 0.69651106
# T = 150   Fidelity = 0.71067826
# T = 175   Fidelity = 0.72380050
# T = 200   Fidelity = 0.73514600
# T = 225   Fidelity = 0.74540576
# T = 250   Fidelity = 0.75523039
# T = 275   Fidelity = 0.76406391
# T = 300   Fidelity = 0.77251360
# T = 400   Fidelity = 0.80046337
# T = 500   Fidelity = 0.82258701
# T = 600   Fidelity = 0.82671405
# T = 700   Fidelity = 0.84971362
# T = 800   Fidelity = 0.87713402
# T = 900   Fidelity = 0.89451098
# T = 1000  Fidelity = 0.89010155
# T = 1010  Fidelity = 0.89721395
# T = 1020  Fidelity = 0.90323578
# T = 1030  Fidelity = 0.90954118
# T = 1040  Fidelity = 0.91321704
# T = 1050  Fidelity = 0.91434395
# T = 1060  Fidelity = 0.91277698
# T = 1070  Fidelity = 0.90999897
# T = 1080  Fidelity = 0.90723436
# T = 1090  Fidelity = 0.90398321
# T = 1100  Fidelity = 0.89968220
# T = 1200  Fidelity = 0.88925630
# T = 1300  Fidelity = 0.94032843
# T = 1400  Fidelity = 0.91506118
# T = 1500  Fidelity = 0.88530683
# T = 2000  Fidelity = 0.92434097
# T = 2100  Fidelity = 0.89586513
# T = 2110  Fidelity = 0.89435686
# T = 2120  Fidelity = 0.88621505
# T = 2130  Fidelity = 0.88239667
# T = 2140  Fidelity = 0.88995301
# T = 2150  Fidelity = 0.90166913
# T = 2160  Fidelity = 0.90727216
# T = 2170  Fidelity = 0.90606001
# T = 2180  Fidelity = 0.90286931
# T = 2190  Fidelity = 0.90420098
# T = 2200  Fidelity = 0.91123691
# T = 2300  Fidelity = 0.91224058
# T = 2400  Fidelity = 0.93287975
# T = 2500  Fidelity = 0.96773525
# T = 2600  Fidelity = 0.96755636
# T = 2700  Fidelity = 0.98658230
#
# Minimum T for Fidelity >= 0.97 : 2700
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 7.31352271e-03
# T = 1     Fidelity = 0.51143974
# T = 2     Fidelity = 0.54461101
# T = 5     Fidelity = 0.59840286
# T = 10    Fidelity = 0.63163292
# T = 20    Fidelity = 0.68363895
# T = 30    Fidelity = 0.71663316
# T = 40    Fidelity = 0.73885187
# T = 50    Fidelity = 0.75853616
# T = 75    Fidelity = 0.79760518
# T = 100   Fidelity = 0.82581344
# T = 125   Fidelity = 0.84741237
# T = 150   Fidelity = 0.86509629
# T = 175   Fidelity = 0.88008472
# T = 200   Fidelity = 0.89248587
# T = 225   Fidelity = 0.90318130
# T = 250   Fidelity = 0.91193445
# T = 275   Fidelity = 0.92016017
# T = 300   Fidelity = 0.92738326
# T = 400   Fidelity = 0.94824558
# T = 500   Fidelity = 0.96150519
# T = 600   Fidelity = 0.97037830
#
# Minimum T for Fidelity >= 0.97 : 600
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.92005942e-02
# T = 1     Fidelity = 0.54956001
# T = 2     Fidelity = 0.59346264
# T = 5     Fidelity = 0.66465341
# T = 10    Fidelity = 0.72014121
# T = 20    Fidelity = 0.78276023
# T = 30    Fidelity = 0.82315937
# T = 40    Fidelity = 0.85203016
# T = 50    Fidelity = 0.87342274
# T = 75    Fidelity = 0.90868931
# T = 100   Fidelity = 0.93108675
# T = 125   Fidelity = 0.94638512
# T = 150   Fidelity = 0.95734378
# T = 175   Fidelity = 0.96527970
# T = 200   Fidelity = 0.97135496
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 3.87723930e-02
# T = 1     Fidelity = 0.60021900
# T = 2     Fidelity = 0.65324408
# T = 5     Fidelity = 0.73589415
# T = 10    Fidelity = 0.80610624
# T = 20    Fidelity = 0.86832988
# T = 30    Fidelity = 0.90341614
# T = 40    Fidelity = 0.92626114
# T = 50    Fidelity = 0.94224077
# T = 75    Fidelity = 0.96465780
# T = 100   Fidelity = 0.97694703
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 6.53468672e-02
# T = 1     Fidelity = 0.65428411
# T = 2     Fidelity = 0.71392777
# T = 5     Fidelity = 0.80123151
# T = 10    Fidelity = 0.87224306
# T = 20    Fidelity = 0.92460645
# T = 30    Fidelity = 0.95035046
# T = 40    Fidelity = 0.96544004
# T = 50    Fidelity = 0.97500902
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.62317299
# T = 2     Fidelity = 0.65190417
# T = 5     Fidelity = 0.70826408
# T = 10    Fidelity = 0.76280613
# T = 20    Fidelity = 0.82917568
# T = 30    Fidelity = 0.86980822
# T = 40    Fidelity = 0.89813622
# T = 50    Fidelity = 0.91830270
# T = 75    Fidelity = 0.94946642
# T = 100   Fidelity = 0.96622193
# T = 125   Fidelity = 0.97485820
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.75203185
# T = 2     Fidelity = 0.76213197
# T = 5     Fidelity = 0.79116128
# T = 10    Fidelity = 0.82194088
# T = 20    Fidelity = 0.85702719
# T = 30    Fidelity = 0.87877823
# T = 40    Fidelity = 0.89415834
# T = 50    Fidelity = 0.90605163
# T = 75    Fidelity = 0.92694348
# T = 100   Fidelity = 0.94087114
# T = 125   Fidelity = 0.95061918
# T = 150   Fidelity = 0.95678479
# T = 175   Fidelity = 0.96322066
# T = 200   Fidelity = 0.96541737
# T = 225   Fidelity = 0.96871909
# T = 250   Fidelity = 0.96731944
# T = 275   Fidelity = 0.97085941
#
# Minimum T for Fidelity >= 0.97 : 275
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.99091584
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.98785420
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.97979503
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.95045668
# T = 2     Fidelity = 0.96644852
# T = 5     Fidelity = 0.97792916
#
# Minimum T for Fidelity >= 0.97 : 5
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.88061441
# T = 2     Fidelity = 0.90341100
# T = 5     Fidelity = 0.92748762
# T = 10    Fidelity = 0.93754630
# T = 20    Fidelity = 0.95180732
# T = 30    Fidelity = 0.95837081
# T = 40    Fidelity = 0.96403372
# T = 50    Fidelity = 0.96748640
# T = 75    Fidelity = 0.97430952
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.78898849
# T = 2     Fidelity = 0.81915893
# T = 5     Fidelity = 0.85776371
# T = 10    Fidelity = 0.87944131
# T = 20    Fidelity = 0.91073815
# T = 30    Fidelity = 0.92494778
# T = 40    Fidelity = 0.93555772
# T = 50    Fidelity = 0.94395577
# T = 75    Fidelity = 0.95765873
# T = 100   Fidelity = 0.96654209
# T = 125   Fidelity = 0.97266864
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.71992892
# T = 2     Fidelity = 0.75652327
# T = 5     Fidelity = 0.80692422
# T = 10    Fidelity = 0.84315598
# T = 20    Fidelity = 0.89162503
# T = 30    Fidelity = 0.91310383
# T = 40    Fidelity = 0.93006175
# T = 50    Fidelity = 0.93975146
# T = 75    Fidelity = 0.95856992
# T = 100   Fidelity = 0.96984320
# T = 125   Fidelity = 0.97709412
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.54594564e-01
# T = 1     Fidelity = 0.69238793
# T = 2     Fidelity = 0.73457358
# T = 5     Fidelity = 0.79306618
# T = 10    Fidelity = 0.84070151
# T = 20    Fidelity = 0.90343982
# T = 30    Fidelity = 0.92706355
# T = 40    Fidelity = 0.94574155
# T = 50    Fidelity = 0.95660378
# T = 75    Fidelity = 0.97334342
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99433036
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.99428765
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.42665601e+00
# T = 1     Fidelity = 0.99389370
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.41121208e+00
# T = 1     Fidelity = 0.99397515
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.99330498
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.99236742
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.99122367
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.98986936
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.98829941
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.98654124
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     275       0.9820418767      2.15534848e-04    None        None        None
# Symmetric      0.311     100       0.9730644828      1.15624067e-06    None        None        None
# Symmetric      0.522     75        0.9914452699      3.42043132e-07    None        None        None
# Symmetric      0.733     40        0.9722187508      1.41278093e-05    None        None        None
# Symmetric      0.944     30        0.9797769412      3.35131121e-04    None        None        None
# Symmetric      1.156     30        0.9965137238      2.39158790e-03    None        None        None
# Symmetric      1.367     30        0.9816761998      8.93695212e-03    None        None        None
# Symmetric      1.578     30        0.9729430683      2.26116126e-02    None        None        None
# Symmetric      1.789     30        0.9725128947      4.43232760e-02    None        None        None
# Symmetric      2.000     30        0.9759658805      7.29248761e-02    None        None        None
# Weak SSB       0.100     75        0.9816202281      1.33865795e-02    None        None        None
# Weak SSB       0.311     400       0.9736159194      2.33760034e-03    None        None        None
# Weak SSB       0.522     None      0.2963616996      1.28632798e-04    0.289127    0.211808    0.500934
# Weak SSB       0.733     None      0.3105972487      1.07617225e-04    0.299571    0.239373    0.538945
# Weak SSB       0.944     None      0.7768415823      2.61167872e-04    0.764781    0.021464    0.786245
# Weak SSB       1.156     2700      0.9865823020      1.86673133e-03    None        None        None
# Weak SSB       1.367     600       0.9703783040      7.31352271e-03    None        None        None
# Weak SSB       1.578     200       0.9713549588      1.92005942e-02    None        None        None
# Weak SSB       1.789     100       0.9769470266      3.87723930e-02    None        None        None
# Weak SSB       2.000     50        0.9750090197      6.53468672e-02    None        None        None
# Weak SSB optimised0.100     125       0.9748581989      8.65519637e-01    None        None        None
# Weak SSB optimised0.311     275       0.9708594149      5.19764834e-01    None        None        None
# Weak SSB optimised0.522     1         0.9909158354      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     1         0.9878542017      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     1         0.9797950280      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     5         0.9779291574      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     75        0.9743095183      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     125       0.9726686417      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     125       0.9770941192      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     75        0.9733434213      2.54594564e-01    None        None        None
# Strong SSB     0.100     1         0.9943303610      3.59472102e+00    None        None        None
# Strong SSB     0.311     1         0.9942876478      1.58498916e+00    None        None        None
# Strong SSB     0.522     1         0.9938936965      1.42665601e+00    None        None        None
# Strong SSB     0.733     1         0.9939751472      1.41121208e+00    None        None        None
# Strong SSB     0.944     1         0.9933049812      1.38481786e+00    None        None        None
# Strong SSB     1.156     1         0.9923674195      1.34302163e+00    None        None        None
# Strong SSB     1.367     1         0.9912236729      1.29217279e+00    None        None        None
# Strong SSB     1.578     1         0.9898693571      1.23335459e+00    None        None        None
# Strong SSB     1.789     1         0.9882994133      1.17426012e+00    None        None        None
# Strong SSB     2.000     1         0.9865412374      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================



case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
# Define colors for each case
case_colors = {
    "Symmetric": "blue",
   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

    
for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()


plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5222
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 2.0000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_exact = match['psi_exact']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-2.0

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_exact = data['psi_exact']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000295
# T = 10    Fidelity = 0.00027927
# T = 20    Fidelity = 0.00630267
# T = 30    Fidelity = 0.02604240
# T = 40    Fidelity = 0.06582107
# T = 50    Fidelity = 0.12447358
# T = 75    Fidelity = 0.30902400
# T = 100   Fidelity = 0.46391161
# T = 125   Fidelity = 0.64204308
# T = 150   Fidelity = 0.69157604
# T = 175   Fidelity = 0.77469193
# T = 200   Fidelity = 0.83395432
# T = 225   Fidelity = 0.81460958
# T = 250   Fidelity = 0.90536125
# T = 275   Fidelity = 0.91626441
# T = 300   Fidelity = 0.86715755
# T = 400   Fidelity = 0.97880042
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.17908350e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00030544
# T = 10    Fidelity = 0.01973185
# T = 20    Fidelity = 0.35206745
# T = 30    Fidelity = 0.52578984
# T = 40    Fidelity = 0.54423957
# T = 50    Fidelity = 0.70352123
# T = 75    Fidelity = 0.85009136
# T = 100   Fidelity = 0.92374619
# T = 125   Fidelity = 0.95513522
# T = 150   Fidelity = 0.97617917
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.522
# ================================================================================
# Minimum path gap = 2.94880934e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000012
# T = 5     Fidelity = 0.01013672
# T = 10    Fidelity = 0.29395229
# T = 20    Fidelity = 0.47648900
# T = 30    Fidelity = 0.65918730
# T = 40    Fidelity = 0.84256583
# T = 50    Fidelity = 0.88343223
# T = 75    Fidelity = 0.96312094
# T = 100   Fidelity = 0.98782579
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.58119044e-07
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000816
# T = 5     Fidelity = 0.06263286
# T = 10    Fidelity = 0.29633553
# T = 20    Fidelity = 0.55808641
# T = 30    Fidelity = 0.72699007
# T = 40    Fidelity = 0.83532510
# T = 50    Fidelity = 0.91098579
# T = 75    Fidelity = 0.98047055
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.944
# ================================================================================
# Minimum path gap = 6.89654396e-08
# T = 1     Fidelity = 0.00000139
# T = 2     Fidelity = 0.00013189
# T = 5     Fidelity = 0.11159815
# T = 10    Fidelity = 0.49004253
# T = 20    Fidelity = 0.76516970
# T = 30    Fidelity = 0.88756361
# T = 40    Fidelity = 0.94380636
# T = 50    Fidelity = 0.97009589
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.17592580e-07
# T = 1     Fidelity = 0.00002208
# T = 2     Fidelity = 0.00081387
# T = 5     Fidelity = 0.15753849
# T = 10    Fidelity = 0.62743191
# T = 20    Fidelity = 0.87767666
# T = 30    Fidelity = 0.95887061
# T = 40    Fidelity = 0.98613014
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.367
# ================================================================================
# Minimum path gap = 2.47961159e-07
# T = 1     Fidelity = 0.00014374
# T = 2     Fidelity = 0.00277573
# T = 5     Fidelity = 0.19658890
# T = 10    Fidelity = 0.73840264
# T = 20    Fidelity = 0.93000899
# T = 30    Fidelity = 0.97197957
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.578
# ================================================================================
# Minimum path gap = 3.56990609e-07
# T = 1     Fidelity = 0.00057657
# T = 2     Fidelity = 0.00690790
# T = 5     Fidelity = 0.23187771
# T = 10    Fidelity = 0.80830628
# T = 20    Fidelity = 0.93689871
# T = 30    Fidelity = 0.96371840
# T = 40    Fidelity = 0.98388531
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.45005900e-06
# T = 1     Fidelity = 0.00169082
# T = 2     Fidelity = 0.01404791
# T = 5     Fidelity = 0.26488262
# T = 10    Fidelity = 0.84405890
# T = 20    Fidelity = 0.92519555
# T = 30    Fidelity = 0.96896668
# T = 40    Fidelity = 0.99383657
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396321
# T = 2     Fidelity = 0.02467360
# T = 5     Fidelity = 0.29523663
# T = 10    Fidelity = 0.85799968
# T = 20    Fidelity = 0.92052729
# T = 30    Fidelity = 0.98400011
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.80997252e-02
# T = 1     Fidelity = 0.60412756
# T = 2     Fidelity = 0.64822265
# T = 5     Fidelity = 0.72636569
# T = 10    Fidelity = 0.80230723
# T = 20    Fidelity = 0.88313436
# T = 30    Fidelity = 0.92517711
# T = 40    Fidelity = 0.94943603
# T = 50    Fidelity = 0.96411178
# T = 75    Fidelity = 0.98215369
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.50638569e-02
# T = 1     Fidelity = 0.54368459
# T = 2     Fidelity = 0.58665254
# T = 5     Fidelity = 0.63062225
# T = 10    Fidelity = 0.66790291
# T = 20    Fidelity = 0.72554200
# T = 30    Fidelity = 0.76737307
# T = 40    Fidelity = 0.79974022
# T = 50    Fidelity = 0.82359721
# T = 75    Fidelity = 0.87074596
# T = 100   Fidelity = 0.90090065
# T = 125   Fidelity = 0.92002646
# T = 150   Fidelity = 0.93405957
# T = 175   Fidelity = 0.94155518
# T = 200   Fidelity = 0.94247204
# T = 225   Fidelity = 0.94991935
# T = 250   Fidelity = 0.94176159
# T = 275   Fidelity = 0.93136968
# T = 300   Fidelity = 0.94555266
# T = 400   Fidelity = 0.96730640
# T = 500   Fidelity = 0.94933910
# T = 600   Fidelity = 0.95732135
# T = 700   Fidelity = 0.83457431
# T = 800   Fidelity = 0.87213781
# T = 900   Fidelity = 0.88478692
# T = 1000  Fidelity = 0.88122890
# T = 1010  Fidelity = 0.93284148
# T = 1020  Fidelity = 0.90777120
# T = 1030  Fidelity = 0.94426651
# T = 1040  Fidelity = 0.94749517
# T = 1050  Fidelity = 0.96162498
# T = 1060  Fidelity = 0.97109699
#
# Minimum T for Fidelity >= 0.97 : 1060
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.29389510e-04
# T = 1     Fidelity = 0.02296709
# T = 2     Fidelity = 0.09367453
# T = 5     Fidelity = 0.43095349
# T = 10    Fidelity = 0.48315821
# T = 20    Fidelity = 0.49842479
# T = 30    Fidelity = 0.49982634
# T = 40    Fidelity = 0.50059230
# T = 50    Fidelity = 0.50259923
# T = 75    Fidelity = 0.50099049
# T = 100   Fidelity = 0.50273811
# T = 125   Fidelity = 0.50112991
# T = 150   Fidelity = 0.50417763
# T = 175   Fidelity = 0.50164461
# T = 200   Fidelity = 0.50156111
# T = 225   Fidelity = 0.50214328
# T = 250   Fidelity = 0.50275970
# T = 275   Fidelity = 0.49986366
# T = 300   Fidelity = 0.49896350
# T = 400   Fidelity = 0.48634974
# T = 500   Fidelity = 0.48011117
# T = 600   Fidelity = 0.50022845
# T = 700   Fidelity = 0.49440048
# T = 800   Fidelity = 0.49129864
# T = 900   Fidelity = 0.50982694
# T = 1000  Fidelity = 0.48758482
# T = 1010  Fidelity = 0.49889681
# T = 1020  Fidelity = 0.49993577
# T = 1030  Fidelity = 0.49590206
# T = 1040  Fidelity = 0.50511865
# T = 1050  Fidelity = 0.49379842
# T = 1060  Fidelity = 0.49911397
# T = 1070  Fidelity = 0.50099044
# T = 1080  Fidelity = 0.50604445
# T = 1090  Fidelity = 0.49778555
# T = 1100  Fidelity = 0.49625400
# T = 1200  Fidelity = 0.50834440
# T = 1300  Fidelity = 0.49890009
# T = 1400  Fidelity = 0.43975558
# T = 1500  Fidelity = 0.49864580
# T = 2000  Fidelity = 0.49506362
# T = 2100  Fidelity = 0.50754750
# T = 2110  Fidelity = 0.50167311
# T = 2120  Fidelity = 0.49772634
# T = 2130  Fidelity = 0.48785942
# T = 2140  Fidelity = 0.50138779
# T = 2150  Fidelity = 0.50406590
# T = 2160  Fidelity = 0.49613036
# T = 2170  Fidelity = 0.48538631
# T = 2180  Fidelity = 0.50039332
# T = 2190  Fidelity = 0.49923848
# T = 2200  Fidelity = 0.49302965
# T = 2300  Fidelity = 0.48811907
# T = 2400  Fidelity = 0.42433341
# T = 2500  Fidelity = 0.49862137
# T = 2600  Fidelity = 0.50480262
# T = 2700  Fidelity = 0.49248102
# T = 2800  Fidelity = 0.49192718
# T = 2900  Fidelity = 0.49154302
# T = 3000  Fidelity = 0.47754488
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 8.15023181e-03
# P0     = 0.12675270
# P1     = 0.00110110
# P0+P1  = 0.12785380
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.10289833e-04
# T = 1     Fidelity = 0.03645695
# T = 2     Fidelity = 0.10843606
# T = 5     Fidelity = 0.28720275
# T = 10    Fidelity = 0.30932817
# T = 20    Fidelity = 0.34001436
# T = 30    Fidelity = 0.33926175
# T = 40    Fidelity = 0.33994682
# T = 50    Fidelity = 0.34380412
# T = 75    Fidelity = 0.34453975
# T = 100   Fidelity = 0.34561518
# T = 125   Fidelity = 0.34549712
# T = 150   Fidelity = 0.34590692
# T = 175   Fidelity = 0.34578931
# T = 200   Fidelity = 0.35318329
# T = 225   Fidelity = 0.35101835
# T = 250   Fidelity = 0.34297787
# T = 275   Fidelity = 0.34844082
# T = 300   Fidelity = 0.35110089
# T = 400   Fidelity = 0.37291650
# T = 500   Fidelity = 0.33261966
# T = 600   Fidelity = 0.34810296
# T = 700   Fidelity = 0.34551154
# T = 800   Fidelity = 0.31519819
# T = 900   Fidelity = 0.31188315
# T = 1000  Fidelity = 0.33986134
# T = 1010  Fidelity = 0.34352797
# T = 1020  Fidelity = 0.34239301
# T = 1030  Fidelity = 0.37247550
# T = 1040  Fidelity = 0.35199862
# T = 1050  Fidelity = 0.37308177
# T = 1060  Fidelity = 0.43305236
# T = 1070  Fidelity = 0.28540024
# T = 1080  Fidelity = 0.33267260
# T = 1090  Fidelity = 0.32950561
# T = 1100  Fidelity = 0.39915708
# T = 1200  Fidelity = 0.41582478
# T = 1300  Fidelity = 0.39090137
# T = 1400  Fidelity = 0.39419313
# T = 1500  Fidelity = 0.27815381
# T = 2000  Fidelity = 0.35476173
# T = 2100  Fidelity = 0.25801356
# T = 2110  Fidelity = 0.39100060
# T = 2120  Fidelity = 0.38086093
# T = 2130  Fidelity = 0.30557349
# T = 2140  Fidelity = 0.45703766
# T = 2150  Fidelity = 0.28454261
# T = 2160  Fidelity = 0.38168059
# T = 2170  Fidelity = 0.31229969
# T = 2180  Fidelity = 0.39106033
# T = 2190  Fidelity = 0.38294530
# T = 2200  Fidelity = 0.36885156
# T = 2300  Fidelity = 0.39068604
# T = 2400  Fidelity = 0.31947406
# T = 2500  Fidelity = 0.38325653
# T = 2600  Fidelity = 0.38426542
# T = 2700  Fidelity = 0.33297547
# T = 2800  Fidelity = 0.32717183
# T = 2900  Fidelity = 0.33994185
# T = 3000  Fidelity = 0.31873271
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.69459506e-04
# P0     = 0.04682231
# P1     = 0.01413220
# P0+P1  = 0.06095451
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.04207670e-04
# T = 1     Fidelity = 0.04079234
# T = 2     Fidelity = 0.09842740
# T = 5     Fidelity = 0.24110866
# T = 10    Fidelity = 0.25384608
# T = 20    Fidelity = 0.27583175
# T = 30    Fidelity = 0.28324484
# T = 40    Fidelity = 0.28119132
# T = 50    Fidelity = 0.28771787
# T = 75    Fidelity = 0.29073054
# T = 100   Fidelity = 0.29477985
# T = 125   Fidelity = 0.30027477
# T = 150   Fidelity = 0.30549507
# T = 175   Fidelity = 0.31405625
# T = 200   Fidelity = 0.31248557
# T = 225   Fidelity = 0.31724582
# T = 250   Fidelity = 0.31570906
# T = 275   Fidelity = 0.31364755
# T = 300   Fidelity = 0.32326973
# T = 400   Fidelity = 0.37221429
# T = 500   Fidelity = 0.29955606
# T = 600   Fidelity = 0.34420270
# T = 700   Fidelity = 0.25245417
# T = 800   Fidelity = 0.39854080
# T = 900   Fidelity = 0.39411273
# T = 1000  Fidelity = 0.36945463
# T = 1010  Fidelity = 0.39539830
# T = 1020  Fidelity = 0.41811166
# T = 1030  Fidelity = 0.37523030
# T = 1040  Fidelity = 0.30094140
# T = 1050  Fidelity = 0.28547033
# T = 1060  Fidelity = 0.31513762
# T = 1070  Fidelity = 0.35009365
# T = 1080  Fidelity = 0.41273543
# T = 1090  Fidelity = 0.43269889
# T = 1100  Fidelity = 0.29726531
# T = 1200  Fidelity = 0.28885937
# T = 1300  Fidelity = 0.43388204
# T = 1400  Fidelity = 0.31289266
# T = 1500  Fidelity = 0.43384325
# T = 2000  Fidelity = 0.43260206
# T = 2100  Fidelity = 0.36860265
# T = 2110  Fidelity = 0.43818085
# T = 2120  Fidelity = 0.40588810
# T = 2130  Fidelity = 0.40819044
# T = 2140  Fidelity = 0.46965778
# T = 2150  Fidelity = 0.38055908
# T = 2160  Fidelity = 0.37128590
# T = 2170  Fidelity = 0.32802284
# T = 2180  Fidelity = 0.33864850
# T = 2190  Fidelity = 0.45887793
# T = 2200  Fidelity = 0.32198159
# T = 2300  Fidelity = 0.44940138
# T = 2400  Fidelity = 0.38590965
# T = 2500  Fidelity = 0.44260026
# T = 2600  Fidelity = 0.43372854
# T = 2700  Fidelity = 0.37098939
# T = 2800  Fidelity = 0.40159115
# T = 2900  Fidelity = 0.44072486
# T = 3000  Fidelity = 0.44726557
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.39396699e-04
# P0     = 0.12617213
# P1     = 0.09634107
# P0+P1  = 0.22251320
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.00641152e-04
# T = 1     Fidelity = 0.04493262
# T = 2     Fidelity = 0.09406446
# T = 5     Fidelity = 0.22412183
# T = 10    Fidelity = 0.23871602
# T = 20    Fidelity = 0.26088132
# T = 30    Fidelity = 0.28421611
# T = 40    Fidelity = 0.29243488
# T = 50    Fidelity = 0.29130481
# T = 75    Fidelity = 0.31349471
# T = 100   Fidelity = 0.31901108
# T = 125   Fidelity = 0.32845598
# T = 150   Fidelity = 0.34033537
# T = 175   Fidelity = 0.34244661
# T = 200   Fidelity = 0.35191633
# T = 225   Fidelity = 0.35805809
# T = 250   Fidelity = 0.35899689
# T = 275   Fidelity = 0.37143849
# T = 300   Fidelity = 0.36994640
# T = 400   Fidelity = 0.33688521
# T = 500   Fidelity = 0.37723297
# T = 600   Fidelity = 0.41835257
# T = 700   Fidelity = 0.42044921
# T = 800   Fidelity = 0.43755614
# T = 900   Fidelity = 0.44578111
# T = 1000  Fidelity = 0.47127220
# T = 1010  Fidelity = 0.41588744
# T = 1020  Fidelity = 0.39650077
# T = 1030  Fidelity = 0.44890855
# T = 1040  Fidelity = 0.48129727
# T = 1050  Fidelity = 0.46862232
# T = 1060  Fidelity = 0.41024213
# T = 1070  Fidelity = 0.36010160
# T = 1080  Fidelity = 0.44187557
# T = 1090  Fidelity = 0.47371682
# T = 1100  Fidelity = 0.38893407
# T = 1200  Fidelity = 0.46390851
# T = 1300  Fidelity = 0.48844481
# T = 1400  Fidelity = 0.45969135
# T = 1500  Fidelity = 0.46015088
# T = 2000  Fidelity = 0.45782731
# T = 2100  Fidelity = 0.47302702
# T = 2110  Fidelity = 0.46079579
# T = 2120  Fidelity = 0.44534564
# T = 2130  Fidelity = 0.45841222
# T = 2140  Fidelity = 0.43786267
# T = 2150  Fidelity = 0.43892122
# T = 2160  Fidelity = 0.44205644
# T = 2170  Fidelity = 0.42419524
# T = 2180  Fidelity = 0.41477607
# T = 2190  Fidelity = 0.43965136
# T = 2200  Fidelity = 0.43329439
# T = 2300  Fidelity = 0.48318569
# T = 2400  Fidelity = 0.49650267
# T = 2500  Fidelity = 0.46338753
# T = 2600  Fidelity = 0.48047236
# T = 2700  Fidelity = 0.49909447
# T = 2800  Fidelity = 0.47450896
# T = 2900  Fidelity = 0.50482734
# T = 3000  Fidelity = 0.50538831
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.24417142e-04
# P0     = 0.08075769
# P1     = 0.07282917
# P0+P1  = 0.15358687
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 9.79040346e-05
# T = 1     Fidelity = 0.04772528
# T = 2     Fidelity = 0.09163597
# T = 5     Fidelity = 0.23551243
# T = 10    Fidelity = 0.25959876
# T = 20    Fidelity = 0.28505751
# T = 30    Fidelity = 0.30792350
# T = 40    Fidelity = 0.33053150
# T = 50    Fidelity = 0.34842594
# T = 75    Fidelity = 0.36871701
# T = 100   Fidelity = 0.38464167
# T = 125   Fidelity = 0.40361984
# T = 150   Fidelity = 0.41211769
# T = 175   Fidelity = 0.42197572
# T = 200   Fidelity = 0.43300564
# T = 225   Fidelity = 0.43675199
# T = 250   Fidelity = 0.44450487
# T = 275   Fidelity = 0.45243111
# T = 300   Fidelity = 0.45037153
# T = 400   Fidelity = 0.46912722
# T = 500   Fidelity = 0.44829694
# T = 600   Fidelity = 0.48338876
# T = 700   Fidelity = 0.47965503
# T = 800   Fidelity = 0.49658740
# T = 900   Fidelity = 0.49955130
# T = 1000  Fidelity = 0.46724413
# T = 1010  Fidelity = 0.49367810
# T = 1020  Fidelity = 0.47550733
# T = 1030  Fidelity = 0.46607370
# T = 1040  Fidelity = 0.49020825
# T = 1050  Fidelity = 0.49168914
# T = 1060  Fidelity = 0.46721680
# T = 1070  Fidelity = 0.49775545
# T = 1080  Fidelity = 0.49092488
# T = 1090  Fidelity = 0.50095148
# T = 1100  Fidelity = 0.48717087
# T = 1200  Fidelity = 0.47989953
# T = 1300  Fidelity = 0.49565538
# T = 1400  Fidelity = 0.46408434
# T = 1500  Fidelity = 0.48536145
# T = 2000  Fidelity = 0.49469568
# T = 2100  Fidelity = 0.50610784
# T = 2110  Fidelity = 0.50313140
# T = 2120  Fidelity = 0.49341456
# T = 2130  Fidelity = 0.49022755
# T = 2140  Fidelity = 0.49784229
# T = 2150  Fidelity = 0.50178854
# T = 2160  Fidelity = 0.50641972
# T = 2170  Fidelity = 0.50322995
# T = 2180  Fidelity = 0.48927466
# T = 2190  Fidelity = 0.49534697
# T = 2200  Fidelity = 0.49007436
# T = 2300  Fidelity = 0.47416808
# T = 2400  Fidelity = 0.50987535
# T = 2500  Fidelity = 0.49297109
# T = 2600  Fidelity = 0.43023911
# T = 2700  Fidelity = 0.45358141
# T = 2800  Fidelity = 0.45060694
# T = 2900  Fidelity = 0.46264910
# T = 3000  Fidelity = 0.40160581
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.13589115e-04
# P0     = 0.07926748
# P1     = 0.07712708
# P0+P1  = 0.15639456
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 9.56243266e-05
# T = 1     Fidelity = 0.05027000
# T = 2     Fidelity = 0.09064812
# T = 5     Fidelity = 0.25527368
# T = 10    Fidelity = 0.29340452
# T = 20    Fidelity = 0.33460187
# T = 30    Fidelity = 0.36224097
# T = 40    Fidelity = 0.38280723
# T = 50    Fidelity = 0.39910340
# T = 75    Fidelity = 0.42811791
# T = 100   Fidelity = 0.44724119
# T = 125   Fidelity = 0.46066910
# T = 150   Fidelity = 0.47045238
# T = 175   Fidelity = 0.47774030
# T = 200   Fidelity = 0.48307285
# T = 225   Fidelity = 0.48725587
# T = 250   Fidelity = 0.49027854
# T = 275   Fidelity = 0.49235406
# T = 300   Fidelity = 0.49350689
# T = 400   Fidelity = 0.49116578
# T = 500   Fidelity = 0.50013079
# T = 600   Fidelity = 0.49442226
# T = 700   Fidelity = 0.50071791
# T = 800   Fidelity = 0.48793430
# T = 900   Fidelity = 0.50406892
# T = 1000  Fidelity = 0.48794968
# T = 1010  Fidelity = 0.50213553
# T = 1020  Fidelity = 0.49199745
# T = 1030  Fidelity = 0.49173574
# T = 1040  Fidelity = 0.50207291
# T = 1050  Fidelity = 0.49621705
# T = 1060  Fidelity = 0.47721967
# T = 1070  Fidelity = 0.49684610
# T = 1080  Fidelity = 0.48523177
# T = 1090  Fidelity = 0.50181914
# T = 1100  Fidelity = 0.49204472
# T = 1200  Fidelity = 0.49189236
# T = 1300  Fidelity = 0.50577956
# T = 1400  Fidelity = 0.45951041
# T = 1500  Fidelity = 0.49049801
# T = 2000  Fidelity = 0.42695479
# T = 2100  Fidelity = 0.43051804
# T = 2110  Fidelity = 0.47502708
# T = 2120  Fidelity = 0.44511733
# T = 2130  Fidelity = 0.44579266
# T = 2140  Fidelity = 0.45826492
# T = 2150  Fidelity = 0.43016892
# T = 2160  Fidelity = 0.42331277
# T = 2170  Fidelity = 0.44262125
# T = 2180  Fidelity = 0.44124421
# T = 2190  Fidelity = 0.42553889
# T = 2200  Fidelity = 0.38997288
# T = 2300  Fidelity = 0.47346937
# T = 2400  Fidelity = 0.46925953
# T = 2500  Fidelity = 0.43047554
# T = 2600  Fidelity = 0.48713462
# T = 2700  Fidelity = 0.49293722
# T = 2800  Fidelity = 0.46524684
# T = 2900  Fidelity = 0.50748004
# T = 3000  Fidelity = 0.50906056
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.05026659e-04
# P0     = 0.12272573
# P1     = 0.12117035
# P0+P1  = 0.24389607
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 9.37092431e-05
# T = 1     Fidelity = 0.05474008
# T = 2     Fidelity = 0.09388739
# T = 5     Fidelity = 0.28210036
# T = 10    Fidelity = 0.33474440
# T = 20    Fidelity = 0.39257193
# T = 30    Fidelity = 0.42427506
# T = 40    Fidelity = 0.44457851
# T = 50    Fidelity = 0.45845994
# T = 75    Fidelity = 0.47931622
# T = 100   Fidelity = 0.49073268
# T = 125   Fidelity = 0.49764228
# T = 150   Fidelity = 0.50188776
# T = 175   Fidelity = 0.50437484
# T = 200   Fidelity = 0.50560239
# T = 225   Fidelity = 0.50636473
# T = 250   Fidelity = 0.50672118
# T = 275   Fidelity = 0.50699614
# T = 300   Fidelity = 0.50693454
# T = 400   Fidelity = 0.49473397
# T = 500   Fidelity = 0.50031879
# T = 600   Fidelity = 0.50822411
# T = 700   Fidelity = 0.50113570
# T = 800   Fidelity = 0.49744400
# T = 900   Fidelity = 0.49386694
# T = 1000  Fidelity = 0.48917184
# T = 1010  Fidelity = 0.51125171
# T = 1020  Fidelity = 0.50350623
# T = 1030  Fidelity = 0.50467172
# T = 1040  Fidelity = 0.50998015
# T = 1050  Fidelity = 0.49065356
# T = 1060  Fidelity = 0.50944631
# T = 1070  Fidelity = 0.51040367
# T = 1080  Fidelity = 0.47975110
# T = 1090  Fidelity = 0.49487867
# T = 1100  Fidelity = 0.50438334
# T = 1200  Fidelity = 0.50075809
# T = 1300  Fidelity = 0.47890010
# T = 1400  Fidelity = 0.47986787
# T = 1500  Fidelity = 0.48004551
# T = 2000  Fidelity = 0.48809926
# T = 2100  Fidelity = 0.49760162
# T = 2110  Fidelity = 0.51593071
# T = 2120  Fidelity = 0.50818551
# T = 2130  Fidelity = 0.51378118
# T = 2140  Fidelity = 0.51843707
# T = 2150  Fidelity = 0.51244868
# T = 2160  Fidelity = 0.50572051
# T = 2170  Fidelity = 0.50310842
# T = 2180  Fidelity = 0.51039971
# T = 2190  Fidelity = 0.51461247
# T = 2200  Fidelity = 0.50847597
# T = 2300  Fidelity = 0.51270834
# T = 2400  Fidelity = 0.51632891
# T = 2500  Fidelity = 0.51611859
# T = 2600  Fidelity = 0.48135537
# T = 2700  Fidelity = 0.51309834
# T = 2800  Fidelity = 0.49446930
# T = 2900  Fidelity = 0.51965318
# T = 3000  Fidelity = 0.50673168
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.78352675e-05
# P0     = 0.10394243
# P1     = 0.10004833
# P0+P1  = 0.20399076
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 9.20598135e-05
# T = 1     Fidelity = 0.06522680
# T = 2     Fidelity = 0.10732797
# T = 5     Fidelity = 0.33516814
# T = 10    Fidelity = 0.40363788
# T = 20    Fidelity = 0.46638819
# T = 30    Fidelity = 0.49759504
# T = 40    Fidelity = 0.51814258
# T = 50    Fidelity = 0.53226093
# T = 75    Fidelity = 0.54740269
# T = 100   Fidelity = 0.55046843
# T = 125   Fidelity = 0.55324425
# T = 150   Fidelity = 0.55462184
# T = 175   Fidelity = 0.55471979
# T = 200   Fidelity = 0.55566558
# T = 225   Fidelity = 0.55597541
# T = 250   Fidelity = 0.55584844
# T = 275   Fidelity = 0.55630088
# T = 300   Fidelity = 0.55537710
# T = 400   Fidelity = 0.54623199
# T = 500   Fidelity = 0.54952732
# T = 600   Fidelity = 0.55278990
# T = 700   Fidelity = 0.55304898
# T = 800   Fidelity = 0.54817921
# T = 900   Fidelity = 0.55334291
# T = 1000  Fidelity = 0.53156305
# T = 1010  Fidelity = 0.55573023
# T = 1020  Fidelity = 0.53828955
# T = 1030  Fidelity = 0.56000280
# T = 1040  Fidelity = 0.53872774
# T = 1050  Fidelity = 0.55351488
# T = 1060  Fidelity = 0.54390968
# T = 1070  Fidelity = 0.53642042
# T = 1080  Fidelity = 0.53476312
# T = 1090  Fidelity = 0.54730494
# T = 1100  Fidelity = 0.55275482
# T = 1200  Fidelity = 0.53692118
# T = 1300  Fidelity = 0.52092139
# T = 1400  Fidelity = 0.51725170
# T = 1500  Fidelity = 0.52356098
# T = 2000  Fidelity = 0.55329976
# T = 2100  Fidelity = 0.55564088
# T = 2110  Fidelity = 0.55424571
# T = 2120  Fidelity = 0.56515700
# T = 2130  Fidelity = 0.56074284
# T = 2140  Fidelity = 0.56651947
# T = 2150  Fidelity = 0.53441975
# T = 2160  Fidelity = 0.54900653
# T = 2170  Fidelity = 0.56320076
# T = 2180  Fidelity = 0.54927627
# T = 2190  Fidelity = 0.56236049
# T = 2200  Fidelity = 0.55748208
# T = 2300  Fidelity = 0.56039825
# T = 2400  Fidelity = 0.55696574
# T = 2500  Fidelity = 0.55758065
# T = 2600  Fidelity = 0.55743996
# T = 2700  Fidelity = 0.51911727
# T = 2800  Fidelity = 0.53679768
# T = 2900  Fidelity = 0.54540739
# T = 3000  Fidelity = 0.56267898
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 9.23373761e-05
# P0     = 0.14583203
# P1     = 0.11630519
# P0+P1  = 0.26213722
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.62949858
# T = 2     Fidelity = 0.65796827
# T = 5     Fidelity = 0.71352814
# T = 10    Fidelity = 0.76686053
# T = 20    Fidelity = 0.83234912
# T = 30    Fidelity = 0.87194355
# T = 40    Fidelity = 0.90023124
# T = 50    Fidelity = 0.91995556
# T = 75    Fidelity = 0.95058536
# T = 100   Fidelity = 0.96479697
# T = 125   Fidelity = 0.97361144
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.311
# ================================================================================
# Minimum path gap = 5.19764834e-01
# T = 1     Fidelity = 0.70465439
# T = 2     Fidelity = 0.77508226
# T = 5     Fidelity = 0.82342696
# T = 10    Fidelity = 0.85283377
# T = 20    Fidelity = 0.88060000
# T = 30    Fidelity = 0.89787038
# T = 40    Fidelity = 0.91097348
# T = 50    Fidelity = 0.92047304
# T = 75    Fidelity = 0.93754473
# T = 100   Fidelity = 0.94815641
# T = 125   Fidelity = 0.95369345
# T = 150   Fidelity = 0.95850877
# T = 175   Fidelity = 0.96462318
# T = 200   Fidelity = 0.97225153
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.522
# ================================================================================
# Minimum path gap = 3.21398905e-01
# T = 1     Fidelity = 0.05163020
# T = 2     Fidelity = 0.19646977
# T = 5     Fidelity = 0.84867460
# T = 10    Fidelity = 0.97006620
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.733
# ================================================================================
# Minimum path gap = 2.64154074e-01
# T = 1     Fidelity = 0.11314460
# T = 2     Fidelity = 0.33337568
# T = 5     Fidelity = 0.84592636
# T = 10    Fidelity = 0.91480711
# T = 20    Fidelity = 0.99919043
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.944
# ================================================================================
# Minimum path gap = 2.26024680e-01
# T = 1     Fidelity = 0.16830136
# T = 2     Fidelity = 0.40069006
# T = 5     Fidelity = 0.89911553
# T = 10    Fidelity = 0.94667689
# T = 20    Fidelity = 0.99428059
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.156
# ================================================================================
# Minimum path gap = 2.01656789e-01
# T = 1     Fidelity = 0.21043992
# T = 2     Fidelity = 0.42986845
# T = 5     Fidelity = 0.87828852
# T = 10    Fidelity = 0.92163208
# T = 20    Fidelity = 0.97135234
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.93673930e-01
# T = 1     Fidelity = 0.21740802
# T = 2     Fidelity = 0.40424968
# T = 5     Fidelity = 0.82689829
# T = 10    Fidelity = 0.86607859
# T = 20    Fidelity = 0.90859500
# T = 30    Fidelity = 0.93511590
# T = 40    Fidelity = 0.94712286
# T = 50    Fidelity = 0.94895958
# T = 75    Fidelity = 0.96227377
# T = 100   Fidelity = 0.96563842
# T = 125   Fidelity = 0.97416789
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.578
# ================================================================================
# Minimum path gap = 2.03071995e-01
# T = 1     Fidelity = 0.20115589
# T = 2     Fidelity = 0.34999175
# T = 5     Fidelity = 0.74546965
# T = 10    Fidelity = 0.79317433
# T = 20    Fidelity = 0.83591448
# T = 30    Fidelity = 0.86341953
# T = 40    Fidelity = 0.88697615
# T = 50    Fidelity = 0.90638629
# T = 75    Fidelity = 0.93062972
# T = 100   Fidelity = 0.94181404
# T = 125   Fidelity = 0.95506531
# T = 150   Fidelity = 0.96259164
# T = 175   Fidelity = 0.96709072
# T = 200   Fidelity = 0.97286072
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.789
# ================================================================================
# Minimum path gap = 2.25515049e-01
# T = 1     Fidelity = 0.18026879
# T = 2     Fidelity = 0.29836829
# T = 5     Fidelity = 0.67075981
# T = 10    Fidelity = 0.73259611
# T = 20    Fidelity = 0.79355433
# T = 30    Fidelity = 0.82963596
# T = 40    Fidelity = 0.85616836
# T = 50    Fidelity = 0.87739488
# T = 75    Fidelity = 0.91485796
# T = 100   Fidelity = 0.93877858
# T = 125   Fidelity = 0.95471632
# T = 150   Fidelity = 0.96542817
# T = 175   Fidelity = 0.97255024
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.48783584e-01
# T = 1     Fidelity = 0.16426964
# T = 2     Fidelity = 0.26156504
# T = 5     Fidelity = 0.62024196
# T = 10    Fidelity = 0.69470603
# T = 20    Fidelity = 0.77255675
# T = 30    Fidelity = 0.82168348
# T = 40    Fidelity = 0.85820109
# T = 50    Fidelity = 0.88627219
# T = 75    Fidelity = 0.93176880
# T = 100   Fidelity = 0.95685755
# T = 125   Fidelity = 0.97136698
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.59472102e+00
# T = 1     Fidelity = 0.99358551
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.311
# ================================================================================
# Minimum path gap = 1.58498916e+00
# T = 1     Fidelity = 0.89710754
# T = 2     Fidelity = 0.95274808
# T = 5     Fidelity = 0.98560356
#
# Minimum T for Fidelity >= 0.97 : 5
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.522
# ================================================================================
# Minimum path gap = 1.31621635e+00
# T = 1     Fidelity = 0.10074661
# T = 2     Fidelity = 0.29835796
# T = 5     Fidelity = 0.80855155
# T = 10    Fidelity = 0.99309631
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.733
# ================================================================================
# Minimum path gap = 1.40805723e+00
# T = 1     Fidelity = 0.13241584
# T = 2     Fidelity = 0.37998267
# T = 5     Fidelity = 0.80822950
# T = 10    Fidelity = 0.92206178
# T = 20    Fidelity = 0.99611800
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.944
# ================================================================================
# Minimum path gap = 1.38481786e+00
# T = 1     Fidelity = 0.23645078
# T = 2     Fidelity = 0.53324878
# T = 5     Fidelity = 0.91878025
# T = 10    Fidelity = 0.98336352
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.156
# ================================================================================
# Minimum path gap = 1.34302163e+00
# T = 1     Fidelity = 0.30533369
# T = 2     Fidelity = 0.59362195
# T = 5     Fidelity = 0.91568155
# T = 10    Fidelity = 0.98265159
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.367
# ================================================================================
# Minimum path gap = 1.29217279e+00
# T = 1     Fidelity = 0.36142579
# T = 2     Fidelity = 0.63564262
# T = 5     Fidelity = 0.93287314
# T = 10    Fidelity = 0.98444945
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.578
# ================================================================================
# Minimum path gap = 1.23335459e+00
# T = 1     Fidelity = 0.40231033
# T = 2     Fidelity = 0.65994132
# T = 5     Fidelity = 0.93966036
# T = 10    Fidelity = 0.98302944
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 1.789
# ================================================================================
# Minimum path gap = 1.17426012e+00
# T = 1     Fidelity = 0.43987825
# T = 2     Fidelity = 0.68175161
# T = 5     Fidelity = 0.94422284
# T = 10    Fidelity = 0.98201779
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.12109308e+00
# T = 1     Fidelity = 0.47116008
# T = 2     Fidelity = 0.69832928
# T = 5     Fidelity = 0.94924042
# T = 10    Fidelity = 0.98135503
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ====================================================================================================================================================================================
# FINAL ADIABATIC SUMMARY
# ====================================================================================================================================================================================
# Case           lambda    T_min     Best Fidelity     Delta_min         P0          P1          P0+P1
# ====================================================================================================================================================================================
# Symmetric      0.100     400       0.9788004242      3.07240439e-04    None        None        None
# Symmetric      0.311     150       0.9761791713      1.17908350e-06    None        None        None
# Symmetric      0.522     100       0.9878257919      2.94880934e-07    None        None        None
# Symmetric      0.733     75        0.9804705511      1.58119044e-07    None        None        None
# Symmetric      0.944     50        0.9700958891      6.89654396e-08    None        None        None
# Symmetric      1.156     40        0.9861301395      1.17592580e-07    None        None        None
# Symmetric      1.367     30        0.9719795746      2.47961159e-07    None        None        None
# Symmetric      1.578     40        0.9838853079      3.56990609e-07    None        None        None
# Symmetric      1.789     40        0.9938365695      2.45005900e-06    None        None        None
# Symmetric      2.000     30        0.9840001055      1.44257094e-05    None        None        None
# Weak SSB       0.100     75        0.9821536909      1.80997252e-02    None        None        None
# Weak SSB       0.311     1060      0.9710969945      1.50638569e-02    None        None        None
# Weak SSB       0.522     None      0.5098269369      1.29389510e-04    0.126753    0.001101    0.127854
# Weak SSB       0.733     None      0.4570376573      1.10289833e-04    0.046822    0.014132    0.060955
# Weak SSB       0.944     None      0.4696577768      1.04207670e-04    0.126172    0.096341    0.222513
# Weak SSB       1.156     None      0.5053883118      1.00641152e-04    0.080758    0.072829    0.153587
# Weak SSB       1.367     None      0.5098753468      9.79040346e-05    0.079267    0.077127    0.156395
# Weak SSB       1.578     None      0.5090605616      9.56243266e-05    0.122726    0.12117     0.243896
# Weak SSB       1.789     None      0.5196531816      9.37092431e-05    0.103942    0.100048    0.203991
# Weak SSB       2.000     None      0.5665194659      9.20598135e-05    0.145832    0.116305    0.262137
# Weak SSB optimised0.100     125       0.9736114398      8.67181393e-01    None        None        None
# Weak SSB optimised0.311     200       0.9722515314      5.19764834e-01    None        None        None
# Weak SSB optimised0.522     10        0.9700662024      3.21398905e-01    None        None        None
# Weak SSB optimised0.733     20        0.9991904310      2.64154074e-01    None        None        None
# Weak SSB optimised0.944     20        0.9942805879      2.26024680e-01    None        None        None
# Weak SSB optimised1.156     20        0.9713523449      2.01656789e-01    None        None        None
# Weak SSB optimised1.367     125       0.9741678899      1.93673930e-01    None        None        None
# Weak SSB optimised1.578     200       0.9728607156      2.03071995e-01    None        None        None
# Weak SSB optimised1.789     175       0.9725502409      2.25515049e-01    None        None        None
# Weak SSB optimised2.000     125       0.9713669785      2.48783584e-01    None        None        None
# Strong SSB     0.100     1         0.9935855087      3.59472102e+00    None        None        None
# Strong SSB     0.311     5         0.9856035612      1.58498916e+00    None        None        None
# Strong SSB     0.522     10        0.9930963123      1.31621635e+00    None        None        None
# Strong SSB     0.733     20        0.9961180030      1.40805723e+00    None        None        None
# Strong SSB     0.944     10        0.9833635246      1.38481786e+00    None        None        None
# Strong SSB     1.156     10        0.9826515862      1.34302163e+00    None        None        None
# Strong SSB     1.367     10        0.9844494513      1.29217279e+00    None        None        None
# Strong SSB     1.578     10        0.9830294370      1.23335459e+00    None        None        None
# Strong SSB     1.789     10        0.9820177867      1.17426012e+00    None        None        None
# Strong SSB     2.000     10        0.9813550338      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.1556
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7333

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ', color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_exact = match['psi_exact']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
