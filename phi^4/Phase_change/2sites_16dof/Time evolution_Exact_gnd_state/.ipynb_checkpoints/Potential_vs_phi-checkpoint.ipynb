# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

import matplotlib.pyplot as plt


# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # -------------------------------------------------------- 

 
    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756907
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
nq_site = 4

nqubits = 2 * nq_site

mu = 1.0

m0_list=[1.0,2.0,-1.0,-2.0]

# ============================================================
# Parameter sets
# ============================================================

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
     {
        "label": "Weak SSB",
        "mI2": -1.0,
        "f": 1*1e-5
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ============================================================
# Lambda scan
# ============================================================

lambda_list = np.linspace(0.1, 2.0, 10)

# ============================================================
# Storage
# ============================================================

all_results = []



def two_site_hs(
    nq,
    mu,
    mI2,
    m0_sq,
    lam,
    f,
    s
):

    Hloc = two_site_hloc(
        nq=nq,
        mu=mu,
        mI2=mI2,
        lam=lam,
        f=f
    )

    Hc = two_site_hc(
        nq=nq,
        mu=mu,
        mI2=mI2,
        m0_sq=m0_sq
    )

    return Hloc + s*Hc




# ============================================================
# Main loop
# ============================================================

all_results = []

for m0_sq in m0_list:

    print("\n")
    print("#"*80)
    print(f"m0² = {m0_sq}")
    print("#"*80)

    # =======================================================
    # Loop over the four physical cases
    # =======================================================

    for params in parameter_sets:

        label = params["label"]
        mI2   = params["mI2"]
        f     = params["f"]

        case_results = []

        # ---------------------------------------------------
        # Loop over lambda
        # ---------------------------------------------------

        for lam in lambda_list:

            # Build total Hamiltonian

            Hs_sparse = two_site_hs(

                nq=nq_site,

                mu=mu,

                mI2=mI2,

                m0_sq=m0_sq,

                lam=lam,

                f=f,

                s=1.0
            )

            # Lowest two eigenstates

            evals, evecs = eigsh(

                Hs_sparse,

                k=2,

                which='SA'
            )

            idx = np.argsort(evals)

            evals = evals[idx]
            evecs = evecs[:, idx]

            E0 = evals[0]
            E1 = evals[1]

            psi0 = evecs[:, 0]
            psi1 = evecs[:, 1]

            gap = E1 - E0

            # Store

            result = {

                "case": label,

                "m0_sq": m0_sq,

                "lambda": lam,

                "mI2": mI2,

                "f": f,

                "E0": E0,

                "E1": E1,

                "gap": gap,

                "psi0": psi0,

                "psi1": psi1
            }

            case_results.append(result)
            all_results.append(result)

        # ===================================================
        # Print ONE summary after all lambda values
        # ===================================================

        print("\n")
        print("="*90)
        print(f"m0² = {m0_sq}      Case = {label}")
        print("="*90)

        print(

            f"{'lambda':<12}"

            f"{'E0':<18}"

            f"{'E1':<18}"

            f"{'Gap':<18}"
        )

        print("-"*90)

        for r in case_results:

            print(

                f"{r['lambda']:<12.4f}"

                f"{r['E0']:<18.10f}"

                f"{r['E1']:<18.10f}"

                f"{r['gap']:<18.10f}"
            )
# Out:
# ################################################################################
# m0² = 1.0
# ################################################################################
#
#
# ==========================================================================================
# m0² = 1.0      Case = Symmetric
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      1.3698805190      2.3795897301      1.0097092111
# 0.3111      1.3778182555      2.4071288286      1.0293105731
# 0.5222      1.3855077234      2.4333626999      1.0478549765
# 0.7333      1.3929736049      2.4584667213      1.0654931164
# 0.9444      1.4002363572      2.4825780373      1.0823416801
# 1.1556      1.4073132214      2.5058067351      1.0984935137
# 1.3667      1.4142189288      2.5282430329      1.1140241041
# 1.5778      1.4209662109      2.5499621250      1.1289959141
# 1.7889      1.4275661795      2.5710275723      1.1434613928
# 2.0000      1.4340286146      2.5914937464      1.1574651318
#
#
# ==========================================================================================
# m0² = 1.0      Case = Weak SSB
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      1.3698805190      2.3795897300      1.0097092111
# 0.3111      1.3778182554      2.4071288285      1.0293105731
# 0.5222      1.3855077233      2.4333626998      1.0478549766
# 0.7333      1.3929736048      2.4584667212      1.0654931165
# 0.9444      1.4002363571      2.4825780372      1.0823416802
# 1.1556      1.4073132213      2.5058067351      1.0984935137
# 1.3667      1.4142189287      2.5282430328      1.1140241042
# 1.5778      1.4209662108      2.5499621250      1.1289959142
# 1.7889      1.4275661794      2.5710275723      1.1434613928
# 2.0000      1.4340286145      2.5914937463      1.1574651318
#
#
# ==========================================================================================
# m0² = 1.0      Case = Weak SSB optimised
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      1.3674284269      2.3771956845      1.0097672576
# 0.3111      1.3754588284      2.4049258858      1.0294670574
# 0.5222      1.3832312605      2.4313170798      1.0480858193
# 0.7333      1.3907720903      2.4565533238      1.0657812335
# 0.9444      1.3981030558      2.4807776104      1.0826745546
# 1.1556      1.4052423967      2.5041041372      1.0988617405
# 1.3667      1.4122056382      2.5266261092      1.1144204709
# 1.5778      1.4190061547      2.5484209509      1.1294147961
# 1.7889      1.4256555851      2.5695539262      1.1438983411
# 2.0000      1.4321641475      2.5900807327      1.1579165852
#
#
# ==========================================================================================
# m0² = 1.0      Case = Strong SSB
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      1.1251349411      2.1405908106      1.0154558695
# 0.3111      1.1430502301      2.1876241192      1.0445738891
# 0.5222      1.1595005875      2.2296587468      1.0701581593
# 0.7333      1.1747668413      2.2679227595      1.0931559183
# 0.9444      1.1890502609      2.3032180297      1.1141677688
# 1.1556      1.2025012629      2.3361018901      1.1336006273
# 1.3667      1.2152358860      2.3669797727      1.1517438867
# 1.5778      1.2273459202      2.3961571064      1.1688111861
# 1.7889      1.2389054664      2.4238704725      1.1849650062
# 2.0000      1.2499753645      2.4503073340      1.2003319695
#
#
# ################################################################################
# m0² = 2.0
# ################################################################################
#
#
# ==========================================================================================
# m0² = 2.0      Case = Symmetric
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      1.7093757072      3.1288907151      1.4195150079
# 0.3111      1.7141156605      3.1446150901      1.4304994296
# 0.5222      1.7187903907      3.1600081816      1.4412177910
# 0.7333      1.7234028609      3.1750910756      1.4516882147
# 0.9444      1.7279557883      3.1898825313      1.4619267430
# 1.1556      1.7324516735      3.2043993459      1.4719476724
# 1.3667      1.7368928269      3.2186566465      1.4817638196
# 1.5778      1.7412813893      3.2326681252      1.4913867359
# 1.7889      1.7456193507      3.2464462326      1.5008268818
# 2.0000      1.7499085656      3.2600023362      1.5100937706
#
#
# ==========================================================================================
# m0² = 2.0      Case = Weak SSB
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      1.7093757071      3.1288907150      1.4195150079
# 0.3111      1.7141156605      3.1446150901      1.4304994296
# 0.5222      1.7187903906      3.1600081816      1.4412177910
# 0.7333      1.7234028609      3.1750910756      1.4516882147
# 0.9444      1.7279557882      3.1898825312      1.4619267430
# 1.1556      1.7324516735      3.2043993458      1.4719476724
# 1.3667      1.7368928268      3.2186566464      1.4817638196
# 1.5778      1.7412813893      3.2326681252      1.4913867359
# 1.7889      1.7456193507      3.2464462325      1.5008268818
# 2.0000      1.7499085656      3.2600023362      1.5100937706
#
#
# ==========================================================================================
# m0² = 2.0      Case = Weak SSB optimised
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      1.7081350310      3.1276607795      1.4195257485
# 0.3111      1.7128939794      3.1434248723      1.4305308929
# 0.5222      1.7175868343      3.1588545164      1.4412676821
# 0.7333      1.7222166294      3.1739711933      1.4517545639
# 0.9444      1.7267861440      3.1887939907      1.4620078467
# 1.1556      1.7312979338      3.2033399819      1.4720420481
# 1.3667      1.7357543582      3.2176245278      1.4818701695
# 1.5778      1.7401576022      3.2316615203      1.4915039182
# 1.7889      1.7445096951      3.2454635819      1.5009538869
# 2.0000      1.7488125271      3.2590422293      1.5102297022
#
#
# ==========================================================================================
# m0² = 2.0      Case = Strong SSB
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      1.5853390789      3.0059260002      1.4205869212
# 0.3111      1.5920363970      3.0256695803      1.4336331833
# 0.5222      1.5985727163      3.0447498540      1.4461771376
# 0.7333      1.6049594979      3.0632318237      1.4582723258
# 0.9444      1.6112068359      3.0811701926      1.4699633567
# 1.1556      1.6173236850      3.0986115582      1.4812878732
# 1.3667      1.6233180397      3.1155960301      1.4922779905
# 1.5778      1.6291970775      3.1321584488      1.5029613714
# 1.7889      1.6349672752      3.1483293208      1.5133620456
# 2.0000      1.6406345039      3.1641355482      1.5235010443
#
#
# ################################################################################
# m0² = -1.0
# ################################################################################
#
#
# ==========================================================================================
# m0² = -1.0      Case = Symmetric
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      -15.9266527163    -15.9134062226    0.0132464937
# 0.3111      -8.1265665027     -8.1242527167     0.0023137860
# 0.5222      -4.0703384243     -4.0703379894     0.0000004349
# 0.7333      -2.4281168930     -2.4281076587     0.0000092343
# 0.9444      -1.5277718121     -1.5275286666     0.0002431455
# 1.1556      -0.9628136699     -0.9609565181     0.0018571518
# 1.3667      -0.5800129203     -0.5727292564     0.0072836640
# 1.5778      -0.3086149367     -0.2894881024     0.0191268343
# 1.7889      -0.1110785019     -0.0724452074     0.0386332944
# 2.0000      0.0355015518      0.1006326760      0.0651311241
#
#
# ==========================================================================================
# m0² = -1.0      Case = Weak SSB
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      -15.9266533627    -15.9134055762    0.0132477865
# 0.3111      -8.1265697819     -8.1242494375     0.0023203444
# 0.5222      -4.0704031723     -4.0702732415     0.0001299308
# 0.7333      -2.4281661892     -2.4280583626     0.0001078265
# 0.9444      -1.5277803361     -1.5275201428     0.0002601933
# 1.1556      -0.9628145684     -0.9609556198     0.0018589487
# 1.3667      -0.5800131037     -0.5727290732     0.0072840305
# 1.5778      -0.3086149934     -0.2894880459     0.0191269475
# 1.7889      -0.1110785249     -0.0724451846     0.0386333403
# 2.0000      0.0355015405      0.1006326870      0.0651311465
#
#
# ==========================================================================================
# m0² = -1.0      Case = Weak SSB optimised
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      -16.3828319825    -15.4573572598    0.9254747227
# 0.3111      -8.5621292181     -7.6905080374     0.8716211807
# 0.5222      -4.3965788725     -3.7469583393     0.6496205331
# 0.7333      -2.6982127034     -2.1611010205     0.5371116829
# 0.9444      -1.7608829594     -1.2977784874     0.4631044720
# 1.1556      -1.1679861940     -0.7594989762     0.4084872179
# 1.3667      -0.7611248384     -0.3958672966     0.3652575418
# 1.5778      -0.4662460794     -0.1369140992     0.3293319802
# 1.7889      -0.2445547658     0.0549296653      0.2994844311
# 2.0000      -0.0738729951     0.2028314051      0.2767044002
#
#
# ==========================================================================================
# m0² = -1.0      Case = Strong SSB
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      -20.5527001108    -16.4675383708    4.0851617400
# 0.3111      -12.5547646262    -10.7629581643    1.7918064618
# 0.5222      -7.4488909667     -5.9664360876     1.4824548791
# 0.7333      -5.2524267108     -3.7949168340     1.4575098768
# 0.9444      -3.9895366854     -2.5397598310     1.4497768544
# 1.1556      -3.1599051277     -1.7258030818     1.4341020459
# 1.3667      -2.5699660755     -1.1513586277     1.4186074478
# 1.5778      -2.1267279369     -0.7273404036     1.3993875333
# 1.7889      -1.7800974914     -0.4014902679     1.3786072235
# 2.0000      -1.5008554115     -0.1437665373     1.3570888742
#
#
# ################################################################################
# m0² = -2.0
# ################################################################################
#
#
# ==========================================================================================
# m0² = -2.0      Case = Symmetric
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      -37.6569079060    -37.6389699505    0.0179379555
# 0.3111      -29.2742795244    -29.2593131931    0.0149663314
# 0.5222      -21.0652773608    -21.0571291947    0.0081481662
# 0.7333      -14.1626218880    -14.1625652748    0.0000566132
# 0.9444      -10.5306938390    -10.5306824315    0.0000114075
# 1.1556      -8.1976466763     -8.1976463869     0.0000002894
# 1.3667      -6.6050368958     -6.6050365845     0.0000003114
# 1.5778      -5.4370940410     -5.4370937445     0.0000002964
# 1.7889      -4.5456080144     -4.5456063279     0.0000016865
# 2.0000      -3.8457846874     -3.8457743635     0.0000103239
#
#
# ==========================================================================================
# m0² = -2.0      Case = Weak SSB
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      -37.6569083916    -37.6389694648    0.0179389268
# 0.3111      -29.2742801026    -29.2593126149    0.0149674876
# 0.5222      -21.0652783937    -21.0571281618    0.0081502318
# 0.7333      -14.1626783112    -14.1625088517    0.0001694595
# 0.9444      -10.5307578336    -10.5306184369    0.0001393967
# 1.1556      -8.1977087402     -8.1975843231     0.0001244171
# 1.3667      -6.6050935347     -6.6049799456     0.0001135891
# 1.5778      -5.4371464061     -5.4370413794     0.0001050267
# 1.7889      -4.5456560888     -4.5455582536     0.0000978353
# 2.0000      -3.8458256941     -3.8457333568     0.0000923374
#
#
# ==========================================================================================
# m0² = -2.0      Case = Weak SSB optimised
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      -38.1147272479    -37.1811779948    0.9335492532
# 0.3111      -29.7319913143    -28.8016615998    0.9303297145
# 0.5222      -21.5200694064    -20.6026172742    0.9174521321
# 0.7333      -14.5628940196    -13.7642705884    0.7986234312
# 0.9444      -10.8786716426    -10.1840348124    0.6946368302
# 1.1556      -8.5094092624     -7.8873304777     0.6220787848
# 1.3667      -6.8897159105     -6.3217808629     0.5679350475
# 1.5778      -5.7004018464     -5.1752802283     0.5251216181
# 1.7889      -4.7909218321     -4.3018285114     0.4890933207
# 2.0000      -4.0759530935     -3.6171731742     0.4587799193
#
#
# ==========================================================================================
# m0² = -2.0      Case = Strong SSB
# ==========================================================================================
# lambda      E0                E1                Gap
# ------------------------------------------------------------------------------------------
# 0.1000      -42.3160964536    -34.6364451885    7.6796512651
# 0.3111      -33.9205815588    -28.5191632386    5.4014183202
# 0.5222      -25.6604297751    -22.5081074656    3.1523223095
# 0.7333      -18.2565854149    -16.8453781024    1.4112073125
# 0.9444      -14.0662361140    -12.0075475898    2.0586885242
# 1.1556      -11.3780334823    -9.4583732491     1.9196602332
# 1.3667      -9.5122032346     -7.5154398635     1.9967633711
# 1.5778      -8.1331187164     -6.1655265351     1.9675921813
# 1.7889      -7.0633930322     -5.1203267722     1.9430662599
# 2.0000      -6.2128896499     -4.2717370145     1.9411526353

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,
    
    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
phi_results = []

for r in all_results:

    M = np.real(

        np.vdot(

            r["psi0"],

            Phi_avg @ r["psi0"]
        )
    )

    phi_results.append({

        "case": r["case"],

        "m0_sq": r["m0_sq"],

        "lambda": r["lambda"],

        "phi": M
    })

# %%
#****<phi>*******

import matplotlib.pyplot as plt

m0_value = -1.0

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "green",
    "Weak SSB optimised": "orange",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case in case_colors:

    lam = []
    phi = []

    for r in phi_results:

        if r["m0_sq"] == m0_value and r["case"] == case:

            lam.append(r["lambda"])
            phi.append(r["phi"])

    plt.plot(
        lam,
        phi,
        marker='o',
        linewidth=2,
        color=case_colors[case],
        label=case
    )

plt.xlabel(r'$\lambda$', fontsize=14)
plt.ylabel(r'$\langle\phi\rangle$', fontsize=14)

plt.title(
    rf'Ground-state $\langle\phi\rangle$ vs $\lambda$, $m_0^2={m0_value}$',
    fontsize=15
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

m0_value = -2.0

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "green",
    "Weak SSB optimised": "orange",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case in case_colors:

    lam = []
    phi = []

    for r in phi_results:

        if r["m0_sq"] == m0_value and r["case"] == case:

            lam.append(r["lambda"])
            phi.append(r["phi"])

    plt.plot(
        lam,
        phi,
        marker='o',
        linewidth=2,
        color=case_colors[case],
        label=case
    )

plt.xlabel(r'$\lambda$', fontsize=14)
plt.ylabel(r'$\langle\phi\rangle$', fontsize=14)

plt.title(
    rf'Ground-state $\langle\phi\rangle$ vs $\lambda$, $m_0^2={m0_value}$',
    fontsize=15
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

m0_value = 1.0

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "g",
    "Weak SSB optimised": "orange",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case in case_colors:

    lam = []
    phi = []

    for r in phi_results:

        if r["m0_sq"] == m0_value and r["case"] == case:

            lam.append(r["lambda"])
            phi.append(r["phi"])

    plt.plot(
        lam,
        phi,
        marker='o',
        linewidth=2,
        color=case_colors[case],
        label=case
    )

plt.xlabel(r'$\lambda$', fontsize=14)
plt.ylabel(r'$\langle\phi\rangle$', fontsize=14)

plt.title(
    rf'Ground-state $\langle\phi\rangle$ vs $\lambda$, $m_0^2={m0_value}$',
    fontsize=15
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

m0_value = 2.0

case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "g",
    "Weak SSB optimised": "orange",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case in case_colors:

    lam = []
    phi = []

    for r in phi_results:

        if r["m0_sq"] == m0_value and r["case"] == case:

            lam.append(r["lambda"])
            phi.append(r["phi"])

    plt.plot(
        lam,
        phi,
        marker='o',
        linewidth=2,
        color=case_colors[case],
        label=case
    )

plt.xlabel(r'$\lambda$', fontsize=14)
plt.ylabel(r'$\langle\phi\rangle$', fontsize=14)

plt.title(
    rf'Ground-state $\langle\phi\rangle$ vs $\lambda$, $m_0^2={m0_value}$',
    fontsize=15
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

import numpy as np

phi_data = {}

for r in phi_results:

    key = (r["m0_sq"], r["case"])

    if key not in phi_data:
        phi_data[key] = {
            "lambda": [],
            "phi": []
        }

    phi_data[key]["lambda"].append(r["lambda"])
    phi_data[key]["phi"].append(r["phi"])

# %%
import matplotlib.pyplot as plt

case_colors = {

    "Symmetric": "blue",

    "Weak SSB": "green",

    "Weak SSB optimised": "orange",

    "Strong SSB": "red"
}

for m0_value in [-2.0, -1.0, 1.0, 2.0]:

    plt.figure(figsize=(8,6))

    for case in case_colors:

        key = (m0_value, case)

        if key not in phi_data:
            continue

        lam = np.array(phi_data[key]["lambda"])
        phi = np.array(phi_data[key]["phi"])

        # Sort by lambda
        idx = np.argsort(lam)

        lam = lam[idx]
        phi = phi[idx]

        print(lam)

        # First derivative

        dphi = np.gradient(phi, lam)

        plt.plot(

            lam,

            dphi,

            marker='o',

            linewidth=2,

            color=case_colors[case],

            label=case
        )

    plt.xlabel(r'$\lambda$', fontsize=14)

    plt.ylabel(r'$d\langle\phi\rangle/d\lambda$', fontsize=14)

    plt.title(

        rf'$d\langle\phi\rangle/d\lambda$ vs $\lambda$, $m_0^2={m0_value}$',

        fontsize=15
    )

    plt.grid(True)

    plt.legend()

    plt.tight_layout()

    plt.savefig(

        f"dphi_dlambda_m0_{m0_value}.pdf",

        bbox_inches="tight"
    )

    plt.show()
# Out:
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]
# [0.1        0.31111111 0.52222222 0.73333333 0.94444444 1.15555556
#  1.36666667 1.57777778 1.78888889 2.        ]

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

phi_data = {}

for r in all_results:

    key = (r["m0_sq"], r["case"])

    if key not in phi_data:

        phi_data[key] = {
            "lambda": [],
            "phi": []
        }

    phi_data[key]["lambda"].append(r["lambda"])
    phi_data[key]["phi"].append(r["phi"])

for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

   # Exact ground state of H_loc
    psi_exact = match['psi_exact']

# Adiabatic evolution starts from the exact local ground state
    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)

    elif case == "Strong SSB":

        M_strong.append(M)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 print(adiabatic_results[0].keys())
#       2
#       3 # ============================================================
#       4 # <phi> from evolved state
#
# NameError: name 'adiabatic_results' is not defined

# %%
# ============================================================
# λc from inflection point
# ============================================================

derivatives = {}

for key, data in phi_data.items():

    lam = np.array(data["lambda"])
    phi = np.array(data["phi"])

    order = np.argsort(lam)

    lam = lam[order]
    phi = phi[order]

    d1 = np.gradient(phi, lam)

    d2 = np.gradient(d1, lam)

    d3 = np.gradient(d2, lam)

    derivatives[key] = {

        "lambda": lam,

        "d2": d2,

        "d3": d3
    }

def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)
    return np.nan

lambda_c = {}

for key, data in derivatives.items():

    lambda_c[key] = find_lambda_c(

        data["lambda"],

        data["d2"],

        data["d3"]
    )


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

case_colors = {

    "Symmetric": "blue",

    "Weak SSB": "orange",

    "Weak SSB optimised": "green",

    "Strong SSB": "red"
}

for m0 in sorted(set(r["m0_sq"] for r in all_results)):

    plt.figure(figsize=(8,6))

    for case in case_colors:

        key = (m0, case)

        if key not in derivatives:

            continue

        lam = derivatives[key]["lambda"]

        d2 = derivatives[key]["d2"]

        lamc = lambda_c[key]

        line, = plt.plot(

            lam,

            d2,

            'o-',

            color=case_colors[case],

            label=case
        )

        if not np.isnan(lamc):

            plt.axvline(

                lamc,

                linestyle='--',

                color=line.get_color()
            )

    plt.axhline(

        0,

        color='k',

        linestyle=':'
    )

    plt.xlabel(r'$\lambda$')

    plt.ylabel(

        r'$d^2\langle\phi\rangle/d\lambda^2$'
    )

    plt.title(

        rf'$m_0^2={m0}$'
    )

    plt.legend()

    plt.grid(True)

    plt.tight_layout()

    plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_list,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_list,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_list,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_0^2=1$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 9
#       5 plt.figure(figsize=(8,6))
#       6
#       7 line1, = plt.plot(
#       8     lambda_list,
# ----> 9     dM_sym,
#      10     'o-',
#      11     label='Symmetric',
#      12     color='b'
#
# NameError: name 'dM_sym' is not defined

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
    "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_exact = match['psi_exact']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])
