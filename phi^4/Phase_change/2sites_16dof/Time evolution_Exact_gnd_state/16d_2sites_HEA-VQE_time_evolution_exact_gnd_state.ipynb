# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity

# ============================================================
# Single-site field operators from ladder operators
# ============================================================

def single_site_field_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Local Hilbert dimension
    # -------------------------------------------------------- 

 
    Nphi = 2**nq   # 64 for nq=6

    # --------------------------------------------------------
    # Ladder operator a
    # --------------------------------------------------------

    a = np.zeros((Nphi, Nphi), dtype=complex)

    for n in range(1, Nphi):

        a[n-1, n] = np.sqrt(n)

    # creation operator
    adag = a.conj().T

    # --------------------------------------------------------
    # Field operator
    #
    # Phi = (a + adag)/sqrt(2 mu)
    # --------------------------------------------------------

    Phi = (
        a + adag
    ) / np.sqrt(2 * mu)

    # --------------------------------------------------------
    # Conjugate momentum operator
    #
    # Pi = -i sqrt(mu/2) (a - adag)
    # --------------------------------------------------------

    Pi = (
        -1j
        * np.sqrt(mu / 2)
        * (a - adag)
    )

    # --------------------------------------------------------
    # Numerical Hermiticity cleanup
    # --------------------------------------------------------

    Phi = 0.5 * (Phi + Phi.conj().T)

    Pi = 0.5 * (Pi + Pi.conj().T)

    return csr_matrix(Phi), csr_matrix(Pi)


# ============================================================
# Two-site embedded operators
# ============================================================

def two_site_operators(nq, mu=1.0):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(
        Nphi,
        format='csr',
        dtype=complex
    )

    # --------------------------------------------------------
    # Site 0 operators
    # --------------------------------------------------------

    Phi0 = kron(Phi, I, format='csr')
    Pi0  = kron(Pi,  I, format='csr')

    # --------------------------------------------------------
    # Site 1 operators
    # --------------------------------------------------------

    Phi1 = kron(I, Phi, format='csr')
    Pi1  = kron(I, Pi,  format='csr')

    return Phi0, Pi0, Phi1, Pi1


# ============================================================
# Example
# ============================================================

nq = 4
mu = 1.0

Phi0, Pi0, Phi1, Pi1 = two_site_operators(
    nq,
    mu
)

print("Hilbert dimension =", Phi0.shape[0])

print("Phi0 shape =", Phi0.shape)
print("Pi0 shape  =", Pi0.shape)

print("Phi1 shape =", Phi1.shape)
print("Pi1 shape  =", Pi1.shape)
# Out:
# Hilbert dimension = 256
# Phi0 shape = (256, 256)
# Pi0 shape  = (256, 256)
# Phi1 shape = (256, 256)
# Pi1 shape  = (256, 256)

# %%
import numpy as np
from scipy.sparse import csr_matrix, kron, identity
from scipy.sparse.linalg import eigsh

# ============================================================
# Local single-site Hamiltonian
# ============================================================

def single_site_hloc(Phi, Pi, mI2, lam, f):

    Phi2 = Phi @ Phi
    Phi4 = Phi2 @ Phi2
    Pi2  = Pi @ Pi

    hloc = (
        0.5 * Pi2
        + 0.5 * mI2 * Phi2
        + (lam / 24.0) * Phi4
        + f * Phi
    )

    return hloc

# %%
# ============================================================
# Two-site local Hamiltonian
# ============================================================

def two_site_hloc(nq, mu=1.0,
                  mI2=1.0,
                  lam=1.0,
                  f=1e-3):

    # --------------------------------------------------------
    # Single-site operators
    # --------------------------------------------------------

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    # --------------------------------------------------------
    # Single-site local Hamiltonian
    # --------------------------------------------------------

    hloc = single_site_hloc(Phi, Pi, mI2, lam, f)

    # --------------------------------------------------------
    # Two-site Hamiltonian
    # H = h ⊗ I + I ⊗ h
    # --------------------------------------------------------

    Hloc = (
        kron(hloc, I, format='csr')
        +
        kron(I, hloc, format='csr')
    )

    return Hloc

# %%
# ============================================================
# Exact ground state
# ============================================================

def ground_state(H):

    # smallest algebraic eigenvalue
    evals, evecs = eigsh(H, k=1, which='SA')

    E0 = evals[0]
    psi0 = evecs[:, 0]

    # normalize explicitly
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
# ============================================================
# Example
# ============================================================

nq   = 4
mu   = 1.0
mI2  = 1.0
lam  = 1.0
f    = 1e-5

Hloc = two_site_hloc(
    nq=nq,
    mu=mu,
    mI2=mI2,
    lam=lam,
    f=f
)

E0_loc, psi_loc = ground_state(Hloc)

print("Ground-state energy =", E0_loc)
print("State dimension     =", psi_loc.shape)
print("Norm                =", np.linalg.norm(psi_loc))
# Out:
# Ground-state energy = 1.0554722545756783
# State dimension     = (256,)
# Norm                = 1.0

# %%
# ============================================================
# Convert scalar-field Hamiltonian to Pauli form

# ============================================================

from qiskit.quantum_info import Operator, SparsePauliOp

# ============================================================
# Build two-site Hamiltonian
# ============================================================

Hloc = two_site_hloc(
    nq=4,
    mu=1.0,
    mI2=1.0,
    lam=1.0,
    f=1e-5
)

# ============================================================
# Convert sparse matrix -> dense matrix
# ============================================================

H_dense = Hloc.toarray()

print("Dense Hamiltonian shape =", H_dense.shape)

# ============================================================
# Convert to Qiskit Operator
# ============================================================

H_op = Operator(H_dense)

# ============================================================
# Convert to SparsePauliOp
# ============================================================

print("\nConverting to Pauli representation...\n")

H_pauli = SparsePauliOp.from_operator(H_op)

# ============================================================
# Remove tiny coefficients
# ============================================================

H_pauli = H_pauli.simplify(atol=1e-10)

print("Done.")

# ============================================================
# Number of Pauli terms
# ============================================================

print("\nNumber of Pauli terms =", len(H_pauli))

# ============================================================
# Show first few Pauli terms
# ============================================================

print("\nFirst few Pauli terms:\n")

for pauli, coeff in zip(
    H_pauli.paulis[:10],
    H_pauli.coeffs[:10]
):

    print(f"{coeff:.6f} * {pauli}")
# Out:
# Dense Hamiltonian shape = (256, 256)
#
# Converting to Pauli representation...
#
# Done.
#
# Number of Pauli terms = 111
#
# First few Pauli terms:
#
# 24.062500+0.000000j * IIIIIIII
# 0.000019+0.000000j * IIIIIIIX
# 3.203275+0.000000j * IIIIIIXI
# -0.031443+0.000000j * IIIIIIXZ
# -0.687500+0.000000j * IIIIIIZI
# -0.937500+0.000000j * IIIIIIZZ
# 0.833067+0.000000j * IIIIIXII
# -0.083419+0.000000j * IIIIIXIZ
# 1.669265+0.000000j * IIIIIXXI
# -0.166668+0.000000j * IIIIIXXZ

# %%
# ============================================================
# Remove identity offset
# ============================================================

coeffs = H_pauli.coeffs
paulis = H_pauli.paulis

new_coeffs = []
new_paulis = []

identity_shift = 0.0

for p, c in zip(paulis, coeffs):

    if str(p) == 'I' * nq:

        identity_shift += np.real(c)

    else:

        new_paulis.append(p)
        new_coeffs.append(c)

H_pauli_shifted = SparsePauliOp(
    new_paulis,
    coeffs=new_coeffs
)

print("Removed identity shift =", identity_shift)

print("Remaining Pauli terms =",
      len(H_pauli_shifted))
# Out:
# Removed identity shift = 0.0
# Remaining Pauli terms = 111

# %% [markdown]
# # VQE

# %%
# ============================================================
# Genuine Qiskit VQE on shifted Pauli Hamiltonian (DO NOT RUN THIS CELL)
# ============================================================

import numpy as np

from qiskit import QuantumCircuit
from qiskit.circuit import ParameterVector
from qiskit.quantum_info import Statevector

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SPSA

from qiskit.primitives import StatevectorEstimator


# ============================================================
# Variational circuit
# ============================================================



# ============================================================
# Ansatz
# ============================================================



# ============================================================
# Estimator
# ============================================================

estimator = StatevectorEstimator()

# ============================================================
# Optimizer
# ============================================================

optimizer = SPSA(
    maxiter=5000
)

# ============================================================
# VQE
# ============================================================


# ============================================================
# Run VQE
# ============================================================


# ============================================================
# Shifted energy
# ============================================================

#E_shifted = result.eigenvalue.real

# ============================================================
# Physical energy
# ============================================================

#E_vqe = E_shifted + identity_shift

# ============================================================
# Optimal parameters
# ============================================================



# ============================================================
# Optimized circuit
# ============================================================



# ============================================================
# VQE state
# ============================================================


# ============================================================
# Fidelity
# ============================================================

#Fidelity = np.abs(
#    np.vdot(psi_loc, psi_vqe)
#)**2

# ============================================================
# Results
# ============================================================

#print("\n================================")
print("Exact energy :", E0_loc)
# Out:
# Exact energy : 1.0554722545756783

# %%
###### Exact Ground State Utility

# ============================================================
# Exact ground state from sparse Hamiltonian
# ============================================================

from scipy.sparse.linalg import eigsh


def exact_ground_state(H_sparse):

    evals, evecs = eigsh(H_sparse, k=1, which='SA')

    E0 = np.real(evals[0])

    psi0 = evecs[:, 0]
    psi0 = psi0 / np.linalg.norm(psi0)

    return E0, psi0

# %%
##### Fidelity Function (DO NOT RUN THIS CELL)

def fidelity(psi_exact, psi_vqe):

    return np.abs(np.vdot(psi_exact, psi_vqe))**2

# %%
import numpy as np

from scipy.sparse import identity, kron

from qiskit.quantum_info import (
    Statevector,
    Operator,
    SparsePauliOp
)

from qiskit.primitives import StatevectorEstimator

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B

# %%
# ============================================================
# Robust VQE with eigenstate tracking (DO NOT RUN THIS CELL)
# ============================================================
import numpy as np

from scipy.sparse import identity, kron

from qiskit.quantum_info import (
    Statevector,
    Operator,
    SparsePauliOp
)

from qiskit.primitives import StatevectorEstimator

from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import L_BFGS_B
def run_robust_vqe(

    H_sparse,

    nq,

    layers,

    n_restarts,

    energy_tol,

    previous_state=None,

    previous_optimal_point=None
):

    nqubits = nq

    # --------------------------------------------------------
    # Exact ground state
    # --------------------------------------------------------

    E_exact, psi_exact = exact_ground_state(H_sparse)

    # --------------------------------------------------------
    # Convert Hamiltonian
    # --------------------------------------------------------

    H_dense = H_sparse.toarray()

    H_op = Operator(H_dense)

    H_pauli = SparsePauliOp.from_operator(H_op)

    coeffs = H_pauli.coeffs

    paulis = H_pauli.paulis

    new_coeffs = []

    new_paulis = []

    identity_shift = 0.0

    for p, c in zip(paulis, coeffs):

        if str(p) == 'I' * nqubits:

            identity_shift += np.real(c)

        else:

            new_paulis.append(p)

            new_coeffs.append(c)

    H_pauli_shifted = SparsePauliOp(

        new_paulis,

        coeffs=new_coeffs
    )

    # --------------------------------------------------------
    # Ansatz
    # --------------------------------------------------------

    ansatz = variational_circuit(

        nq=nqubits,

        layers=layers
    )

    estimator = StatevectorEstimator()

    optimizer = L_BFGS_B(maxiter=1000)

    # ========================================================
    # Multiple restarts
    # ========================================================

    trial_results = []

    for trial in range(n_restarts):

        # ----------------------------------------------------
        # Initial point
        # ----------------------------------------------------

        if trial == 0 and previous_optimal_point is not None:

            initial_point = previous_optimal_point

        else:

            initial_point = 0.01 * np.random.randn(

                ansatz.num_parameters
            )

        # ----------------------------------------------------
        # VQE
        # ----------------------------------------------------

        vqe = VQE(

            estimator=estimator,

            ansatz=ansatz,

            optimizer=optimizer,

            initial_point=initial_point
        )

        result = vqe.compute_minimum_eigenvalue(

            H_pauli_shifted
        )

        E_trial = (

            np.real(result.eigenvalue)

            + identity_shift
        )

        # ----------------------------------------------------
        # Trial state
        # ----------------------------------------------------

        qc_trial = ansatz.assign_parameters(

            result.optimal_parameters
        )

        psi_trial = Statevector.from_instruction(

            qc_trial

        ).data

        # ----------------------------------------------------
        # Overlap tracking
        # ----------------------------------------------------

        if previous_state is None:

            overlap = 1.0

        else:

            overlap = abs(np.vdot(

                previous_state,

                psi_trial

            ))**2

        trial_results.append({

            'energy': E_trial,

            'overlap': overlap,

            'state': psi_trial,

            'result': result
        })

    # ========================================================
    # Hybrid selection
    # ========================================================

    energies = np.array([

        t['energy']

        for t in trial_results
    ])

    E_min = np.min(energies)

    filtered_candidates = [

        t for t in trial_results

        if (t['energy'] - E_min) < energy_tol
    ]

    best_candidate = max(

        filtered_candidates,

        key=lambda x: x['overlap']
    )

    # ========================================================
    # Outputs
    # ========================================================

    # ========================================================
    # Final outputs
    # ========================================================

    psi_vqe = best_candidate['state']

    E_vqe = best_candidate['energy']

    optimal_point = (

        best_candidate['result'].optimal_point
    )

    tracking_overlap = best_candidate['overlap']

    F = fidelity(

    psi_exact,

    psi_vqe
    )

    return {

        "E_exact": E_exact,

        "E_vqe": E_vqe,

        "psi_vqe": psi_vqe,

        "fidelity": F,

        "tracking_overlap": tracking_overlap,

        "optimal_point": optimal_point,

        "state_for_tracking": psi_vqe
    }

# %%
nq_site = 4

nqubits = 2 * nq_site

mu = 1.0

layers = 8

# ============================================================
# VQE settings
# ============================================================

n_restarts = 5

energy_tol = 1e-3

# ============================================================
# Parameter sets
# ============================================================

parameter_sets = [

    {
        "label": "Symmetric",
        "mI2": 1.0,
        "f": 0.0
    },
    {
        "label": "Weak SSB optimised",
        "mI2": -1.0,
        "f": 5*1e-2
    },
   {
        "label": "Strong SSB",
        "mI2": -1.0,
        "f": 0.5
    }
]

# ============================================================
# Lambda scan
# ============================================================

lambda_list = np.linspace(0.1, 2.0, 50)

# ============================================================
# Storage
# ============================================================

all_results = []

# ============================================================
# Main loop
# ============================================================

for params in parameter_sets:

    label = params["label"]

    mI2 = params["mI2"]

    f = params["f"]

    print("\n")
    print("#"*80)

    print(f"CASE: {label}")

    print(f"mI² = {mI2},  f = {f}")

    print("#"*80)

    case_results = []

    # --------------------------------------------------------
    # Tracking variables
    # --------------------------------------------------------


    # ========================================================
    # Lambda loop
    # ========================================================

    for lam in lambda_list:

        print("\n" + "="*60)

        print(f"Running λ = {lam:.3f}")

        print("="*60)

        # ----------------------------------------------------
        # Build H_loc
        # ----------------------------------------------------

        Hloc_sparse = two_site_hloc(

            nq=nq_site,

            mu=mu,

            mI2=mI2,

            lam=lam,

            f=f
                )

        E_exact, psi_exact = exact_ground_state(Hloc_sparse)
     

        # ====================================================
        # Run robust VQE
        # ====================================================


        # ====================================================
        # Extract outputs
        # ====================================================

        
        # ----------------------------------------------------
        # Update tracking
        # ----------------------------------------------------

       
        # ----------------------------------------------------
        # Store
        # ----------------------------------------------------

        data = {

            'case': label,

            'lambda': lam,

            'mI2': mI2,

            'f': f,

            'E_exact': E_exact,

            'psi_exact': psi_exact,
        }

        case_results.append(data)

        all_results.append(data)

        # ----------------------------------------------------
        # Print
        # ----------------------------------------------------

        print("\nFINAL SELECTED STATE")

        print(f"Exact energy     : {E_exact:.12f}")

        print("\nExact ground state obtained")

        print(f"Ground-state energy : {E_exact:.12f}")

    # ========================================================
    # Case summary
    # ========================================================

    print("\n")

    print("="*110)

    print(f"SUMMARY : {label}")

    print("="*110)

    print(

        f"{'lambda':<12} "
        f"{'Exact E':<18} "
    )

    print("="*110)

    for r in case_results:

        print(

            f"{r['lambda']:<12.4f} "
            f"{r['E_exact']:<20.10f} "
        )
# Out:
# ################################################################################
# CASE: Symmetric
# mI² = 1.0,  f = 0.0
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.006161728159
#
# Exact ground state obtained
# Ground-state energy : 1.006161728159
#
# ============================================================
# Running λ = 0.139
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.008505484893
#
# Exact ground state obtained
# Ground-state energy : 1.008505484893
#
# ============================================================
# Running λ = 0.178
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.010825155811
#
# Exact ground state obtained
# Ground-state energy : 1.010825155811
#
# ============================================================
# Running λ = 0.216
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.013121536666
#
# Exact ground state obtained
# Ground-state energy : 1.013121536666
#
# ============================================================
# Running λ = 0.255
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.015395374894
#
# Exact ground state obtained
# Ground-state energy : 1.015395374894
#
# ============================================================
# Running λ = 0.294
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.017647374026
#
# Exact ground state obtained
# Ground-state energy : 1.017647374026
#
# ============================================================
# Running λ = 0.333
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.019878197547
#
# Exact ground state obtained
# Ground-state energy : 1.019878197547
#
# ============================================================
# Running λ = 0.371
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.022088472302
#
# Exact ground state obtained
# Ground-state energy : 1.022088472302
#
# ============================================================
# Running λ = 0.410
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.024278791513
#
# Exact ground state obtained
# Ground-state energy : 1.024278791513
#
# ============================================================
# Running λ = 0.449
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.026449717460
#
# Exact ground state obtained
# Ground-state energy : 1.026449717460
#
# ============================================================
# Running λ = 0.488
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.028601783873
#
# Exact ground state obtained
# Ground-state energy : 1.028601783873
#
# ============================================================
# Running λ = 0.527
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.030735498085
#
# Exact ground state obtained
# Ground-state energy : 1.030735498085
#
# ============================================================
# Running λ = 0.565
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.032851342958
#
# Exact ground state obtained
# Ground-state energy : 1.032851342958
#
# ============================================================
# Running λ = 0.604
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.034949778625
#
# Exact ground state obtained
# Ground-state energy : 1.034949778625
#
# ============================================================
# Running λ = 0.643
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.037031244071
#
# Exact ground state obtained
# Ground-state energy : 1.037031244071
#
# ============================================================
# Running λ = 0.682
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.039096158560
#
# Exact ground state obtained
# Ground-state energy : 1.039096158560
#
# ============================================================
# Running λ = 0.720
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.041144922937
#
# Exact ground state obtained
# Ground-state energy : 1.041144922937
#
# ============================================================
# Running λ = 0.759
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.043177920818
#
# Exact ground state obtained
# Ground-state energy : 1.043177920818
#
# ============================================================
# Running λ = 0.798
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.045195519674
#
# Exact ground state obtained
# Ground-state energy : 1.045195519674
#
# ============================================================
# Running λ = 0.837
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.047198071828
#
# Exact ground state obtained
# Ground-state energy : 1.047198071828
#
# ============================================================
# Running λ = 0.876
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.049185915365
#
# Exact ground state obtained
# Ground-state energy : 1.049185915365
#
# ============================================================
# Running λ = 0.914
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.051159374975
#
# Exact ground state obtained
# Ground-state energy : 1.051159374975
#
# ============================================================
# Running λ = 0.953
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.053118762728
#
# Exact ground state obtained
# Ground-state energy : 1.053118762728
#
# ============================================================
# Running λ = 0.992
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.055064378790
#
# Exact ground state obtained
# Ground-state energy : 1.055064378790
#
# ============================================================
# Running λ = 1.031
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.056996512081
#
# Exact ground state obtained
# Ground-state energy : 1.056996512081
#
# ============================================================
# Running λ = 1.069
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.058915440892
#
# Exact ground state obtained
# Ground-state energy : 1.058915440892
#
# ============================================================
# Running λ = 1.108
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.060821433452
#
# Exact ground state obtained
# Ground-state energy : 1.060821433452
#
# ============================================================
# Running λ = 1.147
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.062714748460
#
# Exact ground state obtained
# Ground-state energy : 1.062714748460
#
# ============================================================
# Running λ = 1.186
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.064595635571
#
# Exact ground state obtained
# Ground-state energy : 1.064595635571
#
# ============================================================
# Running λ = 1.224
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.066464335859
#
# Exact ground state obtained
# Ground-state energy : 1.066464335859
#
# ============================================================
# Running λ = 1.263
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.068321082244
#
# Exact ground state obtained
# Ground-state energy : 1.068321082244
#
# ============================================================
# Running λ = 1.302
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.070166099893
#
# Exact ground state obtained
# Ground-state energy : 1.070166099893
#
# ============================================================
# Running λ = 1.341
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.071999606590
#
# Exact ground state obtained
# Ground-state energy : 1.071999606590
#
# ============================================================
# Running λ = 1.380
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.073821813090
#
# Exact ground state obtained
# Ground-state energy : 1.073821813090
#
# ============================================================
# Running λ = 1.418
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.075632923446
#
# Exact ground state obtained
# Ground-state energy : 1.075632923446
#
# ============================================================
# Running λ = 1.457
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.077433135317
#
# Exact ground state obtained
# Ground-state energy : 1.077433135317
#
# ============================================================
# Running λ = 1.496
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.079222640256
#
# Exact ground state obtained
# Ground-state energy : 1.079222640256
#
# ============================================================
# Running λ = 1.535
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.081001623987
#
# Exact ground state obtained
# Ground-state energy : 1.081001623987
#
# ============================================================
# Running λ = 1.573
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.082770266656
#
# Exact ground state obtained
# Ground-state energy : 1.082770266656
#
# ============================================================
# Running λ = 1.612
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.084528743076
#
# Exact ground state obtained
# Ground-state energy : 1.084528743076
#
# ============================================================
# Running λ = 1.651
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.086277222951
#
# Exact ground state obtained
# Ground-state energy : 1.086277222951
#
# ============================================================
# Running λ = 1.690
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.088015871097
#
# Exact ground state obtained
# Ground-state energy : 1.088015871097
#
# ============================================================
# Running λ = 1.729
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.089744847640
#
# Exact ground state obtained
# Ground-state energy : 1.089744847640
#
# ============================================================
# Running λ = 1.767
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.091464308209
#
# Exact ground state obtained
# Ground-state energy : 1.091464308209
#
# ============================================================
# Running λ = 1.806
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.093174404118
#
# Exact ground state obtained
# Ground-state energy : 1.093174404118
#
# ============================================================
# Running λ = 1.845
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.094875282542
#
# Exact ground state obtained
# Ground-state energy : 1.094875282542
#
# ============================================================
# Running λ = 1.884
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.096567086672
#
# Exact ground state obtained
# Ground-state energy : 1.096567086672
#
# ============================================================
# Running λ = 1.922
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.098249955879
#
# Exact ground state obtained
# Ground-state energy : 1.098249955879
#
# ============================================================
# Running λ = 1.961
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.099924025851
#
# Exact ground state obtained
# Ground-state energy : 1.099924025851
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : 1.101589428743
#
# Exact ground state obtained
# Ground-state energy : 1.101589428743
#
#
# ==============================================================================================================
# SUMMARY : Symmetric
# ==============================================================================================================
# lambda       Exact E
# ==============================================================================================================
# 0.1000       1.0061617282
# 0.1388       1.0085054849
# 0.1776       1.0108251558
# 0.2163       1.0131215367
# 0.2551       1.0153953749
# 0.2939       1.0176473740
# 0.3327       1.0198781975
# 0.3714       1.0220884723
# 0.4102       1.0242787915
# 0.4490       1.0264497175
# 0.4878       1.0286017839
# 0.5265       1.0307354981
# 0.5653       1.0328513430
# 0.6041       1.0349497786
# 0.6429       1.0370312441
# 0.6816       1.0390961586
# 0.7204       1.0411449229
# 0.7592       1.0431779208
# 0.7980       1.0451955197
# 0.8367       1.0471980718
# 0.8755       1.0491859154
# 0.9143       1.0511593750
# 0.9531       1.0531187627
# 0.9918       1.0550643788
# 1.0306       1.0569965121
# 1.0694       1.0589154409
# 1.1082       1.0608214335
# 1.1469       1.0627147485
# 1.1857       1.0645956356
# 1.2245       1.0664643359
# 1.2633       1.0683210822
# 1.3020       1.0701660999
# 1.3408       1.0719996066
# 1.3796       1.0738218131
# 1.4184       1.0756329234
# 1.4571       1.0774331353
# 1.4959       1.0792226403
# 1.5347       1.0810016240
# 1.5735       1.0827702667
# 1.6122       1.0845287431
# 1.6510       1.0862772230
# 1.6898       1.0880158711
# 1.7286       1.0897448476
# 1.7673       1.0914643082
# 1.8061       1.0931744041
# 1.8449       1.0948752825
# 1.8837       1.0965670867
# 1.9224       1.0982499559
# 1.9612       1.0999240259
# 2.0000       1.1015894287
#
#
# ################################################################################
# CASE: Weak SSB optimised
# mI² = -1.0,  f = 0.05
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -17.064693351866
#
# Exact ground state obtained
# Ground-state energy : -17.064693351866
#
# ============================================================
# Running λ = 0.139
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -15.553702359341
#
# Exact ground state obtained
# Ground-state energy : -15.553702359341
#
# ============================================================
# Running λ = 0.178
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -14.053005538998
#
# Exact ground state obtained
# Ground-state energy : -14.053005538998
#
# ============================================================
# Running λ = 0.216
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -12.567319483265
#
# Exact ground state obtained
# Ground-state energy : -12.567319483265
#
# ============================================================
# Running λ = 0.255
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -11.105549193661
#
# Exact ground state obtained
# Ground-state energy : -11.105549193661
#
# ============================================================
# Running λ = 0.294
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -9.686846304441
#
# Exact ground state obtained
# Ground-state energy : -9.686846304441
#
# ============================================================
# Running λ = 0.333
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -8.357247569234
#
# Exact ground state obtained
# Ground-state energy : -8.357247569234
#
# ============================================================
# Running λ = 0.371
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -7.213677201716
#
# Exact ground state obtained
# Ground-state energy : -7.213677201716
#
# ============================================================
# Running λ = 0.410
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -6.333464799165
#
# Exact ground state obtained
# Ground-state energy : -6.333464799165
#
# ============================================================
# Running λ = 0.449
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.660742664947
#
# Exact ground state obtained
# Ground-state energy : -5.660742664947
#
# ============================================================
# Running λ = 0.488
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.115009003677
#
# Exact ground state obtained
# Ground-state energy : -5.115009003677
#
# ============================================================
# Running λ = 0.527
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.653276162899
#
# Exact ground state obtained
# Ground-state energy : -4.653276162899
#
# ============================================================
# Running λ = 0.565
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.254391966540
#
# Exact ground state obtained
# Ground-state energy : -4.254391966540
#
# ============================================================
# Running λ = 0.604
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.906042380199
#
# Exact ground state obtained
# Ground-state energy : -3.906042380199
#
# ============================================================
# Running λ = 0.643
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.599569576841
#
# Exact ground state obtained
# Ground-state energy : -3.599569576841
#
# ============================================================
# Running λ = 0.682
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.328185376932
#
# Exact ground state obtained
# Ground-state energy : -3.328185376932
#
# ============================================================
# Running λ = 0.720
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.086370139744
#
# Exact ground state obtained
# Ground-state energy : -3.086370139744
#
# ============================================================
# Running λ = 0.759
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.869617376442
#
# Exact ground state obtained
# Ground-state energy : -2.869617376442
#
# ============================================================
# Running λ = 0.798
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.674258761156
#
# Exact ground state obtained
# Ground-state energy : -2.674258761156
#
# ============================================================
# Running λ = 0.837
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.497309795414
#
# Exact ground state obtained
# Ground-state energy : -2.497309795414
#
# ============================================================
# Running λ = 0.876
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.336333155563
#
# Exact ground state obtained
# Ground-state energy : -2.336333155563
#
# ============================================================
# Running λ = 0.914
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.189324223389
#
# Exact ground state obtained
# Ground-state energy : -2.189324223389
#
# ============================================================
# Running λ = 0.953
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.054619673765
#
# Exact ground state obtained
# Ground-state energy : -2.054619673765
#
# ============================================================
# Running λ = 0.992
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.930826575500
#
# Exact ground state obtained
# Ground-state energy : -1.930826575500
#
# ============================================================
# Running λ = 1.031
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.816768060749
#
# Exact ground state obtained
# Ground-state energy : -1.816768060749
#
# ============================================================
# Running λ = 1.069
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.711441627471
#
# Exact ground state obtained
# Ground-state energy : -1.711441627471
#
# ============================================================
# Running λ = 1.108
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.613986780155
#
# Exact ground state obtained
# Ground-state energy : -1.613986780155
#
# ============================================================
# Running λ = 1.147
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.523659502528
#
# Exact ground state obtained
# Ground-state energy : -1.523659502528
#
# ============================================================
# Running λ = 1.186
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.439811768383
#
# Exact ground state obtained
# Ground-state energy : -1.439811768383
#
# ============================================================
# Running λ = 1.224
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.361874860025
#
# Exact ground state obtained
# Ground-state energy : -1.361874860025
#
# ============================================================
# Running λ = 1.263
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.289345674347
#
# Exact ground state obtained
# Ground-state energy : -1.289345674347
#
# ============================================================
# Running λ = 1.302
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.221775475374
#
# Exact ground state obtained
# Ground-state energy : -1.221775475374
#
# ============================================================
# Running λ = 1.341
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.158760725492
#
# Exact ground state obtained
# Ground-state energy : -1.158760725492
#
# ============================================================
# Running λ = 1.380
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.099935721243
#
# Exact ground state obtained
# Ground-state energy : -1.099935721243
#
# ============================================================
# Running λ = 1.418
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.044966797768
#
# Exact ground state obtained
# Ground-state energy : -1.044966797768
#
# ============================================================
# Running λ = 1.457
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.993547871774
#
# Exact ground state obtained
# Ground-state energy : -0.993547871774
#
# ============================================================
# Running λ = 1.496
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.945397086810
#
# Exact ground state obtained
# Ground-state energy : -0.945397086810
#
# ============================================================
# Running λ = 1.535
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.900254322413
#
# Exact ground state obtained
# Ground-state energy : -0.900254322413
#
# ============================================================
# Running λ = 1.573
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.857879339400
#
# Exact ground state obtained
# Ground-state energy : -0.857879339400
#
# ============================================================
# Running λ = 1.612
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.818050359228
#
# Exact ground state obtained
# Ground-state energy : -0.818050359228
#
# ============================================================
# Running λ = 1.651
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.780562912439
#
# Exact ground state obtained
# Ground-state energy : -0.780562912439
#
# ============================================================
# Running λ = 1.690
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.745228833423
#
# Exact ground state obtained
# Ground-state energy : -0.745228833423
#
# ============================================================
# Running λ = 1.729
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.711875319604
#
# Exact ground state obtained
# Ground-state energy : -0.711875319604
#
# ============================================================
# Running λ = 1.767
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.680344008029
#
# Exact ground state obtained
# Ground-state energy : -0.680344008029
#
# ============================================================
# Running λ = 1.806
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.650490048784
#
# Exact ground state obtained
# Ground-state energy : -0.650490048784
#
# ============================================================
# Running λ = 1.845
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.622181172415
#
# Exact ground state obtained
# Ground-state energy : -0.622181172415
#
# ============================================================
# Running λ = 1.884
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.595296758871
#
# Exact ground state obtained
# Ground-state energy : -0.595296758871
#
# ============================================================
# Running λ = 1.922
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.569726920013
#
# Exact ground state obtained
# Ground-state energy : -0.569726920013
#
# ============================================================
# Running λ = 1.961
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.545371608491
#
# Exact ground state obtained
# Ground-state energy : -0.545371608491
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -0.522139764298
#
# Exact ground state obtained
# Ground-state energy : -0.522139764298
#
#
# ==============================================================================================================
# SUMMARY : Weak SSB optimised
# ==============================================================================================================
# lambda       Exact E
# ==============================================================================================================
# 0.1000       -17.0646933519
# 0.1388       -15.5537023593
# 0.1776       -14.0530055390
# 0.2163       -12.5673194833
# 0.2551       -11.1055491937
# 0.2939       -9.6868463044
# 0.3327       -8.3572475692
# 0.3714       -7.2136772017
# 0.4102       -6.3334647992
# 0.4490       -5.6607426649
# 0.4878       -5.1150090037
# 0.5265       -4.6532761629
# 0.5653       -4.2543919665
# 0.6041       -3.9060423802
# 0.6429       -3.5995695768
# 0.6816       -3.3281853769
# 0.7204       -3.0863701397
# 0.7592       -2.8696173764
# 0.7980       -2.6742587612
# 0.8367       -2.4973097954
# 0.8755       -2.3363331556
# 0.9143       -2.1893242234
# 0.9531       -2.0546196738
# 0.9918       -1.9308265755
# 1.0306       -1.8167680607
# 1.0694       -1.7114416275
# 1.1082       -1.6139867802
# 1.1469       -1.5236595025
# 1.1857       -1.4398117684
# 1.2245       -1.3618748600
# 1.2633       -1.2893456743
# 1.3020       -1.2217754754
# 1.3408       -1.1587607255
# 1.3796       -1.0999357212
# 1.4184       -1.0449667978
# 1.4571       -0.9935478718
# 1.4959       -0.9453970868
# 1.5347       -0.9002543224
# 1.5735       -0.8578793394
# 1.6122       -0.8180503592
# 1.6510       -0.7805629124
# 1.6898       -0.7452288334
# 1.7286       -0.7118753196
# 1.7673       -0.6803440080
# 1.8061       -0.6504900488
# 1.8449       -0.6221811724
# 1.8837       -0.5952967589
# 1.9224       -0.5697269200
# 1.9612       -0.5453716085
# 2.0000       -0.5221397643
#
#
# ################################################################################
# CASE: Strong SSB
# mI² = -1.0,  f = 0.5
# ################################################################################
#
# ============================================================
# Running λ = 0.100
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -20.777328445265
#
# Exact ground state obtained
# Ground-state energy : -20.777328445265
#
# ============================================================
# Running λ = 0.139
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -19.271689161020
#
# Exact ground state obtained
# Ground-state energy : -19.271689161020
#
# ============================================================
# Running λ = 0.178
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -17.778234217972
#
# Exact ground state obtained
# Ground-state energy : -17.778234217972
#
# ============================================================
# Running λ = 0.216
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -16.302121650288
#
# Exact ground state obtained
# Ground-state energy : -16.302121650288
#
# ============================================================
# Running λ = 0.255
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -14.851972079088
#
# Exact ground state obtained
# Ground-state energy : -14.851972079088
#
# ============================================================
# Running λ = 0.294
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -13.442949771836
#
# Exact ground state obtained
# Ground-state energy : -13.442949771836
#
# ============================================================
# Running λ = 0.333
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -12.102418516949
#
# Exact ground state obtained
# Ground-state energy : -12.102418516949
#
# ============================================================
# Running λ = 0.371
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -10.876489869655
#
# Exact ground state obtained
# Ground-state energy : -10.876489869655
#
# ============================================================
# Running λ = 0.410
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -9.821381657721
#
# Exact ground state obtained
# Ground-state energy : -9.821381657721
#
# ============================================================
# Running λ = 0.449
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -8.959777508951
#
# Exact ground state obtained
# Ground-state energy : -8.959777508951
#
# ============================================================
# Running λ = 0.488
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -8.258474798291
#
# Exact ground state obtained
# Ground-state energy : -8.258474798291
#
# ============================================================
# Running λ = 0.527
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -7.669683556150
#
# Exact ground state obtained
# Ground-state energy : -7.669683556150
#
# ============================================================
# Running λ = 0.565
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -7.160625774099
#
# Exact ground state obtained
# Ground-state energy : -7.160625774099
#
# ============================================================
# Running λ = 0.604
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -6.712603214068
#
# Exact ground state obtained
# Ground-state energy : -6.712603214068
#
# ============================================================
# Running λ = 0.643
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -6.314375067440
#
# Exact ground state obtained
# Ground-state energy : -6.314375067440
#
# ============================================================
# Running λ = 0.682
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.958153446826
#
# Exact ground state obtained
# Ground-state energy : -5.958153446826
#
# ============================================================
# Running λ = 0.720
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.637840639347
#
# Exact ground state obtained
# Ground-state energy : -5.637840639347
#
# ============================================================
# Running λ = 0.759
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.348364869045
#
# Exact ground state obtained
# Ground-state energy : -5.348364869045
#
# ============================================================
# Running λ = 0.798
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -5.085444059546
#
# Exact ground state obtained
# Ground-state energy : -5.085444059546
#
# ============================================================
# Running λ = 0.837
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.845476728317
#
# Exact ground state obtained
# Ground-state energy : -4.845476728317
#
# ============================================================
# Running λ = 0.876
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.625454164532
#
# Exact ground state obtained
# Ground-state energy : -4.625454164532
#
# ============================================================
# Running λ = 0.914
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.422871179322
#
# Exact ground state obtained
# Ground-state energy : -4.422871179322
#
# ============================================================
# Running λ = 0.953
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.235638866162
#
# Exact ground state obtained
# Ground-state energy : -4.235638866162
#
# ============================================================
# Running λ = 0.992
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -4.062006060369
#
# Exact ground state obtained
# Ground-state energy : -4.062006060369
#
# ============================================================
# Running λ = 1.031
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.900493153900
#
# Exact ground state obtained
# Ground-state energy : -3.900493153900
#
# ============================================================
# Running λ = 1.069
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.749838766266
#
# Exact ground state obtained
# Ground-state energy : -3.749838766266
#
# ============================================================
# Running λ = 1.108
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.608957923580
#
# Exact ground state obtained
# Ground-state energy : -3.608957923580
#
# ============================================================
# Running λ = 1.147
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.476909690974
#
# Exact ground state obtained
# Ground-state energy : -3.476909690974
#
# ============================================================
# Running λ = 1.186
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.352872175859
#
# Exact ground state obtained
# Ground-state energy : -3.352872175859
#
# ============================================================
# Running λ = 1.224
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.236123101649
#
# Exact ground state obtained
# Ground-state energy : -3.236123101649
#
# ============================================================
# Running λ = 1.263
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.126024523482
#
# Exact ground state obtained
# Ground-state energy : -3.126024523482
#
# ============================================================
# Running λ = 1.302
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -3.022010610305
#
# Exact ground state obtained
# Ground-state energy : -3.022010610305
#
# ============================================================
# Running λ = 1.341
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.923577709577
#
# Exact ground state obtained
# Ground-state energy : -2.923577709577
#
# ============================================================
# Running λ = 1.380
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.830276134379
#
# Exact ground state obtained
# Ground-state energy : -2.830276134379
#
# ============================================================
# Running λ = 1.418
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.741703275529
#
# Exact ground state obtained
# Ground-state energy : -2.741703275529
#
# ============================================================
# Running λ = 1.457
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.657497756096
#
# Exact ground state obtained
# Ground-state energy : -2.657497756096
#
# ============================================================
# Running λ = 1.496
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.577334424786
#
# Exact ground state obtained
# Ground-state energy : -2.577334424786
#
# ============================================================
# Running λ = 1.535
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.500920038563
#
# Exact ground state obtained
# Ground-state energy : -2.500920038563
#
# ============================================================
# Running λ = 1.573
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.427989521441
#
# Exact ground state obtained
# Ground-state energy : -2.427989521441
#
# ============================================================
# Running λ = 1.612
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.358302711491
#
# Exact ground state obtained
# Ground-state energy : -2.358302711491
#
# ============================================================
# Running λ = 1.651
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.291641525559
#
# Exact ground state obtained
# Ground-state energy : -2.291641525559
#
# ============================================================
# Running λ = 1.690
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.227807483786
#
# Exact ground state obtained
# Ground-state energy : -2.227807483786
#
# ============================================================
# Running λ = 1.729
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.166619545361
#
# Exact ground state obtained
# Ground-state energy : -2.166619545361
#
# ============================================================
# Running λ = 1.767
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.107912214195
#
# Exact ground state obtained
# Ground-state energy : -2.107912214195
#
# ============================================================
# Running λ = 1.806
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -2.051533878982
#
# Exact ground state obtained
# Ground-state energy : -2.051533878982
#
# ============================================================
# Running λ = 1.845
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.997345356979
#
# Exact ground state obtained
# Ground-state energy : -1.997345356979
#
# ============================================================
# Running λ = 1.884
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.945218614854
#
# Exact ground state obtained
# Ground-state energy : -1.945218614854
#
# ============================================================
# Running λ = 1.922
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.895035643493
#
# Exact ground state obtained
# Ground-state energy : -1.895035643493
#
# ============================================================
# Running λ = 1.961
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.846687466679
#
# Exact ground state obtained
# Ground-state energy : -1.846687466679
#
# ============================================================
# Running λ = 2.000
# ============================================================
#
# FINAL SELECTED STATE
# Exact energy     : -1.800073266214
#
# Exact ground state obtained
# Ground-state energy : -1.800073266214
#
#
# ==============================================================================================================
# SUMMARY : Strong SSB
# ==============================================================================================================
# lambda       Exact E
# ==============================================================================================================
# 0.1000       -20.7773284453
# 0.1388       -19.2716891610
# 0.1776       -17.7782342180
# 0.2163       -16.3021216503
# 0.2551       -14.8519720791
# 0.2939       -13.4429497718
# 0.3327       -12.1024185169
# 0.3714       -10.8764898697
# 0.4102       -9.8213816577
# 0.4490       -8.9597775090
# 0.4878       -8.2584747983
# 0.5265       -7.6696835561
# 0.5653       -7.1606257741
# 0.6041       -6.7126032141
# 0.6429       -6.3143750674
# 0.6816       -5.9581534468
# 0.7204       -5.6378406393
# 0.7592       -5.3483648690
# 0.7980       -5.0854440595
# 0.8367       -4.8454767283
# 0.8755       -4.6254541645
# 0.9143       -4.4228711793
# 0.9531       -4.2356388662
# 0.9918       -4.0620060604
# 1.0306       -3.9004931539
# 1.0694       -3.7498387663
# 1.1082       -3.6089579236
# 1.1469       -3.4769096910
# 1.1857       -3.3528721759
# 1.2245       -3.2361231016
# 1.2633       -3.1260245235
# 1.3020       -3.0220106103
# 1.3408       -2.9235777096
# 1.3796       -2.8302761344
# 1.4184       -2.7417032755
# 1.4571       -2.6574977561
# 1.4959       -2.5773344248
# 1.5347       -2.5009200386
# 1.5735       -2.4279895214
# 1.6122       -2.3583027115
# 1.6510       -2.2916415256
# 1.6898       -2.2278074838
# 1.7286       -2.1666195454
# 1.7673       -2.1079122142
# 1.8061       -2.0515338790
# 1.8449       -1.9973453570
# 1.8837       -1.9452186149
# 1.9224       -1.8950356435
# 1.9612       -1.8466874667
# 2.0000       -1.8000732662

# %%
# ============================================================
# H_c
# ============================================================

def two_site_hc(

    nq,

    mu=1.0,

    m0_sq=1.0,

    mI2=1.0
):

    Phi, Pi = single_site_field_operators(nq, mu)

    Nphi = 2**nq

    I = identity(Nphi, format='csr', dtype=complex)

    Phi0 = kron(Phi, I, format='csr')

    Phi1 = kron(I, Phi, format='csr')

    Hc = (

        0.5 * (
            (Phi1 - Phi0) @ (Phi1 - Phi0)
        )

        +

        0.5 * (m0_sq - mI2) * (

            (Phi0 @ Phi0)

            +

            (Phi1 @ Phi1)
        )
    )

    return Hc

# %%
# ============================================================
# H_s
# ============================================================

def two_site_hs(

    nq,

    mu=1.0,

    mI2=1.0,

    m0_sq=1.0,

    lam=1.0,

    f=0.0,

    s=1.0
):

    Hloc = two_site_hloc(

        nq=nq,

        mu=mu,

        mI2=mI2,

        lam=lam,

        f=f
    )

    Hc = two_site_hc(

        nq=nq,

        mu=mu,

        m0_sq=m0_sq,

        mI2=mI2
    )

    return Hloc + s * Hc

# %%
# ============================================================
# Exact ground state
# ============================================================

def exact_ground_state(H):

    H_dense = H.toarray()

    eigvals, eigvecs = np.linalg.eigh(H_dense)

    return eigvals[0], eigvecs[:, 0]

# %%
# ============================================================
# Minimum instantaneous gap along adiabatic path
# ============================================================

def minimum_gap_along_path(

    nq,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    gap_min = 1e100

    for step in range(nsteps):

        s = step / nsteps

        Hs = two_site_hs(

            nq=nq,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        evals, _ = eigsh(

            Hs,

            k=2,

            which='SA'
        )

        evals = np.sort(np.real(evals))

        gap = evals[1] - evals[0]

        gap_min = min(gap_min, gap)

    return gap_min

# %%
# ============================================================
# One Trotter step
# ============================================================
from scipy.linalg import expm
def trotter_step_unitary(

    nq,

    dt,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    s
):

    Hs = two_site_hs(

        nq=nq,

        mu=mu,

        mI2=mI2,

        m0_sq=m0_sq,

        lam=lam,

        f=f,

        s=s
    )

    U = expm(

        -1j * Hs.toarray() * dt

    )

    return U

# %%
# ============================================================
# Adiabatic circuit evolution
# ============================================================

def adiabatic_circuit_evolution(

    initial_state,

    nq,

    T,

    mu,

    mI2,

    m0_sq,

    lam,

    f,

    nsteps=100
):

    nqubits = 2 * nq

    dt = T / nsteps

    psi = Statevector(initial_state)

    # --------------------------------------------------------
    # Time evolution
    # --------------------------------------------------------

    for step in range(nsteps):

        t = step * dt

        s = t / T

        # ----------------------------------------------------
        # Instantaneous unitary
        # ----------------------------------------------------

        U = trotter_step_unitary(

            nq=nq,

            dt=dt,

            mu=mu,

            mI2=mI2,

            m0_sq=m0_sq,

            lam=lam,

            f=f,

            s=s
        )

        # ----------------------------------------------------
        # Quantum circuit
        # ----------------------------------------------------

        qc = QuantumCircuit(nqubits)

        qc.unitary(U, range(nqubits))

        # ----------------------------------------------------
        # Evolve state
        # ----------------------------------------------------

        psi = psi.evolve(qc)

    return psi.data

# %% [markdown]
# # Starting of m0^2=1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

def fidelity(psi1, psi2):

    #Fidelity between two pure state vectors.
    
    return np.abs(np.vdot(psi1, psi2))**2


# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_exact = data['psi_exact']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.00972087e+00
# T = 1     Fidelity = 0.98119774
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.139
# ================================================================================
# Minimum path gap = 1.01341296e+00
# T = 1     Fidelity = 0.98148940
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.178
# ================================================================================
# Minimum path gap = 1.01706408e+00
# T = 1     Fidelity = 0.98177180
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.216
# ================================================================================
# Minimum path gap = 1.02067556e+00
# T = 1     Fidelity = 0.98204545
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.255
# ================================================================================
# Minimum path gap = 1.02424866e+00
# T = 1     Fidelity = 0.98231082
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.294
# ================================================================================
# Minimum path gap = 1.02778454e+00
# T = 1     Fidelity = 0.98256835
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.333
# ================================================================================
# Minimum path gap = 1.03128433e+00
# T = 1     Fidelity = 0.98281843
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.371
# ================================================================================
# Minimum path gap = 1.03474909e+00
# T = 1     Fidelity = 0.98306142
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.410
# ================================================================================
# Minimum path gap = 1.03817982e+00
# T = 1     Fidelity = 0.98329768
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.449
# ================================================================================
# Minimum path gap = 1.04157748e+00
# T = 1     Fidelity = 0.98352751
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.488
# ================================================================================
# Minimum path gap = 1.04494298e+00
# T = 1     Fidelity = 0.98375120
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.527
# ================================================================================
# Minimum path gap = 1.04827719e+00
# T = 1     Fidelity = 0.98396904
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.565
# ================================================================================
# Minimum path gap = 1.05158093e+00
# T = 1     Fidelity = 0.98418128
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.604
# ================================================================================
# Minimum path gap = 1.05485500e+00
# T = 1     Fidelity = 0.98438816
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.643
# ================================================================================
# Minimum path gap = 1.05810014e+00
# T = 1     Fidelity = 0.98458990
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.682
# ================================================================================
# Minimum path gap = 1.06131708e+00
# T = 1     Fidelity = 0.98478672
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.720
# ================================================================================
# Minimum path gap = 1.06450651e+00
# T = 1     Fidelity = 0.98497881
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.759
# ================================================================================
# Minimum path gap = 1.06766910e+00
# T = 1     Fidelity = 0.98516636
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.798
# ================================================================================
# Minimum path gap = 1.07080547e+00
# T = 1     Fidelity = 0.98534955
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.837
# ================================================================================
# Minimum path gap = 1.07391624e+00
# T = 1     Fidelity = 0.98552853
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.876
# ================================================================================
# Minimum path gap = 1.07700199e+00
# T = 1     Fidelity = 0.98570348
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.914
# ================================================================================
# Minimum path gap = 1.08006328e+00
# T = 1     Fidelity = 0.98587453
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.953
# ================================================================================
# Minimum path gap = 1.08310066e+00
# T = 1     Fidelity = 0.98604183
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.992
# ================================================================================
# Minimum path gap = 1.08611464e+00
# T = 1     Fidelity = 0.98620551
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.031
# ================================================================================
# Minimum path gap = 1.08910574e+00
# T = 1     Fidelity = 0.98636570
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.069
# ================================================================================
# Minimum path gap = 1.09207442e+00
# T = 1     Fidelity = 0.98652252
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.108
# ================================================================================
# Minimum path gap = 1.09502116e+00
# T = 1     Fidelity = 0.98667607
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.147
# ================================================================================
# Minimum path gap = 1.09794640e+00
# T = 1     Fidelity = 0.98682648
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.186
# ================================================================================
# Minimum path gap = 1.10085059e+00
# T = 1     Fidelity = 0.98697384
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.224
# ================================================================================
# Minimum path gap = 1.10373413e+00
# T = 1     Fidelity = 0.98711825
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.263
# ================================================================================
# Minimum path gap = 1.10659744e+00
# T = 1     Fidelity = 0.98725981
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.302
# ================================================================================
# Minimum path gap = 1.10944091e+00
# T = 1     Fidelity = 0.98739861
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.341
# ================================================================================
# Minimum path gap = 1.11226491e+00
# T = 1     Fidelity = 0.98753472
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.380
# ================================================================================
# Minimum path gap = 1.11506981e+00
# T = 1     Fidelity = 0.98766824
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.418
# ================================================================================
# Minimum path gap = 1.11785597e+00
# T = 1     Fidelity = 0.98779924
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.457
# ================================================================================
# Minimum path gap = 1.12062373e+00
# T = 1     Fidelity = 0.98792779
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.496
# ================================================================================
# Minimum path gap = 1.12337343e+00
# T = 1     Fidelity = 0.98805398
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.535
# ================================================================================
# Minimum path gap = 1.12610538e+00
# T = 1     Fidelity = 0.98817786
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.573
# ================================================================================
# Minimum path gap = 1.12881990e+00
# T = 1     Fidelity = 0.98829950
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.612
# ================================================================================
# Minimum path gap = 1.13151730e+00
# T = 1     Fidelity = 0.98841897
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.651
# ================================================================================
# Minimum path gap = 1.13419787e+00
# T = 1     Fidelity = 0.98853633
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.690
# ================================================================================
# Minimum path gap = 1.13686189e+00
# T = 1     Fidelity = 0.98865163
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.729
# ================================================================================
# Minimum path gap = 1.13950965e+00
# T = 1     Fidelity = 0.98876493
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.767
# ================================================================================
# Minimum path gap = 1.14214142e+00
# T = 1     Fidelity = 0.98887629
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.806
# ================================================================================
# Minimum path gap = 1.14475745e+00
# T = 1     Fidelity = 0.98898576
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.845
# ================================================================================
# Minimum path gap = 1.14735801e+00
# T = 1     Fidelity = 0.98909338
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.884
# ================================================================================
# Minimum path gap = 1.14994335e+00
# T = 1     Fidelity = 0.98919921
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.922
# ================================================================================
# Minimum path gap = 1.15251370e+00
# T = 1     Fidelity = 0.98930329
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.961
# ================================================================================
# Minimum path gap = 1.15506930e+00
# T = 1     Fidelity = 0.98940567
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.15761039e+00
# T = 1     Fidelity = 0.98950639
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.42819099e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00038179
# T = 10    Fidelity = 0.00054402
# T = 20    Fidelity = 0.01169811
# T = 30    Fidelity = 0.08028339
# T = 40    Fidelity = 0.18957706
# T = 50    Fidelity = 0.42968446
# T = 75    Fidelity = 0.56797234
# T = 100   Fidelity = 0.72731121
# T = 125   Fidelity = 0.80887444
# T = 150   Fidelity = 0.83744632
# T = 175   Fidelity = 0.90619411
# T = 200   Fidelity = 0.91903801
# T = 225   Fidelity = 0.96741094
# T = 250   Fidelity = 0.89096667
# T = 275   Fidelity = 0.96901882
# T = 300   Fidelity = 0.85591728
# T = 400   Fidelity = 0.98094483
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.139
# ================================================================================
# Minimum path gap = 2.49811160e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00048458
# T = 10    Fidelity = 0.00099545
# T = 20    Fidelity = 0.11779921
# T = 30    Fidelity = 0.18415495
# T = 40    Fidelity = 0.49205811
# T = 50    Fidelity = 0.51364193
# T = 75    Fidelity = 0.75627386
# T = 100   Fidelity = 0.73383381
# T = 125   Fidelity = 0.85430843
# T = 150   Fidelity = 0.92286162
# T = 175   Fidelity = 0.91089300
# T = 200   Fidelity = 0.95808876
# T = 225   Fidelity = 0.97179034
#
# Minimum T for Fidelity >= 0.97 : 225
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.178
# ================================================================================
# Minimum path gap = 2.54072606e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00038577
# T = 10    Fidelity = 0.00565102
# T = 20    Fidelity = 0.17138531
# T = 30    Fidelity = 0.23072125
# T = 40    Fidelity = 0.55940553
# T = 50    Fidelity = 0.48702973
# T = 75    Fidelity = 0.69474709
# T = 100   Fidelity = 0.91904095
# T = 125   Fidelity = 0.89972290
# T = 150   Fidelity = 0.86836930
# T = 175   Fidelity = 0.94446812
# T = 200   Fidelity = 0.98371111
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.216
# ================================================================================
# Minimum path gap = 2.56643112e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00023804
# T = 10    Fidelity = 0.03222935
# T = 20    Fidelity = 0.22190478
# T = 30    Fidelity = 0.40280600
# T = 40    Fidelity = 0.58139962
# T = 50    Fidelity = 0.53546617
# T = 75    Fidelity = 0.63859022
# T = 100   Fidelity = 0.76642966
# T = 125   Fidelity = 0.89913176
# T = 150   Fidelity = 0.96695079
# T = 175   Fidelity = 0.98150087
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.255
# ================================================================================
# Minimum path gap = 2.58669725e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00018271
# T = 10    Fidelity = 0.06337605
# T = 20    Fidelity = 0.30571470
# T = 30    Fidelity = 0.60836190
# T = 40    Fidelity = 0.39999955
# T = 50    Fidelity = 0.81061149
# T = 75    Fidelity = 0.86848763
# T = 100   Fidelity = 0.87856100
# T = 125   Fidelity = 0.88849442
# T = 150   Fidelity = 0.89659332
# T = 175   Fidelity = 0.91213285
# T = 200   Fidelity = 0.93090079
# T = 225   Fidelity = 0.95392141
# T = 250   Fidelity = 0.96760346
# T = 275   Fidelity = 0.97638154
#
# Minimum T for Fidelity >= 0.97 : 275
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.294
# ================================================================================
# Minimum path gap = 2.60278666e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000006
# T = 5     Fidelity = 0.00030316
# T = 10    Fidelity = 0.06903075
# T = 20    Fidelity = 0.25741307
# T = 30    Fidelity = 0.66979288
# T = 40    Fidelity = 0.33572455
# T = 50    Fidelity = 0.80930673
# T = 75    Fidelity = 0.79584214
# T = 100   Fidelity = 0.90275116
# T = 125   Fidelity = 0.94872799
# T = 150   Fidelity = 0.94612154
# T = 175   Fidelity = 0.96556325
# T = 200   Fidelity = 0.96508166
# T = 225   Fidelity = 0.96755816
# T = 250   Fidelity = 0.97237249
#
# Minimum T for Fidelity >= 0.97 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.333
# ================================================================================
# Minimum path gap = 2.61560480e-01
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000043
# T = 5     Fidelity = 0.00088671
# T = 10    Fidelity = 0.07398296
# T = 20    Fidelity = 0.25654969
# T = 30    Fidelity = 0.57612184
# T = 40    Fidelity = 0.43558390
# T = 50    Fidelity = 0.76765578
# T = 75    Fidelity = 0.76100004
# T = 100   Fidelity = 0.78124600
# T = 125   Fidelity = 0.87974631
# T = 150   Fidelity = 0.91775675
# T = 175   Fidelity = 0.93498427
# T = 200   Fidelity = 0.96129495
# T = 225   Fidelity = 0.97350091
#
# Minimum T for Fidelity >= 0.97 : 225
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.371
# ================================================================================
# Minimum path gap = 2.62582285e-01
# T = 1     Fidelity = 0.00000015
# T = 2     Fidelity = 0.00000403
# T = 5     Fidelity = 0.00292783
# T = 10    Fidelity = 0.11373885
# T = 20    Fidelity = 0.38028024
# T = 30    Fidelity = 0.64578009
# T = 40    Fidelity = 0.59669470
# T = 50    Fidelity = 0.80288944
# T = 75    Fidelity = 0.85499172
# T = 100   Fidelity = 0.88709057
# T = 125   Fidelity = 0.95531235
# T = 150   Fidelity = 0.97282657
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.410
# ================================================================================
# Minimum path gap = 2.63395041e-01
# T = 1     Fidelity = 0.00000125
# T = 2     Fidelity = 0.00002245
# T = 5     Fidelity = 0.00674546
# T = 10    Fidelity = 0.16295889
# T = 20    Fidelity = 0.45896361
# T = 30    Fidelity = 0.66045677
# T = 40    Fidelity = 0.68107269
# T = 50    Fidelity = 0.81519396
# T = 75    Fidelity = 0.89786292
# T = 100   Fidelity = 0.93427184
# T = 125   Fidelity = 0.97250540
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.449
# ================================================================================
# Minimum path gap = 2.64038170e-01
# T = 1     Fidelity = 0.00000532
# T = 2     Fidelity = 0.00007105
# T = 5     Fidelity = 0.01110394
# T = 10    Fidelity = 0.19124599
# T = 20    Fidelity = 0.51076647
# T = 30    Fidelity = 0.66348610
# T = 40    Fidelity = 0.73191311
# T = 50    Fidelity = 0.82115673
# T = 75    Fidelity = 0.91398005
# T = 100   Fidelity = 0.95094417
# T = 125   Fidelity = 0.97768443
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.488
# ================================================================================
# Minimum path gap = 2.64542625e-01
# T = 1     Fidelity = 0.00001611
# T = 2     Fidelity = 0.00016895
# T = 5     Fidelity = 0.01581818
# T = 10    Fidelity = 0.20904349
# T = 20    Fidelity = 0.55576847
# T = 30    Fidelity = 0.66263471
# T = 40    Fidelity = 0.76631463
# T = 50    Fidelity = 0.82185575
# T = 75    Fidelity = 0.92377753
# T = 100   Fidelity = 0.96117508
# T = 125   Fidelity = 0.98080404
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.527
# ================================================================================
# Minimum path gap = 2.64932997e-01
# T = 1     Fidelity = 0.00004058
# T = 2     Fidelity = 0.00034695
# T = 5     Fidelity = 0.02113875
# T = 10    Fidelity = 0.22344440
# T = 20    Fidelity = 0.59341515
# T = 30    Fidelity = 0.66081564
# T = 40    Fidelity = 0.79298524
# T = 50    Fidelity = 0.82299915
# T = 75    Fidelity = 0.92724082
# T = 100   Fidelity = 0.96801354
# T = 125   Fidelity = 0.98483876
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.565
# ================================================================================
# Minimum path gap = 2.65229010e-01
# T = 1     Fidelity = 0.00009046
# T = 2     Fidelity = 0.00064804
# T = 5     Fidelity = 0.02721481
# T = 10    Fidelity = 0.23644144
# T = 20    Fidelity = 0.62365319
# T = 30    Fidelity = 0.66225698
# T = 40    Fidelity = 0.81250566
# T = 50    Fidelity = 0.82905504
# T = 75    Fidelity = 0.92856295
# T = 100   Fidelity = 0.97066751
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.604
# ================================================================================
# Minimum path gap = 2.65446588e-01
# T = 1     Fidelity = 0.00018318
# T = 2     Fidelity = 0.00112435
# T = 5     Fidelity = 0.03407074
# T = 10    Fidelity = 0.24854930
# T = 20    Fidelity = 0.64657085
# T = 30    Fidelity = 0.67045346
# T = 40    Fidelity = 0.82306199
# T = 50    Fidelity = 0.84129166
# T = 75    Fidelity = 0.93229462
# T = 100   Fidelity = 0.97223804
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.643
# ================================================================================
# Minimum path gap = 2.65598657e-01
# T = 1     Fidelity = 0.00034223
# T = 2     Fidelity = 0.00183387
# T = 5     Fidelity = 0.04166392
# T = 10    Fidelity = 0.25993102
# T = 20    Fidelity = 0.66282588
# T = 30    Fidelity = 0.68569548
# T = 40    Fidelity = 0.82528487
# T = 50    Fidelity = 0.85780080
# T = 75    Fidelity = 0.93979371
# T = 100   Fidelity = 0.97529653
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.682
# ================================================================================
# Minimum path gap = 2.65695732e-01
# T = 1     Fidelity = 0.00059730
# T = 2     Fidelity = 0.00283854
# T = 5     Fidelity = 0.04993937
# T = 10    Fidelity = 0.27069910
# T = 20    Fidelity = 0.67347718
# T = 30    Fidelity = 0.70561182
# T = 40    Fidelity = 0.82338013
# T = 50    Fidelity = 0.87359499
# T = 75    Fidelity = 0.94801238
# T = 100   Fidelity = 0.97916090
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.720
# ================================================================================
# Minimum path gap = 2.65746368e-01
# T = 1     Fidelity = 0.00098448
# T = 2     Fidelity = 0.00420445
# T = 5     Fidelity = 0.05886303
# T = 10    Fidelity = 0.28099486
# T = 20    Fidelity = 0.67960902
# T = 30    Fidelity = 0.72717444
# T = 40    Fidelity = 0.82187184
# T = 50    Fidelity = 0.88499879
# T = 75    Fidelity = 0.95377823
# T = 100   Fidelity = 0.98193747
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.759
# ================================================================================
# Minimum path gap = 2.58678635e-01
# T = 1     Fidelity = 0.00154666
# T = 2     Fidelity = 0.00600335
# T = 5     Fidelity = 0.06843449
# T = 10    Fidelity = 0.29100119
# T = 20    Fidelity = 0.68219537
# T = 30    Fidelity = 0.74780087
# T = 40    Fidelity = 0.82346883
# T = 50    Fidelity = 0.89162436
# T = 75    Fidelity = 0.95708079
# T = 100   Fidelity = 0.98362749
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.798
# ================================================================================
# Minimum path gap = 2.50935075e-01
# T = 1     Fidelity = 0.00233427
# T = 2     Fidelity = 0.00831438
# T = 5     Fidelity = 0.07868711
# T = 10    Fidelity = 0.30093325
# T = 20    Fidelity = 0.68212090
# T = 30    Fidelity = 0.76568474
# T = 40    Fidelity = 0.82873717
# T = 50    Fidelity = 0.89532607
# T = 75    Fidelity = 0.95954389
# T = 100   Fidelity = 0.98507212
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.837
# ================================================================================
# Minimum path gap = 2.43704173e-01
# T = 1     Fidelity = 0.00340599
# T = 2     Fidelity = 0.01122579
# T = 5     Fidelity = 0.08968336
# T = 10    Fidelity = 0.31102422
# T = 20    Fidelity = 0.68021801
# T = 30    Fidelity = 0.77983285
# T = 40    Fidelity = 0.83670309
# T = 50    Fidelity = 0.89830793
# T = 75    Fidelity = 0.96218797
# T = 100   Fidelity = 0.98650718
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.876
# ================================================================================
# Minimum path gap = 2.36944606e-01
# T = 1     Fidelity = 0.00482953
# T = 2     Fidelity = 0.01483622
# T = 5     Fidelity = 0.10150927
# T = 10    Fidelity = 0.32151285
# T = 20    Fidelity = 0.67727429
# T = 30    Fidelity = 0.78997780
# T = 40    Fidelity = 0.84572850
# T = 50    Fidelity = 0.90187411
# T = 75    Fidelity = 0.96510624
# T = 100   Fidelity = 0.98778876
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.914
# ================================================================================
# Minimum path gap = 2.30631967e-01
# T = 1     Fidelity = 0.00668235
# T = 2     Fidelity = 0.01925563
# T = 5     Fidelity = 0.11426956
# T = 10    Fidelity = 0.33263409
# T = 20    Fidelity = 0.67401890
# T = 30    Fidelity = 0.79641527
# T = 40    Fidelity = 0.85424698
# T = 50    Fidelity = 0.90618624
# T = 75    Fidelity = 0.96812698
# T = 100   Fidelity = 0.98886878
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.953
# ================================================================================
# Minimum path gap = 2.24756925e-01
# T = 1     Fidelity = 0.00905216
# T = 2     Fidelity = 0.02460557
# T = 5     Fidelity = 0.12808272
# T = 10    Fidelity = 0.34461185
# T = 20    Fidelity = 0.67110411
# T = 30    Fidelity = 0.79981230
# T = 40    Fidelity = 0.86118157
# T = 50    Fidelity = 0.91066570
# T = 75    Fidelity = 0.97115708
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.992
# ================================================================================
# Minimum path gap = 2.19322771e-01
# T = 1     Fidelity = 0.01203697
# T = 2     Fidelity = 0.03101843
# T = 5     Fidelity = 0.14307554
# T = 10    Fidelity = 0.35765230
# T = 20    Fidelity = 0.66909029
# T = 30    Fidelity = 0.80102820
# T = 40    Fidelity = 0.86606100
# T = 50    Fidelity = 0.91454188
# T = 75    Fidelity = 0.97408783
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.031
# ================================================================================
# Minimum path gap = 2.14342798e-01
# T = 1     Fidelity = 0.01574440
# T = 2     Fidelity = 0.03863524
# T = 5     Fidelity = 0.15937608
# T = 10    Fidelity = 0.37193654
# T = 20    Fidelity = 0.66843646
# T = 30    Fidelity = 0.80097112
# T = 40    Fidelity = 0.86894111
# T = 50    Fidelity = 0.91724494
# T = 75    Fidelity = 0.97665608
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.069
# ================================================================================
# Minimum path gap = 2.09837646e-01
# T = 1     Fidelity = 0.02028989
# T = 2     Fidelity = 0.04760148
# T = 5     Fidelity = 0.17710480
# T = 10    Fidelity = 0.38761222
# T = 20    Fidelity = 0.66949504
# T = 30    Fidelity = 0.80049551
# T = 40    Fidelity = 0.87024107
# T = 50    Fidelity = 0.91856880
# T = 75    Fidelity = 0.97847205
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.108
# ================================================================================
# Minimum path gap = 2.05832643e-01
# T = 1     Fidelity = 0.02579339
# T = 2     Fidelity = 0.05806058
# T = 5     Fidelity = 0.19636384
# T = 10    Fidelity = 0.40478426
# T = 20    Fidelity = 0.67250955
# T = 30    Fidelity = 0.80033539
# T = 40    Fidelity = 0.87056874
# T = 50    Fidelity = 0.91865658
# T = 75    Fidelity = 0.97918330
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.147
# ================================================================================
# Minimum path gap = 2.02355174e-01
# T = 1     Fidelity = 0.03237432
# T = 2     Fidelity = 0.07014508
# T = 5     Fidelity = 0.21722503
# T = 10    Fidelity = 0.42350541
# T = 20    Fidelity = 0.67761454
# T = 30    Fidelity = 0.80106599
# T = 40    Fidelity = 0.87057298
# T = 50    Fidelity = 0.91789433
# T = 75    Fidelity = 0.97864279
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.186
# ================================================================================
# Minimum path gap = 1.99432132e-01
# T = 1     Fidelity = 0.04014493
# T = 2     Fidelity = 0.08396575
# T = 5     Fidelity = 0.23971759
# T = 10    Fidelity = 0.44376786
# T = 20    Fidelity = 0.68483780
# T = 30    Fidelity = 0.80308704
# T = 40    Fidelity = 0.87083699
# T = 50    Fidelity = 0.91678210
# T = 75    Fidelity = 0.97698436
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.224
# ================================================================================
# Minimum path gap = 1.97087558e-01
# T = 1     Fidelity = 0.04920214
# T = 2     Fidelity = 0.09959971
# T = 5     Fidelity = 0.26381719
# T = 10    Fidelity = 0.46549756
# T = 20    Fidelity = 0.69410578
# T = 30    Fidelity = 0.80662299
# T = 40    Fidelity = 0.87181335
# T = 50    Fidelity = 0.91582152
# T = 75    Fidelity = 0.97458488
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.263
# ================================================================================
# Minimum path gap = 1.95340561e-01
# T = 1     Fidelity = 0.05961887
# T = 2     Fidelity = 0.11707896
# T = 5     Fidelity = 0.28943810
# T = 10    Fidelity = 0.48855256
# T = 20    Fidelity = 0.70525290
# T = 30    Fidelity = 0.81173645
# T = 40    Fidelity = 0.87379579
# T = 50    Fidelity = 0.91543567
# T = 75    Fidelity = 0.97194107
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.302
# ================================================================================
# Minimum path gap = 1.94203669e-01
# T = 1     Fidelity = 0.07143582
# T = 2     Fidelity = 0.13638094
# T = 5     Fidelity = 0.31643001
# T = 10    Fidelity = 0.51272670
# T = 20    Fidelity = 0.71803547
# T = 30    Fidelity = 0.81835216
# T = 40    Fidelity = 0.87691975
# T = 50    Fidelity = 0.91592346
# T = 75    Fidelity = 0.96951651
# T = 100   Fidelity = 0.98921979
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.341
# ================================================================================
# Minimum path gap = 1.93681684e-01
# T = 1     Fidelity = 0.08465500
# T = 2     Fidelity = 0.15742323
# T = 5     Fidelity = 0.34458092
# T = 10    Fidelity = 0.53775917
# T = 20    Fidelity = 0.73215005
# T = 30    Fidelity = 0.82628805
# T = 40    Fidelity = 0.88118278
# T = 50    Fidelity = 0.91744386
# T = 75    Fidelity = 0.96763162
# T = 100   Fidelity = 0.98686236
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.380
# ================================================================================
# Minimum path gap = 1.93771116e-01
# T = 1     Fidelity = 0.09923610
# T = 2     Fidelity = 0.18006321
# T = 5     Fidelity = 0.37362618
# T = 10    Fidelity = 0.56334919
# T = 20    Fidelity = 0.74725532
# T = 30    Fidelity = 0.83529011
# T = 40    Fidelity = 0.88647611
# T = 50    Fidelity = 0.92002130
# T = 75    Fidelity = 0.96643207
# T = 100   Fidelity = 0.98465198
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.418
# ================================================================================
# Minimum path gap = 1.94460196e-01
# T = 1     Fidelity = 0.11509665
# T = 2     Fidelity = 0.20410366
# T = 5     Fidelity = 0.40326300
# T = 10    Fidelity = 0.58917447
# T = 20    Fidelity = 0.76299543
# T = 30    Fidelity = 0.84506709
# T = 40    Fidelity = 0.89261948
# T = 50    Fidelity = 0.92356455
# T = 75    Fidelity = 0.96593030
# T = 100   Fidelity = 0.98296711
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.457
# ================================================================================
# Minimum path gap = 1.95729417e-01
# T = 1     Fidelity = 0.13211581
# T = 2     Fidelity = 0.22930328
# T = 5     Fidelity = 0.43316843
# T = 10    Fidelity = 0.61491109
# T = 20    Fidelity = 0.77902257
# T = 30    Fidelity = 0.85532165
# T = 40    Fidelity = 0.89939358
# T = 50    Fidelity = 0.92789394
# T = 75    Fidelity = 0.96608297
# T = 100   Fidelity = 0.98206015
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.496
# ================================================================================
# Minimum path gap = 1.97552503e-01
# T = 1     Fidelity = 0.15014151
# T = 2     Fidelity = 0.25539104
# T = 5     Fidelity = 0.46301861
# T = 10    Fidelity = 0.64025236
# T = 20    Fidelity = 0.79501643
# T = 30    Fidelity = 0.86577515
# T = 40    Fidelity = 0.90656647
# T = 50    Fidelity = 0.93277423
# T = 75    Fidelity = 0.96685204
# T = 100   Fidelity = 0.98189716
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.535
# ================================================================================
# Minimum path gap = 1.99897671e-01
# T = 1     Fidelity = 0.16899983
# T = 2     Fidelity = 0.28208209
# T = 5     Fidelity = 0.49250656
# T = 10    Fidelity = 0.66492433
# T = 20    Fidelity = 0.81069883
# T = 30    Fidelity = 0.87618461
# T = 40    Fidelity = 0.91391333
# T = 50    Fidelity = 0.93795061
# T = 75    Fidelity = 0.96821114
# T = 100   Fidelity = 0.98222196
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.573
# ================================================================================
# Minimum path gap = 2.02729043e-01
# T = 1     Fidelity = 0.18850514
# T = 2     Fidelity = 0.30909336
# T = 5     Fidelity = 0.52135678
# T = 10    Fidelity = 0.68869685
# T = 20    Fidelity = 0.82584249
# T = 30    Fidelity = 0.88635179
# T = 40    Fidelity = 0.92122997
# T = 50    Fidelity = 0.94318308
# T = 75    Fidelity = 0.97010841
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.612
# ================================================================================
# Minimum path gap = 2.06008070e-01
# T = 1     Fidelity = 0.20847002
# T = 2     Fidelity = 0.33615698
# T = 5     Fidelity = 0.54933526
# T = 10    Fidelity = 0.71138934
# T = 20    Fidelity = 0.84027426
# T = 30    Fidelity = 0.89612546
# T = 40    Fidelity = 0.92834173
# T = 50    Fidelity = 0.94827426
# T = 75    Fidelity = 0.97242462
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.651
# ================================================================================
# Minimum path gap = 2.09694873e-01
# T = 1     Fidelity = 0.22871371
# T = 2     Fidelity = 0.36303047
# T = 5     Fidelity = 0.57625481
# T = 10    Fidelity = 0.73287187
# T = 20    Fidelity = 0.85387353
# T = 30    Fidelity = 0.90539849
# T = 40    Fidelity = 0.93510907
# T = 50    Fidelity = 0.95308600
# T = 75    Fidelity = 0.97496806
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.690
# ================================================================================
# Minimum path gap = 2.13749401e-01
# T = 1     Fidelity = 0.24906870
# T = 2     Fidelity = 0.38950342
# T = 5     Fidelity = 0.60197603
# T = 10    Fidelity = 0.75306238
# T = 20    Fidelity = 0.86656713
# T = 30    Fidelity = 0.91410196
# T = 40    Fidelity = 0.94143042
# T = 50    Fidelity = 0.95754328
# T = 75    Fidelity = 0.97751873
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.729
# ================================================================================
# Minimum path gap = 2.18132396e-01
# T = 1     Fidelity = 0.26938512
# T = 2     Fidelity = 0.41540065
# T = 5     Fidelity = 0.62640482
# T = 10    Fidelity = 0.77192126
# T = 20    Fidelity = 0.87832212
# T = 30    Fidelity = 0.92219781
# T = 40    Fidelity = 0.94724242
# T = 50    Fidelity = 0.96162640
# T = 75    Fidelity = 0.97989870
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.767
# ================================================================================
# Minimum path gap = 2.22806129e-01
# T = 1     Fidelity = 0.28953320
# T = 2     Fidelity = 0.44058255
# T = 5     Fidelity = 0.64948766
# T = 10    Fidelity = 0.78944445
# T = 20    Fidelity = 0.88913780
# T = 30    Fidelity = 0.92967164
# T = 40    Fidelity = 0.95251754
# T = 50    Fidelity = 0.96535499
# T = 75    Fidelity = 0.98202371
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.806
# ================================================================================
# Minimum path gap = 2.27734927e-01
# T = 1     Fidelity = 0.30940397
# T = 2     Fidelity = 0.46494325
# T = 5     Fidelity = 0.67120554
# T = 10    Fidelity = 0.80565615
# T = 20    Fidelity = 0.89903775
# T = 30    Fidelity = 0.93652625
# T = 40    Fidelity = 0.95725936
# T = 50    Fidelity = 0.96876871
# T = 75    Fidelity = 0.98390567
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.845
# ================================================================================
# Minimum path gap = 2.32885520e-01
# T = 1     Fidelity = 0.32890874
# T = 2     Fidelity = 0.48840742
# T = 5     Fidelity = 0.69156743
# T = 10    Fidelity = 0.82060174
# T = 20    Fidelity = 0.90806274
# T = 30    Fidelity = 0.94277658
# T = 40    Fidelity = 0.96149603
# T = 50    Fidelity = 0.97190957
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.884
# ================================================================================
# Minimum path gap = 2.38227223e-01
# T = 1     Fidelity = 0.34797768
# T = 2     Fidelity = 0.51092630
# T = 5     Fidelity = 0.71060405
# T = 10    Fidelity = 0.83434147
# T = 20    Fidelity = 0.91626459
# T = 30    Fidelity = 0.94844582
# T = 40    Fidelity = 0.96527272
# T = 50    Fidelity = 0.97480949
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.922
# ================================================================================
# Minimum path gap = 2.43732008e-01
# T = 1     Fidelity = 0.36655788
# T = 2     Fidelity = 0.53247348
# T = 5     Fidelity = 0.72836212
# T = 10    Fidelity = 0.84694519
# T = 20    Fidelity = 0.92370135
# T = 30    Fidelity = 0.95356284
# T = 40    Fidelity = 0.96864387
# T = 50    Fidelity = 0.97748493
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.961
# ================================================================================
# Minimum path gap = 2.49374469e-01
# T = 1     Fidelity = 0.38461118
# T = 2     Fidelity = 0.55304080
# T = 5     Fidelity = 0.74489946
# T = 10    Fidelity = 0.85848797
# T = 20    Fidelity = 0.93043358
# T = 30    Fidelity = 0.95816031
# T = 40    Fidelity = 0.97166612
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 2.000
# ================================================================================
# Minimum path gap = 2.55131735e-01
# T = 1     Fidelity = 0.40211198
# T = 2     Fidelity = 0.57263453
# T = 5     Fidelity = 0.76028096
# T = 10    Fidelity = 0.86904680
# T = 20    Fidelity = 0.93652161
# T = 30    Fidelity = 0.96227353
# T = 40    Fidelity = 0.97439241
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.100
# ================================================================================
# Minimum path gap = 6.07266718e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000008
# T = 5     Fidelity = 0.00083241
# T = 10    Fidelity = 0.06385295
# T = 20    Fidelity = 0.45561586
# T = 30    Fidelity = 0.88090302
# T = 40    Fidelity = 0.96753909
# T = 50    Fidelity = 0.99173612
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.139
# ================================================================================
# Minimum path gap = 6.39041271e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000011
# T = 5     Fidelity = 0.00277418
# T = 10    Fidelity = 0.12239360
# T = 20    Fidelity = 0.74317000
# T = 30    Fidelity = 0.98630554
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.178
# ================================================================================
# Minimum path gap = 6.63631067e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000018
# T = 5     Fidelity = 0.00630198
# T = 10    Fidelity = 0.24214790
# T = 20    Fidelity = 0.92567030
# T = 30    Fidelity = 0.99507125
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.216
# ================================================================================
# Minimum path gap = 6.83849556e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000029
# T = 5     Fidelity = 0.01075931
# T = 10    Fidelity = 0.46357795
# T = 20    Fidelity = 0.98343952
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.255
# ================================================================================
# Minimum path gap = 7.01032133e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000055
# T = 5     Fidelity = 0.01547415
# T = 10    Fidelity = 0.71641711
# T = 20    Fidelity = 0.94832378
# T = 30    Fidelity = 0.99555059
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Strong SSB
# lambda : 0.294
# ...
# Symmetric      0.255     1         0.9823108214      1.02424866e+00    None        None        None
# Symmetric      0.294     1         0.9825683490      1.02778454e+00    None        None        None
# Symmetric      0.333     1         0.9828184272      1.03128433e+00    None        None        None
# Symmetric      0.371     1         0.9830614233      1.03474909e+00    None        None        None
# Symmetric      0.410     1         0.9832976777      1.03817982e+00    None        None        None
# Symmetric      0.449     1         0.9835275064      1.04157748e+00    None        None        None
# Symmetric      0.488     1         0.9837512038      1.04494298e+00    None        None        None
# Symmetric      0.527     1         0.9839690441      1.04827719e+00    None        None        None
# Symmetric      0.565     1         0.9841812836      1.05158093e+00    None        None        None
# Symmetric      0.604     1         0.9843881621      1.05485500e+00    None        None        None
# Symmetric      0.643     1         0.9845899043      1.05810014e+00    None        None        None
# Symmetric      0.682     1         0.9847867213      1.06131708e+00    None        None        None
# Symmetric      0.720     1         0.9849788112      1.06450651e+00    None        None        None
# Symmetric      0.759     1         0.9851663609      1.06766910e+00    None        None        None
# Symmetric      0.798     1         0.9853495463      1.07080547e+00    None        None        None
# Symmetric      0.837     1         0.9855285334      1.07391624e+00    None        None        None
# Symmetric      0.876     1         0.9857034792      1.07700199e+00    None        None        None
# Symmetric      0.914     1         0.9858745320      1.08006328e+00    None        None        None
# Symmetric      0.953     1         0.9860418324      1.08310066e+00    None        None        None
# Symmetric      0.992     1         0.9862055136      1.08611464e+00    None        None        None
# Symmetric      1.031     1         0.9863657020      1.08910574e+00    None        None        None
# Symmetric      1.069     1         0.9865225176      1.09207442e+00    None        None        None
# Symmetric      1.108     1         0.9866760746      1.09502116e+00    None        None        None
# Symmetric      1.147     1         0.9868264815      1.09794640e+00    None        None        None
# Symmetric      1.186     1         0.9869738417      1.10085059e+00    None        None        None
# Symmetric      1.224     1         0.9871182538      1.10373413e+00    None        None        None
# Symmetric      1.263     1         0.9872598117      1.10659744e+00    None        None        None
# Symmetric      1.302     1         0.9873986051      1.10944091e+00    None        None        None
# Symmetric      1.341     1         0.9875347197      1.11226491e+00    None        None        None
# Symmetric      1.380     1         0.9876682374      1.11506981e+00    None        None        None
# Symmetric      1.418     1         0.9877992365      1.11785597e+00    None        None        None
# Symmetric      1.457     1         0.9879277920      1.12062373e+00    None        None        None
# Symmetric      1.496     1         0.9880539757      1.12337343e+00    None        None        None
# Symmetric      1.535     1         0.9881778564      1.12610538e+00    None        None        None
# Symmetric      1.573     1         0.9882995001      1.12881990e+00    None        None        None
# Symmetric      1.612     1         0.9884189701      1.13151730e+00    None        None        None
# Symmetric      1.651     1         0.9885363271      1.13419787e+00    None        None        None
# Symmetric      1.690     1         0.9886516295      1.13686189e+00    None        None        None
# Symmetric      1.729     1         0.9887649334      1.13950965e+00    None        None        None
# Symmetric      1.767     1         0.9888762928      1.14214142e+00    None        None        None
# Symmetric      1.806     1         0.9889857595      1.14475745e+00    None        None        None
# Symmetric      1.845     1         0.9890933834      1.14735801e+00    None        None        None
# Symmetric      1.884     1         0.9891992127      1.14994335e+00    None        None        None
# Symmetric      1.922     1         0.9893032936      1.15251370e+00    None        None        None
# Symmetric      1.961     1         0.9894056708      1.15506930e+00    None        None        None
# Symmetric      2.000     1         0.9895063874      1.15761039e+00    None        None        None
# Weak SSB optimised0.100     400       0.9809448341      2.42819099e-01    None        None        None
# Weak SSB optimised0.139     225       0.9717903382      2.49811160e-01    None        None        None
# Weak SSB optimised0.178     200       0.9837111130      2.54072606e-01    None        None        None
# Weak SSB optimised0.216     175       0.9815008664      2.56643112e-01    None        None        None
# Weak SSB optimised0.255     275       0.9763815372      2.58669725e-01    None        None        None
# Weak SSB optimised0.294     250       0.9723724887      2.60278666e-01    None        None        None
# Weak SSB optimised0.333     225       0.9735009111      2.61560480e-01    None        None        None
# Weak SSB optimised0.371     150       0.9728265717      2.62582285e-01    None        None        None
# Weak SSB optimised0.410     125       0.9725054019      2.63395041e-01    None        None        None
# Weak SSB optimised0.449     125       0.9776844311      2.64038170e-01    None        None        None
# Weak SSB optimised0.488     125       0.9808040404      2.64542625e-01    None        None        None
# Weak SSB optimised0.527     125       0.9848387583      2.64932997e-01    None        None        None
# Weak SSB optimised0.565     100       0.9706675139      2.65229010e-01    None        None        None
# Weak SSB optimised0.604     100       0.9722380360      2.65446588e-01    None        None        None
# Weak SSB optimised0.643     100       0.9752965280      2.65598657e-01    None        None        None
# Weak SSB optimised0.682     100       0.9791609020      2.65695732e-01    None        None        None
# Weak SSB optimised0.720     100       0.9819374660      2.65746368e-01    None        None        None
# Weak SSB optimised0.759     100       0.9836274940      2.58678635e-01    None        None        None
# Weak SSB optimised0.798     100       0.9850721222      2.50935075e-01    None        None        None
# Weak SSB optimised0.837     100       0.9865071778      2.43704173e-01    None        None        None
# Weak SSB optimised0.876     100       0.9877887587      2.36944606e-01    None        None        None
# Weak SSB optimised0.914     100       0.9888687835      2.30631967e-01    None        None        None
# Weak SSB optimised0.953     75        0.9711570840      2.24756925e-01    None        None        None
# Weak SSB optimised0.992     75        0.9740878251      2.19322771e-01    None        None        None
# Weak SSB optimised1.031     75        0.9766560789      2.14342798e-01    None        None        None
# Weak SSB optimised1.069     75        0.9784720463      2.09837646e-01    None        None        None
# Weak SSB optimised1.108     75        0.9791832958      2.05832643e-01    None        None        None
# Weak SSB optimised1.147     75        0.9786427908      2.02355174e-01    None        None        None
# Weak SSB optimised1.186     75        0.9769843638      1.99432132e-01    None        None        None
# Weak SSB optimised1.224     75        0.9745848821      1.97087558e-01    None        None        None
# Weak SSB optimised1.263     75        0.9719410725      1.95340561e-01    None        None        None
# Weak SSB optimised1.302     100       0.9892197916      1.94203669e-01    None        None        None
# Weak SSB optimised1.341     100       0.9868623593      1.93681684e-01    None        None        None
# Weak SSB optimised1.380     100       0.9846519827      1.93771116e-01    None        None        None
# Weak SSB optimised1.418     100       0.9829671075      1.94460196e-01    None        None        None
# Weak SSB optimised1.457     100       0.9820601450      1.95729417e-01    None        None        None
# Weak SSB optimised1.496     100       0.9818971557      1.97552503e-01    None        None        None
# Weak SSB optimised1.535     100       0.9822219647      1.99897671e-01    None        None        None
# Weak SSB optimised1.573     75        0.9701084069      2.02729043e-01    None        None        None
# Weak SSB optimised1.612     75        0.9724246187      2.06008070e-01    None        None        None
# Weak SSB optimised1.651     75        0.9749680615      2.09694873e-01    None        None        None
# Weak SSB optimised1.690     75        0.9775187291      2.13749401e-01    None        None        None
# Weak SSB optimised1.729     75        0.9798987013      2.18132396e-01    None        None        None
# Weak SSB optimised1.767     75        0.9820237122      2.22806129e-01    None        None        None
# Weak SSB optimised1.806     75        0.9839056697      2.27734927e-01    None        None        None
# Weak SSB optimised1.845     50        0.9719095731      2.32885520e-01    None        None        None
# Weak SSB optimised1.884     50        0.9748094880      2.38227223e-01    None        None        None
# Weak SSB optimised1.922     50        0.9774849311      2.43732008e-01    None        None        None
# Weak SSB optimised1.961     40        0.9716661152      2.49374469e-01    None        None        None
# Weak SSB optimised2.000     40        0.9743924077      2.55131735e-01    None        None        None
# Strong SSB     0.100     50        0.9917361242      6.07266718e-01    None        None        None
# Strong SSB     0.139     30        0.9863055357      6.39041271e-01    None        None        None
# Strong SSB     0.178     30        0.9950712538      6.63631067e-01    None        None        None
# Strong SSB     0.216     20        0.9834395175      6.83849556e-01    None        None        None
# Strong SSB     0.255     30        0.9955505945      7.01032133e-01    None        None        None
# Strong SSB     0.294     30        0.9924501189      7.15986695e-01    None        None        None
# Strong SSB     0.333     30        0.9933665758      7.29239313e-01    None        None        None
# Strong SSB     0.371     40        0.9920004221      7.41151726e-01    None        None        None
# Strong SSB     0.410     40        0.9870003770      7.51949506e-01    None        None        None
# Strong SSB     0.449     20        0.9853114498      7.61746768e-01    None        None        None
# Strong SSB     0.488     10        0.9841765811      7.70800538e-01    None        None        None
# Strong SSB     0.527     10        0.9887198676      7.79226914e-01    None        None        None
# Strong SSB     0.565     10        0.9892797941      7.87117731e-01    None        None        None
# Strong SSB     0.604     10        0.9887078469      7.94443925e-01    None        None        None
# Strong SSB     0.643     10        0.9880323697      8.01302198e-01    None        None        None
# Strong SSB     0.682     10        0.9874462369      8.07814178e-01    None        None        None
# Strong SSB     0.720     10        0.9868676780      8.14021160e-01    None        None        None
# Strong SSB     0.759     10        0.9862001583      8.19792177e-01    None        None        None
# Strong SSB     0.798     10        0.9854061591      8.25318461e-01    None        None        None
# Strong SSB     0.837     10        0.9844987489      8.30635575e-01    None        None        None
# Strong SSB     0.876     10        0.9835144479      8.35646817e-01    None        None        None
# Strong SSB     0.914     10        0.9824924430      8.40436724e-01    None        None        None
# Strong SSB     0.953     10        0.9814643421      8.45079811e-01    None        None        None
# Strong SSB     0.992     10        0.9804515258      8.49481679e-01    None        None        None
# Strong SSB     1.031     10        0.9794664031      8.53703111e-01    None        None        None
# Strong SSB     1.069     10        0.9785150000      8.57820216e-01    None        None        None
# Strong SSB     1.108     10        0.9775995088      8.61718673e-01    None        None        None
# Strong SSB     1.147     10        0.9767202493      8.65489995e-01    None        None        None
# Strong SSB     1.186     10        0.9758769454      8.69186996e-01    None        None        None
# Strong SSB     1.224     10        0.9750694244      8.72659708e-01    None        None        None
# Strong SSB     1.263     10        0.9742979045      8.76067422e-01    None        None        None
# Strong SSB     1.302     10        0.9735630304      8.79379989e-01    None        None        None
# Strong SSB     1.341     10        0.9728657756      8.82528320e-01    None        None        None
# Strong SSB     1.380     10        0.9722072957      8.85637502e-01    None        None        None
# Strong SSB     1.418     10        0.9715887808      8.88607958e-01    None        None        None
# Strong SSB     1.457     10        0.9710113307      8.91494656e-01    None        None        None
# Strong SSB     1.496     10        0.9704758641      8.94338934e-01    None        None        None
# Strong SSB     1.535     20        0.9931399482      8.97023563e-01    None        None        None
# Strong SSB     1.573     20        0.9932111229      8.99691214e-01    None        None        None
# Strong SSB     1.612     20        0.9932818192      9.02249629e-01    None        None        None
# Strong SSB     1.651     20        0.9933515392      9.04740729e-01    None        None        None
# Strong SSB     1.690     20        0.9934198931      9.07194851e-01    None        None        None
# Strong SSB     1.729     20        0.9934865847      9.09524076e-01    None        None        None
# Strong SSB     1.767     20        0.9935513997      9.11850846e-01    None        None        None
# Strong SSB     1.806     20        0.9936141958      9.14058775e-01    None        None        None
# Strong SSB     1.845     20        0.9936748953      9.16242117e-01    None        None        None
# Strong SSB     1.884     20        0.9937334775      9.18360165e-01    None        None        None
# Strong SSB     1.922     20        0.9937899714      9.20411078e-01    None        None        None
# Strong SSB     1.961     20        0.9938444489      9.22441717e-01    None        None        None
# Strong SSB     2.000     20        0.9938970179      9.24370129e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================

case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        color=case_colors[case],
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=1$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric', color="blue")

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised', color="green")

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB', color="red")

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title('Energy Gap')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Order parameter operator
# ============================================================

Phi0, Pi0, Phi1, Pi1 = two_site_operators(

    nq_site,

    mu
)

Phi_avg = 0.5 * (Phi0 + Phi1)

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []

for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

   # Exact ground state of H_loc
    psi_exact = match['psi_exact']

# Adiabatic evolution starts from the exact local ground state
    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)

    elif case == "Strong SSB":

        M_strong.append(M)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_list)

dM_weak = np.gradient(M_weak_opt, lambda_list)

dM_strong = np.gradient(M_strong, lambda_list)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_list)

d2M_weak = np.gradient(dM_weak, lambda_list)

d2M_strong = np.gradient(dM_strong, lambda_list)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_list)

d3M_weak = np.gradient(d2M_weak, lambda_list)

d3M_strong = np.gradient(d2M_strong, lambda_list)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_list,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_list,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_list,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_list,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='blue'
)

line2, = plt.plot(
    lambda_list,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='green'
)

line3, = plt.plot(
    lambda_list,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='red'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_list,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_list,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_list,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title('Order Parameter')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_list,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_list,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_list,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_0^2=1$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Starting of m0^2=2

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_exact = data['psi_exact']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 1.01220263e+00
# T = 1     Fidelity = 0.96521661
# T = 2     Fidelity = 0.99334594
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.139
# ================================================================================
# Minimum path gap = 1.01678457e+00
# T = 1     Fidelity = 0.96577502
# T = 2     Fidelity = 0.99352362
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.178
# ================================================================================
# Minimum path gap = 1.02128943e+00
# T = 1     Fidelity = 0.96631610
# T = 2     Fidelity = 0.99369313
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.216
# ================================================================================
# Minimum path gap = 1.02572101e+00
# T = 1     Fidelity = 0.96684075
# T = 2     Fidelity = 0.99385499
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.255
# ================================================================================
# Minimum path gap = 1.03008277e+00
# T = 1     Fidelity = 0.96734982
# T = 2     Fidelity = 0.99400967
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.294
# ================================================================================
# Minimum path gap = 1.03437790e+00
# T = 1     Fidelity = 0.96784408
# T = 2     Fidelity = 0.99415761
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.333
# ================================================================================
# Minimum path gap = 1.03860932e+00
# T = 1     Fidelity = 0.96832424
# T = 2     Fidelity = 0.99429920
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.371
# ================================================================================
# Minimum path gap = 1.04277975e+00
# T = 1     Fidelity = 0.96879097
# T = 2     Fidelity = 0.99443483
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.410
# ================================================================================
# Minimum path gap = 1.04689171e+00
# T = 1     Fidelity = 0.96924489
# T = 2     Fidelity = 0.99456483
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.449
# ================================================================================
# Minimum path gap = 1.05094753e+00
# T = 1     Fidelity = 0.96968658
# T = 2     Fidelity = 0.99468952
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.488
# ================================================================================
# Minimum path gap = 1.05494941e+00
# T = 1     Fidelity = 0.97011657
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.527
# ================================================================================
# Minimum path gap = 1.05889937e+00
# T = 1     Fidelity = 0.97053538
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.565
# ================================================================================
# Minimum path gap = 1.06279932e+00
# T = 1     Fidelity = 0.97094347
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.604
# ================================================================================
# Minimum path gap = 1.06665106e+00
# T = 1     Fidelity = 0.97134128
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.643
# ================================================================================
# Minimum path gap = 1.07045626e+00
# T = 1     Fidelity = 0.97172925
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.682
# ================================================================================
# Minimum path gap = 1.07421650e+00
# T = 1     Fidelity = 0.97210775
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.720
# ================================================================================
# Minimum path gap = 1.07793327e+00
# T = 1     Fidelity = 0.97247715
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.759
# ================================================================================
# Minimum path gap = 1.08160799e+00
# T = 1     Fidelity = 0.97283782
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.798
# ================================================================================
# Minimum path gap = 1.08524197e+00
# T = 1     Fidelity = 0.97319007
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.837
# ================================================================================
# Minimum path gap = 1.08883649e+00
# T = 1     Fidelity = 0.97353422
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.876
# ================================================================================
# Minimum path gap = 1.09239274e+00
# T = 1     Fidelity = 0.97387057
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.914
# ================================================================================
# Minimum path gap = 1.09591184e+00
# T = 1     Fidelity = 0.97419939
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.953
# ================================================================================
# Minimum path gap = 1.09939488e+00
# T = 1     Fidelity = 0.97452096
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.992
# ================================================================================
# Minimum path gap = 1.10284288e+00
# T = 1     Fidelity = 0.97483551
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.031
# ================================================================================
# Minimum path gap = 1.10625682e+00
# T = 1     Fidelity = 0.97514331
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.069
# ================================================================================
# Minimum path gap = 1.10963763e+00
# T = 1     Fidelity = 0.97544456
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.108
# ================================================================================
# Minimum path gap = 1.11298620e+00
# T = 1     Fidelity = 0.97573949
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.147
# ================================================================================
# Minimum path gap = 1.11630337e+00
# T = 1     Fidelity = 0.97602831
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.186
# ================================================================================
# Minimum path gap = 1.11958995e+00
# T = 1     Fidelity = 0.97631122
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.224
# ================================================================================
# Minimum path gap = 1.12284673e+00
# T = 1     Fidelity = 0.97658840
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.263
# ================================================================================
# Minimum path gap = 1.12607444e+00
# T = 1     Fidelity = 0.97686003
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.302
# ================================================================================
# Minimum path gap = 1.12927379e+00
# T = 1     Fidelity = 0.97712628
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.341
# ================================================================================
# Minimum path gap = 1.13244548e+00
# T = 1     Fidelity = 0.97738733
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.380
# ================================================================================
# Minimum path gap = 1.13559015e+00
# T = 1     Fidelity = 0.97764332
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.418
# ================================================================================
# Minimum path gap = 1.13870844e+00
# T = 1     Fidelity = 0.97789441
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.457
# ================================================================================
# Minimum path gap = 1.14180095e+00
# T = 1     Fidelity = 0.97814074
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.496
# ================================================================================
# Minimum path gap = 1.14486825e+00
# T = 1     Fidelity = 0.97838246
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.535
# ================================================================================
# Minimum path gap = 1.14791092e+00
# T = 1     Fidelity = 0.97861968
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.573
# ================================================================================
# Minimum path gap = 1.15092950e+00
# T = 1     Fidelity = 0.97885255
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.612
# ================================================================================
# Minimum path gap = 1.15392449e+00
# T = 1     Fidelity = 0.97908119
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.651
# ================================================================================
# Minimum path gap = 1.15689641e+00
# T = 1     Fidelity = 0.97930570
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.690
# ================================================================================
# Minimum path gap = 1.15984573e+00
# T = 1     Fidelity = 0.97952621
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.729
# ================================================================================
# Minimum path gap = 1.16277292e+00
# T = 1     Fidelity = 0.97974283
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.767
# ================================================================================
# Minimum path gap = 1.16567844e+00
# T = 1     Fidelity = 0.97995565
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.806
# ================================================================================
# Minimum path gap = 1.16856272e+00
# T = 1     Fidelity = 0.98016478
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.845
# ================================================================================
# Minimum path gap = 1.17142618e+00
# T = 1     Fidelity = 0.98037032
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.884
# ================================================================================
# Minimum path gap = 1.17426923e+00
# T = 1     Fidelity = 0.98057236
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.922
# ================================================================================
# Minimum path gap = 1.17709225e+00
# T = 1     Fidelity = 0.98077098
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.961
# ================================================================================
# Minimum path gap = 1.17989564e+00
# T = 1     Fidelity = 0.98096629
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.18267976e+00
# T = 1     Fidelity = 0.98115836
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.43127858e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000149
# T = 10    Fidelity = 0.00047332
# T = 20    Fidelity = 0.00569862
# T = 30    Fidelity = 0.01813085
# T = 40    Fidelity = 0.06193818
# T = 50    Fidelity = 0.16170465
# T = 75    Fidelity = 0.32402788
# T = 100   Fidelity = 0.48071385
# T = 125   Fidelity = 0.62846430
# T = 150   Fidelity = 0.72560861
# T = 175   Fidelity = 0.79321597
# T = 200   Fidelity = 0.83461999
# T = 225   Fidelity = 0.84735507
# T = 250   Fidelity = 0.85438463
# T = 275   Fidelity = 0.71767815
# T = 300   Fidelity = 0.79193144
# T = 400   Fidelity = 0.93093367
# T = 500   Fidelity = 0.91058678
# T = 600   Fidelity = 0.89282403
# T = 700   Fidelity = 0.81714713
# T = 800   Fidelity = 0.64758495
# T = 900   Fidelity = 0.74801514
# T = 1000  Fidelity = 0.62831941
# T = 1010  Fidelity = 0.62101533
# T = 1020  Fidelity = 0.70167591
# T = 1030  Fidelity = 0.67261045
# T = 1040  Fidelity = 0.25365841
# T = 1050  Fidelity = 0.41791175
# T = 1060  Fidelity = 0.50070953
# T = 1070  Fidelity = 0.47186165
# T = 1080  Fidelity = 0.56672806
# T = 1090  Fidelity = 0.54978659
# T = 1100  Fidelity = 0.75368710
# T = 1200  Fidelity = 0.22441469
# T = 1300  Fidelity = 0.25298838
# T = 1400  Fidelity = 0.65236795
# T = 1500  Fidelity = 0.48377233
# T = 2000  Fidelity = 0.33824690
# T = 2100  Fidelity = 0.88744521
# T = 2110  Fidelity = 0.81705806
# T = 2120  Fidelity = 0.76938758
# T = 2130  Fidelity = 0.74849092
# T = 2140  Fidelity = 0.54525989
# T = 2150  Fidelity = 0.75889288
# T = 2160  Fidelity = 0.56105991
# T = 2170  Fidelity = 0.63703445
# T = 2180  Fidelity = 0.70410324
# T = 2190  Fidelity = 0.53384483
# T = 2200  Fidelity = 0.52888515
# T = 2300  Fidelity = 0.33928010
# T = 2400  Fidelity = 0.51618409
# T = 2500  Fidelity = 0.52613070
# T = 2600  Fidelity = 0.30616832
# T = 2700  Fidelity = 0.24573201
# T = 2800  Fidelity = 0.53839521
# T = 2900  Fidelity = 0.50677933
# T = 3000  Fidelity = 0.91728000
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.41952575e+00
# P0     = 0.91728000
# P1     = 0.00917301
# P0+P1  = 0.92645300
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.139
# ================================================================================
# Minimum path gap = 2.48511987e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000079
# T = 10    Fidelity = 0.00135921
# T = 20    Fidelity = 0.00793730
# T = 30    Fidelity = 0.10919435
# T = 40    Fidelity = 0.10277626
# T = 50    Fidelity = 0.24134236
# T = 75    Fidelity = 0.44116859
# T = 100   Fidelity = 0.57241919
# T = 125   Fidelity = 0.71400146
# T = 150   Fidelity = 0.76639627
# T = 175   Fidelity = 0.88318780
# T = 200   Fidelity = 0.89697012
# T = 225   Fidelity = 0.94749313
# T = 250   Fidelity = 0.92939440
# T = 275   Fidelity = 0.94204239
# T = 300   Fidelity = 0.89638207
# T = 400   Fidelity = 0.96039646
# T = 500   Fidelity = 0.94987402
# T = 600   Fidelity = 0.80756262
# T = 700   Fidelity = 0.74818968
# T = 800   Fidelity = 0.62050254
# T = 900   Fidelity = 0.62540873
# T = 1000  Fidelity = 0.54922101
# T = 1010  Fidelity = 0.18321670
# T = 1020  Fidelity = 0.43890168
# T = 1030  Fidelity = 0.45234206
# T = 1040  Fidelity = 0.67595623
# T = 1050  Fidelity = 0.64087232
# T = 1060  Fidelity = 0.78205720
# T = 1070  Fidelity = 0.79118561
# T = 1080  Fidelity = 0.71280440
# T = 1090  Fidelity = 0.60367758
# T = 1100  Fidelity = 0.45169917
# T = 1200  Fidelity = 0.39783749
# T = 1300  Fidelity = 0.36394098
# T = 1400  Fidelity = 0.86206261
# T = 1500  Fidelity = 0.54813607
# T = 2000  Fidelity = 0.65552003
# T = 2100  Fidelity = 0.74296711
# T = 2110  Fidelity = 0.68766767
# T = 2120  Fidelity = 0.73598916
# T = 2130  Fidelity = 0.65105154
# T = 2140  Fidelity = 0.78343402
# T = 2150  Fidelity = 0.67410294
# T = 2160  Fidelity = 0.42210136
# T = 2170  Fidelity = 0.65738213
# T = 2180  Fidelity = 0.57274784
# T = 2190  Fidelity = 0.17287851
# T = 2200  Fidelity = 0.17682039
# T = 2300  Fidelity = 0.18694575
# T = 2400  Fidelity = 0.74894437
# T = 2500  Fidelity = 0.39903856
# T = 2600  Fidelity = 0.46920145
# T = 2700  Fidelity = 0.55169545
# T = 2800  Fidelity = 0.75158164
# T = 2900  Fidelity = 0.74407883
# T = 3000  Fidelity = 0.64761465
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.42156814e+00
# P0     = 0.64761465
# P1     = 0.01323759
# P0+P1  = 0.66085224
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.178
# ================================================================================
# Minimum path gap = 2.52995565e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000078
# T = 10    Fidelity = 0.00214150
# T = 20    Fidelity = 0.01683712
# T = 30    Fidelity = 0.15030709
# T = 40    Fidelity = 0.32553450
# T = 50    Fidelity = 0.35435390
# T = 75    Fidelity = 0.56991392
# T = 100   Fidelity = 0.69710482
# T = 125   Fidelity = 0.83301243
# T = 150   Fidelity = 0.89736739
# T = 175   Fidelity = 0.85231820
# T = 200   Fidelity = 0.85161771
# T = 225   Fidelity = 0.90595945
# T = 250   Fidelity = 0.95443766
# T = 275   Fidelity = 0.95770418
# T = 300   Fidelity = 0.98341736
#
# Minimum T for Fidelity >= 0.97 : 300
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.216
# ================================================================================
# Minimum path gap = 2.57174959e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000153
# T = 10    Fidelity = 0.00212448
# T = 20    Fidelity = 0.05294483
# T = 30    Fidelity = 0.22722140
# T = 40    Fidelity = 0.55517326
# T = 50    Fidelity = 0.34277607
# T = 75    Fidelity = 0.61501701
# T = 100   Fidelity = 0.81424017
# T = 125   Fidelity = 0.77125355
# T = 150   Fidelity = 0.78787292
# T = 175   Fidelity = 0.90681541
# T = 200   Fidelity = 0.97295328
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.255
# ================================================================================
# Minimum path gap = 2.59122113e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000351
# T = 10    Fidelity = 0.00179637
# T = 20    Fidelity = 0.14199079
# T = 30    Fidelity = 0.28314113
# T = 40    Fidelity = 0.51322736
# T = 50    Fidelity = 0.52809962
# T = 75    Fidelity = 0.84247459
# T = 100   Fidelity = 0.73623953
# T = 125   Fidelity = 0.73783788
# T = 150   Fidelity = 0.95269316
# T = 175   Fidelity = 0.93676376
# T = 200   Fidelity = 0.87613523
# T = 225   Fidelity = 0.94701516
# T = 250   Fidelity = 0.98682062
#
# Minimum T for Fidelity >= 0.97 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.294
# ================================================================================
# Minimum path gap = 2.59830215e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00000962
# T = 10    Fidelity = 0.00217300
# T = 20    Fidelity = 0.20610405
# T = 30    Fidelity = 0.26286385
# T = 40    Fidelity = 0.41921932
# T = 50    Fidelity = 0.69497513
# T = 75    Fidelity = 0.80171877
# T = 100   Fidelity = 0.64348215
# T = 125   Fidelity = 0.88648866
# T = 150   Fidelity = 0.84071609
# T = 175   Fidelity = 0.82723209
# T = 200   Fidelity = 0.98141054
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.333
# ================================================================================
# Minimum path gap = 2.61148987e-01
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000010
# T = 5     Fidelity = 0.00003739
# T = 10    Fidelity = 0.00470888
# T = 20    Fidelity = 0.24225555
# T = 30    Fidelity = 0.34780318
# T = 40    Fidelity = 0.28375869
# T = 50    Fidelity = 0.74944788
# T = 75    Fidelity = 0.71690765
# T = 100   Fidelity = 0.74192449
# T = 125   Fidelity = 0.80603045
# T = 150   Fidelity = 0.80035970
# T = 175   Fidelity = 0.95775659
# T = 200   Fidelity = 0.90983149
# T = 225   Fidelity = 0.93744520
# T = 250   Fidelity = 0.95611224
# T = 275   Fidelity = 0.93278265
# T = 300   Fidelity = 0.96048325
# T = 400   Fidelity = 0.95709574
# T = 500   Fidelity = 0.94956388
# T = 600   Fidelity = 0.71332140
# T = 700   Fidelity = 0.32408029
# T = 800   Fidelity = 0.78265554
# T = 900   Fidelity = 0.67997848
# T = 1000  Fidelity = 0.81594811
# T = 1010  Fidelity = 0.79328807
# T = 1020  Fidelity = 0.81414503
# T = 1030  Fidelity = 0.73038720
# T = 1040  Fidelity = 0.61342662
# T = 1050  Fidelity = 0.61070077
# T = 1060  Fidelity = 0.57233944
# T = 1070  Fidelity = 0.57997961
# T = 1080  Fidelity = 0.55085727
# T = 1090  Fidelity = 0.56634977
# T = 1100  Fidelity = 0.48079827
# T = 1200  Fidelity = 0.75704204
# T = 1300  Fidelity = 0.78899886
# T = 1400  Fidelity = 0.91786933
# T = 1500  Fidelity = 0.92468903
# T = 2000  Fidelity = 0.67694145
# T = 2100  Fidelity = 0.81148357
# T = 2110  Fidelity = 0.66045385
# T = 2120  Fidelity = 0.58542500
# T = 2130  Fidelity = 0.59092027
# T = 2140  Fidelity = 0.85141502
# T = 2150  Fidelity = 0.68627954
# T = 2160  Fidelity = 0.41291311
# T = 2170  Fidelity = 0.37438165
# T = 2180  Fidelity = 0.49482186
# T = 2190  Fidelity = 0.28350757
# T = 2200  Fidelity = 0.24426865
# T = 2300  Fidelity = 0.33154882
# T = 2400  Fidelity = 0.73896774
# T = 2500  Fidelity = 0.64883487
# T = 2600  Fidelity = 0.92693323
# T = 2700  Fidelity = 0.26193827
# T = 2800  Fidelity = 0.71547326
# T = 2900  Fidelity = 0.82661178
# T = 3000  Fidelity = 0.57767162
#
# FAILED POINT DIAGNOSTICS
# E1-E0  = 1.43163845e+00
# P0     = 0.57767162
# P1     = 0.12544195
# P0+P1  = 0.70311357
#
# Minimum T for Fidelity >= 0.97 : None
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.371
# ================================================================================
# Minimum path gap = 2.63012923e-01
# T = 1     Fidelity = 0.00000002
# T = 2     Fidelity = 0.00000119
# T = 5     Fidelity = 0.00017745
# T = 10    Fidelity = 0.01226536
# T = 20    Fidelity = 0.30995162
# T = 30    Fidelity = 0.40990914
# T = 40    Fidelity = 0.35264453
# T = 50    Fidelity = 0.74561200
# T = 75    Fidelity = 0.76577984
# T = 100   Fidelity = 0.80214071
# T = 125   Fidelity = 0.82724569
# T = 150   Fidelity = 0.90113086
# T = 175   Fidelity = 0.94142086
# T = 200   Fidelity = 0.95790395
# T = 225   Fidelity = 0.97016084
#
# Minimum T for Fidelity >= 0.97 : 225
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.410
# ================================================================================
# Minimum path gap = 2.63323856e-01
# T = 1     Fidelity = 0.00000021
# T = 2     Fidelity = 0.00000781
# T = 5     Fidelity = 0.00058504
# T = 10    Fidelity = 0.02330374
# T = 20    Fidelity = 0.36965677
# T = 30    Fidelity = 0.46839337
# T = 40    Fidelity = 0.48150672
# T = 50    Fidelity = 0.72868741
# T = 75    Fidelity = 0.79612098
# T = 100   Fidelity = 0.84637677
# T = 125   Fidelity = 0.89411922
# T = 150   Fidelity = 0.93625977
# T = 175   Fidelity = 0.96232403
# T = 200   Fidelity = 0.97758296
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.449
# ================================================================================
# Minimum path gap = 2.63442350e-01
# T = 1     Fidelity = 0.00000111
# T = 2     Fidelity = 0.00002770
# T = 5     Fidelity = 0.00127309
# T = 10    Fidelity = 0.03336952
# T = 20    Fidelity = 0.39286678
# T = 30    Fidelity = 0.52075201
# T = 40    Fidelity = 0.53349978
# T = 50    Fidelity = 0.73068933
# T = 75    Fidelity = 0.81009224
# T = 100   Fidelity = 0.86792711
# T = 125   Fidelity = 0.91735897
# T = 150   Fidelity = 0.95259705
# T = 175   Fidelity = 0.97291684
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.488
# ================================================================================
# Minimum path gap = 2.64216380e-01
# T = 1     Fidelity = 0.00000390
# T = 2     Fidelity = 0.00007211
# T = 5     Fidelity = 0.00225959
# T = 10    Fidelity = 0.04269777
# T = 20    Fidelity = 0.40385367
# T = 30    Fidelity = 0.56364864
# T = 40    Fidelity = 0.56036329
# T = 50    Fidelity = 0.72871594
# T = 75    Fidelity = 0.81057795
# T = 100   Fidelity = 0.87922580
# T = 125   Fidelity = 0.93231146
# T = 150   Fidelity = 0.96322521
# T = 175   Fidelity = 0.97701609
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.527
# ================================================================================
# Minimum path gap = 2.65046948e-01
# T = 1     Fidelity = 0.00001116
# T = 2     Fidelity = 0.00015990
# T = 5     Fidelity = 0.00363151
# T = 10    Fidelity = 0.05216163
# T = 20    Fidelity = 0.41069114
# T = 30    Fidelity = 0.59824694
# T = 40    Fidelity = 0.58540369
# T = 50    Fidelity = 0.72327339
# T = 75    Fidelity = 0.81467225
# T = 100   Fidelity = 0.89515993
# T = 125   Fidelity = 0.94516650
# T = 150   Fidelity = 0.96762791
# T = 175   Fidelity = 0.97778335
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.565
# ================================================================================
# Minimum path gap = 2.64615614e-01
# T = 1     Fidelity = 0.00002777
# T = 2     Fidelity = 0.00031927
# T = 5     Fidelity = 0.00548846
# T = 10    Fidelity = 0.06212697
# T = 20    Fidelity = 0.41514836
# T = 30    Fidelity = 0.62436087
# T = 40    Fidelity = 0.61530282
# T = 50    Fidelity = 0.71730014
# T = 75    Fidelity = 0.82760967
# T = 100   Fidelity = 0.91227616
# T = 125   Fidelity = 0.95071303
# T = 150   Fidelity = 0.96827839
# T = 175   Fidelity = 0.98034157
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.604
# ================================================================================
# Minimum path gap = 2.64825139e-01
# T = 1     Fidelity = 0.00006194
# T = 2     Fidelity = 0.00058737
# T = 5     Fidelity = 0.00791347
# T = 10    Fidelity = 0.07264328
# T = 20    Fidelity = 0.41819510
# T = 30    Fidelity = 0.64236156
# T = 40    Fidelity = 0.64787348
# T = 50    Fidelity = 0.71701177
# T = 75    Fidelity = 0.84670548
# T = 100   Fidelity = 0.92251238
# T = 125   Fidelity = 0.95163098
# T = 150   Fidelity = 0.97142369
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.643
# ================================================================================
# Minimum path gap = 2.65580824e-01
# T = 1     Fidelity = 0.00012603
# T = 2     Fidelity = 0.00100885
# T = 5     Fidelity = 0.01096766
# T = 10    Fidelity = 0.08363875
# T = 20    Fidelity = 0.42049844
# T = 30    Fidelity = 0.65363242
# T = 40    Fidelity = 0.67885744
# T = 50    Fidelity = 0.72465183
# T = 75    Fidelity = 0.86459578
# T = 100   Fidelity = 0.92597434
# T = 125   Fidelity = 0.95444739
# T = 150   Fidelity = 0.97618221
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.682
# ================================================================================
# Minimum path gap = 2.65071155e-01
# T = 1     Fidelity = 0.00023731
# T = 2     Fidelity = 0.00163483
# T = 5     Fidelity = 0.01469786
# T = 10    Fidelity = 0.09503787
# T = 20    Fidelity = 0.42248407
# T = 30    Fidelity = 0.65972586
# T = 40    Fidelity = 0.70539297
# T = 50    Fidelity = 0.73861072
# T = 75    Fidelity = 0.87694780
# T = 100   Fidelity = 0.92781881
# T = 125   Fidelity = 0.95976202
# T = 150   Fidelity = 0.97923641
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.720
# ================================================================================
# Minimum path gap = 2.64971771e-01
# T = 1     Fidelity = 0.00041861
# T = 2     Fidelity = 0.00252282
# T = 5     Fidelity = 0.01914808
# T = 10    Fidelity = 0.10681256
# T = 20    Fidelity = 0.42445694
# T = 30    Fidelity = 0.66194771
# T = 40    Fidelity = 0.72623448
# T = 50    Fidelity = 0.75589843
# T = 75    Fidelity = 0.88389898
# T = 100   Fidelity = 0.93133568
# T = 125   Fidelity = 0.96487219
# T = 150   Fidelity = 0.98091864
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.759
# ================================================================================
# Minimum path gap = 2.58678635e-01
# T = 1     Fidelity = 0.00069917
# T = 2     Fidelity = 0.00373751
# T = 5     Fidelity = 0.02436863
# T = 10    Fidelity = 0.11899122
# T = 20    Fidelity = 0.42669110
# T = 30    Fidelity = 0.66137147
# T = 40    Fidelity = 0.74121047
# T = 50    Fidelity = 0.77357430
# T = 75    Fidelity = 0.88792755
# T = 100   Fidelity = 0.93647518
# T = 125   Fidelity = 0.96843162
# T = 150   Fidelity = 0.98266097
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.798
# ================================================================================
# Minimum path gap = 2.50935075e-01
# T = 1     Fidelity = 0.00111551
# T = 2     Fidelity = 0.00535200
# T = 5     Fidelity = 0.03042131
# T = 10    Fidelity = 0.13164895
# T = 20    Fidelity = 0.42946158
# T = 30    Fidelity = 0.65893878
# T = 40    Fidelity = 0.75082025
# T = 50    Fidelity = 0.78936591
# T = 75    Fidelity = 0.89154585
# T = 100   Fidelity = 0.94194317
# T = 125   Fidelity = 0.97088952
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.837
# ================================================================================
# Minimum path gap = 2.43704173e-01
# T = 1     Fidelity = 0.00171239
# T = 2     Fidelity = 0.00744909
# T = 5     Fidelity = 0.03738162
# T = 10    Fidelity = 0.14489399
# T = 20    Fidelity = 0.43304211
# T = 30    Fidelity = 0.65550911
# T = 40    Fidelity = 0.75597138
# T = 50    Fidelity = 0.80191060
# T = 75    Fidelity = 0.89605628
# T = 100   Fidelity = 0.94698837
# T = 125   Fidelity = 0.97298555
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.876
# ================================================================================
# Minimum path gap = 2.36944606e-01
# T = 1     Fidelity = 0.00254385
# T = 2     Fidelity = 0.01012243
# T = 5     Fidelity = 0.04533928
# T = 10    Fidelity = 0.15885619
# T = 20    Fidelity = 0.43769298
# T = 30    Fidelity = 0.65186185
# T = 40    Fidelity = 0.75777354
# T = 50    Fidelity = 0.81074466
# T = 75    Fidelity = 0.90146383
# T = 100   Fidelity = 0.95159988
# T = 125   Fidelity = 0.97516041
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.914
# ================================================================================
# Minimum path gap = 2.30631967e-01
# T = 1     Fidelity = 0.00367410
# T = 2     Fidelity = 0.01347741
# T = 5     Fidelity = 0.05439763
# T = 10    Fidelity = 0.17367860
# T = 20    Fidelity = 0.44365027
# T = 30    Fidelity = 0.64868205
# T = 40    Fidelity = 0.75737424
# T = 50    Fidelity = 0.81611976
# T = 75    Fidelity = 0.90702116
# T = 100   Fidelity = 0.95595201
# T = 125   Fidelity = 0.97760413
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.953
# ================================================================================
# Minimum path gap = 2.24756925e-01
# T = 1     Fidelity = 0.00517835
# T = 2     Fidelity = 0.01763158
# T = 5     Fidelity = 0.06467215
# T = 10    Fidelity = 0.18951036
# T = 20    Fidelity = 0.45111866
# T = 30    Fidelity = 0.64654794
# T = 40    Fidelity = 0.75584469
# T = 50    Fidelity = 0.81874618
# T = 75    Fidelity = 0.91185078
# T = 100   Fidelity = 0.95997299
# T = 125   Fidelity = 0.98029033
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.992
# ================================================================================
# Minimum path gap = 2.19322771e-01
# T = 1     Fidelity = 0.00714325
# T = 2     Fidelity = 0.02271428
# T = 5     Fidelity = 0.07628751
# T = 10    Fidelity = 0.20649976
# T = 20    Fidelity = 0.46026618
# T = 30    Fidelity = 0.64592515
# T = 40    Fidelity = 0.75411442
# T = 50    Fidelity = 0.81954565
# T = 75    Fidelity = 0.91535497
# T = 100   Fidelity = 0.96334263
# T = 125   Fidelity = 0.98303767
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.031
# ================================================================================
# Minimum path gap = 2.14342798e-01
# T = 1     Fidelity = 0.00966667
# T = 2     Fidelity = 0.02886489
# T = 5     Fidelity = 0.08937269
# T = 10    Fidelity = 0.22478606
# T = 20    Fidelity = 0.47121933
# T = 30    Fidelity = 0.64716589
# T = 40    Fidelity = 0.75294305
# T = 50    Fidelity = 0.81945945
# T = 75    Fidelity = 0.91736497
# T = 100   Fidelity = 0.96569166
# T = 125   Fidelity = 0.98541657
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.069
# ================================================================================
# Minimum path gap = 2.09837646e-01
# T = 1     Fidelity = 0.01285659
# T = 2     Fidelity = 0.03622945
# T = 5     Fidelity = 0.10405391
# T = 10    Fidelity = 0.24448976
# T = 20    Fidelity = 0.48405741
# T = 30    Fidelity = 0.65051073
# T = 40    Fidelity = 0.75291489
# T = 50    Fidelity = 0.81932441
# T = 75    Fidelity = 0.91809596
# T = 100   Fidelity = 0.96681765
# T = 125   Fidelity = 0.98703541
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.108
# ================================================================================
# Minimum path gap = 2.05832643e-01
# T = 1     Fidelity = 0.01682864
# T = 2     Fidelity = 0.04495499
# T = 5     Fidelity = 0.12044507
# T = 10    Fidelity = 0.26570141
# T = 20    Fidelity = 0.49880622
# T = 30    Fidelity = 0.65609147
# T = 40    Fidelity = 0.75444494
# T = 50    Fidelity = 0.81980839
# T = 75    Fidelity = 0.91800027
# T = 100   Fidelity = 0.96676457
# T = 125   Fidelity = 0.98762243
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.147
# ================================================================================
# Minimum path gap = 2.02355174e-01
# T = 1     Fidelity = 0.02170197
# T = 2     Fidelity = 0.05518163
# T = 5     Fidelity = 0.13863629
# T = 10    Fidelity = 0.28846983
# T = 20    Fidelity = 0.51543188
# T = 30    Fidelity = 0.66393478
# T = 40    Fidelity = 0.75778939
# T = 50    Fidelity = 0.82138848
# T = 75    Fidelity = 0.91760681
# T = 100   Fidelity = 0.96579964
# T = 125   Fidelity = 0.98715921
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.186
# ================================================================================
# Minimum path gap = 1.99432132e-01
# T = 1     Fidelity = 0.02759347
# T = 2     Fidelity = 0.06703253
# T = 5     Fidelity = 0.15868132
# T = 10    Fidelity = 0.31279081
# T = 20    Fidelity = 0.53383607
# T = 30    Fidelity = 0.67396739
# T = 40    Fidelity = 0.76305798
# T = 50    Fidelity = 0.82435499
# T = 75    Fidelity = 0.91739799
# T = 100   Fidelity = 0.96434757
# T = 125   Fidelity = 0.98597216
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.224
# ================================================================================
# Minimum path gap = 1.97087558e-01
# T = 1     Fidelity = 0.03461047
# T = 2     Fidelity = 0.08060256
# T = 5     Fidelity = 0.18058523
# T = 10    Fidelity = 0.33859831
# T = 20    Fidelity = 0.55385432
# T = 30    Fidelity = 0.68602396
# T = 40    Fidelity = 0.77022796
# T = 50    Fidelity = 0.82882894
# T = 75    Fidelity = 0.91773815
# T = 100   Fidelity = 0.96285387
# T = 125   Fidelity = 0.98447861
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.263
# ================================================================================
# Minimum path gap = 1.95340561e-01
# T = 1     Fidelity = 0.04284242
# T = 2     Fidelity = 0.09594687
# T = 5     Fidelity = 0.20429435
# T = 10    Fidelity = 0.36575952
# T = 20    Fidelity = 0.57525877
# T = 30    Fidelity = 0.69985874
# T = 40    Fidelity = 0.77916109
# T = 50    Fidelity = 0.83478655
# T = 75    Fidelity = 0.91884770
# T = 100   Fidelity = 0.96167746
# T = 125   Fidelity = 0.98303156
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.302
# ================================================================================
# Minimum path gap = 1.94203669e-01
# T = 1     Fidelity = 0.05235263
# T = 2     Fidelity = 0.11307101
# T = 5     Fidelity = 0.22969024
# T = 10    Fidelity = 0.39407563
# T = 20    Fidelity = 0.59776624
# T = 30    Fidelity = 0.71516162
# T = 40    Fidelity = 0.78962464
# T = 50    Fidelity = 0.84208736
# T = 75    Fidelity = 0.92081163
# T = 100   Fidelity = 0.96105000
# T = 125   Fidelity = 0.98176221
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.341
# ================================================================================
# Minimum path gap = 1.93681684e-01
# T = 1     Fidelity = 0.06317113
# T = 2     Fidelity = 0.13192446
# T = 5     Fidelity = 0.25658934
# T = 10    Fidelity = 0.42328890
# T = 20    Fidelity = 0.62105171
# T = 30    Fidelity = 0.73157805
# T = 40    Fidelity = 0.80131667
# T = 50    Fidelity = 0.85050477
# T = 75    Fidelity = 0.92360947
# T = 100   Fidelity = 0.96108080
# T = 125   Fidelity = 0.98069370
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.380
# ================================================================================
# Minimum path gap = 1.93771116e-01
# T = 1     Fidelity = 0.07528991
# T = 2     Fidelity = 0.15239871
# T = 5     Fidelity = 0.28474898
# T = 10    Fidelity = 0.45309583
# T = 20    Fidelity = 0.64476609
# T = 30    Fidelity = 0.74873172
# T = 40    Fidelity = 0.81389419
# T = 50    Fidelity = 0.85975777
# T = 75    Fidelity = 0.92715062
# T = 100   Fidelity = 0.96180104
# T = 125   Fidelity = 0.97995909
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.418
# ================================================================================
# Minimum path gap = 1.94460196e-01
# T = 1     Fidelity = 0.08866125
# T = 2     Fidelity = 0.17433077
# T = 5     Fidelity = 0.31387936
# T = 10    Fidelity = 0.48316507
# T = 20    Fidelity = 0.66855634
# T = 30    Fidelity = 0.76624770
# T = 40    Fidelity = 0.82700196
# T = 50    Fidelity = 0.86954255
# T = 75    Fidelity = 0.93130565
# T = 100   Fidelity = 0.96317735
# T = 125   Fidelity = 0.97973959
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.457
# ================================================================================
# Minimum path gap = 1.95729417e-01
# T = 1     Fidelity = 0.10319969
# T = 2     Fidelity = 0.19751178
# T = 5     Fidelity = 0.34366010
# T = 10    Fidelity = 0.51315771
# T = 20    Fidelity = 0.69208548
# T = 30    Fidelity = 0.78377367
# T = 40    Fidelity = 0.84029876
# T = 50    Fidelity = 0.87956161
# T = 75    Fidelity = 0.93592942
# T = 100   Fidelity = 0.96510852
# T = 125   Fidelity = 0.98013614
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.496
# ================================================================================
# Minimum path gap = 1.97552503e-01
# T = 1     Fidelity = 0.11878723
# T = 2     Fidelity = 0.22169941
# T = 5     Fidelity = 0.37375907
# T = 10    Fidelity = 0.54274728
# T = 20    Fidelity = 0.71504990
# T = 30    Fidelity = 0.80099709
# T = 40    Fidelity = 0.85347860
# T = 50    Fidelity = 0.88954772
# T = 75    Fidelity = 0.94087294
# T = 100   Fidelity = 0.96745131
# T = 125   Fidelity = 0.98105354
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.535
# ================================================================================
# Minimum path gap = 1.99897671e-01
# T = 1     Fidelity = 0.13528093
# T = 2     Fidelity = 0.24663249
# T = 5     Fidelity = 0.40385088
# T = 10    Fidelity = 0.57163709
# T = 20    Fidelity = 0.73719229
# T = 30    Fidelity = 0.81765689
# T = 40    Fidelity = 0.86628502
# T = 50    Fidelity = 0.89928016
# T = 75    Fidelity = 0.94598495
# T = 100   Fidelity = 0.97003021
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.573
# ================================================================================
# Minimum path gap = 2.02729043e-01
# T = 1     Fidelity = 0.15252188
# T = 2     Fidelity = 0.27204568
# T = 5     Fidelity = 0.43363306
# T = 10    Fidelity = 0.59957308
# T = 20    Fidelity = 0.75830912
# T = 30    Fidelity = 0.83354910
# T = 40    Fidelity = 0.87851823
# T = 50    Fidelity = 0.90859226
# T = 75    Fidelity = 0.95111155
# T = 100   Fidelity = 0.97265524
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.612
# ================================================================================
# Minimum path gap = 2.06008070e-01
# T = 1     Fidelity = 0.17034425
# T = 2     Fidelity = 0.29768268
# T = 5     Fidelity = 0.46283821
# T = 10    Fidelity = 0.62635141
# T = 20    Fidelity = 0.77825277
# T = 30    Fidelity = 0.84852714
# T = 40    Fidelity = 0.89003575
# T = 50    Fidelity = 0.91737078
# T = 75    Fidelity = 0.95610064
# T = 100   Fidelity = 0.97519015
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.651
# ================================================================================
# Minimum path gap = 2.09694873e-01
# T = 1     Fidelity = 0.18858349
# T = 2     Fidelity = 0.32330672
# T = 5     Fidelity = 0.49124162
# T = 10    Fidelity = 0.65182099
# T = 20    Fidelity = 0.79692900
# T = 30    Fidelity = 0.86249764
# T = 40    Fidelity = 0.90074795
# T = 50    Fidelity = 0.92554925
# T = 75    Fidelity = 0.96081360
# T = 100   Fidelity = 0.97759070
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.690
# ================================================================================
# Minimum path gap = 2.13749401e-01
# T = 1     Fidelity = 0.20708305
# T = 2     Fidelity = 0.34870784
# T = 5     Fidelity = 0.51866446
# T = 10    Fidelity = 0.67588169
# T = 20    Fidelity = 0.81429131
# T = 30    Fidelity = 0.87541348
# T = 40    Fidelity = 0.91061052
# T = 50    Fidelity = 0.93309811
# T = 75    Fidelity = 0.96514254
# T = 100   Fidelity = 0.97987335
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.729
# ...
# Symmetric      0.255     2         0.9940096664      1.03008277e+00    None        None        None
# Symmetric      0.294     2         0.9941576051      1.03437790e+00    None        None        None
# Symmetric      0.333     2         0.9942992046      1.03860932e+00    None        None        None
# Symmetric      0.371     2         0.9944348338      1.04277975e+00    None        None        None
# Symmetric      0.410     2         0.9945648332      1.04689171e+00    None        None        None
# Symmetric      0.449     2         0.9946895174      1.05094753e+00    None        None        None
# Symmetric      0.488     1         0.9701165743      1.05494941e+00    None        None        None
# Symmetric      0.527     1         0.9705353794      1.05889937e+00    None        None        None
# Symmetric      0.565     1         0.9709434683      1.06279932e+00    None        None        None
# Symmetric      0.604     1         0.9713412850      1.06665106e+00    None        None        None
# Symmetric      0.643     1         0.9717292467      1.07045626e+00    None        None        None
# Symmetric      0.682     1         0.9721077462      1.07421650e+00    None        None        None
# Symmetric      0.720     1         0.9724771537      1.07793327e+00    None        None        None
# Symmetric      0.759     1         0.9728378186      1.08160799e+00    None        None        None
# Symmetric      0.798     1         0.9731900709      1.08524197e+00    None        None        None
# Symmetric      0.837     1         0.9735342229      1.08883649e+00    None        None        None
# Symmetric      0.876     1         0.9738705701      1.09239274e+00    None        None        None
# Symmetric      0.914     1         0.9741993928      1.09591184e+00    None        None        None
# Symmetric      0.953     1         0.9745209569      1.09939488e+00    None        None        None
# Symmetric      0.992     1         0.9748355148      1.10284288e+00    None        None        None
# Symmetric      1.031     1         0.9751433065      1.10625682e+00    None        None        None
# Symmetric      1.069     1         0.9754445604      1.10963763e+00    None        None        None
# Symmetric      1.108     1         0.9757394939      1.11298620e+00    None        None        None
# Symmetric      1.147     1         0.9760283141      1.11630337e+00    None        None        None
# Symmetric      1.186     1         0.9763112186      1.11958995e+00    None        None        None
# Symmetric      1.224     1         0.9765883960      1.12284673e+00    None        None        None
# Symmetric      1.263     1         0.9768600263      1.12607444e+00    None        None        None
# Symmetric      1.302     1         0.9771262818      1.12927379e+00    None        None        None
# Symmetric      1.341     1         0.9773873268      1.13244548e+00    None        None        None
# Symmetric      1.380     1         0.9776433191      1.13559015e+00    None        None        None
# Symmetric      1.418     1         0.9778944094      1.13870844e+00    None        None        None
# Symmetric      1.457     1         0.9781407422      1.14180095e+00    None        None        None
# Symmetric      1.496     1         0.9783824561      1.14486825e+00    None        None        None
# Symmetric      1.535     1         0.9786196840      1.14791092e+00    None        None        None
# Symmetric      1.573     1         0.9788525535      1.15092950e+00    None        None        None
# Symmetric      1.612     1         0.9790811870      1.15392449e+00    None        None        None
# Symmetric      1.651     1         0.9793057024      1.15689641e+00    None        None        None
# Symmetric      1.690     1         0.9795262126      1.15984573e+00    None        None        None
# Symmetric      1.729     1         0.9797428266      1.16277292e+00    None        None        None
# Symmetric      1.767     1         0.9799556490      1.16567844e+00    None        None        None
# Symmetric      1.806     1         0.9801647807      1.16856272e+00    None        None        None
# Symmetric      1.845     1         0.9803703187      1.17142618e+00    None        None        None
# Symmetric      1.884     1         0.9805723566      1.17426923e+00    None        None        None
# Symmetric      1.922     1         0.9807709845      1.17709225e+00    None        None        None
# Symmetric      1.961     1         0.9809662894      1.17989564e+00    None        None        None
# Symmetric      2.000     1         0.9811583551      1.18267976e+00    None        None        None
# Weak SSB optimised0.100     None      0.9309336746      2.43127858e-01    0.91728     0.009173    0.926453
# Weak SSB optimised0.139     None      0.9603964643      2.48511987e-01    0.647615    0.013238    0.660852
# Weak SSB optimised0.178     300       0.9834173588      2.52995565e-01    None        None        None
# Weak SSB optimised0.216     200       0.9729532814      2.57174959e-01    None        None        None
# Weak SSB optimised0.255     250       0.9868206163      2.59122113e-01    None        None        None
# Weak SSB optimised0.294     200       0.9814105440      2.59830215e-01    None        None        None
# Weak SSB optimised0.333     None      0.9604832524      2.61148987e-01    0.577672    0.125442    0.703114
# Weak SSB optimised0.371     225       0.9701608449      2.63012923e-01    None        None        None
# Weak SSB optimised0.410     200       0.9775829607      2.63323856e-01    None        None        None
# Weak SSB optimised0.449     175       0.9729168355      2.63442350e-01    None        None        None
# Weak SSB optimised0.488     175       0.9770160945      2.64216380e-01    None        None        None
# Weak SSB optimised0.527     175       0.9777833472      2.65046948e-01    None        None        None
# Weak SSB optimised0.565     175       0.9803415665      2.64615614e-01    None        None        None
# Weak SSB optimised0.604     150       0.9714236875      2.64825139e-01    None        None        None
# Weak SSB optimised0.643     150       0.9761822143      2.65580824e-01    None        None        None
# Weak SSB optimised0.682     150       0.9792364050      2.65071155e-01    None        None        None
# Weak SSB optimised0.720     150       0.9809186443      2.64971771e-01    None        None        None
# Weak SSB optimised0.759     150       0.9826609681      2.58678635e-01    None        None        None
# Weak SSB optimised0.798     125       0.9708895220      2.50935075e-01    None        None        None
# Weak SSB optimised0.837     125       0.9729855457      2.43704173e-01    None        None        None
# Weak SSB optimised0.876     125       0.9751604066      2.36944606e-01    None        None        None
# Weak SSB optimised0.914     125       0.9776041346      2.30631967e-01    None        None        None
# Weak SSB optimised0.953     125       0.9802903318      2.24756925e-01    None        None        None
# Weak SSB optimised0.992     125       0.9830376708      2.19322771e-01    None        None        None
# Weak SSB optimised1.031     125       0.9854165712      2.14342798e-01    None        None        None
# Weak SSB optimised1.069     125       0.9870354074      2.09837646e-01    None        None        None
# Weak SSB optimised1.108     125       0.9876224332      2.05832643e-01    None        None        None
# Weak SSB optimised1.147     125       0.9871592052      2.02355174e-01    None        None        None
# Weak SSB optimised1.186     125       0.9859721577      1.99432132e-01    None        None        None
# Weak SSB optimised1.224     125       0.9844786087      1.97087558e-01    None        None        None
# Weak SSB optimised1.263     125       0.9830315645      1.95340561e-01    None        None        None
# Weak SSB optimised1.302     125       0.9817622052      1.94203669e-01    None        None        None
# Weak SSB optimised1.341     125       0.9806936954      1.93681684e-01    None        None        None
# Weak SSB optimised1.380     125       0.9799590930      1.93771116e-01    None        None        None
# Weak SSB optimised1.418     125       0.9797395889      1.94460196e-01    None        None        None
# Weak SSB optimised1.457     125       0.9801361443      1.95729417e-01    None        None        None
# Weak SSB optimised1.496     125       0.9810535401      1.97552503e-01    None        None        None
# Weak SSB optimised1.535     100       0.9700302128      1.99897671e-01    None        None        None
# Weak SSB optimised1.573     100       0.9726552361      2.02729043e-01    None        None        None
# Weak SSB optimised1.612     100       0.9751901479      2.06008070e-01    None        None        None
# Weak SSB optimised1.651     100       0.9775906953      2.09694873e-01    None        None        None
# Weak SSB optimised1.690     100       0.9798733541      2.13749401e-01    None        None        None
# Weak SSB optimised1.729     100       0.9820659389      2.18132396e-01    None        None        None
# Weak SSB optimised1.767     75        0.9724575176      2.22806129e-01    None        None        None
# Weak SSB optimised1.806     75        0.9754726714      2.27734927e-01    None        None        None
# Weak SSB optimised1.845     75        0.9781351815      2.32885520e-01    None        None        None
# Weak SSB optimised1.884     75        0.9805133972      2.38227223e-01    None        None        None
# Weak SSB optimised1.922     75        0.9826636267      2.43732008e-01    None        None        None
# Weak SSB optimised1.961     75        0.9846199126      2.49374469e-01    None        None        None
# Weak SSB optimised2.000     50        0.9727074474      2.55131735e-01    None        None        None
# Strong SSB     0.100     75        0.9942800802      6.06623659e-01    None        None        None
# Strong SSB     0.139     50        0.9947944700      6.38355456e-01    None        None        None
# Strong SSB     0.178     40        0.9964718093      6.62911464e-01    None        None        None
# Strong SSB     0.216     30        0.9894626644      6.82968063e-01    None        None        None
# Strong SSB     0.255     40        0.9744669548      6.99931517e-01    None        None        None
# Strong SSB     0.294     40        0.9899533937      7.14643687e-01    None        None        None
# Strong SSB     0.333     40        0.9871426239      7.27648613e-01    None        None        None
# Strong SSB     0.371     50        0.9840421676      7.39317686e-01    None        None        None
# Strong SSB     0.410     50        0.9764786110      7.49915500e-01    None        None        None
# Strong SSB     0.449     30        0.9803426053      7.59637099e-01    None        None        None
# Strong SSB     0.488     30        0.9900609805      7.68630284e-01    None        None        None
# Strong SSB     0.527     30        0.9925253728      7.77009619e-01    None        None        None
# Strong SSB     0.565     30        0.9923519426      7.84610988e-01    None        None        None
# Strong SSB     0.604     30        0.9916433866      7.91735116e-01    None        None        None
# Strong SSB     0.643     30        0.9911001784      7.98478448e-01    None        None        None
# Strong SSB     0.682     30        0.9908278511      8.04889490e-01    None        None        None
# Strong SSB     0.720     30        0.9907340109      8.11008462e-01    None        None        None
# Strong SSB     0.759     30        0.9907105912      8.16593697e-01    None        None        None
# Strong SSB     0.798     30        0.9906917500      8.21942410e-01    None        None        None
# Strong SSB     0.837     30        0.9906536549      8.27098074e-01    None        None        None
# Strong SSB     0.876     30        0.9905978665      8.32080713e-01    None        None        None
# Strong SSB     0.914     30        0.9905362681      8.36730976e-01    None        None        None
# Strong SSB     0.953     20        0.9710050504      8.41138524e-01    None        None        None
# Strong SSB     0.992     20        0.9732184131      8.45430604e-01    None        None        None
# Strong SSB     1.031     20        0.9751553212      8.49617771e-01    None        None        None
# Strong SSB     1.069     20        0.9768536965      8.53540636e-01    None        None        None
# Strong SSB     1.108     20        0.9783419275      8.57275807e-01    None        None        None
# Strong SSB     1.147     20        0.9796423824      8.60942268e-01    None        None        None
# Strong SSB     1.186     20        0.9807737852      8.64545674e-01    None        None        None
# Strong SSB     1.224     20        0.9817526705      8.67875517e-01    None        None        None
# Strong SSB     1.263     20        0.9825941838      8.71110397e-01    None        None        None
# Strong SSB     1.302     20        0.9833124643      8.74306350e-01    None        None        None
# Strong SSB     1.341     20        0.9839207894      8.77423666e-01    None        None        None
# Strong SSB     1.380     20        0.9844315996      8.80295617e-01    None        None        None
# Strong SSB     1.418     20        0.9848564787      8.83146838e-01    None        None        None
# Strong SSB     1.457     20        0.9852061288      8.85978866e-01    None        None        None
# Strong SSB     1.496     20        0.9854903605      8.88632113e-01    None        None        None
# Strong SSB     1.535     20        0.9857181016      8.91188472e-01    None        None        None
# Strong SSB     1.573     20        0.9858974272      8.93738619e-01    None        None        None
# Strong SSB     1.612     20        0.9860356025      8.96225647e-01    None        None        None
# Strong SSB     1.651     20        0.9861391374      8.98527544e-01    None        None        None
# Strong SSB     1.690     20        0.9862138462      9.00833371e-01    None        None        None
# Strong SSB     1.729     20        0.9862649092      9.03142980e-01    None        None        None
# Strong SSB     1.767     20        0.9862969321      9.05241576e-01    None        None        None
# Strong SSB     1.806     20        0.9863140038      9.07334203e-01    None        None        None
# Strong SSB     1.845     20        0.9863197486      9.09438168e-01    None        None        None
# Strong SSB     1.884     20        0.9863173745      9.11393738e-01    None        None        None
# Strong SSB     1.922     20        0.9863097162      9.13299299e-01    None        None        None
# Strong SSB     1.961     20        0.9862992726      9.15222225e-01    None        None        None
# Strong SSB     2.000     20        0.9862882406      9.17036009e-01    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],
        
        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=2$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.1000
# Weak SSB opt    λc = 0.1000
# Strong SSB      λc = 0.1000

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap,  $m_{0}^{2}=2.0$')
plt.legend()

plt.tight_layout() 
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_exact = match['psi_exact']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )
    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-1

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_exact = data['psi_exact']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-1.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 2.15534848e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009561
# T = 10    Fidelity = 0.00119308
# T = 20    Fidelity = 0.02687515
# T = 30    Fidelity = 0.09667486
# T = 40    Fidelity = 0.19609881
# T = 50    Fidelity = 0.31173180
# T = 75    Fidelity = 0.56619425
# T = 100   Fidelity = 0.72002097
# T = 125   Fidelity = 0.80739193
# T = 150   Fidelity = 0.86470591
# T = 175   Fidelity = 0.90864875
# T = 200   Fidelity = 0.94630112
# T = 225   Fidelity = 0.96686865
# T = 250   Fidelity = 0.95352375
# T = 275   Fidelity = 0.98204188
#
# Minimum T for Fidelity >= 0.97 : 275
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.139
# ================================================================================
# Minimum path gap = 7.94270125e-05
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00019672
# T = 10    Fidelity = 0.00330118
# T = 20    Fidelity = 0.06852371
# T = 30    Fidelity = 0.22802123
# T = 40    Fidelity = 0.41000348
# T = 50    Fidelity = 0.55833197
# T = 75    Fidelity = 0.75045045
# T = 100   Fidelity = 0.83200704
# T = 125   Fidelity = 0.88689259
# T = 150   Fidelity = 0.92854920
# T = 175   Fidelity = 0.96122740
# T = 200   Fidelity = 0.96155812
# T = 225   Fidelity = 0.99264881
#
# Minimum T for Fidelity >= 0.97 : 225
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.178
# ================================================================================
# Minimum path gap = 3.10891251e-05
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00033244
# T = 10    Fidelity = 0.01074354
# T = 20    Fidelity = 0.17276737
# T = 30    Fidelity = 0.43609787
# T = 40    Fidelity = 0.61085348
# T = 50    Fidelity = 0.68288713
# T = 75    Fidelity = 0.80038519
# T = 100   Fidelity = 0.89855246
# T = 125   Fidelity = 0.94155399
# T = 150   Fidelity = 0.96417036
# T = 175   Fidelity = 0.97994587
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.216
# ================================================================================
# Minimum path gap = 1.06147811e-05
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00048511
# T = 10    Fidelity = 0.02912458
# T = 20    Fidelity = 0.30807435
# T = 30    Fidelity = 0.57941558
# T = 40    Fidelity = 0.65416829
# T = 50    Fidelity = 0.70990160
# T = 75    Fidelity = 0.87510619
# T = 100   Fidelity = 0.93250966
# T = 125   Fidelity = 0.96718054
# T = 150   Fidelity = 0.98507254
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.255
# ================================================================================
# Minimum path gap = 3.98493198e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000004
# T = 5     Fidelity = 0.00068279
# T = 10    Fidelity = 0.05673382
# T = 20    Fidelity = 0.46236058
# T = 30    Fidelity = 0.61356867
# T = 40    Fidelity = 0.65299783
# T = 50    Fidelity = 0.79576013
# T = 75    Fidelity = 0.91783776
# T = 100   Fidelity = 0.95621427
# T = 125   Fidelity = 0.98532986
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.294
# ================================================================================
# Minimum path gap = 1.64715494e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000019
# T = 5     Fidelity = 0.00108541
# T = 10    Fidelity = 0.08717121
# T = 20    Fidelity = 0.53195352
# T = 30    Fidelity = 0.60624135
# T = 40    Fidelity = 0.74455286
# T = 50    Fidelity = 0.87417057
# T = 75    Fidelity = 0.92681481
# T = 100   Fidelity = 0.97750841
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.333
# ================================================================================
# Minimum path gap = 7.68096692e-07
# T = 1     Fidelity = 0.00000003
# T = 2     Fidelity = 0.00000135
# T = 5     Fidelity = 0.00222033
# T = 10    Fidelity = 0.12351699
# T = 20    Fidelity = 0.52115387
# T = 30    Fidelity = 0.70031285
# T = 40    Fidelity = 0.76663748
# T = 50    Fidelity = 0.89965356
# T = 75    Fidelity = 0.96221149
# T = 100   Fidelity = 0.97188515
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.371
# ================================================================================
# Minimum path gap = 4.14141285e-07
# T = 1     Fidelity = 0.00000034
# T = 2     Fidelity = 0.00000862
# T = 5     Fidelity = 0.00506832
# T = 10    Fidelity = 0.16966168
# T = 20    Fidelity = 0.54332334
# T = 30    Fidelity = 0.77612688
# T = 40    Fidelity = 0.78936034
# T = 50    Fidelity = 0.93123071
# T = 75    Fidelity = 0.97700123
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.410
# ================================================================================
# Minimum path gap = 3.18425170e-07
# T = 1     Fidelity = 0.00000198
# T = 2     Fidelity = 0.00003484
# T = 5     Fidelity = 0.00949921
# T = 10    Fidelity = 0.21007528
# T = 20    Fidelity = 0.60926869
# T = 30    Fidelity = 0.79383227
# T = 40    Fidelity = 0.84515915
# T = 50    Fidelity = 0.93904656
# T = 75    Fidelity = 0.98726818
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.449
# ================================================================================
# Minimum path gap = 3.07336185e-07
# T = 1     Fidelity = 0.00000742
# T = 2     Fidelity = 0.00009817
# T = 5     Fidelity = 0.01471999
# T = 10    Fidelity = 0.23952791
# T = 20    Fidelity = 0.67686882
# T = 30    Fidelity = 0.79725745
# T = 40    Fidelity = 0.89239030
# T = 50    Fidelity = 0.93682719
# T = 75    Fidelity = 0.99484306
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.488
# ================================================================================
# Minimum path gap = 3.30563732e-07
# T = 1     Fidelity = 0.00002189
# T = 2     Fidelity = 0.00022820
# T = 5     Fidelity = 0.02083686
# T = 10    Fidelity = 0.26393027
# T = 20    Fidelity = 0.73537694
# T = 30    Fidelity = 0.80060702
# T = 40    Fidelity = 0.92855066
# T = 50    Fidelity = 0.93479208
# T = 75    Fidelity = 0.99479133
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.527
# ================================================================================
# Minimum path gap = 3.38998847e-07
# T = 1     Fidelity = 0.00005534
# T = 2     Fidelity = 0.00047058
# T = 5     Fidelity = 0.02811361
# T = 10    Fidelity = 0.28649522
# T = 20    Fidelity = 0.78367464
# T = 30    Fidelity = 0.80621734
# T = 40    Fidelity = 0.95344256
# T = 50    Fidelity = 0.93763215
# T = 75    Fidelity = 0.99104243
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.565
# ================================================================================
# Minimum path gap = 3.58206671e-07
# T = 1     Fidelity = 0.00012407
# T = 2     Fidelity = 0.00088466
# T = 5     Fidelity = 0.03660944
# T = 10    Fidelity = 0.30798980
# T = 20    Fidelity = 0.82213863
# T = 30    Fidelity = 0.81561936
# T = 40    Fidelity = 0.96860194
# T = 50    Fidelity = 0.94618843
# T = 75    Fidelity = 0.98889933
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.604
# ================================================================================
# Minimum path gap = 7.16692413e-07
# T = 1     Fidelity = 0.00025158
# T = 2     Fidelity = 0.00153831
# T = 5     Fidelity = 0.04622751
# T = 10    Fidelity = 0.32835930
# T = 20    Fidelity = 0.85214862
# T = 30    Fidelity = 0.82939815
# T = 40    Fidelity = 0.97632347
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.643
# ================================================================================
# Minimum path gap = 1.89799446e-06
# T = 1     Fidelity = 0.00046869
# T = 2     Fidelity = 0.00250394
# T = 5     Fidelity = 0.05682740
# T = 10    Fidelity = 0.34749970
# T = 20    Fidelity = 0.87524704
# T = 30    Fidelity = 0.84682377
# T = 40    Fidelity = 0.97852018
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.682
# ================================================================================
# Minimum path gap = 4.77657226e-06
# T = 1     Fidelity = 0.00081351
# T = 2     Fidelity = 0.00385657
# T = 5     Fidelity = 0.06829322
# T = 10    Fidelity = 0.36545760
# T = 20    Fidelity = 0.89269445
# T = 30    Fidelity = 0.86658061
# T = 40    Fidelity = 0.97698335
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.720
# ================================================================================
# Minimum path gap = 1.09339613e-05
# T = 1     Fidelity = 0.00133116
# T = 2     Fidelity = 0.00567289
# T = 5     Fidelity = 0.08054697
# T = 10    Fidelity = 0.38238636
# T = 20    Fidelity = 0.90546954
# T = 30    Fidelity = 0.88731271
# T = 40    Fidelity = 0.97351219
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.759
# ================================================================================
# Minimum path gap = 2.29616480e-05
# T = 1     Fidelity = 0.00207321
# T = 2     Fidelity = 0.00802966
# T = 5     Fidelity = 0.09353601
# T = 10    Fidelity = 0.39846685
# T = 20    Fidelity = 0.91437567
# T = 30    Fidelity = 0.90781360
# T = 40    Fidelity = 0.96975203
# T = 50    Fidelity = 0.99593600
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.798
# ================================================================================
# Minimum path gap = 4.47766784e-05
# T = 1     Fidelity = 0.00309655
# T = 2     Fidelity = 0.01100161
# T = 5     Fidelity = 0.10721840
# T = 10    Fidelity = 0.41386222
# T = 20    Fidelity = 0.92010433
# T = 30    Fidelity = 0.92710510
# T = 40    Fidelity = 0.96696507
# T = 50    Fidelity = 0.99893608
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.837
# ================================================================================
# Minimum path gap = 8.19228137e-05
# T = 1     Fidelity = 0.00446198
# T = 2     Fidelity = 0.01465926
# T = 5     Fidelity = 0.12155487
# T = 10    Fidelity = 0.42870564
# T = 20    Fidelity = 0.92325593
# T = 30    Fidelity = 0.94447909
# T = 40    Fidelity = 0.96589094
# T = 50    Fidelity = 0.99938030
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.876
# ================================================================================
# Minimum path gap = 1.41818058e-04
# T = 1     Fidelity = 0.00623264
# T = 2     Fidelity = 0.01906715
# T = 5     Fidelity = 0.13650667
# T = 10    Fidelity = 0.44310442
# T = 20    Fidelity = 0.92434754
# T = 30    Fidelity = 0.95949284
# T = 40    Fidelity = 0.96675422
# T = 50    Fidelity = 0.99800432
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.914
# ================================================================================
# Minimum path gap = 2.33916520e-04
# T = 1     Fidelity = 0.00847251
# T = 2     Fidelity = 0.02428288
# T = 5     Fidelity = 0.15203662
# T = 10    Fidelity = 0.45714847
# T = 20    Fidelity = 0.92382254
# T = 30    Fidelity = 0.97192669
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.953
# ================================================================================
# Minimum path gap = 3.69765765e-04
# T = 1     Fidelity = 0.01124510
# T = 2     Fidelity = 0.03035669
# T = 5     Fidelity = 0.16811086
# T = 10    Fidelity = 0.47091730
# T = 20    Fidelity = 0.92206342
# T = 30    Fidelity = 0.98173041
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.992
# ================================================================================
# Minimum path gap = 5.62953624e-04
# T = 1     Fidelity = 0.01461237
# T = 2     Fidelity = 0.03733151
# T = 5     Fidelity = 0.18470002
# T = 10    Fidelity = 0.48448417
# T = 20    Fidelity = 0.91940472
# T = 30    Fidelity = 0.98897829
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.031
# ================================================================================
# Minimum path gap = 8.28948604e-04
# T = 1     Fidelity = 0.01863375
# T = 2     Fidelity = 0.04524321
# T = 5     Fidelity = 0.20177947
# T = 10    Fidelity = 0.49791762
# T = 20    Fidelity = 0.91614317
# T = 30    Fidelity = 0.99383903
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.069
# ================================================================================
# Minimum path gap = 1.18484510e-03
# T = 1     Fidelity = 0.02336541
# T = 2     Fidelity = 0.05412076
# T = 5     Fidelity = 0.21932859
# T = 10    Fidelity = 0.51128134
# T = 20    Fidelity = 0.91254408
# T = 30    Fidelity = 0.99655654
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.108
# ================================================================================
# Minimum path gap = 1.64902892e-03
# T = 1     Fidelity = 0.02885942
# T = 2     Fidelity = 0.06398634
# T = 5     Fidelity = 0.23732947
# T = 10    Fidelity = 0.52463309
# T = 20    Fidelity = 0.90884436
# T = 30    Fidelity = 0.99743421
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.147
# ================================================================================
# Minimum path gap = 2.24078104e-03
# T = 1     Fidelity = 0.03516300
# T = 2     Fidelity = 0.07485516
# T = 5     Fidelity = 0.25576525
# T = 10    Fidelity = 0.53802344
# T = 20    Fidelity = 0.90525316
# T = 30    Fidelity = 0.99681716
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.186
# ================================================================================
# Minimum path gap = 2.97983845e-03
# T = 1     Fidelity = 0.04231763
# T = 2     Fidelity = 0.08673515
# T = 5     Fidelity = 0.27461837
# T = 10    Fidelity = 0.55149452
# T = 20    Fidelity = 0.90195118
# T = 30    Fidelity = 0.99507092
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.224
# ================================================================================
# Minimum path gap = 3.88593119e-03
# T = 1     Fidelity = 0.05035822
# T = 2     Fidelity = 0.09962646
# T = 5     Fidelity = 0.29386896
# T = 10    Fidelity = 0.56507901
# T = 20    Fidelity = 0.89908945
# T = 30    Fidelity = 0.99255760
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.263
# ================================================================================
# Minimum path gap = 4.97831388e-03
# T = 1     Fidelity = 0.05931212
# T = 2     Fidelity = 0.11352085
# T = 5     Fidelity = 0.31349335
# T = 10    Fidelity = 0.57879944
# T = 20    Fidelity = 0.89678830
# T = 30    Fidelity = 0.98961306
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.302
# ================================================================================
# Minimum path gap = 6.27530923e-03
# T = 1     Fidelity = 0.06919822
# T = 2     Fidelity = 0.12840110
# T = 5     Fidelity = 0.33346294
# T = 10    Fidelity = 0.59266782
# T = 20    Fidelity = 0.89513679
# T = 30    Fidelity = 0.98652790
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.341
# ================================================================================
# Minimum path gap = 7.79387932e-03
# T = 1     Fidelity = 0.08002603
# T = 2     Fidelity = 0.14424039
# T = 5     Fidelity = 0.35374327
# T = 10    Fidelity = 0.60668561
# T = 20    Fidelity = 0.89419292
# T = 30    Fidelity = 0.98353468
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.380
# ================================================================================
# Minimum path gap = 9.54923850e-03
# T = 1     Fidelity = 0.09179489
# T = 2     Fidelity = 0.16100189
# T = 5     Fidelity = 0.37429353
# T = 10    Fidelity = 0.62084389
# T = 20    Fidelity = 0.89398467
# T = 30    Fidelity = 0.98080205
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.418
# ================================================================================
# Minimum path gap = 1.15545198e-02
# T = 1     Fidelity = 0.10449333
# T = 2     Fidelity = 0.17863849
# T = 5     Fidelity = 0.39506637
# T = 10    Fidelity = 0.63512398
# T = 20    Fidelity = 0.89451198
# T = 30    Fidelity = 0.97843574
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.457
# ================================================================================
# Minimum path gap = 1.38205043e-02
# T = 1     Fidelity = 0.11809863
# T = 2     Fidelity = 0.19709277
# T = 5     Fidelity = 0.41600800
# T = 10    Fidelity = 0.64949815
# T = 20    Fidelity = 0.89574948
# T = 30    Fidelity = 0.97648513
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.496
# ================================================================================
# Minimum path gap = 1.63554198e-02
# T = 1     Fidelity = 0.13257666
# T = 2     Fidelity = 0.21629737
# T = 5     Fidelity = 0.43705876
# T = 10    Fidelity = 0.66393074
# T = 20    Fidelity = 0.89765010
# T = 30    Fidelity = 0.97495388
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.535
# ================================================================================
# Minimum path gap = 1.91648137e-02
# T = 1     Fidelity = 0.14788207
# T = 2     Fidelity = 0.23617552
# T = 5     Fidelity = 0.45815387
# T = 10    Fidelity = 0.67837936
# T = 20    Fidelity = 0.90014906
# T = 30    Fidelity = 0.97381283
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.573
# ================================================================================
# Minimum path gap = 2.22515003e-02
# T = 1     Fidelity = 0.16395879
# T = 2     Fidelity = 0.25664214
# T = 5     Fidelity = 0.47922458
# T = 10    Fidelity = 0.69279632
# T = 20    Fidelity = 0.90316837
# T = 30    Fidelity = 0.97301326
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.612
# ================================================================================
# Minimum path gap = 2.56155815e-02
# T = 1     Fidelity = 0.18074084
# T = 2     Fidelity = 0.27760503
# T = 5     Fidelity = 0.50019943
# T = 10    Fidelity = 0.70713025
# T = 20    Fidelity = 0.90662134
# T = 30    Fidelity = 0.97249896
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.651
# ================================================================================
# Minimum path gap = 2.92545358e-02
# T = 1     Fidelity = 0.19815361
# T = 2     Fidelity = 0.29896654
# T = 5     Fidelity = 0.52100580
# T = 10    Fidelity = 0.72132765
# T = 20    Fidelity = 0.91041699
# T = 30    Fidelity = 0.97221579
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.690
# ================================================================================
# Minimum path gap = 3.31633696e-02
# T = 1     Fidelity = 0.21611524
# T = 2     Fidelity = 0.32062533
# T = 5     Fidelity = 0.54157142
# T = 10    Fidelity = 0.73533451
# T = 20    Fidelity = 0.91446412
# T = 30    Fidelity = 0.97211826
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.729
# ================================================================================
# Minimum path gap = 3.73348200e-02
# T = 1     Fidelity = 0.23453842
# T = 2     Fidelity = 0.34247833
# T = 5     Fidelity = 0.56182599
# T = 10    Fidelity = 0.74909790
# T = 20    Fidelity = 0.91867488
# T = 30    Fidelity = 0.97217271
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.767
# ================================================================================
# Minimum path gap = 4.17596003e-02
# T = 1     Fidelity = 0.25333219
# T = 2     Fidelity = 0.36442274
# T = 5     Fidelity = 0.58170262
# T = 10    Fidelity = 0.76256735
# T = 20    Fidelity = 0.92296763
# T = 30    Fidelity = 0.97235785
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.806
# ================================================================================
# Minimum path gap = 4.64266745e-02
# T = 1     Fidelity = 0.27240388
# T = 2     Fidelity = 0.38635798
# T = 5     Fidelity = 0.60113924
# T = 10    Fidelity = 0.77569610
# T = 20    Fidelity = 0.92726921
# T = 30    Fidelity = 0.97266302
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.845
# ================================================================================
# Minimum path gap = 5.13235508e-02
# T = 1     Fidelity = 0.29166105
# T = 2     Fidelity = 0.40818750
# T = 5     Fidelity = 0.62007967
# T = 10    Fidelity = 0.78844208
# T = 20    Fidelity = 0.93151638
# T = 30    Fidelity = 0.97308530
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.884
# ================================================================================
# Minimum path gap = 5.64365810e-02
# T = 1     Fidelity = 0.31101323
# T = 2     Fidelity = 0.42982040
# T = 5     Fidelity = 0.63847457
# T = 10    Fidelity = 0.80076871
# T = 20    Fidelity = 0.93565659
# T = 30    Fidelity = 0.97362591
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.922
# ================================================================================
# Minimum path gap = 6.17512559e-02
# T = 1     Fidelity = 0.33037358
# T = 2     Fidelity = 0.45117276
# T = 5     Fidelity = 0.65628202
# T = 10    Fidelity = 0.81264535
# T = 20    Fidelity = 0.93964823
# T = 30    Fidelity = 0.97428688
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.961
# ================================================================================
# Minimum path gap = 6.72524885e-02
# T = 1     Fidelity = 0.34966025
# T = 2     Fidelity = 0.47216870
# T = 5     Fidelity = 0.67346788
# T = 10    Fidelity = 0.82404761
# T = 20    Fidelity = 0.94346025
# T = 30    Fidelity = 0.97506821
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 7.29248761e-02
# T = 1     Fidelity = 0.36879749
# T = 2     Fidelity = 0.49274105
# T = 5     Fidelity = 0.69000583
# T = 10    Fidelity = 0.83495730
# T = 20    Fidelity = 0.94707142
# T = 30    Fidelity = 0.97596588
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.65519637e-01
# T = 1     Fidelity = 0.62317299
# T = 2     Fidelity = 0.65190417
# T = 5     Fidelity = 0.70826408
# T = 10    Fidelity = 0.76280613
# T = 20    Fidelity = 0.82917568
# T = 30    Fidelity = 0.86980822
# T = 40    Fidelity = 0.89813622
# T = 50    Fidelity = 0.91830270
# T = 75    Fidelity = 0.94946642
# T = 100   Fidelity = 0.96622193
# T = 125   Fidelity = 0.97485820
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.139
# ================================================================================
# Minimum path gap = 8.39578713e-01
# T = 1     Fidelity = 0.62884329
# T = 2     Fidelity = 0.65582992
# T = 5     Fidelity = 0.71109831
# T = 10    Fidelity = 0.76305072
# T = 20    Fidelity = 0.82721472
# T = 30    Fidelity = 0.86652110
# T = 40    Fidelity = 0.89421879
# T = 50    Fidelity = 0.91422968
# T = 75    Fidelity = 0.94571087
# T = 100   Fidelity = 0.96310053
# T = 125   Fidelity = 0.97082588
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.178
# ================================================================================
# Minimum path gap = 8.06866518e-01
# T = 1     Fidelity = 0.63732065
# T = 2     Fidelity = 0.66141678
# T = 5     Fidelity = 0.71465538
# T = 10    Fidelity = 0.76454006
# T = 20    Fidelity = 0.82523112
# T = 30    Fidelity = 0.86275422
# T = 40    Fidelity = 0.88939635
# T = 50    Fidelity = 0.90892300
# T = 75    Fidelity = 0.94042434
# T = 100   Fidelity = 0.95799144
# T = 125   Fidelity = 0.96843382
# T = 150   Fidelity = 0.97305384
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.216
# ================================================================================
# Minimum path gap = 7.48494613e-01
# T = 1     Fidelity = 0.65094160
# T = 2     Fidelity = 0.67087524
# T = 5     Fidelity = 0.72054766
# T = 10    Fidelity = 0.76809869
# T = 20    Fidelity = 0.82384896
# T = 30    Fidelity = 0.85909784
# T = 40    Fidelity = 0.88423158
# T = 50    Fidelity = 0.90280093
# T = 75    Fidelity = 0.93399924
# T = 100   Fidelity = 0.95137923
# T = 125   Fidelity = 0.96371635
# T = 150   Fidelity = 0.97027741
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.255
# ================================================================================
# Minimum path gap = 6.68809100e-01
# T = 1     Fidelity = 0.67476215
# T = 2     Fidelity = 0.68962523
# T = 5     Fidelity = 0.73572579
# T = 10    Fidelity = 0.77568794
# T = 20    Fidelity = 0.82608029
# T = 30    Fidelity = 0.85753064
# T = 40    Fidelity = 0.88025251
# T = 50    Fidelity = 0.89751711
# T = 75    Fidelity = 0.92656896
# T = 100   Fidelity = 0.94461230
# T = 125   Fidelity = 0.95573582
# T = 150   Fidelity = 0.96430076
# T = 175   Fidelity = 0.96950448
# T = 200   Fidelity = 0.96913327
# T = 225   Fidelity = 0.97560638
#
# Minimum T for Fidelity >= 0.97 : 225
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.294
# ================================================================================
# Minimum path gap = 5.68446052e-01
# T = 1     Fidelity = 0.71997687
# T = 2     Fidelity = 0.73059948
# T = 5     Fidelity = 0.76781870
# T = 10    Fidelity = 0.80150538
# T = 20    Fidelity = 0.84058668
# T = 30    Fidelity = 0.86639273
# T = 40    Fidelity = 0.88505308
# T = 50    Fidelity = 0.89880159
# T = 75    Fidelity = 0.92326609
# T = 100   Fidelity = 0.93880872
# T = 125   Fidelity = 0.94955600
# T = 150   Fidelity = 0.95635958
# T = 175   Fidelity = 0.96221055
# T = 200   Fidelity = 0.96695208
# T = 225   Fidelity = 0.96508469
# T = 250   Fidelity = 0.97032375
#
# Minimum T for Fidelity >= 0.97 : 250
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.333
# ================================================================================
# Minimum path gap = 4.61790996e-01
# T = 1     Fidelity = 0.80582609
# T = 2     Fidelity = 0.81748988
# T = 5     Fidelity = 0.83579021
# T = 10    Fidelity = 0.86113460
# T = 20    Fidelity = 0.88778322
# T = 30    Fidelity = 0.90433790
# T = 40    Fidelity = 0.91625352
# T = 50    Fidelity = 0.92534206
# T = 75    Fidelity = 0.94105058
# T = 100   Fidelity = 0.95085863
# T = 125   Fidelity = 0.95789416
# T = 150   Fidelity = 0.96259474
# T = 175   Fidelity = 0.96596603
# T = 200   Fidelity = 0.96960951
# T = 225   Fidelity = 0.97260290
#
# Minimum T for Fidelity >= 0.97 : 225
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.371
# ================================================================================
# Minimum path gap = 3.93901503e-01
# T = 1     Fidelity = 0.91917828
# T = 2     Fidelity = 0.93662247
# T = 5     Fidelity = 0.94512487
# T = 10    Fidelity = 0.95504412
# T = 20    Fidelity = 0.96555043
# T = 30    Fidelity = 0.97095687
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.410
# ================================================================================
# Minimum path gap = 3.69620878e-01
# T = 1     Fidelity = 0.97642255
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.449
# ================================================================================
# Minimum path gap = 3.50304986e-01
# T = 1     Fidelity = 0.98872081
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.488
# ================================================================================
# Minimum path gap = 3.33860714e-01
# T = 1     Fidelity = 0.99084366
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.527
# ================================================================================
# Minimum path gap = 3.19938628e-01
# T = 1     Fidelity = 0.99088506
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.565
# ================================================================================
# Minimum path gap = 3.07507538e-01
# T = 1     Fidelity = 0.99046084
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.604
# ================================================================================
# Minimum path gap = 2.96125952e-01
# T = 1     Fidelity = 0.98993240
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.643
# ================================================================================
# Minimum path gap = 2.85636403e-01
# T = 1     Fidelity = 0.98937149
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.682
# ================================================================================
# Minimum path gap = 2.75952394e-01
# T = 1     Fidelity = 0.98877201
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.720
# ================================================================================
# Minimum path gap = 2.66993394e-01
# T = 1     Fidelity = 0.98810109
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.759
# ================================================================================
# Minimum path gap = 2.58678635e-01
# T = 1     Fidelity = 0.98731466
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.798
# ================================================================================
# Minimum path gap = 2.50935075e-01
# T = 1     Fidelity = 0.98635905
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.837
# ================================================================================
# Minimum path gap = 2.43704173e-01
# T = 1     Fidelity = 0.98516634
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.876
# ================================================================================
# Minimum path gap = 2.36944606e-01
# T = 1     Fidelity = 0.98364922
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.914
# ================================================================================
# Minimum path gap = 2.30631967e-01
# T = 1     Fidelity = 0.98169768
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.953
# ================================================================================
# Minimum path gap = 2.24756925e-01
# T = 1     Fidelity = 0.97917860
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.992
# ================================================================================
# Minimum path gap = 2.19322771e-01
# T = 1     Fidelity = 0.97593826
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.031
# ================================================================================
# Minimum path gap = 2.14342798e-01
# T = 1     Fidelity = 0.97180816
#
# Minimum T for Fidelity >= 0.97 : 1
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.069
# ================================================================================
# Minimum path gap = 2.09837646e-01
# T = 1     Fidelity = 0.96661421
# T = 2     Fidelity = 0.98046607
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.108
# ================================================================================
# Minimum path gap = 2.05832643e-01
# T = 1     Fidelity = 0.96018931
# T = 2     Fidelity = 0.97495063
#
# Minimum T for Fidelity >= 0.97 : 2
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.147
# ================================================================================
# Minimum path gap = 2.02355174e-01
# T = 1     Fidelity = 0.95238863
# T = 2     Fidelity = 0.96814703
# T = 5     Fidelity = 0.97923085
#
# Minimum T for Fidelity >= 0.97 : 5
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.186
# ================================================================================
# Minimum path gap = 1.99432132e-01
# T = 1     Fidelity = 0.94310625
# T = 2     Fidelity = 0.95994820
# T = 5     Fidelity = 0.97290179
#
# Minimum T for Fidelity >= 0.97 : 5
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.224
# ================================================================================
# Minimum path gap = 1.97087558e-01
# T = 1     Fidelity = 0.93229127
# T = 2     Fidelity = 0.95029820
# T = 5     Fidelity = 0.96533105
# T = 10    Fidelity = 0.97070280
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.263
# ================================================================================
# Minimum path gap = 1.95340561e-01
# T = 1     Fidelity = 0.91996082
# T = 2     Fidelity = 0.93920520
# T = 5     Fidelity = 0.95650919
# T = 10    Fidelity = 0.96294378
# T = 20    Fidelity = 0.97072430
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.302
# ================================================================================
# Minimum path gap = 1.94203669e-01
# T = 1     Fidelity = 0.90620770
# T = 2     Fidelity = 0.92674961
# T = 5     Fidelity = 0.94649032
# T = 10    Fidelity = 0.95413861
# T = 20    Fidelity = 0.96407264
# T = 30    Fidelity = 0.96931722
# T = 40    Fidelity = 0.97291478
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.341
# ================================================================================
# Minimum path gap = 1.93681684e-01
# T = 1     Fidelity = 0.89120078
# T = 2     Fidelity = 0.91308531
# T = 5     Fidelity = 0.93539485
# T = 10    Fidelity = 0.94442716
# T = 20    Fidelity = 0.95685886
# T = 30    Fidelity = 0.96286371
# T = 40    Fidelity = 0.96768187
# T = 50    Fidelity = 0.97094598
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.380
# ================================================================================
# Minimum path gap = 1.93771116e-01
# T = 1     Fidelity = 0.87517742
# T = 2     Fidelity = 0.89843329
# T = 5     Fidelity = 0.92340532
# T = 10    Fidelity = 0.93400995
# T = 20    Fidelity = 0.94922665
# T = 30    Fidelity = 0.95609437
# T = 40    Fidelity = 0.96216686
# T = 50    Fidelity = 0.96576059
# T = 75    Fidelity = 0.97309637
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.418
# ================================================================================
# Minimum path gap = 1.94460196e-01
# T = 1     Fidelity = 0.85842893
# T = 2     Fidelity = 0.88306842
# T = 5     Fidelity = 0.91075580
# T = 10    Fidelity = 0.92313352
# T = 20    Fidelity = 0.94134485
# T = 30    Fidelity = 0.94925674
# T = 40    Fidelity = 0.95644388
# T = 50    Fidelity = 0.96072286
# T = 75    Fidelity = 0.96950446
# T = 100   Fidelity = 0.97479812
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.457
# ================================================================================
# Minimum path gap = 1.95729417e-01
# T = 1     Fidelity = 0.84128084
# T = 2     Fidelity = 0.86730097
# T = 5     Fidelity = 0.89771627
# T = 10    Fidelity = 0.91207158
# T = 20    Fidelity = 0.93340758
# T = 30    Fidelity = 0.94259039
# T = 40    Fidelity = 0.95068848
# T = 50    Fidelity = 0.95601521
# T = 75    Fidelity = 0.96591929
# T = 100   Fidelity = 0.97199766
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.496
# ================================================================================
# Minimum path gap = 1.97552503e-01
# T = 1     Fidelity = 0.82407120
# T = 2     Fidelity = 0.85145592
# T = 5     Fidelity = 0.88457434
# T = 10    Fidelity = 0.90110480
# T = 20    Fidelity = 0.92562977
# T = 30    Fidelity = 0.93630018
# T = 40    Fidelity = 0.94516895
# T = 50    Fidelity = 0.95168527
# T = 75    Fidelity = 0.96256498
# T = 100   Fidelity = 0.96980650
# T = 125   Fidelity = 0.97483133
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.535
# ================================================================================
# Minimum path gap = 1.99897671e-01
# T = 1     Fidelity = 0.80712970
# T = 2     Fidelity = 0.83585268
# T = 5     Fidelity = 0.87161692
# T = 10    Fidelity = 0.89050206
# T = 20    Fidelity = 0.91823631
# T = 30    Fidelity = 0.93054937
# T = 40    Fidelity = 0.94018021
# T = 50    Fidelity = 0.94775343
# T = 75    Fidelity = 0.95981237
# T = 100   Fidelity = 0.96803228
# T = 125   Fidelity = 0.97342364
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.573
# ================================================================================
# Minimum path gap = 2.02729043e-01
# T = 1     Fidelity = 0.79076009
# T = 2     Fidelity = 0.82078784
# T = 5     Fidelity = 0.85911406
# T = 10    Fidelity = 0.88050535
# T = 20    Fidelity = 0.91144645
# T = 30    Fidelity = 0.92546658
# T = 40    Fidelity = 0.93596970
# T = 50    Fidelity = 0.94430320
# T = 75    Fidelity = 0.95783229
# T = 100   Fidelity = 0.96665993
# T = 125   Fidelity = 0.97271468
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.612
# ================================================================================
# Minimum path gap = 2.06008070e-01
# T = 1     Fidelity = 0.77522742
# T = 2     Fidelity = 0.80652230
# T = 5     Fidelity = 0.84730653
# T = 10    Fidelity = 0.87131936
# T = 20    Fidelity = 0.90545724
# T = 30    Fidelity = 0.92115588
# T = 40    Fidelity = 0.93269577
# T = 50    Fidelity = 0.94148549
# T = 75    Fidelity = 0.95657157
# T = 100   Fidelity = 0.96591091
# T = 125   Fidelity = 0.97248718
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.651
# ================================================================================
# Minimum path gap = 2.09694873e-01
# T = 1     Fidelity = 0.76075055
# T = 2     Fidelity = 0.79327342
# T = 5     Fidelity = 0.83639769
# T = 10    Fidelity = 0.86310597
# T = 20    Fidelity = 0.90042970
# T = 30    Fidelity = 0.91770229
# T = 40    Fidelity = 0.93042557
# T = 50    Fidelity = 0.93946275
# T = 75    Fidelity = 0.95593452
# T = 100   Fidelity = 0.96587699
# T = 125   Fidelity = 0.97271419
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.690
# ================================================================================
# Minimum path gap = 2.13749401e-01
# T = 1     Fidelity = 0.74749936
# T = 2     Fidelity = 0.78121169
# T = 5     Fidelity = 0.82654952
# T = 10    Fidelity = 0.85598298
# T = 20    Fidelity = 0.89647991
# T = 30    Fidelity = 0.91517125
# T = 40    Fidelity = 0.92915612
# T = 50    Fidelity = 0.93835092
# T = 75    Fidelity = 0.95589161
# T = 100   Fidelity = 0.96644991
# T = 125   Fidelity = 0.97346035
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.729
# ================================================================================
# Minimum path gap = 2.18132396e-01
# T = 1     Fidelity = 0.73559589
# T = 2     Fidelity = 0.77046133
# T = 5     Fidelity = 0.81788217
# T = 10    Fidelity = 0.85002613
# T = 20    Fidelity = 0.89367560
# T = 30    Fidelity = 0.91360430
# T = 40    Fidelity = 0.92883949
# T = 50    Fidelity = 0.93819203
# T = 75    Fidelity = 0.95646124
# T = 100   Fidelity = 0.96748653
# T = 125   Fidelity = 0.97465721
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.767
# ================================================================================
# Minimum path gap = 2.22806129e-01
# T = 1     Fidelity = 0.72511809
# T = 2     Fidelity = 0.76110337
# T = 5     Fidelity = 0.81047606
# T = 10    Fidelity = 0.84527322
# T = 20    Fidelity = 0.89203751
# T = 30    Fidelity = 0.91301455
# T = 40    Fidelity = 0.92940182
# T = 50    Fidelity = 0.93895670
# T = 75    Fidelity = 0.95765174
# T = 100   Fidelity = 0.96890542
# T = 125   Fidelity = 0.97616574
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.806
# ================================================================================
# Minimum path gap = 2.27734927e-01
# T = 1     Fidelity = 0.71610506
# T = 2     Fidelity = 0.75318046
# T = 5     Fidelity = 0.80437558
# T = 10    Fidelity = 0.84172933
# T = 20    Fidelity = 0.89154420
# T = 30    Fidelity = 0.91338405
# T = 40    Fidelity = 0.93075423
# T = 50    Fidelity = 0.94056135
# T = 75    Fidelity = 0.95942618
# T = 100   Fidelity = 0.97066465
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.845
# ================================================================================
# Minimum path gap = 2.32885520e-01
# T = 1     Fidelity = 0.70856300
# T = 2     Fidelity = 0.74670229
# T = 5     Fidelity = 0.79959365
# T = 10    Fidelity = 0.83937235
# T = 20    Fidelity = 0.89213883
# T = 30    Fidelity = 0.91466423
# T = 40    Fidelity = 0.93279814
# T = 50    Fidelity = 0.94288749
# T = 75    Fidelity = 0.96169959
# T = 100   Fidelity = 0.97271839
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.884
# ================================================================================
# Minimum path gap = 2.38227223e-01
# T = 1     Fidelity = 0.70247099
# T = 2     Fidelity = 0.74165110
# T = 5     Fidelity = 0.79611642
# T = 10    Fidelity = 0.83815830
# T = 20    Fidelity = 0.89373672
# T = 30    Fidelity = 0.91677886
# T = 40    Fidelity = 0.93542829
# T = 50    Fidelity = 0.94579770
# T = 75    Fidelity = 0.96435497
# T = 100   Fidelity = 0.97499611
#
# ...
# Symmetric      0.255     125       0.9853298639      3.98493198e-06    None        None        None
# Symmetric      0.294     100       0.9775084125      1.64715494e-06    None        None        None
# Symmetric      0.333     100       0.9718851521      7.68096692e-07    None        None        None
# Symmetric      0.371     75        0.9770012319      4.14141285e-07    None        None        None
# Symmetric      0.410     75        0.9872681770      3.18425170e-07    None        None        None
# Symmetric      0.449     75        0.9948430625      3.07336185e-07    None        None        None
# Symmetric      0.488     75        0.9947913262      3.30563732e-07    None        None        None
# Symmetric      0.527     75        0.9910424292      3.38998847e-07    None        None        None
# Symmetric      0.565     75        0.9888993285      3.58206671e-07    None        None        None
# Symmetric      0.604     40        0.9763234665      7.16692413e-07    None        None        None
# Symmetric      0.643     40        0.9785201811      1.89799446e-06    None        None        None
# Symmetric      0.682     40        0.9769833456      4.77657226e-06    None        None        None
# Symmetric      0.720     40        0.9735121916      1.09339613e-05    None        None        None
# Symmetric      0.759     50        0.9959359988      2.29616480e-05    None        None        None
# Symmetric      0.798     50        0.9989360839      4.47766784e-05    None        None        None
# Symmetric      0.837     50        0.9993802971      8.19228137e-05    None        None        None
# Symmetric      0.876     50        0.9980043175      1.41818058e-04    None        None        None
# Symmetric      0.914     30        0.9719266859      2.33916520e-04    None        None        None
# Symmetric      0.953     30        0.9817304148      3.69765765e-04    None        None        None
# Symmetric      0.992     30        0.9889782899      5.62953624e-04    None        None        None
# Symmetric      1.031     30        0.9938390296      8.28948604e-04    None        None        None
# Symmetric      1.069     30        0.9965565443      1.18484510e-03    None        None        None
# Symmetric      1.108     30        0.9974342055      1.64902892e-03    None        None        None
# Symmetric      1.147     30        0.9968171627      2.24078104e-03    None        None        None
# Symmetric      1.186     30        0.9950709169      2.97983845e-03    None        None        None
# Symmetric      1.224     30        0.9925575995      3.88593119e-03    None        None        None
# Symmetric      1.263     30        0.9896130592      4.97831388e-03    None        None        None
# Symmetric      1.302     30        0.9865279047      6.27530923e-03    None        None        None
# Symmetric      1.341     30        0.9835346786      7.79387932e-03    None        None        None
# Symmetric      1.380     30        0.9808020481      9.54923850e-03    None        None        None
# Symmetric      1.418     30        0.9784357406      1.15545198e-02    None        None        None
# Symmetric      1.457     30        0.9764851305      1.38205043e-02    None        None        None
# Symmetric      1.496     30        0.9749538827      1.63554198e-02    None        None        None
# Symmetric      1.535     30        0.9738128326      1.91648137e-02    None        None        None
# Symmetric      1.573     30        0.9730132632      2.22515003e-02    None        None        None
# Symmetric      1.612     30        0.9724989557      2.56155815e-02    None        None        None
# Symmetric      1.651     30        0.9722157947      2.92545358e-02    None        None        None
# Symmetric      1.690     30        0.9721182607      3.31633696e-02    None        None        None
# Symmetric      1.729     30        0.9721727125      3.73348200e-02    None        None        None
# Symmetric      1.767     30        0.9723578458      4.17596003e-02    None        None        None
# Symmetric      1.806     30        0.9726630238      4.64266745e-02    None        None        None
# Symmetric      1.845     30        0.9730852983      5.13235508e-02    None        None        None
# Symmetric      1.884     30        0.9736259058      5.64365810e-02    None        None        None
# Symmetric      1.922     30        0.9742868771      6.17512559e-02    None        None        None
# Symmetric      1.961     30        0.9750682119      6.72524885e-02    None        None        None
# Symmetric      2.000     30        0.9759658805      7.29248761e-02    None        None        None
# Weak SSB optimised0.100     125       0.9748581989      8.65519637e-01    None        None        None
# Weak SSB optimised0.139     125       0.9708258847      8.39578713e-01    None        None        None
# Weak SSB optimised0.178     150       0.9730538365      8.06866518e-01    None        None        None
# Weak SSB optimised0.216     150       0.9702774085      7.48494613e-01    None        None        None
# Weak SSB optimised0.255     225       0.9756063769      6.68809100e-01    None        None        None
# Weak SSB optimised0.294     250       0.9703237548      5.68446052e-01    None        None        None
# Weak SSB optimised0.333     225       0.9726029019      4.61790996e-01    None        None        None
# Weak SSB optimised0.371     30        0.9709568715      3.93901503e-01    None        None        None
# Weak SSB optimised0.410     1         0.9764225516      3.69620878e-01    None        None        None
# Weak SSB optimised0.449     1         0.9887208058      3.50304986e-01    None        None        None
# Weak SSB optimised0.488     1         0.9908436592      3.33860714e-01    None        None        None
# Weak SSB optimised0.527     1         0.9908850572      3.19938628e-01    None        None        None
# Weak SSB optimised0.565     1         0.9904608427      3.07507538e-01    None        None        None
# Weak SSB optimised0.604     1         0.9899324005      2.96125952e-01    None        None        None
# Weak SSB optimised0.643     1         0.9893714874      2.85636403e-01    None        None        None
# Weak SSB optimised0.682     1         0.9887720056      2.75952394e-01    None        None        None
# Weak SSB optimised0.720     1         0.9881010872      2.66993394e-01    None        None        None
# Weak SSB optimised0.759     1         0.9873146648      2.58678635e-01    None        None        None
# Weak SSB optimised0.798     1         0.9863590504      2.50935075e-01    None        None        None
# Weak SSB optimised0.837     1         0.9851663440      2.43704173e-01    None        None        None
# Weak SSB optimised0.876     1         0.9836492163      2.36944606e-01    None        None        None
# Weak SSB optimised0.914     1         0.9816976756      2.30631967e-01    None        None        None
# Weak SSB optimised0.953     1         0.9791785968      2.24756925e-01    None        None        None
# Weak SSB optimised0.992     1         0.9759382636      2.19322771e-01    None        None        None
# Weak SSB optimised1.031     1         0.9718081619      2.14342798e-01    None        None        None
# Weak SSB optimised1.069     2         0.9804660694      2.09837646e-01    None        None        None
# Weak SSB optimised1.108     2         0.9749506260      2.05832643e-01    None        None        None
# Weak SSB optimised1.147     5         0.9792308452      2.02355174e-01    None        None        None
# Weak SSB optimised1.186     5         0.9729017923      1.99432132e-01    None        None        None
# Weak SSB optimised1.224     10        0.9707027974      1.97087558e-01    None        None        None
# Weak SSB optimised1.263     20        0.9707242964      1.95340561e-01    None        None        None
# Weak SSB optimised1.302     40        0.9729147786      1.94203669e-01    None        None        None
# Weak SSB optimised1.341     50        0.9709459825      1.93681684e-01    None        None        None
# Weak SSB optimised1.380     75        0.9730963686      1.93771116e-01    None        None        None
# Weak SSB optimised1.418     100       0.9747981184      1.94460196e-01    None        None        None
# Weak SSB optimised1.457     100       0.9719976553      1.95729417e-01    None        None        None
# Weak SSB optimised1.496     125       0.9748313267      1.97552503e-01    None        None        None
# Weak SSB optimised1.535     125       0.9734236379      1.99897671e-01    None        None        None
# Weak SSB optimised1.573     125       0.9727146795      2.02729043e-01    None        None        None
# Weak SSB optimised1.612     125       0.9724871820      2.06008070e-01    None        None        None
# Weak SSB optimised1.651     125       0.9727141897      2.09694873e-01    None        None        None
# Weak SSB optimised1.690     125       0.9734603538      2.13749401e-01    None        None        None
# Weak SSB optimised1.729     125       0.9746572133      2.18132396e-01    None        None        None
# Weak SSB optimised1.767     125       0.9761657381      2.22806129e-01    None        None        None
# Weak SSB optimised1.806     100       0.9706646450      2.27734927e-01    None        None        None
# Weak SSB optimised1.845     100       0.9727183925      2.32885520e-01    None        None        None
# Weak SSB optimised1.884     100       0.9749961089      2.38227223e-01    None        None        None
# Weak SSB optimised1.922     100       0.9774038192      2.43732008e-01    None        None        None
# Weak SSB optimised1.961     75        0.9702976231      2.49374469e-01    None        None        None
# Weak SSB optimised2.000     75        0.9733434213      2.54594564e-01    None        None        None
# Strong SSB     0.100     1         0.9943303610      3.59472102e+00    None        None        None
# Strong SSB     0.139     1         0.9943190040      3.21657560e+00    None        None        None
# Strong SSB     0.178     1         0.9943483032      2.82952155e+00    None        None        None
# Strong SSB     0.216     1         0.9944379140      2.44438071e+00    None        None        None
# Strong SSB     0.255     1         0.9945594932      2.07127401e+00    None        None        None
# Strong SSB     0.294     1         0.9945047482      1.72463158e+00    None        None        None
# Strong SSB     0.333     1         0.9937138025      1.42925187e+00    None        None        None
# Strong SSB     0.371     1         0.9917647901      1.22618356e+00    None        None        None
# Strong SSB     0.410     1         0.9897374439      1.16150566e+00    None        None        None
# Strong SSB     0.449     1         0.9903833991      1.23479446e+00    None        None        None
# Strong SSB     0.488     1         0.9926642672      1.36018880e+00    None        None        None
# Strong SSB     0.527     1         0.9939847098      1.43068387e+00    None        None        None
# Strong SSB     0.565     1         0.9944030602      1.44073338e+00    None        None        None
# Strong SSB     0.604     1         0.9944256084      1.43169176e+00    None        None        None
# Strong SSB     0.643     1         0.9943078197      1.42215187e+00    None        None        None
# Strong SSB     0.682     1         0.9941576687      1.41594322e+00    None        None        None
# Strong SSB     0.720     1         0.9940176398      1.41220733e+00    None        None        None
# Strong SSB     0.759     1         0.9938953956      1.40926031e+00    None        None        None
# Strong SSB     0.798     1         0.9937829302      1.40588304e+00    None        None        None
# Strong SSB     0.837     1         0.9936697408      1.40154174e+00    None        None        None
# Strong SSB     0.876     1         0.9935485877      1.39619424e+00    None        None        None
# Strong SSB     0.914     1         0.9934161752      1.39002869e+00    None        None        None
# Strong SSB     0.953     1         0.9932719360      1.38327763e+00    None        None        None
# Strong SSB     0.992     1         0.9931166977      1.37612629e+00    None        None        None
# Strong SSB     1.031     1         0.9929517636      1.36868643e+00    None        None        None
# Strong SSB     1.069     1         0.9927783984      1.36100379e+00    None        None        None
# Strong SSB     1.108     1         0.9925975923      1.35307787e+00    None        None        None
# Strong SSB     1.147     1         0.9924099925      1.34488277e+00    None        None        None
# Strong SSB     1.186     1         0.9922159279      1.33638429e+00    None        None        None
# Strong SSB     1.224     1         0.9920154785      1.32755217e+00    None        None        None
# Strong SSB     1.263     1         0.9918085571      1.31836753e+00    None        None        None
# Strong SSB     1.302     1         0.9915949839      1.30882658e+00    None        None        None
# Strong SSB     1.341     1         0.9913745465      1.29894142e+00    None        None        None
# Strong SSB     1.380     1         0.9911470409      1.28873886e+00    None        None        None
# Strong SSB     1.418     1         0.9909122965      1.27825795e+00    None        None        None
# Strong SSB     1.457     1         0.9906701890      1.26754693e+00    None        None        None
# Strong SSB     1.496     1         0.9904206449      1.25665993e+00    None        None        None
# Strong SSB     1.535     1         0.9901636400      1.24565388e+00    None        None        None
# Strong SSB     1.573     1         0.9898991965      1.23458579e+00    None        None        None
# Strong SSB     1.612     1         0.9896273787      1.22351059e+00    None        None        None
# Strong SSB     1.651     1         0.9893482888      1.21247951e+00    None        None        None
# Strong SSB     1.690     1         0.9890620630      1.20153900e+00    None        None        None
# Strong SSB     1.729     1         0.9887688693      1.19073018e+00    None        None        None
# Strong SSB     1.767     1         0.9884689046      1.18008858e+00    None        None        None
# Strong SSB     1.806     1         0.9881623933      1.16964426e+00    None        None        None
# Strong SSB     1.845     1         0.9878495856      1.15942206e+00    None        None        None
# Strong SSB     1.884     1         0.9875307567      1.14944201e+00    None        None        None
# Strong SSB     1.922     1         0.9872062050      1.13971981e+00    None        None        None
# Strong SSB     1.961     1         0.9868762513      1.13026733e+00    None        None        None
# Strong SSB     2.000     1         0.9865412374      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================



case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
# Define colors for each case
case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}

plt.figure(figsize=(8,6))

    
for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,

        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=-1.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()


plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)

plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-1.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 0.5653
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.4102

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ',color='g')

plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--')

plt.axvline(lamc_weak,
            ls='--')

plt.axvline(lamc_strong,
            ls='--')

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-1.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_exact = match['psi_exact']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-1.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-1.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-1.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Start of m0^2=-2.0

# %%
# ============================================================
# T scan values
# ============================================================

T_values = [

    1,2,5,10,20,30,40,50,75,100,
    125,150,175,200,225,250,275,300,
    400,500,600,700,800,900,
    1000,1010,1020,1030,1040,1050,
    1060,1070,1080,1090,1100,
    1200,1300,1400,1500,
    2000,
    2100,2110,2120,2130,2140,
    2150,2160,2170,2180,2190,
    2200,2300,2400,2500,
    2600,2700,2800,2900,3000
]

target_fidelity = 0.97

# ============================================================
# Storage
# ============================================================

adiabatic_results = []

# ============================================================
# MAIN LOOP
# ============================================================

for data in all_results:

    label   = data['case']
    lam     = data['lambda']
    mI2     = data['mI2']
    f       = data['f']
    psi_exact = data['psi_exact']

    print("\n")
    print("="*80)
    print(f"CASE   : {label}")
    print(f"lambda : {lam:.3f}")
    print("="*80)

    # ========================================================
    # Final Hamiltonian
    # ========================================================

    Hs_final = two_site_hs(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        s=1.0
    )

    E_exact_final, psi_exact_final = exact_ground_state(
        Hs_final
    )

    # ========================================================
    # Minimum gap along adiabatic path
    # ========================================================

    delta_min = minimum_gap_along_path(

        nq=nq_site,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    print(f"Minimum path gap = {delta_min:.8e}")

    # ========================================================
    # Scan T
    # ========================================================

    Tmin_found = None
    best_fidelity = 0.0

    for T in T_values:

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_exact,

            nq=nq_site,

            T=T,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        F = fidelity(
            psi_T,
            psi_exact_final
        )

        best_fidelity = max(
            best_fidelity,
            F
        )

        print(
            f"T = {T:<5} "
            f"Fidelity = {F:.8f}"
        )

        if F >= target_fidelity:

            Tmin_found = T
            break

    # ========================================================
    # Diagnostics
    # ========================================================

    P0 = None
    P1 = None
    P01 = None
    final_gap = None

    if Tmin_found is None:

        print("\nFAILED POINT DIAGNOSTICS")

        psi_T = adiabatic_circuit_evolution(

            initial_state=psi_vqe,

            nq=nq_site,

            T=3000,

            mu=mu,

            mI2=mI2,

            m0_sq=-2.0,

            lam=lam,

            f=f,

            nsteps=100
        )

        evals, evecs = eigsh(

            Hs_final,

            k=3,

            which='SA'
        )

        idx = np.argsort(evals)

        evals = evals[idx]
        evecs = evecs[:, idx]

        psi0 = evecs[:, 0]
        psi1 = evecs[:, 1]

        P0 = np.abs(np.vdot(psi0, psi_T))**2
        P1 = np.abs(np.vdot(psi1, psi_T))**2
        P01 = P0 + P1

        final_gap = evals[1] - evals[0]

        print(f"E1-E0  = {final_gap:.8e}")
        print(f"P0     = {P0:.8f}")
        print(f"P1     = {P1:.8f}")
        print(f"P0+P1  = {P01:.8f}")

    # ========================================================
    # Store
    # ========================================================

    adiabatic_results.append({

        'case': label,
        'lambda': lam,
        'mI2': mI2,
        'f': f,

        'Tmin': Tmin_found,

        'best_fidelity': best_fidelity,

        'delta_min': delta_min,

        'P0': P0,
        'P1': P1,
        'P01': P01,

        'final_gap': final_gap
    })

    print(
        f"\nMinimum T for Fidelity >= 0.97 : "
        f"{Tmin_found}"
    )

# ============================================================
# FINAL SUMMARY
# ============================================================

print("\n")
print("="*180)
print("FINAL ADIABATIC SUMMARY")
print("="*180)

print(

    f"{'Case':<15}"
    f"{'lambda':<10}"
    f"{'T_min':<10}"
    f"{'Best Fidelity':<18}"
    f"{'Delta_min':<18}"
    f"{'P0':<12}"
    f"{'P1':<12}"
    f"{'P0+P1':<12}"
)

print("="*180)

for r in adiabatic_results:

    print(

        f"{r['case']:<15}"
        f"{r['lambda']:<10.3f}"
        f"{str(r['Tmin']):<10}"
        f"{r['best_fidelity']:<18.10f}"
        f"{r['delta_min']:<18.8e}"
        f"{str(None if r['P0'] is None else round(r['P0'],6)):<12}"
        f"{str(None if r['P1'] is None else round(r['P1'],6)):<12}"
        f"{str(None if r['P01'] is None else round(r['P01'],6)):<12}"
    )
# Out:
# ================================================================================
# CASE   : Symmetric
# lambda : 0.100
# ================================================================================
# Minimum path gap = 3.07240439e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000295
# T = 10    Fidelity = 0.00027927
# T = 20    Fidelity = 0.00630267
# T = 30    Fidelity = 0.02604240
# T = 40    Fidelity = 0.06582107
# T = 50    Fidelity = 0.12447358
# T = 75    Fidelity = 0.30902400
# T = 100   Fidelity = 0.46391161
# T = 125   Fidelity = 0.64204308
# T = 150   Fidelity = 0.69157604
# T = 175   Fidelity = 0.77469193
# T = 200   Fidelity = 0.83395432
# T = 225   Fidelity = 0.81460958
# T = 250   Fidelity = 0.90536125
# T = 275   Fidelity = 0.91626441
# T = 300   Fidelity = 0.86715755
# T = 400   Fidelity = 0.97880042
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.139
# ================================================================================
# Minimum path gap = 1.00262907e-04
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00000831
# T = 10    Fidelity = 0.00060574
# T = 20    Fidelity = 0.01673500
# T = 30    Fidelity = 0.07063792
# T = 40    Fidelity = 0.16214514
# T = 50    Fidelity = 0.28085538
# T = 75    Fidelity = 0.54899052
# T = 100   Fidelity = 0.71055420
# T = 125   Fidelity = 0.78882842
# T = 150   Fidelity = 0.80339500
# T = 175   Fidelity = 0.85918607
# T = 200   Fidelity = 0.88571172
# T = 225   Fidelity = 0.96246154
# T = 250   Fidelity = 0.95235452
# T = 275   Fidelity = 0.94513963
# T = 300   Fidelity = 0.96361976
# T = 400   Fidelity = 0.98748711
#
# Minimum T for Fidelity >= 0.97 : 400
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.178
# ================================================================================
# Minimum path gap = 4.06725624e-05
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00001957
# T = 10    Fidelity = 0.00137558
# T = 20    Fidelity = 0.04008426
# T = 30    Fidelity = 0.16268871
# T = 40    Fidelity = 0.33034102
# T = 50    Fidelity = 0.48607756
# T = 75    Fidelity = 0.68245140
# T = 100   Fidelity = 0.77172723
# T = 125   Fidelity = 0.83018032
# T = 150   Fidelity = 0.86679241
# T = 175   Fidelity = 0.90119452
# T = 200   Fidelity = 0.91805682
# T = 225   Fidelity = 0.95264545
# T = 250   Fidelity = 0.95814148
# T = 275   Fidelity = 0.99441065
#
# Minimum T for Fidelity >= 0.97 : 275
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.216
# ================================================================================
# Minimum path gap = 1.26747315e-05
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00004305
# T = 10    Fidelity = 0.00317336
# T = 20    Fidelity = 0.08741990
# T = 30    Fidelity = 0.30889512
# T = 40    Fidelity = 0.51018828
# T = 50    Fidelity = 0.60648210
# T = 75    Fidelity = 0.70651041
# T = 100   Fidelity = 0.83561505
# T = 125   Fidelity = 0.88762652
# T = 150   Fidelity = 0.92258455
# T = 175   Fidelity = 0.93877532
# T = 200   Fidelity = 0.98676312
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.255
# ================================================================================
# Minimum path gap = 4.99212419e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000000
# T = 5     Fidelity = 0.00009060
# T = 10    Fidelity = 0.00658297
# T = 20    Fidelity = 0.17399417
# T = 30    Fidelity = 0.46593289
# T = 40    Fidelity = 0.58038616
# T = 50    Fidelity = 0.60101158
# T = 75    Fidelity = 0.79480733
# T = 100   Fidelity = 0.88593503
# T = 125   Fidelity = 0.91394893
# T = 150   Fidelity = 0.96074716
# T = 175   Fidelity = 0.98392308
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.294
# ================================================================================
# Minimum path gap = 1.70864235e-06
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000001
# T = 5     Fidelity = 0.00020955
# T = 10    Fidelity = 0.01396641
# T = 20    Fidelity = 0.29204279
# T = 30    Fidelity = 0.53608347
# T = 40    Fidelity = 0.54252630
# T = 50    Fidelity = 0.64799040
# T = 75    Fidelity = 0.84419100
# T = 100   Fidelity = 0.91170359
# T = 125   Fidelity = 0.94484692
# T = 150   Fidelity = 0.98537316
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.333
# ================================================================================
# Minimum path gap = 6.70006882e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000002
# T = 5     Fidelity = 0.00049126
# T = 10    Fidelity = 0.02979524
# T = 20    Fidelity = 0.41766167
# T = 30    Fidelity = 0.48920269
# T = 40    Fidelity = 0.59231007
# T = 50    Fidelity = 0.76362688
# T = 75    Fidelity = 0.86878659
# T = 100   Fidelity = 0.93616862
# T = 125   Fidelity = 0.97008095
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.371
# ================================================================================
# Minimum path gap = 3.24972876e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000003
# T = 5     Fidelity = 0.00111832
# T = 10    Fidelity = 0.05617063
# T = 20    Fidelity = 0.46469437
# T = 30    Fidelity = 0.45624484
# T = 40    Fidelity = 0.73085361
# T = 50    Fidelity = 0.78256072
# T = 75    Fidelity = 0.90340294
# T = 100   Fidelity = 0.95399935
# T = 125   Fidelity = 0.97711405
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.410
# ================================================================================
# Minimum path gap = 2.07180341e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000005
# T = 5     Fidelity = 0.00229843
# T = 10    Fidelity = 0.09583300
# T = 20    Fidelity = 0.41315019
# T = 30    Fidelity = 0.58322290
# T = 40    Fidelity = 0.75285545
# T = 50    Fidelity = 0.79947064
# T = 75    Fidelity = 0.91576528
# T = 100   Fidelity = 0.96406197
# T = 125   Fidelity = 0.98611555
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.449
# ================================================================================
# Minimum path gap = 2.05022068e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000007
# T = 5     Fidelity = 0.00424729
# T = 10    Fidelity = 0.15515527
# T = 20    Fidelity = 0.32961335
# T = 30    Fidelity = 0.70994185
# T = 40    Fidelity = 0.73391999
# T = 50    Fidelity = 0.85587972
# T = 75    Fidelity = 0.93308369
# T = 100   Fidelity = 0.97709756
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.488
# ================================================================================
# Minimum path gap = 2.57926392e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000009
# T = 5     Fidelity = 0.00703432
# T = 10    Fidelity = 0.23206696
# T = 20    Fidelity = 0.34254303
# T = 30    Fidelity = 0.71186626
# T = 40    Fidelity = 0.78857772
# T = 50    Fidelity = 0.85051309
# T = 75    Fidelity = 0.94688994
# T = 100   Fidelity = 0.98224645
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.527
# ================================================================================
# Minimum path gap = 2.94157985e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000013
# T = 5     Fidelity = 0.01056435
# T = 10    Fidelity = 0.30013744
# T = 20    Fidelity = 0.49707873
# T = 30    Fidelity = 0.65386492
# T = 40    Fidelity = 0.84194557
# T = 50    Fidelity = 0.88865424
# T = 75    Fidelity = 0.96402379
# T = 100   Fidelity = 0.98760123
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.565
# ================================================================================
# Minimum path gap = 2.95938146e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000018
# T = 5     Fidelity = 0.01490179
# T = 10    Fidelity = 0.33300507
# T = 20    Fidelity = 0.63701215
# T = 30    Fidelity = 0.66853753
# T = 40    Fidelity = 0.80082134
# T = 50    Fidelity = 0.89715959
# T = 75    Fidelity = 0.96382944
# T = 100   Fidelity = 0.98963966
#
# Minimum T for Fidelity >= 0.97 : 100
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.604
# ================================================================================
# Minimum path gap = 2.82226628e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000029
# T = 5     Fidelity = 0.02065213
# T = 10    Fidelity = 0.32392515
# T = 20    Fidelity = 0.62127869
# T = 30    Fidelity = 0.76634775
# T = 40    Fidelity = 0.82605424
# T = 50    Fidelity = 0.88424719
# T = 75    Fidelity = 0.97760791
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.643
# ================================================================================
# Minimum path gap = 2.43063428e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000068
# T = 5     Fidelity = 0.02927172
# T = 10    Fidelity = 0.29242410
# T = 20    Fidelity = 0.55245041
# T = 30    Fidelity = 0.73601568
# T = 40    Fidelity = 0.83718253
# T = 50    Fidelity = 0.89251473
# T = 75    Fidelity = 0.98843040
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.682
# ================================================================================
# Minimum path gap = 2.04773404e-07
# T = 1     Fidelity = 0.00000000
# T = 2     Fidelity = 0.00000211
# T = 5     Fidelity = 0.04229136
# T = 10    Fidelity = 0.27118671
# T = 20    Fidelity = 0.53047450
# T = 30    Fidelity = 0.66958426
# T = 40    Fidelity = 0.79752592
# T = 50    Fidelity = 0.87663578
# T = 75    Fidelity = 0.99019897
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.720
# ================================================================================
# Minimum path gap = 1.74603617e-07
# T = 1     Fidelity = 0.00000001
# T = 2     Fidelity = 0.00000608
# T = 5     Fidelity = 0.05780439
# T = 10    Fidelity = 0.28475573
# T = 20    Fidelity = 0.54680267
# T = 30    Fidelity = 0.70658814
# T = 40    Fidelity = 0.81827792
# T = 50    Fidelity = 0.89938460
# T = 75    Fidelity = 0.98147258
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.759
# ================================================================================
# Minimum path gap = 1.39702905e-07
# T = 1     Fidelity = 0.00000004
# T = 2     Fidelity = 0.00001351
# T = 5     Fidelity = 0.07110696
# T = 10    Fidelity = 0.32432726
# T = 20    Fidelity = 0.58609582
# T = 30    Fidelity = 0.76269368
# T = 40    Fidelity = 0.86599179
# T = 50    Fidelity = 0.93026901
# T = 75    Fidelity = 0.98224873
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.798
# ================================================================================
# Minimum path gap = 1.13020056e-07
# T = 1     Fidelity = 0.00000010
# T = 2     Fidelity = 0.00002460
# T = 5     Fidelity = 0.08122731
# T = 10    Fidelity = 0.36752554
# T = 20    Fidelity = 0.63204028
# T = 30    Fidelity = 0.79922750
# T = 40    Fidelity = 0.89251920
# T = 50    Fidelity = 0.94494840
# T = 75    Fidelity = 0.98809631
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.837
# ================================================================================
# Minimum path gap = 9.49304635e-08
# T = 1     Fidelity = 0.00000022
# T = 2     Fidelity = 0.00004043
# T = 5     Fidelity = 0.08961558
# T = 10    Fidelity = 0.40561968
# T = 20    Fidelity = 0.67409930
# T = 30    Fidelity = 0.82530381
# T = 40    Fidelity = 0.90705265
# T = 50    Fidelity = 0.95099074
# T = 75    Fidelity = 0.99387990
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.876
# ================================================================================
# Minimum path gap = 8.30149158e-08
# T = 1     Fidelity = 0.00000044
# T = 2     Fidelity = 0.00006325
# T = 5     Fidelity = 0.09743460
# T = 10    Fidelity = 0.43861629
# T = 20    Fidelity = 0.71069553
# T = 30    Fidelity = 0.84887426
# T = 40    Fidelity = 0.92018068
# T = 50    Fidelity = 0.95672441
# T = 75    Fidelity = 0.99772955
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.914
# ================================================================================
# Minimum path gap = 7.17057125e-08
# T = 1     Fidelity = 0.00000085
# T = 2     Fidelity = 0.00009636
# T = 5     Fidelity = 0.10529131
# T = 10    Fidelity = 0.46831002
# T = 20    Fidelity = 0.74277159
# T = 30    Fidelity = 0.87136953
# T = 40    Fidelity = 0.93369026
# T = 50    Fidelity = 0.96397632
# T = 75    Fidelity = 0.99860479
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.953
# ================================================================================
# Minimum path gap = 6.68735476e-08
# T = 1     Fidelity = 0.00000159
# T = 2     Fidelity = 0.00014396
# T = 5     Fidelity = 0.11343727
# T = 10    Fidelity = 0.49610122
# T = 20    Fidelity = 0.77121054
# T = 30    Fidelity = 0.89191421
# T = 40    Fidelity = 0.94655598
# T = 50    Fidelity = 0.97183572
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 0.992
# ================================================================================
# Minimum path gap = 6.73812659e-08
# T = 1     Fidelity = 0.00000284
# T = 2     Fidelity = 0.00021086
# T = 5     Fidelity = 0.12189279
# T = 10    Fidelity = 0.52275076
# T = 20    Fidelity = 0.79663069
# T = 30    Fidelity = 0.90983574
# T = 40    Fidelity = 0.95793687
# T = 50    Fidelity = 0.97925449
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.031
# ================================================================================
# Minimum path gap = 7.12119919e-08
# T = 1     Fidelity = 0.00000491
# T = 2     Fidelity = 0.00030200
# T = 5     Fidelity = 0.13053126
# T = 10    Fidelity = 0.54860321
# T = 20    Fidelity = 0.81944164
# T = 30    Fidelity = 0.92511965
# T = 40    Fidelity = 0.96753677
# T = 50    Fidelity = 0.98556764
#
# Minimum T for Fidelity >= 0.97 : 50
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.069
# ================================================================================
# Minimum path gap = 7.95011506e-08
# T = 1     Fidelity = 0.00000815
# T = 2     Fidelity = 0.00042210
# T = 5     Fidelity = 0.13916360
# T = 10    Fidelity = 0.57379304
# T = 20    Fidelity = 0.83990135
# T = 30    Fidelity = 0.93800569
# T = 40    Fidelity = 0.97529129
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.108
# ================================================================================
# Minimum path gap = 9.36478797e-08
# T = 1     Fidelity = 0.00001304
# T = 2     Fidelity = 0.00057543
# T = 5     Fidelity = 0.14761498
# T = 10    Fidelity = 0.59834822
# T = 20    Fidelity = 0.85816677
# T = 30    Fidelity = 0.94868018
# T = 40    Fidelity = 0.98122877
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.147
# ================================================================================
# Minimum path gap = 1.12376363e-07
# T = 1     Fidelity = 0.00002013
# T = 2     Fidelity = 0.00076604
# T = 5     Fidelity = 0.15577154
# T = 10    Fidelity = 0.62222660
# T = 20    Fidelity = 0.87435218
# T = 30    Fidelity = 0.95724609
# T = 40    Fidelity = 0.98542381
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.186
# ================================================================================
# Minimum path gap = 1.36928898e-07
# T = 1     Fidelity = 0.00003012
# T = 2     Fidelity = 0.00099806
# T = 5     Fidelity = 0.16359028
# T = 10    Fidelity = 0.64532793
# T = 20    Fidelity = 0.88855382
# T = 30    Fidelity = 0.96377902
# T = 40    Fidelity = 0.98799436
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.224
# ================================================================================
# Minimum path gap = 1.65133243e-07
# T = 1     Fidelity = 0.00004381
# T = 2     Fidelity = 0.00127599
# T = 5     Fidelity = 0.17108400
# T = 10    Fidelity = 0.66750734
# T = 20    Fidelity = 0.90083519
# T = 30    Fidelity = 0.96838522
# T = 40    Fidelity = 0.98912406
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.263
# ================================================================================
# Minimum path gap = 1.92560618e-07
# T = 1     Fidelity = 0.00006219
# T = 2     Fidelity = 0.00160492
# T = 5     Fidelity = 0.17829787
# T = 10    Fidelity = 0.68859822
# T = 20    Fidelity = 0.91122521
# T = 30    Fidelity = 0.97122735
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.302
# ================================================================================
# Minimum path gap = 2.17451144e-07
# T = 1     Fidelity = 0.00008645
# T = 2     Fidelity = 0.00199050
# T = 5     Fidelity = 0.18528881
# T = 10    Fidelity = 0.70844006
# T = 20    Fidelity = 0.91975067
# T = 30    Fidelity = 0.97252056
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.341
# ================================================================================
# Minimum path gap = 2.38093912e-07
# T = 1     Fidelity = 0.00011794
# T = 2     Fidelity = 0.00243884
# T = 5     Fidelity = 0.19211141
# T = 10    Fidelity = 0.72690317
# T = 20    Fidelity = 0.92647415
# T = 30    Fidelity = 0.97253105
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.380
# ================================================================================
# Minimum path gap = 2.53076482e-07
# T = 1     Fidelity = 0.00015827
# T = 2     Fidelity = 0.00295628
# T = 5     Fidelity = 0.19881043
# T = 10    Fidelity = 0.74390413
# T = 20    Fidelity = 0.93150788
# T = 30    Fidelity = 0.97157418
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.418
# ================================================================================
# Minimum path gap = 2.63966163e-07
# T = 1     Fidelity = 0.00020923
# T = 2     Fidelity = 0.00354927
# T = 5     Fidelity = 0.20541790
# T = 10    Fidelity = 0.75941054
# T = 20    Fidelity = 0.93500247
# T = 30    Fidelity = 0.96999592
# T = 40    Fidelity = 0.98409663
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.457
# ================================================================================
# Minimum path gap = 2.70885549e-07
# T = 1     Fidelity = 0.00027283
# T = 2     Fidelity = 0.00422403
# T = 5     Fidelity = 0.21195331
# T = 10    Fidelity = 0.77343692
# T = 20    Fidelity = 0.93712734
# T = 30    Fidelity = 0.96814226
# T = 40    Fidelity = 0.98321573
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.496
# ================================================================================
# Minimum path gap = 2.74193723e-07
# T = 1     Fidelity = 0.00035129
# T = 2     Fidelity = 0.00498650
# T = 5     Fidelity = 0.21842543
# T = 10    Fidelity = 0.78603503
# T = 20    Fidelity = 0.93805745
# T = 30    Fidelity = 0.96632890
# T = 40    Fidelity = 0.98284618
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.535
# ================================================================================
# Minimum path gap = 2.92180487e-07
# T = 1     Fidelity = 0.00044697
# T = 2     Fidelity = 0.00584210
# T = 5     Fidelity = 0.22483498
# T = 10    Fidelity = 0.79728220
# T = 20    Fidelity = 0.93796977
# T = 30    Fidelity = 0.96481690
# T = 40    Fidelity = 0.98303466
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.573
# ================================================================================
# Minimum path gap = 3.47743476e-07
# T = 1     Fidelity = 0.00056240
# T = 2     Fidelity = 0.00679570
# T = 5     Fidelity = 0.23117744
# T = 10    Fidelity = 0.80727005
# T = 20    Fidelity = 0.93704508
# T = 30    Fidelity = 0.96379593
# T = 40    Fidelity = 0.98377156
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.612
# ================================================================================
# Minimum path gap = 4.58881918e-07
# T = 1     Fidelity = 0.00070026
# T = 2     Fidelity = 0.00785160
# T = 5     Fidelity = 0.23744563
# T = 10    Fidelity = 0.81609530
# T = 20    Fidelity = 0.93546961
# T = 30    Fidelity = 0.96337784
# T = 40    Fidelity = 0.98500251
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.651
# ================================================================================
# Minimum path gap = 6.47311111e-07
# T = 1     Fidelity = 0.00086330
# T = 2     Fidelity = 0.00901350
# T = 5     Fidelity = 0.24363184
# T = 10    Fidelity = 0.82385309
# T = 20    Fidelity = 0.93343333
# T = 30    Fidelity = 0.96360166
# T = 40    Fidelity = 0.98663750
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.690
# ================================================================================
# Minimum path gap = 9.40815950e-07
# T = 1     Fidelity = 0.00105440
# T = 2     Fidelity = 0.01028465
# T = 5     Fidelity = 0.24972934
# T = 10    Fidelity = 0.83063288
# T = 20    Fidelity = 0.93112493
# T = 30    Fidelity = 0.96444789
# T = 40    Fidelity = 0.98855937
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.729
# ================================================================================
# Minimum path gap = 1.37579473e-06
# T = 1     Fidelity = 0.00127651
# T = 2     Fidelity = 0.01166783
# T = 5     Fidelity = 0.25573337
# T = 10    Fidelity = 0.83651653
# T = 20    Fidelity = 0.92872514
# T = 30    Fidelity = 0.96585663
# T = 40    Fidelity = 0.99063365
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.767
# ================================================================================
# Minimum path gap = 1.99980370e-06
# T = 1     Fidelity = 0.00153266
# T = 2     Fidelity = 0.01316554
# T = 5     Fidelity = 0.26164163
# T = 10    Fidelity = 0.84157778
# T = 20    Fidelity = 0.92640012
# T = 30    Fidelity = 0.96774476
# T = 40    Fidelity = 0.99272070
#
# Minimum T for Fidelity >= 0.97 : 40
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.806
# ================================================================================
# Minimum path gap = 2.87406774e-06
# T = 1     Fidelity = 0.00182596
# T = 2     Fidelity = 0.01478000
# T = 5     Fidelity = 0.26745439
# T = 10    Fidelity = 0.84588289
# T = 20    Fidelity = 0.92429625
# T = 30    Fidelity = 0.97001904
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.845
# ================================================================================
# Minimum path gap = 4.07600310e-06
# T = 1     Fidelity = 0.00215958
# T = 2     Fidelity = 0.01651330
# T = 5     Fidelity = 0.27317422
# T = 10    Fidelity = 0.84949164
# T = 20    Fidelity = 0.92253668
# T = 30    Fidelity = 0.97258462
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.884
# ================================================================================
# Minimum path gap = 5.70182503e-06
# T = 1     Fidelity = 0.00253676
# T = 2     Fidelity = 0.01836740
# T = 5     Fidelity = 0.27880572
# T = 10    Fidelity = 0.85245862
# T = 20    Fidelity = 0.92121953
# T = 30    Fidelity = 0.97534958
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.922
# ================================================================================
# Minimum path gap = 7.86929838e-06
# T = 1     Fidelity = 0.00296083
# T = 2     Fidelity = 0.02034424
# T = 5     Fidelity = 0.28435502
# T = 10    Fidelity = 0.85483435
# T = 20    Fidelity = 0.92041752
# T = 30    Fidelity = 0.97822696
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 1.961
# ================================================================================
# Minimum path gap = 1.07206599e-05
# T = 1     Fidelity = 0.00343517
# T = 2     Fidelity = 0.02244569
# T = 5     Fidelity = 0.28982936
# T = 10    Fidelity = 0.85666631
# T = 20    Fidelity = 0.92017861
# T = 30    Fidelity = 0.98113553
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Symmetric
# lambda : 2.000
# ================================================================================
# Minimum path gap = 1.44257094e-05
# T = 1     Fidelity = 0.00396321
# T = 2     Fidelity = 0.02467360
# T = 5     Fidelity = 0.29523663
# T = 10    Fidelity = 0.85799968
# T = 20    Fidelity = 0.92052729
# T = 30    Fidelity = 0.98400011
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.100
# ================================================================================
# Minimum path gap = 8.67181393e-01
# T = 1     Fidelity = 0.62949858
# T = 2     Fidelity = 0.65796827
# T = 5     Fidelity = 0.71352814
# T = 10    Fidelity = 0.76686053
# T = 20    Fidelity = 0.83234912
# T = 30    Fidelity = 0.87194355
# T = 40    Fidelity = 0.90023124
# T = 50    Fidelity = 0.91995556
# T = 75    Fidelity = 0.95058536
# T = 100   Fidelity = 0.96479697
# T = 125   Fidelity = 0.97361144
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.139
# ================================================================================
# Minimum path gap = 8.41737733e-01
# T = 1     Fidelity = 0.63720757
# T = 2     Fidelity = 0.66587776
# T = 5     Fidelity = 0.71754765
# T = 10    Fidelity = 0.76874382
# T = 20    Fidelity = 0.83160140
# T = 30    Fidelity = 0.86943447
# T = 40    Fidelity = 0.89686687
# T = 50    Fidelity = 0.91614160
# T = 75    Fidelity = 0.94695838
# T = 100   Fidelity = 0.96204265
# T = 125   Fidelity = 0.97180610
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.178
# ================================================================================
# Minimum path gap = 8.09223126e-01
# T = 1     Fidelity = 0.64808457
# T = 2     Fidelity = 0.67718373
# T = 5     Fidelity = 0.72596238
# T = 10    Fidelity = 0.77244437
# T = 20    Fidelity = 0.83110455
# T = 30    Fidelity = 0.86754210
# T = 40    Fidelity = 0.89318762
# T = 50    Fidelity = 0.91211812
# T = 75    Fidelity = 0.94224249
# T = 100   Fidelity = 0.96036257
# T = 125   Fidelity = 0.96628244
# T = 150   Fidelity = 0.97277686
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.216
# ================================================================================
# Minimum path gap = 7.48494613e-01
# T = 1     Fidelity = 0.66344025
# T = 2     Fidelity = 0.69388696
# T = 5     Fidelity = 0.73864122
# T = 10    Fidelity = 0.78091449
# T = 20    Fidelity = 0.83279846
# T = 30    Fidelity = 0.86638176
# T = 40    Fidelity = 0.89033508
# T = 50    Fidelity = 0.90795698
# T = 75    Fidelity = 0.93706447
# T = 100   Fidelity = 0.95357046
# T = 125   Fidelity = 0.96594930
# T = 150   Fidelity = 0.96555499
# T = 175   Fidelity = 0.97008810
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.255
# ================================================================================
# Minimum path gap = 6.68809100e-01
# T = 1     Fidelity = 0.68403679
# T = 2     Fidelity = 0.71959876
# T = 5     Fidelity = 0.75931453
# T = 10    Fidelity = 0.79553151
# T = 20    Fidelity = 0.84080385
# T = 30    Fidelity = 0.86902613
# T = 40    Fidelity = 0.88961254
# T = 50    Fidelity = 0.90499869
# T = 75    Fidelity = 0.93234858
# T = 100   Fidelity = 0.94780725
# T = 125   Fidelity = 0.95966723
# T = 150   Fidelity = 0.96723930
# T = 175   Fidelity = 0.96835357
# T = 200   Fidelity = 0.96929764
# T = 225   Fidelity = 0.97482574
#
# Minimum T for Fidelity >= 0.97 : 225
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.294
# ================================================================================
# Minimum path gap = 5.68446052e-01
# T = 1     Fidelity = 0.70408124
# T = 2     Fidelity = 0.75741979
# T = 5     Fidelity = 0.79882198
# T = 10    Fidelity = 0.82999852
# T = 20    Fidelity = 0.86298082
# T = 30    Fidelity = 0.88369235
# T = 40    Fidelity = 0.89943409
# T = 50    Fidelity = 0.91115847
# T = 75    Fidelity = 0.93188111
# T = 100   Fidelity = 0.94660088
# T = 125   Fidelity = 0.95660964
# T = 150   Fidelity = 0.96007215
# T = 175   Fidelity = 0.95931228
# T = 200   Fidelity = 0.96159701
# T = 225   Fidelity = 0.96932690
# T = 250   Fidelity = 0.96790257
# T = 275   Fidelity = 0.96477100
# T = 300   Fidelity = 0.97130653
#
# Minimum T for Fidelity >= 0.97 : 300
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.333
# ================================================================================
# Minimum path gap = 4.61790996e-01
# T = 1     Fidelity = 0.68036155
# T = 2     Fidelity = 0.78494294
# T = 5     Fidelity = 0.85404286
# T = 10    Fidelity = 0.88907497
# T = 20    Fidelity = 0.91353537
# T = 30    Fidelity = 0.92501766
# T = 40    Fidelity = 0.93433554
# T = 50    Fidelity = 0.94009440
# T = 75    Fidelity = 0.95207916
# T = 100   Fidelity = 0.95879930
# T = 125   Fidelity = 0.96442604
# T = 150   Fidelity = 0.96749664
# T = 175   Fidelity = 0.97449233
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.371
# ================================================================================
# Minimum path gap = 3.93901503e-01
# T = 1     Fidelity = 0.49785914
# T = 2     Fidelity = 0.68380837
# T = 5     Fidelity = 0.84696679
# T = 10    Fidelity = 0.93228870
# T = 20    Fidelity = 0.96966020
# T = 30    Fidelity = 0.97839355
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.410
# ================================================================================
# Minimum path gap = 3.69620878e-01
# T = 1     Fidelity = 0.25150363
# T = 2     Fidelity = 0.46037978
# T = 5     Fidelity = 0.74093513
# T = 10    Fidelity = 0.91318834
# T = 20    Fidelity = 0.98498221
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.449
# ================================================================================
# Minimum path gap = 3.50304986e-01
# T = 1     Fidelity = 0.12394626
# T = 2     Fidelity = 0.30990787
# T = 5     Fidelity = 0.68634683
# T = 10    Fidelity = 0.95301256
# T = 20    Fidelity = 0.99061628
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.488
# ================================================================================
# Minimum path gap = 3.33860714e-01
# T = 1     Fidelity = 0.07194173
# T = 2     Fidelity = 0.23333906
# T = 5     Fidelity = 0.73992772
# T = 10    Fidelity = 0.98621342
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.527
# ================================================================================
# Minimum path gap = 3.19938628e-01
# T = 1     Fidelity = 0.05002363
# T = 2     Fidelity = 0.19317718
# T = 5     Fidelity = 0.86270460
# T = 10    Fidelity = 0.96532054
# T = 20    Fidelity = 0.99364055
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.565
# ================================================================================
# Minimum path gap = 3.07507538e-01
# T = 1     Fidelity = 0.04162119
# T = 2     Fidelity = 0.17397011
# T = 5     Fidelity = 0.95409067
# T = 10    Fidelity = 0.94104951
# T = 20    Fidelity = 0.99446717
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.604
# ================================================================================
# Minimum path gap = 2.96125952e-01
# T = 1     Fidelity = 0.04198072
# T = 2     Fidelity = 0.17351785
# T = 5     Fidelity = 0.95330331
# T = 10    Fidelity = 0.97519727
#
# Minimum T for Fidelity >= 0.97 : 10
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.643
# ================================================================================
# Minimum path gap = 2.85636403e-01
# T = 1     Fidelity = 0.05175357
# T = 2     Fidelity = 0.19684269
# T = 5     Fidelity = 0.89035507
# T = 10    Fidelity = 0.95558089
# T = 20    Fidelity = 0.98596541
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.682
# ================================================================================
# Minimum path gap = 2.75952394e-01
# T = 1     Fidelity = 0.07379563
# T = 2     Fidelity = 0.24916935
# T = 5     Fidelity = 0.83961232
# T = 10    Fidelity = 0.90304016
# T = 20    Fidelity = 0.98547290
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.720
# ================================================================================
# Minimum path gap = 2.66993394e-01
# T = 1     Fidelity = 0.10388618
# T = 2     Fidelity = 0.31484692
# T = 5     Fidelity = 0.83899666
# T = 10    Fidelity = 0.90630395
# T = 20    Fidelity = 0.99739660
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.759
# ================================================================================
# Minimum path gap = 2.58678635e-01
# T = 1     Fidelity = 0.12798240
# T = 2     Fidelity = 0.36065402
# T = 5     Fidelity = 0.86229530
# T = 10    Fidelity = 0.93165432
# T = 20    Fidelity = 0.99899999
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.798
# ================================================================================
# Minimum path gap = 2.50935075e-01
# T = 1     Fidelity = 0.14154517
# T = 2     Fidelity = 0.38087171
# T = 5     Fidelity = 0.88348929
# T = 10    Fidelity = 0.94702727
# T = 20    Fidelity = 0.99711487
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.837
# ================================================================================
# Minimum path gap = 2.43704173e-01
# T = 1     Fidelity = 0.14933722
# T = 2     Fidelity = 0.38821009
# T = 5     Fidelity = 0.89617040
# T = 10    Fidelity = 0.95178880
# T = 20    Fidelity = 0.99645983
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.876
# ================================================================================
# Minimum path gap = 2.36944606e-01
# T = 1     Fidelity = 0.15559984
# T = 2     Fidelity = 0.39199310
# T = 5     Fidelity = 0.90119336
# T = 10    Fidelity = 0.95157796
# T = 20    Fidelity = 0.99617532
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.914
# ================================================================================
# Minimum path gap = 2.30631967e-01
# T = 1     Fidelity = 0.16233659
# T = 2     Fidelity = 0.39626744
# T = 5     Fidelity = 0.90111193
# T = 10    Fidelity = 0.94924486
# T = 20    Fidelity = 0.99536883
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.953
# ================================================================================
# Minimum path gap = 2.24756925e-01
# T = 1     Fidelity = 0.17011839
# T = 2     Fidelity = 0.40212324
# T = 5     Fidelity = 0.89838503
# T = 10    Fidelity = 0.94587719
# T = 20    Fidelity = 0.99389936
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 0.992
# ================================================================================
# Minimum path gap = 2.19322771e-01
# T = 1     Fidelity = 0.17873253
# T = 2     Fidelity = 0.40918450
# T = 5     Fidelity = 0.89477754
# T = 10    Fidelity = 0.94210067
# T = 20    Fidelity = 0.99172293
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.031
# ================================================================================
# Minimum path gap = 2.14342798e-01
# T = 1     Fidelity = 0.18758163
# T = 2     Fidelity = 0.41644002
# T = 5     Fidelity = 0.89116677
# T = 10    Fidelity = 0.93814524
# T = 20    Fidelity = 0.98874998
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.069
# ================================================================================
# Minimum path gap = 2.09837646e-01
# T = 1     Fidelity = 0.19597464
# T = 2     Fidelity = 0.42278329
# T = 5     Fidelity = 0.88766587
# T = 10    Fidelity = 0.93388758
# T = 20    Fidelity = 0.98478695
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.108
# ================================================================================
# Minimum path gap = 2.05832643e-01
# T = 1     Fidelity = 0.20333715
# T = 2     Fidelity = 0.42735383
# T = 5     Fidelity = 0.88392426
# T = 10    Fidelity = 0.92899361
# T = 20    Fidelity = 0.97960629
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.147
# ================================================================================
# Minimum path gap = 2.02355174e-01
# T = 1     Fidelity = 0.20931600
# T = 2     Fidelity = 0.42967561
# T = 5     Fidelity = 0.87943554
# T = 10    Fidelity = 0.92310484
# T = 20    Fidelity = 0.97302045
#
# Minimum T for Fidelity >= 0.97 : 20
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.186
# ================================================================================
# Minimum path gap = 1.99432132e-01
# T = 1     Fidelity = 0.21378116
# T = 2     Fidelity = 0.42962885
# T = 5     Fidelity = 0.87374867
# T = 10    Fidelity = 0.91595982
# T = 20    Fidelity = 0.96490322
# T = 30    Fidelity = 0.97606109
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.224
# ================================================================================
# Minimum path gap = 1.97087558e-01
# T = 1     Fidelity = 0.21676682
# T = 2     Fidelity = 0.42733945
# T = 5     Fidelity = 0.86656718
# T = 10    Fidelity = 0.90744560
# T = 20    Fidelity = 0.95519372
# T = 30    Fidelity = 0.97012972
#
# Minimum T for Fidelity >= 0.97 : 30
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.263
# ================================================================================
# Minimum path gap = 1.95340561e-01
# T = 1     Fidelity = 0.21840015
# T = 2     Fidelity = 0.42306338
# T = 5     Fidelity = 0.85776712
# T = 10    Fidelity = 0.89759801
# T = 20    Fidelity = 0.94395517
# T = 30    Fidelity = 0.96271564
# T = 40    Fidelity = 0.96479032
# T = 50    Fidelity = 0.96627806
# T = 75    Fidelity = 0.97624430
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.302
# ================================================================================
# Minimum path gap = 1.94203669e-01
# T = 1     Fidelity = 0.21884601
# T = 2     Fidelity = 0.41710386
# T = 5     Fidelity = 0.84737223
# T = 10    Fidelity = 0.88656029
# T = 20    Fidelity = 0.93141407
# T = 30    Fidelity = 0.95368470
# T = 40    Fidelity = 0.95880438
# T = 50    Fidelity = 0.95926994
# T = 75    Fidelity = 0.97241483
#
# Minimum T for Fidelity >= 0.97 : 75
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.341
# ================================================================================
# Minimum path gap = 1.93681684e-01
# T = 1     Fidelity = 0.21827445
# T = 2     Fidelity = 0.40976554
# T = 5     Fidelity = 0.83551544
# T = 10    Fidelity = 0.87453342
# T = 20    Fidelity = 0.91792249
# T = 30    Fidelity = 0.94304260
# T = 40    Fidelity = 0.95216403
# T = 50    Fidelity = 0.95289133
# T = 75    Fidelity = 0.96707870
# T = 100   Fidelity = 0.96922730
# T = 125   Fidelity = 0.97579020
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.380
# ================================================================================
# Minimum path gap = 1.93771116e-01
# T = 1     Fidelity = 0.21684604
# T = 2     Fidelity = 0.40133471
# T = 5     Fidelity = 0.82240254
# T = 10    Fidelity = 0.86174690
# T = 20    Fidelity = 0.90387361
# T = 30    Fidelity = 0.93092785
# T = 40    Fidelity = 0.94435692
# T = 50    Fidelity = 0.94702613
# T = 75    Fidelity = 0.95953967
# T = 100   Fidelity = 0.96428181
# T = 125   Fidelity = 0.97288213
#
# Minimum T for Fidelity >= 0.97 : 125
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.418
# ================================================================================
# Minimum path gap = 1.94460196e-01
# T = 1     Fidelity = 0.21470787
# T = 2     Fidelity = 0.39207368
# T = 5     Fidelity = 0.80828338
# T = 10    Fidelity = 0.84844446
# T = 20    Fidelity = 0.88963418
# T = 30    Fidelity = 0.91762466
# T = 40    Fidelity = 0.93494503
# T = 50    Fidelity = 0.94103586
# T = 75    Fidelity = 0.95078396
# T = 100   Fidelity = 0.96143782
# T = 125   Fidelity = 0.96720580
# T = 150   Fidelity = 0.97189895
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.457
# ================================================================================
# Minimum path gap = 1.95729417e-01
# T = 1     Fidelity = 0.21199417
# T = 2     Fidelity = 0.38222063
# T = 5     Fidelity = 0.79342972
# T = 10    Fidelity = 0.83486909
# T = 20    Fidelity = 0.87553592
# T = 30    Fidelity = 0.90363300
# T = 40    Fidelity = 0.92397719
# T = 50    Fidelity = 0.93429602
# T = 75    Fidelity = 0.94280969
# T = 100   Fidelity = 0.95819815
# T = 125   Fidelity = 0.96186375
# T = 150   Fidelity = 0.97024961
#
# Minimum T for Fidelity >= 0.97 : 150
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.496
# ================================================================================
# Minimum path gap = 1.97552503e-01
# T = 1     Fidelity = 0.20882802
# T = 2     Fidelity = 0.37199056
# T = 5     Fidelity = 0.77811804
# T = 10    Fidelity = 0.82124591
# T = 20    Fidelity = 0.86189254
# T = 30    Fidelity = 0.88966190
# T = 40    Fidelity = 0.91201371
# T = 50    Fidelity = 0.92639360
# T = 75    Fidelity = 0.93706966
# T = 100   Fidelity = 0.95284051
# T = 125   Fidelity = 0.95962230
# T = 150   Fidelity = 0.96597953
# T = 175   Fidelity = 0.97154529
#
# Minimum T for Fidelity >= 0.97 : 175
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.535
# ================================================================================
# Minimum path gap = 1.99897671e-01
# T = 1     Fidelity = 0.20532267
# T = 2     Fidelity = 0.36157569
# T = 5     Fidelity = 0.76261607
# T = 10    Fidelity = 0.80777106
# T = 20    Fidelity = 0.84900803
# T = 30    Fidelity = 0.87646504
# T = 40    Fidelity = 0.89982565
# T = 50    Fidelity = 0.91728278
# T = 75    Fidelity = 0.93354525
# T = 100   Fidelity = 0.94661268
# T = 125   Fidelity = 0.95836014
# T = 150   Fidelity = 0.96277308
# T = 175   Fidelity = 0.96985966
# T = 200   Fidelity = 0.97306346
#
# Minimum T for Fidelity >= 0.97 : 200
#
#
# ================================================================================
# CASE   : Weak SSB optimised
# lambda : 1.573
# ================================================================================
# Minimum path gap = 2.02729043e-01
# T = 1     Fidelity = 0.20158188
# T = 2     Fidelity = 0.35114512
# T = 5     Fidelity = 0.74717216
# T = 10    Fidelity = 0.79461081
# ...
# Symmetric      0.255     175       0.9839230787      4.99212419e-06    None        None        None
# Symmetric      0.294     150       0.9853731553      1.70864235e-06    None        None        None
# Symmetric      0.333     125       0.9700809470      6.70006882e-07    None        None        None
# Symmetric      0.371     125       0.9771140515      3.24972876e-07    None        None        None
# Symmetric      0.410     125       0.9861155485      2.07180341e-07    None        None        None
# Symmetric      0.449     100       0.9770975610      2.05022068e-07    None        None        None
# Symmetric      0.488     100       0.9822464483      2.57926392e-07    None        None        None
# Symmetric      0.527     100       0.9876012258      2.94157985e-07    None        None        None
# Symmetric      0.565     100       0.9896396604      2.95938146e-07    None        None        None
# Symmetric      0.604     75        0.9776079060      2.82226628e-07    None        None        None
# Symmetric      0.643     75        0.9884303981      2.43063428e-07    None        None        None
# Symmetric      0.682     75        0.9901989692      2.04773404e-07    None        None        None
# Symmetric      0.720     75        0.9814725827      1.74603617e-07    None        None        None
# Symmetric      0.759     75        0.9822487345      1.39702905e-07    None        None        None
# Symmetric      0.798     75        0.9880963088      1.13020056e-07    None        None        None
# Symmetric      0.837     75        0.9938799038      9.49304635e-08    None        None        None
# Symmetric      0.876     75        0.9977295494      8.30149158e-08    None        None        None
# Symmetric      0.914     75        0.9986047899      7.17057125e-08    None        None        None
# Symmetric      0.953     50        0.9718357161      6.68735476e-08    None        None        None
# Symmetric      0.992     50        0.9792544864      6.73812659e-08    None        None        None
# Symmetric      1.031     50        0.9855676353      7.12119919e-08    None        None        None
# Symmetric      1.069     40        0.9752912851      7.95011506e-08    None        None        None
# Symmetric      1.108     40        0.9812287694      9.36478797e-08    None        None        None
# Symmetric      1.147     40        0.9854238056      1.12376363e-07    None        None        None
# Symmetric      1.186     40        0.9879943602      1.36928898e-07    None        None        None
# Symmetric      1.224     40        0.9891240586      1.65133243e-07    None        None        None
# Symmetric      1.263     30        0.9712273497      1.92560618e-07    None        None        None
# Symmetric      1.302     30        0.9725205588      2.17451144e-07    None        None        None
# Symmetric      1.341     30        0.9725310497      2.38093912e-07    None        None        None
# Symmetric      1.380     30        0.9715741750      2.53076482e-07    None        None        None
# Symmetric      1.418     40        0.9840966306      2.63966163e-07    None        None        None
# Symmetric      1.457     40        0.9832157333      2.70885549e-07    None        None        None
# Symmetric      1.496     40        0.9828461792      2.74193723e-07    None        None        None
# Symmetric      1.535     40        0.9830346644      2.92180487e-07    None        None        None
# Symmetric      1.573     40        0.9837715643      3.47743476e-07    None        None        None
# Symmetric      1.612     40        0.9850025143      4.58881918e-07    None        None        None
# Symmetric      1.651     40        0.9866375014      6.47311111e-07    None        None        None
# Symmetric      1.690     40        0.9885593674      9.40815950e-07    None        None        None
# Symmetric      1.729     40        0.9906336513      1.37579473e-06    None        None        None
# Symmetric      1.767     40        0.9927207031      1.99980370e-06    None        None        None
# Symmetric      1.806     30        0.9700190420      2.87406774e-06    None        None        None
# Symmetric      1.845     30        0.9725846222      4.07600310e-06    None        None        None
# Symmetric      1.884     30        0.9753495798      5.70182503e-06    None        None        None
# Symmetric      1.922     30        0.9782269639      7.86929838e-06    None        None        None
# Symmetric      1.961     30        0.9811355268      1.07206599e-05    None        None        None
# Symmetric      2.000     30        0.9840001055      1.44257094e-05    None        None        None
# Weak SSB optimised0.100     125       0.9736114398      8.67181393e-01    None        None        None
# Weak SSB optimised0.139     125       0.9718061015      8.41737733e-01    None        None        None
# Weak SSB optimised0.178     150       0.9727768584      8.09223126e-01    None        None        None
# Weak SSB optimised0.216     175       0.9700880958      7.48494613e-01    None        None        None
# Weak SSB optimised0.255     225       0.9748257380      6.68809100e-01    None        None        None
# Weak SSB optimised0.294     300       0.9713065253      5.68446052e-01    None        None        None
# Weak SSB optimised0.333     175       0.9744923315      4.61790996e-01    None        None        None
# Weak SSB optimised0.371     30        0.9783935490      3.93901503e-01    None        None        None
# Weak SSB optimised0.410     20        0.9849822112      3.69620878e-01    None        None        None
# Weak SSB optimised0.449     20        0.9906162835      3.50304986e-01    None        None        None
# Weak SSB optimised0.488     10        0.9862134223      3.33860714e-01    None        None        None
# Weak SSB optimised0.527     20        0.9936405452      3.19938628e-01    None        None        None
# Weak SSB optimised0.565     20        0.9944671675      3.07507538e-01    None        None        None
# Weak SSB optimised0.604     10        0.9751972661      2.96125952e-01    None        None        None
# Weak SSB optimised0.643     20        0.9859654054      2.85636403e-01    None        None        None
# Weak SSB optimised0.682     20        0.9854729016      2.75952394e-01    None        None        None
# Weak SSB optimised0.720     20        0.9973966046      2.66993394e-01    None        None        None
# Weak SSB optimised0.759     20        0.9989999897      2.58678635e-01    None        None        None
# Weak SSB optimised0.798     20        0.9971148731      2.50935075e-01    None        None        None
# Weak SSB optimised0.837     20        0.9964598284      2.43704173e-01    None        None        None
# Weak SSB optimised0.876     20        0.9961753168      2.36944606e-01    None        None        None
# Weak SSB optimised0.914     20        0.9953688264      2.30631967e-01    None        None        None
# Weak SSB optimised0.953     20        0.9938993580      2.24756925e-01    None        None        None
# Weak SSB optimised0.992     20        0.9917229306      2.19322771e-01    None        None        None
# Weak SSB optimised1.031     20        0.9887499826      2.14342798e-01    None        None        None
# Weak SSB optimised1.069     20        0.9847869501      2.09837646e-01    None        None        None
# Weak SSB optimised1.108     20        0.9796062910      2.05832643e-01    None        None        None
# Weak SSB optimised1.147     20        0.9730204492      2.02355174e-01    None        None        None
# Weak SSB optimised1.186     30        0.9760610876      1.99432132e-01    None        None        None
# Weak SSB optimised1.224     30        0.9701297203      1.97087558e-01    None        None        None
# Weak SSB optimised1.263     75        0.9762443010      1.95340561e-01    None        None        None
# Weak SSB optimised1.302     75        0.9724148262      1.94203669e-01    None        None        None
# Weak SSB optimised1.341     125       0.9757901995      1.93681684e-01    None        None        None
# Weak SSB optimised1.380     125       0.9728821307      1.93771116e-01    None        None        None
# Weak SSB optimised1.418     150       0.9718989504      1.94460196e-01    None        None        None
# Weak SSB optimised1.457     150       0.9702496126      1.95729417e-01    None        None        None
# Weak SSB optimised1.496     175       0.9715452875      1.97552503e-01    None        None        None
# Weak SSB optimised1.535     200       0.9730634587      1.99897671e-01    None        None        None
# Weak SSB optimised1.573     200       0.9730689865      2.02729043e-01    None        None        None
# Weak SSB optimised1.612     200       0.9714918816      2.06008070e-01    None        None        None
# Weak SSB optimised1.651     200       0.9722777324      2.09694873e-01    None        None        None
# Weak SSB optimised1.690     200       0.9737851162      2.13749401e-01    None        None        None
# Weak SSB optimised1.729     200       0.9743487512      2.18132396e-01    None        None        None
# Weak SSB optimised1.767     175       0.9712120323      2.22806129e-01    None        None        None
# Weak SSB optimised1.806     175       0.9734909808      2.27734927e-01    None        None        None
# Weak SSB optimised1.845     175       0.9753060271      2.32885520e-01    None        None        None
# Weak SSB optimised1.884     150       0.9708682446      2.38227223e-01    None        None        None
# Weak SSB optimised1.922     150       0.9743447414      2.42359083e-01    None        None        None
# Weak SSB optimised1.961     150       0.9774880289      2.45891509e-01    None        None        None
# Weak SSB optimised2.000     125       0.9713669785      2.48783584e-01    None        None        None
# Strong SSB     0.100     1         0.9935855087      3.59472102e+00    None        None        None
# Strong SSB     0.139     1         0.9921692769      3.21657560e+00    None        None        None
# Strong SSB     0.178     1         0.9889132734      2.82952155e+00    None        None        None
# Strong SSB     0.216     1         0.9815245958      2.44438071e+00    None        None        None
# Strong SSB     0.255     2         0.9837242474      2.07127401e+00    None        None        None
# Strong SSB     0.294     5         0.9916194487      1.72463158e+00    None        None        None
# Strong SSB     0.333     5         0.9715734623      1.42925187e+00    None        None        None
# Strong SSB     0.371     10        0.9728883461      1.22618356e+00    None        None        None
# Strong SSB     0.410     20        0.9878688940      1.16150566e+00    None        None        None
# Strong SSB     0.449     20        0.9908081227      1.22929553e+00    None        None        None
# Strong SSB     0.488     10        0.9763685318      1.28380403e+00    None        None        None
# Strong SSB     0.527     10        0.9928859870      1.31979522e+00    None        None        None
# Strong SSB     0.565     10        0.9721213233      1.34648227e+00    None        None        None
# Strong SSB     0.604     5         0.9804384064      1.36719913e+00    None        None        None
# Strong SSB     0.643     10        0.9804503582      1.38335344e+00    None        None        None
# Strong SSB     0.682     20        0.9994072662      1.39587381e+00    None        None        None
# Strong SSB     0.720     20        0.9987062848      1.40543484e+00    None        None        None
# Strong SSB     0.759     20        0.9898388968      1.40926031e+00    None        None        None
# Strong SSB     0.798     10        0.9727238449      1.40588304e+00    None        None        None
# Strong SSB     0.837     10        0.9834662236      1.40154174e+00    None        None        None
# Strong SSB     0.876     10        0.9852501404      1.39619424e+00    None        None        None
# Strong SSB     0.914     10        0.9844179764      1.39002869e+00    None        None        None
# Strong SSB     0.953     10        0.9830595132      1.38327763e+00    None        None        None
# Strong SSB     0.992     10        0.9818601899      1.37612629e+00    None        None        None
# Strong SSB     1.031     10        0.9811778526      1.36868643e+00    None        None        None
# Strong SSB     1.069     10        0.9811513094      1.36100379e+00    None        None        None
# Strong SSB     1.108     10        0.9816671208      1.35307787e+00    None        None        None
# Strong SSB     1.147     10        0.9824643456      1.34488277e+00    None        None        None
# Strong SSB     1.186     10        0.9832769044      1.33638429e+00    None        None        None
# Strong SSB     1.224     10        0.9839268320      1.32755217e+00    None        None        None
# Strong SSB     1.263     10        0.9843425128      1.31836753e+00    None        None        None
# Strong SSB     1.302     10        0.9845288689      1.30882658e+00    None        None        None
# Strong SSB     1.341     10        0.9845281250      1.29894142e+00    None        None        None
# Strong SSB     1.380     10        0.9843922810      1.28873886e+00    None        None        None
# Strong SSB     1.418     10        0.9841693923      1.27825795e+00    None        None        None
# Strong SSB     1.457     10        0.9838989073      1.26754693e+00    None        None        None
# Strong SSB     1.496     10        0.9836106714      1.25665993e+00    None        None        None
# Strong SSB     1.535     10        0.9833257573      1.24565388e+00    None        None        None
# Strong SSB     1.573     10        0.9830577890      1.23458579e+00    None        None        None
# Strong SSB     1.612     10        0.9828142580      1.22351059e+00    None        None        None
# Strong SSB     1.651     10        0.9825978919      1.21247951e+00    None        None        None
# Strong SSB     1.690     10        0.9824079334      1.20153900e+00    None        None        None
# Strong SSB     1.729     10        0.9822412970      1.19073018e+00    None        None        None
# Strong SSB     1.767     10        0.9820935444      1.18008858e+00    None        None        None
# Strong SSB     1.806     10        0.9819596908      1.16964426e+00    None        None        None
# Strong SSB     1.845     10        0.9818348603      1.15942206e+00    None        None        None
# Strong SSB     1.884     10        0.9817147784      1.14944201e+00    None        None        None
# Strong SSB     1.922     10        0.9815960953      1.13971981e+00    None        None        None
# Strong SSB     1.961     10        0.9814765583      1.13026733e+00    None        None        None
# Strong SSB     2.000     10        0.9813550338      1.12109308e+00    None        None        None

# %%
# ============================================================
# Plot T_min vs lambda
# ============================================================

import matplotlib.pyplot as plt

# ============================================================
# Separate data by case
# ============================================================

case_data = {}

for r in adiabatic_results:

    case = r['case']

    if case not in case_data:

        case_data[case] = {

            'lambda': [],

            'Tmin': []
        }

    case_data[case]['lambda'].append(

        r['lambda']
    )

    case_data[case]['Tmin'].append(

        r['Tmin']
    )

# ============================================================
# Plot
# ============================================================
case_colors = {
    "Symmetric": "blue",
 #   "Weak SSB": "orange",
    "Weak SSB optimised": "green",
    "Strong SSB": "red"
}
#

plt.figure(figsize=(8,6))

for case, d in case_data.items():

    plt.plot(

        d['lambda'],

        d['Tmin'],

        marker='o',

        linewidth=2,
        
        color=case_colors[case],

        label=case
    )

# ============================================================
# Labels
# ============================================================

plt.xlabel(r'$\lambda$', fontsize=14)

plt.ylabel(r'$T_{\min}$', fontsize=14)

plt.title(

    r'Minimum Adiabatic Time $T_{\min}$ '
    r'for Fidelity $\geq 0.97$, $m_{0}^{2}=-2.0$',

    fontsize=14
)

plt.grid(True)

plt.legend()

plt.tight_layout()
plt.savefig(
    "HEA_adiabatic time vs lambda.pdf",
    bbox_inches='tight'
)
plt.show()

# %%
# ============================================================
# GAP ANALYSIS
# ============================================================

from scipy.sparse.linalg import eigsh

gap_sym = []
gap_weak_opt = []
gap_strong = []

# ------------------------------------------------------------
# Symmetric
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.0,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_sym.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Weak SSB optimized
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=5*1e-2,          # optimized value
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_weak_opt.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Strong SSB
# ------------------------------------------------------------

for lam in lambda_list:

    H = two_site_hs(
        nq=nq_site,
        mu=mu,
        mI2=-1.0,
        m0_sq=-2.0,
        lam=lam,
        f=0.5,
        s=1.0
    )

    evals, _ = eigsh(H, k=2, which='SA')

    evals = np.sort(evals)

    gap_strong.append(evals[1] - evals[0])

# ------------------------------------------------------------
# Critical λ
# ------------------------------------------------------------

lamc_sym = lambda_list[np.argmin(gap_sym)]
lamc_weak = lambda_list[np.argmin(gap_weak_opt)]
lamc_strong = lambda_list[np.argmin(gap_strong)]

print("\nGap minimum estimator")
print("----------------------")
print(f"Symmetric       λc = {lamc_sym:.4f}")
print(f"Weak SSB opt    λc = {lamc_weak:.4f}")
print(f"Strong SSB      λc = {lamc_strong:.4f}")
# Out:
# Gap minimum estimator
# ----------------------
# Symmetric       λc = 1.2245
# Weak SSB opt    λc = 2.0000
# Strong SSB      λc = 0.7204

# %%
# ============================================================
# Plot : Gap vs lambda
# ============================================================

plt.figure(figsize=(7,5))

line1,=plt.plot(lambda_list, gap_sym,
         'o-', label='Symmetric',color='b')

line2,=plt.plot(lambda_list, gap_weak_opt,
         's-', label='Weak SSB optimised ', color='g')

line3,=plt.plot(lambda_list, gap_strong,
         '^-', label='Strong SSB',color='r')

plt.axvline(lamc_sym,
            ls='--',
           color=line1.get_color())

plt.axvline(lamc_weak,
            ls='--',
           color=line2.get_color())

plt.axvline(lamc_strong,
            ls='--',
           color=line3.get_color())

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$\Delta E$')
plt.title(r'Energy Gap, $m_{0}^{2}=-2.0$')
plt.legend()

plt.tight_layout()
plt.show()

# %%
print(adiabatic_results[0].keys())

# ============================================================
# <phi> from evolved state
# ============================================================

M_sym = []

M_weak_opt = []

M_strong = []
lambda_sym = []
lambda_weak_opt = []
lambda_strong = []
for r in adiabatic_results:

    case = r['case']

    if case not in [

        "Symmetric",

        "Weak SSB optimised",

        "Strong SSB"
    ]:

        continue

    lam = r['lambda']

    Tmin = r['Tmin']
    # Skip if no Tmin was found

    if Tmin is None:
        continue

    if np.isnan(Tmin):
        continue

    mI2 = r['mI2']

    f = r['f']

    match = next(
        x for x in all_results
        if (
            x['case'] == case
            and np.isclose(x['lambda'], lam)
        )
    )

    psi_exact = match['psi_exact']

    psi_final = adiabatic_circuit_evolution(

        initial_state=psi_exact,

        nq=nq_site,

        T=Tmin,

        mu=mu,

        mI2=mI2,

        m0_sq=-2.0,

        lam=lam,

        f=f,

        nsteps=100
    )

    M = np.real(

        np.vdot(

            psi_final,

            Phi_avg @ psi_final
        )
    )

    if case == "Symmetric":

        M_sym.append(M)
        lambda_sym.append(lam)

    elif case == "Weak SSB optimised":

        M_weak_opt.append(M)
        lambda_weak_opt.append(lam)

    elif case == "Strong SSB":

        M_strong.append(M)
        lambda_strong.append(lam)
# Out:
# dict_keys(['case', 'lambda', 'mI2', 'f', 'Tmin', 'best_fidelity', 'delta_min', 'P0', 'P1', 'P01', 'final_gap'])

# %%
# ============================================================
# λc from inflection point
# ============================================================

# First derivatives

dM_sym = np.gradient(M_sym, lambda_sym)

dM_weak = np.gradient(M_weak_opt, lambda_weak_opt)

dM_strong = np.gradient(M_strong, lambda_strong)

# Second derivatives

d2M_sym = np.gradient(dM_sym, lambda_sym)

d2M_weak = np.gradient(dM_weak, lambda_weak_opt)

d2M_strong = np.gradient(dM_strong, lambda_strong)

# Third derivatives

d3M_sym = np.gradient(d2M_sym, lambda_sym)

d3M_weak = np.gradient(d2M_weak, lambda_weak_opt)

d3M_strong = np.gradient(d2M_strong, lambda_strong)


def find_lambda_c(lams, d2M, d3M):

    for i in range(len(lams)-1):

        if d2M[i] * d2M[i+1] <= 0:

            if d3M[i] < 0:

                x1 = lams[i]
                x2 = lams[i+1]

                y1 = d2M[i]
                y2 = d2M[i+1]

                return x1 - y1*(x2-x1)/(y2-y1)

    return np.nan

lamc_M_sym = find_lambda_c(
    lambda_sym,
    d2M_sym,
    d3M_sym
)

lamc_M_weak = find_lambda_c(
    lambda_weak_opt,
    d2M_weak,
    d3M_weak
)

lamc_M_strong = find_lambda_c(
    lambda_strong,
    d2M_strong,
    d3M_strong
)


########## Routine to plot d2M/d\lambda2


# ============================================================
# Plot : d²<phi>/dλ² vs λ
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    d2M_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    d2M_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    d2M_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# λc positions from inflection-point analysis

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

# Zero line

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1.5
)

plt.xlabel(r'$\lambda$')

plt.ylabel(
    r'$d^2\langle\phi\rangle/d\lambda^2$'
)

plt.title(
    r'Inflection-point analysis'
)

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : <phi> vs lambda
# ============================================================

plt.figure(figsize=(8,6))

plt.plot(

    lambda_sym,

    M_sym,

    'o-',

    label='Symmetric',
    color='b'
)

plt.plot(

    lambda_weak_opt,

    M_weak_opt,

    's-',

    label='Weak SSB optimised',
    color='g'
)

plt.plot(

    lambda_strong,

    M_strong,

    '^-',

    label='Strong SSB',
    color='r'
)

plt.xlabel(r'$\lambda$')

plt.ylabel(r'$\langle \phi \rangle$')

plt.title(r'Order Parameter, $m_{0}^{2}=-2.0$')

plt.grid(True)

plt.legend()

plt.tight_layout()

plt.show()

# %%
# ============================================================
# Plot : d<phi>/dlambda vs lambda
# ============================================================

plt.figure(figsize=(8,6))

line1, = plt.plot(
    lambda_sym,
    dM_sym,
    'o-',
    label='Symmetric',
    color='b'
)

line2, = plt.plot(
    lambda_weak_opt,
    dM_weak,
    's-',
    label='Weak SSB optimised',
    color='g'
)

line3, = plt.plot(
    lambda_strong,
    dM_strong,
    '^-',
    label='Strong SSB',
    color='r'
)

# Critical lambdas

plt.axvline(
    lamc_M_sym,
    linestyle='--',
    color=line1.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_weak,
    linestyle='--',
    color=line2.get_color(),
    alpha=0.8
)

plt.axvline(
    lamc_M_strong,
    linestyle='--',
    color=line3.get_color(),
    alpha=0.8
)

plt.axhline(
    0,
    color='k',
    linestyle=':',
    linewidth=1
)

plt.xlabel(r'$\lambda$')
plt.ylabel(r'$d\langle\phi\rangle/d\lambda$')

plt.title(
    r'Susceptibility-like quantity $d\langle\phi\rangle/d\lambda$, $m_{0}^{2}=-2.0$'
)

plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
