# %%
import numpy as np
from scipy.linalg import eigh
from scipy.optimize import minimize
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

# %%
# =========================================================
# 1. Field Operators
# =========================================================
def field_operators(nq, mu=1.0):
    Nphi = 2**nq
    
    delta_phi = np.sqrt(2*np.pi/(Nphi * mu))
    phi_vals = np.array([delta_phi * (i - (Nphi-1)/2) for i in range(Nphi)])
    
    # Φ operator (diagonal)
    Phi = np.diag(phi_vals)
    
    # Fourier transform → Π operator
    F = np.fft.fft(np.eye(Nphi)) / np.sqrt(Nphi)
    Pi = F @ Phi @ np.conjugate(F.T)
    
    return Phi, Pi

# %%
# =========================================================
# 2. Local Hamiltonian
# =========================================================
def local_hamiltonian(nq, m2, lam, f, mu=1.0):
    Phi, Pi = field_operators(nq, mu)
    
    H = (
        0.5 * Pi @ Pi
        + 0.5 * m2 * Phi @ Phi
        + lam/24 * np.linalg.matrix_power(Phi, 4)
        + f * Phi
    )
    
    return H

# %%
# =========================================================
# 3. Ground State (Exact)
# =========================================================
def ground_state(H):
    vals, vecs = eigh(H)
    return vecs[:, 0]

# %%
# =========================================================
# 4. Variational Circuit
# =========================================================
def variational_circuit(nq, layers, params):
    qc = QuantumCircuit(nq)
    p = 0
    
    for l in range(layers):
        # Single-qubit rotations
        for q in range(nq):
            qc.ry(params[p], q)
            qc.rz(params[p+1], q)
            p += 2
        
        # Alternating CZ entanglement
        for q in range(0, nq-1, 2):
            qc.cz(q, q+1)
        for q in range(1, nq-1, 2):
            qc.cz(q, q+1)
    
    return qc

# %%
# =========================================================
# 5. Fidelity Function
# =========================================================
def fidelity(params, nq, layers, target):
    qc = variational_circuit(nq, layers, params)
    psi = Statevector.from_instruction(qc).data
    
    return -np.abs(np.dot(np.conjugate(target), psi))**2

# %%
# =========================================================
# 6. Run One Case
# =========================================================
def run_case(nq, m2, lam, f, layer_range, mu=1.0):
    H = local_hamiltonian(nq, m2, lam, f, mu)
    target = ground_state(H)
    
    fidelities = []
    
    for layers in layer_range:
        print(f"  Layers = {layers}")
        
        n_params = layers * nq * 2
        x0 = np.random.uniform(0, 2*np.pi, n_params)
        
        res = minimize(
            fidelity,
            x0,
            args=(nq, layers, target),
            method='COBYLA',
            options={'maxiter': 150}
        )
        
        fid = -res.fun
        fidelities.append(fid)
        print(f"    Fidelity = {fid:.6f}")
    
    return fidelities

# %%
# =========================================================
# 7. Define Physics Cases (Fig. 2 inspired)
# =========================================================
cases = [
    {"label": "Harmonic (λ=0)", "m2": 1.0, "lam": 0.0, "f": 0.0, "mu": 1.0},
    {"label": "Strong λ", "m2": 1.0, "lam": 100.0, "f": 0.0, "mu": 1.0},
    {"label": "small dphi", "m2": 1.0, "lam": 100.0, "f": 0.0, "mu": 4.0},
    {"label": "Neg m2 small f", "m2": -1, "lam": 0.1, "f": 1e-5, "mu": 0.25},
    {"label": "Neg m2 large f", "m2": -1, "lam": 1.0, "f": 4, "mu": 0.25},
]

# =========================================================
# 8. Run Simulation
# =========================================================
nq = 6
layer_range = range(3, 7)   # 3 → 6 layers

results = {}

for case in cases:
   # print("\nRunning case:", case["label"])
    
    fids = run_case(
        nq=nq,
        m2=case["m2"],
        lam=case["lam"],
        f=case["f"],
        mu=case["mu"],
        layer_range=layer_range
    )
    
    results[case["label"]] = fids


# =========================================================
# 9. Plot (Fig. 3 style)
# =========================================================
markers = ['o', 's', '^', 'D','.']

for i, (label, fids) in enumerate(results.items()):
    plt.plot(layer_range, fids, marker=markers[i], label=label)

plt.xlabel("Number of Entanglement Layers")
plt.ylabel("Fidelity")
plt.title("Reproduction of Fig. 3 (6 qubits)")
plt.legend()
plt.grid()
plt.show()
# Out:
# /var/folders/g6/7wnpvdrx3pq6vgv_ykqncp7w0000gn/T/ipykernel_11391/1250408802.py:15: RuntimeWarning: divide by zero encountered in matmul
#   Pi = F @ Phi @ np.conjugate(F.T)
# /var/folders/g6/7wnpvdrx3pq6vgv_ykqncp7w0000gn/T/ipykernel_11391/1250408802.py:15: RuntimeWarning: overflow encountered in matmul
#   Pi = F @ Phi @ np.conjugate(F.T)
# /var/folders/g6/7wnpvdrx3pq6vgv_ykqncp7w0000gn/T/ipykernel_11391/1250408802.py:15: RuntimeWarning: invalid value encountered in matmul
#   Pi = F @ Phi @ np.conjugate(F.T)
# /var/folders/g6/7wnpvdrx3pq6vgv_ykqncp7w0000gn/T/ipykernel_11391/2725440953.py:8: RuntimeWarning: divide by zero encountered in matmul
#   0.5 * Pi @ Pi
# /var/folders/g6/7wnpvdrx3pq6vgv_ykqncp7w0000gn/T/ipykernel_11391/2725440953.py:8: RuntimeWarning: overflow encountered in matmul
#   0.5 * Pi @ Pi
# /var/folders/g6/7wnpvdrx3pq6vgv_ykqncp7w0000gn/T/ipykernel_11391/2725440953.py:8: RuntimeWarning: invalid value encountered in matmul
#   0.5 * Pi @ Pi
# /var/folders/g6/7wnpvdrx3pq6vgv_ykqncp7w0000gn/T/ipykernel_11391/2725440953.py:9: RuntimeWarning: divide by zero encountered in matmul
#   + 0.5 * m2 * Phi @ Phi
# /var/folders/g6/7wnpvdrx3pq6vgv_ykqncp7w0000gn/T/ipykernel_11391/2725440953.py:9: RuntimeWarning: overflow encountered in matmul
#   + 0.5 * m2 * Phi @ Phi
# /var/folders/g6/7wnpvdrx3pq6vgv_ykqncp7w0000gn/T/ipykernel_11391/2725440953.py:9: RuntimeWarning: invalid value encountered in matmul
#   + 0.5 * m2 * Phi @ Phi
#   Layers = 3
#     Fidelity = 0.470941
#   Layers = 4
#     Fidelity = 0.432341
#   Layers = 5
#     Fidelity = 0.367140
#   Layers = 6
#     Fidelity = 0.384171
#   Layers = 3
#     Fidelity = 0.484746
#   Layers = 4
#     Fidelity = 0.410694
#   Layers = 5
#     Fidelity = 0.399987
#   Layers = 6
#     Fidelity = 0.441887
#   Layers = 3
#     Fidelity = 0.464846
#   Layers = 4
#     Fidelity = 0.487585
#   Layers = 5
#     Fidelity = 0.386459
#   Layers = 6
#     Fidelity = 0.410293
#   Layers = 3
#     Fidelity = 0.865789
#   Layers = 4
#     Fidelity = 0.814766
#   Layers = 5
#     Fidelity = 0.805169
#   Layers = 6
#     Fidelity = 0.359603
#   Layers = 3
#     Fidelity = 0.902602
#   Layers = 4
#     Fidelity = 0.799838
#   Layers = 5
#     Fidelity = 0.776062
#   Layers = 6
#     Fidelity = 0.675922
